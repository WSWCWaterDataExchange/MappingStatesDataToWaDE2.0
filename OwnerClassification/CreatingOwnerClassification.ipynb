# %% [markdown]
# # Creating Owner Classification Scripts

# %%
# Needed Libaraies
import os
import numpy as np
import pandas as pd
import re
from sklearn.preprocessing import MinMaxScaler

#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/WaDE Side Projects/OwnerClassification"
os.chdir(workingDir)

# Owner by State Count
ownerstateInput = "OwnerStateCount.csv"
df = pd.read_csv(ownerstateInput)
print(len(df))
df.head(3)

# ## Owner by OwnerID
# ownerstateInput = "OwnerByOwnerID.csv"
# df = pd.read_csv(ownerstateInput)
# print(len(df))
# df.head(3)
# Out:
# 510995
#                     AllocationOwner  CountOwn State
# 0                AGRIUM, U.S., INC.         1    AK
# 1                        ALASKA ZOO         1    AK
# 2  ALYESKA PIPELINE SERVICE COMPANY         7    AK

# %% [markdown]
# ## Attempt #1

# %%
# Commercial OwnerClassification keyword search list

commlist = [
"add",
"admin",
"agency",
"armour",
"assn",
"asso",
"assoc",
"associates",
"association",
"bank",
"big",
"boy scouts",
"brethern",
"bros",
"brothers",
"building",
"buttes",
"café",
"camp",
"campground",
"cattle",
"cement",
"chemical",
"chevron",
"childrens",
"club",
"co",
"cola",
"colony",
"communictn",
"communitations",
"company",
"complex",
"conference",
"consolidated",
"construction",
"consultant",
"consultants",
"contractors",
"cooperative",
"corp",
"corporation",
"corportation",
"crp",
"custer",
"dairy",
"deseret",
"ditch",
"engineering",
"engineers",
"enterprise",
"entrerpise",
"estates",
"excavating",
"express",
"exxon",
"farms",
"fellowship",
"financial",
"foundation",
"foundry",
"fuel",
"gardens",
"gas",
"golf",
"group ",
"hills",
"hoa",
"home",
"homeowners",
"hotel",
"inc",
"incorporated",
"inn",
"insurance",
"investment",
"investments",
"irr",
"irrig",
"irrigation",
"joint",
"l  c ",
"l l c",
"lake",
"lakes",
"lc",
"limited",
"livestock",
"llc",
"lllp",
"llp",
"lodge",
"logging",
"lp",
"ltd",
"management",
"manor",
"marketing",
"markets",
"materials",
"mineral",
"minerals",
"mining",
"mix",
"mobile",
"mortgage",
"municipality",
"museum",
"nursery",
"oil",
"opereation",
"opereations",
"pacific",
"pacificorp",
"partners",
"partnership",
"pc",
"petroleum",
"pipeline",
"poultry",
"power",
"preserving",
"properties",
"prtshp",
"ptnrshp",
"railroad",
"ranch",
"ranches",
"reality",
"realty",
"refining",
"resort",
"resources",
"restaurant",
"ridge",
"rural",
"science",
"sierra",
"silo",
"solutions",
"sons",
"sportsman",
"sppc",
"steel",
"stop",
"store",
"stores",
"subdivision",
"sub-division",
"surveying",
"tank",
"texaco",
"tire",
"trout",
"union",
"unocal",
"users",
"utilities",
"venture",
"village",
"vineyard",
"vineyards",
"wells",
"winery",
"works"]

# %%
# # Generic
# # ---------------------------------------------------------------------
# usalist = ["united states of america", "united state of america", "united states government", "usa", "u of a", "u s of america", "u s a", "u  s  a"]
# unList = ["unspecified" ,"unknown"]
# citylist = ["city", "town", "los angeles", "las vegas"]
# statelist = ["state", "county", "department", "auth", "authority", "transit", "cnty", "division", "district", "dist", "dept", "dept of game", "dept of transportation", "commissioners", "wildlife conservation", "waste management", "board of control"]
# ilist = ["institution", "church", "lds", "bible", "school", "catholic", "baptist", "university", "college", "institute", "methodist"]
# nalist = ["native american", "indian", "apache", "navajo", "hopi", "shoshone", "washoe", "tribe", "tribes"]
# tlist = ["trust", "trusts", "trustee", "trustees"]

# # # State List
# # # ---------------------------------------------------------------------
# # aklist = ["ak", "alaska"]
# # azlist = ["az", "arizona", "adot", "adeq"]
# # calist = ["ca", "california", "calif"]
# # colist = ["colorado"] # using 'co' already in corporation list.
# # idlist = ["id", "idaho"]
# # kslist = ["ks", "kansas"]
# # mtlist = ["mt", "montana"]
# # ndlist = ["nd", "n d", "north dakota"]
# # nelist = ["ne", "nebraska"]
# # nmlist = ["nm", "new mexico"]
# # nvlist = ["nv", "nevada"]
# # oklist = ["ok", "oklahoma"]
# # orlist = ["or", "oregon"]
# # sdlist = ["sd", "south dakota"]
# # txlist = ["tx", "texas"]
# # utlist = ["ut", "utah"]
# # walist = ["wa", "washington"]
# # wylist = ["wy", "wyoming"]


# # Government
# # ---------------------------------------------------------------------
# bialist = ["usbia", "indian affairs"]
# ushudlist = ["ushud", "housing and urban development", "housing & urban development"]
# usdojlist = ["doj", "department of justice", "dept of justice"]
# usdotlist = ["dot", "dept of transportation",  "dept transportation", "federal highway administration"]
# usfaalist = ["usfaa", "federal aviation administration"]
# usgsalist = ["usgsa", "general services administration"]
# usihslist = ["usihs", "indian service"]
# uspslist = ["usps", "postal service", "post office"]


# # Military
# # ---------------------------------------------------------------------
# usaalist = ["army corp of", "army corp", "army corps", "corps of engineer", "corps of engineers", "national guard", "u s army", "usa army", "usa department of the army", "usarmy"]
# uscglist = ["u s c g", "uscg", "coast guard"]
# uscbplist = ["uscbp", "border patrol", "border protection", "customs service ", "customs office"]
# usdodlist = ["department of defense", "dept of defense"]
# usdhslist = ["homeland security"]
# usvalist = ["va", "veterans affairs", "veterans administration"]
# usmarinelist = ["marine corps"]
# usnavylist = ["usnavy", "navy"]
# usaflist = [ "usaf", "usafb", "afb", "air force", "airforce", "aire force"]


# # Natural Resources
# # ---------------------------------------------------------------------
# usblmlist = ["bureau of land management", "bureau of land managenemt", "bureau of land managment", "bureau of land mgmnt", "bureau of land mgmt", "bureau of land mgt"]
# usbrlist = ["usbr", "bureau of reclam", "bureau of reclamation", "bureau reclamation"]
# usdalist = ["u s  dept of agriculture", "u s agriculture", "us agriculture dept", "us department agriculture", "us dept of agriculture", "usa  department of agriculture", "usa  dept of agriculture", "usda"]
# usdoelist = ["doe", "department of energy", "dept of energy, ""dept  of energy", "department energy ", "dept  of energy lanl"]
# usdilist = ["usdi", "inter", "interior", "dept of interior"]
# epalist = ["epa", "environmental protection agency", "e p a"]
# fwlist = ["usfws", "fish and wildlife", "fish & wildlife", "fish wildlife", "fish & wild life"]
# usfslist = ["usfs", "forest service", "u s  forest", "u s  forest service", "ranger"]
# usgslist = ["usgs", "geological survey", "geological survey"]
# usngslist = ["USNGS", "u s n g s "]
# usnplist = ["national park", "natl park serv", "national forest", "nat forest", "natl forest"]

# %%
# # Making the dictionary

# listDictionary = {}

# # # State List
# # # ---------------------------------------------------------------------
# # listDictionary["Alaska"] = aklist
# # listDictionary["Arizona"] = azlist
# # listDictionary["California"] = calist
# # listDictionary["Colorado"] = colist
# # listDictionary["Idaho"] = idlist
# # listDictionary["Kansas"] = kslist
# # listDictionary["Montana"] = mtlist
# # listDictionary["North Dakota"] = ndlist
# # listDictionary["Nebraska"] = nelist
# # listDictionary["New Mexico"] = nmlist
# # listDictionary["Nevada"] = nvlist
# # listDictionary["Oklahoma"] = oklist
# # listDictionary["Oregon"] = orlist
# # listDictionary["South Dakota"] = sdlist
# # listDictionary["Texas"] = txlist
# # listDictionary["Utah"] = utlist
# # listDictionary["Washington"] = walist
# # listDictionary["Wyoming"] = wylist


# # Generic List
# # ---------------------------------------------------------------------
# listDictionary["United States of America"] = usalist
# listDictionary["Unspecified"] = unList
# listDictionary["Commercial"] = commlist
# listDictionary["City"] = citylist
# listDictionary["State"] = statelist
# listDictionary["Institution"] = ilist
# listDictionary["Native American"] = nalist
# listDictionary["Trust"] = tlist


# # Government List
# # ---------------------------------------------------------------------
# listDictionary["Bureau of Indian Affairs (USBIA)"] = bialist
# listDictionary["Department of Housing and Urban Development (USHUD)"] = ushudlist
# listDictionary["Department of Justice (USDOJ)"] = usdojlist
# listDictionary["Department of Transportation (USDOT)"] = usdotlist
# listDictionary["Federal Aviation Administration (USFAA)"] = usfaalist
# listDictionary["General Services Administration (USGSA)"] = usgsalist
# listDictionary["Indian Health Service (USIHS)"] = usihslist
# listDictionary["United States Postal Service (USPS)"] = uspslist


# # Military List
# # ---------------------------------------------------------------------
# listDictionary["Army (USA)"] = usaalist
# listDictionary["Coast Guard (USCG)"] = uscglist
# listDictionary["Customs and Border Patrol (USCBP)"] = uscbplist
# listDictionary["Department of Defense (USDOD)"] = usdodlist
# listDictionary["Department of Homeland Security (USDHS)"] = usdhslist
# listDictionary["Department of Veterans Affairs (USVA)"] = usvalist
# listDictionary["Marine Corps (USMC)"] = usmarinelist
# listDictionary["Navy (USN)"] = usnavylist
# listDictionary["United States Air Force (USAF)"] = usaflist


# # Natural Resources List
# # ---------------------------------------------------------------------
# listDictionary["Bureau of Land Management (USBLM)"] = usblmlist
# listDictionary["Bureau Reclamation (USBR)"] = usbrlist
# listDictionary["Department of Agriculture (USDA)"] = usdalist
# listDictionary["Department of Energy (USDOE)"] = usdoelist
# listDictionary["Department of the Interior (USDI)"] = usdilist
# listDictionary["Environmental Protection Agency (USEPA)"] = epalist
# listDictionary["Fish and Wildlife Service (USFWS)"] = fwlist
# listDictionary["Forest Service (USFS)"] = usfslist
# listDictionary["Geological Survey (USGS)"] = usgslist
# listDictionary["National Geodetic Survey (USNGS)"] = usngslist
# listDictionary["National Park Service (USNPS)"] = usnplist



# listDictionary

# %% [markdown]
# ## Attempt #2

# %%
# Generic
# ---------------------------------------------------------------------
unList = ["unspecified" ,"unknown"]
nalist = ["apace tribe","apache nation","arapaho tribes","arapahoe tribes","blackfeet tribe","cheyenne tribe","indian reservation","kalispel tribe","kootenai tribe","kootenai tribes","muckleshoot indian tribe","navajo nation","navajo tribe","otoe missouria tribe","paiute tribe","peoria tribe","puyallup tribe","quapaw tribe","quileute tribe","quinault indian nation","seneca cayuga tribe","shawnee tribe","shoshone paiute tribes","shoshone tri","shoshone tribe","shoshone tribes","sioux tribe","spirit lake tribe","spokane tribe","stillaquamish indian tribe","ute indian tribe","ute mountain ute tribe","wyandotte tribe","yomba shoshone tribe","yurok tribe","zuni indian tribe","zuni tribe","apache indians","quechan tribe","navajo & hopi indian","pautte tribe","cocopah indain tribe"]




# Government
# ---------------------------------------------------------------------
bialist = ["bureau of indian aff", "indian affairs", "usbia"]
ushudlist = ["housing and urban development", "housing & urban development", "ushud"]
usfaalist = ["usfaa", "federal aviation administration"]
usgsalist = ["usgsa", "general services administration"]


# Military
# ---------------------------------------------------------------------
usaalist = ["us army", "u s army", "usarmy", "usa army", "national guard", "corps of engineer", "corps of engineers", "army corp", "army corps", "army corp of", "usa department of the army"]
uscbplist = ["uscbp", "border patrol", "border protection", "customs service ", "customs office"]
usdodlist = ["department of defense", "dept of defense"]
usdhslist = ["dhs", "homeland security"]
usmarinelist = ["marine corps"]
usaflist = [ "usaf", "usafb", "afb", "air force", "airforce", "aire force", "air national guard"]


# Natural Resources
# ---------------------------------------------------------------------
usblmlist = ["usblm", "bureau of land mgmt", "bureau of land management", "bureau of land mgmnt", "bureau of land mgt", "bureau of land managment", "bureau of land managenemt"]
usbrlist = ["usbr", "bureau of reclam", "bureau of reclamation", "bureau reclamation"]
usdalist = ["u s  dept of agriculture", "u s agriculture", "us agriculture dept", "us department agriculture", "us dept of agriculture", "usa  department of agriculture", "usa  dept of agriculture", "usda"]
usdoelist = ["department of energy", "u s department of energy", "u s dept  of energy lanl", "u s  department of energy", "u s  department of energy", "u s department of energy", "united states department of energy", "us department energy", "us department of energy", "us doe", "usa department of energy"]
epalist = ["environmental protection agency", "epa", "e p a"]
fwlist = ["u s department of the interior fish and wildlife service","u s dept of fish & wildlife","u s dept of the interior fish and wildlife","u s fish & wildlife","u s fish and wildlife","united states fish and wildlife","united states of america fish and wildlife","us department fish & wildlife","us department of fish & wildlife","us dept of interior fish and wildlife","us dept of the interior fish and wildlif","us fish & wild life","us fish & wildlife","us fish and wildlife","us interior dept fish & wildlife","usa department of interior fish and wildlife","usa dept of interior fish & wildlife","usa fish & wildlife","usa fish and wildlife","usdi fish & wildlife","usdi fish and wildlife","usdoi fish & wildlife","usfws"]
usfslist = ["forest service united states","forest service usda","u s d a forest service","u s forest service","u s forest","united states forest service","us forest service","usa forest service","usda forest service","usfs"]
usgslist = ["u s geological survey","us geological survey","usa geological survey"]
usnplist = ["national park", "natl park serv", "national forest", "nat forest", "natl forest"]

# %%
# Making the dictionary

listDictionary = {}


# Generic List
# ---------------------------------------------------------------------
listDictionary["Unspecified"] = unList
listDictionary["Native American"] = nalist


# Government List
# ---------------------------------------------------------------------
listDictionary["Bureau of Indian Affairs (USBIA)"] = bialist
listDictionary["Department of Housing and Urban Development (USHUD)"] = ushudlist
listDictionary["Federal Aviation Administration (USFAA)"] = usfaalist
listDictionary["General Services Administration (USGSA)"] = usgsalist


# Military List
# ---------------------------------------------------------------------
listDictionary["Army (USA)"] = usaalist
listDictionary["Customs and Border Patrol (USCBP)"] = uscbplist
listDictionary["Department of Defense (USDOD)"] = usdodlist
listDictionary["Department of Homeland Security (USDHS)"] = usdhslist
listDictionary["Marine Corps (USMC)"] = usmarinelist
listDictionary["United States Air Force (USAF)"] = usaflist


# Natural Resources List
# ---------------------------------------------------------------------
listDictionary["National Park Service (USNPS)"] = usnplist
listDictionary["Bureau of Land Management (USBLM)"] = usblmlist
listDictionary["Bureau Reclamation (USBR)"] = usbrlist
listDictionary["Department of Agriculture (USDA)"] = usdalist
listDictionary["Department of Energy (USDOE)"] = usdoelist
listDictionary["Environmental Protection Agency (USEPA)"] = epalist
listDictionary["Fish and Wildlife Service (USFWS)"] = fwlist
listDictionary["Forest Service (USFS)"] = usfslist
listDictionary["Geological Survey (USGS)"] = usgslist



listDictionary
# Out:
# {'Unspecified': ['unspecified', 'unknown'],
#  'Native American': ['apace tribe',
#   'apache nation',
#   'arapaho tribes',
#   'arapahoe tribes',
#   'blackfeet tribe',
#   'cheyenne tribe',
#   'indian reservation',
#   'kalispel tribe',
#   'kootenai tribe',
#   'kootenai tribes',
#   'muckleshoot indian tribe',
#   'navajo nation',
#   'navajo tribe',
#   'otoe missouria tribe',
#   'paiute tribe',
#   'peoria tribe',
#   'puyallup tribe',
#   'quapaw tribe',
#   'quileute tribe',
#   'quinault indian nation',
#   'seneca cayuga tribe',
#   'shawnee tribe',
#   'shoshone paiute tribes',
#   'shoshone tri',
#   'shoshone tribe',
#   'shoshone tribes',
#   'sioux tribe',
#   'spirit lake tribe',
#   'spokane tribe',
#   'stillaquamish indian tribe',
#   'ute indian tribe',
#   'ute mountain ute tribe',
#   'wyandotte tribe',
#   'yomba shoshone tribe',
#   'yurok tribe',
#   'zuni indian tribe',
#   'zuni tribe',
#   'apache indians',
#   'quechan tribe',
#   'navajo & hopi indian',
#   'pautte tribe',
#   'cocopah indain tribe'],
#  'Bureau of Indian Affairs (USBIA)': ['bureau of indian aff',
#   'indian affairs',
#   'usbia'],
#  'Department of Housing and Urban Development (USHUD)': ['housing and urban development',
#   'housing & urban development',
#   'ushud'],
#  'Federal Aviation Administration (USFAA)': ['usfaa',
#   'federal aviation administration'],
#  'General Services Administration (USGSA)': ['usgsa',
#   'general services administration'],
#  'Army (USA)': ['us army',
#   'u s army',
#   'usarmy',
#   'usa army',
#   'national guard',
#   'corps of engineer',
#   'corps of engineers',
#   'army corp',
#   'army corps',
#   'army corp of',
#   'usa department of the army'],
#  'Customs and Border Patrol (USCBP)': ['uscbp',
#   'border patrol',
#   'border protection',
#   'customs service ',
#   'customs office'],
#  'Department of Defense (USDOD)': ['department of defense', 'dept of defense'],
#  'Department of Homeland Security (USDHS)': ['dhs', 'homeland security'],
#  'Marine Corps (USMC)': ['marine corps'],
#  'United States Air Force (USAF)': ['usaf',
#   'usafb',
#   'afb',
#   'air force',
#   'airforce',
#   'aire force',
#   'air national guard'],
#  'National Park Service (USNPS)': ['national park',
#   'natl park serv',
#   'national forest',
#   'nat forest',
#   'natl forest'],
#  'Bureau of Land Management (USBLM)': ['usblm',
#   'bureau of land mgmt',
#   'bureau of land management',
#   'bureau of land mgmnt',
#   'bureau of land mgt',
#   'bureau of land managment',
#   'bureau of land managenemt'],
#  'Bureau Reclamation (USBR)': ['usbr',
#   'bureau of reclam',
#   'bureau of reclamation',
#   'bureau reclamation'],
#  'Department of Agriculture (USDA)': ['u s  dept of agriculture',
#   'u s agriculture',
#   'us agriculture dept',
#   'us department agriculture',
#   'us dept of agriculture',
#   'usa  department of agriculture',
#   'usa  dept of agriculture',
#   'usda'],
#  'Department of Energy (USDOE)': ['department of energy',
#   'u s department of energy',
#   'u s dept  of energy lanl',
#   'u s  department of energy',
#   'u s  department of energy',
#   'u s department of energy',
#   'united states department of energy',
#   'us department energy',
#   'us department of energy',
#   'us doe',
#   'usa department of energy'],
#  'Environmental Protection Agency (USEPA)': ['environmental protection agency',
#   'epa',
#   'e p a'],
#  'Fish and Wildlife Service (USFWS)': ['u s department of the interior fish and wildlife service',
#   'u s dept of fish & wildlife',
#   'u s dept of the interior fish and wildlife',
#   'u s fish & wildlife',
#   'u s fish and wildlife',
#   'united states fish and wildlife',
#   'united states of america fish and wildlife',
#   'us department fish & wildlife',
#   'us department of fish & wildlife',
#   'us dept of interior fish and wildlife',
#   'us dept of the interior fish and wildlif',
#   'us fish & wild life',
#   'us fish & wildlife',
#   'us fish and wildlife',
#   'us interior dept fish & wildlife',
#   'usa department of interior fish and wildlife',
#   'usa dept of interior fish & wildlife',
#   'usa fish & wildlife',
#   'usa fish and wildlife',
#   'usdi fish & wildlife',
#   'usdi fish and wildlife',
#   'usdoi fish & wildlife',
#   'usfws'],
#  'Forest Service (USFS)': ['forest service united states',
#   'forest service usda',
#   'u s d a forest service',
#   'u s forest service',
#   'u s forest',
#   'united states forest service',
#   'us forest service',
#   'usa forest service',
#   'usda forest service',
#   'usfs'],
#  'Geological Survey (USGS)': ['u s geological survey',
#   'us geological survey',
#   'usa geological survey']}

# %%
# Assign OwnerClassification value.
# Uses the re library, but requires for loop.
# Order that the lists are inputed into dictoinary is important, want to overide generic search with a more specific search.

def CreateOwnerClassification(val):
    if val == '' or pd.isnull(val):
        outString = "Unspecified"
    else:
#         outString = "Privately Owned" # Default
        outString = "In Review" # Default
        
        # Cleaning text / simple search format
        val = val.replace(",", " ")
        val = val.replace(".", " ")
        val = val.replace(";", " ")
        val = val.replace("-", " ")
        val = val.replace("/", " ")
        val = val.replace("(", " ")
        val = val.replace(")", " ")
        val = val.lower().strip()
        val = " "+val+" "
        
        for x in listDictionary:
            labelString = x
            valueList = listDictionary[x]
            for words in valueList:
                if re.search(" "+words+ " ", val): outString = x
            
    return outString

df['WaDEOwner'] = df.apply(lambda row: CreateOwnerClassification(row['AllocationOwner']), axis=1)
df
# Out:
#                             AllocationOwner  CountOwn State  WaDEOwner
# 0                        AGRIUM, U.S., INC.         1    AK  In Review
# 1                                ALASKA ZOO         1    AK  In Review
# 2          ALYESKA PIPELINE SERVICE COMPANY         7    AK  In Review
# 3             ALYESKA RESORT MANAGEMENT CO.         3    AK  In Review
# 4               BP EXPLORATION (ALASKA) INC         4    AK  In Review
# ...                                     ...       ...   ...        ...
# 510990    ZIGURS, STEVEN A. AND JENNIFER L.         3    WY  In Review
# 510991               ZIMMERMAN, E L PEARL M         1    WY  In Review
# 510992         ZIMMERMAN, PAUL C AND LOLA M         1    WY  In Review
# 510993  ZION SAVINGS BANK AND TRUST COMPANY         1    WY  In Review
# 510994      ZUMBRUNNEN, MELVIN L AND LOLA J         1    WY  In Review
#
# [510995 rows x 4 columns]

# %%
# Group by Statement

df = df.groupby('AllocationOwner').agg(lambda x: ','.join([str(elem) for elem in (list(set(x)))])).replace(np.nan, '').reset_index()

# %%
# df = df.drop_duplicates()
# df = df.drop(['AllocationNativeID', 'AllocationOwner', 'State'], axis=1)
# print(len(df))

# %%
# Exporting Outbound DataFrame.

# df.to_excel('P_OwnerClassification.xlsx', index=False)  # The output
df.to_csv('P_OwnerClassification.csv', index=False)  # The output

# %% [markdown]
# ## Bonus / Experiment Scripts

# %%
# Checking Values / string entries.

val = "FOREST SERVICE,UNITED STATES"
val = val.replace(",", " ")
val = val.replace(".", " ")
val = val.replace(";", " ")
val = val.replace("-", " ")
val = val.replace("/", " ")
val = val.replace("(", " ")
val = val.replace(")", " ")
val = val.lower().strip()
print(val)

ilist = ["institution", "church", "lds", "school", "catholic", "baptist", "university"]

if any(" "+word+" " in " "+val+" " for word in ilist):
    print("Yes")
# Out:
# forest service united states

# %%
# single output approach

# # Assign OwnerClassification value.
# # Uses the re library, but requires for loop.
# # Order that the lists are inputed into dictoinary is important, want to overide generic search with a more specific search.

# def CreateOwnerClassification(val):
#     if val == '' or pd.isnull(val):
#         outString = "Unspecified"
#     else:
#         outString = "Privately Owned" # Default
        
#         # Cleaning text / simple search format
#         val = val.lower().strip()
#         val = val.replace(",", " ")
#         val = val.replace(".", " ")
#         val = val.replace(";", " ")
#         val = val.replace("-", " ")
#         val = val.replace("/", " ")
#         val = val.replace("(", " ")
#         val = val.replace(")", " ")
#         val = " "+val+" "
        
#         for x in listDictionary:
#             labelString = x
#             valueList = listDictionary[x]
#             for words in valueList:
#                 if re.search(" "+words+ " ", val): outString = x
            
#     return outString

# df['WaDEOwner'] = df.apply(lambda row: CreateOwnerClassification(row['AllocationOwner']), axis=1)
# df

# %%
# comma separated string output appracoh

# # Assign OwnerClassification value.
# # Uses the re library, but requires for loop.
# # Order that the lists are inputed into dictionary is important, want to overide generic search with a more specific search.
# # For function, using list, append to list, and a join method to create comma separated string as output.
# # filling in blank string with default value.

# def CreateOwnerClassification(val):
#     outlist = [] # initialize an empty list
#     if val == '' or pd.isnull(val):
#         outlist.append("Unspecified")
#     else:

#         # Cleaning input string / simple search format
#         val = val.lower().strip()
#         val = val.replace(",", " ")
#         val = val.replace(".", " ")
#         val = val.replace("-", " ")
#         val = val.replace("/", " ")
#         val = val.replace("(", " ")
#         val = val.replace(")", " ")
#         val = val.replace(";", ",") # change ; to a ,
#         val = " "+val+" "

#         for x in listDictionary:
#             labelString = x
#             valueList = listDictionary[x]
#             for words in valueList:
#                 if re.search(" "+words+ " ", val):
#                     outlist.append(x)
    
#     outlist = list(set(outlist)) # remove duplicate values from list
#     outlist = ", ".join(outlist) # convert to comma separated string
#     if outlist == "":
#         outlist = "Privately Owned" # deafult value
#     return outlist

# df['WaDEOwner'] = df.apply(lambda row: CreateOwnerClassification(row['AllocationOwner']), axis=1)
# df
