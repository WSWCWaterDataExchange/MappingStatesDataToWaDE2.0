# %% [markdown]
# # Data Assessment Analytics
# - Utah Water Rights Data

# %%
# Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# Cleanup
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
#Setting work directory
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Utah/WaterAllocation/ProcessedInputData"
os.chdir(workingDir)

# %% [markdown]
# ## Water Source Information

# %%
# watersources.csv
inputfile = "watersources.csv"
df_ws = pd.read_csv(inputfile)
print(len(df_ws))
# Out:
# 27931

# %%
df_ws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27931 entries, 0 to 27930
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   WaterSourceUUID          27931 non-null  object
#  1   Geometry                 0 non-null      float64
#  2   GNISFeatureNameCV        0 non-null      float64
#  3   WaterQualityIndicatorCV  27931 non-null  object
#  4   WaterSourceName          27929 non-null  object
#  5   WaterSourceNativeID      27931 non-null  object
#  6   WaterSourceTypeCV        27931 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 1.5+ MB

# %%
df_ws.describe(include='all')
# Out:
#        WaterSourceUUID  Geometry  GNISFeatureNameCV WaterQualityIndicatorCV  \
# count            27931       0.0                0.0                   27931
# unique           27931       NaN                NaN                       1
# top           UTwr_WS1       NaN                NaN                   Fresh
# freq                 1       NaN                NaN                   27931
# mean               NaN       NaN                NaN                     NaN
# std                NaN       NaN                NaN                     NaN
# min                NaN       NaN                NaN                     NaN
# 25%                NaN       NaN                NaN                     NaN
# 50%                NaN       NaN                NaN                     NaN
# 75%                NaN       NaN                NaN                     NaN
# max                NaN       NaN                NaN                     NaN
#
# ...

# %%
# watersources_missing.xlsx
try:
    inputfile = "watersources_missing.xlsx"
    df_ws_ms = pd.read_excel(inputfile)
    print(len(df_ws_ms))
except:
    print("No watersources_missing file.")
# Out:
# No watersources_missing file.

# %%
try:
    df_ws_ms.info()
except:
    print("No watersources_missing file.")
# Out:
# No watersources_missing file.

# %%
try:
    display(df_ws_ms.describe(include='all'))
except:
    print("No watersources_missing file.")
# Out:
# No watersources_missing file.

# %% [markdown]
# ## Site Information

# %%
# sites.csv
inputfile = "sites.csv"
df_s = pd.read_csv(inputfile)
print(len(df_s))
# Out:
# 464611
# C:\Users\rjame\AppData\Local\Temp/ipykernel_24600/1955809976.py:3: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_s = pd.read_csv(inputfile)

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464611 entries, 0 to 464610
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   SiteUUID                464611 non-null  object
#  1   RegulatoryOverlayUUIDs  0 non-null       float64
#  2   WaterSourceUUIDs        464611 non-null  object
#  3   CoordinateAccuracy      0 non-null       float64
#  4   CoordinateMethodCV      464611 non-null  object
#  5   County                  0 non-null       float64
#  6   EPSGCodeCV              464611 non-null  int64
#  7   Geometry                0 non-null       float64
#  8   GNISCodeCV              0 non-null       float64
#  9   HUC12                   0 non-null       float64
#  10  HUC8                    0 non-null       float64
#  11  Latitude                464611 non-null  float64
#  12  Longitude               464611 non-null  float64
# ...

# %%
df_s.describe()
# Out:
#        RegulatoryOverlayUUIDs  CoordinateAccuracy  County  EPSGCodeCV  \
# count                     0.0                 0.0     0.0    464611.0
# mean                      NaN                 NaN     NaN      4326.0
# std                       NaN                 NaN     NaN         0.0
# min                       NaN                 NaN     NaN      4326.0
# 25%                       NaN                 NaN     NaN      4326.0
# 50%                       NaN                 NaN     NaN      4326.0
# 75%                       NaN                 NaN     NaN      4326.0
# max                       NaN                 NaN     NaN      4326.0
#
#        Geometry  GNISCodeCV  HUC12  HUC8       Latitude      Longitude  \
# count       0.0         0.0    0.0   0.0  464611.000000  464611.000000
# mean        NaN         NaN    NaN   NaN      39.813086    -111.732850
# std         NaN         NaN    NaN   NaN       1.344365       1.075414
# ...

# %%
# sites_missing.xlsx
try:
    inputfile = "sites_missing.xlsx"
    df_s_ms = pd.read_excel(inputfile)
    print(len(df_s_ms))
except:
    print("No sites_missing file.")
# Out:
# No sites_missing file.

# %%
try:
    df_s_ms.info()
except:
    print("No sites_missing file.")
# Out:
# No sites_missing file.

# %%
try:
    display(df_s_ms.describe(include='all'))
except:
    print("No sites_missing file.")
# Out:
# No sites_missing file.

# %% [markdown]
# ## Water Allocations Info

# %%
# waterallocations.csv
inputfile = "waterallocations.csv"
df_wa = pd.read_csv(inputfile)
print(len(df_wa))
df_wa.head(1)
# Out:
# 154695
#   AllocationNativeID MethodUUID OrganizationUUID                 SiteUUID  \
# 0            01-1000    UTwr_M1          UTwr_O1  UTwr_S35336,UTwr_S77683
#
#   VariableSpecificUUID  AllocationApplicationDate  \
# 0              UTwr_V1                        NaN
#
#    AllocationAssociatedConsumptiveUseSiteIDs  \
# 0                                        NaN
#
#    AllocationAssociatedWithdrawalSiteIDs  AllocationBasisCV  \
# 0                                    NaN                NaN
#
#    AllocationChangeApplicationIndicator  AllocationCommunityWaterSupplySystem  \
# 0                                   NaN                                   NaN
#
#    AllocationCropDutyAmount  AllocationExpirationDate  AllocationFlow_CFS  \
# 0                       NaN                       NaN                 0.0
#
#    AllocationLegalStatusCV                              AllocationOwner  \
# 0                      NaN  MOAB DISTRICT USA BUREAU OF LAND MANAGEMENT
#
# ...

# %%
df_wa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154695 entries, 0 to 154694
# Data columns (total 38 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   AllocationNativeID                         154695 non-null  object
#  1   MethodUUID                                 154695 non-null  object
#  2   OrganizationUUID                           154695 non-null  object
#  3   SiteUUID                                   154695 non-null  object
#  4   VariableSpecificUUID                       154695 non-null  object
#  5   AllocationApplicationDate                  0 non-null       float64
#  6   AllocationAssociatedConsumptiveUseSiteIDs  0 non-null       float64
#  7   AllocationAssociatedWithdrawalSiteIDs      0 non-null       float64
#  8   AllocationBasisCV                          0 non-null       float64
# ...

# %%
df_wa.describe(include='all')
# Out:
#        AllocationNativeID MethodUUID OrganizationUUID  \
# count              154695     154695           154695
# unique             154695          1                1
# top               01-1000    UTwr_M1          UTwr_O1
# freq                    1     154695           154695
# mean                  NaN        NaN              NaN
# std                   NaN        NaN              NaN
# min                   NaN        NaN              NaN
# 25%                   NaN        NaN              NaN
# 50%                   NaN        NaN              NaN
# 75%                   NaN        NaN              NaN
# max                   NaN        NaN              NaN
#
#                        SiteUUID VariableSpecificUUID  \
# count                    154695               154695
# unique                   154695                    1
# top     UTwr_S35336,UTwr_S77683              UTwr_V1
# freq                          1               154695
# ...

# %%
# waterallocations_missing.xlsx
try:
    inputfile = "waterallocations_missing.xlsx"
    df_wa_ms = pd.read_excel(inputfile)
    print(len(df_wa_ms))
except:
    print("No waterallocations_missing file.")
# Out:
# 28023

# %%
try:
    df_wa_ms.info()
except:
    print("No waterallocations_missing file.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28023 entries, 0 to 28022
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ReasonRemoved      28023 non-null  object
#  1   RowIndex           28023 non-null  int64
#  2   IncompleteField_1  17769 non-null  object
#  3   IncompleteField_2  0 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 875.8+ KB

# %%
try:
    display(df_wa_ms.describe(include='all'))
except:
    print("No waterallocations_missing file.")
# Out:
#                             ReasonRemoved       RowIndex  \
# count                               28023   28023.000000
# unique                                  4            NaN
# top     Incomplete AllocationPriorityDate            NaN
# freq                                26735            NaN
# mean                                  NaN   88903.022624
# std                                   NaN   59348.978826
# min                                   NaN       0.000000
# 25%                                   NaN   21303.500000
# 50%                                   NaN   96207.000000
# 75%                                   NaN  142121.000000
# max                                   NaN  182717.000000
#
#             IncompleteField_1  IncompleteField_2
# count                   17769                0.0
# unique                  15956                NaN
# top     1949-12-08,2000-06-07                NaN
# freq                       38                NaN
# ...
