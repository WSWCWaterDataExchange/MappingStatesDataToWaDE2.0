# %% [markdown]
# # Pre-processing Wyoming Water Right data for WaDEQA upload.
# Purpose:  To pre-process the Wyoming data into one master file for simple DataFrame creation and extraction
#
# Notes:
# - Date Updated: 05/06/2022
# - Merging GW and SW sources into one workable input.

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# Cleanup
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
# Out:
# C:\Users\rjame\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/Wyoming/WaterAllocation"
os.chdir(workingDir)

# %% [markdown]
# # POD Data

# %% [markdown]
# ### POD Groundwater

# %%
# Input File
GW_Input = "RawInputData/POD_GW_DepthI_FC_input.csv"
dfwyg = pd.read_csv(GW_Input)

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfwyg:
    dfwyg['WaDEUUID'] = "wyDG" + dfwyg.index.astype(str)
    dfwyg.to_csv('RawInputData/POD_GW_DepthI_FC_input.csv', index=False)

dfwyg.head()
# Out:
#    OID_ IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate  \
# 0     1        A               A      NaN  CR UW04/059     8/5/1976
# 1     2        A                      NaN   P210075.0W   11/28/2018
# 2     3        A                      NaN   P209213.0W    5/23/2018
# 3     4        A                      NaN   P144429.0W     5/3/2002
# 4     5        A                      NaN   P146345.0W    8/16/2002
#
#   PriorityText SummaryWRStatus                          Company FirstName  \
# 0     8/5/1976                                                       INC.
# 1                   Incomplete              FREESTONE MIDSTREAM
# 2                   Incomplete        CHESAPEAKE OPERATING, LLC
# 3                   Incomplete   POWDER RIVER AGRI-ORGANIC, LLC
# 4                   Incomplete  POWDER RIVER AGRI-ORGANIC, LLC.
#
#       LastName           FacilityName    Uses   Twn   Rng  Sec     Qtr_Qtr  \
# 0  O. W. RANCH            O W WELL #1  IRR_GW  034N  063W   19  NE1/4NE1/4
# 1               LINCOLN WATER WELL #1     MIS  034N  069W   26  NW1/4NW1/4
# 2                  REESE 33-34-69 WSW     MIS  034N  069W   33  SE1/4NW1/4
# 3                             TIFFANY  IRR_GW  035N  086W    8  NW1/4SW1/4
# 4                         GRAND PA #7  IRR_GW  035N  086W   17  NW1/4NW1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0
# 1                                       A
# 2                                       A
# 3                                       A
# 4                                     A6-
#
#    Total_Flow_CFS___Appropriation_GPM_  Total_depth__Ft_  \
# 0                                575.0               NaN
# 1                                750.0               NaN
# 2                                600.0               NaN
# 3                                800.0             440.0
# 4                                800.0             570.0
#
#    StaticWaterLevel__Ft_ Well_Log_Y_N_  Total_Capacity__AF_Yr_ Facility_type  \
# 0                    NaN                                   NaN          Well
# 1                    NaN                                   NaN          Well
# 2                    NaN                                   NaN          Well
# 3                   42.0                                   NaN          Well
# 4                   32.0                                   NaN          Well
#
#   SupplyType Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN DateDownloaded  \
# 0   Original                         External         NENE  3/2/2019 0:00
# 1                                    External         NWNW  3/2/2019 0:00
# 2                                    External         NESW  3/2/2019 0:00
# 3                                 N  External         NWSW  3/2/2019 0:00
# 4                                 N  External         NWNW  3/2/2019 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double Contractor  \
# 0            2.0            2.0        -104.46127         42.91290        CCI
# 1            2.0            2.0        -105.11490         42.89665        CCI
# 2            2.0            2.0        -105.15106         42.87620        CCI
# 3            2.0            2.0        -107.18099         43.01780        CCI
# 4            2.0            2.0        -107.18100         43.01056        CCI
#
#    Contract_ID HORIZONTAL_ACCURACY Creation_Edit_Date  PermitNum OrdrRecNum  \
# 0  05SC0297516                QTR2     4/10/2020 0:00      34894  OR 25/527
# 1  05SC0297516                QTR2     4/10/2020 0:00     210075
# 2  05SC0297516                QTR2     4/10/2020 0:00     209213
# 3  05SC0297516                QTR2     4/10/2020 0:00     144429
# 4  05SC0297516                QTR2     4/10/2020 0:00     146345
#
#   PermitPrefix PermitSuffix Pump_Depth PWBFDepTop PWBFDepBot WaDEUUID
# 0            P            W                                     wyDG0
# 1            P            W                                     wyDG1
# 2            P            W                                     wyDG2
# 3            P            W                   210        400    wyDG3
# 4            P            W                   330        565    wyDG4

# %%
#Update datatype of Priority Date to fit WaDE 2.0 structure
dfwyg['PriorityDate'] = pd.to_datetime(dfwyg['PriorityDate'])
dfwyg['PriorityDate'] = pd.to_datetime(dfwyg["PriorityDate"].dt.strftime('%m/%d/%Y'))
dfwyg.head(1)
# Out:
#    OID_ IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate  \
# 0     1        A               A      NaN  CR UW04/059   1976-08-05
#
#   PriorityText SummaryWRStatus Company FirstName     LastName FacilityName  \
# 0     8/5/1976                              INC.  O. W. RANCH  O W WELL #1
#
#      Uses   Twn   Rng  Sec     Qtr_Qtr  \
# 0  IRR_GW  034N  063W   19  NE1/4NE1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0
#
#    Total_Flow_CFS___Appropriation_GPM_  Total_depth__Ft_  \
# 0                                575.0               NaN
#
#    StaticWaterLevel__Ft_ Well_Log_Y_N_  Total_Capacity__AF_Yr_ Facility_type  \
# 0                    NaN                                   NaN          Well
#
#   SupplyType Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN DateDownloaded  \
# 0   Original                         External         NENE  3/2/2019 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double Contractor  \
# 0            2.0            2.0        -104.46127          42.9129        CCI
#
#    Contract_ID HORIZONTAL_ACCURACY Creation_Edit_Date  PermitNum OrdrRecNum  \
# 0  05SC0297516                QTR2     4/10/2020 0:00      34894  OR 25/527
#
#   PermitPrefix PermitSuffix Pump_Depth PWBFDepTop PWBFDepBot WaDEUUID
# 0            P            W                                     wyDG0

# %%
#Creating WaDE Owner Field.  
#Create from Owner field. If empty, use LastName + FirstName fields.

def retrieveOwner(Com, FN, LN):
    Com = str(Com).strip()
    FN = str(FN).strip()
    LN = str(LN).strip()
    if Com == "" or pd.isnull(Com):
        outList = LN + ", " + FN
    else:
        outList = Com
    return outList
dfwyg['WaDEOwner'] = dfwyg.apply(lambda row: retrieveOwner(row['Company'], row['FirstName'], row['LastName']), axis=1)
dfwyg.head(1)
# Out:
#    OID_ IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate  \
# 0     1        A               A      NaN  CR UW04/059   1976-08-05
#
#   PriorityText SummaryWRStatus Company FirstName     LastName FacilityName  \
# 0     8/5/1976                              INC.  O. W. RANCH  O W WELL #1
#
#      Uses   Twn   Rng  Sec     Qtr_Qtr  \
# 0  IRR_GW  034N  063W   19  NE1/4NE1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0
#
#    Total_Flow_CFS___Appropriation_GPM_  Total_depth__Ft_  \
# 0                                575.0               NaN
#
#    StaticWaterLevel__Ft_ Well_Log_Y_N_  Total_Capacity__AF_Yr_ Facility_type  \
# 0                    NaN                                   NaN          Well
#
#   SupplyType Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN DateDownloaded  \
# 0   Original                         External         NENE  3/2/2019 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double Contractor  \
# 0            2.0            2.0        -104.46127          42.9129        CCI
#
#    Contract_ID HORIZONTAL_ACCURACY Creation_Edit_Date  PermitNum OrdrRecNum  \
# 0  05SC0297516                QTR2     4/10/2020 0:00      34894  OR 25/527
#
#   PermitPrefix PermitSuffix Pump_Depth PWBFDepTop PWBFDepBot WaDEUUID  \
# 0            P            W                                     wyDG0
#
#            WaDEOwner
# 0  O. W. RANCH, INC.

# %%
#Creating Beneficial Use.
#Need to translate WY abbreviatoins to a workable format.

BenUseDict = {
"AESCNG" : "Coal Bed Natural Gas",
"AESFIS" : "Fish Propagation (Aesthetics)",
"AESGWR" : "Ground Water Recharge (Aesthetics)",
"AESREC" : "Recreation (Aesthetics)",
"AESSTK" : "Stock (Aesthetics)",
"AESWET" : "Wetlands (Aesthetics)",
"AESWIL" : "Wildlife (Aesthetics)",
"AQU" : "Aquaculture",
"BOT" : "Bottling Water",
"CAG" : "Commercial Agriculture",
"CBM" : "Coal Bed Methane - Ground Water",
"CHE" : "Chemical",
"CIS" : "Consumptive Instream Flow",
"CMU" : "Combined Uses",
"CNG_SW" : "Coal Bed Natural Gas",
"COM" : "Commercial",
"CUL" : "Culinary",
"DAI" : "Dairy",
"DEW" : "Mine Dewatering",
"DOM_GW" : "Domestic - Ground Water",
"DOM_SW" : "Domestic - Surface Water",
"DPA" : "Domestic (Phase 2 Award)",
"DRI" : "Drilling",
"DSP" : "Domestic Supply",
"DTA" : "Dust Abatement",
"ECAP" : "Existing Capacity",
"ERO" : "Erosion Control",
"FIR" : "Fire Protection",
"FIS" : "Fish Propagation",
"FLO" : "Flood Control",
"FTH" : "Flow Through",
"GWR" : "Ground Water Recharge",
"HEX" : "Heat Extraction",
"HWY" : "Highway Construction",
"HYD" : "Hydropower",
"HYT" : "Hydrostatic Testing",
"ICE" : "Ice Cutting",
"IFA" : "Instream Flow (Phase 2 Award)",
"IND_GW" : "Industrial - Ground Water",
"IND_SW" : "Industrial - Surface Water",
"IRR_GW" : "Irrigation - Ground Water",
"IRR_SW" : "Irrigation - Surface Water",
"ISF" : "Instream Flow",
"LAK" : "Maintain Natural Lake Level (Phase 2 Award)",
"LAW" : "Large Scale Landscape",
"MAI" : "Maintenance (Equipment Washing)",
"MAN" : "Manufacturing",
"MEC" : "Mechanical ",
"MED" : "Medicinal",
"MEM" : "Municipal (Emergency)",
"MIL" : "Milling",
"MIN" : "Mining",
"MIS" : "Miscellaneous - Ground Water",
"MON" : "Monitor",
"MUN_GW" : "Municipal - Ground Water",
"MUN_SW" : "Municipal - Surface Water",
"NAT" : "Natural Flow (Phase 2 Award)",
"O&G" : "Oil and Gas Well Drilling",
"OIL" : "Oil",
"OTH" : "Other",
"OTH_CM" : "Other - Commercial",
"OTH_IN" : "Other - Industrial",
"OTH_TM" : "Other - Temporary",
"P&S" : "Potable and Sanitary Supply",
"PCT" : "Pollution Control",
"POW" : "Power",
"RAI" : "Railroad",
"RDC" : "Road Construction",
"REC" : "Recreation",
"REF" : "Refining",
"RES" : "Reservoir Supply",
"REW" : "Reclamation Watering",
"S&D" : "Stock and Domestic",
"SDG" : "Gpm For Domestic or Stock",
"SDU" : "Stock and Domestic",
"SED" : "Sediment Control",
"SNO" : "Snow Making",
"STE" : "Stream",
"STK" : "Stock Watering",
"STKNDMS" : "Stock and Domestic",
"STO" : "Stock",
"STS" : "Stock",
"STW" : "Stock Watering",
"SWD" : "Subdivision",
"SWP" : "Stock Water Pipeline",
"TEM" : "Temporary",
"TENL" : "Total Enlargement",
"TRA" : "Transportation",
"TST" : "Test Well",
"TWR" : "Tree Watering",
"UTL" : "Utilities",
"W&S" : "Wild and Scenic",
"WDR" : "Well Drilling",
"WET" : "Wetlands",
"WHL" : "Water Hauls",
"WL" : "Wildlife"}

def retrieveBenUse(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outString = "Unspecified"
    else:
        String1 = str(colrowValue).strip()
        x = String1.split(';')
        try:
            outList = []
            for i in range(len(x)):
                y = x[i].strip()
                y = BenUseDict[y]
                outList.append(y)
            outString = ", ".join(str(e) for e in outList)
        except:
            outString = "Unspecified"
    return outString

dfwyg['WaDEBenUse'] = dfwyg.apply(lambda row: retrieveBenUse(row['Uses']), axis=1)
dfwyg.head()
# Out:
#    OID_ IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate  \
# 0     1        A               A      NaN  CR UW04/059   1976-08-05
# 1     2        A                      NaN   P210075.0W   2018-11-28
# 2     3        A                      NaN   P209213.0W   2018-05-23
# 3     4        A                      NaN   P144429.0W   2002-05-03
# 4     5        A                      NaN   P146345.0W   2002-08-16
#
#   PriorityText SummaryWRStatus                          Company FirstName  \
# 0     8/5/1976                                                       INC.
# 1                   Incomplete              FREESTONE MIDSTREAM
# 2                   Incomplete        CHESAPEAKE OPERATING, LLC
# 3                   Incomplete   POWDER RIVER AGRI-ORGANIC, LLC
# 4                   Incomplete  POWDER RIVER AGRI-ORGANIC, LLC.
#
#       LastName           FacilityName    Uses   Twn   Rng  Sec     Qtr_Qtr  \
# 0  O. W. RANCH            O W WELL #1  IRR_GW  034N  063W   19  NE1/4NE1/4
# 1               LINCOLN WATER WELL #1     MIS  034N  069W   26  NW1/4NW1/4
# 2                  REESE 33-34-69 WSW     MIS  034N  069W   33  SE1/4NW1/4
# 3                             TIFFANY  IRR_GW  035N  086W    8  NW1/4SW1/4
# 4                         GRAND PA #7  IRR_GW  035N  086W   17  NW1/4NW1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0
# 1                                       A
# 2                                       A
# 3                                       A
# 4                                     A6-
#
#    Total_Flow_CFS___Appropriation_GPM_  Total_depth__Ft_  \
# 0                                575.0               NaN
# 1                                750.0               NaN
# 2                                600.0               NaN
# 3                                800.0             440.0
# 4                                800.0             570.0
#
#    StaticWaterLevel__Ft_ Well_Log_Y_N_  Total_Capacity__AF_Yr_ Facility_type  \
# 0                    NaN                                   NaN          Well
# 1                    NaN                                   NaN          Well
# 2                    NaN                                   NaN          Well
# 3                   42.0                                   NaN          Well
# 4                   32.0                                   NaN          Well
#
#   SupplyType Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN DateDownloaded  \
# 0   Original                         External         NENE  3/2/2019 0:00
# 1                                    External         NWNW  3/2/2019 0:00
# 2                                    External         NESW  3/2/2019 0:00
# 3                                 N  External         NWSW  3/2/2019 0:00
# 4                                 N  External         NWNW  3/2/2019 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double Contractor  \
# 0            2.0            2.0        -104.46127         42.91290        CCI
# 1            2.0            2.0        -105.11490         42.89665        CCI
# 2            2.0            2.0        -105.15106         42.87620        CCI
# 3            2.0            2.0        -107.18099         43.01780        CCI
# 4            2.0            2.0        -107.18100         43.01056        CCI
#
#    Contract_ID HORIZONTAL_ACCURACY Creation_Edit_Date  PermitNum OrdrRecNum  \
# 0  05SC0297516                QTR2     4/10/2020 0:00      34894  OR 25/527
# 1  05SC0297516                QTR2     4/10/2020 0:00     210075
# 2  05SC0297516                QTR2     4/10/2020 0:00     209213
# 3  05SC0297516                QTR2     4/10/2020 0:00     144429
# 4  05SC0297516                QTR2     4/10/2020 0:00     146345
#
#   PermitPrefix PermitSuffix Pump_Depth PWBFDepTop PWBFDepBot WaDEUUID  \
# 0            P            W                                     wyDG0
# 1            P            W                                     wyDG1
# 2            P            W                                     wyDG2
# 3            P            W                   210        400    wyDG3
# 4            P            W                   330        565    wyDG4
#
#                          WaDEOwner                    WaDEBenUse
# 0                O. W. RANCH, INC.     Irrigation - Ground Water
# 1              FREESTONE MIDSTREAM  Miscellaneous - Ground Water
# 2        CHESAPEAKE OPERATING, LLC  Miscellaneous - Ground Water
# 3   POWDER RIVER AGRI-ORGANIC, LLC     Irrigation - Ground Water
# 4  POWDER RIVER AGRI-ORGANIC, LLC.     Irrigation - Ground Water

# %%
# For Wild and Scenic River benuse
# suffix metadata, and anything with a Z in it also has a beneficial use = Wild and Scenic River benuse

def splitWord(word):
    return [char for char in word]

def retrieveWildCenicRiver(word):
    word = str(word)
    worldList = splitWord(word)
    if worldList[0] == "Z":
        outString = "Wild and Scenic River"
    else:
        outString = ""
    
    return outString
    
dfwyg['PreffixWaDEBenUse'] = dfwyg.apply(lambda row: retrieveWildCenicRiver(row['Survey_Type_Survey_Number_Survey_Suffix']), axis=1)
dfwyg.head(1)
# Out:
#    OID_ IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate  \
# 0     1        A               A      NaN  CR UW04/059   1976-08-05
#
#   PriorityText SummaryWRStatus Company FirstName     LastName FacilityName  \
# 0     8/5/1976                              INC.  O. W. RANCH  O W WELL #1
#
#      Uses   Twn   Rng  Sec     Qtr_Qtr  \
# 0  IRR_GW  034N  063W   19  NE1/4NE1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0
#
#    Total_Flow_CFS___Appropriation_GPM_  Total_depth__Ft_  \
# 0                                575.0               NaN
#
#    StaticWaterLevel__Ft_ Well_Log_Y_N_  Total_Capacity__AF_Yr_ Facility_type  \
# 0                    NaN                                   NaN          Well
#
#   SupplyType Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN DateDownloaded  \
# 0   Original                         External         NENE  3/2/2019 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double Contractor  \
# 0            2.0            2.0        -104.46127          42.9129        CCI
#
#    Contract_ID HORIZONTAL_ACCURACY Creation_Edit_Date  PermitNum OrdrRecNum  \
# 0  05SC0297516                QTR2     4/10/2020 0:00      34894  OR 25/527
#
#   PermitPrefix PermitSuffix Pump_Depth PWBFDepTop PWBFDepBot WaDEUUID  \
# 0            P            W                                     wyDG0
#
#            WaDEOwner                 WaDEBenUse PreffixWaDEBenUse
# 0  O. W. RANCH, INC.  Irrigation - Ground Water

# %%
# For Wild and Scenic River benuse
# combine WaDEBenUse & PreffixWaDEBenUse columns if not blank
def combineWaDEBenUses(valA, valB):
    if valA == "" or pd.isnull(valA):
        outString = valB
    else:
        outString = valB + ", " + valA
    
    return outString

dfwyg['WaDEBenUse'] = dfwyg.apply(lambda row: combineWaDEBenUses(row['PreffixWaDEBenUse'], row['WaDEBenUse']), axis=1)
dfwyg.head(1)
# Out:
#    OID_ IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate  \
# 0     1        A               A      NaN  CR UW04/059   1976-08-05
#
#   PriorityText SummaryWRStatus Company FirstName     LastName FacilityName  \
# 0     8/5/1976                              INC.  O. W. RANCH  O W WELL #1
#
#      Uses   Twn   Rng  Sec     Qtr_Qtr  \
# 0  IRR_GW  034N  063W   19  NE1/4NE1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0
#
#    Total_Flow_CFS___Appropriation_GPM_  Total_depth__Ft_  \
# 0                                575.0               NaN
#
#    StaticWaterLevel__Ft_ Well_Log_Y_N_  Total_Capacity__AF_Yr_ Facility_type  \
# 0                    NaN                                   NaN          Well
#
#   SupplyType Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN DateDownloaded  \
# 0   Original                         External         NENE  3/2/2019 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double Contractor  \
# 0            2.0            2.0        -104.46127          42.9129        CCI
#
#    Contract_ID HORIZONTAL_ACCURACY Creation_Edit_Date  PermitNum OrdrRecNum  \
# 0  05SC0297516                QTR2     4/10/2020 0:00      34894  OR 25/527
#
#   PermitPrefix PermitSuffix Pump_Depth PWBFDepTop PWBFDepBot WaDEUUID  \
# 0            P            W                                     wyDG0
#
#            WaDEOwner                 WaDEBenUse PreffixWaDEBenUse
# 0  O. W. RANCH, INC.  Irrigation - Ground Water

# %%
# Create output dataframe for ground water
columnslist = [   
    ### Water Source Info ###
    "in_WaterSourceName",
    "in_WaterSourceTypeCV",
    
    ### Site Info ###
    "in_Latitude",
    "in_Longitude",
    "in_SiteName",
    "in_SiteTypeCV",
    "in_PODorPOUSite",
    
    ### AllocationAmount_fact Info ###
    "in_AllocationFlow_CFS",
    "in_AllocationNativeID",
    "in_AllocationOwner",
    "in_AllocationPriorityDate",
    "in_AllocationLegalStatusCV",
    "in_BeneficialUseCategory",
    "in_IrrigatedAcreage"]

dfground = pd.DataFrame(columns=columnslist, index=dfwyg.index)

# %%
#############################################################################################
# Data Assessment UUID
dfground['WaDEUUID'] = dfwyg['WaDEUUID']

#WaterSource
dfground['in_WaterSourceTypeCV'] = 'Groundwater'
dfground['in_WaterSourceName'] = "Unspecified"
                                    
#Site
dfground['in_Latitude'] = dfwyg['Latitude_Double'].astype(float)
dfground['in_Longitude'] = dfwyg['Longitude_Double'].astype(float)
dfground['in_SiteName'] = dfwyg['FacilityName'].astype(str)
dfground['in_SiteTypeCV'] = dfwyg['Facility_type'].astype(str)
dfground['in_PODorPOUSite'] = "POD"

#AllocationAmount_fact
dfground['in_AllocationFlow_CFS'] = dfwyg['Total_Flow_CFS___Appropriation_GPM_'].astype(float)
dfground['in_AllocationNativeID'] = dfwyg['WR_Number'].astype(str)
dfground['in_AllocationOwner'] = dfwyg['WaDEOwner'].astype(str)
dfground['in_AllocationPriorityDate'] = dfwyg['PriorityDate']
dfground['in_AllocationLegalStatusCV'] = dfwyg['SummaryWRStatus'].astype(str)
dfground['in_BeneficialUseCategory'] = dfwyg['WaDEBenUse'].astype(str)
dfground['in_IrrigatedAcreage'] = ""

# %%
# Remove NaN values
dfground = dfground.replace(np.nan, '')  # Replaces NaN values with blank.
dfground.head()
# Out:
#   in_WaterSourceName in_WaterSourceTypeCV  in_Latitude  in_Longitude  \
# 0        Unspecified          Groundwater     42.91290    -104.46127
# 1        Unspecified          Groundwater     42.89665    -105.11490
# 2        Unspecified          Groundwater     42.87620    -105.15106
# 3        Unspecified          Groundwater     43.01780    -107.18099
# 4        Unspecified          Groundwater     43.01056    -107.18100
#
#              in_SiteName in_SiteTypeCV in_PODorPOUSite  in_AllocationFlow_CFS  \
# 0            O W WELL #1          Well             POD                  575.0
# 1  LINCOLN WATER WELL #1          Well             POD                  750.0
# 2     REESE 33-34-69 WSW          Well             POD                  600.0
# 3                TIFFANY          Well             POD                  800.0
# 4            GRAND PA #7          Well             POD                  800.0
#
#   in_AllocationNativeID               in_AllocationOwner  \
# 0           CR UW04/059                O. W. RANCH, INC.
# 1            P210075.0W              FREESTONE MIDSTREAM
# 2            P209213.0W        CHESAPEAKE OPERATING, LLC
# 3            P144429.0W   POWDER RIVER AGRI-ORGANIC, LLC
# 4            P146345.0W  POWDER RIVER AGRI-ORGANIC, LLC.
#
#   in_AllocationPriorityDate in_AllocationLegalStatusCV  \
# 0                1976-08-05
# 1                2018-11-28                 Incomplete
# 2                2018-05-23                 Incomplete
# 3                2002-05-03                 Incomplete
# 4                2002-08-16                 Incomplete
#
#        in_BeneficialUseCategory in_IrrigatedAcreage WaDEUUID
# 0     Irrigation - Ground Water                        wyDG0
# 1  Miscellaneous - Ground Water                        wyDG1
# 2  Miscellaneous - Ground Water                        wyDG2
# 3     Irrigation - Ground Water                        wyDG3
# 4     Irrigation - Ground Water                        wyDG4

# %% [markdown]
# ### POD Surface Water

# %%
# Input File
SW_Input = "RawInputData/POD_SW_DepthI_FC_input.csv"
dfwys = pd.read_csv(SW_Input)

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfwys:
    dfwys['WaDEUUID'] = "wyDS" + dfwys.index.astype(str)
    dfwys.to_csv('RawInputData/POD_SW_DepthI_FC_input.csv', index=False)
    
dfwys.head(3)
# Out:
#    OID_ Contractor  Contract_ID Horizontal_Accuracy Creation_Edit_Date  \
# 0     1        CCI  05SC0297516                QTR2     4/14/2020 0:00
# 1     2        CCI  05SC0297516                QTR2     4/14/2020 0:00
# 2     3        CCI  05SC0297516                QTR2     4/14/2020 0:00
#
#   IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate PriorityText  \
# 0        A               A      NaN  CR CC20/011    12/5/1900    12/5/1900
# 1        A               A      NaN  CR CC23/015    12/5/1900    12/5/1900
# 2        A               A      NaN  CR CA03/464   12/31/1886         1886
#
#      SummaryWRStatus                           Company FirstName  LastName  \
# 0  Fully Adjudicated  BUFFALO CREEK LIVE STOCK COMPANY       NaN       NaN
# 1  Fully Adjudicated  BUFFALO CREEK LIVE STOCK COMPANY       NaN       NaN
# 2  Fully Adjudicated                               NaN         K  MCDONALD
#
#           FacilityName    Uses   Twn   Rng Sec     Qtr_Qtr  \
# 0  HOUCK NO. ONE DITCH  IRR_SW  040N  085W  33  SW1/4NW1/4
# 1    HOUCK NO. 2 DITCH  IRR_SW  040N  085W  33  SE1/4SW1/4
# 2           RYAN DITCH  IRR_SW  041N  083W  33  SW1/4SW1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0                                       A
# 1                                       A
# 2                                       A
#
#    Total_Flow_CFS___Appropriation_GPM_  Stream_Source  Total_Capacity__AF_Yr_  \
# 0                                40.05  Buffalo Creek                     NaN
# 1                                20.26  Buffalo Creek                     NaN
# 2                                 2.70   Spring Creek                     NaN
#
#    Diversion_Capacity_at_Headgate_CFS_ Facility_type SupplyType  \
# 0                                  NaN        Stream   Original
# 1                                  NaN        Stream   Original
# 2                                  NaN        Stream        NaN
#
#   Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN  DateDownloaded  \
# 0                    NaN  External         SWNW  10/4/2018 0:00
# 1                    NaN  External         SESW  10/4/2018 0:00
# 2                    NaN  External         SWSW  10/4/2018 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double WaDEUUID
# 0            2.0            8.0       -107.060231        43.393361    wyDS0
# 1            2.0            8.0       -107.053028        43.386402    wyDS1
# 2            2.0            8.0       -106.829119        43.470619    wyDS2

# %%
# #Update datatype of Priority Date to fit WaDE 2.0 structure
# dfwys['PriorityDate'] = pd.to_datetime(dfwys['PriorityDate'])
# dfwys['PriorityDate'] = pd.to_datetime(dfwys["PriorityDate"].dt.strftime('%m/%d/%Y'))
# dfwys.head(3)

# %%
#Creating WaDE Owner Field.  
#Create from Owner field. If empty, use LastName + FirstName fields.

def retrieveOwner(Com, FN, LN):
    Com = str(Com).strip()
    FN = str(FN).strip()
    LN = str(LN).strip()
    if Com == "" or pd.isnull(Com):
        outList = LN + ", " + FN
    else:
        outList = Com
    return outList
dfwys['WaDEOwner'] = dfwys.apply(lambda row: retrieveOwner(row['Company'], row['FirstName'], row['LastName']), axis=1)
dfwys.head(3)
# Out:
#    OID_ Contractor  Contract_ID Horizontal_Accuracy Creation_Edit_Date  \
# 0     1        CCI  05SC0297516                QTR2     4/14/2020 0:00
# 1     2        CCI  05SC0297516                QTR2     4/14/2020 0:00
# 2     3        CCI  05SC0297516                QTR2     4/14/2020 0:00
#
#   IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate PriorityText  \
# 0        A               A      NaN  CR CC20/011    12/5/1900    12/5/1900
# 1        A               A      NaN  CR CC23/015    12/5/1900    12/5/1900
# 2        A               A      NaN  CR CA03/464   12/31/1886         1886
#
#      SummaryWRStatus                           Company FirstName  LastName  \
# 0  Fully Adjudicated  BUFFALO CREEK LIVE STOCK COMPANY       NaN       NaN
# 1  Fully Adjudicated  BUFFALO CREEK LIVE STOCK COMPANY       NaN       NaN
# 2  Fully Adjudicated                               NaN         K  MCDONALD
#
#           FacilityName    Uses   Twn   Rng Sec     Qtr_Qtr  \
# 0  HOUCK NO. ONE DITCH  IRR_SW  040N  085W  33  SW1/4NW1/4
# 1    HOUCK NO. 2 DITCH  IRR_SW  040N  085W  33  SE1/4SW1/4
# 2           RYAN DITCH  IRR_SW  041N  083W  33  SW1/4SW1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0                                       A
# 1                                       A
# 2                                       A
#
#    Total_Flow_CFS___Appropriation_GPM_  Stream_Source  Total_Capacity__AF_Yr_  \
# 0                                40.05  Buffalo Creek                     NaN
# 1                                20.26  Buffalo Creek                     NaN
# 2                                 2.70   Spring Creek                     NaN
#
#    Diversion_Capacity_at_Headgate_CFS_ Facility_type SupplyType  \
# 0                                  NaN        Stream   Original
# 1                                  NaN        Stream   Original
# 2                                  NaN        Stream        NaN
#
#   Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN  DateDownloaded  \
# 0                    NaN  External         SWNW  10/4/2018 0:00
# 1                    NaN  External         SESW  10/4/2018 0:00
# 2                    NaN  External         SWSW  10/4/2018 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double WaDEUUID  \
# 0            2.0            8.0       -107.060231        43.393361    wyDS0
# 1            2.0            8.0       -107.053028        43.386402    wyDS1
# 2            2.0            8.0       -106.829119        43.470619    wyDS2
#
#                           WaDEOwner
# 0  BUFFALO CREEK LIVE STOCK COMPANY
# 1  BUFFALO CREEK LIVE STOCK COMPANY
# 2                               nan

# %%
#Creating Beneficial Use.
#Need to translate WY abbreviatoins to a workable format.

BenUseDict = {
"AESCNG" : "Coal Bed Natural Gas",
"AESFIS" : "Fish Propagation (Aesthetics)",
"AESGWR" : "Ground Water Recharge (Aesthetics)",
"AESREC" : "Recreation (Aesthetics)",
"AESSTK" : "Stock (Aesthetics)",
"AESWET" : "Wetlands (Aesthetics)",
"AESWIL" : "Wildlife (Aesthetics)",
"AQU" : "Aquaculture",
"BOT" : "Bottling Water",
"CAG" : "Commercial Agriculture",
"CBM" : "Coal Bed Methane - Ground Water",
"CHE" : "Chemical",
"CIS" : "Consumptive Instream Flow",
"CMU" : "Combined Uses",
"CNG_SW" : "Coal Bed Natural Gas",
"COM" : "Commercial",
"CUL" : "Culinary",
"DAI" : "Dairy",
"DEW" : "Mine Dewatering",
"DOM_GW" : "Domestic - Ground Water",
"DOM_SW" : "Domestic - Surface Water",
"DPA" : "Domestic (Phase 2 Award)",
"DRI" : "Drilling",
"DSP" : "Domestic Supply",
"DTA" : "Dust Abatement",
"ECAP" : "Existing Capacity",
"ERO" : "Erosion Control",
"FIR" : "Fire Protection",
"FIS" : "Fish Propagation",
"FLO" : "Flood Control",
"FTH" : "Flow Through",
"GWR" : "Ground Water Recharge",
"HEX" : "Heat Extraction",
"HWY" : "Highway Construction",
"HYD" : "Hydropower",
"HYT" : "Hydrostatic Testing",
"ICE" : "Ice Cutting",
"IFA" : "Instream Flow (Phase 2 Award)",
"IND_GW" : "Industrial - Ground Water",
"IND_SW" : "Industrial - Surface Water",
"IRR_GW" : "Irrigation - Ground Water",
"IRR_SW" : "Irrigation - Surface Water",
"ISF" : "Instream Flow",
"LAK" : "Maintain Natural Lake Level (Phase 2 Award)",
"LAW" : "Large Scale Landscape",
"MAI" : "Maintenance (Equipment Washing)",
"MAN" : "Manufacturing",
"MEC" : "Mechanical ",
"MED" : "Medicinal",
"MEM" : "Municipal (Emergency)",
"MIL" : "Milling",
"MIN" : "Mining",
"MIS" : "Miscellaneous - Ground Water",
"MON" : "Monitor",
"MUN_GW" : "Municipal - Ground Water",
"MUN_SW" : "Municipal - Surface Water",
"NAT" : "Natural Flow (Phase 2 Award)",
"O&G" : "Oil and Gas Well Drilling",
"OIL" : "Oil",
"OTH" : "Other",
"OTH_CM" : "Other - Commercial",
"OTH_IN" : "Other - Industrial",
"OTH_TM" : "Other - Temporary",
"P&S" : "Potable and Sanitary Supply",
"PCT" : "Pollution Control",
"POW" : "Power",
"RAI" : "Railroad",
"RDC" : "Road Construction",
"REC" : "Recreation",
"REF" : "Refining",
"RES" : "Reservoir Supply",
"REW" : "Reclamation Watering",
"S&D" : "Stock and Domestic",
"SDG" : "Gpm For Domestic or Stock",
"SDU" : "Stock and Domestic",
"SED" : "Sediment Control",
"SNO" : "Snow Making",
"STE" : "Stream",
"STK" : "Stock Watering",
"STKNDMS" : "Stock and Domestic",
"STO" : "Stock",
"STS" : "Stock",
"STW" : "Stock Watering",
"SWD" : "Subdivision",
"SWP" : "Stock Water Pipeline",
"TEM" : "Temporary",
"TENL" : "Total Enlargement",
"TRA" : "Transportation",
"TST" : "Test Well",
"TWR" : "Tree Watering",
"UTL" : "Utilities",
"W&S" : "Wild and Scenic",
"WDR" : "Well Drilling",
"WET" : "Wetlands",
"WHL" : "Water Hauls",
"WL" : "Wildlife"}

def retrieveBenUse(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outString = "Unspecified"
    else:
        String1 = str(colrowValue).strip()
        x = String1.split(';')
        try:
            outList = []
            for i in range(len(x)):
                y = x[i].strip()
                y = BenUseDict[y]
                outList.append(y)
            outString = ", ".join(str(e) for e in outList)
        except:
            outString = "Unspecified"
    return outString

dfwys['WaDEBenUse'] = dfwys.apply(lambda row: retrieveBenUse(row['Uses']), axis=1)
dfwys.head(3)
# Out:
#    OID_ Contractor  Contract_ID Horizontal_Accuracy Creation_Edit_Date  \
# 0     1        CCI  05SC0297516                QTR2     4/14/2020 0:00
# 1     2        CCI  05SC0297516                QTR2     4/14/2020 0:00
# 2     3        CCI  05SC0297516                QTR2     4/14/2020 0:00
#
#   IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate PriorityText  \
# 0        A               A      NaN  CR CC20/011    12/5/1900    12/5/1900
# 1        A               A      NaN  CR CC23/015    12/5/1900    12/5/1900
# 2        A               A      NaN  CR CA03/464   12/31/1886         1886
#
#      SummaryWRStatus                           Company FirstName  LastName  \
# 0  Fully Adjudicated  BUFFALO CREEK LIVE STOCK COMPANY       NaN       NaN
# 1  Fully Adjudicated  BUFFALO CREEK LIVE STOCK COMPANY       NaN       NaN
# 2  Fully Adjudicated                               NaN         K  MCDONALD
#
#           FacilityName    Uses   Twn   Rng Sec     Qtr_Qtr  \
# 0  HOUCK NO. ONE DITCH  IRR_SW  040N  085W  33  SW1/4NW1/4
# 1    HOUCK NO. 2 DITCH  IRR_SW  040N  085W  33  SE1/4SW1/4
# 2           RYAN DITCH  IRR_SW  041N  083W  33  SW1/4SW1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0                                       A
# 1                                       A
# 2                                       A
#
#    Total_Flow_CFS___Appropriation_GPM_  Stream_Source  Total_Capacity__AF_Yr_  \
# 0                                40.05  Buffalo Creek                     NaN
# 1                                20.26  Buffalo Creek                     NaN
# 2                                 2.70   Spring Creek                     NaN
#
#    Diversion_Capacity_at_Headgate_CFS_ Facility_type SupplyType  \
# 0                                  NaN        Stream   Original
# 1                                  NaN        Stream   Original
# 2                                  NaN        Stream        NaN
#
#   Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN  DateDownloaded  \
# 0                    NaN  External         SWNW  10/4/2018 0:00
# 1                    NaN  External         SESW  10/4/2018 0:00
# 2                    NaN  External         SWSW  10/4/2018 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double WaDEUUID  \
# 0            2.0            8.0       -107.060231        43.393361    wyDS0
# 1            2.0            8.0       -107.053028        43.386402    wyDS1
# 2            2.0            8.0       -106.829119        43.470619    wyDS2
#
#                           WaDEOwner                  WaDEBenUse
# 0  BUFFALO CREEK LIVE STOCK COMPANY  Irrigation - Surface Water
# 1  BUFFALO CREEK LIVE STOCK COMPANY  Irrigation - Surface Water
# 2                               nan  Irrigation - Surface Water

# %%
# For Wild and Scenic River benuse
# suffix metadata, and anything with a Z in it also has a beneficial use = Wild and Scenic River benuse

def splitWord(word):
    return [char for char in word]

def retrieveWildCenicRiver(word):
    word = str(word)
    worldList = splitWord(word)
    if worldList[0] == "Z":
        outString = "Wild and Scenic River"
    else:
        outString = ""
    
    return outString
    
dfwys['PreffixWaDEBenUse'] = dfwys.apply(lambda row: retrieveWildCenicRiver(row['Survey_Type_Survey_Number_Survey_Suffix']), axis=1)
dfwys.head(1)
# Out:
#    OID_ Contractor  Contract_ID Horizontal_Accuracy Creation_Edit_Date  \
# 0     1        CCI  05SC0297516                QTR2     4/14/2020 0:00
#
#   IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate PriorityText  \
# 0        A               A      NaN  CR CC20/011    12/5/1900    12/5/1900
#
#      SummaryWRStatus                           Company FirstName LastName  \
# 0  Fully Adjudicated  BUFFALO CREEK LIVE STOCK COMPANY       NaN      NaN
#
#           FacilityName    Uses   Twn   Rng Sec     Qtr_Qtr  \
# 0  HOUCK NO. ONE DITCH  IRR_SW  040N  085W  33  SW1/4NW1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0                                       A
#
#    Total_Flow_CFS___Appropriation_GPM_  Stream_Source  Total_Capacity__AF_Yr_  \
# 0                                40.05  Buffalo Creek                     NaN
#
#    Diversion_Capacity_at_Headgate_CFS_ Facility_type SupplyType  \
# 0                                  NaN        Stream   Original
#
#   Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN  DateDownloaded  \
# 0                    NaN  External         SWNW  10/4/2018 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double WaDEUUID  \
# 0            2.0            8.0       -107.060231        43.393361    wyDS0
#
#                           WaDEOwner                  WaDEBenUse  \
# 0  BUFFALO CREEK LIVE STOCK COMPANY  Irrigation - Surface Water
#
#   PreffixWaDEBenUse
# 0

# %%
# For Wild and Scenic River benuse
# combine WaDEBenUse & PreffixWaDEBenUse columns if not blank
def combineWaDEBenUses(valA, valB):
    if valA == "" or pd.isnull(valA):
        outString = valB
    else:
        outString = valB + ", " + valA
    
    return outString

dfwys['WaDEBenUse'] = dfwys.apply(lambda row: combineWaDEBenUses(row['PreffixWaDEBenUse'], row['WaDEBenUse']), axis=1)
dfwys.head(1)
# Out:
#    OID_ Contractor  Contract_ID Horizontal_Accuracy Creation_Edit_Date  \
# 0     1        CCI  05SC0297516                QTR2     4/14/2020 0:00
#
#   IsActive SummaryCRStatus  WRPODID    WR_Number PriorityDate PriorityText  \
# 0        A               A      NaN  CR CC20/011    12/5/1900    12/5/1900
#
#      SummaryWRStatus                           Company FirstName LastName  \
# 0  Fully Adjudicated  BUFFALO CREEK LIVE STOCK COMPANY       NaN      NaN
#
#           FacilityName    Uses   Twn   Rng Sec     Qtr_Qtr  \
# 0  HOUCK NO. ONE DITCH  IRR_SW  040N  085W  33  SW1/4NW1/4
#
#   Survey_Type_Survey_Number_Survey_Suffix  \
# 0                                       A
#
#    Total_Flow_CFS___Appropriation_GPM_  Stream_Source  Total_Capacity__AF_Yr_  \
# 0                                40.05  Buffalo Creek                     NaN
#
#    Diversion_Capacity_at_Headgate_CFS_ Facility_type SupplyType  \
# 0                                  NaN        Stream   Original
#
#   Chemical_Analysis_Y_N_ CreatedBy QTRQTR_CLEAN  DateDownloaded  \
# 0                    NaN  External         SWNW  10/4/2018 0:00
#
#    WaterDivision  WaterDistrict  Longitude_Double  Latitude_Double WaDEUUID  \
# 0            2.0            8.0       -107.060231        43.393361    wyDS0
#
#                           WaDEOwner                  WaDEBenUse  \
# 0  BUFFALO CREEK LIVE STOCK COMPANY  Irrigation - Surface Water
#
#   PreffixWaDEBenUse
# 0

# %%
# Create output dataframe for ground water
columnslist = [   
    ### Water Source Info ###
    "in_WaterSourceName",
    "in_WaterSourceTypeCV",
    
    ### Site Info ###
    "in_Latitude",
    "in_Longitude",
    "in_SiteName",
    "in_SiteTypeCV",
    "in_PODorPOUSite",
    
    ### AllocationAmount_fact Info ###
    "in_AllocationFlow_CFS",
    "in_AllocationNativeID",
    "in_AllocationOwner",
    "in_AllocationPriorityDate",
    "in_AllocationLegalStatusCV",
    "in_BeneficialUseCategory",
    "in_IrrigatedAcreage"
]

df_Surface = pd.DataFrame(columns=columnslist, index=dfwys.index)

# %%
#############################################################################################

# Data Assessment UUID
df_Surface['WaDEUUID'] = dfwys['WaDEUUID']

#WaterSource
df_Surface['in_WaterSourceTypeCV'] = 'Surface Water'
df_Surface['in_WaterSourceName'] = dfwys['Stream_Source'].astype(str)
                                    
#Site
df_Surface['in_Latitude'] = dfwys['Latitude_Double'].astype(float)
df_Surface['in_Longitude'] = dfwys['Longitude_Double'].astype(float)
df_Surface['in_SiteName'] = dfwys['FacilityName'].astype(str)
df_Surface['in_SiteTypeCV'] = dfwys['Facility_type'].astype(str)
df_Surface['in_PODorPOUSite'] = "POD"

#AllocationAmount_fact
df_Surface['in_AllocationFlow_CFS'] = dfwys['Total_Flow_CFS___Appropriation_GPM_'].astype(float)
df_Surface['in_AllocationNativeID'] = dfwys['WR_Number'].astype(str)
df_Surface['in_AllocationOwner'] = dfwys['WaDEOwner'].astype(str)
df_Surface['in_AllocationPriorityDate'] = dfwys['PriorityDate']
df_Surface['in_AllocationLegalStatusCV'] = dfwys['SummaryWRStatus'].astype(str)
df_Surface['in_BeneficialUseCategory'] = dfwys['WaDEBenUse'].astype(str)
df_Surface['in_IrrigatedAcreage'] = ""

# %%
# Remove NaN values
df_Surface = df_Surface.replace(np.nan, '')  # Replaces NaN values with blank.
df_Surface.head(3)
# Out:
#   in_WaterSourceName in_WaterSourceTypeCV in_Latitude in_Longitude  \
# 0      Buffalo Creek        Surface Water   43.393361  -107.060231
# 1      Buffalo Creek        Surface Water   43.386402  -107.053028
# 2       Spring Creek        Surface Water   43.470619  -106.829119
#
#            in_SiteName in_SiteTypeCV in_PODorPOUSite  in_AllocationFlow_CFS  \
# 0  HOUCK NO. ONE DITCH        Stream             POD                  40.05
# 1    HOUCK NO. 2 DITCH        Stream             POD                  20.26
# 2           RYAN DITCH        Stream             POD                   2.70
#
#   in_AllocationNativeID                in_AllocationOwner  \
# 0           CR CC20/011  BUFFALO CREEK LIVE STOCK COMPANY
# 1           CR CC23/015  BUFFALO CREEK LIVE STOCK COMPANY
# 2           CR CA03/464                               nan
#
#   in_AllocationPriorityDate in_AllocationLegalStatusCV  \
# 0                 12/5/1900          Fully Adjudicated
# 1                 12/5/1900          Fully Adjudicated
# 2                12/31/1886          Fully Adjudicated
#
#      in_BeneficialUseCategory in_IrrigatedAcreage WaDEUUID
# 0  Irrigation - Surface Water                        wyDS0
# 1  Irrigation - Surface Water                        wyDS1
# 2  Irrigation - Surface Water                        wyDS2

# %% [markdown]
# ### POD Concatenate

# %%
# Concatenate
frames = [dfground, df_Surface]
dfPOD = pd.concat(frames)
dfPOD
# Out:
#           in_WaterSourceName in_WaterSourceTypeCV in_Latitude in_Longitude  \
# 0                Unspecified          Groundwater     42.9129   -104.46127
# 1                Unspecified          Groundwater    42.89665    -105.1149
# 2                Unspecified          Groundwater     42.8762   -105.15106
# 3                Unspecified          Groundwater     43.0178   -107.18099
# 4                Unspecified          Groundwater    43.01056     -107.181
# ...                      ...                  ...         ...          ...
# 9654  Paintrock Lodge Spring        Surface Water   44.404268  -107.146448
# 9655       Springs (1-52-63)        Surface Water   44.525365  -104.360215
# 9656    South Redwater Creek        Surface Water   44.548345  -104.338943
# 9657                                Surface Water   44.840836  -108.425457
# 9658             Horse Creek        Surface Water   41.678828   -104.20588
#
#                                        in_SiteName in_SiteTypeCV  \
# 0                                      O W WELL #1          Well
# 1                            LINCOLN WATER WELL #1          Well
# 2                               REESE 33-34-69 WSW          Well
# 3                                          TIFFANY          Well
# 4                                      GRAND PA #7          Well
# ...                                            ...           ...
# 9654                      PAINTROCK LODGE PIPELINE        Spring
# 9655                                  HEMLER DITCH        Spring
# 9656                                    DRAW DITCH        Spring
# 9657  Hunt & Godfrey Ditch,, Robertson Enlargement        Spring
# 9658                            HAWK SPRINGS DITCH        Spring
#
#      in_PODorPOUSite  in_AllocationFlow_CFS in_AllocationNativeID  \
# 0                POD                575.000           CR UW04/059
# 1                POD                750.000            P210075.0W
# 2                POD                600.000            P209213.0W
# 3                POD                800.000            P144429.0W
# 4                POD                800.000            P146345.0W
# ...              ...                    ...                   ...
# 9654             POD                  0.004             C33112.0D
# 9655             POD                  0.000           CR CC41/494
# 9656             POD                  0.440              P7558.0D
# 9657             POD                  0.420              P5675.0E
# 9658             POD                  0.870           CR CC60/243
#
#                    in_AllocationOwner in_AllocationPriorityDate  \
# 0                   O. W. RANCH, INC.       1976-08-05 00:00:00
# 1                 FREESTONE MIDSTREAM       2018-11-28 00:00:00
# 2           CHESAPEAKE OPERATING, LLC       2018-05-23 00:00:00
# 3      POWDER RIVER AGRI-ORGANIC, LLC       2002-05-03 00:00:00
# 4     POWDER RIVER AGRI-ORGANIC, LLC.       2002-08-16 00:00:00
# ...                               ...                       ...
# 9654              USDA FOREST SERVICE                 11/1/1982
# 9655                      HELMER, A A                12/18/1916
# 9656              ANDREWS, BARBARA G.                 12/4/1906
# 9657              Robertson, Cyrus S.                 4/20/1953
# 9658         DILL, KENNETH AND ELINOR                 7/18/1908
#
#      in_AllocationLegalStatusCV  \
# 0
# 1                    Incomplete
# 2                    Incomplete
# 3                    Incomplete
# 4                    Incomplete
# ...                         ...
# 9654          Fully Adjudicated
# 9655          Fully Adjudicated
# 9656                   Complete
# 9657          Fully Adjudicated
# 9658          Fully Adjudicated
#
#                                in_BeneficialUseCategory in_IrrigatedAcreage  \
# 0                             Irrigation - Ground Water
# 1                          Miscellaneous - Ground Water
# 2                          Miscellaneous - Ground Water
# 3                             Irrigation - Ground Water
# 4                             Irrigation - Ground Water
# ...                                                 ...                 ...
# 9654                    Domestic - Surface Water, Stock
# 9655                         Irrigation - Surface Water
# 9656                                        Unspecified
# 9657  Domestic - Surface Water, Irrigation - Surface...
# 9658     Irrigation - Surface Water, Stock and Domestic
#
#       WaDEUUID
# 0        wyDG0
# 1        wyDG1
# 2        wyDG2
# 3        wyDG3
# 4        wyDG4
# ...        ...
# 9654  wyDS9654
# 9655  wyDS9655
# 9656  wyDS9656
# 9657  wyDS9657
# 9658  wyDS9658
#
# [11982 rows x 15 columns]

# %% [markdown]
# # POU Data

# %%
# Input File
POU_Input = "RawInputData/POU_input.csv"
df = pd.read_csv(POU_Input)

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in df:
    df['WaDEUUID'] = "wyU" + df.index.astype(str)
    df.to_csv('RawInputData/POU_input.csv', index=False)

df.head(5)
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_1704\49739377.py:3: DtypeWarning: Columns (39,45,46,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(POU_Input)
#    OID_  ContractID      Contractor Creation_Edit_Date  Horizontal_Accuracy  \
# 0     1         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 1     2         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 2     3         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 3     4         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 4     5         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
#
#    WRID                                       Duplicate_ID Source_ID  \
# 0   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W05SWSW1/4S...     -3.0-
# 1   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W08NWNW1/4N...     -3.0-
# 2   NaN  -CR CC48/006IRR_SWOriginal014N076W24AllAllL116021         -
# 3   NaN  -CR CC57/443DOM_SW; IRR_SWOriginal016N075W01L3...         -
# 4   NaN  -CR CC57/443DOM_SW; IRR_SWOriginal016N075W01L4...         -
#
#    PermitNumber OrderRecordNumber PermitPrefix PermitSuffix  IsActive  \
# 0           3.0         OR 17/250            -            -       NaN
# 1           3.0         OR 17/250            -            -       NaN
# 2           NaN               NaN          NaN            -       NaN
# 3           NaN               NaN          NaN            -       NaN
# 4           NaN               NaN          NaN            -       NaN
#
#   SummaryCRStatus     WRNumber PriorityDate PriorityText  Priority_YR  \
# 0             NaN    OR 17/250   1877-06-20   Spring1877       1877.0
# 1             NaN    OR 17/250   1877-06-20   Spring1877       1877.0
# 2               A  CR CC48/006   1879-04-19   04/19/1879       1879.0
# 3               A  CR CC57/443   1887-08-27   08/27/1887       1887.0
# 4               A  CR CC57/443   1887-08-27   08/27/1887       1887.0
#
#      SummaryWRStatus                                          Company  \
# 0                NaN                                              NaN
# 1                NaN                                              NaN
# 2  Fully Adjudicated  PIONEER CANAL COMPANY OF ALBANY COUNTY, WYOMING
# 3  Fully Adjudicated                                              NaN
# 4  Fully Adjudicated                                              NaN
#
#    FirstName    LastName    FacilityName            Uses   Twn   Rng   Sec  \
# 0  HOWARD E.  MCCLINTOCK  St. John Ditch          IRR_SW  033N  099W   5.0
# 1  HOWARD E.  MCCLINTOCK  St. John Ditch          IRR_SW  033N  099W   8.0
# 2        NaN         NaN   PIONEER CANAL          IRR_SW  014N  076W  24.0
# 3       FRED     KNADLER      PARK DITCH  DOM_SW; IRR_SW  016N  075W   1.0
# 4       FRED     KNADLER      PARK DITCH  DOM_SW; IRR_SW  016N  075W   1.0
#
#   POUQTR      QtrQtr Survey    POUStatus SupplyType  CreatedBy  Latitude  \
# 0     SW  SW1/4SW1/4   A11-  ADJUDICATED   Original        NaN  42.84638
# 1     NW  NW1/4NW1/4    NaN  ADJUDICATED   Original        NaN  42.84638
# 2    All         All     L1          NaN   Original        NaN       NaN
# 3    NaN         NaN     L3  ADJUDICATED   Original        NaN       NaN
# 4    NaN         NaN     L4  ADJUDICATED   Original        NaN       NaN
#
#    Longitude   DateDownloaded  WaterDivision WaterDistrict QTRQTR_CLEAN  \
# 0 -108.73479  10/31/2018 6:00            3.0             1         SWSW
# 1 -108.73479   6/11/2018 6:00            3.0             1         NWNW
# 2        NaN   5/12/2018 6:00            1.0            4A          All
# 3        NaN              NaN            1.0            4B          NaN
# 4        NaN              NaN            1.0            4B          NaN
#
#   PLSS_SECTION PLSS_QTR     PLSS_QTRQTR   Acres  Mapping_Level  Agg_POU_Count  \
# 0          NaN      NaN  033N099W05SWSW   17.42            0.0            1.0
# 1          NaN      NaN  033N099W08NWNW   17.90            0.0            1.0
# 2   014N076W24      NaN             NaN  160.00            2.0            1.0
# 3          NaN      NaN             NaN   40.00            0.0            1.0
# 4          NaN      NaN             NaN   57.00            0.0            1.0
#
#             PLSS_TractLot SupplySource  FacilityType  Centroid_X  Centroid_Y  \
# 0                     NaN          NaN           NaN -108.722999   42.855441
# 1                     NaN          NaN           NaN -108.722846   42.851810
# 2                     NaN          NaN           NaN -105.872701   41.168013
# 3  WY060160N0750W0SN010L3          NaN           NaN -105.761376   41.392876
# 4  WY060160N0750W0SN010L4          NaN           NaN -105.766251   41.392914
#
#    AcresGISpoly  AcresDifference ErrorType  Notes  Shape_Length  Shape_Area  \
# 0     40.101820       -22.681820       NaN    NaN      0.017115    0.000018
# 1     40.221616       -22.321616       NaN    NaN      0.017133    0.000018
# 2    647.327142      -487.327142       NaN    NaN      0.067776    0.000281
# 3     58.144626       -18.144626       NaN    NaN      0.020144    0.000025
# 4     57.244232        -0.244232       NaN    NaN      0.019984    0.000025
#
#   WaDEUUID
# 0     wyU0
# 1     wyU1
# 2     wyU2
# 3     wyU3
# 4     wyU4

# %%
#Update datatype of Priority Date to fit WaDE 2.0 structure
df['PriorityDate'] = pd.to_datetime(df['PriorityDate'])
df['PriorityDate'] = pd.to_datetime(df["PriorityDate"].dt.strftime('%m/%d/%Y'))
df.head(3)
# Out:
#    OID_  ContractID      Contractor Creation_Edit_Date  Horizontal_Accuracy  \
# 0     1         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 1     2         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 2     3         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
#
#    WRID                                       Duplicate_ID Source_ID  \
# 0   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W05SWSW1/4S...     -3.0-
# 1   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W08NWNW1/4N...     -3.0-
# 2   NaN  -CR CC48/006IRR_SWOriginal014N076W24AllAllL116021         -
#
#    PermitNumber OrderRecordNumber PermitPrefix PermitSuffix  IsActive  \
# 0           3.0         OR 17/250            -            -       NaN
# 1           3.0         OR 17/250            -            -       NaN
# 2           NaN               NaN          NaN            -       NaN
#
#   SummaryCRStatus     WRNumber PriorityDate PriorityText  Priority_YR  \
# 0             NaN    OR 17/250   1877-06-20   Spring1877       1877.0
# 1             NaN    OR 17/250   1877-06-20   Spring1877       1877.0
# 2               A  CR CC48/006   1879-04-19   04/19/1879       1879.0
#
#      SummaryWRStatus                                          Company  \
# 0                NaN                                              NaN
# 1                NaN                                              NaN
# 2  Fully Adjudicated  PIONEER CANAL COMPANY OF ALBANY COUNTY, WYOMING
#
#    FirstName    LastName    FacilityName    Uses   Twn   Rng   Sec POUQTR  \
# 0  HOWARD E.  MCCLINTOCK  St. John Ditch  IRR_SW  033N  099W   5.0     SW
# 1  HOWARD E.  MCCLINTOCK  St. John Ditch  IRR_SW  033N  099W   8.0     NW
# 2        NaN         NaN   PIONEER CANAL  IRR_SW  014N  076W  24.0    All
#
#        QtrQtr Survey    POUStatus SupplyType  CreatedBy  Latitude  Longitude  \
# 0  SW1/4SW1/4   A11-  ADJUDICATED   Original        NaN  42.84638 -108.73479
# 1  NW1/4NW1/4    NaN  ADJUDICATED   Original        NaN  42.84638 -108.73479
# 2         All     L1          NaN   Original        NaN       NaN        NaN
#
#     DateDownloaded  WaterDivision WaterDistrict QTRQTR_CLEAN PLSS_SECTION  \
# 0  10/31/2018 6:00            3.0             1         SWSW          NaN
# 1   6/11/2018 6:00            3.0             1         NWNW          NaN
# 2   5/12/2018 6:00            1.0            4A          All   014N076W24
#
#   PLSS_QTR     PLSS_QTRQTR   Acres  Mapping_Level  Agg_POU_Count  \
# 0      NaN  033N099W05SWSW   17.42            0.0            1.0
# 1      NaN  033N099W08NWNW   17.90            0.0            1.0
# 2      NaN             NaN  160.00            2.0            1.0
#
#   PLSS_TractLot SupplySource  FacilityType  Centroid_X  Centroid_Y  \
# 0           NaN          NaN           NaN -108.722999   42.855441
# 1           NaN          NaN           NaN -108.722846   42.851810
# 2           NaN          NaN           NaN -105.872701   41.168013
#
#    AcresGISpoly  AcresDifference ErrorType  Notes  Shape_Length  Shape_Area  \
# 0     40.101820       -22.681820       NaN    NaN      0.017115    0.000018
# 1     40.221616       -22.321616       NaN    NaN      0.017133    0.000018
# 2    647.327142      -487.327142       NaN    NaN      0.067776    0.000281
#
#   WaDEUUID
# 0     wyU0
# 1     wyU1
# 2     wyU2

# %%
#Creating WaDE Owner Field.  
#Create from Owner field. If empty, use LastName + FirstName fields.

def retrieveOwner(Com, FN, LN):
    Com = str(Com).strip()
    FN = str(FN).strip()
    LN = str(LN).strip()
    if Com == "" or pd.isnull(Com):
        outList = LN + ", " + FN
    else:
        outList = Com
    return outList
df['WaDEOwner'] = df.apply(lambda row: retrieveOwner(row['Company'], row['FirstName'], row['LastName']), axis=1)
df.head(3)
# Out:
#    OID_  ContractID      Contractor Creation_Edit_Date  Horizontal_Accuracy  \
# 0     1         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 1     2         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 2     3         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
#
#    WRID                                       Duplicate_ID Source_ID  \
# 0   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W05SWSW1/4S...     -3.0-
# 1   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W08NWNW1/4N...     -3.0-
# 2   NaN  -CR CC48/006IRR_SWOriginal014N076W24AllAllL116021         -
#
#    PermitNumber OrderRecordNumber PermitPrefix PermitSuffix  IsActive  \
# 0           3.0         OR 17/250            -            -       NaN
# 1           3.0         OR 17/250            -            -       NaN
# 2           NaN               NaN          NaN            -       NaN
#
#   SummaryCRStatus     WRNumber PriorityDate PriorityText  Priority_YR  \
# 0             NaN    OR 17/250   1877-06-20   Spring1877       1877.0
# 1             NaN    OR 17/250   1877-06-20   Spring1877       1877.0
# 2               A  CR CC48/006   1879-04-19   04/19/1879       1879.0
#
#      SummaryWRStatus                                          Company  \
# 0                NaN                                              NaN
# 1                NaN                                              NaN
# 2  Fully Adjudicated  PIONEER CANAL COMPANY OF ALBANY COUNTY, WYOMING
#
#    FirstName    LastName    FacilityName    Uses   Twn   Rng   Sec POUQTR  \
# 0  HOWARD E.  MCCLINTOCK  St. John Ditch  IRR_SW  033N  099W   5.0     SW
# 1  HOWARD E.  MCCLINTOCK  St. John Ditch  IRR_SW  033N  099W   8.0     NW
# 2        NaN         NaN   PIONEER CANAL  IRR_SW  014N  076W  24.0    All
#
#        QtrQtr Survey    POUStatus SupplyType  CreatedBy  Latitude  Longitude  \
# 0  SW1/4SW1/4   A11-  ADJUDICATED   Original        NaN  42.84638 -108.73479
# 1  NW1/4NW1/4    NaN  ADJUDICATED   Original        NaN  42.84638 -108.73479
# 2         All     L1          NaN   Original        NaN       NaN        NaN
#
#     DateDownloaded  WaterDivision WaterDistrict QTRQTR_CLEAN PLSS_SECTION  \
# 0  10/31/2018 6:00            3.0             1         SWSW          NaN
# 1   6/11/2018 6:00            3.0             1         NWNW          NaN
# 2   5/12/2018 6:00            1.0            4A          All   014N076W24
#
#   PLSS_QTR     PLSS_QTRQTR   Acres  Mapping_Level  Agg_POU_Count  \
# 0      NaN  033N099W05SWSW   17.42            0.0            1.0
# 1      NaN  033N099W08NWNW   17.90            0.0            1.0
# 2      NaN             NaN  160.00            2.0            1.0
#
#   PLSS_TractLot SupplySource  FacilityType  Centroid_X  Centroid_Y  \
# 0           NaN          NaN           NaN -108.722999   42.855441
# 1           NaN          NaN           NaN -108.722846   42.851810
# 2           NaN          NaN           NaN -105.872701   41.168013
#
#    AcresGISpoly  AcresDifference ErrorType  Notes  Shape_Length  Shape_Area  \
# 0     40.101820       -22.681820       NaN    NaN      0.017115    0.000018
# 1     40.221616       -22.321616       NaN    NaN      0.017133    0.000018
# 2    647.327142      -487.327142       NaN    NaN      0.067776    0.000281
#
#   WaDEUUID                                        WaDEOwner
# 0     wyU0                                              nan
# 1     wyU1                                              nan
# 2     wyU2  PIONEER CANAL COMPANY OF ALBANY COUNTY, WYOMING

# %%
#Creating Beneficial Use.
#Need to translate WY abbreviatoins to a workable format.

BenUseDict = {
"AESCNG" : "Coal Bed Natural Gas",
"AESFIS" : "Fish Propagation (Aesthetics)",
"AESGWR" : "Ground Water Recharge (Aesthetics)",
"AESREC" : "Recreation (Aesthetics)",
"AESSTK" : "Stock (Aesthetics)",
"AESWET" : "Wetlands (Aesthetics)",
"AESWIL" : "Wildlife (Aesthetics)",
"AQU" : "Aquaculture",
"BOT" : "Bottling Water",
"CAG" : "Commercial Agriculture",
"CBM" : "Coal Bed Methane - Ground Water",
"CHE" : "Chemical",
"CIS" : "Consumptive Instream Flow",
"CMU" : "Combined Uses",
"CNG_SW" : "Coal Bed Natural Gas",
"COM" : "Commercial",
"CUL" : "Culinary",
"DAI" : "Dairy",
"DEW" : "Mine Dewatering",
"DOM_GW" : "Domestic - Ground Water",
"DOM_SW" : "Domestic - Surface Water",
"DPA" : "Domestic (Phase 2 Award)",
"DRI" : "Drilling",
"DSP" : "Domestic Supply",
"DTA" : "Dust Abatement",
"ECAP" : "Existing Capacity",
"ERO" : "Erosion Control",
"FIR" : "Fire Protection",
"FIS" : "Fish Propagation",
"FLO" : "Flood Control",
"FTH" : "Flow Through",
"GWR" : "Ground Water Recharge",
"HEX" : "Heat Extraction",
"HWY" : "Highway Construction",
"HYD" : "Hydropower",
"HYT" : "Hydrostatic Testing",
"ICE" : "Ice Cutting",
"IFA" : "Instream Flow (Phase 2 Award)",
"IND_GW" : "Industrial - Ground Water",
"IND_SW" : "Industrial - Surface Water",
"IRR_GW" : "Irrigation - Ground Water",
"IRR_SW" : "Irrigation - Surface Water",
"ISF" : "Instream Flow",
"LAK" : "Maintain Natural Lake Level (Phase 2 Award)",
"LAW" : "Large Scale Landscape",
"MAI" : "Maintenance (Equipment Washing)",
"MAN" : "Manufacturing",
"MEC" : "Mechanical ",
"MED" : "Medicinal",
"MEM" : "Municipal (Emergency)",
"MIL" : "Milling",
"MIN" : "Mining",
"MIS" : "Miscellaneous - Ground Water",
"MON" : "Monitor",
"MUN_GW" : "Municipal - Ground Water",
"MUN_SW" : "Municipal - Surface Water",
"NAT" : "Natural Flow (Phase 2 Award)",
"O&G" : "Oil and Gas Well Drilling",
"OIL" : "Oil",
"OTH" : "Other",
"OTH_CM" : "Other - Commercial",
"OTH_IN" : "Other - Industrial",
"OTH_TM" : "Other - Temporary",
"P&S" : "Potable and Sanitary Supply",
"PCT" : "Pollution Control",
"POW" : "Power",
"RAI" : "Railroad",
"RDC" : "Road Construction",
"REC" : "Recreation",
"REF" : "Refining",
"RES" : "Reservoir Supply",
"REW" : "Reclamation Watering",
"S&D" : "Stock and Domestic",
"SDG" : "Gpm For Domestic or Stock",
"SDU" : "Stock and Domestic",
"SED" : "Sediment Control",
"SNO" : "Snow Making",
"STE" : "Stream",
"STK" : "Stock Watering",
"STKNDMS" : "Stock and Domestic",
"STO" : "Stock",
"STS" : "Stock",
"STW" : "Stock Watering",
"SWD" : "Subdivision",
"SWP" : "Stock Water Pipeline",
"TEM" : "Temporary",
"TENL" : "Total Enlargement",
"TRA" : "Transportation",
"TST" : "Test Well",
"TWR" : "Tree Watering",
"UTL" : "Utilities",
"W&S" : "Wild and Scenic",
"WDR" : "Well Drilling",
"WET" : "Wetlands",
"WHL" : "Water Hauls",
"WL" : "Wildlife"}

def retrieveBenUse(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outString = "Unspecified"
    else:
        String1 = str(colrowValue).strip()
        x = String1.split(';')
        try:
            outList = []
            for i in range(len(x)):
                y = x[i].strip()
                y = BenUseDict[y]
                outList.append(y)
            outString = ", ".join(str(e) for e in outList)
        except:
            outString = "Unspecified"
    return outString

df['WaDEBenUse'] = df.apply(lambda row: retrieveBenUse(row['Uses']), axis=1)
df.head(10)
# Out:
#    OID_  ContractID      Contractor Creation_Edit_Date  Horizontal_Accuracy  \
# 0     1         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 1     2         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 2     3         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 3     4         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 4     5         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 5     6         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 6     7         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 7     8         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 8     9         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
# 9    10         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
#
#    WRID                                       Duplicate_ID Source_ID  \
# 0   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W05SWSW1/4S...     -3.0-
# 1   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W08NWNW1/4N...     -3.0-
# 2   NaN  -CR CC48/006IRR_SWOriginal014N076W24AllAllL116021         -
# 3   NaN  -CR CC57/443DOM_SW; IRR_SWOriginal016N075W01L3...         -
# 4   NaN  -CR CC57/443DOM_SW; IRR_SWOriginal016N075W01L4...         -
# 5   NaN  A1.0YA1.0YIRR_SWOriginal001S001E19SESW1/4SE1/4...     A1.0Y
# 6   NaN  A10.0YA10.0YIRR_SWOriginal002S001E06NENW1/4NE1...    A10.0Y
# 7   NaN  A10.0YA10.0YIRR_SWOriginal002S001E06NWNE1/4NW1...    A10.0Y
# 8   NaN  A1001.0QA1001.0QIRR_SWOriginal008N005W32NESW1/...  A1001.0Q
# 9   NaN  A1001.0QA1001.0QIRR_SWOriginal008N005W32NWSE1/...  A1001.0Q
#
#    PermitNumber OrderRecordNumber PermitPrefix PermitSuffix  IsActive  \
# 0           3.0         OR 17/250            -            -       NaN
# 1           3.0         OR 17/250            -            -       NaN
# 2           NaN               NaN          NaN            -       NaN
# 3           NaN               NaN          NaN            -       NaN
# 4           NaN               NaN          NaN            -       NaN
# 5           1.0               NaN            A            Y       NaN
# 6          10.0               NaN            A            Y       NaN
# 7          10.0               NaN            A            Y       NaN
# 8        1001.0               NaN            A            Q       NaN
# 9        1001.0               NaN            A            Q       NaN
#
#   SummaryCRStatus     WRNumber PriorityDate PriorityText  Priority_YR  \
# 0             NaN    OR 17/250   1877-06-20   Spring1877       1877.0
# 1             NaN    OR 17/250   1877-06-20   Spring1877       1877.0
# 2               A  CR CC48/006   1879-04-19   04/19/1879       1879.0
# 3               A  CR CC57/443   1887-08-27   08/27/1887       1887.0
# 4               A  CR CC57/443   1887-08-27   08/27/1887       1887.0
# 5             NaN        A1.0Y   1868-07-03   07/03/1868       1868.0
# 6             NaN       A10.0Y   1868-07-03   07/03/1868       1868.0
# 7             NaN       A10.0Y   1868-07-03   07/03/1868       1868.0
# 8             NaN     A1001.0Q   1868-07-03     7/3/1868       1868.0
# 9             NaN     A1001.0Q   1868-07-03     7/3/1868       1868.0
#
#      SummaryWRStatus                                          Company  \
# 0                NaN                                              NaN
# 1                NaN                                              NaN
# 2  Fully Adjudicated  PIONEER CANAL COMPANY OF ALBANY COUNTY, WYOMING
# 3  Fully Adjudicated                                              NaN
# 4  Fully Adjudicated                                              NaN
# 5  Fully Adjudicated                                              NaN
# 6  Fully Adjudicated                                L & W DAIRY, INC.
# 7  Fully Adjudicated                                L & W DAIRY, INC.
# 8  Fully Adjudicated     EASTERN SHOSHONE AND NORTHERN ARAPAHO TRIBES
# 9  Fully Adjudicated     EASTERN SHOSHONE AND NORTHERN ARAPAHO TRIBES
#
#    FirstName    LastName    FacilityName            Uses   Twn   Rng   Sec  \
# 0  HOWARD E.  MCCLINTOCK  St. John Ditch          IRR_SW  033N  099W   5.0
# 1  HOWARD E.  MCCLINTOCK  St. John Ditch          IRR_SW  033N  099W   8.0
# 2        NaN         NaN   PIONEER CANAL          IRR_SW  014N  076W  24.0
# 3       FRED     KNADLER      PARK DITCH  DOM_SW; IRR_SW  016N  075W   1.0
# 4       FRED     KNADLER      PARK DITCH  DOM_SW; IRR_SW  016N  075W   1.0
# 5  ROBERT A.      WOMACK       RAY DITCH          IRR_SW  001S  001E  19.0
# 6        NaN         NaN       RAY DITCH          IRR_SW  002S  001E   6.0
# 7        NaN         NaN       RAY DITCH          IRR_SW  002S  001E   6.0
# 8        NaN         NaN  CAMPBELL DITCH          IRR_SW  008N  005W  32.0
# 9        NaN         NaN  CAMPBELL DITCH          IRR_SW  008N  005W  32.0
#
#   POUQTR      QtrQtr Survey    POUStatus SupplyType  CreatedBy   Latitude  \
# 0     SW  SW1/4SW1/4   A11-  ADJUDICATED   Original        NaN  42.846380
# 1     NW  NW1/4NW1/4    NaN  ADJUDICATED   Original        NaN  42.846380
# 2    All         All     L1          NaN   Original        NaN        NaN
# 3    NaN         NaN     L3  ADJUDICATED   Original        NaN        NaN
# 4    NaN         NaN     L4  ADJUDICATED   Original        NaN        NaN
# 5     SE  SW1/4SE1/4      A  ADJUDICATED   Original        NaN  43.000050
# 6     NE  NW1/4NE1/4      A  ADJUDICATED   Original        NaN  43.000050
# 7     NW  NE1/4NW1/4      A  ADJUDICATED   Original        NaN  43.000050
# 8     NE  SW1/4NE1/4      A  ADJUDICATED   Original        NaN  43.637639
# 9     NW  SE1/4NW1/4      A  ADJUDICATED   Original        NaN  43.637639
#
#     Longitude   DateDownloaded  WaterDivision WaterDistrict QTRQTR_CLEAN  \
# 0 -108.734790  10/31/2018 6:00            3.0             1         SWSW
# 1 -108.734790   6/11/2018 6:00            3.0             1         NWNW
# 2         NaN   5/12/2018 6:00            1.0            4A          All
# 3         NaN              NaN            1.0            4B          NaN
# 4         NaN              NaN            1.0            4B          NaN
# 5 -108.932881   7/11/2018 6:00            3.0             1         SWSE
# 6 -108.932881  11/14/2018 7:00            3.0             1         NWNE
# 7 -108.932881   6/11/2018 6:00            3.0             1         NENW
# 8 -109.357561  11/14/2018 7:00            3.0             3         SWNE
# 9 -109.357561   6/11/2018 6:00            3.0             3         SENW
#
#   PLSS_SECTION PLSS_QTR     PLSS_QTRQTR   Acres  Mapping_Level  Agg_POU_Count  \
# 0          NaN      NaN  033N099W05SWSW   17.42            0.0            1.0
# 1          NaN      NaN  033N099W08NWNW   17.90            0.0            1.0
# 2   014N076W24      NaN             NaN  160.00            2.0            1.0
# 3          NaN      NaN             NaN   40.00            0.0            1.0
# 4          NaN      NaN             NaN   57.00            0.0            1.0
# 5          NaN      NaN  001S001E19SWSE   16.10            0.0            1.0
# 6          NaN      NaN  002S001E06NWNE   33.85            0.0            1.0
# 7          NaN      NaN  002S001E06NENW   30.91            0.0            1.0
# 8          NaN      NaN  008N005W32SWNE    2.00            0.0            1.0
# 9          NaN      NaN  008N005W32SENW    2.70            0.0            1.0
#
#             PLSS_TractLot SupplySource  FacilityType  Centroid_X  Centroid_Y  \
# 0                     NaN          NaN           NaN -108.722999   42.855441
# 1                     NaN          NaN           NaN -108.722846   42.851810
# 2                     NaN          NaN           NaN -105.872701   41.168013
# 3  WY060160N0750W0SN010L3          NaN           NaN -105.761376   41.392876
# 4  WY060160N0750W0SN010L4          NaN           NaN -105.766251   41.392914
# 5                     NaN          NaN           NaN -108.802081   42.955181
# 6                     NaN          NaN           NaN -108.802140   42.922594
# 7                     NaN          NaN           NaN -108.807083   42.922589
# 8                     NaN          NaN           NaN -109.377905   43.629544
# 9                     NaN          NaN           NaN -109.382876   43.629616
#
#    AcresGISpoly  AcresDifference ErrorType  Notes  Shape_Length  Shape_Area  \
# 0     40.101820       -22.681820       NaN    NaN      0.017115    0.000018
# 1     40.221616       -22.321616       NaN    NaN      0.017133    0.000018
# 2    647.327142      -487.327142       NaN    NaN      0.067776    0.000281
# 3     58.144626       -18.144626       NaN    NaN      0.020144    0.000025
# 4     57.244232        -0.244232       NaN    NaN      0.019984    0.000025
# 5     39.885265       -23.785265       NaN    NaN      0.017082    0.000018
# 6     40.323073        -6.473073       NaN    NaN      0.017166    0.000018
# 7     40.393514        -9.483514       NaN    NaN      0.017179    0.000018
# 8     39.978673       -37.978673       NaN    NaN      0.017208    0.000018
# 9     39.585383       -36.885383       NaN    NaN      0.017138    0.000018
#
#   WaDEUUID                                        WaDEOwner  \
# 0     wyU0                                              nan
# 1     wyU1                                              nan
# 2     wyU2  PIONEER CANAL COMPANY OF ALBANY COUNTY, WYOMING
# 3     wyU3                                              nan
# 4     wyU4                                              nan
# 5     wyU5                                              nan
# 6     wyU6                                L & W DAIRY, INC.
# 7     wyU7                                L & W DAIRY, INC.
# 8     wyU8     EASTERN SHOSHONE AND NORTHERN ARAPAHO TRIBES
# 9     wyU9     EASTERN SHOSHONE AND NORTHERN ARAPAHO TRIBES
#
#                                           WaDEBenUse
# 0                         Irrigation - Surface Water
# 1                         Irrigation - Surface Water
# 2                         Irrigation - Surface Water
# 3  Domestic - Surface Water, Irrigation - Surface...
# 4  Domestic - Surface Water, Irrigation - Surface...
# 5                         Irrigation - Surface Water
# 6                         Irrigation - Surface Water
# 7                         Irrigation - Surface Water
# 8                         Irrigation - Surface Water
# 9                         Irrigation - Surface Water

# %%
# For Wild and Scenic River benuse
# suffix metadata, and anything with a Z in it also has a beneficial use = Wild and Scenic River benuse

def splitWord(word):
    return [char for char in word]

def retrieveWildCenicRiver(word):
    word = str(word)
    worldList = splitWord(word)
    if worldList[0] == "Z":
        outString = "Wild and Scenic River"
    else:
        outString = ""
    
    return outString
    
df['PreffixWaDEBenUse'] = df.apply(lambda row: retrieveWildCenicRiver(row['Survey']), axis=1)
df.head(1)
# Out:
#    OID_  ContractID      Contractor Creation_Edit_Date  Horizontal_Accuracy  \
# 0     1         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
#
#    WRID                                       Duplicate_ID Source_ID  \
# 0   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W05SWSW1/4S...     -3.0-
#
#    PermitNumber OrderRecordNumber PermitPrefix PermitSuffix  IsActive  \
# 0           3.0         OR 17/250            -            -       NaN
#
#   SummaryCRStatus   WRNumber PriorityDate PriorityText  Priority_YR  \
# 0             NaN  OR 17/250   1877-06-20   Spring1877       1877.0
#
#   SummaryWRStatus Company  FirstName    LastName    FacilityName    Uses  \
# 0             NaN     NaN  HOWARD E.  MCCLINTOCK  St. John Ditch  IRR_SW
#
#     Twn   Rng  Sec POUQTR      QtrQtr Survey    POUStatus SupplyType  \
# 0  033N  099W  5.0     SW  SW1/4SW1/4   A11-  ADJUDICATED   Original
#
#    CreatedBy  Latitude  Longitude   DateDownloaded  WaterDivision  \
# 0        NaN  42.84638 -108.73479  10/31/2018 6:00            3.0
#
#   WaterDistrict QTRQTR_CLEAN PLSS_SECTION PLSS_QTR     PLSS_QTRQTR  Acres  \
# 0             1         SWSW          NaN      NaN  033N099W05SWSW  17.42
#
#    Mapping_Level  Agg_POU_Count PLSS_TractLot SupplySource  FacilityType  \
# 0            0.0            1.0           NaN          NaN           NaN
#
#    Centroid_X  Centroid_Y  AcresGISpoly  AcresDifference ErrorType  Notes  \
# 0 -108.722999   42.855441      40.10182        -22.68182       NaN    NaN
#
#    Shape_Length  Shape_Area WaDEUUID WaDEOwner                  WaDEBenUse  \
# 0      0.017115    0.000018     wyU0       nan  Irrigation - Surface Water
#
#   PreffixWaDEBenUse
# 0

# %%
# For Wild and Scenic River benuse
# combine WaDEBenUse & PreffixWaDEBenUse columns if not blank
def combineWaDEBenUses(valA, valB):
    if valA == "" or pd.isnull(valA):
        outString = valB
    else:
        outString = valB + ", " + valA
    
    return outString

df['WaDEBenUse'] = df.apply(lambda row: combineWaDEBenUses(row['PreffixWaDEBenUse'], row['WaDEBenUse']), axis=1)
df.head(1)
# Out:
#    OID_  ContractID      Contractor Creation_Edit_Date  Horizontal_Accuracy  \
# 0     1         NaN  MIKE.ROBERTSON      3/6/2021 0:13                  NaN
#
#    WRID                                       Duplicate_ID Source_ID  \
# 0   NaN  -3.0-OR 17/250IRR_SWOriginal033N099W05SWSW1/4S...     -3.0-
#
#    PermitNumber OrderRecordNumber PermitPrefix PermitSuffix  IsActive  \
# 0           3.0         OR 17/250            -            -       NaN
#
#   SummaryCRStatus   WRNumber PriorityDate PriorityText  Priority_YR  \
# 0             NaN  OR 17/250   1877-06-20   Spring1877       1877.0
#
#   SummaryWRStatus Company  FirstName    LastName    FacilityName    Uses  \
# 0             NaN     NaN  HOWARD E.  MCCLINTOCK  St. John Ditch  IRR_SW
#
#     Twn   Rng  Sec POUQTR      QtrQtr Survey    POUStatus SupplyType  \
# 0  033N  099W  5.0     SW  SW1/4SW1/4   A11-  ADJUDICATED   Original
#
#    CreatedBy  Latitude  Longitude   DateDownloaded  WaterDivision  \
# 0        NaN  42.84638 -108.73479  10/31/2018 6:00            3.0
#
#   WaterDistrict QTRQTR_CLEAN PLSS_SECTION PLSS_QTR     PLSS_QTRQTR  Acres  \
# 0             1         SWSW          NaN      NaN  033N099W05SWSW  17.42
#
#    Mapping_Level  Agg_POU_Count PLSS_TractLot SupplySource  FacilityType  \
# 0            0.0            1.0           NaN          NaN           NaN
#
#    Centroid_X  Centroid_Y  AcresGISpoly  AcresDifference ErrorType  Notes  \
# 0 -108.722999   42.855441      40.10182        -22.68182       NaN    NaN
#
#    Shape_Length  Shape_Area WaDEUUID WaDEOwner                  WaDEBenUse  \
# 0      0.017115    0.000018     wyU0       nan  Irrigation - Surface Water
#
#   PreffixWaDEBenUse
# 0

# %%
# Create output dataframe for ground water
columnslist = [   
    ### Water Source Info ###
    "in_WaterSourceName",
    "in_WaterSourceTypeCV",
    
    ### Site Info ###
    "in_Latitude",
    "in_Longitude",
    "in_SiteName",
    "in_SiteTypeCV",
    "in_PODorPOUSite",
    
    ### AllocationAmount_fact Info ###
    "in_AllocationFlow_CFS",
    "in_AllocationNativeID",
    "in_AllocationOwner",
    "in_AllocationPriorityDate",
    "in_AllocationLegalStatusCV",
    "in_BeneficialUseCategory",
    "in_IrrigatedAcreage"]

dfPOU = pd.DataFrame(columns=columnslist, index=df.index)

# %%
#############################################################################################

# Data Assessment UUID
dfPOU['WaDEUUID'] = df['WaDEUUID']

#WaterSource
dfPOU['in_WaterSourceTypeCV'] = "Unspecified"
dfPOU['in_WaterSourceName'] = df['SupplySource'].astype(str)
                                    
#Site
dfPOU['in_Latitude'] = df['Latitude'].astype(float)
dfPOU['in_Longitude'] = df['Longitude'].astype(float)
dfPOU['in_SiteName'] = df['FacilityName'].astype(str)
dfPOU['in_SiteTypeCV'] = df['FacilityType'].astype(str)
dfPOU['in_PODorPOUSite'] = "POU"

#AllocationAmount_fact
dfPOU['in_AllocationFlow_CFS'] = ""
dfPOU['in_AllocationNativeID'] = df['WRNumber'].astype(str)
dfPOU['in_AllocationOwner'] = df['WaDEOwner'].astype(str)
dfPOU['in_AllocationPriorityDate'] = df['PriorityDate']
dfPOU['in_AllocationLegalStatusCV'] = df['SummaryWRStatus'].astype(str)
dfPOU['in_BeneficialUseCategory'] = df['WaDEBenUse'].astype(str)
dfPOU['in_IrrigatedAcreage'] = df['Acres'].astype(float)

# %%
# Remove NaN values
dfPOU = dfPOU.replace(np.nan, "").replace("nan", "")  # Replaces NaN values with blank.
dfPOU.head(3)
# Out:
#   in_WaterSourceName in_WaterSourceTypeCV in_Latitude in_Longitude  \
# 0                             Unspecified    42.84638   -108.73479
# 1                             Unspecified    42.84638   -108.73479
# 2                             Unspecified
#
#       in_SiteName in_SiteTypeCV in_PODorPOUSite in_AllocationFlow_CFS  \
# 0  St. John Ditch                           POU
# 1  St. John Ditch                           POU
# 2   PIONEER CANAL                           POU
#
#   in_AllocationNativeID                               in_AllocationOwner  \
# 0             OR 17/250
# 1             OR 17/250
# 2           CR CC48/006  PIONEER CANAL COMPANY OF ALBANY COUNTY, WYOMING
#
#   in_AllocationPriorityDate in_AllocationLegalStatusCV  \
# 0                1877-06-20
# 1                1877-06-20
# 2                1879-04-19          Fully Adjudicated
#
#      in_BeneficialUseCategory in_IrrigatedAcreage WaDEUUID
# 0  Irrigation - Surface Water               17.42     wyU0
# 1  Irrigation - Surface Water                17.9     wyU1
# 2  Irrigation - Surface Water               160.0     wyU2

# %% [markdown]
# # Concatenate POD & POU

# %%
# Concatenate
frames = [dfPOD, dfPOU]
dfout = pd.concat(frames)
dfout = dfout.replace(np.nan, "").drop_duplicates()
dfout = dfout.replace("nan", "").drop_duplicates()

print(len(dfout))
dfout
# Out:
# 503658
#        in_WaterSourceName in_WaterSourceTypeCV in_Latitude in_Longitude  \
# 0             Unspecified          Groundwater     42.9129   -104.46127
# 1             Unspecified          Groundwater    42.89665    -105.1149
# 2             Unspecified          Groundwater     42.8762   -105.15106
# 3             Unspecified          Groundwater     43.0178   -107.18099
# 4             Unspecified          Groundwater    43.01056     -107.181
# ...                   ...                  ...         ...          ...
# 491671                             Unspecified
# 491672                             Unspecified   43.859519  -110.592447
# 491673                             Unspecified   43.859519  -110.592447
# 491674                             Unspecified     43.8595   -110.59243
# 491675                             Unspecified         0.0          0.0
#
#                         in_SiteName in_SiteTypeCV in_PODorPOUSite  \
# 0                       O W WELL #1          Well             POD
# 1             LINCOLN WATER WELL #1          Well             POD
# 2                REESE 33-34-69 WSW          Well             POD
# 3                           TIFFANY          Well             POD
# 4                       GRAND PA #7          Well             POD
# ...                             ...           ...             ...
# 491671                                                        POU
# 491672  ENL. JACKSON LAKE RESERVOIR                           POU
# 491673  ENL. JACKSON LAKE RESERVOIR                           POU
# 491674  ENL. JACKSON LAKE RESERVOIR                           POU
# 491675                                                        POU
#
#        in_AllocationFlow_CFS in_AllocationNativeID  \
# 0                      575.0           CR UW04/059
# 1                      750.0            P210075.0W
# 2                      600.0            P209213.0W
# 3                      800.0            P144429.0W
# 4                      800.0            P146345.0W
# ...                      ...                   ...
# 491671
# 491672                                 CR CR06/107
# 491673                                 CR CR06/107
# 491674                                 CR CR06/108
# 491675
#
#                      in_AllocationOwner in_AllocationPriorityDate  \
# 0                     O. W. RANCH, INC.       1976-08-05 00:00:00
# 1                   FREESTONE MIDSTREAM       2018-11-28 00:00:00
# 2             CHESAPEAKE OPERATING, LLC       2018-05-23 00:00:00
# 3        POWDER RIVER AGRI-ORGANIC, LLC       2002-05-03 00:00:00
# 4       POWDER RIVER AGRI-ORGANIC, LLC.       2002-08-16 00:00:00
# ...                                 ...                       ...
# 491671
# 491672       USDI BUREAU OF RECLAMATION       1912-05-20 00:00:00
# 491673       USDI BUREAU OF RECLAMATION       1912-05-20 00:00:00
# 491674       U S DEPARTMENT OF INTERIOR       1913-05-24 00:00:00
# 491675
#
#        in_AllocationLegalStatusCV  \
# 0
# 1                      Incomplete
# 2                      Incomplete
# 3                      Incomplete
# 4                      Incomplete
# ...                           ...
# 491671
# 491672          Fully Adjudicated
# 491673          Fully Adjudicated
# 491674          Fully Adjudicated
# 491675
#
#                                  in_BeneficialUseCategory in_IrrigatedAcreage  \
# 0                               Irrigation - Ground Water
# 1                            Miscellaneous - Ground Water
# 2                            Miscellaneous - Ground Water
# 3                               Irrigation - Ground Water
# 4                               Irrigation - Ground Water
# ...                                                   ...                 ...
# 491671                                        Unspecified
# 491672  Domestic - Surface Water, Irrigation - Surface...
# 491673  Domestic - Surface Water, Irrigation - Surface...
# 491674  Domestic - Surface Water, Irrigation - Surface...                 0.0
# 491675                                        Unspecified                 0.0
#
#          WaDEUUID
# 0           wyDG0
# 1           wyDG1
# 2           wyDG2
# 3           wyDG3
# 4           wyDG4
# ...           ...
# 491671  wyU491671
# 491672  wyU491672
# 491673  wyU491673
# 491674  wyU491674
# 491675  wyU491675
#
# [503658 rows x 15 columns]

# %%
import re

def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).strip()
    return Val

dfout['in_AllocationOwner'] = dfout.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
dfout.head(3)
# Out:
#   in_WaterSourceName in_WaterSourceTypeCV in_Latitude in_Longitude  \
# 0        Unspecified          Groundwater     42.9129   -104.46127
# 1        Unspecified          Groundwater    42.89665    -105.1149
# 2        Unspecified          Groundwater     42.8762   -105.15106
#
#              in_SiteName in_SiteTypeCV in_PODorPOUSite in_AllocationFlow_CFS  \
# 0            O W WELL #1          Well             POD                 575.0
# 1  LINCOLN WATER WELL #1          Well             POD                 750.0
# 2     REESE 33-34-69 WSW          Well             POD                 600.0
#
#   in_AllocationNativeID        in_AllocationOwner in_AllocationPriorityDate  \
# 0           CR UW04/059             O W RANCH INC       1976-08-05 00:00:00
# 1            P210075.0W       FREESTONE MIDSTREAM       2018-11-28 00:00:00
# 2            P209213.0W  CHESAPEAKE OPERATING LLC       2018-05-23 00:00:00
#
#   in_AllocationLegalStatusCV      in_BeneficialUseCategory  \
# 0                                Irrigation - Ground Water
# 1                 Incomplete  Miscellaneous - Ground Water
# 2                 Incomplete  Miscellaneous - Ground Water
#
#   in_IrrigatedAcreage WaDEUUID
# 0                        wyDG0
# 1                        wyDG1
# 2                        wyDG2

# %% [markdown]
# ## WaDE Custom Elements (due to missing state site info)

# %%
# Creating WaDE Custom site native ID for easy site identificaiion
# ----------------------------------------------------------------------------------------------------

# Create temp SiteNativeID dataframe of unique site.
def assignSiteUUID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDEWY_S" + string1
    return outstring

dfSiteNativeID = pd.DataFrame()
dfSiteNativeID['in_Latitude'] = dfout['in_Latitude']
dfSiteNativeID['in_Longitude'] = dfout['in_Longitude']
dfSiteNativeID['in_SiteName'] = dfout['in_SiteName']
dfSiteNativeID = dfSiteNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfSiteNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfSiteNativeID['in_SiteNativeID'] = dftemp.apply(lambda row: assignSiteUUID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveSiteNativeID(A, B, D):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfSiteNativeID.loc[(dfSiteNativeID['in_Latitude'] == A) & 
                                (dfSiteNativeID['in_Longitude'] == B) &
                                (dfSiteNativeID['in_SiteName'] == D), 'in_SiteNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfout['in_SiteNativeID'] = dfout.apply(lambda row: retrieveSiteNativeID( row['in_Latitude'], row['in_Longitude'], row['in_SiteName']), axis=1)
dfout
# Out:
#        in_WaterSourceName in_WaterSourceTypeCV in_Latitude in_Longitude  \
# 0             Unspecified          Groundwater     42.9129   -104.46127
# 1             Unspecified          Groundwater    42.89665    -105.1149
# 2             Unspecified          Groundwater     42.8762   -105.15106
# 3             Unspecified          Groundwater     43.0178   -107.18099
# 4             Unspecified          Groundwater    43.01056     -107.181
# ...                   ...                  ...         ...          ...
# 491671                             Unspecified
# 491672                             Unspecified   43.859519  -110.592447
# 491673                             Unspecified   43.859519  -110.592447
# 491674                             Unspecified     43.8595   -110.59243
# 491675                             Unspecified         0.0          0.0
#
#                         in_SiteName in_SiteTypeCV in_PODorPOUSite  \
# 0                       O W WELL #1          Well             POD
# 1             LINCOLN WATER WELL #1          Well             POD
# 2                REESE 33-34-69 WSW          Well             POD
# 3                           TIFFANY          Well             POD
# 4                       GRAND PA #7          Well             POD
# ...                             ...           ...             ...
# 491671                                                        POU
# 491672  ENL. JACKSON LAKE RESERVOIR                           POU
# 491673  ENL. JACKSON LAKE RESERVOIR                           POU
# 491674  ENL. JACKSON LAKE RESERVOIR                           POU
# 491675                                                        POU
#
#        in_AllocationFlow_CFS in_AllocationNativeID  \
# 0                      575.0           CR UW04/059
# 1                      750.0            P210075.0W
# 2                      600.0            P209213.0W
# 3                      800.0            P144429.0W
# 4                      800.0            P146345.0W
# ...                      ...                   ...
# 491671
# 491672                                 CR CR06/107
# 491673                                 CR CR06/107
# 491674                                 CR CR06/108
# 491675
#
#                   in_AllocationOwner in_AllocationPriorityDate  \
# 0                      O W RANCH INC       1976-08-05 00:00:00
# 1                FREESTONE MIDSTREAM       2018-11-28 00:00:00
# 2           CHESAPEAKE OPERATING LLC       2018-05-23 00:00:00
# 3       POWDER RIVER AGRIORGANIC LLC       2002-05-03 00:00:00
# 4       POWDER RIVER AGRIORGANIC LLC       2002-08-16 00:00:00
# ...                              ...                       ...
# 491671
# 491672    USDI BUREAU OF RECLAMATION       1912-05-20 00:00:00
# 491673    USDI BUREAU OF RECLAMATION       1912-05-20 00:00:00
# 491674    U S DEPARTMENT OF INTERIOR       1913-05-24 00:00:00
# 491675
#
#        in_AllocationLegalStatusCV  \
# 0
# 1                      Incomplete
# 2                      Incomplete
# 3                      Incomplete
# 4                      Incomplete
# ...                           ...
# 491671
# 491672          Fully Adjudicated
# 491673          Fully Adjudicated
# 491674          Fully Adjudicated
# 491675
#
#                                  in_BeneficialUseCategory in_IrrigatedAcreage  \
# 0                               Irrigation - Ground Water
# 1                            Miscellaneous - Ground Water
# 2                            Miscellaneous - Ground Water
# 3                               Irrigation - Ground Water
# 4                               Irrigation - Ground Water
# ...                                                   ...                 ...
# 491671                                        Unspecified
# 491672  Domestic - Surface Water, Irrigation - Surface...
# 491673  Domestic - Surface Water, Irrigation - Surface...
# 491674  Domestic - Surface Water, Irrigation - Surface...                 0.0
# 491675                                        Unspecified                 0.0
#
#          WaDEUUID in_SiteNativeID
# 0           wyDG0       WaDEWY_S1
# 1           wyDG1       WaDEWY_S2
# 2           wyDG2       WaDEWY_S3
# 3           wyDG3       WaDEWY_S4
# 4           wyDG4       WaDEWY_S5
# ...           ...             ...
# 491671  wyU491671
# 491672  wyU491672   WaDEWY_S53404
# 491673  wyU491673   WaDEWY_S53405
# 491674  wyU491674   WaDEWY_S53411
# 491675  wyU491675   WaDEWY_S72263
#
# [503658 rows x 16 columns]

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDEWY_WS" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = dfout['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = dfout['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceName'] == A) & 
                                       (dfWaterSourceNativeID['in_WaterSourceTypeCV'] == B), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfout['in_WaterSourceNativeID'] = dfout.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
dfout
# Out:
#        in_WaterSourceName in_WaterSourceTypeCV in_Latitude in_Longitude  \
# 0             Unspecified          Groundwater     42.9129   -104.46127
# 1             Unspecified          Groundwater    42.89665    -105.1149
# 2             Unspecified          Groundwater     42.8762   -105.15106
# 3             Unspecified          Groundwater     43.0178   -107.18099
# 4             Unspecified          Groundwater    43.01056     -107.181
# ...                   ...                  ...         ...          ...
# 491671                             Unspecified
# 491672                             Unspecified   43.859519  -110.592447
# 491673                             Unspecified   43.859519  -110.592447
# 491674                             Unspecified     43.8595   -110.59243
# 491675                             Unspecified         0.0          0.0
#
#                         in_SiteName in_SiteTypeCV in_PODorPOUSite  \
# 0                       O W WELL #1          Well             POD
# 1             LINCOLN WATER WELL #1          Well             POD
# 2                REESE 33-34-69 WSW          Well             POD
# 3                           TIFFANY          Well             POD
# 4                       GRAND PA #7          Well             POD
# ...                             ...           ...             ...
# 491671                                                        POU
# 491672  ENL. JACKSON LAKE RESERVOIR                           POU
# 491673  ENL. JACKSON LAKE RESERVOIR                           POU
# 491674  ENL. JACKSON LAKE RESERVOIR                           POU
# 491675                                                        POU
#
#        in_AllocationFlow_CFS in_AllocationNativeID  \
# 0                      575.0           CR UW04/059
# 1                      750.0            P210075.0W
# 2                      600.0            P209213.0W
# 3                      800.0            P144429.0W
# 4                      800.0            P146345.0W
# ...                      ...                   ...
# 491671
# 491672                                 CR CR06/107
# 491673                                 CR CR06/107
# 491674                                 CR CR06/108
# 491675
#
#                   in_AllocationOwner in_AllocationPriorityDate  \
# 0                      O W RANCH INC       1976-08-05 00:00:00
# 1                FREESTONE MIDSTREAM       2018-11-28 00:00:00
# 2           CHESAPEAKE OPERATING LLC       2018-05-23 00:00:00
# 3       POWDER RIVER AGRIORGANIC LLC       2002-05-03 00:00:00
# 4       POWDER RIVER AGRIORGANIC LLC       2002-08-16 00:00:00
# ...                              ...                       ...
# 491671
# 491672    USDI BUREAU OF RECLAMATION       1912-05-20 00:00:00
# 491673    USDI BUREAU OF RECLAMATION       1912-05-20 00:00:00
# 491674    U S DEPARTMENT OF INTERIOR       1913-05-24 00:00:00
# 491675
#
#        in_AllocationLegalStatusCV  \
# 0
# 1                      Incomplete
# 2                      Incomplete
# 3                      Incomplete
# 4                      Incomplete
# ...                           ...
# 491671
# 491672          Fully Adjudicated
# 491673          Fully Adjudicated
# 491674          Fully Adjudicated
# 491675
#
#                                  in_BeneficialUseCategory in_IrrigatedAcreage  \
# 0                               Irrigation - Ground Water
# 1                            Miscellaneous - Ground Water
# 2                            Miscellaneous - Ground Water
# 3                               Irrigation - Ground Water
# 4                               Irrigation - Ground Water
# ...                                                   ...                 ...
# 491671                                        Unspecified
# 491672  Domestic - Surface Water, Irrigation - Surface...
# 491673  Domestic - Surface Water, Irrigation - Surface...
# 491674  Domestic - Surface Water, Irrigation - Surface...                 0.0
# 491675                                        Unspecified                 0.0
#
#          WaDEUUID in_SiteNativeID in_WaterSourceNativeID
# 0           wyDG0       WaDEWY_S1             WaDEWY_WS1
# 1           wyDG1       WaDEWY_S2             WaDEWY_WS1
# 2           wyDG2       WaDEWY_S3             WaDEWY_WS1
# 3           wyDG3       WaDEWY_S4             WaDEWY_WS1
# 4           wyDG4       WaDEWY_S5             WaDEWY_WS1
# ...           ...             ...                    ...
# 491671  wyU491671                          WaDEWY_WS2591
# 491672  wyU491672   WaDEWY_S53404          WaDEWY_WS2591
# 491673  wyU491673   WaDEWY_S53405          WaDEWY_WS2591
# 491674  wyU491674   WaDEWY_S53411          WaDEWY_WS2591
# 491675  wyU491675   WaDEWY_S72263          WaDEWY_WS2591
#
# [503658 rows x 17 columns]

# %% [markdown]
# ## Export Outputs

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(dfout.dtypes)
# Out:
# in_WaterSourceName            object
# in_WaterSourceTypeCV          object
# in_Latitude                   object
# in_Longitude                  object
# in_SiteName                   object
# in_SiteTypeCV                 object
# in_PODorPOUSite               object
# in_AllocationFlow_CFS         object
# in_AllocationNativeID         object
# in_AllocationOwner            object
# in_AllocationPriorityDate     object
# in_AllocationLegalStatusCV    object
# in_BeneficialUseCategory      object
# in_IrrigatedAcreage           object
# WaDEUUID                      object
# in_SiteNativeID               object
# in_WaterSourceNativeID        object
# dtype: object

# %%
#Exporting to Finished File
dfout.to_csv('RawInputData/P_WyomingMaster.csv', index=False)  # The output

# %%
arrX = dfout['in_BeneficialUseCategory'].unique()
str1 = ','.join(arrX).strip()

def Convert(string):
    li = list(string.split(","))
    return li
list1 = Convert(str1)

for i in list1:
    print(i)
# Out:
# Irrigation - Ground Water
# Miscellaneous - Ground Water
# Industrial - Ground Water
#  Miscellaneous - Ground Water
# Industrial - Ground Water
# Miscellaneous - Ground Water
#  Industrial - Ground Water
# Domestic - Ground Water
#  Industrial - Ground Water
# Domestic - Ground Water
#  Irrigation - Ground Water
# Irrigation - Ground Water
#  Miscellaneous - Ground Water
# Miscellaneous - Ground Water
#  Miscellaneous - Ground Water
# Miscellaneous - Ground Water
#  Stock Watering
# Irrigation - Ground Water
#  Stock Watering
# Domestic - Ground Water
#  Irrigation - Ground Water
#  Miscellaneous - Ground Water
# Municipal - Ground Water
# Miscellaneous - Ground Water
#  Municipal - Ground Water
# Industrial - Ground Water
#  Stock Watering
# Irrigation - Ground Water
#  Miscellaneous - Ground Water
#  Stock Watering
# Industrial - Ground Water
#  Irrigation - Ground Water
#  Stock Watering
# Domestic - Ground Water
#  Irrigation - Ground Water
#  Stock Watering
# Industrial - Ground Water
#  Municipal - Ground Water
#  Stock Watering
# Industrial - Ground Water
#  Miscellaneous - Ground Water
#  Municipal - Ground Water
# Industrial - Ground Water
#  Miscellaneous - Ground Water
#  Municipal - Ground Water
#  Stock Watering
# Municipal - Ground Water
#  Stock Watering
# Coal Bed Methane - Ground Water
#  Miscellaneous - Ground Water
# Miscellaneous - Ground Water
#  Municipal - Ground Water
#  Stock Watering
# Coal Bed Methane - Ground Water
#  Irrigation - Ground Water
#  Miscellaneous - Ground Water
# Coal Bed Methane - Ground Water
#  Irrigation - Ground Water
#  Miscellaneous - Ground Water
#  Stock Watering
# Irrigation - Surface Water
# Domestic - Ground Water
# Domestic - Ground Water
#  Industrial - Ground Water
#  Miscellaneous - Ground Water
# Domestic - Ground Water
#  Stock Watering
# Domestic - Ground Water
#  Miscellaneous - Ground Water
# Domestic - Ground Water
#  Wild and Scenic River
# Industrial - Ground Water
#  Irrigation - Ground Water
# Irrigation - Ground Water
#  Wild and Scenic River
# Industrial - Ground Water
#  Miscellaneous - Ground Water
#  Miscellaneous - Ground Water
# Domestic - Ground Water
#  Industrial - Ground Water
#  Irrigation - Ground Water
#  Stock Watering
# Domestic - Ground Water
#  Irrigation - Ground Water
#  Miscellaneous - Ground Water
#  Stock Watering
# Unspecified
# Irrigation - Surface Water
#  Reservoir Supply
# Power
# Irrigation - Surface Water
#  Stock
# Irrigation - Surface Water
#  Stock and Domestic
# Domestic - Surface Water
#  Irrigation - Surface Water
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Stock
# Fish Propagation
#  Reservoir Supply
# Irrigation - Surface Water
#  Mechanical
# Industrial - Surface Water
# Stock
# Reservoir Supply
# Instream Flow
# Unspecified
#  Wild and Scenic River
# Municipal - Surface Water
# Mechanical
# Recreation
#  Reservoir Supply
#  Wildlife
# Flow Through
#  Reservoir Supply
# Irrigation - Surface Water
#  Wild and Scenic River
# Domestic - Surface Water
#  Fish Propagation
# Fish Propagation
# Temporary
# Hydropower
# Other
# Ground Water Recharge
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Milling
# Domestic - Surface Water
#  Reservoir Supply
# Domestic - Surface Water
#  Hydropower
# Domestic Supply
#  Fire Protection
#  Reservoir Supply
# Hydropower
#  Irrigation - Surface Water
#  Stock
# Flow Through
# Recreation
#  Reservoir Supply
# Domestic Supply
#  Recreation
# Industrial - Surface Water
#  Reservoir Supply
# Domestic Supply
#  Fire Protection
#  Industrial - Surface Water
#  Municipal - Surface Water
# Hydropower
#  Stock and Domestic
# Domestic - Surface Water
#  Industrial - Surface Water
#  Municipal - Surface Water
# Domestic Supply
#  Industrial - Surface Water
#  Municipal - Surface Water
# Industrial - Surface Water
#  Irrigation - Surface Water
# Flow Through
#  Irrigation - Surface Water
#  Reservoir Supply
# Domestic - Surface Water
#  Industrial - Surface Water
# Reservoir Supply
#  Stock
# Domestic - Surface Water
# Domestic - Surface Water
#  Municipal - Surface Water
#  Other
# Irrigation - Surface Water
#  Reservoir Supply
#  Stock
# Manufacturing
#  Stream
# Mining
#  Municipal - Surface Water
#  Power
# Irrigation - Surface Water
#  Municipal - Surface Water
#  Other
# Domestic Supply
#  Reservoir Supply
# Fire Protection
#  Industrial - Surface Water
# Stream
# Irrigation - Surface Water
#  Other
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Reservoir Supply
# Recreation
# Irrigation - Surface Water
#  Stock
#  Wild and Scenic River
# Wetlands
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Stock and Domestic
# Irrigation - Surface Water
#  Domestic - Surface Water
# Domestic Supply
#  Irrigation - Surface Water
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Wild and Scenic River
# Irrigation - Surface Water
#  Municipal - Surface Water
#  Reservoir Supply
# Domestic - Surface Water
#  Municipal - Surface Water
# Irrigation - Surface Water
#  Stock and Domestic
#  Stock
# Combined Uses
# Hydropower
#  Municipal - Surface Water
# Domestic - Surface Water
#  Municipal - Surface Water
#  Reservoir Supply
# Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Reservoir Supply
# Industrial - Surface Water
#  Municipal - Surface Water
#  Reservoir Supply
# Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
# Irrigation - Surface Water
#  Municipal - Surface Water
# Municipal - Surface Water
#  Other
# Irrigation - Surface Water
#  Stock and Domestic
#  Stock and Domestic
# Railroad
# Flow Through
#  Recreation
#  Reservoir Supply
# Stock and Domestic
# Other
#  Stock and Domestic
# Domestic - Surface Water
#  Municipal - Surface Water
#  Other
#  Railroad
# Chemical
#  Domestic - Surface Water
#  Industrial - Surface Water
# Fire Protection
# Other
#  Reservoir Supply
# Domestic Supply
# Other
#  Stock
# Domestic Supply
#  Irrigation - Surface Water
#  Reservoir Supply
# Domestic - Surface Water
#  Erosion Control
#  Irrigation - Surface Water
# Irrigation - Surface Water
#  Stock
#  Domestic - Surface Water
# Fish Propagation
#  Flow Through
#  Reservoir Supply
# Domestic Supply
#  Flow Through
#  Irrigation - Surface Water
#  Reservoir Supply
# Flow Through
#  Recreation
#  Reservoir Supply
#  Stock
# Recreation
#  Stock
# Domestic - Surface Water
#  Industrial - Surface Water
#  Irrigation - Surface Water
# Other
#  Irrigation - Surface Water
# Commercial
# Domestic - Surface Water
#  Industrial - Surface Water
#  Municipal - Surface Water
#  Railroad
# Irrigation - Surface Water
#  Reservoir Supply
#  Stock and Domestic
# Domestic - Surface Water
#  Domestic Supply
# Reservoir Supply
#  Wildlife
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Reservoir Supply
#  Stock
# Fish Propagation
#  Recreation
# Domestic - Surface Water
#  Wild and Scenic River
# Commercial
#  Hydropower
#  Irrigation - Surface Water
# Commercial
#  Domestic - Surface Water
# Fish Propagation
#  Stock and Domestic
# Stock and Domestic
#  Wild and Scenic River
# Irrigation - Surface Water
#  Stock and Domestic
#  Wild and Scenic River
# Domestic - Surface Water
#  Stock
# Other
#  Wild and Scenic River
# Fish Propagation
#  Stock
# Domestic - Surface Water
#  Stream
# Domestic - Surface Water
#  Fire Protection
# Domestic - Surface Water
#  Hydropower
#  Irrigation - Surface Water
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Other
# Domestic - Surface Water
#  Fish Propagation
#  Irrigation - Surface Water
# Stock and Domestic
#  Stock
# Stock
#  Domestic - Surface Water
# Consumptive Instream Flow
# Stock
#  Wildlife
# Domestic Supply
#  Flow Through
#  Reservoir Supply
# Domestic - Surface Water
#  Other
# Domestic - Surface Water
#  Stock
#  Wild and Scenic River
# Domestic - Surface Water
#  Reservoir Supply
#  Stock
# Fire Protection
#  Other
#  Stock
# Reservoir Supply
#  Wild and Scenic River
# Domestic Supply
#  Stock
# Domestic Supply
#  Fire Protection
#  Industrial - Surface Water
#  Stock
# Domestic Supply
#  Stock and Domestic
# Domestic - Surface Water
#  Domestic Supply
#  Stock
# Domestic - Surface Water
#  Power
# Fire Protection
#  Irrigation - Surface Water
#  Stock
# Municipal - Surface Water
#  Stock and Domestic
# Reservoir Supply
#  Stock and Domestic
# Fish Propagation
#  Irrigation - Surface Water
#  Reservoir Supply
# Domestic Supply
#  Irrigation - Surface Water
#  Stock
# Domestic - Surface Water
#  Industrial - Surface Water
#  Stock
# Industrial - Surface Water
#  Municipal - Surface Water
# Domestic - Surface Water
#  Recreation
# Municipal - Surface Water
#  Railroad
#  Stream
# Fish Propagation
#  Stock and Domestic
#  Wildlife
# Flood Control
# Power
#  Stock and Domestic
# Domestic - Surface Water
#  Fire Protection
#  Irrigation - Surface Water
#  Stock
# Domestic - Surface Water
#  Flow Through
#  Irrigation - Surface Water
#  Reservoir Supply
# Irrigation - Surface Water
#  Domestic - Surface Water
#  Wild and Scenic River
# Domestic - Surface Water
#  Oil
# Industrial - Surface Water
#  Recreation
#  Reservoir Supply
# Fish Propagation
#  Irrigation - Surface Water
# Domestic - Surface Water
#  Stream
#  Stock
# Domestic Supply
#  Municipal - Surface Water
#  Stock
# Fish Propagation
#  Flow Through
#  Reservoir Supply
#  Wetlands
# Commercial
#  Domestic Supply
#  Fire Protection
#  Stock
# Commercial
#  Domestic - Surface Water
#  Domestic Supply
#  Fire Protection
#  Stock
# Industrial - Surface Water
#  Stock and Domestic
# Domestic - Surface Water
#  Stock and Domestic
#  Stock
# Domestic - Surface Water
#  Domestic Supply
#  Industrial - Surface Water
#  Irrigation - Surface Water
# Domestic - Ground Water
#  Miscellaneous - Ground Water
#  Stock Watering
# Domestic - Surface Water
#  Stock and Domestic
# Industrial - Surface Water
#  Other
#  Stock and Domestic
# Mining
# Domestic - Surface Water
#  Oil
#  Stock
# Domestic - Surface Water
#  Railroad
# Oil
# Domestic - Surface Water
#  Power
#  Stock
# Stock Watering
#  Domestic - Ground Water
# Domestic - Surface Water
#  Fire Protection
#  Industrial - Surface Water
# Domestic - Ground Water
#  Stock Watering
#  Miscellaneous - Ground Water
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Stream
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Mining
# Irrigation - Ground Water
#  Domestic - Ground Water
# Coal Bed Methane - Ground Water
# Industrial - Ground Water
#  Miscellaneous - Ground Water
#  Stock Watering
# Fish Propagation
#  Irrigation - Surface Water
#  Stock
# Flood Control
#  Industrial - Surface Water
# Wildlife
# Fish Propagation
#  Wildlife
# Fish Propagation
#  Recreation
#  Stock
# Domestic - Surface Water
#  Municipal - Surface Water
#  Railroad
#  Stream
# Coal Bed Methane - Ground Water
#  Stock Watering
# Flood Control
#  Industrial - Surface Water
#  Stock
#  Wildlife
# Fish Propagation
#  Recreation
#  Wildlife
# Fish Propagation
#  Wetlands
# Fish Propagation
#  Other
#  Recreation
#  Wildlife
# Fish Propagation
#  Other
# Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
# Flood Control
#  Industrial - Surface Water
#  Stock
# Industrial - Surface Water
#  Stock
#  Wildlife
# Industrial - Surface Water
#  Stock
# Wetlands
#  Wildlife
# Fire Protection
#  Flood Control
#  Industrial - Surface Water
# Coal Bed Methane - Ground Water
#  Miscellaneous - Ground Water
#  Stock Watering
# Domestic - Surface Water
#  Fish Propagation
#  Recreation
#  Stock
# Fish Propagation
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Recreation
#  Wetlands
# Fish Propagation
#  Recreation
#  Stock
#  Wildlife
# Miscellaneous - Ground Water
#  Monitor
# Stock Watering
#  Miscellaneous - Ground Water
# Fish Propagation
#  Stock
#  Wetlands
# Fish Propagation
#  Stock
#  Wetlands
#  Wildlife
# Flood Control
#  Stock
#  Wildlife
# Fish Propagation
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Fish Propagation
#  Wetlands
#  Wildlife
# Irrigation - Surface Water
#  Recreation
# Flood Control
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Fire Protection
#  Fish Propagation
# Flood Control
#  Irrigation - Surface Water
#  Stock
# Recreation
#  Wildlife
# Fish Propagation
#  Stock
#  Wildlife
# Fish Propagation
#  Irrigation - Surface Water
#  Sediment Control
#  Stock
# Combined Uses
#  Fish Propagation
#  Stock
# Domestic Supply
#  Fish Propagation
#  Irrigation - Surface Water
# Fire Protection
#  Fish Propagation
#  Wetlands
# Domestic - Surface Water
#  Wetlands
# Fish Propagation
#  Other
#  Wetlands
# Combined Uses
#  Fish Propagation
#  Stock
#  Wildlife
# Combined Uses
#  Fish Propagation
#  Wetlands
# Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
# Coal Bed Natural Gas
# Flood Control
#  Other
#  Recreation
#  Stock
#  Wildlife
# Fire Protection
#  Fish Propagation
#  Stock
#  Wildlife
# Recreation
#  Stock
#  Wildlife
# Fish Propagation
#  Recreation
#  Wetlands
#  Wildlife
# Industrial - Surface Water
#  Wildlife
# Fish Propagation
#  Flood Control
#  Wildlife
# Wildlife
#  Stock
#  Combined Uses
# Combined Uses
#  Fish Propagation
#  Recreation
# Coal Bed Methane - Ground Water
#  Domestic - Ground Water
# Other
#  Wildlife
# Stock and Domestic
#  Wildlife
# Combined Uses
#  Stock
#  Wildlife
# Fire Protection
#  Other
# Combined Uses
#  Industrial - Surface Water
#  Stock
#  Wetlands
# Stock Watering
#  Coal Bed Methane - Ground Water
# Combined Uses
#  Fish Propagation
#  Wildlife
# Domestic - Surface Water
#  Stock
#  Wildlife
# Combined Uses
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Wildlife
#  Combined Uses
#  Wetlands
# Irrigation - Surface Water
#  Wildlife
# Combined Uses
#  Wetlands
#  Wildlife
# Fish Propagation
#  Municipal - Surface Water
#  Other
# Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Combined Uses
#  Fish Propagation
#  Stock
#  Wetlands
#  Wildlife
# Combined Uses
#  Recreation
#  Wildlife
# Combined Uses
#  Stock
#  Wetlands
# Flood Control
#  Temporary
# Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Wildlife
#  Wild and Scenic River
# Fire Protection
#  Fish Propagation
#  Stock
# Domestic - Surface Water
#  Hydropower
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Other
#  Stock
# Flood Control
#  Recreation
# Flood Control
#  Other
#  Recreation
# Other
#  Recreation
# Flood Control
#  Recreation
#  Wetlands
# Flood Control
#  Other
#  Recreation
#  Wetlands
# Coal Bed Natural Gas
#  Stock
# Flood Control
#  Wildlife
# Fish Propagation
#  Irrigation - Surface Water
#  Recreation
#  Wildlife
# Combined Uses
#  Fish Propagation
#  Recreation
#  Stock
# Domestic - Surface Water
#  Domestic Supply
#  Irrigation - Surface Water
# Coal Bed Natural Gas
#  Stock
#  Wildlife
# Coal Bed Natural Gas
#  Industrial - Surface Water
#  Stock
#  Wildlife
# Fire Protection
#  Fish Propagation
#  Wetlands
#  Wildlife
# Irrigation - Surface Water
#  Stock
#  Wetlands
# Flood Control
#  Stock
# Coal Bed Natural Gas
#  Irrigation - Surface Water
#  Stock
# Recreation
#  Stock
#  Wetlands
#  Wildlife
# Domestic - Surface Water
#  Railroad
#  Stock
# Combined Uses
#  Coal Bed Natural Gas
#  Stock
#  Wildlife
# Combined Uses
#  Coal Bed Natural Gas
#  Stock
# Combined Uses
#  Coal Bed Natural Gas
#  Industrial - Surface Water
#  Stock
#  Wildlife
# Coal Bed Natural Gas
#  Irrigation - Surface Water
# Domestic Supply
#  Wildlife
# Miscellaneous - Ground Water
#  Wild and Scenic River
# Combined Uses
#  Coal Bed Natural Gas
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Combined Uses
#  Coal Bed Natural Gas
#  Irrigation - Surface Water
#  Stock
# Fish Propagation
#  Recreation
#  Stock
#  Wetlands
# Domestic - Surface Water
#  Fire Protection
#  Stock
#  Wildlife
# Combined Uses
#  Coal Bed Natural Gas
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Combined Uses
#  Fish Propagation
#  Wetlands
#  Wildlife
# Irrigation - Surface Water
#  Stock
#  Wildlife
# Recreation
#  Wetlands
#  Wildlife
# Combined Uses
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Coal Bed Natural Gas
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Domestic Supply
#  Fire Protection
#  Stock
# Combined Uses
#  Fish Propagation
#  Recreation
#  Wildlife
# Combined Uses
#  Fish Propagation
#  Flood Control
#  Industrial - Surface Water
#  Stock
#  Wildlife
# Combined Uses
#  Fire Protection
#  Fish Propagation
#  Recreation
# Railroad
#  Stock and Domestic
# Coal Bed Natural Gas
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
#  Wildlife
# Domestic Supply
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Fire Protection
#  Wildlife
# Combined Uses
#  Industrial - Surface Water
#  Stock
#  Wildlife
# Hydropower
#  Irrigation - Surface Water
#  Municipal - Surface Water
# Industrial - Surface Water
#  Irrigation - Surface Water
#  Wildlife
# Recreation
#  Fish Propagation
#  Wildlife
#  Stock
# Recreation
#  Fish Propagation
#  Wildlife
#  Irrigation - Surface Water
#  Stock
# Irrigation - Surface Water
#  Recreation
#  Stock
# Stock
#  Wetlands
#  Wildlife
# Fish Propagation
#  Other
#  Recreation
#  Stock
# Flow Through
#  Other
#  Reservoir Supply
# Irrigation - Ground Water
#  Stock Watering
#  Domestic - Ground Water
# Wildlife
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Recreation
#  Stock
#  Wildlife
# Irrigation - Surface Water
#  Wetlands
#  Stock
# Irrigation - Surface Water
#  Coal Bed Natural Gas
#  Coal Bed Natural Gas
# Stock
#  Irrigation - Surface Water
#  Coal Bed Natural Gas
# Irrigation - Surface Water
#  Stock
#  Fish Propagation
# Industrial - Surface Water
#  Wetlands
# Domestic Supply
#  Fish Propagation
#  Wildlife
# Irrigation - Ground Water
#  Miscellaneous - Ground Water
#  Municipal - Ground Water
# Fish Propagation
#  Other
#  Recreation
# Recreation
#  Wild and Scenic River
# Domestic Supply
#  Fish Propagation
#  Industrial - Surface Water
#  Recreation
# Domestic Supply
#  Industrial - Surface Water
# Industrial - Surface Water
#  Recreation
#  Wildlife
# Coal Bed Methane - Ground Water
#  Irrigation - Ground Water
# Fish Propagation
#  Wildlife
#  Flood Control
#  Stock
#  Wetlands
# Combined Uses
#  Industrial - Surface Water
#  Recreation
#  Wildlife
# Combined Uses
#  Fish Propagation
#  Recreation
#  Stock
#  Wildlife
# Fish Propagation
#  Irrigation - Surface Water
#  Wetlands
# Irrigation - Surface Water
#  Wetlands
# Industrial - Surface Water
#  Irrigation - Surface Water
#  Other
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Manufacturing
#  Power
# Combined Uses
#  Stock
#  Wetlands
#  Wildlife
# Combined Uses
#  Fish Propagation
#  Recreation
#  Wetlands
# Combined Uses
#  Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Fish Propagation
#  Wildlife
#  Stock
#  Combined Uses
# Industrial - Surface Water
#  Fire Protection
# Fish Propagation
#  Recreation
#  Wetlands
# Domestic - Surface Water
#  Wildlife
# Domestic - Surface Water
#  Flood Control
#  Wildlife
# Fish Propagation
#  Stock
#  Combined Uses
# Flood Control
#  Irrigation - Surface Water
# Combined Uses
#  Fish Propagation
#  Recreation
#  Wetlands
#  Wildlife
# Fish Propagation
#  Wildlife
#  Flood Control
#  Stock
# Combined Uses
#  Recreation
#  Stock
#  Wildlife
# Combined Uses
#  Flood Control
#  Stock
#  Wildlife
# Industrial - Surface Water
#  Flood Control
# Domestic - Surface Water
#  Fish Propagation
#  Stock
# Fish Propagation
#  Industrial - Surface Water
#  Municipal - Surface Water
#  Recreation
# Combined Uses
#  Fish Propagation
#  Stock
#  Wetlands
# Fish Propagation
#  Industrial - Surface Water
#  Stock
#  Wildlife
# Irrigation - Ground Water
#  Municipal - Ground Water
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Manufacturing
#  Municipal - Surface Water
#  Power
#  Stock
# Irrigation - Ground Water
#  Stock Watering
#  Coal Bed Methane - Ground Water
#  Miscellaneous - Ground Water
# Domestic - Surface Water
#  Manufacturing
# Stock Watering
#  Miscellaneous - Ground Water
#  Coal Bed Methane - Ground Water
# Miscellaneous - Ground Water
#  Coal Bed Methane - Ground Water
# Stock and Domestic
#  Stream
# Domestic Supply
#  Municipal - Surface Water
# Domestic - Surface Water
#  Fire Protection
#  Other
# Coal Bed Methane - Ground Water
#  Wild and Scenic River
# Domestic Supply
#  Other
# Municipal - Surface Water
#  Reservoir Supply
# Fish Propagation
#  Flow Through
#  Recreation
#  Reservoir Supply
# Commercial
#  Stock and Domestic
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Power
# Recreation
#  Stock and Domestic
# Miscellaneous - Ground Water
#  Miscellaneous - Ground Water
#  Coal Bed Methane - Ground Water
# Domestic - Ground Water
#  Stock Watering
#  Irrigation - Ground Water
# Stock Watering
#  Coal Bed Methane - Ground Water
#  Miscellaneous - Ground Water
# Miscellaneous - Ground Water
#  Miscellaneous - Ground Water
#  Miscellaneous - Ground Water
# Municipal - Surface Water
#  Stock and Domestic
#  Wild and Scenic River
# Miscellaneous - Ground Water
#  Coal Bed Methane - Ground Water
#  Stock Watering
# Coal Bed Methane - Ground Water
#  Stock Watering
#  Miscellaneous - Ground Water
# Stock Watering
#  Irrigation - Ground Water
#  Miscellaneous - Ground Water
# Irrigation - Ground Water
#  Coal Bed Methane - Ground Water
# Domestic - Surface Water
#  Transportation
# Domestic - Surface Water
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
# Industrial - Ground Water
#  Irrigation - Ground Water
#  Miscellaneous - Ground Water
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Stock
#  Wild and Scenic River
# Domestic - Surface Water
#  Mining
#  Stream
# Hydropower
#  Irrigation - Surface Water
# Fish Propagation
#  Flow Through
# Irrigation - Surface Water
#  Other
#  Stock
# Commercial
#  Industrial - Surface Water
#  Municipal - Surface Water
# Irrigation - Surface Water
#  Reservoir Supply
#  Domestic - Surface Water
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Railroad
# Erosion Control
#  Fish Propagation
#  Recreation
#  Stock
# Domestic - Surface Water
#  Municipal - Surface Water
#  Railroad
# Domestic Supply
#  Fish Propagation
#  Reservoir Supply
# Domestic - Ground Water
#  Municipal - Ground Water
# Fish Propagation
#  Reservoir Supply
#  Wildlife
# Fire Protection
#  Reservoir Supply
# Domestic - Ground Water
#  Irrigation - Ground Water
#  Miscellaneous - Ground Water
#  Municipal - Ground Water
#  Stock Watering
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Stream
# Flow Through
#  Reservoir Supply
#  Stock
# Combined Uses
#  Domestic - Surface Water
# Domestic - Surface Water
#  Flow Through
#  Reservoir Supply
# Domestic Supply
#  Fire Protection
# Flow Through
#  Irrigation - Surface Water
#  Recreation
#  Reservoir Supply
# Reservoir Supply
#  Stock
#  Wetlands
# Hydropower
#  Reservoir Supply
# Domestic Supply
#  Recreation
#  Reservoir Supply
# Fire Protection
#  Irrigation - Surface Water
# Domestic - Surface Water
#  Other
#  Stock
# Hydropower
#  Other
# Domestic - Surface Water
#  Industrial - Surface Water
#  Stream
#  Stock
# Domestic - Surface Water
#  Fish Propagation
#  Irrigation - Surface Water
#  Stock
# Domestic - Surface Water
#  Other
#  Railroad
# Domestic - Surface Water
#  Hydropower
#  Stock
# Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Manufacturing
#  Municipal - Surface Water
#  Power
#  Recreation
# Fish Propagation
#  Irrigation - Surface Water
#  Municipal - Surface Water
# Domestic - Surface Water
#  Fish Propagation
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Stock
# Domestic - Ground Water
#  Industrial - Ground Water
#  Municipal - Ground Water
#  Stock Watering
# Domestic - Surface Water
#  Flood Control
#  Irrigation - Surface Water
# Municipal - Surface Water
#  Other
#  Railroad
# Domestic - Surface Water
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
# Domestic - Surface Water
#  Fish Propagation
#  Ice Cutting
#  Recreation
#  Stock
# Domestic - Surface Water
#  Erosion Control
#  Fire Protection
#  Fish Propagation
#  Flood Control
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Domestic - Surface Water
#  Erosion Control
#  Fire Protection
#  Fish Propagation
#  Flood Control
#  Hydropower
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Domestic - Surface Water
#  Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Power
#  Recreation
# Domestic - Surface Water
#  Erosion Control
#  Fire Protection
#  Fish Propagation
#  Flood Control
#  Irrigation - Surface Water
#  Power
#  Recreation
#  Stock
# Irrigation - Surface Water
#  Irrigation - Surface Water
#  Irrigation - Surface Water
#  Irrigation - Surface Water
# Domestic - Surface Water
#  Fish Propagation
#  Hydropower
#  Irrigation - Surface Water
#  Stock
# Miscellaneous - Ground Water
#  Monitor
#  Stock Watering
# Combined Uses
#  Domestic - Surface Water
#  Fish Propagation
#  Stock
# Combined Uses
#  Domestic - Surface Water
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Stock
# Hydropower
#  Wild and Scenic River
# Fish Propagation
#  Municipal - Surface Water
#  Recreation
#  Stock
# Domestic - Surface Water
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Mining
#  Municipal - Surface Water
#  Stock
# Fish Propagation
#  Irrigation - Surface Water
#  Recreation
# Domestic - Surface Water
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Power
#  Stock
# Flood Control
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Other
# Fish Propagation
#  Irrigation - Surface Water
#  Wildlife
# Irrigation - Surface Water
#  Irrigation - Surface Water
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Other
#  Stock
# Domestic - Ground Water
#  Irrigation - Ground Water
#  Municipal - Ground Water
#  Stock Watering
# Irrigation - Surface Water
#  Irrigation - Surface Water
#  Irrigation - Surface Water
# Domestic - Surface Water
#  Industrial - Surface Water
#  Municipal - Surface Water
#  Other
#  Railroad
# Domestic - Surface Water
#  Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Recreation
#  Stock
#  Wildlife
#  Wild and Scenic River
# Domestic - Surface Water
#  Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Recreation
#  Stock
#  Wildlife
# Domestic - Ground Water
#  Industrial - Ground Water
#  Stock Watering
# Hydropower
#  Municipal - Surface Water
#  Wild and Scenic River
# Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Erosion Control
#  Flood Control
#  Recreation
# Erosion Control
#  Flood Control
#  Stock
# Domestic - Surface Water
#  Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Manufacturing
#  Stock
# Erosion Control
#  Flood Control
# Domestic - Ground Water
#  Industrial - Ground Water
#  Irrigation - Ground Water
#  Miscellaneous - Ground Water
# Commercial
#  Domestic Supply
#  Stock
# Fire Protection
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Combined Uses
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Flood Control
#  Other
#  Stock
# Other
#  Recreation
#  Stock
# Ground Water Recharge
#  Reservoir Supply
# Combined Uses
#  Flood Control
#  Irrigation - Surface Water
#  Stock
# Fire Protection
#  Fish Propagation
#  Reservoir Supply
# Reservoir Supply
#  Wetlands
# Fire Protection
#  Flow Through
#  Reservoir Supply
# Erosion Control
#  Fish Propagation
#  Flood Control
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
# Flood Control
#  Irrigation - Surface Water
#  Other
# Fish Propagation
#  Flood Control
#  Municipal - Surface Water
#  Recreation
# Fish Propagation
#  Flood Control
#  Irrigation - Surface Water
#  Other
#  Recreation
#  Stock
# Domestic - Surface Water
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Power
#  Stream
# Domestic - Surface Water
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Power
#  Recreation
#  Stream
#  Stock
# Hydropower
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Stock
# Industrial - Surface Water
#  Irrigation - Surface Water
#  Power
#  Stock
# Fish Propagation
#  Flood Control
#  Stock
# Domestic Supply
#  Fire Protection
#  Industrial - Surface Water
# Fish Propagation
#  Flood Control
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Domestic - Surface Water
#  Domestic Supply
#  Hydropower
# Recreation
#  Irrigation - Surface Water
#  Stock
# Flood Control
#  Irrigation - Surface Water
#  Other
#  Stock
# Fish Propagation
#  Flood Control
# Flood Control
#  Reservoir Supply
# Flood Control
#  Irrigation - Surface Water
#  Recreation
#  Stock
# Reservoir Supply
#  Flow Through
# Fish Propagation
#  Industrial - Surface Water
#  Recreation
#  Wildlife
# Fish Propagation
#  Flood Control
#  Recreation
# Flow Through
#  Recreation
#  Reservoir Supply
#  Wetlands
# Domestic - Surface Water
#  Domestic Supply
#  Fire Protection
#  Irrigation - Surface Water
#  Stock and Domestic
#  Stock
# Industrial - Surface Water
#  Other
# Combined Uses
#  Industrial - Surface Water
# Mining
#  Municipal - Surface Water
# Domestic - Ground Water
#  Industrial - Ground Water
#  Miscellaneous - Ground Water
#  Stock Watering
# Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
# Combined Uses
#  Coal Bed Natural Gas
#  Industrial - Surface Water
# Flood Control
#  Other
# Wildlife
#  Stock
# Domestic - Surface Water
#  Hydropower
#  Industrial - Surface Water
# Coal Bed Natural Gas
#  Industrial - Surface Water
# Stock Watering
#  Domestic - Ground Water
#  Miscellaneous - Ground Water
# Coal Bed Natural Gas
#  Fire Protection
# Industrial - Surface Water
#  Temporary
# Irrigation - Surface Water
#  Sediment Control
# Miscellaneous - Ground Water
#  Stock Watering
#  Wild and Scenic River
# Domestic - Surface Water
#  Fish Propagation
#  Flood Control
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Other
# Fish Propagation
#  Flood Control
#  Recreation
#  Wildlife
# Fish Propagation
#  Flood Control
#  Recreation
#  Stock
#  Wildlife
# Fish Propagation
#  Municipal - Surface Water
#  Recreation
# Domestic - Surface Water
#  Fish Propagation
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Power
#  Recreation
#  Stock
# Industrial - Surface Water
#  Stream
# Fish Propagation
#  Hydropower
#  Industrial - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Recreation
#  Wetlands
#  Wildlife
# Fish Propagation
#  Hydropower
#  Irrigation - Surface Water
#  Stock
# Fire Protection
#  Industrial - Surface Water
#  Temporary
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Power
#  Stock
# Fish Propagation
#  Irrigation - Surface Water
#  Municipal - Surface Water
#  Recreation
#  Wildlife
# Domestic - Surface Water
#  Irrigation - Surface Water
#  Municipal - Surface Water
# Commercial
#  Domestic - Surface Water
#  Irrigation - Surface Water
# Irrigation - Surface Water
#  Railroad
