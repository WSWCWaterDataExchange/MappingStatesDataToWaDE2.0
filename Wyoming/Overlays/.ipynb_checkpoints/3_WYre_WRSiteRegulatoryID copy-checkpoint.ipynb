# %% [markdown]
# # Assign RegulatoryOverlayUUIDs Values to Water Right sites.csv
# Purpose:  To assign RegulatoryOverlayUUIDs values to state water right sites.csv File.
#
# Notes:
# - requires the completed pre-processed sites.csv & watersource.csv files from the state "WaterAllocation/ProcessedInputData" folder to be copied over to the "Regulatory/ProcessedInputData" folder.  Rename to wr_sites.csv & wr_watersource.csv to preserve inputs.
# - requires awareness of unique WaterSourceTypeCV of each water right site match up to corresponding WaterSourceTypeCV of regulatoryoverlays per reportingunits

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library
import geoplot as gplt # for plotting maps
import geoplot.crs as gcrs #used to pull in webdata

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = os.getcwd() # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: /Volumes/SPACEX/GitHub/Wyoming/Regulatory

# %% [markdown]
# ## Input Data

# %%
# Regulatory Input Data
dfro = pd.read_csv("ProcessedInputData/regulatoryoverlays.csv")
dfru = pd.read_csv("ProcessedInputData/reportingunits.csv")
dfrru = pd.read_csv("ProcessedInputData/regulatoryreportingunits.csv")

# Water right Input Data
dfws = pd.read_csv('ProcessedInputData/wr_watersources.csv')
dfs = pd.read_csv('ProcessedInputData/wr_sites.csv')

# %%
#### regulatory watersource info with reporting unit info

# merge regulatoryoverlays -to- regulatoryreportingunits -to- reportingunits
dfro = pd.merge(dfro[['RegulatoryOverlayUUID', 'WaterSourceTypeCV']], dfrru[['RegulatoryOverlayUUID', 'ReportingUnitUUID']], left_on='RegulatoryOverlayUUID', right_on='RegulatoryOverlayUUID', how='left')
dfru = pd.merge(dfru, dfro, left_on='ReportingUnitUUID', right_on='ReportingUnitUUID', how='left')

print(dfru['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfru))
dfru.head(1)
# Out:
# ['Surface Water and Groundwater']
# 35
#   ReportingUnitUUID  EPSGCodeCV             ReportingUnitName  \
# 0        SDre_RUwy1        4326  Campbell County Conservation
#
#   ReportingUnitNativeID  ReportingUnitProductVersion     ReportingUnitTypeCV  \
# 0                   wy1                          NaN  Conservation Districts
#
#   ReportingUnitUpdateDate StateCV  \
# 0               7/30/2023      WY
#
#                                             Geometry RegulatoryOverlayUUID  \
# 0  POLYGON ((-106.01895941400703 43.7119056633044...              SDre_RO1
#
#                WaterSourceTypeCV
# 0  Surface Water and Groundwater

# %%
#### water right watersource info with site info

# explode site.csv on WaterSourceUUIDs
dfs = dfs.assign(WaterSourceUUIDs=dfs['WaterSourceUUIDs'].str.split(',')).explode('WaterSourceUUIDs').reset_index(drop=True)

# merge watersources to dfs via WaterSourceUUIDs -to -WaterSourceUUID
dfs = pd.merge(dfs, dfws[['WaterSourceUUID', 'WaterSourceTypeCV']], left_on='WaterSourceUUIDs', right_on='WaterSourceUUID', how='left')
print(dfs['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfs))
dfs.head(1)
# Out:
# ['Groundwater' 'Surface Water' nan 'WaDE Unspecified']
# 71612
#         SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 0  WYwr_SwadeID1                     NaN   WYwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV  Geometry  GNISCodeCV  \
# 0   WaDE Unspecified  WaDE Unspecified        4326       NaN         NaN
#
#    HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  NHDProductCV  \
# 0    NaN   NaN  42.91290 -104.46127                 NaN           NaN
#
#   PODorPOUSite     SiteName SiteNativeID  SitePoint SiteTypeCV StateCV  \
# 0          POD  O W Well #1      wadeID1        NaN       Well      WY
#
#    USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0         NaN  WYwr_WSwadeID1       Groundwater

# %% [markdown]
# ## Extract RegulatoryOverlay from Reporting Units and assing to WR Sites
# - repeat scripts based on the number of ReportingUnitTypeCV types.
# - merge all geo-dataframes into one output

# %% [markdown]
# #### Regulatory Area Data #1

# %%
# Create copy of reportingunits dataframe
# Extract out ReportingUnitTypeCV from reportingunits dataframe
# note unique WaterSourceTypeCV

dfru1 = dfru.copy()
nameOfReportingUnitTypeVar = "Conservation Districts" # change here for ReportingUnitTypeCV of interest
dfru1 = dfru1[dfru1['ReportingUnitTypeCV'] == nameOfReportingUnitTypeVar]
print(len(dfru1))
print(dfru1['WaterSourceTypeCV'].unique())
dfru1.head(1)
# Out:
# 35
# ['Surface Water and Groundwater']
#   ReportingUnitUUID  EPSGCodeCV             ReportingUnitName  \
# 0        SDre_RUwy1        4326  Campbell County Conservation
#
#   ReportingUnitNativeID  ReportingUnitProductVersion     ReportingUnitTypeCV  \
# 0                   wy1                          NaN  Conservation Districts
#
#   ReportingUnitUpdateDate StateCV  \
# 0               7/30/2023      WY
#
#                                             Geometry RegulatoryOverlayUUID  \
# 0  POLYGON ((-106.01895941400703 43.7119056633044...              SDre_RO1
#
#                WaterSourceTypeCV
# 0  Surface Water and Groundwater

# %%
# Convert dataframe -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

dfru1 = dfru1[dfru1['Geometry'] != ""].reset_index(drop=True)
dfru1['Geometry'] = gpd.GeoSeries.from_wkt(dfru1['Geometry'], crs="EPSG:4326")
gdfru1 = gpd.GeoDataFrame(dfru1, geometry=dfru1['Geometry'], crs="EPSG:4326") # covert to geodataframe
gplt.polyplot(gdfru1, ax=ax)
# Out:
# <GeoAxes: >

# %%
# Create copy of water right sites dataframe
# Extract out WaterSourceTypeCV and match to that of above reportingunits dataframe

dfs1 = dfs.copy()
#nameOfWaterSourceTypeCV= "Surface Water" # change here for WaterSourceTypeCV of interest
#dfs1 = dfs1[dfs1['WaterSourceTypeCV'] == nameOfWaterSourceTypeCV]
#print(len(dfs1))
print(dfs1['WaterSourceTypeCV'].unique())
dfs1.head(1)
# Out:
# ['Groundwater' 'Surface Water' nan 'WaDE Unspecified']
#         SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 0  WYwr_SwadeID1                     NaN   WYwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV  Geometry  GNISCodeCV  \
# 0   WaDE Unspecified  WaDE Unspecified        4326       NaN         NaN
#
#    HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  NHDProductCV  \
# 0    NaN   NaN  42.91290 -104.46127                 NaN           NaN
#
#   PODorPOUSite     SiteName SiteNativeID  SitePoint SiteTypeCV StateCV  \
# 0          POD  O W Well #1      wadeID1        NaN       Well      WY
#
#    USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0         NaN  WYwr_WSwadeID1       Groundwater

# %%
# Convert extracted water right sites -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gdfs1 = gpd.GeoDataFrame(dfs1, geometry=gpd.points_from_xy(dfs1.Longitude.astype(float), dfs1.Latitude.astype(float)), crs="EPSG:4326")
gplt.pointplot(gdfs1, hue='PODorPOUSite', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxes: >

# %%
# Select sites within polygon.
gdfs1_ru1 = gpd.sjoin(left_df=gdfs1, right_df=gdfru1[['ReportingUnitUUID', 'RegulatoryOverlayUUID', 'geometry']], op='within').replace(np.nan, "")
print(len(gdfs1_ru1))
gdfs1_ru1.head()
# Out:
# /Users/josephmac/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3466: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# 71481
#                SiteUUID RegulatoryOverlayUUIDs   WaterSourceUUIDs  \
# 0         WYwr_SwadeID1                            WYwr_WSwadeID1
# 745   WYwr_SwadeID10692                         WYwr_WSwadeID2581
# 755   WYwr_SwadeID10702                         WYwr_WSwadeID2583
# 764   WYwr_SwadeID10711                           WYwr_WSwadeID54
# 1339  WYwr_SwadeID11238
#
#      CoordinateAccuracy CoordinateMethodCV            County  EPSGCodeCV  \
# 0      WaDE Unspecified   WaDE Unspecified  WaDE Unspecified        4326
# 745    WaDE Unspecified   WaDE Unspecified  WaDE Unspecified        4326
# 755    WaDE Unspecified   WaDE Unspecified  WaDE Unspecified        4326
# 764    WaDE Unspecified   WaDE Unspecified  WaDE Unspecified        4326
# 1339   WaDE Unspecified   WaDE Unspecified  WaDE Unspecified        4326
#
#      Geometry GNISCodeCV HUC12 HUC8  Latitude  Longitude NHDNetworkStatusCV  \
# 0                                    42.91290 -104.46127
# 745                                  42.94122 -104.15988
# 755                                  42.94619 -104.25512
# 764                                  42.89289 -104.73231
# 1339                                 42.77223 -104.39561
#
#      NHDProductCV PODorPOUSite                   SiteName SiteNativeID  \
# 0                          POD                O W Well #1      wadeID1
# 745                        POD         Kraft Ditch No Two  wadeID10692
# 755                        POD  Jensen Portable Sprinkler  wadeID10702
# 764                        POD            Goss No I Ditch  wadeID10711
# 1339                       POU          Christian Well #1  wadeID11238
#
#      SitePoint        SiteTypeCV StateCV USGSSiteID    WaterSourceUUID  \
# 0                           Well      WY                WYwr_WSwadeID1
# 745                       Stream      WY             WYwr_WSwadeID2581
# 755                       Stream      WY             WYwr_WSwadeID2583
# 764                       Stream      WY               WYwr_WSwadeID54
# 1339            WaDE Unspecified      WY
#
#      WaterSourceTypeCV                     geometry  index_right  \
# 0          Groundwater  POINT (-104.46127 42.91290)            9
# 745      Surface Water  POINT (-104.15988 42.94122)            9
# 755      Surface Water  POINT (-104.25512 42.94619)            9
# 764      Surface Water  POINT (-104.73231 42.89289)            9
# 1339                    POINT (-104.39561 42.77223)            9
#
#      ReportingUnitUUID RegulatoryOverlayUUID
# 0          SDre_RUwy18             SDre_RO18
# 745        SDre_RUwy18             SDre_RO18
# 755        SDre_RUwy18             SDre_RO18
# 764        SDre_RUwy18             SDre_RO18
# 1339       SDre_RUwy18             SDre_RO18

# %%
# plot the selected points
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gplt.pointplot(gdfs1_ru1, hue='PODorPOUSite', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxes: >

# %%
# set RegulatoryOverlayUUIDs
gdfs1_ru1['RegulatoryOverlayUUIDs'] = gdfs1_ru1['RegulatoryOverlayUUID']
gdfs1_ru1 = gdfs1_ru1.drop(['RegulatoryOverlayUUID', 'geometry', 'index_right', 'ReportingUnitUUID', 'WaterSourceUUID', 'WaterSourceTypeCV'], axis=1)
gdfs1_ru1.head(1)
# Out:
#         SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 0  WYwr_SwadeID1              SDre_RO18   WYwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV Geometry GNISCodeCV HUC12  \
# 0   WaDE Unspecified  WaDE Unspecified        4326
#
#   HUC8  Latitude  Longitude NHDNetworkStatusCV NHDProductCV PODorPOUSite  \
# 0       42.91290 -104.46127                                          POD
#
#       SiteName SiteNativeID SitePoint SiteTypeCV StateCV USGSSiteID
# 0  O W Well #1      wadeID1                 Well      WY

# %% [markdown]
# #### Regulatory Area Data #2

# %%
# dfru2 = dfru.copy()
# etc etc

# %% [markdown]
# ## Concatenate all Regulatory Area Data Types together
# - drop geometry from the wade wr sites.csv geodataframe

# %%
# Concatenate dataframes into single output
frames = [dfs, gdfs1_ru1] # list all out dataframes here
outdfs = pd.concat(frames)
outdfs = outdfs.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
outdfs = outdfs.groupby('SiteUUID').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem!=''])).replace(np.nan, "").reset_index(drop=True)
print(len(outdfs))
# Out:
# 71590

# %% [markdown]
# # Inspect Output Data & Export

# %%
outdfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71590 entries, 0 to 71589
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   RegulatoryOverlayUUIDs  71590 non-null  object
#  1   WaterSourceUUIDs        71590 non-null  object
#  2   CoordinateAccuracy      71590 non-null  object
#  3   CoordinateMethodCV      71590 non-null  object
#  4   County                  71590 non-null  object
#  5   EPSGCodeCV              71590 non-null  object
#  6   Geometry                71590 non-null  object
#  7   GNISCodeCV              71590 non-null  object
#  8   HUC12                   71590 non-null  object
#  9   HUC8                    71590 non-null  object
#  10  Latitude                71590 non-null  object
#  11  Longitude               71590 non-null  object
#  12  NHDNetworkStatusCV      71590 non-null  object
#  13  NHDProductCV            71590 non-null  object
#  14  PODorPOUSite            71590 non-null  object
#  15  SiteName                71590 non-null  object
#  16  SiteNativeID            71590 non-null  object
#  17  SitePoint               71590 non-null  object
#  18  SiteTypeCV              71590 non-null  object
#  19  StateCV                 71590 non-null  object
#  20  USGSSiteID              71590 non-null  object
#  21  WaterSourceUUID         71590 non-null  object
#  22  WaterSourceTypeCV       71590 non-null  object
# dtypes: object(23)
# memory usage: 12.6+ MB

# %%
outdfs
# Out:
#       RegulatoryOverlayUUIDs   WaterSourceUUIDs CoordinateAccuracy  \
# 0                  SDre_RO18     WYwr_WSwadeID1   WaDE Unspecified
# 1                  SDre_RO11     WYwr_WSwadeID1   WaDE Unspecified
# 2                  SDre_RO17     WYwr_WSwadeID1   WaDE Unspecified
# 3                   SDre_RO8     WYwr_WSwadeID1   WaDE Unspecified
# 4                  SDre_RO24   WYwr_WSwadeID971   WaDE Unspecified
# ...                      ...                ...                ...
# 71585              SDre_RO24  WYwr_WSwadeID2043   WaDE Unspecified
# 71586              SDre_RO15  WYwr_WSwadeID2252   WaDE Unspecified
# 71587              SDre_RO24   WYwr_WSwadeID582   WaDE Unspecified
# 71588              SDre_RO24   WYwr_WSwadeID969   WaDE Unspecified
# 71589              SDre_RO24   WYwr_WSwadeID970   WaDE Unspecified
#
#       CoordinateMethodCV            County EPSGCodeCV Geometry GNISCodeCV  \
# 0       WaDE Unspecified  WaDE Unspecified       4326
# 1       WaDE Unspecified  WaDE Unspecified       4326
# 2       WaDE Unspecified  WaDE Unspecified       4326
# 3       WaDE Unspecified  WaDE Unspecified       4326
# 4       WaDE Unspecified  WaDE Unspecified       4326
# ...                  ...               ...        ...      ...        ...
# 71585   WaDE Unspecified  WaDE Unspecified       4326
# 71586   WaDE Unspecified  WaDE Unspecified       4326
# 71587   WaDE Unspecified  WaDE Unspecified       4326
# 71588   WaDE Unspecified  WaDE Unspecified       4326
# 71589   WaDE Unspecified  WaDE Unspecified       4326
#
#       HUC12 HUC8   Latitude    Longitude NHDNetworkStatusCV NHDProductCV  \
# 0                   42.9129   -104.46127
# 1                 42.519136  -104.467717
# 2                  42.86266   -106.25622
# 3                 41.170561    -104.2651
# 4                  41.63907   -106.71993
# ...     ...  ...        ...          ...                ...          ...
# 71585              41.63093   -106.64952
# 71586              41.77123   -106.59266
# 71587              41.60639   -106.59026
# 71588              41.63696   -106.72698
# 71589              41.63724    -106.7268
#
#       PODorPOUSite                  SiteName SiteNativeID SitePoint  \
# 0              POD               O W Well #1      wadeID1
# 1              POD           Frank Harris #2     wadeID10
# 2              POD          Texas Company #5    wadeID100
# 3              POD  Minnick Ranch No. 1 Well   wadeID1000
# 4              POD         Spring No 3 Ditch  wadeID10000
# ...            ...                       ...          ...       ...
# 71585          POD              Wilson Ditch   wadeID9995
# 71586          POD        Dana Springs Ditch   wadeID9996
# 71587          POD              Spring Ditch   wadeID9997
# 71588          POD         Spring No 1 Ditch   wadeID9998
# 71589          POD         Spring No 2 Ditch   wadeID9999
#
#       SiteTypeCV StateCV USGSSiteID    WaterSourceUUID WaterSourceTypeCV
# 0           Well      WY                WYwr_WSwadeID1       Groundwater
# 1           Well      WY                WYwr_WSwadeID1       Groundwater
# 2           Well      WY                WYwr_WSwadeID1       Groundwater
# 3           Well      WY                WYwr_WSwadeID1       Groundwater
# 4         Spring      WY              WYwr_WSwadeID971     Surface Water
# ...          ...     ...        ...                ...               ...
# 71585     Spring      WY             WYwr_WSwadeID2043     Surface Water
# 71586     Spring      WY             WYwr_WSwadeID2252     Surface Water
# 71587     Spring      WY              WYwr_WSwadeID582     Surface Water
# 71588     Spring      WY              WYwr_WSwadeID969     Surface Water
# 71589     Spring      WY              WYwr_WSwadeID970     Surface Water
#
# [71590 rows x 23 columns]

# %%
# Export out to CSV.
outdfs.to_csv('ProcessedInputData/sites.csv', index=False) # this is in the Regulatory data folder
