# %% [markdown]
# # Pre-processing Aggregated Water Use data for WaDE upload.
# Purpose:  To pre-process the aggregated water use data into one master file for simple DataFrame creation and extraction

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/WaDE Data Folder/GreatLakes/WaterUse_AggregatedArea" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/WaDE Data Folder/GreatLakes/WaterUse_AggregatedArea

# %% [markdown]
# ## Input Source Data

# %%
# Time series info
inputFile ="RawInputData/WSWC Great Lakes Data 2012-2022.zip"
df_ts = pd.read_csv(inputFile, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in df_ts:
    df_ts['WaDEUUID'] = "glag" + df_ts.index.astype(str)
    df_ts.to_csv('RawInputData/WSWC Great Lakes Data 2012-2022.zip', compression=dict(method='zip', archive_name='WSWC Great Lakes Data 2012-2022.csv'), index=False)

print(len(df_ts))
df_ts.head()
# Out:
# 5189
#    sector  source  basin  jurisdiction  unit  with_amt consump  \
# 0       1       1      2             1     1 783.81000 0.00000
# 1       2       1      2             1     1   1.83400 0.00000
# 2       2       3      2             1     1   0.00000 0.00000
# 3       3       1      2             1     1   0.00000 0.00000
# 4       3       3      2             1     1   0.08200 0.08200
#
#   consump_percent consump_coefficient facit_num intrabasin_transfer_amt  \
# 0         0.00000                   0  16.00000                 0.00000
# 1         0.00000                   0   2.00000                 0.00000
# 2         0.00000                   0   0.00000                 0.00000
# 3         0.00000                   0   0.00000                 0.00000
# 4       100.00000                   0   1.00000                 0.00000
#
#   intrabasin_return net_intrabasin_change intrabasin_consump intrabasin_num  \
# 0           0.00000               0.00000            0.00000        0.00000
# 1           0.00000               0.00000            0.00000        0.00000
# 2           0.00000               0.00000            0.00000        0.00000
# 3           0.00000               0.00000            0.00000        0.00000
# 4           0.00000               0.00000            0.00000        0.00000
#
#   diversion_amt diversion_return net_diversion_change diversion_num  method  \
# 0     783.81000          0.00000            783.81000      16.00000 1.00000
# 1       1.83400          0.00000              1.83400       2.00000 1.00000
# 2       0.00000          0.00000              0.00000       0.00000
# 3       0.00000          0.00000              0.00000       0.00000
# 4       0.00000          0.00000              0.00000       0.00000 1.00000
#
#   all_with_amts all_consump  year WaDEUUID
# 0     783.81000     0.00000  2022    glag0
# 1       1.83400     0.00000  2022    glag1
# 2       0.00000     0.00000  2022    glag2
# 3       0.00000     0.00000  2022    glag3
# 4       0.08200     0.08200  2022    glag4

# %%
# create unique id to combine with shp file data

df_ts['shpID'] = "j" + df_ts['jurisdiction'].astype(float).astype(int).astype(str).str.strip() + "_b" + df_ts['basin'].astype(float).astype(int).astype(str).str.strip()
df_ts['shpID'].unique()
# Out:
# array(['j1_b2', 'j2_b2', 'j2_b4', 'j3_b1', 'j3_b2', 'j3_b3', 'j3_b4',
#        'j4_b1', 'j5_b4', 'j5_b5', 'j5_b6', 'j6_b4', 'j7_b1', 'j7_b3',
#        'j7_b4', 'j7_b5', 'j7_b6', 'j8_b4', 'j8_b5', 'j9_b6', 'j10_b1',
#        'j10_b2'], dtype=object)

# %%
# Polygon shp info
inputFile ="RawInputData/shapefiles/Exploded_GLCompact_Basins_Jurisdictions.zip"
df_poly = gpd.read_file(inputFile)

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in df_poly:
    df_poly['WaDEUUID'] = "glag" + df_poly.index.astype(str)
    df_poly.to_csv('RawInputData/Exploded_GLCompact_Basins_Jurisdictions.zip', compression=dict(method='zip', archive_name='Exploded_GLCompact_Basins_Jurisdictions.csv'), index=False)

print(len(df_poly))
df_poly.head()
# Out:
# 22
#    Shape_Leng  jurisdic   basin wadeID jur_name          basin_name notes  \
# 0    34.25696   7.00000 4.00000  j7_b4  Ontario           Lake Erie  None
# 1    47.39882   7.00000 3.00000  j7_b3  Ontario          Lake Huron  None
# 2    60.62183   7.00000 1.00000  j7_b1  Ontario       Lake Superior  None
# 3    34.16079   7.00000 5.00000  j7_b5  Ontario        Lake Ontario  None
# 4    58.22232   7.00000 6.00000  j7_b6  Ontario  St. Lawrence River  None
#
#    Shape_Le_1  Shape_Area                                           geometry  \
# 0    15.01843     2.57080  POLYGON ((-80.14996 43.93119, -80.14998 43.929...
# 1    47.69183    10.17209  POLYGON ((-81.31089 47.44333, -81.31057 47.442...
# 2    49.62184    12.48842  POLYGON ((-89.13481 51.12819, -89.09873 51.108...
# 3    23.80428     3.19340  POLYGON ((-76.57685 44.21177, -76.59855 44.211...
# 4    33.43084     6.31962  POLYGON ((-79.51780 48.07788, -79.51781 48.074...
#
#   WaDEUUID
# 0    glag0
# 1    glag1
# 2    glag2
# 3    glag3
# 4    glag4

# %%
# merge input data into single dataframe

dfIn = pd.merge(df_ts, df_poly, left_on='shpID', right_on='wadeID', how='left')
print(len(dfIn))
dfIn.head()
# Out:
# 5189
#    sector  source  basin_x  jurisdiction  unit  with_amt consump  \
# 0       1       1        2             1     1 783.81000 0.00000
# 1       2       1        2             1     1   1.83400 0.00000
# 2       2       3        2             1     1   0.00000 0.00000
# 3       3       1        2             1     1   0.00000 0.00000
# 4       3       3        2             1     1   0.08200 0.08200
#
#   consump_percent consump_coefficient facit_num intrabasin_transfer_amt  \
# 0         0.00000                   0  16.00000                 0.00000
# 1         0.00000                   0   2.00000                 0.00000
# 2         0.00000                   0   0.00000                 0.00000
# 3         0.00000                   0   0.00000                 0.00000
# 4       100.00000                   0   1.00000                 0.00000
#
#   intrabasin_return net_intrabasin_change intrabasin_consump intrabasin_num  \
# 0           0.00000               0.00000            0.00000        0.00000
# 1           0.00000               0.00000            0.00000        0.00000
# 2           0.00000               0.00000            0.00000        0.00000
# 3           0.00000               0.00000            0.00000        0.00000
# 4           0.00000               0.00000            0.00000        0.00000
#
#   diversion_amt diversion_return net_diversion_change diversion_num  method  \
# 0     783.81000          0.00000            783.81000      16.00000 1.00000
# 1       1.83400          0.00000              1.83400       2.00000 1.00000
# 2       0.00000          0.00000              0.00000       0.00000
# 3       0.00000          0.00000              0.00000       0.00000
# 4       0.00000          0.00000              0.00000       0.00000 1.00000
#
#   all_with_amts all_consump  year WaDEUUID_x  shpID  Shape_Leng  jurisdic  \
# 0     783.81000     0.00000  2022      glag0  j1_b2    40.14281   1.00000
# 1       1.83400     0.00000  2022      glag1  j1_b2    40.14281   1.00000
# 2       0.00000     0.00000  2022      glag2  j1_b2    40.14281   1.00000
# 3       0.00000     0.00000  2022      glag3  j1_b2    40.14281   1.00000
# 4       0.08200     0.08200  2022      glag4  j1_b2    40.14281   1.00000
#
#    basin_y wadeID  jur_name     basin_name  \
# 0  2.00000  j1_b2  Illinois  Lake Michigan
# 1  2.00000  j1_b2  Illinois  Lake Michigan
# 2  2.00000  j1_b2  Illinois  Lake Michigan
# 3  2.00000  j1_b2  Illinois  Lake Michigan
# 4  2.00000  j1_b2  Illinois  Lake Michigan
#
#                                                notes  Shape_Le_1  Shape_Area  \
# 0  IL is exempt from some parts of the Great Lake...     2.33655     0.02798
# 1  IL is exempt from some parts of the Great Lake...     2.33655     0.02798
# 2  IL is exempt from some parts of the Great Lake...     2.33655     0.02798
# 3  IL is exempt from some parts of the Great Lake...     2.33655     0.02798
# 4  IL is exempt from some parts of the Great Lake...     2.33655     0.02798
#
#                                             geometry WaDEUUID_y
# 0  POLYGON ((-87.82568 42.49206, -87.81587 42.491...     glag21
# 1  POLYGON ((-87.82568 42.49206, -87.81587 42.491...     glag21
# 2  POLYGON ((-87.82568 42.49206, -87.81587 42.491...     glag21
# 3  POLYGON ((-87.82568 42.49206, -87.81587 42.491...     glag21
# 4  POLYGON ((-87.82568 42.49206, -87.81587 42.491...     glag21

# %%
# determine WaDE MethodTypeCV and Name from dictionary

MethodDict = {
"1":"Measured",
"2":"Partially Measured",
"3":"Calculated"}

def DetermineMethodFunc(valA):  
    if valA == '' or pd.isnull(valA):
        outString = 'WaDE Blank'
    else:
        try:
            valA = str(int(float(valA))).strip()
            outString = MethodDict[valA]
        except:
            outString = 'WaDE Blank'
    return outString

dfIn['in_MethodTypeCV'] = dfIn.apply(lambda row: DetermineMethodFunc(row['method']), axis=1)
dfIn['in_MethodTypeCV'].value_counts()
# Out:
# in_MethodTypeCV
# Partially Measured    2670
# Measured               973
# Calculated             791
# WaDE Blank             755
# Name: count, dtype: int64

# %%
# determine WaDE iWaterSourceTypeCV dictionary

WaterSourceDict = {
"1":"Great Lakes St Lawrence Surface Water",
"2":"Other Surface Water",
"3":"Groundwater"}

def DetermineWaterSourceFunc(valA):  
    if valA == '' or pd.isnull(valA):
        outString = 'WaDE Blank'
    else:
        try:
            valA = str(int(float(valA))).strip()
            outString = WaterSourceDict[valA]
        except:
            outString = 'WaDE Blank'
    return outString

dfIn['in_WaterSourceTypeCV'] = dfIn.apply(lambda row: DetermineWaterSourceFunc(row['source']), axis=1)
dfIn['in_WaterSourceTypeCV'].value_counts()
# Out:
# in_WaterSourceTypeCV
# Other Surface Water                      1790
# Great Lakes St Lawrence Surface Water    1704
# Groundwater                              1695
# Name: count, dtype: int64

# %%
# determine WaDE Benefical Use from dictionary

BenUseDict = {
"1":"Public Water Supply",
"2":"Self Supply Commercial and Institutional",
"3":"Self Supply Irrigation",
"4":"Self Supply Livestock",
"5":"Self Supply Industrial",
"6":"Self Supply Thermoelectric Power Production Once Through Cooling",
"7":"Self Supply Thermoelectric Power Production Recirculated Cooling",
"8":"Off Stream Hydroelectric Power Production",
"9":"In Stream Hydroelectric Water Use",
"10":"Other Self Supply"}

def DetermineBenUseFunc(valA):
    if valA == '' or pd.isnull(valA):
        outString = 'WaDE Blank'
    else:
        try:
            valA = str(int(float(valA))).strip()
            outString = BenUseDict[valA]
        except:
            outString = 'WaDE Blank'
    return outString

dfIn['in_BeneficialUseCategory'] = dfIn.apply(lambda row: DetermineBenUseFunc(row['sector']), axis=1)
dfIn['in_BeneficialUseCategory'].value_counts()
# Out:
# in_BeneficialUseCategory
# Public Water Supply                                                 671
# Self Supply Industrial                                              662
# Self Supply Irrigation                                              639
# Self Supply Commercial and Institutional                            597
# Other Self Supply                                                   528
# Self Supply Livestock                                               526
# Self Supply Thermoelectric Power Production Once Through Cooling    483
# In Stream Hydroelectric Water Use                                   428
# Self Supply Thermoelectric Power Production Recirculated Cooling    336
# Off Stream Hydroelectric Power Production                           319
# Name: count, dtype: int64

# %%
# determine WaDE Amount
# need to convert to an MG/year value to be specific with the annual timestep
# "1" : MG/day
# "2" : ML/day

def ConvertAmountToAfFunc(valAmount, valUnit):
    valUnit = str(valUnit).strip()
    if valUnit == "1": 
        outValue = valAmount * 365
    elif valUnit == "2":
        outValue = valAmount * 0.264172 * 365
    else:
        outValue = valAmount
    return outValue

dfIn['in_Amount'] = dfIn.apply(lambda row: ConvertAmountToAfFunc(row['with_amt'], row['unit']), axis=1)
dfIn['in_Amount'].unique()
# Out:
# array([286090.64999999997, 669.4100000000001, 0.0, ..., 4253.3085,
#        502.386, 639.918], dtype=object)

# %%
# Transfer input data to WaDE specific output

# create dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfIn['WaDEUUID_x']

# Method Info
df['in_MethodTypeCV'] = dfIn['in_MethodTypeCV']
df['in_MethodUUID'] = "" # determine below

# Variable Info
df['in_VariableSpecificUUID'] = "" # determine below
df['in_AggregationIntervalUnitCV'] = "Annual"
df['in_VariableCV'] = "Withdrawal"
df['in_VariableSpecificCV'] = "" # determine below

# Organization Info
df['in_OrganizationUUID'] = "GLwuag_O1"

# Water Source
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df["in_WaterSourceName"] = "WaDE Blank"
df['in_WaterSourceNativeID'] = "" # determine below if not provided
df["in_WaterSourceTypeCV"] = dfIn['in_WaterSourceTypeCV']

# ReportingUnits Info
df['in_EPSGCodeCV'] = "4326"
df['in_ReportingUnitName'] = dfIn['jur_name'] + dfIn['basin_name']
df['in_ReportingUnitNativeID'] = "GL_" + dfIn['shpID'].astype(str).str.strip()
df['in_ReportingUnitProductVersion'] = ""
df['in_ReportingUnitTypeCV'] = "Basin"
df['in_ReportingUnitUpdateDate'] = ""
df['in_StateCV'] = "GL"

# AggregatedAmounts Info
df['in_AllocationCropDutyAmount'] = ""
df['in_Amount'] = dfIn['in_Amount']
df['in_BeneficialUseCategory'] = dfIn['in_BeneficialUseCategory']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_InterbasinTransferFromID'] = ""
df['in_InterbasinTransferToID'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerGeneratedGWh'] = ""
df['in_PowerType'] = ""
df['in_PrimaryUseCategoryCV'] = ""
df['in_ReportYearCV'] = dfIn['year'].astype(float).astype(int).astype(str).str.strip()
df['in_SDWISIdentifierCV'] = ""
df['in_TimeframeEnd'] = "12/31/" + dfIn['year'].astype(float).astype(int).astype(str).str.strip()
df['in_TimeframeStart'] = "01/01/" + dfIn['year'].astype(float).astype(int).astype(str).str.strip()

outdf = df.copy()
outdf = outdf.drop_duplicates().reset_index(drop=True)
print(len(outdf))
outdf.head(5)
# Out:
# 5189
#   WaDEUUID in_MethodTypeCV in_MethodUUID in_VariableSpecificUUID  \
# 0    glag0        Measured
# 1    glag1        Measured
# 2    glag2      WaDE Blank
# 3    glag3      WaDE Blank
# 4    glag4        Measured
#
#   in_AggregationIntervalUnitCV in_VariableCV in_VariableSpecificCV  \
# 0                       Annual    Withdrawal
# 1                       Annual    Withdrawal
# 2                       Annual    Withdrawal
# 3                       Annual    Withdrawal
# 4                       Annual    Withdrawal
#
#   in_OrganizationUUID in_Geometry in_GNISFeatureNameCV  \
# 0           GLwuag_O1
# 1           GLwuag_O1
# 2           GLwuag_O1
# 3           GLwuag_O1
# 4           GLwuag_O1
#
#   in_WaterQualityIndicatorCV in_WaterSourceName in_WaterSourceNativeID  \
# 0                                    WaDE Blank
# 1                                    WaDE Blank
# 2                                    WaDE Blank
# 3                                    WaDE Blank
# 4                                    WaDE Blank
#
#                     in_WaterSourceTypeCV in_EPSGCodeCV   in_ReportingUnitName  \
# 0  Great Lakes St Lawrence Surface Water          4326  IllinoisLake Michigan
# 1  Great Lakes St Lawrence Surface Water          4326  IllinoisLake Michigan
# 2                            Groundwater          4326  IllinoisLake Michigan
# 3  Great Lakes St Lawrence Surface Water          4326  IllinoisLake Michigan
# 4                            Groundwater          4326  IllinoisLake Michigan
#
#   in_ReportingUnitNativeID in_ReportingUnitProductVersion  \
# 0                 GL_j1_b2
# 1                 GL_j1_b2
# 2                 GL_j1_b2
# 3                 GL_j1_b2
# 4                 GL_j1_b2
#
#   in_ReportingUnitTypeCV in_ReportingUnitUpdateDate in_StateCV  \
# 0                  Basin                                    GL
# 1                  Basin                                    GL
# 2                  Basin                                    GL
# 3                  Basin                                    GL
# 4                  Basin                                    GL
#
#   in_AllocationCropDutyAmount    in_Amount  \
# 0                             286090.65000
# 1                                669.41000
# 2                                  0.00000
# 3                                  0.00000
# 4                                 29.93000
#
#                    in_BeneficialUseCategory in_CommunityWaterSupplySystem  \
# 0                       Public Water Supply
# 1  Self Supply Commercial and Institutional
# 2  Self Supply Commercial and Institutional
# 3                    Self Supply Irrigation
# 4                    Self Supply Irrigation
#
#   in_CropTypeCV in_CustomerTypeCV in_DataPublicationDate  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDOI in_InterbasinTransferFromID in_InterbasinTransferToID  \
# 0
# 1
# 2
# 3
# 4
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategoryCV in_ReportYearCV  \
# 0                                                                      2022
# 1                                                                      2022
# 2                                                                      2022
# 3                                                                      2022
# 4                                                                      2022
#
#   in_SDWISIdentifierCV in_TimeframeEnd in_TimeframeStart
# 0                           12/31/2022        01/01/2022
# 1                           12/31/2022        01/01/2022
# 2                           12/31/2022        01/01/2022
# 3                           12/31/2022        01/01/2022
# 4                           12/31/2022        01/01/2022

# %% [markdown]
# ## Concatenate Data (if needed).

# %%
# # Concatenate dataframes

# frames = [df1, df2]  # list all out dataframes here
# outdf = pd.concat(frames)
# outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
# print(len(outdf))

# %% [markdown]
# ## Clean Data / Data Types

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip().rstrip(',')
    return Val
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\)'
# <>:4: SyntaxWarning: invalid escape sequence '\)'
# C:\Users\rjame\AppData\Local\Temp\ipykernel_9856\1085762661.py:4: SyntaxWarning: invalid escape sequence '\)'
#   Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip().rstrip(',')

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Wade Blank'], dtype=object)

# %%
outdf['in_ReportingUnitName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_ReportingUnitName']), axis=1)
outdf['in_ReportingUnitName'].unique()
# Out:
# array(['Illinoislake Michigan', 'Indianalake Michigan',
#        'Indianalake Erie', 'Michiganlake Superior',
#        'Michiganlake Michigan', 'Michiganlake Huron', 'Michiganlake Erie',
#        'Minnesotalake Superior', 'New Yorklake Erie',
#        'New Yorklake Ontario', 'New Yorkst Lawrence River',
#        'Ohiolake Erie', 'Ontariolake Superior', 'Ontariolake Huron',
#        'Ontariolake Erie', 'Ontariolake Ontario',
#        'Ontariost Lawrence River', 'Pennsylvanialake Erie',
#        'Pennsylvanialake Ontario', 'Quebecst Lawrence River',
#        'Wisconsinlake Superior', 'Wisconsinlake Michigan'], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Wade Blank'], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Great Lakes St Lawrence Surface Water', 'Groundwater',
#        'Other Surface Water'], dtype=object)

# %%
outdf['in_ReportingUnitName'] = outdf.apply(lambda row: ensureEmptyString(row['in_ReportingUnitName']), axis=1)
outdf['in_ReportingUnitName'].unique()
# Out:
# array(['Illinoislake Michigan', 'Indianalake Michigan',
#        'Indianalake Erie', 'Michiganlake Superior',
#        'Michiganlake Michigan', 'Michiganlake Huron', 'Michiganlake Erie',
#        'Minnesotalake Superior', 'New Yorklake Erie',
#        'New Yorklake Ontario', 'New Yorkst Lawrence River',
#        'Ohiolake Erie', 'Ontariolake Superior', 'Ontariolake Huron',
#        'Ontariolake Erie', 'Ontariolake Ontario',
#        'Ontariost Lawrence River', 'Pennsylvanialake Erie',
#        'Pennsylvanialake Ontario', 'Quebecst Lawrence River',
#        'Wisconsinlake Superior', 'Wisconsinlake Michigan'], dtype=object)

# %%
outdf['in_ReportingUnitTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_ReportingUnitTypeCV']), axis=1)
outdf['in_ReportingUnitTypeCV'].unique()
# Out:
# array(['Basin'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
uniqueList = list(set([i.strip() for i in ','.join(outdf['in_BeneficialUseCategory'].astype(str)).split(',')]))
uniqueList.sort()
uniqueList
# Out:
# ['In Stream Hydroelectric Water Use',
#  'Off Stream Hydroelectric Power Production',
#  'Other Self Supply',
#  'Public Water Supply',
#  'Self Supply Commercial and Institutional',
#  'Self Supply Industrial',
#  'Self Supply Irrigation',
#  'Self Supply Livestock',
#  'Self Supply Thermoelectric Power Production Once Through Cooling',
#  'Self Supply Thermoelectric Power Production Recirculated Cooling']

# %%
# Fixing n_Amount entry is either numireic or a 0

outdf['in_Amount'] = pd.to_numeric(outdf['in_Amount'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_Amount'].unique()
# Out:
# array([286090.65, 669.41, '', ..., 4253.31, 502.39, 639.92], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3'], dtype=object)

# %%
# determine in_VariableSpecificCV

outdf['in_VariableSpecificCV'] = outdf['in_VariableCV'].astype(str) + "_" + outdf['in_AggregationIntervalUnitCV'].astype(str) + "_" + outdf['in_BeneficialUseCategory'].astype(str) + "_" + outdf['in_WaterSourceTypeCV'].astype(str)
outdf['in_VariableSpecificCV'].unique()
# Out:
# array(['Withdrawal_Annual_Public Water Supply_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_Self Supply Commercial and Institutional_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_Self Supply Commercial and Institutional_Groundwater',
#        'Withdrawal_Annual_Self Supply Irrigation_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_Self Supply Irrigation_Groundwater',
#        'Withdrawal_Annual_Self Supply Livestock_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_Self Supply Industrial_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_Self Supply Thermoelectric Power Production Once Through Cooling_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_Self Supply Thermoelectric Power Production Recirculated Cooling_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_Off Stream Hydroelectric Power Production_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_In Stream Hydroelectric Water Use_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_Other Self Supply_Great Lakes St Lawrence Surface Water',
#        'Withdrawal_Annual_Public Water Supply_Other Surface Water',
#        'Withdrawal_Annual_Public Water Supply_Groundwater',
#        'Withdrawal_Annual_Self Supply Commercial and Institutional_Other Surface Water',
#        'Withdrawal_Annual_Self Supply Irrigation_Other Surface Water',
#        'Withdrawal_Annual_Self Supply Livestock_Other Surface Water',
#        'Withdrawal_Annual_Self Supply Livestock_Groundwater',
#        'Withdrawal_Annual_Self Supply Industrial_Other Surface Water',
#        'Withdrawal_Annual_Self Supply Industrial_Groundwater',
#        'Withdrawal_Annual_Self Supply Thermoelectric Power Production Once Through Cooling_Other Surface Water',
#        'Withdrawal_Annual_Self Supply Thermoelectric Power Production Once Through Cooling_Groundwater',
#        'Withdrawal_Annual_Self Supply Thermoelectric Power Production Recirculated Cooling_Other Surface Water',
#        'Withdrawal_Annual_Self Supply Thermoelectric Power Production Recirculated Cooling_Groundwater',
#        'Withdrawal_Annual_Off Stream Hydroelectric Power Production_Other Surface Water',
#        'Withdrawal_Annual_Off Stream Hydroelectric Power Production_Groundwater',
#        'Withdrawal_Annual_In Stream Hydroelectric Water Use_Other Surface Water',
#        'Withdrawal_Annual_In Stream Hydroelectric Water Use_Groundwater',
#        'Withdrawal_Annual_Other Self Supply_Other Surface Water',
#        'Withdrawal_Annual_Other Self Supply_Groundwater'], dtype=object)

# %%
# Create MethodUUID

Methodict = {
"Measured" : " GLwuag_M1",
"Partially Measured" : " GLwuag_M2",
"Calculated" : " GLwuag_M3",
"WaDE Blank" : " GLwuag_M4"}

def DetermineMethodUUIDFunc(valA):
    if valA == '' or pd.isnull(valA):
        outString = 'WaDE Blank'
    else:
        try:
            valA = str(valA).strip()
            outString = Methodict[valA]
        except:
            outString = 'WaDE Blank'
    return outString

outdf['in_MethodUUID'] = outdf.apply(lambda row: DetermineMethodUUIDFunc(row['in_MethodTypeCV']), axis=1)
outdf['in_MethodUUID'].value_counts()
# Out:
# in_MethodUUID
# GLwuag_M2    2670
# GLwuag_M1     973
# GLwuag_M3     791
# GLwuag_M4     755
# Name: count, dtype: int64

# %%
# %%time

# Creating WaDE VariableSpecificUUID for easy VariableSpecificCV identification 
# use these inputs: VariableCV_AggregationIntervalUnitCV_BeneficalUse_WaterSourceTypeCV
# ----------------------------------------------------------------------------------------------------

# Create temp VariableSpecificUUID dataframe of unique water source.
def assignVariableSpecificUUID(colrowValue):
    string1 = str(colrowValue)
    outstring = "NDwuag_V" + string1
    return outstring

dfVariableSpecificUUID = pd.DataFrame()
dfVariableSpecificUUID['in_VariableCV'] = outdf['in_VariableCV']
dfVariableSpecificUUID['in_AggregationIntervalUnitCV'] = outdf['in_AggregationIntervalUnitCV']
dfVariableSpecificUUID['in_BeneficialUseCategory'] = outdf['in_BeneficialUseCategory']
dfVariableSpecificUUID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfVariableSpecificUUID = dfVariableSpecificUUID.drop_duplicates()

dftemp = pd.DataFrame(index=dfVariableSpecificUUID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfVariableSpecificUUID['in_VariableSpecificUUID'] = dftemp.apply(lambda row: assignVariableSpecificUUID(row['Count']), axis=1)
dfVariableSpecificUUID['linkKey'] = dfVariableSpecificUUID['in_VariableCV'].astype(str) + dfVariableSpecificUUID['in_AggregationIntervalUnitCV'].astype(str) + dfVariableSpecificUUID['in_BeneficialUseCategory'].astype(str) + dfVariableSpecificUUID['in_WaterSourceTypeCV'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom variable native ID
VariableSpecificUUIDdict = pd.Series(dfVariableSpecificUUID.in_VariableSpecificUUID.values, index=dfVariableSpecificUUID.linkKey.astype(str)).to_dict()
def retrieveVariableSpecificUUID(A, B, C, D):
    if (A == '' and B == '' and C == '' and D == '') or (pd.isnull(A) and pd.isnull(B) and pd.isnull(C) and pd.isnull(D)):
        outList = ''
    else:
        colrowValue = str(A).strip() + str(B).strip() + str(C).strip() + str(D).strip()
        try:
            outList = VariableSpecificUUIDdict[colrowValue]
        except:
            outList = ''
    return outList

outdf['in_VariableSpecificUUID'] = outdf.apply(lambda row: retrieveVariableSpecificUUID(row['in_VariableCV'], row['in_AggregationIntervalUnitCV'], row['in_BeneficialUseCategory'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_VariableSpecificUUID'].unique()
# Out:
# CPU times: total: 78.1 ms
# Wall time: 80.6 ms
# array(['NDwuag_V1', 'NDwuag_V2', 'NDwuag_V3', 'NDwuag_V4', 'NDwuag_V5',
#        'NDwuag_V6', 'NDwuag_V7', 'NDwuag_V8', 'NDwuag_V9', 'NDwuag_V10',
#        'NDwuag_V11', 'NDwuag_V12', 'NDwuag_V13', 'NDwuag_V14',
#        'NDwuag_V15', 'NDwuag_V16', 'NDwuag_V17', 'NDwuag_V18',
#        'NDwuag_V19', 'NDwuag_V20', 'NDwuag_V21', 'NDwuag_V22',
#        'NDwuag_V23', 'NDwuag_V24', 'NDwuag_V25', 'NDwuag_V26',
#        'NDwuag_V27', 'NDwuag_V28', 'NDwuag_V29', 'NDwuag_V30'],
#       dtype=object)

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to csv inputs.

# %%
# Shapefile Data (can just be copy of above input)\

# shapefileInput = gpd.read_file('RawInputData/shapefiles/{enter file name here}.zip')
# dfshapetemp = gpd.read_file(shapefileInput)

dfshapetemp = df_poly.copy()
print(len(dfshapetemp))
dfshapetemp.head()
# Out:
# 22
#    Shape_Leng  jurisdic   basin wadeID jur_name          basin_name notes  \
# 0    34.25696   7.00000 4.00000  j7_b4  Ontario           Lake Erie  None
# 1    47.39882   7.00000 3.00000  j7_b3  Ontario          Lake Huron  None
# 2    60.62183   7.00000 1.00000  j7_b1  Ontario       Lake Superior  None
# 3    34.16079   7.00000 5.00000  j7_b5  Ontario        Lake Ontario  None
# 4    58.22232   7.00000 6.00000  j7_b6  Ontario  St. Lawrence River  None
#
#    Shape_Le_1  Shape_Area                                           geometry  \
# 0    15.01843     2.57080  POLYGON ((-80.14996 43.93119, -80.14998 43.929...
# 1    47.69183    10.17209  POLYGON ((-81.31089 47.44333, -81.31057 47.442...
# 2    49.62184    12.48842  POLYGON ((-89.13481 51.12819, -89.09873 51.108...
# 3    23.80428     3.19340  POLYGON ((-76.57685 44.21177, -76.59855 44.211...
# 4    33.43084     6.31962  POLYGON ((-79.51780 48.07788, -79.51781 48.074...
#
#   WaDEUUID
# 0    glag0
# 1    glag1
# 2    glag2
# 3    glag3
# 4    glag4

# %%
columnsList = ['in_ReportingUnitNativeID', 'geometry']
outshape = pd.DataFrame(columns=columnsList)
outshape['in_ReportingUnitNativeID'] = "GL_" + "j" + dfshapetemp['jurisdic'].astype(float).astype(int).astype(str).str.strip() + "_b" + dfshapetemp['basin'].astype(float).astype(int).astype(str).str.strip()
outshape['geometry'] = dfshapetemp['geometry']
outshape = outshape.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
outshape.head(20)
# Out:
#    in_ReportingUnitNativeID                                           geometry
# 0                  GL_j7_b4  POLYGON ((-80.14996 43.93119, -80.14998 43.929...
# 1                  GL_j7_b3  POLYGON ((-81.31089 47.44333, -81.31057 47.442...
# 2                  GL_j7_b1  POLYGON ((-89.13481 51.12819, -89.09873 51.108...
# 3                  GL_j7_b5  POLYGON ((-76.57685 44.21177, -76.59855 44.211...
# 4                  GL_j7_b6  POLYGON ((-79.51780 48.07788, -79.51781 48.074...
# 5                  GL_j3_b4  POLYGON ((-82.42207 43.00626, -82.42173 42.998...
# 6                  GL_j3_b3  POLYGON ((-84.18079 46.53084, -84.17163 46.528...
# 7                  GL_j3_b2  POLYGON ((-88.13544 46.73357, -88.13491 46.733...
# 8                  GL_j3_b1  POLYGON ((-87.89235 47.47407, -87.86253 47.471...
# 9                  GL_j6_b4  POLYGON ((-80.51867 41.68897, -80.52239 41.688...
# 10                 GL_j5_b4  POLYGON ((-78.35911 42.38056, -78.35932 42.381...
# 11                 GL_j5_b5  POLYGON ((-74.51475 43.73701, -74.51485 43.736...
# 12                 GL_j5_b6  POLYGON ((-74.67052 45.00628, -74.65320 45.002...
# 13                 GL_j8_b4  POLYGON ((-79.76348 42.16908, -79.76381 42.169...
# 14                 GL_j8_b5  POLYGON ((-77.99501 41.99889, -77.96649 41.998...
# 15                 GL_j2_b4  POLYGON ((-84.80672 41.69575, -84.80650 41.606...
# 16                 GL_j2_b2  POLYGON ((-85.65355 41.76075, -85.57630 41.760...
# 17                GL_j10_b2  POLYGON ((-88.88684 46.05520, -88.87513 46.050...
# 18                GL_j10_b1  POLYGON ((-90.84319 46.95787, -90.84145 46.957...
# 19                 GL_j4_b1  POLYGON ((-90.11495 48.10427, -90.11126 48.104...

# %% [markdown]
# # Export Data

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5189 entries, 0 to 5188
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   WaDEUUID                        5189 non-null   object
#  1   in_MethodTypeCV                 5189 non-null   object
#  2   in_MethodUUID                   5189 non-null   object
#  3   in_VariableSpecificUUID         5189 non-null   object
#  4   in_AggregationIntervalUnitCV    5189 non-null   object
#  5   in_VariableCV                   5189 non-null   object
#  6   in_VariableSpecificCV           5189 non-null   object
#  7   in_OrganizationUUID             5189 non-null   object
#  8   in_Geometry                     5189 non-null   object
#  9   in_GNISFeatureNameCV            5189 non-null   object
#  10  in_WaterQualityIndicatorCV      5189 non-null   object
#  11  in_WaterSourceName              5189 non-null   object
#  12  in_WaterSourceNativeID          5189 non-null   object
#  13  in_WaterSourceTypeCV            5189 non-null   object
#  14  in_EPSGCodeCV                   5189 non-null   object
#  15  in_ReportingUnitName            5189 non-null   object
#  16  in_ReportingUnitNativeID        5189 non-null   object
#  17  in_ReportingUnitProductVersion  5189 non-null   object
#  18  in_ReportingUnitTypeCV          5189 non-null   object
#  19  in_ReportingUnitUpdateDate      5189 non-null   object
#  20  in_StateCV                      5189 non-null   object
#  21  in_AllocationCropDutyAmount     5189 non-null   object
#  22  in_Amount                       5189 non-null   object
#  23  in_BeneficialUseCategory        5189 non-null   object
#  24  in_CommunityWaterSupplySystem   5189 non-null   object
#  25  in_CropTypeCV                   5189 non-null   object
#  26  in_CustomerTypeCV               5189 non-null   object
#  27  in_DataPublicationDate          5189 non-null   object
#  28  in_DataPublicationDOI           5189 non-null   object
#  29  in_InterbasinTransferFromID     5189 non-null   object
#  30  in_InterbasinTransferToID       5189 non-null   object
#  31  in_IrrigatedAcreage             5189 non-null   object
#  32  in_IrrigationMethodCV           5189 non-null   object
#  33  in_PopulationServed             5189 non-null   object
#  34  in_PowerGeneratedGWh            5189 non-null   object
#  35  in_PowerType                    5189 non-null   object
#  36  in_PrimaryUseCategoryCV         5189 non-null   object
#  37  in_ReportYearCV                 5189 non-null   object
#  38  in_SDWISIdentifierCV            5189 non-null   object
#  39  in_TimeframeEnd                 5189 non-null   object
#  40  in_TimeframeStart               5189 non-null   object
# dtypes: object(41)
# memory usage: 1.6+ MB

# %%
outdf
# Out:
#       WaDEUUID in_MethodTypeCV in_MethodUUID in_VariableSpecificUUID  \
# 0        glag0        Measured     GLwuag_M1               NDwuag_V1
# 1        glag1        Measured     GLwuag_M1               NDwuag_V2
# 2        glag2      WaDE Blank     GLwuag_M4               NDwuag_V3
# 3        glag3      WaDE Blank     GLwuag_M4               NDwuag_V4
# 4        glag4        Measured     GLwuag_M1               NDwuag_V5
# ...        ...             ...           ...                     ...
# 5184  glag5184      Calculated     GLwuag_M3              NDwuag_V21
# 5185  glag5185      Calculated     GLwuag_M3               NDwuag_V9
# 5186  glag5186      WaDE Blank     GLwuag_M4              NDwuag_V30
# 5187  glag5187      Calculated     GLwuag_M3              NDwuag_V29
# 5188  glag5188      Calculated     GLwuag_M3              NDwuag_V30
#
#      in_AggregationIntervalUnitCV in_VariableCV  \
# 0                          Annual    Withdrawal
# 1                          Annual    Withdrawal
# 2                          Annual    Withdrawal
# 3                          Annual    Withdrawal
# 4                          Annual    Withdrawal
# ...                           ...           ...
# 5184                       Annual    Withdrawal
# 5185                       Annual    Withdrawal
# 5186                       Annual    Withdrawal
# 5187                       Annual    Withdrawal
# 5188                       Annual    Withdrawal
#
#                                   in_VariableSpecificCV in_OrganizationUUID  \
# 0     Withdrawal_Annual_Public Water Supply_Great La...           GLwuag_O1
# 1     Withdrawal_Annual_Self Supply Commercial and I...           GLwuag_O1
# 2     Withdrawal_Annual_Self Supply Commercial and I...           GLwuag_O1
# 3     Withdrawal_Annual_Self Supply Irrigation_Great...           GLwuag_O1
# 4     Withdrawal_Annual_Self Supply Irrigation_Groun...           GLwuag_O1
# ...                                                 ...                 ...
# 5184  Withdrawal_Annual_Self Supply Thermoelectric P...           GLwuag_O1
# 5185  Withdrawal_Annual_Self Supply Thermoelectric P...           GLwuag_O1
# 5186    Withdrawal_Annual_Other Self Supply_Groundwater           GLwuag_O1
# 5187  Withdrawal_Annual_Other Self Supply_Other Surf...           GLwuag_O1
# 5188    Withdrawal_Annual_Other Self Supply_Groundwater           GLwuag_O1
#
#      in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...          ...                  ...                        ...
# 5184
# 5185
# 5186
# 5187
# 5188
#
#      in_WaterSourceName in_WaterSourceNativeID  \
# 0            Wade Blank                wadeId1
# 1            Wade Blank                wadeId1
# 2            Wade Blank                wadeId2
# 3            Wade Blank                wadeId1
# 4            Wade Blank                wadeId2
# ...                 ...                    ...
# 5184         Wade Blank                wadeId3
# 5185         Wade Blank                wadeId1
# 5186         Wade Blank                wadeId2
# 5187         Wade Blank                wadeId3
# 5188         Wade Blank                wadeId2
#
#                        in_WaterSourceTypeCV in_EPSGCodeCV  \
# 0     Great Lakes St Lawrence Surface Water          4326
# 1     Great Lakes St Lawrence Surface Water          4326
# 2                               Groundwater          4326
# 3     Great Lakes St Lawrence Surface Water          4326
# 4                               Groundwater          4326
# ...                                     ...           ...
# 5184                    Other Surface Water          4326
# 5185  Great Lakes St Lawrence Surface Water          4326
# 5186                            Groundwater          4326
# 5187                    Other Surface Water          4326
# 5188                            Groundwater          4326
#
#         in_ReportingUnitName in_ReportingUnitNativeID  \
# 0      Illinoislake Michigan                 GL_j1_b2
# 1      Illinoislake Michigan                 GL_j1_b2
# 2      Illinoislake Michigan                 GL_j1_b2
# 3      Illinoislake Michigan                 GL_j1_b2
# 4      Illinoislake Michigan                 GL_j1_b2
# ...                      ...                      ...
# 5184  Wisconsinlake Michigan                GL_j10_b2
# 5185  Wisconsinlake Michigan                GL_j10_b2
# 5186  Wisconsinlake Superior                GL_j10_b1
# 5187  Wisconsinlake Michigan                GL_j10_b2
# 5188  Wisconsinlake Michigan                GL_j10_b2
#
#      in_ReportingUnitProductVersion in_ReportingUnitTypeCV  \
# 0                                                    Basin
# 1                                                    Basin
# 2                                                    Basin
# 3                                                    Basin
# 4                                                    Basin
# ...                             ...                    ...
# 5184                                                 Basin
# 5185                                                 Basin
# 5186                                                 Basin
# 5187                                                 Basin
# 5188                                                 Basin
#
#      in_ReportingUnitUpdateDate in_StateCV in_AllocationCropDutyAmount  \
# 0                                       GL
# 1                                       GL
# 2                                       GL
# 3                                       GL
# 4                                       GL
# ...                         ...        ...                         ...
# 5184                                    GL
# 5185                                    GL
# 5186                                    GL
# 5187                                    GL
# 5188                                    GL
#
#         in_Amount                           in_BeneficialUseCategory  \
# 0    286090.65000                                Public Water Supply
# 1       669.41000           Self Supply Commercial and Institutional
# 2                           Self Supply Commercial and Institutional
# 3                                             Self Supply Irrigation
# 4        29.93000                             Self Supply Irrigation
# ...           ...                                                ...
# 5184 109550.37000  Self Supply Thermoelectric Power Production On...
# 5185   4253.31000  Self Supply Thermoelectric Power Production Re...
# 5186                                               Other Self Supply
# 5187    502.39000                                  Other Self Supply
# 5188    639.92000                                  Other Self Supply
#
#      in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...           ...               ...
# 5184
# 5185
# 5186
# 5187
# 5188
#
#      in_DataPublicationDate in_DataPublicationDOI in_InterbasinTransferFromID  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...                   ...                         ...
# 5184
# 5185
# 5186
# 5187
# 5188
#
#      in_InterbasinTransferToID in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                 ...                   ...
# 5184
# 5185
# 5186
# 5187
# 5188
#
#      in_PopulationServed in_PowerGeneratedGWh in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                  ...          ...
# 5184
# 5185
# 5186
# 5187
# 5188
#
#      in_PrimaryUseCategoryCV in_ReportYearCV in_SDWISIdentifierCV  \
# 0                                       2022
# 1                                       2022
# 2                                       2022
# 3                                       2022
# 4                                       2022
# ...                      ...             ...                  ...
# 5184                                    2012
# 5185                                    2012
# 5186                                    2012
# 5187                                    2012
# 5188                                    2012
#
#      in_TimeframeEnd in_TimeframeStart
# 0         12/31/2022        01/01/2022
# 1         12/31/2022        01/01/2022
# 2         12/31/2022        01/01/2022
# 3         12/31/2022        01/01/2022
# 4         12/31/2022        01/01/2022
# ...              ...               ...
# 5184      12/31/2012        01/01/2012
# 5185      12/31/2012        01/01/2012
# 5186      12/31/2012        01/01/2012
# 5187      12/31/2012        01/01/2012
# 5188      12/31/2012        01/01/2012
#
# [5189 rows x 41 columns]

# %%
# Export the output dataframe
outdf.to_csv('RawInputData/Pwuag_Main.zip', compression=dict(method='zip', archive_name='Pag_Main.csv'), index=False)   # The output, save as a zip
outshape.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
