# %% [markdown]
# # Pre-processing Delaware Riber Basin Commission Aggregated Amounts data for WaDE upload.
# Date Updated: 06/05/2023
# Purpose:  To pre-process the DRBC data into one master file for simple DataFrame creation and extraction

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
import re
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x) # suppress scientific notation in Pandas

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/DelawareRiverBasinCommission/AggregatedAmounts/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## Input Source Data

# %%
# timeseries data, xlsx file
# we only want the historic surface water and groundwater data. Which can be found on the following sheets: A-1, A-6, A-9, A-11, A-14, A-17, A-22
dfA1 = pd.read_excel(io="2060report_data-release_v2110.xlsx", sheet_name='A-1')
dfA6 = pd.read_excel(io="2060report_data-release_v2110.xlsx", sheet_name='A-6')
dfA9 = pd.read_excel(io="2060report_data-release_v2110.xlsx", sheet_name='A-9')
dfA11 = pd.read_excel(io="2060report_data-release_v2110.xlsx", sheet_name='A-11')
dfA14 = pd.read_excel(io="2060report_data-release_v2110.xlsx", sheet_name='A-14')
dfA17 = pd.read_excel(io="2060report_data-release_v2110.xlsx", sheet_name='A-17')
dfA22 = pd.read_excel(io="2060report_data-release_v2110.xlsx", sheet_name='A-22')

# Concatenate dataframes
frames = [dfA1, dfA6, dfA9, dfA11, dfA14, dfA17, dfA22] 
dfIn = pd.concat(frames)
dfIn = dfIn.drop_duplicates().reset_index(drop=True).replace(np.nan, "")


# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfIn:
    dfIn['WaDEUUID'] = "drbc" + dfIn.index.astype(str)
    dfIn.to_csv('2060report_data-release_v2110_A1_6_9_11_14_17_22.zip', compression=dict(method='zip', archive_name='2060report_data-release_v2110_A1_6_9_11_14_17_22.csv'), index=False)

print(len(dfIn))
dfIn.head(1)
# Out:
# 21468
#                 SECTOR             CATEGORY STATE BASIN_ID GWPA_ID  \
# 0  Public Water Supply  Public Water Supply    PA   DB-074 1.00000
#
#   DESIGNATION  YEAR  WD_MGD  CU_MGD NUCLEAR_FACILITY COOLING_TYPE HYDRO_TYPE  \
# 0          GW  1990 0.04144 0.00414
#
#   WaDEUUID
# 0    drbc0

# %%
# shapefile info
gdf_drb147 = gpd.read_file('shapefile/drb147.shp', crs="EPSG:4326")
print(len(gdf_drb147))
gdf_drb147.head(1)
# Out:
# 147
#    OBJECTID       SQM STATEID BASIN_ID                       STREAMS  \
# 0         1 143.78600      NY   DB-001  Upper West Br Delaware River
#
#     Shape_Leng       HUC8_Name  Shape_Le_1  Shape_Area  \
# 0 118207.57278  Upper Delaware     1.26136     0.04069
#
#                                             geometry
# 0  POLYGON ((-74.82876 42.39163, -74.82836 42.392...

# %%
# left merge timeseries info with shapefile info.
dfIn2 = pd.DataFrame()
dfIn2 = pd.merge(dfIn, gdf_drb147, on='BASIN_ID', how='left')
dfIn2 = dfIn2.drop_duplicates().replace(np.nan, "").replace("nan,nan", "").reset_index(drop=True)
print(len(dfIn2))
dfIn2.head(1)
# Out:
# 21468
#                 SECTOR             CATEGORY STATE BASIN_ID GWPA_ID  \
# 0  Public Water Supply  Public Water Supply    PA   DB-074 1.00000
#
#   DESIGNATION  YEAR  WD_MGD  CU_MGD NUCLEAR_FACILITY COOLING_TYPE HYDRO_TYPE  \
# 0          GW  1990 0.04144 0.00414
#
#   WaDEUUID  OBJECTID       SQM STATEID      STREAMS   Shape_Leng  \
# 0    drbc0        82 112.15500      PA  Tohichon Cr 116919.21975
#
#                       HUC8_Name  Shape_Le_1  Shape_Area  \
# 0  Middle Delaware-Musconetcong     1.23170     0.03083
#
#                                             geometry
# 0  POLYGON ((-75.34706 40.51062, -75.34622 40.509...

# %% [markdown]
# ## Convert to WaDE Input Data

# %%
# covert MGPD to AFY to
# 1000000 US liquid gallons / Day = 1120.14406 Acre-foot / year.

def convertMGPDtoAFYFunc(Val):
    Val = str(Val).strip()
    if (Val == "" ) or (pd.isnull(Val)):
        outList = ""
    else:
        outList = float(Val) * 1120.14406 
    return outList

# %%
# withdrawal values
dfIn2['in_WD_AFY'] = dfIn2.apply(lambda row: convertMGPDtoAFYFunc(row['WD_MGD']), axis=1)
dfIn2['in_WD_AFY'].unique()
# Out:
# array([  46.41692851,  401.47190666,  320.76015658, ..., 1025.87273591,
#         158.88123347,  855.96932172])

# %%
# consumptive values
dfIn2['in_CU_AFY'] = dfIn2.apply(lambda row: convertMGPDtoAFYFunc(row['CU_MGD']), axis=1)
dfIn2['in_CU_AFY'].unique()
# Out:
# array([ 4.64169285, 40.14719067, 32.07601566, ..., 51.2936368 ,
#         7.94406167, 42.79846609])

# %%
# Withdrawal dataframe
# --------------------------

# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfIn2['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "DRBCag_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "" # determine below
df['in_AggregationIntervalUnitCV'] = "Annual"
df['in_VariableCV'] = "Withdrawal"
df['in_VariableSpecificCV'] = "" # determine below

# Organization Info
df['in_OrganizationUUID'] = "DRBCag_O1"

# Water Source
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df["in_WaterSourceName"] = ""
df['in_WaterSourceNativeID'] = ""
df["in_WaterSourceTypeCV"] = dfIn2['DESIGNATION']

# ReportingUnits Info
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_ReportingUnitName'] = dfIn2['STREAMS']
df['in_ReportingUnitNativeID'] = dfIn2['BASIN_ID'].replace("", 0).fillna(0).astype(str).str.strip()
df['in_ReportingUnitProductVersion'] = ""
df['in_ReportingUnitTypeCV'] = "Subbasin"
df['in_ReportingUnitUpdateDate'] = ""
df['in_StateCV'] = "DE"

# AggregatedAmounts Info
df['in_AllocationCropDutyAmount'] = ""
df['in_Amount'] = dfIn2['in_WD_AFY'] #use withdrawl value here, see above for conversion
df['in_BeneficialUseCategory'] = dfIn2['CATEGORY']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_InterbasinTransferFromID'] = ""
df['in_InterbasinTransferToID'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerGeneratedGWh'] = ""
df['in_PowerType'] = ""
df['in_PrimaryUseCategory'] = ""
df['in_ReportYearCV'] = dfIn2['YEAR']
df['in_SDWISIdentifierCV'] = ""
df['in_TimeframeEnd'] = "" # determine below
df['in_TimeframeStart'] = "" # determine below

outWith = df.copy()
outWith = outWith.drop_duplicates().reset_index(drop=True)
print(len(outWith))
outWith.head()
# Out:
# 21468
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_AggregationIntervalUnitCV  \
# 0    drbc0     DRBCag_M1                                               Annual
# 1    drbc1     DRBCag_M1                                               Annual
# 2    drbc2     DRBCag_M1                                               Annual
# 3    drbc3     DRBCag_M1                                               Annual
# 4    drbc4     DRBCag_M1                                               Annual
#
#   in_VariableCV in_VariableSpecificCV in_OrganizationUUID in_Geometry  \
# 0    Withdrawal                                 DRBCag_O1
# 1    Withdrawal                                 DRBCag_O1
# 2    Withdrawal                                 DRBCag_O1
# 3    Withdrawal                                 DRBCag_O1
# 4    Withdrawal                                 DRBCag_O1
#
#   in_GNISFeatureNameCV in_WaterQualityIndicatorCV in_WaterSourceName  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceNativeID in_WaterSourceTypeCV  in_EPSGCodeCV  \
# 0                                          GW           4326
# 1                                          GW           4326
# 2                                          GW           4326
# 3                                          GW           4326
# 4                                          GW           4326
#
#                         in_ReportingUnitName in_ReportingUnitNativeID  \
# 0                                Tohichon Cr                   DB-074
# 1  Neshaminy Cr below Little Neshaminy Creek                   DB-084
# 2         Crum Cr, Ridley Cr, Marcus Hook Cr                   DB-114
# 3                   West Branch Perkiomen Cr                   DB-106
# 4                   West Branch Perkiomen Cr                   DB-106
#
#   in_ReportingUnitProductVersion in_ReportingUnitTypeCV  \
# 0                                              Subbasin
# 1                                              Subbasin
# 2                                              Subbasin
# 3                                              Subbasin
# 4                                              Subbasin
#
#   in_ReportingUnitUpdateDate in_StateCV in_AllocationCropDutyAmount  \
# 0                                    DE
# 1                                    DE
# 2                                    DE
# 3                                    DE
# 4                                    DE
#
#    in_Amount in_BeneficialUseCategory in_CommunityWaterSupplySystem  \
# 0   46.41693      Public Water Supply
# 1  401.47191      Public Water Supply
# 2  320.76016      Public Water Supply
# 3  107.65659      Public Water Supply
# 4  354.37369      Public Water Supply
#
#   in_CropTypeCV in_CustomerTypeCV in_DataPublicationDate  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDOI in_InterbasinTransferFromID in_InterbasinTransferToID  \
# 0
# 1
# 2
# 3
# 4
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategory  in_ReportYearCV  \
# 0                                                                     1990
# 1                                                                     1990
# 2                                                                     1990
# 3                                                                     1990
# 4                                                                     1990
#
#   in_SDWISIdentifierCV in_TimeframeEnd in_TimeframeStart
# 0
# 1
# 2
# 3
# 4

# %%
# Consumptive dataframe
# --------------------------

# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfIn2['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "DRBCag_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "" # determine below
df['in_AggregationIntervalUnitCV'] = "Annual"
df['in_VariableCV'] = "Consumptive"
df['in_VariableSpecificCV'] = "" # determine below

# Organization Info
df['in_OrganizationUUID'] = "DRBCag_O1"

# Water Source
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df["in_WaterSourceName"] = ""
df['in_WaterSourceNativeID'] = ""
df["in_WaterSourceTypeCV"] = dfIn2['DESIGNATION']

# ReportingUnits Info
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_ReportingUnitName'] = dfIn2['STREAMS']
df['in_ReportingUnitNativeID'] = dfIn2['BASIN_ID'].replace("", 0).fillna(0).astype(str).str.strip()
df['in_ReportingUnitProductVersion'] = ""
df['in_ReportingUnitTypeCV'] = "Subbasin"
df['in_ReportingUnitUpdateDate'] = ""
df['in_StateCV'] = "DE"

# AggregatedAmounts Info
df['in_AllocationCropDutyAmount'] = ""
df['in_Amount'] = dfIn2['in_CU_AFY'] #use consumptive value here, see above for conversion
df['in_BeneficialUseCategory'] = dfIn2['CATEGORY']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_InterbasinTransferFromID'] = ""
df['in_InterbasinTransferToID'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerGeneratedGWh'] = ""
df['in_PowerType'] = ""
df['in_PrimaryUseCategory'] = ""
df['in_ReportYearCV'] = dfIn2['YEAR']
df['in_SDWISIdentifierCV'] = ""
df['in_TimeframeEnd'] = "" # determine below
df['in_TimeframeStart'] = "" # determine below

outCons = df.copy()
outCons = outCons.drop_duplicates().reset_index(drop=True)
print(len(outCons))
outCons.head()
# Out:
# 21468
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_AggregationIntervalUnitCV  \
# 0    drbc0     DRBCag_M1                                               Annual
# 1    drbc1     DRBCag_M1                                               Annual
# 2    drbc2     DRBCag_M1                                               Annual
# 3    drbc3     DRBCag_M1                                               Annual
# 4    drbc4     DRBCag_M1                                               Annual
#
#   in_VariableCV in_VariableSpecificCV in_OrganizationUUID in_Geometry  \
# 0   Consumptive                                 DRBCag_O1
# 1   Consumptive                                 DRBCag_O1
# 2   Consumptive                                 DRBCag_O1
# 3   Consumptive                                 DRBCag_O1
# 4   Consumptive                                 DRBCag_O1
#
#   in_GNISFeatureNameCV in_WaterQualityIndicatorCV in_WaterSourceName  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceNativeID in_WaterSourceTypeCV  in_EPSGCodeCV  \
# 0                                          GW           4326
# 1                                          GW           4326
# 2                                          GW           4326
# 3                                          GW           4326
# 4                                          GW           4326
#
#                         in_ReportingUnitName in_ReportingUnitNativeID  \
# 0                                Tohichon Cr                   DB-074
# 1  Neshaminy Cr below Little Neshaminy Creek                   DB-084
# 2         Crum Cr, Ridley Cr, Marcus Hook Cr                   DB-114
# 3                   West Branch Perkiomen Cr                   DB-106
# 4                   West Branch Perkiomen Cr                   DB-106
#
#   in_ReportingUnitProductVersion in_ReportingUnitTypeCV  \
# 0                                              Subbasin
# 1                                              Subbasin
# 2                                              Subbasin
# 3                                              Subbasin
# 4                                              Subbasin
#
#   in_ReportingUnitUpdateDate in_StateCV in_AllocationCropDutyAmount  \
# 0                                    DE
# 1                                    DE
# 2                                    DE
# 3                                    DE
# 4                                    DE
#
#    in_Amount in_BeneficialUseCategory in_CommunityWaterSupplySystem  \
# 0    4.64169      Public Water Supply
# 1   40.14719      Public Water Supply
# 2   32.07602      Public Water Supply
# 3   10.76566      Public Water Supply
# 4   35.43737      Public Water Supply
#
#   in_CropTypeCV in_CustomerTypeCV in_DataPublicationDate  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDOI in_InterbasinTransferFromID in_InterbasinTransferToID  \
# 0
# 1
# 2
# 3
# 4
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategory  in_ReportYearCV  \
# 0                                                                     1990
# 1                                                                     1990
# 2                                                                     1990
# 3                                                                     1990
# 4                                                                     1990
#
#   in_SDWISIdentifierCV in_TimeframeEnd in_TimeframeStart
# 0
# 1
# 2
# 3
# 4

# %%
# Concatenate dataframes together
frames = [outWith, outCons] #withdrawl, consumptive
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 42936

# %% [markdown]
# ## WaDE Custom Elements (due to missing sate info)

# %%
# determine water source type from provided abbreviations.

def determineWaterSourceTypeCVFunc(Val):
    Val = str(Val).strip()
    if (Val == "GW"):
        outString = "Groundwater"
    elif (Val == "SW"):
        outString = "Surface Water"
    else:
        outString = ""
    return outString

outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: determineWaterSourceTypeCVFunc(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater', 'Surface Water'], dtype=object)

# %%
# create in_TimeframeEnd & in_TimeframeStart, use in_ReportYearCV as input.

def determineReportYearCVFunc(mdVal, Val):
    Val = str(int(Val)).strip()
    if (Val == "" ) or (pd.isnull(Val)):
        outString = ""
    else:
        outString = mdVal + Val
    return outString

# %%
# in_TimeframeEnd values
outdf['in_TimeframeEnd'] = outdf.apply(lambda row: determineReportYearCVFunc("12/31/", row['in_ReportYearCV']), axis=1)
outdf['in_TimeframeEnd'].unique()
# Out:
# array(['12/31/1990', '12/31/1991', '12/31/1992', '12/31/1993',
#        '12/31/1994', '12/31/1995', '12/31/1996', '12/31/1997',
#        '12/31/1998', '12/31/1999', '12/31/2000', '12/31/2001',
#        '12/31/2002', '12/31/2003', '12/31/2004', '12/31/2005',
#        '12/31/2006', '12/31/2007', '12/31/2008', '12/31/2009',
#        '12/31/2010', '12/31/2011', '12/31/2012', '12/31/2013',
#        '12/31/2014', '12/31/2015', '12/31/2016', '12/31/2017'],
#       dtype=object)

# %%
# in_TimeframeStart values
outdf['in_TimeframeStart'] = outdf.apply(lambda row: determineReportYearCVFunc("01/01/", row['in_ReportYearCV']), axis=1)
outdf['in_TimeframeStart'].unique()
# Out:
# array(['01/01/1990', '01/01/1991', '01/01/1992', '01/01/1993',
#        '01/01/1994', '01/01/1995', '01/01/1996', '01/01/1997',
#        '01/01/1998', '01/01/1999', '01/01/2000', '01/01/2001',
#        '01/01/2002', '01/01/2003', '01/01/2004', '01/01/2005',
#        '01/01/2006', '01/01/2007', '01/01/2008', '01/01/2009',
#        '01/01/2010', '01/01/2011', '01/01/2012', '01/01/2013',
#        '01/01/2014', '01/01/2015', '01/01/2016', '01/01/2017'],
#       dtype=object)

# %%
# Clean owner name up
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;,/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

# %%
outdf['in_ReportingUnitName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_ReportingUnitName']), axis=1)
outdf['in_ReportingUnitName'].unique()
# Out:
# array(['Tohichon Cr', 'Neshaminy Cr Below Little Neshaminy Creek',
#        'Crum Cr Ridley Cr Marcus Hook Cr', 'West Branch Perkiomen Cr',
#        'Neshaminy Cr Above Little Neshaminy Creek',
#        'Perkiomen Cr Above Northeast Branch',
#        'Tribs To Middle Schuylkill River Lower',
#        'Lower Schuylkill Tribs Above Skippack Cr',
#        'Poquessing Cr Pennypack Cr Tribs To Delaware River',
#        'Lower Schuylkill Tribs Below Skippack Cr',
#        'East Br Brandywine Cr', 'Chester Cr', 'West Br Brandywine Cr',
#        'Brandywine Cr Main Stem', 'Wissahickon Cr', 'French Cr',
#        'Upper West Br Delaware River',
#        'Third Branch West Branch East Branch', 'Oquaga Cr',
#        'Upper East Br Delaware River Above Platte Kill', 'Willowemoc Cr',
#        'Lower East Br Delaware River',
#        'Hankins Crbasket Crhoolahan Crabe Lord Crhumphries Crblue Mill Stream Tribs To Delaware River',
#        'North Br Callicoon Cr', 'Unamed Tributaries To Delaware River',
#        'W Branch Lackawaxen River', 'Middle Cr', 'Lackawaxen River',
#        'Wallenpaupack Cr',
#        'Mongaup River Above Swinging Bridge Reservoir',
#        'Walker Lake Crpond Eddy Cr Cummins Cr Sawkill Cr Craword Br Tribs To Delaware River',
#        'Neversink River Below Reservoir', 'Basher Kill',
#        'Raymond Rundingmans Crconashaugh Crdry Bkadams Crharnbacks Crtoms Cr Tribs To Delaware River',
#        'Bushkill Cr', 'Broadhead Cr', 'Pocono Cr',
#        'Cherry Cr Caledonia Cr Tribs To Delaware River',
#        'Slateford Cr Jacoby Cr Allegheny Cr Tribs To Delaware River',
#        'Paulins Kill Above Stillwater Village Trout Brook',
#        'Paulins Kill Below Stillwater Village', 'Pequest River',
#        'Martins Cr Mud Run Tribs To Delaware River',
#        'Pophandusing Bk Buckhorn Cr Lopatcong Cr Tribs To Delaware River',
#        'Tobyhanna Cr', 'Middle Lehigh River Above Sandy Run',
#        'Middle Lehigh River Above Black Creek',
#        'Middle Lehigh River Above Pohopoco Creek',
#        'Lower Lehigh River Upper Part', 'Aquashicola Cr',
#        'Lower Lehigh River Above Little Lehigh Creek', 'Jordan Cr',
#        'Little Lehigh Cr', 'Lower Lehigh River Below Little Lehigh Creek',
#        'Pohatcong Creek', 'Musconetcong River Above Trout Brook',
#        'Musconetcong River Below Including Trout Brook',
#        'Hakihokake Harihokake Nishisakawick Creeks And Tribs To Delaware River',
#        'Lockatong Cr Wickecheoke Cr Tribs To Delaware River',
#        'Geddes R Hickorypaunacussingaquetongpidockjerichohoughsdyersbuck Creekshollow R',
#        'Alexauken Moore Jacobs Creeks Tribs To Delaware Riv',
#        'Assunpink Creek',
#        'Sciotts Cr Martins Cr Tributaries To Delaware River',
#        'Crosswicks Ck',
#        'Crafts Creek Blacks Creek Tribs To Delaware River',
#        'Assiscunk Cr Burlington Edgewater Park Del Tribs',
#        'Nb Rancocas Cr Above New Lisbon Dam Greenwood Br',
#        'Sb Rancocas Creek Above Bobbys Run',
#        'Sb Rancocas Creek Sw Branch',
#        'Rancocas Creek Mainstem With Nb Below New Lisbon Dam Sb Below Bobbys Run',
#        'Pennsauken Cr Pompeston Cr Swede Run Tributaries To Delaware River',
#        'Cooper River',
#        'Woodbury Big Timber Newton Creeks Tributaries To Delaware River',
#        'Upper Schuylkill River Below Pottsville',
#        'Tribs To Middle Schuylkill River Upper',
#        'Maiden Cr Above Saucony Creek', 'Maiden Cr Below Saucony Creek',
#        'Upper Tulpehocken Cr Above Blue Marsh Res',
#        'Lower Tulpehocken Cr Below Blue Marsh Res', 'Manatawny Cr',
#        'Mantua Creek',
#        'Cedar Swamp Repaupo Cr Clonmell Cr Tributaries To Delaware River',
#        'Raccoon Creek Birch Creek',
#        'Salem River Above Dam Salem Canal Tribs To Delaware Bay',
#        'Red Clay Cr', 'White Clay Cr',
#        'Christina River Tribs To Delaware River',
#        'Salem River Below Dam Tributaries To Delaware Bay',
#        'Army Redlion Dragon Creeks Tribs To Delaware Riv',
#        'Cd Canal Tribs Top Delaware Bay',
#        'Augustine Cr Appoquunimick Riv Blackbird Cr Tribs To Delaware Bay',
#        'Cedar Swamp Smyrna Riv Duck Cr Tribs To Delaware Bay',
#        'Cohansey River',
#        'Lepsic Simons Little Rivers Tribs To Delaware Bay',
#        'Scotland Run Still Run Little Ease Run',
#        'Maurice River Above Sherman Ave Bridge Muddy Run',
#        'Maurice River Above Menantico Cr',
#        'Menantico Creek Manamuskin River',
#        'West Cr East Crriggins Ditch Dennis Cr Tribs To Delaware Bay',
#        'Cape May West Tribs To Delaware Bay', 'St Jones River',
#        'Murderkill River', 'Missipillion River Tribs To Delaware Bay',
#        'Round Pole Br Red Mill Cr Wagamons Pond N Rehoboth',
#        'Pohopoco Cr', 'Little Schuylkill River',
#        'Upper Schuylkill River Above Pottsville',
#        'Alloway Creek Hope Creek Tribs To Delaware Bay',
#        'Mast Hope Cr Westcolona Cr Tributaries To Delaware River',
#        'Shohola Cr Panther Cr Tributaries To Delaware River',
#        'Oldmans Creek', 'Bear Creek',
#        'Back Cedar Nantuxent Dividing Creeks Tribs To Delaware Bay',
#        'Frya Run Cooks Cr Tinicum Cr Other Tribs To Delaware River',
#        'Van Campens Bk Dunnfiled Cr Tribs To Delaware River',
#        'Beaver Dam Crcaulkins Crcooley Crhollister Cr Beaverdam Cr Peggy Run Tribs To Delaware River',
#        'Dyberry Creek', 'West Branch Wallenpaupack Cr',
#        'Upper Lehigh River', 'Middle West Br Delaware River',
#        'Upper East Br Delaware River Tribs To Pepacton Reservoir',
#        'Mongaup River Tributaries To Swinging Bridge Reservoir',
#        'Mongaup River Below Swinging Bridge Res + Shingle Kill',
#        'Maurice River Below Menantico Cr',
#        'Cedar Cr Slaughter Cr Prime Hook Cr Tribs To Delaware Bay',
#        'Frankfort Cr Tribs To Delaware River',
#        'Naamans Cr Shellpot Cr Tribs To Delaware River',
#        'Stony Brook Delawanna Creek Beaver Brook',
#        'Stow Creek Tribs To Delaware Bay', 'Darby Cr'], dtype=object)

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater', 'Surface Water'], dtype=object)

# %%
outdf['in_ReportingUnitName'] = outdf.apply(lambda row: ensureEmptyString(row['in_ReportingUnitName']), axis=1)
outdf['in_ReportingUnitName'].unique()
# Out:
# array(['Tohichon Cr', 'Neshaminy Cr Below Little Neshaminy Creek',
#        'Crum Cr Ridley Cr Marcus Hook Cr', 'West Branch Perkiomen Cr',
#        'Neshaminy Cr Above Little Neshaminy Creek',
#        'Perkiomen Cr Above Northeast Branch',
#        'Tribs To Middle Schuylkill River Lower',
#        'Lower Schuylkill Tribs Above Skippack Cr',
#        'Poquessing Cr Pennypack Cr Tribs To Delaware River',
#        'Lower Schuylkill Tribs Below Skippack Cr',
#        'East Br Brandywine Cr', 'Chester Cr', 'West Br Brandywine Cr',
#        'Brandywine Cr Main Stem', 'Wissahickon Cr', 'French Cr',
#        'Upper West Br Delaware River',
#        'Third Branch West Branch East Branch', 'Oquaga Cr',
#        'Upper East Br Delaware River Above Platte Kill', 'Willowemoc Cr',
#        'Lower East Br Delaware River',
#        'Hankins Crbasket Crhoolahan Crabe Lord Crhumphries Crblue Mill Stream Tribs To Delaware River',
#        'North Br Callicoon Cr', 'Unamed Tributaries To Delaware River',
#        'W Branch Lackawaxen River', 'Middle Cr', 'Lackawaxen River',
#        'Wallenpaupack Cr',
#        'Mongaup River Above Swinging Bridge Reservoir',
#        'Walker Lake Crpond Eddy Cr Cummins Cr Sawkill Cr Craword Br Tribs To Delaware River',
#        'Neversink River Below Reservoir', 'Basher Kill',
#        'Raymond Rundingmans Crconashaugh Crdry Bkadams Crharnbacks Crtoms Cr Tribs To Delaware River',
#        'Bushkill Cr', 'Broadhead Cr', 'Pocono Cr',
#        'Cherry Cr Caledonia Cr Tribs To Delaware River',
#        'Slateford Cr Jacoby Cr Allegheny Cr Tribs To Delaware River',
#        'Paulins Kill Above Stillwater Village Trout Brook',
#        'Paulins Kill Below Stillwater Village', 'Pequest River',
#        'Martins Cr Mud Run Tribs To Delaware River',
#        'Pophandusing Bk Buckhorn Cr Lopatcong Cr Tribs To Delaware River',
#        'Tobyhanna Cr', 'Middle Lehigh River Above Sandy Run',
#        'Middle Lehigh River Above Black Creek',
#        'Middle Lehigh River Above Pohopoco Creek',
#        'Lower Lehigh River Upper Part', 'Aquashicola Cr',
#        'Lower Lehigh River Above Little Lehigh Creek', 'Jordan Cr',
#        'Little Lehigh Cr', 'Lower Lehigh River Below Little Lehigh Creek',
#        'Pohatcong Creek', 'Musconetcong River Above Trout Brook',
#        'Musconetcong River Below Including Trout Brook',
#        'Hakihokake Harihokake Nishisakawick Creeks And Tribs To Delaware River',
#        'Lockatong Cr Wickecheoke Cr Tribs To Delaware River',
#        'Geddes R Hickorypaunacussingaquetongpidockjerichohoughsdyersbuck Creekshollow R',
#        'Alexauken Moore Jacobs Creeks Tribs To Delaware Riv',
#        'Assunpink Creek',
#        'Sciotts Cr Martins Cr Tributaries To Delaware River',
#        'Crosswicks Ck',
#        'Crafts Creek Blacks Creek Tribs To Delaware River',
#        'Assiscunk Cr Burlington Edgewater Park Del Tribs',
#        'Nb Rancocas Cr Above New Lisbon Dam Greenwood Br',
#        'Sb Rancocas Creek Above Bobbys Run',
#        'Sb Rancocas Creek Sw Branch',
#        'Rancocas Creek Mainstem With Nb Below New Lisbon Dam Sb Below Bobbys Run',
#        'Pennsauken Cr Pompeston Cr Swede Run Tributaries To Delaware River',
#        'Cooper River',
#        'Woodbury Big Timber Newton Creeks Tributaries To Delaware River',
#        'Upper Schuylkill River Below Pottsville',
#        'Tribs To Middle Schuylkill River Upper',
#        'Maiden Cr Above Saucony Creek', 'Maiden Cr Below Saucony Creek',
#        'Upper Tulpehocken Cr Above Blue Marsh Res',
#        'Lower Tulpehocken Cr Below Blue Marsh Res', 'Manatawny Cr',
#        'Mantua Creek',
#        'Cedar Swamp Repaupo Cr Clonmell Cr Tributaries To Delaware River',
#        'Raccoon Creek Birch Creek',
#        'Salem River Above Dam Salem Canal Tribs To Delaware Bay',
#        'Red Clay Cr', 'White Clay Cr',
#        'Christina River Tribs To Delaware River',
#        'Salem River Below Dam Tributaries To Delaware Bay',
#        'Army Redlion Dragon Creeks Tribs To Delaware Riv',
#        'Cd Canal Tribs Top Delaware Bay',
#        'Augustine Cr Appoquunimick Riv Blackbird Cr Tribs To Delaware Bay',
#        'Cedar Swamp Smyrna Riv Duck Cr Tribs To Delaware Bay',
#        'Cohansey River',
#        'Lepsic Simons Little Rivers Tribs To Delaware Bay',
#        'Scotland Run Still Run Little Ease Run',
#        'Maurice River Above Sherman Ave Bridge Muddy Run',
#        'Maurice River Above Menantico Cr',
#        'Menantico Creek Manamuskin River',
#        'West Cr East Crriggins Ditch Dennis Cr Tribs To Delaware Bay',
#        'Cape May West Tribs To Delaware Bay', 'St Jones River',
#        'Murderkill River', 'Missipillion River Tribs To Delaware Bay',
#        'Round Pole Br Red Mill Cr Wagamons Pond N Rehoboth',
#        'Pohopoco Cr', 'Little Schuylkill River',
#        'Upper Schuylkill River Above Pottsville',
#        'Alloway Creek Hope Creek Tribs To Delaware Bay',
#        'Mast Hope Cr Westcolona Cr Tributaries To Delaware River',
#        'Shohola Cr Panther Cr Tributaries To Delaware River',
#        'Oldmans Creek', 'Bear Creek',
#        'Back Cedar Nantuxent Dividing Creeks Tribs To Delaware Bay',
#        'Frya Run Cooks Cr Tinicum Cr Other Tribs To Delaware River',
#        'Van Campens Bk Dunnfiled Cr Tribs To Delaware River',
#        'Beaver Dam Crcaulkins Crcooley Crhollister Cr Beaverdam Cr Peggy Run Tribs To Delaware River',
#        'Dyberry Creek', 'West Branch Wallenpaupack Cr',
#        'Upper Lehigh River', 'Middle West Br Delaware River',
#        'Upper East Br Delaware River Tribs To Pepacton Reservoir',
#        'Mongaup River Tributaries To Swinging Bridge Reservoir',
#        'Mongaup River Below Swinging Bridge Res + Shingle Kill',
#        'Maurice River Below Menantico Cr',
#        'Cedar Cr Slaughter Cr Prime Hook Cr Tribs To Delaware Bay',
#        'Frankfort Cr Tribs To Delaware River',
#        'Naamans Cr Shellpot Cr Tribs To Delaware River',
#        'Stony Brook Delawanna Creek Beaver Brook',
#        'Stow Creek Tribs To Delaware Bay', 'Darby Cr'], dtype=object)

# %%
outdf['in_ReportingUnitTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_ReportingUnitTypeCV']), axis=1)
outdf['in_ReportingUnitTypeCV'].unique()
# Out:
# array(['Subbasin'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
for x in outdf['in_BeneficialUseCategory'].sort_values().unique():
    print(f'"' + x + '",')
# Out:
# "Agriculture",
# "Bottled Water",
# "Commercial",
# "Cranberries",
# "Fish Hatchery",
# "Golf/CC",
# "Hospital/Health",
# "Hydroelectric Power",
# "Industrial",
# "Military",
# "Mining",
# "Non-Agricultural Irrigation",
# "Nursery",
# "Parks/Recreation",
# "Prison",
# "Public Water Supply",
# "Refinery",
# "Remediation",
# "School",
# "Ski/Snowmaking",
# "Thermoelectric Power",
# "Unassociated GW",
# "Unassociated SW",

# %%
# Fixing n_Amount datatype
outdf['in_Amount'] = pd.to_numeric(outdf['in_Amount'], errors='coerce').replace(0,"").fillna("")
outdf['in_Amount'].unique()
# Out:
# array([46.41692851369868, 401.471906655343, 320.76015657863053, ...,
#        51.29363679552, 7.944061673520001, 42.798466085812684],
#       dtype=object)

# %%
# %%time

# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)
dfWaterSourceNativeID['linkKey'] = dfWaterSourceNativeID['in_WaterSourceName'].astype(str) + dfWaterSourceNativeID['in_WaterSourceTypeCV'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
WaterSourceNativeIDdict = pd.Series(dfWaterSourceNativeID.in_WaterSourceNativeID.values, index=dfWaterSourceNativeID.linkKey.astype(str)).to_dict()
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        colrowValue = str(A).strip() + str(B).strip()
        try:
            outList = WaterSourceNativeIDdict[colrowValue]
        except:
            outList = ''
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# Wall time: 521 ms
# array(['wadeID1', 'wadeID2'], dtype=object)

# %%
# determine in_VariableSpecificCV
outdf['in_VariableSpecificCV'] = outdf['in_VariableCV'].astype(str) + "_" + outdf['in_AggregationIntervalUnitCV'].astype(str) + "_" + outdf['in_BeneficialUseCategory'].astype(str) + "_" + outdf['in_WaterSourceTypeCV'].astype(str)
outdf['in_VariableSpecificCV'].unique()
# Out:
# array(['Withdrawal_Annual_Public Water Supply_Groundwater',
#        'Withdrawal_Annual_Public Water Supply_Surface Water',
#        'Withdrawal_Annual_Thermoelectric Power_Surface Water',
#        'Withdrawal_Annual_Thermoelectric Power_Groundwater',
#        'Withdrawal_Annual_Hydroelectric Power_Surface Water',
#        'Withdrawal_Annual_Industrial_Groundwater',
#        'Withdrawal_Annual_Remediation_Groundwater',
#        'Withdrawal_Annual_Refinery_Groundwater',
#        'Withdrawal_Annual_Industrial_Surface Water',
#        'Withdrawal_Annual_Remediation_Surface Water',
#        'Withdrawal_Annual_Refinery_Surface Water',
#        'Withdrawal_Annual_Mining_Groundwater',
#        'Withdrawal_Annual_Mining_Surface Water',
#        'Withdrawal_Annual_Agriculture_Groundwater',
#        'Withdrawal_Annual_Cranberries_Groundwater',
#        'Withdrawal_Annual_Golf/CC_Groundwater',
#        'Withdrawal_Annual_Non-Agricultural Irrigation_Groundwater',
#        'Withdrawal_Annual_Nursery_Groundwater',
#        'Withdrawal_Annual_Agriculture_Surface Water',
#        'Withdrawal_Annual_Cranberries_Surface Water',
#        'Withdrawal_Annual_Golf/CC_Surface Water',
#        'Withdrawal_Annual_Non-Agricultural Irrigation_Surface Water',
#        'Withdrawal_Annual_Nursery_Surface Water',
#        'Withdrawal_Annual_Parks/Recreation_Groundwater',
#        'Withdrawal_Annual_Unassociated GW_Groundwater',
#        'Withdrawal_Annual_School_Groundwater',
#        'Withdrawal_Annual_Commercial_Groundwater',
#        'Withdrawal_Annual_Prison_Groundwater',
#        'Withdrawal_Annual_Hospital/Health_Groundwater',
#        'Withdrawal_Annual_Military_Groundwater',
#        'Withdrawal_Annual_Fish Hatchery_Groundwater',
#        'Withdrawal_Annual_Unassociated SW_Surface Water',
#        'Withdrawal_Annual_Commercial_Surface Water',
#        'Withdrawal_Annual_Ski/Snowmaking_Surface Water',
#        'Withdrawal_Annual_Military_Surface Water',
#        'Withdrawal_Annual_Ski/Snowmaking_Groundwater',
#        'Withdrawal_Annual_Bottled Water_Groundwater',
#        'Withdrawal_Annual_Fish Hatchery_Surface Water',
#        'Consumptive_Annual_Public Water Supply_Groundwater',
#        'Consumptive_Annual_Public Water Supply_Surface Water',
#        'Consumptive_Annual_Thermoelectric Power_Surface Water',
#        'Consumptive_Annual_Thermoelectric Power_Groundwater',
#        'Consumptive_Annual_Hydroelectric Power_Surface Water',
#        'Consumptive_Annual_Industrial_Groundwater',
#        'Consumptive_Annual_Remediation_Groundwater',
#        'Consumptive_Annual_Refinery_Groundwater',
#        'Consumptive_Annual_Industrial_Surface Water',
#        'Consumptive_Annual_Remediation_Surface Water',
#        'Consumptive_Annual_Refinery_Surface Water',
#        'Consumptive_Annual_Mining_Groundwater',
#        'Consumptive_Annual_Mining_Surface Water',
#        'Consumptive_Annual_Agriculture_Groundwater',
#        'Consumptive_Annual_Cranberries_Groundwater',
#        'Consumptive_Annual_Golf/CC_Groundwater',
#        'Consumptive_Annual_Non-Agricultural Irrigation_Groundwater',
#        'Consumptive_Annual_Nursery_Groundwater',
#        'Consumptive_Annual_Agriculture_Surface Water',
#        'Consumptive_Annual_Cranberries_Surface Water',
#        'Consumptive_Annual_Golf/CC_Surface Water',
#        'Consumptive_Annual_Non-Agricultural Irrigation_Surface Water',
#        'Consumptive_Annual_Nursery_Surface Water',
#        'Consumptive_Annual_Parks/Recreation_Groundwater',
#        'Consumptive_Annual_Unassociated GW_Groundwater',
#        'Consumptive_Annual_School_Groundwater',
#        'Consumptive_Annual_Commercial_Groundwater',
#        'Consumptive_Annual_Prison_Groundwater',
#        'Consumptive_Annual_Hospital/Health_Groundwater',
#        'Consumptive_Annual_Military_Groundwater',
#        'Consumptive_Annual_Fish Hatchery_Groundwater',
#        'Consumptive_Annual_Unassociated SW_Surface Water',
#        'Consumptive_Annual_Commercial_Surface Water',
#        'Consumptive_Annual_Ski/Snowmaking_Surface Water',
#        'Consumptive_Annual_Military_Surface Water',
#        'Consumptive_Annual_Ski/Snowmaking_Groundwater',
#        'Consumptive_Annual_Bottled Water_Groundwater',
#        'Consumptive_Annual_Fish Hatchery_Surface Water'], dtype=object)

# %%
# %%time

# Creating WaDE VariableSpecificUUID for easy VariableSpecificCV identification 
# use these inputs: VariableCV_AggregationIntervalUnitCV_BeneficalUse_WaterSourceTypeCV
# ----------------------------------------------------------------------------------------------------

# Create temp VariableSpecificUUID dataframe of unique water source.
def assignVariableSpecificUUID(colrowValue):
    string1 = str(colrowValue)
    outstring = "DRBCwr_V" + string1
    return outstring

dfVariableSpecificUUID = pd.DataFrame()
dfVariableSpecificUUID['in_VariableCV'] = outdf['in_VariableCV']
dfVariableSpecificUUID['in_AggregationIntervalUnitCV'] = outdf['in_AggregationIntervalUnitCV']
dfVariableSpecificUUID['in_BeneficialUseCategory'] = outdf['in_BeneficialUseCategory']
dfVariableSpecificUUID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfVariableSpecificUUID = dfVariableSpecificUUID.drop_duplicates()

dftemp = pd.DataFrame(index=dfVariableSpecificUUID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfVariableSpecificUUID['in_VariableSpecificUUID'] = dftemp.apply(lambda row: assignVariableSpecificUUID(row['Count']), axis=1)
dfVariableSpecificUUID['linkKey'] = dfVariableSpecificUUID['in_VariableCV'].astype(str) + dfVariableSpecificUUID['in_AggregationIntervalUnitCV'].astype(str) + dfVariableSpecificUUID['in_BeneficialUseCategory'].astype(str) + dfVariableSpecificUUID['in_WaterSourceTypeCV'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
VariableSpecificUUIDdict = pd.Series(dfVariableSpecificUUID.in_VariableSpecificUUID.values, index=dfVariableSpecificUUID.linkKey.astype(str)).to_dict()
def retrieveVariableSpecificUUID(A, B, C, D):
    if (A == '' and B == '' and C == '' and D == '') or (pd.isnull(A) and pd.isnull(B) and pd.isnull(C) and pd.isnull(D)):
        outList = ''
    else:
        colrowValue = str(A).strip() + str(B).strip() + str(C).strip() + str(D).strip()
        try:
            outList = VariableSpecificUUIDdict[colrowValue]
        except:
            outList = ''
    return outList

outdf['in_VariableSpecificUUID'] = outdf.apply(lambda row: retrieveVariableSpecificUUID(row['in_VariableCV'], row['in_AggregationIntervalUnitCV'], row['in_BeneficialUseCategory'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_VariableSpecificUUID'].unique()
# Out:
# Wall time: 646 ms
# array(['DRBCwr_V1', 'DRBCwr_V2', 'DRBCwr_V3', 'DRBCwr_V4', 'DRBCwr_V5',
#        'DRBCwr_V6', 'DRBCwr_V7', 'DRBCwr_V8', 'DRBCwr_V9', 'DRBCwr_V10',
#        'DRBCwr_V11', 'DRBCwr_V12', 'DRBCwr_V13', 'DRBCwr_V14',
#        'DRBCwr_V15', 'DRBCwr_V16', 'DRBCwr_V17', 'DRBCwr_V18',
#        'DRBCwr_V19', 'DRBCwr_V20', 'DRBCwr_V21', 'DRBCwr_V22',
#        'DRBCwr_V23', 'DRBCwr_V24', 'DRBCwr_V25', 'DRBCwr_V26',
#        'DRBCwr_V27', 'DRBCwr_V28', 'DRBCwr_V29', 'DRBCwr_V30',
#        'DRBCwr_V31', 'DRBCwr_V32', 'DRBCwr_V33', 'DRBCwr_V34',
#        'DRBCwr_V35', 'DRBCwr_V36', 'DRBCwr_V37', 'DRBCwr_V38',
#        'DRBCwr_V39', 'DRBCwr_V40', 'DRBCwr_V41', 'DRBCwr_V42',
#        'DRBCwr_V43', 'DRBCwr_V44', 'DRBCwr_V45', 'DRBCwr_V46',
#        'DRBCwr_V47', 'DRBCwr_V48', 'DRBCwr_V49', 'DRBCwr_V50',
#        'DRBCwr_V51', 'DRBCwr_V52', 'DRBCwr_V53', 'DRBCwr_V54',
#        'DRBCwr_V55', 'DRBCwr_V56', 'DRBCwr_V57', 'DRBCwr_V58',
#        'DRBCwr_V59', 'DRBCwr_V60', 'DRBCwr_V61', 'DRBCwr_V62',
#        'DRBCwr_V63', 'DRBCwr_V64', 'DRBCwr_V65', 'DRBCwr_V66',
#        'DRBCwr_V67', 'DRBCwr_V68', 'DRBCwr_V69', 'DRBCwr_V70',
#        'DRBCwr_V71', 'DRBCwr_V72', 'DRBCwr_V73', 'DRBCwr_V74',
#        'DRBCwr_V75', 'DRBCwr_V76'], dtype=object)

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to csv inputs.

# %%
# PoU Shapefile Data
# Shapefile input
dfshapetemp = gpd.read_file('shapefile/drb147.shp', crs="EPSG:4326")
print(len(dfshapetemp))
dfshapetemp.head()
# Out:
# 147
#    OBJECTID       SQM STATEID BASIN_ID  \
# 0         1 143.78600      NY   DB-001
# 1         2 210.12200      NY   DB-010
# 2         3  82.85000      NY   DB-003
# 3         4  52.26300      NY   DB-002
# 4         5  53.08400      NY   DB-004
#
#                                           STREAMS   Shape_Leng  \
# 0                    Upper West Br Delaware River 118207.57278
# 1  Upper East Br Delaware River above Platte Kill 122934.23131
# 2                   Middle West Br Delaware River  99450.67916
# 3                           Little Delaware River  67203.77633
# 4          Third Branch, West Branch, East Branch  58100.66790
#
#               HUC8_Name  Shape_Le_1  Shape_Area  \
# 0        Upper Delaware     1.26136     0.04069
# 1  East Branch Delaware     1.28764     0.05932
# 2        Upper Delaware     1.05879     0.02340
# 3        Upper Delaware     0.72892     0.01477
# 4        Upper Delaware     0.61221     0.01499
#
#                                             geometry
# 0  POLYGON ((-74.82876 42.39163, -74.82836 42.392...
# 1  POLYGON ((-74.55828 42.36695, -74.55811 42.366...
# 2  POLYGON ((-75.04722 42.30325, -75.04739 42.304...
# 3  POLYGON ((-74.66058 42.29526, -74.66106 42.294...
# 4  POLYGON ((-75.20544 42.25283, -75.20539 42.252...

# %%
columnsList = ['in_ReportingUnitNativeID', 'geometry']
outshape = pd.DataFrame(columns=columnsList)
outshape['in_ReportingUnitNativeID'] = dfshapetemp['BASIN_ID'].replace("", 0).fillna(0).astype(str).str.strip()
outshape['geometry'] = dfshapetemp['geometry']
outshape = outshape.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
outshape.head()
# Out:
#   in_ReportingUnitNativeID                                           geometry
# 0                   DB-001  POLYGON ((-74.82876 42.39163, -74.82836 42.392...
# 1                   DB-010  POLYGON ((-74.55828 42.36695, -74.55811 42.366...
# 2                   DB-003  POLYGON ((-75.04722 42.30325, -75.04739 42.304...
# 3                   DB-002  POLYGON ((-74.66058 42.29526, -74.66106 42.294...
# 4                   DB-004  POLYGON ((-75.20544 42.25283, -75.20539 42.252...

# %% [markdown]
# # Export the Output

# %%
outdf.info
# Out:
# <bound method DataFrame.info of         WaDEUUID in_MethodUUID in_VariableSpecificUUID  \
# 0          drbc0     DRBCag_M1               DRBCwr_V1
# 1          drbc1     DRBCag_M1               DRBCwr_V1
# 2          drbc2     DRBCag_M1               DRBCwr_V1
# 3          drbc3     DRBCag_M1               DRBCwr_V1
# 4          drbc4     DRBCag_M1               DRBCwr_V1
# ...          ...           ...                     ...
# 42931  drbc21463     DRBCag_M1              DRBCwr_V70
# 42932  drbc21464     DRBCag_M1              DRBCwr_V70
# 42933  drbc21465     DRBCag_M1              DRBCwr_V70
# 42934  drbc21466     DRBCag_M1              DRBCwr_V70
# 42935  drbc21467     DRBCag_M1              DRBCwr_V70
#
#       in_AggregationIntervalUnitCV in_VariableCV  \
# 0                           Annual    Withdrawal
# 1                           Annual    Withdrawal
# 2                           Annual    Withdrawal
# 3                           Annual    Withdrawal
# 4                           Annual    Withdrawal
# ...                            ...           ...
# 42931                       Annual   Consumptive
# 42932                       Annual   Consumptive
# 42933                       Annual   Consumptive
# 42934                       Annual   Consumptive
# 42935                       Annual   Consumptive
#
#                                    in_VariableSpecificCV in_OrganizationUUID  \
# 0      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# 1      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# 2      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# 3      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# 4      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# ...                                                  ...                 ...
# 42931   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
# 42932   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
# 42933   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
# 42934   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
# 42935   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
#
#       in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...           ...                  ...                        ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                       wadeID1          Groundwater
# 1                                       wadeID1          Groundwater
# 2                                       wadeID1          Groundwater
# 3                                       wadeID1          Groundwater
# 4                                       wadeID1          Groundwater
# ...                  ...                    ...                  ...
# 42931                                   wadeID2        Surface Water
# 42932                                   wadeID2        Surface Water
# 42933                                   wadeID2        Surface Water
# 42934                                   wadeID2        Surface Water
# 42935                                   wadeID2        Surface Water
#
#        in_EPSGCodeCV                       in_ReportingUnitName  \
# 0               4326                                Tohichon Cr
# 1               4326  Neshaminy Cr Below Little Neshaminy Creek
# 2               4326           Crum Cr Ridley Cr Marcus Hook Cr
# 3               4326                   West Branch Perkiomen Cr
# 4               4326                   West Branch Perkiomen Cr
# ...              ...                                        ...
# 42931           4326              Maiden Cr Below Saucony Creek
# 42932           4326  Upper Tulpehocken Cr Above Blue Marsh Res
# 42933           4326  Lower Tulpehocken Cr Below Blue Marsh Res
# 42934           4326     Tribs To Middle Schuylkill River Lower
# 42935           4326                      West Br Brandywine Cr
#
#       in_ReportingUnitNativeID in_ReportingUnitProductVersion  \
# 0                       DB-074
# 1                       DB-084
# 2                       DB-114
# 3                       DB-106
# 4                       DB-106
# ...                        ...                            ...
# 42931                   DB-099
# 42932                   DB-100
# 42933                   DB-101
# 42934                   DB-102
# 42935                   DB-121
#
#       in_ReportingUnitTypeCV in_ReportingUnitUpdateDate in_StateCV  \
# 0                   Subbasin                                    DE
# 1                   Subbasin                                    DE
# 2                   Subbasin                                    DE
# 3                   Subbasin                                    DE
# 4                   Subbasin                                    DE
# ...                      ...                        ...        ...
# 42931               Subbasin                                    DE
# 42932               Subbasin                                    DE
# 42933               Subbasin                                    DE
# 42934               Subbasin                                    DE
# 42935               Subbasin                                    DE
#
#       in_AllocationCropDutyAmount in_Amount in_BeneficialUseCategory  \
# 0                                  46.41693      Public Water Supply
# 1                                 401.47191      Public Water Supply
# 2                                 320.76016      Public Water Supply
# 3                                 107.65659      Public Water Supply
# 4                                 354.37369      Public Water Supply
# ...                           ...       ...                      ...
# 42931                               0.00000          Unassociated SW
# 42932                              51.29364          Unassociated SW
# 42933                               7.94406          Unassociated SW
# 42934                              42.79847          Unassociated SW
# 42935                              16.69463          Unassociated SW
#
#       in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...           ...               ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...                   ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_InterbasinTransferFromID in_InterbasinTransferToID  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                       ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_IrrigatedAcreage in_IrrigationMethodCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                   ...                 ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategory  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...          ...                   ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#        in_ReportYearCV in_SDWISIdentifierCV in_TimeframeEnd in_TimeframeStart
# 0                 1990                           12/31/1990        01/01/1990
# 1                 1990                           12/31/1990        01/01/1990
# 2                 1990                           12/31/1990        01/01/1990
# 3                 1990                           12/31/1990        01/01/1990
# 4                 1990                           12/31/1990        01/01/1990
# ...                ...                  ...             ...               ...
# 42931             2017                           12/31/2017        01/01/2017
# 42932             2017                           12/31/2017        01/01/2017
# 42933             2017                           12/31/2017        01/01/2017
# 42934             2017                           12/31/2017        01/01/2017
# 42935             2017                           12/31/2017        01/01/2017
#
# [42936 rows x 40 columns]>

# %%
outdf
# Out:
#         WaDEUUID in_MethodUUID in_VariableSpecificUUID  \
# 0          drbc0     DRBCag_M1               DRBCwr_V1
# 1          drbc1     DRBCag_M1               DRBCwr_V1
# 2          drbc2     DRBCag_M1               DRBCwr_V1
# 3          drbc3     DRBCag_M1               DRBCwr_V1
# 4          drbc4     DRBCag_M1               DRBCwr_V1
# ...          ...           ...                     ...
# 42931  drbc21463     DRBCag_M1              DRBCwr_V70
# 42932  drbc21464     DRBCag_M1              DRBCwr_V70
# 42933  drbc21465     DRBCag_M1              DRBCwr_V70
# 42934  drbc21466     DRBCag_M1              DRBCwr_V70
# 42935  drbc21467     DRBCag_M1              DRBCwr_V70
#
#       in_AggregationIntervalUnitCV in_VariableCV  \
# 0                           Annual    Withdrawal
# 1                           Annual    Withdrawal
# 2                           Annual    Withdrawal
# 3                           Annual    Withdrawal
# 4                           Annual    Withdrawal
# ...                            ...           ...
# 42931                       Annual   Consumptive
# 42932                       Annual   Consumptive
# 42933                       Annual   Consumptive
# 42934                       Annual   Consumptive
# 42935                       Annual   Consumptive
#
#                                    in_VariableSpecificCV in_OrganizationUUID  \
# 0      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# 1      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# 2      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# 3      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# 4      Withdrawal_Annual_Public Water Supply_Groundwater           DRBCag_O1
# ...                                                  ...                 ...
# 42931   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
# 42932   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
# 42933   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
# 42934   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
# 42935   Consumptive_Annual_Unassociated SW_Surface Water           DRBCag_O1
#
#       in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...           ...                  ...                        ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                       wadeID1          Groundwater
# 1                                       wadeID1          Groundwater
# 2                                       wadeID1          Groundwater
# 3                                       wadeID1          Groundwater
# 4                                       wadeID1          Groundwater
# ...                  ...                    ...                  ...
# 42931                                   wadeID2        Surface Water
# 42932                                   wadeID2        Surface Water
# 42933                                   wadeID2        Surface Water
# 42934                                   wadeID2        Surface Water
# 42935                                   wadeID2        Surface Water
#
#        in_EPSGCodeCV                       in_ReportingUnitName  \
# 0               4326                                Tohichon Cr
# 1               4326  Neshaminy Cr Below Little Neshaminy Creek
# 2               4326           Crum Cr Ridley Cr Marcus Hook Cr
# 3               4326                   West Branch Perkiomen Cr
# 4               4326                   West Branch Perkiomen Cr
# ...              ...                                        ...
# 42931           4326              Maiden Cr Below Saucony Creek
# 42932           4326  Upper Tulpehocken Cr Above Blue Marsh Res
# 42933           4326  Lower Tulpehocken Cr Below Blue Marsh Res
# 42934           4326     Tribs To Middle Schuylkill River Lower
# 42935           4326                      West Br Brandywine Cr
#
#       in_ReportingUnitNativeID in_ReportingUnitProductVersion  \
# 0                       DB-074
# 1                       DB-084
# 2                       DB-114
# 3                       DB-106
# 4                       DB-106
# ...                        ...                            ...
# 42931                   DB-099
# 42932                   DB-100
# 42933                   DB-101
# 42934                   DB-102
# 42935                   DB-121
#
#       in_ReportingUnitTypeCV in_ReportingUnitUpdateDate in_StateCV  \
# 0                   Subbasin                                    DE
# 1                   Subbasin                                    DE
# 2                   Subbasin                                    DE
# 3                   Subbasin                                    DE
# 4                   Subbasin                                    DE
# ...                      ...                        ...        ...
# 42931               Subbasin                                    DE
# 42932               Subbasin                                    DE
# 42933               Subbasin                                    DE
# 42934               Subbasin                                    DE
# 42935               Subbasin                                    DE
#
#       in_AllocationCropDutyAmount in_Amount in_BeneficialUseCategory  \
# 0                                  46.41693      Public Water Supply
# 1                                 401.47191      Public Water Supply
# 2                                 320.76016      Public Water Supply
# 3                                 107.65659      Public Water Supply
# 4                                 354.37369      Public Water Supply
# ...                           ...       ...                      ...
# 42931                               0.00000          Unassociated SW
# 42932                              51.29364          Unassociated SW
# 42933                               7.94406          Unassociated SW
# 42934                              42.79847          Unassociated SW
# 42935                              16.69463          Unassociated SW
#
#       in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...           ...               ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...                   ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_InterbasinTransferFromID in_InterbasinTransferToID  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                       ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_IrrigatedAcreage in_IrrigationMethodCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                   ...                 ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#       in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategory  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...          ...                   ...
# 42931
# 42932
# 42933
# 42934
# 42935
#
#        in_ReportYearCV in_SDWISIdentifierCV in_TimeframeEnd in_TimeframeStart
# 0                 1990                           12/31/1990        01/01/1990
# 1                 1990                           12/31/1990        01/01/1990
# 2                 1990                           12/31/1990        01/01/1990
# 3                 1990                           12/31/1990        01/01/1990
# 4                 1990                           12/31/1990        01/01/1990
# ...                ...                  ...             ...               ...
# 42931             2017                           12/31/2017        01/01/2017
# 42932             2017                           12/31/2017        01/01/2017
# 42933             2017                           12/31/2017        01/01/2017
# 42934             2017                           12/31/2017        01/01/2017
# 42935             2017                           12/31/2017        01/01/2017
#
# [42936 rows x 40 columns]

# %%
# Export the output dataframe
outdf.to_csv('Pag_drbcMain.zip', compression=dict(method='zip', archive_name='Pag_drbcMain.csv'), index=False)   # The output, save as a zip
outshape.to_csv('P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
