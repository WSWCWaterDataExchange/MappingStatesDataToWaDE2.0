# %% [markdown]
# # Pre-processing "XX" Water Right and Time Series Water Use data for WaDE Upload
# - Purpose:  To pre-process the data into one main file for simple DataFrame creation and extraction

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Utah/SS_PublicSupplyWaterUse" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Utah/SS_PublicSupplyWaterUse

# %% [markdown]
# ## Data Input

# %%
# Input File - water_use_data_Source
fileInput = "RawInputData/water_use_data_Source.zip"
dfin1 = pd.read_csv(fileInput).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin1:
    dfin1['WaDEUUID'] = "in1" + dfin1.index.astype(str)
    dfin1.to_csv("RawInputData/water_use_data_Source.zip", compression=dict(method='zip', archive_name="water_use_data_Source.csv"), index=False)

print(len(dfin1))
dfin1.head(1)
# Out:
# 8836
#    System ID                             System Name  Source ID  \
# 0       1000  Leeds Domestic Water Users Association   10000001
#
#                 Source Name Source Status Lat NAD83  Lon NAD83 Source Type  \
# 0  Oak Grove Spring (WS001)        Active  37.30895 -113.42877      Spring
#
#   Diversion Type        Use Type Year Units Method of Measurement Jan Feb Mar  \
# 0     Withdrawal  Water Supplier
#
#   Apr May Jun Jul Aug Sep Oct Nov Dec Total  \
# 0
#
#                                      Source Comments WaDEUUID
# 0  *Source 1 springs and Source 2 well are combin...     in10

# %%
# remove special characters from 'Source Name', including commas
def cleanSourceNameFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.,;/\)(-]", "", Val).replace("  ", " ").strip()
    return Val

dfin1['Source Name'] = dfin1.apply(lambda row: cleanSourceNameFunc(row['Source Name']), axis=1)
dfin1['Source Name'].unique()
# Out:
# array(['Oak Grove Spring WS001', 'Leeds Well No 1 WS002',
#        'Leeds Well No4 WS006', ..., 'Tropic Well',
#        'Zion Under Canvas Well WS001',
#        'Bryce Canyon Under Canvas Well WS001'], dtype=object)

# %%
# Input File - water_use_data_System
fileInput = "RawInputData/water_use_data_System.zip"
dfin2 = pd.read_csv(fileInput).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin2:
    dfin2['WaDEUUID'] = "in2" + dfin2.index.astype(str)
    dfin2.to_csv("RawInputData/water_use_data_System.zip", compression=dict(method='zip', archive_name="water_use_data_System.csv"), index=False)

print(len(dfin2))
dfin2.head(1)
# Out:
# 22514
# C:\Users\rjame\AppData\Local\Temp\ipykernel_5932\1321048333.py:3: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfin2 = pd.read_csv(fileInput).replace(np.nan, "")
#    System ID                             System Name System Type  \
# 0       1000  Leeds Domestic Water Users Association      Public
#
#   System Status  History Year Date Received      County Use Cooling Percent  \
# 0        Active          1960    12/31/1960  Washington
#
#   Use Process Percent Use Domestic Percent Use Miscellaneous Percent  \
# 0
#
#   Irrigation (Lawn and Garden) Percent Acres Irrigated  \
# 0
#
#   Irrigation (Agriculture) Acres Irrigated.1      DEQ ID Population  \
# 0                                            27010.00000    0.00000
#
#   Domestic Use Commercial Use Industrial Use Institutional Use      Total Use  \
# 0      0.00000        0.00000        0.00000                   18301270.92000
#
#   Method of Measurement Domestic Connections Commercial Connections  \
# 0                                    0.00000                0.00000
#
#   Industrial Connections Institutional Connections Total Connections  \
# 0                0.00000                                    52.00000
#
#   Peak Date Peak Demand Peak Demand Units Peak Use Include  \
# 0
#
#   Peak Measurement Type Peak Wholesale Volume Peak Wholesale Volume Units  \
# 0
#
#   ERC Yes/No  ERC Value Secondary Domestic Percent  \
# 0          Y  Not Avail
#
#   Secondary Industrial Percent Secondary Commercial Percent  \
# 0
#
#   Secondary Institutional Percent Secondary Agriculture Percent  \
# 0
#
#   Secondary Domestic Connections Secondary Industrial Connections  \
# 0
#
#   Secondary Commercial Connections Secondary Institutional Connections  \
# 0
#
#   Secondary Agriculture Connections  \
# 0
#
#   Secondary Irrigation (Lawn and Garden) Acres  \
# 0
#
#   Secondary Irrigation (Agriculture) Acres  \
# 0
#
#   Secondary Metered Domestic Connections  \
# 0
#
#   Secondary Metered Industrial Connections  \
# 0
#
#   Secondary Metered Commercial Connections  \
# 0
#
#   Secondary Metered Institutional Connections  \
# 0
#
#   Secondary Metered Agriculture Connections Secondary Metered Domestic Use  \
# 0
#
#   Secondary Metered Commercial Use Secondary Metered Industrial Use  \
# 0
#
#   Secondary Metered Institutional Use Secondary Metered Agriculture Use  \
# 0
#
#                                      System Comments WaDEUUID
# 0  (1988)1. Spring totals do not include overflow...     in20

# %%
# remove special characters from 'System Name', including commas
def cleanSystemNameFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.,;/\)(-]", "", Val).replace("  ", " ").strip()
    return Val

dfin2['System Name'] = dfin2.apply(lambda row: cleanSystemNameFunc(row['System Name']), axis=1)
dfin2['System Name'].unique()
# Out:
# array(['Leeds Domestic Water Users Association', 'Riverdale City',
#        'Fillmore Municipal Water System', ..., 'Tropic Town Misc',
#        'Zion Under Canvas', 'Under Canvas Bryce Canyon'], dtype=object)

# %%
# Input File - CulinaryWaterServiceArea.shp
shapefileInput = "RawInputData/shapefiles/CulinaryWaterServiceArea.zip" # ziped folder of the shp file
dfPoUshapetemp = gpd.read_file(shapefileInput)
dfPoUshapetemp['geometry'] = dfPoUshapetemp['geometry'].to_crs(epsg=4326) # Realign Geometry Projection
dfPoUshapetemp.head(1)
# Out:
#    FID_1   WRENAME    WRNAME    DWNAME SYSTEMTYPE  WATERRESID   WRID  \
# 0      1  Irontown  Irontown  Irontown          C         564  11358
#
#     DWSYSNUM                                             WRLINK WHOLESALER  \
# 0  UTAH11070  https://www.waterrights.utah.gov/asp_apps/view...        NaN
#
#   LABEL STATE COUNTY         BASIN   SUBAREA        SUBAREANAM      LANUM  \
# 0   NaN  Utah   Iron  Cedar/Beaver  06-03-01  Escalante Desert  06-03-01a
#
#              LANAME  ENDYEAR     DATASOURCE  SOURCEDATE     EDITOR  \
# 0  Escalante Desert     2022  DWRe/Supplier  2021-09-08  ADAMCLARK
#
#      EDITDATE  STATUS  wade_cent_  wade_cent1  Shape_Leng  SHAPE_Le_1  \
# 0  2021-11-19  Active  -113.44596    37.60243  6132.97250  6132.97250
#
#    Shape_Le_2  Shape_Area                                           geometry
# 0     0.06338     0.00007  POLYGON ((-113.45270 37.60395, -113.45335 37.6...

# %% [markdown]
# ## Work with Data

# %% [markdown]
# ### Source POD Data

# %%
# left merge
dfin1_2 = dfin1.merge(dfin2[['System ID', 'System Name', 'County']], left_on='System ID', right_on='System ID', how='left').replace(np.nan, "")
print(len(dfin1_2))
dfin1_2.head(1)
# Out:
# 187006
#    System ID                           System Name_x  Source ID  \
# 0       1000  Leeds Domestic Water Users Association   10000001
#
#               Source Name Source Status Lat NAD83  Lon NAD83 Source Type  \
# 0  Oak Grove Spring WS001        Active  37.30895 -113.42877      Spring
#
#   Diversion Type        Use Type Year Units Method of Measurement Jan Feb Mar  \
# 0     Withdrawal  Water Supplier
#
#   Apr May Jun Jul Aug Sep Oct Nov Dec Total  \
# 0
#
#                                      Source Comments WaDEUUID  \
# 0  *Source 1 springs and Source 2 well are combin...     in10
#
#                             System Name_y      County
# 0  Leeds Domestic Water Users Association  Washington

# %%
# fix blank / null in_MethodTypeCV

def fixMethodTypeCV(valA):
    valA = str(valA).strip().title()
    if valA == "" or pd.isnull(valA):
        outString = "WaDE Blank"
    else:
        outString = valA
    return outString

dfin1_2['in_MethodTypeCV'] = dfin1_2.apply(lambda row: fixMethodTypeCV(row['Method of Measurement']), axis=1)
dfin1_2['in_MethodTypeCV'].unique()
# Out:
# array(['WaDE Blank', 'Weir', 'Estimated', 'Calculated'], dtype=object)

# %%
# fix blank / null WaterSourcetypeCV
# simplify to WaDE specific categories

wsTypeDict = {
    "Well" : "Groundwater",
    "Well/Spring" : "Groundwater",
    "Well Field" : "Groundwater",
    "Well/Stream" : "Groundwater",
    "Tunnel" : "Groundwater",
    "Drain" : "Groundwater",
    "Stream" : "Surface Water",
    "Spring" : "Surface Water",
    "Reservoir" : "Surface Water",
    "Lake" : "Surface Water"}

def fixWaterSourceTypeCV(valA):
    valA = str(valA).strip()
    if valA == "" or pd.isnull(valA):
        outString = "WaDE Blank"
    else:
        try:
            outString = wsTypeDict[valA]
        except:
            outString = "WaDE Blank"
    return outString

dfin1_2['in_WaterSourceTypeCV'] = dfin1_2.apply(lambda row: fixWaterSourceTypeCV(row['Source Type']), axis=1)
dfin1_2['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater'], dtype=object)

# %%
# Loop data list.  Use this to search for specific fields.
amountList   =  ['Jan',     'Feb',     'Mar',     'Apr',     'May',    'Jun',      'Jul',     'Aug',     'Sep',     'Oct',     'Nov',     'Dec',     'Total']
aggregatList =  ["Monthly", "Monthly", "Monthly", "Monthly", "Monthly", "Monthly", "Monthly", "Monthly", "Monthly", "Monthly", "Monthly", "Monthly", "Annual"]
startDateList = ["01/01/",  "02/01/",  "03/01/",  "04/01/",  "05/01/",  "06/01/",  "07/01/",  "08/01/",  "09/01/",  "10/01/",  "11/01/",  "12/01/",  "01/01/"]
endDateList =   ["01/31/",  "02/28/",  "03/31/",  "04/30/",  "05/31/",  "06/30/",  "07/31/",  "08/31/",  "09/30/",  "10/31/",  "11/30/",  "12/31/",  "12/31/"]

# %%
# create output POD dataframe
outdf1 = pd.DataFrame()

# for each value in variableTypeList
for x in range(len(amountList)):

    df = pd.DataFrame()
   
    # Data Assessment UUID
    df['WaDEUUID'] = dfin1_2['WaDEUUID']
    
    # Method Info
    df['in_MethodUUID'] = "" # will create sa portion below
    df['in_MethodTypeCV'] = dfin1_2['in_MethodTypeCV'] # see above
    
    # Variable Info
    df['in_VariableSpecificUUID'] = "" # will create sa portion below
    df['in_AggregationIntervalUnitCV'] = aggregatList[x]
    df['in_VariableCV'] = dfin1_2['Diversion Type']
    
    # Organization Info
    df['in_OrganizationUUID'] = "UTssps_O1"
    
    # WaterSource Info
    df['in_Geometry'] = ""
    df['in_GNISFeatureNameCV'] = ""
    df['in_WaterQualityIndicatorCV'] = "Fresh"
    df['in_WaterSourceName'] = "WaDE Blank" # need this for auto fill below
    df['in_WaterSourceNativeID'] = "" # auto fill in below
    df['in_WaterSourceTypeCV'] = dfin1_2['in_WaterSourceTypeCV'] # see above
    
    # Site Info
    df['in_CoordinateAccuracy'] = "WaDE Blank"
    df['in_CoordinateMethodCV'] = "WaDE Blank"
    df['in_County'] = dfin1_2['County']
    df['in_EPSGCodeCV'] = 4326
    df['in_Geometry'] = ""
    df['in_GNISCodeCV'] = ""
    df['in_HUC12'] = ""
    df['in_HUC8'] = ""
    df['in_Latitude'] = dfin1_2['Lat NAD83']
    df['in_Longitude'] = dfin1_2['Lon NAD83']
    df['in_NHDNetworkStatusCV'] = ""
    df['in_NHDProductCV'] = ""
    df['in_PODorPOUSite'] = "POD"
    df['in_SiteName'] = dfin1_2['Source Name']
    df['in_SiteNativeID'] = "d" + dfin1_2['Source ID'].astype(str)
    df['in_SitePoint'] = ""
    df['in_SiteTypeCV'] = dfin1_2['Source Type']
    df['in_StateCV'] = "UT"
    df['in_USGSSiteID'] = ""
       
    # Site VariableAmounts Info
    df['in_Amount'] = dfin1_2[amountList[x]]
    df['in_AllocationCropDutyAmount'] = ""
    df['in_AssociatedNativeAllocationIDs'] = ""
    df['in_BeneficialUseCategory'] = dfin1_2['Use Type']
    df['in_CommunityWaterSupplySystem'] = dfin1_2['System Name_y']
    df['in_CropTypeCV'] = ""
    df['in_CustomerTypeCV'] = ""
    df['in_DataPublicationDate'] = ""
    df['in_DataPublicationDOI'] = ""
    df['in_Geometry'] = ""
    df['in_IrrigatedAcreage'] = ""
    df['in_IrrigationMethodCV'] = ""
    df['in_PopulationServed'] = ""
    df['in_PowerGeneratedGWh'] = ""
    df['in_PowerType'] = ""
    df['in_PrimaryUseCategory'] = "" # auto fill in below
    df['in_ReportYearCV'] =  dfin1_2['Year'].replace("", 0).fillna(0).astype(int).astype(str)
    df['in_SDWISIdentifier'] = ""
    df['in_TimeframeEnd'] = endDateList[x] + dfin1_2['Year'].replace("", 0).fillna(0).astype(int).astype(str)
    df['in_TimeframeStart'] = startDateList[x] + dfin1_2['Year'].replace("", 0).fillna(0).astype(int).astype(str)

    outdf1 = pd.concat([outdf1, df])

outdf1 = outdf1.drop_duplicates().reset_index(drop=True)
print(len(outdf1))
outdf1.head()
# Out:
# 114868
#   WaDEUUID in_MethodUUID in_MethodTypeCV in_VariableSpecificUUID  \
# 0     in10                    WaDE Blank
# 1     in11                    WaDE Blank
# 2     in12                    WaDE Blank
# 3     in13                    WaDE Blank
# 4     in14                    WaDE Blank
#
#   in_AggregationIntervalUnitCV in_VariableCV in_OrganizationUUID in_Geometry  \
# 0                      Monthly    Withdrawal           UTssps_O1
# 1                      Monthly    Withdrawal           UTssps_O1
# 2                      Monthly    Withdrawal           UTssps_O1
# 3                      Monthly    Withdrawal           UTssps_O1
# 4                      Monthly    Withdrawal           UTssps_O1
#
#   in_GNISFeatureNameCV in_WaterQualityIndicatorCV in_WaterSourceName  \
# 0                                           Fresh         WaDE Blank
# 1                                           Fresh         WaDE Blank
# 2                                           Fresh         WaDE Blank
# 3                                           Fresh         WaDE Blank
# 4                                           Fresh         WaDE Blank
#
#   in_WaterSourceNativeID in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0                               Surface Water            WaDE Blank
# 1                                 Groundwater            WaDE Blank
# 2                                 Groundwater            WaDE Blank
# 3                                 Groundwater            WaDE Blank
# 4                                 Groundwater            WaDE Blank
#
#   in_CoordinateMethodCV   in_County  in_EPSGCodeCV in_GNISCodeCV in_HUC12  \
# 0            WaDE Blank  Washington           4326
# 1            WaDE Blank  Washington           4326
# 2            WaDE Blank  Washington           4326
# 3            WaDE Blank       Weber           4326
# 4            WaDE Blank     Millard           4326
#
#   in_HUC8 in_Latitude in_Longitude in_NHDNetworkStatusCV in_NHDProductCV  \
# 0            37.30895   -113.42877
# 1            37.26708   -113.36336
# 2            37.26668   -113.36341
# 3            41.16996   -112.00563
# 4            38.96439   -112.38104
#
#   in_PODorPOUSite                in_SiteName in_SiteNativeID in_SitePoint  \
# 0             POD     Oak Grove Spring WS001       d10000001
# 1             POD      Leeds Well No 1 WS002       d10000002
# 2             POD       Leeds Well No4 WS006      d108547239
# 3             POD  5190S 1050W #1 Well WS003       d10010001
# 4             POD           FC Well #2 WS003       d10030001
#
#   in_SiteTypeCV in_StateCV in_USGSSiteID in_Amount  \
# 0        Spring         UT
# 1          Well         UT
# 2          Well         UT
# 3          Well         UT
# 4          Well         UT
#
#   in_AllocationCropDutyAmount in_AssociatedNativeAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_BeneficialUseCategory           in_CommunityWaterSupplySystem  \
# 0           Water Supplier  Leeds Domestic Water Users Association
# 1           Water Supplier  Leeds Domestic Water Users Association
# 2           Water Supplier  Leeds Domestic Water Users Association
# 3           Water Supplier                          Riverdale City
# 4           Water Supplier         Fillmore Municipal Water System
#
#   in_CropTypeCV in_CustomerTypeCV in_DataPublicationDate  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDOI in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PopulationServed in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategory  \
# 0
# 1
# 2
# 3
# 4
#
#   in_ReportYearCV in_SDWISIdentifier in_TimeframeEnd in_TimeframeStart
# 0               0                            01/31/0           01/01/0
# 1               0                            01/31/0           01/01/0
# 2               0                            01/31/0           01/01/0
# 3               0                            01/31/0           01/01/0
# 4               0                            01/31/0           01/01/0

# %% [markdown]
# ### System POU Data

# %%
# left merge dfPoUshapetemp shp info for lat & long info
dfin2_2 = dfin2.merge(dfPoUshapetemp[['WRID', 'wade_cent1', 'wade_cent_']], left_on='System ID', right_on='WRID', how='left').replace(np.nan, "")
print(len(dfin2_2))
dfin2_2.head(1)
# Out:
# 22902
#    System ID                             System Name System Type  \
# 0       1000  Leeds Domestic Water Users Association      Public
#
#   System Status  History Year Date Received      County Use Cooling Percent  \
# 0        Active          1960    12/31/1960  Washington
#
#   Use Process Percent Use Domestic Percent Use Miscellaneous Percent  \
# 0
#
#   Irrigation (Lawn and Garden) Percent Acres Irrigated  \
# 0
#
#   Irrigation (Agriculture) Acres Irrigated.1      DEQ ID Population  \
# 0                                            27010.00000    0.00000
#
#   Domestic Use Commercial Use Industrial Use Institutional Use      Total Use  \
# 0      0.00000        0.00000        0.00000                   18301270.92000
#
#   Method of Measurement Domestic Connections Commercial Connections  \
# 0                                    0.00000                0.00000
#
#   Industrial Connections Institutional Connections Total Connections  \
# 0                0.00000                                    52.00000
#
#   Peak Date Peak Demand Peak Demand Units Peak Use Include  \
# 0
#
#   Peak Measurement Type Peak Wholesale Volume Peak Wholesale Volume Units  \
# 0
#
#   ERC Yes/No  ERC Value Secondary Domestic Percent  \
# 0          Y  Not Avail
#
#   Secondary Industrial Percent Secondary Commercial Percent  \
# 0
#
#   Secondary Institutional Percent Secondary Agriculture Percent  \
# 0
#
#   Secondary Domestic Connections Secondary Industrial Connections  \
# 0
#
#   Secondary Commercial Connections Secondary Institutional Connections  \
# 0
#
#   Secondary Agriculture Connections  \
# 0
#
#   Secondary Irrigation (Lawn and Garden) Acres  \
# 0
#
#   Secondary Irrigation (Agriculture) Acres  \
# 0
#
#   Secondary Metered Domestic Connections  \
# 0
#
#   Secondary Metered Industrial Connections  \
# 0
#
#   Secondary Metered Commercial Connections  \
# 0
#
#   Secondary Metered Institutional Connections  \
# 0
#
#   Secondary Metered Agriculture Connections Secondary Metered Domestic Use  \
# 0
#
#   Secondary Metered Commercial Use Secondary Metered Industrial Use  \
# 0
#
#   Secondary Metered Institutional Use Secondary Metered Agriculture Use  \
# 0
#
#                                      System Comments WaDEUUID       WRID  \
# 0  (1988)1. Spring totals do not include overflow...     in20 1000.00000
#
#   wade_cent1 wade_cent_
# 0   37.23727 -113.34673

# %%
# Loop data list.  Use this to search for specific fields.
benuseList = ["Domestic",     "Commercial",     "Industrial",     "Institutional"]
amountList = ["Domestic Use", "Commercial Use", "Industrial Use", "Institutional Use"]

# %%
# create output POD dataframe
outdf2 = pd.DataFrame()

# for each value in variableTypeList
for x in range(len(amountList)):

    df = pd.DataFrame()
   
    # Data Assessment UUID
    df['WaDEUUID'] = dfin2_2['WaDEUUID']
    
    # Method Info
    df['in_MethodUUID'] = "" # will create sa portion below
    df['in_MethodTypeCV'] = "Metered" # I think all POU system data is coming from a meter value
    
    # Variable Info
    df['in_VariableSpecificUUID'] = "" # will create sa portion below
    df['in_AggregationIntervalUnitCV'] = "Annual"
    df['in_VariableCV'] = "Consumptive Use"
    
    # Organization Info
    df['in_OrganizationUUID'] = "UTssps_O1"
    
    # WaterSource Info
    df['in_Geometry'] = ""
    df['in_GNISFeatureNameCV'] = ""
    df['in_WaterQualityIndicatorCV'] = "Fresh"
    df['in_WaterSourceName'] = "WaDE Blank" # need this for auto fill below
    df['in_WaterSourceNativeID'] = "" # auto fill in below
    df['in_WaterSourceTypeCV'] = "WaDE Blank"
    
    # Site Info
    df['in_CoordinateAccuracy'] = "WaDE Blank"
    df['in_CoordinateMethodCV'] = "WaDE Blank"
    df['in_County'] = dfin2_2['County']
    df['in_EPSGCodeCV'] = 4326
    df['in_Geometry'] = ""
    df['in_GNISCodeCV'] = ""
    df['in_HUC12'] = ""
    df['in_HUC8'] = ""
    df['in_Latitude'] = dfin2_2['wade_cent1']
    df['in_Longitude'] = dfin2_2['wade_cent_']
    df['in_NHDNetworkStatusCV'] = ""
    df['in_NHDProductCV'] = ""
    df['in_PODorPOUSite'] = "POU"
    df['in_SiteName'] = dfin2_2['System Name']
    df['in_SiteNativeID'] = "u" + dfin2_2['System ID'].astype(str)
    df['in_SitePoint'] = ""
    df['in_SiteTypeCV'] = dfin2_2['System Type']
    df['in_StateCV'] = "UT"
    df['in_USGSSiteID'] = ""
    
    # Site VariableAmounts Info
    df['in_Amount'] = dfin2_2[amountList[x]]
    df['in_AllocationCropDutyAmount'] = ""
    df['in_AssociatedNativeAllocationIDs'] = ""
    df['in_BeneficialUseCategory'] = benuseList[x]
    df['in_CommunityWaterSupplySystem'] = dfin2_2['System Name']
    df['in_CropTypeCV'] = ""
    df['in_CustomerTypeCV'] = ""
    df['in_DataPublicationDate'] = ""
    df['in_DataPublicationDOI'] = ""
    df['in_Geometry'] = ""
    df['in_IrrigatedAcreage'] = ""
    df['in_IrrigationMethodCV'] = ""
    df['in_PopulationServed'] = dfin2_2['Population']
    df['in_PowerGeneratedGWh'] = ""
    df['in_PowerType'] = ""
    df['in_PrimaryUseCategory'] = "" # auto fill in below
    df['in_ReportYearCV'] =  dfin2_2['History Year'].replace("", 0).fillna(0).astype(int).astype(str)
    df['in_SDWISIdentifier'] = ""
    df['in_TimeframeEnd'] = "12/31/" + dfin2_2['History Year'].replace("", 0).fillna(0).astype(int).astype(str)
    df['in_TimeframeStart'] = "01/01/" + dfin2_2['History Year'].replace("", 0).fillna(0).astype(int).astype(str)

    outdf2 = pd.concat([outdf2, df])

outdf2 = outdf2.drop_duplicates().reset_index(drop=True)
print(len(outdf2))
outdf2.head()
# Out:
# 91608
#   WaDEUUID in_MethodUUID in_MethodTypeCV in_VariableSpecificUUID  \
# 0     in20                       Metered
# 1     in21                       Metered
# 2     in22                       Metered
# 3     in23                       Metered
# 4     in24                       Metered
#
#   in_AggregationIntervalUnitCV    in_VariableCV in_OrganizationUUID  \
# 0                       Annual  Consumptive Use           UTssps_O1
# 1                       Annual  Consumptive Use           UTssps_O1
# 2                       Annual  Consumptive Use           UTssps_O1
# 3                       Annual  Consumptive Use           UTssps_O1
# 4                       Annual  Consumptive Use           UTssps_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0                                                       Fresh
# 1                                                       Fresh
# 2                                                       Fresh
# 3                                                       Fresh
# 4                                                       Fresh
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0         WaDE Blank                                  WaDE Blank
# 1         WaDE Blank                                  WaDE Blank
# 2         WaDE Blank                                  WaDE Blank
# 3         WaDE Blank                                  WaDE Blank
# 4         WaDE Blank                                  WaDE Blank
#
#   in_CoordinateAccuracy in_CoordinateMethodCV   in_County  in_EPSGCodeCV  \
# 0            WaDE Blank            WaDE Blank  Washington           4326
# 1            WaDE Blank            WaDE Blank  Washington           4326
# 2            WaDE Blank            WaDE Blank  Washington           4326
# 3            WaDE Blank            WaDE Blank  Washington           4326
# 4            WaDE Blank            WaDE Blank  Washington           4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8 in_Latitude in_Longitude  \
# 0                                   37.23727   -113.34673
# 1                                   37.23727   -113.34673
# 2                                   37.23727   -113.34673
# 3                                   37.23727   -113.34673
# 4                                   37.23727   -113.34673
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0                                                   POU
# 1                                                   POU
# 2                                                   POU
# 3                                                   POU
# 4                                                   POU
#
#                               in_SiteName in_SiteNativeID in_SitePoint  \
# 0  Leeds Domestic Water Users Association           u1000
# 1  Leeds Domestic Water Users Association           u1000
# 2  Leeds Domestic Water Users Association           u1000
# 3  Leeds Domestic Water Users Association           u1000
# 4  Leeds Domestic Water Users Association           u1000
#
#   in_SiteTypeCV in_StateCV in_USGSSiteID in_Amount  \
# 0        Public         UT                 0.00000
# 1        Public         UT                 0.00000
# 2        Public         UT                 0.00000
# 3        Public         UT                 0.00000
# 4        Public         UT                 0.00000
#
#   in_AllocationCropDutyAmount in_AssociatedNativeAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_BeneficialUseCategory           in_CommunityWaterSupplySystem  \
# 0                 Domestic  Leeds Domestic Water Users Association
# 1                 Domestic  Leeds Domestic Water Users Association
# 2                 Domestic  Leeds Domestic Water Users Association
# 3                 Domestic  Leeds Domestic Water Users Association
# 4                 Domestic  Leeds Domestic Water Users Association
#
#   in_CropTypeCV in_CustomerTypeCV in_DataPublicationDate  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDOI in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PopulationServed in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategory  \
# 0             0.00000
# 1             0.00000
# 2             0.00000
# 3             0.00000
# 4             0.00000
#
#   in_ReportYearCV in_SDWISIdentifier in_TimeframeEnd in_TimeframeStart
# 0            1960                         12/31/1960        01/01/1960
# 1            1962                         12/31/1962        01/01/1962
# 2            1963                         12/31/1963        01/01/1963
# 3            1964                         12/31/1964        01/01/1964
# 4            1965                         12/31/1965        01/01/1965

# %% [markdown]
# ## Concatenate POD and POU Data.  Make needed changes

# %%
# Concatenate dataframes
frames = [outdf1, outdf2]  # list all out dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 206476

# %% [markdown]
# ## Clean Data / data types

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Wade Blank'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['Washington', 'Weber', 'Millard', 'Davis', 'Tooele', 'Iron',
#        'Box Elder', 'Salt Lake', 'Utah', 'Morgan', 'Carbon', 'Piute',
#        'Summit', 'Beaver', 'Duchesne', 'Cache', 'Kane', 'Emery', 'Wayne',
#        'Juab', 'Uintah', 'Grand', 'Garfield', 'Sevier', 'Wasatch',
#        'Sanpete', 'San Juan', 'Rich', 'Daggett'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['Oak Grove Spring Ws001', 'Leeds Well No 1 Ws002',
#        'Leeds Well No4 Ws006', ..., 'Tropic Town Misc',
#        'Zion Under Canvas', 'Under Canvas Bryce Canyon'], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Wade Blank'], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater', 'WaDE Blank'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['Spring', 'Well', 'Reservoir', 'Stream', 'Drain', 'Tunnel', 'Lake',
#        'Public', 'Industrial', 'Mgt Plan', 'Secondary'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['Oak Grove Spring Ws001', 'Leeds Well No 1 Ws002',
#        'Leeds Well No4 Ws006', ..., 'Tropic Town Misc',
#        'Zion Under Canvas', 'Under Canvas Bryce Canyon'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: ensureEmptyString(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['Washington', 'Weber', 'Millard', 'Davis', 'Tooele', 'Iron',
#        'Box Elder', 'Salt Lake', 'Utah', 'Morgan', 'Carbon', 'Piute',
#        'Summit', 'Beaver', 'Duchesne', 'Cache', 'Kane', 'Emery', 'Wayne',
#        'Juab', 'Uintah', 'Grand', 'Garfield', 'Sevier', 'Wasatch',
#        'Sanpete', 'San Juan', 'Rich', 'Daggett'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
uniqueList = list(set([i.strip() for i in ','.join(outdf['in_BeneficialUseCategory'].astype(str)).split(',')]))
uniqueList.sort()
uniqueList
# Out:
# ['Agricultural',
#  'Commercial',
#  'Domestic',
#  'Geothermal',
#  'Industrial',
#  'Institutional',
#  'Irrigation',
#  'Mining',
#  'Power (Fossil-Fuel)',
#  'Power (Geothermal)',
#  'Power (Hydro-Elec)',
#  'Water Supplier']

# %%
# Ensure Latitude entry is numireic, replace '0' values for removal
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([37.30895298, 37.26707725, 37.2666804, ..., 40.9540068992,
#        40.1441288757, 40.8695941542], dtype=object)

# %%
# Ensure Longitude entry is numireic, replace '0' values for removal
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-113.4287713, -113.363361, -113.3634141, ..., -110.815260029,
#        -111.016678598, -111.585571449], dtype=object)

# %%
# Ensure Amount entry is either numireic or blank, no 0 entries
outdf['in_Amount'] = pd.to_numeric(outdf['in_Amount'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_Amount'].unique()
# Out:
# array(['', 1798000.0, 3441000.0, ..., 192249.0, 922159.54, 343257.5],
#       dtype=object)

# %%
# Ensure PopulationServed entry is numireic WITH 0 entries (no blank strings)
outdf['in_PopulationServed'] = pd.to_numeric(outdf['in_PopulationServed'], errors='coerce').round().replace("",0).fillna(0).astype(int).astype(str)
outdf['in_PopulationServed'].unique()
# Out:
# array(['0', '255', '269', ..., '369362', '376117', '3514'], dtype=object)

# %%
# Convert TimeframeEnd to YYYY-MM-DD format.
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf['in_TimeframeEnd'], utc=True, errors = 'coerce').fillna("")
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf["in_TimeframeEnd"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeEnd'].unique()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_5932\1073956363.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   outdf['in_TimeframeEnd'] = pd.to_datetime(outdf['in_TimeframeEnd'], utc=True, errors = 'coerce').fillna("")
# <DatetimeArray>
# ['2000-01-31 00:00:00', '2019-01-31 00:00:00', '2020-01-31 00:00:00',
#  '2021-01-31 00:00:00', '2022-01-31 00:00:00', '2017-01-31 00:00:00',
#  '2018-01-31 00:00:00', '1996-01-31 00:00:00', '1997-01-31 00:00:00',
#  '1998-01-31 00:00:00',
#  ...
#  '1991-12-31 00:00:00', '1992-12-31 00:00:00', '1993-12-31 00:00:00',
#  '1994-12-31 00:00:00', '1959-12-31 00:00:00', '1970-12-31 00:00:00',
#  '1974-12-31 00:00:00', '1961-12-31 00:00:00', '1957-12-31 00:00:00',
#  '1958-12-31 00:00:00']
# Length: 408, dtype: datetime64[ns]

# %%
# Convert TimeframeStart to YYYY-MM-DD format.
outdf['in_TimeframeStart'] = pd.to_datetime(outdf['in_TimeframeStart'], utc=True, errors = 'coerce').fillna("")
outdf['in_TimeframeStart'] = pd.to_datetime(outdf["in_TimeframeStart"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeStart'].unique()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_5932\523555427.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   outdf['in_TimeframeStart'] = pd.to_datetime(outdf['in_TimeframeStart'], utc=True, errors = 'coerce').fillna("")
# <DatetimeArray>
# ['2000-01-01 00:00:00', '2019-01-01 00:00:00', '2020-01-01 00:00:00',
#  '2021-01-01 00:00:00', '2022-01-01 00:00:00', '2017-01-01 00:00:00',
#  '2018-01-01 00:00:00', '1996-01-01 00:00:00', '1997-01-01 00:00:00',
#  '1998-01-01 00:00:00',
#  ...
#  '1991-01-01 00:00:00', '1992-01-01 00:00:00', '1993-01-01 00:00:00',
#  '1994-01-01 00:00:00', '1959-01-01 00:00:00', '1970-01-01 00:00:00',
#  '1974-01-01 00:00:00', '1961-01-01 00:00:00', '1957-01-01 00:00:00',
#  '1958-01-01 00:00:00']
# Length: 408, dtype: datetime64[ns]

# %%
# extract year out
outdf['in_ReportYearCV'] = outdf['in_ReportYearCV'].replace("", 0).fillna(0).astype(int).astype(str)
outdf['in_ReportYearCV'].unique()
# Out:
# array(['0', '2019', '2020', '2021', '2022', '2017', '2018', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2006',
#        '2007', '2008', '2009', '2015', '2013', '2016', '2004', '2005',
#        '2023', '2014', '2010', '2011', '2012', '1975', '1988', '1995',
#        '1960', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1971', '1972', '1973', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1959', '1970',
#        '1974', '1961', '1957', '1958'], dtype=object)

# %%
# Assign Primary Use Category

import sys
sys.path.append("C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/5_CustomFunctions/AssignPrimaryUseCategory")
import AssignPrimaryUseCategoryFile # Use Custom import file

outdf['in_PrimaryUseCategory'] = outdf.apply(lambda row: AssignPrimaryUseCategoryFile.retrievePrimaryUseCategory(row['in_BeneficialUseCategory']), axis=1)
outdf['in_PrimaryUseCategory'].unique()
# Out:
# array(['Public Supply', 'Domestic', 'Commercial/Industrial',
#        'Agriculture Irrigation', 'Geothermal', 'Mining', 'Hydroelectric',
#        'Municipal Irrigation'], dtype=object)

# %%
# Creating WaDE MethodUUID
# ----------------------------------------------------------------------------------------------------

mtDict = {"WaDE Blank" : "UTssps_M1",
          "Weir" : "UTssps_M2",
          "Estimated" : "UTssps_M3",
          "Calculated" : "UTssps_M4",
          "Metered" : "UTssps_M5"}

def fillInMethodUUID(valA):
    valA = str(valA).strip()
    outString = mtDict[valA]
    return outString

outdf['in_MethodUUID'] = outdf.apply(lambda row: fillInMethodUUID(row['in_MethodTypeCV']), axis=1)
outdf['in_MethodUUID'].unique()
# Out:
# array(['UTssps_M1', 'UTssps_M2', 'UTssps_M3', 'UTssps_M4', 'UTssps_M5'],
#       dtype=object)

# %%
# Creating WaDE Custom VariableSpecificCV
# ----------------------------------------------------------------------------------------------------
def createVariableSpecificCV(inV, inAIU, inPU, inWST):
    inV = str(inV).strip()
    inAIU = str(inAIU).strip()
    inPU = str(inPU).strip().title()
    inWST = str(inWST).strip()
    outString = inV + "_" + inAIU + "_" + inPU + "_" + inWST
    return outString

outdf['in_VariableSpecificCV'] = outdf.apply(lambda row: createVariableSpecificCV(row['in_VariableCV'], 
                                                                                  row['in_AggregationIntervalUnitCV'],
                                                                                  row['in_PrimaryUseCategory'],
                                                                                  row['in_WaterSourceTypeCV']), axis=1)
outdf['in_VariableSpecificCV'].unique()
# Out:
# array(['Withdrawal_Monthly_Public Supply_Surface Water',
#        'Withdrawal_Monthly_Public Supply_Groundwater',
#        'Withdrawal_Monthly_Domestic_Groundwater',
#        'Withdrawal_Monthly_Commercial/Industrial_Groundwater',
#        'Transfer Out_Monthly_Public Supply_Groundwater',
#        'Transfer In_Monthly_Public Supply_Groundwater',
#        'Withdrawal_Monthly_Domestic_Surface Water',
#        'Transfer In_Monthly_Public Supply_Surface Water',
#        'Withdrawal_Monthly_Agriculture Irrigation_Groundwater',
#        'Transfer Out_Monthly_Public Supply_Surface Water',
#        'Return_Monthly_Agriculture Irrigation_Surface Water',
#        'Delivery_Monthly_Agriculture Irrigation_Surface Water',
#        'Return_Monthly_Public Supply_Groundwater',
#        'Delivery_Monthly_Public Supply_Surface Water',
#        'Transfer Out_Monthly_Agriculture Irrigation_Surface Water',
#        'Withdrawal_Monthly_Agriculture Irrigation_Surface Water',
#        'Withdrawal_Monthly_Commercial/Industrial_Surface Water',
#        'Transfer In_Monthly_Commercial/Industrial_Surface Water',
#        'Withdrawal_Monthly_Geothermal_Groundwater',
#        'Return_Monthly_Geothermal_Groundwater',
#        'Delivery_Monthly_Agriculture Irrigation_Groundwater',
#        'Return_Monthly_Commercial/Industrial_Surface Water',
#        'Transfer Out_Monthly_Commercial/Industrial_Surface Water',
#        'Transfer In_Monthly_Commercial/Industrial_Groundwater',
#        'Return_Monthly_Commercial/Industrial_Groundwater',
#        'Withdrawal_Monthly_Mining_Groundwater',
#        'Transfer In_Monthly_Mining_Groundwater',
#        'Withdrawal_Monthly_Mining_Surface Water',
#        'Withdrawal_Monthly_Hydroelectric_Groundwater',
#        'Transfer Out_Monthly_Hydroelectric_Groundwater',
#        'Withdrawal_Monthly_Hydroelectric_Surface Water',
#        'Withdrawal_Monthly_Geothermal_Surface Water',
#        'Transfer In_Monthly_Agriculture Irrigation_Surface Water',
#        'Transfer In_Monthly_Agriculture Irrigation_Groundwater',
#        'Transfer Out_Monthly_Agriculture Irrigation_Groundwater',
#        'Return_Monthly_Agriculture Irrigation_Groundwater',
#        'Transfer Out_Monthly_Commercial/Industrial_Groundwater',
#        'Return_Monthly_Public Supply_Surface Water',
#        'Return_Monthly_Hydroelectric_Surface Water',
#        'Withdrawal_Annual_Public Supply_Surface Water',
#        'Withdrawal_Annual_Public Supply_Groundwater',
#        'Withdrawal_Annual_Domestic_Groundwater',
#        'Withdrawal_Annual_Commercial/Industrial_Groundwater',
#        'Transfer Out_Annual_Public Supply_Groundwater',
#        'Transfer In_Annual_Public Supply_Groundwater',
#        'Withdrawal_Annual_Domestic_Surface Water',
#        'Transfer In_Annual_Public Supply_Surface Water',
#        'Withdrawal_Annual_Agriculture Irrigation_Groundwater',
#        'Transfer Out_Annual_Public Supply_Surface Water',
#        'Return_Annual_Agriculture Irrigation_Surface Water',
#        'Delivery_Annual_Agriculture Irrigation_Surface Water',
#        'Return_Annual_Public Supply_Groundwater',
#        'Delivery_Annual_Public Supply_Surface Water',
#        'Transfer Out_Annual_Agriculture Irrigation_Surface Water',
#        'Withdrawal_Annual_Agriculture Irrigation_Surface Water',
#        'Withdrawal_Annual_Commercial/Industrial_Surface Water',
#        'Transfer In_Annual_Commercial/Industrial_Surface Water',
#        'Withdrawal_Annual_Geothermal_Groundwater',
#        'Return_Annual_Geothermal_Groundwater',
#        'Delivery_Annual_Agriculture Irrigation_Groundwater',
#        'Return_Annual_Commercial/Industrial_Surface Water',
#        'Transfer Out_Annual_Commercial/Industrial_Surface Water',
#        'Transfer In_Annual_Commercial/Industrial_Groundwater',
#        'Return_Annual_Commercial/Industrial_Groundwater',
#        'Withdrawal_Annual_Mining_Groundwater',
#        'Transfer In_Annual_Mining_Groundwater',
#        'Withdrawal_Annual_Mining_Surface Water',
#        'Withdrawal_Annual_Hydroelectric_Groundwater',
#        'Transfer Out_Annual_Hydroelectric_Groundwater',
#        'Withdrawal_Annual_Hydroelectric_Surface Water',
#        'Withdrawal_Annual_Geothermal_Surface Water',
#        'Transfer In_Annual_Agriculture Irrigation_Surface Water',
#        'Transfer In_Annual_Agriculture Irrigation_Groundwater',
#        'Transfer Out_Annual_Agriculture Irrigation_Groundwater',
#        'Return_Annual_Agriculture Irrigation_Groundwater',
#        'Transfer Out_Annual_Commercial/Industrial_Groundwater',
#        'Return_Annual_Public Supply_Surface Water',
#        'Return_Annual_Hydroelectric_Surface Water',
#        'Consumptive Use_Annual_Domestic_WaDE Blank',
#        'Consumptive Use_Annual_Commercial/Industrial_WaDE Blank',
#        'Consumptive Use_Annual_Municipal Irrigation_WaDE Blank'],
#       dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], 
                                                                              row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3'], dtype=object)

# %%
# Creating WaDE Custom site native ID for easy site identification
# use Unique Latitude, Longitude, SiteName and SiteTypeCV values
# ----------------------------------------------------------------------------------------------------

# Create temp in_SiteNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_Latitude'] = outdf['in_Latitude'].astype(str).str.strip()
dfTempID['in_Longitude'] = outdf['in_Longitude'].astype(str).str.strip()
dfTempID['in_SiteName'] = outdf['in_SiteName'].astype(str).str.strip()
dfTempID['in_SiteTypeCV'] = outdf['in_SiteTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_SiteNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_Latitude'].astype(str) + dfTempID['in_Longitude'].astype(str) + dfTempID['in_SiteName'].astype(str)+ dfTempID['in_SiteTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_SiteNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB, valC, valD):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip() + str(valC).strip() + str(valD).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_SiteNativeID'], 
                                                                       row['in_Latitude'], row['in_Longitude'],
                                                                       row['in_SiteName'], row['in_SiteTypeCV']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# array(['d10000001', 'd10000002', 'd108547239', ..., 'u12023', 'u12024',
#        'u12026'], dtype=object)

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to POU csv inputs.

# %%
# PoU Shapefile Data
# see above for input

print(len(dfPoUshapetemp))
dfPoUshapetemp.head()
# Out:
# 1350
#    FID_1                WRENAME  \
# 0      1               Irontown
# 1      2      Mountain View SSD
# 2      3    Park West Water Co.
# 3      4  Fifetown Water System
# 4      5     Eagle Valley Ranch
#
#                                            WRNAME                     DWNAME  \
# 0                                        Irontown                   Irontown
# 1          Mountain View Special Service District  Mt. View Spec. Serv. Dist
# 2                        Park West Culinary Water    Park West Water Company
# 3  Central Iron County Water Conservancy District      Fifetown Water System
# 4                              Eagle Valley Ranch         Eagle Valley Ranch
#
#   SYSTEMTYPE  WATERRESID   WRID   DWSYSNUM  \
# 0          C         564  11358  UTAH11070
# 1          C         533  11169  UTAH11037
# 2         NP         509   1195  UTAH11009
# 3         NP         559  11047  UTAH11065
# 4         NP         551  11047  UTAH11056
#
#                                               WRLINK WHOLESALER LABEL STATE  \
# 0  https://www.waterrights.utah.gov/asp_apps/view...        NaN   NaN  Utah
# 1  https://www.waterrights.utah.gov/asp_apps/view...        NaN   NaN  Utah
# 2  https://www.waterrights.utah.gov/asp_apps/view...        NaN   NaN  Utah
# 3  https://www.waterrights.utah.gov/asp_apps/view...        NaN   NaN  Utah
# 4  https://www.waterrights.utah.gov/asp_apps/view...        NaN   NaN  Utah
#
#   COUNTY         BASIN   SUBAREA        SUBAREANAM      LANUM  \
# 0   Iron  Cedar/Beaver  06-03-01  Escalante Desert  06-03-01a
# 1   Iron  Cedar/Beaver  06-02-02             Cedar  06-02-02a
# 2   Iron  Cedar/Beaver  06-02-02             Cedar  06-02-02a
# 3   Iron  Cedar/Beaver  06-02-02             Cedar  06-02-02a
# 4   Iron  Cedar/Beaver  06-02-02             Cedar  06-02-02a
#
#              LANAME  ENDYEAR     DATASOURCE  SOURCEDATE     EDITOR  \
# 0  Escalante Desert     2022  DWRe/Supplier  2021-09-08  ADAMCLARK
# 1             Cedar     2022            NaN         NaN  ADAMCLARK
# 2             Cedar     2005            NaN         NaN  ADAMCLARK
# 3             Cedar     2005            NaN         NaN  ADAMCLARK
# 4             Cedar     2005            NaN         NaN  ADAMCLARK
#
#      EDITDATE    STATUS  wade_cent_  wade_cent1  Shape_Leng  SHAPE_Le_1  \
# 0  2021-11-19    Active  -113.44596    37.60243  6132.97250  6132.97250
# 1  2021-11-19    Active  -113.18932    37.69904  3106.90342  3106.90342
# 2  2017-05-31  Inactive  -113.14798    37.71320  3769.21561  3769.21561
# 3  2017-05-31  Inactive  -113.10044    37.73981  2986.43970  2986.43970
# 4  2017-06-01  Inactive  -113.08533    37.77760  6569.17120  6569.17120
#
#    Shape_Le_2  Shape_Area                                           geometry
# 0     0.06338     0.00007  POLYGON ((-113.45270 37.60395, -113.45335 37.6...
# 1     0.03145     0.00005  POLYGON ((-113.19375 37.70101, -113.19003 37.7...
# 2     0.03821     0.00009  POLYGON ((-113.15327 37.71748, -113.14286 37.7...
# 3     0.02963     0.00005  POLYGON ((-113.10386 37.74385, -113.09725 37.7...
# 4     0.06486     0.00013  POLYGON ((-113.09064 37.76492, -113.09055 37.7...

# %%
# create temp dataframe to hold native ID and geometry from shapefile input
columnsList = ['in_SiteNativeID', 'geometry']
dfPoUshape = pd.DataFrame(columns=columnsList)

# assing values to temp dataframe based on shapefile input
# for in_SiteNativeID assure ID value is the same as that listed above for POU info.
dfPoUshape['in_SiteNativeID'] = "u" + dfPoUshapetemp['WRID'].astype(str)
dfPoUshape['geometry'] = dfPoUshapetemp['geometry']
dfPoUshape = dfPoUshape.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
print(len(dfPoUshape))
dfPoUshape.head()
# Out:
# 1350
#   in_SiteNativeID                                           geometry
# 0          u11358  POLYGON ((-113.45270 37.60395, -113.45335 37.6...
# 1          u11169  POLYGON ((-113.19375 37.70101, -113.19003 37.7...
# 2           u1195  POLYGON ((-113.15327 37.71748, -113.14286 37.7...
# 3          u11047  POLYGON ((-113.10386 37.74385, -113.09725 37.7...
# 4          u11047  POLYGON ((-113.09064 37.76492, -113.09055 37.7...

# %% [markdown]
# ## Export Outputs

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206476 entries, 0 to 206475
# Data columns (total 51 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   WaDEUUID                          206476 non-null  object
#  1   in_MethodUUID                     206476 non-null  object
#  2   in_MethodTypeCV                   206476 non-null  object
#  3   in_VariableSpecificUUID           206476 non-null  object
#  4   in_AggregationIntervalUnitCV      206476 non-null  object
#  5   in_VariableCV                     206476 non-null  object
#  6   in_OrganizationUUID               206476 non-null  object
#  7   in_Geometry                       206476 non-null  object
#  8   in_GNISFeatureNameCV              206476 non-null  object
#  9   in_WaterQualityIndicatorCV        206476 non-null  object
#  10  in_WaterSourceName                206476 non-null  object
#  11  in_WaterSourceNativeID            206476 non-null  object
#  12  in_WaterSourceTypeCV              206476 non-null  object
#  13  in_CoordinateAccuracy             206476 non-null  object
#  14  in_CoordinateMethodCV             206476 non-null  object
#  15  in_County                         206476 non-null  object
#  16  in_EPSGCodeCV                     206476 non-null  int64
#  17  in_GNISCodeCV                     206476 non-null  object
#  18  in_HUC12                          206476 non-null  object
#  19  in_HUC8                           206476 non-null  object
#  20  in_Latitude                       206476 non-null  object
#  21  in_Longitude                      206476 non-null  object
#  22  in_NHDNetworkStatusCV             206476 non-null  object
#  23  in_NHDProductCV                   206476 non-null  object
#  24  in_PODorPOUSite                   206476 non-null  object
#  25  in_SiteName                       206476 non-null  object
#  26  in_SiteNativeID                   206476 non-null  object
#  27  in_SitePoint                      206476 non-null  object
#  28  in_SiteTypeCV                     206476 non-null  object
#  29  in_StateCV                        206476 non-null  object
#  30  in_USGSSiteID                     206476 non-null  object
#  31  in_Amount                         206476 non-null  object
#  32  in_AllocationCropDutyAmount       206476 non-null  object
#  33  in_AssociatedNativeAllocationIDs  206476 non-null  object
#  34  in_BeneficialUseCategory          206476 non-null  object
#  35  in_CommunityWaterSupplySystem     206476 non-null  object
#  36  in_CropTypeCV                     206476 non-null  object
#  37  in_CustomerTypeCV                 206476 non-null  object
#  38  in_DataPublicationDate            206476 non-null  object
#  39  in_DataPublicationDOI             206476 non-null  object
#  40  in_IrrigatedAcreage               206476 non-null  object
#  41  in_IrrigationMethodCV             206476 non-null  object
#  42  in_PopulationServed               206476 non-null  object
#  43  in_PowerGeneratedGWh              206476 non-null  object
#  44  in_PowerType                      206476 non-null  object
#  45  in_PrimaryUseCategory             206476 non-null  object
#  46  in_ReportYearCV                   206476 non-null  object
#  47  in_SDWISIdentifier                206476 non-null  object
#  48  in_TimeframeEnd                   206476 non-null  datetime64[ns]
#  49  in_TimeframeStart                 206476 non-null  datetime64[ns]
#  50  in_VariableSpecificCV             206476 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(48)
# memory usage: 80.3+ MB

# %%
outdf
# Out:
#         WaDEUUID in_MethodUUID in_MethodTypeCV in_VariableSpecificUUID  \
# 0           in10     UTssps_M1      WaDE Blank
# 1           in11     UTssps_M1      WaDE Blank
# 2           in12     UTssps_M1      WaDE Blank
# 3           in13     UTssps_M1      WaDE Blank
# 4           in14     UTssps_M1      WaDE Blank
# ...          ...           ...             ...                     ...
# 206471  in222509     UTssps_M5         Metered
# 206472  in222510     UTssps_M5         Metered
# 206473  in222511     UTssps_M5         Metered
# 206474  in222512     UTssps_M5         Metered
# 206475  in222513     UTssps_M5         Metered
#
#        in_AggregationIntervalUnitCV    in_VariableCV in_OrganizationUUID  \
# 0                           Monthly       Withdrawal           UTssps_O1
# 1                           Monthly       Withdrawal           UTssps_O1
# 2                           Monthly       Withdrawal           UTssps_O1
# 3                           Monthly       Withdrawal           UTssps_O1
# 4                           Monthly       Withdrawal           UTssps_O1
# ...                             ...              ...                 ...
# 206471                       Annual  Consumptive Use           UTssps_O1
# 206472                       Annual  Consumptive Use           UTssps_O1
# 206473                       Annual  Consumptive Use           UTssps_O1
# 206474                       Annual  Consumptive Use           UTssps_O1
# 206475                       Annual  Consumptive Use           UTssps_O1
#
#        in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0                                                            Fresh
# 1                                                            Fresh
# 2                                                            Fresh
# 3                                                            Fresh
# 4                                                            Fresh
# ...            ...                  ...                        ...
# 206471                                                       Fresh
# 206472                                                       Fresh
# 206473                                                       Fresh
# 206474                                                       Fresh
# 206475                                                       Fresh
#
#        in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0              Wade Blank                wadeId1        Surface Water
# 1              Wade Blank                wadeId2          Groundwater
# 2              Wade Blank                wadeId2          Groundwater
# 3              Wade Blank                wadeId2          Groundwater
# 4              Wade Blank                wadeId2          Groundwater
# ...                   ...                    ...                  ...
# 206471         Wade Blank                wadeId3           WaDE Blank
# 206472         Wade Blank                wadeId3           WaDE Blank
# 206473         Wade Blank                wadeId3           WaDE Blank
# 206474         Wade Blank                wadeId3           WaDE Blank
# 206475         Wade Blank                wadeId3           WaDE Blank
#
#        in_CoordinateAccuracy in_CoordinateMethodCV   in_County  in_EPSGCodeCV  \
# 0                 WaDE Blank            WaDE Blank  Washington           4326
# 1                 WaDE Blank            WaDE Blank  Washington           4326
# 2                 WaDE Blank            WaDE Blank  Washington           4326
# 3                 WaDE Blank            WaDE Blank       Weber           4326
# 4                 WaDE Blank            WaDE Blank     Millard           4326
# ...                      ...                   ...         ...            ...
# 206471            WaDE Blank            WaDE Blank    Garfield           4326
# 206472            WaDE Blank            WaDE Blank  Washington           4326
# 206473            WaDE Blank            WaDE Blank    Garfield           4326
# 206474            WaDE Blank            WaDE Blank  Washington           4326
# 206475            WaDE Blank            WaDE Blank    Garfield           4326
#
#        in_GNISCodeCV in_HUC12 in_HUC8 in_Latitude in_Longitude  \
# 0                                        37.30895   -113.42877
# 1                                        37.26708   -113.36336
# 2                                        37.26668   -113.36341
# 3                                        41.16996   -112.00563
# 4                                        38.96439   -112.38104
# ...              ...      ...     ...         ...          ...
# 206471
# 206472
# 206473
# 206474
# 206475
#
#        in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0                                                        POD
# 1                                                        POD
# 2                                                        POD
# 3                                                        POD
# 4                                                        POD
# ...                      ...             ...             ...
# 206471                                                   POU
# 206472                                                   POU
# 206473                                                   POU
# 206474                                                   POU
# 206475                                                   POU
#
#                                             in_SiteName in_SiteNativeID  \
# 0                                Oak Grove Spring Ws001       d10000001
# 1                                 Leeds Well No 1 Ws002       d10000002
# 2                                  Leeds Well No4 Ws006      d108547239
# 3                             5190S 1050W #1 Well Ws003       d10010001
# 4                                      Fc Well #2 Ws003       d10030001
# ...                                                 ...             ...
# 206471  West Panguitch Irrigation And Reservoir Company          u12016
# 206472                        Virgin Irrigation Company          u12018
# 206473                                 Tropic Town Misc          u12023
# 206474                                Zion Under Canvas          u12024
# 206475                        Under Canvas Bryce Canyon          u12026
#
#        in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID in_Amount  \
# 0                          Spring         UT
# 1                            Well         UT
# 2                            Well         UT
# 3                            Well         UT
# 4                            Well         UT
# ...             ...           ...        ...           ...       ...
# 206471                  Secondary         UT
# 206472                  Secondary         UT
# 206473                   Mgt Plan         UT
# 206474                     Public         UT
# 206475                     Public         UT
#
#        in_AllocationCropDutyAmount in_AssociatedNativeAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...                              ...
# 206471
# 206472
# 206473
# 206474
# 206475
#
#        in_BeneficialUseCategory  \
# 0                Water Supplier
# 1                Water Supplier
# 2                Water Supplier
# 3                Water Supplier
# 4                Water Supplier
# ...                         ...
# 206471            Institutional
# 206472            Institutional
# 206473            Institutional
# 206474            Institutional
# 206475            Institutional
#
#                           in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0                Leeds Domestic Water Users Association
# 1                Leeds Domestic Water Users Association
# 2                Leeds Domestic Water Users Association
# 3                                        Riverdale City
# 4                       Fillmore Municipal Water System
# ...                                                 ...           ...
# 206471  West Panguitch Irrigation and Reservoir Company
# 206472                        Virgin Irrigation Company
# 206473                                 Tropic Town Misc
# 206474                                Zion Under Canvas
# 206475                        Under Canvas Bryce Canyon
#
#        in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                    ...                   ...
# 206471
# 206472
# 206473
# 206474
# 206475
#
#        in_IrrigatedAcreage in_IrrigationMethodCV in_PopulationServed  \
# 0                                                                  0
# 1                                                                  0
# 2                                                                  0
# 3                                                                  0
# 4                                                                  0
# ...                    ...                   ...                 ...
# 206471                                                             0
# 206472                                                             0
# 206473                                                             0
# 206474                                                             0
# 206475                                                             0
#
#        in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategory  \
# 0                                                Public Supply
# 1                                                Public Supply
# 2                                                Public Supply
# 3                                                Public Supply
# 4                                                Public Supply
# ...                     ...          ...                   ...
# 206471                                    Municipal Irrigation
# 206472                                    Municipal Irrigation
# 206473                                    Municipal Irrigation
# 206474                                    Municipal Irrigation
# 206475                                    Municipal Irrigation
#
#        in_ReportYearCV in_SDWISIdentifier in_TimeframeEnd in_TimeframeStart  \
# 0                    0                         2000-01-31        2000-01-01
# 1                    0                         2000-01-31        2000-01-01
# 2                    0                         2000-01-31        2000-01-01
# 3                    0                         2000-01-31        2000-01-01
# 4                    0                         2000-01-31        2000-01-01
# ...                ...                ...             ...               ...
# 206471            2023                         2023-12-31        2023-01-01
# 206472            2023                         2023-12-31        2023-01-01
# 206473            2023                         2023-12-31        2023-01-01
# 206474            2023                         2023-12-31        2023-01-01
# 206475            2023                         2023-12-31        2023-01-01
#
#                                     in_VariableSpecificCV
# 0          Withdrawal_Monthly_Public Supply_Surface Water
# 1            Withdrawal_Monthly_Public Supply_Groundwater
# 2            Withdrawal_Monthly_Public Supply_Groundwater
# 3            Withdrawal_Monthly_Public Supply_Groundwater
# 4            Withdrawal_Monthly_Public Supply_Groundwater
# ...                                                   ...
# 206471  Consumptive Use_Annual_Municipal Irrigation_Wa...
# 206472  Consumptive Use_Annual_Municipal Irrigation_Wa...
# 206473  Consumptive Use_Annual_Municipal Irrigation_Wa...
# 206474  Consumptive Use_Annual_Municipal Irrigation_Wa...
# 206475  Consumptive Use_Annual_Municipal Irrigation_Wa...
#
# [206476 rows x 51 columns]

# %%
# Export the output dataframe
outdf.to_csv('RawInputData/Pssps_Main.zip', compression=dict(method='zip', archive_name='Pssps_Main.csv'), index=False)  # The output, save as a zip
dfPoUshape.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
