# %% [markdown]
# # Preprocessing Utah Reservoir and Gage data for WaDE

# %%
# Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/Utah/SS_ReservoirsObservationSites/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## Data: "Distribution Stations" site data

# %%
fileInput = "Distribution_Stations.csv"
dfds = pd.read_csv(fileInput)
print(len(dfds))
dfds.head()
# Out:
# 1657
#    OID_  STATION_ID        SYSTEM                    NAME   Latitude  \
# 0     1      9949.0  ASHLEY CREEK  ASHLEY TWINS RESERVOIR  40.726466
# 1     2      3133.0  ASHLEY CREEK           CENTRAL CANAL  40.491609
# 2     3      3130.0  ASHLEY CREEK            COLTON DITCH  40.484401
# 3     4      9946.0  ASHLEY CREEK              DEEP CREEK  40.790203
# 4     5      3136.0  ASHLEY CREEK             DODDS DITCH  40.491666
#
#     Longitude       X_UTM        Y_UTM
# 0 -109.800949  601259.825  4509083.604
# 1 -109.585557  619869.012  4483283.467
# 2 -109.598781  618761.000  4482465.461
# 3 -109.760110  604608.802  4516206.801
# 4 -109.585061  619911.012  4483290.467

# %% [markdown]
# ## Data: get timeseries data via API service per site

# %%
# %%time

# Get list of STATION_ID
stationIDList = dfds['STATION_ID'].astype(int).astype(str).tolist()   

# issue with SSL verification for this data. Use this to ignore
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# create empty url dataframe for timeseries data
dfurl = pd.DataFrame()

slength = len(stationIDList)
for i in range(slength):
    fileInputURL = "https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=1900&EYEAR=2023&StationId=" + str(stationIDList[i])
    print(fileInputURL)
    try:
        # get metadata
        dfmetadata = pd.read_csv(fileInputURL, nrows=5) # read in file
        dfmetadata_T = dfmetadata.transpose() # tranpose the dataframe
        new_header = dfmetadata_T.iloc[0] #grab the first row for the header
        dfmetadata_T = dfmetadata_T[1:] #take the data less the header row
        dfmetadata_T.columns = new_header #set the header row as the df header
        unitsString = dfmetadata_T['Units'].astype(str).to_string() # convert value to string
        
        # get timeseries
        dftemp = pd.read_csv(fileInputURL, skiprows=5)
        dftemp['Units'] = unitsString
        dftemp['timeseriesID'] =  str(stationIDList[i])
        dftemp['url'] = fileInputURL
        dfurl = pd.concat([dfurl, dftemp])
    except:
        dftemp = pd.DataFrame()
        dftemp['Units'] = ""
        dftemp['timeseriesID'] =  str(stationIDList[i])
        dftemp['url'] = fileInputURL
        dfurl = pd.concat([dfurl, dftemp])
        print("Error, issue with API return.")

        
dfurl.to_csv('url_timeseries.zip', compression=dict(method='zip', archive_name='url_timeseries.csv'), index=False)
print(len(dfurl))
dfurl.head(1)
# Out:
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9949
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3133
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3130
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9946
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3136
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3134
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3128
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3132
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9526
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9174
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9948
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9746
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9525
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3131
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3135
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3127
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9524
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3129
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10496
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10497
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9295
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9296
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2605
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2604
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2612
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2532
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2613
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2614
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9815
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2603
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9754
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2608
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9297
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2598
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9730
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9300
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9301
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2616
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2602
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2609
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2627
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2593
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2618
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2619
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3901
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2651
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2606
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2610
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2601
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3907
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9561
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9562
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9518
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9563
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9564
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9565
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9566
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9519
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9424
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9847
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9846
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9848
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9849
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4342
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4338
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9921
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10440
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10441
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10442
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10443
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10446
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10447
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10448
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10449
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10450
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10451
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10452
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10453
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10456
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10457
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4646
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4946
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4647
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4980
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4643
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10317
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8962
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4648
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9624
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3037
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9198
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9197
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9230
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3033
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3047
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3022
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3969
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9226
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3029
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3055
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9209
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3054
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9227
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8436
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4782
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9235
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3031
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3051
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3024
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3023
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9203
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9207
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9211
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9678
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9539
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9538
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9449
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9533
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9541
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9536
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9540
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9733
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9537
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9762
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9201
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9232
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9233
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9236
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3028
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9225
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9204
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4200
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8951
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3041
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9229
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3050
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3049
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9650
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9683
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9527
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9682
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9684
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9688
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9528
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9685
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9687
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9692
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9696
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9697
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9698
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9699
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9700
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9701
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9702
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9745
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9530
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9703
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9704
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9705
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9706
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9707
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9708
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9709
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9625
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9630
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9744
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9715
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9713
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9714
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9637
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9717
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3265
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3155
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3193
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9593
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3233
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3192
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3195
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3189
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3264
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3186
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9592
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10182
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9531
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=530
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9342
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9346
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2990
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8481
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8482
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1541
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=509
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8483
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3065
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=6059
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1614
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2872
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8484
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1616
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1615
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3062
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2513
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9355
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8486
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9356
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9374
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=510
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9835
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9836
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8489
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8490
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=512
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1551
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1556
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3346
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8492
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8493
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3025
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=513
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8494
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3026
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2137
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8495
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=515
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2501
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=516
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9311
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=525
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=528
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1567
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=529
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=555
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8496
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2519
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9337
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9339
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9343
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9404
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1575
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1547
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2909
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8491
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1552
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1554
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1570
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1534
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8963
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4159
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1572
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1571
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3991
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3897
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=551
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1561
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1569
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8472
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3837
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3308
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9603
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9602
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4492
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3256
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4494
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10055
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3870
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4955
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4641
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4493
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3914
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3830
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9604
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3269
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9504
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8511
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8509
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9814
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9616
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9615
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9629
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9614
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9617
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9634
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10118
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9435
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9437
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9434
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9432
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9436
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9433
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9582
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9583
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9585
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9580
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9584
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9590
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9591
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9618
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9586
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9612
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9581
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10328
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9588
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9587
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9579
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10501
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10537
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10481
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10498
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10499
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10483
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10477
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10480
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10479
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10478
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10502
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10500
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10464
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10473
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10475
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10467
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9928
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9943
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9933
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9934
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10489
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9932
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10474
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9937
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9938
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9942
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9936
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10470
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9944
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9930
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10468
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10469
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9925
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9929
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9935
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9941
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10476
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9931
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9926
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10471
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10472
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10466
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9927
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10463
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10465
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10462
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10482
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2991
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2994
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2995
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9237
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9181
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2993
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=3061
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2782
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2784
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2786
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2779
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8197
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2771
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9175
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10516
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10311
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2772
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2776
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9738
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2783
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2781
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9743
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9742
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2778
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2774
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10287
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2785
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2770
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2775
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2777
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8455
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8452
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4798
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9176
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8457
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4795
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8453
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4797
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8451
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9304
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9335
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9328
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4800
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4801
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4806
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9327
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=4802
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9326
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8456
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=56
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=21
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9644
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9840
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10324
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=26
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=17
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=15
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=58
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=27
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=28
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=48
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=49
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=50
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=51
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=52
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=19
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=54
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=18
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=24
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=25
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=53
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=23
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=20
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=22
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9645
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=16
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1689
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1690
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1691
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1692
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1693
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1709
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1695
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1696
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1697
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9305
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1698
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1699
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1700
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1701
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1702
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1703
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1704
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1705
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1706
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9308
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1707
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1710
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1711
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9306
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1712
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1713
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9307
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1714
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9313
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1715
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1716
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1717
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1719
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1720
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1721
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1722
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=181
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1723
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1724
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9218
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1725
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1726
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1727
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1728
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1729
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1733
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1732
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1734
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1735
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9310
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1736
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1543
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1737
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2631
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1739
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1740
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1741
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1742
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1743
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1744
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1745
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1763
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1746
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1747
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=9416
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1748
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1752
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1751
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1749
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1750
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1753
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1624
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=1754
# ...
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8795
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8796
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8797
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8799
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8800
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8801
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8802
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8803
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8804
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8805
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8806
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8807
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8808
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8809
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8810
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8811
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8812
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8813
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8814
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8815
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8816
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8817
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8818
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8819
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8820
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8821
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8822
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8823
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8824
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8825
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8826
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8827
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8828
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8829
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8830
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8831
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8833
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8834
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8836
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8837
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8838
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8839
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8840
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8841
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8842
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8843
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8844
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8845
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8846
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8847
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8848
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8849
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8850
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8852
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8853
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8854
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8855
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8856
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8857
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8859
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8860
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8861
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8862
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8913
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8914
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8915
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8917
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8918
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8919
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8920
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8930
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8931
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8932
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8933
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8934
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8935
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8936
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8938
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8939
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8940
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8863
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8864
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8865
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8866
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8867
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8868
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8869
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8870
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8871
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8872
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8873
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8874
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8875
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8876
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8877
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8878
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8879
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8880
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8881
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8882
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8883
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8884
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8885
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8886
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8887
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8888
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8889
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8890
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8891
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8892
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8893
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8894
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8895
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8896
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8897
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8898
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8899
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8900
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8901
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8902
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8903
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8904
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8905
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8906
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8907
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8908
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8909
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8910
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8911
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8912
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8602
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=409
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=411
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=457
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=282
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=142
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=274
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=273
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=440
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=439
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=449
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=292
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8478
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8062
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=452
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=6064
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8085
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=450
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=445
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=144
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2552
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=2551
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=10419
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=254
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=276
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=455
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=459
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=438
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=6017
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=421
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=280
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=279
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8858
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=2000&EYEAR=2023&StationId=8629
# 3641751
# Wall time: 18min 1s
#   DateEnd  2023 timeseriesID  \
# 0    Date  Flow         9949
#
#                                                  url
# 0  https://www.waterrights.utah.gov/dvrtdb/DailyC...

# %%
# %%time
stationIDList = "3130"
url = "https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=1900&EYEAR=2023&StationId=" + str(stationIDList)
print(url)

dfmetadata = pd.read_csv(url, nrows=5) # read in file
dfmetadata_T = dfmetadata.transpose()
new_header = dfmetadata_T.iloc[0] #grab the first row for the header
dfmetadata_T = dfmetadata_T[1:] #take the data less the header row
dfmetadata_T.columns = new_header #set the header row as the df header
dfmetadata_T = dfmetadata_T.reset_index(drop=True)
unitsString = dfmetadata_T['Units'].astype(str).to_string()

dfapi = pd.read_csv(url, on_bad_lines='skip', skiprows=5) # read in file
dfapi['stationID'] = str(stationIDList)
dfapi['url'] = url
dfapi['Units'] = unitsString
print(len(dfapi))
dfapi
# Out:
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=1900&EYEAR=2023&StationId=3130
# 8924
# Wall time: 1.91 s
#             Date  Flow stationID  \
# 0     05/01/1965   0.0      3130
# 1     05/02/1965   0.0      3130
# 2     05/03/1965   0.0      3130
# 3     05/04/1965   0.0      3130
# 4     05/05/1965   0.0      3130
# ...          ...   ...       ...
# 8919  06/26/2019   4.0      3130
# 8920  06/27/2019   4.0      3130
# 8921  06/28/2019   4.0      3130
# 8922  06/29/2019   6.0      3130
# 8923  06/30/2019   6.0      3130
#
#                                                     url  \
# 0     https://www.waterrights.utah.gov/dvrtdb/DailyC...
# 1     https://www.waterrights.utah.gov/dvrtdb/DailyC...
# 2     https://www.waterrights.utah.gov/dvrtdb/DailyC...
# 3     https://www.waterrights.utah.gov/dvrtdb/DailyC...
# 4     https://www.waterrights.utah.gov/dvrtdb/DailyC...
# ...                                                 ...
# 8919  https://www.waterrights.utah.gov/dvrtdb/DailyC...
# 8920  https://www.waterrights.utah.gov/dvrtdb/DailyC...
# 8921  https://www.waterrights.utah.gov/dvrtdb/DailyC...
# 8922  https://www.waterrights.utah.gov/dvrtdb/DailyC...
# 8923  https://www.waterrights.utah.gov/dvrtdb/DailyC...
#
#                                  Units
# 0     0    Mean daily discharge in CFS
# 1     0    Mean daily discharge in CFS
# 2     0    Mean daily discharge in CFS
# 3     0    Mean daily discharge in CFS
# 4     0    Mean daily discharge in CFS
# ...                                ...
# 8919  0    Mean daily discharge in CFS
# 8920  0    Mean daily discharge in CFS
# 8921  0    Mean daily discharge in CFS
# 8922  0    Mean daily discharge in CFS
# 8923  0    Mean daily discharge in CFS
#
# [8924 rows x 5 columns]

# %%
type(unitsString)
# Out:
# pandas.core.series.Series

# %%
dfmetadata_T
# Out:
# SystemName    StationName                        Units DateStart DateEnd  Date
# 0           CENTRAL CANAL  Mean daily discharge in CFS      1900    2023  Flow

# %%
# %%time
stationIDList = "3133"
url = "https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=1900&EYEAR=2023&StationId=" + str(stationIDList)
print(url)
dfmetadata = pd.read_csv(url, nrows=5) # read in file
dfmetadata_T = dfmetadata.transpose()
new_header = dfmetadata_T.iloc[0] #grab the first row for the header
dfmetadata_T = dfmetadata_T[1:] #take the data less the header row
dfmetadata_T.columns = new_header #set the header row as the df header

print(len(dfmetadata_T))
dfmetadata_T
# Out:
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=1900&EYEAR=2023&StationId=3133
# 1
# Wall time: 979 ms
# SystemName      StationName                        Units DateStart DateEnd  \
# ASHLEY CREEK  CENTRAL CANAL  Mean daily discharge in CFS      1900    2023
#
# SystemName    Date
# ASHLEY CREEK  Flow

# %%
# %%time
stationIDList = "3133"
url = "https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=1900&EYEAR=2023&StationId=" + str(stationIDList)
print(url)
dfmetadata = pd.read_csv(url, nrows=5) # read in file
dfmetadata_T = dfmetadata.transpose()
new_header = dfmetadata_T.iloc[0] #grab the first row for the header
dfmetadata_T = dfmetadata_T[1:] #take the data less the header row
dfmetadata_T.columns = new_header #set the header row as the df header
unitsString = dfmetadata_T['Units'].astype(str).to_string()

print(type(unitsString))
unitsString
# Out:
# https://www.waterrights.utah.gov/dvrtdb/DailyCommaData.asp?BYEAR=1900&EYEAR=2023&StationId=3133
# <class 'str'>
# Wall time: 1.1 s
# 'ASHLEY CREEK    Mean daily discharge in CFS'

# %% [markdown]
# ## Data: Total Lake Reservoir Storage Volume

# %%
df1a = pd.read_csv("total_lake_reservoir_storage_volume/data set label.csv")
df2a = pd.read_csv("total_lake_reservoir_storage_volume/location identifier.csv")
df3a = pd.read_csv("total_lake_reservoir_storage_volume/location name.csv")
df4a = pd.read_csv("total_lake_reservoir_storage_volume/location type.csv")
df5a = pd.read_csv("total_lake_reservoir_storage_volume/latitude.csv")
df6a = pd.read_csv("total_lake_reservoir_storage_volume/longitude.csv")

df1a = df1a.rename({'Value': 'data set label'}, axis=1)
df1a = df1a.merge(df2a[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'location identifier'}, axis=1)
df1a = df1a.merge(df3a[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'location name'}, axis=1)
df1a = df1a.merge(df4a[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'location type'}, axis=1)
df1a = df1a.merge(df5a[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'latitude'}, axis=1)
df1a = df1a.merge(df6a[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'longitude'}, axis=1)

dftlrsv_site = df1a.copy()
print(len(dftlrsv_site))
dftlrsv_site.head(3)

# %%
# %%time

# datasetidList = dftlrsv_site['Data Set Id'].astype(str).str.replace(" ", "%20").str.replace("@", "%40").tolist()  

# # issue with SSL verification for this data. Use this to ignore
# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context

# # create empty url dataframe for timeseries data
# dftlrsv_timeseries = pd.DataFrame()

# slength = len(datasetidList)
# for i in range(slength):
#     fileInputURL = "https://seoflow.wyo.gov/Export/BulkExport?DateRange=EntirePeriodOfRecord&TimeZone=0&Calendar=CALENDARYEAR&Interval=Daily&Step=1&ExportFormat=csv&TimeAligned=True&RoundData=False&IncludeGradeCodes=False&IncludeApprovalLevels=False&IncludeQualifiers=undefined&IncludeInterpolationTypes=False&Datasets[0].Calculation=Aggregate&Datasets[0].UnitId=198&_=1679336048953&Datasets[0].DatasetName=" + str(datasetidList[i])
#     print(fileInputURL)
#     try:
#         dftemp = pd.read_csv(fileInputURL, skiprows=4)
#         dftemp['timeseriesID'] =  str(datasetidList[i])
#         dftemp['url'] = fileInputURL
#         dftlrsv_timeseries = pd.concat([dftlrsv_timeseries, dftemp])
#     except:
#         dftemp = pd.DataFrame()
#         dftemp['timeseriesID'] =  str(datasetidList[i])
#         dftemp['url'] = fileInputURL
#         dftlrsv_timeseries = pd.concat([dftlrsv_timeseries, dftemp])
#         print("Error, issue with API return.")

        
# dftlrsv_timeseries.to_csv('total_lake_reservoir_storage_volume/tlrsv_timeseries.zip', compression=dict(method='zip', archive_name='tlrsv_timeseries.csv'), index=False)
# print(len(dftlrsv_timeseries))
# dftlrsv_timeseries.head(1)

# %%
# Input File - dataframeTimeSeries.zip
dftlrsv_timeseries = pd.read_csv('total_lake_reservoir_storage_volume/tlrsv_timeseries.zip', compression='zip')

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dftlrsv_timeseries:
    dftlrsv_timeseries['WaDEUUID'] = "tx_tlrsv" + dftlrsv_timeseries.index.astype(str)
    dftlrsv_timeseries.to_csv('total_lake_reservoir_storage_volume/tlrsv_timeseries.zip', compression=dict(method='zip', archive_name='tlrsv_timeseries.csv'), index=False)

dftlrsv_timeseries['timeseriesID'] = dftlrsv_timeseries['timeseriesID'].astype(str).str.replace("%20", " ").str.replace("%40", "@")

print(len(dftlrsv_timeseries))
dftlrsv_timeseries.head(1)

# %%
dftlrsv = pd.merge(dftlrsv_timeseries, dftlrsv_site, left_on='timeseriesID', right_on='Data Set Id', how='left')
print(len(dftlrsv))
dftlrsv.head(2)

# %%
# WaDE Fields

# output dataframe
df1 = pd.DataFrame(index=dftlrsv.index)

# data assessment
df1['WaDEUUID'] = dftlrsv['WaDEUUID']

# variable info
df1['in_VariableCV'] = dftlrsv['WaDE Interpretation']

# water source info
df1['in_WaterSourceName'] = "WaDE Unspecified"
df1['in_WaterSourceNativeID'] = "WaDEID_WYws1"
df1['in_WaterSourceTypeCV'] = "Surface Water"

# Site Info
df1['in_CoordinateAccuracy'] = "WaDE Unspecified"
df1['in_CoordinateMethodCV'] = "WaDE Unspecified"
df1['in_County'] = "WaDE Unspecified"
df1['in_HUC12'] = "WaDE Unspecified"
df1['in_HUC8'] = "WaDE Unspecified"
df1['in_Latitude'] = dftlrsv['latitude']
df1['in_Longitude'] = dftlrsv['longitude']
df1['in_PODorPOUSite'] = "Reservoir"
df1['in_SiteNativeID'] =dftlrsv['location identifier']
df1['in_SiteName'] = dftlrsv['location name']
df1['in_SiteTypeCV'] = "Reservoir/Lake"
df1['in_StateCV'] = 'WY'

# Site VariableAmounts Info
df1['in_Amount'] = dftlrsv['Average (Acre-ft)'] # change here
df1['in_BeneficialUseCategory'] = "Storage"
df1['in_ReportYearCV'] = "" # will fill in below
df1['in_TimeframeEnd'] = dftlrsv['End of Interval (UTC)']
df1['in_TimeframeStart'] = dftlrsv['Start of Interval (UTC)']

df1 = df1.drop_duplicates().reset_index(drop=True)

print(len(df1))
df1.head(1)

# %% [markdown]
# ## Data: Discharge

# %%
df1b = pd.read_csv("discharge/data set label.csv")
df2b = pd.read_csv("discharge/location identifier.csv")
df3b = pd.read_csv("discharge/location name.csv")
df4b = pd.read_csv("discharge/location type.csv")
df5b = pd.read_csv("discharge/latitude.csv")
df6b = pd.read_csv("discharge/longitude.csv")

df1b = df1b.rename({'Value': 'data set label'}, axis=1)
df1b = df1b.merge(df2b[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'location identifier'}, axis=1)
df1b = df1b.merge(df3b[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'location name'}, axis=1)
df1b = df1b.merge(df4b[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'location type'}, axis=1)
df1b = df1b.merge(df5b[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'latitude'}, axis=1)
df1b = df1b.merge(df6b[['Data Set Id', 'Value']], on='Data Set Id', how='left').rename({'Value': 'longitude'}, axis=1)

dfdis_site = df1b.copy()
print(len(dfdis_site))
dfdis_site.head(3)

# %%
# %%time

# datasetidList = dfdis_site['Data Set Id'].astype(str).str.replace(" ", "%20").str.replace("@", "%40").tolist()  

# # issue with SSL verification for this data. Use this to ignore
# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context

# # create empty url dataframe for timeseries data
# dfdis_timeseries = pd.DataFrame()

# slength = len(datasetidList)
# for i in range(slength):
#     fileInputURL = "https://seoflow.wyo.gov/Export/BulkExport?DateRange=EntirePeriodOfRecord&TimeZone=0&Calendar=CALENDARYEAR&Interval=Daily&Step=1&ExportFormat=csv&TimeAligned=True&RoundData=False&IncludeGradeCodes=False&IncludeApprovalLevels=False&IncludeQualifiers=undefined&IncludeInterpolationTypes=False&Datasets[0].Calculation=Instantaneous&Datasets[0].UnitId=208&_=1679418181067&Datasets[0].DatasetName=" + str(datasetidList[i])
#     print(fileInputURL)
#     try:
#         dftemp = pd.read_csv(fileInputURL, skiprows=4)
#         dftemp['timeseriesID'] =  str(datasetidList[i])
#         dftemp['url'] = fileInputURL
#         dfdis_timeseries = pd.concat([dfdis_timeseries, dftemp])
#     except:
#         dftemp = pd.DataFrame()
#         dftemp['timeseriesID'] =  str(datasetidList[i])
#         dftemp['url'] = fileInputURL
#         dfdis_timeseries = pd.concat([dfdis_timeseries, dftemp])
#         print("Error, issue with API return.")

        
# dfdis_timeseries.to_csv('discharge/dis_timeseries.zip', compression=dict(method='zip', archive_name='dis_timeseries.csv'), index=False)
# print(len(dfdis_timeseries))
# dfdis_timeseries.head(1)

# %%
# Input File - dataframeTimeSeries.zip
dfdis_timeseries = pd.read_csv('discharge/dis_timeseries.zip', compression='zip')

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfdis_timeseries:
    dfdis_timeseries['WaDEUUID'] = "tx_dis" + dfdis_timeseries.index.astype(str)
    dfdis_timeseries.to_csv('discharge/dis_timeseries.zip', compression=dict(method='zip', archive_name='dis_timeseries.csv'), index=False)

dfdis_timeseries['timeseriesID'] = dfdis_timeseries['timeseriesID'].astype(str).str.replace("%20", " ").str.replace("%40", "@")

print(len(dfdis_timeseries))
dfdis_timeseries.head(1)

# %%
dfdis = pd.merge(dfdis_timeseries, dfdis_site, left_on='timeseriesID', right_on='Data Set Id', how='left')
print(len(dfdis))
dfdis.head(2)

# %%
# WaDE Fields

# output dataframe
df2 = pd.DataFrame(index=dfdis.index)

# data assessment
df2['WaDEUUID'] = dfdis['WaDEUUID']

# variable info
df2['in_VariableCV'] = dfdis['WaDE Interpretation']

# water source info
df2['in_WaterSourceName'] = "WaDE Unspecified"
df2['in_WaterSourceNativeID'] = "WaDEID_WYws1"
df2['in_WaterSourceTypeCV'] = "Surface Water"

# Site Info
df2['in_CoordinateAccuracy'] = "WaDE Unspecified"
df2['in_CoordinateMethodCV'] = "WaDE Unspecified"
df2['in_County'] = "WaDE Unspecified"
df2['in_HUC12'] = "WaDE Unspecified"
df2['in_HUC8'] = "WaDE Unspecified"
df2['in_Latitude'] = dfdis['latitude']
df2['in_Longitude'] = dfdis['longitude']
df2['in_PODorPOUSite'] = "Stream Gage"
df2['in_SiteNativeID'] =dfdis['location identifier']
df2['in_SiteName'] = dfdis['location name']
df2['in_SiteTypeCV'] = "Hydrology Station"
df2['in_StateCV'] = 'WY'

# Site VariableAmounts Info
df2['in_Amount'] = dfdis['Value at End of Interval (ft^3/s)'] # change here
df2['in_BeneficialUseCategory'] = "Discharge"
df2['in_ReportYearCV'] = "" # will fill in below
df2['in_TimeframeEnd'] = dfdis['End of Interval (UTC)']
df2['in_TimeframeStart'] = dfdis['Start of Interval (UTC)']

df2 = df2.drop_duplicates().reset_index(drop=True)

print(len(df2))
df2.head(1)

# %% [markdown]
# ## Concatenate Together. Output Dataframe.

# %%
# Concatenate Produced Data Together
frames = [df1, df2]
dfout = pd.concat(frames).reset_index(drop=True)
print(len(dfout))

# %%
dfout.info()

# %% [markdown]
# ## Fixing a few errors

# %%
 # Create VariableSpecificCV field

dfout['in_VariableSpecificCV'] = dfout['in_VariableCV'].astype(str) + "_Daily_" + dfout['in_BeneficialUseCategory'].astype(str) + "_" + dfout['in_WaterSourceTypeCV'].astype(str)
dfout['in_VariableSpecificCV'].unique()

# %%
# Converting data from string to datetime64[ns]
# extracting year component of datetime64[ns]
dfout['in_TimeframeEnd'] = pd.to_datetime(dfout['in_TimeframeEnd'])
dfout['in_TimeframeStart'] = pd.to_datetime(dfout['in_TimeframeStart'])
dfout['in_ReportYearCV'] = dfout['in_TimeframeStart'].dt.to_period('Y')
dfout.head(1)

# %%
# in_Latitude 
dfout['in_Latitude'] = pd.to_numeric(dfout['in_Latitude'], errors='coerce').fillna(0)
dfout['in_Latitude'].unique()

# %%
# in_Longitude
dfout['in_Longitude'] = pd.to_numeric(dfout['in_Longitude'], errors='coerce').fillna(0)
dfout['in_Longitude'].unique()

# %%
# Fixing Water Amount datatype
dfout['in_Amount'] = pd.to_numeric(dfout['in_Amount'], errors='coerce').fillna(0)
dfout.head(1)

# %% [markdown]
# ## Review and Export

# %%
dfout.info()

# %%
#Exporting to Finished File
dfout.to_csv('P_wySSROMain.zip', index=False, compression="zip")  # The output, save as a zip
