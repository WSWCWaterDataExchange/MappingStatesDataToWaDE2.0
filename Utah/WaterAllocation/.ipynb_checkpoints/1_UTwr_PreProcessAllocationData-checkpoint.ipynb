# %% [markdown]
# # Pre-processing Utah Allocation data for WaDE upload.
# - Purpose:  To pre-process the Utah data into one master file for simple DataFrame creation and extraction

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Utah/WaterAllocation" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Utah/WaterAllocation

# %% [markdown]
# ## Point of Diversion Data

# %%
# Input File
FI_PoD = "RawInputData/Utah_Points_of_Diversion.zip"
dfinPOD = pd.read_csv(FI_PoD, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "utD" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('RawInputData/Utah_Points_of_Diversion.zip', compression=dict(method='zip', archive_name='Utah_Points_of_Diversion.csv'), index=False)

print(len(dfinPOD))
dfinPOD.head()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_19788\3212114136.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfinPOD = pd.read_csv(FI_PoD, encoding = "ISO-8859-1").replace(np.nan, "")
# 382049
#   WaDEUUID                                      ReasonRemoved IncompleteField  \
# 0     utD0
# 1     utD1  Incomplete or bad entry for AllocationPriority...
# 2    utD10  Incomplete or bad entry for AllocationPriority...
# 3   utD100
# 4  utD1000  Incomplete or bad entry for AllocationPriority...
#
#    Ã¯Â»Â¿OID_   OBJECTID       WRNUM CHEXNUM             TYPE SUMMARY_ST  \
# 0           1  864475622     66-1001  t39016   Point to Point          T
# 1           2  864475623  0259005M00              Underground          A
# 2          11  864475632  0259008M00              Underground          A
# 3         101  864475722      18-427              Underground          P
# 4        1001  864476622  0265001P00          Abandonded Well          A
#
#     STATUS  PRIORITY USES     CFS    ACFT                     LOCATION  \
# 0  APPLLAP  20130516    O 0.06100 6.38000    N660 E660 SW 28 14S 1E SL
# 1  APPLAPP                0.00000 0.00000     N616 E379 S4 09 2S 1W SL
# 2  APPLAPP                0.00000 0.00000    S2750 E120 NW 10 2S 1W SL
# 3  APPLWUC  19800721  DIS 0.01500 0.00000  N980 W1550 SE 04 14S 18W SL
# 4  APPLAPP                0.00000 0.00000  N1465 W2085 SE 04 17S 3E SL
#
#    Latitude  Longitude    WIN                                     OWNER  \
# 0  39.56057 -111.83268      0                  LEVAN IRRIGATION COMPANY
# 1  40.65480 -111.95654  25726  TAYLORSVILLE CITY C/O GEO ENGERY SYSTEMS
# 2  40.66009 -111.94791  25924                              FEC DRILLING
# 3  39.61925 -113.87756  21198                            STEPHEN P MUMM
# 4  39.36270 -111.58694  24997                         JEFFERIES VINCENT
#
#                                            SOURCE  \
# 0                                               P
# 1  Non-Production Well: Closed Loop Heat Exchange
# 2                    Non-Production Well: Unknown
# 3                          Underground Water Well
# 4                       Non-Production Well: Test
#
#                                              WebLink
# 0  https://www.waterrights.utah.gov/search/?q=t39016
# 1  https://www.waterrights.utah.gov/search/?q=025...
# 2  https://www.waterrights.utah.gov/search/?q=025...
# 3  https://www.waterrights.utah.gov/search/?q=18-427
# 4  https://www.waterrights.utah.gov/search/?q=026...

# %%
# We don't want to use any CHEXNUM data
dfinPOD['CHEXNUM'] = dfinPOD['CHEXNUM'].str.strip()
dfinPOD = dfinPOD[dfinPOD['CHEXNUM'] == ""].reset_index(drop=True)
print(len(dfinPOD))
dfinPOD.head()
# Out:
# 282359
#    WaDEUUID                                      ReasonRemoved  \
# 0      utD1  Incomplete or bad entry for AllocationPriority...
# 1     utD10  Incomplete or bad entry for AllocationPriority...
# 2    utD100
# 3   utD1000  Incomplete or bad entry for AllocationPriority...
# 4  utD10000
#
#   IncompleteField  Ã¯Â»Â¿OID_   OBJECTID       WRNUM CHEXNUM             TYPE  \
# 0                           2  864475623  0259005M00              Underground
# 1                          11  864475632  0259008M00              Underground
# 2                         101  864475722      18-427              Underground
# 3                        1001  864476622  0265001P00          Abandonded Well
# 4                       10044  864485665     73-1713           Point to Point
#
#   SUMMARY_ST   STATUS  PRIORITY USES     CFS    ACFT  \
# 0          A  APPLAPP                0.00000 0.00000
# 1          A  APPLAPP                0.00000 0.00000
# 2          P  APPLWUC  19800721  DIS 0.01500 0.00000
# 3          A  APPLAPP                0.00000 0.00000
# 4          P      DIL      1856    S 0.00000 0.44800
#
#                       LOCATION  Latitude  Longitude    WIN  \
# 0     N616 E379 S4 09 2S 1W SL  40.65480 -111.95654  25726
# 1    S2750 E120 NW 10 2S 1W SL  40.66009 -111.94791  25924
# 2  N980 W1550 SE 04 14S 18W SL  39.61925 -113.87756  21198
# 3  N1465 W2085 SE 04 17S 3E SL  39.36270 -111.58694  24997
# 4  S660 W1980 E4 29 36S 10W SL  37.63907 -113.00251      0
#
#                                       OWNER  \
# 0  TAYLORSVILLE CITY C/O GEO ENGERY SYSTEMS
# 1                              FEC DRILLING
# 2                            STEPHEN P MUMM
# 3                         JEFFERIES VINCENT
# 4                              SIDEHILL LLC
#
#                                            SOURCE  \
# 0  Non-Production Well: Closed Loop Heat Exchange
# 1                    Non-Production Well: Unknown
# 2                          Underground Water Well
# 3                       Non-Production Well: Test
# 4                        White Rock Spring Stream
#
#                                              WebLink
# 0  https://www.waterrights.utah.gov/search/?q=025...
# 1  https://www.waterrights.utah.gov/search/?q=025...
# 2  https://www.waterrights.utah.gov/search/?q=18-427
# 3  https://www.waterrights.utah.gov/search/?q=026...
# 4  https://www.waterrights.utah.gov/search/?q=73-...

# %%
# For creating BeneficialUseCategory
benUseDict = {
    "I" : "Irrigation",
    "S" : "Stockwatering",
    "D" : "Domestic",
    "M" : "Municipal",
    "X" : "Mining",
    "P" : "Power",
    "O" : "Other"}
def assignBenUseCategory(colrowValue):
    colrowValue = str(colrowValue).strip()
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = ""
    else:
        outList = ",".join(benUseDict[inx] for inx in list(str(colrowValue)))
    return outList


dfinPOD['in_BeneficialUseCategory'] = dfinPOD.apply(lambda row: assignBenUseCategory(row['USES']), axis=1)
dfinPOD['in_BeneficialUseCategory'].unique()
# Out:
# array(['', 'Domestic,Irrigation,Stockwatering', 'Stockwatering',
#        'Domestic,Other', 'Other', 'Irrigation', 'Domestic',
#        'Domestic,Irrigation', 'Irrigation,Stockwatering',
#        'Irrigation,Municipal,Stockwatering', 'Municipal',
#        'Domestic,Stockwatering',
#        'Domestic,Irrigation,Other,Stockwatering', 'Irrigation,Other',
#        'Other,Stockwatering', 'Domestic,Irrigation,Municipal', 'Power',
#        'Irrigation,Other,Stockwatering', 'Municipal,Other',
#        'Domestic,Other,Stockwatering',
#        'Domestic,Irrigation,Municipal,Stockwatering',
#        'Domestic,Irrigation,Other', 'Mining',
#        'Irrigation,Municipal,Other,Stockwatering',
#        'Domestic,Stockwatering,Mining', 'Irrigation,Mining',
#        'Domestic,Mining', 'Stockwatering,Mining',
#        'Domestic,Irrigation,Mining', 'Domestic,Municipal',
#        'Domestic,Irrigation,Other,Power',
#        'Domestic,Irrigation,Municipal,Other,Stockwatering',
#        'Irrigation,Municipal,Other', 'Other,Mining',
#        'Municipal,Stockwatering', 'Other,Power', 'Irrigation,Municipal',
#        'Domestic,Irrigation,Stockwatering,Power', 'Irrigation,Power',
#        'Domestic,Municipal,Other', 'Irrigation,Municipal,Other,Power',
#        'Irrigation,Municipal,Power', 'Irrigation,Stockwatering,Power',
#        'Municipal,Other,Power', 'Irrigation,Other,Stockwatering,Power',
#        'Domestic,Irrigation,Municipal,Other', 'Municipal,Power',
#        'Domestic,Other,Power,Mining', 'Domestic,Other,Power',
#        'Domestic,Municipal,Other,Power', 'Domestic,Power',
#        'Domestic,Irrigation,Municipal,Other,Mining',
#        'Domestic,Irrigation,Municipal,Mining',
#        'Domestic,Irrigation,Municipal,Other,Stockwatering,Power',
#        'Domestic,Other,Mining', 'Domestic,Municipal,Other,Stockwatering',
#        'Irrigation,Other,Power',
#        'Irrigation,Municipal,Other,Stockwatering,Power',
#        'Domestic,Municipal,Stockwatering',
#        'Domestic,Irrigation,Municipal,Stockwatering,Power',
#        'Power,Mining', 'Domestic,Stockwatering,Power',
#        'Irrigation,Municipal,Stockwatering,Power', 'Other,Power,Mining',
#        'Domestic,Irrigation,Stockwatering,Mining',
#        'Domestic,Irrigation,Stockwatering,Power,Mining',
#        'Irrigation,Municipal,Other,Stockwatering,Mining',
#        'Domestic,Irrigation,Municipal,Other,Stockwatering,Power,Mining',
#        'Irrigation,Stockwatering,Mining', 'Other,Stockwatering,Power',
#        'Domestic,Irrigation,Power',
#        'Domestic,Irrigation,Other,Stockwatering,Power,Mining',
#        'Domestic,Other,Stockwatering,Mining', 'Stockwatering,Power',
#        'Domestic,Irrigation,Other,Stockwatering,Power',
#        'Other,Stockwatering,Mining',
#        'Domestic,Municipal,Other,Stockwatering,Mining',
#        'Domestic,Irrigation,Other,Mining',
#        'Municipal,Other,Stockwatering', 'Irrigation,Other,Mining',
#        'Domestic,Municipal,Mining', 'Domestic,Power,Mining',
#        'Municipal,Other,Mining', 'Irrigation,Other,Stockwatering,Mining',
#        'Municipal,Mining',
#        'Domestic,Irrigation,Municipal,Other,Stockwatering,Mining',
#        'Municipal,Stockwatering,Mining',
#        'Irrigation,Other,Stockwatering,Power,Mining',
#        'Irrigation,Power,Mining',
#        'Domestic,Irrigation,Other,Stockwatering,Mining',
#        'Municipal,Stockwatering,Power', 'Irrigation,Municipal,Mining',
#        'Domestic,Irrigation,Municipal,Other,Power'], dtype=object)

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfinPOD['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "UTwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "UTwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "UTwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfinPOD['SOURCE']
df['in_WaterSourceNativeID'] = "" #auto fill in below
df['in_WaterSourceTypeCV'] = dfinPOD['TYPE']

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = ""
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfinPOD['Latitude']
df['in_Longitude'] = dfinPOD['Longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"
df['in_SiteName'] = dfinPOD['SOURCE']
df['in_SiteNativeID'] = "POD" + dfinPOD['OBJECTID'].replace("", 0).fillna(0).astype(int).astype(str)
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = ""
df['in_StateCV'] = "UT"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = dfinPOD['CFS'].astype(float)
df['in_AllocationLegalStatusCV'] = dfinPOD['STATUS']
df['in_AllocationNativeID'] =  dfinPOD['WRNUM'].replace("", 0).fillna(0).astype(str)
df['in_AllocationOwner'] = dfinPOD['OWNER']
df['in_AllocationPriorityDate'] = dfinPOD['PRIORITY']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = dfinPOD['ACFT']
df['in_BeneficialUseCategory'] = dfinPOD['in_BeneficialUseCategory']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = dfinPOD['WebLink']

outPOD = df.copy()
outPOD = outPOD.drop_duplicates().reset_index(drop=True)
print(len(outPOD))
outPOD.head()
# Out:
# 282359
#    WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0      utD1       UTwr_M1                 UTwr_V1             UTwr_O1
# 1     utD10       UTwr_M1                 UTwr_V1             UTwr_O1
# 2    utD100       UTwr_M1                 UTwr_V1             UTwr_O1
# 3   utD1000       UTwr_M1                 UTwr_V1             UTwr_O1
# 4  utD10000       UTwr_M1                 UTwr_V1             UTwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#                                in_WaterSourceName in_WaterSourceNativeID  \
# 0  Non-Production Well: Closed Loop Heat Exchange
# 1                    Non-Production Well: Unknown
# 2                          Underground Water Well
# 3                       Non-Production Well: Test
# 4                        White Rock Spring Stream
#
#   in_WaterSourceTypeCV in_CoordinateAccuracy in_CoordinateMethodCV in_County  \
# 0          Underground
# 1          Underground
# 2          Underground
# 3      Abandonded Well
# 4       Point to Point
#
#    in_EPSGCodeCV in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0           4326                                    40.65480    -111.95654
# 1           4326                                    40.66009    -111.94791
# 2           4326                                    39.61925    -113.87756
# 3           4326                                    39.36270    -111.58694
# 4           4326                                    37.63907    -113.00251
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0                                                   POD
# 1                                                   POD
# 2                                                   POD
# 3                                                   POD
# 4                                                   POD
#
#                                       in_SiteName in_SiteNativeID  \
# 0  Non-Production Well: Closed Loop Heat Exchange    POD864475623
# 1                    Non-Production Well: Unknown    POD864475632
# 2                          Underground Water Well    POD864475722
# 3                       Non-Production Well: Test    POD864476622
# 4                        White Rock Spring Stream    POD864485665
#
#   in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                                    UT
# 1                                    UT
# 2                                    UT
# 3                                    UT
# 4                                    UT
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.01500
# 3                                            0.00000
# 4                                            0.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                    APPLAPP            0259005M00
# 1                    APPLAPP            0259008M00
# 2                    APPLWUC                18-427
# 3                    APPLAPP            0265001P00
# 4                        DIL               73-1713
#
#                          in_AllocationOwner in_AllocationPriorityDate  \
# 0  TAYLORSVILLE CITY C/O GEO ENGERY SYSTEMS
# 1                              FEC DRILLING
# 2                            STEPHEN P MUMM                  19800721
# 3                         JEFFERIES VINCENT
# 4                              SIDEHILL LLC                      1856
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeStart in_AllocationTypeCV  in_AllocationVolume_AF  \
# 0                                                                 0.00000
# 1                                                                 0.00000
# 2                                                                 0.00000
# 3                                                                 0.00000
# 4                                                                 0.44800
#
#             in_BeneficialUseCategory in_CommunityWaterSupplySystem  \
# 0
# 1
# 2  Domestic,Irrigation,Stockwatering
# 3
# 4                      Stockwatering
#
#   in_CropTypeCV in_CustomerTypeCV in_DataPublicationDate  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
#
#   in_GeneratedPowerCapacityMW in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://www.waterrights.utah.gov/search/?q=025...
# 1  https://www.waterrights.utah.gov/search/?q=025...
# 2  https://www.waterrights.utah.gov/search/?q=18-427
# 3  https://www.waterrights.utah.gov/search/?q=026...
# 4  https://www.waterrights.utah.gov/search/?q=73-...

# %% [markdown]
# ## Place of Use Data

# %%
# Input File - place of use data
FI_POU = "RawInputData/Utah_Place_of_Use_Irrigation.zip"
dfinPOU = pd.read_csv(FI_POU, encoding = "ISO-8859-1").replace(np.nan, "") 

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOU:
    dfinPOU['WaDEUUID'] = "utU" + dfinPOU.index.astype(str)
    dfinPOU.to_csv('RawInputData/Utah_Place_of_Use_Irrigation.zip', compression=dict(method='zip', archive_name='Utah_Place_of_Use_Irrigation.csv'), index=False)

dfinPOU['WRNUMS'] = dfinPOU['WRNUMS'].replace(" ", "").str.strip().astype(str)
dfinPOU = dfinPOU.drop_duplicates().reset_index(drop=True)
print(len(dfinPOU))
dfinPOU.head()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_19788\2174205847.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfinPOU = pd.read_csv(FI_POU, encoding = "ISO-8859-1").replace(np.nan, "")
# 76449
#   WaDEUUID ReasonRemoved IncompleteField  Ã¯Â»Â¿OID_  RECORD_ID  GROUP_NUMB  \
# 0     utU0                                         1   34305720          85
# 1     utU1                                         2   34305721          82
# 2    utU10                                        11   34305730         120
# 3   utU100                                       101   34305820      622976
# 4  utU1000                                      1001   34306720        4166
#
#   AREA_CODE CHNUM POU_TYPE                  SOURCE  \
# 0         1                               ProofMap
# 1         1                               ProofMap
# 2         1                 Hydrgraphic Survey Map
# 3         5                               ProofMap
# 4         9                               ProofMap
#
#                                                  URL    ACRES  \
# 0  https://waterrights.utah.gov/adjdinfo/hydromap...  0.00431
# 1  https://waterrights.utah.gov/docImport/0547/05... 18.94507
# 2  https://waterrights.utah.gov/docSys/v925/R925/...  0.10614
# 3  https://waterrights.utah.gov/docImport/0513/05...  0.00730
# 4  https://waterrights.utah.gov/docImport/0513/05...  0.12817
#
#              WRNUMS                                              dbURL  \
# 0           01-1127  https://maps.waterrights.utah.gov/POUPolygons/...
# 1  01-1078, 01-1124  https://maps.waterrights.utah.gov/POUPolygons/...
# 2     01-50, 01-134  https://maps.waterrights.utah.gov/POUPolygons/...
# 3           05-3185  https://maps.waterrights.utah.gov/POUPolygons/...
# 4           09-2167  https://maps.waterrights.utah.gov/POUPolygons/...
#
#    recordID  cent_Latitude  cent_Longitude  Shape__Are  Shape__Len  \
# 0         1       38.65522      -109.67395    17.43164    31.16859
# 1         3       38.65817      -109.68494 76631.45801  2248.41702
# 2        37       38.81333      -109.29940   429.43018    89.41734
# 3       190       38.31771      -109.45342    29.51660    24.34504
# 4      1997       37.28068      -109.56935   518.45996   109.49079
#
#    Shape_Length  Shape_Area
# 0       0.00033     0.00000
# 1       0.02335     0.00001
# 2       0.00093     0.00000
# 3       0.00026     0.00000
# 4       0.00113     0.00000

# %%
# Need to split out WRNUMS into their own row
# The explode() method explodes lists into separate rows.
dfinPOU = dfinPOU.assign(WRNUMS=dfinPOU['WRNUMS'].str.split(',')).explode('WRNUMS').reset_index()
dfinPOU = dfinPOU.rename({'WRNUMS': 'WRNUM'}, axis=1)
dfinPOU['WRNUM'] = dfinPOU['WRNUM'].str.strip().replace("", 0).fillna(0).astype(str)
dfinPOU = dfinPOU.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
dfinPOU['WRNUM'].unique()
# Out:
# array(['01-1127', '01-1078', '01-1124', ..., '25-1623', '25-1624',
#        '25-1626'], dtype=object)

# %%
# tie POD data to POU data for correct watersource info
dfinPOU = pd.merge(dfinPOU, outPOD[['in_AllocationNativeID', 'in_WaterSourceTypeCV', 'in_WaterSourceName']], left_on='WRNUM', right_on='in_AllocationNativeID', how='left')
print(len(dfinPOU))
dfinPOU.head(1)
# Out:
# 562185
#    index WaDEUUID ReasonRemoved IncompleteField  Ã¯Â»Â¿OID_  RECORD_ID  \
# 0      0     utU0                                         1   34305720
#
#    GROUP_NUMB AREA_CODE CHNUM POU_TYPE    SOURCE  \
# 0          85         1                 ProofMap
#
#                                                  URL   ACRES    WRNUM  \
# 0  https://waterrights.utah.gov/adjdinfo/hydromap... 0.00431  01-1127
#
#                                                dbURL  recordID  cent_Latitude  \
# 0  https://maps.waterrights.utah.gov/POUPolygons/...         1       38.65522
#
#    cent_Longitude  Shape__Are  Shape__Len  Shape_Length  Shape_Area  \
# 0      -109.67395    17.43164    31.16859       0.00033     0.00000
#
#   in_AllocationNativeID in_WaterSourceTypeCV      in_WaterSourceName
# 0               01-1127          Underground  Underground Water Well

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfinPOU['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "UTwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "UTwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "UTwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfinPOU['in_WaterSourceName'] # from POD
df['in_WaterSourceNativeID'] = "" #auto fill in below
df['in_WaterSourceTypeCV'] = dfinPOU['in_WaterSourceTypeCV'] # from POD

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = ""
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfinPOU['cent_Latitude']
df['in_Longitude'] = dfinPOU['cent_Longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POU"
df['in_SiteName'] = ""
df['in_SiteNativeID'] = "POU" + dfinPOU['RECORD_ID'].replace("", 0).fillna(0).astype(int).astype(str).str.strip()
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = ""
df['in_StateCV'] = "UT"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = ""
df['in_AllocationLegalStatusCV'] = ""
df['in_AllocationNativeID'] =  dfinPOU['WRNUM'].replace("", 0).fillna(0).astype(str)
df['in_AllocationOwner'] = ""
df['in_AllocationPriorityDate'] = ""
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = ""
df['in_BeneficialUseCategory'] = ""
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = ""

outPOU = df.copy()
outPOU = outPOU.drop_duplicates().reset_index(drop=True)
print(len(outPOU))
outPOU.head()
# Out:
# 255805
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     utU0       UTwr_M1                 UTwr_V1             UTwr_O1
# 1     utU1       UTwr_M1                 UTwr_V1             UTwr_O1
# 2     utU1       UTwr_M1                 UTwr_V1             UTwr_O1
# 3    utU10       UTwr_M1                 UTwr_V1             UTwr_O1
# 4    utU10       UTwr_M1                 UTwr_V1             UTwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#         in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0   Underground Water Well                                 Underground
# 1   Underground Water Well                                 Underground
# 2   Underground Water Well                                 Underground
# 3  Colorado River and Well                                     Surface
# 4  Colorado River and Well                                 Underground
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                                                 4326
# 1                                                                 4326
# 2                                                                 4326
# 3                                                                 4326
# 4                                                                 4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    38.65522    -109.67395
# 1                                    38.65817    -109.68494
# 2                                    38.65817    -109.68494
# 3                                    38.81333    -109.29940
# 4                                    38.81333    -109.29940
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                   POU
# 1                                                   POU
# 2                                                   POU
# 3                                                   POU
# 4                                                   POU
#
#   in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0     POU34305720                                    UT
# 1     POU34305721                                    UT
# 2     POU34305721                                    UT
# 3     POU34305730                                    UT
# 4     POU34305730                                    UT
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 0                                          01-1127
# 1                                          01-1078
# 2                                          01-1124
# 3                                            01-50
# 4                                            01-50
#
#   in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeEnd in_AllocationTimeframeStart in_AllocationTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationVolume_AF in_BeneficialUseCategory  \
# 0
# 1
# 2
# 3
# 4
#
#   in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDate in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                                           0
# 1                                                                           0
# 2                                                                           0
# 3                                                                           0
# 4                                                                           0
#
#   in_GeneratedPowerCapacityMW in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterAllocationNativeURL
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Concatenate POD and POU Data.  Clean Data.

# %%
# Concatenate dataframes
frames = [outPOD, outPOU]
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 538164

# %%
# Assign LegalStatusCV value.
# Uses the re library, but requires for loop.
# Order that the lists are inputed into dictoinary is important, want to overide generic search with a more specific search.

# Create the Lists
ADECList = ["ADEC"]
ADVList = ["ADV"]
APPList = ["APP"]
CERTList = ["CERT"]
DECList = ["DEC"]
DILList = ["DIL"]
DISList = ["DIS"]
EXPList = ["EXP"]
FORFList = ["FORF"]
LAPList = ["LAP"]
NPRList = ["NPR"]
NUSEList = ["NUSE"]
PERFList = ["PERF"]
REJList = ["REJ"]
RNUMList = ["RNUM"]
STATUSList = ["STATUS"]
TEMPList = ["TEMP"]
TERMList = ["TERM"]
UGWCList = ["UGWC"]
UNAPList = ["UNAP"]
WDList = ["WD"]
WUCList = ["WUC"]


# Making the dictionary
listDictionary = {}

listDictionary["Lapsed"] = LAPList

listDictionary["Adjudication Decree"] = ADECList
listDictionary["Adverse Use Claim"] = ADVList
listDictionary["Approved"] = APPList
listDictionary["Certificated"] = CERTList
listDictionary["Decree"] = DECList
listDictionary["Diligence Claim"] = DILList
listDictionary["Disallowed"] = DISList
listDictionary["Expired"] = EXPList
listDictionary["Forfeited"] = FORFList
listDictionary["No Proof Required"] = NPRList
listDictionary["Nonuse"] = NUSEList
listDictionary["Perfected"] = PERFList
listDictionary["Rejected"] = REJList
listDictionary["Renumbered"] = RNUMList
listDictionary["Deff"] = STATUSList
listDictionary["Temp Applications"] = TEMPList
listDictionary["Terminated"] = TERMList
listDictionary["Underground Water Claim"] = UGWCList
listDictionary["Unapproved"] = UNAPList
listDictionary["Withdrawn"] = WDList
listDictionary["Water User`s Claim"] = WUCList


def CreateLegalStatus(val):
    val = str(val).strip()
    if val == "" or pd.isnull(val):
        outString = ""
    else:
        outString = ""
        for x in listDictionary:
            valueList = listDictionary[x]
            for words in valueList:
                if words in val: outString = x
    
    if outString == "" or pd.isnull(val):
        outString = ""

    return outString

outdf['in_AllocationLegalStatusCV'] = outdf.apply(lambda row: CreateLegalStatus( row['in_AllocationLegalStatusCV']), axis=1)
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Approved', 'Water User`s Claim', 'Diligence Claim', '',
#        'Renumbered', 'No Proof Required', 'Disallowed', 'Certificated',
#        'Underground Water Claim', 'Rejected', 'Decree',
#        'Temp Applications', 'Withdrawn', 'Adverse Use Claim',
#        'Unapproved', 'Lapsed', 'Expired', 'Terminated', 'Forfeited'],
#       dtype=object)

# %%
# Clean owner name up
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;,/\)(-]", "", Val).replace("  ", " ").strip()
    return Val

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['TAYLORSVILLE CITY CO GEO ENGERY SYSTEMS', 'FEC DRILLING',
#        'STEPHEN P MUMM', ..., 'RAWLINGS', 'IRA WAYMAN',
#        'E D AND ELDA HAWS'], dtype=object)

# %%
# ID POD source data has a few names that contain a ',' in them, but should still be okay
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['NonProduction Well: Closed Loop Heat Exchange',
#        'NonProduction Well: Unknown', 'Underground Water Well', ...,
#        'Sethys Canyon Spring #2', 'Sethys Canyon Spring #3',
#        'Unnamed Tributary to Soilder Creek'], dtype=object)

# %%
# Ensure Empty String

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Non-Production Well: Closed Loop Heat Exchange',
#        'Non-Production Well: Unknown', 'Underground Water Well', ...,
#        'Sethys Canyon Spring #2', 'Sethys Canyon Spring #3',
#        'Unnamed Tributary to Soilder Creek'], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Underground', 'Abandonded Well', 'Point to Point', 'Surface',
#        'Rediversion', 'Point of Return', 'Spring', 'Drain', 'Sewage',
#        'Sewage Reuse', ''], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['NonProduction Well: Closed Loop Heat Exchange',
#        'NonProduction Well: Unknown', 'Underground Water Well', ...,
#        'Sethys Canyon Spring #2', 'Sethys Canyon Spring #3',
#        'Unnamed Tributary to Soilder Creek'], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['TAYLORSVILLE CITY CO GEO ENGERY SYSTEMS', 'FEC DRILLING',
#        'STEPHEN P MUMM', ..., 'RAWLINGS', 'IRA WAYMAN',
#        'E D AND ELDA HAWS'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['', 'Domestic,Irrigation,Stockwatering', 'Stockwatering',
#        'Domestic,Other', 'Other', 'Irrigation', 'Domestic',
#        'Domestic,Irrigation', 'Irrigation,Stockwatering',
#        'Irrigation,Municipal,Stockwatering', 'Municipal',
#        'Domestic,Stockwatering',
#        'Domestic,Irrigation,Other,Stockwatering', 'Irrigation,Other',
#        'Other,Stockwatering', 'Domestic,Irrigation,Municipal', 'Power',
#        'Irrigation,Other,Stockwatering', 'Municipal,Other',
#        'Domestic,Other,Stockwatering',
#        'Domestic,Irrigation,Municipal,Stockwatering',
#        'Domestic,Irrigation,Other', 'Mining',
#        'Irrigation,Municipal,Other,Stockwatering',
#        'Domestic,Stockwatering,Mining', 'Irrigation,Mining',
#        'Domestic,Mining', 'Stockwatering,Mining',
#        'Domestic,Irrigation,Mining', 'Domestic,Municipal',
#        'Domestic,Irrigation,Other,Power',
#        'Domestic,Irrigation,Municipal,Other,Stockwatering',
#        'Irrigation,Municipal,Other', 'Other,Mining',
#        'Municipal,Stockwatering', 'Other,Power', 'Irrigation,Municipal',
#        'Domestic,Irrigation,Stockwatering,Power', 'Irrigation,Power',
#        'Domestic,Municipal,Other', 'Irrigation,Municipal,Other,Power',
#        'Irrigation,Municipal,Power', 'Irrigation,Stockwatering,Power',
#        'Municipal,Other,Power', 'Irrigation,Other,Stockwatering,Power',
#        'Domestic,Irrigation,Municipal,Other', 'Municipal,Power',
#        'Domestic,Other,Power,Mining', 'Domestic,Other,Power',
#        'Domestic,Municipal,Other,Power', 'Domestic,Power',
#        'Domestic,Irrigation,Municipal,Other,Mining',
#        'Domestic,Irrigation,Municipal,Mining',
#        'Domestic,Irrigation,Municipal,Other,Stockwatering,Power',
#        'Domestic,Other,Mining', 'Domestic,Municipal,Other,Stockwatering',
#        'Irrigation,Other,Power',
#        'Irrigation,Municipal,Other,Stockwatering,Power',
#        'Domestic,Municipal,Stockwatering',
#        'Domestic,Irrigation,Municipal,Stockwatering,Power',
#        'Power,Mining', 'Domestic,Stockwatering,Power',
#        'Irrigation,Municipal,Stockwatering,Power', 'Other,Power,Mining',
#        'Domestic,Irrigation,Stockwatering,Mining',
#        'Domestic,Irrigation,Stockwatering,Power,Mining',
#        'Irrigation,Municipal,Other,Stockwatering,Mining',
#        'Domestic,Irrigation,Municipal,Other,Stockwatering,Power,Mining',
#        'Irrigation,Stockwatering,Mining', 'Other,Stockwatering,Power',
#        'Domestic,Irrigation,Power',
#        'Domestic,Irrigation,Other,Stockwatering,Power,Mining',
#        'Domestic,Other,Stockwatering,Mining', 'Stockwatering,Power',
#        'Domestic,Irrigation,Other,Stockwatering,Power',
#        'Other,Stockwatering,Mining',
#        'Domestic,Municipal,Other,Stockwatering,Mining',
#        'Domestic,Irrigation,Other,Mining',
#        'Municipal,Other,Stockwatering', 'Irrigation,Other,Mining',
#        'Domestic,Municipal,Mining', 'Domestic,Power,Mining',
#        'Municipal,Other,Mining', 'Irrigation,Other,Stockwatering,Mining',
#        'Municipal,Mining',
#        'Domestic,Irrigation,Municipal,Other,Stockwatering,Mining',
#        'Municipal,Stockwatering,Mining',
#        'Irrigation,Other,Stockwatering,Power,Mining',
#        'Irrigation,Power,Mining',
#        'Domestic,Irrigation,Other,Stockwatering,Mining',
#        'Municipal,Stockwatering,Power', 'Irrigation,Municipal,Mining',
#        'Domestic,Irrigation,Municipal,Other,Power'], dtype=object)

# %%
# in_Latitude
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([40.65479994, 40.66009038, 39.61925335, ..., 41.6812731 ,
#        41.64289046, 41.67786685])

# %%
# in_Longitude
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-111.95654327, -111.94791433, -113.87756202, ..., -111.95649944,
#        -111.9248735 , -111.93489009])

# %%
# Changing datatype of used date fields. 
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'], errors = 'coerce')
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# array([                          'NaT', '1980-07-21T00:00:00.000000000',
#        '1856-01-01T00:00:00.000000000', ...,
#        '1935-10-30T00:00:00.000000000', '1958-07-15T00:00:00.000000000',
#        '1942-09-05T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# Fixing in_AllocationFlow_CFS datatype
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array(['', 0.015, 0.338, ..., 2.565, 4.748, 6.94], dtype=object)

# %%
# Fixing in_AllocationVolume_AF datatype
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array(['', 0.448, 0.476, ..., 30.75, 54.48, 411.04], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName'].str.strip()
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].str.strip()
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)
dfWaterSourceNativeID['linkKey'] = dfWaterSourceNativeID['in_WaterSourceName'].astype(str) + dfWaterSourceNativeID['in_WaterSourceTypeCV'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
WaterSourceNativeIDdict = pd.Series(dfWaterSourceNativeID.in_WaterSourceNativeID.values, index=dfWaterSourceNativeID.linkKey.astype(str)).to_dict()
def retrieveWaterSourceNativeID(A, B):
    colrowValue = str(A).strip() + str(B).strip()
    try:
        outList = WaterSourceNativeIDdict[colrowValue]
    except:
        outList = ""
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeID1', 'wadeID2', 'wadeID3', ..., 'wadeID26038', 'wadeID26039',
#        'wadeID26040'], dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For UT, we don't want water rights that are considered: Rejected, Disallowed, Withdrawn, Temp Applications, Unapproved, Forfeited, Lapsed, Expired, Terminated

# %%
# drop non-active AllocationLegalStatusCV values specific to that state.

# drop the list
dropLegalStatusList = ["Rejected", "Disallowed", "Withdrawn", "Temp Applications", "Unapproved", "Forfeited", "Lapsed", "Expired", "Terminated"]

# drop rows from above list
outdf = outdf[outdf.in_AllocationLegalStatusCV.isin(dropLegalStatusList) == False].reset_index(drop=True)

print(len(outdf))
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# 514224
# array(['Approved', 'Water User`s Claim', 'Diligence Claim', '',
#        'Renumbered', 'No Proof Required', 'Certificated',
#        'Underground Water Claim', 'Decree', 'Adverse Use Claim'],
#       dtype=object)

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to POU csv inputs.

# %%
# PoU Shapefile Data
# Shapefile input
dfPoUshapetemp = gpd.read_file('RawInputData/shapefiles/Utah_Place_of_Use_Irrigation.zip')
print(len(dfPoUshapetemp))
dfPoUshapetemp.head()
# Out:
# 76449
#    RECORD_ID  GROUP_NUMB AREA_CODE CHNUM POU_TYPE    SOURCE  \
# 0   34305720          85        01  None     None  ProofMap
# 1   34305721          82        01  None     None  ProofMap
# 2   34305722          80        01  None     None  ProofMap
# 3   34305723      627071        01  None     None  ProofMap
# 4   34305724          63        01  None     None  ProofMap
#
#                                                  URL    ACRES  \
# 0  https://waterrights.utah.gov/adjdinfo/hydromap...  0.00431
# 1  https://waterrights.utah.gov/docImport/0547/05... 18.94507
# 2  https://waterrights.utah.gov/docImport/0547/05...  0.49387
# 3  https://waterrights.utah.gov/docImport/0547/05...  0.16730
# 4  https://waterrights.utah.gov/docSys/v903/K903/...  0.42000
#
#              WRNUMS                                              dbURL  \
# 0           01-1127  https://maps.waterrights.utah.gov/POUPolygons/...
# 1  01-1078, 01-1124  https://maps.waterrights.utah.gov/POUPolygons/...
# 2           01-1122  https://maps.waterrights.utah.gov/POUPolygons/...
# 3           01-1169  https://maps.waterrights.utah.gov/POUPolygons/...
# 4           01-1106  https://maps.waterrights.utah.gov/POUPolygons/...
#
#    recordID  cent_Latit  cent_Longi  Shape__Are  Shape__Len  Shape_Leng  \
# 0         1    38.65522  -109.67395    17.43164    31.16859     0.00033
# 1         3    38.65817  -109.68494 76631.45801  2248.41702     0.02335
# 2         4    38.84946  -109.28307  1998.11963   212.27895     0.00227
# 3         5    39.07298  -109.13151   676.93848   433.03334     0.00448
# 4        28    38.67979  -109.68728  1838.14722   411.68113     0.00469
#
#    Shape_Area                                           geometry
# 0     0.00000  POLYGON ((-109.67401 38.65519, -109.67402 38.6...
# 1     0.00001  MULTIPOLYGON (((-109.68702 38.65724, -109.6870...
# 2     0.00000  POLYGON ((-109.28259 38.84929, -109.28302 38.8...
# 3     0.00000  MULTIPOLYGON (((-109.13127 39.07287, -109.1312...
# 4     0.00000  POLYGON ((-109.68840 38.67975, -109.68840 38.6...

# %%
columnsList = ['in_SiteNativeID', 'geometry']
dfPoUshape = pd.DataFrame(columns=columnsList)
dfPoUshape['in_SiteNativeID'] = "POU" + dfPoUshapetemp['RECORD_ID'].replace("", 0).fillna(0).astype(int).astype(str).str.strip()
dfPoUshape['geometry'] = dfPoUshapetemp['geometry']
dfPoUshape = dfPoUshape.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
print(len(dfPoUshape))
dfPoUshape.head()
# Out:
# 76449
#   in_SiteNativeID                                           geometry
# 0     POU34305720  POLYGON ((-109.67401 38.65519, -109.67402 38.6...
# 1     POU34305721  MULTIPOLYGON (((-109.68702 38.65724, -109.6870...
# 2     POU34305722  POLYGON ((-109.28259 38.84929, -109.28302 38.8...
# 3     POU34305723  MULTIPOLYGON (((-109.13127 39.07287, -109.1312...
# 4     POU34305724  POLYGON ((-109.68840 38.67975, -109.68840 38.6...

# %% [markdown]
# ## Export Data

# %%
outdf.info
# Out:
# <bound method DataFrame.info of         WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0           utD1       UTwr_M1                 UTwr_V1             UTwr_O1
# 1          utD10       UTwr_M1                 UTwr_V1             UTwr_O1
# 2         utD100       UTwr_M1                 UTwr_V1             UTwr_O1
# 3        utD1000       UTwr_M1                 UTwr_V1             UTwr_O1
# 4       utD10000       UTwr_M1                 UTwr_V1             UTwr_O1
# ...          ...           ...                     ...                 ...
# 514219   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
# 514220   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
# 514221   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
# 514222   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
# 514223   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
#
#        in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...            ...                  ...                        ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#                                     in_WaterSourceName in_WaterSourceNativeID  \
# 0       Non-Production Well: Closed Loop Heat Exchange                wadeID1
# 1                         Non-Production Well: Unknown                wadeID2
# 2                               Underground Water Well                wadeID3
# 3                            Non-Production Well: Test                wadeID4
# 4                             White Rock Spring Stream                wadeID5
# ...                                                ...                    ...
# 514219                          Underground Water Well                wadeID3
# 514220                          Underground Water Well                wadeID3
# 514221                          Underground Water Well                wadeID3
# 514222                          Underground Water Well                wadeID3
# 514223                           Clayton Spring Stream             wadeID9107
#
#        in_WaterSourceTypeCV in_CoordinateAccuracy in_CoordinateMethodCV  \
# 0               Underground
# 1               Underground
# 2               Underground
# 3           Abandonded Well
# 4            Point to Point
# ...                     ...                   ...                   ...
# 514219          Underground
# 514220          Underground
# 514221          Underground
# 514222          Underground
# 514223              Surface
#
#        in_County  in_EPSGCodeCV in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  \
# 0                          4326                                    40.65480
# 1                          4326                                    40.66009
# 2                          4326                                    39.61925
# 3                          4326                                    39.36270
# 4                          4326                                    37.63907
# ...          ...            ...           ...      ...     ...          ...
# 514219                     4326                                    41.67787
# 514220                     4326                                    41.67787
# 514221                     4326                                    41.67787
# 514222                     4326                                    41.67787
# 514223                     4326                                    41.67787
#
#         in_Longitude in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0         -111.95654                                                   POD
# 1         -111.94791                                                   POD
# 2         -113.87756                                                   POD
# 3         -111.58694                                                   POD
# 4         -113.00251                                                   POD
# ...              ...                   ...             ...             ...
# 514219    -111.93489                                                   POU
# 514220    -111.93489                                                   POU
# 514221    -111.93489                                                   POU
# 514222    -111.93489                                                   POU
# 514223    -111.93489                                                   POU
#
#                                           in_SiteName in_SiteNativeID  \
# 0       NonProduction Well: Closed Loop Heat Exchange    POD864475623
# 1                         NonProduction Well: Unknown    POD864475632
# 2                              Underground Water Well    POD864475722
# 3                            NonProduction Well: Test    POD864476622
# 4                            White Rock Spring Stream    POD864485665
# ...                                               ...             ...
# 514219                                                    POU34315719
# 514220                                                    POU34315719
# 514221                                                    POU34315719
# 514222                                                    POU34315719
# 514223                                                    POU34315719
#
#        in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                                         UT
# 1                                         UT
# 2                                         UT
# 3                                         UT
# 4                                         UT
# ...             ...           ...        ...           ...
# 514219                                    UT
# 514220                                    UT
# 514221                                    UT
# 514222                                    UT
# 514223                                    UT
#
#        in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                             ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...                  ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                         ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2                                                0.01500
# 3
# 4
# ...                            ...                   ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                        Approved            0259005M00
# 1                        Approved            0259008M00
# 2              Water User`s Claim                18-427
# 3                        Approved            0265001P00
# 4                 Diligence Claim               73-1713
# ...                           ...                   ...
# 514219                                          25-1622
# 514220                                          25-1623
# 514221                                          25-1624
# 514222                                          25-1626
# 514223                                          25-1629
#
#                              in_AllocationOwner in_AllocationPriorityDate  \
# 0       TAYLORSVILLE CITY CO GEO ENGERY SYSTEMS                       NaT
# 1                                  FEC DRILLING                       NaT
# 2                                STEPHEN P MUMM                1980-07-21
# 3                             JEFFERIES VINCENT                       NaT
# 4                                  SIDEHILL LLC                1856-01-01
# ...                                         ...                       ...
# 514219                                                                NaT
# 514220                                                                NaT
# 514221                                                                NaT
# 514222                                                                NaT
# 514223                                                                NaT
#
#        in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                       ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0
# 1
# 2
# 3
# 4                                                                     0.44800
# ...                            ...                 ...                    ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#                  in_BeneficialUseCategory in_CommunityWaterSupplySystem  \
# 0
# 1
# 2       Domestic,Irrigation,Stockwatering
# 3
# 4                           Stockwatering
# ...                                   ...                           ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_CropTypeCV in_CustomerTypeCV in_DataPublicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...              ...               ...                    ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                         0
# 1                                                         0
# 2                                                         0
# 3                                                         0
# 4                                                         0
# ...                      ...                            ...
# 514219                                                    0
# 514220                                                    0
# 514221                                                    0
# 514222                                                    0
# 514223                                                    0
#
#        in_GeneratedPowerCapacityMW in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...                 ...                   ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                      ...                 ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...             ...                             ...                  ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#                               in_WaterAllocationNativeURL
# 0       https://www.waterrights.utah.gov/search/?q=025...
# 1       https://www.waterrights.utah.gov/search/?q=025...
# 2       https://www.waterrights.utah.gov/search/?q=18-427
# 3       https://www.waterrights.utah.gov/search/?q=026...
# 4       https://www.waterrights.utah.gov/search/?q=73-...
# ...                                                   ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
# [514224 rows x 63 columns]>

# %%
outdf
# Out:
#         WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0           utD1       UTwr_M1                 UTwr_V1             UTwr_O1
# 1          utD10       UTwr_M1                 UTwr_V1             UTwr_O1
# 2         utD100       UTwr_M1                 UTwr_V1             UTwr_O1
# 3        utD1000       UTwr_M1                 UTwr_V1             UTwr_O1
# 4       utD10000       UTwr_M1                 UTwr_V1             UTwr_O1
# ...          ...           ...                     ...                 ...
# 514219   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
# 514220   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
# 514221   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
# 514222   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
# 514223   utU9999       UTwr_M1                 UTwr_V1             UTwr_O1
#
#        in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...            ...                  ...                        ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#                                     in_WaterSourceName in_WaterSourceNativeID  \
# 0       Non-Production Well: Closed Loop Heat Exchange                wadeID1
# 1                         Non-Production Well: Unknown                wadeID2
# 2                               Underground Water Well                wadeID3
# 3                            Non-Production Well: Test                wadeID4
# 4                             White Rock Spring Stream                wadeID5
# ...                                                ...                    ...
# 514219                          Underground Water Well                wadeID3
# 514220                          Underground Water Well                wadeID3
# 514221                          Underground Water Well                wadeID3
# 514222                          Underground Water Well                wadeID3
# 514223                           Clayton Spring Stream             wadeID9107
#
#        in_WaterSourceTypeCV in_CoordinateAccuracy in_CoordinateMethodCV  \
# 0               Underground
# 1               Underground
# 2               Underground
# 3           Abandonded Well
# 4            Point to Point
# ...                     ...                   ...                   ...
# 514219          Underground
# 514220          Underground
# 514221          Underground
# 514222          Underground
# 514223              Surface
#
#        in_County  in_EPSGCodeCV in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  \
# 0                          4326                                    40.65480
# 1                          4326                                    40.66009
# 2                          4326                                    39.61925
# 3                          4326                                    39.36270
# 4                          4326                                    37.63907
# ...          ...            ...           ...      ...     ...          ...
# 514219                     4326                                    41.67787
# 514220                     4326                                    41.67787
# 514221                     4326                                    41.67787
# 514222                     4326                                    41.67787
# 514223                     4326                                    41.67787
#
#         in_Longitude in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0         -111.95654                                                   POD
# 1         -111.94791                                                   POD
# 2         -113.87756                                                   POD
# 3         -111.58694                                                   POD
# 4         -113.00251                                                   POD
# ...              ...                   ...             ...             ...
# 514219    -111.93489                                                   POU
# 514220    -111.93489                                                   POU
# 514221    -111.93489                                                   POU
# 514222    -111.93489                                                   POU
# 514223    -111.93489                                                   POU
#
#                                           in_SiteName in_SiteNativeID  \
# 0       NonProduction Well: Closed Loop Heat Exchange    POD864475623
# 1                         NonProduction Well: Unknown    POD864475632
# 2                              Underground Water Well    POD864475722
# 3                            NonProduction Well: Test    POD864476622
# 4                            White Rock Spring Stream    POD864485665
# ...                                               ...             ...
# 514219                                                    POU34315719
# 514220                                                    POU34315719
# 514221                                                    POU34315719
# 514222                                                    POU34315719
# 514223                                                    POU34315719
#
#        in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                                         UT
# 1                                         UT
# 2                                         UT
# 3                                         UT
# 4                                         UT
# ...             ...           ...        ...           ...
# 514219                                    UT
# 514220                                    UT
# 514221                                    UT
# 514222                                    UT
# 514223                                    UT
#
#        in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                             ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...                  ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                         ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2                                                0.01500
# 3
# 4
# ...                            ...                   ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                        Approved            0259005M00
# 1                        Approved            0259008M00
# 2              Water User`s Claim                18-427
# 3                        Approved            0265001P00
# 4                 Diligence Claim               73-1713
# ...                           ...                   ...
# 514219                                          25-1622
# 514220                                          25-1623
# 514221                                          25-1624
# 514222                                          25-1626
# 514223                                          25-1629
#
#                              in_AllocationOwner in_AllocationPriorityDate  \
# 0       TAYLORSVILLE CITY CO GEO ENGERY SYSTEMS                       NaT
# 1                                  FEC DRILLING                       NaT
# 2                                STEPHEN P MUMM                1980-07-21
# 3                             JEFFERIES VINCENT                       NaT
# 4                                  SIDEHILL LLC                1856-01-01
# ...                                         ...                       ...
# 514219                                                                NaT
# 514220                                                                NaT
# 514221                                                                NaT
# 514222                                                                NaT
# 514223                                                                NaT
#
#        in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                       ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0
# 1
# 2
# 3
# 4                                                                     0.44800
# ...                            ...                 ...                    ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#                  in_BeneficialUseCategory in_CommunityWaterSupplySystem  \
# 0
# 1
# 2       Domestic,Irrigation,Stockwatering
# 3
# 4                           Stockwatering
# ...                                   ...                           ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_CropTypeCV in_CustomerTypeCV in_DataPublicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...              ...               ...                    ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                         0
# 1                                                         0
# 2                                                         0
# 3                                                         0
# 4                                                         0
# ...                      ...                            ...
# 514219                                                    0
# 514220                                                    0
# 514221                                                    0
# 514222                                                    0
# 514223                                                    0
#
#        in_GeneratedPowerCapacityMW in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...                 ...                   ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                      ...                 ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#        in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...             ...                             ...                  ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
#                               in_WaterAllocationNativeURL
# 0       https://www.waterrights.utah.gov/search/?q=025...
# 1       https://www.waterrights.utah.gov/search/?q=025...
# 2       https://www.waterrights.utah.gov/search/?q=18-427
# 3       https://www.waterrights.utah.gov/search/?q=026...
# 4       https://www.waterrights.utah.gov/search/?q=73-...
# ...                                                   ...
# 514219
# 514220
# 514221
# 514222
# 514223
#
# [514224 rows x 63 columns]

# %%
# Export the output dataframe
outdf.to_csv('RawInputData/Pwr_utMain.zip', compression=dict(method='zip', archive_name='Pwr_utMain.csv'), index=False)  # The output, save as a zip
dfPoUshape.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.

# %%
# # Not sure how this was made, it does not agree with any WaDE Logic / existing UT notes

# ####################################################

# # Assign SiteTypeCV value.
# # Uses the re library, but requires for loop.
# # Order that the lists are inputed into dictoinary is important, want to overide generic search with a more specific search.

# # Create the Lists
# canalList = ["canal", "canals"]
# creekList = ["creek"]
# ditchList = ["ditch"]
# drainList = ["drain", "drains"]
# lakeList = ["lake"]
# pondList = ["pond"]
# reservoirList = ["reservoir"]
# riverList = ["river", "fork", "surface"]
# sloughList = ["slough"]
# springList = ["spring", "springs", "gulch", "seep"]
# tunnelList = ["tunnel", "tunnels"]
# washList = ["wash"]
# wellList = ["well", "wells", "well:", "draw", "hollow"]

# # Making the dictionary
# listDictionary = {}
# listDictionary["Canal"] = canalList
# listDictionary["Creek"] = creekList
# listDictionary["Ditch"] = ditchList
# listDictionary["Drain"] = drainList
# listDictionary["Lake"] = lakeList
# listDictionary["Pond"] = pondList
# listDictionary["Reservoir"] = reservoirList
# listDictionary["River"] = riverList
# listDictionary["Slough"] = sloughList
# listDictionary["Spring"] = springList
# listDictionary["Tunnel"] = tunnelList
# listDictionary["Wash"] = washList
# listDictionary["Well"] = wellList

# def CreateSiteTypeCV(val):
#     if val == "" or pd.isnull(val):
#         outString = ""
#     else:
#         outString = "" # Default
        
#         # Cleaning text / simple search format
#         val = val.replace(",", " ")
#         val = val.replace(".", " ")
#         val = val.replace(";", " ")
#         val = val.replace("-", " ")
#         val = val.replace("/", " ")
#         val = val.replace("(", " ")
#         val = val.replace(")", " ")
#         val = val.lower().strip()
#         val = " "+val+" "
        
#         for x in listDictionary:
#             labelString = x
#             valueList = listDictionary[x]
#             for words in valueList:
#                 if re.search(" "+words+ " ", val): outString = x
            
#     return outString

# outdf['in_SiteTypeCV'] = outdf.apply(lambda row: CreateSiteTypeCV( row['in_SiteTypeCV']), axis=1)
# outdf['in_SiteTypeCV'].unique()
