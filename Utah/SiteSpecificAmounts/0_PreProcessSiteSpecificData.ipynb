# %% [markdown]
# # Pre-processing Utah Site Specific data for WaDEQA upload.
# Date Updated: 07/30/2020
# Purpose:  To pre-process the Utah data into one master file for simple DataFrame creation and extraction
#
# Notes:
# 1) Need to left join of System Data and Source Data
# 2) Cut down on number of columns in Source Data to reduce redundecy (Source_temp).
# 3) Made custom link ID by hand for both System and Source Data by combining SystemID + Year: SystemID_Year_ID

# %%
#Needed Libararies
import os
import numpy as np
import pandas as pd
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
#Working Directory and Input File
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Utah/SiteSpecificAmounts/RawInputData"
os.chdir(workingDir)
System_Input = "SystemData_temp.csv"
Source_Input = "SourceData_temp.csv"

#Dataframe creation
df_sys = pd.read_csv(System_Input, encoding = "ISO-8859-1")
df_sor = pd.read_csv(Source_Input, encoding = "ISO-8859-1")

# %%
#Merge
df = pd.merge(df_sys, df_sor, left_on='SystemID_Year_ID', right_on='SystemID_Year_ID', how='inner')
df
# Out:
#        SystemID_Year_ID                                      System Name_x  \
# 0              10001979             Leeds Domestic Water Users Association
# 1              10001980             Leeds Domestic Water Users Association
# 2              10001981             Leeds Domestic Water Users Association
# 3              10001982             Leeds Domestic Water Users Association
# 4              10001983             Leeds Domestic Water Users Association
# ...                 ...                                                ...
# 27299          12412018  National Park Service, Glen Canyon Bullfrog Re...
# 27300          12412018  National Park Service, Glen Canyon Bullfrog Re...
# 27301          12412019  National Park Service, Glen Canyon Bullfrog Re...
# 27302          12412019  National Park Service, Glen Canyon Bullfrog Re...
# 27303          12412019  National Park Service, Glen Canyon Bullfrog Re...
#
#        System ID_x System Type System Status  History Year Date Received  \
# 0             1000      Public        Active          1979     3/10/1980
# 1             1000      Public        Active          1980      3/9/1981
# 2             1000      Public        Active          1981     1/25/1982
# 3             1000      Public        Active          1982     3/24/1983
# 4             1000      Public        Active          1983     2/21/1984
# ...            ...         ...           ...           ...           ...
# 27299         1241      Public        Active          2018      7/8/2019
# 27300         1241      Public        Active          2018      7/8/2019
# 27301         1241      Public        Active          2019     2/28/2020
# 27302         1241      Public        Active          2019     2/28/2020
# 27303         1241      Public        Active          2019     2/28/2020
#
#            County  Use Cooling Percent  Use Process Percent  \
# 0      Washington                  NaN                  NaN
# 1      Washington                  NaN                  NaN
# 2      Washington                  NaN                  NaN
# 3      Washington                  NaN                  NaN
# 4      Washington                  NaN                  NaN
# ...           ...                  ...                  ...
# 27299        Kane                  NaN                  NaN
# 27300        Kane                  NaN                  NaN
# 27301        Kane                  NaN                  NaN
# 27302        Kane                  NaN                  NaN
# 27303        Kane                  NaN                  NaN
#
#        Use Domestic Percent  Use Miscellaneous Percent  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ...                     ...                        ...
# 27299                   NaN                        NaN
# 27300                   NaN                        NaN
# 27301                   NaN                        NaN
# 27302                   NaN                        NaN
# 27303                   NaN                        NaN
#
#        Irrigation (Lawn and Garden) Percent  Acres Irrigated  \
# 0                                       NaN              NaN
# 1                                       NaN              NaN
# 2                                       NaN              NaN
# 3                                       NaN              NaN
# 4                                       NaN              NaN
# ...                                     ...              ...
# 27299                                   NaN              NaN
# 27300                                   NaN              NaN
# 27301                                   NaN              NaN
# 27302                                   NaN              NaN
# 27303                                   NaN              NaN
#
#        Irrigation (Agriculture)  Acres Irrigated.1 DEQ ID  Population  \
# 0                           NaN                NaN  27010       255.0
# 1                           NaN                NaN  27010       269.0
# 2                           NaN                NaN  27010       269.0
# 3                           NaN                NaN  27010       218.0
# 4                           NaN                NaN  27010       250.0
# ...                         ...                ...    ...         ...
# 27299                       NaN                NaN  13014       220.0
# 27300                       NaN                NaN  13014       220.0
# 27301                       NaN                NaN  13014       220.0
# 27302                       NaN                NaN  13014       220.0
# 27303                       NaN                NaN  13014       220.0
#
#        Domestic Use  Commercial Use  Industrial Use  Institutional Use  \
# 0          0.000000             0.0             0.0                NaN
# 1          0.000000             0.0             0.0                NaN
# 2          0.000000             0.0             0.0                NaN
# 3          0.000000             0.0             0.0                NaN
# 4          0.000000             0.0             0.0                NaN
# ...             ...             ...             ...                ...
# 27299     58.189881             0.0             0.0          22.447347
# 27300     58.189881             0.0             0.0          22.447347
# 27301     33.902260             0.0             0.0          23.076971
# 27302     33.902260             0.0             0.0          23.076971
# 27303     33.902260             0.0             0.0          23.076971
#
#         Total Use  Domestic Connections  Commercial Connections  \
# 0       89.071316                   0.0                     0.0
# 1      102.188634                  95.0                     7.0
# 2       88.426806                 103.0                     6.0
# 3       80.223111                   0.0                     0.0
# 4       69.705318                   0.0                     0.0
# ...           ...                   ...                     ...
# 27299   80.637228                 125.0                     0.0
# 27300   80.637228                 125.0                     0.0
# 27301   56.979232                 125.0                     0.0
# 27302   56.979232                 125.0                     0.0
# 27303   56.979232                 125.0                     0.0
#
#        Industrial Connections  Institutional Connections  Total Connections  \
# 0                         0.0                        NaN              101.0
# 1                         0.0                        NaN              102.0
# 2                         0.0                        NaN              109.0
# 3                         0.0                        NaN               90.0
# 4                         0.0                        NaN               99.0
# ...                       ...                        ...                ...
# 27299                     0.0                        9.0              134.0
# 27300                     0.0                        9.0              134.0
# 27301                     0.0                        9.0              134.0
# 27302                     0.0                        9.0              134.0
# 27303                     0.0                        9.0              134.0
#
#       Peak Date  Peak Demand Peak Demand Units    Peak Use Include  \
# 0           NaN          NaN               NaN                 NaN
# 1           NaN          NaN               NaN                 NaN
# 2           NaN          NaN               NaN                 NaN
# 3           NaN          NaN               NaN                 NaN
# 4           NaN          NaN               NaN                 NaN
# ...         ...          ...               ...                 ...
# 27299  8/8/2018     1.592750         acre feet  Indoor and Outdoor
# 27300  8/8/2018     1.592750         acre feet  Indoor and Outdoor
# 27301  7/7/2019     1.117074         acre feet  Indoor and Outdoor
# 27302  7/7/2019     1.117074         acre feet  Indoor and Outdoor
# 27303  7/7/2019     1.117074         acre feet  Indoor and Outdoor
#
#       Peak Measurement Type  Peak Wholesale Volume  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
# ...                     ...                    ...
# 27299                   NaN                    NaN
# 27300                   NaN                    NaN
# 27301                   NaN               0.355211
# 27302                   NaN               0.355211
# 27303                   NaN               0.355211
#
#       Peak Wholesale Volume Units  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 27299                         NaN
# 27300                         NaN
# 27301                   acre feet
# 27302                   acre feet
# 27303                   acre feet
#
#                                            System Name_y  System ID_y    Year  \
# 0                 Leeds Domestic Water Users Association         1000  1979.0
# 1                 Leeds Domestic Water Users Association         1000  1980.0
# 2                 Leeds Domestic Water Users Association         1000  1981.0
# 3                 Leeds Domestic Water Users Association         1000  1982.0
# 4                 Leeds Domestic Water Users Association         1000  1983.0
# ...                                                  ...          ...     ...
# 27299  National Park Service, Glen Canyon Bullfrog Re...         1241  2018.0
# 27300  National Park Service, Glen Canyon Bullfrog Re...         1241  2018.0
# 27301  National Park Service, Glen Canyon Bullfrog Re...         1241  2019.0
# 27302  National Park Service, Glen Canyon Bullfrog Re...         1241  2019.0
# 27303  National Park Service, Glen Canyon Bullfrog Re...         1241  2019.0
#
#        Source ID               Source Name Source Status  Lat NAD83  \
# 0       10000001  Oak Grove Spring (WS001)        Active  37.309077
# 1       10000001  Oak Grove Spring (WS001)        Active  37.309077
# 2       10000001  Oak Grove Spring (WS001)        Active  37.309077
# 3       10000001  Oak Grove Spring (WS001)        Active  37.309077
# 4       10000001  Oak Grove Spring (WS001)        Active  37.309077
# ...          ...                       ...           ...        ...
# 27299   12410002         Well No.2 (WS002)        Active  37.531396
# 27300  108544946           Sold to Aramark        Active        NaN
# 27301   12410001         Well No.1 (WS001)        Active  37.527684
# 27302   12410002         Well No.2 (WS002)        Active  37.531396
# 27303  108544946           Sold to Aramark        Active        NaN
#
#         Lon NAD83 Source Type Diversion Type
# 0     -113.429412      Spring     Withdrawal
# 1     -113.429412      Spring     Withdrawal
# 2     -113.429412      Spring     Withdrawal
# 3     -113.429412      Spring     Withdrawal
# 4     -113.429412      Spring     Withdrawal
# ...           ...         ...            ...
# 27299 -110.711764        Well     Withdrawal
# 27300         NaN         NaN   Transfer Out
# 27301 -110.717070        Well     Withdrawal
# 27302 -110.711764        Well     Withdrawal
# 27303         NaN         NaN   Transfer Out
#
# [27304 rows x 45 columns]

# %%
#check columns
df.columns
# Out:
# Index(['SystemID_Year_ID', 'System Name_x', 'System ID_x', 'System Type',
#        'System Status', 'History Year', 'Date Received', 'County',
#        'Use Cooling Percent', 'Use Process Percent', 'Use Domestic Percent',
#        'Use Miscellaneous Percent', 'Irrigation (Lawn and Garden) Percent',
#        'Acres Irrigated', 'Irrigation (Agriculture)', 'Acres Irrigated.1',
#        'DEQ ID', 'Population', 'Domestic Use', 'Commercial Use',
#        'Industrial Use', 'Institutional Use', 'Total Use',
#        'Domestic Connections', 'Commercial Connections',
#        'Industrial Connections', 'Institutional Connections',
#        'Total Connections', 'Peak Date', 'Peak Demand', 'Peak Demand Units',
#        'Peak Use Include', 'Peak Measurement Type', 'Peak Wholesale Volume',
#        'Peak Wholesale Volume Units', 'System Name_y', 'System ID_y', 'Year',
#        'Source ID', 'Source Name', 'Source Status', 'Lat NAD83', 'Lon NAD83',
#        'Source Type', 'Diversion Type'],
#       dtype='object')

# %%
#check datatype
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.dtypes)
# Out:
# SystemID_Year_ID                          int64
# System Name_x                            object
# System ID_x                               int64
# System Type                              object
# System Status                            object
# History Year                              int64
# Date Received                            object
# County                                   object
# Use Cooling Percent                     float64
# Use Process Percent                     float64
# Use Domestic Percent                    float64
# Use Miscellaneous Percent               float64
# Irrigation (Lawn and Garden) Percent    float64
# Acres Irrigated                         float64
# Irrigation (Agriculture)                float64
# Acres Irrigated.1                       float64
# DEQ ID                                   object
# Population                              float64
# Domestic Use                            float64
# Commercial Use                          float64
# Industrial Use                          float64
# Institutional Use                       float64
# Total Use                               float64
# Domestic Connections                    float64
# Commercial Connections                  float64
# Industrial Connections                  float64
# Institutional Connections               float64
# Total Connections                       float64
# Peak Date                                object
# Peak Demand                             float64
# Peak Demand Units                        object
# Peak Use Include                         object
# Peak Measurement Type                    object
# Peak Wholesale Volume                   float64
# Peak Wholesale Volume Units              object
# System Name_y                            object
# System ID_y                               int64
# Year                                    float64
# Source ID                                 int64
# Source Name                              object
# Source Status                            object
# Lat NAD83                               float64
# Lon NAD83                               float64
# Source Type                              object
# Diversion Type                           object
# dtype: object

# %%
#Exporting to Finished File
df.to_csv('P_MasterUTSiteSpecific.csv', index=False)  # The output
