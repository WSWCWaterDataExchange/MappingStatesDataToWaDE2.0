# %% [markdown]
# # Preprocessing Utah Site Specific data for WaDEQA upload.
# - Date Updated: 06/11/2021
# - Purpose:  To preprocess the UDWRi and UDWRe data into one master file for simple DataFrame creation and extraction
#
# Notes:
# - Seperate out Use UDWRi_SystemData water use data by customer type (e.g. Domestic, Commerical, Industrial, Insitutional, Total).
# - Extract site data from both  UDWRi_Source Data & UDWRe_CulinaryWaterServiceArea data.
# - Left-outter join system data to site data.
# - create missing elements (water source ID)

# %%
# Needed Libararies
import os
import numpy as np
import pandas as pd
from datetime import datetime
import geopandas as gpd # the library that lets us read in shapefiles
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
# Working Directory and Input File
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Utah/SiteSpecificAmounts/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ### UDWRi System Data

# %%
# Dataframe Creation - system Data
sys_Input = "UDWRi_SystemData_input.csv"
df_sys = pd.read_csv(sys_Input, encoding = "ISO-8859-1")
df_sys.head(1)
# Out:
#                               System Name  System ID System Type  \
# 0  Leeds Domestic Water Users Association       1000      Public
#
#   System Status  History Year Date Received      County  Use Cooling Percent  \
# 0        Active          2019     1/22/2020  Washington                  NaN
#
#    Use Process Percent  Use Domestic Percent  Use Miscellaneous Percent  \
# 0                  NaN                   NaN                        NaN
#
#    Irrigation (Lawn and Garden) Percent  Acres Irrigated  \
# 0                                   NaN              NaN
#
#    Irrigation (Agriculture)  Acres Irrigated.1 DEQ ID  Population  \
# 0                       NaN                NaN  27010       800.0
#
#    Domestic Use  Commercial Use  Industrial Use  Institutional Use  Total Use  \
# 0      62166.25        14418.28          110.34            2749.36   79444.23
#
#    Domestic Connections  Commercial Connections  Industrial Connections  \
# 0                 349.0                    16.0                     1.0
#
#    Institutional Connections  Total Connections  Peak Date  Peak Demand  \
# 0                        5.0              371.0  7/30/2019        309.3
#
#   Peak Demand Units    Peak Use Include Peak Measurement Type  \
# 0          kgallons  Indoor and Outdoor                   NaN
#
#    Peak Wholesale Volume Peak Wholesale Volume Units
# 0                    NaN                         NaN

# %%
# Dropping system data that isn't needed for upload.
df_sys = df_sys.drop(['Use Cooling Percent',
                      'Use Process Percent', 
                      'Use Domestic Percent',
                      'Use Miscellaneous Percent', 
                      'Irrigation (Lawn and Garden) Percent',
                      'Peak Date', 
                      'Peak Demand', 
                      'Peak Demand Units',
                      'Peak Use Include', 
                      'Peak Measurement Type', 
                      'Peak Wholesale Volume',
                      'Peak Wholesale Volume Units'], axis=1)
df_sys.head(1)
# Out:
#                               System Name  System ID System Type  \
# 0  Leeds Domestic Water Users Association       1000      Public
#
#   System Status  History Year Date Received      County  Acres Irrigated  \
# 0        Active          2019     1/22/2020  Washington              NaN
#
#    Irrigation (Agriculture)  Acres Irrigated.1 DEQ ID  Population  \
# 0                       NaN                NaN  27010       800.0
#
#    Domestic Use  Commercial Use  Industrial Use  Institutional Use  Total Use  \
# 0      62166.25        14418.28          110.34            2749.36   79444.23
#
#    Domestic Connections  Commercial Connections  Industrial Connections  \
# 0                 349.0                    16.0                     1.0
#
#    Institutional Connections  Total Connections
# 0                        5.0              371.0

# %%
# System Data - Domestic
df_sys_Domestic = df_sys
df_sys_Domestic['WaterUse'] = df_sys_Domestic['Domestic Use']
df_sys_Domestic['NumOfConnections'] = df_sys_Domestic['Domestic Connections']
df_sys_Domestic['BenUse'] = "Domestic"
df_sys_Domestic['in_VariableSpecificCV'] = "Domestic"
df_sys_Domestic['in_CustomerTypeCV'] = "Domestic"
df_sys_Domestic = df_sys_Domestic.drop(['Domestic Use', 'Commercial Use', 'Industrial Use', 'Institutional Use', 'Total Use'], axis=1)
df_sys_Domestic = df_sys_Domestic.drop(['Domestic Connections', 'Commercial Connections','Industrial Connections', 'Institutional Connections', 'Total Connections'], axis=1)

print(len(df_sys_Domestic))
df_sys_Domestic.head(1)
# Out:
# 21129
#                               System Name  System ID System Type  \
# 0  Leeds Domestic Water Users Association       1000      Public
#
#   System Status  History Year Date Received      County  Acres Irrigated  \
# 0        Active          2019     1/22/2020  Washington              NaN
#
#    Irrigation (Agriculture)  Acres Irrigated.1 DEQ ID  Population  WaterUse  \
# 0                       NaN                NaN  27010       800.0  62166.25
#
#    NumOfConnections    BenUse in_VariableSpecificCV in_CustomerTypeCV
# 0             349.0  Domestic              Domestic          Domestic

# %%
# System Data - Commercial
df_sys_Commercial = df_sys
df_sys_Commercial['WaterUse'] = df_sys_Commercial['Commercial Use']
df_sys_Commercial['NumOfConnections'] = df_sys_Commercial['Commercial Connections']
df_sys_Commercial['BenUse'] = "Commercial"
df_sys_Commercial['in_VariableSpecificCV'] = "Commercial"
df_sys_Commercial['in_CustomerTypeCV'] = "Commercial"
df_sys_Commercial = df_sys_Commercial.drop(['Domestic Use', 'Commercial Use', 'Industrial Use', 'Institutional Use', 'Total Use'], axis=1)
df_sys_Commercial = df_sys_Commercial.drop(['Domestic Connections', 'Commercial Connections','Industrial Connections', 'Institutional Connections', 'Total Connections'], axis=1)

print(len(df_sys_Commercial))
df_sys_Commercial.head(1)
# Out:
# 21129
#                               System Name  System ID System Type  \
# 0  Leeds Domestic Water Users Association       1000      Public
#
#   System Status  History Year Date Received      County  Acres Irrigated  \
# 0        Active          2019     1/22/2020  Washington              NaN
#
#    Irrigation (Agriculture)  Acres Irrigated.1 DEQ ID  Population  WaterUse  \
# 0                       NaN                NaN  27010       800.0  14418.28
#
#    NumOfConnections      BenUse in_VariableSpecificCV in_CustomerTypeCV
# 0              16.0  Commercial            Commercial        Commercial

# %%
# System Data - Industrial
df_sys_Industrial = df_sys
df_sys_Industrial['WaterUse'] = df_sys_Industrial['Industrial Use']
df_sys_Industrial['NumOfConnections'] = df_sys_Industrial['Industrial Connections']
df_sys_Industrial['BenUse'] = "Industrial"
df_sys_Industrial['in_VariableSpecificCV'] = "Industrial"
df_sys_Industrial['in_CustomerTypeCV'] = "Industrial"
df_sys_Industrial = df_sys_Industrial.drop(['Domestic Use', 'Commercial Use', 'Industrial Use', 'Institutional Use', 'Total Use'], axis=1)
df_sys_Industrial = df_sys_Industrial.drop(['Domestic Connections', 'Commercial Connections','Industrial Connections', 'Institutional Connections', 'Total Connections'], axis=1)

print(len(df_sys_Industrial))
df_sys_Industrial.head(1)
# Out:
# 21129
#                               System Name  System ID System Type  \
# 0  Leeds Domestic Water Users Association       1000      Public
#
#   System Status  History Year Date Received      County  Acres Irrigated  \
# 0        Active          2019     1/22/2020  Washington              NaN
#
#    Irrigation (Agriculture)  Acres Irrigated.1 DEQ ID  Population  WaterUse  \
# 0                       NaN                NaN  27010       800.0    110.34
#
#    NumOfConnections      BenUse in_VariableSpecificCV in_CustomerTypeCV
# 0               1.0  Industrial            Industrial        Industrial

# %%
# Institutional
df_sys_Institutional = df_sys
df_sys_Institutional['WaterUse'] = df_sys_Institutional['Institutional Use']
df_sys_Institutional['NumOfConnections'] = df_sys_Institutional['Institutional Connections']
df_sys_Institutional['BenUse'] = "Institutional"
df_sys_Institutional['in_VariableSpecificCV'] = "Institutional"
df_sys_Institutional['in_CustomerTypeCV'] = "Institutional"
df_sys_Institutional = df_sys_Institutional.drop(['Domestic Use', 'Commercial Use', 'Industrial Use', 'Institutional Use', 'Total Use'], axis=1)
df_sys_Institutional = df_sys_Institutional.drop(['Domestic Connections', 'Commercial Connections','Industrial Connections', 'Institutional Connections', 'Total Connections'], axis=1)

print(len(df_sys_Institutional))
df_sys_Institutional.head(1)
# Out:
# 21129
#                               System Name  System ID System Type  \
# 0  Leeds Domestic Water Users Association       1000      Public
#
#   System Status  History Year Date Received      County  Acres Irrigated  \
# 0        Active          2019     1/22/2020  Washington              NaN
#
#    Irrigation (Agriculture)  Acres Irrigated.1 DEQ ID  Population  WaterUse  \
# 0                       NaN                NaN  27010       800.0   2749.36
#
#    NumOfConnections         BenUse in_VariableSpecificCV in_CustomerTypeCV
# 0               5.0  Institutional         Institutional     Institutional

# %%
# System Data - Total (DCII)
df_sys_Total = df_sys
df_sys_Total['WaterUse'] = df_sys_Total['Total Use']
df_sys_Total['NumOfConnections'] = df_sys_Total['Total Connections']
df_sys_Total['BenUse'] = "Total (DCII)"
df_sys_Total['in_VariableSpecificCV'] = "Total (DCII)"
df_sys_Total['in_CustomerTypeCV'] = "Total"
df_sys_Total = df_sys_Total.drop(['Domestic Use', 'Commercial Use', 'Industrial Use', 'Institutional Use', 'Total Use'], axis=1)
df_sys_Total = df_sys_Total.drop(['Domestic Connections', 'Commercial Connections','Industrial Connections', 'Institutional Connections', 'Total Connections'], axis=1)

print(len(df_sys_Total))
df_sys_Total.head(1)
# Out:
# 21129
#                               System Name  System ID System Type  \
# 0  Leeds Domestic Water Users Association       1000      Public
#
#   System Status  History Year Date Received      County  Acres Irrigated  \
# 0        Active          2019     1/22/2020  Washington              NaN
#
#    Irrigation (Agriculture)  Acres Irrigated.1 DEQ ID  Population  WaterUse  \
# 0                       NaN                NaN  27010       800.0  79444.23
#
#    NumOfConnections        BenUse in_VariableSpecificCV in_CustomerTypeCV
# 0             371.0  Total (DCII)          Total (DCII)             Total

# %%
# Concatenate System Data into one long dataframe.
frames = [df_sys_Domestic, df_sys_Commercial, df_sys_Industrial, df_sys_Institutional, df_sys_Total]
df_sys_all = pd.concat(frames)

df_sys_all = df_sys_all.replace(np.nan, "").drop_duplicates().reset_index(drop=True)
print(len(df_sys_all))
df_sys_all.head(1)
# Out:
# 105645
#                               System Name  System ID System Type  \
# 0  Leeds Domestic Water Users Association       1000      Public
#
#   System Status  History Year Date Received      County Acres Irrigated  \
# 0        Active          2019     1/22/2020  Washington
#
#   Irrigation (Agriculture) Acres Irrigated.1 DEQ ID Population  WaterUse  \
# 0                                             27010      800.0  62166.25
#
#   NumOfConnections    BenUse in_VariableSpecificCV in_CustomerTypeCV
# 0            349.0  Domestic              Domestic          Domestic

# %% [markdown]
# ### UDWRi Source Data

# %%
# Dataframe Creation - system Data
sour_Input = "UDWRi_SourceData_input.csv"
df_sour = pd.read_csv(sour_Input, encoding = "ISO-8859-1")
df_sour.head(1)
# Out:
#    Source ID               Source Name  Year Source Status  \
# 0   10000001  Oak Grove Spring (WS001)   NaN        Active
#
#                               System Name  System ID  Lat NAD83   Lon NAD83  \
# 0  Leeds Domestic Water Users Association       1000  37.309077 -113.429412
#
#   Source Type Diversion Type        Use Type Units  Jan  Feb  Mar  Apr  May  \
# 0      Spring     Withdrawal  Water Supplier   NaN  NaN  NaN  NaN  NaN  NaN
#
#    Jun  Jul  Aug  Sep  Oct  Nov  Dec  Total
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN

# %%
# Creating Water Source Type.
wsTypeDict = {
    "Spring" : "Surface Water",
    "Well" : "Groundwater",
    "Stream" : "Surface Water",
    "Tunnel" : "Groundwater",
    "Reservoir" : "Surface Water",
    "Drain" : "Surface Water",
    "Lake" : "Surface Water"}
def assignWaterSourceTypeCV(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = ""
    else:
        String1 = colrowValue.strip()
        try:
            outList = wsTypeDict[String1]
        except:
            outList = ""
    return outList

df_sour['in_WaterSourceTypeCV'] = df_sour.apply(lambda row: assignWaterSourceTypeCV(row['Source Type']), axis=1)
df_sour.head(1)
# Out:
#    Source ID               Source Name  Year Source Status  \
# 0   10000001  Oak Grove Spring (WS001)   NaN        Active
#
#                               System Name  System ID  Lat NAD83   Lon NAD83  \
# 0  Leeds Domestic Water Users Association       1000  37.309077 -113.429412
#
#   Source Type Diversion Type        Use Type Units  Jan  Feb  Mar  Apr  May  \
# 0      Spring     Withdrawal  Water Supplier   NaN  NaN  NaN  NaN  NaN  NaN
#
#    Jun  Jul  Aug  Sep  Oct  Nov  Dec  Total in_WaterSourceTypeCV
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN        Surface Water

# %%
# Output dataframe for Culinary Service Area Data

df_sourOut = pd.DataFrame(index=df_sour.index)
df_sourOut['linkKey'] = df_sour['System ID']

# # Variable Info
# df_sourOut['in_VariableSpecificCV'] = "Water Use " + df_sour['Diversion Type']

# Water Source Info
df_sourOut['in_WaterSourceTypeCV'] = df_sour['in_WaterSourceTypeCV']

# Site Info
df_sourOut['in_CoordinateMethodCV'] = "Representation Node"
df_sourOut['in_Latitude'] = df_sour['Lat NAD83'].astype(float)
df_sourOut['in_Longitude'] = df_sour['Lon NAD83'].astype(float)
df_sourOut['in_PODorPOUSite'] = "POD"
df_sourOut['in_SiteName'] = df_sour['Source Name']
df_sourOut['in_SiteNativeID'] =df_sour['Source ID']
df_sourOut['in_SiteTypeCV'] = df_sour['Source Type']

df_sourOut = df_sourOut.replace(np.nan, "").drop_duplicates().reset_index(drop=True)
print(len(df_sourOut))
df_sourOut.head(1)
# Out:
# 7041
#    linkKey in_WaterSourceTypeCV in_CoordinateMethodCV in_Latitude  \
# 0     1000        Surface Water   Representation Node   37.309077
#
#   in_Longitude in_PODorPOUSite               in_SiteName  in_SiteNativeID  \
# 0  -113.429412             POD  Oak Grove Spring (WS001)         10000001
#
#   in_SiteTypeCV
# 0        Spring

# %% [markdown]
# ### UDWRe Culinary Service Area Data

# %%
# Dataframe Creation - UDWRe site information
csa_Input = "UDWRe_CulinaryWaterServiceAreas_input.csv"
df_csa = pd.read_csv(csa_Input, encoding = "ISO-8859-1")
df_csa.head(1)
# Out:
#    FID_1   WRENAME    WRNAME    DWNAME SYSTEMTYPE  WATERRESID   WRID  \
# 0      1  Irontown  Irontown  Irontown          C         564  11358
#
#     DWSYSNUM                                             WRLINK WHOLESALER  \
# 0  UTAH11070  http://waterrights.utah.gov/cgi-bin/wuseview.e...
#
#   LABEL STATE COUNTY         BASIN   SUBAREA        SUBAREANAM      LANUM  \
# 0        Utah   Iron  Cedar/Beaver  6/3/2001  Escalante Desert  06-03-01a
#
#              LANAME  ENDYEAR     DATASOURCE      SOURCEDATE     EDITOR  \
# 0  Escalante Desert     2019  DWRe/Supplier  5/21/2019 0:00  ADAMCLARK
#
#           EDITDATE   SHAPE_Leng  Shape__Are   Shape__Len  Shape_Length  \
# 0  10/19/2020 0:00  5567.248025  656517.818  5567.248025   5567.248025
#
#     Shape_Area  Longitude   Latitude
# 0  656517.8179 -113.44603  37.602583

# %%
# Output dataframe for Culinary Service Area Data

df_csaOut = pd.DataFrame(index=df_csa.index)
df_csaOut['linkKey'] = df_csa['WRID']

# # Variable Info
# df_csaOut['in_VariableSpecificCV'] = "Water Use Unspecified"

# Water Source Info
df_csaOut['in_WaterSourceTypeCV'] = "Unspecified"

# Site Info
df_csaOut['in_CoordinateMethodCV'] = "Centroid of Area"
df_csaOut['in_Latitude'] = df_csa['Latitude'].astype(float)
df_csaOut['in_Longitude'] = df_csa['Longitude'].astype(float)
df_csaOut['in_PODorPOUSite'] = "POU"
df_csaOut['in_SiteName'] = df_csa['WRENAME']
df_csaOut['in_SiteNativeID'] = df_csa['WRID']
#df_csaOut['in_SiteTypeCV'] = df_csa['SYSTEMTYPE']
df_csaOut['in_SiteTypeCV'] = "Unspecified"

df_csaOut = df_csaOut.replace(np.nan, "").drop_duplicates().reset_index(drop=True)
print(len(df_csaOut))
df_csaOut.head(1)
# Out:
# 1294
#    linkKey in_WaterSourceTypeCV in_CoordinateMethodCV  in_Latitude  \
# 0    11358          Unspecified      Centroid of Area    37.602583
#
#    in_Longitude in_PODorPOUSite in_SiteName  in_SiteNativeID in_SiteTypeCV
# 0    -113.44603             POU    Irontown            11358   Unspecified

# %% [markdown]
# ### Concatenate  UDWRi Source Data with DWRe Culinary Service Area Data to create one long dataframe

# %%
# Concatenate System Data into one long dataframe.
frames = [df_sourOut, df_csaOut]
df_site = pd.concat(frames)

df_site = df_site.replace(np.nan, "").drop_duplicates().reset_index(drop=True)
print(len(df_site))
df_site
# Out:
# 8335
#       linkKey in_WaterSourceTypeCV in_CoordinateMethodCV in_Latitude  \
# 0        1000        Surface Water   Representation Node   37.309077
# 1        1000          Groundwater   Representation Node   37.267014
# 2        1000          Groundwater   Representation Node   37.265809
# 3        1001          Groundwater   Representation Node   41.169959
# 4        1001          Groundwater   Representation Node   41.164615
# ...       ...                  ...                   ...         ...
# 8330        0          Unspecified      Centroid of Area   37.559081
# 8331        0          Unspecified      Centroid of Area   40.641739
# 8332    11472          Unspecified      Centroid of Area   40.693258
# 8333    11608          Unspecified      Centroid of Area   37.709078
# 8334    11615          Unspecified      Centroid of Area   40.402443
#
#      in_Longitude in_PODorPOUSite  \
# 0     -113.429412             POD
# 1      -113.36306             POD
# 2     -113.351593             POD
# 3     -112.005634             POD
# 4     -112.005275             POD
# ...           ...             ...
# 8330  -113.225921             POU
# 8331  -111.971124             POU
# 8332    -112.2603             POU
# 8333  -113.080866             POU
# 8334   -111.90741             POU
#
#                                             in_SiteName  in_SiteNativeID  \
# 0                              Oak Grove Spring (WS001)         10000001
# 1                                    Leeds Well (WS002)         10000002
# 2              El Dorado Hills Well (8 in, 335 ft deep)        108540479
# 3                           5190S 1050W #1 Well (WS003)         10010001
# 4                                        Golf Well (6`)         10010002
# ...                                                 ...              ...
# 8330                                Harmony Mtn Ranches                0
# 8331                             Summit Vista Water Co.                0
# 8332                              BCI-LP Holdings, L.C.            11472
# 8333  Staker Parsons Co. - Western Rock Products (Ce...            11608
# 8334                         River Jordan Mink Ranch 54            11615
#
#      in_SiteTypeCV
# 0           Spring
# 1             Well
# 2             Well
# 3             Well
# 4             Well
# ...            ...
# 8330   Unspecified
# 8331   Unspecified
# 8332   Unspecified
# 8333   Unspecified
# 8334   Unspecified
#
# [8335 rows x 9 columns]

# %% [markdown]
# ### Merge UDWRi System Data with site Data
# - Need to do an left outer join, then remove NULL rows

# %%
# Create output dataframe.  Merge the two dataframes into one.
dfout = pd.merge(df_sys_all, df_site, left_on='System ID', right_on='linkKey', how='left')

dfout = dfout.replace(np.nan, "").drop_duplicates().reset_index(drop=True)
print(len(dfout))
dfout
# Out:
# 926235
#                                    System Name  System ID System Type  \
# 0       Leeds Domestic Water Users Association       1000      Public
# 1       Leeds Domestic Water Users Association       1000      Public
# 2       Leeds Domestic Water Users Association       1000      Public
# 3       Leeds Domestic Water Users Association       1000      Public
# 4       Leeds Domestic Water Users Association       1000      Public
# ...                                        ...        ...         ...
# 926230                   Magnum Holdings, LLC.      11716  Industrial
# 926231                   Magnum Holdings, LLC.      11716  Industrial
# 926232                   Magnum Holdings, LLC.      11716  Industrial
# 926233                   Magnum Holdings, LLC.      11716  Industrial
# 926234                   Magnum Holdings, LLC.      11716  Industrial
#
#        System Status  History Year Date Received      County Acres Irrigated  \
# 0             Active          2019     1/22/2020  Washington
# 1             Active          2019     1/22/2020  Washington
# 2             Active          2019     1/22/2020  Washington
# 3             Active          2019     1/22/2020  Washington
# 4             Active          2018     4/30/2019  Washington
# ...              ...           ...           ...         ...             ...
# 926230        Active          2019     10/2/2020     Millard             0.0
# 926231        Active          2019     10/2/2020     Millard             0.0
# 926232        Active          2019     10/2/2020     Millard             0.0
# 926233        Active          2019     10/2/2020     Millard             0.0
# 926234        Active          2019     10/2/2020     Millard             0.0
#
#        Irrigation (Agriculture) Acres Irrigated.1 DEQ ID Population  WaterUse  \
# 0                                                  27010      800.0  62166.25
# 1                                                  27010      800.0  62166.25
# 2                                                  27010      800.0  62166.25
# 3                                                  27010      800.0  62166.25
# 4                                                  27010      800.0  61670.86
# ...                         ...               ...    ...        ...       ...
# 926230                      0.0               0.0
# 926231                      0.0               0.0
# 926232                      0.0               0.0
# 926233                      0.0               0.0
# 926234                      0.0               0.0
#
#        NumOfConnections        BenUse in_VariableSpecificCV in_CustomerTypeCV  \
# 0                 349.0      Domestic              Domestic          Domestic
# 1                 349.0      Domestic              Domestic          Domestic
# 2                 349.0      Domestic              Domestic          Domestic
# 3                 349.0      Domestic              Domestic          Domestic
# 4                 335.0      Domestic              Domestic          Domestic
# ...                 ...           ...                   ...               ...
# 926230                   Total (DCII)          Total (DCII)             Total
# 926231                   Total (DCII)          Total (DCII)             Total
# 926232                   Total (DCII)          Total (DCII)             Total
# 926233                   Total (DCII)          Total (DCII)             Total
# 926234                   Total (DCII)          Total (DCII)             Total
#
#         linkKey in_WaterSourceTypeCV in_CoordinateMethodCV in_Latitude  \
# 0          1000        Surface Water   Representation Node   37.309077
# 1          1000          Groundwater   Representation Node   37.267014
# 2          1000          Groundwater   Representation Node   37.265809
# 3          1000          Unspecified      Centroid of Area   37.237197
# 4          1000        Surface Water   Representation Node   37.309077
# ...         ...                  ...                   ...         ...
# 926230    11716          Groundwater   Representation Node   39.488348
# 926231    11716          Groundwater   Representation Node   39.486722
# 926232    11716          Groundwater   Representation Node   39.494021
# 926233    11716          Groundwater   Representation Node   39.486279
# 926234    11716          Groundwater   Representation Node   39.471903
#
#        in_Longitude in_PODorPOUSite                               in_SiteName  \
# 0       -113.429412             POD                  Oak Grove Spring (WS001)
# 1        -113.36306             POD                        Leeds Well (WS002)
# 2       -113.351593             POD  El Dorado Hills Well (8 in, 335 ft deep)
# 3       -113.347061             POU         Leeds Domestic Water Users Assoc.
# 4       -113.429412             POD                  Oak Grove Spring (WS001)
# ...             ...             ...                                       ...
# 926230  -112.604034             POD                                  Well #10
# 926231  -112.611788             POD                           Well #11 (MH-5)
# 926232  -112.612465             POD                            Well #6 (MH-1)
# 926233  -112.624303             POD                                  Well #12
# 926234   -112.59327             POD                                  Well #13
#
#         in_SiteNativeID in_SiteTypeCV
# 0              10000001        Spring
# 1              10000002          Well
# 2             108540479          Well
# 3                  1000   Unspecified
# 4              10000001        Spring
# ...                 ...           ...
# 926230        108545955          Well
# 926231        108545956          Well
# 926232        108545957          Well
# 926233        108545958          Well
# 926234        108545959          Well
#
# [926235 rows x 26 columns]

# %%
# Convert History Year to string.
# Create WaDE Timeframe start and end date.  Assume start = 01/01 & end =  12/31 for now.

dfout['History Year'] = dfout['History Year'].astype(str)
dfout['in_TimeframeEnd'] = '12/31/' + dfout['History Year']
dfout['in_TimeframeStart'] = '01/01/' + dfout['History Year']

dfout['in_TimeframeEnd'] = pd.to_datetime(dfout['in_TimeframeEnd'], errors = 'coerce')
dfout['in_TimeframeEnd'] = pd.to_datetime(dfout["in_TimeframeEnd"].dt.strftime('%m/%d/%Y'))

dfout['in_TimeframeStart'] = pd.to_datetime(dfout['in_TimeframeStart'], errors = 'coerce')
dfout['in_TimeframeStart'] = pd.to_datetime(dfout["in_TimeframeStart"].dt.strftime('%m/%d/%Y'))

dfout.head(1)
# Out:
#                               System Name  System ID System Type  \
# 0  Leeds Domestic Water Users Association       1000      Public
#
#   System Status History Year Date Received      County Acres Irrigated  \
# 0        Active         2019     1/22/2020  Washington
#
#   Irrigation (Agriculture) Acres Irrigated.1 DEQ ID Population  WaterUse  \
# 0                                             27010      800.0  62166.25
#
#   NumOfConnections    BenUse in_VariableSpecificCV in_CustomerTypeCV  linkKey  \
# 0            349.0  Domestic              Domestic          Domestic     1000
#
#   in_WaterSourceTypeCV in_CoordinateMethodCV in_Latitude in_Longitude  \
# 0        Surface Water   Representation Node   37.309077  -113.429412
#
#   in_PODorPOUSite               in_SiteName  in_SiteNativeID in_SiteTypeCV  \
# 0             POD  Oak Grove Spring (WS001)         10000001        Spring
#
#   in_TimeframeEnd in_TimeframeStart
# 0      2019-12-31        2019-01-01

# %%
# # Converting Population to float value.
# dfout['Population'] = dfout['Population'].astype(float).replace(np.nan, 0, regex=True)
# dfout['Population'] = dfout['Population'].astype(int)
# dfout['Population']

# %% [markdown]
# ## WaDE Custom Elements (due to missing info)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDEUT_WS" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = dfout['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A):
    if (A == '') or (pd.isnull(A)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceTypeCV'] == A), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfout['in_WaterSourceNativeID'] = dfout.apply(lambda row: retrieveWaterSourceNativeID(row['in_WaterSourceTypeCV']), axis=1)
dfout
# Out:
#                                    System Name  System ID System Type  \
# 0       Leeds Domestic Water Users Association       1000      Public
# 1       Leeds Domestic Water Users Association       1000      Public
# 2       Leeds Domestic Water Users Association       1000      Public
# 3       Leeds Domestic Water Users Association       1000      Public
# 4       Leeds Domestic Water Users Association       1000      Public
# ...                                        ...        ...         ...
# 926230                   Magnum Holdings, LLC.      11716  Industrial
# 926231                   Magnum Holdings, LLC.      11716  Industrial
# 926232                   Magnum Holdings, LLC.      11716  Industrial
# 926233                   Magnum Holdings, LLC.      11716  Industrial
# 926234                   Magnum Holdings, LLC.      11716  Industrial
#
#        System Status History Year Date Received      County Acres Irrigated  \
# 0             Active         2019     1/22/2020  Washington
# 1             Active         2019     1/22/2020  Washington
# 2             Active         2019     1/22/2020  Washington
# 3             Active         2019     1/22/2020  Washington
# 4             Active         2018     4/30/2019  Washington
# ...              ...          ...           ...         ...             ...
# 926230        Active         2019     10/2/2020     Millard             0.0
# 926231        Active         2019     10/2/2020     Millard             0.0
# 926232        Active         2019     10/2/2020     Millard             0.0
# 926233        Active         2019     10/2/2020     Millard             0.0
# 926234        Active         2019     10/2/2020     Millard             0.0
#
#        Irrigation (Agriculture) Acres Irrigated.1 DEQ ID Population  WaterUse  \
# 0                                                  27010      800.0  62166.25
# 1                                                  27010      800.0  62166.25
# 2                                                  27010      800.0  62166.25
# 3                                                  27010      800.0  62166.25
# 4                                                  27010      800.0  61670.86
# ...                         ...               ...    ...        ...       ...
# 926230                      0.0               0.0
# 926231                      0.0               0.0
# 926232                      0.0               0.0
# 926233                      0.0               0.0
# 926234                      0.0               0.0
#
#        NumOfConnections        BenUse in_VariableSpecificCV in_CustomerTypeCV  \
# 0                 349.0      Domestic              Domestic          Domestic
# 1                 349.0      Domestic              Domestic          Domestic
# 2                 349.0      Domestic              Domestic          Domestic
# 3                 349.0      Domestic              Domestic          Domestic
# 4                 335.0      Domestic              Domestic          Domestic
# ...                 ...           ...                   ...               ...
# 926230                   Total (DCII)          Total (DCII)             Total
# 926231                   Total (DCII)          Total (DCII)             Total
# 926232                   Total (DCII)          Total (DCII)             Total
# 926233                   Total (DCII)          Total (DCII)             Total
# 926234                   Total (DCII)          Total (DCII)             Total
#
#         linkKey in_WaterSourceTypeCV in_CoordinateMethodCV in_Latitude  \
# 0          1000        Surface Water   Representation Node   37.309077
# 1          1000          Groundwater   Representation Node   37.267014
# 2          1000          Groundwater   Representation Node   37.265809
# 3          1000          Unspecified      Centroid of Area   37.237197
# 4          1000        Surface Water   Representation Node   37.309077
# ...         ...                  ...                   ...         ...
# 926230    11716          Groundwater   Representation Node   39.488348
# 926231    11716          Groundwater   Representation Node   39.486722
# 926232    11716          Groundwater   Representation Node   39.494021
# 926233    11716          Groundwater   Representation Node   39.486279
# 926234    11716          Groundwater   Representation Node   39.471903
#
#        in_Longitude in_PODorPOUSite                               in_SiteName  \
# 0       -113.429412             POD                  Oak Grove Spring (WS001)
# 1        -113.36306             POD                        Leeds Well (WS002)
# 2       -113.351593             POD  El Dorado Hills Well (8 in, 335 ft deep)
# 3       -113.347061             POU         Leeds Domestic Water Users Assoc.
# 4       -113.429412             POD                  Oak Grove Spring (WS001)
# ...             ...             ...                                       ...
# 926230  -112.604034             POD                                  Well #10
# 926231  -112.611788             POD                           Well #11 (MH-5)
# 926232  -112.612465             POD                            Well #6 (MH-1)
# 926233  -112.624303             POD                                  Well #12
# 926234   -112.59327             POD                                  Well #13
#
#         in_SiteNativeID in_SiteTypeCV in_TimeframeEnd in_TimeframeStart  \
# 0              10000001        Spring      2019-12-31        2019-01-01
# 1              10000002          Well      2019-12-31        2019-01-01
# 2             108540479          Well      2019-12-31        2019-01-01
# 3                  1000   Unspecified      2019-12-31        2019-01-01
# 4              10000001        Spring      2018-12-31        2018-01-01
# ...                 ...           ...             ...               ...
# 926230        108545955          Well      2019-12-31        2019-01-01
# 926231        108545956          Well      2019-12-31        2019-01-01
# 926232        108545957          Well      2019-12-31        2019-01-01
# 926233        108545958          Well      2019-12-31        2019-01-01
# 926234        108545959          Well      2019-12-31        2019-01-01
#
#        in_WaterSourceNativeID
# 0                  WaDEUT_WS1
# 1                  WaDEUT_WS2
# 2                  WaDEUT_WS2
# 3                  WaDEUT_WS3
# 4                  WaDEUT_WS1
# ...                       ...
# 926230             WaDEUT_WS2
# 926231             WaDEUT_WS2
# 926232             WaDEUT_WS2
# 926233             WaDEUT_WS2
# 926234             WaDEUT_WS2
#
# [926235 rows x 29 columns]

# %%
# Converting Population to float value.
dfout['Population'] = dfout['Population'].replace(np.nan, 0, regex=True)
dfout['Population'] = dfout['Population'].replace('', 0, regex=True)
dfout['Population'] = dfout['Population'].astype(int)
dfout['Population']
# Out:
# 0         800
# 1         800
# 2         800
# 3         800
# 4         800
#          ...
# 926230      0
# 926231      0
# 926232      0
# 926233      0
# 926234      0
# Name: Population, Length: 926235, dtype: int32

# %%
#check datatype
print(len(dfout))
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(dfout.dtypes)
# Out:
# 926235
# System Name                         object
# System ID                            int64
# System Type                         object
# System Status                       object
# History Year                        object
# Date Received                       object
# County                              object
# Acres Irrigated                     object
# Irrigation (Agriculture)            object
# Acres Irrigated.1                   object
# DEQ ID                              object
# Population                           int32
# WaterUse                            object
# NumOfConnections                    object
# BenUse                              object
# in_VariableSpecificCV               object
# in_CustomerTypeCV                   object
# linkKey                              int64
# in_WaterSourceTypeCV                object
# in_CoordinateMethodCV               object
# in_Latitude                         object
# in_Longitude                        object
# in_PODorPOUSite                     object
# in_SiteName                         object
# in_SiteNativeID                      int64
# in_SiteTypeCV                       object
# in_TimeframeEnd             datetime64[ns]
# in_TimeframeStart           datetime64[ns]
# in_WaterSourceNativeID              object
# dtype: object

# %%
# Exporting output files.
dfout.to_csv('P_MasterUTSiteSpecific.csv', index=False)  # The output.
