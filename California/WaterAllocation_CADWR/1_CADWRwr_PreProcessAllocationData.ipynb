# %% [markdown]
# # Pre-processing California Department of Water Resources Allocation data for WaDE upload.
# - Purpose:  To pre-process the data into one master file for simple DataFrame creation and extraction

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# Working Directory
print(os.getcwd()) # see the current working directory

# set working directory, if need be
workingDir = "G:/Shared drives/WaDE Data/California/WaterAllocation_CADWR" # file location
os.chdir(workingDir)
print(os.getcwd())
# Out:
# C:\Users\rjame\Documents\WSWC Documents\MappingStatesDataToWaDE2.0\California\WaterAllocation_CADWR
# G:\Shared drives\WaDE Data\California\WaterAllocation_CADWR

# %% [markdown]
# ## Point of Diversion Data

# %%
# Input File - wellcompletionreports
FI_PoD = "RawInputData/WellCompletionReports.zip"
# dfinPOD = pd.read_csv(FI_PoD, encoding = "ISO-8859-1").replace(np.nan, "")
dfinPOD = pd.read_csv(FI_PoD).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "cnra" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('RawInputData/WellCompletionReports.zip', compression=dict(method='zip', archive_name='WellCompletionReports.csv'), index=False)

print(len(dfinPOD))
dfinPOD.head()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_17516\2834921686.py:4: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfinPOD = pd.read_csv(FI_PoD).replace(np.nan, "")
# 1074973
#    _id       WCRNUMBER LEGACYLOGNUMBER                     REGIONOFFICE  \
# 0    1  WCR1997-004295          525475  DWR North Central Region Office
# 1    2  WCR1997-004359          525154  DWR North Central Region Office
# 2    3  WCR1996-001972          449388  DWR North Central Region Office
# 3    4  WCR1996-001974          449390  DWR North Central Region Office
# 4    5  WCR1996-000021         01-567E  DWR North Central Region Office
#
#   COUNTYNAME                                  LOCALPERMITAGENCY PERMITDATE  \
# 0    Alameda                      Alameda County Water District
# 1    Alameda  Alameda County Public Works Agency, Water Reso...
# 2    Alameda                      Alameda County Water District
# 3    Alameda  Alameda County Public Works Agency, Water Reso...
# 4    Alameda  Zone 7 Water Agency - Alameda County Flood Con...
#
#   PERMITNUMBER OWNERASSIGNEDWELLNUMBER      WELLLOCATION       CITY  \
# 0                                                            NEWARK
# 1                                                           OAKLAND
# 2                                       35735 CEDAR BLVD     NEWARK
# 3                                                           OAKLAND
# 4                                                         LIVERMORE
#
#   PLANNEDUSEFORMERUSE                                        DRILLERNAME  \
# 0          Monitoring  GREGG DRILLING & TESTING, GREGG DRILLING & TES...
# 1             Unknown                MITCHELL DRILLING MITCHELL DRILLING
# 2             Unknown  MARTELL WATER SYSTEMS INC MARTELL WATER SYSTEM...
# 3             Unknown  MARTELL WATER SYSTEMS INC MARTELL WATER SYSTEM...
# 4             Unknown  WOODWARD DRILLING COMPANY WOODWARD DRILLING CO...
#
#   DRILLERLICENSENUMBER                                      RECORDTYPE  \
# 0               485165  WellCompletion/New/Production or Monitoring/NA
# 1               672617                WellCompletion/Destruction/NA/NA
# 2               510952                WellCompletion/Destruction/NA/NA
# 3               510952                WellCompletion/Destruction/NA/NA
# 4               710079                WellCompletion/Destruction/NA/NA
#
#   DECIMALLATITUDE DECIMALLONGITUDE METHODOFDETERMINATIONLL  \
# 0        37.52790       -122.01500        Derived from TRS
# 1
# 2        37.55670       -122.03300        Derived from TRS
# 3
# 4        37.65820       -121.77900        Derived from TRS
#
#             LLACCURACY HORIZONTALDATUM GROUNDSURFACEELEVATION  \
# 0  Centroid of Section
# 1
# 2  Centroid of Section
# 3
# 4  Centroid of Section
#
#   ELEVATIONACCURACY ELEVATIONDETERMINATIONMETHOD VERTICALDATUM TOWNSHIP RANGE  \
# 0                                                                   05S   01W
# 1
# 2                                                                   04S   02W
# 3
# 4                                                                   03S   02E
#
#   SECTION BASELINEMERIDIAN APN        DATEWORKENDED WORKFLOWSTATUS  \
# 0      06     Mount Diablo      1997-04-17T00:00:00
# 1             Mount Diablo      1997-10-15T00:00:00
# 2      25     Mount Diablo      1996-08-24T00:00:00
# 3             Mount Diablo      1996-09-06T00:00:00
# 4      20     Mount Diablo      1996-04-03T00:00:00
#
#   RECEIVEDDATE TOTALDRILLDEPTH TOTALCOMPLETEDDEPTH TOPOFPERFORATEDINTERVAL  \
# 0                                         15.00000
# 1
# 2
# 3
# 4
#
#   BOTTOMOFPERFORATEDINTERVAL CASINGDIAMETER DRILLINGMETHOD FLUID  \
# 0
# 1
# 2
# 3                                   8.00000
# 4
#
#   STATICWATERLEVEL TOTALDRAWDOWN TESTTYPE PUMPTESTLENGTH WELLYIELD  \
# 0
# 1
# 2
# 3
# 4
#
#   WELLYIELDUNITOFMEASURE OTHEROBSERVATIONS WaDEUUID
# 0                                             cnra0
# 1                                             cnra1
# 2                                             cnra2
# 3                                             cnra3
# 4                                             cnra4

# %%
# Input File - wellreportpdflinks

lCsv = "RawInputData/WellCompletionReportPDFLinks.zip"# to match wrcn to state well number
linkCsv = pd.read_csv(lCsv, encoding = "ISO-8859-1").replace(np.nan, "")

# merge with wellcompletionreports
dfinPOD2 = pd.merge(dfinPOD, linkCsv, left_on='WCRNUMBER', right_on='WCRNumber',how='left')
dfinPOD2 = dfinPOD2.drop_duplicates().replace(np.nan, "").replace("nan,nan", "").reset_index(drop=True)
print(len(dfinPOD2))
dfinPOD2.head()
# Out:
# 1142777
#    _id       WCRNUMBER LEGACYLOGNUMBER                     REGIONOFFICE  \
# 0    1  WCR1997-004295          525475  DWR North Central Region Office
# 1    2  WCR1997-004359          525154  DWR North Central Region Office
# 2    3  WCR1996-001972          449388  DWR North Central Region Office
# 3    3  WCR1996-001972          449388  DWR North Central Region Office
# 4    4  WCR1996-001974          449390  DWR North Central Region Office
#
#   COUNTYNAME                                  LOCALPERMITAGENCY PERMITDATE  \
# 0    Alameda                      Alameda County Water District
# 1    Alameda  Alameda County Public Works Agency, Water Reso...
# 2    Alameda                      Alameda County Water District
# 3    Alameda                      Alameda County Water District
# 4    Alameda  Alameda County Public Works Agency, Water Reso...
#
#   PERMITNUMBER OWNERASSIGNEDWELLNUMBER      WELLLOCATION     CITY  \
# 0                                                          NEWARK
# 1                                                         OAKLAND
# 2                                       35735 CEDAR BLVD   NEWARK
# 3                                       35735 CEDAR BLVD   NEWARK
# 4                                                         OAKLAND
#
#   PLANNEDUSEFORMERUSE                                        DRILLERNAME  \
# 0          Monitoring  GREGG DRILLING & TESTING, GREGG DRILLING & TES...
# 1             Unknown                MITCHELL DRILLING MITCHELL DRILLING
# 2             Unknown  MARTELL WATER SYSTEMS INC MARTELL WATER SYSTEM...
# 3             Unknown  MARTELL WATER SYSTEMS INC MARTELL WATER SYSTEM...
# 4             Unknown  MARTELL WATER SYSTEMS INC MARTELL WATER SYSTEM...
#
#   DRILLERLICENSENUMBER                                      RECORDTYPE  \
# 0               485165  WellCompletion/New/Production or Monitoring/NA
# 1               672617                WellCompletion/Destruction/NA/NA
# 2               510952                WellCompletion/Destruction/NA/NA
# 3               510952                WellCompletion/Destruction/NA/NA
# 4               510952                WellCompletion/Destruction/NA/NA
#
#   DECIMALLATITUDE DECIMALLONGITUDE METHODOFDETERMINATIONLL  \
# 0        37.52790       -122.01500        Derived from TRS
# 1
# 2        37.55670       -122.03300        Derived from TRS
# 3        37.55670       -122.03300        Derived from TRS
# 4
#
#             LLACCURACY HORIZONTALDATUM GROUNDSURFACEELEVATION  \
# 0  Centroid of Section
# 1
# 2  Centroid of Section
# 3  Centroid of Section
# 4
#
#   ELEVATIONACCURACY ELEVATIONDETERMINATIONMETHOD VERTICALDATUM TOWNSHIP RANGE  \
# 0                                                                   05S   01W
# 1
# 2                                                                   04S   02W
# 3                                                                   04S   02W
# 4
#
#   SECTION BASELINEMERIDIAN APN        DATEWORKENDED WORKFLOWSTATUS  \
# 0      06     Mount Diablo      1997-04-17T00:00:00
# 1             Mount Diablo      1997-10-15T00:00:00
# 2      25     Mount Diablo      1996-08-24T00:00:00
# 3      25     Mount Diablo      1996-08-24T00:00:00
# 4             Mount Diablo      1996-09-06T00:00:00
#
#   RECEIVEDDATE TOTALDRILLDEPTH TOTALCOMPLETEDDEPTH TOPOFPERFORATEDINTERVAL  \
# 0                                         15.00000
# 1
# 2
# 3
# 4
#
#   BOTTOMOFPERFORATEDINTERVAL CASINGDIAMETER DRILLINGMETHOD FLUID  \
# 0
# 1
# 2
# 3
# 4                                   8.00000
#
#   STATICWATERLEVEL TOTALDRAWDOWN TESTTYPE PUMPTESTLENGTH WELLYIELD  \
# 0
# 1
# 2
# 3
# 4
#
#   WELLYIELDUNITOFMEASURE OTHEROBSERVATIONS WaDEUUID       ï»¿_id  \
# 0                                             cnra0 642370.00000
# 1                                             cnra1
# 2                                             cnra2 630570.00000
# 3                                             cnra2 630571.00000
# 4                                             cnra3
#
#         WCRNumber                                            WCRLink
# 0  WCR1997-004295  https://cadwr.app.box.com/v/WellCompletionRepo...
# 1
# 2  WCR1996-001972  https://cadwr.app.box.com/v/WellCompletionRepo...
# 3  WCR1996-001972  https://cadwr.app.box.com/v/WellCompletionRepo...
# 4

# %%
#removing these records
dfinPOD2 = dfinPOD2[dfinPOD2['RECORDTYPE'] != 'WellCompletion/Destruction/NA/NA']
dfinPOD2 = dfinPOD2[dfinPOD2['RECORDTYPE'] != 'WellCompletion/Drill and Destroy/NA/NA']
print(len(dfinPOD2))
# Out:
# 953914

# %%
# create output POD dataframe
df = pd.DataFrame()


# Data Assessment UUID
df['WaDEUUID'] = dfinPOD2['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "CADWRwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "CADWRwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "CADWRwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = "Fresh"
df['in_WaterSourceName'] = ""
df['in_WaterSourceNativeID'] = "" # auto fill in below if not provdied
df['in_WaterSourceTypeCV'] = "Groundwater"

# Site Info
df['in_CoordinateAccuracy'] = dfinPOD2['LLACCURACY']
df['in_CoordinateMethodCV'] = "Digitized"
df['in_County'] = dfinPOD2['COUNTYNAME']
df['in_EPSGCodeCV'] = "4326"
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfinPOD2['DECIMALLATITUDE']
df['in_Longitude'] = dfinPOD2['DECIMALLONGITUDE']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"  # "Point of Diversion"
df['in_SiteName'] = dfinPOD2['OWNERASSIGNEDWELLNUMBER']
df['in_SiteNativeID'] = ""
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = "Well"
df['in_StateCV'] = "CA"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = ""
df['in_AllocationLegalStatusCV'] = ""
df['in_AllocationNativeID'] =  dfinPOD2['WCRNUMBER']
df['in_AllocationOwner'] = "" 
df['in_AllocationPriorityDate'] = ""
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = "Correlative Rights"
df['in_AllocationVolume_AF'] = ""
df['in_BeneficialUseCategory'] = dfinPOD2['PLANNEDUSEFORMERUSE']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = "1" # either a 1 or 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = dfinPOD2['LEGACYLOGNUMBER']
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = dfinPOD2['WCRLink']

outPOD = df.copy()
outPOD = outPOD.drop_duplicates().reset_index(drop=True)
print(len(outPOD))
outPOD.tail()
# Out:
# 953519
#            WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 953514  cnra1074968    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 953515  cnra1074969    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 953516  cnra1074970    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 953517  cnra1074971    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 953518  cnra1074972    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
#
#        in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 953514                                                       Fresh
# 953515                                                       Fresh
# 953516                                                       Fresh
# 953517                                                       Fresh
# 953518                                                       Fresh
#
#        in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 953514                                                    Groundwater
# 953515                                                    Groundwater
# 953516                                                    Groundwater
# 953517                                                    Groundwater
# 953518                                                    Groundwater
#
#        in_CoordinateAccuracy in_CoordinateMethodCV in_County in_EPSGCodeCV  \
# 953514                >50 FT             Digitized                    4326
# 953515                                   Digitized                    4326
# 953516               Unknown             Digitized                    4326
# 953517                                   Digitized                    4326
# 953518               Unknown             Digitized                    4326
#
#        in_GNISCodeCV in_HUC12 in_HUC8 in_Latitude in_Longitude  \
# 953514                                   36.38122   -119.29016
# 953515
# 953516                                   38.31187   -121.82957
# 953517
# 953518                                   37.53622   -121.93128
#
#        in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 953514                                                   POD
# 953515                                                   POD        2275
# 953516                                                   POD        PZ-8
# 953517                                                   POD           1
# 953518                                                   POD        W035
#
#        in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 953514                                       Well         CA
# 953515                                       Well         CA
# 953516                                       Well         CA
# 953517                                       Well         CA
# 953518                                       Well         CA
#
#        in_AllocationApplicationDate  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationChangeApplicationIndicator  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 953514                                   WCR2017-009452
# 953515                                   WCR2011-005405
# 953516                                   WCR2017-011186
# 953517                                   WCR2018-012226
# 953518                                   WCR2016-017626
#
#        in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationTimeframeEnd in_AllocationTimeframeStart  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationTypeCV in_AllocationVolume_AF in_BeneficialUseCategory  \
# 953514  Correlative Rights                           Water Supply Domestic
# 953515  Correlative Rights                           Water Supply Domestic
# 953516  Correlative Rights                                      Monitoring
# 953517  Correlative Rights                           Water Supply Domestic
# 953518  Correlative Rights                                         Unknown
#
#        in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_DataPublicationDate in_DataPublicationDOI  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 953514                             1
# 953515                             1
# 953516                             1
# 953517                             1
# 953518                             1
#
#        in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 953514                                                         E0371068
# 953515                                                         e0146791
# 953516                                                         E0353767
# 953517                                                         E0369132
# 953518                                                         E0314231
#
#        in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_WaterAllocationNativeURL
# 953514
# 953515
# 953516
# 953517
# 953518

# %%
# Concatenate dataframes
frames = [outPOD]  # list all out dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 953519

# %% [markdown]
# ## Clean Data / data types

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).replace("  ", " ").strip().rstrip(',')
    return Val

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras', 'Colusa',
#        'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno', 'Glenn',
#        'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Lassen',
#        'Los Angeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino',
#        'Merced', 'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange',
#        'Placer', 'Plumas', 'Riverside', 'Sacramento', 'San Benito',
#        'San Bernardino', 'San Diego', 'San Francisco', 'San Joaquin',
#        'San Luis Obispo', 'San Mateo', 'Santa Barbara', 'Santa Clara',
#        'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou', 'Solano', 'Sonoma',
#        'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Tuolumne',
#        'Ventura', 'Yolo', 'Yuba', 'Unknown', ''], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['', 'CPT04', 'MW3D', ..., 'JOHN TOSTE JR', '2275', 'W035'],
#       dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array([''], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['Well'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['', 'CPT04', 'MW3D', ..., 'JOHN TOSTE JR', '2275', 'W035'],
#       dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
uniqueList = list(set([i.strip() for i in ','.join(outdf['in_BeneficialUseCategory'].astype(str)).split(',')]))
uniqueList.sort()
uniqueList
# Out:
# ['',
#  'Cathodic Protection',
#  'Dewatering',
#  'Injection',
#  'Monitoring',
#  'Other',
#  'Remediation',
#  'Sparging',
#  'Test Well',
#  'Unknown',
#  'Vapor Extraction',
#  'Water Supply Domestic',
#  'Water Supply Industrial',
#  'Water Supply Irrigation - Agriculture',
#  'Water Supply Irrigation - Landscape',
#  'Water Supply Public',
#  'Water Supply Stock or Animal Watering']

# %%
# Ensure Latitude entry is either numireic or a 0
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([37.5279, 37.5421, '', ..., 36.381223, 38.311869, 37.536222],
#       dtype=object)

# %%
# Ensure Longitude entry is either numireic or a 0
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-122.015, -121.997, '', ..., -119.290159, -121.82957, -121.93128],
#       dtype=object)

# %%
# # Changing datatype of Priority Date to date fields entry
# outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'], errors = 'coerce')
# outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
# outdf['in_AllocationPriorityDate'].unique()

# %%
# Ensure Flow entry is either numireic or a 0
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([''], dtype=object)

# %%
# Ensure Volume entry is either numireic or a 0
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array([''], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], 
                                                                              row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1'], dtype=object)

# %%
# Creating WaDE Custom site native ID for easy site identification
# use Unique Latitude, Longitude, SiteName and SiteTypeCV values
# ----------------------------------------------------------------------------------------------------

# Create temp in_SiteNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_Latitude'] = outdf['in_Latitude'].astype(str).str.strip()
dfTempID['in_Longitude'] = outdf['in_Longitude'].astype(str).str.strip()
dfTempID['in_SiteName'] = outdf['in_SiteName'].astype(str).str.strip()
dfTempID['in_SiteTypeCV'] = outdf['in_SiteTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_SiteNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_Latitude'].astype(str) + dfTempID['in_Longitude'].astype(str) + dfTempID['in_SiteName'].astype(str)+ dfTempID['in_SiteTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_SiteNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB, valC, valD):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip() + str(valC).strip() + str(valD).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_SiteNativeID'], 
                                                                       row['in_Latitude'], row['in_Longitude'],
                                                                       row['in_SiteName'], row['in_SiteTypeCV']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', ..., 'wadeId298978',
#        'wadeId298979', 'wadeId298980'], dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For this {state name / organization}, we don't want water rights that are considered: "Inactive", "Revoked", "Pending", "Cancelled", "Rejected", "Closed"

# %%
# drop non-active AllocationLegalStatusCV values specific to that state.

# drop the list
dropLegalStatusList = ["Inactive", "Revoked", "Pending", "Cancelled", "Rejected", "Closed"] # enter string entries here

# drop rows from above list
outdf = outdf[outdf.in_AllocationLegalStatusCV.isin(dropLegalStatusList) == False].reset_index(drop=True)

print(len(outdf))
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# 953519
# array([''], dtype=object)

# %% [markdown]
# ## Export Data

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953519 entries, 0 to 953518
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   WaDEUUID                                      953519 non-null  object
#  1   in_MethodUUID                                 953519 non-null  object
#  2   in_VariableSpecificUUID                       953519 non-null  object
#  3   in_OrganizationUUID                           953519 non-null  object
#  4   in_Geometry                                   953519 non-null  object
#  5   in_GNISFeatureNameCV                          953519 non-null  object
#  6   in_WaterQualityIndicatorCV                    953519 non-null  object
#  7   in_WaterSourceName                            953519 non-null  object
#  8   in_WaterSourceNativeID                        953519 non-null  object
#  9   in_WaterSourceTypeCV                          953519 non-null  object
#  10  in_CoordinateAccuracy                         953519 non-null  object
#  11  in_CoordinateMethodCV                         953519 non-null  object
#  12  in_County                                     953519 non-null  object
#  13  in_EPSGCodeCV                                 953519 non-null  object
#  14  in_GNISCodeCV                                 953519 non-null  object
#  15  in_HUC12                                      953519 non-null  object
#  16  in_HUC8                                       953519 non-null  object
#  17  in_Latitude                                   953519 non-null  object
#  18  in_Longitude                                  953519 non-null  object
#  19  in_NHDNetworkStatusCV                         953519 non-null  object
#  20  in_NHDProductCV                               953519 non-null  object
#  21  in_PODorPOUSite                               953519 non-null  object
#  22  in_SiteName                                   953519 non-null  object
#  23  in_SiteNativeID                               953519 non-null  object
#  24  in_SitePoint                                  953519 non-null  object
#  25  in_SiteTypeCV                                 953519 non-null  object
#  26  in_StateCV                                    953519 non-null  object
#  27  in_USGSSiteID                                 953519 non-null  object
#  28  in_AllocationApplicationDate                  953519 non-null  object
#  29  in_AllocationAssociatedConsumptiveUseSiteIDs  953519 non-null  object
#  30  in_AllocationAssociatedWithdrawalSiteIDs      953519 non-null  object
#  31  in_AllocationBasisCV                          953519 non-null  object
#  32  in_AllocationChangeApplicationIndicator       953519 non-null  object
#  33  in_AllocationCommunityWaterSupplySystem       953519 non-null  object
#  34  in_AllocationCropDutyAmount                   953519 non-null  object
#  35  in_AllocationExpirationDate                   953519 non-null  object
#  36  in_AllocationFlow_CFS                         953519 non-null  object
#  37  in_AllocationLegalStatusCV                    953519 non-null  object
#  38  in_AllocationNativeID                         953519 non-null  object
#  39  in_AllocationOwner                            953519 non-null  object
#  40  in_AllocationPriorityDate                     953519 non-null  object
#  41  in_AllocationSDWISIdentifierCV                953519 non-null  object
#  42  in_AllocationTimeframeEnd                     953519 non-null  object
#  43  in_AllocationTimeframeStart                   953519 non-null  object
#  44  in_AllocationTypeCV                           953519 non-null  object
#  45  in_AllocationVolume_AF                        953519 non-null  object
#  46  in_BeneficialUseCategory                      953519 non-null  object
#  47  in_CommunityWaterSupplySystem                 953519 non-null  object
#  48  in_CropTypeCV                                 953519 non-null  object
#  49  in_CustomerTypeCV                             953519 non-null  object
#  50  in_DataPublicationDate                        953519 non-null  object
#  51  in_DataPublicationDOI                         953519 non-null  object
#  52  in_ExemptOfVolumeFlowPriority                 953519 non-null  object
#  53  in_GeneratedPowerCapacityMW                   953519 non-null  object
#  54  in_IrrigatedAcreage                           953519 non-null  object
#  55  in_IrrigationMethodCV                         953519 non-null  object
#  56  in_LegacyAllocationIDs                        953519 non-null  object
#  57  in_OwnerClassificationCV                      953519 non-null  object
#  58  in_PopulationServed                           953519 non-null  object
#  59  in_PowerType                                  953519 non-null  object
#  60  in_PrimaryBeneficialUseCategory               953519 non-null  object
#  61  in_SDWISIdentifierCV                          953519 non-null  object
#  62  in_WaterAllocationNativeURL                   953519 non-null  object
# dtypes: object(63)
# memory usage: 458.3+ MB

# %%
outdf
# Out:
#            WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0             cnra0    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 1             cnra5    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 2             cnra6    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 3             cnra9    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 4            cnra10    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# ...             ...           ...                     ...                 ...
# 953514  cnra1074968    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 953515  cnra1074969    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 953516  cnra1074970    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 953517  cnra1074971    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
# 953518  cnra1074972    CADWRwr_M1              CADWRwr_V1          CADWRwr_O1
#
#        in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0                                                            Fresh
# 1                                                            Fresh
# 2                                                            Fresh
# 3                                                            Fresh
# 4                                                            Fresh
# ...            ...                  ...                        ...
# 953514                                                       Fresh
# 953515                                                       Fresh
# 953516                                                       Fresh
# 953517                                                       Fresh
# 953518                                                       Fresh
#
#        in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                        wadeId1          Groundwater
# 1                                        wadeId1          Groundwater
# 2                                        wadeId1          Groundwater
# 3                                        wadeId1          Groundwater
# 4                                        wadeId1          Groundwater
# ...                   ...                    ...                  ...
# 953514                                   wadeId1          Groundwater
# 953515                                   wadeId1          Groundwater
# 953516                                   wadeId1          Groundwater
# 953517                                   wadeId1          Groundwater
# 953518                                   wadeId1          Groundwater
#
#        in_CoordinateAccuracy in_CoordinateMethodCV in_County in_EPSGCodeCV  \
# 0        Centroid of Section             Digitized   Alameda          4326
# 1        Centroid of Section             Digitized   Alameda          4326
# 2                                        Digitized   Alameda          4326
# 3                                        Digitized   Alameda          4326
# 4        Centroid of Section             Digitized   Alameda          4326
# ...                      ...                   ...       ...           ...
# 953514                >50 FT             Digitized                    4326
# 953515                                   Digitized                    4326
# 953516               Unknown             Digitized                    4326
# 953517                                   Digitized                    4326
# 953518               Unknown             Digitized                    4326
#
#        in_GNISCodeCV in_HUC12 in_HUC8 in_Latitude in_Longitude  \
# 0                                        37.52790   -122.01500
# 1                                        37.54210   -121.99700
# 2
# 3
# 4                                        37.74510   -122.19900
# ...              ...      ...     ...         ...          ...
# 953514                                   36.38122   -119.29016
# 953515
# 953516                                   38.31187   -121.82957
# 953517
# 953518                                   37.53622   -121.93128
#
#        in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                        POD
# 1                                                        POD
# 2                                                        POD
# 3                                                        POD
# 4                                                        POD
# ...                      ...             ...             ...         ...
# 953514                                                   POD
# 953515                                                   POD        2275
# 953516                                                   POD         PZ8
# 953517                                                   POD           1
# 953518                                                   POD        W035
#
#        in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0              wadeId1                       Well         CA
# 1              wadeId2                       Well         CA
# 2              wadeId3                       Well         CA
# 3              wadeId3                       Well         CA
# 4              wadeId4                       Well         CA
# ...                ...          ...           ...        ...           ...
# 953514    wadeId298977                       Well         CA
# 953515    wadeId298978                       Well         CA
# 953516    wadeId298979                       Well         CA
# 953517      wadeId1169                       Well         CA
# 953518    wadeId298980                       Well         CA
#
#        in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                             ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...                  ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                         ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...                   ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 0                                        WCR1997-004295
# 1                                        WCR1996-004199
# 2                                        WCR1996-004573
# 3                                        WCR1996-003330
# 4                                        WCR1992-006082
# ...                           ...                   ...                ...
# 953514                                   WCR2017-009452
# 953515                                   WCR2011-005405
# 953516                                   WCR2017-011186
# 953517                                   WCR2018-012226
# 953518                                   WCR2016-017626
#
#        in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                            ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationTimeframeEnd in_AllocationTimeframeStart  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                         ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_AllocationTypeCV in_AllocationVolume_AF in_BeneficialUseCategory  \
# 0       Correlative Rights                                      Monitoring
# 1       Correlative Rights                                      Monitoring
# 2       Correlative Rights                                Vapor Extraction
# 3       Correlative Rights                                Vapor Extraction
# 4       Correlative Rights                                      Monitoring
# ...                    ...                    ...                      ...
# 953514  Correlative Rights                           Water Supply Domestic
# 953515  Correlative Rights                           Water Supply Domestic
# 953516  Correlative Rights                                      Monitoring
# 953517  Correlative Rights                           Water Supply Domestic
# 953518  Correlative Rights                                         Unknown
#
#        in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...           ...               ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                   ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  1
# ...                              ...                         ...
# 953514                             1
# 953515                             1
# 953516                             1
# 953517                             1
# 953518                             1
#
#        in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0                                                                525475
# 1                                                                525776
# 2                                                                525127
# 3                                                                477187
# 4                                                               413618A
# ...                    ...                   ...                    ...
# 953514                                                         E0371068
# 953515                                                         e0146791
# 953516                                                         E0353767
# 953517                                                         E0369132
# 953518                                                         E0314231
#
#        in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                 ...          ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#        in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                ...                  ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
#                               in_WaterAllocationNativeURL
# 0       https://cadwr.app.box.com/v/WellCompletionRepo...
# 1       https://cadwr.app.box.com/v/WellCompletionRepo...
# 2
# 3
# 4       https://cadwr.app.box.com/v/WellCompletionRepo...
# ...                                                   ...
# 953514
# 953515
# 953516
# 953517
# 953518
#
# [953519 rows x 63 columns]

# %%
# Export the output dataframe
# change output name / abbreviation to match native state provdier and wade data type 
outdf.to_csv('RawInputData/Pwr_caMain.zip', compression=dict(method='zip', archive_name='Pwr_caMain.csv'), index=False)  # The output, save as a zip
