# %% [markdown]
# # Pre-processing California State Water Resource Control Board Water Right and Time Series Water Use data for WaDE Upload
# - Purpose:  To pre-process the data into one main file for simple DataFrame creation and extraction

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/California/WaterAllocation_WaterUse_CSWRCB" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/California/WaterAllocation_WaterUse_CSWRCB

# %% [markdown]
# ## Data Input

# %%
# Input File #1 - ewrims_flat_file_pod
fileInput = "RawInputData/water_right/ewrims_flat_file_pod.zip"
dfin1 = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin1:
    dfin1['WaDEUUID'] = "in1" + dfin1.index.astype(str)
    dfin1.to_csv("RawInputData/ewrims_flat_file_pod.zip", compression=dict(method='zip', archive_name='ewrims_flat_file_pod.csv'), index=False)

print(len(dfin1))
dfin1.head()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_2160\3169106468.py:3: DtypeWarning: Columns (7,13,42,49,59,61,66,72,74,88,89,91,94,96,98,103,105,110,121,126,132,133,146,147,148,150,151,153,154,155,156,157,158,159,160,161,162,163,166,167,168,169) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfin1 = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")
# 64873
#    ï»¿POD_ID POD_NUMBER POD_STATUS SOURCE_TYPE             POD_NAME  \
# 0      60497    1.00000   Inactive     Surface  COMPOUND STOCK POND
# 1      60498    2.00000   Inactive     Surface         LAKE DOMINGO
# 2        404    1.00000     Active
# 3      17603    1.00000     Active
# 4      29028    1.00000     Active
#
#                     POD_TYPE DIVERSION_WORKS_STATUS STREAM_CLASSIFICATION  \
# 0  Point of Direct Diversion               Existing               Unknown
# 1  Point of Direct Diversion               Proposed               Unknown
# 2  Point of Direct Diversion
# 3  Point of Direct Diversion
# 4  Point of Direct Diversion
#
#   DIRECT_DIV_AMOUNT DIRECT_DIVERSION_RATE   DIRECT_DIV_RATE_UNIT  \
# 0          48.00000               0.15000  Cubic Feet per Second
# 1          48.00000               0.15000  Cubic Feet per Second
# 2           0.00000               0.02500  Cubic Feet per Second
# 3           0.00000               0.02500  Cubic Feet per Second
# 4           0.00000               0.02500  Cubic Feet per Second
#
#   STORAGE_AMOUNT DIVERSION_RATE_TO_OFF_STREAM OFF_STO_DIV_RATE_UNIT  \
# 0
# 1
# 2        0.00000
# 3        0.00000
# 4        0.00000
#
#   POD_LAST_UPDATE_DATE  POD_COUNT  APPL_ID    OBJECTID POD_NUMBER_GIS  \
# 0                               2  T032025 97404.00000        1.00000
# 1                               2  T032025 95308.00000        2.00000
# 2                               4  A000016 58413.00000        1.00000
# 3                               4  A000016 58414.00000        1.00000
# 4                               4  A000016 57787.00000        1.00000
#
#   HAS_OPOD    APPL_POD  POD_ID_GIS       COUNTY  PARCEL_NUMBER SP_ZONE  \
# 0        N  T032025_01       60497    San Diego                6.00000
# 1        N  T032025_02       60498    San Diego                6.00000
# 2        N  A000016_01         404  Los Angeles                5.00000
# 3        N  A000016_01       17603  Los Angeles                5.00000
# 4        N  A000016_01       29028  Los Angeles  005-370-43-00 5.00000
#
#    DIVERSION_SITE_NAME   NORTH_COORD    EAST_COORD LATITUDE  LONGITUDE  \
# 0  COMPOUND STOCK POND 1814680.00000 6549776.00000 32.64560 -116.28860
# 1         LAKE DOMINGO 1803326.00000 6554711.00000 32.61440 -116.27260
# 2                      2032842.89100 6474612.14800 34.57797 -118.28921
# 3                      2032842.89100 6474612.14800 34.57797 -118.28921
# 4                      2033642.80200 6474614.80600 34.58017 -118.28921
#
#   QUARTER_QUARTER QUARTER SECTION_CLASSIFIER SECTION_NUMBER TOWNSHIP_NUMBER  \
# 0              NE      SW                          32.00000        17.00000
# 1              SE      SW                           9.00000        18.00000
# 2              NE      SE                          30.00000         6.00000
# 3              NE      SE                          30.00000         6.00000
# 4              SE      NE                          30.00000         6.00000
#
#   TOWNSHIP_DIRECTION RANGE_NUMBER RANGE_DIRECTION         MERIDIAN  \
# 0                  S      7.00000               E   San Bernardino
# 1                  S      7.00000               E   San Bernardino
# 2                  N     13.00000               W   San Bernardino
# 3                  N     13.00000               W   San Bernardino
# 4                  N     13.00000               W   San Bernardino
#
#   LOCATION_METHOD SPECIAL_USE_AREA       SOURCE_NAME       TRIB_DESC  \
# 0          GIS_NE                     UNNAMED STREAM  BOUNDARY CREEK
# 1          GIS_NE                       LAKE DOMINGO  BOUNDARY CREEK
# 2           DD_NE                    ICY SPRING NO 1
# 3           DD_NE                   KERR SPRING NO 2
# 4           DD_NE                   KERR SPRING NO 1
#
#       WATERSHED      HUC_12_NUMBER                HUC_12_NAME   HUC_8_NUMBER  \
# 0  ANZA BORREGO 181000000000.00000             Boundary Creek 18100202.00000
# 1  ANZA BORREGO 181000000000.00000             Boundary Creek 18100202.00000
# 2      ANTELOPE 181000000000.00000  Headwaters Amargosa Creek 18090206.00000
# 3      ANTELOPE 181000000000.00000  Headwaters Amargosa Creek 18090206.00000
# 4      ANTELOPE 181000000000.00000  Headwaters Amargosa Creek 18090206.00000
#
#                  HUC_8_NAME     QUAD_MAP_NAME QUAD_MAP_NUMBER  \
# 0             Carrizo Creek  LIVE OAK SPRINGS
# 1             Carrizo Creek    TIERRA DEL SOL
# 2  Antelope-Fremont Valleys     SLEEPY VALLEY           OO071
# 3  Antelope-Fremont Valleys     SLEEPY VALLEY           OO071
# 4  Antelope-Fremont Valleys     SLEEPY VALLEY           OO071
#
#    WR_WATER_RIGHT_ID APPLICATION_NUMBER CERTIFICATE_ID PERMIT_ID LICENSE_ID  \
# 0                  1            T032025
# 1                  1            T032025
# 2                  2            A000016       41.00000  30.00000   41.00000
# 3                  2            A000016       41.00000  30.00000   41.00000
# 4                  2            A000016       41.00000  30.00000   41.00000
#
#    WATER_RIGHT_TYPE WATER_RIGHT_STATUS APPLICATION_NUMBER_PARTY PWSS_ID  \
# 0  Temporary Permit          Cancelled                  T032025
# 1  Temporary Permit          Cancelled                  T032025
# 2     Appropriative           Licensed                  A000016
# 3     Appropriative           Licensed                  A000016
# 4     Appropriative           Licensed                  A000016
#
#   PRIORITY_DATE RECEIPT_DATE REJECTION_DATE APPLICATION_RECD_DATE  \
# 0                  4/18/2013                            4/18/2013
# 1                  4/18/2013                            4/18/2013
# 2
# 3
# 4
#
#   APPLICATION_ACCEPTANCE_DATE PROJECT_TYPE  \
# 0                   4/18/2013
# 1                   4/18/2013
# 2                   2/15/1915
# 3                   2/15/1915
# 4                   2/15/1915
#
#                          RECORD_SUMMARY INCOMPLETE_STATEMENT  \
# 0  Migrated data from old WRIMS system.
# 1  Migrated data from old WRIMS system.
# 2  Migrated data from old WRIMS system.
# 3  Migrated data from old WRIMS system.
# 4  Migrated data from old WRIMS system.
#
#    NUMBER_OF_PROTESTS   AGENT_NAME AGENT_ENTITY_TYPE  \
# 0                   0
# 1                   0
# 2                   0  MATT  CRAIG        Individual
# 3                   0  MATT  CRAIG        Individual
# 4                   0  MATT  CRAIG        Individual
#
#         APPLICATION_PRIMARY_OWNER  PRIMARY_OWNER_ENTITY_TYPE SUB_TYPE  \
# 0  569 EAST COUNTY BOULEVARD, LLC  Limited Liability Company
# 1  569 EAST COUNTY BOULEVARD, LLC  Limited Liability Company
# 2          LILAC HILLS ESTATES LP                Corporation
# 3          LILAC HILLS ESTATES LP                Corporation
# 4          LILAC HILLS ESTATES LP                Corporation
#
#   INI_REPORTED_DIV_AMOUNT INI_REPORTED_DIV_UNIT  FACE_VALUE_AMOUNT  \
# 0                                                         48.00000
# 1                                                         48.00000
# 2                                                         18.10000
# 3                                                         18.10000
# 4                                                         18.10000
#
#      FACE_VALUE_UNITS    FEE_DUE FEE_RECEIVED APPL_FEE_AMOUNT  \
# 0  Acre-feet per Year 1570.00000   1570.00000      1570.00000
# 1  Acre-feet per Year 1570.00000   1570.00000      1570.00000
# 2  Acre-feet per Year   10.00000     10.00000        10.00000
# 3  Acre-feet per Year   10.00000     10.00000        10.00000
# 4  Acre-feet per Year   10.00000     10.00000        10.00000
#
#   APPL_FEE_AMT_RECD MAX_DD_APPL           MAX_DD_UNITS MAX_DD_ANN MAX_STORAGE  \
# 0        1570.00000     0.15000  Cubic Feet per Second   48.00000
# 1        1570.00000     0.15000  Cubic Feet per Second   48.00000
# 2          10.00000     0.02500  Cubic Feet per Second    0.00000     0.00000
# 3          10.00000     0.02500  Cubic Feet per Second    0.00000     0.00000
# 4          10.00000     0.02500  Cubic Feet per Second    0.00000     0.00000
#
#   MAX_TAKEN_FROM_SOURCE YEAR_DIVERSION_COMMENCED MAX_BENEFICIALLY_USED  \
# 0               0.00000                                        0.00000
# 1               0.00000                                        0.00000
# 2              18.10000                                        0.00000
# 3              18.10000                                        0.00000
# 4              18.10000                                        0.00000
#
#   SUPPLEMENTAL_STATEMENT_CYCLE TYPE_OF_DIVERSION_FACILITY  \
# 0
# 1
# 2
# 3
# 4
#
#   QUANTITY_OF_WATER_DIVERTED QOW_DIVERTED_UNIT QUANTITY_MEASUREMENT_YEAR  \
# 0
# 1
# 2
# 3
# 4
#
#   MAX_RATE_OF_DIVERSION MAX_RATE_OF_DIV_UNIT RECENT_WATER_USE_MIN  \
# 0
# 1
# 2
# 3
# 4
#
#   WATER_USE_MIN_UNIT RECENT_WATER_USE_MAX WATER_USE_MAX_UNIT  \
# 0
# 1
# 2
# 3
# 4
#
#   REQUEST_FOR_REVOCATION_RECD  NUM_COMMENTS  NUM_ATTACHMENTS LAST_UPDATE_DATE  \
# 0                           N             1                1
# 1                           N             1                1
# 2                           N             0                2
# 3                           N             0                2
# 4                           N             0                2
#
#   STATE_WELL_NUMBER DRILLED_WELL_YEAR SURFACE_WATER_DIVERSIONS DEPTH_OF_WELL  \
# 0                                                                    0.00000
# 1                                                                    0.00000
# 2
# 3
# 4
#
#   RELATIONSHIP_TYPE     PARTY_ID EFFECTIVE_FROM_DATE EFFECTIVE_TO_DATE  \
# 0     Primary Owner 539608.00000           4/18/2013
# 1     Primary Owner 539608.00000           4/18/2013
# 2     Primary Owner 437566.00000           7/21/2006
# 3     Primary Owner 437566.00000           7/21/2006
# 4     Primary Owner 437566.00000           7/21/2006
#
#               PRIMARY_OWNER_NAME PRIMARY_OWNER_ENTITY_TYPE_P  \
# 0  569 EAST COUNTY BOULEVARD LLC   Limited Liability Company
# 1  569 EAST COUNTY BOULEVARD LLC   Limited Liability Company
# 2         LILAC HILLS ESTATES LP                 Corporation
# 3         LILAC HILLS ESTATES LP                 Corporation
# 4         LILAC HILLS ESTATES LP                 Corporation
#
#   OFFICIAL_MAIL_RECEIVER  COUNT_NPO_OR_OTHER CURRENT_STATUS EFFECTIVE_DATE  \
# 0                      Y                   0      Cancelled       8/9/2013
# 1                      Y                   0      Cancelled       8/9/2013
# 2                      N                   2       Licensed      2/19/1915
# 3                      N                   2       Licensed      2/19/1915
# 4                      N                   2       Licensed      2/19/1915
#
#   UPDATE_DATETIME      USE_CODE                    USE_STATUS  \
# 0                  Dust Control          Requested when filed
# 1                  Dust Control          Requested when filed
# 2                      Domestic  Migrated from old WRIMS data
# 3                      Domestic  Migrated from old WRIMS data
# 4                      Domestic  Migrated from old WRIMS data
#
#   NUMBER_OF_RESIDENCES SEPERATELY_OWNED USE_POPULATION USE_POPULATION_PEOPLE  \
# 0                                              0.00000
# 1                                              0.00000
# 2                                              0.00000
# 3                                              0.00000
# 4                                              0.00000
#
#   ESTIMATED_USE_PER_PERSON USE_POPULATION_STOCK TYPE_OF_STOCK  \
# 0
# 1
# 2
# 3
# 4
#
#   AREA_FOR_INCI_IRRIGATION USE_NET_ACREAGE USE_GROSS_ACREAGE  \
# 0                                  0.00000           0.00000
# 1                                  0.00000           0.00000
# 2                                  0.00000           0.00000
# 3                                  0.00000           0.00000
# 4                                  0.00000           0.00000
#
#   USE_DIRECT_DIV_ANNUAL_AMOUNT USE_DIRECT_DIVERSION_RATE  \
# 0                    109.00000                   0.15000
# 1                    109.00000                   0.15000
# 2                      0.00000                   0.00000
# 3                      0.00000                   0.00000
# 4                      0.00000                   0.00000
#
#   USE_DIRECT_DIV_RATE_UNITS POU_DEVELOPMENT_STATUS DIRECT_DIV_SEASON_START  \
# 0     Cubic Feet per Second                Partial                   1-Jan
# 1     Cubic Feet per Second                Partial                   1-Jan
# 2                                                                    1-Jan
# 3                                                                    1-Jan
# 4                                                                    1-Jan
#
#   DIRECT_DIV_SEASON_END USE_STORAGE_AMOUNT STORAGE_SEASON_START  \
# 0                31-Dec            0.00000
# 1                31-Dec            0.00000
# 2                31-Dec            0.00000
# 3                31-Dec            0.00000
# 4                31-Dec            0.00000
#
#   STORAGE_SEASON_END SEASON_DIRECT_DIV_RATE SEASON_STORAGE_AMOUNT  \
# 0                                   0.15000               0.00000
# 1                                   0.15000               0.00000
# 2                                                         0.00000
# 3                                                         0.00000
# 4                                                         0.00000
#
#   SEASON_DIRECT_DIV_AA      DIRECT_DIV_SEASON_STATUS  \
# 0            109.00000          Requested when filed
# 1            109.00000          Requested when filed
# 2                       Migrated from old WRIMS data
# 3                       Migrated from old WRIMS data
# 4                       Migrated from old WRIMS data
#
#        COLLECTION_SEASON_STATUS  USE_COUNT PERMIT_PERMIT_ID  \
# 0                                        1
# 1                                        1
# 2  Migrated from old WRIMS data          2         30.00000
# 3  Migrated from old WRIMS data          2         30.00000
# 4  Migrated from old WRIMS data          2         30.00000
#
#   PERMIT_ORIGINAL_ISSUE_DATE COMPLETE_CONSTRUCTION_DATE  \
# 0
# 1
# 2                 10/28/1915
# 3                 10/28/1915
# 4                 10/28/1915
#
#   COMPLETE_APPLIC_WATER_DATE LICENSE_LICENSE_ID LICENSE_ORIGINAL_ISSUE_DATE  \
# 0
# 1
# 2                                      41.00000                   9/25/1918
# 3                                      41.00000                   9/25/1918
# 4                                      41.00000                   9/25/1918
#
#                 WATER_RIGHT_DESCRIPTION PROGRAM_UNIT LICENSE_REQUEST_TYPE  \
# 0
# 1
# 2  Migrated data from old WRIMS system.                  Permitee Request
# 3  Migrated data from old WRIMS system.                  Permitee Request
# 4  Migrated data from old WRIMS system.                  Permitee Request
#
#   LICENSE_REQUESTED_DATE INSPECTION_DATE REPORT_DATE OFFER_SENT_DATE  \
# 0
# 1
# 2
# 3
# 4
#
#   ACCEPTED_OFFER_DATE PETITION_ID PETITION_TYPE PETITION_STATUS_TYPE  \
# 0
# 1
# 2
# 3
# 4
#
#   DATE_RECEIVED DATE_COMPLETED PET_LAST_UPDATE_DATE NUM_OF_PETITIONS  \
# 0
# 1
# 2
# 3
# 4
#
#   ENF_CASE_NUMBER ENF_CASE_START_DATE ENF_CASE_CLOSURE_DATE ENF_CASE_COUNTY  \
# 0
# 1
# 2
# 3
# 4
#
#    NUMBER_OF_ENFORCEMENT_CASE WaDEUUID
# 0                           0     in10
# 1                           0     in11
# 2                           0     in12
# 3                           0     in13
# 4                           0     in14

# %%
# Input File #2 - water-rights-water-use-reported-short
fileInput = "RawInputData/water_use/water-rights-water-use-reported-short.zip"
dfin2 = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin2:
    dfin2['WaDEUUID'] = "in2" + dfin2.index.astype(str)
    dfin2.to_csv("RawInputData/water-rights-water-use-reported-short.zip", compression=dict(method='zip', archive_name='water-rights-water-use-reported-short.csv'), index=False)

print(len(dfin2))
dfin2.head()
# Out:
# 11731056
#   ï»¿MONTH NAME MONTH FORMATTED  WATER_RIGHT_ID  APPL_ID  YEAR  MONTH  AMOUNT  \
# 0       January        1/1/2001            1307  A006599  2001      1 0.00000
# 1       January        1/1/2006            1393  A006944  2006      1 0.00000
# 2       January        1/1/2007            1299  A006563  2007      1 0.00000
# 3       January        1/1/2007            1307  A006599  2007      1 0.00000
# 4       January        1/1/2007            1308  A006603  2007      1 0.00000
#
#                 DIVERSION_TYPE WaDEUUID
# 0  Combined (Direct + Storage)     in20
# 1  Combined (Direct + Storage)     in21
# 2  Combined (Direct + Storage)     in22
# 3  Combined (Direct + Storage)     in23
# 4  Combined (Direct + Storage)     in24

# %%
#POD_TYPE fix. 
# we only want the first listed POD_TYPE value

def firstPOD_TYPEFunc(val):
    val = str(val).strip()
    if "," in val:
        outString = val.split(",")
        # outString = val[0]
        outString = ''.join(outString)
    else:
        outString = val
    return outString

dfin1['POD_TYPE'] = dfin1.apply(lambda row: firstPOD_TYPEFunc(row['POD_TYPE']), axis=1)
dfin1['POD_TYPE'].unique()
# Out:
# array(['Point of Direct Diversion', 'Point of Storage - Unspecified',
#        'Point of Onstream Storage',
#        'Point of Diversion to Underground Storage',
#        'Point of Diversion to Offstream Storage', 'Point of Rediversion',
#        'Movable Point of Diversion', 'Movable Point of Rediversion', ''],
#       dtype=object)

# %%
# Clean data a little
dfin1 = dfin1.fillna("") # remove nan values
dfin1['USE_DIRECT_DIVERSION_RATE'] = pd.to_numeric(dfin1['USE_DIRECT_DIVERSION_RATE'], errors='coerce').fillna(0) # make sure this is numeric.

# %%
# Create VariableSpecificCv value
def createVariableSpecificUUID(unit):
    outString = ""
    if unit == "Cubic Feet per Second":
        outString = "CSWRCBwr_V1"
    if unit == "Gallons per Day":
        outString = "CSWRCBwr_V1"
    if unit == "Acre-feet per Year":
        outString = "CSWRCBwr_V1"
    if unit == "Gallons per Minute":
        outString = "CSWRCBwr_V1"
    if unit == 'Acre-feet':
        outString = "CSWRCBwr_V2"
    if unit == 'Gallons':
        outString = "CSWRCBwr_V2"
    else:
        outString = "CSWRCBwr_V1"

    return(outString)

dfin1['in_VariableSpecificUUID'] = dfin1.apply(lambda row: createVariableSpecificUUID(row['USE_DIRECT_DIV_RATE_UNITS']), axis=1)
dfin1['in_VariableSpecificUUID'].unique()
# Out:
# array(['CSWRCBwr_V1', 'CSWRCBwr_V2'], dtype=object)

# %%
# convert all flow values to CFS
def convertFlowFunc(val, unit):
    CFS_Value = None
    if unit == "Cubic Feet per Second":
        CFS_Value = val
    if unit == "Gallons per Day":
        CFS_Value = val / (646316.883)
    if unit == "Acre-feet per Year":
        CFS_Value = val / (723.968)
    if unit == "Gallons per Minute":
        CFS_Value = val / (448.83117)
    return(CFS_Value)

dfin1['in_AllocationFlow_CFS'] = dfin1.apply(lambda row: convertFlowFunc(row['USE_DIRECT_DIVERSION_RATE'], row['USE_DIRECT_DIV_RATE_UNITS']), axis=1)
dfin1['in_AllocationFlow_CFS'].unique()
# Out:
# array([1.50000000e-01,            nan, 2.50000000e+00, ...,
#        2.35946180e-05, 5.34722221e-01, 5.05758101e-01])

# %%
# convert all volume values to AF
def convertVolumeFunc(val, unit):
    AF_Value = None
    if unit == 'Acre-feet':
        AF_Value = val
    if unit == 'Gallons':
        AF_Value = val / (325850.943)
    return(AF_Value)

dfin1['in_AllocationVolume_AF'] = dfin1.apply(lambda row: convertVolumeFunc(row['USE_DIRECT_DIVERSION_RATE'], row['USE_DIRECT_DIV_RATE_UNITS']), axis=1)
dfin1['in_AllocationVolume_AF'].unique()
# Out:
# array([      nan, 0.000e+00, 1.300e-01, 3.650e+02, 2.062e+01])

# %%
# remove speicial characters from SUB_TYPE
def cleanupSubTypeFunc(val):
    val = str(val).strip()
    val = val.rstrip('_') # remove trailing "_"
    val = val.rstrip(',') # remove trailing commas
    if val == "" or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        val = val.replace("," ," ")
        outString = "" + val
    return outString

dfin1['wade_SUB_TYPE'] = dfin1.apply(lambda row: cleanupSubTypeFunc(row['SUB_TYPE']), axis=1)
dfin1['wade_SUB_TYPE'].unique()
# Out:
# array(['', 'RIPERIAN', 'RIPERIAN PRE1914', 'PRE1914', 'OTHER',
#        'PRE1914 OTHER', 'COURTADJ', 'RIPERIAN PRE1914 OTHER',
#        'RIPERIAN PRE1914 COURTADJ OTHER', 'RIPERIAN PRE1914 COURTADJ',
#        'PRE1914 COURTADJ', 'RIPERIAN OTHER', 'RIPERIAN COURTADJ',
#        'PRE1914 PENDING', 'PENDING', 'RIPERIAN PENDING', 'COURTADJ OTHER',
#        'PENDING OTHER', 'RIPERIAN COURTADJ OTHER',
#        'RIPERIAN PRE1914 PENDING', 'PRE1914 COURTADJ OTHER',
#        'RIPERIAN PENDING OTHER'], dtype=object)

# %%
#left merge sites to water use
dfin1 = dfin1.merge(dfin2, left_on='APPLICATION_NUMBER', right_on='APPL_ID', how='left')
print(len(dfin1))
dfin1.head()
# Out:
# 14198199
#    ï»¿POD_ID POD_NUMBER POD_STATUS SOURCE_TYPE             POD_NAME  \
# 0      60497    1.00000   Inactive     Surface  COMPOUND STOCK POND
# 1      60498    2.00000   Inactive     Surface         LAKE DOMINGO
# 2        404    1.00000     Active
# 3        404    1.00000     Active
# 4        404    1.00000     Active
#
#                     POD_TYPE DIVERSION_WORKS_STATUS STREAM_CLASSIFICATION  \
# 0  Point of Direct Diversion               Existing               Unknown
# 1  Point of Direct Diversion               Proposed               Unknown
# 2  Point of Direct Diversion
# 3  Point of Direct Diversion
# 4  Point of Direct Diversion
#
#   DIRECT_DIV_AMOUNT DIRECT_DIVERSION_RATE   DIRECT_DIV_RATE_UNIT  \
# 0          48.00000               0.15000  Cubic Feet per Second
# 1          48.00000               0.15000  Cubic Feet per Second
# 2           0.00000               0.02500  Cubic Feet per Second
# 3           0.00000               0.02500  Cubic Feet per Second
# 4           0.00000               0.02500  Cubic Feet per Second
#
#   STORAGE_AMOUNT DIVERSION_RATE_TO_OFF_STREAM OFF_STO_DIV_RATE_UNIT  \
# 0
# 1
# 2        0.00000
# 3        0.00000
# 4        0.00000
#
#   POD_LAST_UPDATE_DATE  POD_COUNT APPL_ID_x    OBJECTID POD_NUMBER_GIS  \
# 0                               2   T032025 97404.00000        1.00000
# 1                               2   T032025 95308.00000        2.00000
# 2                               4   A000016 58413.00000        1.00000
# 3                               4   A000016 58413.00000        1.00000
# 4                               4   A000016 58413.00000        1.00000
#
#   HAS_OPOD    APPL_POD  POD_ID_GIS       COUNTY PARCEL_NUMBER SP_ZONE  \
# 0        N  T032025_01       60497    San Diego               6.00000
# 1        N  T032025_02       60498    San Diego               6.00000
# 2        N  A000016_01         404  Los Angeles               5.00000
# 3        N  A000016_01         404  Los Angeles               5.00000
# 4        N  A000016_01         404  Los Angeles               5.00000
#
#    DIVERSION_SITE_NAME   NORTH_COORD    EAST_COORD LATITUDE  LONGITUDE  \
# 0  COMPOUND STOCK POND 1814680.00000 6549776.00000 32.64560 -116.28860
# 1         LAKE DOMINGO 1803326.00000 6554711.00000 32.61440 -116.27260
# 2                      2032842.89100 6474612.14800 34.57797 -118.28921
# 3                      2032842.89100 6474612.14800 34.57797 -118.28921
# 4                      2032842.89100 6474612.14800 34.57797 -118.28921
#
#   QUARTER_QUARTER QUARTER SECTION_CLASSIFIER SECTION_NUMBER TOWNSHIP_NUMBER  \
# 0              NE      SW                          32.00000        17.00000
# 1              SE      SW                           9.00000        18.00000
# 2              NE      SE                          30.00000         6.00000
# 3              NE      SE                          30.00000         6.00000
# 4              NE      SE                          30.00000         6.00000
#
#   TOWNSHIP_DIRECTION RANGE_NUMBER RANGE_DIRECTION         MERIDIAN  \
# 0                  S      7.00000               E   San Bernardino
# 1                  S      7.00000               E   San Bernardino
# 2                  N     13.00000               W   San Bernardino
# 3                  N     13.00000               W   San Bernardino
# 4                  N     13.00000               W   San Bernardino
#
#   LOCATION_METHOD SPECIAL_USE_AREA      SOURCE_NAME       TRIB_DESC  \
# 0          GIS_NE                    UNNAMED STREAM  BOUNDARY CREEK
# 1          GIS_NE                      LAKE DOMINGO  BOUNDARY CREEK
# 2           DD_NE                   ICY SPRING NO 1
# 3           DD_NE                   ICY SPRING NO 1
# 4           DD_NE                   ICY SPRING NO 1
#
#       WATERSHED      HUC_12_NUMBER                HUC_12_NAME   HUC_8_NUMBER  \
# 0  ANZA BORREGO 181000000000.00000             Boundary Creek 18100202.00000
# 1  ANZA BORREGO 181000000000.00000             Boundary Creek 18100202.00000
# 2      ANTELOPE 181000000000.00000  Headwaters Amargosa Creek 18090206.00000
# 3      ANTELOPE 181000000000.00000  Headwaters Amargosa Creek 18090206.00000
# 4      ANTELOPE 181000000000.00000  Headwaters Amargosa Creek 18090206.00000
#
#                  HUC_8_NAME     QUAD_MAP_NAME QUAD_MAP_NUMBER  \
# 0             Carrizo Creek  LIVE OAK SPRINGS
# 1             Carrizo Creek    TIERRA DEL SOL
# 2  Antelope-Fremont Valleys     SLEEPY VALLEY           OO071
# 3  Antelope-Fremont Valleys     SLEEPY VALLEY           OO071
# 4  Antelope-Fremont Valleys     SLEEPY VALLEY           OO071
#
#    WR_WATER_RIGHT_ID APPLICATION_NUMBER CERTIFICATE_ID PERMIT_ID LICENSE_ID  \
# 0                  1            T032025
# 1                  1            T032025
# 2                  2            A000016       41.00000  30.00000   41.00000
# 3                  2            A000016       41.00000  30.00000   41.00000
# 4                  2            A000016       41.00000  30.00000   41.00000
#
#    WATER_RIGHT_TYPE WATER_RIGHT_STATUS APPLICATION_NUMBER_PARTY PWSS_ID  \
# 0  Temporary Permit          Cancelled                  T032025
# 1  Temporary Permit          Cancelled                  T032025
# 2     Appropriative           Licensed                  A000016
# 3     Appropriative           Licensed                  A000016
# 4     Appropriative           Licensed                  A000016
#
#   PRIORITY_DATE RECEIPT_DATE REJECTION_DATE APPLICATION_RECD_DATE  \
# 0                  4/18/2013                            4/18/2013
# 1                  4/18/2013                            4/18/2013
# 2
# 3
# 4
#
#   APPLICATION_ACCEPTANCE_DATE PROJECT_TYPE  \
# 0                   4/18/2013
# 1                   4/18/2013
# 2                   2/15/1915
# 3                   2/15/1915
# 4                   2/15/1915
#
#                          RECORD_SUMMARY INCOMPLETE_STATEMENT  \
# 0  Migrated data from old WRIMS system.
# 1  Migrated data from old WRIMS system.
# 2  Migrated data from old WRIMS system.
# 3  Migrated data from old WRIMS system.
# 4  Migrated data from old WRIMS system.
#
#    NUMBER_OF_PROTESTS   AGENT_NAME AGENT_ENTITY_TYPE  \
# 0                   0
# 1                   0
# 2                   0  MATT  CRAIG        Individual
# 3                   0  MATT  CRAIG        Individual
# 4                   0  MATT  CRAIG        Individual
#
#         APPLICATION_PRIMARY_OWNER  PRIMARY_OWNER_ENTITY_TYPE SUB_TYPE  \
# 0  569 EAST COUNTY BOULEVARD, LLC  Limited Liability Company
# 1  569 EAST COUNTY BOULEVARD, LLC  Limited Liability Company
# 2          LILAC HILLS ESTATES LP                Corporation
# 3          LILAC HILLS ESTATES LP                Corporation
# 4          LILAC HILLS ESTATES LP                Corporation
#
#   INI_REPORTED_DIV_AMOUNT INI_REPORTED_DIV_UNIT  FACE_VALUE_AMOUNT  \
# 0                                                         48.00000
# 1                                                         48.00000
# 2                                                         18.10000
# 3                                                         18.10000
# 4                                                         18.10000
#
#      FACE_VALUE_UNITS    FEE_DUE FEE_RECEIVED APPL_FEE_AMOUNT  \
# 0  Acre-feet per Year 1570.00000   1570.00000      1570.00000
# 1  Acre-feet per Year 1570.00000   1570.00000      1570.00000
# 2  Acre-feet per Year   10.00000     10.00000        10.00000
# 3  Acre-feet per Year   10.00000     10.00000        10.00000
# 4  Acre-feet per Year   10.00000     10.00000        10.00000
#
#   APPL_FEE_AMT_RECD MAX_DD_APPL           MAX_DD_UNITS MAX_DD_ANN MAX_STORAGE  \
# 0        1570.00000     0.15000  Cubic Feet per Second   48.00000
# 1        1570.00000     0.15000  Cubic Feet per Second   48.00000
# 2          10.00000     0.02500  Cubic Feet per Second    0.00000     0.00000
# 3          10.00000     0.02500  Cubic Feet per Second    0.00000     0.00000
# 4          10.00000     0.02500  Cubic Feet per Second    0.00000     0.00000
#
#   MAX_TAKEN_FROM_SOURCE YEAR_DIVERSION_COMMENCED MAX_BENEFICIALLY_USED  \
# 0               0.00000                                        0.00000
# 1               0.00000                                        0.00000
# 2              18.10000                                        0.00000
# 3              18.10000                                        0.00000
# 4              18.10000                                        0.00000
#
#   SUPPLEMENTAL_STATEMENT_CYCLE TYPE_OF_DIVERSION_FACILITY  \
# 0
# 1
# 2
# 3
# 4
#
#   QUANTITY_OF_WATER_DIVERTED QOW_DIVERTED_UNIT QUANTITY_MEASUREMENT_YEAR  \
# 0
# 1
# 2
# 3
# 4
#
#   MAX_RATE_OF_DIVERSION MAX_RATE_OF_DIV_UNIT RECENT_WATER_USE_MIN  \
# 0
# 1
# 2
# 3
# 4
#
#   WATER_USE_MIN_UNIT RECENT_WATER_USE_MAX WATER_USE_MAX_UNIT  \
# 0
# 1
# 2
# 3
# 4
#
#   REQUEST_FOR_REVOCATION_RECD  NUM_COMMENTS  NUM_ATTACHMENTS LAST_UPDATE_DATE  \
# 0                           N             1                1
# 1                           N             1                1
# 2                           N             0                2
# 3                           N             0                2
# 4                           N             0                2
#
#   STATE_WELL_NUMBER DRILLED_WELL_YEAR SURFACE_WATER_DIVERSIONS DEPTH_OF_WELL  \
# 0                                                                    0.00000
# 1                                                                    0.00000
# 2
# 3
# 4
#
#   RELATIONSHIP_TYPE     PARTY_ID EFFECTIVE_FROM_DATE EFFECTIVE_TO_DATE  \
# 0     Primary Owner 539608.00000           4/18/2013
# 1     Primary Owner 539608.00000           4/18/2013
# 2     Primary Owner 437566.00000           7/21/2006
# 3     Primary Owner 437566.00000           7/21/2006
# 4     Primary Owner 437566.00000           7/21/2006
#
#               PRIMARY_OWNER_NAME PRIMARY_OWNER_ENTITY_TYPE_P  \
# 0  569 EAST COUNTY BOULEVARD LLC   Limited Liability Company
# 1  569 EAST COUNTY BOULEVARD LLC   Limited Liability Company
# 2         LILAC HILLS ESTATES LP                 Corporation
# 3         LILAC HILLS ESTATES LP                 Corporation
# 4         LILAC HILLS ESTATES LP                 Corporation
#
#   OFFICIAL_MAIL_RECEIVER  COUNT_NPO_OR_OTHER CURRENT_STATUS EFFECTIVE_DATE  \
# 0                      Y                   0      Cancelled       8/9/2013
# 1                      Y                   0      Cancelled       8/9/2013
# 2                      N                   2       Licensed      2/19/1915
# 3                      N                   2       Licensed      2/19/1915
# 4                      N                   2       Licensed      2/19/1915
#
#   UPDATE_DATETIME      USE_CODE                    USE_STATUS  \
# 0                  Dust Control          Requested when filed
# 1                  Dust Control          Requested when filed
# 2                      Domestic  Migrated from old WRIMS data
# 3                      Domestic  Migrated from old WRIMS data
# 4                      Domestic  Migrated from old WRIMS data
#
#   NUMBER_OF_RESIDENCES SEPERATELY_OWNED USE_POPULATION USE_POPULATION_PEOPLE  \
# 0                                              0.00000
# 1                                              0.00000
# 2                                              0.00000
# 3                                              0.00000
# 4                                              0.00000
#
#   ESTIMATED_USE_PER_PERSON USE_POPULATION_STOCK TYPE_OF_STOCK  \
# 0
# 1
# 2
# 3
# 4
#
#   AREA_FOR_INCI_IRRIGATION USE_NET_ACREAGE USE_GROSS_ACREAGE  \
# 0                                  0.00000           0.00000
# 1                                  0.00000           0.00000
# 2                                  0.00000           0.00000
# 3                                  0.00000           0.00000
# 4                                  0.00000           0.00000
#
#   USE_DIRECT_DIV_ANNUAL_AMOUNT  USE_DIRECT_DIVERSION_RATE  \
# 0                    109.00000                    0.15000
# 1                    109.00000                    0.15000
# 2                      0.00000                    0.00000
# 3                      0.00000                    0.00000
# 4                      0.00000                    0.00000
#
#   USE_DIRECT_DIV_RATE_UNITS POU_DEVELOPMENT_STATUS DIRECT_DIV_SEASON_START  \
# 0     Cubic Feet per Second                Partial                   1-Jan
# 1     Cubic Feet per Second                Partial                   1-Jan
# 2                                                                    1-Jan
# 3                                                                    1-Jan
# 4                                                                    1-Jan
#
#   DIRECT_DIV_SEASON_END USE_STORAGE_AMOUNT STORAGE_SEASON_START  \
# 0                31-Dec            0.00000
# 1                31-Dec            0.00000
# 2                31-Dec            0.00000
# 3                31-Dec            0.00000
# 4                31-Dec            0.00000
#
#   STORAGE_SEASON_END SEASON_DIRECT_DIV_RATE SEASON_STORAGE_AMOUNT  \
# 0                                   0.15000               0.00000
# 1                                   0.15000               0.00000
# 2                                                         0.00000
# 3                                                         0.00000
# 4                                                         0.00000
#
#   SEASON_DIRECT_DIV_AA      DIRECT_DIV_SEASON_STATUS  \
# 0            109.00000          Requested when filed
# 1            109.00000          Requested when filed
# 2                       Migrated from old WRIMS data
# 3                       Migrated from old WRIMS data
# 4                       Migrated from old WRIMS data
#
#        COLLECTION_SEASON_STATUS  USE_COUNT PERMIT_PERMIT_ID  \
# 0                                        1
# 1                                        1
# 2  Migrated from old WRIMS data          2         30.00000
# 3  Migrated from old WRIMS data          2         30.00000
# 4  Migrated from old WRIMS data          2         30.00000
#
#   PERMIT_ORIGINAL_ISSUE_DATE COMPLETE_CONSTRUCTION_DATE  \
# 0
# 1
# 2                 10/28/1915
# 3                 10/28/1915
# 4                 10/28/1915
#
#   COMPLETE_APPLIC_WATER_DATE LICENSE_LICENSE_ID LICENSE_ORIGINAL_ISSUE_DATE  \
# 0
# 1
# 2                                      41.00000                   9/25/1918
# 3                                      41.00000                   9/25/1918
# 4                                      41.00000                   9/25/1918
#
#                 WATER_RIGHT_DESCRIPTION PROGRAM_UNIT LICENSE_REQUEST_TYPE  \
# 0
# 1
# 2  Migrated data from old WRIMS system.                  Permitee Request
# 3  Migrated data from old WRIMS system.                  Permitee Request
# 4  Migrated data from old WRIMS system.                  Permitee Request
#
#   LICENSE_REQUESTED_DATE INSPECTION_DATE REPORT_DATE OFFER_SENT_DATE  \
# 0
# 1
# 2
# 3
# 4
#
#   ACCEPTED_OFFER_DATE PETITION_ID PETITION_TYPE PETITION_STATUS_TYPE  \
# 0
# 1
# 2
# 3
# 4
#
#   DATE_RECEIVED DATE_COMPLETED PET_LAST_UPDATE_DATE NUM_OF_PETITIONS  \
# 0
# 1
# 2
# 3
# 4
#
#   ENF_CASE_NUMBER ENF_CASE_START_DATE ENF_CASE_CLOSURE_DATE ENF_CASE_COUNTY  \
# 0
# 1
# 2
# 3
# 4
#
#    NUMBER_OF_ENFORCEMENT_CASE WaDEUUID_x in_VariableSpecificUUID  \
# 0                           0       in10             CSWRCBwr_V1
# 1                           0       in11             CSWRCBwr_V1
# 2                           0       in12             CSWRCBwr_V1
# 3                           0       in12             CSWRCBwr_V1
# 4                           0       in12             CSWRCBwr_V1
#
#    in_AllocationFlow_CFS  in_AllocationVolume_AF wade_SUB_TYPE ï»¿MONTH NAME  \
# 0                0.15000                     NaN                         NaN
# 1                0.15000                     NaN                         NaN
# 2                    NaN                     NaN                     January
# 3                    NaN                     NaN                     January
# 4                    NaN                     NaN                     January
#
#   MONTH FORMATTED  WATER_RIGHT_ID APPL_ID_y       YEAR   MONTH  AMOUNT  \
# 0             NaN             NaN       NaN        NaN     NaN     NaN
# 1             NaN             NaN       NaN        NaN     NaN     NaN
# 2        1/1/2011         2.00000   A000016 2011.00000 1.00000 0.00000
# 3        1/1/2011         2.00000   A000016 2011.00000 1.00000 0.00000
# 4        1/1/2011         2.00000   A000016 2011.00000 1.00000 0.00000
#
#   DIVERSION_TYPE   WaDEUUID_y
# 0            NaN          NaN
# 1            NaN          NaN
# 2        STORAGE  in211244013
# 3         DIRECT  in211244014
# 4            USE  in211244015

# %%
# # convert units to WaDE Approproiate values (CFS or AF)
# def convertAmountToUnitFunc(val, unit):
#     outValue = None
#     if unit == "Cubic Feet per Second":
#         outValue = val
#     if unit == "Gallons per Day":
#         outValue = val / (646316.883)
#     if unit == "Acre-feet per Year":
#         outValue = val / (723.968)
#     if unit == "Gallons per Minute":
#         outValue = val / (448.83117)
#     if unit == 'Acre-feet':
#         outValue = val
#     if unit == 'Gallons':
#         outValue = val / (325850.943)
#     return(outValue)

# dfin1['in_Amount'] = dfin1.apply(lambda row: convertAmountToUnitFunc(row['USE_DIRECT_DIVERSION_RATE'], row['USE_DIRECT_DIV_RATE_UNITS']), axis=1)
# dfin1['in_Amount'].unique()

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfin1['WaDEUUID_x']

# Method Info
df['in_MethodUUID'] = "CSWRCBwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = dfin1['in_VariableSpecificUUID'] # for wr records portion only, will create sa portion below
df['in_AggregationIntervalUnitCV'] = "Monthly"
df['in_VariableCV'] = "Water Use"

# Organization Info
df['in_OrganizationUUID'] = "CSWRCBwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfin1['SOURCE_NAME'].str.title()
df['in_WaterSourceNativeID'] = "" # create customID for temp solution
df['in_WaterSourceTypeCV'] = dfin1['SOURCE_TYPE'].str.title()

# Site Info
df['in_RegulatoryOverlayUUIDs'] = ""
df['in_WaterSourceUUID'] = "" # ???
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = dfin1['LOCATION_METHOD']
df['in_County'] = dfin1['COUNTY'].str.title()
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = dfin1['HUC_12_NUMBER'].replace("", 0).fillna(0).astype(int).astype(str)
df['in_HUC8'] = dfin1['HUC_8_NUMBER'].replace("", 0).fillna(0).astype(int).astype(str)
df['in_Latitude'] = dfin1['LATITUDE']
df['in_Longitude'] = dfin1['LONGITUDE']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"
df['in_SiteName'] = dfin1['POD_NAME'].str.title()
df['in_SiteNativeID'] = dfin1['ï»¿POD_ID'].replace("", 0).fillna(0).astype(int).astype(str)
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = dfin1['POD_TYPE'].astype(str).str.title()
df['in_StateCV'] = "CA"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = dfin1['APPLICATION_RECD_DATE']
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = dfin1['in_AllocationFlow_CFS'].astype(float) # see above for conversion
df['in_AllocationLegalStatusCV'] = dfin1['WATER_RIGHT_STATUS'].str.title()
df['in_AllocationNativeID'] =  dfin1['APPLICATION_NUMBER'].replace("", 0).fillna(0).astype(str)
df['in_AllocationOwner'] = dfin1['PRIMARY_OWNER_NAME']
df['in_AllocationPriorityDate'] = dfin1['PRIORITY_DATE']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = dfin1['DIRECT_DIV_SEASON_END']
df['in_AllocationTimeframeStart'] = dfin1['DIRECT_DIV_SEASON_START']
df['in_AllocationTypeCV'] = dfin1['WATER_RIGHT_TYPE'].astype(str) + " " + dfin1['wade_SUB_TYPE'].astype(str)
df['in_AllocationTypeCV'] = df['in_AllocationTypeCV'].astype(str).str.strip()
df['in_AllocationVolume_AF'] = dfin1['in_AllocationVolume_AF'].astype(float) # see above for conversion
df['in_BeneficialUseCategory'] = dfin1['USE_CODE'].str.title()
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = "1" # we want this data to be exempt
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = "" # temp fix, leave blank for now
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = "" # temp fix, leave blank for now
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = "https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/EWServlet?Redirect_Page=EWPublicAppSummary.jsp&Purpose=getEwrimsPublicSummary&wrWaterRightID=" + dfin1['WR_WATER_RIGHT_ID'].replace("", 0).fillna(0).astype(int).astype(str)


# Site VariableAmounts Info
df['in_Amount'] = dfin1['AMOUNT']
df['in_AssociatedNativeAllocationIDs'] = dfin1['APPLICATION_NUMBER']
df['in_PowerGeneratedGWh'] = ""
df['in_PrimaryUseCategory'] = "" # see below
df['in_ReportYearCV'] = dfin1['YEAR'].replace("", 0).fillna(0).astype(int).astype(str)
df['in_SDWISIdentifier'] = ""
df['in_TimeframeEnd'] = dfin1['MONTH FORMATTED']
df['in_TimeframeStart'] = dfin1['MONTH FORMATTED']
# df['in_AllocationCropDutyAmount'] = "" see above AllocationAmount Info
# df['in_BeneficialUseCategory'] = "" see above AllocationAmount Info
# df['in_CommunityWaterSupplySystem'] = "" see above AllocationAmount Info
# df['in_CropTypeCV'] = "" see above AllocationAmount Info
# df['in_CustomerTypeCV'] = "" see above AllocationAmount Info
# df['in_DataPublicationDate'] = "" see above AllocationAmount Info
# df['in_DataPublicationDOI'] = "" see above AllocationAmount Info
# df['in_Geometry'] = "" see above Site Info
# df['in_IrrigatedAcreage'] = "" see above AllocationAmount Info
# df['in_IrrigationMethodCV'] = "" see above AllocationAmount Info
# df['in_PopulationServed'] = "" see above AllocationAmount Info
# df['in_PowerType'] = "" see above AllocationAmount Info
# df['in_SDWISIdentifier'] = "" see above AllocationAmount Info

outdf1 = df.copy()
outdf1 = outdf1.drop_duplicates().reset_index(drop=True)
print(len(outdf1))
outdf1.head()
# Out:
# 7739363
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_AggregationIntervalUnitCV  \
# 0     in10   CSWRCBwr_M1             CSWRCBwr_V1                      Monthly
# 1     in11   CSWRCBwr_M1             CSWRCBwr_V1                      Monthly
# 2     in12   CSWRCBwr_M1             CSWRCBwr_V1                      Monthly
# 3     in12   CSWRCBwr_M1             CSWRCBwr_V1                      Monthly
# 4     in12   CSWRCBwr_M1             CSWRCBwr_V1                      Monthly
#
#   in_VariableCV in_OrganizationUUID in_Geometry in_GNISFeatureNameCV  \
# 0     Water Use         CSWRCBwr_O1
# 1     Water Use         CSWRCBwr_O1
# 2     Water Use         CSWRCBwr_O1
# 3     Water Use         CSWRCBwr_O1
# 4     Water Use         CSWRCBwr_O1
#
#   in_WaterQualityIndicatorCV in_WaterSourceName in_WaterSourceNativeID  \
# 0                                Unnamed Stream
# 1                                  Lake Domingo
# 2                               Icy Spring No 1
# 3                               Icy Spring No 1
# 4                               Icy Spring No 1
#
#   in_WaterSourceTypeCV in_RegulatoryOverlayUUIDs in_WaterSourceUUID  \
# 0              Surface
# 1              Surface
# 2
# 3
# 4
#
#   in_CoordinateAccuracy in_CoordinateMethodCV    in_County  in_EPSGCodeCV  \
# 0                                      GIS_NE    San Diego           4326
# 1                                      GIS_NE    San Diego           4326
# 2                                       DD_NE  Los Angeles           4326
# 3                                       DD_NE  Los Angeles           4326
# 4                                       DD_NE  Los Angeles           4326
#
#   in_GNISCodeCV     in_HUC12   in_HUC8 in_Latitude in_Longitude  \
# 0                -2147483648  18100202    32.64560   -116.28860
# 1                -2147483648  18100202    32.61440   -116.27260
# 2                -2147483648  18090206    34.57797   -118.28921
# 3                -2147483648  18090206    34.57797   -118.28921
# 4                -2147483648  18090206    34.57797   -118.28921
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite          in_SiteName  \
# 0                                                   POD  Compound Stock Pond
# 1                                                   POD         Lake Domingo
# 2                                                   POD
# 3                                                   POD
# 4                                                   POD
#
#   in_SiteNativeID in_SitePoint              in_SiteTypeCV in_StateCV  \
# 0           60497               Point Of Direct Diversion         CA
# 1           60498               Point Of Direct Diversion         CA
# 2             404               Point Of Direct Diversion         CA
# 3             404               Point Of Direct Diversion         CA
# 4             404               Point Of Direct Diversion         CA
#
#   in_USGSSiteID in_AllocationApplicationDate  \
# 0                                  4/18/2013
# 1                                  4/18/2013
# 2
# 3
# 4
#
#   in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                                            0.15000
# 1                                            0.15000
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                  Cancelled               T032025
# 1                  Cancelled               T032025
# 2                   Licensed               A000016
# 3                   Licensed               A000016
# 4                   Licensed               A000016
#
#               in_AllocationOwner in_AllocationPriorityDate  \
# 0  569 EAST COUNTY BOULEVARD LLC
# 1  569 EAST COUNTY BOULEVARD LLC
# 2         LILAC HILLS ESTATES LP
# 3         LILAC HILLS ESTATES LP
# 4         LILAC HILLS ESTATES LP
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0                                                   31-Dec
# 1                                                   31-Dec
# 2                                                   31-Dec
# 3                                                   31-Dec
# 4                                                   31-Dec
#
#   in_AllocationTimeframeStart in_AllocationTypeCV  in_AllocationVolume_AF  \
# 0                       1-Jan    Temporary Permit                     NaN
# 1                       1-Jan    Temporary Permit                     NaN
# 2                       1-Jan       Appropriative                     NaN
# 3                       1-Jan       Appropriative                     NaN
# 4                       1-Jan       Appropriative                     NaN
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0             Dust Control
# 1             Dust Control
# 2                 Domestic
# 3                 Domestic
# 4                 Domestic
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#   in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL  in_Amount  \
# 0  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...        NaN
# 1  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...        NaN
# 2  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...    0.00000
# 3  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...    0.00000
# 4  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...    0.00000
#
#   in_AssociatedNativeAllocationIDs in_PowerGeneratedGWh in_PrimaryUseCategory  \
# 0                          T032025
# 1                          T032025
# 2                          A000016
# 3                          A000016
# 4                          A000016
#
#   in_ReportYearCV in_SDWISIdentifier in_TimeframeEnd in_TimeframeStart
# 0               0                                NaN               NaN
# 1               0                                NaN               NaN
# 2            2011                           1/1/2011          1/1/2011
# 3            2011                           2/1/2011          2/1/2011
# 4            2011                           3/1/2011          3/1/2011

# %% [markdown]
# ## Concatenate POD and POU Data.  Make needed changes

# %%
# etc etc,
# outdf2

# %% [markdown]
# ## Concatenate DataFrames together

# %%
# Concatenate dataframes
frames = [outdf1]  # list all out dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 7739363

# %% [markdown]
# ## Clean Data / data types

# %%
# updating in_WaterSourceTypeCV to be more machine readable / WaDE specific
# ----------------------------------------------------------------------------------------------------

def createWaterSourceTypeCV(inWST):
    inWST = str(inWST).strip()
    
    if inWST == "":
        outString = "Unspecified"
    elif inWST == "Subsurfacer":
        outString = "Groundwater"
    else:
        outString =  "Surface Water"
      
    return outString

outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: createWaterSourceTypeCV(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Unspecified'], dtype=object)

# %%
# Fill empty ben use values

def fillEmptyBenUseFunc(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = "Unspecified"
    else:
        outString = val
    return outString
    
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: fillEmptyBenUseFunc(row['in_BeneficialUseCategory']), axis=1)
outdf['in_PrimaryUseCategory'] = outdf.apply(lambda row: fillEmptyBenUseFunc(row['in_PrimaryUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['Dust Control', 'Domestic', 'Irrigation', 'Power', 'Municipal',
#        'Fish And Wildlife Preservation And Enhancement', 'Stockwatering',
#        'Industrial', 'Mining', 'Recreational', 'Fire Protection',
#        'Incidental Power', 'Frost Protection', 'Aquaculture',
#        'Snow Making', 'Milling', 'Heat Control', 'Other', 'Unspecified',
#        'Aesthetic', 'Water Quality'], dtype=object)

# %%
# Update datatype of Priority Date to fit WaDE 2.0 structure
def formatDateString(inString1):
    inString = str(inString1).strip()
    try:
        if inString == "" or pd.isnull(inString):
            valndf = ""
        else:
            valD = pd.to_datetime(inString)
            valnDd = valD.date()
            valndf = valnDd.strftime('%m/%d/%Y')
    except:
        valndf = ""
    return valndf

outdf['in_AllocationPriorityDate'] = outdf.apply(lambda row: formatDateString(row['in_AllocationPriorityDate']), axis=1)
outdf['in_AllocationPriorityDate'].unique()
# Out:
# array(['', '07/22/1915', '04/17/1916', ..., '06/23/2023', '03/02/2022',
#        '09/09/2021'], dtype=object)

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Unnamed Stream', 'Lake Domingo', 'Icy Spring No 1', ...,
#        'Unnamed Stream, Tributary To Rowes Creek, Thence Outlet Creek',
#        'Unnamed Stream, Tributary To Larabee Creek, Thence Eel River',
#        'Broaddus Creek'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['San Diego', 'Los Angeles', 'Glenn', 'Madera', 'Lake', 'Colusa',
#        'Mono', 'Lassen', 'Tuolumne', 'Riverside', 'San Bernardino',
#        'Inyo', 'Modoc', 'Sacramento', 'El Dorado', 'Trinity', 'Fresno',
#        'San Luis Obispo', 'Santa Clara', 'Shasta', 'Tulare', 'Kern',
#        'San Joaquin', 'Tehama', 'Kings', 'Stanislaus', 'Siskiyou',
#        'Contra Costa', 'Butte', 'Yuba', 'Sierra', 'Napa', 'Sutter',
#        'Placer', 'Ventura', 'Yolo', 'Alpine', 'Plumas', 'Santa Barbara',
#        'Mendocino', 'Sonoma', 'Calaveras', 'Mariposa', 'Merced',
#        'Humboldt', 'Nevada', 'San Benito', 'Solano', 'Santa Cruz',
#        'Monterey', 'Marin', 'Amador', 'Alameda', 'San Mateo', '',
#        'Orange', 'Imperial', 'Del Norte', 'San Francisco'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['Compound Stock Pond', 'Lake Domingo', '', ..., 'Highway Pump',
#        'Money Pit', 'Kurfeld'], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['569 East County Boulevard Llc', 'Lilac Hills Estates Lp',
#        'Glenncolusa Irrigation District', ..., 'Overland Road Llc',
#        'Harugama Llc', 'Richard Casarotti'], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Unnamed Stream', 'Lake Domingo', 'Icy Spring No 1', ...,
#        'Unnamed Stream, Tributary To Rowes Creek, Thence Outlet Creek',
#        'Unnamed Stream, Tributary To Larabee Creek, Thence Eel River',
#        'Broaddus Creek'], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Unspecified'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['Point Of Direct Diversion', 'Point Of Storage - Unspecified',
#        'Point Of Onstream Storage',
#        'Point Of Diversion To Underground Storage',
#        'Point Of Diversion To Offstream Storage', 'Point Of Rediversion',
#        'Movable Point Of Diversion', 'Movable Point Of Rediversion', ''],
#       dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['Compound Stock Pond', 'Lake Domingo', '', ..., 'Highway Pump',
#        'Money Pit', 'Kurfeld'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: ensureEmptyString(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['San Diego', 'Los Angeles', 'Glenn', 'Madera', 'Lake', 'Colusa',
#        'Mono', 'Lassen', 'Tuolumne', 'Riverside', 'San Bernardino',
#        'Inyo', 'Modoc', 'Sacramento', 'El Dorado', 'Trinity', 'Fresno',
#        'San Luis Obispo', 'Santa Clara', 'Shasta', 'Tulare', 'Kern',
#        'San Joaquin', 'Tehama', 'Kings', 'Stanislaus', 'Siskiyou',
#        'Contra Costa', 'Butte', 'Yuba', 'Sierra', 'Napa', 'Sutter',
#        'Placer', 'Ventura', 'Yolo', 'Alpine', 'Plumas', 'Santa Barbara',
#        'Mendocino', 'Sonoma', 'Calaveras', 'Mariposa', 'Merced',
#        'Humboldt', 'Nevada', 'San Benito', 'Solano', 'Santa Cruz',
#        'Monterey', 'Marin', 'Amador', 'Alameda', 'San Mateo', '',
#        'Orange', 'Imperial', 'Del Norte', 'San Francisco'], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['569 East County Boulevard Llc', 'Lilac Hills Estates Lp',
#        'Glenncolusa Irrigation District', ..., 'Overland Road Llc',
#        'Harugama Llc', 'Richard Casarotti'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
uniqueList = list(set([i.strip() for i in ','.join(outdf['in_BeneficialUseCategory'].astype(str)).split(',')]))
uniqueList.sort()
uniqueList
# Out:
# ['Aesthetic',
#  'Aquaculture',
#  'Domestic',
#  'Dust Control',
#  'Fire Protection',
#  'Fish And Wildlife Preservation And Enhancement',
#  'Frost Protection',
#  'Heat Control',
#  'Incidental Power',
#  'Industrial',
#  'Irrigation',
#  'Milling',
#  'Mining',
#  'Municipal',
#  'Other',
#  'Power',
#  'Recreational',
#  'Snow Making',
#  'Stockwatering',
#  'Unspecified',
#  'Water Quality']

# %%
# Ensure Latitude entry is numireic, replace '0' values for removal
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([32.6456, 32.6144, 34.57797187, ..., 39.399486, 39.39983869,
#        39.215055], dtype=object)

# %%
# Ensure Longitude entry is numireic, replace '0' values for removal
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-116.2886, -116.2726, -118.2892096, ..., -123.390005, -123.3898763,
#        -123.312955], dtype=object)

# %%
# Fixing in_AllocationFlow_CFS datatype
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([0.15, '', 2.5, ..., 2.359461799411124e-05, 0.5347222208297164,
#        0.5057581005347734], dtype=object)

# %%
# Fixing in_AllocationVolume_AF datatype
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array(['', 0.13, 365.0, 20.62], dtype=object)

# %%
# Ensure Amount entry is either numireic or blank, no 0 entries
outdf['in_Amount'] = pd.to_numeric(outdf['in_Amount'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_Amount'].unique()
# Out:
# array(['', 3270.0, 6758.0, ..., 141834.0, 411.82, 354.06], dtype=object)

# %%
# Ensure PopulationServed entry is numireic WITH 0 entries (no blank strings)
outdf['in_PopulationServed'] = pd.to_numeric(outdf['in_PopulationServed'], errors='coerce').round().replace("",0).fillna(0).astype(int).replace(0,"").fillna("")
outdf['in_PopulationServed'].unique()
# Out:
# array([''], dtype=object)

# %%
#Update datatype of Priority Date to fit WaDE 2.0 structure
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'])
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# <DatetimeArray>
# [                'NaT', '1915-07-22 00:00:00', '1916-04-17 00:00:00',
#  '1916-04-28 00:00:00', '1917-01-03 00:00:00', '1917-07-12 00:00:00',
#  '1918-12-31 00:00:00', '1919-02-26 00:00:00', '1919-10-10 00:00:00',
#  '1920-02-11 00:00:00',
#  ...
#  '2020-10-01 00:00:00', '2023-05-10 00:00:00', '2021-06-07 00:00:00',
#  '2021-12-10 00:00:00', '2022-04-05 00:00:00', '2021-04-19 00:00:00',
#  '2022-05-20 00:00:00', '2023-06-23 00:00:00', '2022-03-02 00:00:00',
#  '2021-09-09 00:00:00']
# Length: 1868, dtype: datetime64[ns]

# %%
# Convert TimeframeEnd to YYYY-MM-DD format.
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf['in_TimeframeEnd'], utc=True, errors = 'coerce').fillna("")
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf["in_TimeframeEnd"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeEnd'].unique()
# Out:
# <DatetimeArray>
# [                'NaT', '2011-01-01 00:00:00', '2011-02-01 00:00:00',
#  '2011-03-01 00:00:00', '2011-04-01 00:00:00', '2011-05-01 00:00:00',
#  '2011-06-01 00:00:00', '2011-07-01 00:00:00', '2011-08-01 00:00:00',
#  '2011-09-01 00:00:00',
#  ...
#  '1974-12-01 00:00:00', '1977-12-01 00:00:00', '1978-12-01 00:00:00',
#  '1979-12-01 00:00:00', '1980-12-01 00:00:00', '1981-12-01 00:00:00',
#  '1982-12-01 00:00:00', '1983-12-01 00:00:00', '1984-12-01 00:00:00',
#  '1985-12-01 00:00:00']
# Length: 709, dtype: datetime64[ns]

# %%
# Convert TimeframeStart to YYYY-MM-DD format.
outdf['in_TimeframeStart'] = pd.to_datetime(outdf['in_TimeframeStart'], utc=True, errors = 'coerce').fillna("")
outdf['in_TimeframeStart'] = pd.to_datetime(outdf["in_TimeframeStart"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeStart'].unique()
# Out:
# <DatetimeArray>
# [                'NaT', '2011-01-01 00:00:00', '2011-02-01 00:00:00',
#  '2011-03-01 00:00:00', '2011-04-01 00:00:00', '2011-05-01 00:00:00',
#  '2011-06-01 00:00:00', '2011-07-01 00:00:00', '2011-08-01 00:00:00',
#  '2011-09-01 00:00:00',
#  ...
#  '1974-12-01 00:00:00', '1977-12-01 00:00:00', '1978-12-01 00:00:00',
#  '1979-12-01 00:00:00', '1980-12-01 00:00:00', '1981-12-01 00:00:00',
#  '1982-12-01 00:00:00', '1983-12-01 00:00:00', '1984-12-01 00:00:00',
#  '1985-12-01 00:00:00']
# Length: 709, dtype: datetime64[ns]

# %%
# extract year out
outdf['in_ReportYearCV'].unique()
# Out:
# array(['0', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2008', '2009', '2010', '2021', '2022',
#        '2007', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '1975', '1930', '1993', '1994',
#        '1995', '1991', '1992', '1986', '1987', '1988', '1989', '1990',
#        '1915', '1963', '1913', '1959', '1906', '1916', '1976', '1971',
#        '1972', '1973', '1974', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985'], dtype=object)

# %%
# Assign Primary Use Category

import sys
sys.path.append("C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/5_CustomFunctions/AssignPrimaryUseCategory")
import AssignPrimaryUseCategoryFile # Use Custom import file

outdf['in_PrimaryUseCategory'] = outdf.apply(lambda row: AssignPrimaryUseCategoryFile.retrievePrimaryUseCategory(row['in_BeneficialUseCategory']), axis=1)
outdf['in_PrimaryUseCategory'].unique()
# Out:
# array(['Other', 'Domestic', 'Agriculture Irrigation', 'Hydroelectric',
#        'Public Supply', 'In-stream Flow', 'Livestock',
#        'Commercial/Industrial', 'Mining', 'Recreation', 'Fire',
#        'Unspecified', 'Aquaculture', 'Snow', 'Thermoelectric Cooling',
#        'Municipal Irrigation'], dtype=object)

# %%
# Creating WaDE Custom VariableSpecificCV
# ----------------------------------------------------------------------------------------------------
def createVariableSpecificCV(inV, inAIU, inPU, inWST):
    inV = str(inV).strip()
    inAIU = str(inAIU).strip()
    inPU = str(inPU).strip().title()
    inWST = str(inWST).strip()
    outString = inV + "_" + inAIU + "_" + inPU + "_" + inWST
    return outString

outdf['in_VariableSpecificCV'] = outdf.apply(lambda row: createVariableSpecificCV(row['in_VariableCV'], 
                                                                                  row['in_AggregationIntervalUnitCV'],
                                                                                  row['in_PrimaryUseCategory'],
                                                                                  row['in_WaterSourceTypeCV']), axis=1)
outdf['in_VariableSpecificCV'].unique()
# Out:
# array(['Water Use_Monthly_Other_Surface Water',
#        'Water Use_Monthly_Domestic_Unspecified',
#        'Water Use_Monthly_Agriculture Irrigation_Unspecified',
#        'Water Use_Monthly_Hydroelectric_Unspecified',
#        'Water Use_Monthly_Domestic_Surface Water',
#        'Water Use_Monthly_Public Supply_Unspecified',
#        'Water Use_Monthly_In-Stream Flow_Unspecified',
#        'Water Use_Monthly_Agriculture Irrigation_Surface Water',
#        'Water Use_Monthly_Livestock_Unspecified',
#        'Water Use_Monthly_Public Supply_Surface Water',
#        'Water Use_Monthly_Commercial/Industrial_Surface Water',
#        'Water Use_Monthly_Mining_Unspecified',
#        'Water Use_Monthly_Recreation_Unspecified',
#        'Water Use_Monthly_Commercial/Industrial_Unspecified',
#        'Water Use_Monthly_Livestock_Surface Water',
#        'Water Use_Monthly_Hydroelectric_Surface Water',
#        'Water Use_Monthly_Fire_Unspecified',
#        'Water Use_Monthly_Unspecified_Unspecified',
#        'Water Use_Monthly_Other_Unspecified',
#        'Water Use_Monthly_Aquaculture_Unspecified',
#        'Water Use_Monthly_Snow_Unspecified',
#        'Water Use_Monthly_In-Stream Flow_Surface Water',
#        'Water Use_Monthly_Thermoelectric Cooling_Unspecified',
#        'Water Use_Monthly_Unspecified_Surface Water',
#        'Water Use_Monthly_Fire_Surface Water',
#        'Water Use_Monthly_Recreation_Surface Water',
#        'Water Use_Monthly_Thermoelectric Cooling_Surface Water',
#        'Water Use_Monthly_Aquaculture_Surface Water',
#        'Water Use_Monthly_Mining_Surface Water',
#        'Water Use_Monthly_Municipal Irrigation_Surface Water',
#        'Water Use_Monthly_Snow_Surface Water',
#        'Water Use_Monthly_Municipal Irrigation_Unspecified'], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], 
                                                                              row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', ..., 'wadeId9701', 'wadeId9702',
#        'wadeId9703'], dtype=object)

# %%
# Creating WaDE Custom site native ID for easy site identification
# use Unique Latitude, Longitude, SiteName and SiteTypeCV values
# ----------------------------------------------------------------------------------------------------

# Create temp in_SiteNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_Latitude'] = outdf['in_Latitude'].astype(str).str.strip()
dfTempID['in_Longitude'] = outdf['in_Longitude'].astype(str).str.strip()
dfTempID['in_SiteName'] = outdf['in_SiteName'].astype(str).str.strip()
dfTempID['in_SiteTypeCV'] = outdf['in_SiteTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_SiteNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_Latitude'].astype(str) + dfTempID['in_Longitude'].astype(str) + dfTempID['in_SiteName'].astype(str)+ dfTempID['in_SiteTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_SiteNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB, valC, valD):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip() + str(valC).strip() + str(valD).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_SiteNativeID'], 
                                                                       row['in_Latitude'], row['in_Longitude'],
                                                                       row['in_SiteName'], row['in_SiteTypeCV']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# array(['60497', '60498', '404', ..., '85187', '85188', '85189'],
#       dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For CA, we don't want water rights that are considered: "Cancelled", "Closed", "Inactive", "Pending", "Rejected", "Revoked"

# %%
# drop non-active AllocationLegalStatusCV values specific to that state.

print(f'length of df before removing non-active rights: ', len(outdf))

# drop list
dropLegalStatusList = ["Cancelled", "Closed", "Inactive", "Pending", "Rejected", "Revoked"]

# drop rows from above list
outdf = outdf[outdf.in_AllocationLegalStatusCV.isin(dropLegalStatusList) == False].reset_index(drop=True)

print(f'length of df after removing non-active rights: ', len(outdf))
for x in outdf['in_AllocationLegalStatusCV'].sort_values().unique():
    print(f'"' + x + '",')
# Out:
# length of df before removing non-active rights:  7739363
# length of df after removing non-active rights:  7545262
# "",
# "Active",
# "Adjudicated",
# "Certified",
# "Claimed",
# "Claimed - Local Oversight",
# "Completed",
# "Licensed",
# "Permitted",
# "Registered",

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to POU csv inputs.

# %%
# N/A

# %% [markdown]
# ## Export Outputs

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7545262 entries, 0 to 7545261
# Data columns (total 76 columns):
#  #   Column                                        Dtype
# ---  ------                                        -----
#  0   WaDEUUID                                      object
#  1   in_MethodUUID                                 object
#  2   in_VariableSpecificUUID                       object
#  3   in_AggregationIntervalUnitCV                  object
#  4   in_VariableCV                                 object
#  5   in_OrganizationUUID                           object
#  6   in_Geometry                                   object
#  7   in_GNISFeatureNameCV                          object
#  8   in_WaterQualityIndicatorCV                    object
#  9   in_WaterSourceName                            object
#  10  in_WaterSourceNativeID                        object
#  11  in_WaterSourceTypeCV                          object
#  12  in_RegulatoryOverlayUUIDs                     object
#  13  in_WaterSourceUUID                            object
#  14  in_CoordinateAccuracy                         object
#  15  in_CoordinateMethodCV                         object
#  16  in_County                                     object
#  17  in_EPSGCodeCV                                 int64
#  18  in_GNISCodeCV                                 object
#  19  in_HUC12                                      object
#  20  in_HUC8                                       object
#  21  in_Latitude                                   object
#  22  in_Longitude                                  object
#  23  in_NHDNetworkStatusCV                         object
#  24  in_NHDProductCV                               object
#  25  in_PODorPOUSite                               object
#  26  in_SiteName                                   object
#  27  in_SiteNativeID                               object
#  28  in_SitePoint                                  object
#  29  in_SiteTypeCV                                 object
#  30  in_StateCV                                    object
#  31  in_USGSSiteID                                 object
#  32  in_AllocationApplicationDate                  object
#  33  in_AllocationAssociatedConsumptiveUseSiteIDs  object
#  34  in_AllocationAssociatedWithdrawalSiteIDs      object
#  35  in_AllocationBasisCV                          object
#  36  in_AllocationChangeApplicationIndicator       object
#  37  in_AllocationCommunityWaterSupplySystem       object
#  38  in_AllocationCropDutyAmount                   object
#  39  in_AllocationExpirationDate                   object
#  40  in_AllocationFlow_CFS                         object
#  41  in_AllocationLegalStatusCV                    object
#  42  in_AllocationNativeID                         object
#  43  in_AllocationOwner                            object
#  44  in_AllocationPriorityDate                     datetime64[ns]
#  45  in_AllocationSDWISIdentifierCV                object
#  46  in_AllocationTimeframeEnd                     object
#  47  in_AllocationTimeframeStart                   object
#  48  in_AllocationTypeCV                           object
#  49  in_AllocationVolume_AF                        object
#  50  in_BeneficialUseCategory                      object
#  51  in_CommunityWaterSupplySystem                 object
#  52  in_CropTypeCV                                 object
#  53  in_CustomerTypeCV                             object
#  54  in_DataPublicationDate                        object
#  55  in_DataPublicationDOI                         object
#  56  in_ExemptOfVolumeFlowPriority                 object
#  57  in_GeneratedPowerCapacityMW                   object
#  58  in_IrrigatedAcreage                           object
#  59  in_IrrigationMethodCV                         object
#  60  in_LegacyAllocationIDs                        object
#  61  in_OwnerClassificationCV                      object
#  62  in_PopulationServed                           object
#  63  in_PowerType                                  object
#  64  in_PrimaryBeneficialUseCategory               object
#  65  in_SDWISIdentifierCV                          object
#  66  in_WaterAllocationNativeURL                   object
#  67  in_Amount                                     object
#  68  in_AssociatedNativeAllocationIDs              object
#  69  in_PowerGeneratedGWh                          object
#  70  in_PrimaryUseCategory                         object
#  71  in_ReportYearCV                               object
#  72  in_SDWISIdentifier                            object
#  73  in_TimeframeEnd                               datetime64[ns]
#  74  in_TimeframeStart                             datetime64[ns]
#  75  in_VariableSpecificCV                         object
# dtypes: datetime64[ns](3), int64(1), object(72)
# memory usage: 4.3+ GB

# %%
outdf
# Out:
#          WaDEUUID in_MethodUUID in_VariableSpecificUUID  \
# 0            in12   CSWRCBwr_M1             CSWRCBwr_V1
# 1            in12   CSWRCBwr_M1             CSWRCBwr_V1
# 2            in12   CSWRCBwr_M1             CSWRCBwr_V1
# 3            in12   CSWRCBwr_M1             CSWRCBwr_V1
# 4            in12   CSWRCBwr_M1             CSWRCBwr_V1
# ...           ...           ...                     ...
# 7545257  in164868   CSWRCBwr_M1             CSWRCBwr_V1
# 7545258  in164869   CSWRCBwr_M1             CSWRCBwr_V1
# 7545259  in164870   CSWRCBwr_M1             CSWRCBwr_V1
# 7545260  in164871   CSWRCBwr_M1             CSWRCBwr_V1
# 7545261  in164872   CSWRCBwr_M1             CSWRCBwr_V1
#
#         in_AggregationIntervalUnitCV in_VariableCV in_OrganizationUUID  \
# 0                            Monthly     Water Use         CSWRCBwr_O1
# 1                            Monthly     Water Use         CSWRCBwr_O1
# 2                            Monthly     Water Use         CSWRCBwr_O1
# 3                            Monthly     Water Use         CSWRCBwr_O1
# 4                            Monthly     Water Use         CSWRCBwr_O1
# ...                              ...           ...                 ...
# 7545257                      Monthly     Water Use         CSWRCBwr_O1
# 7545258                      Monthly     Water Use         CSWRCBwr_O1
# 7545259                      Monthly     Water Use         CSWRCBwr_O1
# 7545260                      Monthly     Water Use         CSWRCBwr_O1
# 7545261                      Monthly     Water Use         CSWRCBwr_O1
#
#         in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...             ...                  ...                        ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0          Icy Spring No 1                wadeId3          Unspecified
# 1          Icy Spring No 1                wadeId3          Unspecified
# 2          Icy Spring No 1                wadeId3          Unspecified
# 3          Icy Spring No 1                wadeId3          Unspecified
# 4          Icy Spring No 1                wadeId3          Unspecified
# ...                    ...                    ...                  ...
# 7545257     Broaddus Creek             wadeId9703        Surface Water
# 7545258                                  wadeId40        Surface Water
# 7545259                                 wadeId362          Unspecified
# 7545260                                  wadeId40        Surface Water
# 7545261     Unnamed Spring             wadeId3667        Surface Water
#
#         in_RegulatoryOverlayUUIDs in_WaterSourceUUID in_CoordinateAccuracy  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                ...                   ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_CoordinateMethodCV    in_County  in_EPSGCodeCV in_GNISCodeCV  \
# 0                       DD_NE  Los Angeles           4326
# 1                       DD_NE  Los Angeles           4326
# 2                       DD_NE  Los Angeles           4326
# 3                       DD_NE  Los Angeles           4326
# 4                       DD_NE  Los Angeles           4326
# ...                       ...          ...            ...           ...
# 7545257                GIS_LL    Mendocino           4326
# 7545258             GIS_CLICK    Mendocino           4326
# 7545259                                              4326
# 7545260                                              4326
# 7545261                GIS_LL    Mendocino           4326
#
#             in_HUC12   in_HUC8 in_Latitude in_Longitude in_NHDNetworkStatusCV  \
# 0        -2147483648  18090206    34.57797   -118.28921
# 1        -2147483648  18090206    34.57797   -118.28921
# 2        -2147483648  18090206    34.57797   -118.28921
# 3        -2147483648  18090206    34.57797   -118.28921
# 4        -2147483648  18090206    34.57797   -118.28921
# ...              ...       ...         ...          ...                   ...
# 7545257  -2147483648  18010103    39.39949   -123.39001
# 7545258  -2147483648  18010103    39.39984   -123.38988
# 7545259            0         0
# 7545260            0         0
# 7545261  -2147483648  18010110    39.21505   -123.31296
#
#         in_NHDProductCV in_PODorPOUSite  in_SiteName in_SiteNativeID  \
# 0                                   POD                          404
# 1                                   POD                          404
# 2                                   POD                          404
# 3                                   POD                          404
# 4                                   POD                          404
# ...                 ...             ...          ...             ...
# 7545257                             POD  Primary Pod           85123
# 7545258                             POD    Money Pit           85124
# 7545259                             POD                        85187
# 7545260                             POD      Kurfeld           85188
# 7545261                             POD  Primary Pod           85189
#
#         in_SitePoint                            in_SiteTypeCV in_StateCV  \
# 0                                   Point Of Direct Diversion         CA
# 1                                   Point Of Direct Diversion         CA
# 2                                   Point Of Direct Diversion         CA
# 3                                   Point Of Direct Diversion         CA
# 4                                   Point Of Direct Diversion         CA
# ...              ...                                      ...        ...
# 7545257               Point Of Diversion To Offstream Storage         CA
# 7545258               Point Of Diversion To Offstream Storage         CA
# 7545259                                                               CA
# 7545260               Point Of Diversion To Offstream Storage         CA
# 7545261               Point Of Diversion To Offstream Storage         CA
#
#         in_USGSSiteID in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...               ...                          ...
# 7545257                                   3/2/2022
# 7545258                                   3/2/2022
# 7545259
# 7545260                                   9/9/2021
# 7545261                                   9/9/2021
#
#         in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                              ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                          ...                  ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...                         ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...                   ...
# 7545257                                           0.02228
# 7545258                                           0.02228
# 7545259
# 7545260                                           0.02228
# 7545261                                           0.02228
#
#         in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                         Licensed               A000016
# 1                         Licensed               A000016
# 2                         Licensed               A000016
# 3                         Licensed               A000016
# 4                         Licensed               A000016
# ...                            ...                   ...
# 7545257                 Registered               H511199
# 7545258                 Registered               H511199
# 7545259                     Active              NJ000780
# 7545260                 Registered               H511005
# 7545261                 Registered               H511005
#
#              in_AllocationOwner in_AllocationPriorityDate  \
# 0        Lilac Hills Estates Lp                       NaT
# 1        Lilac Hills Estates Lp                       NaT
# 2        Lilac Hills Estates Lp                       NaT
# 3        Lilac Hills Estates Lp                       NaT
# 4        Lilac Hills Estates Lp                       NaT
# ...                         ...                       ...
# 7545257       Richard Casarotti                2022-03-02
# 7545258       Richard Casarotti                2022-03-02
# 7545259                                               NaT
# 7545260          David Kurzfeld                2021-09-09
# 7545261          David Kurzfeld                2021-09-09
#
#         in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0                                                         31-Dec
# 1                                                         31-Dec
# 2                                                         31-Dec
# 3                                                         31-Dec
# 4                                                         31-Dec
# ...                                ...                       ...
# 7545257                                                   31-Mar
# 7545258                                                   31-Mar
# 7545259
# 7545260                                                   31-Mar
# 7545261                                                   31-Mar
#
#         in_AllocationTimeframeStart    in_AllocationTypeCV  \
# 0                             1-Jan          Appropriative
# 1                             1-Jan          Appropriative
# 2                             1-Jan          Appropriative
# 3                             1-Jan          Appropriative
# 4                             1-Jan          Appropriative
# ...                             ...                    ...
# 7545257                       1-Nov  Registration Cannabis
# 7545258                       1-Nov  Registration Cannabis
# 7545259                                 Non Jurisdictional
# 7545260                       1-Nov  Registration Cannabis
# 7545261                       1-Nov  Registration Cannabis
#
#         in_AllocationVolume_AF in_BeneficialUseCategory  \
# 0                                              Domestic
# 1                                              Domestic
# 2                                              Domestic
# 3                                              Domestic
# 4                                              Domestic
# ...                        ...                      ...
# 7545257                                      Irrigation
# 7545258                                      Irrigation
# 7545259                                     Unspecified
# 7545260                                 Fire Protection
# 7545261                                 Fire Protection
#
#         in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...           ...               ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                   ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                   1
# 1                                   1
# 2                                   1
# 3                                   1
# 4                                   1
# ...                               ...                         ...
# 7545257                             1
# 7545258                             1
# 7545259                             1
# 7545260                             1
# 7545261                             1
#
#         in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...                   ...                    ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                 ...          ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#         in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                 ...                  ...
# 7545257
# 7545258
# 7545259
# 7545260
# 7545261
#
#                                in_WaterAllocationNativeURL in_Amount  \
# 0        https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
# 1        https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
# 2        https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
# 3        https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
# 4        https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
# ...                                                    ...       ...
# 7545257  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
# 7545258  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
# 7545259  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
# 7545260  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
# 7545261  https://ciwqs.waterboards.ca.gov/ciwqs/ewrims/...
#
#         in_AssociatedNativeAllocationIDs in_PowerGeneratedGWh  \
# 0                                A000016
# 1                                A000016
# 2                                A000016
# 3                                A000016
# 4                                A000016
# ...                                  ...                  ...
# 7545257                          H511199
# 7545258                          H511199
# 7545259                         NJ000780
# 7545260                          H511005
# 7545261                          H511005
#
#           in_PrimaryUseCategory in_ReportYearCV in_SDWISIdentifier  \
# 0                      Domestic            2011
# 1                      Domestic            2011
# 2                      Domestic            2011
# 3                      Domestic            2011
# 4                      Domestic            2011
# ...                         ...             ...                ...
# 7545257  Agriculture Irrigation               0
# 7545258  Agriculture Irrigation               0
# 7545259             Unspecified               0
# 7545260                    Fire               0
# 7545261                    Fire               0
#
#         in_TimeframeEnd in_TimeframeStart  \
# 0            2011-01-01        2011-01-01
# 1            2011-02-01        2011-02-01
# 2            2011-03-01        2011-03-01
# 3            2011-04-01        2011-04-01
# 4            2011-05-01        2011-05-01
# ...                 ...               ...
# 7545257             NaT               NaT
# 7545258             NaT               NaT
# 7545259             NaT               NaT
# 7545260             NaT               NaT
# 7545261             NaT               NaT
#
#                                      in_VariableSpecificCV
# 0                   Water Use_Monthly_Domestic_Unspecified
# 1                   Water Use_Monthly_Domestic_Unspecified
# 2                   Water Use_Monthly_Domestic_Unspecified
# 3                   Water Use_Monthly_Domestic_Unspecified
# 4                   Water Use_Monthly_Domestic_Unspecified
# ...                                                    ...
# 7545257  Water Use_Monthly_Agriculture Irrigation_Surfa...
# 7545258  Water Use_Monthly_Agriculture Irrigation_Surfa...
# 7545259          Water Use_Monthly_Unspecified_Unspecified
# 7545260               Water Use_Monthly_Fire_Surface Water
# 7545261               Water Use_Monthly_Fire_Surface Water
#
# [7545262 rows x 76 columns]

# %%
# Export the output dataframe
outdf.to_csv('RawInputData/Pwr_wu_Main.zip', compression=dict(method='zip', archive_name='Pwr_wu_Main.csv'), index=False)  # The output, save as a zip
