# %% [markdown]
# # Pre-processing California for Site-Specific Division & Withdrawl Site data for WaDE upload
# - Purpose:  To pre-process the data into one main file for simple DataFrame creation and extraction

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/California/SS_DiversionsWithdrawalsWaterUse" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/California/SS_DiversionsWithdrawalsWaterUse

# %% [markdown]
# ## Data Input 1

# %%
# Input File - gage stations
fileInput = "RawInputData/water-rights-water-use-reported-2016-18.zip"
dfin1 = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin1:
    dfin1['WaDEUUID'] = "in1" + dfin1.index.astype(str)
    dfin1.to_csv("RawInputData/water-rights-water-use-reported-2016-18.zip", compression=dict(method='zip', archive_name='water-rights-water-use-reported-2016-18.csv'), index=False)

print(len(dfin1))
dfin1.head()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_21808\2483223087.py:3: DtypeWarning: Columns (15,16,18,19,20,21,22,24,25,28,30,43,44,46,49,51,53,54,55,57,62,71,76,82,83,84,85,87,88,92,93,98,99,101,102,108,119,126,136,143,144,145,146,147,148,150,151,152,153,154,155,156,157,158,159,161,163,164,165,166) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfin1 = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")
# 4889274
#   ÃÂ¯ÃÂ»ÃÂ¿MONTH NAME MONTH FORMATTED  WATER_RIGHT_ID  APPL_ID  YEAR  \
# 0                January        1/1/2016             331  A002270  2016
# 1                January        1/1/2017             331  A002270  2017
# 2                January        1/1/2018             331  A002270  2018
# 3                January        1/1/2021             331  A002270  2021
# 4                January        1/1/2022             331  A002270  2022
#
#    MONTH     AMOUNT DIVERSION_TYPE  WR_WATER_RIGHT_ID APPLICATION_NUMBER  \
# 0      1 1047.00000         DIRECT                331            A002270
# 1      1    0.00000         DIRECT                331            A002270
# 2      1    0.00000         DIRECT                331            A002270
# 3      1    0.00000         DIRECT                331            A002270
# 4      1    0.00000         DIRECT                331            A002270
#
#   CERTIFICATE_ID  PERMIT_ID  LICENSE_ID WATER_RIGHT_TYPE WATER_RIGHT_STATUS  \
# 0    11835.00000 2631.00000 11835.00000    Appropriative           Licensed
# 1    11835.00000 2631.00000 11835.00000    Appropriative           Licensed
# 2    11835.00000 2631.00000 11835.00000    Appropriative           Licensed
# 3    11835.00000 2631.00000 11835.00000    Appropriative           Licensed
# 4    11835.00000 2631.00000 11835.00000    Appropriative           Licensed
#
#   PRIORITY_DATE RECEIPT_DATE REJECTION_DATE APPLICATION_RECD_DATE  \
# 0                  3/22/1921                            3/22/1921
# 1                  3/22/1921                            3/22/1921
# 2                  3/22/1921                            3/22/1921
# 3                  3/22/1921                            3/22/1921
# 4                  3/22/1921                            3/22/1921
#
#   APPLICATION_ACCEPTANCE_DATE PROJECT_TYPE  \
# 0                   3/22/1921
# 1                   3/22/1921
# 2                   3/22/1921
# 3                   3/22/1921
# 4                   3/22/1921
#
#                          RECORD_SUMMARY INCOMPLETE_STATEMENT  \
# 0  Migrated data from old WRIMS system.
# 1  Migrated data from old WRIMS system.
# 2  Migrated data from old WRIMS system.
# 3  Migrated data from old WRIMS system.
# 4  Migrated data from old WRIMS system.
#
#    NUMBER_OF_PROTESTS       AGENT_NAME AGENT_ENTITY_TYPE  \
# 0                   0  BRIAN   MUELLER        Individual
# 1                   0  BRIAN   MUELLER        Individual
# 2                   0  BRIAN   MUELLER        Individual
# 3                   0  BRIAN   MUELLER        Individual
# 4                   0  BRIAN   MUELLER        Individual
#
#        APPLICATION_PRIMARY_OWNER PRIMARY_OWNER_ENTITY_TYPE SUB_TYPE  \
# 0  EL DORADO IRRIGATION DISTRICT               Corporation
# 1  EL DORADO IRRIGATION DISTRICT               Corporation
# 2  EL DORADO IRRIGATION DISTRICT               Corporation
# 3  EL DORADO IRRIGATION DISTRICT               Corporation
# 4  EL DORADO IRRIGATION DISTRICT               Corporation
#
#   INI_REPORTED_DIV_AMOUNT INI_REPORTED_DIV_UNIT  FACE_VALUE_AMOUNT  \
# 0                                                      29845.90000
# 1                                                      29845.90000
# 2                                                      29845.90000
# 3                                                      29845.90000
# 4                                                      29845.90000
#
#      FACE_VALUE_UNITS FEE_RECEIVED APPL_FEE_AMOUNT APPL_FEE_AMT_RECD  \
# 0  Acre-feet per Year      5.00000         5.00000           5.00000
# 1  Acre-feet per Year      5.00000         5.00000           5.00000
# 2  Acre-feet per Year      5.00000         5.00000           5.00000
# 3  Acre-feet per Year      5.00000         5.00000           5.00000
# 4  Acre-feet per Year      5.00000         5.00000           5.00000
#
#   MAX_DD_APPL           MAX_DD_UNITS MAX_DD_ANN MAX_STORAGE  \
# 0    63.80000  Cubic Feet per Second    0.00000 22000.00000
# 1    63.80000  Cubic Feet per Second    0.00000 22000.00000
# 2    63.80000  Cubic Feet per Second    0.00000 22000.00000
# 3    63.80000  Cubic Feet per Second    0.00000 22000.00000
# 4    63.80000  Cubic Feet per Second    0.00000 22000.00000
#
#   MAX_TAKEN_FROM_SOURCE YEAR_DIVERSION_COMMENCED MAX_BENEFICIALLY_USED  \
# 0           29845.90000                                        0.00000
# 1           29845.90000                                        0.00000
# 2           29845.90000                                        0.00000
# 3           29845.90000                                        0.00000
# 4           29845.90000                                        0.00000
#
#   SUPPLEMENTAL_STATEMENT_CYCLE TYPE_OF_DIVERSION_FACILITY  \
# 0
# 1
# 2
# 3
# 4
#
#   QUANTITY_OF_WATER_DIVERTED QOW_DIVERTED_UNIT QUANTITY_MEASUREMENT_YEAR  \
# 0
# 1
# 2
# 3
# 4
#
#   MAX_RATE_OF_DIVERSION MAX_RATE_OF_DIV_UNIT RECENT_WATER_USE_MIN  \
# 0
# 1
# 2
# 3
# 4
#
#   WATER_USE_MIN_UNIT RECENT_WATER_USE_MAX WATER_USE_MAX_UNIT  \
# 0
# 1
# 2
# 3
# 4
#
#   REQUEST_FOR_REVOCATION_RECD STATE_WELL_NUMBER DRILLED_WELL_YEAR  \
# 0                           N
# 1                           N
# 2                           N
# 3                           N
# 4                           N
#
#   SURFACE_WATER_DIVERSIONS DEPTH_OF_WELL RELATIONSHIP_TYPE     PARTY_ID  \
# 0                                            Primary Owner 401810.00000
# 1                                            Primary Owner 401810.00000
# 2                                            Primary Owner 401810.00000
# 3                                            Primary Owner 401810.00000
# 4                                            Primary Owner 401810.00000
#
#   EFFECTIVE_FROM_DATE EFFECTIVE_TO_DATE             PRIMARY_OWNER_NAME  \
# 0           1/23/2004                    EL DORADO IRRIGATION DISTRICT
# 1           1/23/2004                    EL DORADO IRRIGATION DISTRICT
# 2           1/23/2004                    EL DORADO IRRIGATION DISTRICT
# 3           1/23/2004                    EL DORADO IRRIGATION DISTRICT
# 4           1/23/2004                    EL DORADO IRRIGATION DISTRICT
#
#   OFFICIAL_MAIL_RECEIVER  COUNT_NPO_OR_OTHER EFFECTIVE_DATE  \
# 0                      N                   2      1/17/1986
# 1                      N                   2      1/17/1986
# 2                      N                   2      1/17/1986
# 3                      N                   2      1/17/1986
# 4                      N                   2      1/17/1986
#
#          UPDATE_DATETIME          USE_CODE             USE_STATUS  \
# 0  10/5/2009 10:26:27 AM  Incidental Power  Added by change order
# 1  10/5/2009 10:26:27 AM  Incidental Power  Added by change order
# 2  10/5/2009 10:26:27 AM  Incidental Power  Added by change order
# 3  10/5/2009 10:26:27 AM  Incidental Power  Added by change order
# 4  10/5/2009 10:26:27 AM  Incidental Power  Added by change order
#
#   NUMBER_OF_RESIDENCES SEPERATELY_OWNED USE_POPULATION USE_POPULATION_PEOPLE  \
# 0                                              0.00000
# 1                                              0.00000
# 2                                              0.00000
# 3                                              0.00000
# 4                                              0.00000
#
#   ESTIMATED_USE_PER_PERSON USE_POPULATION_STOCK TYPE_OF_STOCK  \
# 0
# 1
# 2
# 3
# 4
#
#   AREA_FOR_INCI_IRRIGATION USE_NET_ACREAGE USE_GROSS_ACREAGE  \
# 0                                  0.00000           0.00000
# 1                                  0.00000           0.00000
# 2                                  0.00000           0.00000
# 3                                  0.00000           0.00000
# 4                                  0.00000           0.00000
#
#   USE_DIRECT_DIV_ANNUAL_AMOUNT USE_DIRECT_DIVERSION_RATE  \
# 0                      0.00000
# 1                      0.00000
# 2                      0.00000
# 3                      0.00000
# 4                      0.00000
#
#   USE_DIRECT_DIV_RATE_UNITS POU_DEVELOPMENT_STATUS DIRECT_DIV_SEASON_START  \
# 0     Cubic Feet per Second                                           4/15
# 1     Cubic Feet per Second                                           4/15
# 2     Cubic Feet per Second                                           4/15
# 3     Cubic Feet per Second                                           4/15
# 4     Cubic Feet per Second                                           4/15
#
#   DIRECT_DIV_SEASON_END USE_STORAGE_AMOUNT STORAGE_SEASON_START  \
# 0                  6/15        22000.00000                11/15
# 1                  6/15        22000.00000                11/15
# 2                  6/15        22000.00000                11/15
# 3                  6/15        22000.00000                11/15
# 4                  6/15        22000.00000                11/15
#
#   STORAGE_SEASON_END SEASON_DIRECT_DIV_RATE SEASON_STORAGE_AMOUNT  \
# 0                6/1               63.80000           22000.00000
# 1                6/1               63.80000           22000.00000
# 2                6/1               63.80000           22000.00000
# 3                6/1               63.80000           22000.00000
# 4                6/1               63.80000           22000.00000
#
#   SEASON_DIRECT_DIV_AA DIRECT_DIV_SEASON_STATUS COLLECTION_SEASON_STATUS  \
# 0
# 1
# 2
# 3
# 4
#
#    USE_COUNT POD_NUMBER      POD_ID POD_STATUS SOURCE_TYPE POD_NAME  \
# 0          7    1.00000 40933.00000     Active
# 1          7    1.00000 40933.00000     Active
# 2          7    1.00000 40933.00000     Active
# 3          7    1.00000 40933.00000     Active
# 4          7    1.00000 40933.00000     Active
#
#                                             POD_TYPE DIVERSION_WORKS_STATUS  \
# 0  Point of Direct Diversion,Point of Storage - U...
# 1  Point of Direct Diversion,Point of Storage - U...
# 2  Point of Direct Diversion,Point of Storage - U...
# 3  Point of Direct Diversion,Point of Storage - U...
# 4  Point of Direct Diversion,Point of Storage - U...
#
#   STREAM_CLASSIFICATION DIRECT_DIV_AMOUNT DIRECT_DIVERSION_RATE  \
# 0                                 0.00000              27.10000
# 1                                 0.00000              27.10000
# 2                                 0.00000              27.10000
# 3                                 0.00000              27.10000
# 4                                 0.00000              27.10000
#
#     DIRECT_DIV_RATE_UNIT STORAGE_AMOUNT DIVERSION_RATE_TO_OFF_STREAM  \
# 0  Cubic Feet per Second     7000.00000
# 1  Cubic Feet per Second     7000.00000
# 2  Cubic Feet per Second     7000.00000
# 3  Cubic Feet per Second     7000.00000
# 4  Cubic Feet per Second     7000.00000
#
#   OFF_STO_DIV_RATE_UNIT  POD_LAST_UPDATE_DATE  POD_COUNT APPLICATION_ID  \
# 0                        9/28/2007 6:55:24 PM    2.00000        A002270
# 1                        9/28/2007 6:55:24 PM    2.00000        A002270
# 2                        9/28/2007 6:55:24 PM    2.00000        A002270
# 3                        9/28/2007 6:55:24 PM    2.00000        A002270
# 4                        9/28/2007 6:55:24 PM    2.00000        A002270
#
#      OBJECTID POD_NUMBER_GIS HAS_OPOD    APPL_POD  POD_ID_GIS     COUNTY  \
# 0 74857.00000        1.00000        N  A002270_01 40933.00000  El Dorado
# 1 74857.00000        1.00000        N  A002270_01 40933.00000  El Dorado
# 2 74857.00000        1.00000        N  A002270_01 40933.00000  El Dorado
# 3 74857.00000        1.00000        N  A002270_01 40933.00000  El Dorado
# 4 74857.00000        1.00000        N  A002270_01 40933.00000  El Dorado
#
#   SP_ZONE DIVERSION_SITE_NAME   NORTH_COORD    EAST_COORD LATITUDE  LONGITUDE  \
# 0 2.00000                     2025485.09699 6972060.86210 38.71507 -120.56160
# 1 2.00000                     2025485.09699 6972060.86210 38.71507 -120.56160
# 2 2.00000                     2025485.09699 6972060.86210 38.71507 -120.56160
# 3 2.00000                     2025485.09699 6972060.86210 38.71507 -120.56160
# 4 2.00000                     2025485.09699 6972060.86210 38.71507 -120.56160
#
#   QUARTER_QUARTER QUARTER SECTION_CLASSIFIER SECTION_NUMBER TOWNSHIP_NUMBER  \
# 0              NE      SW                          17.00000        10.00000
# 1              NE      SW                          17.00000        10.00000
# 2              NE      SW                          17.00000        10.00000
# 3              NE      SW                          17.00000        10.00000
# 4              NE      SW                          17.00000        10.00000
#
#   TOWNSHIP_DIRECTION RANGE_NUMBER RANGE_DIRECTION      MERIDIAN  \
# 0                  N     13.00000               E  Mount Diablo
# 1                  N     13.00000               E  Mount Diablo
# 2                  N     13.00000               E  Mount Diablo
# 3                  N     13.00000               E  Mount Diablo
# 4                  N     13.00000               E  Mount Diablo
#
#   LOCATION_METHOD                            SPECIAL_USE_AREA     SOURCE_NAME  \
# 0           DD_NE  DELTA WATERSHEDS,FULLY APPROPRIATED STREAM  SLY PARK CREEK
# 1           DD_NE  DELTA WATERSHEDS,FULLY APPROPRIATED STREAM  SLY PARK CREEK
# 2           DD_NE  DELTA WATERSHEDS,FULLY APPROPRIATED STREAM  SLY PARK CREEK
# 3           DD_NE  DELTA WATERSHEDS,FULLY APPROPRIATED STREAM  SLY PARK CREEK
# 4           DD_NE  DELTA WATERSHEDS,FULLY APPROPRIATED STREAM  SLY PARK CREEK
#
#   TRIB_DESC      WATERSHED      HUC_12_NUMBER     HUC_12_NAME   HUC_8_NUMBER  \
# 0            MIDDLE SIERRA 180400130101.00000  Sly Park Creek 18040013.00000
# 1            MIDDLE SIERRA 180400130101.00000  Sly Park Creek 18040013.00000
# 2            MIDDLE SIERRA 180400130101.00000  Sly Park Creek 18040013.00000
# 3            MIDDLE SIERRA 180400130101.00000  Sly Park Creek 18040013.00000
# 4            MIDDLE SIERRA 180400130101.00000  Sly Park Creek 18040013.00000
#
#        HUC_8_NAME QUAD_MAP_NAME QUAD_MAP_NUMBER PERMIT_ORIGINAL_ISSUE_DATE  \
# 0  Upper Cosumnes      SLY PARK           GG024                  9/30/1926
# 1  Upper Cosumnes      SLY PARK           GG024                  9/30/1926
# 2  Upper Cosumnes      SLY PARK           GG024                  9/30/1926
# 3  Upper Cosumnes      SLY PARK           GG024                  9/30/1926
# 4  Upper Cosumnes      SLY PARK           GG024                  9/30/1926
#
#   COMPLETE_CONSTRUCTION_DATE COMPLETE_APPLIC_WATER_DATE  \
# 0                   7/1/1969                   7/1/1979
# 1                   7/1/1969                   7/1/1979
# 2                   7/1/1969                   7/1/1979
# 3                   7/1/1969                   7/1/1979
# 4                   7/1/1969                   7/1/1979
#
#   LICENSE_ORIGINAL_ISSUE_DATE               WATER_RIGHT_DESCRIPTION  \
# 0                   1/17/1986  Migrated data from old WRIMS system.
# 1                   1/17/1986  Migrated data from old WRIMS system.
# 2                   1/17/1986  Migrated data from old WRIMS system.
# 3                   1/17/1986  Migrated data from old WRIMS system.
# 4                   1/17/1986  Migrated data from old WRIMS system.
#
#   PROGRAM_UNIT LICENSE_REQUEST_TYPE LICENSE_REQUESTED_DATE INSPECTION_DATE  \
# 0                  Permitee Request
# 1                  Permitee Request
# 2                  Permitee Request
# 3                  Permitee Request
# 4                  Permitee Request
#
#   REPORT_DATE OFFER_SENT_DATE ACCEPTED_OFFER_DATE     PETITION_ID  \
# 0                                                  A002270P009092
# 1                                                  A002270P009092
# 2                                                  A002270P009092
# 3                                                  A002270P009092
# 4                                                  A002270P009092
#
#   PETITION_TYPE PETITION_STATUS_TYPE DATE_RECEIVED DATE_COMPLETED  \
# 0        Change            Completed     1/12/2010
# 1        Change            Completed     1/12/2010
# 2        Change            Completed     1/12/2010
# 3        Change            Completed     1/12/2010
# 4        Change            Completed     1/12/2010
#
#     PET_LAST_UPDATE_DATE NUM_OF_PETITIONS ENF_CASE_NUMBER ENF_CASE_START_DATE  \
# 0  10/26/2010 1:13:45 PM          1.00000
# 1  10/26/2010 1:13:45 PM          1.00000
# 2  10/26/2010 1:13:45 PM          1.00000
# 3  10/26/2010 1:13:45 PM          1.00000
# 4  10/26/2010 1:13:45 PM          1.00000
#
#   ENF_CASE_CLOSURE_DATE ENF_CASE_COUNTY  NUMBER_OF_ENFORCEMENT_CASE WaDEUUID
# 0                                                                 0     in10
# 1                                                                 0     in11
# 2                                                                 0     in12
# 3                                                                 0     in13
# 4                                                                 0     in14

# %%
# Clean data a little
dfin1 = dfin1.fillna("") # remove nan values
dfin1['USE_DIRECT_DIVERSION_RATE'] = pd.to_numeric(dfin1['USE_DIRECT_DIVERSION_RATE'], errors='coerce').fillna(0) # make sure this is numeric.

# %%
# convert units to WaDE Approproiate values (CFS or AF)
def convertAmountToUnitFunc(val, unit):
    outValue = None
    if unit == "Cubic Feet per Second":
        outValue = val
    if unit == "Gallons per Day":
        outValue = val / (646316.883)
    if unit == "Acre-feet per Year":
        outValue = val / (723.968)
    if unit == "Gallons per Minute":
        outValue = val / (448.83117)
    if unit == 'Acre-feet':
        outValue = val
    if unit == 'Gallons':
        outValue = val / (325850.943)
    return(outValue)

dfin1['in_Amount'] = dfin1.apply(lambda row: convertAmountToUnitFunc(row['USE_DIRECT_DIVERSION_RATE'], row['USE_DIRECT_DIV_RATE_UNITS']), axis=1)
dfin1['in_Amount'].unique()
# Out:
# array([0.00000000e+00,            nan, 1.00000000e+00, 6.65308321e-03,
#        3.09445731e-04, 4.64168596e-03, 2.90105372e-03, 1.89000000e+02,
#        2.00000000e+02, 3.01709587e-03, 7.73614326e-04, 2.32084298e-04,
#        1.54722865e-04, 3.86807163e-05, 7.00000000e+00, 1.46986722e-02,
#        1.20683835e-02, 2.47556584e-02, 8.00000000e+00, 1.15268535e-02,
#        5.00000000e+00, 1.31514435e-02, 2.22800926e-03, 9.28337192e-04,
#        3.09445731e-03, 1.58590937e-02, 1.50000000e+01, 5.00000000e+01,
#        1.54722865e-03, 2.30000000e+01, 1.30000000e+02, 1.85667438e-03,
#        1.39250579e-03, 7.73614326e-05, 4.50000000e+01, 3.30000000e+02,
#        3.90000000e+01, 3.40390304e-03, 5.00000000e+03, 2.20000000e+01,
#        2.80000000e+01, 3.00000000e+00, 1.85667438e-04, 3.86807163e-03,
#        2.70000000e+01, 8.00000000e+01, 4.50000000e+02, 1.16000000e+02,
#        1.09600000e+03, 3.69849536e-01, 4.00000000e+00, 1.60000000e+01,
#        1.70195152e-02, 2.00000000e+00, 1.67100694e-02, 4.64168596e-04,
#        2.01139725e-02, 3.20000000e+01, 2.29299286e-02, 4.17751736e-04,
#        1.30000000e+01, 1.54722865e-02, 6.03419174e-03, 6.00000000e+00,
#        1.00000000e+02, 2.00000000e+01, 8.46024627e-03, 1.16042149e-03,
#        1.10000000e+01, 1.98000000e+02, 9.28337192e-03, 6.18891461e-03,
#        1.32000000e+02, 6.65308321e-04, 5.13679913e-03, 3.32654160e-03,
#        3.40000000e+01, 3.50000000e+01, 1.00000000e+01, 8.20031186e-03,
#        1.42886566e-02, 6.96252894e-03, 1.36929736e-03, 1.65089297e-02,
#        3.09445731e-02, 1.52402022e-02, 5.80210745e-04, 4.54885224e-04,
#        1.00569862e-04, 1.09853234e-03, 6.49836034e-03, 2.33631527e-03,
#        1.08306006e-03, 6.18891461e-04, 6.46586854e-03, 2.20480083e-03,
#        5.41530028e-03, 8.20031186e-04, 6.37458205e-03, 6.88516750e-03,
#        5.95683031e-03, 6.34363748e-03, 4.99909578e-03, 2.65659160e-03,
#        2.12743940e-03, 6.73044464e-03, 7.00000000e+02, 1.16042149e-04,
#        1.89535510e-03, 2.52198270e-03, 6.80780607e-04, 4.00000000e+01,
#        4.25487879e-04, 2.38892104e-03, 1.68029032e-03, 1.46213108e-03,
#        6.00000000e+01, 3.34201389e-03, 2.32084298e-03, 2.00056665e-03,
#        2.22800926e-02, 7.12962963e-02, 6.68402778e-03, 3.50000000e+02,
#        1.20000000e+01, 1.11400463e-02, 6.01562500e+00, 3.71334877e-05,
#        1.00260417e-01, 3.86807163e-04, 1.78240741e-02, 5.57002315e-03,
#        4.28582337e-04, 5.12442130e+00, 3.34201389e-01, 1.75000000e+02,
#        4.45601852e-02, 1.22540509e+00, 3.69849537e-01, 2.40000000e+01,
#        4.45601852e-01, 2.67361111e-01, 3.00000000e+01, 1.55960648e-02,
#        1.33680556e+00, 7.79803241e-02, 2.50000000e+01, 3.00000000e+02,
#        2.00000000e+04, 1.67100694e+00, 1.11400463e-01, 1.67100694e-01,
#        5.57002315e-01, 8.66448045e-01, 4.33224023e-01, 1.11400463e+00,
#        6.68402778e-01, 7.58142040e+00, 2.00520833e+00, 5.57002315e+01,
#        6.68402778e+01, 4.45601852e+00, 2.56644387e+01, 5.57002315e-02,
#        2.45081019e-01, 6.68402778e-02, 2.67361111e-02, 3.00781250e+00,
#        2.22800926e+00, 1.33680556e-01, 6.12702546e+01, 5.79282408e+00,
#        2.67361111e+00, 3.92129630e+00, 3.37295846e-01, 4.10000000e+01,
#        2.10000000e+01, 2.77000000e+02, 9.00000000e+00, 3.29559703e-04,
#        1.80000000e+01, 2.86237301e-04, 1.20683835e-04, 5.90000000e+01,
#        6.69950007e-04, 1.69700000e+03, 8.50000000e+01, 7.30000000e+02,
#        3.05000000e+02, 7.00000000e+01, 9.00000000e+01, 1.36156121e+01,
#        3.34201389e-02, 3.34201389e+00, 8.91203704e+00, 4.45601852e-03,
#        7.11725180e+00, 8.91203704e-01, 1.70000000e+01, 6.50000000e+02,
#        1.20000000e+02, 5.40000000e+01, 1.50000000e+02, 6.50000000e+01,
#        2.25000000e+02, 1.25000000e+02, 1.03000000e+02, 7.50000000e+01,
#        3.60000000e+02, 5.60000000e+01, 1.90000000e+01, 2.78501157e-04,
#        5.57002315e-04, 2.60000000e+01, 1.80000000e+02, 3.10000000e+01,
#        1.11400463e-03, 1.23000000e+02, 2.78501157e-03, 5.00000000e+02,
#        1.65000000e+02, 1.55000000e+02, 3.30000000e+01, 4.20000000e+01,
#        1.49300000e+03, 3.70000000e+01, 1.70195152e-05, 2.65000000e+02,
#        8.35000000e+02, 1.40000000e+01, 4.00000000e+02, 1.48300000e+03,
#        8.00000000e+02, 6.70000000e+01, 5.10000000e+01, 4.60000000e+01,
#        1.78200000e+03, 3.80000000e+02, 3.60000000e+01, 2.50000000e+02,
#        1.04000000e+02, 4.25000000e+02, 6.60000000e+01, 5.66285687e-04,
#        6.13000000e+02, 1.29657761e-03, 1.36001399e-03, 2.37190152e-03,
#        1.70195152e-03, 3.40390304e-04, 6.00000000e+02, 3.71334877e-04,
#        9.28337192e-05, 5.02849312e-04, 1.43892265e-03, 1.10472126e-03,
#        4.45601851e-01, 1.78240740e+01, 1.11400463e-02, 6.68402776e-03,
#        2.08875868e-03, 2.93973444e-03, 6.68402776e+00, 1.60000000e+02,
#        3.78761573e-01, 2.22800925e-01, 3.78761573e+00, 7.12962961e-01,
#        8.91203701e-03, 4.45601851e-03, 2.22800925e-03, 6.68402776e-02,
#        4.01041666e-02, 2.22800925e-02, 1.11400463e-01, 2.00520833e+01,
#        3.34201388e+01, 4.23321758e+01, 1.00260416e+01, 2.22800925e+00,
#        4.45601851e+00, 3.34201388e+00, 1.05211548e-03, 2.67361110e+00,
#        1.77931295e-04, 1.46986722e-03, 8.04558899e-04, 2.67670557e-03,
#        4.34771251e-03, 6.80780607e-03, 4.50243538e-03, 2.55292728e-04,
#        2.01139725e-03, 3.55862590e-04, 3.97637764e-04, 3.23989680e-03,
#        1.33680555e-01, 5.57002313e+00, 2.00520833e-01, 1.17589378e-04,
#        4.90162036e+00, 1.33680555e-02, 2.67361110e-02, 8.91203701e-01,
#        4.87377026e-03, 3.48126447e-03, 1.97271653e-03, 3.24918017e-03,
#        1.39250579e-02, 5.57002313e-02, 5.15227141e-04, 2.67361110e-01,
#        8.50975759e-02, 1.23778292e-02, 2.66123328e-04, 4.45601851e-02,
#        6.68402776e-01, 4.67881943e-02, 7.35243054e-02, 3.11921295e-02,
#        1.67100694e+01, 6.12702545e-01, 1.78240740e-02, 8.91203701e-02,
#        1.55960648e-02, 3.34201388e-02, 2.84962384e+00, 1.18530092e+00,
#        6.01562498e-01, 1.98070023e+00, 5.01302082e-01, 2.78501157e-01,
#        1.67100694e+00, 2.20572916e+00, 2.45081018e+00, 1.11400463e+00,
#        1.78240740e+00, 1.71556713e+00, 2.00520833e+00, 7.12962961e+00,
#        5.34722221e+00, 1.63090277e+00, 1.30561342e+00, 9.66956016e-01,
#        1.44820601e+00, 2.86076388e+00, 5.48313077e+00, 1.22540509e+00,
#        6.96098171e-03, 3.56481481e+00, 2.91423610e+00, 2.50428240e+00,
#        7.35243054e+00, 8.35503470e-01, 1.09262193e-01, 7.79803239e-02,
#        5.72474601e-04, 1.55960648e+01, 8.91203701e+00, 3.11921295e-01,
#        4.90162036e-01, 2.45081018e-02, 2.16612011e-03, 7.73614326e-06,
#        1.78240740e-01, 2.47556584e-04, 3.11921295e+00, 7.79803239e-01,
#        1.12960069e+00, 1.77126736e+00, 1.94950810e+00, 1.40587384e+00,
#        1.72447916e+00, 9.30193866e-03, 1.48007893e-02, 5.88875225e-03,
#        6.01562498e+00, 2.85185184e-01, 2.07204861e-01, 1.84924768e-01,
#        4.01041666e+00, 7.20000000e+01, 7.73614326e-03, 3.79071020e-02,
#        2.32084298e-02, 6.18891461e-06, 1.23778292e-03, 8.91203704e-03,
#        1.55960648e+00, 1.67100694e-01, 1.11400463e+01, 1.29224537e+00,
#        2.00520833e-02, 4.90162036e-02, 5.57002313e-01, 7.35243054e-01,
#        3.34201388e-01, 5.90422452e-01, 7.79803239e+00, 7.41927081e-01,
#        6.86226850e-01, 2.11660879e+00, 3.56481481e-02, 2.08875868e-02,
#        5.83305202e-04, 4.95113169e-03, 1.53175637e-03, 3.18729102e-04,
#        5.34722221e-02, 3.62051505e-03, 3.71334877e-03, 1.02488426e+00,
#        5.79282406e-02, 1.33680555e+00, 4.67881943e+00, 2.56221064e+00,
#        2.90000000e+01, 1.33680555e+01, 4.67881943e-01, 1.79169078e-03,
#        6.43000000e+03, 7.72840712e-03, 1.32612968e-02, 1.06944444e+01,
#        1.85000000e+02, 7.50405896e-04, 5.77116287e-04, 1.31514435e-04,
#        5.41530028e-04, 8.46643516e-02, 3.56481481e-01, 1.19198495e+00,
#        1.57817323e-04, 1.32566551e+00, 4.34461804e-01, 2.45081018e-01,
#        5.79282406e-01, 9.13483794e-02, 3.00781249e-01, 5.33793885e-03,
#        8.66448045e-04, 2.80048386e-03, 1.43118650e-03, 4.15740339e-03,
#        5.30000000e+01, 3.89901619e+00, 4.17751735e+00, 3.67621527e+00,
#        5.10585455e-05, 1.53949251e-03, 2.06555025e-03, 1.41416699e-03,
#        6.96252894e-04, 2.82369229e-03, 8.50975759e-04, 1.00569862e-03,
#        6.03419174e-04, 1.36156121e-03, 3.01709587e-04, 6.72116127e-03,
#        3.48126447e-04, 3.24918017e-04, 5.10585455e-04, 2.74633086e-03,
#        2.73550026e-03, 1.25325521e-04, 2.96139564e-03, 1.06913500e-03,
#        2.88712867e-03, 3.11766573e-03, 1.08306006e-04, 4.76546425e-04,
#        2.20789529e-03, 7.68663192e-01, 2.49537036e+01, 2.89641203e-02,
#        6.46122684e-01, 3.20000000e+02, 1.62459009e-02, 1.39250579e-04,
#        5.94878471e-01, 4.33224023e-02, 8.35503472e-04, 5.12442128e-01,
#        1.03045428e-03, 6.49836034e-04, 1.05830440e-03, 7.65878183e-04,
#        3.23370788e-03, 8.12295043e-04, 1.54722865e-05, 1.37703350e-03,
#        1.30276653e-03, 2.89641203e-01, 3.89901619e-01, 1.29967207e-03,
#        5.78663516e-04, 9.58043979e-02, 2.70765014e-04, 1.21148003e-03,
#        3.67621527e-01, 9.25242734e-04, 2.32084298e-05, 2.56221064e-01,
#        1.44820601e-01, 7.57523146e-02, 1.24768518e-01, 1.74063223e-03,
#        1.96064814e-01, 1.04716435e-01, 1.50390625e+00, 1.22540509e+01,
#        3.24918017e-02, 1.85667438e-02, 1.29967207e-02, 1.17589378e-02,
#        1.96498039e-02, 3.54624807e-03, 3.02563657e+00, 1.89380787e+00,
#        3.03411539e-03, 1.00000000e+03, 1.51504629e+01, 1.00260416e+00,
#        1.03602430e+00, 5.81000000e+02, 2.00000000e+03, 5.05943769e-04,
#        8.50975759e-05, 1.11400463e+02, 1.37858073e-03, 3.11040000e+04,
#        2.05007796e-03, 8.97392618e-04, 2.10769675e+00, 2.86521990e+00,
#        2.47556584e-03, 8.10747814e-04, 5.10585455e-03, 3.65393518e+00,
#        1.23778292e-04, 2.56839956e-04, 5.12442128e-02, 1.03664320e-03,
#        2.53993055e+01, 8.64467590e-01, 1.55960648e-01, 5.87946888e-03,
#        2.93973444e-02, 6.37458205e-04, 2.75406700e-03, 4.76701148e-03,
#        1.76384066e-02, 1.00879308e-03, 6.89963409e-01, 9.76800000e+03,
#        8.81920332e-04, 2.50032150e-03, 1.74527392e-03, 1.09698511e-03,
#        1.14649643e-03, 1.16042149e-02, 1.45130048e-03, 1.48069782e-03,
#        1.08306006e-05, 6.46122684e-02, 5.37507234e-03, 6.54477720e-04,
#        4.44828238e-03, 4.02124727e-03, 7.11725180e-04, 1.60911780e-03,
#        1.27646364e-03, 2.60677083e+00, 3.60046295e+00, 3.89901620e-03,
#        3.00781249e+00, 5.32494212e+00, 5.77054397e-01, 1.62459009e-01,
#        1.29224537e+01, 1.85667438e-05, 3.63134565e-03, 6.23842591e+00,
#        1.38136574e+01, 2.63028871e-03, 1.31514435e-03, 4.01041666e-01,
#        1.22540509e-01, 3.92841355e-03, 6.88826196e-03, 9.59281765e-04,
#        2.25431215e-03, 5.23000000e+02, 7.60000000e+01, 1.69328703e+01,
#        6.57485531e+00, 8.02083331e-01, 9.35763886e-01, 8.46643516e+00,
#        2.89641203e+00, 1.17248987e-02])

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfin1['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "CAssdw_M1"

# Variable Info
df['in_AggregationIntervalUnitCV'] = "Monthly"
df['in_VariableCV'] = "Water Use"

# Organization Info
df['in_OrganizationUUID'] = "CAssdw_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfin1['SOURCE_NAME']
df['in_WaterSourceNativeID'] = "" # auto fill in below if not provdied by state
df['in_WaterSourceTypeCV'] = dfin1['SOURCE_TYPE']

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = dfin1['LOCATION_METHOD']
df['in_County'] = dfin1['COUNTY']
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = dfin1['HUC_12_NUMBER']
df['in_HUC8'] = dfin1['HUC_8_NUMBER']
df['in_Latitude'] = dfin1['LATITUDE']
df['in_Longitude'] = dfin1['LONGITUDE']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD" 
df['in_SiteName'] = dfin1['POD_NAME']
df['in_SiteNativeID'] = dfin1['POD_ID']
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = dfin1['POD_TYPE']
df['in_StateCV'] = "CA"
df['in_USGSSiteID'] = ""

# Site VariableAmounts Info
df['in_Amount'] = dfin1['in_Amount']
df['in_AllocationCropDutyAmount'] = ""
df['in_AssociatedNativeAllocationIDs'] = dfin1['APPLICATION_NUMBER']
df['in_BeneficialUseCategory'] = dfin1['USE_CODE']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_Geometry'] = ""
#df['in_IrrigatedAcreage'] = dfin1['USE_NET_ACREAGE']
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
#df['in_PopulationServed'] = dfin1['USE_POPULATION']
df['in_PopulationServed'] = ""
df['in_PowerGeneratedGWh'] = ""
df['in_PowerType'] = ""
df['in_PrimaryUseCategory'] = dfin1['USE_CODE']
df['in_ReportYearCV'] = dfin1['YEAR']
df['in_SDWISIdentifier'] = ""
df['in_TimeframeEnd'] = dfin1['MONTH FORMATTED']
df['in_TimeframeStart'] = dfin1['MONTH FORMATTED']

outdf1 = df.copy()
outdf1 = outdf1.drop_duplicates().reset_index(drop=True)
print(len(outdf1))
outdf1.head()
# Out:
# 4889274
#   WaDEUUID in_MethodUUID in_AggregationIntervalUnitCV in_VariableCV  \
# 0     in10     CAssdw_M1                      Monthly     Water Use
# 1     in11     CAssdw_M1                      Monthly     Water Use
# 2     in12     CAssdw_M1                      Monthly     Water Use
# 3     in13     CAssdw_M1                      Monthly     Water Use
# 4     in14     CAssdw_M1                      Monthly     Water Use
#
#   in_OrganizationUUID in_Geometry in_GNISFeatureNameCV  \
# 0           CAssdw_O1
# 1           CAssdw_O1
# 2           CAssdw_O1
# 3           CAssdw_O1
# 4           CAssdw_O1
#
#   in_WaterQualityIndicatorCV in_WaterSourceName in_WaterSourceNativeID  \
# 0                                SLY PARK CREEK
# 1                                SLY PARK CREEK
# 2                                SLY PARK CREEK
# 3                                SLY PARK CREEK
# 4                                SLY PARK CREEK
#
#   in_WaterSourceTypeCV in_CoordinateAccuracy in_CoordinateMethodCV  in_County  \
# 0                                                            DD_NE  El Dorado
# 1                                                            DD_NE  El Dorado
# 2                                                            DD_NE  El Dorado
# 3                                                            DD_NE  El Dorado
# 4                                                            DD_NE  El Dorado
#
#    in_EPSGCodeCV in_GNISCodeCV           in_HUC12        in_HUC8 in_Latitude  \
# 0           4326               180400130101.00000 18040013.00000    38.71507
# 1           4326               180400130101.00000 18040013.00000    38.71507
# 2           4326               180400130101.00000 18040013.00000    38.71507
# 3           4326               180400130101.00000 18040013.00000    38.71507
# 4           4326               180400130101.00000 18040013.00000    38.71507
#
#   in_Longitude in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0   -120.56160                                                   POD
# 1   -120.56160                                                   POD
# 2   -120.56160                                                   POD
# 3   -120.56160                                                   POD
# 4   -120.56160                                                   POD
#
#   in_SiteName  in_SiteNativeID in_SitePoint  \
# 0                  40933.00000
# 1                  40933.00000
# 2                  40933.00000
# 3                  40933.00000
# 4                  40933.00000
#
#                                        in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0  Point of Direct Diversion,Point of Storage - U...         CA
# 1  Point of Direct Diversion,Point of Storage - U...         CA
# 2  Point of Direct Diversion,Point of Storage - U...         CA
# 3  Point of Direct Diversion,Point of Storage - U...         CA
# 4  Point of Direct Diversion,Point of Storage - U...         CA
#
#    in_Amount in_AllocationCropDutyAmount in_AssociatedNativeAllocationIDs  \
# 0    0.00000                                                      A002270
# 1    0.00000                                                      A002270
# 2    0.00000                                                      A002270
# 3    0.00000                                                      A002270
# 4    0.00000                                                      A002270
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0         Incidental Power
# 1         Incidental Power
# 2         Incidental Power
# 3         Incidental Power
# 4         Incidental Power
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategory  in_ReportYearCV  \
# 0                                        Incidental Power             2016
# 1                                        Incidental Power             2017
# 2                                        Incidental Power             2018
# 3                                        Incidental Power             2021
# 4                                        Incidental Power             2022
#
#   in_SDWISIdentifier in_TimeframeEnd in_TimeframeStart
# 0                           1/1/2016          1/1/2016
# 1                           1/1/2017          1/1/2017
# 2                           1/1/2018          1/1/2018
# 3                           1/1/2021          1/1/2021
# 4                           1/1/2022          1/1/2022

# %% [markdown]
# ## Data Input 2
# - site info
# - timeseries info

# %%
# etc etc,
# outdf2

# %% [markdown]
# ## Concatenate DataFrames together

# %%
# Concatenate dataframes
frames = [outdf1] # list all out dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 4889274

# %% [markdown]
# ## Clean Data / data types

# %%
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['', 'Surface', 'Subsurface'], dtype=object)

# %%
# updating in_WaterSourceTypeCV to be more machine readable / WaDE specific
# ----------------------------------------------------------------------------------------------------

def createWaterSourceTypeCV(inWST):
    inWST = str(inWST).strip()
    
    if inWST == "":
        outString = "Unspecified"
    elif inWST == "Subsurfacer":
        outString = "Groundwater"
    else:
        outString =  "Surface Water"
      
    return outString

outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: createWaterSourceTypeCV(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Unspecified', 'Surface Water'], dtype=object)

# %%
# Fill empty ben use values

def fillEmptyBenUseFunc(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = "Unspecified"
    else:
        outString = val
    return outString
    
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: fillEmptyBenUseFunc(row['in_BeneficialUseCategory']), axis=1)
outdf['in_PrimaryUseCategory'] = outdf.apply(lambda row: fillEmptyBenUseFunc(row['in_PrimaryUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['Incidental Power', 'Domestic', 'Irrigation',
#        'Fish and Wildlife Preservation and Enhancement', 'Recreational',
#        'Municipal', 'Power', 'Fire Protection', 'Industrial',
#        'Aquaculture', 'Mining', 'Frost Protection', 'Stockwatering',
#        'Milling', 'Heat Control', 'Other', 'Dust Control', 'Unspecified',
#        'Snow Making', 'Aesthetic', 'Water Quality'], dtype=object)

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\),(-]", "", Val).title().replace("  ", " ").strip()
    return Val

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Sly Park Creek', 'Icy Spring No 2', 'Forsythe Creek', ...,
#        'Boardman Lake', 'Stone Lakesnodgrass Slough', 'Mokeloumne River'],
#       dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['', 'Decree No 6616', 'Houk Pump', ..., "Mario'S Pump",
#        'Spocjlei Pod', 'Thornton Almonds Llc Pump'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['El Dorado', 'Los Angeles', 'Mendocino', 'Sutter', 'Siskiyou',
#        'Yuba', 'Stanislaus', 'Santa Barbara', 'Yolo', 'Nevada', 'Sonoma',
#        'Sacramento', 'San Mateo', 'Mono', 'Butte', 'Lake', 'San Joaquin',
#        'Trinity', 'Placer', 'Modoc', 'Merced', 'Contra Costa', 'Sierra',
#        'Glenn', 'Amador', 'Plumas', 'Inyo', 'Santa Cruz', 'Shasta',
#        'Madera', 'Santa Clara', 'Napa', 'San Bernardino', 'Colusa',
#        'Monterey', 'San Diego', 'Del Norte', 'Riverside', 'Tulare',
#        'Kings', 'San Benito', 'Alameda', 'Marin', 'Humboldt', 'Calaveras',
#        'Lassen', 'Kern', 'Alpine', 'Tehama', 'Orange', 'Tuolumne',
#        'Solano', 'Ventura', '', 'Fresno', 'San Luis Obispo', 'Mariposa',
#        'Imperial', 'San Francisco'], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Sly Park Creek', 'Icy Spring No 2', 'Forsythe Creek', ...,
#        'Boardman Lake', 'Stone Lakesnodgrass Slough', 'Mokeloumne River'],
#       dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Unspecified', 'Surface Water'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['Point of Direct Diversion,Point of Storage - Unspecified',
#        'Point of Direct Diversion', 'Movable Point of Diversion',
#        'Point of Storage - Unspecified,Point of Storage - Unspecified',
#        'Point of Storage - Unspecified', 'Point of Onstream Storage',
#        'Point of Direct Diversion,Point of Diversion to Offstream Storage',
#        'Point of Diversion to Underground Storage',
#        'Point of Direct Diversion,Point of Rediversion',
#        'Point of Rediversion',
#        'Point of Diversion to Underground Storage,Point of Storage - Unspecified,Point of Storage - Unspecified',
#        'Point of Direct Diversion,Point of Direct Diversion',
#        'Point of Direct Diversion,Point of Onstream Storage',
#        'Point of Direct Diversion,Point of Onstream Storage,Point of Rediversion',
#        'Point of Diversion to Underground Storage,Point of Onstream Storage',
#        'Point of Diversion to Underground Storage,Point of Rediversion',
#        'Point of Diversion to Underground Storage,Point of Storage - Unspecified',
#        'Point of Direct Diversion,Point of Diversion to Underground Storage,Point of Storage - Unspecified',
#        'Point of Diversion to Offstream Storage',
#        'Point of Direct Diversion,Point of Diversion to Underground Storage',
#        'Point of Direct Diversion,Point of Diversion to Offstream Storage,Point of Diversion to Underground Storage',
#        'Movable Point of Rediversion',
#        'Point of Direct Diversion,Point of Diversion to Offstream Storage,Point of Rediversion',
#        'Point of Direct Diversion,Point of Diversion to Underground Storage,Point of Rediversion',
#        'Point of Onstream Storage,Point of Rediversion',
#        'Movable Point of Diversion,Movable Point of Rediversion',
#        'Point of Direct Diversion,Point of Storage - Unspecified,Point of Storage - Unspecified',
#        'Point of Diversion to Offstream Storage,Point of Onstream Storage',
#        'Point of Onstream Storage,Point of Rediversion,Point of Storage - Unspecified',
#        'Movable Point of Diversion,Movable Point of Rediversion,Point of Diversion to Underground Storage',
#        'Point of Direct Diversion,Point of Diversion to Offstream Storage,Point of Onstream Storage',
#        'Point of Direct Diversion,Point of Direct Diversion,Point of Diversion to Offstream Storage',
#        '', 'Movable Point of Diversion,Point of Direct Diversion'],
#       dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['', 'Decree No 6616', 'Houk Pump', ..., "Mario'S Pump",
#        'Spocjlei Pod', 'Thornton Almonds Llc Pump'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: ensureEmptyString(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['El Dorado', 'Los Angeles', 'Mendocino', 'Sutter', 'Siskiyou',
#        'Yuba', 'Stanislaus', 'Santa Barbara', 'Yolo', 'Nevada', 'Sonoma',
#        'Sacramento', 'San Mateo', 'Mono', 'Butte', 'Lake', 'San Joaquin',
#        'Trinity', 'Placer', 'Modoc', 'Merced', 'Contra Costa', 'Sierra',
#        'Glenn', 'Amador', 'Plumas', 'Inyo', 'Santa Cruz', 'Shasta',
#        'Madera', 'Santa Clara', 'Napa', 'San Bernardino', 'Colusa',
#        'Monterey', 'San Diego', 'Del Norte', 'Riverside', 'Tulare',
#        'Kings', 'San Benito', 'Alameda', 'Marin', 'Humboldt', 'Calaveras',
#        'Lassen', 'Kern', 'Alpine', 'Tehama', 'Orange', 'Tuolumne',
#        'Solano', 'Ventura', '', 'Fresno', 'San Luis Obispo', 'Mariposa',
#        'Imperial', 'San Francisco'], dtype=object)

# %%
# Ensure Latitude entry is numireic, replace '0' values for removal
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([38.71507495, 34.57797187, 39.24992704, ..., 38.41246111,
#        38.20644444, 40.14626712], dtype=object)

# %%
# Ensure Longitude entry is numireic, replace '0' values for removal
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-120.56159884, -118.28920963, -123.20600424, ..., -121.50423333,
#        -121.48065833, -123.87636654], dtype=object)

# %%
# Ensure Amount entry is either numireic or blank, no 0 entries
outdf['in_Amount'] = pd.to_numeric(outdf['in_Amount'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_Amount'].unique()
# Out:
# array(['', 1.0, 0.01, 189.0, 200.0, 7.0, 0.02, 8.0, 5.0, 15.0, 50.0, 23.0,
#        130.0, 45.0, 330.0, 39.0, 5000.0, 22.0, 28.0, 3.0, 27.0, 80.0,
#        450.0, 116.0, 1096.0, 0.37, 4.0, 16.0, 2.0, 32.0, 13.0, 6.0, 100.0,
#        20.0, 11.0, 198.0, 132.0, 34.0, 35.0, 10.0, 0.03, 700.0, 40.0,
#        60.0, 0.07, 350.0, 12.0, 6.02, 0.1, 5.12, 0.33, 175.0, 0.04, 1.23,
#        24.0, 0.45, 0.27, 30.0, 1.34, 0.08, 25.0, 300.0, 20000.0, 1.67,
#        0.11, 0.17, 0.56, 0.87, 0.43, 1.11, 0.67, 7.58, 2.01, 55.7, 66.84,
#        4.46, 25.66, 0.06, 0.25, 3.01, 2.23, 0.13, 61.27, 5.79, 2.67, 3.92,
#        0.34, 41.0, 21.0, 277.0, 9.0, 18.0, 59.0, 1697.0, 85.0, 730.0,
#        305.0, 70.0, 90.0, 13.62, 3.34, 8.91, 7.12, 0.89, 17.0, 650.0,
#        120.0, 54.0, 150.0, 65.0, 225.0, 125.0, 103.0, 75.0, 360.0, 56.0,
#        19.0, 26.0, 180.0, 31.0, 123.0, 500.0, 165.0, 155.0, 33.0, 42.0,
#        1493.0, 37.0, 265.0, 835.0, 14.0, 400.0, 1483.0, 800.0, 67.0, 51.0,
#        46.0, 1782.0, 380.0, 36.0, 250.0, 104.0, 425.0, 66.0, 613.0, 600.0,
#        17.82, 6.68, 160.0, 0.38, 0.22, 3.79, 0.71, 20.05, 33.42, 42.33,
#        10.03, 5.57, 0.2, 4.9, 0.09, 0.05, 16.71, 0.61, 2.85, 1.19, 0.6,
#        1.98, 0.5, 0.28, 2.21, 2.45, 1.78, 1.72, 7.13, 5.35, 1.63, 1.31,
#        0.97, 1.45, 2.86, 5.48, 3.56, 2.91, 2.5, 7.35, 0.84, 15.6, 0.31,
#        0.49, 0.18, 3.12, 0.78, 1.13, 1.77, 1.95, 1.41, 0.29, 0.21, 4.01,
#        72.0, 1.56, 11.14, 1.29, 0.74, 0.59, 7.8, 0.69, 2.12, 1.02, 4.68,
#        2.56, 29.0, 13.37, 0.47, 6430.0, 10.69, 185.0, 0.36, 1.33, 0.58,
#        0.3, 53.0, 3.9, 4.18, 3.68, 0.77, 24.95, 0.65, 320.0, 0.51, 0.39,
#        0.26, 0.14, 0.12, 1.5, 12.25, 3.03, 1.89, 1000.0, 15.15, 1.04,
#        581.0, 2000.0, 111.4, 31104.0, 2.11, 2.87, 3.65, 25.4, 0.86, 0.16,
#        9768.0, 2.61, 3.6, 5.32, 12.92, 6.24, 13.81, 0.4, 523.0, 76.0,
#        16.93, 6.57, 0.8, 0.94, 8.47, 2.9], dtype=object)

# %%
# # Ensure PopulationServed entry is numireic WITH 0 entries (no blank strings)
# outdf['in_PopulationServed'] = pd.to_numeric(outdf['in_PopulationServed'], errors='coerce').round().replace("",0).fillna(0).astype(int)
# outdf['in_PopulationServed'].unique()

# %%
# Convert TimeframeEnd to YYYY-MM-DD format.
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf['in_TimeframeEnd'], utc=True, errors = 'coerce').fillna("")
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf["in_TimeframeEnd"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeEnd'].unique()
# Out:
# <DatetimeArray>
# ['2016-01-01 00:00:00', '2017-01-01 00:00:00', '2018-01-01 00:00:00',
#  '2021-01-01 00:00:00', '2022-01-01 00:00:00', '2016-02-01 00:00:00',
#  '2017-02-01 00:00:00', '2018-02-01 00:00:00', '2021-02-01 00:00:00',
#  '2022-02-01 00:00:00',
#  ...
#  '1985-03-01 00:00:00', '1985-04-01 00:00:00', '1985-05-01 00:00:00',
#  '1985-06-01 00:00:00', '1985-07-01 00:00:00', '1985-08-01 00:00:00',
#  '1985-09-01 00:00:00', '1985-10-01 00:00:00', '1985-11-01 00:00:00',
#  '1985-12-01 00:00:00']
# Length: 432, dtype: datetime64[ns]

# %%
# Convert TimeframeStart to YYYY-MM-DD format.
outdf['in_TimeframeStart'] = pd.to_datetime(outdf['in_TimeframeStart'], utc=True, errors = 'coerce').fillna("")
outdf['in_TimeframeStart'] = pd.to_datetime(outdf["in_TimeframeStart"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeStart'].unique()
# Out:
# <DatetimeArray>
# ['2016-01-01 00:00:00', '2017-01-01 00:00:00', '2018-01-01 00:00:00',
#  '2021-01-01 00:00:00', '2022-01-01 00:00:00', '2016-02-01 00:00:00',
#  '2017-02-01 00:00:00', '2018-02-01 00:00:00', '2021-02-01 00:00:00',
#  '2022-02-01 00:00:00',
#  ...
#  '1985-03-01 00:00:00', '1985-04-01 00:00:00', '1985-05-01 00:00:00',
#  '1985-06-01 00:00:00', '1985-07-01 00:00:00', '1985-08-01 00:00:00',
#  '1985-09-01 00:00:00', '1985-10-01 00:00:00', '1985-11-01 00:00:00',
#  '1985-12-01 00:00:00']
# Length: 432, dtype: datetime64[ns]

# %%
# extract year out
# outdf['in_ReportYearCV'] = pd.to_datetime(outdf['in_ReportYearCV'], utc=True)
# outdf['in_ReportYearCV'] = pd.to_datetime(outdf["in_ReportYearCV"].dt.strftime('%m/%d/%Y'))
# outdf['in_ReportYearCV'] = outdf['in_ReportYearCV'].dt.year
outdf['in_ReportYearCV'].unique()
# Out:
# array([2016, 2017, 2018, 2021, 2022, 1995, 1993, 1994, 1991, 1992, 1975,
#        1986, 1987, 1988, 1989, 1990, 1915, 1963, 1913, 1959, 1906, 1976,
#        1916, 1971, 1972, 1973, 1974, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985], dtype=int64)

# %%
# Creating WaDE Custom VariableSpecificCV
# ----------------------------------------------------------------------------------------------------
def createVariableSpecificCV(inV, inAIU, inBU, inWST):
    inV = str(inV).strip()
    inAIU = str(inAIU).strip()
    inBU = str(inBU).strip().title()
    inWST = str(inWST).strip()
    outString = inV + "_" + inAIU + "_" + inBU + "_" + inWST
    return outString

outdf['in_VariableSpecificCV'] = outdf.apply(lambda row: createVariableSpecificCV(row['in_VariableCV'], 
                                                                                  row['in_AggregationIntervalUnitCV'],
                                                                                  row['in_BeneficialUseCategory'],
                                                                                  row['in_WaterSourceTypeCV']), axis=1)
outdf['in_VariableSpecificCV'].unique()
# Out:
# array(['Water Use_Monthly_Incidental Power_Unspecified',
#        'Water Use_Monthly_Domestic_Unspecified',
#        'Water Use_Monthly_Irrigation_Unspecified',
#        'Water Use_Monthly_Fish And Wildlife Preservation And Enhancement_Unspecified',
#        'Water Use_Monthly_Domestic_Surface Water',
#        'Water Use_Monthly_Recreational_Unspecified',
#        'Water Use_Monthly_Irrigation_Surface Water',
#        'Water Use_Monthly_Municipal_Unspecified',
#        'Water Use_Monthly_Power_Unspecified',
#        'Water Use_Monthly_Fire Protection_Unspecified',
#        'Water Use_Monthly_Industrial_Unspecified',
#        'Water Use_Monthly_Municipal_Surface Water',
#        'Water Use_Monthly_Power_Surface Water',
#        'Water Use_Monthly_Aquaculture_Unspecified',
#        'Water Use_Monthly_Mining_Unspecified',
#        'Water Use_Monthly_Frost Protection_Unspecified',
#        'Water Use_Monthly_Stockwatering_Unspecified',
#        'Water Use_Monthly_Milling_Unspecified',
#        'Water Use_Monthly_Heat Control_Unspecified',
#        'Water Use_Monthly_Frost Protection_Surface Water',
#        'Water Use_Monthly_Industrial_Surface Water',
#        'Water Use_Monthly_Incidental Power_Surface Water',
#        'Water Use_Monthly_Fish And Wildlife Preservation And Enhancement_Surface Water',
#        'Water Use_Monthly_Stockwatering_Surface Water',
#        'Water Use_Monthly_Fire Protection_Surface Water',
#        'Water Use_Monthly_Other_Unspecified',
#        'Water Use_Monthly_Heat Control_Surface Water',
#        'Water Use_Monthly_Aquaculture_Surface Water',
#        'Water Use_Monthly_Recreational_Surface Water',
#        'Water Use_Monthly_Dust Control_Unspecified',
#        'Water Use_Monthly_Mining_Surface Water',
#        'Water Use_Monthly_Unspecified_Unspecified',
#        'Water Use_Monthly_Snow Making_Unspecified',
#        'Water Use_Monthly_Unspecified_Surface Water',
#        'Water Use_Monthly_Dust Control_Surface Water',
#        'Water Use_Monthly_Other_Surface Water',
#        'Water Use_Monthly_Aesthetic_Surface Water',
#        'Water Use_Monthly_Snow Making_Surface Water',
#        'Water Use_Monthly_Water Quality_Surface Water'], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], 
                                                                              row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', ..., 'wadeId7368', 'wadeId7369',
#        'wadeId7370'], dtype=object)

# %%
# Creating WaDE Custom site native ID for easy site identification
# use Unique Latitude, Longitude, SiteName and SiteTypeCV values
# ----------------------------------------------------------------------------------------------------

# Create temp in_SiteNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_Latitude'] = outdf['in_Latitude'].astype(str).str.strip()
dfTempID['in_Longitude'] = outdf['in_Longitude'].astype(str).str.strip()
dfTempID['in_SiteName'] = outdf['in_SiteName'].astype(str).str.strip()
dfTempID['in_SiteTypeCV'] = outdf['in_SiteTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_SiteNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_Latitude'].astype(str) + dfTempID['in_Longitude'].astype(str) + dfTempID['in_SiteName'].astype(str)+ dfTempID['in_SiteTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_SiteNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB, valC, valD):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip() + str(valC).strip() + str(valD).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_SiteNativeID'], 
                                                                       row['in_Latitude'], row['in_Longitude'],
                                                                       row['in_SiteName'], row['in_SiteTypeCV']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# array(['40933.0', '34881.0', '28895.0', ..., '84721.0', '84722.0',
#        '64319.0'], dtype=object)

# %% [markdown]
# ## Export Outputs

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4889274 entries, 0 to 4889273
# Data columns (total 49 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   WaDEUUID                          object
#  1   in_MethodUUID                     object
#  2   in_AggregationIntervalUnitCV      object
#  3   in_VariableCV                     object
#  4   in_OrganizationUUID               object
#  5   in_Geometry                       object
#  6   in_GNISFeatureNameCV              object
#  7   in_WaterQualityIndicatorCV        object
#  8   in_WaterSourceName                object
#  9   in_WaterSourceNativeID            object
#  10  in_WaterSourceTypeCV              object
#  11  in_CoordinateAccuracy             object
#  12  in_CoordinateMethodCV             object
#  13  in_County                         object
#  14  in_EPSGCodeCV                     int64
#  15  in_GNISCodeCV                     object
#  16  in_HUC12                          object
#  17  in_HUC8                           object
#  18  in_Latitude                       object
#  19  in_Longitude                      object
#  20  in_NHDNetworkStatusCV             object
#  21  in_NHDProductCV                   object
#  22  in_PODorPOUSite                   object
#  23  in_SiteName                       object
#  24  in_SiteNativeID                   object
#  25  in_SitePoint                      object
#  26  in_SiteTypeCV                     object
#  27  in_StateCV                        object
#  28  in_USGSSiteID                     object
#  29  in_Amount                         object
#  30  in_AllocationCropDutyAmount       object
#  31  in_AssociatedNativeAllocationIDs  object
#  32  in_BeneficialUseCategory          object
#  33  in_CommunityWaterSupplySystem     object
#  34  in_CropTypeCV                     object
#  35  in_CustomerTypeCV                 object
#  36  in_DataPublicationDate            object
#  37  in_DataPublicationDOI             object
#  38  in_IrrigatedAcreage               object
#  39  in_IrrigationMethodCV             object
#  40  in_PopulationServed               object
#  41  in_PowerGeneratedGWh              object
#  42  in_PowerType                      object
#  43  in_PrimaryUseCategory             object
#  44  in_ReportYearCV                   int64
#  45  in_SDWISIdentifier                object
#  46  in_TimeframeEnd                   datetime64[ns]
#  47  in_TimeframeStart                 datetime64[ns]
#  48  in_VariableSpecificCV             object
# dtypes: datetime64[ns](2), int64(2), object(45)
# memory usage: 1.8+ GB

# %%
outdf
# Out:
#            WaDEUUID in_MethodUUID in_AggregationIntervalUnitCV in_VariableCV  \
# 0              in10     CAssdw_M1                      Monthly     Water Use
# 1              in11     CAssdw_M1                      Monthly     Water Use
# 2              in12     CAssdw_M1                      Monthly     Water Use
# 3              in13     CAssdw_M1                      Monthly     Water Use
# 4              in14     CAssdw_M1                      Monthly     Water Use
# ...             ...           ...                          ...           ...
# 4889269  in15015536     CAssdw_M1                      Monthly     Water Use
# 4889270  in15015537     CAssdw_M1                      Monthly     Water Use
# 4889271  in15015538     CAssdw_M1                      Monthly     Water Use
# 4889272  in15015539     CAssdw_M1                      Monthly     Water Use
# 4889273  in15015540     CAssdw_M1                      Monthly     Water Use
#
#         in_OrganizationUUID in_Geometry in_GNISFeatureNameCV  \
# 0                 CAssdw_O1
# 1                 CAssdw_O1
# 2                 CAssdw_O1
# 3                 CAssdw_O1
# 4                 CAssdw_O1
# ...                     ...         ...                  ...
# 4889269           CAssdw_O1
# 4889270           CAssdw_O1
# 4889271           CAssdw_O1
# 4889272           CAssdw_O1
# 4889273           CAssdw_O1
#
#         in_WaterQualityIndicatorCV in_WaterSourceName in_WaterSourceNativeID  \
# 0                                      Sly Park Creek                wadeId1
# 1                                      Sly Park Creek                wadeId1
# 2                                      Sly Park Creek                wadeId1
# 3                                      Sly Park Creek                wadeId1
# 4                                      Sly Park Creek                wadeId1
# ...                            ...                ...                    ...
# 4889269                                Dashiell Creek             wadeId7348
# 4889270                                Dashiell Creek             wadeId7348
# 4889271                                Dashiell Creek             wadeId7348
# 4889272                                Dashiell Creek             wadeId7348
# 4889273                                Dashiell Creek             wadeId7348
#
#         in_WaterSourceTypeCV in_CoordinateAccuracy in_CoordinateMethodCV  \
# 0                Unspecified                                       DD_NE
# 1                Unspecified                                       DD_NE
# 2                Unspecified                                       DD_NE
# 3                Unspecified                                       DD_NE
# 4                Unspecified                                       DD_NE
# ...                      ...                   ...                   ...
# 4889269        Surface Water                                      GIS_LL
# 4889270        Surface Water                                      GIS_LL
# 4889271        Surface Water                                      GIS_LL
# 4889272        Surface Water                                      GIS_LL
# 4889273        Surface Water                                      GIS_LL
#
#          in_County  in_EPSGCodeCV in_GNISCodeCV           in_HUC12  \
# 0        El Dorado           4326               180400130101.00000
# 1        El Dorado           4326               180400130101.00000
# 2        El Dorado           4326               180400130101.00000
# 3        El Dorado           4326               180400130101.00000
# 4        El Dorado           4326               180400130101.00000
# ...            ...            ...           ...                ...
# 4889269       Lake           4326               180101030502.00000
# 4889270       Lake           4326               180101030502.00000
# 4889271       Lake           4326               180101030502.00000
# 4889272       Lake           4326               180101030502.00000
# 4889273       Lake           4326               180101030502.00000
#
#                in_HUC8 in_Latitude in_Longitude in_NHDNetworkStatusCV  \
# 0       18040013.00000    38.71507   -120.56160
# 1       18040013.00000    38.71507   -120.56160
# 2       18040013.00000    38.71507   -120.56160
# 3       18040013.00000    38.71507   -120.56160
# 4       18040013.00000    38.71507   -120.56160
# ...                ...         ...          ...                   ...
# 4889269 18010103.00000    39.41650   -123.05230
# 4889270 18010103.00000    39.41650   -123.05230
# 4889271 18010103.00000    39.41650   -123.05230
# 4889272 18010103.00000    39.41650   -123.05230
# 4889273 18010103.00000    39.41650   -123.05230
#
#         in_NHDProductCV in_PODorPOUSite in_SiteName in_SiteNativeID  \
# 0                                   POD                     40933.0
# 1                                   POD                     40933.0
# 2                                   POD                     40933.0
# 3                                   POD                     40933.0
# 4                                   POD                     40933.0
# ...                 ...             ...         ...             ...
# 4889269                             POD                     62673.0
# 4889270                             POD                     62673.0
# 4889271                             POD                     62673.0
# 4889272                             POD                     62673.0
# 4889273                             POD                     62673.0
#
#         in_SitePoint                                      in_SiteTypeCV  \
# 0                     Point of Direct Diversion,Point of Storage - U...
# 1                     Point of Direct Diversion,Point of Storage - U...
# 2                     Point of Direct Diversion,Point of Storage - U...
# 3                     Point of Direct Diversion,Point of Storage - U...
# 4                     Point of Direct Diversion,Point of Storage - U...
# ...              ...                                                ...
# 4889269                                       Point of Direct Diversion
# 4889270                                       Point of Direct Diversion
# 4889271                                       Point of Direct Diversion
# 4889272                                       Point of Direct Diversion
# 4889273                                       Point of Direct Diversion
#
#         in_StateCV in_USGSSiteID in_Amount in_AllocationCropDutyAmount  \
# 0               CA
# 1               CA
# 2               CA
# 3               CA
# 4               CA
# ...            ...           ...       ...                         ...
# 4889269         CA
# 4889270         CA
# 4889271         CA
# 4889272         CA
# 4889273         CA
#
#         in_AssociatedNativeAllocationIDs in_BeneficialUseCategory  \
# 0                                A002270         Incidental Power
# 1                                A002270         Incidental Power
# 2                                A002270         Incidental Power
# 3                                A002270         Incidental Power
# 4                                A002270         Incidental Power
# ...                                  ...                      ...
# 4889269                          S024415                 Domestic
# 4889270                          S024415                 Domestic
# 4889271                          S024415                 Domestic
# 4889272                          S024415                 Domestic
# 4889273                          S024415                 Domestic
#
#         in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...           ...               ...
# 4889269
# 4889270
# 4889271
# 4889272
# 4889273
#
#         in_DataPublicationDate in_DataPublicationDOI in_IrrigatedAcreage  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                   ...                 ...
# 4889269
# 4889270
# 4889271
# 4889272
# 4889273
#
#         in_IrrigationMethodCV in_PopulationServed in_PowerGeneratedGWh  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                 ...                  ...
# 4889269
# 4889270
# 4889271
# 4889272
# 4889273
#
#         in_PowerType in_PrimaryUseCategory  in_ReportYearCV  \
# 0                         Incidental Power             2016
# 1                         Incidental Power             2017
# 2                         Incidental Power             2018
# 3                         Incidental Power             2021
# 4                         Incidental Power             2022
# ...              ...                   ...              ...
# 4889269                           Domestic             2018
# 4889270                           Domestic             2018
# 4889271                           Domestic             2018
# 4889272                           Domestic             2018
# 4889273                           Domestic             2018
#
#         in_SDWISIdentifier in_TimeframeEnd in_TimeframeStart  \
# 0                               2016-01-01        2016-01-01
# 1                               2017-01-01        2017-01-01
# 2                               2018-01-01        2018-01-01
# 3                               2021-01-01        2021-01-01
# 4                               2022-01-01        2022-01-01
# ...                    ...             ...               ...
# 4889269                         2018-08-01        2018-08-01
# 4889270                         2018-09-01        2018-09-01
# 4889271                         2018-10-01        2018-10-01
# 4889272                         2018-11-01        2018-11-01
# 4889273                         2018-12-01        2018-12-01
#
#                                   in_VariableSpecificCV
# 0        Water Use_Monthly_Incidental Power_Unspecified
# 1        Water Use_Monthly_Incidental Power_Unspecified
# 2        Water Use_Monthly_Incidental Power_Unspecified
# 3        Water Use_Monthly_Incidental Power_Unspecified
# 4        Water Use_Monthly_Incidental Power_Unspecified
# ...                                                 ...
# 4889269        Water Use_Monthly_Domestic_Surface Water
# 4889270        Water Use_Monthly_Domestic_Surface Water
# 4889271        Water Use_Monthly_Domestic_Surface Water
# 4889272        Water Use_Monthly_Domestic_Surface Water
# 4889273        Water Use_Monthly_Domestic_Surface Water
#
# [4889274 rows x 49 columns]

# %%
# Export the output dataframe
outdf.to_csv('RawInputData/Pssdw_Main.zip', compression=dict(method='zip', archive_name='Pssdw_Main.csv'), index=False)  # The output, save as a zip
