# %% [markdown]
# This code prepares the "reportingunits.csv" file for NM where aggregations are done on basin level.
# Another code "reportingunits_NN.py" aggregates on county level.

# %%
#!/usr/bin/env python
import pandas as pd
import numpy as np
import os
from datetime import datetime
from dateutil.parser import parse
import shapefile
import pygeoif
import json
import geopandas as gpd
from utilityFunctions import *

# %%
# working directory
working_dir = "../AggregatedAmounts/RawInputData/"
os.chdir(working_dir)

# %%
target_columns = ["ReportingUnitUUID", "ReportingUnitNativeID", "ReportingUnitName", 
                  "ReportingUnitTypeCV", "ReportingUnitUpdateDate", "ReportingUnitProductVersion",
                  "StateCV", "EPSGCodeCV", "Geometry"]

# %%
outdf100 = pd.DataFrame(columns=target_columns)

# %%
# Input files
fileInput1 = "Summary of withdrawals by county 90-15.xlsx" 
fileInput2 = "Summary of withdrawals by River Basin 90-15.xlsx"

# %%
df10 = pd.read_excel(fileInput2, header=0, sheet_name=0, skiprows=1, encoding = "ISO-8859-1")
#df20 = pd.read_excel(fileInput2, header=0, sheet_name=0, skiprows=1, encoding = "ISO-8859-1")
list(df10.columns)
#list(df20.columns)
# Out:
# ['RVB', 'CAT', 'WSW', 'WGW', 'TW']

# %%
# combine multiple sheets to one dataFrame

startYear = 1990
endYear = 2015
numSheets = 5
yearList = np.linspace(startYear, endYear, numSheets)
df100_list = []
for isx in range (numSheets):
    df10 = pd.read_excel(fileInput2, header=0, sheet_name=isx, skiprows=1, encoding = "ISO-8859-1")
    df10 = df10.assign(ReportYearCV=yearList[isx])
    df10.ReportYearCV = df10.ReportYearCV.astype(int)
    df100_list.append(df10)
    
df100 = pd.concat(df100_list, sort=True)

df100
# Out:
#                            CAT  RVB  ReportYearCV            TW  \
# 0          Public Water Supply  AWR          1990  6.308600e+03
# 1     Domestic (self-supplied)  AWR          1990  6.111500e+02
# 2        Irrigated Agriculture  AWR          1990  2.937790e+05
# 3    Livestock (self-supplied)  AWR          1990  4.149130e+03
# 4   Commercial (self-supplied)  AWR          1990  5.877100e+02
# 5   Industrial (self-supplied)  AWR          1990  0.000000e+00
# 6       Mining (self-supplied)  AWR          1990  2.936900e+02
# 7        Power (self-supplied)  AWR          1990  0.000000e+00
# 8        Reservoir Evaporation  AWR          1990  6.292140e+04
# 9          Public Water Supply   TG          1990  2.437476e+04
# 10    Domestic (self-supplied)   TG          1990  1.251700e+03
# 11       Irrigated Agriculture   TG          1990  6.304370e+05
# 12   Livestock (self-supplied)   TG          1990  2.905790e+03
# 13  Commercial (self-supplied)   TG          1990  1.416060e+03
# 14  Industrial (self-supplied)   TG          1990  4.316000e+02
# 15      Mining (self-supplied)   TG          1990  1.254326e+04
# 16       Power (self-supplied)   TG          1990  5.376470e+03
# 17       Reservoir Evaporation   TG          1990  0.000000e+00
# 18         Public Water Supply    P          1990  3.960886e+04
# 19    Domestic (self-supplied)    P          1990  1.956240e+03
# 20       Irrigated Agriculture    P          1990  6.586300e+05
# 21   Livestock (self-supplied)    P          1990  5.986730e+03
# 22  Commercial (self-supplied)    P          1990  4.676570e+03
# 23  Industrial (self-supplied)    P          1990  2.242900e+03
# 24      Mining (self-supplied)    P          1990  1.945386e+04
# 25       Power (self-supplied)    P          1990  0.000000e+00
# 26       Reservoir Evaporation    P          1990  2.227962e+04
# 27         Public Water Supply   RG          1990  2.138382e+05
# 28    Domestic (self-supplied)   RG          1990  1.861658e+04
# 29       Irrigated Agriculture   RG          1990  1.323593e+06
# ..                         ...  ...           ...           ...
# 24       Power (self-supplied)    P          2015  0.000000e+00
# 25         Public Water Supply    P          2015  4.266567e+04
# 26       Reservoir Evaporation    P          2015  3.596200e+04
# 27  Commercial (self-supplied)   RG          2015  4.172665e+04
# 28    Domestic (self-supplied)   RG          2015  1.872699e+04
# 29  Industrial (self-supplied)   RG          2015  7.548097e+03
# 30       Irrigated Agriculture   RG          2015  1.299979e+06
# 31   Livestock (self-supplied)   RG          2015  9.794727e+03
# 32      Mining (self-supplied)   RG          2015  2.268068e+04
# 33       Power (self-supplied)   RG          2015  7.123457e+03
# 34         Public Water Supply   RG          2015  2.208641e+05
# 35       Reservoir Evaporation   RG          2015  1.450780e+05
# 36  Commercial (self-supplied)   TG          2015  3.326101e+03
# 37    Domestic (self-supplied)   TG          2015  2.132855e+03
# 38  Industrial (self-supplied)   TG          2015  5.490400e+00
# 39       Irrigated Agriculture   TG          2015  5.242108e+05
# 40   Livestock (self-supplied)   TG          2015  1.292157e+04
# 41      Mining (self-supplied)   TG          2015  1.050389e+03
# 42       Power (self-supplied)   TG          2015  3.781160e+03
# 43         Public Water Supply   TG          2015  2.263936e+04
# 44       Reservoir Evaporation   TG          2015  0.000000e+00
# 45  Commercial (self-supplied)   UC          2015  1.134610e+03
# 46    Domestic (self-supplied)   UC          2015  2.942536e+03
# 47  Industrial (self-supplied)   UC          2015  9.262365e+02
# 48       Irrigated Agriculture   UC          2015  3.134422e+05
# 49   Livestock (self-supplied)   UC          2015  5.920401e+02
# 50      Mining (self-supplied)   UC          2015  8.624700e+02
# 51       Power (self-supplied)   UC          2015  4.743436e+04
# 52         Public Water Supply   UC          2015  2.032030e+04
# 53       Reservoir Evaporation   UC          2015  2.950500e+04
#
#               WGW            WSW
# 0     3503.840000    2804.760000
# 1      611.150000       0.000000
# 2   105199.000000  188580.000000
# 3     3197.640000     951.490000
# 4      378.150000     209.560000
# 5        0.000000       0.000000
# 6      293.690000       0.000000
# 7        0.000000       0.000000
# 8        0.000000   62921.400000
# 9    24374.760000       0.000000
# 10    1251.700000       0.000000
# 11  630437.000000       0.000000
# 12    2753.660000     152.130000
# 13    1416.060000       0.000000
# 14     431.600000       0.000000
# 15   12543.260000       0.000000
# 16    5376.470000       0.000000
# 17       0.000000       0.000000
# 18   35046.240000    4562.620000
# 19    1956.240000       0.000000
# 20  431621.000000  227009.000000
# 21    5045.180000     941.550000
# 22    4192.670000     483.900000
# 23    2242.900000       0.000000
# 24   19409.780000      44.080000
# 25       0.000000       0.000000
# 26       0.000000   22279.620000
# 27  201462.400000   12375.790000
# 28   18616.580000       0.000000
# 29  345259.000000  978334.000000
# ..            ...            ...
# 24       0.000000       0.000000
# 25   38859.411119    3806.262000
# 26       0.000000   35962.000000
# 27   41376.024815     350.628000
# 28   18726.989588       0.000000
# 29    7547.026500       1.070000
# 30  345731.290000  954247.430000
# 31    8739.580863    1055.146112
# 32   14668.624481    8012.060000
# 33    7123.457000       0.000000
# 34  165679.451136   55184.664142
# 35       0.000000  145077.980000
# 36    3326.101179       0.000000
# 37    2132.855181       0.000000
# 38       5.490400       0.000000
# 39  524210.840000       0.000000
# 40   12684.071824     237.499984
# 41    1050.388763       0.000000
# 42    3781.160000       0.000000
# 43   22639.358444       0.000000
# 44       0.000000       0.000000
# 45      43.148623    1091.461538
# 46    2942.536445       0.000000
# 47       1.236500     925.000000
# 48       0.000000  313442.190000
# 49     444.020992     148.019110
# 50     146.070000     716.400000
# 51       0.000000   47434.360000
# 52     451.850167   19868.450000
# 53       0.000000   29505.000000
#
# [270 rows x 6 columns]

# %%
print("Copying basin name...")

# all we need from input is river basin name

# first remove redundancies
df100 = df100.drop_duplicates(subset=["RVB"])   #
df100 = df100.reset_index(drop=True)

print(len(df100.index))

outdf100["ReportingUnitName"] = df100["RVB"]
# Out:
# Copying basin name...
# 6

# %%
# ReportingUnitNativeID	 	 Auto generate
outdf100['ReportingUnitNativeID'] = range(1, len(outdf100.index) + 1)

#ReportingUnitUUID	 	 NM_NativeID
outdf100['ReportingUnitUUID'] = outdf100.apply(lambda row: 
                                              "_".join(["NM", str(row['ReportingUnitNativeID'])]),
                                                axis=1)

# %%
# make sure the shapefile is in the same working directory

print("Geometry...")

basins = "WUR_surface_Basins.shp"

sf = shapefile.Reader(basins)
#print(sf)

shapes = sf.shapes()
#shapes[0].shapeType
fields = sf.fields
print (fields)
records = sf.records()
print(records)

print(outdf100["ReportingUnitName"])

fields = sf.fields[1:] 
field_names = [field[0] for field in fields] 

# construction of a dctionary field_name:value  
for r in sf.shapeRecords():  
    atr = dict(zip(field_names, r.record)) 
    if atr['STATE'] == 'New Mexico':
        action
gm= pygeoif.geometry.as_shape(shapes[0])
#print (gm.wkt)
gm=[]
for sp in shapes:
    gm.append(pygeoif.geometry.as_shape(sp)) 
m = pygeoif.MultiPoint(gm)
#print (m.wkt)
# Out:
# Geometry...
# [('DeletionFlag', 'C', 1, 0), ['REG_NAME', 'C', 60, 0], ['Shape_Leng', 'F', 19, 11], ['Shape_Area', 'F', 19, 11], ['Acre', 'F', 19, 11]]
# [Record #0: ['Upper Colorado Region', 21759.7389687, 21136137.6785, 6248871.35774], Record #1: ['Arkansas-White-Red Region', 290931.572706, 2579621573.23, 11302813.135], Record #2: ['Rio Grande Region', 413346.403199, 7966971248.07, 32070699.4266], Record #3: ['Lower Colorado Region', 396911.568088, 3530633008.58, 8535605.24968], Record #4: ['Pecos Region', 709376.617843, 9442245477.58, 16263638.3], Record #5: ['Texas-Gulf Region', 136903.395422, 747261081.817, 3400856.08862]]
# 0    AWR
# 1     TG
# 2      P
# 3     RG
# 4     UC
# 5     LC
# Name: ReportingUnitName, dtype: object

# %%
geojson_file = "basins_geojson"
geodf = gpd.read_file(basins)
geodf.to_file(geojson_file, driver = "GeoJSON")

with open(geojson_file) as geofile:
    basinsJson = json.load(geofile)

#basinsJson
#print(locations)
idS = [basinsJson['features'][k]['id'] for k in range(len(basinsJson['features']))]
#print(basinsJson['features'][5].keys())
#print(basinsJson['features'][0]['properties'])
text=[feat['properties']['REG_NAME'] for feat in basinsJson['features'] if feat['id'] in locations]
text

# %%
"""
fields = sf.fields[1:] 
field_names = [field[0] for field in fields] 
# construction of a dctionary field_name:value  
for r in sf.shapeRecords():  
    atr = dict(zip(field_names, r.record)) 
    if atr['STATE'] == 'New Mexico':
        action

>>> for shapeRec in sf.iterShapeRecords():
...     # do something here
...     pass


"""

# %%
# hardcoded

outdf100.StateCV = "NM"
outdf100.ReportingUnitTypeCV = "River Basin"
outdf100.EPSGCodeCV = "EPSG:4326"
sampleWKT =  'POLYGON((-99.54319297853704 37.15853229006052, -97.26976797641987 37.15759429005948, -105.11636298372741 37.14764529005038, -104.52740598317905 37.15119229005359, -104.09963198278069 37.15376929005606, -103.56062798227867 37.156443290058405, -103.12301898187116 37.157137290059154, -103.08639398183686 37.15689329005886, -103.00203898175846 37.156332290058344, -99.90287697887197 37.162385290064094, -99.54319297853704 37.15853229006052))'
outdf100.Geometry = sampleWKT

# replace NaN with blank cells
outdf100 = outdf100.replace(np.nan, '')
outdf100.head(5)

# %%
print("Writing out...")

#write out
out_repunit = 'reportingunits.csv'
outdf100.to_csv(out_repunit, index=False, encoding = "utf-8")

print("Done sites")
