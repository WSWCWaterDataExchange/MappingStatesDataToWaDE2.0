# %% [markdown]
# # Preprocessing New Mexico Allocation data for WaDE upload.
# - Purpose:  To preprocess the New Mexico data into one master file for simple DataFrame creation and extraction.

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/NewMexico/WaterAllocation" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/NewMexico/WaterAllocation

# %% [markdown]
# ### OSE POD Data

# %%
# Input File - OSE POD data
dfinPOD = pd.read_csv('RawInputData/OSE_PODs.zip', compression='zip').replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "nmwr" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('RawInputData/OSE_PODs.zip', compression=dict(method='zip', archive_name='OSE_PODs.csv'), index=False)

print(len(dfinPOD))
dfinPOD.head(1)
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_332\1262176936.py:2: DtypeWarning: Columns (3,31,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfinPOD = pd.read_csv('RawInputData/OSE_PODs.zip', compression='zip').replace(np.nan, "")
# 265651
#    OBJECTID_1  OBJECTID pod_basin pod_nbr pod_suffix ref pod_name  tws  rng  \
# 0           1         1         B     928                          11N  10W
#
#   sec qtr_4th qtr_16th qtr_64th blk zone       x       y landgrant legal  \
# 0  22       3        4                   0.00000 0.00000
#
#   county  license_nb start_date finish_dat plug_date pcw_rcv_da  elevation  \
# 0     CI         644                                               0.00000
#
#    depth_well grnd_wtr_s  percent_sh  depth_wate              log_file_d  \
# 0         138          S         100         100  1981/10/30 07:00:00+00
#
#   sched_date use_of_wel pump_type pump_seria discharge aquifer  \
# 0              DOMESTIC
#
#                  sys_date subdiv_nam subdiv_loc  restrict_  lat_deg  lat_min  \
# 0  2008/09/25 06:00:00+00                          0.00000        0        0
#
#    lat_sec  lon_deg  lon_min  lon_sec  surface_co  estimate_y pod_status  \
# 0  0.00000        0        0  0.00000           0          30        ACT
#
#    casing_siz ditch_name  utm_zone      easting      northing  datum  \
# 0     0.00000                   13 237475.00000 3894893.00000  NAD83
#
#   utm_source utm_accura xy_source xy_accurac lat_lon_so lat_lon_ac tract_nbr  \
# 0          G          0
#
#   map_nbr surv_map other_loc  pod_rec_nb cfs_start_ cfs_end_md  cfs_cnv_fa  \
# 0                                      1                           0.00000
#
#    cs_code  wrats_s_id utm_error pod_sub_ba well_tag  static_lev pod_file  \
# 0        0           0                    B                    0  B-00928
#
#    sum_rec_nb basin  nbr suffix sub_basin status use_  total_div sub_file  \
# 0         619     B  928                B    PMT  DOM    3.00000
#
#   sf_header  db_file own_lname own_fname           addr1 addr2    city state  \
# 0            B-00928  GALLEGOS  BENNIE G  408 W SANTA FE        GRANTS    NM
#
#      zip contact_ln contact_fn  \
# 0  87020
#
#                                           nmwrrs_wrs  in_state  \
# 0  http://nmwrrs.ose.state.nm.us/ReportDispatcher...         1
#
#                 dump_date  loc_error  wr_count  replaced WaDEUUID
# 0  2023/07/31 06:00:00+00          0         1         1    nmwr0

# %%
#technique to check datatype of long dataframes.
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(dfinPOD.dtypes)
# Out:
# OBJECTID_1      int64
# OBJECTID        int64
# pod_basin      object
# pod_nbr        object
# pod_suffix     object
# ref            object
# pod_name       object
# tws            object
# rng            object
# sec            object
# qtr_4th        object
# qtr_16th       object
# qtr_64th       object
# blk            object
# zone           object
# x             float64
# y             float64
# landgrant      object
# legal          object
# county         object
# license_nb      int64
# start_date     object
# finish_dat     object
# plug_date      object
# pcw_rcv_da     object
# elevation     float64
# depth_well      int64
# grnd_wtr_s     object
# percent_sh      int64
# depth_wate      int64
# log_file_d     object
# sched_date     object
# use_of_wel     object
# pump_type      object
# pump_seria     object
# discharge      object
# aquifer        object
# sys_date       object
# subdiv_nam     object
# subdiv_loc     object
# restrict_     float64
# lat_deg         int64
# lat_min         int64
# lat_sec       float64
# lon_deg         int64
# lon_min         int64
# lon_sec       float64
# surface_co      int64
# estimate_y      int64
# pod_status     object
# casing_siz    float64
# ditch_name     object
# utm_zone        int64
# easting       float64
# northing      float64
# datum          object
# utm_source     object
# utm_accura     object
# xy_source      object
# xy_accurac     object
# lat_lon_so     object
# lat_lon_ac     object
# tract_nbr      object
# map_nbr        object
# surv_map       object
# other_loc      object
# pod_rec_nb      int64
# cfs_start_     object
# cfs_end_md     object
# cfs_cnv_fa    float64
# cs_code         int64
# wrats_s_id      int64
# utm_error      object
# pod_sub_ba     object
# well_tag       object
# static_lev      int64
# pod_file       object
# sum_rec_nb      int64
# basin          object
# nbr            object
# suffix         object
# sub_basin      object
# status         object
# use_           object
# total_div     float64
# sub_file       object
# sf_header      object
# db_file        object
# own_lname      object
# own_fname      object
# addr1          object
# addr2          object
# city           object
# state          object
# zip            object
# contact_ln     object
# contact_fn     object
# nmwrrs_wrs     object
# in_state        int64
# dump_date      object
# loc_error       int64
# wr_count        int64
# replaced        int64
# WaDEUUID       object
# dtype: object

# %%
print("Project to longitude/ latitude ")

from pyproj import transform, Proj

dfinPOD = dfinPOD.assign(in_Longitude='')
dfinPOD = dfinPOD.assign(in_Latitude='')

utmProj = Proj(init="epsg:26913", proj="utm", zone=13)

lonList = []
latList = []

for ix in range(len(dfinPOD.index)):
    #print(ix)
    x1 = dfinPOD.loc[ix, 'easting']
    y1 = dfinPOD.loc[ix, 'northing']
    try:
        lon, lat = utmProj(float(x1), float(y1), inverse=True)
        lonList.append(lon)
        latList.append(lat)
    except:
        lonList.append('')
        latList.append('')

dfinPOD['in_Longitude'] = lonList
dfinPOD['in_Latitude'] = latList
dfinPOD.head(3)
# Out:
# Project to longitude/ latitude
# C:\Users\rjame\anaconda3\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#    OBJECTID_1  OBJECTID pod_basin pod_nbr pod_suffix ref pod_name  tws  rng  \
# 0           1         1         B     928                          11N  10W
# 1           2         2         B      17    EXPLORE               12N  10W
# 2           3         3         B     691                          10N  10W
#
#   sec qtr_4th qtr_16th qtr_64th blk zone       x       y landgrant legal  \
# 0  22       3        4                   0.00000 0.00000
# 1  20       3        3        3          0.00000 0.00000
# 2  03                                    0.00000 0.00000
#
#   county  license_nb              start_date              finish_dat  \
# 0     CI         644
# 1     CI         207  1956/11/30 07:00:01+00  1957/02/01 07:00:01+00
# 2     VA         641  1979/06/19 06:00:00+00  1979/06/19 06:00:00+00
#
#   plug_date pcw_rcv_da  elevation  depth_well grnd_wtr_s  percent_sh  \
# 0                         0.00000         138          S         100
# 1                         0.00000         275          S         100
# 2                         0.00000         220          S         100
#
#    depth_wate              log_file_d sched_date  use_of_wel pump_type  \
# 0         100  1981/10/30 07:00:00+00               DOMESTIC
# 1         152  1957/02/25 07:00:01+00             INDUSTRIAL
# 2         180  1979/09/27 06:00:00+00               DOMESTIC
#
#   pump_seria discharge aquifer                sys_date       subdiv_nam  \
# 0                               2008/09/25 06:00:00+00
# 1                               2009/11/19 06:59:59+00
# 2                               2002/07/17 06:00:00+00  VISTA DEL VALLE
#
#              subdiv_loc  restrict_  lat_deg  lat_min  lat_sec  lon_deg  \
# 0                          0.00000        0        0  0.00000        0
# 1                          0.00000        0        0  0.00000        0
# 2  2     1           VA    0.00000        0        0  0.00000        0
#
#    lon_min  lon_sec  surface_co  estimate_y pod_status  casing_siz ditch_name  \
# 0        0  0.00000           0          30        ACT     0.00000
# 1        0  0.00000           0           0        ACT    12.00000
# 2        0  0.00000           0          13        ACT     5.00000
#
#    utm_zone      easting      northing  datum utm_source utm_accura xy_source  \
# 0        13 237475.00000 3894893.00000  NAD83          G          0
# 1        13 234013.00000 3904479.00000  NAD83          G          0
# 2        13 237445.00000 3890736.00000  NAD83          G          0
#
#   xy_accurac lat_lon_so lat_lon_ac tract_nbr map_nbr surv_map other_loc  \
# 0
# 1
# 2
#
#    pod_rec_nb cfs_start_ cfs_end_md  cfs_cnv_fa  cs_code  wrats_s_id  \
# 0           1                           0.00000        0           0
# 1           2                           0.00000        0           0
# 2           3                           0.00000        0           0
#
#   utm_error pod_sub_ba well_tag  static_lev         pod_file  sum_rec_nb  \
# 0                    B                    0          B-00928         619
# 1                    B                    0  B-00017-EXPLORE        1127
# 2                    B                    0          B-00691        1082
#
#   basin  nbr suffix sub_basin status use_  total_div sub_file sf_header  \
# 0     B  928                B    PMT  DOM    3.00000
# 1     B   17                B    LIC  IND 3295.54000
# 2     B  691                B    PMT  DOM    3.00000
#
#    db_file               own_lname own_fname                 addr1 addr2  \
# 0  B-00928                GALLEGOS  BENNIE G        408 W SANTA FE
# 1  B-00017  TRI-STATE ASSOC., INC.            1100 WEST 116TH AVE.
# 2  B-00691                   JICHA       RON        P. O. BOX 1979
#
#           city state    zip     contact_ln contact_fn  \
# 0       GRANTS    NM  87020
# 1  WESTMINSTER    CO  80234  SEE ALSO B-18
# 2       GRANTS    NM  87020
#
#                                           nmwrrs_wrs  in_state  \
# 0  http://nmwrrs.ose.state.nm.us/ReportDispatcher...         1
# 1  http://nmwrrs.ose.state.nm.us/ReportDispatcher...         1
# 2  http://nmwrrs.ose.state.nm.us/ReportDispatcher...         1
#
#                 dump_date  loc_error  wr_count  replaced WaDEUUID  \
# 0  2023/07/31 06:00:00+00          0         1         1    nmwr0
# 1  2023/07/31 06:00:00+00          0         1         0    nmwr1
# 2  2023/07/31 06:00:00+00          0         1         0    nmwr2
#
#    in_Longitude  in_Latitude
# 0    -107.88224     35.16272
# 1    -107.92330     35.24814
# 2    -107.88125     35.12528

# %%
# For creating Water source type

dfinPOD.assign(GroundWaterSourceTypeCV='')
dfinPOD.assign(SurfaceWaterSourceTypeCV='')

dfinPOD["GroundWaterSourceTypeCV"] = dfinPOD.apply(lambda row: 'Groundwater' 
                                             if str(row["grnd_wtr_s"]).strip() != '' 
                                             else '', axis=1)
dfinPOD["SurfaceWaterSourceTypeCV"] =dfinPOD.apply(lambda row: 'Surface Water' 
                                              if int(row["surface_co"]) > 0 
                                              else '', axis=1)



dfinPOD.assign(WaterSourceTypeCV='')

waterSourceList = []
for index, row in dfinPOD.iterrows():
    #print(index)
    groundWatetrStr = row['GroundWaterSourceTypeCV']
    surfaceWatetrStr = row['SurfaceWaterSourceTypeCV']
    if (groundWatetrStr != '') & (surfaceWatetrStr != ''):
        waterSourceList.append("Surface and Groundwater")
    elif groundWatetrStr != '':
        waterSourceList.append(groundWatetrStr)
    elif surfaceWatetrStr != '':
        waterSourceList.append(surfaceWatetrStr)
    else:
        waterSourceList.append("")

dfinPOD['in_WaterSourceTypeCV'] = waterSourceList
dfinPOD['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater', '', 'Surface and Groundwater', 'Surface Water'],
#       dtype=object)

# %%
#WaterSourceName

waterSourceDict = {
"1":"ABBOT CREEK",
"2":"ABBOTT LAKE",
"3":"ABIQUIU CREEK",
"4":"ABIQUIU RESERVOIR",
"5":"ABO ARROYO",
"6":"ADAMS CANYON",
"7":"AGUA CALIENTE",
"8":"AGUA CHIQUITA CREEK",
"9":"AGUA FRIA CREEK",
"10":"AGUA FRIA CREEK",
"11":"AGUA FRIA CREEK /N",
"12":"AGUA LIMPIA /N",
"13":"AGUA MEDIA",
"14":"AGUA NEGRA RIVER /N",
"15":"AGUA OLYMPIA",
"16":"AGUA SARCA",
"17":"AGUAJE ARROYO /NM",
"18":"AGUILA CANYON",
"19":"AHOGADERO CREEK",
"20":"ALAMAGORDO RESERVOIR",
"21":"ALAMITO CREEK",
"22":"ALAMITOS CANYON",
"23":"ALAMITOS CREEK",
"24":"ALAMO ARROYO",
"25":"ALAMO CANYON",
"26":"ALAMO CANYON",
"27":"ALAMO CANYON",
"28":"ALAMO CREEK",
"29":"ALAMO CREEK",
"30":"ALAMOCITA ARROYO",
colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        String1 = str(colrowValue)
        String1 = String1.strip()  # remove whitespace chars
        try:
            outList = waterSourceDict[String1]
        except:
            outList = ''
    return outList

dfinPOD['in_WaterSourceName'] = dfinPOD.apply(lambda row: assignWaterSourceName(row['surface_co']), axis=1)
dfinPOD['in_WaterSourceName'].unique()
# Out:
# array(['', 'ABBOTT LAKE', 'ABO ARROYO', 'AGUA CHIQUITA CREEK',
#        'RIO RUIDOSO', 'AGUA CALIENTE', 'RIO BRAZOS', 'BLACK RIVER',
#        'RIO CHUPADERO', 'RIO GRANDE AREA 5', 'RIO GRANDE AREA 3',
#        'RIO GRANDE AREA 1', 'RIO GRANDE AREA 2', 'RIO TESUQUE',
#        'RIO SANTA BARBARA', 'LA JARA CREEK', 'RIO SAN JOSE /N',
#        'RIO CHAMA', 'CANONES CREEK /N', 'CHAVEZ CREEK', 'RIO CHAMITA',
#        'BRAZOS RIVER', 'SAN FRANCISCO RIVER', 'PATOS CREEK',
#        'CARRACAS CANYON', 'JONES CANYON /NM', 'JIM GOODLOE CANYON /NM',
#        'INDIAN RIDGE CANYON /NM', 'WILLOW CREEK /N', 'RITO DEL TANQUE',
#        'VANDERITAS CREEK /N', 'ALAMOSA CREEK', 'RIO EN MEDIO',
#        'GALISTEO CREEK', 'SANTA FE RIVER', 'COX CANYON', 'RIO PENASCO',
#        'JAMES CANYON', 'CANADA LARGA', 'NOGAL CREEK /N', 'EMBUDO CREEK',
#        'RIO PUERCO', 'JEMEZ RIVER', 'RIO GALLINA',
#        'CANON DE LOS CORDOVAS', 'SMITH CANYON', 'CANON DE TERRERO',
#        'PATTERSON CANYON', 'AGUA MEDIA', 'BARILLAS CREEK', 'HARRIS CREEK',
#        'SANTA CRUZ RIVER', 'SPRING CANYON', 'LAS ANIMAS CREEK',
#        'WILLS CANYON', 'PALOMAS CREEK', 'ABBOT CREEK', 'BLUEWATER CREEK',
#        'YOUNG CANYON', 'GREEN CANYON', 'PERCHA CREEK', 'SECO CREEK',
#        'CROW CANYON', 'NORTH SALEM ARROYO', 'COUNTY LINE ARROYO',
#        'RALPH ARROYO', 'BROAD CANYON', 'TORTUGAS ARROYO',
#        'SOUTH PERCHA CREEK', 'JARALOSA CREEK', 'SAND HILL ARROYO',
#        'RICKETSON DRAW', 'ANTHONY ARROYO', 'VELARDE ARROYO',
#        'RODEY ARROYO', 'RHODES ARROYO', 'HAMMETT ARROYO',
#        'BERRENDA CREEK', 'TORTOLITA CREEK', 'APODACA ARROYO',
#        'SALOPEK ARROYO', 'MOSSMAN ARROYO', 'BISHOPS CAP ARROYO',
#        'PENA BLANCA ARROYO', 'APACHE ARROYO', 'NORTH PERCHA CREEK',
#        'MIDDLE PERCHA CREEK', 'TIERRA BLANCA CREEK', 'SACRAMENTO RIVER',
#        'BAYLOR CANYON', 'MESCAL CANYON', 'EAST FORK MASON DRAW /N',
#        'SILVA CANYON', 'MASON DRAW', 'MIDDLE FORK MASON DRAW /N',
#        'WILDHORSE CANYON', 'TRUJILLO CREEK', 'CABALLERO CANYON',
#        'HAY CANYON', 'NOGAL ARROYO /N', 'MUD SPRINGS CANYON',
#        'EMERSON CANYON', 'DOG CANYON', 'MOORE CANYON', 'LA LUZ CREEK',
#        'COTTONWOOD CANYON', 'TULAROSA RIVER', 'NOGAL CANYON /N',
#        'RIO TULAROSA', 'COTTONWOOD CREEK', 'ELEPHANT BUTTE RESERVOIR',
#        'FRESNAL CANYON', 'WHITE OAKS CANYON', 'TULAROSA BASIN',
#        'LABORCITA CANYON', 'RANCHERIA CANYON', 'COYOTE CANYON',
#        'KARR CANYON', 'HAYNES CANYON', 'DEEP CANYON', 'WILSON CANYON',
#        'LONG CANYON', 'RIO BONITO', 'PECOS RIVER AREA 1', 'INDIAN CREEK',
#        'THREE RIVERS', 'RIO HONDO', 'MIMBRES RIVER', 'CANJILON CREEK',
#        'RIO PUEBLO', 'ANIMAS RIVER', 'SAN JUAN AREA 1', 'OX CANYON',
#        'CANON DE LAS PALAS', 'CANON COLORADO', 'ARROYO DEL CUERVO',
#        'RIO SALADO', 'DARK CANYON /N', 'HYATT CANYON', 'LA PLATA RIVER',
#        'GILA RIVER AREA 2', 'WAYLAND CANYON', 'SILVER SPRINGS CANYON',
#        'BEAR CANYON /N', 'SLOUGH CANYON', 'POTATO CANYON',
#        'PEPPER CANYON', 'OJO DE GALLO SPRING', 'RITO DE LA LAMA',
#        'DUCK CREEK', 'VALLECITO CREEK', 'ABIQUIU CREEK', 'EL RITO',
#        'OJO CALIENTE', 'SAN MATEO CREEK', 'POLEO CREEK',
#        'RIO PUERCO DE CHAMA', 'COYOTE CREEK', 'AGUA SARCA',
#        'RITO DEL OJO', 'RITO DE LAS SILLAS', 'RITO ENCINO',
#        'CORRALITOS CREEK', 'RIO TUSAS', 'SAN ANTONIO CREEK',
#        'RIO VALLECITOS /N', 'SANTA CLARA CREEK', 'MADERA CANON',
#        'POJOAQUE RIVER', 'BARRANCONES CREEK', 'OJITOS CANYON',
#        'RIO PUEBLO DE TAOS', 'CAPULIN CREEK /N', 'RIO CAPULIN /N',
#        'RIO NUTRIAS', 'RITO DEL MEDIO', 'RIO DEL OSO', 'EL RITO CREEK /N',
#        'RIO CEBOLLA', 'SALADO ARROYO /NM', 'ARROYO PECOS',
#        'GALLINAS RIVER /N', 'SPRING ARROYO /NM',
#        'RITO DE TIERRA AMARILLA', 'AGUA LIMPIA /N',
#        'SANGUIJUELA CREEK /N', 'CEBOLLA CREEK', 'NAVAJO RIVER',
#        'AMARGO CREEK', 'SAN JUAN AREA 2', 'WESTWATER ARROYO',
#        'HANOVER CREEK', 'WILLOW CREEK', 'VAQUEROS CANYON',
#        'CABRESTO CANYON', 'MENTZEL CANYON', 'ZUNI RIVER',
#        'HORSE LAKE CREEK', 'CUEVO CANYON /N', 'GILA RIVER AREA 1',
#        'RIO GUADALUPE', 'SAPELLO RIVER', 'RIO NAMBE',
#        'COTTONWOOD ARROYO /N', 'ADAMS CANYON', 'CHACO RIVER',
#        'JAROSA CREEK /N', 'PUERCO RIVER', 'WEBB CREEK',
#        'ALLISON DRAW /NM', 'SHUMWAY ARROYO', 'CARRIZO CREEK',
#        'LA JARA CANYON', 'CEREZA CANYON', 'CHACO WASH', 'RIO CHIQUITO /N',
#        'SALT CREEK', 'CIENEGA CREEK', 'RIO DE TRUCHAS',
#        'RIO GRANDE AREA 4', 'TAPICITA CREEK', 'RIO FRIJOLES', 'RIO MEDIO',
#        'RIO QUEMADO', 'DRY CIMARRON RIVER', 'TRAVESSER CREEK',
#        'PINE CANYON', 'FLATHEAD CANYON', 'FISHER CREEK',
#        'TRINCHERITA CREEK /NM', 'TRINCHERA CREEK', 'PECOS RIVER AREA 2',
#        'MORA RIVER', 'MAGADO CREEK', 'HINCHLEY CANYON',
#        'MITTEN BAR CANYON /N', 'EAGLE CREEK /N', 'BONITO LAKE',
#        'LOOKOUT CANYON', 'LITTLE CREEK', 'SALADO CREEK', 'CEDAR CREEK',
#        'CARRIZO CREEK /N', 'BONITO CREEK', 'PHILADELPHIA CANYON',
#        'TANBARK CANYON', 'GONZALES CANYON', 'MILLS CANYON',
#        'LINCOLN CANYON', 'MITT AND BAR CANYON', 'SANTA RITA CANYON',
#        'ANAN CANYON', 'RITO DE LOS PINOS', 'SAN SIMON CIENEGA',
#        'GOBERNADOR CANYON', 'OSO CREEK', 'LITTLE COYOTE CREEK',
#        'TRUCHAS CREEK', 'SILVER SPRINGS CREEK',
#        'RITO DE AGUA NEGRA CHIQUITA /N', 'DOLLINS CANYON', 'LUCAS CANYON',
#        'GREASY CANYON', 'TELEPHONE CANYON', 'CIENEGA CANYON',
#        'WILLIE WHITE CANYON', 'BENSON CANYON', 'CURTIS CANYON',
#        'NEWMAN CANYON', 'GRAVEYARD CANYON', 'ANIMAS BASIN',
#        'TECOLOTE CEEK', 'PENASCO CANYON', 'DURAN CANYON',
#        'NACIMIENTO CREEK', 'GALLINAS CREEK', 'ARROYO HONDO', 'COW CREEK',
#        'PECOS RIVER AREA 4', 'COTTONWOOD CANYON /N', 'CASS DRAW',
#        'RIO DE LOS PINOS', 'AGUA NEGRA RIVER /N', 'LAS HUERTAS CREEK',
#        'PECOS RIVER AREA 5', 'TURKEY CANYON', 'CANARIO CANYON',
#        'CORRUMPA CREEK', 'SOUTH BRANCH CORRUMPA CREEK',
#        'NORTH BRANCH CORRUMPA CREEK', 'RAFAEL CREEK /NM', 'ROAD CANYON',
#        'RIO DE LAS VACAS', 'AMERICAN CREEK',
#        'RIO GRANDE AREA 0 (COLORADO)', 'WILD HORSE CANYON',
#        'SAN AUGUSTIN PLAINS', 'SPRING CREEK', 'WEST LATIR CREEK',
#        'RED RIVER', 'CABRESTO CREEK', 'CEDRITO ARROYO', 'URRACA CREEK',
#        'PIONEER CREEK', 'BITTER CREEK', 'PINABETE CREEK',
#        'RIO GRANDE DE RANCHO', 'RIO FERNANDO DE TAOS', 'RIO LUCERO',
#        'AGUA OLYMPIA', 'ARROYO SECO', 'TIENDITAS CREEK',
#        'SEBOYETITA CREEK', 'SAN CRISTOBAL', 'RITO LA PRESA',
#        'DICKEY CANYON'], dtype=object)

# %%
#Creating Owner

def assignownerName(colrowValue1, colrowValue2):
    if colrowValue1 == '' or pd.isnull(colrowValue1):
        outList1 = ''
    else:
        outList1 = colrowValue1.strip()  # remove whitespace chars
    if colrowValue2 == '' or pd.isnull(colrowValue2):
        outList2 = ''
    else:
        outList2 = colrowValue2.strip()  # remove whitespace chars

    if outList1 == '' and outList2 == '':
        outList = ''
    elif outList1 == '':
        outList = outList2
    elif outList2 == '':
        outList = outList1
    else:
        outList = " ".join(map(str, [colrowValue1, colrowValue2]))
    return outList

dfinPOD['in_AllocationOwner'] = dfinPOD.apply(lambda row: assignownerName(row['own_fname'], row['own_lname']), axis=1)


def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).title().strip()
    return Val

dfinPOD['in_AllocationOwner'] = dfinPOD.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
dfinPOD['in_AllocationOwner'].unique()
# Out:
# array(['Bennie G Gallegos', 'Tristate Assoc Inc', 'Ron Jicha', ...,
#        'Mrs Juanita Miera', 'Steven Kyle Gillen', 'Connie J Neslage'],
#       dtype=object)

# %%
benUseDict = {
    "AGR":"Agriculture other than irrigation",
    "AUG":"Augmentation well",
    "BPW":"Brine production well",
    "CEM":"Cemetery",
    "CLS":"Closed file",
    "COM":"Commercial",
    "CON":"Construction",
    "CPS":"Cathodic protection well",
    "DAI":"Dairy operation",
    "DCN":"Domestic construction",
    "DEW":"Dewatering well",
    "DOL":"72-12-1 domestic and livestock watering",
    "DOM":"72-12-1 domestic one household",
    "EXP":"Exploration",
    "FCD":"Flood control",
    "FGP":"Fish and game propogation",
    "FPO":"Feed pen operation",
    "GEO":"Geothermal boreholes",
    "HWY":"Highway construction",
    "IND":"Industrial",
    "INJ":"Injection",
    "IRR":"Irrigation",
    "MDW":"Community type use",
    "MFG":"Manufacturing",
    "MIL":"Military - military installations",
    "MIN":"Mining or milling or oil",
    "MOB":"Mobile home parks",
    "MON":"Monitoring well",
    "MPP":"Meat packing plant",
    "MUL":"72-12-1 multiple domestic households",
    "MUN":"Municipal - city or county supplied water",
    "N07":"No pre-1907 water right exists on this land",
    "NON":"Non-profit organizational use",
    "NOT":"No use of right or POD",
    "NRT":"No right",
    "OBS":"Observation",
    "OFM":"Oil field maintenance",
    "OIL":"Oil production",
    "PDL":"Non 72-12-1 domestic and livestock watering",
    "PDM":"Non 72-12-1 domestic one household",
    "PLS":"Non 72-12-1 livestock watering",
    "PMH":"Non 72-12-1 multiple domestic households",
    "POL":"Pollution control well",
    "POU":"Poultry and egg operation",
    "PPP":"Petroleum processing plant",
    "PRO":"72-12-1 Prospecting or development of natural resource",
    "PUB":"72-12-1 Construction of public works",
    "REC":"Recreation",
    "SAN":"72-12-1 Sanitary in conjunction with a commercial use",
    "SCH":"School use",
    "SRO":"Secondary recovery of oil",
    "STK":"72-12-1 livestock watering",
    "STO":"Storage",
    "STR":"Strategic water reserve",
    "SUB":"Subdivision",
    "SWR":"Stacked water right",
    "TBD":"To be determined",
    "UTL":"Public utility"}


def assignBenUseCategory(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = benUseDict[String1]
        except:
            outList = ''
    return outList

dfinPOD['in_BeneficialUseCategory'] = dfinPOD.apply(lambda row: assignBenUseCategory(row['use_']), axis=1)
dfinPOD['in_BeneficialUseCategory'].unique()
# Out:
# array(['72-12-1 domestic one household', 'Industrial', 'Exploration',
#        'Municipal - city or county supplied water',
#        '72-12-1 Sanitary in conjunction with a commercial use',
#        '72-12-1 livestock watering', 'Mining or milling or oil',
#        '72-12-1 Construction of public works', 'Irrigation',
#        '72-12-1 Prospecting or development of natural resource',
#        'Subdivision', '', 'Dewatering well', 'Commercial',
#        'Pollution control well', '72-12-1 multiple domestic households',
#        '72-12-1 domestic and livestock watering', 'Mobile home parks',
#        'Community type use', 'Monitoring well', 'Highway construction',
#        'Agriculture other than irrigation', 'Construction',
#        'No use of right or POD', 'Non 72-12-1 domestic one household',
#        'School use', 'Non 72-12-1 livestock watering', 'Closed file',
#        'Public utility', 'Non 72-12-1 domestic and livestock watering',
#        'Oil production', 'Dairy operation', 'Observation', 'No right',
#        'Domestic construction', 'Fish and game propogation', 'Recreation',
#        'Non 72-12-1 multiple domestic households',
#        'Non-profit organizational use',
#        'Military - military installations', 'Poultry and egg operation',
#        'Manufacturing', 'Injection', 'Feed pen operation', 'Cemetery',
#        'Stacked water right', 'Secondary recovery of oil',
#        'Cathodic protection well', 'Augmentation well',
#        'Oil field maintenance', 'Meat packing plant',
#        'Petroleum processing plant', 'Storage', 'Flood control',
#        'Strategic water reserve', 'Brine production well',
#        'Geothermal boreholes', 'To be determined'], dtype=object)

# %%
AllocationLegalStatusDictionaryNM = {
    "ADJ":"Adjudicated",
    "ADM":"Administrative",
    "APP":"Application",
    "APR":"Application Being Protested",
    "CAN":"Cancelled",
    "CLS":"Closed File",
    "DCL":"Declaration",
    "DED":"Dedicated",
    "DEN":"Denied",
    "EXP":"Expired",
    "HS ":"Hydrographic Survey",
    "LIC":"Licensed",
    "NOI":"Notice of Intention",
    "NOT":"Not implies that there is no status",
    "OMS":"Owner Management Status",
    "OOJ":"Offer of Judgment",
    "PBU":"Proof of Beneficial Use",
    "PMT":"Permit",
    "PRG":"Purged Conversion Record",
    "REN":"Renumbered",
    "RET":"Retired",
    "TRN":"Transferred",
    "WMS":"Water Master Status",
    "WTD":"Withdrawn"    
}


def assignLegalStatus(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = AllocationLegalStatusDictionaryNM[String1]
        except:
            outList = ''
    return outList

dfinPOD['in_AllocationLegalStatusCV'] = dfinPOD.apply(lambda row: assignLegalStatus(row['status']), axis=1)
dfinPOD['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Permit', 'Licensed', 'Expired', 'Declaration', 'Cancelled',
#        'Denied', '', 'Closed File', 'Application',
#        'Purged Conversion Record', 'Adjudicated',
#        'Not implies that there is no status', 'Offer of Judgment',
#        'Renumbered', 'Dedicated', 'Withdrawn', 'Transferred', 'Retired',
#        'Owner Management Status', 'Notice of Intention', 'Administrative',
#        'Water Master Status', 'Proof of Beneficial Use'], dtype=object)

# %%
# County
CountyDictionaryNM = {
"BE" : "Bernalillo",
"CA" : "Catron",
"CH" : "Chaves",
"CI" : "Cibola",
"CO" : "Colfax",
"CU" : "Curry",
"DA" : "Dona Ana",
"DB" : "De Baca",
"ED" : "Eddy",
"GR" : "Grant",
"GU" : "Guadalupe",
"HA" : "Harding",
"HI" : "Hidalgo",
"LA" : "Los Alamos",
"LE" : "Lea",
"LI" : "Lincoln",
"LU" : "Luna",
"MK" : "McKinley",
"MO" : "Mora",
"OT" : "Otero",
"QU" : "Quay",
"RA" : "Rio Arriba",
"RO" : "Roosevelt",
"SA" : "Sandoval",
"SF" : "Santa Fe",
"SI" : "Sierra",
"SJ" : "San Juan",
"SM" : "San Miguel",
"SO" : "Socorro",
"TA" : "Taos",
"TO" : "Torrance",
"UN" : "Union",
"VA" : "Valencia",
"XX" : ""}


def assignCounty(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = CountyDictionaryNM[String1]
        except:
            outList = ''
    return outList

dfinPOD['in_County'] = dfinPOD.apply(lambda row: assignCounty(row['county']), axis=1)
dfinPOD['in_County'].unique()
# Out:
# array(['Cibola', 'Valencia', 'McKinley', '', 'Santa Fe', 'Catron',
#        'Rio Arriba', 'Bernalillo', 'Socorro', 'Sandoval', 'San Miguel',
#        'Taos', 'Torrance', 'Sierra', 'Los Alamos', 'Colfax', 'Chaves',
#        'Luna', 'Guadalupe', 'Dona Ana', 'Otero', 'Grant', 'Lincoln',
#        'Hidalgo', 'Eddy', 'Lea', 'Curry', 'De Baca', 'Roosevelt', 'Quay',
#        'San Juan', 'Mora', 'Harding', 'Union'], dtype=object)

# %%
# create output POD dataframe
dfPOD = pd.DataFrame()

# Data Assessment UUID
dfPOD['WaDEUUID'] = dfinPOD['WaDEUUID']

# Method Info
dfPOD['in_MethodUUID'] = "NMwr_M1"

# Variable Info
dfPOD['in_VariableSpecificUUID'] = "NMwr_V1"

# Organization Info
dfPOD['in_OrganizationUUID'] = "NMwr_O1"

# WaterSource Info
dfPOD['in_Geometry'] = ""
dfPOD['in_GNISFeatureNameCV'] = ""
dfPOD['in_WaterQualityIndicatorCV'] = ""
dfPOD['in_WaterSourceName'] = dfinPOD['in_WaterSourceName'].str.title()
dfPOD['in_WaterSourceNativeID'] = "" # create customID for temp solution
dfPOD['in_WaterSourceTypeCV'] = dfinPOD['in_WaterSourceTypeCV']

# Site Info
dfPOD['in_CoordinateAccuracy'] = "WaDE Unspecified"
dfPOD['in_CoordinateMethodCV'] = "WaDE Unspecified"
dfPOD['in_County'] = dfinPOD['in_County']
dfPOD['in_Geometry'] = ""
dfPOD['in_GNISCodeCV'] = ""
dfPOD['in_HUC12'] = ""
dfPOD['in_HUC8'] = ""
dfPOD['in_Latitude'] = dfinPOD['in_Latitude']
dfPOD['in_Longitude'] = dfinPOD['in_Longitude']
dfPOD['in_NHDNetworkStatusCV'] = ""
dfPOD['in_NHDProductCV'] = ""
dfPOD['in_PODorPOUSite'] = "POD"
dfPOD['in_SiteName'] = dfinPOD['ditch_name'].str.title()
dfPOD['in_SiteNativeID'] = dfinPOD['pod_file'].str.strip()
dfPOD['in_SitePoint'] = ""
dfPOD['in_SiteTypeCV'] = "WaDE Unspecified"
dfPOD['in_StateCV'] = "NM"
dfPOD['in_USGSSiteID'] = ""

# AllocationAmount Info
dfPOD['in_AllocationApplicationDate'] = ""
dfPOD['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
dfPOD['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
dfPOD['in_AllocationBasisCV'] = ""
dfPOD['in_AllocationChangeApplicationIndicator'] = ""
dfPOD['in_AllocationCommunityWaterSupplySystem'] = ""
dfPOD['in_AllocationCropDutyAmount'] = ""
dfPOD['in_AllocationExpirationDate'] = ""
dfPOD['in_AllocationFlow_CFS'] = ""
dfPOD['in_AllocationLegalStatusCV'] = dfinPOD['in_AllocationLegalStatusCV']
dfPOD['in_AllocationNativeID'] =  dfinPOD['db_file'].str.strip()
dfPOD['in_AllocationOwner'] = dfinPOD['in_AllocationOwner']
dfPOD['in_AllocationPriorityDate'] = ""
dfPOD['in_AllocationSDWISIdentifierCV'] = ""
dfPOD['in_AllocationTimeframeEnd'] = ""
dfPOD['in_AllocationTimeframeStart'] = ""
dfPOD['in_AllocationTypeCV'] = ""
dfPOD['in_AllocationVolume_AF'] = dfinPOD['total_div']
dfPOD['in_BeneficialUseCategory'] = dfinPOD['in_BeneficialUseCategory']
dfPOD['in_CommunityWaterSupplySystem'] = ""
dfPOD['in_CropTypeCV'] = ""
dfPOD['in_CustomerTypeCV'] = ""
dfPOD['in_DataPublicationDate'] = ""
dfPOD['in_DataPublicationDOI'] = ""
dfPOD['in_ExemptOfVolumeFlowPriority'] = 1
dfPOD['in_GeneratedPowerCapacityMW'] = ""
dfPOD['in_IrrigatedAcreage'] = ""
dfPOD['in_IrrigationMethodCV'] = ""
dfPOD['in_LegacyAllocationIDs'] = ""
dfPOD['in_OwnerClassificationCV'] = ""
dfPOD['in_PopulationServed'] = ""
dfPOD['in_PowerType'] = ""
dfPOD['in_PrimaryBeneficialUseCategory'] = ""
dfPOD['in_SDWISIdentifierCV'] = ""
dfPOD['in_WaterAllocationNativeURL'] = dfinPOD['nmwrrs_wrs']


dfPOD = dfPOD.drop_duplicates().reset_index(drop=True)

print(len(dfPOD))
dfPOD.head()
# Out:
# 265651
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0    nmwr0       NMwr_M1                 NMwr_V1             NMwr_O1
# 1    nmwr1       NMwr_M1                 NMwr_V1             NMwr_O1
# 2    nmwr2       NMwr_M1                 NMwr_V1             NMwr_O1
# 3    nmwr3       NMwr_M1                 NMwr_V1             NMwr_O1
# 4    nmwr4       NMwr_M1                 NMwr_V1             NMwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                                    Groundwater
# 1                                                    Groundwater
# 2                                                    Groundwater
# 3                                                    Groundwater
# 4
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County in_GNISCodeCV  \
# 0      WaDE Unspecified      WaDE Unspecified    Cibola
# 1      WaDE Unspecified      WaDE Unspecified    Cibola
# 2      WaDE Unspecified      WaDE Unspecified  Valencia
# 3      WaDE Unspecified      WaDE Unspecified    Cibola
# 4      WaDE Unspecified      WaDE Unspecified    Cibola
#
#   in_HUC12 in_HUC8  in_Latitude  in_Longitude in_NHDNetworkStatusCV  \
# 0                      35.16272    -107.88224
# 1                      35.24814    -107.92330
# 2                      35.12528    -107.88125
# 3                      35.22996    -107.86800
# 4                      35.30136    -108.15312
#
#   in_NHDProductCV in_PODorPOUSite in_SiteName   in_SiteNativeID in_SitePoint  \
# 0                             POD                       B-00928
# 1                             POD               B-00017-EXPLORE
# 2                             POD                       B-00691
# 3                             POD              B-00408-EXPLOR-4
# 4                             POD                       B-01077
#
#       in_SiteTypeCV in_StateCV in_USGSSiteID in_AllocationApplicationDate  \
# 0  WaDE Unspecified         NM
# 1  WaDE Unspecified         NM
# 2  WaDE Unspecified         NM
# 3  WaDE Unspecified         NM
# 4  WaDE Unspecified         NM
#
#   in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                     Permit               B-00928
# 1                   Licensed               B-00017
# 2                     Permit               B-00691
# 3                     Permit               B-00408
# 4                    Expired               B-01077
#
#              in_AllocationOwner in_AllocationPriorityDate  \
# 0             Bennie G Gallegos
# 1            Tristate Assoc Inc
# 2                     Ron Jicha
# 3  United Nuclearhomestake Ptnr
# 4               George Sherfick
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeStart in_AllocationTypeCV  in_AllocationVolume_AF  \
# 0                                                                 3.00000
# 1                                                              3295.54000
# 2                                                                 3.00000
# 3                                                                 0.00000
# 4                                                                 0.00000
#
#          in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0  72-12-1 domestic one household
# 1                      Industrial
# 2  72-12-1 domestic one household
# 3                     Exploration
# 4  72-12-1 domestic one household
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#    in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 1  http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 2  http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 3  http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 4  http://nmwrrs.ose.state.nm.us/ReportDispatcher...

# %%
# Concatenate dataframes
frames = [dfPOD] # add dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 265651

# %% [markdown]
# ## WaDE Custom Elements (due to missing sate info)

# %%
# Remove Special Characters
def removeSpecialCharFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).strip()
    return Val

# %%
# # some of their records differ by special characters only
# # we are going to try and leave special characters in, for now

# outdf['in_AllocationNativeID'] = outdf.apply(lambda row: removeSpecialCharFunc(row['in_AllocationNativeID']), axis=1)
# outdf['in_AllocationNativeID'].unique()

# %%
# # some of their records differ by special characters only
# # we are going to try and leave special characters in, for now

# outdf['in_SiteNativeID'] = outdf.apply(lambda row: removeSpecialCharFunc(row['in_SiteNativeID']), axis=1)
# outdf['in_SiteNativeID'].unique()

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['', 'Bluewater Toltec', 'Cano', ..., 'Ralston East Side',
#        'Rosa Community Luceros Ditch', 'Enterprise Ditch'], dtype=object)

# %%
# Ensure Empty String

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['', 'Abbott Lake', 'Abo Arroyo', 'Agua Chiquita Creek',
#        'Rio Ruidoso', 'Agua Caliente', 'Rio Brazos', 'Black River',
#        'Rio Chupadero', 'Rio Grande Area 5', 'Rio Grande Area 3',
#        'Rio Grande Area 1', 'Rio Grande Area 2', 'Rio Tesuque',
#        'Rio Santa Barbara', 'La Jara Creek', 'Rio San Jose /N',
#        'Rio Chama', 'Canones Creek /N', 'Chavez Creek', 'Rio Chamita',
#        'Brazos River', 'San Francisco River', 'Patos Creek',
#        'Carracas Canyon', 'Jones Canyon /Nm', 'Jim Goodloe Canyon /Nm',
#        'Indian Ridge Canyon /Nm', 'Willow Creek /N', 'Rito Del Tanque',
#        'Vanderitas Creek /N', 'Alamosa Creek', 'Rio En Medio',
#        'Galisteo Creek', 'Santa Fe River', 'Cox Canyon', 'Rio Penasco',
#        'James Canyon', 'Canada Larga', 'Nogal Creek /N', 'Embudo Creek',
#        'Rio Puerco', 'Jemez River', 'Rio Gallina',
#        'Canon De Los Cordovas', 'Smith Canyon', 'Canon De Terrero',
#        'Patterson Canyon', 'Agua Media', 'Barillas Creek', 'Harris Creek',
#        'Santa Cruz River', 'Spring Canyon', 'Las Animas Creek',
#        'Wills Canyon', 'Palomas Creek', 'Abbot Creek', 'Bluewater Creek',
#        'Young Canyon', 'Green Canyon', 'Percha Creek', 'Seco Creek',
#        'Crow Canyon', 'North Salem Arroyo', 'County Line Arroyo',
#        'Ralph Arroyo', 'Broad Canyon', 'Tortugas Arroyo',
#        'South Percha Creek', 'Jaralosa Creek', 'Sand Hill Arroyo',
#        'Ricketson Draw', 'Anthony Arroyo', 'Velarde Arroyo',
#        'Rodey Arroyo', 'Rhodes Arroyo', 'Hammett Arroyo',
#        'Berrenda Creek', 'Tortolita Creek', 'Apodaca Arroyo',
#        'Salopek Arroyo', 'Mossman Arroyo', 'Bishops Cap Arroyo',
#        'Pena Blanca Arroyo', 'Apache Arroyo', 'North Percha Creek',
#        'Middle Percha Creek', 'Tierra Blanca Creek', 'Sacramento River',
#        'Baylor Canyon', 'Mescal Canyon', 'East Fork Mason Draw /N',
#        'Silva Canyon', 'Mason Draw', 'Middle Fork Mason Draw /N',
#        'Wildhorse Canyon', 'Trujillo Creek', 'Caballero Canyon',
#        'Hay Canyon', 'Nogal Arroyo /N', 'Mud Springs Canyon',
#        'Emerson Canyon', 'Dog Canyon', 'Moore Canyon', 'La Luz Creek',
#        'Cottonwood Canyon', 'Tularosa River', 'Nogal Canyon /N',
#        'Rio Tularosa', 'Cottonwood Creek', 'Elephant Butte Reservoir',
#        'Fresnal Canyon', 'White Oaks Canyon', 'Tularosa Basin',
#        'Laborcita Canyon', 'Rancheria Canyon', 'Coyote Canyon',
#        'Karr Canyon', 'Haynes Canyon', 'Deep Canyon', 'Wilson Canyon',
#        'Long Canyon', 'Rio Bonito', 'Pecos River Area 1', 'Indian Creek',
#        'Three Rivers', 'Rio Hondo', 'Mimbres River', 'Canjilon Creek',
#        'Rio Pueblo', 'Animas River', 'San Juan Area 1', 'Ox Canyon',
#        'Canon De Las Palas', 'Canon Colorado', 'Arroyo Del Cuervo',
#        'Rio Salado', 'Dark Canyon /N', 'Hyatt Canyon', 'La Plata River',
#        'Gila River Area 2', 'Wayland Canyon', 'Silver Springs Canyon',
#        'Bear Canyon /N', 'Slough Canyon', 'Potato Canyon',
#        'Pepper Canyon', 'Ojo De Gallo Spring', 'Rito De La Lama',
#        'Duck Creek', 'Vallecito Creek', 'Abiquiu Creek', 'El Rito',
#        'Ojo Caliente', 'San Mateo Creek', 'Poleo Creek',
#        'Rio Puerco De Chama', 'Coyote Creek', 'Agua Sarca',
#        'Rito Del Ojo', 'Rito De Las Sillas', 'Rito Encino',
#        'Corralitos Creek', 'Rio Tusas', 'San Antonio Creek',
#        'Rio Vallecitos /N', 'Santa Clara Creek', 'Madera Canon',
#        'Pojoaque River', 'Barrancones Creek', 'Ojitos Canyon',
#        'Rio Pueblo De Taos', 'Capulin Creek /N', 'Rio Capulin /N',
#        'Rio Nutrias', 'Rito Del Medio', 'Rio Del Oso', 'El Rito Creek /N',
#        'Rio Cebolla', 'Salado Arroyo /Nm', 'Arroyo Pecos',
#        'Gallinas River /N', 'Spring Arroyo /Nm',
#        'Rito De Tierra Amarilla', 'Agua Limpia /N',
#        'Sanguijuela Creek /N', 'Cebolla Creek', 'Navajo River',
#        'Amargo Creek', 'San Juan Area 2', 'Westwater Arroyo',
#        'Hanover Creek', 'Willow Creek', 'Vaqueros Canyon',
#        'Cabresto Canyon', 'Mentzel Canyon', 'Zuni River',
#        'Horse Lake Creek', 'Cuevo Canyon /N', 'Gila River Area 1',
#        'Rio Guadalupe', 'Sapello River', 'Rio Nambe',
#        'Cottonwood Arroyo /N', 'Adams Canyon', 'Chaco River',
#        'Jarosa Creek /N', 'Puerco River', 'Webb Creek',
#        'Allison Draw /Nm', 'Shumway Arroyo', 'Carrizo Creek',
#        'La Jara Canyon', 'Cereza Canyon', 'Chaco Wash', 'Rio Chiquito /N',
#        'Salt Creek', 'Cienega Creek', 'Rio De Truchas',
#        'Rio Grande Area 4', 'Tapicita Creek', 'Rio Frijoles', 'Rio Medio',
#        'Rio Quemado', 'Dry Cimarron River', 'Travesser Creek',
#        'Pine Canyon', 'Flathead Canyon', 'Fisher Creek',
#        'Trincherita Creek /Nm', 'Trinchera Creek', 'Pecos River Area 2',
#        'Mora River', 'Magado Creek', 'Hinchley Canyon',
#        'Mitten Bar Canyon /N', 'Eagle Creek /N', 'Bonito Lake',
#        'Lookout Canyon', 'Little Creek', 'Salado Creek', 'Cedar Creek',
#        'Carrizo Creek /N', 'Bonito Creek', 'Philadelphia Canyon',
#        'Tanbark Canyon', 'Gonzales Canyon', 'Mills Canyon',
#        'Lincoln Canyon', 'Mitt And Bar Canyon', 'Santa Rita Canyon',
#        'Anan Canyon', 'Rito De Los Pinos', 'San Simon Cienega',
#        'Gobernador Canyon', 'Oso Creek', 'Little Coyote Creek',
#        'Truchas Creek', 'Silver Springs Creek',
#        'Rito De Agua Negra Chiquita /N', 'Dollins Canyon', 'Lucas Canyon',
#        'Greasy Canyon', 'Telephone Canyon', 'Cienega Canyon',
#        'Willie White Canyon', 'Benson Canyon', 'Curtis Canyon',
#        'Newman Canyon', 'Graveyard Canyon', 'Animas Basin',
#        'Tecolote Ceek', 'Penasco Canyon', 'Duran Canyon',
#        'Nacimiento Creek', 'Gallinas Creek', 'Arroyo Hondo', 'Cow Creek',
#        'Pecos River Area 4', 'Cottonwood Canyon /N', 'Cass Draw',
#        'Rio De Los Pinos', 'Agua Negra River /N', 'Las Huertas Creek',
#        'Pecos River Area 5', 'Turkey Canyon', 'Canario Canyon',
#        'Corrumpa Creek', 'South Branch Corrumpa Creek',
#        'North Branch Corrumpa Creek', 'Rafael Creek /Nm', 'Road Canyon',
#        'Rio De Las Vacas', 'American Creek',
#        'Rio Grande Area 0 (Colorado)', 'Wild Horse Canyon',
#        'San Augustin Plains', 'Spring Creek', 'West Latir Creek',
#        'Red River', 'Cabresto Creek', 'Cedrito Arroyo', 'Urraca Creek',
#        'Pioneer Creek', 'Bitter Creek', 'Pinabete Creek',
#        'Rio Grande De Rancho', 'Rio Fernando De Taos', 'Rio Lucero',
#        'Agua Olympia', 'Arroyo Seco', 'Tienditas Creek',
#        'Seboyetita Creek', 'San Cristobal', 'Rito La Presa',
#        'Dickey Canyon'], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater', '', 'Surface and Groundwater', 'Surface Water'],
#       dtype=object)

# %%
outdf['in_CoordinateAccuracy'] = outdf.apply(lambda row: ensureEmptyString(row['in_CoordinateAccuracy']), axis=1)
outdf['in_CoordinateAccuracy'].unique()
# Out:
# array(['WaDE Unspecified'], dtype=object)

# %%
outdf['in_CoordinateMethodCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_CoordinateMethodCV']), axis=1)
outdf['in_CoordinateMethodCV'].unique()
# Out:
# array(['WaDE Unspecified'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: ensureEmptyString(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['Cibola', 'Valencia', 'McKinley', '', 'Santa Fe', 'Catron',
#        'Rio Arriba', 'Bernalillo', 'Socorro', 'Sandoval', 'San Miguel',
#        'Taos', 'Torrance', 'Sierra', 'Los Alamos', 'Colfax', 'Chaves',
#        'Luna', 'Guadalupe', 'Dona Ana', 'Otero', 'Grant', 'Lincoln',
#        'Hidalgo', 'Eddy', 'Lea', 'Curry', 'De Baca', 'Roosevelt', 'Quay',
#        'San Juan', 'Mora', 'Harding', 'Union'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['WaDE Unspecified'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['', 'Bluewater Toltec', 'Cano', ..., 'Ralston East Side',
#        'Rosa Community Luceros Ditch', 'Enterprise Ditch'], dtype=object)

# %%
outdf['in_AllocationLegalStatusCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationLegalStatusCV']), axis=1)
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Permit', 'Licensed', 'Expired', 'Declaration', 'Cancelled',
#        'Denied', '', 'Closed File', 'Application',
#        'Purged Conversion Record', 'Adjudicated',
#        'Not implies that there is no status', 'Offer of Judgment',
#        'Renumbered', 'Dedicated', 'Withdrawn', 'Transferred', 'Retired',
#        'Owner Management Status', 'Notice of Intention', 'Administrative',
#        'Water Master Status', 'Proof of Beneficial Use'], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Bennie G Gallegos', 'Tristate Assoc Inc', 'Ron Jicha', ...,
#        'Mrs Juanita Miera', 'Steven Kyle Gillen', 'Connie J Neslage'],
#       dtype=object)

# %%
outdf['in_AllocationTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationTypeCV']), axis=1)
outdf['in_AllocationTypeCV'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['72-12-1 domestic one household', 'Industrial', 'Exploration',
#        'Municipal - city or county supplied water',
#        '72-12-1 Sanitary in conjunction with a commercial use',
#        '72-12-1 livestock watering', 'Mining or milling or oil',
#        '72-12-1 Construction of public works', 'Irrigation',
#        '72-12-1 Prospecting or development of natural resource',
#        'Subdivision', '', 'Dewatering well', 'Commercial',
#        'Pollution control well', '72-12-1 multiple domestic households',
#        '72-12-1 domestic and livestock watering', 'Mobile home parks',
#        'Community type use', 'Monitoring well', 'Highway construction',
#        'Agriculture other than irrigation', 'Construction',
#        'No use of right or POD', 'Non 72-12-1 domestic one household',
#        'School use', 'Non 72-12-1 livestock watering', 'Closed file',
#        'Public utility', 'Non 72-12-1 domestic and livestock watering',
#        'Oil production', 'Dairy operation', 'Observation', 'No right',
#        'Domestic construction', 'Fish and game propogation', 'Recreation',
#        'Non 72-12-1 multiple domestic households',
#        'Non-profit organizational use',
#        'Military - military installations', 'Poultry and egg operation',
#        'Manufacturing', 'Injection', 'Feed pen operation', 'Cemetery',
#        'Stacked water right', 'Secondary recovery of oil',
#        'Cathodic protection well', 'Augmentation well',
#        'Oil field maintenance', 'Meat packing plant',
#        'Petroleum processing plant', 'Storage', 'Flood control',
#        'Strategic water reserve', 'Brine production well',
#        'Geothermal boreholes', 'To be determined'], dtype=object)

# %%
# Fixing in_AllocationFlow_CFS datatype
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([''], dtype=object)

# %%
# Fixing in_AllocationVolume_AF datatype
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array([3.0, 3295.54, '', ..., 121.25, 8710.0, 86.14], dtype=object)

# %%
# Fixing in_IrrigatedAcreage datatype
outdf['in_IrrigatedAcreage'] = pd.to_numeric(outdf['in_IrrigatedAcreage'], errors='coerce').replace(0,"").fillna("")
outdf['in_IrrigatedAcreage'].unique()
# Out:
# array([''], dtype=object)

# %%
# in_Latitude
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([35.16272037, 35.24813599, 35.12527547, ..., 37.00921819,
#        37.04208861, 31.97215682])

# %%
# in_Longitude
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-107.88223973, -107.92329981, -107.88124797, ..., -107.40959318,
#        -108.18461161, -106.62933951])

# %%
# %%time

# Creating WaDE Custom water source native ID for easy water source identification
# Change 'outstring' name to be state specific.
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceName'] == A) & 
                                       (dfWaterSourceNativeID['in_WaterSourceTypeCV'] == B), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# Wall time: 1min 19s
# array(['wadeID1', '', 'wadeID3', 'wadeID4', 'wadeID5', 'wadeID6',
#        'wadeID7', 'wadeID8', 'wadeID9', 'wadeID10', 'wadeID11',
#        'wadeID12', 'wadeID13', 'wadeID14', 'wadeID15', 'wadeID16',
#        'wadeID17', 'wadeID18', 'wadeID19', 'wadeID20', 'wadeID21',
#        'wadeID22', 'wadeID23', 'wadeID24', 'wadeID25', 'wadeID26',
#        'wadeID27', 'wadeID28', 'wadeID29', 'wadeID30', 'wadeID31',
#        'wadeID32', 'wadeID33', 'wadeID34', 'wadeID35', 'wadeID36',
#        'wadeID37', 'wadeID38', 'wadeID39', 'wadeID40', 'wadeID41',
#        'wadeID42', 'wadeID43', 'wadeID44', 'wadeID45', 'wadeID46',
#        'wadeID47', 'wadeID48', 'wadeID49', 'wadeID50', 'wadeID51',
#        'wadeID52', 'wadeID53', 'wadeID54', 'wadeID55', 'wadeID56',
#        'wadeID57', 'wadeID58', 'wadeID59', 'wadeID60', 'wadeID61',
#        'wadeID62', 'wadeID63', 'wadeID64', 'wadeID65', 'wadeID66',
#        'wadeID67', 'wadeID68', 'wadeID69', 'wadeID70', 'wadeID71',
#        'wadeID72', 'wadeID73', 'wadeID74', 'wadeID75', 'wadeID76',
#        'wadeID77', 'wadeID78', 'wadeID79', 'wadeID80', 'wadeID81',
#        'wadeID82', 'wadeID83', 'wadeID84', 'wadeID85', 'wadeID86',
#        'wadeID87', 'wadeID88', 'wadeID89', 'wadeID90', 'wadeID91',
#        'wadeID92', 'wadeID93', 'wadeID94', 'wadeID95', 'wadeID96',
#        'wadeID97', 'wadeID98', 'wadeID99', 'wadeID100', 'wadeID101',
#        'wadeID102', 'wadeID103', 'wadeID104', 'wadeID105', 'wadeID106',
#        'wadeID107', 'wadeID108', 'wadeID109', 'wadeID110', 'wadeID111',
#        'wadeID112', 'wadeID113', 'wadeID114', 'wadeID115', 'wadeID116',
#        'wadeID117', 'wadeID118', 'wadeID119', 'wadeID120', 'wadeID121',
#        'wadeID122', 'wadeID123', 'wadeID124', 'wadeID125', 'wadeID126',
#        'wadeID127', 'wadeID128', 'wadeID129', 'wadeID130', 'wadeID131',
#        'wadeID132', 'wadeID133', 'wadeID134', 'wadeID135', 'wadeID136',
#        'wadeID137', 'wadeID138', 'wadeID139', 'wadeID140', 'wadeID141',
#        'wadeID142', 'wadeID143', 'wadeID144', 'wadeID145', 'wadeID146',
#        'wadeID147', 'wadeID148', 'wadeID149', 'wadeID150', 'wadeID151',
#        'wadeID152', 'wadeID153', 'wadeID154', 'wadeID155', 'wadeID156',
#        'wadeID157', 'wadeID158', 'wadeID159', 'wadeID160', 'wadeID161',
#        'wadeID162', 'wadeID163', 'wadeID164', 'wadeID165', 'wadeID166',
#        'wadeID167', 'wadeID168', 'wadeID169', 'wadeID170', 'wadeID171',
#        'wadeID172', 'wadeID173', 'wadeID174', 'wadeID175', 'wadeID176',
#        'wadeID177', 'wadeID178', 'wadeID179', 'wadeID180', 'wadeID181',
#        'wadeID182', 'wadeID183', 'wadeID184', 'wadeID185', 'wadeID186',
#        'wadeID187', 'wadeID188', 'wadeID189', 'wadeID190', 'wadeID191',
#        'wadeID192', 'wadeID193', 'wadeID194', 'wadeID195', 'wadeID196',
#        'wadeID197', 'wadeID198', 'wadeID199', 'wadeID200', 'wadeID201',
#        'wadeID202', 'wadeID203', 'wadeID204', 'wadeID205', 'wadeID206',
#        'wadeID207', 'wadeID208', 'wadeID209', 'wadeID210', 'wadeID211',
#        'wadeID212', 'wadeID213', 'wadeID214', 'wadeID215', 'wadeID216',
#        'wadeID217', 'wadeID218', 'wadeID219', 'wadeID220', 'wadeID221',
#        'wadeID222', 'wadeID223', 'wadeID224', 'wadeID225', 'wadeID226',
#        'wadeID227', 'wadeID228', 'wadeID229', 'wadeID230', 'wadeID231',
#        'wadeID232', 'wadeID233', 'wadeID234', 'wadeID235', 'wadeID236',
#        'wadeID237', 'wadeID238', 'wadeID239', 'wadeID240', 'wadeID241',
#        'wadeID242', 'wadeID243', 'wadeID244', 'wadeID245', 'wadeID246',
#        'wadeID247', 'wadeID248', 'wadeID249', 'wadeID250', 'wadeID251',
#        'wadeID252', 'wadeID253', 'wadeID254', 'wadeID255', 'wadeID256',
#        'wadeID257', 'wadeID258', 'wadeID259', 'wadeID260', 'wadeID261',
#        'wadeID262', 'wadeID263', 'wadeID264', 'wadeID265', 'wadeID266',
#        'wadeID267', 'wadeID268', 'wadeID269', 'wadeID270', 'wadeID271',
#        'wadeID272', 'wadeID273', 'wadeID274', 'wadeID275', 'wadeID276',
#        'wadeID277', 'wadeID278', 'wadeID279', 'wadeID280', 'wadeID281',
#        'wadeID282', 'wadeID283', 'wadeID284', 'wadeID285', 'wadeID286',
#        'wadeID287', 'wadeID288', 'wadeID289', 'wadeID290', 'wadeID291',
#        'wadeID292', 'wadeID293', 'wadeID294', 'wadeID295', 'wadeID296',
#        'wadeID297', 'wadeID298', 'wadeID299', 'wadeID300', 'wadeID301',
#        'wadeID302', 'wadeID303', 'wadeID304', 'wadeID305', 'wadeID306',
#        'wadeID307', 'wadeID308', 'wadeID309', 'wadeID310', 'wadeID311',
#        'wadeID312', 'wadeID313', 'wadeID314', 'wadeID315', 'wadeID316',
#        'wadeID317', 'wadeID318', 'wadeID319', 'wadeID320', 'wadeID321',
#        'wadeID322', 'wadeID323', 'wadeID324', 'wadeID325', 'wadeID326',
#        'wadeID327', 'wadeID328', 'wadeID329', 'wadeID330', 'wadeID331',
#        'wadeID332', 'wadeID333', 'wadeID334'], dtype=object)

# %% [markdown]
# ## Review and Export

# %%
outdf.dtypes
# Out:
# WaDEUUID                           object
# in_MethodUUID                      object
# in_VariableSpecificUUID            object
# in_OrganizationUUID                object
# in_Geometry                        object
#                                     ...
# in_PopulationServed                object
# in_PowerType                       object
# in_PrimaryBeneficialUseCategory    object
# in_SDWISIdentifierCV               object
# in_WaterAllocationNativeURL        object
# Length: 62, dtype: object

# %%
outdf
# Out:
#           WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0            nmwr0       NMwr_M1                 NMwr_V1             NMwr_O1
# 1            nmwr1       NMwr_M1                 NMwr_V1             NMwr_O1
# 2            nmwr2       NMwr_M1                 NMwr_V1             NMwr_O1
# 3            nmwr3       NMwr_M1                 NMwr_V1             NMwr_O1
# 4            nmwr4       NMwr_M1                 NMwr_V1             NMwr_O1
# ...            ...           ...                     ...                 ...
# 265646  nmwr265646       NMwr_M1                 NMwr_V1             NMwr_O1
# 265647  nmwr265647       NMwr_M1                 NMwr_V1             NMwr_O1
# 265648  nmwr265648       NMwr_M1                 NMwr_V1             NMwr_O1
# 265649  nmwr265649       NMwr_M1                 NMwr_V1             NMwr_O1
# 265650  nmwr265650       NMwr_M1                 NMwr_V1             NMwr_O1
#
#        in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...            ...                  ...                        ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                        wadeID1          Groundwater
# 1                                        wadeID1          Groundwater
# 2                                        wadeID1          Groundwater
# 3                                        wadeID1          Groundwater
# 4
# ...                   ...                    ...                  ...
# 265646     La Plata River              wadeID146        Surface Water
# 265647     La Plata River              wadeID146        Surface Water
# 265648    San Juan Area 1              wadeID136        Surface Water
# 265649
# 265650
#
#        in_CoordinateAccuracy in_CoordinateMethodCV in_County in_GNISCodeCV  \
# 0           WaDE Unspecified      WaDE Unspecified    Cibola
# 1           WaDE Unspecified      WaDE Unspecified    Cibola
# 2           WaDE Unspecified      WaDE Unspecified  Valencia
# 3           WaDE Unspecified      WaDE Unspecified    Cibola
# 4           WaDE Unspecified      WaDE Unspecified    Cibola
# ...                      ...                   ...       ...           ...
# 265646      WaDE Unspecified      WaDE Unspecified
# 265647      WaDE Unspecified      WaDE Unspecified
# 265648      WaDE Unspecified      WaDE Unspecified
# 265649      WaDE Unspecified      WaDE Unspecified  San Juan
# 265650      WaDE Unspecified      WaDE Unspecified  Dona Ana
#
#        in_HUC12 in_HUC8  in_Latitude  in_Longitude in_NHDNetworkStatusCV  \
# 0                           35.16272    -107.88224
# 1                           35.24814    -107.92330
# 2                           35.12528    -107.88125
# 3                           35.22996    -107.86800
# 4                           35.30136    -108.15312
# ...         ...     ...          ...           ...                   ...
# 265646                      37.23131    -107.71417
# 265647                      37.24542    -107.73214
# 265648                      37.00922    -107.40959
# 265649                      37.04209    -108.18461
# 265650                      31.97216    -106.62934
#
#        in_NHDProductCV in_PODorPOUSite                   in_SiteName  \
# 0                                  POD
# 1                                  POD
# 2                                  POD
# 3                                  POD
# 4                                  POD
# ...                ...             ...                           ...
# 265646                             POD
# 265647                             POD
# 265648                             POD  Rosa Community Luceros Ditch
# 265649                             POD              Enterprise Ditch
# 265650                             POD
#
#          in_SiteNativeID in_SitePoint     in_SiteTypeCV in_StateCV  \
# 0                B-00928               WaDE Unspecified         NM
# 1        B-00017-EXPLORE               WaDE Unspecified         NM
# 2                B-00691               WaDE Unspecified         NM
# 3       B-00408-EXPLOR-4               WaDE Unspecified         NM
# 4                B-01077               WaDE Unspecified         NM
# ...                  ...          ...               ...        ...
# 265646        SP-02883-4               WaDE Unspecified         NM
# 265647        SP-02883-5               WaDE Unspecified         NM
# 265648          SD-06504               WaDE Unspecified         NM
# 265649          SD-05155               WaDE Unspecified         NM
# 265650    LRG-01782-POD2               WaDE Unspecified         NM
#
#        in_USGSSiteID in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...              ...                          ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                             ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...                  ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                         ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...                   ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                          Permit               B-00928
# 1                        Licensed               B-00017
# 2                          Permit               B-00691
# 3                          Permit               B-00408
# 4                         Expired               B-01077
# ...                           ...                   ...
# 265646                     Permit              SP-02883
# 265647                     Permit            SP-02883-C
# 265648                Adjudicated            SD-06504-3
# 265649                Adjudicated            SD-05155-4
# 265650                Declaration           LRG-01782-A
#
#                   in_AllocationOwner in_AllocationPriorityDate  \
# 0                  Bennie G Gallegos
# 1                 Tristate Assoc Inc
# 2                          Ron Jicha
# 3       United Nuclearhomestake Ptnr
# 4                    George Sherfick
# ...                              ...                       ...
# 265646     San Juan Water Commission
# 265647      San Juan Water Comission
# 265648             Mrs Juanita Miera
# 265649            Steven Kyle Gillen
# 265650              Connie J Neslage
#
#        in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                       ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0                                                                     3.00000
# 1                                                                  3295.54000
# 2                                                                     3.00000
# 3
# 4
# ...                            ...                 ...                    ...
# 265646                                                             8710.00000
# 265647                                                             6300.00000
# 265648                                                               42.50000
# 265649                                                               86.14000
# 265650
#
#                          in_BeneficialUseCategory  \
# 0                  72-12-1 domestic one household
# 1                                      Industrial
# 2                  72-12-1 domestic one household
# 3                                     Exploration
# 4                  72-12-1 domestic one household
# ...                                           ...
# 265646                                 Irrigation
# 265647  Municipal - city or county supplied water
# 265648                                 Irrigation
# 265649                                 Irrigation
# 265650                                 Irrigation
#
#        in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...           ...               ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                   ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#         in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                   1
# 1                                   1
# 2                                   1
# 3                                   1
# 4                                   1
# ...                               ...                         ...
# 265646                              1
# 265647                              1
# 265648                              1
# 265649                              1
# 265650                              1
#
#        in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...                   ...                    ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                 ...          ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#        in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                ...                  ...
# 265646
# 265647
# 265648
# 265649
# 265650
#
#                               in_WaterAllocationNativeURL
# 0       http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 1       http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 2       http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 3       http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 4       http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# ...                                                   ...
# 265646  http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 265647  http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 265648  http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 265649  http://nmwrrs.ose.state.nm.us/ReportDispatcher...
# 265650  http://nmwrrs.ose.state.nm.us/ReportDispatcher...
#
# [265651 rows x 62 columns]

# %%
# Export the output dataframe
outdf.to_csv('RawInputData/Pwr_nmMain.zip', index=False, compression="zip")  # The output, save as a zip
