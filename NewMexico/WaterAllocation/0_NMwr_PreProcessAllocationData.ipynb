# %% [markdown]
# # Preprocessing New Mexico Allocation data for WaDEQA upload.
# - Purpose:  To preprocess the New Mexico data into one master file for simple DataFrame creation and extraction.

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x) # suppress scientific notation in Pandas

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/NewMexico/WaterAllocation/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ### OSE POD Data

# %%
# Input File - OSE POD data
df = pd.read_csv('OSE_PODs.zip', compression='zip')

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in df:
    df['WaDEUUID'] = "nmwr" + df.index.astype(str)
    df.to_csv('OSE_PODs.zip', compression=dict(method='zip', archive_name='OSE_PODs.csv'), index=False)

print(len(df))
df.head(1)
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_23112\3714400210.py:2: DtypeWarning: Columns (4,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('OSE_PODs.zip', compression='zip')
# 260149
#   WaDEUUID                                      ReasonRemoved  \
# 0    nmwr0  Unused Site Record,Incomplete or bad entry for...
#
#                                    IncompleteField pod_basin pod_nbr  \
# 0  Licensed,Adjudicated,Expired,Permit,Declaration         G    1904
#
#   pod_suffix ref pod_name  tws  rng sec qtr_4th qtr_16th qtr_64th blk zone  \
# 0                          13N  16W   9       1        4        3
#
#         x       y landgrant legal county start_date plug_date  elevation  \
# 0 0.00000 0.00000                     MK        NaN       NaN    0.00000
#
#    depth_well sched_date pump_type discharge aquifer                sys_date  \
# 0          25        NaN                              2003/11/04 00:00:00+00
#
#    restrict_  lat_deg  lat_min  lat_sec  lon_deg  lon_min  lon_sec pod_status  \
# 0    0.00000        0        0  0.00000        0        0  0.00000
#
#   ditch_name  utm_zone      easting      northing  datum utm_source xy_source  \
# 0                   13 178203.00000 3920141.00000  NAD83          G
#
#   tract_nbr map_nbr surv_map other_loc  cs_code  wrats_s_id utm_error  \
# 0                                             0           0
#
#   well_tag pod_file basin   nbr suffix sub_basin status use_  total_div  \
# 0           G-01904     G  1904                G    DCL  STK    1.00000
#
#   sub_file sf_header  db_file own_lname                 own_fname  \
# 0                     G-01904    BERGER  LAURENCE R. AND DIANA M.
#
#              addr1          addr2    city state    zip  in_state  \
# 0  REVOCABLE TRUST  406 BAKER AVE  GALLUP    NM  87301         1
#
#                 dump_date  loc_error  wr_count  replaced  OBJECTID_1  \
# 0  2022/05/31 00:00:00+00          0         1         0      134957
#
#    OBJECTID  license_nb              finish_dat pcw_rcv_da grnd_wtr_s  \
# 0    134957           0  1950/01/01 00:00:00+00        NaN
#
#    percent_sh  depth_wate log_file_d use_of_wel pump_seria subdiv_nam  \
# 0           0           0        NaN
#
#   subdiv_loc  surface_co  estimate_y  casing_siz utm_accura xy_accurac  \
# 0                      0           5     0.00000          0
#
#   lat_lon_so lat_lon_ac  pod_rec_nb cfs_start_ cfs_end_md  cfs_cnv_fa  \
# 0                     M      196552                           0.00000
#
#   pod_sub_ba  static_lev  sum_rec_nb contact_ln contact_fn  \
# 0          G           0      186627
#
#                                           nmwrrs_wrs
# 0  http://nmwrrs.ose.state.nm.us/ReportDispatcher...

# %%
#technique to check datatype of long dataframes.
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.dtypes)
# Out:
# WaDEUUID            object
# ReasonRemoved       object
# IncompleteField     object
# pod_basin           object
# pod_nbr             object
# pod_suffix          object
# ref                 object
# pod_name            object
# tws                 object
# rng                 object
# sec                 object
# qtr_4th             object
# qtr_16th            object
# qtr_64th            object
# blk                 object
# zone                object
# x                  float64
# y                  float64
# landgrant           object
# legal               object
# county              object
# start_date          object
# plug_date           object
# elevation          float64
# depth_well           int64
# sched_date          object
# pump_type           object
# discharge           object
# aquifer             object
# sys_date            object
# restrict_          float64
# lat_deg              int64
# lat_min              int64
# lat_sec            float64
# lon_deg              int64
# lon_min              int64
# lon_sec            float64
# pod_status          object
# ditch_name          object
# utm_zone             int64
# easting            float64
# northing           float64
# datum               object
# utm_source          object
# xy_source           object
# tract_nbr           object
# map_nbr             object
# surv_map            object
# other_loc           object
# cs_code              int64
# wrats_s_id           int64
# utm_error           object
# well_tag            object
# pod_file            object
# basin               object
# nbr                 object
# suffix              object
# sub_basin           object
# status              object
# use_                object
# total_div          float64
# sub_file            object
# sf_header           object
# db_file             object
# own_lname           object
# own_fname           object
# addr1               object
# addr2               object
# city                object
# state               object
# zip                 object
# in_state             int64
# dump_date           object
# loc_error            int64
# wr_count             int64
# replaced             int64
# OBJECTID_1           int64
# OBJECTID             int64
# license_nb           int64
# finish_dat          object
# pcw_rcv_da          object
# grnd_wtr_s          object
# percent_sh           int64
# depth_wate           int64
# log_file_d          object
# use_of_wel          object
# pump_seria          object
# subdiv_nam          object
# subdiv_loc          object
# surface_co           int64
# estimate_y           int64
# casing_siz         float64
# utm_accura          object
# xy_accurac          object
# lat_lon_so          object
# lat_lon_ac          object
# pod_rec_nb           int64
# cfs_start_          object
# cfs_end_md          object
# cfs_cnv_fa         float64
# pod_sub_ba          object
# static_lev           int64
# sum_rec_nb           int64
# contact_ln          object
# contact_fn          object
# nmwrrs_wrs          object
# dtype: object

# %%
print("Project to longitude/ latitude ")

from pyproj import transform, Proj

df = df.assign(in_Longitude='')
df = df.assign(in_Latitude='')

utmProj = Proj(init="epsg:26913", proj="utm", zone=13)

lonList = []
latList = []

#for ix in range(len(df100.index)):
for ix in range(len(df.index)):
    #print(ix)
    x1 = df.loc[ix, 'easting']
    y1 = df.loc[ix, 'northing']
    try:
        lon, lat = utmProj(float(x1), float(y1), inverse=True)
        lonList.append(lon)
        latList.append(lat)
    except:
        lonList.append('')
        latList.append('')

df['in_Longitude'] = lonList
df['in_Latitude'] = latList
df.head(3)
# Out:
# Project to longitude/ latitude
# C:\Users\rjame\anaconda3\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#   WaDEUUID                                      ReasonRemoved  \
# 0    nmwr0  Unused Site Record,Incomplete or bad entry for...
# 1    nmwr1  Unused Site Record,Incomplete or bad entry for...
# 2   nmwr10                          Unused WaterSource Record
#
#                                      IncompleteField pod_basin pod_nbr  \
# 0    Licensed,Adjudicated,Expired,Permit,Declaration         G    1904
# 1  Licensed,Adjudicated,Expired,Closed File,Permi...        CL     128
# 2                                                NaN        RG   68193
#
#   pod_suffix ref pod_name  tws  rng sec qtr_4th qtr_16th qtr_64th blk zone  \
# 0                          13N  16W   9       1        4        3
# 1       POD1               05S  36E  13       3        1        1
# 2                          12N  03E  26       2        1
#
#         x       y landgrant legal county              start_date plug_date  \
# 0 0.00000 0.00000                     MK                     NaN       NaN
# 1 0.00000 0.00000                     RO                     NaN       NaN
# 2 0.00000 0.00000                     SA  1800/01/01 00:00:00+00       NaN
#
#    elevation  depth_well sched_date pump_type discharge aquifer  \
# 0    0.00000          25        NaN
# 1    0.00000         180        NaN
# 2    0.00000          80        NaN
#
#                  sys_date  restrict_  lat_deg  lat_min  lat_sec  lon_deg  \
# 0  2003/11/04 00:00:00+00    0.00000        0        0  0.00000        0
# 1  2009/12/02 00:00:00+00    0.00000        0        0  0.00000        0
# 2  1997/08/01 00:00:00+00    0.00000        0        0  0.00000        0
#
#    lon_min  lon_sec pod_status ditch_name  utm_zone      easting  \
# 0        0  0.00000                              13 178203.00000
# 1        0  0.00000                              13 673387.00000
# 2        0  0.00000                              13 355053.00000
#
#        northing  datum utm_source xy_source tract_nbr map_nbr surv_map  \
# 0 3920141.00000  NAD83          G
# 1 3749476.00000  NAD83          G
# 2 3901383.00000  NAD83          G                 44A      15    MRGCD
#
#   other_loc  cs_code  wrats_s_id utm_error well_tag       pod_file basin  \
# 0                  0           0                           G-01904     G
# 1                  0           0                     CL-00128-POD1    CL
# 2                  0           0                          RG-68193    RG
#
#      nbr suffix sub_basin status use_  total_div sub_file sf_header   db_file  \
# 0   1904                G    DCL  STK    1.00000                      G-01904
# 1    128               CL    PMT  IRR  120.00000                     CL-00128
# 2  68193              MRG    DCL  IRR   16.52500                     RG-68193
#
#    own_lname                 own_fname                    addr1  \
# 0     BERGER  LAURENCE R. AND DIANA M.          REVOCABLE TRUST
# 1     WATSON                   KODDY D  2326 S ROOSEVELT ROAD L
# 2  TARGHETTA                   ROBERTA            P. O. BOX 433
#
#            addr2      city state    zip  in_state               dump_date  \
# 0  406 BAKER AVE    GALLUP    NM  87301         1  2022/05/31 00:00:00+00
# 1                   ROGERS    NM  88132         1  2022/05/31 00:00:00+00
# 2                 CORRALES    NM  87048         1  2022/05/31 00:00:00+00
#
#    loc_error  wr_count  replaced  OBJECTID_1  OBJECTID  license_nb  \
# 0          0         1         0      134957    134957           0
# 1          0         1         0      156596    156596           0
# 2          0         1         0       74049     74049           0
#
#                finish_dat pcw_rcv_da grnd_wtr_s  percent_sh  depth_wate  \
# 0  1950/01/01 00:00:00+00        NaN                      0           0
# 1  1950/12/31 00:00:00+00        NaN                      0           0
# 2  1800/01/01 00:00:00+00        NaN          S         100           8
#
#   log_file_d  use_of_wel pump_seria subdiv_nam subdiv_loc  surface_co  \
# 0        NaN                                                        0
# 1        NaN                                                        0
# 2        NaN  IRRIGATION                                            0
#
#    estimate_y  casing_siz utm_accura xy_accurac lat_lon_so lat_lon_ac  \
# 0           5     0.00000          0                                M
# 1           0    16.00000
# 2           0     2.00000
#
#    pod_rec_nb cfs_start_ cfs_end_md  cfs_cnv_fa pod_sub_ba  static_lev  \
# 0      196552                           0.00000          G           0
# 1      223552                           0.00000         CL           0
# 2      105170                           0.00000        MRG           0
#
#    sum_rec_nb contact_ln contact_fn  \
# 0      186627
# 1      220177
# 2      103768
#
#                                           nmwrrs_wrs  in_Longitude  \
# 0  http://nmwrrs.ose.state.nm.us/ReportDispatcher...    -108.54187
# 1  http://nmwrrs.ose.state.nm.us/ReportDispatcher...    -103.12541
# 2  http://nmwrrs.ose.state.nm.us/ReportDispatcher...    -106.59313
#
#    in_Latitude
# 0     35.37273
# 1     33.87138
# 2     35.24506

# %%
print ("SiteName...")

# For creating assignSiteName
def assignSiteName(val):
    val = str(val).strip()
    if val == '' or val == ' ' or pd.isnull(val):
        outString = 'WaDE Unspecified'
    else:
        outString = val
    return outString

df['in_SiteName'] = df.apply(lambda row: assignSiteName(row['ditch_name']), axis=1)
df['in_SiteName'].unique()
# Out:
# SiteName...
# array(['WaDE Unspecified', 'BENADO SPRING', '2', ..., 'MAXWELL DITCH',
#        'ESTES & EGBERT NO. 1 N DITCH', 'MILLIKEN NO. 1 N DITCH ENLARGE'],
#       dtype=object)

# %%
print ("Water source type")

df.assign(GroundWaterSourceTypeCV='')
df.assign(SurfaceWaterSourceTypeCV='')

df["GroundWaterSourceTypeCV"] = df.apply(lambda row: 'Groundwater' 
                                             if str(row["grnd_wtr_s"]).strip() != '' 
                                             else '', axis=1)
df["SurfaceWaterSourceTypeCV"] = df.apply(lambda row: 'Surface Water' 
                                              if int(row["surface_co"]) > 0 
                                              else '', axis=1)



df.assign(WaterSourceTypeCV='')

waterSourceList = []
for index, row in df.iterrows():
    #print(index)
    groundWatetrStr = row['GroundWaterSourceTypeCV']
    surfaceWatetrStr = row['SurfaceWaterSourceTypeCV']
    if (groundWatetrStr != '') & (surfaceWatetrStr != ''):
        waterSourceList.append("Surface and Groundwater")
    elif groundWatetrStr != '':
        waterSourceList.append(groundWatetrStr)
    elif surfaceWatetrStr != '':
        waterSourceList.append(surfaceWatetrStr)
    else:
        waterSourceList.append("WaDE Unspecified")

df['in_WaterSourceTypeCV'] = waterSourceList
df['in_WaterSourceTypeCV'].unique()
# Out:
# Water source type
# array(['WaDE Unspecified', 'Groundwater', 'Surface Water',
#        'Surface and Groundwater'], dtype=object)

# %%
#WaterSourceName

waterSourceDict = {
"1":"ABBOT CREEK",
"2":"ABBOTT LAKE",
"3":"ABIQUIU CREEK",
"4":"ABIQUIU RESERVOIR",
"5":"ABO ARROYO",
"6":"ADAMS CANYON",
"7":"AGUA CALIENTE",
"8":"AGUA CHIQUITA CREEK",
"9":"AGUA FRIA CREEK",
"10":"AGUA FRIA CREEK",
"11":"AGUA FRIA CREEK /N",
"12":"AGUA LIMPIA /N",
"13":"AGUA MEDIA",
"14":"AGUA NEGRA RIVER /N",
"15":"AGUA OLYMPIA",
"16":"AGUA SARCA",
"17":"AGUAJE ARROYO /NM",
"18":"AGUILA CANYON",
"19":"AHOGADERO CREEK",
"20":"ALAMAGORDO RESERVOIR",
"21":"ALAMITO CREEK",
"1672":"WHISKEY CREEK",
"1673":"WHITE DEER CANYON",
"1674":"WHITE HORSE DRAW",
"1675":"WHITE LAKE",
"1676":"WHITE OAKS CANYON",
"1677":"WHITE ROCK CANYON",
"1678":"WHITEROCK CANYON",
"1679":"WHITES DRAW",
"1680":"WHITEWATER ARROYO",
"1681":"WHITEWATER CANYON",
"1682":"WHITEWATER CANYON",
"1683":"WHITEWATER CREEK",
"1684":"WHITEWATER CREEK",
"1685":"WHITEWATER CREEK",
"1686":"WHITMIRE CREEK",
"1687":"WILD HORSE CANYON",
"1688":"WILD HORSE CANYON /N",
"1689":"WILDCAN CANYON",
"1690":"WILDHORSE CANYON",
"1691":"WILLIE WHITE CANYON",
"1692":"WILLOW CANYON",
"1693":"WILLOW CREEK",
"1694":"WILLOW CREEK",
"1695":"WILLOW CREEK /N",
"1696":"WILLOW CREEK /N",
"1697":"WILLOW DRAW",
"1698":"WILLOW DRAW",
"1699":"WILLOW LAKE",
"1700":"WILLOW SPRING DRAW",
"1701":"WILLS CANYON",
"1702":"WILSON CANYON",
"1703":"WILSON CREEK",
"1704":"WIND CANYON",
"1705":"WIND MOUNTAIN DRAW",
"1706":"WINDHAM CANYON",
"1707":"WINN CANYON",
"1708":"WOLF CREEK",
"1709":"WOOD CANYON",
"1710":"WOOD CANYON",
"1711":"WOOD CANYON",
"1712":"WOODROW ARROYO /N",
"1713":"WOOTEN CANYON",
"1714":"WRIGHT CANYON /NM",
"1715":"WYLIE DRAW",
"1716":"WYNN CREEK",
"1717":"YANKEE CREEK /N",
"1718":"YELLOW POINT VALLEY",
"1719":"YESO CREEK",
"1720":"YL CANYON",
"1721":"YOAST DRAW",
"1722":"YORK CANYON",
"1723":"YOUNG CANYON",
"1724":"Z SLASH CANYON",
"1725":"ZEUFELDT ARROYO",
"1726":"ZUBER /N",
"1727":"ZUBER HOLLOW /N",
"1728":"ZUBI DRAW",
"1729":"ZUNI CANYON",
"1730":"ZUNI RIVER",
"1731":"BEAR SPRINGS CANYON",
"1732":"CHAVEZ CANYON",
"1733":"BEAR CANYON"}


def assignWaterSourceName(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = 'WaDE Unspecified'
    else:
        String1 = str(colrowValue)
        String1 = String1.strip()  # remove whitespace chars
        try:
            outList = waterSourceDict[String1]
        except:
            outList = 'WaDE Unspecified'
    return outList

df['in_WaterSourceName'] = df.apply(lambda row: assignWaterSourceName(row['surface_co']), axis=1)
df.head(3)
# Out:
#   WaDEUUID                                      ReasonRemoved  \
# 0    nmwr0  Unused Site Record,Incomplete or bad entry for...
# 1    nmwr1  Unused Site Record,Incomplete or bad entry for...
# 2   nmwr10                          Unused WaterSource Record
#
#                                      IncompleteField pod_basin pod_nbr  \
# 0    Licensed,Adjudicated,Expired,Permit,Declaration         G    1904
# 1  Licensed,Adjudicated,Expired,Closed File,Permi...        CL     128
# 2                                                NaN        RG   68193
#
#   pod_suffix ref pod_name  tws  rng sec qtr_4th qtr_16th qtr_64th blk zone  \
# 0                          13N  16W   9       1        4        3
# 1       POD1               05S  36E  13       3        1        1
# 2                          12N  03E  26       2        1
#
#         x       y landgrant legal county              start_date plug_date  \
# 0 0.00000 0.00000                     MK                     NaN       NaN
# 1 0.00000 0.00000                     RO                     NaN       NaN
# 2 0.00000 0.00000                     SA  1800/01/01 00:00:00+00       NaN
#
#    elevation  depth_well sched_date pump_type discharge aquifer  \
# 0    0.00000          25        NaN
# 1    0.00000         180        NaN
# 2    0.00000          80        NaN
#
#                  sys_date  restrict_  lat_deg  lat_min  lat_sec  lon_deg  \
# 0  2003/11/04 00:00:00+00    0.00000        0        0  0.00000        0
# 1  2009/12/02 00:00:00+00    0.00000        0        0  0.00000        0
# 2  1997/08/01 00:00:00+00    0.00000        0        0  0.00000        0
#
#    lon_min  lon_sec pod_status ditch_name  utm_zone      easting  \
# 0        0  0.00000                              13 178203.00000
# 1        0  0.00000                              13 673387.00000
# 2        0  0.00000                              13 355053.00000
#
#        northing  datum utm_source xy_source tract_nbr map_nbr surv_map  \
# 0 3920141.00000  NAD83          G
# 1 3749476.00000  NAD83          G
# 2 3901383.00000  NAD83          G                 44A      15    MRGCD
#
#   other_loc  cs_code  wrats_s_id utm_error well_tag       pod_file basin  \
# 0                  0           0                           G-01904     G
# 1                  0           0                     CL-00128-POD1    CL
# 2                  0           0                          RG-68193    RG
#
#      nbr suffix sub_basin status use_  total_div sub_file sf_header   db_file  \
# 0   1904                G    DCL  STK    1.00000                      G-01904
# 1    128               CL    PMT  IRR  120.00000                     CL-00128
# 2  68193              MRG    DCL  IRR   16.52500                     RG-68193
#
#    own_lname                 own_fname                    addr1  \
# 0     BERGER  LAURENCE R. AND DIANA M.          REVOCABLE TRUST
# 1     WATSON                   KODDY D  2326 S ROOSEVELT ROAD L
# 2  TARGHETTA                   ROBERTA            P. O. BOX 433
#
#            addr2      city state    zip  in_state               dump_date  \
# 0  406 BAKER AVE    GALLUP    NM  87301         1  2022/05/31 00:00:00+00
# 1                   ROGERS    NM  88132         1  2022/05/31 00:00:00+00
# 2                 CORRALES    NM  87048         1  2022/05/31 00:00:00+00
#
#    loc_error  wr_count  replaced  OBJECTID_1  OBJECTID  license_nb  \
# 0          0         1         0      134957    134957           0
# 1          0         1         0      156596    156596           0
# 2          0         1         0       74049     74049           0
#
#                finish_dat pcw_rcv_da grnd_wtr_s  percent_sh  depth_wate  \
# 0  1950/01/01 00:00:00+00        NaN                      0           0
# 1  1950/12/31 00:00:00+00        NaN                      0           0
# 2  1800/01/01 00:00:00+00        NaN          S         100           8
#
#   log_file_d  use_of_wel pump_seria subdiv_nam subdiv_loc  surface_co  \
# 0        NaN                                                        0
# 1        NaN                                                        0
# 2        NaN  IRRIGATION                                            0
#
#    estimate_y  casing_siz utm_accura xy_accurac lat_lon_so lat_lon_ac  \
# 0           5     0.00000          0                                M
# 1           0    16.00000
# 2           0     2.00000
#
#    pod_rec_nb cfs_start_ cfs_end_md  cfs_cnv_fa pod_sub_ba  static_lev  \
# 0      196552                           0.00000          G           0
# 1      223552                           0.00000         CL           0
# 2      105170                           0.00000        MRG           0
#
#    sum_rec_nb contact_ln contact_fn  \
# 0      186627
# 1      220177
# 2      103768
#
#                                           nmwrrs_wrs  in_Longitude  \
# 0  http://nmwrrs.ose.state.nm.us/ReportDispatcher...    -108.54187
# 1  http://nmwrrs.ose.state.nm.us/ReportDispatcher...    -103.12541
# 2  http://nmwrrs.ose.state.nm.us/ReportDispatcher...    -106.59313
#
#    in_Latitude       in_SiteName GroundWaterSourceTypeCV  \
# 0     35.37273  WaDE Unspecified
# 1     33.87138  WaDE Unspecified
# 2     35.24506  WaDE Unspecified             Groundwater
#
#   SurfaceWaterSourceTypeCV in_WaterSourceTypeCV in_WaterSourceName
# 0                              WaDE Unspecified   WaDE Unspecified
# 1                              WaDE Unspecified   WaDE Unspecified
# 2                                   Groundwater   WaDE Unspecified

# %%
#Creating Owner

def assignownerName(colrowValue1, colrowValue2):
    if colrowValue1 == '' or pd.isnull(colrowValue1):
        outList1 = ''
    else:
        outList1 = colrowValue1.strip()  # remove whitespace chars
    if colrowValue2 == '' or pd.isnull(colrowValue2):
        outList2 = ''
    else:
        outList2 = colrowValue2.strip()  # remove whitespace chars

    if outList1 == '' and outList2 == '':
        outList = ''
    elif outList1 == '':
        outList = outList2
    elif outList2 == '':
        outList = outList1
    else:
        outList = " ".join(map(str, [colrowValue1, colrowValue2]))
    return outList

df['in_AllocationOwner'] = df.apply(lambda row: assignownerName(row['own_fname'], row['own_lname']), axis=1)



#clean owner name
import re

def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).strip()
    return Val

df['in_AllocationOwner'] = df.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)

df['in_AllocationOwner'].unique()
# Out:
# array(['LAURENCE R AND DIANA M BERGER', 'KODDY D WATSON',
#        'ROBERTA TARGHETTA', ..., 'CHRIS G RODRIGUEZ', 'JAN MARTIN',
#        'BILLY HULL'], dtype=object)

# %%
benUseDict = {
    "AGR":"Agriculture other than irrigation",
    "AUG":"Augmentation well",
    "BPW":"Brine production well",
    "CEM":"Cemetery",
    "CLS":"Closed file",
    "COM":"Commercial",
    "CON":"Construction",
    "CPS":"Cathodic protection well",
    "DAI":"Dairy operation",
    "DCN":"Domestic construction",
    "DEW":"Dewatering well",
    "DOL":"72-12-1 domestic and livestock watering",
    "DOM":"72-12-1 domestic one household",
    "EXP":"Exploration",
    "FCD":"Flood control",
    "FGP":"Fish and game propogation",
    "FPO":"Feed pen operation",
    "GEO":"Geothermal boreholes",
    "HWY":"Highway construction",
    "IND":"Industrial",
    "INJ":"Injection",
    "IRR":"Irrigation",
    "MDW":"Community type use",
    "MFG":"Manufacturing",
    "MIL":"Military - military installations",
    "MIN":"Mining or milling or oil",
    "MOB":"Mobile home parks",
    "MON":"Monitoring well",
    "MPP":"Meat packing plant",
    "MUL":"72-12-1 multiple domestic households",
    "MUN":"Municipal - city or county supplied water",
    "N07":"No pre-1907 water right exists on this land",
    "NON":"Non-profit organizational use",
    "NOT":"No use of right or POD",
    "NRT":"No right",
    "OBS":"Observation",
    "OFM":"Oil field maintenance",
    "OIL":"Oil production",
    "PDL":"Non 72-12-1 domestic and livestock watering",
    "PDM":"Non 72-12-1 domestic one household",
    "PLS":"Non 72-12-1 livestock watering",
    "PMH":"Non 72-12-1 multiple domestic households",
    "POL":"Pollution control well",
    "POU":"Poultry and egg operation",
    "PPP":"Petroleum processing plant",
    "PRO":"72-12-1 Prospecting or development of natural resource",
    "PUB":"72-12-1 Construction of public works",
    "REC":"Recreation",
    "SAN":"72-12-1 Sanitary in conjunction with a commercial use",
    "SCH":"School use",
    "SRO":"Secondary recovery of oil",
    "STK":"72-12-1 livestock watering",
    "STO":"Storage",
    "STR":"Strategic water reserve",
    "SUB":"Subdivision",
    "SWR":"Stacked water right",
    "TBD":"To be determined",
    "UTL":"Public utility"}


def assignBenUseCategory(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = 'WaDE Unspecified'
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = benUseDict[String1]
        except:
            outList = 'WaDE Unspecified'
    return outList

df['in_BeneficialUseCategory'] = df.apply(lambda row: assignBenUseCategory(row['use_']), axis=1)
df['in_BeneficialUseCategory'].unique()
# Out:
# array(['72-12-1 livestock watering', 'Irrigation',
#        '72-12-1 domestic one household',
#        '72-12-1 Sanitary in conjunction with a commercial use',
#        'WaDE Unspecified', '72-12-1 multiple domestic households',
#        '72-12-1 Prospecting or development of natural resource',
#        '72-12-1 domestic and livestock watering', 'Closed file',
#        'Non 72-12-1 livestock watering', 'No use of right or POD',
#        'Recreation', 'Secondary recovery of oil', 'Subdivision',
#        'No right', 'Exploration',
#        'Non 72-12-1 domestic and livestock watering', 'Industrial',
#        'Non 72-12-1 multiple domestic households', 'School use',
#        'Commercial', 'Non 72-12-1 domestic one household',
#        '72-12-1 Construction of public works',
#        'Municipal - city or county supplied water', 'Monitoring well',
#        'Highway construction', 'Community type use',
#        'Pollution control well', 'Dairy operation',
#        'Agriculture other than irrigation', 'Oil production',
#        'Construction', 'Fish and game propogation', 'Storage',
#        'Non-profit organizational use', 'Mining or milling or oil',
#        'Military - military installations', 'Injection',
#        'Mobile home parks', 'Feed pen operation', 'Observation',
#        'Domestic construction', 'Public utility', 'Flood control',
#        'Strategic water reserve', 'Oil field maintenance',
#        'Poultry and egg operation', 'Stacked water right',
#        'Dewatering well', 'Augmentation well', 'Cathodic protection well',
#        'Geothermal boreholes', 'Brine production well',
#        'To be determined', 'Manufacturing', 'Cemetery',
#        'Meat packing plant', 'Petroleum processing plant'], dtype=object)

# %%
AllocationLegalStatusDictionaryNM = {
    "ADJ":"Adjudicated",
    "ADM":"Administrative",
    "APP":"Application",
    "APR":"Application Being Protested",
    "CAN":"Cancelled",
    "CLS":"Closed File",
    "DCL":"Declaration",
    "DED":"Dedicated",
    "DEN":"Denied",
    "EXP":"Expired",
    "HS ":"Hydrographic Survey",
    "LIC":"Licensed",
    "NOI":"Notice of Intention",
    "NOT":"Not implies that there is no status",
    "OMS":"Owner Management Status",
    "OOJ":"Offer of Judgment",
    "PBU":"Proof of Beneficial Use",
    "PMT":"Permit",
    "PRG":"Purged Conversion Record",
    "REN":"Renumbered",
    "RET":"Retired",
    "TRN":"Transferred",
    "WMS":"Water Master Status",
    "WTD":"Withdrawn"    
}


def assignLegalStatus(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = 'WaDE Unspecified'
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = AllocationLegalStatusDictionaryNM[String1]
        except:
            outList = 'WaDE Unspecified'
    return outList

df['in_AllocationLegalStatusCV'] = df.apply(lambda row: assignLegalStatus(row['status']), axis=1)
df['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Declaration', 'Permit', 'Adjudicated', 'Licensed', 'Closed File',
#        'Expired', 'WaDE Unspecified', 'Owner Management Status',
#        'Application', 'Offer of Judgment', 'Cancelled',
#        'Not implies that there is no status', 'Notice of Intention',
#        'Transferred', 'Denied', 'Withdrawn', 'Renumbered',
#        'Purged Conversion Record', 'Dedicated', 'Administrative',
#        'Water Master Status', 'Retired'], dtype=object)

# %%
# Creating the output Dataframe for PODs.

dfPOD = pd.DataFrame(index=df.index)

# Data Assessment UUID
dfPOD['WaDEUUID'] = df['WaDEUUID']

# Water Source
dfPOD["in_WaterSourceName"] = df['in_WaterSourceName']
dfPOD["in_WaterSourceTypeCV"] = df['in_WaterSourceTypeCV']

# Site
dfPOD["in_CoordinateAccuracy"] = "WaDE Unspecified"
dfPOD["in_CoordinateMethodCV"] = "WaDE Unspecified"
dfPOD['in_HUC12'] = ""
dfPOD['in_HUC8'] = ""
dfPOD['in_County'] = ""
dfPOD["in_Latitude"] = df['in_Latitude']
dfPOD["in_Longitude"] = df['in_Longitude']
dfPOD["in_PODorPOUSite"] = "POD"
dfPOD["in_SiteName"] = df['in_SiteName']
dfPOD["in_SiteNativeID"] = "" # make custom below
dfPOD["in_SiteTypeCV"] = "WaDE Unspecified"
dfPOD["in_StateCV"] = "NM"

# Allocation
dfPOD["in_AllocationFlow_CFS"] = ""
dfPOD["in_AllocationVolume_AF"] = df['restrict_'].astype(float)
dfPOD['in_AllocationLegalStatusCV'] = df['in_AllocationLegalStatusCV']
dfPOD["in_AllocationNativeID"] = df['nbr']
dfPOD['in_AllocationOwner'] = df['in_AllocationOwner']
dfPOD['in_AllocationPriorityDate'] = ""
dfPOD['in_AllocationTimeframeEnd'] = ""
dfPOD['in_AllocationTimeframeStart'] = ""
dfPOD['in_AllocationTypeCV'] = ""
dfPOD["in_BeneficialUseCategory"] = df['in_BeneficialUseCategory']  #see above
dfPOD['in_CommunityWaterSupplySystem'] = ""
dfPOD['in_ExemptOfVolumeFlowPriority'] = "1" # we want this data excempt
dfPOD["in_IrrigatedAcreage"] = df['total_div']
dfPOD["in_IrrigationMethodCV"] = "WaDE Unspecified"
dfPOD["in_WaterAllocationNativeURL"] = df['nmwrrs_wrs']

dfPOD = dfPOD.drop_duplicates().reset_index(drop=True)
print(len(dfPOD))
dfPOD.head(1)
# Out:
# 260149
#   WaDEUUID in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0    nmwr0   WaDE Unspecified     WaDE Unspecified      WaDE Unspecified
#
#   in_CoordinateMethodCV in_HUC12 in_HUC8 in_County  in_Latitude  in_Longitude  \
# 0      WaDE Unspecified                                35.37273    -108.54187
#
#   in_PODorPOUSite       in_SiteName in_SiteNativeID     in_SiteTypeCV  \
# 0             POD  WaDE Unspecified                  WaDE Unspecified
#
#   in_StateCV in_AllocationFlow_CFS  in_AllocationVolume_AF  \
# 0         NM                                       0.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                Declaration                  1904
#
#               in_AllocationOwner in_AllocationPriorityDate  \
# 0  LAURENCE R AND DIANA M BERGER
#
#   in_AllocationTimeframeEnd in_AllocationTimeframeStart in_AllocationTypeCV  \
# 0
#
#      in_BeneficialUseCategory in_CommunityWaterSupplySystem  \
# 0  72-12-1 livestock watering
#
#   in_ExemptOfVolumeFlowPriority  in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0                             1              1.00000      WaDE Unspecified
#
#                          in_WaterAllocationNativeURL
# 0  http://nmwrrs.ose.state.nm.us/ReportDispatcher...

# %% [markdown]
# ## WaDE Custom Elements (due to missing sate info)

# %%
# Making Sure datatype of Long, Lat, Wrex, Irrigation are Float
dfPOD['in_AllocationVolume_AF'] = pd.to_numeric(dfPOD['in_AllocationVolume_AF'], errors='coerce')
dfPOD['in_AllocationVolume_AF'].unique()
# Out:
# array([  0.  ,   1.5 ,   3.  , ..., 145.05,  58.1 ,  42.19])

# %%
# %%time

# Creating WaDE Custom water source native ID for easy water source identification
# Change 'outstring' name to be state specific.
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDENM_WS" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = dfPOD['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = dfPOD['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceName'] == A) & 
                                       (dfWaterSourceNativeID['in_WaterSourceTypeCV'] == B), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfPOD['in_WaterSourceNativeID'] = dfPOD.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
dfPOD['in_WaterSourceNativeID'].unique()
# Out:
# Wall time: 1min 52s
# array(['WaDENM_WS1', 'WaDENM_WS2', 'WaDENM_WS3', 'WaDENM_WS4',
#        'WaDENM_WS5', 'WaDENM_WS6', 'WaDENM_WS7', 'WaDENM_WS8',
#        'WaDENM_WS9', 'WaDENM_WS10', 'WaDENM_WS11', 'WaDENM_WS12',
#        'WaDENM_WS13', 'WaDENM_WS14', 'WaDENM_WS15', 'WaDENM_WS16',
#        'WaDENM_WS17', 'WaDENM_WS18', 'WaDENM_WS19', 'WaDENM_WS20',
#        'WaDENM_WS21', 'WaDENM_WS22', 'WaDENM_WS23', 'WaDENM_WS24',
#        'WaDENM_WS25', 'WaDENM_WS26', 'WaDENM_WS27', 'WaDENM_WS28',
#        'WaDENM_WS29', 'WaDENM_WS30', 'WaDENM_WS31', 'WaDENM_WS32',
#        'WaDENM_WS33', 'WaDENM_WS34', 'WaDENM_WS35', 'WaDENM_WS36',
#        'WaDENM_WS37', 'WaDENM_WS38', 'WaDENM_WS39', 'WaDENM_WS40',
#        'WaDENM_WS41', 'WaDENM_WS42', 'WaDENM_WS43', 'WaDENM_WS44',
#        'WaDENM_WS45', 'WaDENM_WS46', 'WaDENM_WS47', 'WaDENM_WS48',
#        'WaDENM_WS49', 'WaDENM_WS50', 'WaDENM_WS51', 'WaDENM_WS52',
#        'WaDENM_WS53', 'WaDENM_WS54', 'WaDENM_WS55', 'WaDENM_WS56',
#        'WaDENM_WS57', 'WaDENM_WS58', 'WaDENM_WS59', 'WaDENM_WS60',
#        'WaDENM_WS61', 'WaDENM_WS62', 'WaDENM_WS63', 'WaDENM_WS64',
#        'WaDENM_WS65', 'WaDENM_WS66', 'WaDENM_WS67', 'WaDENM_WS68',
#        'WaDENM_WS69', 'WaDENM_WS70', 'WaDENM_WS71', 'WaDENM_WS72',
#        'WaDENM_WS73', 'WaDENM_WS74', 'WaDENM_WS75', 'WaDENM_WS76',
#        'WaDENM_WS77', 'WaDENM_WS78', 'WaDENM_WS79', 'WaDENM_WS80',
#        'WaDENM_WS81', 'WaDENM_WS82', 'WaDENM_WS83', 'WaDENM_WS84',
#        'WaDENM_WS85', 'WaDENM_WS86', 'WaDENM_WS87', 'WaDENM_WS88',
#        'WaDENM_WS89', 'WaDENM_WS90', 'WaDENM_WS91', 'WaDENM_WS92',
#        'WaDENM_WS93', 'WaDENM_WS94', 'WaDENM_WS95', 'WaDENM_WS96',
#        'WaDENM_WS97', 'WaDENM_WS98', 'WaDENM_WS99', 'WaDENM_WS100',
#        'WaDENM_WS101', 'WaDENM_WS102', 'WaDENM_WS103', 'WaDENM_WS104',
#        'WaDENM_WS105', 'WaDENM_WS106', 'WaDENM_WS107', 'WaDENM_WS108',
#        'WaDENM_WS109', 'WaDENM_WS110', 'WaDENM_WS111', 'WaDENM_WS112',
#        'WaDENM_WS113', 'WaDENM_WS114', 'WaDENM_WS115', 'WaDENM_WS116',
#        'WaDENM_WS117', 'WaDENM_WS118', 'WaDENM_WS119', 'WaDENM_WS120',
#        'WaDENM_WS121', 'WaDENM_WS122', 'WaDENM_WS123', 'WaDENM_WS124',
#        'WaDENM_WS125', 'WaDENM_WS126', 'WaDENM_WS127', 'WaDENM_WS128',
#        'WaDENM_WS129', 'WaDENM_WS130', 'WaDENM_WS131', 'WaDENM_WS132',
#        'WaDENM_WS133', 'WaDENM_WS134', 'WaDENM_WS135', 'WaDENM_WS136',
#        'WaDENM_WS137', 'WaDENM_WS138', 'WaDENM_WS139', 'WaDENM_WS140',
#        'WaDENM_WS141', 'WaDENM_WS142', 'WaDENM_WS143', 'WaDENM_WS144',
#        'WaDENM_WS145', 'WaDENM_WS146', 'WaDENM_WS147', 'WaDENM_WS148',
#        'WaDENM_WS149', 'WaDENM_WS150', 'WaDENM_WS151', 'WaDENM_WS152',
#        'WaDENM_WS153', 'WaDENM_WS154', 'WaDENM_WS155', 'WaDENM_WS156',
#        'WaDENM_WS157', 'WaDENM_WS158', 'WaDENM_WS159', 'WaDENM_WS160',
#        'WaDENM_WS161', 'WaDENM_WS162', 'WaDENM_WS163', 'WaDENM_WS164',
#        'WaDENM_WS165', 'WaDENM_WS166', 'WaDENM_WS167', 'WaDENM_WS168',
#        'WaDENM_WS169', 'WaDENM_WS170', 'WaDENM_WS171', 'WaDENM_WS172',
#        'WaDENM_WS173', 'WaDENM_WS174', 'WaDENM_WS175', 'WaDENM_WS176',
#        'WaDENM_WS177', 'WaDENM_WS178', 'WaDENM_WS179', 'WaDENM_WS180',
#        'WaDENM_WS181', 'WaDENM_WS182', 'WaDENM_WS183', 'WaDENM_WS184',
#        'WaDENM_WS185', 'WaDENM_WS186', 'WaDENM_WS187', 'WaDENM_WS188',
#        'WaDENM_WS189', 'WaDENM_WS190', 'WaDENM_WS191', 'WaDENM_WS192',
#        'WaDENM_WS193', 'WaDENM_WS194', 'WaDENM_WS195', 'WaDENM_WS196',
#        'WaDENM_WS197', 'WaDENM_WS198', 'WaDENM_WS199', 'WaDENM_WS200',
#        'WaDENM_WS201', 'WaDENM_WS202', 'WaDENM_WS203', 'WaDENM_WS204',
#        'WaDENM_WS205', 'WaDENM_WS206', 'WaDENM_WS207', 'WaDENM_WS208',
#        'WaDENM_WS209', 'WaDENM_WS210', 'WaDENM_WS211', 'WaDENM_WS212',
#        'WaDENM_WS213', 'WaDENM_WS214', 'WaDENM_WS215', 'WaDENM_WS216',
#        'WaDENM_WS217', 'WaDENM_WS218', 'WaDENM_WS219', 'WaDENM_WS220',
#        'WaDENM_WS221', 'WaDENM_WS222', 'WaDENM_WS223', 'WaDENM_WS224',
#        'WaDENM_WS225', 'WaDENM_WS226', 'WaDENM_WS227', 'WaDENM_WS228',
#        'WaDENM_WS229', 'WaDENM_WS230', 'WaDENM_WS231', 'WaDENM_WS232',
#        'WaDENM_WS233', 'WaDENM_WS234', 'WaDENM_WS235', 'WaDENM_WS236',
#        'WaDENM_WS237', 'WaDENM_WS238', 'WaDENM_WS239', 'WaDENM_WS240',
#        'WaDENM_WS241', 'WaDENM_WS242', 'WaDENM_WS243', 'WaDENM_WS244',
#        'WaDENM_WS245', 'WaDENM_WS246', 'WaDENM_WS247', 'WaDENM_WS248',
#        'WaDENM_WS249', 'WaDENM_WS250', 'WaDENM_WS251', 'WaDENM_WS252',
#        'WaDENM_WS253', 'WaDENM_WS254', 'WaDENM_WS255', 'WaDENM_WS256',
#        'WaDENM_WS257', 'WaDENM_WS258', 'WaDENM_WS259', 'WaDENM_WS260',
#        'WaDENM_WS261', 'WaDENM_WS262', 'WaDENM_WS263', 'WaDENM_WS264',
#        'WaDENM_WS265', 'WaDENM_WS266', 'WaDENM_WS267', 'WaDENM_WS268',
#        'WaDENM_WS269', 'WaDENM_WS270', 'WaDENM_WS271', 'WaDENM_WS272',
#        'WaDENM_WS273', 'WaDENM_WS274', 'WaDENM_WS275', 'WaDENM_WS276',
#        'WaDENM_WS277', 'WaDENM_WS278', 'WaDENM_WS279', 'WaDENM_WS280',
#        'WaDENM_WS281', 'WaDENM_WS282', 'WaDENM_WS283', 'WaDENM_WS284',
#        'WaDENM_WS285', 'WaDENM_WS286', 'WaDENM_WS287', 'WaDENM_WS288',
#        'WaDENM_WS289', 'WaDENM_WS290', 'WaDENM_WS291', 'WaDENM_WS292',
#        'WaDENM_WS293', 'WaDENM_WS294', 'WaDENM_WS295', 'WaDENM_WS296',
#        'WaDENM_WS297', 'WaDENM_WS298', 'WaDENM_WS299', 'WaDENM_WS300',
#        'WaDENM_WS301', 'WaDENM_WS302', 'WaDENM_WS303', 'WaDENM_WS304',
#        'WaDENM_WS305', 'WaDENM_WS306', 'WaDENM_WS307', 'WaDENM_WS308',
#        'WaDENM_WS309', 'WaDENM_WS310', 'WaDENM_WS311', 'WaDENM_WS312',
#        'WaDENM_WS313', 'WaDENM_WS314', 'WaDENM_WS315', 'WaDENM_WS316',
#        'WaDENM_WS317', 'WaDENM_WS318', 'WaDENM_WS319', 'WaDENM_WS320',
#        'WaDENM_WS321', 'WaDENM_WS322', 'WaDENM_WS323', 'WaDENM_WS324',
#        'WaDENM_WS325', 'WaDENM_WS326', 'WaDENM_WS327', 'WaDENM_WS328',
#        'WaDENM_WS329', 'WaDENM_WS330'], dtype=object)

# %%
# %%time

# Creating WaDE Custom site native ID for easy site identificaiion
# Change 'outstring' name to be state specific.
# ----------------------------------------------------------------------------------------------------

# Create temp SiteNativeID dataframe of unique site.
def assignSiteUUID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDENM_S" + string1
    return outstring

dfSiteNativeID = pd.DataFrame()
dfSiteNativeID['in_Latitude'] = dfPOD['in_Latitude']
dfSiteNativeID['in_Longitude'] = dfPOD['in_Longitude']
dfSiteNativeID['in_SiteName'] = dfPOD['in_SiteName']
dfSiteNativeID = dfSiteNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfSiteNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfSiteNativeID['in_SiteNativeID'] = dftemp.apply(lambda row: assignSiteUUID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveSiteNativeID(A, B, C):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfSiteNativeID.loc[(dfSiteNativeID['in_Latitude'] == A) & 
                                (dfSiteNativeID['in_Longitude'] == B) &
                                (dfSiteNativeID['in_SiteName'] == C), 'in_SiteNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfPOD['in_SiteNativeID'] = dfPOD.apply(lambda row: retrieveSiteNativeID( row['in_Latitude'], row['in_Longitude'], row['in_SiteName']), axis=1)
dfPOD['in_SiteNativeID'].unique()

# %%
print(len(dfPOD))
dfPOD.head()

# %%
# Export the output dataframe
dfPOD.to_csv('Pwr_NewMexicoMain.zip', index=False, compression="zip")  # The output, save as a zip
