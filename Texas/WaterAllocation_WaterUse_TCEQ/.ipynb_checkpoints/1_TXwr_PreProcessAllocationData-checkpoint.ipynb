# %% [markdown]
# # Pre-processing Texas TCEQ Allocation data for WaDEQA upload.
# Purpose:  To pre-process the Texas data into one master file for simple DataFrame creation and extraction

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
import re
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x) # suppress scientific notation in Pandas

# %%
#Working Directory
workingDir = "G:/Shared drives/WaDE Data/Texas/WaterAllocation/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## Input Data

# %% [markdown]
# #### Onwer Info

# %%
#Dataframe creation - owners
ownerInput = "WaterRightOwner.zip"
df_owner = pd.read_csv(ownerInput).replace(np.nan, "")
print(len(df_owner))
df_owner.head(1)
# Out:
# 11327
#    OID_  WR_ID              OWNERS
# 0     1  P5264  River Bend, L.L.P.

# %%
# Clean Owner info.  Remove special characters
def cleanOwnerDataFunc(Val):
    Val = str(Val).strip()
    Val = re.sub("[$'\"'@&.;,/\)(-]", "", Val).title().strip()
    return Val

df_owner['OWNERS'] = df_owner.apply(lambda row: cleanOwnerDataFunc(row['OWNERS']), axis=1)
for x in df_owner['OWNERS'].sort_values().unique():
    print(f'"' + x + '",')
# Out:
# "",
# "1031 Facilitators No 21 Llc",
# "141 Ranch Company Llc",
# "177 Lake Estates Assn Inc",
# "1802 Main Street Partners Lp",
# "1951 Interests Lp",
# "1970 Childress Lp",
# "2006 Brazoria Venture Llc",
# "2016 Shahan Family Partnership Lp",
# "2017 Pg Investments Llc",
# "2219 Kaufman Partners Lp",
# "2350 Senator Partners Llc",
# "2Br Land Lp",
# "2Gl Llc",
# "2Mb Land And Cattle Llc",
# "3 H Lake Inc",
# "3276 Medina Nstanton Llc",
# "3Bu Family Limited Partnership",
# "3K River Ranch Llc",
# "3S Real Estate Investments Llc",
# "46 Skyline Drive Llc",
# "4C Ranch Properties Llc",
# "4Gs Ranch Partnership",
# "4L Family Lp",
# "4Leaf Properties Llc",
# "4Ses Llc",
# "4W Trust",
# "5653041 Acre Ranch Lp",
# "5D Inc",
# "7 M Ranch Trust",
# "759 Cr 144 Llc",
# "7D Ue Llc",
# "85 Jacaranda Limited Partnership",
# "A  H Developers Inc",
# "A A Martin",
# "A D D Corp",
# "A Dean Mabry Et Al",
# "A Farrer Et Al",
# "A G Spanos Construction Inc",
# "A Jabler Rodriguez",
# "A L Martinez",
# "A R E Property Owners Association Inc",
# "A R Galloway Inc",
# "A Staude Family Limited Partnership",
# "A Wayne Clark",
# "A2 Cattle Feeding Inc",
# "Aa Landscape  Irrigation Lp",
# "Aaron Barnes",
# "Aaron Bedell",
# "Aaron Clifton Henicke",
# "Abbey Randolph Jn",
# "Abbey Sharon M",
# "Abbott Helen R",
# "Abbott John A",
# "Abbott Tommy Joe",
# "Abel C Longoria",
# "Abels Bobby Lee",
# "Abernathy Lee E",
# "Abernathy Mattie G",
# "Abie Williams",
# "Abilene Country Club",
# "Abilio Saenz Jr",
# "Acl Armendariz Partnership",
# "Acme Brick Company",
# "Across The River Farm Llc",
# "Adami Walter",
# "Adams Connie Bagley",
# "Adams Donna",
# "Adams Douglas James",
# "Adams Edith",
# "Adams Family Trust",
# "Adams Gardens Irrigation District 19",
# "Adams J W",
# "Adams Larry Wayne",
# "Adams Preston L",
# "Adams Thomas Q",
# "Adan Farias Vela",
# "Adan Madrid",
# "Adan Villarreal",
# "Addington Gloria Guerra",
# "Addison Jerry G",
# "Addison Linda J",
# "Adela Rivera",
# "Adelaide H Church",
# "Adkins Alice M",
# "Adl Development Lp",
# "Adlong Sadie Wilkins",
# "Adolfo Pena Jr",
# "Adolphus Andrew Hicks",
# "Adrienne Goff",
# "Adron Staley",
# "Adtin Llc",
# "Advario Texas Independent Deepwater Expansion Llc",
# "Aelvoet Anna",
# "Aelvoet Genevieve",
# "Aelvoet Julius O",
# "Aelvoet Rene T",
# "Aelvoet Rosie",
# "Aem Land  Cattle Lp",
# "Aeropajita Medina",
# "Aery Bradley K",
# "Aery Randi G",
# "Aes Western Power Llc",
# "Affiliated Developers Inc",
# "Ag Services Inc",
# "Agua Special Utility District",
# "Ail Investment Lp",
# "Aime`E Rhodes Cook",
# "Ainsworth Alice",
# "Aj And Julia Champion Living Trust",
# "Akers David K",
# "Akers Margaret F",
# "Akin Ruth",
# "Al E Margo",
# "Al Louis Lindig",
# "Alabama Coushatta Indian Reservation",
# "Alamo Builders Lp",
# "Alamo Concrete Products Company",
# "Alamo Freight Lines Inc",
# "Alan Doug Hopper",
# "Alan L Baier",
# "Alan R Kowalik",
# "Alan S Caudle And Nancy L Caudle Revocable Trust",
# "Alan Schoellkopf",
# "Alaniz Alma P",
# "Alaniz Fidela Valadez",
# "Alaniz Olga",
# "Alaniz Reynaldo M",
# "Alavro N Gomez",
# "Albert G Dwarshus Jr",
# "Albert J Stowell",
# "Alberto Zepeda Jr",
# "Albrecht Elinor Gaylord",
# "Alcoa World Alumina Llc",
# "Alders Nolan Bailey",
# "Aldridge Danie May",
# "Alecia Turner",
# "Alejandra De La Rosa",
# "Alejandra Saenz",
# "Alejandro V Gomez",
# "Alex Pope Jr Et Al",
# "Alexander Combined Exempt Trust For Benjamin M Alexander",
# "Alexander Combined Exempt Trust For Gail E Alexander",
# "Alexander Combined Exempt Trust For Maureen M Alexander",
# "Alexander Combined Exempt Trust For Phyllis Terry",
# "Alexander Combined Exempt Trust For Rosalind A Kokolis",
# "Alexander Frick Et Al",
# "Alexander Kenneth",
# "Alexander Robert L",
# "Alfonso C Brito",
# "Alfonso Esteban Gomez Iii",
# "Alfonso Ortiz",
# "Alfonso Paredes",
# "Alford E Landon",
# "Alford John R Jr",
# "Alfred A Wiley",
# "Alfred B Hegar Childrens Trust",
# "Alfred L Carey",
# "Alfred S Waldrop",
# "Alfredo Antonio Gavito",
# "Alfredo M Vidaurri",
# "Alice Ainsworth Et Al",
# "Alice Anne Everett Brown",
# "Alice Country Club",
# "Alice K Lee",
# "Alice Water Authority",
# "Alicia C Gonzales",
# "Andrew De La Garza",
# "Andrew Deck",
# "Andrew H Jackson",
# "Andrew Paul Zacharias",
# "Andrew Rives",
# "Andrews Frances",
# "Andrews Ronnie",
# "Andrews Teri",
# "Angela D Risher",
# "Angelina  Neches River Authority",
# "Angelina And Neches River Authority",
# "Angelina Nacogdoches Counties Wcid 1",
# "Angle Investments Llc",
# "Anibal Leal Garcia",
# "Anice Chesebrough",
# "Animate Habitat Ltd",
# "Anita Adair",
# "Anita Gardner",
# "Anita Gotcher",
# "Anita L Day",
# "Anita Lewis",
# "Anita Marie Kleinert",
# "Anita Meeves",
# "Ann Austin",
# "Ann Carr",
# "Ann Fortson Marcy",
# "Ann Hooker",
# "Ann Lovett",
# "Ann Marie Littlefield",
# "Ann Mcphail",
# "Ann Moody",
# "Anna C Floyd",
# "Anna Guerra Munoz",
# "Anna M Schmidt",
# "Anna M Vidaurri",
# "Anna Mae Johnston Trust",
# "Anna Maria Cowan Revocable Living Trust",
# "Anna Marie Widen Speir",
# "Anna R Fike",
# "Anna V Espinoza",
# "Annabelle Partners Ltd",
# "Anne Ashley Whitworth",
# "Anne Butler Cowan",
# "Anne Jeffers Jackson Family Trust",
# "Anne Jeffers Jackson Special Marital Trust",
# "Anne Karen Clark Trust",
# "Anne Kerr Mccarty Trust",
# "Anne M Broussard",
# "Anne Marie Speir",
# "Anne Pare",
# "Anne R Farris",
# "Annette B Steinman",
# "Annie L Haston",
# "Ansley Annie Lee",
# "Anthony Clifford Rast",
# "Anthony Esposito",
# "Anthony F Lucido",
# "Anthony F Smith",
# "Anthony G Huston",
# "Anthony Gray",
# "Anthony J Chandler",
# "Anthony Jay Volner",
# "Anton Fritz Otto",
# "Antonia Fulton",
# "Antonio C Lopez",
# "Antonio Carlos Lopez Jr",
# "Anzon Inc",
# "Apache Shores Inc",
# "Apache Springs Lp",
# "Appelt Leslie L",
# "Applied Materials Inc",
# "Araceli Vanderpool",
# "Arbor Development Company",
# "Arborgen Inc",
# "Arcadia Partners Llc",
# "Arce Florence G",
# "Arcelormittal Texas Hbi Llc",
# "Arcosa Aggregates Inc",
# "Arcosa Lws Llc",
# "Arely G Montesgarza",
# "Argentina G Garcia",
# "Arkema Inc",
# "Arlene B Rhoades",
# "Arlene Myra Rash Aldridge",
# "Arlie Coan",
# "Arlin Leroy Hartzog",
# "Arlington Sports Facilities Development Authority Inc",
# "Armand J Colaninni",
# "Armandina B Villarreal",
# "Armando Mondragon Ritchie",
# "Armendariz Frank",
# "Armendariz Luz S",
# "Armendariz Martha R",
# "Armstrong Connie C Jr",
# "Arnett Bobby G",
# "Arnett Mary",
# "Arnold Majors",
# "Arnosky Frank T",
# "Arnosky Pamela H",
# "Arnulfo E Martinez",
# "Arp Club Lake",
# "Arrow D Ranch Inc",
# "Arrowhead Lakes Property Owners Inc",
# "Arroyo Cynthia",
# "Artecona Edgar",
# "Artecona Robin",
# "Artesian Ranch Llc",
# "Arthur A Priesmeyer",
# "Arthur John Northrop",
# "Arthur L Hensley Iii",
# "Arthur L Jones Co Trustee",
# "Arthur Thomas L Iii",
# "Arthur W Beckwith Jr Trust",
# "Arturo D Hinojosa",
# "Arturo Garza",
# "Arturo Guajardo Jr",
# "Arvel Fleming",
# "Arwine Skidmore Estate",
# "Asa Waterman",
# "Asaff Harl Roberta",
# "Ascend Performance Materials Texas Inc",
# "Asckcc Llp",
# "Ash Grove Cement Company",
# "Ashby Edwin B",
# "Ashby Laura Kidd",
# "Ashby Seaborn L",
# "Ashcraft Allan C",
# "Ashley D Christian",
# "Ashley Flores",
# "Ashton Dallas Residential Llc",
# "Atascosa Cowboy Recreation Association",
# "Athens Fish And Game Club",
# "Athens Municipal Water Authority",
# "Atherton Russell Stephen",
# "Atlee M Kohl Trustee",
# "Atm 2005 Llc",
# "Attoyac Hunting And Fishing Club",
# "Atwell William W",
# "Auba V Hinson",
# "Audax Inc",
# "Audrey D Laird",
# "August Ilee Simon",
# "Auld Enterprise I Ltd",
# "Austin Aquaplex Pud Hoa Inc",
# "Austin Bayou Lp",
# "Austin Investment Co",
# "Austin Lorenzo Jr",
# "Autry And Peggy Andress Revocable Trust",
# "Autry C Stephens",
# "Auvenshine Dory Allen",
# "Auvenshine Jamie Collin",
# "Auvenshine Mernell",
# "Auvenshine Timothy Lane",
# "Auvenshine Wayland Tabbert",
# "Averitt W T Iii",
# "B Fanning",
# "B Gentry Ventures Ltd",
# "B J Shipping Company Inc",
# "B K Holmes",
# "B Lynn Sanders",
# "B N Huddleston",
# "Babb Muriel",
# "Baca Ileana",
# "Bacon Dan W",
# "Bae Systems Inc",
# "Baethage Bradley Owen",
# "Baeza Alfredo S",
# "Bagby James Thomas Jr",
# "Baggett Edwin",
# "Baggett Jimmie Lou",
# "Bagley Dean Jr",
# "Bagley Gailian Dean Jr",
# "Bagley Roy",
# "Bagwell R A",
# "Bailey F Kenneth",
# "Bailey Rex C Iii",
# "Bailey Rex C Jr",
# "Bain Carl B",
# "Baird Roger C",
# "Baker And Associates Joint Venture 4",
# "Baker Cynthia Ann",
# "Baker Denise L",
# "Baker Diana L",
# "Baker Donna B",
# "Baker Family Trust",
# "Baker Jay Collie",
# "Baker Jay E",
# "Baker Jayme",
# "Baker Jennifer",
# "Baker Jerry M",
# "Baker Larry",
# "Baker Lucas",
# "Baker Natalie",
# "Baker Thomas B",
# "Balcones Country Club Membership Association Inc",
# "Balcones Crossing Llc",
# "Baldobino Jane",
# "Baldobino Willie",
# "Baldridge Family Land Ltd",
# "Ball Emilie Sue",
# "Ballard John S Iii",
# "Ballard Patricia D",
# "Balli Clemente Jr",
# "Balli Felipe",
# "Balli Jaime",
# "Balli Ricardo",
# "Ballinger Country Club",
# "Baltgem Development Corporation",
# "Bandera Electric Cooperative Inc",
# "Bank Of America National Association",
# "Banner Residual Trust",
# "Bannworths Inc",
# "Bar J Grassfed Beef Inc",
# "Bar To Lo Corporation",
# "Bar V Holdings Llc",
# "Barbara Ann Jones",
# "Barbara Ann Markey Crim Trust",
# "Barbara Beckmann Hagel",
# "Bill Deagen  Sons Ltd",
# "Bill I Neiman",
# "Bill Kirk",
# "Bill Pittman Trustee",
# "Bill Ward",
# "Billie Anne Martin",
# "Billie F Sawyer",
# "Billie Faye Sawyer",
# "Billie J Fry",
# "Billie Jean Basham",
# "Billie Newton Moore",
# "Billie Voss Bright",
# "Billingsley James",
# "Billy A Kniffen",
# "Billy G Curry",
# "Billy J Mckibben",
# "Billy J Nitsche",
# "Billy J Terry",
# "Billy Jay",
# "Billy L Sawyer",
# "Billy Wayne  Carolyn Jean Hayes Family Trust",
# "Bines Audrey Dalas",
# "Bingham Ava Nell",
# "Bingham Berry Ray",
# "Bingham Glen H",
# "Bingham Jerry W",
# "Bingham Jimmy L",
# "Bingham Michael R",
# "Bippert Farms",
# "Birch Creek Forest Properties Inc",
# "Birkner Jack",
# "Birkner Mary Lou",
# "Birnie Sandra",
# "Bishop B J",
# "Bishop Jimmy Dane",
# "Bistone Municipal Water Supply District",
# "Bkg Corp",
# "Bl R Owner Llc",
# "Blackburn Bobby Don",
# "Blackburn Brothers Inc",
# "Blackburn Properties 401K",
# "Blacklock Carroll D",
# "Blacklock Johnnie F",
# "Blackwell John M",
# "Blaine Emilie S",
# "Blaine Rachelle Moss Davis",
# "Blair P Woodall",
# "Blair Pauline H",
# "Blair Sandra",
# "Blake E Woodall Ii",
# "Blake Lewis Duncan Family Trust",
# "Blake Millican",
# "Blakemore Forbus E",
# "Blakemore James A",
# "Blanca Margarita Cavazos Garcia",
# "Blanch Double Diamond Development Corp",
# "Blanchard Refining Company Llc",
# "Blanek Harry J",
# "Blanek Kathy J",
# "Blanek Kathy Seidel",
# "Blankenship Family Trust",
# "Blanton Charles E",
# "Blau Mark E",
# "Blessing Holdings Llc",
# "Blount Elizabeth Mcgowan",
# "Blount James Robert",
# "Blue Lake Ranch Llc",
# "Blue Mine  Red River Llc",
# "Bluebonnet Savings Bank Fsb",
# "Bluegreen Communities Of Texas Lp",
# "Bluegreen Southwest One Lp",
# "Bn Leasing Corporation",
# "Boasso America Corporation",
# "Bob Gold",
# "Bob Harris Oil Company",
# "Bob J Keesee",
# "Bobbie Carol Waller Obrien",
# "Bobbie Nell Carey",
# "Bobby Keith Pearson",
# "Bobby L Howell",
# "Bobby Stokes Family Limited Partnership",
# "Bobby Zugg",
# "Bobbye Jo Mcmillon",
# "Bobkat Inc",
# "Bobo Maria Isabel Trevino",
# "Boca Chica Water Supply Inc",
# "Bodden Carleen",
# "Bodden Nix O",
# "Bodine Guy Iii",
# "Bodine Sherron R",
# "Boehmer Otto",
# "Boehmer Sharon",
# "Boening Enterprises",
# "Boggy Creek Ranch Inc",
# "Bohls Cattle Ranch And Investments Venture",
# "Boles Billy J",
# "Boles Karen R",
# "Bollinger Lyle",
# "Bollinger Mary",
# "Bolner Victor D",
# "Bolton Lennon W",
# "Bolton Minnie A",
# "Bond Elizabeth Lacy",
# "Bonita M Thedford",
# "Bonita Owners Association",
# "Bonn Corrine",
# "Bonn Melvin",
# "Bonner Rosalea C",
# "Bonnett F F",
# "Bonnett Shirlene A",
# "Bonnie Dee Crumley",
# "Bonnie Dernehl Orsak",
# "Bonnie Harkey",
# "Bonnie Helwig Huckabee",
# "Bonnie Jo Blythe",
# "Bonnie L Bradshaw",
# "Bonnie Lange",
# "Bonnie Pate",
# "Boot Ranch Holdings Llc",
# "Boothe Jack H",
# "Boothe Robert L",
# "Boral Bricks Llc",
# "Bordano Angelina",
# "Borden County",
# "Border N Land Investment Ltd",
# "Borders Gene",
# "Borders Pansy",
# "Borho Billy W",
# "Borho Gloria L",
# "Borrego Lilia Leticia Pena",
# "Bosch Peter",
# "Boston Mary Jean",
# "Boucher Mary Ruth",
# "Boudreaux Nolia F",
# "Boultinghouse Roy Lee",
# "Boulware  Anson Family Ltd",
# "Bounds Jeanette",
# "Bounds Melba Lois",
# "Bounds Miriam M",
# "Bounds Vincent Gates",
# "Bourbon House Llc",
# "Bowen Jennifer J",
# "Bowen Raymond M Jr",
# "Bowers B W",
# "Bowers Lake Limited Partnership",
# "Bowers Sara J",
# "Box Adam",
# "Box Charlie",
# "Box John Iv",
# "Box Norma",
# "Box Oscar",
# "Box Ward L",
# "Boy Scouts Of America Alamo Area Council Inc",
# "Boyce N Ward",
# "Boyd H Lakey",
# "Boyd Jimmie Helen",
# "Boyd Joe D",
# "Boykin Burwell F",
# "Boykin Paula S",
# "Boykin Robert L",
# "Bozka Matt J",
# "Br  Wr Evans Farms Inc",
# "Brabant De Esther",
# "Bracewell W T",
# "Brad Hemmenway",
# "Brad Steven Lemons",
# "Braddock Karol Kotara",
# "Braden Erna",
# "Braden John Jr",
# "Bradford R Smith",
# "Bradley B Ware",
# "Bradley D Boyd  Rebecca G Boyd Living Trust",
# "Bradley D Lengel",
# "Bradley Earl T",
# "Bradshaw Billy J",
# "Bradshaw Carol E",
# "Bradshaw Charlene",
# "Bradshaw Comy E",
# "Brady Bend Farm Llc",
# "Brady Jean Branch",
# "Brady Lonie Branch",
# "Brady William L",
# "Braeburn Country Club",
# "Braiden Ben Hagel",
# "Bramlet Richard D",
# "Bramlette Jay",
# "Branch Linda Sue",
# "Branch Ronnie Duane",
# "Brand Christian Youth Camp Inc",
# "Brandenberger Franklin W",
# "Brandi Bradford",
# "Brandl Anton Jr",
# "Brandl Dorothy",
# "Brannies Everett George Jr",
# "Branson Capital Partners Ltd",
# "Braskdumont Ranch Inc",
# "Bravenec Karen Berry",
# "Bravo J E",
# "Brazos Bend 2012 Trust",
# "Brazos Farm Limited",
# "Brazos River Authority",
# "Brazos River Club",
# "Brazosport Water Authority",
# "Breckenridge Gasoline Company",
# "Bredemeyer W E",
# "Breedlove Charles",
# "Breining Berryman M",
# "Breitenstein Nellie Jo C",
# "Bremerg Llc",
# "Brenan Diane Marcum",
# "Brenda Elizabeth Waters Trustee",
# "Brenda Kay Burks Trust",
# "Brenda Lindig",
# "Brenda Reel",
# "Brenda Salguero",
# "Brent A Neuhaus 1994 Trust",
# "Brent Haney Bratton",
# "Brett A Turner",
# "Bretzke Robert Lee",
# "Brewer Foster L",
# "Brewster County",
# "Brewster Sam J",
# "Brian Day",
# "Brian J Bristow",
# "Brian J Slater",
# "Brian Kern",
# "Brian S Johnson",
# "Brian Smith",
# "Brian Vossler",
# "Brian W Lengel",
# "Brian Wayne Stroud",
# "Brice Douglas M",
# "Bridgeland Development Lp",
# "Bridges Equipment Ltd",
# "Bridgford David Thomas",
# "Briggs James Buford",
# "Briggs R W Jr",
# "Briley Ronnie Bo",
# "Brimberry E Hubert",
# "Briones Ernestina H",
# "Briscoe Dolph Iii",
# "Briscoe Ranch Inc",
# "Brister Jackie",
# "Brito Laurencio",
# "Britt Bobbie G",
# "Britt Elizabeth Ann",
# "Britta Herzog",
# "Brittany Anne Bailey",
# "Brittany Tonozzi",
# "Britten Christopher L",
# "Britten Deborah E",
# "Brl Ranches Lp",
# "Bronder Felix",
# "Brook Anne Johnson Broesche Trust 1",
# "Brook Hollow Golf Club",
# "Brooke John C",
# "Brookhaven Country Club Inc",
# "Brookhaven In The Pines",
# "Brooks Amber Michelle",
# "Brooks Garnett T",
# "Brooks Joseph D",
# "Brooks Patsy A",
# "Broussard James L",
# "Broussard Loretha Ann",
# "Broussard Tim J",
# "Broventure Company Inc",
# "Brown A Reese",
# "Brown Audrey Mussette",
# "Brown Barbara",
# "Brown Bernie",
# "Brown Betty",
# "Brown Billy",
# "Brown Boston T",
# "Brown Brothers Farm Inc",
# "Brown Carolyn May",
# "Brown County Water Improvement District 1",
# "Brown Daniel F",
# "Brown Darrell",
# "Brown Don",
# "Brown Dorothy",
# "Brown E E",
# "Brown Edith",
# "Brown Gene",
# "Brown George W",
# "Brown Jimmie Kate Terry",
# "Brown Jimmy W",
# "Brown Joe Russell",
# "Brown Joseph Carlton",
# "Brown Judy Macha",
# "Brown Lake Fishing Club",
# "Brown Marie F",
# "Brown Martha",
# "Brown Mary",
# "Brown Mary C",
# "Brown Mary Kathyrn",
# "Brown Nancy",
# "Brown Roger",
# "Brown W A",
# "Brown Walter Othel",
# "Brown William L",
# "Brown Wyman",
# "Brown Wynelle",
# "Browne Larry E",
# "Browne Phylis A",
# "Brownsville Irrigation And Drainage District",
# "Brownsville Irrigation District",
# "Brownwood Country Club",
# "Bruce B Baxter Iii 1967 Trust",
# "Bruce Beverly Baxter Iii 1967 Trust",
# "Bruce Charles P",
# "Bruce Flanigan",
# "Bruce W Blinn",
# "Brulloths Benjamin G",
# "Brumbaugh Jay Larry",
# "Brumbaugh Sally M",
# "Bruton Terrace Lake Association",
# "Bryan C Booth",
# "Bryan Douglas Fore",
# "Bryan Payne",
# "Bryant Buster L",
# "Bryce Kary",
# "Bt Livestock Inc",
# "Bts Enterprises Inc",
# "Buck Beth",
# "Buck Lewis J",
# "Buck Lonnie Leonard Iii",
# "Buckley James H",
# "Buckley Martha G",
# "Buckner International",
# "Buehring E F",
# "Buffalo Springs Ranch Llc",
# "Bulanek Clara Pearl",
# "Bulanek Donald Joe",
# "Bull Hollow Lp",
# "Bullion D I",
# "Bundara Mamie J",
# "Bunnell Ray B",
# "Burditt John J",
# "Burditt Velma E",
# "Burditt William J",
# "Burditt William R",
# "Burford Debra W",
# "Burford John",
# "Burgess F W",
# "Burgess Rebecca F",
# "Burgess William G",
# "Burk C Murchison",
# "Burkett Water Supply Corporation",
# "Burkett Zack",
# "Burks Deborah D",
# "Burks Janet M",
# "Burks Jerry H",
# "Burks Larry J",
# "Burleson Billie James",
# "Burleson Lake Shareholders",
# "Burleson Steven L",
# "Burlington Northern Santa Fe Corporation",
# "Burnham Donald D",
# "Burnham Martha Owen",
# "Burnham Reagan O",
# "Burnham Renice",
# "Burns Ann",
# "Burns Brothers Ltd",
# "Burns Eddie",
# "Burns Hugh",
# "Burns Imogene",
# "Burns Janet",
# "Burns Margaret Isabel Garcia",
# "Burns Robert M",
# "Burns T E",
# "Burrhus Bertice Posey",
# "Burrhus Don",
# "Burris John H",
# "Burrow Leslie William",
# "Burt J Fred",
# "Burt Penny Puryear",
# "Burton Allie B",
# "Burton E Stovall",
# "Burton Jack C",
# "Burton Joe L",
# "Burton John F",
# "Burton Margaret",
# "Busenlehner Cecilia",
# "Busenlehner Joe",
# "Busenlehner Joseph Jr",
# "Busenlehner Sharon L",
# "Bush Cheryl W",
# "Bush Dale A",
# "Bush Philip L",
# "Business And Industrial Corporation Of Denison Inc",
# "Butler Family Partnership Ltd",
# "Butler Farm Estates Homeowners Association Inc",
# "Butler Residual Trust",
# "Butt Howard E",
# "Butts Dorothy E",
# "Butts Nolan",
# "Butz Karl T Jr",
# "Bwc Texas Terminals Llc",
# "Byars J B",
# "Bynum Virginia",
# "Byram Dan H",
# "Byrd Lawrence",
# "Byron C Hulett",
# "Byron Kade Broussard",
# "Byron Keith Hooper",
# "C A R D Inc",
# "C And L Company Inc",
# "C B Fields",
# "C Baldwin Jr",
# "C C Meek Estate",
# "C D Cheatham Jr",
# "C F And L Enterprises",
# "C G Johnson",
# "C G Vickers",
# "C H  Betty Jean Williamson",
# "C H Flanagan",
# "C H Mccall Et Ux",
# "C J Holloway",
# "C L Machinery Company",
# "C L Ranch A Partnership",
# "C L Sligh Farms",
# "C R Hocott Trustee",
# "C Stanley Jones",
# "C W Duncan Iii",
# "C7 Llc",
# "Cabaniss Allen Dwight",
# "Cabaniss Harold Bruce",
# "Cabelas Retail Tx Lp",
# "Cabriales Benito D",
# "Cabriales Maria A",
# "Cactus Feeders Inc",
# "Caddell Delton",
# "Caddo Lake Institute Inc",
# "Cadena Jose A",
# "Cadena Joy R",
# "Cadena Martha",
# "Cadg Erwin Farms Llc",
# "Cafema Properties Llc",
# "Cagle Harold W",
# "Cain Lula Scott",
# "Cain Wendell",
# "Cal Sierra Produce Inc",
# "Calaveras Lake Ltd",
# "Calhoun Port Authority",
# "Calixtro Lopez",
# "Callahan Anne C",
# "Callaway Margaret",
# "Callender Lake Property Owners Improvement Association",
# "Calpine Construction Finance Company Lp",
# "Caltex Ranch Lp",
# "Calvin Kraemer",
# "Carroll Mary L",
# "Carroll R C",
# "Carroll Samuel N",
# "Carroll Tessie B",
# "Carroll Tom R",
# "Carroll William D",
# "Carrozza Robert",
# "Carskadden Kathleen Davenport",
# "Carson Kw",
# "Carter Lake Home Owners Corporation",
# "Carter Thomas J",
# "Carter Thomas J Jr",
# "Carters Ponderosa Group I Lp",
# "Caruth Trust",
# "Casaundra Lea Talbott",
# "Casey Joe Fisher",
# "Caskey Willie Bedford",
# "Cass Elsa Pena",
# "Cassandra Keith",
# "Casso Ltd",
# "Castella Berneice",
# "Castella William F",
# "Castellano And Tijerina Family Limited Partnership",
# "Castellano Josefa T",
# "Castillo Maria Cristina Garza",
# "Castillo Romulo",
# "Castro Albesa Rodriguez",
# "Castro Development Company Inc",
# "Castro Properties Llc",
# "Catarina De La Rosa",
# "Catharine C Whittenburg Joint Account Ltd",
# "Catherine Barbosa",
# "Catherine E D Urquhart 1986 Trust",
# "Catherine W Cralle Jones",
# "Cathleen S Cantrell",
# "Catholic Diocese Of Fort Worth",
# "Cathy A Reddell",
# "Cathy Gayle Gray",
# "Cathy Philipski",
# "Cattani Family  Red River Llc",
# "Cauble Douglas",
# "Cavallino Place Ltd",
# "Cavazos Belen Garza",
# "Cavazos Francisco",
# "Cavazos Jose Alfredo",
# "Cavazos Romulo",
# "Cave Linda",
# "Cave M L",
# "Cc Panther Oaks Llc",
# "Cc Woodlands Llc",
# "Cca Cpnl Marine Development Center",
# "Cecelia D Cheever",
# "Cecil Campbell",
# "Cedar Bayou Ltd",
# "Celia J Griffin",
# "Cemex Construction Materials South Llc",
# "Cemex El Paso Inc",
# "Central Texas Country Club Inc",
# "Cerco Development Inc",
# "Cervenka Patty",
# "Cervenka William J",
# "Cesar H Hinojosa",
# "Cesar Palma",
# "Cf Fossil Creek Arcis Llc",
# "Cf Lantana Arcis Llc",
# "Cf Plantation Arcis Llc",
# "Cgc Ritchie",
# "Chad E Castro",
# "Chad Michael Alcock",
# "Chaffin Deborah A",
# "Chaffin James R",
# "Chaffin Leland S Jr",
# "Chaffin Lloyd N",
# "Challenge Development Inc",
# "Chamales Linda Lorraine",
# "Chamales Michael Hood",
# "Chamberlin Family Trust",
# "Chambers County",
# "Chambers Liberty Counties Navigation District",
# "Chamblee Guy Clifford",
# "Chamisa Caes At Tulia Llc",
# "Champion Domain Llc",
# "Chanas Ranch Llc",
# "Chance Jerry Darrell",
# "Chandler Charlena J",
# "Chandler Wayne Jr",
# "Chapa Alberto X",
# "Chapa Alfonso",
# "Chapa Alfonso Mario Jr",
# "Chapa Blas",
# "Chapa Casimiro",
# "Chapa Dora",
# "Chapa Ester",
# "Chapa Gilberto",
# "Chapa Marcelo",
# "Chapa Mario",
# "Chapa Moises",
# "Chapa Ofelia D",
# "Chapa Pedro A",
# "Chapa Rafaela G",
# "Chapaline Loma Limited",
# "Chaparral Recreation Association",
# "Chaparrosa Ranches Ltd",
# "Chapman Joyce Virginia",
# "Chapman Karen Kim",
# "Chapman Ranch Trusts 1 And 3",
# "Chappell Hills Inc",
# "Charca Ltd",
# "Charlene M Sefcik",
# "Charlene Myers",
# "Charles  Mary Book",
# "Charles A Bates",
# "Charles A Doby",
# "Charles A Donaldson",
# "Charles Allen Hicks",
# "Charles Baker",
# "Charles Burton",
# "Charles C Mcwilliams",
# "Charles D Crow",
# "Charles D Sanderson",
# "Charles D Winship Revocable Trust Agreement Of 2000",
# "Charles Dameron",
# "Charles David Rottersmann",
# "Charles Donald Schuler",
# "Charles E Parsley",
# "Charles E Pool Jr",
# "Charles Ezzell",
# "Charles F Hedges Jr",
# "Charles Kenneth Clark Trust",
# "Charles L Harless Et Ux",
# "Charles L Sonnenberg",
# "Charles Lydell Thalmann",
# "Charles M Stockton",
# "Charles Mccasland",
# "Charles N Jackson",
# "Charles R Milford",
# "Charles R Timm",
# "Charles Steven Wolfe",
# "Charles Stewart Roberts",
# "Charles T Trefny",
# "Charles Vernon Blythe",
# "Charles W Killough",
# "Charles W Wilson Inc",
# "Charles Wendall Warner",
# "Charlie Cockburn",
# "Charlie Thomas",
# "Charlotte F Reaugh",
# "Charlotte Jane Parks Trust No 101",
# "Charlotte Kellermeier",
# "Charlotte Mitchell",
# "Charlotte Spragins",
# "Chavez Ernestina",
# "Chavez Raquel C",
# "Chenault Charles Blake",
# "Cheniere Land Holdings Llc",
# "Cheree Hamblen",
# "Cherie L Orear",
# "Cheris L Cearley",
# "Cherokee Water Company",
# "Cheryl Corso Brown",
# "Cheryl J Hoyle",
# "Cheryl Pritchard",
# "Cheryl Rene Jackson",
# "Chester James Donald",
# "Cheswood Lake Club",
# "Chevron Phillips Chemical Company Lp",
# "Cheyenne Interests Inc",
# "Children Of Richard Barry Lewis Jr  Wife Cathi Lea Lewis Trust",
# "Choate Bronwen",
# "Chris Cabbiness",
# "Chris Craig",
# "Chris Moldenhauer",
# "Chris Sylte",
# "Christa G Armantrout",
# "Christi L Blakkolb",
# "Christina Durdin Warren",
# "Christina Pena",
# "Christina W Mccullough",
# "Christina Wheatcraft",
# "Christine Brininstool",
# "Christine Cooper Oliphant",
# "Christine De La Garza",
# "Christine Diane Pool Bessent",
# "Christine Ruth Schulze",
# "Christopher Hunter Coffield",
# "Christopher James Hales",
# "Christopher Luther Dean",
# "Christopher N Bezner",
# "Christopher Paul Piel",
# "Christopher Perry Alexander",
# "Christopher Pool",
# "Christoval Independent School District",
# "Christy A Forrest",
# "Christy Moncile Hughes",
# "Chs Farms Ltd",
# "Churchill Bobbie",
# "Churchill Frank",
# "Cia Hidden Forest Inc",
# "Cibolo Creek Municipal Authority",
# "Cili Llc",
# "Cimarron Ranch Properties Lp",
# "Cinco H Family Holdings Lp",
# "Cinco Residential Property Association Inc",
# "Cindee J Schieffer",
# "Cindi Payne",
# "Cindi Sako",
# "Cindy A Newton Shaw",
# "Cindy Cretsinger",
# "Cindy Kirby",
# "Cindy L Preacher",
# "Cindy M Turner",
# "Circle C Cattle Co Ltd",
# "Circle R Hunting And Fishing Club Inc",
# "Circle Ten Council Inc Boy Scouts Of America",
# "Clark Amizetta Mcfaddin",
# "Clark Bobby J",
# "Clark Don Frazier",
# "Clark Gaylon",
# "Clark Jack D Iii",
# "Clark Jack D Jr",
# "Clark John",
# "Clark Marilyn",
# "Clark Patricia B",
# "Clark Powers",
# "Clark W B",
# "Clark W N",
# "Clark Warren",
# "Clark Warren Dale",
# "Clark Wiginton Irrevocable 2015 Trust",
# "Clarke Mark D",
# "Clarksville Country Club",
# "Claudia Curran Freels",
# "Clay Alan Pevehouse",
# "Clay County Country Club Inc",
# "Clay Dameron",
# "Clay Humphries",
# "Clay Perry",
# "Clayton Jones",
# "Clayton Maxwell Chandler Trust",
# "Clayton W Mercer",
# "Cld Group Lp",
# "Clear Lake Pines Inc",
# "Clear Lake Pines Maintenance Corporation",
# "Clearwater Springs Llc",
# "Cleckler Lewis",
# "Cleckler Monica",
# "Clements Hally B",
# "Clements Thurman S",
# "Clemmaco Ltd",
# "Clemmons Jerry",
# "Clemmons Joy",
# "Cleta J Stapp",
# "Cletis Grona",
# "Cleveland Courts Jr",
# "Cleveland Jeanne C",
# "Cleveland L Kenneth",
# "Clevenger Family Partners Ltd",
# "Clifford N Auten",
# "Clifford W Zeliff",
# "Clifton Chowning",
# "Clint Amanda Garza",
# "Clint W Murchison Iii",
# "Clinton Claude Ramsey",
# "Clinton Sam Houston Jr",
# "Clinton Wilson Ritchie",
# "Clonts Samuel E",
# "Cloud Construction Co Inc",
# "Cloudt Olga H",
# "Clove Partnership Ii Ltd",
# "Clove Partnership Ltd",
# "Clovis R Barker",
# "Club Mark Corporation",
# "Clubb Herbert",
# "Clubb O D",
# "Clubb Robert",
# "Clyde H Emmons",
# "Clyde Mcmahon Concrete Co",
# "Clymer Guy L",
# "Cmrt Ltd",
# "Coan Lyndell F",
# "Coastal Bend Bays  Estuaries Program Inc",
# "Coastal Bend Property Development Lp",
# "Coats John R",
# "Coats Lynn",
# "Cobb William J",
# "Cobblestone Golf Group Inc",
# "Cochran Mabel",
# "Cody Wallace",
# "Cody Wayne Sulak",
# "Coe Robert",
# "Cofertaylor Karla",
# "Cogburn Christal",
# "Cogburn Toby",
# "Cold Spring Granite Company",
# "Cole Ann Marie Heinen",
# "Coleman County",
# "Coleman Farms Inc",
# "Coleman Isd",
# "Coleman Nat",
# "Coleman Young",
# "Coleto Cattle Ltd",
# "Coleto Creek Power Lp",
# "Collecting Bank N A",
# "Colleen Curran Hook",
# "Colleen Darnell",
# "Collie Bruce",
# "Collie Holly",
# "Collier Materials Inc",
# "Collin County Youth Camp",
# "Collins Ann H",
# "Collins Dwayne",
# "Colmesneil Isd",
# "Colorado Bend Ranch Llc",
# "Colorado River Municipal Water District",
# "Colunga Aurora Weaver",
# "Colvin Family Trust",
# "Colvin J W Iii",
# "Colvin Sandra G",
# "Comanche Ash Three Llcseries 105",
# "Comanche Harborports O Call Owners Association",
# "Comanche Maverick Ranch Investments Lp",
# "Comanche Trace Development Company Lp",
# "Comanche Waters Property Owners Association",
# "Combs Susan",
# "Con Can Enterprises Inc",
# "Conargo Llc",
# "Concan Water Supply Corporation",
# "Concho Grande Llc",
# "Confair Dorothy Benson",
# "Confluence Partners Ltd",
# "Connecticut Mutual Life Insurance Company",
# "Conner C H",
# "Connie Pinkerton",
# "Connie Smith",
# "Conocophillips Company",
# "Conroe Country Club",
# "Constance Elizabeth Booth",
# "Constance Widen Alexander",
# "Constellation Handley Power Llc",
# "Cook Canyon Ranch Ltd",
# "Cook Don H",
# "Cook Elaine Holub",
# "Cook Jane M",
# "Coolcreek Llc",
# "Coolwater Llc",
# "Coon Creek Club",
# "Cooper Allen A Jr",
# "Cooper Patsy Stout",
# "Cooper Roy L",
# "Cooper Sheila K",
# "Coopers Marine Service Inc",
# "Copano Enterprises Llc",
# "Copeland A B Jr",
# "Copeland David J",
# "Copeland Marsha",
# "Coplen Alma L",
# "Coppock Michael Andrew",
# "Corbin 5 Farms Llc",
# "Cordillera Ranch Property Owners Association Inc",
# "Corix Utilities Texas Inc",
# "Corman Brenda Jean Burroughs",
# "Corman Cherry Faye Adams",
# "Corman Victor Ray Jr",
# "Corman Victor Ray Sr",
# "Corman Wayne Lee",
# "Cornelison Doyr",
# "Cornelison Ryta",
# "Cornelius Herff",
# "Corporate Employees Recreation Association",
# "Corpus Christi Liquefaction Llc",
# "Corpus Christi Polymers Llc",
# "Corpus Dora",
# "Corsicana Country Club",
# "Cortez Alfonso",
# "Cortez Ezequiel",
# "Cortez Jose A",
# "Cortez Mary Jane",
# "Cortez Mateo Jr",
# "Cortez Paulita R",
# "Cortez Pedro",
# "Cortez Raul C",
# "Cortez Santiago",
# "Cortez Senorina",
# "Cortinas Jose A",
# "Cortinas Lucila P",
# "Cory Allen Lelek",
# "Corydon James Kobernat",
# "Cosper Judith Mcbean",
# "Cosper Lee Roy",
# "Cosper Mary Ann",
# "Cotter Kathryn Ritchie",
# "Cotterell Anne Rieck",
# "Cotterell William James Iii",
# "Cottonwood Lake Llc",
# "Couch Karla",
# "Coulter John R",
# "Coulter Ruth",
# "Countiss Sam",
# "Country Club Lake Park Inc",
# "Country Day Lake Association",
# "County Road 2173 Lp",
# "Courtney David C",
# "Courtney Moody E",
# "Cove Creek Corporation",
# "Covos Manuel",
# "Covos Olivia R",
# "Cox Bruce",
# "Cox Edwin L",
# "Cox Edwin L Jr",
# "Cox Paula Babb",
# "Cox Radio Inc",
# "Cox T 5 Inc",
# "Cox Troy Dylan",
# "Coyote Crew Ranch Ltd",
# "Cpg Diamond Oaks Lp",
# "Cpha Inc",
# "Cr Eason Jr Investments Lp",
# "Craig Barber",
# "Craig Huffman",
# "Craig James Sherlock",
# "Craig L Meador",
# "Craig Randall",
# "Craig Sims",
# "Craig Stencil",
# "Craig T Stephens",
# "Craig Thomas",
# "Cranfill Dairy Farms Inc",
# "Crawford Family Farm Lp",
# "Creek House Ranch Llc",
# "Creektree Lufkin Development Ltd",
# "Creekview Resort Llc",
# "Crepe Myrtles Of Texas Inc",
# "Crestwater Homeowners Association Inc",
# "Crews Evelyn",
# "Crews W C Iii",
# "Crews W C Jr",
# "Crider Bobby",
# "Crider Nancy",
# "Crisoforo S Vela Jr",
# "Crockett Doris Goodman",
# "Cromer Family Ranches Ltd",
# "Crosley James",
# "Crosley Linnie B",
# "Crosson Pauline Juarez",
# "Crouch Martha A",
# "Crow Gary",
# "Crown Colony Country Club Inc",
# "Crown Oaks Property Owners Association",
# "Crown Pine Timber 1 Lp",
# "Crownover Wilma Faye",
# "Crutsinger Hope",
# "Crystal Clare",
# "Csr Golf Group Inc",
# "Csta Ranch Lp",
# "Ctd Holdings Ltd",
# "Ctd Llc",
# "Cuatro Estrellas Ltd",
# "Cullen V Mancuso",
# "Culwell Don A",
# "Cummings Dam Llc",
# "Cundiff Patricia A",
# "Cundiff R L",
# "Cunningham Bobby",
# "Cunningham Charles",
# "Cunningham Chester",
# "Cunningham Donald",
# "Cunningham Elsie",
# "Cunningham G V",
# "Cunningham Juanice",
# "Cunningham Kay",
# "Cunningham Ranch Ltd",
# "Currie John J Jr",
# "Curt D Johnson Trust 1",
# "Curtis Harry Mahla Revocable Trust",
# "Curtis Marlin Farris",
# "Cushing Land And Cattle Company Llc",
# "Cutbirth Family Revocable Trust Amended And Restated Trust Agreement",
# "Cw Operating Company Inc",
# "Cwl Limited",
# "Cynthia Andrae",
# "Cynthia Broussard Rod",
# "Cynthia C Kelley",
# "Cynthia Carlene Delany",
# "Cynthia Dianne Mcqueen",
# "Cynthia Elders",
# "Cynthia Krouskup",
# "Cynthia M Silva",
# "Cynthia Mccann",
# "Cynthia Taylor",
# "Cypress Cove Maintenance Association",
# "Czar Consuelo L",
# "D A Reidland Estate",
# "D Arcy Mell Poulson",
# "D Bar P Ranch Lp",
# "D F Dutton Jr Land Trust",
# "D G Brown",
# "D J Brown",
# "D Malcolm Long",
# "D Mayes Middleton Ii Nonexempt Trust",
# "D S Enterprises Inc",
# "D Vaughn",
# "Dabs Brown Hollimon",
# "Daily Loyd",
# "Daily Sunny",
# "Daisy Farms Llc",
# "Dale A Crenwelge",
# "Dale Ann Santleben Cuppetilli",
# "Dale Bordelon",
# "Dale K Price",
# "Dale L Best",
# "Dale V Gaudier",
# "Dalgleish Land  Sea Lp",
# "Dallas Athletic Country Club",
# "Dallas Co Comm College Dist",
# "Dallas Country Club",
# "Dallas County",
# "Dallas County Community College District",
# "Dallas County Irrigation District No1",
# "Dallas County Park Cities Municipal Utility District",
# "Dallas County Utility  Reclamation District",
# "Dallas Hunting  Fishing Club Inc",
# "Dallasfort Worth Regional Airport Board",
# "Dalrymple Mildred Inks",
# "Damson 198182 Oil And Gas Income Fund  Series 19821",
# "Damson 198182 Oil And Gas Income Fund  Series 19822",
# "Damson 198283 Oil And Gas Income Fund  Series 19823",
# "Damson Consolidated Energy Income I",
# "Damson Institutional Series 82E1 Corporation",
# "Damson Oil Corporation",
# "Dan Riley Griffith",
# "Dan Robert Vestal",
# "Dan T Brady",
# "Dan Weldon Williams",
# "Dana Estep",
# "Dana G Sanditen",
# "Dana M Meador",
# "Dana Marie Kent",
# "Dana St Clair",
# "Dana T Oliver",
# "Dane Allison",
# "Dane Bolton",
# "Dane Mahan",
# "Daneil De La Rosa",
# "Daniel Acevedo",
# "Daniel Cordova",
# "Daniel Damon",
# "Daniel Durdin",
# "Daniel E Arnold",
# "Daniel H Crofut",
# "Daniel Jim Roy",
# "Daniel K Holy",
# "Daniel M Oliver",
# "Daniel M Rimkus",
# "Daniel Price",
# "Daniel R Walker",
# "Daniel Ray Bolf",
# "Danilo Lozano Jr",
# "Danis Bristow",
# "Dankworth J B",
# "Danny Barnett",
# "Danny Davis",
# "Danny R Fentress",
# "Darby B R Jr",
# "Darla F Card",
# "Darnell A Muenchow",
# "Darnell James C",
# "Darnell Terri",
# "Darrell Lyssy",
# "Darren Bullard",
# "Darwin Ray Nilsson",
# "Daryl Reber",
# "Dave R Edmiston",
# "Dave Wilcox",
# "Davenport Harris",
# "David A Cummings",
# "David A Davila",
# "David A Vance",
# "David And Leslie De Jong Family Limited Partnership",
# "David B Fletcher",
# "David Ballew",
# "David Barber",
# "David C Husfeld",
# "David C Young",
# "David Clay Kruckemeyer",
# "David Cruz Jr",
# "David Domingo Porras",
# "David E Carter",
# "David Egger",
# "David F Austin",
# "David G Geeslin",
# "David G Weinheimer",
# "David Gibson",
# "David H Guerra",
# "David Hopson",
# "David Jensen",
# "David John Kenley Revocable Trust",
# "David K Combs Trust",
# "David Kerce",
# "David Kirk",
# "David Kit Carlton",
# "David L Paz",
# "David L Reddell Ii",
# "David Lawrence Payne",
# "David Lehmann",
# "David M Henry",
# "David M King",
# "David M Kruger",
# "David Mark White",
# "David Michael Hixon 2011 Trust",
# "David Moody Trustee",
# "David P Granchukoff",
# "David Pate",
# "David Pfeuffer",
# "David Q Isaacs Jr",
# "David Q Isaacs Sr",
# "David Randolph Thormann",
# "David Ray Rabon",
# "David S Zachry",
# "David Swenson",
# "David T Gibson",
# "David T Hindman",
# "David W  Rosberg",
# "David W Philipp",
# "David William Jenny",
# "Davidson Barbara Ann",
# "Davila Ernesto S Dds",
# "Davina Patsy R",
# "Davis George W",
# "Davis Hazel T",
# "Davis Hugh Whitfield",
# "Davis J L",
# "Davis John D",
# "Davis Keith",
# "Davis Lloyd L",
# "Davis Louise G",
# "Davis Lucia M Garza",
# "Davis Mary A",
# "Davis Mcmahon Lp",
# "Davis Ray",
# "Davis Robert C",
# ...
# "Twin Creeks Allen Arcis Llc",
# "Twin Falls Ranch Ltd",
# "Twinell Johnson",
# "Twinwood Corporation Nv",
# "Twinwood Us Inc",
# "Two Star Development Inc",
# "Tye D Sims",
# "Tyler Matthew C",
# "Tyler Sand Company",
# "Tyler Staci L",
# "Tynes Anita L",
# "Tyus Billy Jack",
# "Tyus Patsy",
# "Ubar Ranch Inc",
# "Ullmann Nell Frances",
# "Ullmann Richard E",
# "Umphrey Family Limited Partnership",
# "Umphrey Walter",
# "Union Carbide Corporation",
# "Union Design Developers Lp",
# "Union Pacific Railroad Company",
# "Verstuyft Marvin G",
# "Verstuyft Merlynn B",
# "Verstuyft Patricia J",
# "Verstuyft Rodger G",
# "Vestry Lp",
# "Veterans Of Foreign Wars Of The United States",
# "Vezetti Isabel Garcia",
# "Vicki Lee Williams",
# "Vicki Powers",
# "Vickie Deike",
# "Victor Earl Garrett",
# "Victor Manuel Garza",
# "Victor Padilla",
# "Victor Salguero",
# "Victoria County Navigation District",
# "Victoria County Port Facilities Corporation",
# "Victoria M Contreras",
# "Victoria V Martinez",
# "Victoria Wle Lp",
# "Vidal Farias Vela",
# "Vidaurri Gerardo",
# "Vidaurri Jorge",
# "Vidaurri Juan Javier",
# "Vidaurri Julia T",
# "Vieman John D",
# "Viereck Helen Raaz",
# "Viktorin Gladys K",
# "Villarreal Blas Jr",
# "Villarreal Dora G",
# "Villarreal Elida",
# "Villarreal Fidel",
# "Villarreal Francisco G",
# "Villarreal Marisela",
# "Villarreal Martha",
# "Villarreal Oscar Jesus",
# "Villarreal Ramiro",
# "Villarreal Santos",
# "Vimosa Ii",
# "Vincent Drexell S",
# "Vincent Jerry Lee",
# "Vincent Nancy L",
# "Vineyard Billy John",
# "Vinson David W",
# "Vinson Ionah",
# "Viola E Kautz",
# "Virden Tony",
# "Virden Wanda",
# "Virgil Keith Anderson",
# "Virginia A Leonard Marital Trust",
# "Virginia A Lovell",
# "Virginia Ann Parker",
# "Virginia Hill Family Revocable Trust",
# "Virginia Margo Jones",
# "Virginia Turner Brooks",
# "Vista Del Mar Irrigation Company",
# "Vitera Harry E",
# "Viterbo Jules R",
# "Viterbo Verne D Jr",
# "Vitro Flat Glass Llc",
# "Vivian L Barbee",
# "Viviana Galvan",
# "Vizza Wash Inc",
# "Vmk Ranch Llc",
# "Vns  Cls Partners Ltd",
# "Volpe Adam",
# "Vopak Moda Houston Llc",
# "Vopak Terminal Deer Park Inc",
# "Voth B P",
# "Voth Brothers",
# "Vrazel Trust",
# "Vulcan Lands Inc",
# "Vulgamore Family Farms Llc",
# "W B Giles",
# "W B Griffith",
# "W C Moody Sr",
# "W C Smith Children Trust",
# "W E Scarborough Estate",
# "W F Company Ltd",
# "W G Burrell Estate",
# "W Glenn Bell Jr",
# "W J Mcknight Estate",
# "W J Stricklin",
# "W L Flowers Machine And Welding Co Inc",
# "W Moreland By Pass Trust",
# "W O Rankin",
# "W S Glover",
# "W Scott Campbell",
# "W6 Ranch Llc",
# "Wade Finas D",
# "Wade L Pennington",
# "Waggoner James E",
# "Wagner Cyril Jr",
# "Wagner Enterprises Inc",
# "Waite Sharon Rees",
# "Waitz Super Market Inc",
# "Wakefield Jimmy H",
# "Walden Family Properties Ltd",
# "Walker Aleen Taylor",
# "Walker Barbara J",
# "Walker Billy O",
# "Walker Darline L",
# "Walker Doyle",
# "Walker Harold H",
# "Walker Kenneth H",
# "Wallace Birkes",
# "Wallace Gilbert B Iii",
# "Wallace Maddox",
# "Wallace Mchenry",
# "Waller Edward Boggs Estate",
# "Walls Irene C",
# "Walls William Jr",
# "Walnut Canyon Ranch Llc",
# "Walnut Creek Farms Of Granbury Inc",
# "Walnut Creek Management Corporation",
# "Walnut Creek Mining Company",
# "Walsh Bessie",
# "Walsh Ranches Limited Partnership",
# "Walter Charles Bolton",
# "Walter Development Corporation",
# "Walter Holik Jr",
# "Walter Holmsten Ii 2012 Decendants Trust",
# "Walter Mazurek",
# "Walters Investments Lp",
# "Wanda Brown Roberts",
# "Wanda Bynum",
# "Wanda Dean Trust",
# "Wanda Deboer",
# "Wanda J Hollon",
# "Wanda L Crow",
# "Wanda Lagow",
# "Wanda Sue Sansom",
# "Wanda Teel",
# "Ward Anna Maria",
# "Wardlaw Jane Mary Ellis",
# "Warlick Leonard T",
# "Warlick Mattie Y",
# "Warner B Croft",
# "Warren D B",
# "Warren Family Ranch Partnership",
# "Warren James A",
# "Warren Jatzlau",
# "Warren John Iv",
# "Warren Kirby J",
# "Warren Kirby Jack",
# "Warren M Woelfel",
# "Warren T J",
# "Warren William B Ii",
# "Warrens Turf Nursery Inc",
# "Washington Bonnie Jean",
# "Washington Clarence",
# "Waterfront Club Acquisitions Llc",
# "Waters Edge",
# "Waters Edge Property Owners Association Inc",
# "Waters Edge Ranch Property Owners Association",
# "Waters Louis A",
# "Waters Ridge Limited Partnership",
# "Watkins Cynthia A",
# "Watson Acy L",
# "Watson James T",
# "Watson Robert L G",
# "Watts Herbert J",
# "Watts John H Iii",
# "Watts Kathleen A",
# "Watts Martha M",
# "Watts Maurine K",
# "Waxahachie Country Club",
# "Waymon G Peavy Trust",
# "Wayne E Partain",
# "Wayne F Creek",
# "Wayne Newkumet",
# "Wayne R Shahan",
# "Wayne Weeks",
# "Wbh Ranches Lp",
# "Wbw Development Group Llc",
# "Wdw Llc",
# "Weathers Julia B Muller",
# "Weaver Alvin",
# "Weaver Andrea",
# "Weaver Antonio",
# "Weaver Bobby A",
# "Weaver Edna E",
# "Weaver Joe Roy",
# "Weaver Manuel",
# "Weaver Nancy C",
# "Weaver Olga",
# "Weaver Olga M",
# "Weaver Paul Alexander Jr",
# "Weaver Tony",
# "Webb Carroll F",
# "Webb County",
# "Webb Florene Goodman",
# "Webb Hill Country Club Inc",
# "Webb James Patrick Kenneth",
# "Webb Jess",
# "Weedon Joe Dan",
# "Wehmeyer Willie A Jr",
# "Weid Nobert",
# "Weinacht Charles",
# "Weinacht Don",
# "Weinheimer Edmund A Jr",
# "Weinzapfel Henry G",
# "Weirgate Lumber Company Inc",
# "Weirich Bros Inc",
# "Weiss Alice Mae",
# "Weiss Hans",
# "Weiss Waltraud",
# "Weitz Elsie A",
# "Weitz Robert D",
# "Welch Kenneth Roy",
# "Welder Patrick Hughes Jr",
# "Welder Wildlife Foundation",
# "Weldon Joyce",
# "Weldon S Laas",
# "Weldon Troy D",
# "Weldon W Alders",
# "Wellborn Bobby J",
# "Wells A A",
# "Wells Branch Muncipal Utility District",
# "Wells Don",
# "Wells James Alexander",
# "Wells Jay Larry",
# "Wells Joyce Wood",
# "Wells Land  Cattle Company Inc",
# "Wells Robert C",
# "Wells Wayne William",
# "Wells Weldon S",
# "Wendal Lee Phillips Family Partnership Ltd",
# "Wende Lynne Quintanilla",
# "Wentz Milton E Jr",
# "Wenzel Floyd A",
# "Wesley Ray Carson",
# "West Carol A",
# "West Central Texas Municipal Water District",
# "West Harvey A",
# "West Lakes Club Inc",
# "West Margie Carol",
# "West Rose M Maha",
# "West Texas Boys Ranch",
# "Westbrook Eva Sue",
# "Westerfield Ira H",
# "Western Lake Estates Owners Association",
# "Westerra Stonebridge Lp",
# "Westover Land And Livestock Company",
# "Westwood Country Club Inc",
# "Westwood Shores Property Owners Association",
# "Westworth Redevelopment Authority",
# "Wetsel K Stan",
# "Wharton County Generation Llc",
# "Wheat Josiah",
# "Wheatcraft Curtis J",
# "Wheatcraft Inc",
# "Wheelus C Daniel",
# "Whisenhunt Mary Jane",
# "Whisenhunt W N",
# "Whitaker Terry M",
# "Whitaker Vicki L",
# "White Carol Joan Graves",
# "White Eugene",
# "White J W",
# "White Katherine Choate",
# "White Leland R",
# "White Nancy Elizabeth",
# "White Oak Resources Vi Llc",
# "White Oak Springs Poa",
# "White River Municipal Water District",
# "White Settlement West  Teslin Master Joint Venture",
# "White William C",
# "Whitehead C J",
# "Whitehead Properties Incorporated",
# "Whitehead Robert",
# "Whitley Jon Bill",
# "Whitley Wayne M",
# "Whitlow Lori D",
# "Whitlow Warren D",
# "Whitman Carey C",
# "Whitman Connie",
# "Whitman Frances A",
# "Whittle Charles",
# "Whitwell M C",
# "Whitwell Wanda",
# "Wichita County Water Improvement District 2",
# "Wichita Partnership Ltd",
# "Wied William Mark",
# "Wiedebusch Nona Fa",
# "Wiedebusch Reginald R",
# "Wiese Benjamin F Iv",
# "Wiggins Land Company Of Texas Inc",
# "Wiggins Matthew H",
# "Wiggins Susan F",
# "Wigginton Elaine",
# "Wigginton Gaynard",
# "Wiggs Land And Cattle Llc",
# "Wilber B E",
# "Wilber C C",
# "Wilber Charles Lee",
# "Wilber Dorothy Nell",
# "Wilber W L",
# "Wilbert O Dernehl Jr",
# "Wilbowfairview No 1 Development Corporation",
# "Wilburn Becky",
# "Wilburn James D",
# "Wilda E Turner",
# "Wildwood Property Owners Association",
# "Wilfong Birch",
# "Wiliam David Smith",
# "Wilkins Alice Williams",
# "Wilkins Kenneth",
# "Wilkins Tom",
# "Wilkinson Donna Gail",
# "Wilkinson Gary Wayne",
# "Wilkinson George W",
# "Wilkinson Nancy G",
# "Wilkinson Rock H",
# "Will D Brown Testamentary Trust",
# "Willacy County Navigation District",
# "Willard Harvey Zumwalt",
# "Willard L Burk",
# "Willberg Family Trust",
# "Willberg Wilma B",
# "William A Ansley",
# "William A Messer Iii",
# "William A Messer Iv",
# "William Arthur Roane Land Trust",
# "William B Farr",
# "William Batts Hodges",
# "William C Isaacs",
# "William Dan Schneemann",
# "William Douglas Forrest",
# "William F Garrison",
# "William G Bredthauer",
# "William Gavranovic",
# "William Gould Brown",
# "William Gregory Thaggard",
# "William H Armstrong Ii Trustee",
# "William H Cunningham",
# "William Henderson Iii",
# "William I Henderson",
# "William J Alguire",
# "William J Pagach",
# "William J Thomas",
# "William Jeffery Vaughan",
# "William Joseph Cohn",
# "William K Boyd",
# "William Keaton Blackburn",
# "William Linn Owen Iii",
# "William Milton North",
# "William O Carter Trustee",
# "William O Maedgen Iii",
# "William P Gossett",
# "William P Thedford",
# "William Paul Slobojan",
# "William R Seifman",
# "William Reneau",
# "William Stokes",
# "William T Bayern",
# "William T Crumley",
# "William Travis Byrd Jr",
# "William W Bivins Iii",
# "Williams Bobby Dean",
# "Williams Clayton W Jr",
# "Williams Drace",
# "Williams Francis",
# "Williams George Jr",
# "Williams George M Sr",
# "Williams J Mcdonald",
# "Williams Lee H Jr",
# "Williams Mozelle M",
# "Williams Raymond A Jr",
# "Williams Roy Lee",
# "Williams S A",
# "Williams Shanna",
# "Williams Shirley Ann Jenkins",
# "Williams Stella Elizabeth Wardl",
# "Williamson C W",
# "Williamson County Municipal Utility District 10",
# "Williamson County Municipal Utility District 11",
# "Williamson County Municipal Utility District 12",
# "Williamson County Municipal Utility District 15",
# "Williamson Pauline",
# "Willingham Coye",
# "Willingham I C",
# "Willingham William W Iii",
# "Willis B Simmons Inc",
# "Willis Fred",
# "Willis Ray Bynum",
# "Willis Wanda L",
# "Willmann Dian Eckert",
# "Willow Bend Lakes Master Homeowners Association Inc",
# "Willow Lake Estates Association",
# "Wilma Lemons",
# "Wilmeth Gray Mac",
# "Wilmeth Judy",
# "Wilson Charles W",
# "Wilson Charles W Sr",
# "Wilson D K",
# "Wilson Don H",
# "Wilson Dorothy",
# "Wilson Glynn A",
# "Wilson Henry Llc",
# "Wilson Isabel B",
# "Wilson Lake Maintenance Association Inc",
# "Wilson Loyd",
# "Wilson Mabel C",
# "Wilson Madeline",
# "Wilson Marjorie V",
# "Wilson Robert B",
# "Wilson Robert W",
# "Wilson Schoellkopf",
# "Wilson Steven",
# "Wilson Trust",
# "Wilson W Capron",
# "Wilson Wallace S",
# "Wilson Woodrow",
# "Wimpee Marc W",
# "Windermere",
# "Windrow John Robert",
# "Windrow Vivian Ward",
# "Windthorst Water Supply Corporation",
# "Windventures Llc",
# "Windy Hill Rents Llc",
# "Winfrey Glenn E",
# "Winfrey Peggy L",
# "Wingate H E",
# "Wingate Jim R",
# "Wingate Pansy E",
# "Wingshot Lp",
# "Winkenhower Mary",
# "Winn Marjorie D",
# "Winn William E",
# "Winnell Scott Rankin",
# "Winnsboro Fishing  Hunting Club",
# "Winterrowd Farms Inc",
# "Winters Sports And Recreation Association",
# "Wisdom William Jackson",
# "Wise Asset No 3 Ltd",
# "Wise Doug",
# "Wise James G",
# "Wishert Pat",
# "Wissemann Lillian M",
# "Wissemann Stanley",
# "Witzsche Ruth",
# "Witzsche Wilford",
# "Wl Curry",
# "Wocr Holding Llc",
# "Woehl Courtney",
# "Woelfel Darlene R",
# "Wolfe James W",
# "Wolfe Pecanlands Inc",
# "Wolfenbarger O K Jr",
# "Zigmond Farms Ltd",
# "Zimmerman Limited Partnership No 1",
# "Zl  Syk Llc",
# "Zoe Monique Wilbur Trust",
# "Zohn Milam",
# "Zona Ann Gatewood",
# "Zook Gary",
# "Zook Virginia",
# "Zuber Billie",
# "Zunker David Charlie",
# "Zwahr Kenneth L",

# %%
# group owner info by WR_ID
df_owner = df_owner.drop(['OID_'], axis=1) # drop unused columns
df_owner = df_owner.groupby('WR_ID').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem != ""])).replace(np.nan, "").reset_index()
print(len(df_owner))
df_owner.head()
# Out:
# 6228
#    WR_ID                                             OWNERS
# 0
# 1    C10                            Edward Mathers Farms Lp
# 2   C100  Carlota Coy Leal,Guzman Amelia Coy,Alfonso Est...
# 3  C1000      Wilson Dorothy,Wilson Robert W,Wilson Woodrow
# 4  C1001                                      Borden County

# %% [markdown]
# #### Ben Use Info

# %%
#Dataframe creation - ben use
useInput = "WaterUse.zip"
df_use = pd.read_csv(useInput).replace(np.nan, "")
print(len(df_use))
df_use.head(1)
# Out:
# 60313
#    OID_  WR_ID                          OWN_NAME     USE_NAME  YEAR  JAN_DIV  \
# 0     1  C1010  CHERYL J. HOYLE; NATHAN C. HOYLE  AGRICULTURE  2017  0.00000
#
#    FEB_DIV  MAR_DIV  APR_DIV  MAY_DIV  JUN_DIV  JUL_DIV  AUG_DIV  SEPT_DIV  \
# 0  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000   0.00000
#
#    OCT_DIV  NOV_DIV  DEC_DIV   TOTAL
# 0  0.00000  0.00000  0.00000 0.00000

# %%
# clean ben use info
df_use = df_use[['WR_ID', 'USE_NAME']].copy()
df_use['USE_NAME'] = df_use['USE_NAME'].str.strip().str.replace("  ", " ").str.title()

def fixBenUse(val):
    val = str(val).strip()
    if val == "Domestic And Livestock":
        outString = "Domestic, Livestock"
    elif val == "Domestic And Livestock & Livestock":
        outString = "Domestic, Livestock"
    elif val == "Non-Consumptive":
        outString = "Non Consumptive"
    elif val == "Instraem":
        outString = "Instream"
    elif val == "Wilflife Management":
        outString = "Wildlife Management"
    elif val == "Watwe Quality":
        outString = "Water Quality"
    elif val == "Minng":
        outString = "Mining"
    elif val == "Muncipal":
        outString = "Municipal"
    else:
        outString = val
    return outString

df_use['USE_NAME'] = df_use.apply(lambda row: fixBenUse(row['USE_NAME']), axis=1)
for x in df_use['USE_NAME'].sort_values().unique():
    print(f'"' + x + '",')
# Out:
# "Agriculture",
# "Aquaculture",
# "Chloride Control",
# "Domestic",
# "Domestic, Livestock",
# "Fire Fighting",
# "Flood Control",
# "Flood Control, Recreation",
# "Game Preserves",
# "Hydroelectric",
# "Industrial",
# "Instream",
# "Mariculture",
# "Mining",
# "Multi Use",
# "Municipal",
# "Navigation",
# "Non Consumptive",
# "Other",
# "Recharge",
# "Recreation",
# "Recreation, Water Quality",
# "Recreation, Wetlands",
# "Reuse",
# "Saltwater Barrier",
# "Storage",
# "Water Quality",
# "Wetlands",
# "Wildlife Management",

# %%
# group owner info by WR_ID
df_use = df_use.groupby('WR_ID').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem != ""])).replace(np.nan, "").reset_index()
print(len(df_use))
df_use.head()
# Out:
# 4559
#    WR_ID                                           USE_NAME
# 0  C1000                                        Agriculture
# 1  C1001                               Recreation,Municipal
# 2  C1002  Agriculture,Mining,Industrial,Recreation,Munic...
# 3  C1003                                        Agriculture
# 4  C1004                                        Agriculture

# %% [markdown]
# #### POD Surface water points info

# %%
# Input File
fileInput = "Water_Rights_As_Single_Points.zip"
dfinPOD = pd.read_csv(fileInput).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "txD" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('Water_Rights_As_Single_Points.zip', compression=dict(method='zip', archive_name='Water_Rights_As_Single_Points.csv'), index=False)

print(len(dfinPOD))
dfinPOD.head()
# Out:
# 15541
#    OID_           TCEQ_ID                           TYPE  VERIFIED wadeSiteID  \
# 0     1 10503942001.00000                Diversion Point         2      wade1
# 1     2 10503969001.00000                Diversion Point         2      wade2
# 2     3 10503969501.00000                Discharge Point         2      wade3
# 3     4 10504202201.00000  U/S Limit - Diversion Segment         2      wade4
# 4     5 10504202101.00000  D/S Limit - Diversion Segment         2      wade5
#
#    Latitude  Longitude LocationMethod  LocationAccuracy Reference  \
# 0  32.79544  -95.20610            DRG          12.00000     OTHER
# 1  32.60875  -95.09037            DRG          12.00000     OTHER
# 2  32.60286  -95.09196            DRG          12.00000     OTHER
# 3  32.72922  -95.43441            DRG          12.00000     OTHER
# 4  32.71574  -95.41702            DRG          12.00000     OTHER
#
#         LocationDate LocationOrganization  Datum  WR_ID  WR_TYPE_NO WaDEUUID
# 0  8/25/2008 0:00:00                 TCEQ  NAD83  P3942  WRPERM3942     txD0
# 1  8/25/2008 0:00:00                 TCEQ  NAD83  P3969  WRPERM3969     txD1
# 2  8/25/2008 0:00:00                 TCEQ  NAD83  P3969  WRPERM3969     txD2
# 3  8/25/2008 0:00:00                 TCEQ  NAD83  P4202  WRPERM4202     txD3
# 4  8/25/2008 0:00:00                 TCEQ  NAD83  P4202  WRPERM4202     txD4

# %%
# Assign owner name to POD

# Loop up dictonary using owner dataframe
OwnerDict = pd.Series(df_owner.OWNERS.values, index=df_owner.WR_ID).to_dict()

def retrieveOwner(val):
    if val == "" or pd.isnull(val):
        outString = ""
    else:
        String1 = str(val).strip()
        try:
            outString = OwnerDict[String1]
        except:
            outString = ""
    return outString

dfinPOD['in_AllocationOwner'] = dfinPOD.apply(lambda row: retrieveOwner(row['WR_ID']), axis=1)
dfinPOD['in_AllocationOwner'].unique()
# Out:
# array(['Peach Springs Nursery Llc', 'Tyler Sand Company', 'Kay H Walker',
#        ..., 'Our Savior Lutheran Church',
#        'Cinco Residential Property Association Inc',
#        'Cove Creek Corporation'], dtype=object)

# %%
# Assign ben use to POD

# Loop up dictonary using ben use dataframe
BenuseDict = pd.Series(df_use.USE_NAME.values, index=df_use.WR_ID).to_dict()

def retrieveBenUse(val):
    if val == "" or pd.isnull(val):
        outString = ""
    else:
        String1 = str(val).strip()
        try:
            outString = BenuseDict[String1]
        except:
            outString = ""
    return outString

dfinPOD['in_BeneficialUseCategory'] = dfinPOD.apply(lambda row: retrieveBenUse(row['WR_ID']), axis=1)
dfinPOD['in_BeneficialUseCategory'].unique()
# Out:
# array(['Agriculture', 'Mining', 'Agriculture,Industrial', 'Municipal',
#        'Domestic, Livestock', 'Industrial,Aquaculture', 'Recreation',
#        'Industrial,Recreation,Municipal', 'Industrial,Mining',
#        'Domestic, Livestock,Recreation', 'Agriculture,Recreation',
#        'Fire Fighting,Recreation,Municipal', 'Industrial,Recreation',
#        'Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Industrial,Municipal', 'Recreation,Municipal',
#        'Agriculture,Mining', 'Industrial',
#        'Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Agriculture,Industrial,Municipal',
#        'Agriculture,Mining,Wildlife Management,Industrial,Recreation',
#        'Domestic, Livestock,Mining', 'Agriculture,Industrial,Recreation',
#        'Agriculture,Recreation,Municipal',
#        'Wildlife Management,Industrial,Recreation,Aquaculture',
#        'Hydroelectric,Municipal', 'Flood Control',
#        'Hydroelectric,Agriculture,Industrial,Recreation,Municipal',
#        'Agriculture,Domestic,Industrial,Recreation,Municipal',
#        'Agriculture,Mining,Storage,Industrial,Recreation,Municipal',
#        'Industrial,Mining,Municipal', 'Flood Control,Agriculture',
#        'Agriculture,Industrial,Recreation,Municipal',
#        'Agriculture,Domestic, Livestock', 'Agriculture,Municipal',
#        'Agriculture,Industrial,Mining,Municipal',
#        'Recreation, Water Quality,Water Quality,Recreation',
#        'Wildlife Management,Recreation',
#        'Wildlife Management,Domestic, Livestock,Recreation',
#        'Recreation,Mining',
#        'Navigation,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Water Quality,Recreation, Water Quality,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Flood Control, Recreation,Recreation',
#        'Domestic, Livestock,Recreation,Mining',
#        'Multi Use,Industrial,Recreation,Municipal',
#        'Industrial,Recreation,Mining,Municipal', 'Non Consumptive,Mining',
#        'Multi Use,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Non Consumptive,Industrial',
#        'Agriculture,Industrial,Multi Use,Municipal',
#        'Agriculture,Multi Use,Industrial,Municipal',
#        'Recreation,Mining,Municipal',
#        'Multi Use,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Other,Municipal',
#        'Domestic, Livestock,Agriculture,Mining,Industrial,Municipal',
#        'Wetlands', 'Wildlife Management,Agriculture',
#        'Wildlife Management', 'Agriculture,Industrial,Recreation,Mining',
#        'Mining,Municipal', 'Non Consumptive,Industrial,Recreation',
#        'Water Quality,Agriculture,Mining,Industrial,Municipal',
#        'Wetlands,Multi Use,Agriculture,Industrial,Municipal',
#        'Agriculture,Storage', 'Domestic, Livestock,Industrial,Recreation',
#        'Agriculture,Industrial,Aquaculture',
#        'Multi Use,Agriculture,Mining,Industrial,Municipal',
#        'Agriculture,Mining,Storage,Industrial,Municipal',
#        'Mining,Domestic, Livestock,Industrial,Recreation',
#        'Recreation,Municipal,Storage',
#        'Multi Use,Agriculture,Industrial,Recreation,Municipal',
#        'Wetlands,Recreation',
#        'Domestic, Livestock,Multi Use,Agriculture,Mining,Industrial',
#        'Agriculture,Domestic, Livestock,Recreation',
#        'Agriculture,Domestic, Livestock,Industrial,Mining',
#        'Industrial,Multi Use,Agriculture,Non Consumptive,Recreation,Municipal',
#        'Hydroelectric', '',
#        'Domestic, Livestock,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal,Recharge',
#        'Instream,Domestic, Livestock,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Water Quality,Industrial', 'Agriculture,Wetlands',
#        'Agriculture,Industrial,Recreation,Aquaculture',
#        'Water Quality,Mining', 'Reuse,Agriculture,Industrial,Municipal',
#        'Water Quality',
#        'Instream,Hydroelectric,Agriculture,Mining,Industrial,Municipal',
#        'Water Quality,Industrial,Mining', 'Hydroelectric,Industrial',
#        'Agriculture,Municipal,Storage',
#        'Water Quality,Industrial,Mining,Municipal',
#        'Agriculture,Industrial,Mining', 'Instream,Agriculture',
#        'Domestic, Livestock,Municipal',
#        'Multi Use,Industrial,Agriculture,Municipal',
#        'Agriculture,Multi Use',
#        'Multi Use,Agriculture,Domestic,Industrial,Municipal',
#        'Agriculture,Recreation,Multi Use', 'Multi Use',
#        'Multi Use,Agriculture,Municipal', 'Navigation',
#        'Instream,Wildlife Management,Industrial,Recreation,Municipal',
#        'Municipal,Multi Use', 'Saltwater Barrier', 'Non Consumptive',
#        'Municipal,Industrial,Multi Use',
#        'Municipal,Agriculture,Multi Use',
#        'Agriculture,Industrial,Multi Use', 'Non Consumptive,Recreation',
#        'Multi Use,Municipal', 'Agriculture,Mining,Multi Use', 'Recharge',
#        'Industrial,Recreation,Aquaculture',
#        'Domestic, Livestock,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Domestic, Livestock,Multi Use,Domestic,Industrial,Municipal',
#        'Wildlife Management,Wetlands', 'Storage,Recharge',
#        'Agriculture,Municipal,Multi Use',
#        'Wildlife Management,Agriculture,Domestic, Livestock,Recreation',
#        'Agriculture,Industrial,Wetlands,Aquaculture',
#        'Agriculture,Recreation,Aquaculture',
#        'Agriculture,Mining,Municipal',
#        'Wildlife Management,Agriculture,Recreation', 'Chloride Control',
#        'Wildlife Management,Domestic, Livestock',
#        'Wildlife Management,Agriculture,Domestic, Livestock',
#        'Wetlands,Industrial,Agriculture,Municipal',
#        'Domestic, Livestock,Agriculture,Domestic,Industrial,Municipal',
#        'Wildlife Management,Domestic, Livestock,Game Preserves',
#        'Domestic, Livestock,Hydroelectric,Agriculture,Mining,Domestic,Industrial,Recreation,Municipal',
#        'Agriculture,Industrial,Wetlands',
#        'Recreation, Wetlands,Recreation',
#        'Domestic, Livestock,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Flood Control,Recreation', 'Domestic, Livestock,Industrial',
#        'Instream,Agriculture,Industrial,Recreation', 'Mining,Multi Use',
#        'Industrial,Recreation,Mining',
#        'Recreation, Wetlands,Wetlands,Recreation',
#        'Industrial,Recreation,Multi Use',
#        'Non Consumptive,Domestic, Livestock,Reuse,Domestic,Industrial',
#        'Wildlife Management,Agriculture,Recreation,Mining',
#        'Agriculture,Domestic, Livestock,Municipal',
#        'Agriculture,Industrial,Municipal,Multi Use', 'Instream',
#        'Instream,Agriculture,Recreation'], dtype=object)

# %%
# clean TYPE info
dfinPOD['TYPE'] = dfinPOD['TYPE'].str.strip().str.replace("  ", " ")

def fixBenUse(val):
    val = str(val).strip()
    if val == "On-channel Reservior":
        outString = "On-channel Reservoir"
    else:
        outString = val
    return outString

dfinPOD['TYPE'] = dfinPOD.apply(lambda row: fixBenUse(row['TYPE']), axis=1)   
for x in dfinPOD['TYPE'].sort_values().unique():
    print(f'"' + x + '",')
# Out:
# "D/S Limit - Discharge Segment",
# "D/S Limit - Diversion Segment",
# "D/S Limit - Release Segment",
# "Discharge Point",
# "Diversion Point",
# "Diversion Point - Well",
# "GW - Release Point",
# "IBT - Discharge Point",
# "IBT - Diversion Point",
# "IBT - Off-channel Diversion Pt",
# "IBT - Off-channel Reservoir",
# "IBT - On-channel Reservoir",
# "IBT - Release Point",
# "Off-channel Diversion Point",
# "Off-channel Release Point",
# "Off-channel Reservoir",
# "Off-channel Reservoir Complex",
# "On-channel Reservoir",
# "On-channel Reservoir Complex",
# "Other - Rec Use",
# "Release Point",
# "Return Flow Point",
# "U/S Dam",
# "U/S Limit - Discharge Segment",
# "U/S Limit - Diversion Segment",
# "U/S Limit - Release Segment",
# "WWTP Release Point",

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfinPOD['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "TXwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "TXwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "TXwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = "WaDE Blank" # need this for auto fill below
df['in_WaterSourceNativeID'] = "" # auto fill in below
df['in_WaterSourceTypeCV'] = "WaDE Blank" # need this for auto fill below

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = ""
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfinPOD['Latitude']
df['in_Longitude'] = dfinPOD['Longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"
df['in_SiteName'] = ""
df['in_SiteNativeID'] = "POD" + dfinPOD['wadeSiteID'].replace("", 0).fillna(0).astype(str)
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = dfinPOD['TYPE']
df['in_StateCV'] = "TX"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = "" #empty
df['in_AllocationLegalStatusCV'] = ""
df['in_AllocationNativeID'] =  dfinPOD['WR_ID'].replace("", 0).fillna(0).str.strip().astype(str)
df['in_AllocationOwner'] = dfinPOD['in_AllocationOwner']
df['in_AllocationPriorityDate'] = "" #empty
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = "" #empty
df['in_BeneficialUseCategory'] = dfinPOD['in_BeneficialUseCategory']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 1 # we want this data excempt
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = "https://gisweb.tceq.texas.gov/WRRetrieveRights/?ID=" + dfinPOD['WR_TYPE_NO'].replace("", 0).fillna(0).str.strip().astype(str)

outPOD = df.copy()
outPOD = outPOD.drop_duplicates().reset_index(drop=True)
print(len(outPOD))
outPOD.head()
# Out:
# 15541
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     txD0       TXwr_M1                 TXwr_V1             TXwr_O1
# 1     txD1       TXwr_M1                 TXwr_V1             TXwr_O1
# 2     txD2       TXwr_M1                 TXwr_V1             TXwr_O1
# 3     txD3       TXwr_M1                 TXwr_V1             TXwr_O1
# 4     txD4       TXwr_M1                 TXwr_V1             TXwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                                                 4326
# 1                                                                 4326
# 2                                                                 4326
# 3                                                                 4326
# 4                                                                 4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    32.79544     -95.20610
# 1                                    32.60875     -95.09037
# 2                                    32.60286     -95.09196
# 3                                    32.72922     -95.43441
# 4                                    32.71574     -95.41702
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                   POD
# 1                                                   POD
# 2                                                   POD
# 3                                                   POD
# 4                                                   POD
#
#   in_SiteNativeID in_SitePoint                  in_SiteTypeCV in_StateCV  \
# 0        PODwade1                             Diversion Point         TX
# 1        PODwade2                             Diversion Point         TX
# 2        PODwade3                             Discharge Point         TX
# 3        PODwade4               U/S Limit - Diversion Segment         TX
# 4        PODwade5               D/S Limit - Diversion Segment         TX
#
#   in_USGSSiteID in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationLegalStatusCV in_AllocationNativeID         in_AllocationOwner  \
# 0                                            P3942  Peach Springs Nursery Llc
# 1                                            P3969         Tyler Sand Company
# 2                                            P3969         Tyler Sand Company
# 3                                            P4202               Kay H Walker
# 4                                            P4202               Kay H Walker
#
#   in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeEnd in_AllocationTimeframeStart in_AllocationTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationVolume_AF in_BeneficialUseCategory  \
# 0                                     Agriculture
# 1                                          Mining
# 2                                          Mining
# 3                                     Agriculture
# 4                                     Agriculture
#
#   in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDate in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                                           1
# 1                                                                           1
# 2                                                                           1
# 3                                                                           1
# 4                                                                           1
#
#   in_GeneratedPowerCapacityMW in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://gisweb.tceq.texas.gov/WRRetrieveRights...
# 1  https://gisweb.tceq.texas.gov/WRRetrieveRights...
# 2  https://gisweb.tceq.texas.gov/WRRetrieveRights...
# 3  https://gisweb.tceq.texas.gov/WRRetrieveRights...
# 4  https://gisweb.tceq.texas.gov/WRRetrieveRights...

# %%
# Concatenate dataframes
frames = [outPOD]
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 15541

# %% [markdown]
# ## Inspect and Clean Data

# %%
# Ensure Empty String

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['Diversion Point', 'Discharge Point',
#        'U/S Limit - Diversion Segment', 'D/S Limit - Diversion Segment',
#        'On-channel Reservoir', 'IBT - Discharge Point', 'Release Point',
#        'Off-channel Reservoir', 'Off-channel Diversion Point',
#        'Off-channel Reservoir Complex', 'U/S Limit - Discharge Segment',
#        'D/S Limit - Discharge Segment', 'IBT - Diversion Point',
#        'On-channel Reservoir Complex', 'Return Flow Point',
#        'IBT - Off-channel Reservoir', 'IBT - Release Point',
#        'IBT - Off-channel Diversion Pt', 'Diversion Point - Well',
#        'U/S Dam', 'IBT - On-channel Reservoir', 'GW - Release Point',
#        'U/S Limit - Release Segment', 'D/S Limit - Release Segment',
#        'Off-channel Release Point', 'WWTP Release Point',
#        'Other - Rec Use'], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Peach Springs Nursery Llc', 'Tyler Sand Company', 'Kay H Walker',
#        ..., 'Our Savior Lutheran Church',
#        'Cinco Residential Property Association Inc',
#        'Cove Creek Corporation'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['Agriculture', 'Mining', 'Agriculture,Industrial', 'Municipal',
#        'Domestic, Livestock', 'Industrial,Aquaculture', 'Recreation',
#        'Industrial,Recreation,Municipal', 'Industrial,Mining',
#        'Domestic, Livestock,Recreation', 'Agriculture,Recreation',
#        'Fire Fighting,Recreation,Municipal', 'Industrial,Recreation',
#        'Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Industrial,Municipal', 'Recreation,Municipal',
#        'Agriculture,Mining', 'Industrial',
#        'Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Agriculture,Industrial,Municipal',
#        'Agriculture,Mining,Wildlife Management,Industrial,Recreation',
#        'Domestic, Livestock,Mining', 'Agriculture,Industrial,Recreation',
#        'Agriculture,Recreation,Municipal',
#        'Wildlife Management,Industrial,Recreation,Aquaculture',
#        'Hydroelectric,Municipal', 'Flood Control',
#        'Hydroelectric,Agriculture,Industrial,Recreation,Municipal',
#        'Agriculture,Domestic,Industrial,Recreation,Municipal',
#        'Agriculture,Mining,Storage,Industrial,Recreation,Municipal',
#        'Industrial,Mining,Municipal', 'Flood Control,Agriculture',
#        'Agriculture,Industrial,Recreation,Municipal',
#        'Agriculture,Domestic, Livestock', 'Agriculture,Municipal',
#        'Agriculture,Industrial,Mining,Municipal',
#        'Recreation, Water Quality,Water Quality,Recreation',
#        'Wildlife Management,Recreation',
#        'Wildlife Management,Domestic, Livestock,Recreation',
#        'Recreation,Mining',
#        'Navigation,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Water Quality,Recreation, Water Quality,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Flood Control, Recreation,Recreation',
#        'Domestic, Livestock,Recreation,Mining',
#        'Multi Use,Industrial,Recreation,Municipal',
#        'Industrial,Recreation,Mining,Municipal', 'Non Consumptive,Mining',
#        'Multi Use,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Non Consumptive,Industrial',
#        'Agriculture,Industrial,Multi Use,Municipal',
#        'Agriculture,Multi Use,Industrial,Municipal',
#        'Recreation,Mining,Municipal',
#        'Multi Use,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Other,Municipal',
#        'Domestic, Livestock,Agriculture,Mining,Industrial,Municipal',
#        'Wetlands', 'Wildlife Management,Agriculture',
#        'Wildlife Management', 'Agriculture,Industrial,Recreation,Mining',
#        'Mining,Municipal', 'Non Consumptive,Industrial,Recreation',
#        'Water Quality,Agriculture,Mining,Industrial,Municipal',
#        'Wetlands,Multi Use,Agriculture,Industrial,Municipal',
#        'Agriculture,Storage', 'Domestic, Livestock,Industrial,Recreation',
#        'Agriculture,Industrial,Aquaculture',
#        'Multi Use,Agriculture,Mining,Industrial,Municipal',
#        'Agriculture,Mining,Storage,Industrial,Municipal',
#        'Mining,Domestic, Livestock,Industrial,Recreation',
#        'Recreation,Municipal,Storage',
#        'Multi Use,Agriculture,Industrial,Recreation,Municipal',
#        'Wetlands,Recreation',
#        'Domestic, Livestock,Multi Use,Agriculture,Mining,Industrial',
#        'Agriculture,Domestic, Livestock,Recreation',
#        'Agriculture,Domestic, Livestock,Industrial,Mining',
#        'Industrial,Multi Use,Agriculture,Non Consumptive,Recreation,Municipal',
#        'Hydroelectric', '',
#        'Domestic, Livestock,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal,Recharge',
#        'Instream,Domestic, Livestock,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Water Quality,Industrial', 'Agriculture,Wetlands',
#        'Agriculture,Industrial,Recreation,Aquaculture',
#        'Water Quality,Mining', 'Reuse,Agriculture,Industrial,Municipal',
#        'Water Quality',
#        'Instream,Hydroelectric,Agriculture,Mining,Industrial,Municipal',
#        'Water Quality,Industrial,Mining', 'Hydroelectric,Industrial',
#        'Agriculture,Municipal,Storage',
#        'Water Quality,Industrial,Mining,Municipal',
#        'Agriculture,Industrial,Mining', 'Instream,Agriculture',
#        'Domestic, Livestock,Municipal',
#        'Multi Use,Industrial,Agriculture,Municipal',
#        'Agriculture,Multi Use',
#        'Multi Use,Agriculture,Domestic,Industrial,Municipal',
#        'Agriculture,Recreation,Multi Use', 'Multi Use',
#        'Multi Use,Agriculture,Municipal', 'Navigation',
#        'Instream,Wildlife Management,Industrial,Recreation,Municipal',
#        'Municipal,Multi Use', 'Saltwater Barrier', 'Non Consumptive',
#        'Municipal,Industrial,Multi Use',
#        'Municipal,Agriculture,Multi Use',
#        'Agriculture,Industrial,Multi Use', 'Non Consumptive,Recreation',
#        'Multi Use,Municipal', 'Agriculture,Mining,Multi Use', 'Recharge',
#        'Industrial,Recreation,Aquaculture',
#        'Domestic, Livestock,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Domestic, Livestock,Multi Use,Domestic,Industrial,Municipal',
#        'Wildlife Management,Wetlands', 'Storage,Recharge',
#        'Agriculture,Municipal,Multi Use',
#        'Wildlife Management,Agriculture,Domestic, Livestock,Recreation',
#        'Agriculture,Industrial,Wetlands,Aquaculture',
#        'Agriculture,Recreation,Aquaculture',
#        'Agriculture,Mining,Municipal',
#        'Wildlife Management,Agriculture,Recreation', 'Chloride Control',
#        'Wildlife Management,Domestic, Livestock',
#        'Wildlife Management,Agriculture,Domestic, Livestock',
#        'Wetlands,Industrial,Agriculture,Municipal',
#        'Domestic, Livestock,Agriculture,Domestic,Industrial,Municipal',
#        'Wildlife Management,Domestic, Livestock,Game Preserves',
#        'Domestic, Livestock,Hydroelectric,Agriculture,Mining,Domestic,Industrial,Recreation,Municipal',
#        'Agriculture,Industrial,Wetlands',
#        'Recreation, Wetlands,Recreation',
#        'Domestic, Livestock,Hydroelectric,Agriculture,Mining,Industrial,Recreation,Municipal',
#        'Flood Control,Recreation', 'Domestic, Livestock,Industrial',
#        'Instream,Agriculture,Industrial,Recreation', 'Mining,Multi Use',
#        'Industrial,Recreation,Mining',
#        'Recreation, Wetlands,Wetlands,Recreation',
#        'Industrial,Recreation,Multi Use',
#        'Non Consumptive,Domestic, Livestock,Reuse,Domestic,Industrial',
#        'Wildlife Management,Agriculture,Recreation,Mining',
#        'Agriculture,Domestic, Livestock,Municipal',
#        'Agriculture,Industrial,Municipal,Multi Use', 'Instream',
#        'Instream,Agriculture,Recreation'], dtype=object)

# %%
# in_Latitude
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([32.79544371, 32.60875158, 32.60286437, ..., 29.66044217,
#        29.62854717, 29.62761517])

# %%
# in_Longitude
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-95.20610292, -95.09037256, -95.09195996, ..., -95.55312805,
#        -95.51472403, -95.51399603])

# %%
#Update datatype of Priority Date to fit WaDE 2.0 structure
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'])
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# array(['NaT'], dtype='datetime64[ns]')

# %%
# Fixing in_AllocationFlow_CFS datatype
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([''], dtype=object)

# %%
# Fixing in_AllocationVolume_AF datatype
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array([''], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)
dfWaterSourceNativeID['linkKey'] = dfWaterSourceNativeID['in_WaterSourceName'].astype(str) + dfWaterSourceNativeID['in_WaterSourceTypeCV'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
WaterSourceNativeIDdict = pd.Series(dfWaterSourceNativeID.in_WaterSourceNativeID.values, index=dfWaterSourceNativeID.linkKey.astype(str)).to_dict()
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        colrowValue = str(A).strip() + str(B).strip()
        try:
            outList = WaterSourceNativeIDdict[colrowValue]
        except:
            outList = ''
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array([''], dtype=object)

# %% [markdown]
# ## Export Data

# %%
# Export the output dataframe
outdf.to_csv('Pwr_txMain.zip', compression=dict(method='zip', archive_name='Pwr_txMain.csv'), index=False) # The output, save as a zip
#dfPoUshape.to_csv('P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
