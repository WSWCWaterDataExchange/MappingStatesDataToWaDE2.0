# %% [markdown]
# # Pre-processing (state / organization Name) Allocation data for WaDE upload.
# - Purpose:  To pre-process the data into one master file for simple DataFrame creation and extraction

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Texas/WaterAllocation_TWDB" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Texas/WaterAllocation_TWDB

# %% [markdown]
# ## Point of Diversion Data

# %%
# Input File
FI_PoD = "RawInputData/TWDB_Groundwater.csv"
dfinPOD = pd.read_csv(FI_PoD, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "txD" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('RawInputData/TWDB_Groundwater.zip', compression=dict(method='zip', archive_name='TWDB_Groundwater.csv'), index=False)

print(len(dfinPOD))
dfinPOD.head()
# Out:
# 141605
#    StateWellN                        OwnerName     PrimaryWat  Elevation  \
# 0      657116              1. B. Dugger Estate     Irrigation       3722
# 1      657118                      L. W. Smith     Irrigation       3679
# 2      657207  Amarillo Municipal Water System  Public Supply       3705
# 3      657209                   Ervin Podzemny     Irrigation       3707
# 4      657211              Caroline Bush Emery     Irrigation       3685
#
#    WellDepth                  WaterLevel WaterQuali  \
# 0  275.00000                                      N
# 1  274.00000  Miscellaneous Measurements          N
# 2  305.00000  Miscellaneous Measurements          Y
# 3  285.00000  Miscellaneous Measurements          N
# 4  258.00000  Miscellaneous Measurements          N
#
#                      AquiferCod  CoordDDLat  CoordDDLon CountyName  \
# 0  121OGLL - Ogallala Formation    35.11361  -101.97611    Randall
# 1  121OGLL - Ogallala Formation    35.08500  -101.98695    Randall
# 2  121OGLL - Ogallala Formation    35.11722  -101.94889    Randall
# 3  121OGLL - Ogallala Formation    35.10556  -101.94611    Randall
# 4  121OGLL - Ogallala Formation    35.10195  -101.95278    Randall
#
#               WellType WaDEUUID
# 0  Withdrawal of Water     txD0
# 1  Withdrawal of Water     txD1
# 2  Withdrawal of Water     txD2
# 3  Withdrawal of Water     txD3
# 4  Withdrawal of Water     txD4

# %%
def extractNativeIDFunc(A):
    A = str(A).strip()
    try:
        outString = A.split('-')[1]
    except:
        outString = A
    return outString
dfinPOD['nativeName'] = dfinPOD.apply(lambda row: extractNativeIDFunc(row['AquiferCod']), axis=1)
dfinPOD['nativeName'].unique()
# Out:
# array([' Ogallala Formation', ' Dockum Formation', ' Quaternary Alluvium',
#        ' Alluvium', 'APPL ', ' Paluxy Sand',
#        ' Travis Peak Formation and Paluxy Sand', ' Midway Group',
#        ' Nacatoch Sand', ' Ogallala Formation and Dockum Formation',
#        ' Ochoan Series', ' Wilcox Group', ' Seymour Formation',
#        ' Blossom Sand', ' Taylor Marl', ' San Angleo Formation',
#        ' Fredericksburg Group', ' Alluvium and Ogallala Formation',
#        ' Purgatoire and Morrison Formations',
#        ' Quartermaster Formation and Whitehorse Group',
#        ' Terrace Deposits', ' Canyon Group', ' Whitehorse Group',
#        ' Jurassic System',
#        ' Ogallala Formation, Dakota Group and Purgatoire Formation',
#        ' Ogallala and Morrison Formations',
#        ' Dakota Group, Purgatoire Formation and Jurassic',
#        ' Aquifer Not Able to be Determined',
#        ' Dakota Group and Purgatoire Formation', ' Hosston Formation',
#        ' Choza Formation', ' Wichita Formation or Group',
#        ' Tahoka and Ogallala Formations',
#        ' Alluvium and High Terrace Deposits',
#        ' Ogallala Formation and Fredericksburg Group', ' Antlers Sand',
#        ' Blaine Formation', ' Antlers Sand and Dockum Formation',
#        ' Cypress Aquifer', ' Alluvium and Antlers Sand',
#        ' Quaternary System', ' Fredericksburg and Trinity Groups',
#        ' Glen Rose (Lower), Pearsall (Hensell, Cow Creek), Sligo & Hosston Fms',
#        ' Travis Peak Formation', ' Woodbine Sand', ' Glen Rose Limestone',
#        ' Ogallala Formation and Dakota Group', ' Clear Fork Group',
#        ' Tahoka Formation, Fredericksburg Group and Antlers Sand',
#        ' Pease River Group', ' Trinity Group',
#        ' Reklaw Formation and Carrizo Sand', ' Twin Mountains Formation',
#        ' Pearsall Formation', ' Permian System',
#        ' Ogallala Formation, Fredericksburg Group and Antlers Sand',
#        ' Cenozoic Pecos Alluvium', ' Eagle Ford Group',
#        ' Wilcox and Midway Groups', ' Queen City Sand of Claiborne Group',
#        ' Seymour Formation and Clear Fork Group', ' Dune Sand',
#        ' Mineral Wells Formation',
#        ' Alluvium, Low Terrace and Channel Fill Deposits and Ogallala Formation',
#        ' Ogallala Formation and Whitehorse Group',
#        ' Dog Creek Shale and Blaine Gypsum',
#        ' Fort Worth Limestone and Duck Creek Formation, Undivided',
#        ' Paleozoic Erathem', ' Gober Tongue of Austin Chalk',
#        ' Alluvial Plain Deposits and Whitehorse Group',
#        ' Merkel Dolomite Member of Choza Formation',
#        ' Alluvial Channel and Plain Deposits and Ochoa Series',
#        ' Alluvium and Permian System', ' Hickory Sandstone',
#        ' Cisco Group', ' Alluvium and Carrizo Sand',
#        ' Alluvium and Vale Formation', ' Pueblo Formation',
#        ' Sparta Sand',
#        ' Alluvium, High Terrace Deposits and Whitehorse Group',
#        ' Reklaw Formation of Claiborne Group',
#        ' Seymour and Choza Formations',
#        ' Dog Creek Shale, Blaine Gypsum and Flowerpot Shale',
#        ' Dune Sand and Ogallala Formation', ' Cambrian System',
#        ' Admiral Formation', ' Paluxy Sand and Glen Rose Limestone',
#        ' Bullwagon Dolomite Member of Vale Formation', ' Vale Formation',
#        ' Belle Plains Formation', ' Carrizo Sand', '', ' Moran Formation',
#        ' Ogallala Formation, Dakota Group, Purgatoire Formation and Jurassic',
#        ' Exeter Sandstone', ' Artesia Group',
#        ' Ogallala Formation and Antlers Sand', ' Austin Chalk',
#        ' Paluxy and Twin Mountains Formations', ' Tahoka Formation',
#        ' Alluvium and Fluviatile Terrace Deposits',
#        ' Windblown Sand, Quaternary', ' Pleistocene Series',
#        ' Choza Formation and Bullwagon Dolomite',
#        ' Alluvial Plain Deposits',
#        ' Whitehorse Group, Dog Creek and Blaine Formations',
#        ' Comanche Peak Limestone', ' Wolf Mountain Shale',
#        ' Arroyo Formation', ' Ellenburger Group', ' Thrifty Formation',
#        ' Graham Formation', ' Pennsylvanian System',
#        ' Palo Pinto Limestone',
#        ' Trinity Sand, Graham Formation and Home Creek Limestone',
#        ' Wolf Mountain and Posideon Shales', ' Colony Creek Shale',
#        ' Thrifty and Graham Formations', ' Pawpaw Formation',
#        ' Woodbine and Paluxy Formations',
#        ' Alluvial Plain Deposits, Blaine Gypsum and Dog Creek Shale',
#        ' Alluvial Terrace and Channel Deposits',
#        ' Alluvium and Blaine Gypsum', ' Wichita and Cisco Groups',
#        ' Woodbine Sand and Paluxy and Hosston Formations',
#        ' Glen Rose Limestone and Twin Mountains Formation',
#        ' Antlers Sand and Permian Rocks',
#        ' Wolfe City Sand Member of Taylor Marl', ' Strawn Group',
#        ' Twin Mountains and Mineral Wells Formations',
#        ' Twin Mountains Formation and Pennsylvanian Rocks',
#        ' Placid Shale',
#        ' Wolf Mountain Shale, Posideon Shale and Palo Pinto Limestone',
#        ' Hensell Sand and Hosston Formation',
#        ' Colony Creek Shale, Ranger Limestone and Placid Shale',
#        ' Queen City Sand and Carrizo Sand',
#        ' Alluvium and Clear Fork Group',
#        ' Dakota Group, Lytle, Morrison and Exeter',
#        ' Dakota Sandstone or Formation',
#        ' Ogallala and Purgatoire Formations', ' Quartermaster Formation',
#        ' Alluvium and Artesia Group', ' Lueders Limestone',
#        ' Alluvium, Low Terrace and Channel Fill Deposits',
#        ' Ogallala Formation, Purgatoire Formation and Jurassic',
#        ' Alluvium, Low Terrace and Channel Fill Deposits and Whitehorse Group',
#        ' Navarro Group', ' Bonham Marl',
#        ' Alluvium, Terrace Deposits, Seymour Formation and Blaine Formation',
#        ' Edwards and Associated Limestones, Antlers Sand and Dockum Formation',
#        ' Alluvium and Queen City Sand', ' Navarro and Taylor Groups',
#        ' Alluvium and Arroyo Formation',
#        ' Alluvium, Choza Formation and Bullwagon Dolomite',
#        ' Upper Cretaceous Series',
#        ' Carrizo Sand and Wilcox Group, Undifferentiated',
#        ' Putnam Formation',
#        ' Hensell Sand Member of Travis Peak Formation',
#        ' Cretaceous System', ' Mineral Wells and Brazos River Formations',
#        ' Alluvium and Austin Chalk', ' Walnut Clay',
#        ' Dockum Formation and Permian Rocks', ' Harpersville Formation',
#        ' Trinity Sand and Graham Formation',
#        ' Edwards and Associated Limestones and Antlers Sand',
#        ' Alluvial Terrace and Channel Deposits and Whitehorse Group',
#        ' Alluvial Terrace and Channel Deposits and Flowerpot Shale',
#        ' Alluvium, Flood Plain', ' Weches Formation of Claiborne Group',
#        ' Alluvium and Terrace Deposits',
#        ' Queen City Sand and Reklaw Formation', ' Jasper Aquifer',
#        ' Kiamichi Formation', ' Woodbine Sand and Trinity Group',
#        ' Antlers Sand and Pennsylvanian Rocks',
#        ' Sparta Sand and Queen City Sand', ' Petrolia Formation',
#        ' Chicot Aquifer', ' Choza and Vale Formations',
#        ' Cane River Formation', ' Archer City Formation',
#        ' Flowerpot Shale', ' Wolfcamp Formation',
#        ' Alluvium and Wichita Group', ' Purgatoire Formation',
#        ' Alluvium and Dockum Formation', ' Washita Group',
#        ' Cook Mountain Formation', ' Lower Jackson Unit',
#        ' Lower Yegua Unit and Underlying Unit', ' Yegua Formation',
#        ' Fredericksburg Group and Antlers Sand', ' Edwards Limestone',
#        ' Queen City Sand, Carrizo Sand and Wilcox Group',
#        ' Palo Pinto Formation', ' Avis Sandstone',
#        ' Colony Creek and Placid Shales', ' Catahoula Formation',
#        ' Winchell Limestone',
#        ' Brazos River Conglomerate Member, Lower Part of Garner Formation',
#        ' Brazos River Conglomerate Member, Upper Part of Garner Formation',
#        ' Jackson Group', ' Upper Jackson Unit', ' Upper Yegua Unit',
#        ' Home Creek Limestone', ' Alluvium and Choza Formation',
#        ' Simsboro Sand Member of Rockdale Formation',
#        ' Edwards and Associated Limestones and Trinity Group',
#        ' Alluvium and Edwards and Associated Limestones', ' Volcanics',
#        ' Igneous Rocks', ' Gulf Coast Aquifer', ' Rustler Formation',
#        ' Dimple Limestone', ' Markley Formation',
#        ' Alluvium and Cisco Group', ' Gonzales Creek Member',
#        ' Leona Formation', ' Calvert Bluff Formation',
#        ' Edwards and Associated Limestones',
#        ' Yegua Formation and Jackson Group', ' Canyon and Cisco Groups',
#        ' Alluvium, Brazos River', ' Queen City Sand and Sparta Sand',
#        ' Alluvium and Cretaceous Rocks',
#        ' Glen Rose Limestone and Hensell Member of Pearsall Formation',
#        ' Pecos Aquifer', ' Paluxy Formation and Permian Rocks',
#        ' Capitan Reef Complex and Associated Limestones',
#        ' Lagarto Clay and Oakville Sandstone',
#        ' Ochoan Series and Artesia Group',
#        ' Cenozoic Pecos Alluvium and Cretaceous Rocks',
#        ' Hensell Sand and Pearsall Formation',
#        ' Igneous Rocks (Cretaceous)',
#        ' Leona Formation and Choza Formation', ' Hooper Formation',
#        ' Pearsall and Hosston Formations', ' Ellenburger Group and Post',
#        ' Leona Formation and Bullwagon Dolomite',
#        ' Ellenburger Group and Cambrian Rocks', ' Pecos River Alluvium',
#        ' Palo Pinto Formation and Turkey Creek Sandstone',
#        ' Fort Pena Formation and Alsate Shale, Undifferentiated',
#        ' Marathon Limestone', ' Alluvium and Tertiary Volcanics',
#        ' Standpipe Limestone Member of Arroyo Formation',
#        ' Marathon Limestone and Dagger Flat Sandstone, Undifferentiated',
#        ' Caballos Novaculite and Maravillas Chert, Undifferentiated',
#        ' Leona Formation and San Angelo Sandstone',
#        ' Glen Rose Limestone, Upper Member', ' Haymond Formation',
#        ' Cook Mountain Formation and Carrizo Sand', ' Ranger Limestone',
#        ' Placid Shale, Winchell Limestone and Wolf Mountain Shale',
#        ' Alluvium and Canyon Group',
#        ' Alluvium and Lower Cretaceous Rocks',
#        ' Cenozoic Pecos Alluvium and Lower Cretaceous Rocks',
#        ' Fredericksburg Group and Glen Rose Limestone',
#        ' Alluvium, Edwards and Associated Limestones and Trinity Sands',
#        ' Placid Shale and Wolf Mountain Formation',
#        ' Ordovician Rocks, Undifferentiated', ' San Andres Limestone',
#        ' Glen Rose LS and Hensell SH and Cow Creek LS Members of Pearsall FM',
#        ' Edwards and Associated Limestones ', ' Tesnus Formation',
#        ' Hensell and Cow Creek Mbrs of Pearsall Formation and Sligo and Hosston',
#        ' Cow Creek Limestone',
#        ' Cenozoic Pecos Alluvium and Dockum Formation',
#        ' Welge Sandstone', ' Seven Rivers Formation',
#        ' Alluvium and Wilcox Group',
#        ' Ellenburger Group and San Saba Limestone',
#        ' Edwards and Associated Limestones and Upper Mbr of Glen Rose Limestone',
#        ' Edwards and Associated Limestones and Glen Rose Limestone',
#        ' Glen Rose Limestone, Lower Member', ' Capitan Limestone',
#        ' Leona Formation and Antlers Sands',
#        ' Limestones of Fredericksburg and Washita Groups',
#        ' Morgan Creek Limestone and Welge Sandstone',
#        ' Ellenburger Group and Hickory Sandstone',
#        ' Delaware Mountain Formation or Group',
#        ' Upper Glen Rose, Hensell and Cow Creek Members of Pearsall Formation',
#        ' Welge and Lion Mountain Sandstones', ' Wilberns Formation',
#        ' Hensell Sand and Cow Creek Limestone',
#        ' Cenozoic Pecos Alluvium, and Dockum and Rustler Formations',
#        ' Precambrian Erathem', ' San Saba Limestone',
#        ' Alluvium, Colorado River', ' Lower Cretaceous Series',
#        ' Hosston Formation and Cow Creek Limestone',
#        ' Valley Spring Gneiss', ' Packsaddle Schist',
#        ' Jackson Group and Yegua Formation', ' Georgetown Limestone',
#        ' Riley Formation',
#        ' Trinity (Hensell Sand) and Ellenburger Group',
#        ' Salt Bolson and Delaware Mountain Group',
#        ' Pearsall, Sligo and Hosston Formations',
#        ' Salt Bolson and Cretaceous Rocks', ' Honeycut Formation',
#        ' Sligo and Hosston Formations',
#        ' Glen Rose Limestone, Lower and Hensell Shale Mbr of Pearsall Formation',
#        ' Precambrian Granite',
#        ' Bone Spring and Victorio Peak Limestones', ' Woods Hollow Shale',
#        ' Carrizo Sand and Calvert Bluff Formation',
#        ' Rio Grande Alluvium', ' Hueco Bolson',
#        ' Simsboro Sand Member and Hooper Formation',
#        ' Wills Point Formation', ' Granite Wash', ' Intrusive Rocks',
#        ' Mesilla Bolson',
#        ' Calvert Bluff Formation and Simsboro Sand Member',
#        ' Bolson Deposits', ' Alluvium and Simsboro Formation',
#        ' Alluvium, Antlers Sand and Permian System',
#        ' Marble Falls Limestone', ' Alluvium and Precambrian Granite',
#        ' Salt Bolson and Capitan Reef Complex', ' Bone Spring Limestone',
#        ' Marble Falls Limestone and Ellenburger Group',
#        ' Alluvium and Yegua Formation', ' Salt Bolson', ' Castile Gypsum',
#        ' Holocene, Pleistocene and Pliocene Alluvial Deposits',
#        ' Delaware Mountain Group ', ' Capitan Reef Complex ',
#        ' Welge, Lion Mountain and Hickory Sandstones',
#        ' Morgan Creek Limestone Member of Wilberns Formation',
#        ' Smithwick Shale', ' Cap Mountain of the Riley Formation',
#        ' Alluvium and Taylor Group',
#        ' Morgan Creek Limestone and Welge and Lion Mountain Sandstones',
#        ' Edwards and Associated Limestones and Permian System',
#        ' Eagle Flat Bolson',
#        ' Glen Rose Limestone and Pearsall Formation',
#        ' Victorio Peak Limestone', ' Red Light Draw Bolson',
#        ' Glen Rose Limestone and Trinity Sand, Undifferentiated',
#        ' Caballos Novaculite', ' Rocks Between Ellenburger',
#        ' Alluvium, Terrace Deposits and Seymour Formation',
#        ' Alluvium and Reklaw Formation', ' Fort Pena Formation',
#        ' Gaptank Formation', ' Gorman Formation', ' Tanyard Formation',
#        ' Lion Mountain Sandstone',
#        ' Lower Glen Rose and Cow Creek Limestones',
#        ' Alluvium and Marble Falls Limestone',
#        ' Alluvium and Sparta Sand',
#        ' Sycamore Sand Member of Travis Peak Formation',
#        ' Dewey Lake Red Beds', ' Bell Canyon Formation',
#        ' Caliche, Quarternary',
#        ' Sparta Sand and Spiller Sand Member of Cook Mountain Formation',
#        ' Carrizo Sand and Simsboro Sand Member of Rockdale Formation',
#        ' Spiller Sand Member of Cook Mountain Formation',
#        ' Lower Glen Rose and Hosston Formation',
#        ' Salt Bolson and Permian Rocks',
#        ' Yegua and Cook Mountain Formations',
#        ' Ellenburger Group, San Saba Limestone and Welge Sandstone',
#        ' Sparta Sand and Carrizo Sand',
#        ' Alluvium and Glen Rose Limestone',
#        ' Lower Jackson Unit and Upper Yegua Unit',
#        ' Carrizo Sand, Calvert Bluff Formation and Simsboro Formation',
#        ' Hueco Limestone',
#        ' Glen Rose Limestone, Upper and Hensell Shale Mbr of Pearsall Formation',
#        ' Tehuacana Member of Kincaid Formation',
#        ' Jasper Aquifer, Upper Unit', ' Evangeline Aquifer',
#        ' Glen Rose Limestone, Hensell Sand and Hosston Formation',
#        ' Fleming Formation', ' Alluvium and Travis Peak Formations',
#        ' Burkeville Aquiclude', ' Chicot Aquifer, Upper',
#        ' Chicot and Evangeline Aquifers', ' Salado Formation',
#        ' Cook Mountain Formation and Sparta Sand', ' Goliad Sand',
#        ' Jasper Aquifer and Jackson Group', ' Chicot Aquifer, Lower',
#        ' Goliad and Younger Rocks, Undifferentiated',
#        ' Chicot Aquifer, Middle',
#        ' Oakville Sandstone and Catahoula Tuff', ' Lagarto Clay',
#        ' Alluvium and Leona Formation',
#        ' Fleming Formation and Burkeville Aquiclude',
#        ' Catahoula Tuff and Jackson Group', ' Lissie Formation',
#        ' Evangeline and Jasper Aquifers',
#        ' Jasper Aquifer and Burkeville Aquiclude',
#        ' Jasper Aquifer and Catahoula Sandstone',
#        ' Leona Formation and Wilcox Group', ' Oakville Sandstone',
#        ' Salt Bolson and Tertiary Volcanics',
#        ' Alluvium and Cook Mountain Formation',
#        ' Presidio and Redford Bolsons', ' Beaumont Clay',
#        ' Alluvium and Jackson Group',
#        ' Evangeline Aquifer and Upper Unit of Jasper Aquifer',
#        ' Evangeline Aquifer and Burkeville Aquiclude',
#        ' Laredo Formation', ' Escondido Formation', ' Green River Bolson',
#        ' Alluvium and Evangeline Aquifer',
#        ' Lissie Formation and Goliad Sand',
#        ' Bigford Formation and Carrizo Sand',
#        ' Alluvium and Pease River Group',
#        ' Beaumont Clay and Lissie Formation',
#        ' Bigford Formation of Claiborne Group', ' Indio Formation',
#        ' Anacacho Limestone',
#        ' Austin Chalk and Edwards and Associated Limestones',
#        ' Yucca Formation',
#        ' Point Peak Shale Member of Wilberns Formation',
#        ' Guadalupe Series',
#        ' Beaumont Clay, Lissie Formation and Goliad Sand',
#        ' Alluvium, Leona Formation and Wilcox Group',
#        ' Barrier Island Deposits', ' Leona Formation and Austin Chalk',
#        ' Willis Sand', ' Buda Limestone and Washita Group',
#        ' El Picacho Formation', ' Barrier Island and Beach Deposits',
#        ' El Pico Clay', ' Mercedes', ' Cox Sandstone', ' Sligo Formation',
#        ' Goliad Sand and Lagarto Clay', ' Blackwater Draw Formation',
#        ' Alluvium and Goliad Sand', ' Buda Limestone',
#        ' Limestones of Fredericksburg, Washita and Upper Glen Rose',
#        ' Uvalde Gravel', ' Alta Loma Sand', ' Pleistocene',
#        ' Aguja Formation', ' Boquillas Formation',
#        ' Basement Cretaceous Sands', ' Alluvium and Lissie Sand',
#        ' San Miguel Formation', ' Leona Formation and Serpentine',
#        ' Santa Elena Limestone', ' Pen Formation',
#        ' Coleman Junction Limestone Member of Putnam Formation',
#        ' San Angelo Sandstone and Choza Formation',
#        ' Leona Formation and Buda Limestone', ' Willis and Goliad Sands',
#        ' South Texas Eolian Plain Deposits'], dtype=object)

# %%
def extractNativeIDFunc(A):
    A = str(A).strip()
    try:
        outString = A.split('-')[0]
    except:
        outString = A
    return outString
dfinPOD['nativeID'] = dfinPOD.apply(lambda row: extractNativeIDFunc(row['AquiferCod']), axis=1)
dfinPOD['nativeID'].unique()
# Out:
# array(['121OGLL ', '231DCKM ', '110ALVM ', '100ALVM ', 'NOT', '218PLXY ',
#        '218TPPX ', '125MDWY ', '211NCTC ', '121OGDK ', '312OCHO ',
#        '124WLCX ', '112SYMR ', '211BLSM ', '211TYLR ', '318SAGL ',
#        '218FKBG ', '110AVOG ', '217PGTM ', '310QRMW ', '110TRRC ',
#        '321CNYN ', '313WTRS ', '220JRSC ', '121OGDP ', '121OGLM ',
#        '211DKPJ ', 'UNKNOWN ', '211DKOP ', '217HSTN ', '318CHOZ ',
#        '318WCHT ', '112TAOG ', '110AHTP ', '121OGFG ', '218ALRS ',
#        '313BLIN ', '218ASDG ', '124CPRS ', '110AVAN ', '110QRNR ',
#        '218FKBT ', '218GPSH ', '218TVPK ', '212WDBN ', '218GLRS ',
#        '121OGLD ', '318CLFK ', '112TEDAS ', '318PRVR ', '218TRNT ',
#        '124RKCZ ', '218TWMT ', '218PRSL ', '310PRMN ', '121OGFA ',
#        '100PECS ', '211EGFD ', '124WXMW ', '124QNCT ', '112SCFX ',
#        '110DUNE ', '324MLWL ', '110ALTO ', '121OGLW ', '313DCKB ',
#        '218FWDK ', '300PLZC ', '211GOBR ', '110AVPW ', '318MRKL ',
#        '110ACPO ', '110AVPS ', '371HCKR ', '321CSCO ', '110AVCZ ',
#        '110AVVL ', '319PUBL ', '124SPRT ', '110AHTW ', '124RKLW ',
#        '112SYCZ ', '313DCBF ', '110DOGL ', '370CMBR ', '318ADML ',
#        '218PXGR ', '318BLGN ', '318VALE ', '318BLPL ', '124CRRZ ', '',
#        '319MORN ', '121ODPJ ', '221EXTR ', '313ARTS ', '121OGAL ',
#        '211ASTN ', '218PXTM ', '112TAHK ', '110AVFV ', '110QWSD ',
#        '112PLSC ', '318CZBW ', '110ALVP ', '313WDCB ', '218CMPK ',
#        '321WLFM ', '318ARRY ', '367ELBG ', '321TRFT ', '321GRHM ',
#        '320PSLV ', '321PLPN ', '218TGHC ', '321WFMP ', '321CLCK ',
#        '321TFGM ', '218PWPW ', '212WBPX ', '110ABDC ', '110AVTC ',
#        '110AVBL ', '318WCCC ', '212WBPH ', '218GRTM ', '218ANTP ',
#        '211WLFC ', '324STRN ', '218TWMW ', '218TMFP ', '321PLCD ',
#        '321WMPP ', '218HNHS ', '321CCRP ', '124QCCZ ', '110AVCF ',
#        '211DLME ', '211DKOT ', '121OGLP ', '310QRRM ', '110AVMA ',
#        '318LDRS ', '110ALTC ', '121OGPJ ', '110ALTW ', '211NVRR ',
#        '211BNHM ', '110ATSB ', '218EDAD ', '110AVQC ', '211NVTY ',
#        '110AVAR ', '110AVCB ', '211CRCSU ', '124CZWX ', '319PTNM ',
#        '218HNSL ', '210CRCS ', '324MWBR ', '110AVAU ', '218WLNT ',
#        '231DCKP ', '321HPVL ', '218TRGM ', '218EDAS ', '110ATCW ',
#        '110ATCF ', '110AVFP ', '124WCHS ', '111AVMT ', '124QCRK ',
#        '122JSPR ', '218KMCI ', '212WDBT ', '218ALSP ', '124SPQC ',
#        '318PTRL ', '112CHCT ', '318CZVL ', '124CRVR ', '319ARCT ',
#        '313FLRP ', '319WFMP ', '110AVMW ', '217PRGR ', '110AVDK ',
#        '218WSHT ', '124CKMN ', '124JCKSL ', '124YEGUL ', '124YEGU ',
#        '218FGAS ', '218EDRD ', '124QCCW ', '321PLPT ', '321AVIS ',
#        '321CCPS ', '122CTHL ', '321WNCL ', '324BZRVL ', '324BZRVU ',
#        '124JCKS ', '124JCKSU ', '124YEGUU ', '321HMCK ', '110AVCH ',
#        '124SMBR ', '218EDDT ', '110AVME ', '120VLCC ', '120IGNS ',
#        '112GLFC ', '312RSLR ', '323DMPL ', '321MARK ', '110AVCG ',
#        '321GZCK ', '112LEON ', '124CABF ', '218EDRDA ', '124YGJK ',
#        '321CNCS ', '111ABZR ', '124QCSP ', '110AVCC ', '218GLRH ',
#        '112PECSA ', '218PLXP ', '313CRCX ', '122LOKV ', '312OCAR ',
#        '100CPCR ', '218HEPF ', '210CIGR ', '112LNCZ ', '124HOOP ',
#        '218PRHF ', '367EBPH ', '112LBLG ', '367EBCR ', '111PCRV ',
#        '321PPTC ', '363FPAS ', '367MRTN ', '110AVTV ', '318SDPP ',
#        '369MTDF ', '361CBMV ', '112LNSA ', '218GLRSU ', '321HYMD ',
#        '124CKMC ', '321RNGR ', '321PWWM ', '110AVCY ', '110AVLC ',
#        '100CPCRL ', '218FRGR ', '110AVET ', '321PSWM ', '367ORDV ',
#        '313SADR ', '218GRHC ', '218EBFZA ', '327TSNS ', '218HCSH ',
#        '218CCRK ', '100CPDG ', '371WELG ', '313SVRV ', '110AVWX ',
#        '367EBSS ', '218EDGRU ', '218EDGR ', '218GLRSL ', '313CPTN ',
#        '112LNAN ', '218FKBW ', '371MCWG ', '367EBHK ', '313DLRM ',
#        '218GRHCU ', '371WGLM ', '371WLBR ', '218HSCC ', '100CPDR ',
#        '400PCMB ', '371SNSB ', '111AVCR ', '217CRCSL ', '217HSCC ',
#        '400VSPG ', '400PCKD ', '124JKYG ', '218GRGN ', '371RILY ',
#        '218TSEB ', '112SBDM ', '218PSGH ', '112SBCR ', '367HNCT ',
#        '219SLGH ', '218GRLH ', '400GRNT ', '318BSVP ', '362WDHL ',
#        '124CZCB ', '111RGRD ', '112HCBL ', '124SBHP ', '125WLSP ',
#        '371GRNT ', '120IVIG ', '112MSBL ', '124CBSB ', '120BLSN ',
#        '110AVSB ', '110AASP ', '320MBLF ', '110AGRT ', '112SBCRC ',
#        '318BSPG ', '327MFEB ', '110AVYG ', '112SLBL ', '312CSTL ',
#        '111HPPA ', '313DMBS ', '313CRDM ', '371WGLH ', '371MGCK ',
#        '320SMCK ', '371CPMN ', '110AVTY ', '371MWLM ', '218EDPM ',
#        '112EFBL ', '218GLRP ', '318VCPK ', '112RLBL ', '218GLRT ',
#        '360CABL ', '371RESH ', '110AVTS ', '110AVRF ', '363FTPN ',
#        '320GPTK ', '367GRMN ', '367TNRD ', '371LNMN ', '218GRCCU ',
#        '110AVMF ', '110AVSS ', '218SCMR ', '312DYLK ', '313BELC ',
#        '110QCCH ', '124SPSP ', '124CZSB ', '124SPLR ', '218LGRLH ',
#        '112SBLP ', '124YGCM ', '367EBSW ', '124SPCZ ', '110AVGR ',
#        '124LJUY ', '124CZCSB ', '318HUCL ', '218GRUH ', '125THCN ',
#        '122JSPRU ', '121EVGL ', '100TAHO ', '218GRHH ', '122FLMG ',
#        '110AVTP ', '122BKVL ', '112CHCTU ', '112CEVG ', '312SLDO ',
#        '124CKMS ', '121GOLD ', '122JPJK ', '112CHCTL ', '112GOLD ',
#        '112CHCTM ', '122OKVC ', '122LGRT ', '110AVML ', '122FBKV ',
#        '122CJCK ', '112LISS ', '121EVJP ', '122JBKV ', '122JPCL ',
#        '112LWCX ', '122OKVL ', '112SBTV ', '110AVCM ', '112PRBL ',
#        '112BMNT ', '110AVJK ', '121EVJPU ', '121EVBV ', '124LRDO ',
#        '211ECDD ', '112GRBL ', '110AVEV ', '112LGLD ', '124BFCS ',
#        '110AVPR ', '112BMLS ', '124BGDF ', '124INDO ', '211ANCC ',
#        '211AEDD ', '218YUCC ', '371PNPK ', '313GDLP ', '112BMLG ',
#        '110ALWX ', '110BILD ', '112LNAS ', '112WLLS ', '211BLWG ',
#        '211EPIC ', '110BIBC ', '124ELPC ', '112MCSB ', '218COXS ',
#        '217SLGO ', '121GDLG ', '110BWDR ', '110AVGL ', '211BUDA ',
#        '218FWGR ', '121UVLD ', '112ALLM ', '112PCPC ', '211AGUJ ',
#        '211BQLS ', '217BSCS ', '110AVLS ', '211SMGL ', '112LSRP ',
#        '218SNEL ', '212PEN ', '319CMJC ', '318SACZ ', '112LNBD ',
#        '112GOWS ', '110STEP '], dtype=object)

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfinPOD['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "TWDBwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "TWDBwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "TWDBwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfinPOD['nativeName']
df['in_WaterSourceNativeID'] = dfinPOD['nativeID']
df['in_WaterSourceTypeCV'] = "Groundwater"

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = "Digitized"
df['in_County'] = dfinPOD["CountyName"]
df['in_EPSGCodeCV'] = ""
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfinPOD["CoordDDLat"]
df['in_Longitude'] = dfinPOD["CoordDDLon"]
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"  # "Point of Diversion"
df['in_SiteName'] = ""
df['in_SiteNativeID'] = "POD" + dfinPOD["StateWellN"].astype(int).astype(str).str.strip()
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = dfinPOD["WellType"]
df['in_StateCV'] = "TX"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = ""
df['in_AllocationLegalStatusCV'] =""
df['in_AllocationNativeID'] =  dfinPOD["StateWellN"].astype(int).astype(str).str.strip()
df['in_AllocationOwner'] = dfinPOD["OwnerName"]
df['in_AllocationPriorityDate'] = ""
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = "Rules of Capture"
df['in_AllocationVolume_AF'] = ""
df['in_BeneficialUseCategory'] = dfinPOD["PrimaryWat"]
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = "1" # either a 1 or 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = "https://www3.twdb.texas.gov/apps/waterdatainteractive//GetReports.aspx?Num=" + dfinPOD["StateWellN"].astype(int).astype(str).str.strip() + "&Type=GWDB"

outPOD = df.copy()
outPOD = outPOD.drop_duplicates().reset_index(drop=True)
print(len(outPOD))
outPOD.head()
# Out:
# 141605
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     txD0     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 1     txD1     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 2     txD2     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 3     txD3     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 4     txD4     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#     in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0   Ogallala Formation               121OGLL           Groundwater
# 1   Ogallala Formation               121OGLL           Groundwater
# 2   Ogallala Formation               121OGLL           Groundwater
# 3   Ogallala Formation               121OGLL           Groundwater
# 4   Ogallala Formation               121OGLL           Groundwater
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County in_EPSGCodeCV  \
# 0                                   Digitized   Randall
# 1                                   Digitized   Randall
# 2                                   Digitized   Randall
# 3                                   Digitized   Randall
# 4                                   Digitized   Randall
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    35.11361    -101.97611
# 1                                    35.08500    -101.98695
# 2                                    35.11722    -101.94889
# 3                                    35.10556    -101.94611
# 4                                    35.10195    -101.95278
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                   POD
# 1                                                   POD
# 2                                                   POD
# 3                                                   POD
# 4                                                   POD
#
#   in_SiteNativeID in_SitePoint        in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0       POD657116               Withdrawal of Water         TX
# 1       POD657118               Withdrawal of Water         TX
# 2       POD657207               Withdrawal of Water         TX
# 3       POD657209               Withdrawal of Water         TX
# 4       POD657211               Withdrawal of Water         TX
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                                           657116
# 1                                           657118
# 2                                           657207
# 3                                           657209
# 4                                           657211
#
#                 in_AllocationOwner in_AllocationPriorityDate  \
# 0              1. B. Dugger Estate
# 1                      L. W. Smith
# 2  Amarillo Municipal Water System
# 3                   Ervin Podzemny
# 4              Caroline Bush Emery
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0                                Rules of Capture
# 1                                Rules of Capture
# 2                                Rules of Capture
# 3                                Rules of Capture
# 4                                Rules of Capture
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0               Irrigation
# 1               Irrigation
# 2            Public Supply
# 3               Irrigation
# 4               Irrigation
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#   in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://www3.twdb.texas.gov/apps/waterdatainte...
# 1  https://www3.twdb.texas.gov/apps/waterdatainte...
# 2  https://www3.twdb.texas.gov/apps/waterdatainte...
# 3  https://www3.twdb.texas.gov/apps/waterdatainte...
# 4  https://www3.twdb.texas.gov/apps/waterdatainte...

# %% [markdown]
# ## Concatenate POD Data.  Make needed changes

# %%
outdf = outPOD
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")

print(len(outdf))
# Out:
# 141605

# %% [markdown]
# ## Clean Data / data types

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Ogallala Formation', 'Dockum Formation', 'Quaternary Alluvium',
#        'Alluvium', 'Appl', 'Paluxy Sand',
#        'Travis Peak Formation And Paluxy Sand', 'Midway Group',
#        'Nacatoch Sand', 'Ogallala Formation And Dockum Formation',
#        'Ochoan Series', 'Wilcox Group', 'Seymour Formation',
#        'Blossom Sand', 'Taylor Marl', 'San Angleo Formation',
#        'Fredericksburg Group', 'Alluvium And Ogallala Formation',
#        'Purgatoire And Morrison Formations',
#        'Quartermaster Formation And Whitehorse Group', 'Terrace Deposits',
#        'Canyon Group', 'Whitehorse Group', 'Jurassic System',
#        'Ogallala Formation, Dakota Group And Purgatoire Formation',
#        'Ogallala And Morrison Formations',
#        'Dakota Group, Purgatoire Formation And Jurassic',
#        'Aquifer Not Able To Be Determined',
#        'Dakota Group And Purgatoire Formation', 'Hosston Formation',
#        'Choza Formation', 'Wichita Formation Or Group',
#        'Tahoka And Ogallala Formations',
#        'Alluvium And High Terrace Deposits',
#        'Ogallala Formation And Fredericksburg Group', 'Antlers Sand',
#        'Blaine Formation', 'Antlers Sand And Dockum Formation',
#        'Cypress Aquifer', 'Alluvium And Antlers Sand',
#        'Quaternary System', 'Fredericksburg And Trinity Groups',
#        'Glen Rose Lower, Pearsall Hensell, Cow Creek, Sligo Hosston Fms',
#        'Travis Peak Formation', 'Woodbine Sand', 'Glen Rose Limestone',
#        'Ogallala Formation And Dakota Group', 'Clear Fork Group',
#        'Tahoka Formation, Fredericksburg Group And Antlers Sand',
#        'Pease River Group', 'Trinity Group',
#        'Reklaw Formation And Carrizo Sand', 'Twin Mountains Formation',
#        'Pearsall Formation', 'Permian System',
#        'Ogallala Formation, Fredericksburg Group And Antlers Sand',
#        'Cenozoic Pecos Alluvium', 'Eagle Ford Group',
#        'Wilcox And Midway Groups', 'Queen City Sand Of Claiborne Group',
#        'Seymour Formation And Clear Fork Group', 'Dune Sand',
#        'Mineral Wells Formation',
#        'Alluvium, Low Terrace And Channel Fill Deposits And Ogallala Formation',
#        'Ogallala Formation And Whitehorse Group',
#        'Dog Creek Shale And Blaine Gypsum',
#        'Fort Worth Limestone And Duck Creek Formation, Undivided',
#        'Paleozoic Erathem', 'Gober Tongue Of Austin Chalk',
#        'Alluvial Plain Deposits And Whitehorse Group',
#        'Merkel Dolomite Member Of Choza Formation',
#        'Alluvial Channel And Plain Deposits And Ochoa Series',
#        'Alluvium And Permian System', 'Hickory Sandstone', 'Cisco Group',
#        'Alluvium And Carrizo Sand', 'Alluvium And Vale Formation',
#        'Pueblo Formation', 'Sparta Sand',
#        'Alluvium, High Terrace Deposits And Whitehorse Group',
#        'Reklaw Formation Of Claiborne Group',
#        'Seymour And Choza Formations',
#        'Dog Creek Shale, Blaine Gypsum And Flowerpot Shale',
#        'Dune Sand And Ogallala Formation', 'Cambrian System',
#        'Admiral Formation', 'Paluxy Sand And Glen Rose Limestone',
#        'Bullwagon Dolomite Member Of Vale Formation', 'Vale Formation',
#        'Belle Plains Formation', 'Carrizo Sand', '', 'Moran Formation',
#        'Ogallala Formation, Dakota Group, Purgatoire Formation And Jurassic',
#        'Exeter Sandstone', 'Artesia Group',
#        'Ogallala Formation And Antlers Sand', 'Austin Chalk',
#        'Paluxy And Twin Mountains Formations', 'Tahoka Formation',
#        'Alluvium And Fluviatile Terrace Deposits',
#        'Windblown Sand, Quaternary', 'Pleistocene Series',
#        'Choza Formation And Bullwagon Dolomite',
#        'Alluvial Plain Deposits',
#        'Whitehorse Group, Dog Creek And Blaine Formations',
#        'Comanche Peak Limestone', 'Wolf Mountain Shale',
#        'Arroyo Formation', 'Ellenburger Group', 'Thrifty Formation',
#        'Graham Formation', 'Pennsylvanian System', 'Palo Pinto Limestone',
#        'Trinity Sand, Graham Formation And Home Creek Limestone',
#        'Wolf Mountain And Posideon Shales', 'Colony Creek Shale',
#        'Thrifty And Graham Formations', 'Pawpaw Formation',
#        'Woodbine And Paluxy Formations',
#        'Alluvial Plain Deposits, Blaine Gypsum And Dog Creek Shale',
#        'Alluvial Terrace And Channel Deposits',
#        'Alluvium And Blaine Gypsum', 'Wichita And Cisco Groups',
#        'Woodbine Sand And Paluxy And Hosston Formations',
#        'Glen Rose Limestone And Twin Mountains Formation',
#        'Antlers Sand And Permian Rocks',
#        'Wolfe City Sand Member Of Taylor Marl', 'Strawn Group',
#        'Twin Mountains And Mineral Wells Formations',
#        'Twin Mountains Formation And Pennsylvanian Rocks', 'Placid Shale',
#        'Wolf Mountain Shale, Posideon Shale And Palo Pinto Limestone',
#        'Hensell Sand And Hosston Formation',
#        'Colony Creek Shale, Ranger Limestone And Placid Shale',
#        'Queen City Sand And Carrizo Sand',
#        'Alluvium And Clear Fork Group',
#        'Dakota Group, Lytle, Morrison And Exeter',
#        'Dakota Sandstone Or Formation',
#        'Ogallala And Purgatoire Formations', 'Quartermaster Formation',
#        'Alluvium And Artesia Group', 'Lueders Limestone',
#        'Alluvium, Low Terrace And Channel Fill Deposits',
#        'Ogallala Formation, Purgatoire Formation And Jurassic',
#        'Alluvium, Low Terrace And Channel Fill Deposits And Whitehorse Group',
#        'Navarro Group', 'Bonham Marl',
#        'Alluvium, Terrace Deposits, Seymour Formation And Blaine Formation',
#        'Edwards And Associated Limestones, Antlers Sand And Dockum Formation',
#        'Alluvium And Queen City Sand', 'Navarro And Taylor Groups',
#        'Alluvium And Arroyo Formation',
#        'Alluvium, Choza Formation And Bullwagon Dolomite',
#        'Upper Cretaceous Series',
#        'Carrizo Sand And Wilcox Group, Undifferentiated',
#        'Putnam Formation', 'Hensell Sand Member Of Travis Peak Formation',
#        'Cretaceous System', 'Mineral Wells And Brazos River Formations',
#        'Alluvium And Austin Chalk', 'Walnut Clay',
#        'Dockum Formation And Permian Rocks', 'Harpersville Formation',
#        'Trinity Sand And Graham Formation',
#        'Edwards And Associated Limestones And Antlers Sand',
#        'Alluvial Terrace And Channel Deposits And Whitehorse Group',
#        'Alluvial Terrace And Channel Deposits And Flowerpot Shale',
#        'Alluvium, Flood Plain', 'Weches Formation Of Claiborne Group',
#        'Alluvium And Terrace Deposits',
#        'Queen City Sand And Reklaw Formation', 'Jasper Aquifer',
#        'Kiamichi Formation', 'Woodbine Sand And Trinity Group',
#        'Antlers Sand And Pennsylvanian Rocks',
#        'Sparta Sand And Queen City Sand', 'Petrolia Formation',
#        'Chicot Aquifer', 'Choza And Vale Formations',
#        'Cane River Formation', 'Archer City Formation', 'Flowerpot Shale',
#        'Wolfcamp Formation', 'Alluvium And Wichita Group',
#        'Purgatoire Formation', 'Alluvium And Dockum Formation',
#        'Washita Group', 'Cook Mountain Formation', 'Lower Jackson Unit',
#        'Lower Yegua Unit And Underlying Unit', 'Yegua Formation',
#        'Fredericksburg Group And Antlers Sand', 'Edwards Limestone',
#        'Queen City Sand, Carrizo Sand And Wilcox Group',
#        'Palo Pinto Formation', 'Avis Sandstone',
#        'Colony Creek And Placid Shales', 'Catahoula Formation',
#        'Winchell Limestone',
#        'Brazos River Conglomerate Member, Lower Part Of Garner Formation',
#        'Brazos River Conglomerate Member, Upper Part Of Garner Formation',
#        'Jackson Group', 'Upper Jackson Unit', 'Upper Yegua Unit',
#        'Home Creek Limestone', 'Alluvium And Choza Formation',
#        'Simsboro Sand Member Of Rockdale Formation',
#        'Edwards And Associated Limestones And Trinity Group',
#        'Alluvium And Edwards And Associated Limestones', 'Volcanics',
#        'Igneous Rocks', 'Gulf Coast Aquifer', 'Rustler Formation',
#        'Dimple Limestone', 'Markley Formation',
#        'Alluvium And Cisco Group', 'Gonzales Creek Member',
#        'Leona Formation', 'Calvert Bluff Formation',
#        'Edwards And Associated Limestones',
#        'Yegua Formation And Jackson Group', 'Canyon And Cisco Groups',
#        'Alluvium, Brazos River', 'Queen City Sand And Sparta Sand',
#        'Alluvium And Cretaceous Rocks',
#        'Glen Rose Limestone And Hensell Member Of Pearsall Formation',
#        'Pecos Aquifer', 'Paluxy Formation And Permian Rocks',
#        'Capitan Reef Complex And Associated Limestones',
#        'Lagarto Clay And Oakville Sandstone',
#        'Ochoan Series And Artesia Group',
#        'Cenozoic Pecos Alluvium And Cretaceous Rocks',
#        'Hensell Sand And Pearsall Formation', 'Igneous Rocks Cretaceous',
#        'Leona Formation And Choza Formation', 'Hooper Formation',
#        'Pearsall And Hosston Formations', 'Ellenburger Group And Post',
#        'Leona Formation And Bullwagon Dolomite',
#        'Ellenburger Group And Cambrian Rocks', 'Pecos River Alluvium',
#        'Palo Pinto Formation And Turkey Creek Sandstone',
#        'Fort Pena Formation And Alsate Shale, Undifferentiated',
#        'Marathon Limestone', 'Alluvium And Tertiary Volcanics',
#        'Standpipe Limestone Member Of Arroyo Formation',
#        'Marathon Limestone And Dagger Flat Sandstone, Undifferentiated',
#        'Caballos Novaculite And Maravillas Chert, Undifferentiated',
#        'Leona Formation And San Angelo Sandstone',
#        'Glen Rose Limestone, Upper Member', 'Haymond Formation',
#        'Cook Mountain Formation And Carrizo Sand', 'Ranger Limestone',
#        'Placid Shale, Winchell Limestone And Wolf Mountain Shale',
#        'Alluvium And Canyon Group', 'Alluvium And Lower Cretaceous Rocks',
#        'Cenozoic Pecos Alluvium And Lower Cretaceous Rocks',
#        'Fredericksburg Group And Glen Rose Limestone',
#        'Alluvium, Edwards And Associated Limestones And Trinity Sands',
#        'Placid Shale And Wolf Mountain Formation',
#        'Ordovician Rocks, Undifferentiated', 'San Andres Limestone',
#        'Glen Rose Ls And Hensell Sh And Cow Creek Ls Members Of Pearsall Fm',
#        'Tesnus Formation',
#        'Hensell And Cow Creek Mbrs Of Pearsall Formation And Sligo And Hosston',
#        'Cow Creek Limestone',
#        'Cenozoic Pecos Alluvium And Dockum Formation', 'Welge Sandstone',
#        'Seven Rivers Formation', 'Alluvium And Wilcox Group',
#        'Ellenburger Group And San Saba Limestone',
#        'Edwards And Associated Limestones And Upper Mbr Of Glen Rose Limestone',
#        'Edwards And Associated Limestones And Glen Rose Limestone',
#        'Glen Rose Limestone, Lower Member', 'Capitan Limestone',
#        'Leona Formation And Antlers Sands',
#        'Limestones Of Fredericksburg And Washita Groups',
#        'Morgan Creek Limestone And Welge Sandstone',
#        'Ellenburger Group And Hickory Sandstone',
#        'Delaware Mountain Formation Or Group',
#        'Upper Glen Rose, Hensell And Cow Creek Members Of Pearsall Formation',
#        'Welge And Lion Mountain Sandstones', 'Wilberns Formation',
#        'Hensell Sand And Cow Creek Limestone',
#        'Cenozoic Pecos Alluvium, And Dockum And Rustler Formations',
#        'Precambrian Erathem', 'San Saba Limestone',
#        'Alluvium, Colorado River', 'Lower Cretaceous Series',
#        'Hosston Formation And Cow Creek Limestone',
#        'Valley Spring Gneiss', 'Packsaddle Schist',
#        'Jackson Group And Yegua Formation', 'Georgetown Limestone',
#        'Riley Formation', 'Trinity Hensell Sand And Ellenburger Group',
#        'Salt Bolson And Delaware Mountain Group',
#        'Pearsall, Sligo And Hosston Formations',
#        'Salt Bolson And Cretaceous Rocks', 'Honeycut Formation',
#        'Sligo And Hosston Formations',
#        'Glen Rose Limestone, Lower And Hensell Shale Mbr Of Pearsall Formation',
#        'Precambrian Granite', 'Bone Spring And Victorio Peak Limestones',
#        'Woods Hollow Shale', 'Carrizo Sand And Calvert Bluff Formation',
#        'Rio Grande Alluvium', 'Hueco Bolson',
#        'Simsboro Sand Member And Hooper Formation',
#        'Wills Point Formation', 'Granite Wash', 'Intrusive Rocks',
#        'Mesilla Bolson',
#        'Calvert Bluff Formation And Simsboro Sand Member',
#        'Bolson Deposits', 'Alluvium And Simsboro Formation',
#        'Alluvium, Antlers Sand And Permian System',
#        'Marble Falls Limestone', 'Alluvium And Precambrian Granite',
#        'Salt Bolson And Capitan Reef Complex', 'Bone Spring Limestone',
#        'Marble Falls Limestone And Ellenburger Group',
#        'Alluvium And Yegua Formation', 'Salt Bolson', 'Castile Gypsum',
#        'Holocene, Pleistocene And Pliocene Alluvial Deposits',
#        'Delaware Mountain Group', 'Capitan Reef Complex',
#        'Welge, Lion Mountain And Hickory Sandstones',
#        'Morgan Creek Limestone Member Of Wilberns Formation',
#        'Smithwick Shale', 'Cap Mountain Of The Riley Formation',
#        'Alluvium And Taylor Group',
#        'Morgan Creek Limestone And Welge And Lion Mountain Sandstones',
#        'Edwards And Associated Limestones And Permian System',
#        'Eagle Flat Bolson', 'Glen Rose Limestone And Pearsall Formation',
#        'Victorio Peak Limestone', 'Red Light Draw Bolson',
#        'Glen Rose Limestone And Trinity Sand, Undifferentiated',
#        'Caballos Novaculite', 'Rocks Between Ellenburger',
#        'Alluvium, Terrace Deposits And Seymour Formation',
#        'Alluvium And Reklaw Formation', 'Fort Pena Formation',
#        'Gaptank Formation', 'Gorman Formation', 'Tanyard Formation',
#        'Lion Mountain Sandstone',
#        'Lower Glen Rose And Cow Creek Limestones',
#        'Alluvium And Marble Falls Limestone', 'Alluvium And Sparta Sand',
#        'Sycamore Sand Member Of Travis Peak Formation',
#        'Dewey Lake Red Beds', 'Bell Canyon Formation',
#        'Caliche, Quarternary',
#        'Sparta Sand And Spiller Sand Member Of Cook Mountain Formation',
#        'Carrizo Sand And Simsboro Sand Member Of Rockdale Formation',
#        'Spiller Sand Member Of Cook Mountain Formation',
#        'Lower Glen Rose And Hosston Formation',
#        'Salt Bolson And Permian Rocks',
#        'Yegua And Cook Mountain Formations',
#        'Ellenburger Group, San Saba Limestone And Welge Sandstone',
#        'Sparta Sand And Carrizo Sand', 'Alluvium And Glen Rose Limestone',
#        'Lower Jackson Unit And Upper Yegua Unit',
#        'Carrizo Sand, Calvert Bluff Formation And Simsboro Formation',
#        'Hueco Limestone',
#        'Glen Rose Limestone, Upper And Hensell Shale Mbr Of Pearsall Formation',
#        'Tehuacana Member Of Kincaid Formation',
#        'Jasper Aquifer, Upper Unit', 'Evangeline Aquifer',
#        'Glen Rose Limestone, Hensell Sand And Hosston Formation',
#        'Fleming Formation', 'Alluvium And Travis Peak Formations',
#        'Burkeville Aquiclude', 'Chicot Aquifer, Upper',
#        'Chicot And Evangeline Aquifers', 'Salado Formation',
#        'Cook Mountain Formation And Sparta Sand', 'Goliad Sand',
#        'Jasper Aquifer And Jackson Group', 'Chicot Aquifer, Lower',
#        'Goliad And Younger Rocks, Undifferentiated',
#        'Chicot Aquifer, Middle', 'Oakville Sandstone And Catahoula Tuff',
#        'Lagarto Clay', 'Alluvium And Leona Formation',
#        'Fleming Formation And Burkeville Aquiclude',
#        'Catahoula Tuff And Jackson Group', 'Lissie Formation',
#        'Evangeline And Jasper Aquifers',
#        'Jasper Aquifer And Burkeville Aquiclude',
#        'Jasper Aquifer And Catahoula Sandstone',
#        'Leona Formation And Wilcox Group', 'Oakville Sandstone',
#        'Salt Bolson And Tertiary Volcanics',
#        'Alluvium And Cook Mountain Formation',
#        'Presidio And Redford Bolsons', 'Beaumont Clay',
#        'Alluvium And Jackson Group',
#        'Evangeline Aquifer And Upper Unit Of Jasper Aquifer',
#        'Evangeline Aquifer And Burkeville Aquiclude', 'Laredo Formation',
#        'Escondido Formation', 'Green River Bolson',
#        'Alluvium And Evangeline Aquifer',
#        'Lissie Formation And Goliad Sand',
#        'Bigford Formation And Carrizo Sand',
#        'Alluvium And Pease River Group',
#        'Beaumont Clay And Lissie Formation',
#        'Bigford Formation Of Claiborne Group', 'Indio Formation',
#        'Anacacho Limestone',
#        'Austin Chalk And Edwards And Associated Limestones',
#        'Yucca Formation', 'Point Peak Shale Member Of Wilberns Formation',
#        'Guadalupe Series',
#        'Beaumont Clay, Lissie Formation And Goliad Sand',
#        'Alluvium, Leona Formation And Wilcox Group',
#        'Barrier Island Deposits', 'Leona Formation And Austin Chalk',
#        'Willis Sand', 'Buda Limestone And Washita Group',
#        'El Picacho Formation', 'Barrier Island And Beach Deposits',
#        'El Pico Clay', 'Mercedes', 'Cox Sandstone', 'Sligo Formation',
#        'Goliad Sand And Lagarto Clay', 'Blackwater Draw Formation',
#        'Alluvium And Goliad Sand', 'Buda Limestone',
#        'Limestones Of Fredericksburg, Washita And Upper Glen Rose',
#        'Uvalde Gravel', 'Alta Loma Sand', 'Pleistocene',
#        'Aguja Formation', 'Boquillas Formation',
#        'Basement Cretaceous Sands', 'Alluvium And Lissie Sand',
#        'San Miguel Formation', 'Leona Formation And Serpentine',
#        'Santa Elena Limestone', 'Pen Formation',
#        'Coleman Junction Limestone Member Of Putnam Formation',
#        'San Angelo Sandstone And Choza Formation',
#        'Leona Formation And Buda Limestone', 'Willis And Goliad Sands',
#        'South Texas Eolian Plain Deposits'], dtype=object)

# %%
outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceNativeID']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['121Ogll', '231Dckm', '110Alvm', '100Alvm', 'Not', '218Plxy',
#        '218Tppx', '125Mdwy', '211Nctc', '121Ogdk', '312Ocho', '124Wlcx',
#        '112Symr', '211Blsm', '211Tylr', '318Sagl', '218Fkbg', '110Avog',
#        '217Pgtm', '310Qrmw', '110Trrc', '321Cnyn', '313Wtrs', '220Jrsc',
#        '121Ogdp', '121Oglm', '211Dkpj', 'Unknown', '211Dkop', '217Hstn',
#        '318Choz', '318Wcht', '112Taog', '110Ahtp', '121Ogfg', '218Alrs',
#        '313Blin', '218Asdg', '124Cprs', '110Avan', '110Qrnr', '218Fkbt',
#        '218Gpsh', '218Tvpk', '212Wdbn', '218Glrs', '121Ogld', '318Clfk',
#        '112Tedas', '318Prvr', '218Trnt', '124Rkcz', '218Twmt', '218Prsl',
#        '310Prmn', '121Ogfa', '100Pecs', '211Egfd', '124Wxmw', '124Qnct',
#        '112Scfx', '110Dune', '324Mlwl', '110Alto', '121Oglw', '313Dckb',
#        '218Fwdk', '300Plzc', '211Gobr', '110Avpw', '318Mrkl', '110Acpo',
#        '110Avps', '371Hckr', '321Csco', '110Avcz', '110Avvl', '319Publ',
#        '124Sprt', '110Ahtw', '124Rklw', '112Sycz', '313Dcbf', '110Dogl',
#        '370Cmbr', '318Adml', '218Pxgr', '318Blgn', '318Vale', '318Blpl',
#        '124Crrz', '', '319Morn', '121Odpj', '221Extr', '313Arts',
#        '121Ogal', '211Astn', '218Pxtm', '112Tahk', '110Avfv', '110Qwsd',
#        '112Plsc', '318Czbw', '110Alvp', '313Wdcb', '218Cmpk', '321Wlfm',
#        '318Arry', '367Elbg', '321Trft', '321Grhm', '320Pslv', '321Plpn',
#        '218Tghc', '321Wfmp', '321Clck', '321Tfgm', '218Pwpw', '212Wbpx',
#        '110Abdc', '110Avtc', '110Avbl', '318Wccc', '212Wbph', '218Grtm',
#        '218Antp', '211Wlfc', '324Strn', '218Twmw', '218Tmfp', '321Plcd',
#        '321Wmpp', '218Hnhs', '321Ccrp', '124Qccz', '110Avcf', '211Dlme',
#        '211Dkot', '121Oglp', '310Qrrm', '110Avma', '318Ldrs', '110Altc',
#        '121Ogpj', '110Altw', '211Nvrr', '211Bnhm', '110Atsb', '218Edad',
#        '110Avqc', '211Nvty', '110Avar', '110Avcb', '211Crcsu', '124Czwx',
#        '319Ptnm', '218Hnsl', '210Crcs', '324Mwbr', '110Avau', '218Wlnt',
#        '231Dckp', '321Hpvl', '218Trgm', '218Edas', '110Atcw', '110Atcf',
#        '110Avfp', '124Wchs', '111Avmt', '124Qcrk', '122Jspr', '218Kmci',
#        '212Wdbt', '218Alsp', '124Spqc', '318Ptrl', '112Chct', '318Czvl',
#        '124Crvr', '319Arct', '313Flrp', '319Wfmp', '110Avmw', '217Prgr',
#        '110Avdk', '218Wsht', '124Ckmn', '124Jcksl', '124Yegul', '124Yegu',
#        '218Fgas', '218Edrd', '124Qccw', '321Plpt', '321Avis', '321Ccps',
#        '122Cthl', '321Wncl', '324Bzrvl', '324Bzrvu', '124Jcks',
#        '124Jcksu', '124Yeguu', '321Hmck', '110Avch', '124Smbr', '218Eddt',
#        '110Avme', '120Vlcc', '120Igns', '112Glfc', '312Rslr', '323Dmpl',
#        '321Mark', '110Avcg', '321Gzck', '112Leon', '124Cabf', '218Edrda',
#        '124Ygjk', '321Cncs', '111Abzr', '124Qcsp', '110Avcc', '218Glrh',
#        '112Pecsa', '218Plxp', '313Crcx', '122Lokv', '312Ocar', '100Cpcr',
#        '218Hepf', '210Cigr', '112Lncz', '124Hoop', '218Prhf', '367Ebph',
#        '112Lblg', '367Ebcr', '111Pcrv', '321Pptc', '363Fpas', '367Mrtn',
#        '110Avtv', '318Sdpp', '369Mtdf', '361Cbmv', '112Lnsa', '218Glrsu',
#        '321Hymd', '124Ckmc', '321Rngr', '321Pwwm', '110Avcy', '110Avlc',
#        '100Cpcrl', '218Frgr', '110Avet', '321Pswm', '367Ordv', '313Sadr',
#        '218Grhc', '218Ebfza', '327Tsns', '218Hcsh', '218Ccrk', '100Cpdg',
#        '371Welg', '313Svrv', '110Avwx', '367Ebss', '218Edgru', '218Edgr',
#        '218Glrsl', '313Cptn', '112Lnan', '218Fkbw', '371Mcwg', '367Ebhk',
#        '313Dlrm', '218Grhcu', '371Wglm', '371Wlbr', '218Hscc', '100Cpdr',
#        '400Pcmb', '371Snsb', '111Avcr', '217Crcsl', '217Hscc', '400Vspg',
#        '400Pckd', '124Jkyg', '218Grgn', '371Rily', '218Tseb', '112Sbdm',
#        '218Psgh', '112Sbcr', '367Hnct', '219Slgh', '218Grlh', '400Grnt',
#        '318Bsvp', '362Wdhl', '124Czcb', '111Rgrd', '112Hcbl', '124Sbhp',
#        '125Wlsp', '371Grnt', '120Ivig', '112Msbl', '124Cbsb', '120Blsn',
#        '110Avsb', '110Aasp', '320Mblf', '110Agrt', '112Sbcrc', '318Bspg',
#        '327Mfeb', '110Avyg', '112Slbl', '312Cstl', '111Hppa', '313Dmbs',
#        '313Crdm', '371Wglh', '371Mgck', '320Smck', '371Cpmn', '110Avty',
#        '371Mwlm', '218Edpm', '112Efbl', '218Glrp', '318Vcpk', '112Rlbl',
#        '218Glrt', '360Cabl', '371Resh', '110Avts', '110Avrf', '363Ftpn',
#        '320Gptk', '367Grmn', '367Tnrd', '371Lnmn', '218Grccu', '110Avmf',
#        '110Avss', '218Scmr', '312Dylk', '313Belc', '110Qcch', '124Spsp',
#        '124Czsb', '124Splr', '218Lgrlh', '112Sblp', '124Ygcm', '367Ebsw',
#        '124Spcz', '110Avgr', '124Ljuy', '124Czcsb', '318Hucl', '218Gruh',
#        '125Thcn', '122Jspru', '121Evgl', '100Taho', '218Grhh', '122Flmg',
#        '110Avtp', '122Bkvl', '112Chctu', '112Cevg', '312Sldo', '124Ckms',
#        '121Gold', '122Jpjk', '112Chctl', '112Gold', '112Chctm', '122Okvc',
#        '122Lgrt', '110Avml', '122Fbkv', '122Cjck', '112Liss', '121Evjp',
#        '122Jbkv', '122Jpcl', '112Lwcx', '122Okvl', '112Sbtv', '110Avcm',
#        '112Prbl', '112Bmnt', '110Avjk', '121Evjpu', '121Evbv', '124Lrdo',
#        '211Ecdd', '112Grbl', '110Avev', '112Lgld', '124Bfcs', '110Avpr',
#        '112Bmls', '124Bgdf', '124Indo', '211Ancc', '211Aedd', '218Yucc',
#        '371Pnpk', '313Gdlp', '112Bmlg', '110Alwx', '110Bild', '112Lnas',
#        '112Wlls', '211Blwg', '211Epic', '110Bibc', '124Elpc', '112Mcsb',
#        '218Coxs', '217Slgo', '121Gdlg', '110Bwdr', '110Avgl', '211Buda',
#        '218Fwgr', '121Uvld', '112Allm', '112Pcpc', '211Aguj', '211Bqls',
#        '217Bscs', '110Avls', '211Smgl', '112Lsrp', '218Snel', '212Pen',
#        '319Cmjc', '318Sacz', '112Lnbd', '112Gows', '110Step'],
#       dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['1 B Dugger Estate', 'L W Smith',
#        'Amarillo Municipal Water System', ..., 'Rafael Cantu',
#        'Daniel Garcia', 'Carlos Alexander'], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Ogallala Formation', 'Dockum Formation', 'Quaternary Alluvium',
#        'Alluvium', 'Appl', 'Paluxy Sand',
#        'Travis Peak Formation And Paluxy Sand', 'Midway Group',
#        'Nacatoch Sand', 'Ogallala Formation And Dockum Formation',
#        'Ochoan Series', 'Wilcox Group', 'Seymour Formation',
#        'Blossom Sand', 'Taylor Marl', 'San Angleo Formation',
#        'Fredericksburg Group', 'Alluvium And Ogallala Formation',
#        'Purgatoire And Morrison Formations',
#        'Quartermaster Formation And Whitehorse Group', 'Terrace Deposits',
#        'Canyon Group', 'Whitehorse Group', 'Jurassic System',
#        'Ogallala Formation, Dakota Group And Purgatoire Formation',
#        'Ogallala And Morrison Formations',
#        'Dakota Group, Purgatoire Formation And Jurassic',
#        'Aquifer Not Able To Be Determined',
#        'Dakota Group And Purgatoire Formation', 'Hosston Formation',
#        'Choza Formation', 'Wichita Formation Or Group',
#        'Tahoka And Ogallala Formations',
#        'Alluvium And High Terrace Deposits',
#        'Ogallala Formation And Fredericksburg Group', 'Antlers Sand',
#        'Blaine Formation', 'Antlers Sand And Dockum Formation',
#        'Cypress Aquifer', 'Alluvium And Antlers Sand',
#        'Quaternary System', 'Fredericksburg And Trinity Groups',
#        'Glen Rose Lower, Pearsall Hensell, Cow Creek, Sligo Hosston Fms',
#        'Travis Peak Formation', 'Woodbine Sand', 'Glen Rose Limestone',
#        'Ogallala Formation And Dakota Group', 'Clear Fork Group',
#        'Tahoka Formation, Fredericksburg Group And Antlers Sand',
#        'Pease River Group', 'Trinity Group',
#        'Reklaw Formation And Carrizo Sand', 'Twin Mountains Formation',
#        'Pearsall Formation', 'Permian System',
#        'Ogallala Formation, Fredericksburg Group And Antlers Sand',
#        'Cenozoic Pecos Alluvium', 'Eagle Ford Group',
#        'Wilcox And Midway Groups', 'Queen City Sand Of Claiborne Group',
#        'Seymour Formation And Clear Fork Group', 'Dune Sand',
#        'Mineral Wells Formation',
#        'Alluvium, Low Terrace And Channel Fill Deposits And Ogallala Formation',
#        'Ogallala Formation And Whitehorse Group',
#        'Dog Creek Shale And Blaine Gypsum',
#        'Fort Worth Limestone And Duck Creek Formation, Undivided',
#        'Paleozoic Erathem', 'Gober Tongue Of Austin Chalk',
#        'Alluvial Plain Deposits And Whitehorse Group',
#        'Merkel Dolomite Member Of Choza Formation',
#        'Alluvial Channel And Plain Deposits And Ochoa Series',
#        'Alluvium And Permian System', 'Hickory Sandstone', 'Cisco Group',
#        'Alluvium And Carrizo Sand', 'Alluvium And Vale Formation',
#        'Pueblo Formation', 'Sparta Sand',
#        'Alluvium, High Terrace Deposits And Whitehorse Group',
#        'Reklaw Formation Of Claiborne Group',
#        'Seymour And Choza Formations',
#        'Dog Creek Shale, Blaine Gypsum And Flowerpot Shale',
#        'Dune Sand And Ogallala Formation', 'Cambrian System',
#        'Admiral Formation', 'Paluxy Sand And Glen Rose Limestone',
#        'Bullwagon Dolomite Member Of Vale Formation', 'Vale Formation',
#        'Belle Plains Formation', 'Carrizo Sand', '', 'Moran Formation',
#        'Ogallala Formation, Dakota Group, Purgatoire Formation And Jurassic',
#        'Exeter Sandstone', 'Artesia Group',
#        'Ogallala Formation And Antlers Sand', 'Austin Chalk',
#        'Paluxy And Twin Mountains Formations', 'Tahoka Formation',
#        'Alluvium And Fluviatile Terrace Deposits',
#        'Windblown Sand, Quaternary', 'Pleistocene Series',
#        'Choza Formation And Bullwagon Dolomite',
#        'Alluvial Plain Deposits',
#        'Whitehorse Group, Dog Creek And Blaine Formations',
#        'Comanche Peak Limestone', 'Wolf Mountain Shale',
#        'Arroyo Formation', 'Ellenburger Group', 'Thrifty Formation',
#        'Graham Formation', 'Pennsylvanian System', 'Palo Pinto Limestone',
#        'Trinity Sand, Graham Formation And Home Creek Limestone',
#        'Wolf Mountain And Posideon Shales', 'Colony Creek Shale',
#        'Thrifty And Graham Formations', 'Pawpaw Formation',
#        'Woodbine And Paluxy Formations',
#        'Alluvial Plain Deposits, Blaine Gypsum And Dog Creek Shale',
#        'Alluvial Terrace And Channel Deposits',
#        'Alluvium And Blaine Gypsum', 'Wichita And Cisco Groups',
#        'Woodbine Sand And Paluxy And Hosston Formations',
#        'Glen Rose Limestone And Twin Mountains Formation',
#        'Antlers Sand And Permian Rocks',
#        'Wolfe City Sand Member Of Taylor Marl', 'Strawn Group',
#        'Twin Mountains And Mineral Wells Formations',
#        'Twin Mountains Formation And Pennsylvanian Rocks', 'Placid Shale',
#        'Wolf Mountain Shale, Posideon Shale And Palo Pinto Limestone',
#        'Hensell Sand And Hosston Formation',
#        'Colony Creek Shale, Ranger Limestone And Placid Shale',
#        'Queen City Sand And Carrizo Sand',
#        'Alluvium And Clear Fork Group',
#        'Dakota Group, Lytle, Morrison And Exeter',
#        'Dakota Sandstone Or Formation',
#        'Ogallala And Purgatoire Formations', 'Quartermaster Formation',
#        'Alluvium And Artesia Group', 'Lueders Limestone',
#        'Alluvium, Low Terrace And Channel Fill Deposits',
#        'Ogallala Formation, Purgatoire Formation And Jurassic',
#        'Alluvium, Low Terrace And Channel Fill Deposits And Whitehorse Group',
#        'Navarro Group', 'Bonham Marl',
#        'Alluvium, Terrace Deposits, Seymour Formation And Blaine Formation',
#        'Edwards And Associated Limestones, Antlers Sand And Dockum Formation',
#        'Alluvium And Queen City Sand', 'Navarro And Taylor Groups',
#        'Alluvium And Arroyo Formation',
#        'Alluvium, Choza Formation And Bullwagon Dolomite',
#        'Upper Cretaceous Series',
#        'Carrizo Sand And Wilcox Group, Undifferentiated',
#        'Putnam Formation', 'Hensell Sand Member Of Travis Peak Formation',
#        'Cretaceous System', 'Mineral Wells And Brazos River Formations',
#        'Alluvium And Austin Chalk', 'Walnut Clay',
#        'Dockum Formation And Permian Rocks', 'Harpersville Formation',
#        'Trinity Sand And Graham Formation',
#        'Edwards And Associated Limestones And Antlers Sand',
#        'Alluvial Terrace And Channel Deposits And Whitehorse Group',
#        'Alluvial Terrace And Channel Deposits And Flowerpot Shale',
#        'Alluvium, Flood Plain', 'Weches Formation Of Claiborne Group',
#        'Alluvium And Terrace Deposits',
#        'Queen City Sand And Reklaw Formation', 'Jasper Aquifer',
#        'Kiamichi Formation', 'Woodbine Sand And Trinity Group',
#        'Antlers Sand And Pennsylvanian Rocks',
#        'Sparta Sand And Queen City Sand', 'Petrolia Formation',
#        'Chicot Aquifer', 'Choza And Vale Formations',
#        'Cane River Formation', 'Archer City Formation', 'Flowerpot Shale',
#        'Wolfcamp Formation', 'Alluvium And Wichita Group',
#        'Purgatoire Formation', 'Alluvium And Dockum Formation',
#        'Washita Group', 'Cook Mountain Formation', 'Lower Jackson Unit',
#        'Lower Yegua Unit And Underlying Unit', 'Yegua Formation',
#        'Fredericksburg Group And Antlers Sand', 'Edwards Limestone',
#        'Queen City Sand, Carrizo Sand And Wilcox Group',
#        'Palo Pinto Formation', 'Avis Sandstone',
#        'Colony Creek And Placid Shales', 'Catahoula Formation',
#        'Winchell Limestone',
#        'Brazos River Conglomerate Member, Lower Part Of Garner Formation',
#        'Brazos River Conglomerate Member, Upper Part Of Garner Formation',
#        'Jackson Group', 'Upper Jackson Unit', 'Upper Yegua Unit',
#        'Home Creek Limestone', 'Alluvium And Choza Formation',
#        'Simsboro Sand Member Of Rockdale Formation',
#        'Edwards And Associated Limestones And Trinity Group',
#        'Alluvium And Edwards And Associated Limestones', 'Volcanics',
#        'Igneous Rocks', 'Gulf Coast Aquifer', 'Rustler Formation',
#        'Dimple Limestone', 'Markley Formation',
#        'Alluvium And Cisco Group', 'Gonzales Creek Member',
#        'Leona Formation', 'Calvert Bluff Formation',
#        'Edwards And Associated Limestones',
#        'Yegua Formation And Jackson Group', 'Canyon And Cisco Groups',
#        'Alluvium, Brazos River', 'Queen City Sand And Sparta Sand',
#        'Alluvium And Cretaceous Rocks',
#        'Glen Rose Limestone And Hensell Member Of Pearsall Formation',
#        'Pecos Aquifer', 'Paluxy Formation And Permian Rocks',
#        'Capitan Reef Complex And Associated Limestones',
#        'Lagarto Clay And Oakville Sandstone',
#        'Ochoan Series And Artesia Group',
#        'Cenozoic Pecos Alluvium And Cretaceous Rocks',
#        'Hensell Sand And Pearsall Formation', 'Igneous Rocks Cretaceous',
#        'Leona Formation And Choza Formation', 'Hooper Formation',
#        'Pearsall And Hosston Formations', 'Ellenburger Group And Post',
#        'Leona Formation And Bullwagon Dolomite',
#        'Ellenburger Group And Cambrian Rocks', 'Pecos River Alluvium',
#        'Palo Pinto Formation And Turkey Creek Sandstone',
#        'Fort Pena Formation And Alsate Shale, Undifferentiated',
#        'Marathon Limestone', 'Alluvium And Tertiary Volcanics',
#        'Standpipe Limestone Member Of Arroyo Formation',
#        'Marathon Limestone And Dagger Flat Sandstone, Undifferentiated',
#        'Caballos Novaculite And Maravillas Chert, Undifferentiated',
#        'Leona Formation And San Angelo Sandstone',
#        'Glen Rose Limestone, Upper Member', 'Haymond Formation',
#        'Cook Mountain Formation And Carrizo Sand', 'Ranger Limestone',
#        'Placid Shale, Winchell Limestone And Wolf Mountain Shale',
#        'Alluvium And Canyon Group', 'Alluvium And Lower Cretaceous Rocks',
#        'Cenozoic Pecos Alluvium And Lower Cretaceous Rocks',
#        'Fredericksburg Group And Glen Rose Limestone',
#        'Alluvium, Edwards And Associated Limestones And Trinity Sands',
#        'Placid Shale And Wolf Mountain Formation',
#        'Ordovician Rocks, Undifferentiated', 'San Andres Limestone',
#        'Glen Rose Ls And Hensell Sh And Cow Creek Ls Members Of Pearsall Fm',
#        'Tesnus Formation',
#        'Hensell And Cow Creek Mbrs Of Pearsall Formation And Sligo And Hosston',
#        'Cow Creek Limestone',
#        'Cenozoic Pecos Alluvium And Dockum Formation', 'Welge Sandstone',
#        'Seven Rivers Formation', 'Alluvium And Wilcox Group',
#        'Ellenburger Group And San Saba Limestone',
#        'Edwards And Associated Limestones And Upper Mbr Of Glen Rose Limestone',
#        'Edwards And Associated Limestones And Glen Rose Limestone',
#        'Glen Rose Limestone, Lower Member', 'Capitan Limestone',
#        'Leona Formation And Antlers Sands',
#        'Limestones Of Fredericksburg And Washita Groups',
#        'Morgan Creek Limestone And Welge Sandstone',
#        'Ellenburger Group And Hickory Sandstone',
#        'Delaware Mountain Formation Or Group',
#        'Upper Glen Rose, Hensell And Cow Creek Members Of Pearsall Formation',
#        'Welge And Lion Mountain Sandstones', 'Wilberns Formation',
#        'Hensell Sand And Cow Creek Limestone',
#        'Cenozoic Pecos Alluvium, And Dockum And Rustler Formations',
#        'Precambrian Erathem', 'San Saba Limestone',
#        'Alluvium, Colorado River', 'Lower Cretaceous Series',
#        'Hosston Formation And Cow Creek Limestone',
#        'Valley Spring Gneiss', 'Packsaddle Schist',
#        'Jackson Group And Yegua Formation', 'Georgetown Limestone',
#        'Riley Formation', 'Trinity Hensell Sand And Ellenburger Group',
#        'Salt Bolson And Delaware Mountain Group',
#        'Pearsall, Sligo And Hosston Formations',
#        'Salt Bolson And Cretaceous Rocks', 'Honeycut Formation',
#        'Sligo And Hosston Formations',
#        'Glen Rose Limestone, Lower And Hensell Shale Mbr Of Pearsall Formation',
#        'Precambrian Granite', 'Bone Spring And Victorio Peak Limestones',
#        'Woods Hollow Shale', 'Carrizo Sand And Calvert Bluff Formation',
#        'Rio Grande Alluvium', 'Hueco Bolson',
#        'Simsboro Sand Member And Hooper Formation',
#        'Wills Point Formation', 'Granite Wash', 'Intrusive Rocks',
#        'Mesilla Bolson',
#        'Calvert Bluff Formation And Simsboro Sand Member',
#        'Bolson Deposits', 'Alluvium And Simsboro Formation',
#        'Alluvium, Antlers Sand And Permian System',
#        'Marble Falls Limestone', 'Alluvium And Precambrian Granite',
#        'Salt Bolson And Capitan Reef Complex', 'Bone Spring Limestone',
#        'Marble Falls Limestone And Ellenburger Group',
#        'Alluvium And Yegua Formation', 'Salt Bolson', 'Castile Gypsum',
#        'Holocene, Pleistocene And Pliocene Alluvial Deposits',
#        'Delaware Mountain Group', 'Capitan Reef Complex',
#        'Welge, Lion Mountain And Hickory Sandstones',
#        'Morgan Creek Limestone Member Of Wilberns Formation',
#        'Smithwick Shale', 'Cap Mountain Of The Riley Formation',
#        'Alluvium And Taylor Group',
#        'Morgan Creek Limestone And Welge And Lion Mountain Sandstones',
#        'Edwards And Associated Limestones And Permian System',
#        'Eagle Flat Bolson', 'Glen Rose Limestone And Pearsall Formation',
#        'Victorio Peak Limestone', 'Red Light Draw Bolson',
#        'Glen Rose Limestone And Trinity Sand, Undifferentiated',
#        'Caballos Novaculite', 'Rocks Between Ellenburger',
#        'Alluvium, Terrace Deposits And Seymour Formation',
#        'Alluvium And Reklaw Formation', 'Fort Pena Formation',
#        'Gaptank Formation', 'Gorman Formation', 'Tanyard Formation',
#        'Lion Mountain Sandstone',
#        'Lower Glen Rose And Cow Creek Limestones',
#        'Alluvium And Marble Falls Limestone', 'Alluvium And Sparta Sand',
#        'Sycamore Sand Member Of Travis Peak Formation',
#        'Dewey Lake Red Beds', 'Bell Canyon Formation',
#        'Caliche, Quarternary',
#        'Sparta Sand And Spiller Sand Member Of Cook Mountain Formation',
#        'Carrizo Sand And Simsboro Sand Member Of Rockdale Formation',
#        'Spiller Sand Member Of Cook Mountain Formation',
#        'Lower Glen Rose And Hosston Formation',
#        'Salt Bolson And Permian Rocks',
#        'Yegua And Cook Mountain Formations',
#        'Ellenburger Group, San Saba Limestone And Welge Sandstone',
#        'Sparta Sand And Carrizo Sand', 'Alluvium And Glen Rose Limestone',
#        'Lower Jackson Unit And Upper Yegua Unit',
#        'Carrizo Sand, Calvert Bluff Formation And Simsboro Formation',
#        'Hueco Limestone',
#        'Glen Rose Limestone, Upper And Hensell Shale Mbr Of Pearsall Formation',
#        'Tehuacana Member Of Kincaid Formation',
#        'Jasper Aquifer, Upper Unit', 'Evangeline Aquifer',
#        'Glen Rose Limestone, Hensell Sand And Hosston Formation',
#        'Fleming Formation', 'Alluvium And Travis Peak Formations',
#        'Burkeville Aquiclude', 'Chicot Aquifer, Upper',
#        'Chicot And Evangeline Aquifers', 'Salado Formation',
#        'Cook Mountain Formation And Sparta Sand', 'Goliad Sand',
#        'Jasper Aquifer And Jackson Group', 'Chicot Aquifer, Lower',
#        'Goliad And Younger Rocks, Undifferentiated',
#        'Chicot Aquifer, Middle', 'Oakville Sandstone And Catahoula Tuff',
#        'Lagarto Clay', 'Alluvium And Leona Formation',
#        'Fleming Formation And Burkeville Aquiclude',
#        'Catahoula Tuff And Jackson Group', 'Lissie Formation',
#        'Evangeline And Jasper Aquifers',
#        'Jasper Aquifer And Burkeville Aquiclude',
#        'Jasper Aquifer And Catahoula Sandstone',
#        'Leona Formation And Wilcox Group', 'Oakville Sandstone',
#        'Salt Bolson And Tertiary Volcanics',
#        'Alluvium And Cook Mountain Formation',
#        'Presidio And Redford Bolsons', 'Beaumont Clay',
#        'Alluvium And Jackson Group',
#        'Evangeline Aquifer And Upper Unit Of Jasper Aquifer',
#        'Evangeline Aquifer And Burkeville Aquiclude', 'Laredo Formation',
#        'Escondido Formation', 'Green River Bolson',
#        'Alluvium And Evangeline Aquifer',
#        'Lissie Formation And Goliad Sand',
#        'Bigford Formation And Carrizo Sand',
#        'Alluvium And Pease River Group',
#        'Beaumont Clay And Lissie Formation',
#        'Bigford Formation Of Claiborne Group', 'Indio Formation',
#        'Anacacho Limestone',
#        'Austin Chalk And Edwards And Associated Limestones',
#        'Yucca Formation', 'Point Peak Shale Member Of Wilberns Formation',
#        'Guadalupe Series',
#        'Beaumont Clay, Lissie Formation And Goliad Sand',
#        'Alluvium, Leona Formation And Wilcox Group',
#        'Barrier Island Deposits', 'Leona Formation And Austin Chalk',
#        'Willis Sand', 'Buda Limestone And Washita Group',
#        'El Picacho Formation', 'Barrier Island And Beach Deposits',
#        'El Pico Clay', 'Mercedes', 'Cox Sandstone', 'Sligo Formation',
#        'Goliad Sand And Lagarto Clay', 'Blackwater Draw Formation',
#        'Alluvium And Goliad Sand', 'Buda Limestone',
#        'Limestones Of Fredericksburg, Washita And Upper Glen Rose',
#        'Uvalde Gravel', 'Alta Loma Sand', 'Pleistocene',
#        'Aguja Formation', 'Boquillas Formation',
#        'Basement Cretaceous Sands', 'Alluvium And Lissie Sand',
#        'San Miguel Formation', 'Leona Formation And Serpentine',
#        'Santa Elena Limestone', 'Pen Formation',
#        'Coleman Junction Limestone Member Of Putnam Formation',
#        'San Angelo Sandstone And Choza Formation',
#        'Leona Formation And Buda Limestone', 'Willis And Goliad Sands',
#        'South Texas Eolian Plain Deposits'], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['Withdrawal of Water', 'Observation', 'Spring', 'Test Hole',
#        'Drain', 'Oil or Gas', 'Surface Water (not a spring)', 'Seismic',
#        'Waste Disposal', 'Mine', 'Recharge', 'Other (see remarks)',
#        'Geothermal', '', 'Anode'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['1 B Dugger Estate', 'L W Smith',
#        'Amarillo Municipal Water System', ..., 'Rafael Cantu',
#        'Daniel Garcia', 'Carlos Alexander'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['Irrigation', 'Public Supply', 'Stock', 'Domestic', 'Unused',
#        'Industrial', '', 'Plugged or Destroyed', 'Recreation',
#        'Commercial', 'Power', 'Institution', 'Industrial (cooling)',
#        'Unknown', 'Aquaculture', 'De-watering', 'Other', 'Medicinal',
#        'Monitor', 'Mining', 'Air Conditioning', 'Rig Supply', 'Fire',
#        'Withdrawal of Water', 'Bottling', 'Fracking Supply', 'Test Well',
#        'Desalination', 'Extraction'], dtype=object)

# %%
# Unique values for 'WaterSourceTypeCV'
for x in outdf['in_BeneficialUseCategory'].sort_values().unique():
    print(f'"' + x + '",')
# Out:
# "",
# "Air Conditioning",
# "Aquaculture",
# "Bottling",
# "Commercial",
# "De-watering",
# "Desalination",
# "Domestic",
# "Extraction",
# "Fire",
# "Fracking Supply",
# "Industrial",
# "Industrial (cooling)",
# "Institution",
# "Irrigation",
# "Medicinal",
# "Mining",
# "Monitor",
# "Other",
# "Plugged or Destroyed",
# "Power",
# "Public Supply",
# "Recreation",
# "Rig Supply",
# "Stock",
# "Test Well",
# "Unknown",
# "Unused",
# "Withdrawal of Water",

# %%
# Ensure Latitude entry is either numireic or blank, no 0 entries
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([35.113612, 35.085   , 35.117222, ..., 27.433334, 27.406667,
#        27.309723])

# %%
# Ensure Longitude entry is either numireic or blank, no 0 entries
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-101.976111 , -101.986945 , -101.948889 , ...,  -99.6227778,
#         -99.475    , -103.9730556])

# %%
# # Changing datatype of Priority Date to date fields entry
# outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'], errors = 'coerce')
# outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
# outdf['in_AllocationPriorityDate'].unique()

# %%
# Ensure Flow entry is either numireic or blank, no 0 entries
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([''], dtype=object)

# %%
# Ensure Volume entry is either numireic or blank, no 0 entries
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array([''], dtype=object)

# %%
# missing WaterSourceNativeID in the natve it.  Swill put in a blank value for now on missing vields.

# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)
dfWaterSourceNativeID['linkKey'] = dfWaterSourceNativeID['in_WaterSourceName'].astype(str) + dfWaterSourceNativeID['in_WaterSourceTypeCV'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
WaterSourceNativeIDdict = pd.Series(dfWaterSourceNativeID.in_WaterSourceNativeID.values, index=dfWaterSourceNativeID.linkKey.astype(str)).to_dict()
def retrieveWaterSourceNativeID(A, B, C):
    C = str(C).strip()
    if (C != ""):
        outList = C
    else:
        colrowValue = str(A).strip() + str(B).strip()
        try:
            outList = WaterSourceNativeIDdict[colrowValue]
        except:
            outList = C
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV'], row['in_WaterSourceNativeID']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['121Ogll', '231Dckm', '110Alvm', '100Alvm', 'Not', '218Plxy',
#        '218Tppx', '125Mdwy', '211Nctc', '121Ogdk', '312Ocho', '124Wlcx',
#        '112Symr', '211Blsm', '211Tylr', '318Sagl', '218Fkbg', '110Avog',
#        '217Pgtm', '310Qrmw', '110Trrc', '321Cnyn', '313Wtrs', '220Jrsc',
#        '121Ogdp', '121Oglm', '211Dkpj', 'Unknown', '211Dkop', '217Hstn',
#        '318Choz', '318Wcht', '112Taog', '110Ahtp', '121Ogfg', '218Alrs',
#        '313Blin', '218Asdg', '124Cprs', '110Avan', '110Qrnr', '218Fkbt',
#        '218Gpsh', '218Tvpk', '212Wdbn', '218Glrs', '121Ogld', '318Clfk',
#        '112Tedas', '318Prvr', '218Trnt', '124Rkcz', '218Twmt', '218Prsl',
#        '310Prmn', '121Ogfa', '100Pecs', '211Egfd', '124Wxmw', '124Qnct',
#        '112Scfx', '110Dune', '324Mlwl', '110Alto', '121Oglw', '313Dckb',
#        '218Fwdk', '300Plzc', '211Gobr', '110Avpw', '318Mrkl', '110Acpo',
#        '110Avps', '371Hckr', '321Csco', '110Avcz', '110Avvl', '319Publ',
#        '124Sprt', '110Ahtw', '124Rklw', '112Sycz', '313Dcbf', '110Dogl',
#        '370Cmbr', '318Adml', '218Pxgr', '318Blgn', '318Vale', '318Blpl',
#        '124Crrz', 'wadeID92', '319Morn', '121Odpj', '221Extr', '313Arts',
#        '121Ogal', '211Astn', '218Pxtm', '112Tahk', '110Avfv', '110Qwsd',
#        '112Plsc', '318Czbw', '110Alvp', '313Wdcb', '218Cmpk', '321Wlfm',
#        '318Arry', '367Elbg', '321Trft', '321Grhm', '320Pslv', '321Plpn',
#        '218Tghc', '321Wfmp', '321Clck', '321Tfgm', '218Pwpw', '212Wbpx',
#        '110Abdc', '110Avtc', '110Avbl', '318Wccc', '212Wbph', '218Grtm',
#        '218Antp', '211Wlfc', '324Strn', '218Twmw', '218Tmfp', '321Plcd',
#        '321Wmpp', '218Hnhs', '321Ccrp', '124Qccz', '110Avcf', '211Dlme',
#        '211Dkot', '121Oglp', '310Qrrm', '110Avma', '318Ldrs', '110Altc',
#        '121Ogpj', '110Altw', '211Nvrr', '211Bnhm', '110Atsb', '218Edad',
#        '110Avqc', '211Nvty', '110Avar', '110Avcb', '211Crcsu', '124Czwx',
#        '319Ptnm', '218Hnsl', '210Crcs', '324Mwbr', '110Avau', '218Wlnt',
#        '231Dckp', '321Hpvl', '218Trgm', '218Edas', '110Atcw', '110Atcf',
#        '110Avfp', '124Wchs', '111Avmt', '124Qcrk', '122Jspr', '218Kmci',
#        '212Wdbt', '218Alsp', '124Spqc', '318Ptrl', '112Chct', '318Czvl',
#        '124Crvr', '319Arct', '313Flrp', '319Wfmp', '110Avmw', '217Prgr',
#        '110Avdk', '218Wsht', '124Ckmn', '124Jcksl', '124Yegul', '124Yegu',
#        '218Fgas', '218Edrd', '124Qccw', '321Plpt', '321Avis', '321Ccps',
#        '122Cthl', '321Wncl', '324Bzrvl', '324Bzrvu', '124Jcks',
#        '124Jcksu', '124Yeguu', '321Hmck', '110Avch', '124Smbr', '218Eddt',
#        '110Avme', '120Vlcc', '120Igns', '112Glfc', '312Rslr', '323Dmpl',
#        '321Mark', '110Avcg', '321Gzck', '112Leon', '124Cabf', '218Edrda',
#        '124Ygjk', '321Cncs', '111Abzr', '124Qcsp', '110Avcc', '218Glrh',
#        '112Pecsa', '218Plxp', '313Crcx', '122Lokv', '312Ocar', '100Cpcr',
#        '218Hepf', '210Cigr', '112Lncz', '124Hoop', '218Prhf', '367Ebph',
#        '112Lblg', '367Ebcr', '111Pcrv', '321Pptc', '363Fpas', '367Mrtn',
#        '110Avtv', '318Sdpp', '369Mtdf', '361Cbmv', '112Lnsa', '218Glrsu',
#        '321Hymd', '124Ckmc', '321Rngr', '321Pwwm', '110Avcy', '110Avlc',
#        '100Cpcrl', '218Frgr', '110Avet', '321Pswm', '367Ordv', '313Sadr',
#        '218Grhc', '218Ebfza', '327Tsns', '218Hcsh', '218Ccrk', '100Cpdg',
#        '371Welg', '313Svrv', '110Avwx', '367Ebss', '218Edgru', '218Edgr',
#        '218Glrsl', '313Cptn', '112Lnan', '218Fkbw', '371Mcwg', '367Ebhk',
#        '313Dlrm', '218Grhcu', '371Wglm', '371Wlbr', '218Hscc', '100Cpdr',
#        '400Pcmb', '371Snsb', '111Avcr', '217Crcsl', '217Hscc', '400Vspg',
#        '400Pckd', '124Jkyg', '218Grgn', '371Rily', '218Tseb', '112Sbdm',
#        '218Psgh', '112Sbcr', '367Hnct', '219Slgh', '218Grlh', '400Grnt',
#        '318Bsvp', '362Wdhl', '124Czcb', '111Rgrd', '112Hcbl', '124Sbhp',
#        '125Wlsp', '371Grnt', '120Ivig', '112Msbl', '124Cbsb', '120Blsn',
#        '110Avsb', '110Aasp', '320Mblf', '110Agrt', '112Sbcrc', '318Bspg',
#        '327Mfeb', '110Avyg', '112Slbl', '312Cstl', '111Hppa', '313Dmbs',
#        '313Crdm', '371Wglh', '371Mgck', '320Smck', '371Cpmn', '110Avty',
#        '371Mwlm', '218Edpm', '112Efbl', '218Glrp', '318Vcpk', '112Rlbl',
#        '218Glrt', '360Cabl', '371Resh', '110Avts', '110Avrf', '363Ftpn',
#        '320Gptk', '367Grmn', '367Tnrd', '371Lnmn', '218Grccu', '110Avmf',
#        '110Avss', '218Scmr', '312Dylk', '313Belc', '110Qcch', '124Spsp',
#        '124Czsb', '124Splr', '218Lgrlh', '112Sblp', '124Ygcm', '367Ebsw',
#        '124Spcz', '110Avgr', '124Ljuy', '124Czcsb', '318Hucl', '218Gruh',
#        '125Thcn', '122Jspru', '121Evgl', '100Taho', '218Grhh', '122Flmg',
#        '110Avtp', '122Bkvl', '112Chctu', '112Cevg', '312Sldo', '124Ckms',
#        '121Gold', '122Jpjk', '112Chctl', '112Gold', '112Chctm', '122Okvc',
#        '122Lgrt', '110Avml', '122Fbkv', '122Cjck', '112Liss', '121Evjp',
#        '122Jbkv', '122Jpcl', '112Lwcx', '122Okvl', '112Sbtv', '110Avcm',
#        '112Prbl', '112Bmnt', '110Avjk', '121Evjpu', '121Evbv', '124Lrdo',
#        '211Ecdd', '112Grbl', '110Avev', '112Lgld', '124Bfcs', '110Avpr',
#        '112Bmls', '124Bgdf', '124Indo', '211Ancc', '211Aedd', '218Yucc',
#        '371Pnpk', '313Gdlp', '112Bmlg', '110Alwx', '110Bild', '112Lnas',
#        '112Wlls', '211Blwg', '211Epic', '110Bibc', '124Elpc', '112Mcsb',
#        '218Coxs', '217Slgo', '121Gdlg', '110Bwdr', '110Avgl', '211Buda',
#        '218Fwgr', '121Uvld', '112Allm', '112Pcpc', '211Aguj', '211Bqls',
#        '217Bscs', '110Avls', '211Smgl', '112Lsrp', '218Snel', '212Pen',
#        '319Cmjc', '318Sacz', '112Lnbd', '112Gows', '110Step'],
#       dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For this {state name / organization}, we don't want water rights that are considered: {enter string entries here}

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to POU csv inputs.

# %% [markdown]
# ## Export Data

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141605 entries, 0 to 141604
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   WaDEUUID                                      141605 non-null  object
#  1   in_MethodUUID                                 141605 non-null  object
#  2   in_VariableSpecificUUID                       141605 non-null  object
#  3   in_OrganizationUUID                           141605 non-null  object
#  4   in_Geometry                                   141605 non-null  object
#  5   in_GNISFeatureNameCV                          141605 non-null  object
#  6   in_WaterQualityIndicatorCV                    141605 non-null  object
#  7   in_WaterSourceName                            141605 non-null  object
#  8   in_WaterSourceNativeID                        141605 non-null  object
#  9   in_WaterSourceTypeCV                          141605 non-null  object
#  10  in_CoordinateAccuracy                         141605 non-null  object
#  11  in_CoordinateMethodCV                         141605 non-null  object
#  12  in_County                                     141605 non-null  object
#  13  in_EPSGCodeCV                                 141605 non-null  object
#  14  in_GNISCodeCV                                 141605 non-null  object
#  15  in_HUC12                                      141605 non-null  object
#  16  in_HUC8                                       141605 non-null  object
#  17  in_Latitude                                   141605 non-null  float64
#  18  in_Longitude                                  141605 non-null  float64
#  19  in_NHDNetworkStatusCV                         141605 non-null  object
#  20  in_NHDProductCV                               141605 non-null  object
#  21  in_PODorPOUSite                               141605 non-null  object
#  22  in_SiteName                                   141605 non-null  object
#  23  in_SiteNativeID                               141605 non-null  object
#  24  in_SitePoint                                  141605 non-null  object
#  25  in_SiteTypeCV                                 141605 non-null  object
#  26  in_StateCV                                    141605 non-null  object
#  27  in_USGSSiteID                                 141605 non-null  object
#  28  in_AllocationApplicationDate                  141605 non-null  object
#  29  in_AllocationAssociatedConsumptiveUseSiteIDs  141605 non-null  object
#  30  in_AllocationAssociatedWithdrawalSiteIDs      141605 non-null  object
#  31  in_AllocationBasisCV                          141605 non-null  object
#  32  in_AllocationChangeApplicationIndicator       141605 non-null  object
#  33  in_AllocationCommunityWaterSupplySystem       141605 non-null  object
#  34  in_AllocationCropDutyAmount                   141605 non-null  object
#  35  in_AllocationExpirationDate                   141605 non-null  object
#  36  in_AllocationFlow_CFS                         141605 non-null  object
#  37  in_AllocationLegalStatusCV                    141605 non-null  object
#  38  in_AllocationNativeID                         141605 non-null  object
#  39  in_AllocationOwner                            141605 non-null  object
#  40  in_AllocationPriorityDate                     141605 non-null  object
#  41  in_AllocationSDWISIdentifierCV                141605 non-null  object
#  42  in_AllocationTimeframeEnd                     141605 non-null  object
#  43  in_AllocationTimeframeStart                   141605 non-null  object
#  44  in_AllocationTypeCV                           141605 non-null  object
#  45  in_AllocationVolume_AF                        141605 non-null  object
#  46  in_BeneficialUseCategory                      141605 non-null  object
#  47  in_CommunityWaterSupplySystem                 141605 non-null  object
#  48  in_CropTypeCV                                 141605 non-null  object
#  49  in_CustomerTypeCV                             141605 non-null  object
#  50  in_DataPublicationDate                        141605 non-null  object
#  51  in_DataPublicationDOI                         141605 non-null  object
#  52  in_ExemptOfVolumeFlowPriority                 141605 non-null  object
#  53  in_GeneratedPowerCapacityMW                   141605 non-null  object
#  54  in_IrrigatedAcreage                           141605 non-null  object
#  55  in_IrrigationMethodCV                         141605 non-null  object
#  56  in_LegacyAllocationIDs                        141605 non-null  object
#  57  in_OwnerClassificationCV                      141605 non-null  object
#  58  in_PopulationServed                           141605 non-null  object
#  59  in_PowerType                                  141605 non-null  object
#  60  in_PrimaryBeneficialUseCategory               141605 non-null  object
#  61  in_SDWISIdentifierCV                          141605 non-null  object
#  62  in_WaterAllocationNativeURL                   141605 non-null  object
# dtypes: float64(2), object(61)
# memory usage: 68.1+ MB

# %%
outdf
# Out:
#          WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0            txD0     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 1            txD1     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 2            txD2     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 3            txD3     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 4            txD4     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# ...           ...           ...                     ...                 ...
# 141600  txD141600     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 141601  txD141601     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 141602  txD141602     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 141603  txD141603     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
# 141604  txD141604     TWDBwr_M1               TWDBwr_V1           TWDBwr_O1
#
#        in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...            ...                  ...                        ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#         in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0       Ogallala Formation                121Ogll          Groundwater
# 1       Ogallala Formation                121Ogll          Groundwater
# 2       Ogallala Formation                121Ogll          Groundwater
# 3       Ogallala Formation                121Ogll          Groundwater
# 4       Ogallala Formation                121Ogll          Groundwater
# ...                    ...                    ...                  ...
# 141600    Laredo Formation                124Lrdo          Groundwater
# 141601    Laredo Formation                124Lrdo          Groundwater
# 141602    Laredo Formation                124Lrdo          Groundwater
# 141603    Laredo Formation                124Lrdo          Groundwater
# 141604    Laredo Formation                124Lrdo          Groundwater
#
#        in_CoordinateAccuracy in_CoordinateMethodCV in_County in_EPSGCodeCV  \
# 0                                        Digitized   Randall
# 1                                        Digitized   Randall
# 2                                        Digitized   Randall
# 3                                        Digitized   Randall
# 4                                        Digitized   Randall
# ...                      ...                   ...       ...           ...
# 141600                                   Digitized      Webb
# 141601                                   Digitized      Webb
# 141602                                   Digitized      Webb
# 141603                                   Digitized      Webb
# 141604                                   Digitized      Webb
#
#        in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                         35.11361    -101.97611
# 1                                         35.08500    -101.98695
# 2                                         35.11722    -101.94889
# 3                                         35.10556    -101.94611
# 4                                         35.10195    -101.95278
# ...              ...      ...     ...          ...           ...
# 141600                                    27.49056     -99.42361
# 141601                                    27.43333     -99.48250
# 141602                                    27.40667     -99.47861
# 141603                                    27.45722     -99.01639
# 141604                                    27.30972     -99.35778
#
#        in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                        POD
# 1                                                        POD
# 2                                                        POD
# 3                                                        POD
# 4                                                        POD
# ...                      ...             ...             ...         ...
# 141600                                                   POD
# 141601                                                   POD
# 141602                                                   POD
# 141603                                                   POD
# 141604                                                   POD
#
#        in_SiteNativeID in_SitePoint        in_SiteTypeCV in_StateCV  \
# 0            POD657116               Withdrawal of Water         TX
# 1            POD657118               Withdrawal of Water         TX
# 2            POD657207               Withdrawal of Water         TX
# 3            POD657209               Withdrawal of Water         TX
# 4            POD657211               Withdrawal of Water         TX
# ...                ...          ...                  ...        ...
# 141600      POD8537207               Withdrawal of Water         TX
# 141601      POD8537405               Withdrawal of Water         TX
# 141602      POD8537702               Withdrawal of Water         TX
# 141603      POD8540601               Withdrawal of Water         TX
# 141604      POD8546401               Withdrawal of Water         TX
#
#        in_USGSSiteID in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...              ...                          ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                             ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...                  ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                         ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...                   ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                                                657116
# 1                                                657118
# 2                                                657207
# 3                                                657209
# 4                                                657211
# ...                           ...                   ...
# 141600                                          8537207
# 141601                                          8537405
# 141602                                          8537702
# 141603                                          8540601
# 141604                                          8546401
#
#                      in_AllocationOwner in_AllocationPriorityDate  \
# 0                     1 B Dugger Estate
# 1                             L W Smith
# 2       Amarillo Municipal Water System
# 3                        Ervin Podzemny
# 4                   Caroline Bush Emery
# ...                                 ...                       ...
# 141600                         Gonzalez
# 141601                     Rafael Cantu
# 141602                          Gf Link
# 141603                    Daniel Garcia
# 141604                 Carlos Alexander
#
#        in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                       ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0                                     Rules of Capture
# 1                                     Rules of Capture
# 2                                     Rules of Capture
# 3                                     Rules of Capture
# 4                                     Rules of Capture
# ...                            ...                 ...                    ...
# 141600                                Rules of Capture
# 141601                                Rules of Capture
# 141602                                Rules of Capture
# 141603                                Rules of Capture
# 141604                                Rules of Capture
#
#        in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0                    Irrigation
# 1                    Irrigation
# 2                 Public Supply
# 3                    Irrigation
# 4                    Irrigation
# ...                         ...                           ...           ...
# 141600
# 141601                 Domestic
# 141602                    Stock
# 141603                    Stock
# 141604                    Stock
#
#        in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                    ...                   ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  1
# ...                              ...                         ...
# 141600                             1
# 141601                             1
# 141602                             1
# 141603                             1
# 141604                             1
#
#        in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...                   ...                    ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                 ...          ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#        in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                ...                  ...
# 141600
# 141601
# 141602
# 141603
# 141604
#
#                               in_WaterAllocationNativeURL
# 0       https://www3.twdb.texas.gov/apps/waterdatainte...
# 1       https://www3.twdb.texas.gov/apps/waterdatainte...
# 2       https://www3.twdb.texas.gov/apps/waterdatainte...
# 3       https://www3.twdb.texas.gov/apps/waterdatainte...
# 4       https://www3.twdb.texas.gov/apps/waterdatainte...
# ...                                                   ...
# 141600  https://www3.twdb.texas.gov/apps/waterdatainte...
# 141601  https://www3.twdb.texas.gov/apps/waterdatainte...
# 141602  https://www3.twdb.texas.gov/apps/waterdatainte...
# 141603  https://www3.twdb.texas.gov/apps/waterdatainte...
# 141604  https://www3.twdb.texas.gov/apps/waterdatainte...
#
# [141605 rows x 63 columns]

# %%
# Export the output dataframe
# change output name / abbreviation to match native state provdier and wade data type 
outdf.to_csv('RawInputData/Pwr_twdbMain.zip', compression=dict(method='zip', archive_name='Pwr_twdbMain.csv'), index=False)  # The output, save as a zip
