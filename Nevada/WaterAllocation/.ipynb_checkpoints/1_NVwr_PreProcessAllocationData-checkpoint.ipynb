# %% [markdown]
# # Pre-processing Allocation data for WaDE upload.
# - Purpose:  To pre-process the data into one main file for simple DataFrame creation and extraction

# %%
import os
import sys
print(os.environ['CONDA_DEFAULT_ENV'])
print(sys.version)
# Out:
# base
# 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:20:11) [MSC v.1938 64 bit (AMD64)]

# %%
# Needed Libraries / Modules

# ---- working with data ----
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/WaDE Data Folder/Nevada/WaterAllocation" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/WaDE Data Folder/Nevada/WaterAllocation

# %% [markdown]
# ## Point of Diversion Data

# %%
# Input File
FI_PoD = "RawInputData/PointsofDiversion.zip"
dfinPOD = pd.read_csv(FI_PoD).replace(np.nan, "")
# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "utD" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('RawInputData/PointsofDiversion.zip', compression=dict(method='zip', archive_name='PointsofDiversion.csv'), index=False)

FI_POwner="RawInputData/Permit_Owners.zip"
dfinPOwner = pd.read_csv(FI_POwner).replace(np.nan, "")
dfinPOwner['app'] = dfinPOwner['app'].str.replace('\s+','')
dfinPOwner= dfinPOwner.groupby('app').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem != ""])).replace(np.nan, "").reset_index()   

mergedData = pd.merge(dfinPOD, dfinPOwner, left_on='app', right_on='app',how='left' )#merging pod and permit owner tables

#pd.reset_option('max_columns')
pd.set_option('display.max_columns', None)
print(len(dfinPOwner))
#dfinPOD.head()
mergedData.head(1)
# Out:
# 110169
#      app app_status site_name poly_id cert  mou basin county_x source  \
# 0  13425        CAN                         IRR   001       HU    UG
#
#   source_desc duty_balance diversion_balance diversion_rate pou_acre_total  \
# 0                  0.00000           0.00000        4.00000      400.00000
#
#            priority_date            permit_date              file_date  \
# 0  6/19/1950 8:00:00.000  9/17/1951 8:00:00.000  6/19/1950 8:00:00.000
#
#   rfa_date  publication_sent_date poc_filed_date          poc_due_date  \
# 0           6/14/1951 8:00:00.000                 4/2/1958 8:00:00.000
#
#   pbu_due_date por_due_date decree_name project_name monitor_plan  \
# 0
#
#   reporting_required meter_required interbasin_transfer hydro_assessment  \
# 0
#
#   secondary_use                                      permit_record  latitude  \
# 0                https://tools.water.nv.gov/permitinformation.a...  41.96222
#
#    longitude record_last_updated                                GlobalID  \
# 0 -118.65139                      {6EE70B72-8929-4711-9C02-02B9E0844644}
#
#   WaDEUUID OBJECTID owner_name owner_type owner_pct owner_duty owner_div_rate  \
# 0     utD0      NaN        NaN        NaN       NaN        NaN            NaN
#
#   owner_acre owner_chg_app county_y  apn owner_remark
# 0        NaN           NaN      NaN  NaN          NaN

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = mergedData['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "NVwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "NVwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "NVwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = ""
df['in_WaterSourceNativeID'] = "" # auto fill in below
df['in_WaterSourceTypeCV'] = mergedData['source']

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = "Digitized"
df['in_County'] = mergedData['county_x']
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = mergedData['latitude']
df['in_Longitude'] = mergedData['longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"
df['in_SiteName'] = mergedData['site_name']
df['in_SiteNativeID'] = ""
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = mergedData['source_desc']
df['in_StateCV'] = "NV"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = mergedData['diversion_rate']
df['in_AllocationLegalStatusCV'] = mergedData['app_status']
df['in_AllocationNativeID'] =  mergedData['app'].replace("", 0).fillna(0).astype(str).str.lower().str.strip()
df['in_AllocationOwner'] = mergedData['owner_name']
df['in_AllocationPriorityDate'] = mergedData['priority_date']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = mergedData['duty_balance']
df['in_BeneficialUseCategory'] = mergedData['mou']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0 # either a 1 or 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = mergedData['pou_acre_total']
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = mergedData['permit_record']

outPOD = df.copy()
outPOD = outPOD.drop_duplicates().reset_index(drop=True)
print(len(outPOD))
outPOD.head()
# Out:
# 108475
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     utD0       NVwr_M1                 NVwr_V1             NVwr_O1
# 1     utD1       NVwr_M1                 NVwr_V1             NVwr_O1
# 2     utD2       NVwr_M1                 NVwr_V1             NVwr_O1
# 3     utD3       NVwr_M1                 NVwr_V1             NVwr_O1
# 4     utD4       NVwr_M1                 NVwr_V1             NVwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                                            UG
# 1                                                            SPR
# 2                                                            UG
# 3                                                            UG
# 4                                                            UG
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                   Digitized        HU           4326
# 1                                   Digitized        HU           4326
# 2                                   Digitized        HU           4326
# 3                                   Digitized        HU           4326
# 4                                   Digitized        HU           4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    41.96222    -118.65139
# 1                                    41.82827    -118.65229
# 2                                    41.98946    -118.63394
# 3                                    41.93695    -118.58222
# 4                                    41.95917    -118.60611
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite           in_SiteName  \
# 0                                                   POD
# 1                                                   POD
# 2                                                   POD  001  N47 E30 03B   1
# 3                                                   POD
# 4                                                   POD
#
#   in_SiteNativeID in_SitePoint    in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                                                       NV
# 1                               ANTELOPE SPRING         NV
# 2                                                       NV
# 3                                                       NV
# 4                                                       NV
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0                                           4.00000
# 1                                           0.25000
# 2                                           0.03300
# 3                                           6.00000
# 4                                           4.50000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 0                        CAN                 13425                NaN
# 1                        CAN                 13922                NaN
# 2                        CER                 18083                NaN
# 3                        CAN                 19512                NaN
# 4                        ABR                 23155                NaN
#
#   in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0     6/19/1950 8:00:00.000
# 1    11/26/1951 8:00:00.000
# 2     6/25/1959 8:00:00.000
# 3     1/30/1961 8:00:00.000
# 4     6/21/1966 8:00:00.000
#
#   in_AllocationTimeframeEnd in_AllocationTimeframeStart in_AllocationTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationVolume_AF in_BeneficialUseCategory  \
# 0                0.00000                      IRR
# 1                0.00000                      STK
# 2                4.00000                      IRR
# 3                0.00000                      IRR
# 4                0.00000                      IRR
#
#   in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDate in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                                           0
# 1                                                                           0
# 2                                                                           0
# 3                                                                           0
# 4                                                                           0
#
#   in_GeneratedPowerCapacityMW in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0                                       400.00000
# 1                                         0.00000
# 2                                         1.00000
# 3                                       320.00000
# 4                                       640.00000
#
#   in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://tools.water.nv.gov/permitinformation.a...
# 1  https://tools.water.nv.gov/permitinformation.a...
# 2  https://tools.water.nv.gov/permitinformation.a...
# 3  https://tools.water.nv.gov/permitinformation.a...
# 4  https://tools.water.nv.gov/permitinformation.a...

# %% [markdown]
# ## Place of Use Data

# %%
# Input File - place of use data
FI_POU = "RawInputData/shapefiles/Water_Rights_Places_of_Use.zip"
dfinPOU = gpd.read_file(FI_POU).replace(np.nan, "") 
dfinPOU['geometry'] = dfinPOU['geometry'].to_crs(epsg=4326) # Realign Geometry Projection

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOU:
    dfinPOU['WaDEUUID'] = "utU" + dfinPOU.index.astype(str)
    dfinPOU.to_csv('RawInputData/Water_Rights_Places_of_Use.zip', compression=dict(method='zip', archive_name='Water_Rights_Places_of_Use.csv'), index=False)

dfinPOwner = pd.read_csv(FI_POwner, encoding = "ISO-8859-1").replace(np.nan, "")
dfinPOwner['app'] = dfinPOwner['app'].str.replace('\s+','')
dfinPOwner= dfinPOwner.groupby('app').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem != ""])).replace(np.nan, "").reset_index()   
PouMergedData = pd.merge(dfinPOU, dfinPOwner, left_on='app', right_on='app',how='left' )

print(len(PouMergedData))
PouMergedData.head(1)
# Out:
# 35076
#    OBJECTID    app app_status             site_name  poly_id   cert  mou  \
# 0         1  83684        CER  002  N44 E28 10DCBD1    71366  20243  STK
#
#   basin county_x source source_des  duty_balan  diversion_  diversio_1  \
# 0   002       HU     UG               13.44000     0.01860     0.01860
#
#    pou_acre_t priority_d permit_dat  file_date   rfa_date publicatio  \
# 0     0.00000 2014-03-31 2014-10-13 2014-03-31 2014-06-05 2014-04-09
#
#   poc_filed_ poc_due_da pbu_due_da por_due_da decree_nam project_na  \
# 0 2015-11-09 2015-10-13 2016-10-13        NaT
#
#   monitor_pl reporting_  meter_requ interbasin hydro_asse secondary_  \
# 0                                 0
#
#                                           permit_rec  latitude  longitude  \
# 0  https://tools.water.nv.gov/permitinformation.a...  41.75270 -118.75259
#
#   record_las                                GlobalID   Shape__Are  Shape__Len  \
# 0 2022-02-18  {5EA36B9F-CFFB-4A72-89BE-313B313A8F68} 165876.99597  1630.07557
#
#    Shape_Leng  Shape_Area                                           geometry  \
# 0     0.01712     0.00002  POLYGON ((-118.75024 41.7537, -118.75015 41.74...
#
#   WaDEUUID ï»¿OBJECTID owner_name owner_type owner_pct owner_duty  \
# 0     utU0         NaN        NaN        NaN       NaN        NaN
#
#   owner_div_rate owner_acre owner_chg_app county_y  apn owner_remark
# 0            NaN        NaN           NaN      NaN  NaN          NaN

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = PouMergedData['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "NVwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "NVwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "NVwr_O1"

#dfinPOU['']

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = ""
df['in_WaterSourceNativeID'] = ""
df['in_WaterSourceTypeCV'] = PouMergedData['source']

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = "Digitized"
df['in_County'] = PouMergedData['county_x']
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = PouMergedData['geometry']
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = PouMergedData['latitude']
df['in_Longitude'] = PouMergedData['longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POU"  # "Place of Use"
df['in_SiteName'] = PouMergedData['site_name']
df['in_SiteNativeID'] = "u" + PouMergedData['OBJECTID'].astype(str) ###################
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = PouMergedData['source_des']
df['in_StateCV'] = "NV"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = PouMergedData['diversio_1']
df['in_AllocationLegalStatusCV'] =PouMergedData['app_status']
df['in_AllocationNativeID'] =  PouMergedData['app'].replace("", 0).fillna(0).astype(str).str.lower().str.strip()
df['in_AllocationOwner'] = PouMergedData['owner_name']
df['in_AllocationPriorityDate'] = PouMergedData['priority_d']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = PouMergedData['duty_balan']
df['in_BeneficialUseCategory'] = PouMergedData['mou']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0 # either a 1 or 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = PouMergedData['pou_acre_t']
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = PouMergedData['permit_rec']

outPOU = df.copy()
outPOU = outPOU.drop_duplicates().reset_index(drop=True)
print(len(outPOU))
outPOU.head()
# Out:
# 35076
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     utU0       NVwr_M1                 NVwr_V1             NVwr_O1
# 1     utU1       NVwr_M1                 NVwr_V1             NVwr_O1
# 2     utU2       NVwr_M1                 NVwr_V1             NVwr_O1
# 3     utU3       NVwr_M1                 NVwr_V1             NVwr_O1
# 4     utU4       NVwr_M1                 NVwr_V1             NVwr_O1
#
#                                          in_Geometry in_GNISFeatureNameCV  \
# 0  POLYGON ((-118.75024 41.7537, -118.75015 41.74...
# 1  POLYGON ((-118.74926 41.80192, -118.74959 41.7...
# 2  POLYGON ((-119.96893 41.50136, -119.96749 41.5...
# 3  POLYGON ((-119.96893 41.50136, -119.96749 41.5...
# 4  MULTIPOLYGON (((-119.46469 40.70969, -119.4650...
#
#   in_WaterQualityIndicatorCV in_WaterSourceName in_WaterSourceNativeID  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceTypeCV in_CoordinateAccuracy in_CoordinateMethodCV in_County  \
# 0                   UG                                   Digitized        HU
# 1                   UG                                   Digitized        HU
# 2                  SPR                                   Digitized        WA
# 3                  SPR                                   Digitized        WA
# 4                   UG                                   Digitized        WA
#
#    in_EPSGCodeCV in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0           4326                                    41.75270    -118.75259
# 1           4326                                    41.79056    -118.74670
# 2           4326                                    41.50126    -119.96801
# 3           4326                                    41.50279    -119.96535
# 4           4326                                    40.70758    -119.46560
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite           in_SiteName  \
# 0                                                   POU  002  N44 E28 10DCBD1
# 1                                                   POU  002  N45 E28 34BCCC1
# 2                                                   POU  014  N41 E18 04DAAD1
# 3                                                   POU  014  N14 E18 03CBBA1
# 4                                                   POU  021  N33 E22 26CCDA1
#
#   in_SiteNativeID in_SitePoint            in_SiteTypeCV in_StateCV  \
# 0              u1                                               NV
# 1              u2                                               NV
# 2              u3               LOU'S SPRING (SEE PG 3)         NV
# 3              u4                         THOR'S SPRING         NV
# 4              u5                                               NV
#
#   in_USGSSiteID in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                                            0.01860
# 1                                            4.74000
# 2                                            0.20000
# 3                                            0.00400
# 4                                            0.04000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 0                        CER                 83684                NaN
# 1                        PER                 84922                NaN
# 2                        CER                 28567                NaN
# 3                        CER                 44666                NaN
# 4                        CER                 78054                NaN
#
#   in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0                2014-03-31
# 1                1952-02-08
# 2                1974-08-02
# 3                1993-04-28
# 4                1987-12-21
#
#   in_AllocationTimeframeEnd in_AllocationTimeframeStart in_AllocationTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#    in_AllocationVolume_AF in_BeneficialUseCategory  \
# 0                13.44000                      STK
# 1              3377.60000                      IRR
# 2                12.00000                      IRR
# 3                 2.93000                      IRR
# 4                 6.74000                      IRR
#
#   in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDate in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                                           0
# 1                                                                           0
# 2                                                                           0
# 3                                                                           0
# 4                                                                           0
#
#   in_GeneratedPowerCapacityMW  in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0                                          0.00000
# 1                                          0.00000
# 2                                          3.00000
# 3                                          3.00000
# 4                                          0.00000
#
#   in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://tools.water.nv.gov/permitinformation.a...
# 1  https://tools.water.nv.gov/permitinformation.a...
# 2  https://tools.water.nv.gov/permitinformation.a...
# 3  https://tools.water.nv.gov/permitinformation.a...
# 4  https://tools.water.nv.gov/permitinformation.a...

# %% [markdown]
# ## Concatenate POD and POU Data.  Make needed changes

# %%
# Concatenate dataframes
frames = [outPOD, outPOU]
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 143551

# %%
# For creating County
CountyDict = {
    "HU" : "Humboldt",
    "CC" : "Carson City",
    "CH" : "Churchill",
    "CL" : "Clark",
    "DO" : "Douglas",
    "EL" : "Elko",
    "ES" : "Esmerelda",
    "EU" : "Eureka",
    "LA" : "Lander",
    "LI" : "Lincoln",
    "LY": "Lyon",
    "MI": "Mineral",
    "NY": "Nye",
    "PE": "Pershing",
    "ST": "Storey",
     "": "Unknown",
    "WA": "Washoe",
    "WP": "White Pine",
    "UK": "Unknown"}
def assignCounty(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ""
    else:
        String1 = colrowValue.strip()
        try:
            outList = CountyDict[String1]
        except:
            outList = ""
    return outList

outdf['in_County'] = outdf.apply(lambda row: assignCounty(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['Humboldt', 'Washoe', 'Pershing', 'Unknown', 'Elko', 'Nye',
#        'White Pine', 'Eureka', 'Lander', 'Esmerelda', 'Churchill',
#        'Storey', 'Lyon', 'Douglas', 'Carson City', '', 'Mineral',
#        'Lincoln', 'Clark'], dtype=object)

# %%
# For creating AllocationLegalStatusCV
LegalDict = {
"ABN" : "Abandoned",
"ABR" : "Abrogated",
"APP" : "Application",
"CAN" : "Canceled",
"CER" : "Certificate",
"CUR" : "Curtailed",
"DEC" : "Decreed",
"DEN": "Denied",
"EXP": "Expired",
"FOR": "Forfeited",
"PER": "Permit",
"REJ": "Rejected",
"REL": "Relinquished",
"RES": "Reserved",
"RFA": "Ready For Action",
"RFP": "Ready for Action (Protested)",
"RLP": "Relinquish a Portion",
"RSC": "Rescinded",
"RVK": "Revoked",
"RVP": "Revocable Permit",
"SUP": "Supersceded",
"SUS": "Suspended",
"VST": "Vested Rights",
"WDR": "Withdrawn"}
def assignAllocationLegalStatusCV(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue) == True :
        outList = ""
    else:
        String1 = colrowValue.strip()
        try:
            outList = LegalDict[String1]
        except:
            outList = ""
    return outList
outdf['in_AllocationLegalStatusCV'] = outdf.apply(lambda row: assignAllocationLegalStatusCV(row['in_AllocationLegalStatusCV']), axis=1)
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Canceled', 'Certificate', 'Abrogated', 'Withdrawn', 'Denied',
#        'Vested Rights', 'Permit', 'Decreed', 'Expired',
#        'Ready for Action (Protested)', 'Ready For Action', 'Application',
#        'Reserved', 'Rejected', 'Abandoned', 'Supersceded', 'Forfeited',
#        'Relinquished', 'Relinquish a Portion', 'Rescinded', 'Suspended',
#        '', 'Revocable Permit', 'Revoked'], dtype=object)

# %%
# For creating BeneficialUse
BeneficialUseDict = {
"COM" : "Commercial",
"CON" : "Construction",
"DEC" : "As Decreed",
"DOM" : "Domestic",
"DWR" : "Dewatering",
"ENV" : "Environmental",
"EVP" : "Evaporation",
"IND": "Industrial",
"IRC": "Irrigation-Carey Act",
"IRD": "Irrigation-DLE",
"IRR": "Irrigation",
"MM": "Mining and Milling",
"MMD": "Mining Milling and Dewatering",
"MUN": "Municipal",
"OTH": "Other",
"PWR": "Power",
"QM": "Quasi-Municipal",
"REC": "Recreational",
"STK": "Stockwatering",
"STO": "Storage",
"UKN": "Unknown",
"WLD": "Wildlife"}
def assignBeneficialUse(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = BeneficialUseDict[String1]
        except:
            outList = ""

    return outList
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: assignBeneficialUse(row['in_BeneficialUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['Irrigation', 'Stockwatering', 'Quasi-Municipal', 'Commercial',
#        'Other', 'Mining and Milling', 'Irrigation-DLE', 'Domestic',
#        'Storage', 'Power', 'Municipal', 'Construction', 'Industrial',
#        'Wildlife', 'Mining Milling and Dewatering',
#        'Irrigation-Carey Act', 'Recreational', 'Dewatering', 'As Decreed',
#        'Environmental', 'Unknown', 'Evaporation'], dtype=object)

# %%
# For creating WaterSourceTypeCV
UnknownWSCVDict = {
"EFF" : "Reuse",
"GEO" : "Groundwater",
"LAK" : "Surface Water",
"OGW" : "Groundwater",
"OSW" : "Surface Water",
"RES" : "Reservoir",
"SPR" : "Surface Water",
"STO" : "Storage",
"STR" : "Surface Water",
"UG" : "Groundwater",
"UKN" : "Unknown"}
def assignWaterSourceTypeCV(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = ""
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = UnknownWSCVDict[String1]
        except:
            outList = ""
    return outList

outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: assignWaterSourceTypeCV(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater', 'Surface Water', 'Reservoir', 'Storage', 'Reuse',
#        'Unknown'], dtype=object)

# %%
# For creating SiteTypeCV
UnknownSTCVDict = {
    "EFF":"Effluent",
    "GEO":"Geothermal",
    "LAK":"lake",
    "OGW":"Other Ground Water",
    "OSW":"Other Surface Water",
    "RES":"Reservoir",
    "SPR":"Spring",
    "STO":"Storage",
    "STR":"stream",
    "UG":"Underground",
    "UKN":"Unknown"}
def assignSiteTypeCV(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ""
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = UnknownSTCVDict[String1]
        except:
            outList = ""
    return outList

outdf['in_SiteTypeCV'] = outdf.apply(lambda row: assignSiteTypeCV(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['', 'Geothermal', 'Spring', 'Underground'], dtype=object)

# %% [markdown]
# ## Clean Data / data types

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip().rstrip(',')
    return Val

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['', '001 N47 E30 03B  1', '001 N47 E30 04B  5', ..., 'Na',
#        '133 N18 E37 20Acdc1', '162 S20 E52 02Caab1'], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array([''], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater', 'Surface Water', 'Reservoir', 'Storage', 'Reuse',
#        'Unknown'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['', 'Geothermal', 'Spring', 'Underground'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['', '001 N47 E30 03B  1', '001 N47 E30 04B  5', ..., 'Na',
#        '133 N18 E37 20Acdc1', '162 S20 E52 02Caab1'], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
uniqueList = list(set([i.strip() for i in ','.join(outdf['in_BeneficialUseCategory'].astype(str)).split(',')]))
uniqueList.sort()
uniqueList
# Out:
# ['As Decreed',
#  'Commercial',
#  'Construction',
#  'Dewatering',
#  'Domestic',
#  'Environmental',
#  'Evaporation',
#  'Industrial',
#  'Irrigation',
#  'Irrigation-Carey Act',
#  'Irrigation-DLE',
#  'Mining Milling and Dewatering',
#  'Mining and Milling',
#  'Municipal',
#  'Other',
#  'Power',
#  'Quasi-Municipal',
#  'Recreational',
#  'Stockwatering',
#  'Storage',
#  'Unknown',
#  'Wildlife']

# %%
# Ensure Latitude entry is either numireic or blank, no 0 entries
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([41.962223, 41.828273, 41.989459, ..., 35.812644, 36.045556,
#        36.2416  ])

# %%
# Ensure Longitude entry is either numireic or blank, no 0 entries
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-118.65139 , -118.65229 , -118.633941, ...,  115.246944,
#         115.191944,  114.802238])

# %%
# Changing datatype of Priority Date to date fields entry
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'], errors = 'coerce')
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# <DatetimeArray>
# ['1950-06-19 00:00:00', '1951-11-26 00:00:00', '1959-06-25 00:00:00',
#  '1961-01-30 00:00:00', '1966-06-21 00:00:00', '1966-05-27 00:00:00',
#  '1964-10-06 00:00:00', '1973-04-18 00:00:00', '1993-08-02 00:00:00',
#  '1992-10-14 00:00:00',
#  ...
#  '1932-11-05 00:00:00', '1931-04-07 00:00:00', '2019-11-04 00:00:00',
#  '2003-02-27 00:00:00', '2003-06-25 00:00:00', '2003-12-08 00:00:00',
#  '2004-07-19 00:00:00', '2021-10-01 00:00:00', '2022-08-29 00:00:00',
#  '2023-07-18 00:00:00']
# Length: 18367, dtype: datetime64[ns]

# %%
# Ensure Flow entry is either numireic or blank, no 0 entries
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([4.0, 0.25, 0.033, ..., 2.2205, 0.00823, 23.21], dtype=object)

# %%
# Ensure Volume entry is either numireic or blank, no 0 entries
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array(['', 4.0, 0.71, ..., 79.66, 7304.9, 84.05], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], 
                                                                              row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', 'wadeId4', 'wadeId5', 'wadeId6'],
#       dtype=object)

# %%
# Creating WaDE Custom site native ID for easy site identification
# use Unique Latitude, Longitude, SiteName and SiteTypeCV values
# ----------------------------------------------------------------------------------------------------

# Create temp in_SiteNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_Latitude'] = outdf['in_Latitude'].astype(str).str.strip()
dfTempID['in_Longitude'] = outdf['in_Longitude'].astype(str).str.strip()
dfTempID['in_SiteName'] = outdf['in_SiteName'].astype(str).str.strip()
dfTempID['in_SiteTypeCV'] = outdf['in_SiteTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_SiteNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_Latitude'].astype(str) + dfTempID['in_Longitude'].astype(str) + dfTempID['in_SiteName'].astype(str)+ dfTempID['in_SiteTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_SiteNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB, valC, valD):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip() + str(valC).strip() + str(valD).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_SiteNativeID'], 
                                                                       row['in_Latitude'], row['in_Longitude'],
                                                                       row['in_SiteName'], row['in_SiteTypeCV']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', ..., 'u35074', 'u35075', 'u35076'],
#       dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For this {state name / organization}, we don't want water rights that are considered: {enter string entries here}

# %%
# drop non-active AllocationLegalStatusCV values specific to that state.

# drop the list
dropLegalStatusList = ["Abandoned", "Abrogated", "Application", "Canceled", "Denied", "Expired", "Forfeited", "Ready For Action", "Ready for Action (Protested)", "Rejected", "Revoked", "Supersceded", "Withdrawn"]

# drop rows from above list
outdf = outdf[outdf.in_AllocationLegalStatusCV.isin(dropLegalStatusList) == False].reset_index(drop=True)

print(len(outdf))
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# 64436
# array(['Certificate', 'Vested Rights', 'Permit', 'Decreed', 'Reserved',
#        'Relinquished', 'Relinquish a Portion', 'Rescinded', 'Suspended',
#        '', 'Revocable Permit'], dtype=object)

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to POU csv inputs.

# %%
# # Input File / or use same input as above

gdfin1 = outdf.copy()
gdfin1 = gdfin1[gdfin1['in_Geometry'] != ""]
gdfin1 = gpd.GeoDataFrame(gdfin1, geometry=gdfin1['in_Geometry'], crs="EPSG:4326") # covert to geodataframe
print(len(gdfin1))
gdfin1.head()
# Out:
# 23754
#       WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 40682     utU0       NVwr_M1                 NVwr_V1             NVwr_O1
# 40683     utU1       NVwr_M1                 NVwr_V1             NVwr_O1
# 40684     utU2       NVwr_M1                 NVwr_V1             NVwr_O1
# 40685     utU3       NVwr_M1                 NVwr_V1             NVwr_O1
# 40686     utU4       NVwr_M1                 NVwr_V1             NVwr_O1
#
#                                              in_Geometry in_GNISFeatureNameCV  \
# 40682  POLYGON ((-118.75023613699994 41.7536958550000...
# 40683  POLYGON ((-118.74926472199996 41.8019185290000...
# 40684  POLYGON ((-119.96892520199998 41.5013580610000...
# 40685  POLYGON ((-119.96892520199998 41.5013580610000...
# 40686  MULTIPOLYGON (((-119.46469219299996 40.7096931...
#
#       in_WaterQualityIndicatorCV in_WaterSourceName in_WaterSourceNativeID  \
# 40682                                                              wadeId1
# 40683                                                              wadeId1
# 40684                                                              wadeId2
# 40685                                                              wadeId2
# 40686                                                              wadeId1
#
#       in_WaterSourceTypeCV in_CoordinateAccuracy in_CoordinateMethodCV  \
# 40682          Groundwater                                   Digitized
# 40683          Groundwater                                   Digitized
# 40684        Surface Water                                   Digitized
# 40685        Surface Water                                   Digitized
# 40686          Groundwater                                   Digitized
#
#       in_County  in_EPSGCodeCV in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  \
# 40682  Humboldt           4326                                    41.75270
# 40683  Humboldt           4326                                    41.79056
# 40684    Washoe           4326                                    41.50126
# 40685    Washoe           4326                                    41.50279
# 40686    Washoe           4326                                    40.70758
#
#        in_Longitude in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 40682    -118.75259                                                   POU
# 40683    -118.74670                                                   POU
# 40684    -119.96801                                                   POU
# 40685    -119.96535                                                   POU
# 40686    -119.46560                                                   POU
#
#                in_SiteName in_SiteNativeID in_SitePoint in_SiteTypeCV  \
# 40682  002 N44 E28 10Dcbd1              u1
# 40683  002 N45 E28 34Bccc1              u2
# 40684  014 N41 E18 04Daad1              u3
# 40685  014 N14 E18 03Cbba1              u4
# 40686  021 N33 E22 26Ccda1              u5
#
#       in_StateCV in_USGSSiteID in_AllocationApplicationDate  \
# 40682         NV
# 40683         NV
# 40684         NV
# 40685         NV
# 40686         NV
#
#       in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 40682
# 40683
# 40684
# 40685
# 40686
#
#       in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 40682
# 40683
# 40684
# 40685
# 40686
#
#       in_AllocationChangeApplicationIndicator  \
# 40682
# 40683
# 40684
# 40685
# 40686
#
#       in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 40682
# 40683
# 40684
# 40685
# 40686
#
#       in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 40682                                           0.01860
# 40683                                           4.74000
# 40684                                           0.20000
# 40685                                           0.00400
# 40686                                           0.04000
#
#       in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 40682                Certificate                 83684
# 40683                     Permit                 84922
# 40684                Certificate                 28567
# 40685                Certificate                 44666
# 40686                Certificate                 78054
#
#       in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 40682                2014-03-31
# 40683                1952-02-08
# 40684                1974-08-02
# 40685                1993-04-28
# 40686                1987-12-21
#
#       in_AllocationTimeframeEnd in_AllocationTimeframeStart  \
# 40682
# 40683
# 40684
# 40685
# 40686
#
#       in_AllocationTypeCV in_AllocationVolume_AF in_BeneficialUseCategory  \
# 40682                                   13.44000            Stockwatering
# 40683                                 3377.60000               Irrigation
# 40684                                   12.00000               Irrigation
# 40685                                    2.93000               Irrigation
# 40686                                    6.74000               Irrigation
#
#       in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 40682
# 40683
# 40684
# 40685
# 40686
#
#       in_DataPublicationDate in_DataPublicationDOI  \
# 40682
# 40683
# 40684
# 40685
# 40686
#
#        in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 40682                              0
# 40683                              0
# 40684                              0
# 40685                              0
# 40686                              0
#
#       in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 40682             0.00000
# 40683             0.00000
# 40684             3.00000
# 40685             3.00000
# 40686             0.00000
#
#       in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 40682
# 40683
# 40684
# 40685
# 40686
#
#       in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 40682
# 40683
# 40684
# 40685
# 40686
#
#                              in_WaterAllocationNativeURL  \
# 40682  https://tools.water.nv.gov/permitinformation.a...
# 40683  https://tools.water.nv.gov/permitinformation.a...
# 40684  https://tools.water.nv.gov/permitinformation.a...
# 40685  https://tools.water.nv.gov/permitinformation.a...
# 40686  https://tools.water.nv.gov/permitinformation.a...
#
#                                                 geometry
# 40682  POLYGON ((-118.75024 41.7537, -118.75015 41.74...
# 40683  POLYGON ((-118.74926 41.80192, -118.74959 41.7...
# 40684  POLYGON ((-119.96893 41.50136, -119.96749 41.5...
# 40685  POLYGON ((-119.96893 41.50136, -119.96749 41.5...
# 40686  MULTIPOLYGON (((-119.46469 40.70969, -119.4650...

# %%
# plot shape info to map
gdfin1.plot()
# Out:
# <Axes: >

# %%
# create output for Regulatory Area #1 dataframe
df = pd.DataFrame()

columnsList = ['in_SiteNativeID', 'geometry']
goutdf1 = pd.DataFrame(columns=columnsList, index=gdfin1.index)

goutdf1['in_SiteNativeID'] =  gdfin1["in_SiteNativeID"].astype(str)  #in_SiteNativeID needs to match source from above equivalent dataframe
goutdf1['geometry'] = gdfin1['in_Geometry']
goutdf1 = goutdf1.drop_duplicates().reset_index(drop=True)

# drop geometery from outdf
outdf = outdf.drop(['in_Geometry'], axis=1)

print(len(goutdf1))
goutdf1.head()
# Out:
# 23754
#   in_SiteNativeID                                           geometry
# 0              u1  POLYGON ((-118.75023613699994 41.7536958550000...
# 1              u2  POLYGON ((-118.74926472199996 41.8019185290000...
# 2              u3  POLYGON ((-119.96892520199998 41.5013580610000...
# 3              u4  POLYGON ((-119.96892520199998 41.5013580610000...
# 4              u5  MULTIPOLYGON (((-119.46469219299996 40.7096931...

# %% [markdown]
# ## Export Data

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64436 entries, 0 to 64435
# Data columns (total 62 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   WaDEUUID                                      64436 non-null  object
#  1   in_MethodUUID                                 64436 non-null  object
#  2   in_VariableSpecificUUID                       64436 non-null  object
#  3   in_OrganizationUUID                           64436 non-null  object
#  4   in_GNISFeatureNameCV                          64436 non-null  object
#  5   in_WaterQualityIndicatorCV                    64436 non-null  object
#  6   in_WaterSourceName                            64436 non-null  object
#  7   in_WaterSourceNativeID                        64436 non-null  object
#  8   in_WaterSourceTypeCV                          64436 non-null  object
#  9   in_CoordinateAccuracy                         64436 non-null  object
#  10  in_CoordinateMethodCV                         64436 non-null  object
#  11  in_County                                     64436 non-null  object
#  12  in_EPSGCodeCV                                 64436 non-null  int64
#  13  in_GNISCodeCV                                 64436 non-null  object
#  14  in_HUC12                                      64436 non-null  object
#  15  in_HUC8                                       64436 non-null  object
#  16  in_Latitude                                   64436 non-null  float64
#  17  in_Longitude                                  64436 non-null  float64
#  18  in_NHDNetworkStatusCV                         64436 non-null  object
#  19  in_NHDProductCV                               64436 non-null  object
#  20  in_PODorPOUSite                               64436 non-null  object
#  21  in_SiteName                                   64436 non-null  object
#  22  in_SiteNativeID                               64436 non-null  object
#  23  in_SitePoint                                  64436 non-null  object
#  24  in_SiteTypeCV                                 64436 non-null  object
#  25  in_StateCV                                    64436 non-null  object
#  26  in_USGSSiteID                                 64436 non-null  object
#  27  in_AllocationApplicationDate                  64436 non-null  object
#  28  in_AllocationAssociatedConsumptiveUseSiteIDs  64436 non-null  object
#  29  in_AllocationAssociatedWithdrawalSiteIDs      64436 non-null  object
#  30  in_AllocationBasisCV                          64436 non-null  object
#  31  in_AllocationChangeApplicationIndicator       64436 non-null  object
#  32  in_AllocationCommunityWaterSupplySystem       64436 non-null  object
#  33  in_AllocationCropDutyAmount                   64436 non-null  object
#  34  in_AllocationExpirationDate                   64436 non-null  object
#  35  in_AllocationFlow_CFS                         64436 non-null  object
#  36  in_AllocationLegalStatusCV                    64436 non-null  object
#  37  in_AllocationNativeID                         64436 non-null  object
#  38  in_AllocationOwner                            64436 non-null  object
#  39  in_AllocationPriorityDate                     63195 non-null  datetime64[ns]
#  40  in_AllocationSDWISIdentifierCV                64436 non-null  object
#  41  in_AllocationTimeframeEnd                     64436 non-null  object
#  42  in_AllocationTimeframeStart                   64436 non-null  object
#  43  in_AllocationTypeCV                           64436 non-null  object
#  44  in_AllocationVolume_AF                        64436 non-null  object
#  45  in_BeneficialUseCategory                      64436 non-null  object
#  46  in_CommunityWaterSupplySystem                 64436 non-null  object
#  47  in_CropTypeCV                                 64436 non-null  object
#  48  in_CustomerTypeCV                             64436 non-null  object
#  49  in_DataPublicationDate                        64436 non-null  object
#  50  in_DataPublicationDOI                         64436 non-null  object
#  51  in_ExemptOfVolumeFlowPriority                 64436 non-null  int64
#  52  in_GeneratedPowerCapacityMW                   64436 non-null  object
#  53  in_IrrigatedAcreage                           64436 non-null  object
#  54  in_IrrigationMethodCV                         64436 non-null  object
#  55  in_LegacyAllocationIDs                        64436 non-null  object
#  56  in_OwnerClassificationCV                      64436 non-null  object
#  57  in_PopulationServed                           64436 non-null  object
#  58  in_PowerType                                  64436 non-null  object
#  59  in_PrimaryBeneficialUseCategory               64436 non-null  object
#  60  in_SDWISIdentifierCV                          64436 non-null  object
#  61  in_WaterAllocationNativeURL                   64436 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(57)
# memory usage: 30.5+ MB

# %%
outdf
# Out:
#        WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0          utD2       NVwr_M1                 NVwr_V1             NVwr_O1
# 1          utD9       NVwr_M1                 NVwr_V1             NVwr_O1
# 2         utD10       NVwr_M1                 NVwr_V1             NVwr_O1
# 3         utD15       NVwr_M1                 NVwr_V1             NVwr_O1
# 4         utD17       NVwr_M1                 NVwr_V1             NVwr_O1
# ...         ...           ...                     ...                 ...
# 64431  utU35070       NVwr_M1                 NVwr_V1             NVwr_O1
# 64432  utU35071       NVwr_M1                 NVwr_V1             NVwr_O1
# 64433  utU35072       NVwr_M1                 NVwr_V1             NVwr_O1
# 64434  utU35073       NVwr_M1                 NVwr_V1             NVwr_O1
# 64435  utU35074       NVwr_M1                 NVwr_V1             NVwr_O1
#
#       in_GNISFeatureNameCV in_WaterQualityIndicatorCV in_WaterSourceName  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...                        ...                ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#       in_WaterSourceNativeID in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0                    wadeId1          Groundwater
# 1                    wadeId1          Groundwater
# 2                    wadeId1          Groundwater
# 3                    wadeId2        Surface Water
# 4                    wadeId2        Surface Water
# ...                      ...                  ...                   ...
# 64431                wadeId2        Surface Water
# 64432                wadeId1          Groundwater
# 64433                wadeId1          Groundwater
# 64434                wadeId2        Surface Water
# 64435                wadeId1          Groundwater
#
#       in_CoordinateMethodCV in_County  in_EPSGCodeCV in_GNISCodeCV in_HUC12  \
# 0                 Digitized  Humboldt           4326
# 1                 Digitized  Humboldt           4326
# 2                 Digitized  Humboldt           4326
# 3                 Digitized  Humboldt           4326
# 4                 Digitized  Humboldt           4326
# ...                     ...       ...            ...           ...      ...
# 64431             Digitized    Washoe           4326
# 64432             Digitized    Washoe           4326
# 64433             Digitized    Washoe           4326
# 64434             Digitized    Washoe           4326
# 64435             Digitized    Washoe           4326
#
#       in_HUC8  in_Latitude  in_Longitude in_NHDNetworkStatusCV  \
# 0                 41.98946    -118.63394
# 1                 41.98905    -118.63599
# 2                 41.97720    -118.54150
# 3                 41.95763    -118.38856
# 4                 41.98722    -118.64833
# ...       ...          ...           ...                   ...
# 64431             39.22583    -119.84496
# 64432             39.28665    -119.83759
# 64433             39.30218    -119.82797
# 64434             39.23293    -119.83249
# 64435             39.23186    -119.82680
#
#       in_NHDProductCV in_PODorPOUSite          in_SiteName in_SiteNativeID  \
# 0                                 POD   001 N47 E30 03B  1         wadeId3
# 1                                 POD   001 N47 E30 04B  5        wadeId10
# 2                                 POD  001 N47 E31 07Aaaa1        wadeId11
# 3                                 POD  001 N47 E32 16Abcb1        wadeId16
# 4                                 POD                             wadeId18
# ...               ...             ...                  ...             ...
# 64431                             POU  089 N16 E19 27Bcbb1          u35071
# 64432                             POU  089 N16 E19 03Baac1          u35072
# 64433                             POU  089 N17 E19 34Aaaa1          u35073
# 64434                             POU  089 N16 E19 22Dcaa1          u35074
# 64435                             POU  089 N16 E19 22Ddad1          u35075
#
#       in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                                        NV
# 1                                        NV
# 2                                        NV
# 3                                        NV
# 4                                        NV
# ...            ...           ...        ...           ...
# 64431                                    NV
# 64432                                    NV
# 64433                                    NV
# 64434                                    NV
# 64435                                    NV
#
#       in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#       in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                            ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#       in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                  ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#       in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#       in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...                         ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#       in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0                                               0.03300
# 1                                               0.50000
# 2                                               0.00900
# 3                                               0.02800
# 4                                               0.22000
# ...                           ...                   ...
# 64431                                           0.23000
# 64432                                           0.73200
# 64433                                           0.46760
# 64434
# 64435                                           0.00880
#
#       in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 0                    Certificate                 18083
# 1                    Certificate                 50082
# 2                    Certificate                 58248
# 3                    Certificate                  9580
# 4                  Vested Rights                v12046
# ...                          ...                   ...                ...
# 64431                     Permit                 66612
# 64432                     Permit                 68111
# 64433                     Permit                 68113
# 64434                Certificate              69734s02
# 64435                Certificate                 73191
#
#       in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0                    1959-06-25
# 1                    1993-08-02
# 2                    1992-10-14
# 3                    1932-03-28
# 4                    1892-01-01
# ...                         ...                            ...
# 64431                1986-08-13
# 64432                1962-08-20
# 64433                1966-08-02
# 64434                2014-02-28
# 64435                1962-08-20
#
#       in_AllocationTimeframeEnd in_AllocationTimeframeStart  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                         ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#       in_AllocationTypeCV in_AllocationVolume_AF in_BeneficialUseCategory  \
# 0                                        4.00000               Irrigation
# 1                                        0.71000          Quasi-Municipal
# 2                                        6.72089            Stockwatering
# 3                                       13.50316            Stockwatering
# 4                                                           Stockwatering
# ...                   ...                    ...                      ...
# 64431                                  136.67000             Recreational
# 64432                                  502.52000               Irrigation
# 64433                                  274.35000               Irrigation
# 64434                                    6.00000               Irrigation
# 64435                                    6.39400               Irrigation
#
#       in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...           ...               ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#       in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...                   ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#        in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...                         ...
# 64431                              0
# 64432                              0
# 64433                              0
# 64434                              0
# 64435                              0
#
#       in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0                 1.00000
# 1                 0.00000
# 2                 0.00000
# 3                 0.00000
# 4                 0.00000
# ...                   ...                   ...                    ...
# 64431           171.13000
# 64432             0.00000
# 64433             0.00000
# 64434             0.00000
# 64435             0.00000
#
#       in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                 ...          ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#       in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                  ...
# 64431
# 64432
# 64433
# 64434
# 64435
#
#                              in_WaterAllocationNativeURL
# 0      https://tools.water.nv.gov/permitinformation.a...
# 1      https://tools.water.nv.gov/permitinformation.a...
# 2      https://tools.water.nv.gov/permitinformation.a...
# 3      https://tools.water.nv.gov/permitinformation.a...
# 4      https://tools.water.nv.gov/permitinformation.a...
# ...                                                  ...
# 64431  https://tools.water.nv.gov/permitinformation.a...
# 64432  https://tools.water.nv.gov/permitinformation.a...
# 64433  https://tools.water.nv.gov/permitinformation.a...
# 64434  https://tools.water.nv.gov/permitinformation.a...
# 64435  https://tools.water.nv.gov/permitinformation.a...
#
# [64436 rows x 62 columns]

# %%
# Export the output dataframe
# change output name / abbreviation to match native state provdier and wade data type 
outdf.to_csv('RawInputData/Pwr_nain.zip', compression=dict(method='zip', archive_name='Pwr_Main.csv'), index=False)  # The output, save as a zip
goutdf1.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
# Out:
# Done
