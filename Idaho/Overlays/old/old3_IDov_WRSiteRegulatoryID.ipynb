# %% [markdown]
# # Assign RegulatoryOverlayUUIDs Values to Water Right sites.csv
# Purpose:  To assign RegulatoryOverlayUUIDs values to state water right sites.csv File.
#
# Notes:
# - requires the completed pre-processed sites.csv & watersource.csv files from the state "WaterAllocation/ProcessedInputData" folder to be copied over to the "Regulatory/ProcessedInputData" folder.  Rename to wr_sites.csv & wr_watersource.csv to preserve inputs.
# - requires awareness of unique WaterSourceTypeCV of each water right site match up to corresponding WaterSourceTypeCV of regulatoryoverlays per reportingunits

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library
import geoplot as gplt # for plotting maps
import geoplot.crs as gcrs #used to pull in webdata

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Idaho/Regulatory" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Idaho/Regulatory

# %% [markdown]
# ## Input Data

# %%
# Regulatory Input Data
dfro = pd.read_csv("ProcessedInputData/regulatoryoverlays.csv")
dfru = pd.read_csv("ProcessedInputData/reportingunits.csv")
dfrru = pd.read_csv("ProcessedInputData/regulatoryreportingunits.csv")

# Water right Input Data
dfws = pd.read_csv('ProcessedInputData/wr_watersources.csv')
dfs = pd.read_csv('ProcessedInputData/wr_sites.csv', engine = "python", on_bad_lines = 'skip')

# %%
#### regulatory watersource info with reporting unit info

# merge regulatoryoverlays -to- regulatoryreportingunits -to- reportingunits
dfro = pd.merge(dfro[['RegulatoryOverlayUUID', 'WaterSourceTypeCV']], dfrru[['RegulatoryOverlayUUID', 'ReportingUnitUUID']], left_on='RegulatoryOverlayUUID', right_on='RegulatoryOverlayUUID', how='left')
dfru = pd.merge(dfru, dfro, left_on='ReportingUnitUUID', right_on='ReportingUnitUUID', how='left')

print(dfru['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfru))
dfru.head(1)
# Out:
# ['Groundwater']
# 31
#   ReportingUnitUUID  EPSGCodeCV                            ReportingUnitName  \
# 0   IDre_RUwadeARD1        4326  Lower Snake River Aquifer Recharge District
#
#   ReportingUnitNativeID  ReportingUnitProductVersion  \
# 0              wadeARD1                          NaN
#
#           ReportingUnitTypeCV ReportingUnitUpdateDate StateCV  \
# 0  Aquifer Recharge Districts               4/27/2023      ID
#
#                                             Geometry RegulatoryOverlayUUID  \
# 0  POLYGON ((-114.45343337104535 42.6049368772191...       IDre_ROwadeARD1
#
#   WaterSourceTypeCV
# 0       Groundwater

# %%
#### water right watersource info with site info

# explode site.csv on WaterSourceUUIDs
dfs = dfs.assign(WaterSourceUUIDs=dfs['WaterSourceUUIDs'].str.split(',')).explode('WaterSourceUUIDs').reset_index(drop=True)

# merge watersources to dfs via WaterSourceUUIDs -to -WaterSourceUUID
dfs = pd.merge(dfs, dfws[['WaterSourceUUID', 'WaterSourceTypeCV']], left_on='WaterSourceUUIDs', right_on='WaterSourceUUID', how='left')
print(dfs['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfs))
dfs.head(1)
# Out:
# ['Groundwater' 'Surface Water' 'Reuse' 'WaDE Unspecified']
# 463791
#          SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 0  IDwr_SPOD10001                     NaN   IDwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV Geometry  GNISCodeCV  \
# 0                QQQ  WaDE Unspecified        4326      NaN         NaN
#
#    HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  NHDProductCV  \
# 0    NaN   NaN  46.78678 -116.75633                 NaN           NaN
#
#   PODorPOUSite          SiteName SiteNativeID  SitePoint        SiteTypeCV  \
# 0          POD  WaDE Unspecified     POD10001        NaN  WaDE Unspecified
#
#   StateCV  USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0      ID         NaN  IDwr_WSwadeID1       Groundwater

# %% [markdown]
# ## Extract RegulatoryOverlay from Reporting Units and assing to WR Sites
# - repeat scripts based on the number of ReportingUnitTypeCV types.
# - merge all geo-dataframes into one output

# %% [markdown]
# #### Regulatory Area Data - CAMP

# %%
# Create copy of reportingunits dataframe
# Extract out ReportingUnitTypeCV from reportingunits dataframe
# note unique WaterSourceTypeCV

dfru0 = dfru.copy()
nameOfReportingUnitTypeVar = "Comprehensive Aquifer Management Plan" # change here for ReportingUnitTypeCV of interest
dfru0 = dfru0[dfru0['ReportingUnitTypeCV'] == nameOfReportingUnitTypeVar]
print(len(dfru0))
print(dfru0['WaterSourceTypeCV'].unique())
dfru0.head(1)
# Out:
# 3
# ['Groundwater']
#          ReportingUnitUUID  EPSGCodeCV ReportingUnitName  \
# 1  IDre_RUwadeEasternSnake        4326     Eastern Snake
#
#   ReportingUnitNativeID  ReportingUnitProductVersion  \
# 1      wadeEasternSnake                          NaN
#
#                      ReportingUnitTypeCV ReportingUnitUpdateDate StateCV  \
# 1  Comprehensive Aquifer Management Plan                     NaN      ID
#
#                                             Geometry    RegulatoryOverlayUUID  \
# 1  POLYGON ((-111.67756699799997 44.2230369650000...  IDre_ROwadeEasternSnake
#
#   WaterSourceTypeCV
# 1       Groundwater

# %%
# Convert dataframe -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

dfru0 = dfru0[dfru0['Geometry'] != ""].reset_index(drop=True)
dfru0['Geometry'] = gpd.GeoSeries.from_wkt(dfru0['Geometry'], crs="EPSG:4326")
gdfru0 = gpd.GeoDataFrame(dfru0, geometry=dfru0['Geometry'], crs="EPSG:4326") # covert to geodataframe
gplt.polyplot(gdfru0, ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Create copy of water right sites dataframe
# Extract out WaterSourceTypeCV and match to that of above reportingunits dataframe

dfs0 = dfs.copy()
nameOfWaterSourceTypeCV= "Groundwater" # change here for WaterSourceTypeCV of interest
dfs0 = dfs0[dfs0['WaterSourceTypeCV'] == nameOfWaterSourceTypeCV]
dfs0 = dfs0[dfs0['PODorPOUSite'] == 'POD']
print(len(dfs0))
print(dfs0['WaterSourceTypeCV'].unique())
dfs0.head(1)
# Out:
# 134908
# ['Groundwater']
#          SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 0  IDwr_SPOD10001                     NaN   IDwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV Geometry  GNISCodeCV  \
# 0                QQQ  WaDE Unspecified        4326      NaN         NaN
#
#    HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  NHDProductCV  \
# 0    NaN   NaN  46.78678 -116.75633                 NaN           NaN
#
#   PODorPOUSite          SiteName SiteNativeID  SitePoint        SiteTypeCV  \
# 0          POD  WaDE Unspecified     POD10001        NaN  WaDE Unspecified
#
#   StateCV  USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0      ID         NaN  IDwr_WSwadeID1       Groundwater

# %%
# Convert extracted water right sites -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gdfs0 = gpd.GeoDataFrame(dfs0, geometry=gpd.points_from_xy(dfs0.Longitude.astype(float), dfs0.Latitude.astype(float)), crs="EPSG:4326")
gplt.pointplot(gdfs0, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Select sites within polygon.
gdfs0_ru0 = gpd.sjoin(left_df=gdfs0, right_df=gdfru0[['ReportingUnitUUID', 'RegulatoryOverlayUUID', 'geometry']], op='within').replace(np.nan, "")
print(len(gdfs0_ru0))
gdfs0_ru0.head()
# Out:
# C:\Users\rjame\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3466: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# 72441
#            SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 3   IDwr_SPOD100116                          IDwr_WSwadeID1
# 7   IDwr_SPOD100156                          IDwr_WSwadeID1
# 34  IDwr_SPOD100408                          IDwr_WSwadeID1
# 35  IDwr_SPOD100415                          IDwr_WSwadeID1
# 36  IDwr_SPOD100425                          IDwr_WSwadeID1
#
#    CoordinateAccuracy CoordinateMethodCV            County  EPSGCodeCV  \
# 3    WaDE Unspecified          Digitized  WaDE Unspecified        4326
# 7    WaDE Unspecified                 QQ  WaDE Unspecified        4326
# 34   WaDE Unspecified                 QQ  WaDE Unspecified        4326
# 35   WaDE Unspecified          Digitized  WaDE Unspecified        4326
# 36   WaDE Unspecified   GPS - Downloaded  WaDE Unspecified        4326
#
#    Geometry GNISCodeCV HUC12 HUC8  Latitude  Longitude NHDNetworkStatusCV  \
# 3                                  43.20912 -112.32591
# 7                                  42.77748 -114.92504
# 34                                 43.83951 -112.33379
# 35                                 42.88440 -112.88605
# 36                                 42.75278 -114.77182
#
#    NHDProductCV PODorPOUSite          SiteName SiteNativeID SitePoint  \
# 3                        POD  WaDE Unspecified    POD100116
# 7                        POD  WaDE Unspecified    POD100156
# 34                       POD  WaDE Unspecified    POD100408
# 35                       POD  WaDE Unspecified    POD100415
# 36                       POD  WaDE Unspecified    POD100425
#
#           SiteTypeCV StateCV USGSSiteID WaterSourceUUID WaterSourceTypeCV  \
# 3   WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 7   WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 34  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 35  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 36  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
#
#                        geometry  index_right        ReportingUnitUUID  \
# 3   POINT (-112.32591 43.20912)            0  IDre_RUwadeEasternSnake
# 7   POINT (-114.92504 42.77748)            0  IDre_RUwadeEasternSnake
# 34  POINT (-112.33379 43.83951)            0  IDre_RUwadeEasternSnake
# 35  POINT (-112.88605 42.88440)            0  IDre_RUwadeEasternSnake
# 36  POINT (-114.77182 42.75278)            0  IDre_RUwadeEasternSnake
#
#       RegulatoryOverlayUUID
# 3   IDre_ROwadeEasternSnake
# 7   IDre_ROwadeEasternSnake
# 34  IDre_ROwadeEasternSnake
# 35  IDre_ROwadeEasternSnake
# 36  IDre_ROwadeEasternSnake

# %%
# plot the selected points
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gplt.pointplot(gdfs0_ru0, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# set RegulatoryOverlayUUIDs
gdfs0_ru0['RegulatoryOverlayUUIDs'] = gdfs0_ru0['RegulatoryOverlayUUID']
gdfs0_ru0 = gdfs0_ru0.drop(['RegulatoryOverlayUUID', 'geometry', 'index_right', 'ReportingUnitUUID', 'WaterSourceUUID', 'WaterSourceTypeCV'], axis=1)
gdfs0_ru0.head(1)
# Out:
#           SiteUUID   RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 3  IDwr_SPOD100116  IDre_ROwadeEasternSnake   IDwr_WSwadeID1
#
#   CoordinateAccuracy CoordinateMethodCV            County  EPSGCodeCV  \
# 3   WaDE Unspecified          Digitized  WaDE Unspecified        4326
#
#   Geometry GNISCodeCV HUC12 HUC8  Latitude  Longitude NHDNetworkStatusCV  \
# 3                                 43.20912 -112.32591
#
#   NHDProductCV PODorPOUSite          SiteName SiteNativeID SitePoint  \
# 3                       POD  WaDE Unspecified    POD100116
#
#          SiteTypeCV StateCV USGSSiteID
# 3  WaDE Unspecified      ID

# %% [markdown]
# #### Regulatory Area Data - Groundwater Districts

# %%
# Create copy of reportingunits dataframe
# Extract out ReportingUnitTypeCV from reportingunits dataframe
# note unique WaterSourceTypeCV

dfru1 = dfru.copy()
nameOfReportingUnitTypeVar = "Groundwater Districts" # change here for ReportingUnitTypeCV of interest
dfru1 = dfru1[dfru1['ReportingUnitTypeCV'] == nameOfReportingUnitTypeVar]
print(len(dfru1))
print(dfru1['WaterSourceTypeCV'].unique())
dfru1.head(1)
# Out:
# 13
# ['Groundwater']
#   ReportingUnitUUID  EPSGCodeCV  \
# 2    IDre_RUwadeGD1        4326
#
#                                ReportingUnitName ReportingUnitNativeID  \
# 2  Aberdeen-American Falls Ground Water District               wadeGD1
#
#    ReportingUnitProductVersion    ReportingUnitTypeCV ReportingUnitUpdateDate  \
# 2                          NaN  Groundwater Districts                     NaN
#
#   StateCV                                           Geometry  \
# 2      ID  POLYGON ((-113.00753494940288 43.1542972978970...
#
#   RegulatoryOverlayUUID WaterSourceTypeCV
# 2        IDre_ROwadeGD1       Groundwater

# %%
# Convert dataframe -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

dfru1 = dfru1[dfru1['Geometry'] != ""].reset_index(drop=True)
dfru1['Geometry'] = gpd.GeoSeries.from_wkt(dfru1['Geometry'], crs="EPSG:4326")
gdfru1 = gpd.GeoDataFrame(dfru1, geometry=dfru1['Geometry'], crs="EPSG:4326") # covert to geodataframe
gplt.polyplot(gdfru1, ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Create copy of water right sites dataframe
# Extract out WaterSourceTypeCV and match to that of above reportingunits dataframe

dfs1 = dfs.copy()
nameOfWaterSourceTypeCV= "Groundwater" # change here for WaterSourceTypeCV of interest
dfs1 = dfs1[dfs1['WaterSourceTypeCV'] == nameOfWaterSourceTypeCV]
dfs1 = dfs1[dfs1['PODorPOUSite'] == 'POD']
print(len(dfs1))
print(dfs1['WaterSourceTypeCV'].unique())
dfs1.head(1)
# Out:
# 134908
# ['Groundwater']
#          SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 0  IDwr_SPOD10001                     NaN   IDwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV Geometry  GNISCodeCV  \
# 0                QQQ  WaDE Unspecified        4326      NaN         NaN
#
#    HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  NHDProductCV  \
# 0    NaN   NaN  46.78678 -116.75633                 NaN           NaN
#
#   PODorPOUSite          SiteName SiteNativeID  SitePoint        SiteTypeCV  \
# 0          POD  WaDE Unspecified     POD10001        NaN  WaDE Unspecified
#
#   StateCV  USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0      ID         NaN  IDwr_WSwadeID1       Groundwater

# %%
# Convert extracted water right sites -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gdfs1 = gpd.GeoDataFrame(dfs1, geometry=gpd.points_from_xy(dfs1.Longitude.astype(float), dfs1.Latitude.astype(float)), crs="EPSG:4326")
gplt.pointplot(gdfs1, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Select sites within polygon.
gdfs1_ru1 = gpd.sjoin(left_df=gdfs1, right_df=gdfru1[['ReportingUnitUUID', 'RegulatoryOverlayUUID', 'geometry']], op='within').replace(np.nan, "")
print(len(gdfs1_ru1))
gdfs1_ru1.head()
# Out:
# C:\Users\rjame\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3466: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# 48386
#             SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 3    IDwr_SPOD100116                          IDwr_WSwadeID1
# 94   IDwr_SPOD100861                          IDwr_WSwadeID1
# 95   IDwr_SPOD100862                          IDwr_WSwadeID1
# 100  IDwr_SPOD100886                          IDwr_WSwadeID1
# 107  IDwr_SPOD100911                          IDwr_WSwadeID1
#
#     CoordinateAccuracy CoordinateMethodCV            County  EPSGCodeCV  \
# 3     WaDE Unspecified          Digitized  WaDE Unspecified        4326
# 94    WaDE Unspecified   GPS - Downloaded  WaDE Unspecified        4326
# 95    WaDE Unspecified   GPS - Downloaded  WaDE Unspecified        4326
# 100   WaDE Unspecified          Digitized  WaDE Unspecified        4326
# 107   WaDE Unspecified          Digitized  WaDE Unspecified        4326
#
#     Geometry GNISCodeCV HUC12 HUC8  Latitude  Longitude NHDNetworkStatusCV  \
# 3                                   43.20912 -112.32591
# 94                                  43.41806 -112.13366
# 95                                  43.41492 -112.13482
# 100                                 43.19453 -112.47977
# 107                                 43.19453 -112.47977
#
#     NHDProductCV PODorPOUSite           SiteName SiteNativeID SitePoint  \
# 3                         POD   WaDE Unspecified    POD100116
# 94                        POD  Woodville Well #3    POD100861
# 95                        POD  Woodville Well #1    POD100862
# 100                       POD             358609    POD100886
# 107                       POD             358609    POD100911
#
#            SiteTypeCV StateCV USGSSiteID WaterSourceUUID WaterSourceTypeCV  \
# 3    WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 94   WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 95   WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 100  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 107  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
#
#                         geometry  index_right ReportingUnitUUID  \
# 3    POINT (-112.32591 43.20912)            2   IDre_RUwadeGD11
# 94   POINT (-112.13366 43.41806)            2   IDre_RUwadeGD11
# 95   POINT (-112.13482 43.41492)            2   IDre_RUwadeGD11
# 100  POINT (-112.47977 43.19453)            2   IDre_RUwadeGD11
# 107  POINT (-112.47977 43.19453)            2   IDre_RUwadeGD11
#
#     RegulatoryOverlayUUID
# 3         IDre_ROwadeGD11
# 94        IDre_ROwadeGD11
# 95        IDre_ROwadeGD11
# 100       IDre_ROwadeGD11
# 107       IDre_ROwadeGD11

# %%
# plot the selected points
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gplt.pointplot(gdfs1_ru1, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# set RegulatoryOverlayUUIDs
gdfs1_ru1['RegulatoryOverlayUUIDs'] = gdfs1_ru1['RegulatoryOverlayUUID']
gdfs1_ru1 = gdfs1_ru1.drop(['RegulatoryOverlayUUID', 'geometry', 'index_right', 'ReportingUnitUUID', 'WaterSourceUUID', 'WaterSourceTypeCV'], axis=1)
gdfs1_ru1.head(1)
# Out:
#           SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 3  IDwr_SPOD100116        IDre_ROwadeGD11   IDwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV Geometry GNISCodeCV HUC12  \
# 3          Digitized  WaDE Unspecified        4326
#
#   HUC8  Latitude  Longitude NHDNetworkStatusCV NHDProductCV PODorPOUSite  \
# 3       43.20912 -112.32591                                          POD
#
#            SiteName SiteNativeID SitePoint        SiteTypeCV StateCV  \
# 3  WaDE Unspecified    POD100116            WaDE Unspecified      ID
#
#   USGSSiteID
# 3

# %% [markdown]
# #### Regulatory Area Data - Groundwater Management Areas

# %%
# Create copy of reportingunits dataframe
# Extract out ReportingUnitTypeCV from reportingunits dataframe
# note unique WaterSourceTypeCV

dfru2 = dfru.copy()
nameOfReportingUnitTypeVar2 = "Groundwater Management Areas" # change here for ReportingUnitTypeCV of interest
dfru2 = dfru2[dfru2['ReportingUnitTypeCV'] == nameOfReportingUnitTypeVar2]
print(len(dfru2))
print(dfru2['WaterSourceTypeCV'].unique())
dfru2.head(1)
# Out:
# 14
# ['Groundwater']
#    ReportingUnitUUID  EPSGCodeCV    ReportingUnitName ReportingUnitNativeID  \
# 15   IDre_RUwadeGMA1        4326  Banbury Hot Springs              wadeGMA1
#
#     ReportingUnitProductVersion           ReportingUnitTypeCV  \
# 15                          NaN  Groundwater Management Areas
#
#    ReportingUnitUpdateDate StateCV  \
# 15               4/27/2023      ID
#
#                                              Geometry RegulatoryOverlayUUID  \
# 15  POLYGON ((-114.84727118448886 42.7250076989836...       IDre_ROwadeGMA1
#
#    WaterSourceTypeCV
# 15       Groundwater

# %%
# Convert dataframe -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

dfru2 = dfru2[dfru2['Geometry'] != ""].reset_index(drop=True)
dfru2['Geometry'] = gpd.GeoSeries.from_wkt(dfru2['Geometry'], crs="EPSG:4326")
gdfru2 = gpd.GeoDataFrame(dfru2, geometry=dfru2['Geometry'], crs="EPSG:4326") # covert to geodataframe
gplt.polyplot(gdfru2, ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Create copy of water right sites dataframe
# Extract out WaterSourceTypeCV and match to that of above reportingunits dataframe

dfs2 = dfs.copy()
nameOfWaterSourceTypeCV2= "Groundwater" # change here for WaterSourceTypeCV of interest
dfs2 = dfs2[dfs2['WaterSourceTypeCV'] == nameOfWaterSourceTypeCV2]
dfs2 = dfs2[dfs2['PODorPOUSite'] == 'POD']
print(len(dfs2))
print(dfs2['WaterSourceTypeCV'].unique())
dfs2.head(1)
# Out:
# 134908
# ['Groundwater']
#          SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 0  IDwr_SPOD10001                     NaN   IDwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV Geometry  GNISCodeCV  \
# 0                QQQ  WaDE Unspecified        4326      NaN         NaN
#
#    HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  NHDProductCV  \
# 0    NaN   NaN  46.78678 -116.75633                 NaN           NaN
#
#   PODorPOUSite          SiteName SiteNativeID  SitePoint        SiteTypeCV  \
# 0          POD  WaDE Unspecified     POD10001        NaN  WaDE Unspecified
#
#   StateCV  USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0      ID         NaN  IDwr_WSwadeID1       Groundwater

# %%
# Convert extracted water right sites -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gdfs2 = gpd.GeoDataFrame(dfs2, geometry=gpd.points_from_xy(dfs2.Longitude.astype(float), dfs1.Latitude.astype(float)), crs="EPSG:4326")
gplt.pointplot(gdfs2, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Select sites within polygon.
gdfs2_ru2 = gpd.sjoin(left_df=gdfs2, right_df=gdfru2[['ReportingUnitUUID', 'RegulatoryOverlayUUID', 'geometry']], op='within').replace(np.nan, "")
print(len(gdfs2_ru2))
gdfs2_ru2.head()
# Out:
# C:\Users\rjame\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3466: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# 65375
#            SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 3   IDwr_SPOD100116                          IDwr_WSwadeID1
# 34  IDwr_SPOD100408                          IDwr_WSwadeID1
# 35  IDwr_SPOD100415                          IDwr_WSwadeID1
# 36  IDwr_SPOD100425                          IDwr_WSwadeID1
# 40  IDwr_SPOD100518                          IDwr_WSwadeID1
#
#    CoordinateAccuracy CoordinateMethodCV            County  EPSGCodeCV  \
# 3    WaDE Unspecified          Digitized  WaDE Unspecified        4326
# 34   WaDE Unspecified                 QQ  WaDE Unspecified        4326
# 35   WaDE Unspecified          Digitized  WaDE Unspecified        4326
# 36   WaDE Unspecified   GPS - Downloaded  WaDE Unspecified        4326
# 40   WaDE Unspecified                 QQ  WaDE Unspecified        4326
#
#    Geometry GNISCodeCV HUC12 HUC8  Latitude  Longitude NHDNetworkStatusCV  \
# 3                                  43.20912 -112.32591
# 34                                 43.83951 -112.33379
# 35                                 42.88440 -112.88605
# 36                                 42.75278 -114.77182
# 40                                 43.45184 -112.08586
#
#    NHDProductCV PODorPOUSite          SiteName SiteNativeID SitePoint  \
# 3                        POD  WaDE Unspecified    POD100116
# 34                       POD  WaDE Unspecified    POD100408
# 35                       POD  WaDE Unspecified    POD100415
# 36                       POD  WaDE Unspecified    POD100425
# 40                       POD  WaDE Unspecified    POD100518
#
#           SiteTypeCV StateCV USGSSiteID WaterSourceUUID WaterSourceTypeCV  \
# 3   WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 34  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 35  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 36  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 40  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
#
#                        geometry  index_right ReportingUnitUUID  \
# 3   POINT (-112.32591 43.20912)           10   IDre_RUwadeGMA6
# 34  POINT (-112.33379 43.83951)           10   IDre_RUwadeGMA6
# 35  POINT (-112.88605 42.88440)           10   IDre_RUwadeGMA6
# 36  POINT (-114.77182 42.75278)           10   IDre_RUwadeGMA6
# 40  POINT (-112.08586 43.45184)           10   IDre_RUwadeGMA6
#
#    RegulatoryOverlayUUID
# 3        IDre_ROwadeGMA6
# 34       IDre_ROwadeGMA6
# 35       IDre_ROwadeGMA6
# 36       IDre_ROwadeGMA6
# 40       IDre_ROwadeGMA6

# %%
# plot the selected points
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gplt.pointplot(gdfs2_ru2, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# set RegulatoryOverlayUUIDs
gdfs2_ru2['RegulatoryOverlayUUIDs'] = gdfs2_ru2['RegulatoryOverlayUUID']
gdfs2_ru2 = gdfs2_ru2.drop(['RegulatoryOverlayUUID', 'geometry', 'index_right', 'ReportingUnitUUID', 'WaterSourceUUID', 'WaterSourceTypeCV'], axis=1)
gdfs2_ru2.head(1)
# Out:
#           SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 3  IDwr_SPOD100116        IDre_ROwadeGMA6   IDwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV Geometry GNISCodeCV HUC12  \
# 3          Digitized  WaDE Unspecified        4326
#
#   HUC8  Latitude  Longitude NHDNetworkStatusCV NHDProductCV PODorPOUSite  \
# 3       43.20912 -112.32591                                          POD
#
#            SiteName SiteNativeID SitePoint        SiteTypeCV StateCV  \
# 3  WaDE Unspecified    POD100116            WaDE Unspecified      ID
#
#   USGSSiteID
# 3

# %% [markdown]
# #### Regulatory Area Data - Aquifer Recharge District

# %%
# Create copy of reportingunits dataframe
# Extract out ReportingUnitTypeCV from reportingunits dataframe
# note unique WaterSourceTypeCV

dfru3 = dfru.copy()
nameOfReportingUnitTypeVar3 = "Aquifer Recharge Districts" # change here for ReportingUnitTypeCV of interest
dfru3 = dfru3[dfru3['ReportingUnitTypeCV'] == nameOfReportingUnitTypeVar3]
print(len(dfru3))
print(dfru3['WaterSourceTypeCV'].unique())
dfru3.head(1)
# Out:
# 1
# ['Groundwater']
#   ReportingUnitUUID  EPSGCodeCV                            ReportingUnitName  \
# 0   IDre_RUwadeARD1        4326  Lower Snake River Aquifer Recharge District
#
#   ReportingUnitNativeID  ReportingUnitProductVersion  \
# 0              wadeARD1                          NaN
#
#           ReportingUnitTypeCV ReportingUnitUpdateDate StateCV  \
# 0  Aquifer Recharge Districts               4/27/2023      ID
#
#                                             Geometry RegulatoryOverlayUUID  \
# 0  POLYGON ((-114.45343337104535 42.6049368772191...       IDre_ROwadeARD1
#
#   WaterSourceTypeCV
# 0       Groundwater

# %%
# Convert dataframe -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

dfru3 = dfru3[dfru3['Geometry'] != ""].reset_index(drop=True)
dfru3['Geometry'] = gpd.GeoSeries.from_wkt(dfru3['Geometry'], crs="EPSG:4326")
gdfru3 = gpd.GeoDataFrame(dfru3, geometry=dfru3['Geometry'], crs="EPSG:4326") # covert to geodataframe
gplt.polyplot(gdfru3, ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Create copy of water right sites dataframe
# Extract out WaterSourceTypeCV and match to that of above reportingunits dataframe

dfs3 = dfs.copy()
nameOfWaterSourceTypeCV3= "Groundwater" # change here for WaterSourceTypeCV of interest
dfs3 = dfs3[dfs3['WaterSourceTypeCV'] == nameOfWaterSourceTypeCV3]
dfs3 = dfs3[dfs3['PODorPOUSite'] == 'POD']
print(len(dfs3))
print(dfs3['WaterSourceTypeCV'].unique())
dfs3.head(1)
# Out:
# 134908
# ['Groundwater']
#          SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 0  IDwr_SPOD10001                     NaN   IDwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV Geometry  GNISCodeCV  \
# 0                QQQ  WaDE Unspecified        4326      NaN         NaN
#
#    HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  NHDProductCV  \
# 0    NaN   NaN  46.78678 -116.75633                 NaN           NaN
#
#   PODorPOUSite          SiteName SiteNativeID  SitePoint        SiteTypeCV  \
# 0          POD  WaDE Unspecified     POD10001        NaN  WaDE Unspecified
#
#   StateCV  USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0      ID         NaN  IDwr_WSwadeID1       Groundwater

# %%
# Convert extracted water right sites -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gdfs3 = gpd.GeoDataFrame(dfs3, geometry=gpd.points_from_xy(dfs3.Longitude.astype(float), dfs1.Latitude.astype(float)), crs="EPSG:4326")
gplt.pointplot(gdfs3, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Select sites within polygon.
gdfs3_ru3 = gpd.sjoin(left_df=gdfs3, right_df=gdfru3[['ReportingUnitUUID', 'RegulatoryOverlayUUID', 'geometry']], op='within').replace(np.nan, "")
print(len(gdfs3_ru3))
gdfs3_ru3.head()
# Out:
# 786
# C:\Users\rjame\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3466: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#              SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 7     IDwr_SPOD100156                          IDwr_WSwadeID1
# 6786  IDwr_SPOD231467                          IDwr_WSwadeID1
# 6787  IDwr_SPOD231468                          IDwr_WSwadeID1
# 6795  IDwr_SPOD231475                          IDwr_WSwadeID1
# 6817  IDwr_SPOD231500                          IDwr_WSwadeID1
#
#      CoordinateAccuracy CoordinateMethodCV            County  EPSGCodeCV  \
# 7      WaDE Unspecified                 QQ  WaDE Unspecified        4326
# 6786   WaDE Unspecified   GPS - Downloaded  WaDE Unspecified        4326
# 6787   WaDE Unspecified   GPS - Downloaded  WaDE Unspecified        4326
# 6795   WaDE Unspecified   GPS - Downloaded  WaDE Unspecified        4326
# 6817   WaDE Unspecified   GPS - Downloaded  WaDE Unspecified        4326
#
#      Geometry GNISCodeCV HUC12 HUC8  Latitude  Longitude NHDNetworkStatusCV  \
# 7                                    42.77748 -114.92504
# 6786                                 42.66596 -114.63185
# 6787                                 42.67023 -114.62896
# 6795                                 42.72495 -114.81666
# 6817                                 42.72495 -114.81666
#
#      NHDProductCV PODorPOUSite          SiteName SiteNativeID SitePoint  \
# 7                          POD  WaDE Unspecified    POD100156
# 6786                       POD  WaDE Unspecified    POD231467
# 6787                       POD  WaDE Unspecified    POD231468
# 6795                       POD   Sand Springs #1    POD231475
# 6817                       POD   Sand Springs #1    POD231500
#
#             SiteTypeCV StateCV USGSSiteID WaterSourceUUID WaterSourceTypeCV  \
# 7     WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 6786  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 6787  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 6795  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
# 6817  WaDE Unspecified      ID             IDwr_WSwadeID1       Groundwater
#
#                          geometry  index_right ReportingUnitUUID  \
# 7     POINT (-114.92504 42.77748)            0   IDre_RUwadeARD1
# 6786  POINT (-114.63185 42.66596)            0   IDre_RUwadeARD1
# 6787  POINT (-114.62896 42.67023)            0   IDre_RUwadeARD1
# 6795  POINT (-114.81666 42.72495)            0   IDre_RUwadeARD1
# 6817  POINT (-114.81666 42.72495)            0   IDre_RUwadeARD1
#
#      RegulatoryOverlayUUID
# 7          IDre_ROwadeARD1
# 6786       IDre_ROwadeARD1
# 6787       IDre_ROwadeARD1
# 6795       IDre_ROwadeARD1
# 6817       IDre_ROwadeARD1

# %%
# plot the selected points
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gplt.pointplot(gdfs3_ru3, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# set RegulatoryOverlayUUIDs
gdfs3_ru3['RegulatoryOverlayUUIDs'] = gdfs3_ru3['RegulatoryOverlayUUID']
gdfs3_ru3 = gdfs3_ru3.drop(['RegulatoryOverlayUUID', 'geometry', 'index_right', 'ReportingUnitUUID', 'WaterSourceUUID', 'WaterSourceTypeCV'], axis=1)
gdfs3_ru3.head(1)
# Out:
#           SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 7  IDwr_SPOD100156        IDre_ROwadeARD1   IDwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County  EPSGCodeCV Geometry GNISCodeCV HUC12  \
# 7                 QQ  WaDE Unspecified        4326
#
#   HUC8  Latitude  Longitude NHDNetworkStatusCV NHDProductCV PODorPOUSite  \
# 7       42.77748 -114.92504                                          POD
#
#            SiteName SiteNativeID SitePoint        SiteTypeCV StateCV  \
# 7  WaDE Unspecified    POD100156            WaDE Unspecified      ID
#
#   USGSSiteID
# 7

# %% [markdown]
# ## Concatenate all Regulatory Area Data Types together
# - drop geometry from the wade wr sites.csv geodataframe

# %%
# Concatenate dataframes into single output
frames = [dfs, gdfs0_ru0, gdfs1_ru1, gdfs2_ru2, gdfs3_ru3] # list all out dataframes here
outdfs = pd.concat(frames)
outdfs = outdfs.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
outdfs = outdfs.groupby('SiteUUID').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem != ""])).replace(np.nan, "").reset_index()
print(len(outdfs))
outdfs.head(1)
# Out:
# 463609
#          SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs CoordinateAccuracy  \
# 0  IDwr_SPOD10001                          IDwr_WSwadeID1   WaDE Unspecified
#
#   CoordinateMethodCV            County EPSGCodeCV Geometry GNISCodeCV HUC12  \
# 0                QQQ  WaDE Unspecified       4326
#
#   HUC8      Latitude       Longitude NHDNetworkStatusCV NHDProductCV  \
# 0       46.786783431  -116.756334953
#
#   PODorPOUSite          SiteName SiteNativeID SitePoint        SiteTypeCV  \
# 0          POD  WaDE Unspecified     POD10001            WaDE Unspecified
#
#   StateCV USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0      ID             IDwr_WSwadeID1       Groundwater

# %% [markdown]
# # Inspect Output Data & Export

# %%
outdfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463609 entries, 0 to 463608
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   SiteUUID                463609 non-null  object
#  1   RegulatoryOverlayUUIDs  463609 non-null  object
#  2   WaterSourceUUIDs        463609 non-null  object
#  3   CoordinateAccuracy      463609 non-null  object
#  4   CoordinateMethodCV      463609 non-null  object
#  5   County                  463609 non-null  object
#  6   EPSGCodeCV              463609 non-null  object
#  7   Geometry                463609 non-null  object
#  8   GNISCodeCV              463609 non-null  object
#  9   HUC12                   463609 non-null  object
#  10  HUC8                    463609 non-null  object
#  11  Latitude                463609 non-null  object
#  12  Longitude               463609 non-null  object
#  13  NHDNetworkStatusCV      463609 non-null  object
#  14  NHDProductCV            463609 non-null  object
#  15  PODorPOUSite            463609 non-null  object
#  16  SiteName                463609 non-null  object
#  17  SiteNativeID            463609 non-null  object
#  18  SitePoint               463609 non-null  object
#  19  SiteTypeCV              463609 non-null  object
#  20  StateCV                 463609 non-null  object
#  21  USGSSiteID              463609 non-null  object
#  22  WaterSourceUUID         463609 non-null  object
#  23  WaterSourceTypeCV       463609 non-null  object
# dtypes: object(24)
# memory usage: 84.9+ MB

# %%
outdfs
# Out:
#                SiteUUID                             RegulatoryOverlayUUIDs  \
# 0        IDwr_SPOD10001
# 1        IDwr_SPOD10002
# 2        IDwr_SPOD10011
# 3       IDwr_SPOD100116  IDre_ROwadeEasternSnake,IDre_ROwadeGD11,IDre_R...
# 4        IDwr_SPOD10012
# ...                 ...                                                ...
# 463604   IDwr_SPOU99984
# 463605   IDwr_SPOU99985
# 463606   IDwr_SPOU99987
# 463607    IDwr_SPOU9999
# 463608   IDwr_SPOU99997
#
#          WaterSourceUUIDs CoordinateAccuracy CoordinateMethodCV  \
# 0          IDwr_WSwadeID1   WaDE Unspecified                QQQ
# 1          IDwr_WSwadeID2   WaDE Unspecified                QQQ
# 2        IDwr_WSwadeID464   WaDE Unspecified          Digitized
# 3          IDwr_WSwadeID1   WaDE Unspecified          Digitized
# 4          IDwr_WSwadeID2   WaDE Unspecified          Digitized
# ...                   ...                ...                ...
# 463604  IDwr_WSwadeID1071   WaDE Unspecified           Centroid
# 463605     IDwr_WSwadeID4   WaDE Unspecified           Centroid
# 463606  IDwr_WSwadeID1239   WaDE Unspecified           Centroid
# 463607     IDwr_WSwadeID1   WaDE Unspecified           Centroid
# 463608     IDwr_WSwadeID2   WaDE Unspecified           Centroid
#
#                   County EPSGCodeCV  \
# 0       WaDE Unspecified       4326
# 1       WaDE Unspecified       4326
# 2       WaDE Unspecified       4326
# 3       WaDE Unspecified       4326
# 4       WaDE Unspecified       4326
# ...                  ...        ...
# 463604  WaDE Unspecified       4326
# 463605  WaDE Unspecified       4326
# 463606  WaDE Unspecified       4326
# 463607  WaDE Unspecified       4326
# 463608  WaDE Unspecified       4326
#
#                                                  Geometry GNISCodeCV HUC12  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...        ...   ...
# 463604  POLYGON ((-113.83349343399999 43.3785455800000...
# 463605  POLYGON ((-113.76915873299998 43.3895130230000...
# 463606  POLYGON ((-114.17487861799998 43.9047213540000...
# 463607  POLYGON ((-112.39023373799995 42.7510759940000...
# 463608  POLYGON ((-114.78214903099996 43.5727974930000...
#
#        HUC8       Latitude       Longitude NHDNetworkStatusCV NHDProductCV  \
# 0             46.786783431  -116.756334953
# 1             46.620745726  -116.678043708
# 2             48.619278353  -116.411597116
# 3             43.209117477  -112.325906615
# 4             48.619278353  -116.411597116
# ...     ...            ...             ...                ...          ...
# 463604       43.3768924284  -113.831084803
# 463605       43.3930982896  -113.766591765
# 463606       43.9046611773  -114.175966206
# 463607        42.752865087  -112.392685561
# 463608       43.5709822324  -114.779659942
#
#        PODorPOUSite                             SiteName SiteNativeID  \
# 0               POD                     WaDE Unspecified     POD10001
# 1               POD                     WaDE Unspecified     POD10002
# 2               POD  Ascentnorthwest Academy  Ruby Creek     POD10011
# 3               POD                     WaDE Unspecified    POD100116
# 4               POD  Ascentnorthwest Academy  Ruby Creek     POD10012
# ...             ...                                  ...          ...
# 463604          POU                     WaDE Unspecified     POU99984
# 463605          POU                     WaDE Unspecified     POU99985
# 463606          POU                     WaDE Unspecified     POU99987
# 463607          POU                     WaDE Unspecified      POU9999
# 463608          POU                     WaDE Unspecified     POU99997
#
#        SitePoint        SiteTypeCV StateCV USGSSiteID    WaterSourceUUID  \
# 0                 WaDE Unspecified      ID                IDwr_WSwadeID1
# 1                 WaDE Unspecified      ID                IDwr_WSwadeID2
# 2                 WaDE Unspecified      ID              IDwr_WSwadeID464
# 3                 WaDE Unspecified      ID                IDwr_WSwadeID1
# 4                 WaDE Unspecified      ID                IDwr_WSwadeID2
# ...          ...               ...     ...        ...                ...
# 463604            WaDE Unspecified      ID             IDwr_WSwadeID1071
# 463605            WaDE Unspecified      ID                IDwr_WSwadeID4
# 463606            WaDE Unspecified      ID             IDwr_WSwadeID1239
# 463607            WaDE Unspecified      ID                IDwr_WSwadeID1
# 463608            WaDE Unspecified      ID                IDwr_WSwadeID2
#
#        WaterSourceTypeCV
# 0            Groundwater
# 1          Surface Water
# 2          Surface Water
# 3            Groundwater
# 4          Surface Water
# ...                  ...
# 463604     Surface Water
# 463605     Surface Water
# 463606     Surface Water
# 463607       Groundwater
# 463608     Surface Water
#
# [463609 rows x 24 columns]

# %%
# Export out to CSV.
outdfs.to_csv('ProcessedInputData/sites.csv', index=False) # this is in the Regulatory data folder
