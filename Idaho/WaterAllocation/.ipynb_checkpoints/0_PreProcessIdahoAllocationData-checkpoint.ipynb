# %% [markdown]
# # Pre-processing Idaho Allocation data for WaDEQA upload.
# - Date Updated: 09/09/2022
# - Purpose:  To pre-process the Idaho data into one master file for simple DataFrame creation and extraction.  Working Idaho data for WaDEQA 2.0 is mostly composed of point of diversion data.
# - Notes: working with POD and POU data.  Working with assumption that both POD and POU data share the same water right record information.

# %%
# Needed Libararies
import os
import numpy as np
import pandas as pd
import datetime
import geopandas as gpd # the library that lets us read in shapefiles
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/Idaho/WaterAllocation/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## Import Input Data

# %%
# POD Data
FI_POD = "Water_Right_PODs_input.csv"
dfinPOD = pd.read_csv(FI_POD)

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "idD" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('Water_Right_PODs_input.csv', index=False)

print(len(dfinPOD))
dfinPOD.head(1)
# Out:
# 259213
#    OID_  OBJECTID WaterRight  BasinNumbe  SequenceNu SplitSuffi  VersionNum  \
# 0     0         1   63-10824          63       10824                      0
#
#    Status    Basis         PriorityDa            Owner  OverallMax  \
# 0  Active  License  6/21/1989 0:00:00  MAURICE MC CLUE        0.19
#
#          Source SourceQual TributaryO Tributar_1 WaterDistr DiversionN  \
# 0  GROUND WATER                                         TBD
#
#   DataSource MetalTagNu DiversionT  RightID  PointOfDiv  \
# 0         QQ                             22          16
#
#                                             WRReport  \
# 0  https://research.idwr.idaho.gov/apps/waterrigh...
#
#                                               WRDocs  \
# 0  https://research.idwr.idaho.gov/apps/Shared/Lf...
#
#                                                WRMap  SpatialDat TrustOrNon  \
# 0  https://maps.idwr.idaho.gov/apps/Shared/PrintM...      482579
#
#     Latitude   Longitude WaDEUUID
# 0  43.690868 -116.416209     idD0

# %%
# POU
FI_POU = "WaterRightPOUs_input.csv"
dfinPOU = pd.read_csv(FI_POU)

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOU:
    dfinPOU['WaDEUUID'] = "idU" + dfinPOU.index.astype(str)
    dfinPOU.to_csv('WaterRightPOUs_input.csv', index=False)

print(len(dfinPOU))
dfinPOU.head(1)
# Out:
# 212562
#    OID_ WaterRight  BasinNumbe  SequenceNu SplitSuffi  Status  \
# 0     0   33-10900          33       10900             Active
#
#           PriorityDa          DecreedDat  \
# 0  6/28/1934 0:00:00  10/11/2001 0:00:00
#
#                                      Owner    WaterUse  WaterUseCo  \
# 0  UNITED STATES OF AMERICA ACTING THROUGH  STOCKWATER           4
#
#    TotalAcres  AcreLimit             Source SourceQual TributaryO Tributar_1  \
# 0         0.0        0.0  LITTLE LOST RIVER                 SINKS
#
#   WaterDistr  LargePOU  RightID  PlaceOfUse  \
# 0         33         0   222600           2
#
#                                             WRReport  \
# 0  https://research.idwr.idaho.gov/apps/waterrigh...
#
#                                               WRDocs  \
# 0  https://research.idwr.idaho.gov/apps/waterrigh...
#
#                                                WRMap TrustOrNon    SHAPE_STAr  \
# 0  https://maps.idwr.idaho.gov/apps/Shared/PrintM...             8.321867e+06
#
#      SHAPE_STLe   Latitude   Longitude WaDEUUID
# 0  54110.179685  43.981402 -113.169818     idU0

# %% [markdown]
# ## POD Sites Data

# %%
# extract a few POU elements

dfinPODm = pd.merge(dfinPOD, dfinPOU[['RightID', 'WaterUse', 'AcreLimit', 'TotalAcres']], on='RightID', how='left')
print(len(dfinPODm))
dfinPODm.head(1)
# Out:
# 308132
#    OID_  OBJECTID WaterRight  BasinNumbe  SequenceNu SplitSuffi  VersionNum  \
# 0     0         1   63-10824          63       10824                      0
#
#    Status    Basis         PriorityDa            Owner  OverallMax  \
# 0  Active  License  6/21/1989 0:00:00  MAURICE MC CLUE        0.19
#
#          Source SourceQual TributaryO Tributar_1 WaterDistr DiversionN  \
# 0  GROUND WATER                                         TBD
#
#   DataSource MetalTagNu DiversionT  RightID  PointOfDiv  \
# 0         QQ                             22          16
#
#                                             WRReport  \
# 0  https://research.idwr.idaho.gov/apps/waterrigh...
#
#                                               WRDocs  \
# 0  https://research.idwr.idaho.gov/apps/Shared/Lf...
#
#                                                WRMap  SpatialDat TrustOrNon  \
# 0  https://maps.idwr.idaho.gov/apps/Shared/PrintM...      482579
#
#     Latitude   Longitude WaDEUUID    WaterUse  AcreLimit  TotalAcres
# 0  43.690868 -116.416209     idD0  IRRIGATION        0.0        15.0

# %%
# # Idaho projection = EPSG:8826.  WGS84 projection used by WaDE 2.0 = epsg:4326.
# from pyproj import Transformer, transform
# transformer = Transformer.from_proj(8826, 4326)  # A trick to drastically optimize the Transformer of pyproj.

# # For converting projection latitude.
# def assignLat(colrowValLat, colrowValLong):
#     lat, long = transformer.transform(colrowValLat, colrowValLong)
#     return lat

# # For converting projection longitude.
# def assignLong(colrowValLat, colrowValLong):
#     lat, long = transformer.transform(colrowValLat, colrowValLong)
#     return long


# dfinPODm['Latitude'] = dfinPODm.apply(lambda row: assignLat(row['Y'], row['X']), axis=1)
# dfinPODm['Longitude'] = dfinPODm.apply(lambda row: assignLong(row['Y'], row['X']), axis=1)
# dfinPODm.head(1)

# %%
# IrrigatedAcreage

def assignIrrigatedAcreage(AcreLimit, TotalAcres):
    AcreLimit = float(AcreLimit)
    TotalAcres = float(TotalAcres)
    if AcreLimit > 0:
        outVal = AcreLimit
    else:
        outVal = TotalAcres
    return outVal

dfinPODm['in_IrrigatedAcreage'] = dfinPODm.apply(lambda row: assignIrrigatedAcreage(row['AcreLimit'], row['TotalAcres']), axis=1)
dfinPODm['in_IrrigatedAcreage'].unique()
# Out:
# array([  15. ,    0. ,   60. , ...,  908. , 2135. ,  120.2])

# %%
# create output POD dataframe

dfPOD = pd.DataFrame()

# Data Assessment UUID
dfPOD['WaDEUUID'] = dfinPODm['WaDEUUID']

# Water Source
dfPOD['in_WaterSourceName'] = dfinPODm['Source'].str.strip()
dfPOD['in_WaterSourceTypeCV'] = dfinPODm['Source'].str.strip()

# Site
dfPOD['in_CoordinateAccuracy'] = "Unspecified"
dfPOD['in_CoordinateMethodCV'] = dfinPODm['DataSource']
dfPOD['in_County'] = "Unspecified"
dfPOD['in_Latitude'] = dfinPODm['Latitude']
dfPOD['in_Longitude'] = dfinPODm['Longitude']
dfPOD['in_PODorPOUSite'] = "POD"
dfPOD['in_SiteName'] = dfinPODm['DiversionN']
dfPOD['in_SiteNativeID'] = "POD" + dfinPODm['PointOfDiv'].astype(str).str.strip()
dfPOD['in_SiteTypeCV'] = "Unspecified"

# Allocation Fact
dfPOD['in_AllocationNativeID'] = dfinPODm['WaterRight']
dfPOD['in_AllocationOwner'] = dfinPODm['Owner']
dfPOD['in_AllocationPriorityDate'] = dfinPODm['PriorityDa']
dfPOD['in_AllocationFlow_CFS'] = dfinPODm['OverallMax']
dfPOD['in_AllocationBasisCV'] = dfinPODm['Basis'].str.strip()
dfPOD['in_AllocationLegalStatusCV'] = dfinPODm['Status'].str.strip()
dfPOD['in_BeneficialUseCategory'] = dfinPODm['WaterUse'].str.strip()
dfPOD['in_IrrigatedAcreage'] = dfinPODm['in_IrrigatedAcreage']
dfPOD['in_WaterAllocationNativeURL'] = dfinPODm['WRReport']

print(len(dfPOD))
dfPOD.head(1)
# Out:
# 308132
#   WaDEUUID in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0     idD0       GROUND WATER         GROUND WATER           Unspecified
#
#   in_CoordinateMethodCV    in_County  in_Latitude  in_Longitude  \
# 0                    QQ  Unspecified    43.690868   -116.416209
#
#   in_PODorPOUSite in_SiteName in_SiteNativeID in_SiteTypeCV  \
# 0             POD                       POD16   Unspecified
#
#   in_AllocationNativeID in_AllocationOwner in_AllocationPriorityDate  \
# 0              63-10824    MAURICE MC CLUE         6/21/1989 0:00:00
#
#    in_AllocationFlow_CFS in_AllocationBasisCV in_AllocationLegalStatusCV  \
# 0                   0.19              License                     Active
#
#   in_BeneficialUseCategory  in_IrrigatedAcreage  \
# 0               IRRIGATION                 15.0
#
#                          in_WaterAllocationNativeURL
# 0  https://research.idwr.idaho.gov/apps/waterrigh...

# %% [markdown]
# ## POU Site Data

# %%
# extract POD elements

dfinPOUm = pd.merge(dfinPOU, dfinPOD, on='RightID', how='left')
print(len(dfinPOUm))
dfinPOUm.head(1)
# Out:
# 306039
#    OID__x WaterRight_x  BasinNumbe_x  SequenceNu_x SplitSuffi_x Status_x  \
# 0       0     33-10900            33         10900                Active
#
#         PriorityDa_x          DecreedDat  \
# 0  6/28/1934 0:00:00  10/11/2001 0:00:00
#
#                                    Owner_x    WaterUse  WaterUseCo  \
# 0  UNITED STATES OF AMERICA ACTING THROUGH  STOCKWATER           4
#
#    TotalAcres  AcreLimit           Source_x SourceQual_x TributaryO_x  \
# 0         0.0        0.0  LITTLE LOST RIVER                     SINKS
#
#   Tributar_1_x WaterDistr_x  LargePOU  RightID  PlaceOfUse  \
# 0                        33         0   222600           2
#
#                                           WRReport_x  \
# 0  https://research.idwr.idaho.gov/apps/waterrigh...
#
#                                             WRDocs_x  \
# 0  https://research.idwr.idaho.gov/apps/waterrigh...
#
#                                              WRMap_x TrustOrNon_x  \
# 0  https://maps.idwr.idaho.gov/apps/Shared/PrintM...
#
#      SHAPE_STAr    SHAPE_STLe  Latitude_x  Longitude_x WaDEUUID_x   OID__y  \
# 0  8.321867e+06  54110.179685   43.981402  -113.169818       idU0  25937.0
#
#    OBJECTID WaterRight_y  BasinNumbe_y  SequenceNu_y SplitSuffi_y  VersionNum  \
# 0   25938.0     33-10900          33.0       10900.0                      0.0
#
#   Status_y    Basis       PriorityDa_y  \
# 0   Active  Decreed  6/28/1934 0:00:00
#
#                                    Owner_y  OverallMax           Source_y  \
# 0  UNITED STATES OF AMERICA ACTING THROUGH        0.02  LITTLE LOST RIVER
#
#   SourceQual_y TributaryO_y Tributar_1_y WaterDistr_y DiversionN DataSource  \
# 0                     SINKS                        33                   QQQ
#
#   MetalTagNu DiversionT  PointOfDiv  \
# 0                     E    234195.0
#
#                                           WRReport_y  \
# 0  https://research.idwr.idaho.gov/apps/waterrigh...
#
#                                             WRDocs_y  \
# 0  https://research.idwr.idaho.gov/apps/Shared/Lf...
#
#                                              WRMap_y  SpatialDat TrustOrNon_y  \
# 0  https://maps.idwr.idaho.gov/apps/Shared/PrintM...    217355.0
#
#    Latitude_y  Longitude_y WaDEUUID_y
# 0   43.935198  -113.165924   idD25937

# %%
# IrrigatedAcreage

def assignIrrigatedAcreage(AcreLimit, TotalAcres):
    AcreLimit = float(AcreLimit)
    TotalAcres = float(TotalAcres)
    if AcreLimit > 0:
        outVal = AcreLimit
    else:
        outVal = TotalAcres
    return outVal

dfinPOUm['in_IrrigatedAcreage'] = dfinPOUm.apply(lambda row: assignIrrigatedAcreage(row['AcreLimit'], row['TotalAcres']), axis=1)
dfinPOUm['in_IrrigatedAcreage'].unique()
# Out:
# array([0.000e+00, 1.600e+02, 7.200e+01, ..., 8.100e-02, 2.210e+00,
#        1.202e+02])

# %%
# create output POD dataframe

dfPOU = pd.DataFrame()

# Data Assessment UUID
dfPOU['WaDEUUID'] = dfinPOUm['WaDEUUID_x']

# Water Source
dfPOU['in_WaterSourceName'] = dfinPOUm['Source_x'].str.strip()
dfPOU['in_WaterSourceTypeCV'] = dfinPOUm['Source_x'].str.strip()

# Site
dfPOU['in_CoordinateAccuracy'] = "Unspecified"
dfPOU['in_CoordinateMethodCV'] = "Centroid"
dfPOU['in_County'] = "Unspecified"
dfPOU['in_Latitude'] = dfinPOUm['Latitude_x']
dfPOU['in_Longitude'] = dfinPOUm['Longitude_x']
dfPOU['in_PODorPOUSite'] = "POU"
dfPOU['in_SiteName'] = "Unspecified"
dfPOU['in_SiteTypeCV'] = "Unspecified"
dfPOU['in_SiteNativeID'] = "POU" + dfinPOUm['PlaceOfUse'].astype(str).str.strip()

# Allocation Fact
dfPOU['in_AllocationNativeID'] = dfinPOUm['WaterRight_x']
dfPOU['in_AllocationOwner'] = dfinPOUm['Owner_x']
dfPOU['in_AllocationPriorityDate'] = dfinPOUm['PriorityDa_x']
dfPOU['in_AllocationFlow_CFS'] = dfinPOUm['OverallMax']
dfPOU['in_AllocationBasisCV'] = dfinPOUm['Basis'].str.strip()
dfPOU['in_AllocationLegalStatusCV'] = dfinPOUm['Status_x'].str.title()
dfPOU['in_BeneficialUseCategory'] = dfinPOUm['WaterUse'].str.strip()
dfPOU['in_IrrigatedAcreage'] = dfinPOUm['in_IrrigatedAcreage']
dfPOU['in_WaterAllocationNativeURL'] = dfinPOUm['WRReport_y']

print(len(dfPOU))
dfPOU.head(1)
# Out:
# 306039
#   WaDEUUID in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0     idU0  LITTLE LOST RIVER    LITTLE LOST RIVER           Unspecified
#
#   in_CoordinateMethodCV    in_County  in_Latitude  in_Longitude  \
# 0              Centroid  Unspecified    43.981402   -113.169818
#
#   in_PODorPOUSite  in_SiteName in_SiteTypeCV in_SiteNativeID  \
# 0             POU  Unspecified   Unspecified            POU2
#
#   in_AllocationNativeID                       in_AllocationOwner  \
# 0              33-10900  UNITED STATES OF AMERICA ACTING THROUGH
#
#   in_AllocationPriorityDate  in_AllocationFlow_CFS in_AllocationBasisCV  \
# 0         6/28/1934 0:00:00                   0.02              Decreed
#
#   in_AllocationLegalStatusCV in_BeneficialUseCategory  in_IrrigatedAcreage  \
# 0                     Active               STOCKWATER                  0.0
#
#                          in_WaterAllocationNativeURL
# 0  https://research.idwr.idaho.gov/apps/waterrigh...

# %% [markdown]
# ## Concatenate and Clean Data

# %%
# Concatenate dataframes
frames = [dfPOD, dfPOU]
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates()
print(len(outdf))
# Out:
# 520694

# %%
# clean up AllocationNativeID

def cleanAllocationNativeID(Val):
    Val = str(Val).strip()
    return Val

outdf['in_AllocationNativeID'] = outdf.apply(lambda row: cleanAllocationNativeID(row['in_AllocationNativeID']), axis=1)
outdf['in_AllocationNativeID'].unique()
# Out:
# array(['63-10824', '67-7744', '63-11206', ..., '95-17846', '96-9864',
#        '11-7926'], dtype=object)

# %%
# remove special characters AllocationOwner

import re

def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,'/\)(-]", "", Val).strip()
    return Val

outdf['in_AllocationOwner'] = outdf.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['MAURICE MC CLUE', 'UNITED STATES OF AMERICA ACTING THROUGH',
#        'JAMES P MERTZ', ..., 'SCOTT RUDOLPH', 'EMILY R PALMER',
#        'BRANDON BAUMAN'], dtype=object)

# %%
# WaterSourceType

WaterSourceTypeDict = {
"River" : "Surface Water",
"Ground Water" : "Groundwater",
"Spring" :  "Groundwater",
"Lake" :  "Surface Water",
"Pond" :  "Surface Water", 
"Canal" :  "Surface Water",
"Creek" : "Surface Water",
"Fork" : "Surface Water",
"Waste Water" : "Reuse",
"Drain" : "Surface Water",
"Gluch" : "Surface Water",
"Reservoir" : "Surface Water",
"Slough" : "Surface Water",
"Ditch" : "Surface Water",
"Channel" : "Surface Water",
"Dry" : "Surface Water"}

def assignWaterSourceType(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = 'Unspecified'
    elif colrowValue == "GROUND WATER":
        outList = "Groundwater"
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        String1 = String1.title()  # change to title format
        list_of_words = String1.split()
        for i in list_of_words:
            if i in WaterSourceTypeDict.keys():
                outList = WaterSourceTypeDict[i]
            else:
                outList = 'Unspecified'
    return outList

outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: assignWaterSourceType(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater', 'Surface Water', 'Unspecified'], dtype=object)

# %%
# Update datatype of Priority Date to fit WaDE 2.0 structure

def formatDateString(inString1):
    inString = str(inString1).strip()
    try:
        if inString == "" or pd.isnull(inString):
            valndf = ""
        else:
            valD = pd.to_datetime(inString)
            valnDd = valD.date()
            valndf = valnDd.strftime('%m/%d/%Y')
    except:
        valndf = ""
    return valndf

outdf['in_AllocationPriorityDate'] = outdf.apply(lambda row: formatDateString(row['in_AllocationPriorityDate']), axis=1)
outdf['in_AllocationPriorityDate'].unique()
# Out:
# array(['06/21/1989', '05/27/1992', '02/28/1990', ..., '10/03/2016',
#        '07/11/2019', '05/18/2021'], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDEID_WS" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceName'] == A) & 
                                       (dfWaterSourceNativeID['in_WaterSourceTypeCV'] == B), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['WaDEID_WS1', 'WaDEID_WS2', 'WaDEID_WS3', ..., 'WaDEID_WS6781',
#        'WaDEID_WS6782', 'WaDEID_WS6783'], dtype=object)

# %% [markdown]
# ## Shapefile Data
# - For attaching gemetry to csv inputs.

# %%
# Shapefile input
dfPoUshapetemp = gpd.read_file('shapefile/WaterRightPOUs/WaterRightPOUs.shp')
print(len(dfPoUshapetemp))
dfPoUshapetemp.head(1)
# Out:
# 212562
#   WaterRight  BasinNumbe  SequenceNu SplitSuffi  Status  PriorityDa  \
# 0   33-10900          33       10900       None  Active  1934-06-28
#
#    DecreedDat                                    Owner    WaterUse WaterUseCo  \
# 0  2001-10-11  UNITED STATES OF AMERICA ACTING THROUGH  STOCKWATER         04
#
#    TotalAcres  AcreLimit             Source SourceQual TributaryO Tributar_1  \
# 0         0.0        0.0  LITTLE LOST RIVER       None      SINKS       None
#
#   WaterDistr  LargePOU  RightID  PlaceOfUse  \
# 0         33         0   222600           2
#
#                                             WRReport  \
# 0  https://research.idwr.idaho.gov/apps/waterrigh...
#
#                                               WRDocs  \
# 0  https://research.idwr.idaho.gov/apps/waterrigh...
#
#                                                WRMap TrustOrNon    SHAPE_STAr  \
# 0  https://maps.idwr.idaho.gov/apps/Shared/PrintM...       None  8.321867e+06
#
#      SHAPE_STLe   Latitude   Longitude  \
# 0  54110.179685  43.981402 -113.169818
#
#                                             geometry
# 0  MULTIPOLYGON (((2572371.560 1409769.100, 25727...

# %%
dfPoUshapetemp.plot()
# Out:
# <AxesSubplot:>

# %%
columnsList = ['in_SiteNativeID', 'geometry']
dfPoUshape = pd.DataFrame(columns=columnsList)
dfPoUshape['in_SiteNativeID'] = "POU" + dfPoUshapetemp['PlaceOfUse'].astype(str).str.strip()
dfPoUshape['geometry'] = dfPoUshapetemp['geometry']
dfPoUshape = dfPoUshape.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
dfPoUshape.head(3)
# Out:
#   in_SiteNativeID                                           geometry
# 0            POU2  MULTIPOLYGON (((2572371.560 1409769.100, 25727...
# 1            POU7  POLYGON ((2264773.050 1372926.480, 2264762.080...
# 2            POU9  POLYGON ((2324403.000 1378048.380, 2324372.460...

# %% [markdown]
# ## Review and Export

# %%
outdf.dtypes
# Out:
# WaDEUUID                        object
# in_WaterSourceName              object
# in_WaterSourceTypeCV            object
# in_CoordinateAccuracy           object
# in_CoordinateMethodCV           object
# in_County                       object
# in_Latitude                    float64
# in_Longitude                   float64
# in_PODorPOUSite                 object
# in_SiteName                     object
# in_SiteNativeID                 object
# in_SiteTypeCV                   object
# in_AllocationNativeID           object
# in_AllocationOwner              object
# in_AllocationPriorityDate       object
# in_AllocationFlow_CFS          float64
# in_AllocationBasisCV            object
# in_AllocationLegalStatusCV      object
# in_BeneficialUseCategory        object
# in_IrrigatedAcreage            float64
# in_WaterAllocationNativeURL     object
# in_WaterSourceNativeID          object
# dtype: object

# %%
#Exporting to Finished File
outdf.to_csv('P_IdahoMaster.csv', index=False)  # The output
dfPoUshape.to_csv('P_idGeometry.csv', index=False) # The output geometry.

# %%
# plot check sites.csv file
fileInput = "G:/Shared drives/WaDE Data/Idaho/WaterAllocation/ProcessedInputData/sites.csv"
df = pd.read_csv(fileInput)

import geoplot as gplt
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude), crs="EPSG:4326")
gplt.pointplot(gdf)
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_11880\3573840994.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fileInput)
# <AxesSubplot:>

# %%
# plot check sites.csv file
fileInput = "G:/Shared drives/WaDE Data/Idaho/WaterAllocation/ProcessedInputData/sites.csv"
df = pd.read_csv(fileInput)
df = df[df['PODorPOUSite'] =='POU']

gs = gpd.GeoSeries.from_wkt(df['Geometry'])
gdf = gpd.GeoDataFrame(df, geometry=gs, crs="EPSG:4326")
gdf.plot()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_11880\3902184442.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fileInput)
#             SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 258070  IDwr_S258071                     NaN         IDwr_WS7
# 258071  IDwr_S258072                     NaN         IDwr_WS4
# 258072  IDwr_S258073                     NaN         IDwr_WS2
# 258073  IDwr_S258074                     NaN         IDwr_WS1
# 258074  IDwr_S258075                     NaN        IDwr_WS31
#
#        CoordinateAccuracy CoordinateMethodCV  County  EPSGCodeCV  \
# 258070        Unspecified           Centroid     NaN        4326
# 258071        Unspecified           Centroid     NaN        4326
# 258072        Unspecified           Centroid     NaN        4326
# 258073        Unspecified           Centroid     NaN        4326
# 258074        Unspecified           Centroid     NaN        4326
#
#                                                  Geometry  GNISCodeCV  HUC12  \
# 258070  POLYGON ((2626218.390099829 1330447.9901001318...         NaN    NaN
# 258071  POLYGON ((2280027.7300998596 1522685.660100106...         NaN    NaN
# 258072  POLYGON ((2521616.8800998433 1512605.670100120...         NaN    NaN
# 258073  POLYGON ((2262669.7900998574 1455295.830100106...         NaN    NaN
# 258074  POLYGON ((2671190.5000998336 1470225.380100131...         NaN    NaN
#
#         HUC8   Latitude   Longitude  NHDNetworkStatusCV  NHDProductCV  \
# 258070   NaN  43.164401 -112.449867                 NaN           NaN
# 258071   NaN  44.869834 -116.792433                 NaN           NaN
# 258072   NaN  44.816327 -113.724083                 NaN           NaN
# 258073   NaN  44.258414 -116.970645                 NaN           NaN
# 258074   NaN  44.411254 -111.847309                 NaN           NaN
#
#        PODorPOUSite     SiteName SiteNativeID  SitePoint   SiteTypeCV StateCV  \
# 258070          POU  Unspecified     POU10000        NaN  Unspecified      ID
# 258071          POU  Unspecified    POU100000        NaN  Unspecified      ID
# 258072          POU  Unspecified    POU100002        NaN  Unspecified      ID
# 258073          POU  Unspecified    POU100005        NaN  Unspecified      ID
# 258074          POU  Unspecified    POU100006        NaN  Unspecified      ID
#
#         USGSSiteID
# 258070         NaN
# 258071         NaN
# 258072         NaN
# 258073         NaN
# 258074         NaN
