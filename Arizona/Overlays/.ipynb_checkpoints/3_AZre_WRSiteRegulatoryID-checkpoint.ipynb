# %% [markdown]
# # Assign OverlayUUIDs Values to Water Right sites.csv
# Purpose:  To assign OverlayUUIDs values to state water right sites.csv File.
#
# Notes:
# - requires the completed pre-processed sites.csv & watersource.csv files from the state "WaterAllocation/ProcessedInputData" folder to be copied over to the "Regulatory/ProcessedInputData" folder.  Rename to wr_sites.csv & wr_watersource.csv to preserve inputs.
# - requires awareness of unique WaterSourceTypeCV of each water right site match up to corresponding WaterSourceTypeCV of Overlays per reportingunits

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library
import geoplot as gplt # for plotting maps
import geoplot.crs as gcrs #used to pull in webdata

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Arizona/Regulatory" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Arizona/Regulatory

# %% [markdown]
# ## Input Data

# %%
# Regulatory Input Data
dfov = pd.read_csv("ProcessedInputData/overlays.csv")
dfru = pd.read_csv("ProcessedInputData/reportingunits.csv")
dfrru = pd.read_csv("ProcessedInputData/overlayreportingunits.csv")

# Water right Input Data
dfws = pd.read_csv('ProcessedInputData/wr_watersources.csv')
dfs = pd.read_csv('ProcessedInputData/wr_sites.csv')

# %%
#### regulatory watersource info with reporting unit info

# merge Overlays -to- regulatoryreportingunits -to- reportingunits
dfov = pd.merge(dfov[['OverlayUUID ', 'WaterSourceTypeCV']], dfrru[['OverlayUUID ', 'ReportingUnitUUID']], left_on='OverlayUUID ', right_on='OverlayUUID ', how='left')
dfru = pd.merge(dfru, dfov, left_on='ReportingUnitUUID', right_on='ReportingUnitUUID', how='left')

print(dfru['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfru))
dfru.head(1)
# Out:
# ['Groundwater']
# 8
#   ReportingUnitUUID  EPSGCodeCV ReportingUnitName ReportingUnitNativeID  \
# 0        AZre_RUaz1        4326    SANTA CRUZ AMA                   az1
#
#    ReportingUnitProductVersion     ReportingUnitTypeCV  \
# 0                          NaN  Active Management Area
#
#   ReportingUnitUpdateDate StateCV  \
# 0               1/10/2023      AZ
#
#                                             Geometry OverlayUUID  \
# 0  POLYGON ((-111.19920647185997 31.8582010611542...              AZre_RO1
#
#   WaterSourceTypeCV
# 0       Groundwater

# %%
#### water right watersource info with site info

# explode site.csv on WaterSourceUUIDs
dfs = dfs.assign(WaterSourceUUIDs=dfs['WaterSourceUUIDs'].str.split(',')).explode('WaterSourceUUIDs').reset_index()

# merge watersources to dfs via WaterSourceUUIDs -to -WaterSourceUUID
dfs = pd.merge(dfs, dfws[['WaterSourceUUID', 'WaterSourceTypeCV']], left_on='WaterSourceUUIDs', right_on='WaterSourceUUID', how='left')
print(dfs['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfs))
dfs.head(1)
# Out:
# ['Groundwater' 'Surface Water']
# 203215
#    index               SiteUUID  OverlayUUIDs WaterSourceUUIDs  \
# 0      0  AZwr_SPODA01001001BAB                     NaN   AZwr_WSwadeID1
#
#   CoordinateAccuracy CoordinateMethodCV    County  EPSGCodeCV  Geometry  \
# 0   WaDE Unspecified   WaDE Unspecified  Maricopa        4326       NaN
#
#    GNISCodeCV  HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  \
# 0         NaN    NaN   NaN  33.46482 -112.21531                 NaN
#
#    NHDProductCV PODorPOUSite          SiteName     SiteNativeID  SitePoint  \
# 0           NaN          POD  WaDE Unspecified  PODA01001001BAB        NaN
#
#   SiteTypeCV StateCV  USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0       Well      AZ         NaN  AZwr_WSwadeID1       Groundwater

# %% [markdown]
# ## Extract RegulatoryOverlay from Reporting Units and assing to WR Sites
# - repeat scripts based on the number of ReportingUnitTypeCV types.
# - merge all geo-dataframes into one output

# %% [markdown]
# #### Regulatory Area Data #1

# %%
# Create copy of reportingunits dataframe
# Extract out ReportingUnitTypeCV from reportingunits dataframe
# note unique WaterSourceTypeCV

dfru1 = dfru.copy()
nameOfReportingUnitTypeVar = "Active Management Area" # change here for ReportingUnitTypeCV of interest
dfru1 = dfru1[dfru1['ReportingUnitTypeCV'] == nameOfReportingUnitTypeVar]
print(len(dfru1))
print(dfru1['WaterSourceTypeCV'].unique())
dfru1.head(1)
# Out:
# 8
# ['Groundwater']
#   ReportingUnitUUID  EPSGCodeCV ReportingUnitName ReportingUnitNativeID  \
# 0        AZre_RUaz1        4326    SANTA CRUZ AMA                   az1
#
#    ReportingUnitProductVersion     ReportingUnitTypeCV  \
# 0                          NaN  Active Management Area
#
#   ReportingUnitUpdateDate StateCV  \
# 0               1/10/2023      AZ
#
#                                             Geometry OverlayUUID  \
# 0  POLYGON ((-111.19920647185997 31.8582010611542...              AZre_RO1
#
#   WaterSourceTypeCV
# 0       Groundwater

# %%
# Convert dataframe -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

dfru1 = dfru1[dfru1['Geometry'] != ""].reset_index(drop=True)
dfru1['Geometry'] = gpd.GeoSeries.from_wkt(dfru1['Geometry'], crs="EPSG:4326")
gdfru1 = gpd.GeoDataFrame(dfru1, geometry=dfru1['Geometry'], crs="EPSG:4326") # covert to geodataframe
gplt.polyplot(gdfru1, ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
## WARNING: for AZ, we only want 'Groundwater' water right records

# %%
# Create copy of water right sites dataframe
# Extract out WaterSourceTypeCV and match to that of above reportingunits dataframe

dfs1 = dfs.copy()
nameOfWaterSourceTypeCV= "Groundwater" # change here for WaterSourceTypeCV of interest
dfs1 = dfs1[dfs1['WaterSourceTypeCV'] == nameOfWaterSourceTypeCV]
print(len(dfs1))
print(dfs1['WaterSourceTypeCV'].unique())
dfs1.head(1)
# Out:
# 123976
# ['Groundwater']
#    index               SiteUUID  OverlayUUIDs WaterSourceUUIDs  \
# 0      0  AZwr_SPODA01001001BAB                     NaN   AZwr_WSwadeID1
#
#   CoordinateAccuracy CoordinateMethodCV    County  EPSGCodeCV  Geometry  \
# 0   WaDE Unspecified   WaDE Unspecified  Maricopa        4326       NaN
#
#    GNISCodeCV  HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  \
# 0         NaN    NaN   NaN  33.46482 -112.21531                 NaN
#
#    NHDProductCV PODorPOUSite          SiteName     SiteNativeID  SitePoint  \
# 0           NaN          POD  WaDE Unspecified  PODA01001001BAB        NaN
#
#   SiteTypeCV StateCV  USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0       Well      AZ         NaN  AZwr_WSwadeID1       Groundwater

# %%
# Convert extracted water right sites -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gdfs1 = gpd.GeoDataFrame(dfs1, geometry=gpd.points_from_xy(dfs1.Longitude.astype(float), dfs1.Latitude.astype(float)), crs="EPSG:4326")
gplt.pointplot(gdfs1, hue='PODorPOUSite', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Select sites within polygon.
gdfs1_ru1 = gpd.sjoin(left_df=gdfs1, right_df=gdfru1[['ReportingUnitUUID', 'OverlayUUID ', 'geometry']], op='within').replace(np.nan, "")
print(len(gdfs1_ru1))
gdfs1_ru1.head()
# Out:
# C:\Users\rjame\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3377: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
# 50524
#    index               SiteUUID OverlayUUIDs WaterSourceUUIDs  \
# 0      0  AZwr_SPODA01001001BAB                          AZwr_WSwadeID1
# 1      1  AZwr_SPODA01001001BCB                          AZwr_WSwadeID1
# 2      2  AZwr_SPODA01001001BDC                          AZwr_WSwadeID1
# 3      3  AZwr_SPODA01001001CAA                          AZwr_WSwadeID1
# 4      4  AZwr_SPODA01001001CBB                          AZwr_WSwadeID1
#
#   CoordinateAccuracy CoordinateMethodCV    County  EPSGCodeCV Geometry  \
# 0   WaDE Unspecified   WaDE Unspecified  Maricopa        4326
# 1   WaDE Unspecified   WaDE Unspecified  Maricopa        4326
# 2   WaDE Unspecified   WaDE Unspecified  Maricopa        4326
# 3   WaDE Unspecified   WaDE Unspecified  Maricopa        4326
# 4   WaDE Unspecified   WaDE Unspecified  Maricopa        4326
#
#   GNISCodeCV HUC12 HUC8  Latitude  Longitude NHDNetworkStatusCV NHDProductCV  \
# 0                        33.46482 -112.21531
# 1                        33.46127 -112.21972
# 2                        33.45954 -112.21538
# 3                        33.45778 -112.21323
# 4                        33.45778 -112.21978
#
#   PODorPOUSite          SiteName     SiteNativeID SitePoint SiteTypeCV  \
# 0          POD  WaDE Unspecified  PODA01001001BAB                 Well
# 1          POD  WaDE Unspecified  PODA01001001BCB                 Well
# 2          POD  WaDE Unspecified  PODA01001001BDC                 Well
# 3          POD  WaDE Unspecified  PODA01001001CAA                 Well
# 4          POD  WaDE Unspecified  PODA01001001CBB                 Well
#
#   StateCV USGSSiteID WaterSourceUUID WaterSourceTypeCV  \
# 0      AZ             AZwr_WSwadeID1       Groundwater
# 1      AZ             AZwr_WSwadeID1       Groundwater
# 2      AZ             AZwr_WSwadeID1       Groundwater
# 3      AZ             AZwr_WSwadeID1       Groundwater
# 4      AZ             AZwr_WSwadeID1       Groundwater
#
#                       geometry  index_right ReportingUnitUUID  \
# 0  POINT (-112.21531 33.46482)            4        AZre_RUaz5
# 1  POINT (-112.21972 33.46127)            4        AZre_RUaz5
# 2  POINT (-112.21538 33.45954)            4        AZre_RUaz5
# 3  POINT (-112.21323 33.45778)            4        AZre_RUaz5
# 4  POINT (-112.21978 33.45778)            4        AZre_RUaz5
#
#   OverlayUUID
# 0              AZre_RO5
# 1              AZre_RO5
# 2              AZre_RO5
# 3              AZre_RO5
# 4              AZre_RO5

# %%
# plot the selected points
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gplt.pointplot(gdfs1_ru1, hue='PODorPOUSite', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# set OverlayUUIDs
gdfs1_ru1['OverlayUUIDs'] = gdfs1_ru1['OverlayUUID ']
gdfs1_ru1 = gdfs1_ru1.drop(['index', 'OverlayUUID ', 'geometry', 'index_right', 'ReportingUnitUUID', 'WaterSourceUUID', 'WaterSourceTypeCV'], axis=1)
gdfs1_ru1.head(1)
# Out:
#    index               SiteUUID OverlayUUIDs WaterSourceUUIDs  \
# 0      0  AZwr_SPODA01001001BAB               AZre_RO5   AZwr_WSwadeID1
#
#   CoordinateAccuracy CoordinateMethodCV    County  EPSGCodeCV Geometry  \
# 0   WaDE Unspecified   WaDE Unspecified  Maricopa        4326
#
#   GNISCodeCV HUC12 HUC8  Latitude  Longitude NHDNetworkStatusCV NHDProductCV  \
# 0                        33.46482 -112.21531
#
#   PODorPOUSite          SiteName     SiteNativeID SitePoint SiteTypeCV  \
# 0          POD  WaDE Unspecified  PODA01001001BAB                 Well
#
#   StateCV USGSSiteID
# 0      AZ

# %% [markdown]
# #### Regulatory Area Data #2

# %%
# dfru2 = dfru.copy()
# etc etc

# %% [markdown]
# ## Concatenate all Regulatory Area Data Types together
# - drop geometry from the wade wr sites.csv geodataframe

# %%
# Concatenate dataframes into single output
frames = [dfs, gdfs1_ru1] # list all out dataframes here
outdfs = pd.concat(frames)
outdfs = outdfs.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
outdfs = outdfs.groupby('SiteUUID').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem!=''])).replace(np.nan, "").reset_index()
print(len(outdfs))
# Out:
# 192208

# %% [markdown]
# # Inspect Output Data & Export

# %%
outdfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192208 entries, 0 to 192207
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   SiteUUID                192208 non-null  object
#  1   index                   192208 non-null  object
#  2   OverlayUUIDs  192208 non-null  object
#  3   WaterSourceUUIDs        192208 non-null  object
#  4   CoordinateAccuracy      192208 non-null  object
#  5   CoordinateMethodCV      192208 non-null  object
#  6   County                  192208 non-null  object
#  7   EPSGCodeCV              192208 non-null  object
#  8   Geometry                192208 non-null  object
#  9   GNISCodeCV              192208 non-null  object
#  10  HUC12                   192208 non-null  object
#  11  HUC8                    192208 non-null  object
#  12  Latitude                192208 non-null  object
#  13  Longitude               192208 non-null  object
#  14  NHDNetworkStatusCV      192208 non-null  object
#  15  NHDProductCV            192208 non-null  object
#  16  PODorPOUSite            192208 non-null  object
#  17  SiteName                192208 non-null  object
#  18  SiteNativeID            192208 non-null  object
#  19  SitePoint               192208 non-null  object
#  20  SiteTypeCV              192208 non-null  object
#  21  StateCV                 192208 non-null  object
#  22  USGSSiteID              192208 non-null  object
#  23  WaterSourceUUID         192208 non-null  object
#  24  WaterSourceTypeCV       192208 non-null  object
# dtypes: object(25)
# memory usage: 36.7+ MB

# %%
outdfs
# Out:
#                      SiteUUID   index OverlayUUIDs  \
# 0       AZwr_SPODA01001001BAB       0               AZre_RO5
# 1       AZwr_SPODA01001001BCB       1               AZre_RO5
# 2       AZwr_SPODA01001001BDC       2               AZre_RO5
# 3       AZwr_SPODA01001001CAA       3               AZre_RO5
# 4       AZwr_SPODA01001001CBB       4               AZre_RO5
# ...                       ...     ...                    ...
# 192203  AZwr_SPOUD24032004CB0  192203
# 192204  AZwr_SPOUD24032004CC0  192204
# 192205  AZwr_SPOUD24032017AB0  192205
# 192206  AZwr_SPOUD24032018CC0  192206
# 192207  AZwr_SPOUD24032018CD0  192207
#
#          WaterSourceUUIDs CoordinateAccuracy CoordinateMethodCV    County  \
# 0          AZwr_WSwadeID1   WaDE Unspecified   WaDE Unspecified  Maricopa
# 1          AZwr_WSwadeID1   WaDE Unspecified   WaDE Unspecified  Maricopa
# 2          AZwr_WSwadeID1   WaDE Unspecified   WaDE Unspecified  Maricopa
# 3          AZwr_WSwadeID1   WaDE Unspecified   WaDE Unspecified  Maricopa
# 4          AZwr_WSwadeID1   WaDE Unspecified   WaDE Unspecified  Maricopa
# ...                   ...                ...                ...       ...
# 192203  AZwr_WSwadeID4096   WaDE Unspecified   WaDE Unspecified   Cochise
# 192204  AZwr_WSwadeID6486   WaDE Unspecified   WaDE Unspecified   Cochise
# 192205  AZwr_WSwadeID5777   WaDE Unspecified   WaDE Unspecified   Cochise
# 192206  AZwr_WSwadeID2449   WaDE Unspecified   WaDE Unspecified   Cochise
# 192207  AZwr_WSwadeID2449   WaDE Unspecified   WaDE Unspecified   Cochise
#
#        EPSGCodeCV Geometry GNISCodeCV HUC12 HUC8            Latitude  \
# 0            4326                                 33.464821819000065
# 1            4326                                 33.461270187000025
# 2            4326                                  33.45953603900006
# 3            4326                                  33.45778043200005
# 4            4326                                  33.45777930400004
# ...           ...      ...        ...   ...  ...                 ...
# 192203       4326                                 31.369468383305765
# 192204       4326                                 31.365875882556868
# 192205       4326                                 31.347644755495377
# 192206       4326                                  31.33685005484909
# 192207       4326                                  31.33685185425968
#
#                   Longitude NHDNetworkStatusCV NHDProductCV PODorPOUSite  \
# 0       -112.21531226699994                                          POD
# 1       -112.21971850299995                                          POD
# 2       -112.21538376199996                                          POD
# 3       -112.21322774999996                                          POD
# 4       -112.21977613599996                                          POD
# ...                     ...                ...          ...          ...
# 192203  -109.09674528535508                                          POU
# 192204  -109.09673623722612                                          POU
# 192205  -109.10505480722252                                          POU
# 192206  -109.13030329208902                                          POU
# 192207   -109.1260975185986                                          POU
#
#                 SiteName     SiteNativeID SitePoint        SiteTypeCV StateCV  \
# 0       WaDE Unspecified  PODA01001001BAB                        Well      AZ
# 1       WaDE Unspecified  PODA01001001BCB                        Well      AZ
# 2       WaDE Unspecified  PODA01001001BDC                        Well      AZ
# 3       WaDE Unspecified  PODA01001001CAA                        Well      AZ
# 4       WaDE Unspecified  PODA01001001CBB                        Well      AZ
# ...                  ...              ...       ...               ...     ...
# 192203  WaDE Unspecified  POUD24032004CB0            WaDE Unspecified      AZ
# 192204  WaDE Unspecified  POUD24032004CC0            WaDE Unspecified      AZ
# 192205  WaDE Unspecified  POUD24032017AB0            WaDE Unspecified      AZ
# 192206  WaDE Unspecified  POUD24032018CC0            WaDE Unspecified      AZ
# 192207  WaDE Unspecified  POUD24032018CD0            WaDE Unspecified      AZ
#
#        USGSSiteID    WaterSourceUUID WaterSourceTypeCV
# 0                     AZwr_WSwadeID1       Groundwater
# 1                     AZwr_WSwadeID1       Groundwater
# 2                     AZwr_WSwadeID1       Groundwater
# 3                     AZwr_WSwadeID1       Groundwater
# 4                     AZwr_WSwadeID1       Groundwater
# ...           ...                ...               ...
# 192203             AZwr_WSwadeID4096     Surface Water
# 192204             AZwr_WSwadeID6486     Surface Water
# 192205             AZwr_WSwadeID5777     Surface Water
# 192206             AZwr_WSwadeID2449     Surface Water
# 192207             AZwr_WSwadeID2449     Surface Water
#
# [192208 rows x 25 columns]

# %%
# Export out to CSV.
outdfs.to_csv('ProcessedInputData/sites.csv', index=False) # this is in the Regulatory data folder
