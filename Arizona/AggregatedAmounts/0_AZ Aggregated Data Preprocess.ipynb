# %% [markdown]
# # Working with AZ Aggregated Data
#
# Pre-processing input data for a smoother upload experience of the state data to the WaDE 2.0 database.
# Using geopandas to read in shp file, and coverting to WKT for ReportingUnit geometry.

# %%
#Needed Libararies
import os
import numpy as np
import pandas as pd
from datetime import datetime
import geopandas as gpd # the library that lets us read in shapefiles
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Arizona/AggregatedAmounts"
os.chdir(workingDir)

#CSV input file
fileInput = "RawInputData/rawSafeYield.csv"
df = pd.read_csv(fileInput)

#Shapefile input
AZ_AMA = gpd.read_file('C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Arizona/AggregatedAmounts/RawInputData/AMA_and_INA-shp/AMA_and_INA.shp')
dfshape = pd.DataFrame(AZ_AMA)

# %%
#check csv input
df
# Out:
#      Basin Code Inflow/Outflow  \
# 0           PHX         Inflow
# 1           PHX         Inflow
# 2           PHX         Inflow
# 3           PHX         Inflow
# 4           PHX         Inflow
# ...         ...            ...
# 2571        TUC        Outflow
# 2572        TUC        Outflow
# 2573        TUC        Outflow
# 2574        TUC        Outflow
# 2575        TUC        Outflow
#
#                                                  Sector  Year     Quantity  \
# 0     Agricultural                                  ...  1985  585460.7374
# 1     Agricultural                                  ...  1986  577371.6134
# 2     Agricultural                                  ...  1987  569202.1827
# 3     Agricultural                                  ...  1988  522300.0849
# 4     Agricultural                                  ...  1989  514523.2052
# ...                                                 ...   ...          ...
# 2571                                            Natural  2015    5330.0000
# 2572                                            Natural  2016   23650.0000
# 2573                                            Natural  2016    4400.0000
# 2574                                            Natural  2017          NaN
# 2575                                            Natural  2017          NaN
#
#                                              Water Type            Component
# 0     Groundwater                                   ...  Incidental Recharge
# 1     Groundwater                                   ...  Incidental Recharge
# 2     Groundwater                                   ...  Incidental Recharge
# 3     Groundwater                                   ...  Incidental Recharge
# 4     Groundwater                                   ...  Incidental Recharge
# ...                                                 ...                  ...
# 2571  Groundwater                                   ...      Riparian Demand
# 2572  Groundwater                                   ...  Groundwater Outflow
# 2573  Groundwater                                   ...      Riparian Demand
# 2574  Groundwater                                   ...  Groundwater Outflow
# 2575  Groundwater                                   ...      Riparian Demand
#
# [2576 rows x 7 columns]

# %%
#check shp input
dfshape
# Out:
#    OBJECTID       BASIN_NAME NAME_ABBR        BASIN_NA_1     Shape_Leng  \
# 0         1   SANTA CRUZ AMA       SCA    SANTA CRUZ AMA  227784.354771
# 1         2     PRESCOTT AMA       PRE      PRESCOTT AMA  194403.011308
# 2         3   HARQUAHALA INA       HAR  HARQUAHALA BASIN  239098.916340
# 3         4  JOSEPH CITY INA       JCI              None   96874.388475
# 4         5      PHOENIX AMA       PHX       PHOENIX AMA  844515.038021
# 5         6       TUCSON AMA       TUC        TUCSON AMA  620924.455520
# 6         7      DOUGLAS INA       DIN              None  198604.224004
# 7         8        PINAL AMA       PIN         PINAL AMA  668757.778618
#
#      Shape_Area                                           geometry
# 0  1.853991e+09  POLYGON ((481155.981 3524735.269, 481185.919 3...
# 1  1.244308e+09  POLYGON ((357041.632 3843374.192, 357053.632 3...
# 2  1.983267e+09  POLYGON ((287010.098 3746236.654, 287022.598 3...
# 3  4.679288e+08  POLYGON ((566517.367 3872842.551, 566546.615 3...
# 4  1.395001e+10  POLYGON ((401515.842 3762674.078, 401552.531 3...
# 5  1.001952e+10  POLYGON ((506728.980 3630477.361, 506694.731 3...
# 6  1.436741e+09  POLYGON ((643213.248 3467601.452, 642645.622 3...
# 7  1.060738e+10  POLYGON ((480036.328 3671581.352, 479984.327 3...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.dtypes)
# Out:
# Basin Code         object
# Inflow/Outflow     object
# Sector             object
# Year                int64
# Quantity          float64
# Water Type         object
# Component          object
# dtype: object

# %%
#Removing NaN, and missing (999) values from Quantit
df['Quantity'] = df['Quantity'].fillna(0)
df['Quantity'] = df['Quantity'].replace(999, 0)
df
# Out:
#      Basin Code Inflow/Outflow  \
# 0           PHX         Inflow
# 1           PHX         Inflow
# 2           PHX         Inflow
# 3           PHX         Inflow
# 4           PHX         Inflow
# ...         ...            ...
# 2571        TUC        Outflow
# 2572        TUC        Outflow
# 2573        TUC        Outflow
# 2574        TUC        Outflow
# 2575        TUC        Outflow
#
#                                                  Sector  Year     Quantity  \
# 0     Agricultural                                  ...  1985  585460.7374
# 1     Agricultural                                  ...  1986  577371.6134
# 2     Agricultural                                  ...  1987  569202.1827
# 3     Agricultural                                  ...  1988  522300.0849
# 4     Agricultural                                  ...  1989  514523.2052
# ...                                                 ...   ...          ...
# 2571                                            Natural  2015    5330.0000
# 2572                                            Natural  2016   23650.0000
# 2573                                            Natural  2016    4400.0000
# 2574                                            Natural  2017       0.0000
# 2575                                            Natural  2017       0.0000
#
#                                              Water Type            Component
# 0     Groundwater                                   ...  Incidental Recharge
# 1     Groundwater                                   ...  Incidental Recharge
# 2     Groundwater                                   ...  Incidental Recharge
# 3     Groundwater                                   ...  Incidental Recharge
# 4     Groundwater                                   ...  Incidental Recharge
# ...                                                 ...                  ...
# 2571  Groundwater                                   ...      Riparian Demand
# 2572  Groundwater                                   ...  Groundwater Outflow
# 2573  Groundwater                                   ...      Riparian Demand
# 2574  Groundwater                                   ...  Groundwater Outflow
# 2575  Groundwater                                   ...      Riparian Demand
#
# [2576 rows x 7 columns]

# %%
#Creating AMA name for Watersources from Basin Code
AMANameDic = {
"SCA" : "SANTA CRUZ AMA",
"PRE" : "PRESCOTT AMA",
"HAR" : "HARQUAHALA INA",
"JCI" : "JOSEPH CITY INA",
"PHX" : "PHOENIX AMA",
"TUC" : "TUCSON AMA",
"DIN" : "DOUGLAS INA",
"PIN" : "PINAL AMA"}

def assignAMAName(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ""
    else:
        String1 = colrowValue  # remove whitespace chars
        try:
            outList = AMANameDic[String1].strip()
        except:
            outList = ""
    return outList

df['AMA Name'] = df.apply(lambda row: assignAMAName(row['Basin Code']), axis=1)
df
# Out:
#      Basin Code Inflow/Outflow  \
# 0           PHX         Inflow
# 1           PHX         Inflow
# 2           PHX         Inflow
# 3           PHX         Inflow
# 4           PHX         Inflow
# ...         ...            ...
# 2571        TUC        Outflow
# 2572        TUC        Outflow
# 2573        TUC        Outflow
# 2574        TUC        Outflow
# 2575        TUC        Outflow
#
#                                                  Sector  Year     Quantity  \
# 0     Agricultural                                  ...  1985  585460.7374
# 1     Agricultural                                  ...  1986  577371.6134
# 2     Agricultural                                  ...  1987  569202.1827
# 3     Agricultural                                  ...  1988  522300.0849
# 4     Agricultural                                  ...  1989  514523.2052
# ...                                                 ...   ...          ...
# 2571                                            Natural  2015    5330.0000
# 2572                                            Natural  2016   23650.0000
# 2573                                            Natural  2016    4400.0000
# 2574                                            Natural  2017       0.0000
# 2575                                            Natural  2017       0.0000
#
#                                              Water Type            Component  \
# 0     Groundwater                                   ...  Incidental Recharge
# 1     Groundwater                                   ...  Incidental Recharge
# 2     Groundwater                                   ...  Incidental Recharge
# 3     Groundwater                                   ...  Incidental Recharge
# 4     Groundwater                                   ...  Incidental Recharge
# ...                                                 ...                  ...
# 2571  Groundwater                                   ...      Riparian Demand
# 2572  Groundwater                                   ...  Groundwater Outflow
# 2573  Groundwater                                   ...      Riparian Demand
# 2574  Groundwater                                   ...  Groundwater Outflow
# 2575  Groundwater                                   ...      Riparian Demand
#
#          AMA Name
# 0     PHOENIX AMA
# 1     PHOENIX AMA
# 2     PHOENIX AMA
# 3     PHOENIX AMA
# 4     PHOENIX AMA
# ...           ...
# 2571   TUCSON AMA
# 2572   TUCSON AMA
# 2573   TUCSON AMA
# 2574   TUCSON AMA
# 2575   TUCSON AMA
#
# [2576 rows x 8 columns]

# %%
#transfer WKT gemetry from dfshape
def retrieveGeometry(colrowValue, dfshape):
    if (colrowValue == '') or (pd.isnull(colrowValue)):
        outList = ''
    else:
        ml = dfshape.loc[(dfshape['NAME_ABBR'] == colrowValue), 'geometry']
        if not(ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

df['Geometry'] = df.apply(lambda row: retrieveGeometry(row['Basin Code'], dfshape), axis=1)
df
# Out:
#      Basin Code Inflow/Outflow  \
# 0           PHX         Inflow
# 1           PHX         Inflow
# 2           PHX         Inflow
# 3           PHX         Inflow
# 4           PHX         Inflow
# ...         ...            ...
# 2571        TUC        Outflow
# 2572        TUC        Outflow
# 2573        TUC        Outflow
# 2574        TUC        Outflow
# 2575        TUC        Outflow
#
#                                                  Sector  Year     Quantity  \
# 0     Agricultural                                  ...  1985  585460.7374
# 1     Agricultural                                  ...  1986  577371.6134
# 2     Agricultural                                  ...  1987  569202.1827
# 3     Agricultural                                  ...  1988  522300.0849
# 4     Agricultural                                  ...  1989  514523.2052
# ...                                                 ...   ...          ...
# 2571                                            Natural  2015    5330.0000
# 2572                                            Natural  2016   23650.0000
# 2573                                            Natural  2016    4400.0000
# 2574                                            Natural  2017       0.0000
# 2575                                            Natural  2017       0.0000
#
#                                              Water Type            Component  \
# 0     Groundwater                                   ...  Incidental Recharge
# 1     Groundwater                                   ...  Incidental Recharge
# 2     Groundwater                                   ...  Incidental Recharge
# 3     Groundwater                                   ...  Incidental Recharge
# 4     Groundwater                                   ...  Incidental Recharge
# ...                                                 ...                  ...
# 2571  Groundwater                                   ...      Riparian Demand
# 2572  Groundwater                                   ...  Groundwater Outflow
# 2573  Groundwater                                   ...      Riparian Demand
# 2574  Groundwater                                   ...  Groundwater Outflow
# 2575  Groundwater                                   ...      Riparian Demand
#
#          AMA Name                                           Geometry
# 0     PHOENIX AMA  POLYGON ((401515.8422997798 3762674.077700167,...
# 1     PHOENIX AMA  POLYGON ((401515.8422997798 3762674.077700167,...
# 2     PHOENIX AMA  POLYGON ((401515.8422997798 3762674.077700167,...
# 3     PHOENIX AMA  POLYGON ((401515.8422997798 3762674.077700167,...
# 4     PHOENIX AMA  POLYGON ((401515.8422997798 3762674.077700167,...
# ...           ...                                                ...
# 2571   TUCSON AMA  POLYGON ((506728.9803997681 3630477.361000173,...
# 2572   TUCSON AMA  POLYGON ((506728.9803997681 3630477.361000173,...
# 2573   TUCSON AMA  POLYGON ((506728.9803997681 3630477.361000173,...
# 2574   TUCSON AMA  POLYGON ((506728.9803997681 3630477.361000173,...
# 2575   TUCSON AMA  POLYGON ((506728.9803997681 3630477.361000173,...
#
# [2576 rows x 9 columns]

# %%
#Issue of lengthy geometry result exceeding the nvchar(250) limit of an excel cell.  Using xlsx file to check completness, and csv as input.

#Printing file to xlsx
df.to_excel('RawInputData/P_AZagg.xlsx', index=False)

#Printing file to xlsx
df.to_csv('RawInputData/P_AZagg.csv', index=False)
