# %% [markdown]
# # Working with AZ Aggregated Data
#
# Pre-processing input data for a smoother upload experience of the state data to the WaDE 2.0 database.
# Using geopandas to read in shp file, and coverting to WKT for ReportingUnit geometry.

# %%
#Needed Libararies
import os
import numpy as np
import pandas as pd
from datetime import datetime
import geopandas as gpd # the library that lets us read in shapefiles
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Arizona/AggregatedAmounts"
os.chdir(workingDir)

#CSV input file
fileInput = "RawInputData/AMA Demand Supply from DW_use as input.xlsx"
df = pd.read_excel(fileInput)

#Shapefile input
AZ_AMA = gpd.read_file('C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Arizona/AggregatedAmounts/RawInputData/AMA_and_INA-shp/AMA_and_INA.shp')
dfshape = pd.DataFrame(AZ_AMA)

# %%
#check csv input
df.head(3)
# Out:
#           AMA  YEAR        SECTOR             CATEGORY  \
# 0  TUCSON AMA  1985  Agricultural            Allotment
# 1  TUCSON AMA  1985  Agricultural               Demand
# 2  TUCSON AMA  1985  Agricultural  Incidental Recharge
#
#   PARENT WATER TYPE OR SECTOR Custom WSWC Water Type Translation  \
# 0                Agricultural                        Groundwater
# 1                Agricultural                        Unspecified
# 2                         NaN                           Recharge
#
#                BUDGET ELEMENT  QUANTITY
# 0       Groundwater Allotment    212718
# 1            Non-Exempt IGFRs    114879
# 2  Incidental Recharge Lagged     44371

# %%
#check shp input
dfshape.head(3)
# Out:
#    OBJECTID      BASIN_NAME NAME_ABBR        BASIN_NA_1     Shape_Leng  \
# 0         1  SANTA CRUZ AMA       SCA    SANTA CRUZ AMA  227784.354771
# 1         2    PRESCOTT AMA       PRE      PRESCOTT AMA  194403.011308
# 2         3  HARQUAHALA INA       HAR  HARQUAHALA BASIN  239098.916340
#
#      Shape_Area                                           geometry
# 0  1.853991e+09  POLYGON ((481155.981 3524735.269, 481185.919 3...
# 1  1.244308e+09  POLYGON ((357041.632 3843374.192, 357053.632 3...
# 2  1.983267e+09  POLYGON ((287010.098 3746236.654, 287022.598 3...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.dtypes)
# Out:
# AMA                                   object
# YEAR                                   int64
# SECTOR                                object
# CATEGORY                              object
# PARENT WATER TYPE OR SECTOR           object
# Custom WSWC Water Type Translation    object
# BUDGET ELEMENT                        object
# QUANTITY                               int64
# dtype: object

# %%
#Dropping fields we don't need.
df = df.drop(['PARENT WATER TYPE OR SECTOR', 'BUDGET ELEMENT'], axis=1)
df
# Out:
#               AMA  YEAR        SECTOR             CATEGORY  \
# 0      TUCSON AMA  1985  Agricultural            Allotment
# 1      TUCSON AMA  1985  Agricultural               Demand
# 2      TUCSON AMA  1985  Agricultural  Incidental Recharge
# 3      TUCSON AMA  1985  Agricultural  Incidental Recharge
# 4      TUCSON AMA  1985        Indian               Demand
# ...           ...   ...           ...                  ...
# 7494  PHOENIX AMA  2016    Industrial               Supply
# 7495  PHOENIX AMA  2017  Agricultural               Supply
# 7496  PHOENIX AMA  2017    Industrial               Supply
# 7497  PHOENIX AMA  2018  Agricultural               Supply
# 7498  PHOENIX AMA  2018    Industrial               Supply
#
#      Custom WSWC Water Type Translation  QUANTITY
# 0                           Groundwater    212718
# 1                           Unspecified    114879
# 2                              Recharge     44371
# 3                              Recharge     28720
# 4                           Unspecified        72
# ...                                 ...       ...
# 7494                            Unknown       689
# 7495                            Unknown      5142
# 7496                            Unknown       799
# 7497                            Unknown      4752
# 7498                            Unknown       766
#
# [7499 rows x 6 columns]

# %%
#Group by and Sum the 'Quantity' field.
df = df.groupby(['AMA','YEAR', 'SECTOR', 'CATEGORY', 'Custom WSWC Water Type Translation'])['QUANTITY'].sum().reset_index()
df
# Out:
#               AMA  YEAR        SECTOR             CATEGORY  \
# 0     PHOENIX AMA  1985  Agricultural            Allotment
# 1     PHOENIX AMA  1985  Agricultural               Demand
# 2     PHOENIX AMA  1985  Agricultural               Demand
# 3     PHOENIX AMA  1985  Agricultural  Incidental Recharge
# 4     PHOENIX AMA  1985  Agricultural               Supply
# ...           ...   ...           ...                  ...
# 4177   TUCSON AMA  2018     Municipal           Population
# 4178   TUCSON AMA  2018     Municipal           Population
# 4179   TUCSON AMA  2018     Municipal               Supply
# 4180   TUCSON AMA  2018     Municipal               Supply
# 4181   TUCSON AMA  2018     Municipal               Supply
#
#      Custom WSWC Water Type Translation  QUANTITY
# 0                           Groundwater   1877572
# 1                                  Lost     42832
# 2                           Unspecified   1222803
# 3                              Recharge   1013442
# 4                              Effluent     30138
# ...                                 ...       ...
# 4177                        Groundwater     32434
# 4178                        Unspecified    998987
# 4179                           Effluent     13342
# 4180                        Groundwater     31666
# 4181                      Surface Water    109340
#
# [4182 rows x 6 columns]

# %%
#transfer WKT gemetry from dfshape
def retrieveGeometry(colrowValue, dfshape):
    if (colrowValue == '') or (pd.isnull(colrowValue)):
        outList = ''
    else:
        ml = dfshape.loc[(dfshape['BASIN_NAME'] == colrowValue), 'geometry']
        if not(ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

df['Geometry'] = df.apply(lambda row: retrieveGeometry(row['AMA'], dfshape), axis=1)
df
# Out:
#               AMA  YEAR        SECTOR             CATEGORY  \
# 0     PHOENIX AMA  1985  Agricultural            Allotment
# 1     PHOENIX AMA  1985  Agricultural               Demand
# 2     PHOENIX AMA  1985  Agricultural               Demand
# 3     PHOENIX AMA  1985  Agricultural  Incidental Recharge
# 4     PHOENIX AMA  1985  Agricultural               Supply
# ...           ...   ...           ...                  ...
# 4177   TUCSON AMA  2018     Municipal           Population
# 4178   TUCSON AMA  2018     Municipal           Population
# 4179   TUCSON AMA  2018     Municipal               Supply
# 4180   TUCSON AMA  2018     Municipal               Supply
# 4181   TUCSON AMA  2018     Municipal               Supply
#
#      Custom WSWC Water Type Translation  QUANTITY  \
# 0                           Groundwater   1877572
# 1                                  Lost     42832
# 2                           Unspecified   1222803
# 3                              Recharge   1013442
# 4                              Effluent     30138
# ...                                 ...       ...
# 4177                        Groundwater     32434
# 4178                        Unspecified    998987
# 4179                           Effluent     13342
# 4180                        Groundwater     31666
# 4181                      Surface Water    109340
#
#                                                Geometry
# 0     POLYGON ((401515.8422997798 3762674.077700167,...
# 1     POLYGON ((401515.8422997798 3762674.077700167,...
# 2     POLYGON ((401515.8422997798 3762674.077700167,...
# 3     POLYGON ((401515.8422997798 3762674.077700167,...
# 4     POLYGON ((401515.8422997798 3762674.077700167,...
# ...                                                 ...
# 4177  POLYGON ((506728.9803997681 3630477.361000173,...
# 4178  POLYGON ((506728.9803997681 3630477.361000173,...
# 4179  POLYGON ((506728.9803997681 3630477.361000173,...
# 4180  POLYGON ((506728.9803997681 3630477.361000173,...
# 4181  POLYGON ((506728.9803997681 3630477.361000173,...
#
# [4182 rows x 7 columns]

# %%
#Issue of lengthy geometry result exceeding the nvchar(250) limit of an excel cell.  Using xlsx file to check completness, and csv as input.

#Printing file to xlsx
df.to_excel('RawInputData/P_AZagg.xlsx', index=False)

#Printing file to xlsx
df.to_csv('RawInputData/P_AZagg.csv', index=False)
