# %% [markdown]
# # Preprocessing Arizona Allocation data for WaDEQA upload.
# Purpose:  To preprocess the Arizona data into one mail file for simple DataFrame creation and extraction.

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
import re
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x) # suppress scientific notation in Pandas

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/Arizona/WaterAllocation_GW"
os.chdir(workingDir)

# %% [markdown]
# ## Groundwater Data (POD)

# %%
# input File - Well_Registry.csv
fileInput = "RawInputData/Well_Registry.zip"
dfgw = pd.read_csv(fileInput, compression='zip').replace(np.nan, "")

if 'WaDEUUID' not in dfgw:
    dfgw['WaDEUUID'] = "azGW" + dfgw.index.astype(str)
    dfgw.to_csv('RawInputData/Well_Registry.zip', compression='zip', index=False)

print(len(dfgw))
dfgw.head()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_19588\1776752269.py:3: DtypeWarning: Columns (35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfgw = pd.read_csv(fileInput, compression='zip').replace(np.nan, "")
# 229051
#    WaDEUUID ReasonRemoved IncompleteField  OID_  OBJECTID  PROGRAM  \
# 0     azGW0                                   1         1       55
# 1     azGW1                                   2         2       55
# 2    azGW10                                  11        11       55
# 3   azGW100                                 101       101       55
# 4  azGW1000                                1001      1001       55
#
#    REGISTRY_I                                  OWNER_NAME RGR_PUMP_D  \
# 0       60000    ARIZONA SONORAN COPPER COMPANY (USA) INC         NO
# 1       60001            ROUTE 14 INVESTMENT PARTNERS LLC        YES
# 2       84580                          H & R HENRY FARMS,         NO
# 3       84955                             GEDRGE, LAUREL,         NO
# 4       86084                            ANAMAX MINIG CO,         NO
#
#                                         WELLTYPE  WELL_TYPE_ DLIC_NUM  \
# 0                                     NON-EXEMPT  NON-EXEMPT        0
# 1                       NON-EXEMPT - NON-SERVICE  NON-EXEMPT      611
# 2  NON-EXEMPT - REPLACEMENT WELL IN NEW LOCATION  NON-EXEMPT        0
# 3                                         EXEMPT      EXEMPT       35
# 4                                     NON-EXEMPT  NON-EXEMPT        0
#
#             APPROVED           INSTALLED  WELL_DEPTH  WATER_LEVE  CASING_DEP  \
# 0                                               1790         257          60
# 1  1/24/2003 0:00:00    7/2/1984 0:00:00        1000         520        1000
# 2                                                  0           0           0
# 3                      8/16/1980 0:00:00         180          90         180
# 4                     11/14/1980 0:00:00         390         260         387
#
#    CASING_DIA                            CASING_TYP            PUMP_TYPE  \
# 0          20                  OPEN HOLE IN AQUIFER  NO PUMP CODE LISTED
# 1          12  STEEL - PERFORATED OR SLOTTED CASING          SUBMERSIBLE
# 2           0                 NO CASING CODE LISTED  NO PUMP CODE LISTED
# 3           5                        PLASTIC OR PVC  NO PUMP CODE LISTED
# 4          10  STEEL - PERFORATED OR SLOTTED CASING          SUBMERSIBLE
#
#                     PUMP_POWER  PUMPRATE  TESTEDRATE  DRAW_DOWN COMPLETION  \
# 0         NO POWER CODE LISTED         0           0          0
# 1  ELECTRIC MOTOR  16 - 100 HP       200         400         75
# 2         NO POWER CODE LISTED         0           0          0
# 3         NO POWER CODE LISTED         0           0          0
# 4  ELECTRIC MOTOR  16 - 100 HP       240         240         30
#
#   DRILL_LOG WELL_CANCE     CADASTRAL    COUNTY         WATERSHED   BASIN_NAME  \
# 0                    N  D05005035ABA     PINAL  SANTA CRUZ RIVER    PINAL AMA
# 1                       B05002008CCB  MARICOPA   AGUA FRIA RIVER  PHOENIX AMA
# 2                    Y  B01003026BBB  MARICOPA  LOWER GILA RIVER  PHOENIX AMA
# 3                       A06003007ACC  MARICOPA   AGUA FRIA RIVER  PHOENIX AMA
# 4                       D18013005ABA      PIMA  SANTA CRUZ RIVER   TUCSON AMA
#
#                SUBBASIN_N      AMA QUAD_CODE  WHOLE_TOWN HALF_TOWNS  \
# 0                    ELOY    PINAL         D           5          0
# 1  WEST SALT RIVER VALLEY  PHOENIX         B           5          0
# 2  WEST SALT RIVER VALLEY  PHOENIX         B           1          0
# 3  EAST SALT RIVER VALLEY  PHOENIX         A           6          0
# 4        UPPER SANTA CRUZ   TUCSON         D          18          0
#
#   NORTHSOUTH  WHOLE_RANG HALF_RANGE EASTWEST  SECTION QUARTER_16 QACRE160DI  \
# 0          S           5          0        E       35          A         NE
# 1          N           2          0        W        8          C         SW
# 2          N           3          0        W       26          B         NW
# 3          N           3          0        E        7          A         NE
# 4          S          13          0        E        5          A         NE
#
#   QUARTER_40 QACRE40DIR QUARTER_10 QACRE10DIR   UTM_X_METE    UTM_Y_METE  \
# 0          B         NW          A         NE 423912.10000 3646244.00000
# 1          C         SW          B         NW 361297.10000 3739323.00000
# 2          B         NW          B         NW 356989.90000 3697339.00000
# 3          C         SW          C         SW 399170.10000 3749371.00000
# 4          B         NW          A         NE 496769.60000 3529202.00000
#
#            APPLICATIO             ADDRESS1                   ADDRESS2  \
# 0    1/1/1900 0:00:00  ATTN: TRAVIS SNYDER  850 W. ELLIOT RD. STE 106
# 1   2/25/1985 0:00:00  ATTN: MARK REPANICH          33040 N 203RD AVE
# 2   6/30/1980 0:00:00            PO BOX 66
# 3    7/8/1980 0:00:00     43442 N 13TH AVE
# 4  12/15/1980 0:00:00           PO BOX 127
#
#         CITY STATE    ZIP ZIP4   WATER_USE  latitude  longitude
# 0      TEMPE    AZ  85284       DEWATERING  32.95186 -111.81407
# 1   WITTMANN    AZ  85361       INDUSTRIAL  33.78498 -112.49814
# 2    BUCKEYE    AZ  85326       IRRIGATION  33.40587 -112.53792
# 3    PHOENIX    AZ  85027         DOMESTIC  33.87987 -112.09030
# 4  SAHUARITA    AZ  85629         DRAINAGE  31.89865 -111.03417

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfgw['WaDEUUID']

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = ""
df['in_WaterSourceNativeID'] = "" # create customID for temp solution
df['in_WaterSourceTypeCV'] = "Groundwater"

# Site Info
df['in_RegulatoryOverlayUUIDs'] = ""
df['in_WaterSourceUUID'] = "" # ???
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = dfgw['COUNTY'].str.title()
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfgw['latitude']
df['in_Longitude'] = dfgw['longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"
df['in_SiteName'] = ""
df['in_SiteNativeID'] = "POD" + dfgw['CADASTRAL'].replace("", 0).fillna(0).astype(str)
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = "Well" # these should all be well records
df['in_StateCV'] = "AZ"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_MethodUUID'] = "AZwr_M1" # for goundwater (separate from SW project)
df['in_OrganizationUUID'] = "AZwr_O1"
df['in_SiteUUID'] = "" # ???
df['in_VariableSpecificUUID'] =  "AZwr_V1" # for CFS (separate from SW project)
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = dfgw['PUMPRATE'].astype(float)
df['in_AllocationLegalStatusCV'] = ""
df['in_AllocationNativeID'] =  dfgw['REGISTRY_I'].replace("", 0).fillna(0).astype(int).astype(str)
df['in_AllocationOwner'] = dfgw['OWNER_NAME']
df['in_AllocationPriorityDate'] = ""
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = "12/31"
df['in_AllocationTimeframeStart'] = "01/01"
#df['in_AllocationTypeCV'] = dfgw['WELL_TYPE_'] # skip for now
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = ""
df['in_BeneficialUseCategory'] = dfgw['WATER_USE'].str.title()
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 1 # all these gw records should be considered exempt for us.
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = "https://app.azwater.gov/WellRegistry/Detail.aspx?" + dfgw['REGISTRY_I'].replace("", 0).fillna(0).astype(int).astype(str)

dfgwOut = df.copy()
print(len(dfgwOut))
dfgwOut.head()
# Out:
# 229051
#    WaDEUUID in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0     azGW0
# 1     azGW1
# 2    azGW10
# 3   azGW100
# 4  azGW1000
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                                    Groundwater
# 1                                                    Groundwater
# 2                                                    Groundwater
# 3                                                    Groundwater
# 4                                                    Groundwater
#
#   in_RegulatoryOverlayUUIDs in_WaterSourceUUID in_CoordinateAccuracy  \
# 0
# 1
# 2
# 3
# 4
#
#   in_CoordinateMethodCV in_County  in_EPSGCodeCV in_GNISCodeCV in_HUC12  \
# 0                           Pinal           4326
# 1                        Maricopa           4326
# 2                        Maricopa           4326
# 3                        Maricopa           4326
# 4                            Pima           4326
#
#   in_HUC8  in_Latitude  in_Longitude in_NHDNetworkStatusCV in_NHDProductCV  \
# 0             32.95186    -111.81407
# 1             33.78498    -112.49814
# 2             33.40587    -112.53792
# 3             33.87987    -112.09030
# 4             31.89865    -111.03417
#
#   in_PODorPOUSite in_SiteName  in_SiteNativeID in_SitePoint in_SiteTypeCV  \
# 0             POD              PODD05005035ABA                       Well
# 1             POD              PODB05002008CCB                       Well
# 2             POD              PODB01003026BBB                       Well
# 3             POD              PODA06003007ACC                       Well
# 4             POD              PODD18013005ABA                       Well
#
#   in_StateCV in_USGSSiteID in_MethodUUID in_OrganizationUUID in_SiteUUID  \
# 0         AZ                     AZwr_M1             AZwr_O1
# 1         AZ                     AZwr_M1             AZwr_O1
# 2         AZ                     AZwr_M1             AZwr_O1
# 3         AZ                     AZwr_M1             AZwr_O1
# 4         AZ                     AZwr_M1             AZwr_O1
#
#   in_VariableSpecificUUID in_AllocationApplicationDate  \
# 0                 AZwr_V1
# 1                 AZwr_V1
# 2                 AZwr_V1
# 3                 AZwr_V1
# 4                 AZwr_V1
#
#   in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                                            0.00000
# 1                                          200.00000
# 2                                            0.00000
# 3                                            0.00000
# 4                                          240.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                                            60000
# 1                                            60001
# 2                                            84580
# 3                                            84955
# 4                                            86084
#
#                            in_AllocationOwner in_AllocationPriorityDate  \
# 0    ARIZONA SONORAN COPPER COMPANY (USA) INC
# 1            ROUTE 14 INVESTMENT PARTNERS LLC
# 2                          H & R HENRY FARMS,
# 3                             GEDRGE, LAUREL,
# 4                            ANAMAX MINIG CO,
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0                                                    12/31
# 1                                                    12/31
# 2                                                    12/31
# 3                                                    12/31
# 4                                                    12/31
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0                       01/01
# 1                       01/01
# 2                       01/01
# 3                       01/01
# 4                       01/01
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0               Dewatering
# 1               Industrial
# 2               Irrigation
# 3                 Domestic
# 4                 Drainage
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#    in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://app.azwater.gov/WellRegistry/Detail.as...
# 1  https://app.azwater.gov/WellRegistry/Detail.as...
# 2  https://app.azwater.gov/WellRegistry/Detail.as...
# 3  https://app.azwater.gov/WellRegistry/Detail.as...
# 4  https://app.azwater.gov/WellRegistry/Detail.as...

# %%
frames = [dfgwOut] # add dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 229051

# %% [markdown]
# ## Clean output dataframes

# %%
# AZwr Groundwater PUMPRATE is in GPM, need to convert to CFS
# 448.8 CFS = 1 GPM

# Clean owner name up
def ConvertGPMToCFSFunc(Val):
    Val = Val / 448.8 
    return Val

outdf['in_AllocationFlow_CFS'] = outdf.apply(lambda row: ConvertGPMToCFSFunc(row['in_AllocationFlow_CFS']), axis=1)
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([ 0.        ,  0.4456328 ,  0.53475936, ...,  4.89527629,
#         0.67959002, 51.24777184])

# %%
# Clean owner name up
def cleanOwnerDataFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;,/\)(-]", "", Val).title().strip()
    return Val

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Arizona Sonoran Copper Company Usa Inc',
#        'Route 14 Investment Partners Llc', 'H  R Henry Farms', ...,
#        'Guy Freeman', 'Mohr And Leap', 'All Star Gas Inc Of Az'],
#       dtype=object)

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: cleanOwnerDataFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: cleanOwnerDataFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: cleanOwnerDataFunc(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['Pinal', 'Maricopa', 'Pima', 'Yavapai', 'Cochise', 'Navajo',
#        'Santa Cruz', 'Mohave', 'Gila', 'La Paz', 'Apache', 'Yuma',
#        'Coconino', 'Graham', 'Greenlee'], dtype=object)

# %%
# Ensure Empty String

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: ensureEmptyString(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['Pinal', 'Maricopa', 'Pima', 'Yavapai', 'Cochise', 'Navajo',
#        'Santa Cruz', 'Mohave', 'Gila', 'La Paz', 'Apache', 'Yuma',
#        'Coconino', 'Graham', 'Greenlee'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['Well'], dtype=object)

# %%
outdf['in_AllocationLegalStatusCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationLegalStatusCV']), axis=1)
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Arizona Sonoran Copper Company Usa Inc',
#        'Route 14 Investment Partners Llc', 'H  R Henry Farms', ...,
#        'Guy Freeman', 'Mohr And Leap', 'All Star Gas Inc Of Az'],
#       dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['Dewatering', 'Industrial', 'Irrigation', 'Domestic', 'Drainage',
#        'Stock', 'Municipal Uses, Commercial', 'Test', 'Municipal Uses',
#        'Commercial', '', 'Mining', 'Reserved', 'Monitoring',
#        'Other - Production', 'No Water Use', 'Test, Monitoring',
#        'Domestic, Stock', 'No Use Code On Noi', 'Test, No Water Use',
#        'Other - Mineral Explore', 'Monitoring, No Water Use',
#        'No Water Use, Monitoring', 'No Use Code On Noi, Recovery',
#        'Recovery, Municipal Uses, Industrial', 'Remediation',
#        'Irrigation, Commercial, Domestic, Municipal Uses, Mining, Stock',
#        'Utility (Water Co)', 'Test, Industrial', 'Domestic, Irrigation',
#        'Recovery', 'Municipal Uses, Recovery', 'Domestic, Monitoring',
#        'Municipal Uses, No Water Use', 'Test, Remediation',
#        'Test, Reserved', 'Monitoring, Monitoring',
#        'Irrigation, Municipal Uses, Recovery', 'Irrigation, Industrial',
#        'Industrial, Municipal Uses', 'Domestic, Irrigation, Stock',
#        'Irrigation, Stock', 'Municipal Uses, Domestic',
#        'Commercial, Domestic', 'Municipal Uses, Industrial, Recovery',
#        'Domestic, Municipal Uses', 'Domestic, Commercial',
#        'Municipal Uses, Industrial', 'Municipal Uses, Test',
#        'Recreation, Industrial', 'Mining, Other - Mineral Explore',
#        'Municipal Uses, Domestic, Recovery', 'Stock, Stock, Irrigation',
#        'Unknown', 'Commercial, Stock', 'Municipal Uses, Monitoring',
#        'Municipal Uses, Municipal Uses, Test, Recovery',
#        'Test, Municipal Uses', 'Irrigation, Commercial, Domestic, Stock',
#        'Irrigation, Domestic', 'Domestic, Domestic',
#        'Commercial, Monitoring', 'Utility (Water Co), Domestic',
#        'Industrial, Mining', 'Irrigation, Municipal Uses, Industrial',
#        'Irrigation, Municipal Uses, Domestic, Recovery',
#        'Domestic, Stock, Irrigation', 'Subdivision',
#        'Drainage, Industrial', 'Utility (Water Co), Recovery',
#        'Industrial, Monitoring', 'Domestic, Irrigation, Recreation',
#        'Stock, Irrigation', 'Industrial, Domestic',
#        'Monitoring, Industrial', 'Stock, Domestic',
#        'Industrial, Other - Production', 'Commercial, Other - Production',
#        'Domestic, Other - Production', 'Mining, Other - Production',
#        'Stock, Other - Production',
#        'Domestic, No Use Code On Noi, Utility (Water Co)',
#        'Monitoring, Domestic', 'Commercial, Irrigation',
#        'Domestic, Commercial, Irrigation', 'Monitoring, Test',
#        'Municipal Uses, No Use Code On Noi',
#        'No Water Use, No Use Code On Noi', 'Domestic, Commercial, Stock',
#        'Recreation, Domestic', 'Test, Recovery, Industrial',
#        'Commercial, Municipal Uses', 'Mining, Domestic',
#        'Municipal Uses, Stock, Domestic', 'Commercial, Commercial, Stock',
#        'Irrigation, Municipal Uses', 'Remediation, Municipal Uses',
#        'Municipal Uses, Test, Subdivision, Test, Domestic',
#        'Industrial, Municipal Uses, Domestic',
#        'Commercial, Irrigation, Domestic',
#        'Domestic, Commercial, Industrial', 'Recreation, No Water Use',
#        'Drainage, No Water Use', 'Recreation', 'No Water Use, Reserved',
#        'Stock, Domestic, Mining', 'Stock, Mining',
#        'Commercial, Commercial', 'No Water Use, Municipal Uses',
#        'Municipal Uses, Test, Recovery', 'Domestic, Utility (Water Co)',
#        'Municipal Uses, Utility (Water Co)',
#        'Irrigation, Other - Production', 'Other - Production, Domestic',
#        'Irrigation, Commercial, Domestic', 'Industrial, Irrigation',
#        'Test, Municipal Uses, Recovery, Industrial, Recovery',
#        'Test, Municipal Uses, Industrial, Recovery',
#        'Commercial, Utility (Water Co)',
#        'Irrigation, Recovery, Industrial',
#        'Irrigation, Domestic, Stock, Domestic, Stock',
#        'Irrigation, Commercial', 'Recovery, Drainage',
#        'Irrigation, Domestic, Stock',
#        'Subdivision, Test, Subdivision, Test',
#        'No Use Code On Noi, Industrial, Recovery',
#        'Domestic, No Water Use', 'Municipal Uses, Irrigation, Recovery',
#        'No Water Use, Industrial, Recovery',
#        'Municipal Uses, Municipal Uses', 'Industrial, Test, Test',
#        'Industrial, Test', 'Irrigation, Domestic, Industrial, Recovery',
#        'Industrial, Test, Industrial, Test', 'Test, Recovery',
#        'Irrigation, Recreation', 'Recreation, Irrigation',
#        'Municipal Uses, Test, Subdivision, Test', 'Recovery, Industrial',
#        'Irrigation, Industrial, Recovery', 'Irrigation, Stock, Domestic',
#        'Municipal Uses, Industrial, Other - Production',
#        'Municipal Uses, Irrigation', 'Irrigation, Stock, No Water Use',
#        'Industrial, Industrial',
#        'Municipal Uses, Commercial, Domestic, Recovery',
#        'Test, Municipal Uses, Industrial',
#        'Municipal Uses, Test, Municipal Uses, Test, Recovery',
#        'Stock, Domestic, Irrigation', 'Utility (Water Co), Commercial',
#        'Irrigation, Domestic, Industrial',
#        'Utility (Water Co), Municipal Uses',
#        'No Use Code On Noi, Reserved', 'Domestic, Stock, Domestic',
#        'Subdivision, Test', 'Domestic, Domestic, Irrigation, Stock',
#        'Municipal Uses, Municipal Uses, Recovery',
#        'Recovery, Municipal Uses', 'Commercial, Recovery',
#        'Domestic, Industrial', 'Recovery, No Water Use',
#        'Monitoring, No Use Code On Noi', 'Monitoring, Reserved',
#        'Commercial, Municipal Uses, Industrial', 'Recovery, Monitoring',
#        'Irrigation, Recovery', 'Industrial, Test, Municipal Uses',
#        'Municipal Uses, Industrial, Test', 'Domestic, Stock, Commercial',
#        'Remediation, Monitoring',
#        'Commercial, Other - Production, Irrigation', 'Domestic, Test',
#        'Stock, Irrigation, Domestic', 'Stock, Industrial',
#        'Municipal Uses, Domestic, Municipal Uses',
#        'Domestic, Domestic, Stock', 'Domestic, Stock, Municipal Uses',
#        'Mining, Stock', 'Domestic, Irrigation, Mining, Stock',
#        'Commercial, Industrial', 'Domestic, Recreation',
#        'Utility (Water Co), Other - Production',
#        'Municipal Uses, Other - Production',
#        'Commercial, Domestic, Irrigation',
#        'Utility (Water Co), Irrigation, Domestic',
#        'Commercial, Irrigation, Domestic, Municipal Uses, Industrial',
#        'Industrial, Test, Recovery',
#        'Utility (Water Co), Irrigation, Stock', 'Stock, Stock',
#        'Irrigation, Domestic, Other - Production',
#        'No Water Use, Domestic', 'Domestic, Stock, Other - Production',
#        'No Use Code On Noi, Monitoring', 'Commercial, Subdivision',
#        'Irrigation, Domestic, Stock, Other - Production',
#        'Utility (Water Co), Irrigation',
#        'Domestic, Municipal Uses, Reserved',
#        'Irrigation, Municipal Uses, Other - Production',
#        'Domestic, Mining', 'Monitoring, Recovery',
#        'Domestic, Stock, No Water Use',
#        'Domestic, Irrigation, Commercial, Stock',
#        'Commercial, Industrial, Mining',
#        'Domestic, Irrigation, Industrial, Stock, Commercial, Mining',
#        'Irrigation, No Water Use', 'Irrigation, Recreation, Domestic',
#        'Irrigation, Recovery, Municipal Uses', 'Mining, Commercial',
#        'Utility (Water Co), No Water Use', 'Test, Industrial, Recovery',
#        'Stock, Domestic, Industrial',
#        'No Water Use, Municipal Uses, Recovery', 'Industrial, Commercial',
#        'Irrigation, Domestic, Recovery',
#        'Industrial, Municipal Uses, Test', 'Domestic, Stock, Stock',
#        'Other - Production, Irrigation, Commercial',
#        'Other - Production, No Water Use',
#        'Industrial, Domestic, Utility (Water Co)',
#        'Irrigation, Stock, Other - Production',
#        'Municipal Uses, Recreation',
#        'Commercial, Irrigation, Other - Production',
#        'Utility (Water Co), Utility (Water Co)',
#        'Reserved, Irrigation, Stock', 'Recreation, Recreation',
#        'Test, Utility (Water Co)', 'Recovery, Test, Municipal Uses',
#        'Domestic, Irrigation, Commercial', 'No Water Use, Industrial',
#        'Dewatering, Mining', 'Irrigation, Test',
#        'Test, Recovery, Monitoring', 'Commercial, No Water Use',
#        'Industrial, Recovery', 'Municipal Uses, Municipal Uses, Test',
#        'Commercial, Industrial, Domestic',
#        'Other - Mineral Explore, No Water Use',
#        'Municipal Uses, Industrial, Monitoring',
#        'Utility (Water Co), Subdivision', 'Remediation, Reserved',
#        'Domestic, Irrigation, Utility (Water Co)',
#        'Commercial, Domestic, Stock', 'Irrigation, Irrigation',
#        'Irrigation, Stock, Industrial',
#        'Municipal Uses, Municipal Uses, Industrial',
#        'Domestic, Stock, Industrial', 'Stock, Other - Mineral Explore',
#        'Test, Stock', 'Industrial, Domestic, Stock',
#        'Irrigation, Domestic, Municipal Uses', 'Industrial, Recreation',
#        'Utility (Water Co), Recovery, Monitoring',
#        'Utility (Water Co), Recovery, Monitoring, Municipal Uses',
#        'Irrigation, Domestic, Commercial',
#        'Mining, Municipal Uses, No Use Code On Noi', 'Mining, Industrial',
#        'Stock, Domestic, No Water Use', 'Stock, Domestic, Recreation',
#        'Monitoring, Stock, Irrigation', 'Industrial, Stock',
#        'Irrigation, Utility (Water Co)',
#        'Irrigation, Utility (Water Co), Municipal Uses',
#        'Domestic, Municipal Uses, Industrial',
#        'Municipal Uses, Industrial, Domestic',
#        'Domestic, Municipal Uses, Recovery',
#        'Utility (Water Co), Municipal Uses, Recovery',
#        'Irrigation, Utility (Water Co), Municipal Uses, Industrial',
#        'Municipal Uses, Irrigation, Utility (Water Co), Industrial',
#        'Municipal Uses, Domestic, Industrial',
#        'Industrial, Domestic, No Water Use', 'Mining, Mining',
#        'Municipal Uses, Domestic, Mining',
#        'Municipal Uses, Municipal Uses, Irrigation, Recovery',
#        'Irrigation, Utility (Water Co), Other - Production',
#        'No Water Use, Utility (Water Co)',
#        'Municipal Uses, Irrigation, Industrial',
#        'Municipal Uses, Utility (Water Co), Municipal Uses, Industrial',
#        'Mining, Stock, Domestic',
#        'Stock, Domestic, Irrigation, No Water Use', 'Stock, No Water Use',
#        'Domestic, Stock, Mining', 'Test, Irrigation',
#        'Industrial, No Water Use',
#        'Irrigation, Utility (Water Co), No Water Use',
#        'Utility (Water Co), Irrigation, Municipal Uses',
#        'Municipal Uses, Irrigation, Utility (Water Co)',
#        'Industrial, Irrigation, Municipal Uses, Utility (Water Co)',
#        'Domestic, Municipal Uses, Stock',
#        'Irrigation, Industrial, Municipal Uses', 'Irrigation, Reserved',
#        'Industrial, Irrigation, Utility (Water Co), Municipal Uses',
#        'Irrigation, Irrigation, Stock',
#        'Utility (Water Co), Municipal Uses, Industrial',
#        'Other - Production, Stock', 'Irrigation, Domestic, Monitoring',
#        'Mining, Domestic, Municipal Uses',
#        'Irrigation, No Use Code On Noi',
#        'Domestic, Irrigation, Other - Production',
#        'Municipal Uses, Stock', 'Utility (Water Co), Stock',
#        'Recreation, Mining', 'Irrigation, Stock, Municipal Uses',
#        'No Water Use, Irrigation', 'Domestic, Industrial, Mining',
#        'Recreation, Stock', 'Industrial, Irrigation, Domestic',
#        'Domestic, Industrial, Utility (Water Co)',
#        'Stock, Domestic, Other - Mineral Explore',
#        'Commercial, Stock, Irrigation',
#        'Irrigation, Stock, Domestic, Municipal Uses',
#        'Irrigation, Stock, Industrial, Municipal Uses',
#        'No Water Use, Stock', 'Municipal Uses, Stock, Municipal Uses',
#        'Utility (Water Co), Monitoring',
#        'Domestic, Other - Mineral Explore', 'Domestic, Subdivision',
#        'Domestic, Reserved',
#        'Irrigation, Stock, Municipal Uses, No Water Use',
#        'Domestic, Stock, Irrigation, Municipal Uses',
#        'Stock, Domestic, Municipal Uses',
#        'Irrigation, Stock, Domestic, No Water Use',
#        'Industrial, Stock, Domestic', 'Domestic, Recreation, Irrigation',
#        'Irrigation, Monitoring', 'Irrigation, Stock, Drainage',
#        'Recovery, Irrigation', 'Industrial, Domestic, Irrigation',
#        'Irrigation, Stock, Irrigation', 'Industrial, Stock, Industrial',
#        'Industrial, Reserved', 'Domestic, No Use Code On Noi',
#        'Municipal Uses, Domestic, Irrigation', 'Monitoring, Mining',
#        'Municipal Uses, Reserved',
#        'Irrigation, Municipal Uses, No Use Code On Noi',
#        'Irrigation, Industrial, Stock',
#        'Municipal Uses, No Use Code On Noi, Recovery',
#        'Domestic, Industrial, Irrigation',
#        'Domestic, Irrigation, Stock, No Water Use',
#        'Stock, Municipal Uses', 'Stock, Irrigation, Industrial',
#        'Stock, Reserved', 'Other - Production, Stock, Domestic',
#        'Domestic, Irrigation, No Water Use',
#        'Municipal Uses, Domestic, Stock',
#        'Irrigation, Industrial, Domestic', 'Reserved, Stock, Domestic',
#        'Mining, No Water Use', 'No Water Use, Domestic, Stock',
#        'Stock, Irrigation, Municipal Uses', 'Mining, Domestic, Stock',
#        'Domestic, Irrigation, Industrial', 'Domestic, Stock, Subdivision',
#        'Domestic, Utility (Water Co), Municipal Uses',
#        'Domestic, Domestic, Industrial',
#        'Domestic, Industrial, Commercial', 'Stock, Recreation',
#        'Stock, Domestic, Stock', 'Irrigation, Stock, Commercial',
#        'Other - Production, Subdivision, Irrigation',
#        'Other - Production, Subdivision',
#        'Domestic, Irrigation, Municipal Uses',
#        'Domestic, Municipal Uses, Recreation',
#        'Stock, Municipal Uses, Industrial', 'Commercial, Stock, Domestic',
#        'Municipal Uses, Domestic, Municipal Uses, Industrial',
#        'Stock, Unknown', 'Stock, Domestic, Commercial',
#        'Monitoring, Municipal Uses, Industrial',
#        'Utility (Water Co), Domestic, Industrial',
#        'Domestic, Municipal Uses, Mining', 'Mining, Recovery',
#        'Irrigation, Municipal Uses, Industrial, Recovery',
#        'Other - Production, Domestic, Industrial',
#        'Recreation, Municipal Uses',
#        'Unknown, Municipal Uses, Industrial',
#        'Industrial, Irrigation, Municipal Uses',
#        'Irrigation, Municipal Uses, Utility (Water Co)',
#        'Municipal Uses, Irrigation, Industrial, Recovery',
#        'Irrigation, Mining', 'Other - Production, Domestic, Stock',
#        'Utility (Water Co), Industrial, Domestic',
#        'Subdivision, Irrigation', 'Domestic, Unknown',
#        'Utility (Water Co), Industrial', 'No Water Use, Stock, Domestic',
#        'No Use Code On Noi, Domestic, Stock', 'Stock, Stock, Domestic',
#        'Domestic, Domestic, Irrigation', 'Stock, Mining, Domestic',
#        'Domestic, Stock, Reserved', 'Stock, No Use Code On Noi',
#        'Domestic, Commercial, Irrigation, Utility (Water Co)',
#        'Stock, Monitoring', 'Domestic, Dewatering',
#        'Domestic, Irrigation, Stock, Irrigation',
#        'Recreation, Domestic, Mining',
#        'Irrigation, Recreation, Municipal Uses',
#        'Recreation, Municipal Uses, Domestic',
#        'Municipal Uses, Industrial, No Water Use',
#        'Municipal Uses, Industrial, Irrigation', 'Unknown, Domestic',
#        'Commercial, Domestic, Domestic', 'Domestic, Stock, Recreation',
#        'Domestic, Industrial, No Water Use', 'Commercial, Recreation',
#        'Irrigation, Municipal Uses, Irrigation',
#        'Domestic, Industrial, Municipal Uses',
#        'Domestic, Industrial, Stock', 'Irrigation, Stock, Recreation',
#        'Irrigation, Recreation, Stock',
#        'Recreation, Domestic, Irrigation', 'Irrigation, Domestic, Mining',
#        'Commercial, Mining', 'Municipal Uses, Industrial, Stock',
#        'Recreation, Stock, Irrigation', 'Irrigation, Drainage',
#        'Domestic, Recreation, Mining', 'Dewatering, Industrial, Mining',
#        'Mining, Domestic, Irrigation', 'Industrial, Irrigation, Mining',
#        'Domestic, Irrigation, Utility (Water Co), Commercial',
#        'Mining, Irrigation, Domestic',
#        'Municipal Uses, Irrigation, Stock',
#        'Stock, Irrigation, No Water Use',
#        'Domestic, Stock, Irrigation, No Water Use',
#        'Irrigation, Stock, Mining',
#        'Municipal Uses, Industrial, Irrigation, Recovery',
#        'Domestic, Irrigation, Mining',
#        'Domestic, Commercial, No Water Use',
#        'Irrigation, Commercial, Domestic, Municipal Uses, Stock',
#        'Industrial, Mining, Commercial', 'Domestic, Mining, Stock',
#        'Monitoring, Stock', 'Mining, Industrial, Domestic',
#        'Mining, Industrial, Commercial', 'Domestic, Mining, Irrigation',
#        'Domestic, Mining, Recreation', 'No Use Code On Noi, No Water Use',
#        'Mining, Drainage', 'No Water Use, Test', 'Stock, Subdivision',
#        'Monitoring, Municipal Uses', 'Stock, Commercial',
#        'Domestic, Recovery', 'Mining, Municipal Uses, Domestic',
#        'No Water Use, No Water Use', 'Irrigation, Domestic, Recreation',
#        'Other - Production, Recovery',
#        'Industrial, Industrial, Irrigation',
#        'Stock, Domestic, Industrial, Reserved', 'No Water Use, Recovery',
#        'No Use Code On Noi, Dewatering',
#        'Monitoring, Domestic, No Water Use',
#        'Irrigation, Domestic, No Water Use',
#        'Recreation, Irrigation, Domestic',
#        'Irrigation, Domestic, Irrigation', 'Other - Production, Mining',
#        'Other - Production, Other - Production', 'Industrial, Dewatering',
#        'Mining, Dewatering', 'Domestic, Irrigation, Domestic, Stock',
#        'Irrigation, Stock, Industrial, Mining',
#        'Irrigation, Commercial, Domestic, Municipal Uses, Industrial, Stock',
#        'Utility (Water Co), Domestic, Stock',
#        'Domestic, Irrigation, Stock, Other - Production',
#        'Irrigation, Mining, No Use Code On Noi',
#        'Domestic, Irrigation, Domestic',
#        'No Use Code On Noi, Other - Production',
#        'Municipal Uses, Irrigation, Utility (Water Co), Domestic, Stock',
#        'Industrial, Domestic, Other - Production',
#        'Utility (Water Co), Commercial, Domestic, Municipal Uses',
#        'Commercial, Domestic, Irrigation, Mining',
#        'Stock, Utility (Water Co), Domestic, Other - Production',
#        'Recovery, Recovery', 'Dewatering, Irrigation',
#        'Municipal Uses, Commercial, Domestic, Industrial', 'Stock, Test',
#        'Domestic, Commercial, Municipal Uses',
#        'Commercial, Irrigation, Stock',
#        'Commercial, Domestic, Municipal Uses, Industrial, Stock',
#        'Test, Domestic', 'Irrigation, Stock, Test', 'Commercial, Test',
#        'Stock, Irrigation, Test', 'Drainage, Recovery',
#        'Irrigation, Dewatering',
#        'Mining, Commercial, Domestic, Industrial',
#        'Industrial, Stock, Irrigation',
#        'Commercial, Irrigation, Commercial, Domestic',
#        'Commercial, Irrigation, Domestic, Stock',
#        'Dewatering, Commercial',
#        'Commercial, Irrigation, Domestic, Industrial',
#        'Commercial, Domestic, Industrial, Stock',
#        'Dewatering, Industrial', 'Irrigation, Domestic, Test',
#        'Remediation, Industrial', 'Remediation, Irrigation, Industrial',
#        'Stock, Commercial, Domestic',
#        'Utility (Water Co), Domestic, Municipal Uses, Industrial',
#        'No Water Use, Remediation',
#        'Municipal Uses, Commercial, Domestic',
#        'Irrigation, Commercial, Stock',
#        'Utility (Water Co), Irrigation, Commercial, Domestic',
#        'Domestic, Stock, Utility (Water Co)',
#        'Municipal Uses, Remediation',
#        'Domestic, Irrigation, Stock, Irrigation, Stock',
#        'Mining, Irrigation, Industrial, Stock',
#        'Commercial, Industrial, Stock',
#        'Stock, Irrigation, Commercial, Domestic',
#        'Reserved, No Water Use',
#        'Other - Mineral Explore, Stock, No Use Code On Noi, Industrial',
#        'Domestic, Recreation, Industrial',
#        'Domestic, Industrial, Recreation',
#        'Mining, Irrigation, Domestic, Industrial, Stock',
#        'Industrial, Mining, Domestic',
#        'Other - Mineral Explore, Industrial',
#        'Industrial, Domestic, Commercial', 'Subdivision, Domestic',
#        'Commercial, Domestic, Industrial',
#        'Municipal Uses, Recovery, Test', 'Irrigation, Unknown',
#        'Commercial, Irrigation, Utility (Water Co), Domestic, Stock',
#        'Drainage, No Use Code On Noi', 'Stock, Industrial, Domestic',
#        'Drainage, Dewatering', 'Irrigation, Drainage, Domestic',
#        'No Use Code On Noi, Industrial',
#        'Industrial, Utility (Water Co), Other - Production',
#        'Domestic, Municipal Uses, Irrigation', 'Recreation, Commercial',
#        'Drainage, Irrigation', 'Commercial, Reserved',
#        'Stock, Mining, Domestic, No Use Code On Noi',
#        'Monitoring, Remediation',
#        'Municipal Uses, Utility (Water Co), Industrial',
#        'Recreation, Municipal Uses, Monitoring, Recovery',
#        'Recreation, Municipal Uses, Recovery',
#        'Commercial, Recreation, Domestic',
#        'Domestic, Industrial, Industrial',
#        'Domestic, Utility (Water Co), Stock',
#        'Industrial, Mining, Monitoring', 'Industrial, Monitoring, Mining',
#        'Commercial, Industrial, Other - Production, Irrigation',
#        'Commercial, Irrigation, Monitoring',
#        'Commercial, Irrigation, Test', 'Irrigation, Mining, Domestic',
#        'No Use Code On Noi, Stock', 'Drainage, Reserved',
#        'Mining, Industrial, Utility (Water Co)',
#        'No Water Use, Other - Mineral Explore', 'No Water Use, Unknown',
#        'Domestic, Commercial, Recreation', 'Monitoring, Unknown',
#        'Drainage, Mining, Other - Production',
#        'Remediation, No Water Use', 'Monitoring, Commercial',
#        'Municipal Uses, Monitoring, Recovery',
#        'Subdivision, Domestic, Recovery',
#        'Utility (Water Co), Commercial, Domestic',
#        'Domestic, Irrigation, Irrigation',
#        'Domestic, Municipal Uses, No Water Use',
#        'Municipal Uses, Domestic, Monitoring',
#        'Other - Production, Irrigation',
#        'Other - Mineral Explore, Commercial, Recovery',
#        'Other - Mineral Explore, Commercial',
#        'Irrigation, Recreation, Commercial', 'Drainage, Monitoring',
#        'Test, Municipal Uses, Municipal Uses',
#        'Irrigation, Municipal Uses, Industrial, Utility (Water Co), Recovery',
#        'Subdivision, Test, Recovery', 'Drainage, Mining, Industrial',
#        'Irrigation, Domestic, Municipal Uses, Test, Recovery',
#        'Other - Production, Commercial', 'Subdivision, Industrial',
#        'Industrial, Test, Utility (Water Co)', 'Mining, Test',
#        'Irrigation, Industrial, Municipal Uses, Recovery',
#        'Irrigation, Domestic, Municipal Uses, Recreation',
#        'Drainage, Commercial', 'Other - Production, Industrial',
#        'Municipal Uses, Industrial, Reserved',
#        'Municipal Uses, Drainage, Industrial, Monitoring, Recovery',
#        'Monitoring, Municipal Uses, Recovery',
#        'Commercial, Domestic, Irrigation, Stock',
#        'Dewatering, No Water Use', 'Test, Municipal Uses, Irrigation',
#        'Industrial, Industrial, Municipal Uses'], dtype=object)

# %%
# in_Latitude
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([32.95186342, 33.78497696, 33.40586557, ..., 35.49350294,
#        32.54821538, 34.61574124])

# %%
# in_Longitude
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-111.81406538, -112.49814261, -112.53791578, ..., -113.59392918,
#        -114.62650306, -111.91439603])

# %%
#Update datatype of Priority Date to fit WaDE 2.0 structure
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'], errors = 'coerce')
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# array(['NaT'], dtype='datetime64[ns]')

# %%
# Fixing in_AllocationFlow_CFS datatype
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array(['', 0.44563279857397503, 0.5347593582887701, ...,
#        4.895276292335116, 0.6795900178253119, 51.24777183600713],
#       dtype=object)

# %%
# Fixing in_AllocationVolume_AF datatype
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array([''], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)
dfWaterSourceNativeID['linkKey'] = dfWaterSourceNativeID['in_WaterSourceName'].astype(str) + dfWaterSourceNativeID['in_WaterSourceTypeCV'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
WaterSourceNativeIDdict = pd.Series(dfWaterSourceNativeID.in_WaterSourceNativeID.values, index=dfWaterSourceNativeID.linkKey.astype(str)).to_dict()
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        colrowValue = str(A).strip() + str(B).strip()
        try:
            outList = WaterSourceNativeIDdict[colrowValue]
        except:
            outList = ''
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeID1'], dtype=object)

# %% [markdown]
# ## Review and Export

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229051 entries, 0 to 229050
# Data columns (total 66 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   WaDEUUID                                      229051 non-null  object
#  1   in_Geometry                                   229051 non-null  object
#  2   in_GNISFeatureNameCV                          229051 non-null  object
#  3   in_WaterQualityIndicatorCV                    229051 non-null  object
#  4   in_WaterSourceName                            229051 non-null  object
#  5   in_WaterSourceNativeID                        229051 non-null  object
#  6   in_WaterSourceTypeCV                          229051 non-null  object
#  7   in_RegulatoryOverlayUUIDs                     229051 non-null  object
#  8   in_WaterSourceUUID                            229051 non-null  object
#  9   in_CoordinateAccuracy                         229051 non-null  object
#  10  in_CoordinateMethodCV                         229051 non-null  object
#  11  in_County                                     229051 non-null  object
#  12  in_EPSGCodeCV                                 229051 non-null  int64
#  13  in_GNISCodeCV                                 229051 non-null  object
#  14  in_HUC12                                      229051 non-null  object
#  15  in_HUC8                                       229051 non-null  object
#  16  in_Latitude                                   229051 non-null  float64
#  17  in_Longitude                                  229051 non-null  float64
#  18  in_NHDNetworkStatusCV                         229051 non-null  object
#  19  in_NHDProductCV                               229051 non-null  object
#  20  in_PODorPOUSite                               229051 non-null  object
#  21  in_SiteName                                   229051 non-null  object
#  22  in_SiteNativeID                               229051 non-null  object
#  23  in_SitePoint                                  229051 non-null  object
#  24  in_SiteTypeCV                                 229051 non-null  object
#  25  in_StateCV                                    229051 non-null  object
#  26  in_USGSSiteID                                 229051 non-null  object
#  27  in_MethodUUID                                 229051 non-null  object
#  28  in_OrganizationUUID                           229051 non-null  object
#  29  in_SiteUUID                                   229051 non-null  object
#  30  in_VariableSpecificUUID                       229051 non-null  object
#  31  in_AllocationApplicationDate                  229051 non-null  object
#  32  in_AllocationAssociatedConsumptiveUseSiteIDs  229051 non-null  object
#  33  in_AllocationAssociatedWithdrawalSiteIDs      229051 non-null  object
#  34  in_AllocationBasisCV                          229051 non-null  object
#  35  in_AllocationChangeApplicationIndicator       229051 non-null  object
#  36  in_AllocationCommunityWaterSupplySystem       229051 non-null  object
#  37  in_AllocationCropDutyAmount                   229051 non-null  object
#  38  in_AllocationExpirationDate                   229051 non-null  object
#  39  in_AllocationFlow_CFS                         229051 non-null  object
#  40  in_AllocationLegalStatusCV                    229051 non-null  object
#  41  in_AllocationNativeID                         229051 non-null  object
#  42  in_AllocationOwner                            229051 non-null  object
#  43  in_AllocationPriorityDate                     0 non-null       datetime64[ns]
#  44  in_AllocationSDWISIdentifierCV                229051 non-null  object
#  45  in_AllocationTimeframeEnd                     229051 non-null  object
#  46  in_AllocationTimeframeStart                   229051 non-null  object
#  47  in_AllocationTypeCV                           229051 non-null  object
#  48  in_AllocationVolume_AF                        229051 non-null  object
#  49  in_BeneficialUseCategory                      229051 non-null  object
#  50  in_CommunityWaterSupplySystem                 229051 non-null  object
#  51  in_CropTypeCV                                 229051 non-null  object
#  52  in_CustomerTypeCV                             229051 non-null  object
#  53  in_DataPublicationDate                        229051 non-null  object
#  54  in_DataPublicationDOI                         229051 non-null  object
#  55  in_ExemptOfVolumeFlowPriority                 229051 non-null  int64
#  56  in_GeneratedPowerCapacityMW                   229051 non-null  object
#  57  in_IrrigatedAcreage                           229051 non-null  object
#  58  in_IrrigationMethodCV                         229051 non-null  object
#  59  in_LegacyAllocationIDs                        229051 non-null  object
#  60  in_OwnerClassificationCV                      229051 non-null  object
#  61  in_PopulationServed                           229051 non-null  object
#  62  in_PowerType                                  229051 non-null  object
#  63  in_PrimaryBeneficialUseCategory               229051 non-null  object
#  64  in_SDWISIdentifierCV                          229051 non-null  object
#  65  in_WaterAllocationNativeURL                   229051 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(61)
# memory usage: 115.3+ MB

# %%
outdf
# Out:
#          WaDEUUID in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0           azGW0
# 1           azGW1
# 2          azGW10
# 3         azGW100
# 4        azGW1000
# ...           ...         ...                  ...                        ...
# 229046  azGW99995
# 229047  azGW99996
# 229048  azGW99997
# 229049  azGW99998
# 229050  azGW99999
#
#        in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                        wadeID1          Groundwater
# 1                                        wadeID1          Groundwater
# 2                                        wadeID1          Groundwater
# 3                                        wadeID1          Groundwater
# 4                                        wadeID1          Groundwater
# ...                   ...                    ...                  ...
# 229046                                   wadeID1          Groundwater
# 229047                                   wadeID1          Groundwater
# 229048                                   wadeID1          Groundwater
# 229049                                   wadeID1          Groundwater
# 229050                                   wadeID1          Groundwater
#
#        in_RegulatoryOverlayUUIDs in_WaterSourceUUID in_CoordinateAccuracy  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                ...                   ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#        in_CoordinateMethodCV in_County  in_EPSGCodeCV in_GNISCodeCV in_HUC12  \
# 0                                Pinal           4326
# 1                             Maricopa           4326
# 2                             Maricopa           4326
# 3                             Maricopa           4326
# 4                                 Pima           4326
# ...                      ...       ...            ...           ...      ...
# 229046                         Cochise           4326
# 229047                          La Paz           4326
# 229048                           Pinal           4326
# 229049                            Yuma           4326
# 229050                         Yavapai           4326
#
#        in_HUC8  in_Latitude  in_Longitude in_NHDNetworkStatusCV  \
# 0                  32.95186    -111.81407
# 1                  33.78498    -112.49814
# 2                  33.40587    -112.53792
# 3                  33.87987    -112.09030
# 4                  31.89865    -111.03417
# ...        ...          ...           ...                   ...
# 229046             31.90773    -109.91406
# 229047             33.63776    -114.11419
# 229048             32.65012    -111.10336
# 229049             32.54822    -114.62650
# 229050             34.61574    -111.91440
#
#        in_NHDProductCV in_PODorPOUSite in_SiteName  in_SiteNativeID  \
# 0                                  POD              PODD05005035ABA
# 1                                  POD              PODB05002008CCB
# 2                                  POD              PODB01003026BBB
# 3                                  POD              PODA06003007ACC
# 4                                  POD              PODD18013005ABA
# ...                ...             ...         ...              ...
# 229046                             POD              PODD17024033CCB
# 229047                             POD              PODB03018004AAA
# 229048                             POD              PODD09012016ADD
# 229049                             POD              PODC10023021BDB
# 229050                             POD              PODA14004010CDD
#
#        in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID in_MethodUUID  \
# 0                            Well         AZ                     AZwr_M1
# 1                            Well         AZ                     AZwr_M1
# 2                            Well         AZ                     AZwr_M1
# 3                            Well         AZ                     AZwr_M1
# 4                            Well         AZ                     AZwr_M1
# ...             ...           ...        ...           ...           ...
# 229046                       Well         AZ                     AZwr_M1
# 229047                       Well         AZ                     AZwr_M1
# 229048                       Well         AZ                     AZwr_M1
# 229049                       Well         AZ                     AZwr_M1
# 229050                       Well         AZ                     AZwr_M1
#
#        in_OrganizationUUID in_SiteUUID in_VariableSpecificUUID  \
# 0                  AZwr_O1                             AZwr_V1
# 1                  AZwr_O1                             AZwr_V1
# 2                  AZwr_O1                             AZwr_V1
# 3                  AZwr_O1                             AZwr_V1
# 4                  AZwr_O1                             AZwr_V1
# ...                    ...         ...                     ...
# 229046             AZwr_O1                             AZwr_V1
# 229047             AZwr_O1                             AZwr_V1
# 229048             AZwr_O1                             AZwr_V1
# 229049             AZwr_O1                             AZwr_V1
# 229050             AZwr_O1                             AZwr_V1
#
#        in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#        in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                             ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#        in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...                  ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#        in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#        in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                         ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#        in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1                                                0.44563
# 2
# 3
# 4                                                0.53476
# ...                            ...                   ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#        in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                                                 60000
# 1                                                 60001
# 2                                                 84580
# 3                                                 84955
# 4                                                 86084
# ...                           ...                   ...
# 229046                                           568422
# 229047                                           568423
# 229048                                           568424
# 229049                                           568425
# 229050                                           568426
#
#                             in_AllocationOwner in_AllocationPriorityDate  \
# 0       Arizona Sonoran Copper Company Usa Inc                       NaT
# 1             Route 14 Investment Partners Llc                       NaT
# 2                             H  R Henry Farms                       NaT
# 3                                Gedrge Laurel                       NaT
# 4                              Anamax Minig Co                       NaT
# ...                                        ...                       ...
# 229046                  James R  Linda S Blake                       NaT
# 229047                        Delford D Hyslip                       NaT
# 229048                             P L 183 Llc                       NaT
# 229049                                  Agtech                       NaT
# 229050                  All Star Gas Inc Of Az                       NaT
#
#        in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0                                                         12/31
# 1                                                         12/31
# 2                                                         12/31
# 3                                                         12/31
# 4                                                         12/31
# ...                               ...                       ...
# 229046                                                    12/31
# 229047                                                    12/31
# 229048                                                    12/31
# 229049                                                    12/31
# 229050                                                    12/31
#
#        in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0                            01/01
# 1                            01/01
# 2                            01/01
# 3                            01/01
# 4                            01/01
# ...                            ...                 ...                    ...
# 229046                       01/01
# 229047                       01/01
# 229048                       01/01
# 229049                       01/01
# 229050                       01/01
#
#        in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0                    Dewatering
# 1                    Industrial
# 2                    Irrigation
# 3                      Domestic
# 4                      Drainage
# ...                         ...                           ...           ...
# 229046                 Domestic
# 229047                 Domestic
# 229048                 Domestic
# 229049               Irrigation
# 229050               Commercial
#
#        in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                    ...                   ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#         in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                   1
# 1                                   1
# 2                                   1
# 3                                   1
# 4                                   1
# ...                               ...                         ...
# 229046                              1
# 229047                              1
# 229048                              1
# 229049                              1
# 229050                              1
#
#        in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...                   ...                    ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#        in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                 ...          ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#        in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                ...                  ...
# 229046
# 229047
# 229048
# 229049
# 229050
#
#                               in_WaterAllocationNativeURL
# 0       https://app.azwater.gov/WellRegistry/Detail.as...
# 1       https://app.azwater.gov/WellRegistry/Detail.as...
# 2       https://app.azwater.gov/WellRegistry/Detail.as...
# 3       https://app.azwater.gov/WellRegistry/Detail.as...
# 4       https://app.azwater.gov/WellRegistry/Detail.as...
# ...                                                   ...
# 229046  https://app.azwater.gov/WellRegistry/Detail.as...
# 229047  https://app.azwater.gov/WellRegistry/Detail.as...
# 229048  https://app.azwater.gov/WellRegistry/Detail.as...
# 229049  https://app.azwater.gov/WellRegistry/Detail.as...
# 229050  https://app.azwater.gov/WellRegistry/Detail.as...
#
# [229051 rows x 66 columns]

# %%
# Export the output dataframe
outdf.to_csv('RawInputData/Pwr_azgwMain.zip', compression=dict(method='zip', archive_name='Pwr_azMain.csv'), index=False) # The output, save as a zip
#dfPoUshape.to_csv('P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
