# %% [markdown]
# # Pre-processing Montana Site Specific data for WaDEQA upload.
# - Date Updated: 09/13/2021
# - Purpose:  To pre-process the Montana ss data into one master file for simple DataFrame creation and extraction
#
# ### Goal
# - Create sites_input.csv, contains location and site information.
# - Create cleaned input_timeseries.csv with a native site ID field.

# %%
import os
import numpy as np
import pandas as pd
import requests
import json
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

#Working Directory and Input Files
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Montana/SiteSpecificAmounts/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ### DataFrame Creation

# %%
# Dataframe Creation - location data
inputFile1 = "MGS_locations.csv"
df_loc = pd.read_csv(inputFile1)
print(len(df_loc))
df_loc.head()
# Out:
# 174
#    OID_                        LocationID LocationCode  \
# 0     1  b947d0c2364e4948a8032baac8904bef     40A 1500
# 1     2  b85ca58a37784f2aa2fb33588dc4cfe9     40A 2000
# 2     3  f412dc9558214d9f82ca6dd0ebcc3970    40A 10000
# 3     4  61da4aa318334518843094d1f7d8fe0e     40A 3000
# 4     5  35143516212943bf8c60b01287ad82f0     40A 4080
#
#                         LocationName            LocationPath  \
# 0       NF Musselshell near Delphine  All Locations.DNRC SWP
# 1  NF Musselshell blw Bair Reservoir  All Locations.DNRC SWP
# 2                       Barber Canal  All Locations.DNRC SWP
# 3     NF Musselshell Diversion Canal  All Locations.DNRC SWP
# 4           Martinsdale Supply Canal  All Locations.DNRC SWP
#
#         LocationType  IsExternalLocation  Longitude  Latitude UtcOffset  \
# 0  Hydrology Station                   0  -110.5768   46.6094     -PT7H
# 1  Hydrology Station                   0  -110.5535   46.5747     -PT7H
# 2  Hydrology Station                   0  -109.4012   46.3379     -PT7H
# 3  Hydrology Station                   0  -110.4180   46.5359     -PT7H
# 4  Hydrology Station                   0  -110.3088   46.4540     -PT7H
#
#         LastModified ElevationUnits  Elevation  \
# 0  2/4/2021 15:20:51             ft   5380.533
# 1  2/4/2021 15:33:18             ft   5232.450
# 2  2/4/2021 15:34:28             ft   3877.729
# 3  2/4/2021 15:34:56             ft   4958.962
# 4  2/4/2021 15:36:09             ft   4802.065
#
#                                          Description  \
# 0         North Fork Musselshell River near Delphine
# 1  North Fork Musselshell River below Bair Reservoir
# 2  Deadman's Basin Outlet Canal-Barber Canal (Son...
# 3  North Fork Musselshell River Diversion Canal b...
# 4                 Martinsdale Supply Canal abv Drop
#
#                                                 Tags ExtendedAttributeValues  \
# 0  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 1  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 2  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 3  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 4  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
#
#   StatusDesc  ActiveFlag
# 0  Real-time           1
# 1  Real-time           1
# 2  Real-time           1
# 3  Real-time           1
# 4  Real-time           1

# %%
# Dataframe Creation - datasets data
inputFile2 = "MGS_datasets.csv"
df_dase = pd.read_csv(inputFile2)
print(len(df_dase))
df_dase.head()
# Out:
# 509
#    OID_                        SensorCode                          SensorID  \
# 0     1  Discharge.Daily Average@40A 1500  e069deacfba143b3ba052cc39714d44d
# 1     2      Discharge.discharge@40A 1500  d3310b1c958446fe99a69e8997d848d8
# 2     3            Stage.working@40A 1500  650125de347f4ff5b617d6dd995cd4e7
# 3     4  Discharge.Daily Average@40A 2000  71a11087f6ce4e25b753b429143e9b23
# 4     5      Discharge.discharge@40A 2000  0f1ce86e86f841ae91996afb7ced5ac7
#
#      SensorLabel Comment Description  isPublished  \
# 0  Daily Average     NaN         NaN            1
# 1      discharge     NaN         NaN            1
# 2        working     NaN         NaN            1
# 3  Daily Average     NaN         NaN            1
# 4      discharge     NaN         NaN            1
#
#                         LocationName LocationCode  \
# 0       NF Musselshell near Delphine     40A 1500
# 1       NF Musselshell near Delphine     40A 1500
# 2       NF Musselshell near Delphine     40A 1500
# 3  NF Musselshell blw Bair Reservoir     40A 2000
# 4  NF Musselshell blw Bair Reservoir     40A 2000
#
#                          LocationID  SubLocationCode    TimeSeriesType  \
# 0  b947d0c2364e4948a8032baac8904bef              NaN  ProcessorDerived
# 1  b947d0c2364e4948a8032baac8904bef              NaN  ProcessorDerived
# 2  b947d0c2364e4948a8032baac8904bef              NaN  ProcessorDerived
# 3  b85ca58a37784f2aa2fb33588dc4cfe9              NaN  ProcessorDerived
# 4  b85ca58a37784f2aa2fb33588dc4cfe9              NaN  ProcessorDerived
#
#   Parameter UnitOfMeasure UtcOffset ComputationMethod ComputationPeriod  \
# 0        QR        ft^3/s     -PT7H              Mean             Daily
# 1        QR        ft^3/s     -PT7H           Unknown           Unknown
# 2        HG            ft     -PT7H           Unknown           Unknown
# 3        QR        ft^3/s     -PT7H              Mean             Daily
# 4        QR        ft^3/s     -PT7H           Unknown           Unknown
#
#    LastModifiedTime ExtendedAttributeValues ParameterLabel
# 0  2/2/2021 6:24:02                      []      Discharge
# 1  2/2/2021 6:24:02                      []      Discharge
# 2  2/2/2021 6:24:02                      []          Stage
# 3  2/2/2021 6:24:02                      []      Discharge
# 4  2/2/2021 6:24:02                      []      Discharge

# %%
# Dataframe Creation - timeseries data
inputFile3 = "MGS_timeseries.csv"
df_ts = pd.read_csv(inputFile3)
print(len(df_ts))
df_ts.head()
# Out:
# 26459294
#    OID_                          SensorID            Timestamp  RecordedValue  \
# 0     1  e069deacfba143b3ba052cc39714d44d    1/30/1981 0:00:00            NaN
# 1     2  e069deacfba143b3ba052cc39714d44d   1/14/1982 12:00:00            NaN
# 2     3  e069deacfba143b3ba052cc39714d44d    1/15/1983 0:00:00            NaN
# 3     4  e069deacfba143b3ba052cc39714d44d   12/31/1983 0:00:00            NaN
# 4     5  e069deacfba143b3ba052cc39714d44d  12/29/1984 12:00:00            NaN
#
#    GradeCode GradeName Method  ApprovalLevel ApprovalName
# 0        NaN       NaN    NaN            NaN          NaN
# 1        NaN       NaN    NaN            NaN          NaN
# 2        NaN       NaN    NaN            NaN          NaN
# 3        NaN       NaN    NaN            NaN          NaN
# 4        NaN       NaN    NaN            NaN          NaN

# %% [markdown]
# ### Location & Site Information

# %%
# Only working with ParameterLabel = Discharge, ComputationMethod = Mean & ComputationPeriod = Daily values for now.
df_dasetemp = df_dase[(df_dase['ParameterLabel'] == 'Discharge') & 
                      (df_dase['ComputationMethod'] == 'Mean') &
                      (df_dase['ComputationPeriod'] == 'Daily')]
print(len(df_dasetemp))
df_dasetemp.head()
# Out:
# 120
#     OID_                         SensorCode                          SensorID  \
# 0      1   Discharge.Daily Average@40A 1500  e069deacfba143b3ba052cc39714d44d
# 3      4   Discharge.Daily Average@40A 2000  71a11087f6ce4e25b753b429143e9b23
# 7      8  Discharge.Daily Average@40A 10000  53271ee869f147a4b2e1d4bf6d8c5f30
# 10    11   Discharge.Daily Average@40A 3000  2db3dc36ee104d15825a70e189b1a972
# 13    14   Discharge.Daily Average@40A 4080  2a35ab6f412e42eca0ee527848845c04
#
#       SensorLabel Comment Description  isPublished  \
# 0   Daily Average     NaN         NaN            1
# 3   Daily Average     NaN         NaN            1
# 7   Daily Average     NaN         NaN            1
# 10  Daily Average     NaN         NaN            1
# 13  Daily Average     NaN         NaN            1
#
#                          LocationName LocationCode  \
# 0        NF Musselshell near Delphine     40A 1500
# 3   NF Musselshell blw Bair Reservoir     40A 2000
# 7                        Barber Canal    40A 10000
# 10     NF Musselshell Diversion Canal     40A 3000
# 13           Martinsdale Supply Canal     40A 4080
#
#                           LocationID  SubLocationCode    TimeSeriesType  \
# 0   b947d0c2364e4948a8032baac8904bef              NaN  ProcessorDerived
# 3   b85ca58a37784f2aa2fb33588dc4cfe9              NaN  ProcessorDerived
# 7   f412dc9558214d9f82ca6dd0ebcc3970              NaN  ProcessorDerived
# 10  61da4aa318334518843094d1f7d8fe0e              NaN  ProcessorDerived
# 13  35143516212943bf8c60b01287ad82f0              NaN  ProcessorDerived
#
#    Parameter UnitOfMeasure UtcOffset ComputationMethod ComputationPeriod  \
# 0         QR        ft^3/s     -PT7H              Mean             Daily
# 3         QR        ft^3/s     -PT7H              Mean             Daily
# 7         QR        ft^3/s     -PT7H              Mean             Daily
# 10        QR        ft^3/s     -PT7H              Mean             Daily
# 13        QR        ft^3/s     -PT7H              Mean             Daily
#
#     LastModifiedTime ExtendedAttributeValues ParameterLabel
# 0   2/2/2021 6:24:02                      []      Discharge
# 3   2/2/2021 6:24:02                      []      Discharge
# 7   2/2/2021 6:24:02                      []      Discharge
# 10  2/2/2021 6:24:02                      []      Discharge
# 13  2/2/2021 6:24:02                      []      Discharge

# %%
# trim down dataset to those fields that are needed.
df_dasetemp_sub = df_dasetemp[['LocationCode', 'SensorID', 'SensorLabel', 'TimeSeriesType', 'Parameter', 'UnitOfMeasure', 'ComputationMethod', 'ComputationPeriod', 'LastModifiedTime', 'ParameterLabel']]
print(len(df_dasetemp_sub))
df_dasetemp_sub.head()
# Out:
# 120
#    LocationCode                          SensorID    SensorLabel  \
# 0      40A 1500  e069deacfba143b3ba052cc39714d44d  Daily Average
# 3      40A 2000  71a11087f6ce4e25b753b429143e9b23  Daily Average
# 7     40A 10000  53271ee869f147a4b2e1d4bf6d8c5f30  Daily Average
# 10     40A 3000  2db3dc36ee104d15825a70e189b1a972  Daily Average
# 13     40A 4080  2a35ab6f412e42eca0ee527848845c04  Daily Average
#
#       TimeSeriesType Parameter UnitOfMeasure ComputationMethod  \
# 0   ProcessorDerived        QR        ft^3/s              Mean
# 3   ProcessorDerived        QR        ft^3/s              Mean
# 7   ProcessorDerived        QR        ft^3/s              Mean
# 10  ProcessorDerived        QR        ft^3/s              Mean
# 13  ProcessorDerived        QR        ft^3/s              Mean
#
#    ComputationPeriod  LastModifiedTime ParameterLabel
# 0              Daily  2/2/2021 6:24:02      Discharge
# 3              Daily  2/2/2021 6:24:02      Discharge
# 7              Daily  2/2/2021 6:24:02      Discharge
# 10             Daily  2/2/2021 6:24:02      Discharge
# 13             Daily  2/2/2021 6:24:02      Discharge

# %%
# merge location info with trimmed down dataset data
df_loctemp=pd.DataFrame()
df_loctemp = pd.merge(df_loc, df_dasetemp_sub, on='LocationCode', how='left')
print(len(df_loctemp))
df_loctemp.head()
# Out:
# 174
#    OID_                        LocationID LocationCode  \
# 0     1  b947d0c2364e4948a8032baac8904bef     40A 1500
# 1     2  b85ca58a37784f2aa2fb33588dc4cfe9     40A 2000
# 2     3  f412dc9558214d9f82ca6dd0ebcc3970    40A 10000
# 3     4  61da4aa318334518843094d1f7d8fe0e     40A 3000
# 4     5  35143516212943bf8c60b01287ad82f0     40A 4080
#
#                         LocationName            LocationPath  \
# 0       NF Musselshell near Delphine  All Locations.DNRC SWP
# 1  NF Musselshell blw Bair Reservoir  All Locations.DNRC SWP
# 2                       Barber Canal  All Locations.DNRC SWP
# 3     NF Musselshell Diversion Canal  All Locations.DNRC SWP
# 4           Martinsdale Supply Canal  All Locations.DNRC SWP
#
#         LocationType  IsExternalLocation  Longitude  Latitude UtcOffset  \
# 0  Hydrology Station                   0  -110.5768   46.6094     -PT7H
# 1  Hydrology Station                   0  -110.5535   46.5747     -PT7H
# 2  Hydrology Station                   0  -109.4012   46.3379     -PT7H
# 3  Hydrology Station                   0  -110.4180   46.5359     -PT7H
# 4  Hydrology Station                   0  -110.3088   46.4540     -PT7H
#
#         LastModified ElevationUnits  Elevation  \
# 0  2/4/2021 15:20:51             ft   5380.533
# 1  2/4/2021 15:33:18             ft   5232.450
# 2  2/4/2021 15:34:28             ft   3877.729
# 3  2/4/2021 15:34:56             ft   4958.962
# 4  2/4/2021 15:36:09             ft   4802.065
#
#                                          Description  \
# 0         North Fork Musselshell River near Delphine
# 1  North Fork Musselshell River below Bair Reservoir
# 2  Deadman's Basin Outlet Canal-Barber Canal (Son...
# 3  North Fork Musselshell River Diversion Canal b...
# 4                 Martinsdale Supply Canal abv Drop
#
#                                                 Tags ExtendedAttributeValues  \
# 0  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 1  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 2  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 3  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 4  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
#
#   StatusDesc  ActiveFlag                          SensorID    SensorLabel  \
# 0  Real-time           1  e069deacfba143b3ba052cc39714d44d  Daily Average
# 1  Real-time           1  71a11087f6ce4e25b753b429143e9b23  Daily Average
# 2  Real-time           1  53271ee869f147a4b2e1d4bf6d8c5f30  Daily Average
# 3  Real-time           1  2db3dc36ee104d15825a70e189b1a972  Daily Average
# 4  Real-time           1  2a35ab6f412e42eca0ee527848845c04  Daily Average
#
#      TimeSeriesType Parameter UnitOfMeasure ComputationMethod  \
# 0  ProcessorDerived        QR        ft^3/s              Mean
# 1  ProcessorDerived        QR        ft^3/s              Mean
# 2  ProcessorDerived        QR        ft^3/s              Mean
# 3  ProcessorDerived        QR        ft^3/s              Mean
#  'c713ac6b9dae4e75a9f05da29122c2a8',
#  'c0925856c3c74440afd2045c7f0dbc7c',
#  '433a7dfbbc5148a7816000558c97c559',
#  'd93fb860cc734dbbbf7a2d0239a88a4b',
#  '57e3055d2b784daeb394306dfb1c2b45',
#  '9cdc2d9f098549df935b652435baceeb',
#  '04cbb5334d674e88aeb382d677270a0a',
#  '5e2094ae768a427787d67755011675ca',
#  '8ef6c28acce64c778275b662ccdd1d84',
#  '3c0e422e47614e0aa8c1b70d060b1e63']

# %%
# use only those timeseries rows who's SensorID is in the list
df_tstemp = df_ts
df_tstemp = df_tstemp[df_tstemp['SensorID'].isin(SensorIDList)].drop_duplicates().reset_index(drop=True)
print(len(df_tstemp))
df_tstemp.head()
# Out:
# 278469
#    OID_                          SensorID            Timestamp  RecordedValue  \
# 0     1  e069deacfba143b3ba052cc39714d44d    1/30/1981 0:00:00            NaN
# 1     2  e069deacfba143b3ba052cc39714d44d   1/14/1982 12:00:00            NaN
# 2     3  e069deacfba143b3ba052cc39714d44d    1/15/1983 0:00:00            NaN
# 3     4  e069deacfba143b3ba052cc39714d44d   12/31/1983 0:00:00            NaN
# 4     5  e069deacfba143b3ba052cc39714d44d  12/29/1984 12:00:00            NaN
#
#    GradeCode GradeName Method  ApprovalLevel ApprovalName
# 0        NaN       NaN    NaN            NaN          NaN
# 1        NaN       NaN    NaN            NaN          NaN
# 2        NaN       NaN    NaN            NaN          NaN
# 3        NaN       NaN    NaN            NaN          NaN
# 4        NaN       NaN    NaN            NaN          NaN

# %%
# extract date and time values from Timestamp field
# -------------------------------------------------

#convert from string to datetime
df_tstemp['Timestamp'] = pd.to_datetime(df_tstemp['Timestamp']) 

# extract date, year and time, create three new fields
df_tstemp['Timestamp_Date'] = df_tstemp['Timestamp'].dt.date
df_tstemp['Timestamp_Date'] = pd.to_datetime(df_tstemp['Timestamp_Date'], errors = 'coerce')
df_tstemp['Timestamp_Date'] = pd.to_datetime(df_tstemp['Timestamp_Date'].dt.strftime('%m/%d/%Y'))

# Year
df_tstemp['Timestamp_Year'] = pd.DatetimeIndex(df_tstemp['Timestamp_Date']).year

# time
df_tstemp['Timestamp_Time'] = df_tstemp['Timestamp'].dt.time

print(len(df_tstemp))
df_tstemp.head()
# Out:
# 278469
#    OID_                          SensorID           Timestamp  RecordedValue  \
# 0     1  e069deacfba143b3ba052cc39714d44d 1981-01-30 00:00:00            NaN
# 1     2  e069deacfba143b3ba052cc39714d44d 1982-01-14 12:00:00            NaN
# 2     3  e069deacfba143b3ba052cc39714d44d 1983-01-15 00:00:00            NaN
# 3     4  e069deacfba143b3ba052cc39714d44d 1983-12-31 00:00:00            NaN
# 4     5  e069deacfba143b3ba052cc39714d44d 1984-12-29 12:00:00            NaN
#
#    GradeCode GradeName Method  ApprovalLevel ApprovalName Timestamp_Date  \
# 0        NaN       NaN    NaN            NaN          NaN     1981-01-30
# 1        NaN       NaN    NaN            NaN          NaN     1982-01-14
# 2        NaN       NaN    NaN            NaN          NaN     1983-01-15
# 3        NaN       NaN    NaN            NaN          NaN     1983-12-31
# 4        NaN       NaN    NaN            NaN          NaN     1984-12-29
#
#    Timestamp_Year Timestamp_Time
# 0            1981       00:00:00
# 1            1982       12:00:00
# 2            1983       00:00:00
# 3            1983       00:00:00
# 4            1984       12:00:00

# %%
# remove unused fields
# -------------------------------------------------
df_tstemp = df_tstemp.drop(['OID_', 'GradeCode', 'GradeName', 'ApprovalLevel'], axis=1)
df_tstemp = df_tstemp.drop_duplicates().reset_index(drop=True)
df_tstemp
# Out:
#                                 SensorID           Timestamp  RecordedValue  \
# 0       e069deacfba143b3ba052cc39714d44d 1981-01-30 00:00:00            NaN
# 1       e069deacfba143b3ba052cc39714d44d 1982-01-14 12:00:00            NaN
# 2       e069deacfba143b3ba052cc39714d44d 1983-01-15 00:00:00            NaN
# 3       e069deacfba143b3ba052cc39714d44d 1983-12-31 00:00:00            NaN
# 4       e069deacfba143b3ba052cc39714d44d 1984-12-29 12:00:00            NaN
# ...                                  ...                 ...            ...
# 277417  f309b329bf724707b6ef7730d612604a 2021-09-07 00:00:00      44.511918
# 277418  a7fa1a92160140ed9d141a2343a48719 2021-09-06 00:00:00      50.152872
# 277419  a7fa1a92160140ed9d141a2343a48719 2021-09-07 00:00:00      48.973710
# 277420  c0925856c3c74440afd2045c7f0dbc7c 2021-09-06 00:00:00     150.129749
# 277421  c0925856c3c74440afd2045c7f0dbc7c 2021-09-07 00:00:00     128.849878
#
#              Method ApprovalName Timestamp_Date  Timestamp_Year Timestamp_Time
# 0               NaN          NaN     1981-01-30            1981       00:00:00
# 1               NaN          NaN     1982-01-14            1982       12:00:00
# 2               NaN          NaN     1983-01-15            1983       00:00:00
# 3               NaN          NaN     1983-12-31            1983       00:00:00
# 4               NaN          NaN     1984-12-29            1984       12:00:00
# ...             ...          ...            ...             ...            ...
# 277417  DefaultNone  Provisional     2021-09-07            2021       00:00:00
# 277418  DefaultNone  Provisional     2021-09-06            2021       00:00:00
# 277419  DefaultNone  Provisional     2021-09-07            2021       00:00:00
# 277420  DefaultNone  Provisional     2021-09-06            2021       00:00:00
# 277421  DefaultNone  Provisional     2021-09-07            2021       00:00:00
#
# [277422 rows x 8 columns]

# %% [markdown]
# ### Export out csv

# %%
#Merge ts with database
dfsupertemp = pd.merge(df_tstemp, df_loctemp, on='SensorID', how='left')

print(len(dfsupertemp))
dfsupertemp.head()
# Out:
# 277422
#                            SensorID           Timestamp  RecordedValue Method  \
# 0  e069deacfba143b3ba052cc39714d44d 1981-01-30 00:00:00            NaN    NaN
# 1  e069deacfba143b3ba052cc39714d44d 1982-01-14 12:00:00            NaN    NaN
# 2  e069deacfba143b3ba052cc39714d44d 1983-01-15 00:00:00            NaN    NaN
# 3  e069deacfba143b3ba052cc39714d44d 1983-12-31 00:00:00            NaN    NaN
# 4  e069deacfba143b3ba052cc39714d44d 1984-12-29 12:00:00            NaN    NaN
#
#   ApprovalName Timestamp_Date  Timestamp_Year Timestamp_Time  OID_  \
# 0          NaN     1981-01-30            1981       00:00:00   1.0
# 1          NaN     1982-01-14            1982       12:00:00   1.0
# 2          NaN     1983-01-15            1983       00:00:00   1.0
# 3          NaN     1983-12-31            1983       00:00:00   1.0
# 4          NaN     1984-12-29            1984       12:00:00   1.0
#
#                          LocationID LocationCode  \
# 0  b947d0c2364e4948a8032baac8904bef     40A 1500
# 1  b947d0c2364e4948a8032baac8904bef     40A 1500
# 2  b947d0c2364e4948a8032baac8904bef     40A 1500
# 3  b947d0c2364e4948a8032baac8904bef     40A 1500
# 4  b947d0c2364e4948a8032baac8904bef     40A 1500
#
#                    LocationName            LocationPath       LocationType  \
# 0  NF Musselshell near Delphine  All Locations.DNRC SWP  Hydrology Station
# 1  NF Musselshell near Delphine  All Locations.DNRC SWP  Hydrology Station
# 2  NF Musselshell near Delphine  All Locations.DNRC SWP  Hydrology Station
# 3  NF Musselshell near Delphine  All Locations.DNRC SWP  Hydrology Station
# 4  NF Musselshell near Delphine  All Locations.DNRC SWP  Hydrology Station
#
#    IsExternalLocation  Longitude  Latitude UtcOffset       LastModified  \
# 0                 0.0  -110.5768   46.6094     -PT7H  2/4/2021 15:20:51
# 1                 0.0  -110.5768   46.6094     -PT7H  2/4/2021 15:20:51
# 2                 0.0  -110.5768   46.6094     -PT7H  2/4/2021 15:20:51
# 3                 0.0  -110.5768   46.6094     -PT7H  2/4/2021 15:20:51
# 4                 0.0  -110.5768   46.6094     -PT7H  2/4/2021 15:20:51
#
#   ElevationUnits  Elevation                                 Description  \
# 0             ft   5380.533  North Fork Musselshell River near Delphine
# 1             ft   5380.533  North Fork Musselshell River near Delphine
# 2             ft   5380.533  North Fork Musselshell River near Delphine
# 3             ft   5380.533  North Fork Musselshell River near Delphine
# 4             ft   5380.533  North Fork Musselshell River near Delphine
#
#                                                 Tags ExtendedAttributeValues  \
# 0  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 1  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 2  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 3  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 4  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
#
#   StatusDesc  ActiveFlag    SensorLabel    TimeSeriesType Parameter  \
# 0  Real-time         1.0  Daily Average  ProcessorDerived        QR
# 1  Real-time         1.0  Daily Average  ProcessorDerived        QR
# 2  Real-time         1.0  Daily Average  ProcessorDerived        QR
# 3  Real-time         1.0  Daily Average  ProcessorDerived        QR
# 4  Real-time         1.0  Daily Average  ProcessorDerived        QR
#
#   UnitOfMeasure ComputationMethod ComputationPeriod  LastModifiedTime  \
# 0        ft^3/s              Mean             Daily  2/2/2021 6:24:02
# 1        ft^3/s              Mean             Daily  2/2/2021 6:24:02
# 2        ft^3/s              Mean             Daily  2/2/2021 6:24:02
# 3        ft^3/s              Mean             Daily  2/2/2021 6:24:02
# 4        ft^3/s              Mean             Daily  2/2/2021 6:24:02
#
#   ParameterLabel
# 0      Discharge
# 1      Discharge
# 2      Discharge
# 3      Discharge
# 4      Discharge

# %%
# Export out to CSV.
# df_tstemp.to_csv('P_mnSSTimeSeries.csv', index=False) # The output.
# df_loctemp.to_csv('P_mnSSSiteInfo.csv', index=False) # The site information.
dfsupertemp.to_csv('P_mtSSMaster.csv', index=False) # The output.

# %%
dfsupertemp['UnitOfMeasure'].value_counts()
# Out:
# ft^3/s    276322
# Name: UnitOfMeasure, dtype: int64
