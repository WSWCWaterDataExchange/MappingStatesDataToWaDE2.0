# %% [markdown]
# # Pre-processing Montana Site Specific data for WaDEQA upload.
# - Date Updated: 09/13/2021
# - Purpose:  To pre-process the Montana ss data into one master file for simple DataFrame creation and extraction
#
# ### Goal
# - Create sites_input.csv, contains location and site information.
# - Create cleaned input_timeseries.csv with a native site ID field.

# %%
import os
import numpy as np
import pandas as pd
import requests
import json
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

#Working Directory and Input Files
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Montana/SiteSpecificAmounts/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ### DataFrame Creation

# %%
# Dataframe Creation - location data
inputFile1 = "MGS_locations.csv"
df_loc = pd.read_csv(inputFile1)
print(len(df_loc))
df_loc.head(1)
# Out:
# 174
#    OID_                        LocationID LocationCode  \
# 0     1  b947d0c2364e4948a8032baac8904bef     40A 1500
#
#                    LocationName            LocationPath       LocationType  \
# 0  NF Musselshell near Delphine  All Locations.DNRC SWP  Hydrology Station
#
#    IsExternalLocation  Longitude  Latitude UtcOffset       LastModified  \
# 0                   0  -110.5768   46.6094     -PT7H  2/4/2021 15:20:51
#
#   ElevationUnits  Elevation                                 Description  \
# 0             ft   5380.533  North Fork Musselshell River near Delphine
#
#                                                 Tags ExtendedAttributeValues  \
# 0  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
#
#   StatusDesc  ActiveFlag
# 0  Real-time           1

# %%
# Dataframe Creation - datasets data
inputFile2 = "MGS_datasets.csv"
df_dase = pd.read_csv(inputFile2)
print(len(df_dase))
df_dase.head(1)
# Out:
# 509
#    OID_                        SensorCode                          SensorID  \
# 0     1  Discharge.Daily Average@40A 1500  e069deacfba143b3ba052cc39714d44d
#
#      SensorLabel Comment Description  isPublished  \
# 0  Daily Average     NaN         NaN            1
#
#                    LocationName LocationCode  \
# 0  NF Musselshell near Delphine     40A 1500
#
#                          LocationID  SubLocationCode    TimeSeriesType  \
# 0  b947d0c2364e4948a8032baac8904bef              NaN  ProcessorDerived
#
#   Parameter UnitOfMeasure UtcOffset ComputationMethod ComputationPeriod  \
# 0        QR        ft^3/s    #NAME?              Mean             Daily
#
#   LastModifiedTime ExtendedAttributeValues ParameterLabel
# 0    2/2/2021 6:24                      []      Discharge

# %%
# Dataframe Creation - timeseries data
inputFile3 = "MGS_timeseries.csv"
df_ts = pd.read_csv(inputFile3)
print(len(df_ts))
df_ts.head(1)
# Out:
# 26459294
#    OID_                          SensorID          Timestamp  RecordedValue  \
# 0     1  e069deacfba143b3ba052cc39714d44d  1/30/1981 0:00:00            NaN
#
#    GradeCode GradeName Method  ApprovalLevel ApprovalName
# 0        NaN       NaN    NaN            NaN          NaN

# %% [markdown]
# ### Location & Site Information

# %%
# Only working with ParameterLabel = Discharge, ComputationMethod = Mean & ComputationPeriod = Daily values for now.
df_dasetemp = df_dase[(df_dase['SensorLabel'] == 'discharge') |
                      (df_dase['SensorLabel'] == 'stage')]
print(len(df_dasetemp))
df_dasetemp.head()
# Out:
# 131
#     OID_                     SensorCode                          SensorID  \
# 1      2   Discharge.discharge@40A 1500  d3310b1c958446fe99a69e8997d848d8
# 4      5   Discharge.discharge@40A 2000  0f1ce86e86f841ae91996afb7ced5ac7
# 5      6           Stage.stage@40A 2000  94664635d58f42c4afad73ab0094a396
# 8      9  Discharge.discharge@40A 10000  8efc886fb5364b46998d82168cb09504
# 11    12   Discharge.discharge@40A 3000  ad9340452c964165abe86957f46a7092
#
#    SensorLabel Comment Description  isPublished  \
# 1    discharge     NaN         NaN            1
# 4    discharge     NaN         NaN            1
# 5        stage     NaN         NaN            1
# 8    discharge     NaN         NaN            1
# 11   discharge     NaN         NaN            1
#
#                          LocationName LocationCode  \
# 1        NF Musselshell near Delphine     40A 1500
# 4   NF Musselshell blw Bair Reservoir     40A 2000
# 5   NF Musselshell blw Bair Reservoir     40A 2000
# 8                        Barber Canal    40A 10000
# 11     NF Musselshell Diversion Canal     40A 3000
#
#                           LocationID  SubLocationCode    TimeSeriesType  \
# 1   b947d0c2364e4948a8032baac8904bef              NaN  ProcessorDerived
# 4   b85ca58a37784f2aa2fb33588dc4cfe9              NaN  ProcessorDerived
# 5   b85ca58a37784f2aa2fb33588dc4cfe9              NaN    ProcessorBasic
# 8   f412dc9558214d9f82ca6dd0ebcc3970              NaN  ProcessorDerived
# 11  61da4aa318334518843094d1f7d8fe0e              NaN  ProcessorDerived
#
#    Parameter UnitOfMeasure UtcOffset ComputationMethod ComputationPeriod  \
# 1         QR        ft^3/s    #NAME?           Unknown           Unknown
# 4         QR        ft^3/s    #NAME?           Unknown           Unknown
# 5         HG            ft    #NAME?           Unknown           Unknown
# 8         QR        ft^3/s    #NAME?           Unknown           Unknown
# 11        QR        ft^3/s    #NAME?           Unknown           Unknown
#
#    LastModifiedTime ExtendedAttributeValues ParameterLabel
# 1     2/2/2021 6:24                      []      Discharge
# 4     2/2/2021 6:24                      []      Discharge
# 5     2/2/2021 6:16                      []          Stage
# 8     2/2/2021 6:24                      []      Discharge
# 11    2/2/2021 6:24                      []      Discharge

# %%
# Create VariableSpecificCV

def createVariableSpecificCV(A):
    if A == 'discharge':
        outString = "Reservoirs and Gages - Daily - Discharge"
    if A == 'stage':
        outString = "Reservoirs and Gages - Daily - Stage"
    return outString


df_dasetemp['in_VariableSpecificCV'] = df_dasetemp.apply(lambda row: createVariableSpecificCV(row['SensorLabel']), axis=1)
# Out:
# <ipython-input-6-3e0f9fa33743>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dasetemp['in_VariableSpecificCV'] = df_dasetemp.apply(lambda row: createVariableSpecificCV(row['SensorLabel']), axis=1)

# %%
df_dasetemp['in_VariableSpecificCV'].nunique()
# Out:
# 2

# %%
# trim down dataset to those fields that are needed.
df_dasetemp_sub = df_dasetemp[['LocationCode', 'SensorID', 'SensorLabel', 'TimeSeriesType', 'Parameter', 'UnitOfMeasure', 'ComputationMethod', 'ComputationPeriod', 'LastModifiedTime', 'ParameterLabel', 'in_VariableSpecificCV']]
print(len(df_dasetemp_sub))
df_dasetemp_sub.head()
# Out:
# 131
#    LocationCode                          SensorID SensorLabel  \
# 1      40A 1500  d3310b1c958446fe99a69e8997d848d8   discharge
# 4      40A 2000  0f1ce86e86f841ae91996afb7ced5ac7   discharge
# 5      40A 2000  94664635d58f42c4afad73ab0094a396       stage
# 8     40A 10000  8efc886fb5364b46998d82168cb09504   discharge
# 11     40A 3000  ad9340452c964165abe86957f46a7092   discharge
#
#       TimeSeriesType Parameter UnitOfMeasure ComputationMethod  \
# 1   ProcessorDerived        QR        ft^3/s           Unknown
# 4   ProcessorDerived        QR        ft^3/s           Unknown
# 5     ProcessorBasic        HG            ft           Unknown
# 8   ProcessorDerived        QR        ft^3/s           Unknown
# 11  ProcessorDerived        QR        ft^3/s           Unknown
#
#    ComputationPeriod LastModifiedTime ParameterLabel  \
# 1            Unknown    2/2/2021 6:24      Discharge
# 4            Unknown    2/2/2021 6:24      Discharge
# 5            Unknown    2/2/2021 6:16          Stage
# 8            Unknown    2/2/2021 6:24      Discharge
# 11           Unknown    2/2/2021 6:24      Discharge
#
#                        in_VariableSpecificCV
# 1   Reservoirs and Gages - Daily - Discharge
# 4   Reservoirs and Gages - Daily - Discharge
# 5       Reservoirs and Gages - Daily - Stage
# 8   Reservoirs and Gages - Daily - Discharge
# 11  Reservoirs and Gages - Daily - Discharge

# %%
# merge location info with trimmed down dataset data
df_loctemp=pd.DataFrame()
df_loctemp = pd.merge(df_loc, df_dasetemp_sub, on='LocationCode', how='left')
print(len(df_loctemp))
df_loctemp.head()
# Out:
# 178
#    OID_                        LocationID LocationCode  \
# 0     1  b947d0c2364e4948a8032baac8904bef     40A 1500
# 1     2  b85ca58a37784f2aa2fb33588dc4cfe9     40A 2000
# 2     2  b85ca58a37784f2aa2fb33588dc4cfe9     40A 2000
# 3     3  f412dc9558214d9f82ca6dd0ebcc3970    40A 10000
# 4     4  61da4aa318334518843094d1f7d8fe0e     40A 3000
#
#                         LocationName            LocationPath  \
# 0       NF Musselshell near Delphine  All Locations.DNRC SWP
# 1  NF Musselshell blw Bair Reservoir  All Locations.DNRC SWP
# 2  NF Musselshell blw Bair Reservoir  All Locations.DNRC SWP
# 3                       Barber Canal  All Locations.DNRC SWP
# 4     NF Musselshell Diversion Canal  All Locations.DNRC SWP
#
#         LocationType  IsExternalLocation  Longitude  Latitude UtcOffset  \
# 0  Hydrology Station                   0  -110.5768   46.6094     -PT7H
# 1  Hydrology Station                   0  -110.5535   46.5747     -PT7H
# 2  Hydrology Station                   0  -110.5535   46.5747     -PT7H
# 3  Hydrology Station                   0  -109.4012   46.3379     -PT7H
# 4  Hydrology Station                   0  -110.4180   46.5359     -PT7H
#
#         LastModified ElevationUnits  Elevation  \
# 0  2/4/2021 15:20:51             ft   5380.533
# 1  2/4/2021 15:33:18             ft   5232.450
# 2  2/4/2021 15:33:18             ft   5232.450
# 3  2/4/2021 15:34:28             ft   3877.729
# 4  2/4/2021 15:34:56             ft   4958.962
#
#                                          Description  \
# 0         North Fork Musselshell River near Delphine
# 1  North Fork Musselshell River below Bair Reservoir
# 2  North Fork Musselshell River below Bair Reservoir
# 3  Deadman's Basin Outlet Canal-Barber Canal (Son...
# 4  North Fork Musselshell River Diversion Canal b...
#
#                                                 Tags ExtendedAttributeValues  \
# 0  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 1  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 2  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 3  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 4  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
#
#   StatusDesc  ActiveFlag                          SensorID SensorLabel  \
# 0  Real-time           1  d3310b1c958446fe99a69e8997d848d8   discharge
# 1  Real-time           1  0f1ce86e86f841ae91996afb7ced5ac7   discharge
# 2  Real-time           1  94664635d58f42c4afad73ab0094a396       stage
# 3  Real-time           1  8efc886fb5364b46998d82168cb09504   discharge
# 4  Real-time           1  ad9340452c964165abe86957f46a7092   discharge
#
#      TimeSeriesType Parameter UnitOfMeasure ComputationMethod  \
# 0  ProcessorDerived        QR        ft^3/s           Unknown
# 1  ProcessorDerived        QR        ft^3/s           Unknown
# 2    ProcessorBasic        HG            ft           Unknown
#  'fdc7c6c9a6074c6f9161192c3d27fdc1',
#  '20888159cd5e42268dfe4ab65ca382de',
#  '1662da412180418ea98e583965253d9a',
#  '9a92e0e3e8014d3e80c95aee4c2bb5e0',
#  'db654d70d25741b0909815a8d24744f2',
#  '54916a715a1040fbb0265235c50351cb',
#  '8b1f66b93a7940cea5fb815293419a82',
#  'd255f7a88f6a4c4a83f505c7752873a9',
#  'f0876657da68481d8c5fd665947a1061',
#  'b44f53a73d1d496ab882a36b4dbf9228',
#  'f8c99312e371434481cb0ff36ecd66d9',
#  'd9d72db4b1514e04924f7021eaf8589d',
#  '7c5e2b3ea77d4ef0ad3ace508de24152',
#  '6ff215f70a9a494d9978d6aeec36a009',
#  'a585edb7d40948febbfb1cba55475aa8',
#  '612ec6eb18af48c4920fcd549fa91bae',
#  '6990415da551431fa38ef66fa91fe5f8',
#  'd1bddfaf51db4dd2a7e7db5fbfacfcee',
#  '4e3f6333761e406e849b77fb783f52da',
#  'f301673a9f7743c8aceee9cb94af6637',
#  'd7ee9ede030e4aedb8d1ada7062b1c9e',
#  '887741d954bc4ca2a718e0735a4acc99']

# %%
# use only those timeseries rows who's SensorID is in the list
df_tstemp = df_ts
df_tstemp = df_tstemp[df_tstemp['SensorID'].isin(SensorIDList)].drop_duplicates().reset_index(drop=True)
print(len(df_tstemp))
df_tstemp.head()
# Out:
# 10645520
#      OID_                          SensorID           Timestamp  \
# 0  194407  94664635d58f42c4afad73ab0094a396  4/12/2006 12:00:00
# 1  194408  94664635d58f42c4afad73ab0094a396  4/13/2006 12:00:00
# 2  194409  94664635d58f42c4afad73ab0094a396  4/14/2006 12:00:00
# 3  194410  94664635d58f42c4afad73ab0094a396  4/15/2006 12:00:00
# 4  194411  94664635d58f42c4afad73ab0094a396  4/16/2006 12:00:00
#
#    RecordedValue  GradeCode GradeName Method  ApprovalLevel ApprovalName
# 0            NaN        NaN       NaN    NaN            NaN          NaN
# 1            NaN        NaN       NaN    NaN            NaN          NaN
# 2            NaN        NaN       NaN    NaN            NaN          NaN
# 3            NaN        NaN       NaN    NaN            NaN          NaN
# 4            NaN        NaN       NaN    NaN            NaN          NaN

# %%
# extract date and time values from Timestamp field
# -------------------------------------------------

#convert from string to datetime
df_tstemp['Timestamp'] = pd.to_datetime(df_tstemp['Timestamp']) 

# extract date, year and time, create three new fields
df_tstemp['Timestamp_Date'] = df_tstemp['Timestamp'].dt.date
df_tstemp['Timestamp_Date'] = pd.to_datetime(df_tstemp['Timestamp_Date'], errors = 'coerce')
df_tstemp['Timestamp_Date'] = pd.to_datetime(df_tstemp['Timestamp_Date'].dt.strftime('%m/%d/%Y'))

# Year
df_tstemp['Timestamp_Year'] = pd.DatetimeIndex(df_tstemp['Timestamp_Date']).year

# time
df_tstemp['Timestamp_Time'] = df_tstemp['Timestamp'].dt.time

print(len(df_tstemp))
df_tstemp.head()
# Out:
# 10645520
#      OID_                          SensorID           Timestamp  \
# 0  194407  94664635d58f42c4afad73ab0094a396 2006-04-12 12:00:00
# 1  194408  94664635d58f42c4afad73ab0094a396 2006-04-13 12:00:00
# 2  194409  94664635d58f42c4afad73ab0094a396 2006-04-14 12:00:00
# 3  194410  94664635d58f42c4afad73ab0094a396 2006-04-15 12:00:00
# 4  194411  94664635d58f42c4afad73ab0094a396 2006-04-16 12:00:00
#
#    RecordedValue  GradeCode GradeName Method  ApprovalLevel ApprovalName  \
# 0            NaN        NaN       NaN    NaN            NaN          NaN
# 1            NaN        NaN       NaN    NaN            NaN          NaN
# 2            NaN        NaN       NaN    NaN            NaN          NaN
# 3            NaN        NaN       NaN    NaN            NaN          NaN
# 4            NaN        NaN       NaN    NaN            NaN          NaN
#
#   Timestamp_Date  Timestamp_Year Timestamp_Time
# 0     2006-04-12            2006       12:00:00
# 1     2006-04-13            2006       12:00:00
# 2     2006-04-14            2006       12:00:00
# 3     2006-04-15            2006       12:00:00
# 4     2006-04-16            2006       12:00:00

# %%
# remove unused fields
# -------------------------------------------------
df_tstemp = df_tstemp.drop(['OID_', 'GradeCode', 'GradeName', 'ApprovalLevel'], axis=1)
df_tstemp = df_tstemp.drop_duplicates().reset_index(drop=True)
df_tstemp
# Out:
#                                   SensorID           Timestamp  RecordedValue  \
# 0         94664635d58f42c4afad73ab0094a396 2006-04-12 12:00:00            NaN
# 1         94664635d58f42c4afad73ab0094a396 2006-04-13 12:00:00            NaN
# 2         94664635d58f42c4afad73ab0094a396 2006-04-14 12:00:00            NaN
# 3         94664635d58f42c4afad73ab0094a396 2006-04-15 12:00:00            NaN
# 4         94664635d58f42c4afad73ab0094a396 2006-04-16 12:00:00            NaN
# ...                                    ...                 ...            ...
# 10455751  1654933d997b4207b4c9429005a74569 2021-09-07 14:30:00      54.907559
# 10455752  05aeabe35a554edb824f42ae1bca3621 2021-09-07 13:45:00     469.388196
# 10455753  05aeabe35a554edb824f42ae1bca3621 2021-09-07 14:00:00     469.388196
# 10455754  05aeabe35a554edb824f42ae1bca3621 2021-09-07 14:15:00     469.388196
# 10455755  05aeabe35a554edb824f42ae1bca3621 2021-09-07 14:30:00     469.388196
#
#                Method ApprovalName Timestamp_Date  Timestamp_Year  \
# 0                 NaN          NaN     2006-04-12            2006
# 1                 NaN          NaN     2006-04-13            2006
# 2                 NaN          NaN     2006-04-14            2006
# 3                 NaN          NaN     2006-04-15            2006
# 4                 NaN          NaN     2006-04-16            2006
# ...               ...          ...            ...             ...
# 10455751  DefaultNone  Provisional     2021-09-07            2021
# 10455752  DefaultNone  Provisional     2021-09-07            2021
# 10455753  DefaultNone  Provisional     2021-09-07            2021
# 10455754  DefaultNone  Provisional     2021-09-07            2021
# 10455755  DefaultNone  Provisional     2021-09-07            2021
#
#          Timestamp_Time
# 0              12:00:00
# 1              12:00:00
# 2              12:00:00
# 3              12:00:00
# 4              12:00:00
# ...                 ...
# 10455751       14:30:00
# 10455752       13:45:00
# 10455753       14:00:00
# 10455754       14:15:00
# 10455755       14:30:00
#
# [10455756 rows x 8 columns]

# %% [markdown]
# ### Export out csv

# %%
#Merge ts with database
dfsupertemp = pd.merge(df_tstemp, df_loctemp, on='SensorID', how='left')

print(len(dfsupertemp))
dfsupertemp.head()
# Out:
# 10455756
#                            SensorID           Timestamp  RecordedValue Method  \
# 0  94664635d58f42c4afad73ab0094a396 2006-04-12 12:00:00            NaN    NaN
# 1  94664635d58f42c4afad73ab0094a396 2006-04-13 12:00:00            NaN    NaN
# 2  94664635d58f42c4afad73ab0094a396 2006-04-14 12:00:00            NaN    NaN
# 3  94664635d58f42c4afad73ab0094a396 2006-04-15 12:00:00            NaN    NaN
# 4  94664635d58f42c4afad73ab0094a396 2006-04-16 12:00:00            NaN    NaN
#
#   ApprovalName Timestamp_Date  Timestamp_Year Timestamp_Time  OID_  \
# 0          NaN     2006-04-12            2006       12:00:00     2
# 1          NaN     2006-04-13            2006       12:00:00     2
# 2          NaN     2006-04-14            2006       12:00:00     2
# 3          NaN     2006-04-15            2006       12:00:00     2
# 4          NaN     2006-04-16            2006       12:00:00     2
#
#                          LocationID LocationCode  \
# 0  b85ca58a37784f2aa2fb33588dc4cfe9     40A 2000
# 1  b85ca58a37784f2aa2fb33588dc4cfe9     40A 2000
# 2  b85ca58a37784f2aa2fb33588dc4cfe9     40A 2000
# 3  b85ca58a37784f2aa2fb33588dc4cfe9     40A 2000
# 4  b85ca58a37784f2aa2fb33588dc4cfe9     40A 2000
#
#                         LocationName            LocationPath  \
# 0  NF Musselshell blw Bair Reservoir  All Locations.DNRC SWP
# 1  NF Musselshell blw Bair Reservoir  All Locations.DNRC SWP
# 2  NF Musselshell blw Bair Reservoir  All Locations.DNRC SWP
# 3  NF Musselshell blw Bair Reservoir  All Locations.DNRC SWP
# 4  NF Musselshell blw Bair Reservoir  All Locations.DNRC SWP
#
#         LocationType  IsExternalLocation  Longitude  Latitude UtcOffset  \
# 0  Hydrology Station                   0  -110.5535   46.5747     -PT7H
# 1  Hydrology Station                   0  -110.5535   46.5747     -PT7H
# 2  Hydrology Station                   0  -110.5535   46.5747     -PT7H
# 3  Hydrology Station                   0  -110.5535   46.5747     -PT7H
# 4  Hydrology Station                   0  -110.5535   46.5747     -PT7H
#
#         LastModified ElevationUnits  Elevation  \
# 0  2/4/2021 15:33:18             ft    5232.45
# 1  2/4/2021 15:33:18             ft    5232.45
# 2  2/4/2021 15:33:18             ft    5232.45
# 3  2/4/2021 15:33:18             ft    5232.45
# 4  2/4/2021 15:33:18             ft    5232.45
#
#                                          Description  \
# 0  North Fork Musselshell River below Bair Reservoir
# 1  North Fork Musselshell River below Bair Reservoir
# 2  North Fork Musselshell River below Bair Reservoir
# 3  North Fork Musselshell River below Bair Reservoir
# 4  North Fork Musselshell River below Bair Reservoir
#
#                                                 Tags ExtendedAttributeValues  \
# 0  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 1  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 2  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 3  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
# 4  [{"UniqueId": "1c1aabaa26e8495bae4b3f69f0fd617...                      []
#
#   StatusDesc  ActiveFlag SensorLabel  TimeSeriesType Parameter UnitOfMeasure  \
# 0  Real-time           1       stage  ProcessorBasic        HG            ft
# 1  Real-time           1       stage  ProcessorBasic        HG            ft
# 2  Real-time           1       stage  ProcessorBasic        HG            ft
# 3  Real-time           1       stage  ProcessorBasic        HG            ft
# 4  Real-time           1       stage  ProcessorBasic        HG            ft
#
#   ComputationMethod ComputationPeriod LastModifiedTime ParameterLabel  \
# 0           Unknown           Unknown    2/2/2021 6:16          Stage
# 1           Unknown           Unknown    2/2/2021 6:16          Stage
# 2           Unknown           Unknown    2/2/2021 6:16          Stage
# 3           Unknown           Unknown    2/2/2021 6:16          Stage
# 4           Unknown           Unknown    2/2/2021 6:16          Stage
#
#                   in_VariableSpecificCV
# 0  Reservoirs and Gages - Daily - Stage
# 1  Reservoirs and Gages - Daily - Stage
# 2  Reservoirs and Gages - Daily - Stage
# 3  Reservoirs and Gages - Daily - Stage
# 4  Reservoirs and Gages - Daily - Stage

# %%
# Export out to CSV.
# df_tstemp.to_csv('P_mnSSTimeSeries.csv', index=False) # The output.
# df_loctemp.to_csv('P_mnSSSiteInfo.csv', index=False) # The site information.
dfsupertemp.to_csv('P_mtSSMaster.csv', index=False) # The output.

# %%
dfsupertemp['UnitOfMeasure'].value_counts()
# Out:
# ft^3/s    10031502
# ft          424254
# Name: UnitOfMeasure, dtype: int64
