# %%
#!/usr/bin/env python
import pandas as pd
import numpy as np
import os
import beneficialUseDictionary
from utilityFunctions import *

# %%
# working directory
working_dir = "./ProcessedInputData"
os.chdir(working_dir)

# %%
# Input files
fileInput1 = "WaterRights_Diversion.csv"

# output water sources
out_put = "watersources.csv"

# %%
##### WaDE columns

columns=['WaterSourceUUID', 'WaterSourceNativeID',	'WaterSourceName', 'WaterSourceTypeCV',
         'WaterQualityIndicatorCV',	'GNISFeatureNameCV', 'Geometry']

dtypesx = ['BigInt	NVarChar(250)	NVarChar(250)	NVarChar(250)	NVarChar(100)	NVarChar(100)',
           'NVarChar(250)	Geometry']

# %%
### target dataFrame

# TODO: assumes dtypes inferred from CO file
outdf100=pd.DataFrame(columns=columns)

# %%
print("Reading inputs...")


df100 = pd.read_csv(fileInput1,encoding = "ISO-8859-1") #, or alternatively encoding = "utf-8"

print (len(df100.index))

#df100 = df100.head(10000) #only runs first 100 lines for testing.

#df100 = df100.replace('', np.nan)
df100.head(5)
# Out:
# Reading inputs...
# 13797
#       WRKEY BOCA_CD  WTR_ID      WR_NUMBER          WRTE_DESCR WRTE_CD  \
# 0  200059-1     39E  113577  39E 113577 00  STATEMENT OF CLAIM    STOC
# 1  304174-1     39E  115446  39E 115446 00  STATEMENT OF CLAIM    STOC
# 2  304174-1     39E  115446  39E 115446 00  STATEMENT OF CLAIM    STOC
# 3  203253-1     39E  115458  39E 115458 00  STATEMENT OF CLAIM    STOC
# 4  203253-1     39E  115458  39E 115458 00  STATEMENT OF CLAIM    STOC
#
#   WRST_DESCR WRST_CD  VERS_ID_SEQ       VERS_TYPE  ...  SCTN     QTR GOVT_LOT  \
# 0     ACTIVE    ACTV            1  ORIGINAL RIGHT  ...  15.0  SWNESE      NaN
# 1     ACTIVE    ACTV            1  ORIGINAL RIGHT  ...  25.0  SWSESW      NaN
# 2     ACTIVE    ACTV            1  ORIGINAL RIGHT  ...  25.0  SWSESW      NaN
# 3     ACTIVE    ACTV            1  ORIGINAL RIGHT  ...  35.0  NWNWNW      NaN
# 4     ACTIVE    ACTV            1  ORIGINAL RIGHT  ...  35.0  NWNWNW      NaN
#
#   SPX SPY WELL_DPTH  RES           GEOCODES DTM_CREATED Unnamed: 46
# 0 NaN NaN       NaN  NaN  4208591540101A400    20191212         NaN
# 1 NaN NaN       NaN  NaN  4208582530101A400    20191212         NaN
# 2 NaN NaN       NaN  NaN  4208582530101A400    20191212         NaN
# 3 NaN NaN       NaN  NaN                NaN    20191212         NaN
# 4 NaN NaN       NaN  NaN                NaN    20191212         NaN
#
# [5 rows x 47 columns]

# %%
list(df100.columns)
# Out:
# ['WRKEY',
#  'BOCA_CD',
#  'WTR_ID',
#  'WR_NUMBER',
#  'WRTE_DESCR',
#  'WRTE_CD',
#  'WRST_DESCR',
#  'WRST_CD',
#  'VERS_ID_SEQ',
#  'VERS_TYPE',
#  'ENF_PRTY_DT_DATE',
#  'MAJOR_TYPE',
#  'SOURCE_NAME',
#  'MODV_DESCR',
#  'PURT_DESCR',
#  'PURT_CD',
#  'LST_NM_OR_BUSN_NM',
#  'FST_NM',
#  'MID_INT',
#  'SUFX',
#  'OWNER',
#  'MAX_FLOW',
#  'MAX_VOL',
#  'MAX_ACRES',
#  'SCANNED',
#  'DIV_CNT',
#  'POU_CNT',
#  'IRR_CNT',
#  'RESV_CNT',
#  'ISSUE_RMK',
#  'DITCH',
#  'HIST_TYPE',
#  'POD_NO',
#  'COUNTY',
#  'CNTY_CD',
#  'COUNTY_ST_CD',
#  'TR',
#  'SCTN',
#  'QTR',
#  'GOVT_LOT',
#  'SPX',
#  'SPY',
#  'WELL_DPTH',
#  'RES',
#  'GEOCODES',
#  'DTM_CREATED',
#  'Unnamed: 46']

# %%
print ("Source name and type")

def mapSource(inString1):
    inString = str(inString1).strip()
    try:
        if inString == 'S':
            return "Surface"
        elif inString == 'G':
            return "Ground"
        else:
            return 'Unknown'        
    except:
        return 'Unknown'
        
            
df100 = df100.assign(WaterSourceTypeCV='')

df100['WaterSourceTypeCV'] = df100.apply(lambda row: mapSource(row['MAJOR_TYPE']), axis=1)
df100

destCols=['WaterSourceName','WaterSourceTypeCV']
srsCols=['SOURCE_NAME', 'WaterSourceTypeCV']

outdf100[destCols] = df100[srsCols]
# Out:
# Source name and type

# %%
print("Hard coded ...")

outdf100.WaterQualityIndicatorCV = "Fresh"
# Out:
# Hard coded ...

# %%
print("Dropping duplicates...")

print(len(outdf100.index))
outdf100 = outdf100.drop_duplicates(subset=['WaterSourceName','WaterSourceTypeCV']) #,'WaterQualityIndicatorCV'
outdf100 = outdf100.reset_index(drop=True)
print(len(outdf100.index))

outdf100
# Out:
# Dropping duplicates...
# 13797
# 1632
#      WaterSourceUUID WaterSourceNativeID  \
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                NaN                 NaN
# 5                NaN                 NaN
# 6                NaN                 NaN
# 7                NaN                 NaN
# 8                NaN                 NaN
# 9                NaN                 NaN
# 10               NaN                 NaN
# 11               NaN                 NaN
# 12               NaN                 NaN
# 13               NaN                 NaN
# 14               NaN                 NaN
# 15               NaN                 NaN
# 16               NaN                 NaN
# 17               NaN                 NaN
# 18               NaN                 NaN
# 19               NaN                 NaN
# 20               NaN                 NaN
# 21               NaN                 NaN
# 22               NaN                 NaN
# 23               NaN                 NaN
# 24               NaN                 NaN
# 25               NaN                 NaN
# 26               NaN                 NaN
# 27               NaN                 NaN
# 28               NaN                 NaN
# 29               NaN                 NaN
# ...              ...                 ...
# 1602             NaN                 NaN
# 1603             NaN                 NaN
# 1604             NaN                 NaN
# 1605             NaN                 NaN
# 1606             NaN                 NaN
# 1607             NaN                 NaN
# 1608             NaN                 NaN
# 1609             NaN                 NaN
# 1610             NaN                 NaN
# 1611             NaN                 NaN
# 1612             NaN                 NaN
# 1613             NaN                 NaN
# 1614             NaN                 NaN
# 1615             NaN                 NaN
# 1616             NaN                 NaN
# 1617             NaN                 NaN
# 1618             NaN                 NaN
# 1619             NaN                 NaN
# 1620             NaN                 NaN
# 1621             NaN                 NaN
# 1622             NaN                 NaN
# 1623             NaN                 NaN
# 1624             NaN                 NaN
# 1625             NaN                 NaN
# 1626             NaN                 NaN
# 1627             NaN                 NaN
# 1628             NaN                 NaN
# 1629             NaN                 NaN
# 1630             NaN                 NaN
# 1631             NaN                 NaN
#
#                                         WaterSourceName WaterSourceTypeCV  \
# 0                                           GROUNDWATER            Ground
# 1                   UNNAMED TRIBUTARY OF BOXELDER CREEK           Surface
# 2                        UNNAMED TRIBUTARY OF COW CREEK           Surface
# 3           SPRING, UNNAMED TRIBUTARY OF BOXELDER CREEK            Ground
# 4            SPRING, UNNAMED TRIBUTARY OF FLASTED CREEK            Ground
# 5     SPRING, UNNAMED TRIBUTARY OF NORTH THOMPSON CREEK            Ground
# 6         UNNAMED TRIBUTARY OF WILLOW CREEK, NORTH FORK           Surface
# 7     SPRING, UNNAMED TRIBUTARY OF WILLOW CREEK, NOR...            Ground
# 8      SPRING, UNNAMED TRIBUTARY OF LITTLE BEAVER CREEK            Ground
# 9         SPRING, UNNAMED TRIBUTARY OF SHEEP CAMP CREEK            Ground
# 10          SPRING, UNNAMED TRIBUTARY OF RICHARDS CREEK            Ground
# 11           SPRING, UNNAMED TRIBUTARY OF TERRELL CREEK            Ground
# 12     SPRING, UNNAMED TRIBUTARY OF LITTLE BEAVER CREEK           Surface
# 13                                    CHAMBERLAIN CREEK            Ground
# 14             SPRING, UNNAMED TRIBUTARY OF SMITH CREEK            Ground
# 15            SPRING, UNNAMED TRIBUTARY OF BEAVER CREEK            Ground
# 16                                         LOWER SPRING            Ground
# 17                                         UPPER SPRING            Ground
# 18                                        CONNOR SPRING            Ground
# 19              SPRING, UNNAMED TRIBUTARY OF LEBO CREEK            Ground
# 20              SPRING, UNNAMED TRIBUTARY OF FISH CREEK            Ground
# 21         SPRING, UNNAMED TRIBUTARY OF HALFBREED CREEK            Ground
# 22                                       GOULDING CREEK           Surface
# 23    SPRING, UNNAMED TRIBUTARY OF MUSSELSHELL RIVER...            Ground
# 24    SPRING, UNNAMED TRIBUTARY OF CHECKERBOARD CREE...            Ground
# 25           SPRING, UNNAMED TRIBUTARY OF SIMMONS CREEK            Ground
# 26    SPRING, UNNAMED TRIBUTARY OF AMERICAN FORK, SO...            Ground
# 27              SPRING, UNNAMED TRIBUTARY OF NIEL CREEK            Ground
# 28         SPRING, UNNAMED TRIBUTARY OF SOURDOUGH CREEK            Ground
# 29           SPRING, UNNAMED TRIBUTARY OF AMERICAN FORK            Ground
# ...                                                 ...               ...
# 1602                                   BIG BEAVER CREEK           Surface
# 1603          SPRING, UNNAMED TRIBUTARY OF MILLER GULCH            Ground
# 1604                                   GOVERNMENT CREEK           Surface
# 1605                                         LANG CREEK           Surface
# 1606                                         GOAT CREEK           Surface
# 1607  SPRING, UNNAMED TRIBUTARY OF UNNAMED TRIBUTARY...            Ground
# 1608       SPRING, UNNAMED TRIBUTARY OF NOXON RESERVOIR            Ground
# 1609                                     MCGREGOR CREEK           Surface
# 1610                                LITTLE BEAVER CREEK           Surface
# 1611  SPRING, UNNAMED TRIBUTARY OF CABINET GORGE RES...            Ground
# 1612       UNNAMED TRIBUTARY OF CABINET GORGE RESERVOIR           Surface
# 1613                                      COMBEST CREEK           Surface
# 1614       SPRING, UNNAMED TRIBUTARY OF NOXON RESERVOIR           Surface
# 1615                                        WEBER GULCH           Surface
# 1616                                        KIRBY GULCH           Surface
# 1617                  UNNAMED TRIBUTARY OF BEAVER GULCH           Surface
# 1618                                         BULL RIVER           Surface
# 1619        SPRING, UNNAMED TRIBUTARY OF THOMPSON RIVER            Ground
# 1620       SPRING, UNNAMED TRIBUTARY OF HINCHWOOD CREEK            Ground
# 1621                    UNNAMED TRIBUTARY OF BULL RIVER           Surface
# 1622            SPRING, UNNAMED TRIBUTARY OF SILTA DRAW            Ground
# 1623                                   WHITE PINE CREEK           Surface
# 1624               UNNAMED TRIBUTARY OF NOXON RESERVOIR           Surface
# 1625         SPRING, UNNAMED TRIBUTARY OF PILGRIM CREEK            Ground
# 1626                                       GRIMES GULCH           Surface
# 1627                                        SQUAW CREEK           Surface
# 1628                UNNAMED TRIBUTARY OF THOMPSON RIVER           Surface
# 1629                                     THOMPSON RIVER           Surface
# 1630                           SOUTH BRANCH SWAMP CREEK           Surface
# 1631                                        PYATT CREEK           Surface
#
#      WaterQualityIndicatorCV GNISFeatureNameCV Geometry
# 0                      Fresh               NaN      NaN
# 1                      Fresh               NaN      NaN
# 2                      Fresh               NaN      NaN
# 3                      Fresh               NaN      NaN
# 4                      Fresh               NaN      NaN
# 5                      Fresh               NaN      NaN
# 6                      Fresh               NaN      NaN
# 7                      Fresh               NaN      NaN
# 8                      Fresh               NaN      NaN
# 9                      Fresh               NaN      NaN
# 10                     Fresh               NaN      NaN
# 11                     Fresh               NaN      NaN
# 12                     Fresh               NaN      NaN
# 13                     Fresh               NaN      NaN
# 14                     Fresh               NaN      NaN
# 15                     Fresh               NaN      NaN
# 16                     Fresh               NaN      NaN
# 17                     Fresh               NaN      NaN
# 18                     Fresh               NaN      NaN
# 19                     Fresh               NaN      NaN
# 20                     Fresh               NaN      NaN
# 21                     Fresh               NaN      NaN
# 22                     Fresh               NaN      NaN
# 23                     Fresh               NaN      NaN
# 24                     Fresh               NaN      NaN
# 25                     Fresh               NaN      NaN
# 26                     Fresh               NaN      NaN
# 27                     Fresh               NaN      NaN
# 28                     Fresh               NaN      NaN
# 29                     Fresh               NaN      NaN
# ...                      ...               ...      ...
# 1602                   Fresh               NaN      NaN
# 1603                   Fresh               NaN      NaN
# 1604                   Fresh               NaN      NaN
# 1605                   Fresh               NaN      NaN
# 1606                   Fresh               NaN      NaN
# 1607                   Fresh               NaN      NaN
# 1608                   Fresh               NaN      NaN
# 1609                   Fresh               NaN      NaN
# 1610                   Fresh               NaN      NaN
# 1611                   Fresh               NaN      NaN
# 1612                   Fresh               NaN      NaN
# 1613                   Fresh               NaN      NaN
# 1614                   Fresh               NaN      NaN
# 1615                   Fresh               NaN      NaN
# 1616                   Fresh               NaN      NaN
# 1617                   Fresh               NaN      NaN
# 1618                   Fresh               NaN      NaN
# 1619                   Fresh               NaN      NaN
# 1620                   Fresh               NaN      NaN
# 1621                   Fresh               NaN      NaN
# 1622                   Fresh               NaN      NaN
# 1623                   Fresh               NaN      NaN
# 1624                   Fresh               NaN      NaN
# 1625                   Fresh               NaN      NaN
# 1626                   Fresh               NaN      NaN
# 1627                   Fresh               NaN      NaN
# 1628                   Fresh               NaN      NaN
# 1629                   Fresh               NaN      NaN
# 1630                   Fresh               NaN      NaN
# 1631                   Fresh               NaN      NaN
#
# [1632 rows x 7 columns]

# %%
print ("Water source native id and UUID")

#9.12.19 Adel: For water sources table, how about we do an incremental ID? like 1, 2, 3 etc?
outdf100 = outdf100.reset_index(drop=True)
outdf100['WaterSourceNativeID'] = range(1, len(outdf100.index) + 1)

print("Adding UUID...")
outdf100['WaterSourceUUID'] = outdf100.apply(lambda row: 
                                        "_".join(["MT", str(row['WaterSourceNativeID'])]), axis=1)

outdf100 = outdf100.replace(np.nan, '')

outdf100
# Out:
# Water source native id and UUID
# Adding UUID...
#      WaterSourceUUID  WaterSourceNativeID  \
# 0               MT_1                    1
# 1               MT_2                    2
# 2               MT_3                    3
# 3               MT_4                    4
# 4               MT_5                    5
# 5               MT_6                    6
# 6               MT_7                    7
# 7               MT_8                    8
# 8               MT_9                    9
# 9              MT_10                   10
# 10             MT_11                   11
# 11             MT_12                   12
# 12             MT_13                   13
# 13             MT_14                   14
# 14             MT_15                   15
# 15             MT_16                   16
# 16             MT_17                   17
# 17             MT_18                   18
# 18             MT_19                   19
# 19             MT_20                   20
# 20             MT_21                   21
# 21             MT_22                   22
# 22             MT_23                   23
# 23             MT_24                   24
# 24             MT_25                   25
# 25             MT_26                   26
# 26             MT_27                   27
# 27             MT_28                   28
# 28             MT_29                   29
# 29             MT_30                   30
# ...              ...                  ...
# 1602         MT_1603                 1603
# 1603         MT_1604                 1604
# 1604         MT_1605                 1605
# 1605         MT_1606                 1606
# 1606         MT_1607                 1607
# 1607         MT_1608                 1608
# 1608         MT_1609                 1609
# 1609         MT_1610                 1610
# 1610         MT_1611                 1611
# 1611         MT_1612                 1612
# 1612         MT_1613                 1613
# 1613         MT_1614                 1614
# 1614         MT_1615                 1615
# 1615         MT_1616                 1616
# 1616         MT_1617                 1617
# 1617         MT_1618                 1618
# 1618         MT_1619                 1619
# 1619         MT_1620                 1620
# 1620         MT_1621                 1621
# 1621         MT_1622                 1622
# 1622         MT_1623                 1623
# 1623         MT_1624                 1624
# 1624         MT_1625                 1625
# 1625         MT_1626                 1626
# 1626         MT_1627                 1627
# 1627         MT_1628                 1628
# 1628         MT_1629                 1629
# 1629         MT_1630                 1630
# 1630         MT_1631                 1631
# 1631         MT_1632                 1632
#
#                                         WaterSourceName WaterSourceTypeCV  \
# 0                                           GROUNDWATER            Ground
# 1                   UNNAMED TRIBUTARY OF BOXELDER CREEK           Surface
# 2                        UNNAMED TRIBUTARY OF COW CREEK           Surface
# 3           SPRING, UNNAMED TRIBUTARY OF BOXELDER CREEK            Ground
# 4            SPRING, UNNAMED TRIBUTARY OF FLASTED CREEK            Ground
# 5     SPRING, UNNAMED TRIBUTARY OF NORTH THOMPSON CREEK            Ground
# 6         UNNAMED TRIBUTARY OF WILLOW CREEK, NORTH FORK           Surface
# 7     SPRING, UNNAMED TRIBUTARY OF WILLOW CREEK, NOR...            Ground
# 8      SPRING, UNNAMED TRIBUTARY OF LITTLE BEAVER CREEK            Ground
# 9         SPRING, UNNAMED TRIBUTARY OF SHEEP CAMP CREEK            Ground
# 10          SPRING, UNNAMED TRIBUTARY OF RICHARDS CREEK            Ground
# 11           SPRING, UNNAMED TRIBUTARY OF TERRELL CREEK            Ground
# 12     SPRING, UNNAMED TRIBUTARY OF LITTLE BEAVER CREEK           Surface
# 13                                    CHAMBERLAIN CREEK            Ground
# 14             SPRING, UNNAMED TRIBUTARY OF SMITH CREEK            Ground
# 15            SPRING, UNNAMED TRIBUTARY OF BEAVER CREEK            Ground
# 16                                         LOWER SPRING            Ground
# 17                                         UPPER SPRING            Ground
# 18                                        CONNOR SPRING            Ground
# 19              SPRING, UNNAMED TRIBUTARY OF LEBO CREEK            Ground
# 20              SPRING, UNNAMED TRIBUTARY OF FISH CREEK            Ground
# 21         SPRING, UNNAMED TRIBUTARY OF HALFBREED CREEK            Ground
# 22                                       GOULDING CREEK           Surface
# 23    SPRING, UNNAMED TRIBUTARY OF MUSSELSHELL RIVER...            Ground
# 24    SPRING, UNNAMED TRIBUTARY OF CHECKERBOARD CREE...            Ground
# 25           SPRING, UNNAMED TRIBUTARY OF SIMMONS CREEK            Ground
# 26    SPRING, UNNAMED TRIBUTARY OF AMERICAN FORK, SO...            Ground
# 27              SPRING, UNNAMED TRIBUTARY OF NIEL CREEK            Ground
# 28         SPRING, UNNAMED TRIBUTARY OF SOURDOUGH CREEK            Ground
# 29           SPRING, UNNAMED TRIBUTARY OF AMERICAN FORK            Ground
# ...                                                 ...               ...
# 1602                                   BIG BEAVER CREEK           Surface
# 1603          SPRING, UNNAMED TRIBUTARY OF MILLER GULCH            Ground
# 1604                                   GOVERNMENT CREEK           Surface
# 1605                                         LANG CREEK           Surface
# 1606                                         GOAT CREEK           Surface
# 1607  SPRING, UNNAMED TRIBUTARY OF UNNAMED TRIBUTARY...            Ground
# 1608       SPRING, UNNAMED TRIBUTARY OF NOXON RESERVOIR            Ground
# 1609                                     MCGREGOR CREEK           Surface
# 1610                                LITTLE BEAVER CREEK           Surface
# 1611  SPRING, UNNAMED TRIBUTARY OF CABINET GORGE RES...            Ground
# 1612       UNNAMED TRIBUTARY OF CABINET GORGE RESERVOIR           Surface
# 1613                                      COMBEST CREEK           Surface
# 1614       SPRING, UNNAMED TRIBUTARY OF NOXON RESERVOIR           Surface
# 1615                                        WEBER GULCH           Surface
# 1616                                        KIRBY GULCH           Surface
# 1617                  UNNAMED TRIBUTARY OF BEAVER GULCH           Surface
# 1618                                         BULL RIVER           Surface
# 1619        SPRING, UNNAMED TRIBUTARY OF THOMPSON RIVER            Ground
# 1620       SPRING, UNNAMED TRIBUTARY OF HINCHWOOD CREEK            Ground
# 1621                    UNNAMED TRIBUTARY OF BULL RIVER           Surface
# 1622            SPRING, UNNAMED TRIBUTARY OF SILTA DRAW            Ground
# 1623                                   WHITE PINE CREEK           Surface
# 1624               UNNAMED TRIBUTARY OF NOXON RESERVOIR           Surface
# 1625         SPRING, UNNAMED TRIBUTARY OF PILGRIM CREEK            Ground
# 1626                                       GRIMES GULCH           Surface
# 1627                                        SQUAW CREEK           Surface
# 1628                UNNAMED TRIBUTARY OF THOMPSON RIVER           Surface
# 1629                                     THOMPSON RIVER           Surface
# 1630                           SOUTH BRANCH SWAMP CREEK           Surface
# 1631                                        PYATT CREEK           Surface
#
#      WaterQualityIndicatorCV GNISFeatureNameCV Geometry
# 0                      Fresh
# 1                      Fresh
# 2                      Fresh
# 3                      Fresh
# 4                      Fresh
# 5                      Fresh
# 6                      Fresh
# 7                      Fresh
# 8                      Fresh
# 9                      Fresh
# 10                     Fresh
# 11                     Fresh
# 12                     Fresh
# 13                     Fresh
# 14                     Fresh
# 15                     Fresh
# 16                     Fresh
# 17                     Fresh
# 18                     Fresh
# 19                     Fresh
# 20                     Fresh
# 21                     Fresh
# 22                     Fresh
# 23                     Fresh
# 24                     Fresh
# 25                     Fresh
# 26                     Fresh
# 27                     Fresh
# 28                     Fresh
# 29                     Fresh
# ...                      ...               ...      ...
# 1602                   Fresh
# 1603                   Fresh
# 1604                   Fresh
# 1605                   Fresh
# 1606                   Fresh
# 1607                   Fresh
# 1608                   Fresh
# 1609                   Fresh
# 1610                   Fresh
# 1611                   Fresh
# 1612                   Fresh
# 1613                   Fresh
# 1614                   Fresh
# 1615                   Fresh
# 1616                   Fresh
# 1617                   Fresh
# 1618                   Fresh
# 1619                   Fresh
# 1620                   Fresh
# 1621                   Fresh
# 1622                   Fresh
# 1623                   Fresh
# 1624                   Fresh
# 1625                   Fresh
# 1626                   Fresh
# 1627                   Fresh
# 1628                   Fresh
# 1629                   Fresh
# 1630                   Fresh
# 1631                   Fresh
#
# [1632 rows x 7 columns]

# %%
#write out
outdf100.to_csv(out_put, index=False, encoding = "utf-8")

print("Done watersources")
# Out:
# Done watersources
