# %% [markdown]
# # Pre-processing (state / organization Name) Allocation data for WaDE upload.
# - Purpose:  To pre-process the data into one master file for simple DataFrame creation and extraction

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Minnesota/WaterAllocation" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Minnesota/WaterAllocation

# %% [markdown]
# ## Point of Diversion Data

# %%
# Input File
FI_PoD = "RawInputData/mpars_index_permits_installations_uses_WGS1984.zip"
dfinPOD = pd.read_csv(FI_PoD, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "d" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('RawInputData/mpars_index_permits_installations_uses_WGS1984.zip', compression=dict(method='zip', archive_name='mpars_index_permits_installatio.csv'), index=False)

print(len(dfinPOD))
dfinPOD.head()
# Out:
# 30818
# C:\Users\rjame\AppData\Local\Temp\ipykernel_17828\2854341385.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfinPOD = pd.read_csv(FI_PoD, encoding = "ISO-8859-1").replace(np.nan, "")
#    Ã¯Â»Â¿OID_ permit_number general_permit_number permit_status  \
# 0           1     1945-0008                            Inactive
# 1           2     1947-0012                              Active
# 2           3     1947-0014                              Active
# 3           4     1947-0014                              Active
# 4           5     1947-0014                              Active
#
#         permit_class                                use_type  \
# 0  Individual Permit            Agricultural/Food Processing
# 1  Individual Permit  Mine Processing (excludes sand/gravel)
# 2  Individual Permit           Municipal/Public Water Supply
# 3  Individual Permit           Municipal/Public Water Supply
# 4  Individual Permit           Municipal/Public Water Supply
#
#             use_category permit_total_volume_mgy permit_total_acres  \
# 0  Industrial Processing              1769.70000
# 1  Industrial Processing             50000.00000
# 2           Water Supply               730.00000
# 3           Water Supply               730.00000
# 4           Water Supply               730.00000
#
#   permit_effective_date permit_expiration_date   project_name  \
# 0     10/8/1984 0:00:00                              Moorhead
# 1      5/9/2003 0:00:00                         LAKE SUPERIOR
# 2     2/24/1989 0:00:00
# 3     2/24/1989 0:00:00
# 4     2/24/1989 0:00:00
#
#                                  landowner agent  installation_name  \
# 0           American Crystal Sugar Company                        1
# 1  Cleveland Cliffs - Northshore Mining Co                        1
# 2                  Moorhead Public Service        Well #10 - 222051
# 3                  Moorhead Public Service         Well #8 - 222049
# 4                  Moorhead Public Service         Well #9 - 222050
#
#   installation_status installation_pumping_rate_gpm  \
# 0            Inactive                    3363.00000
# 1              Active                   95000.00000
# 2              Active                       0.00000
# 3              Active                       0.00000
# 4              Active                       0.00000
#
#   location_legal_description        utm_x         utm_y  latitude  longitude  \
# 0             T140N-R48W-S32 212733.00000 5199908.00000  46.89055  -96.77104
# 1                T55N-R7W-S6 630929.00000 5237380.00000  47.27682  -91.26885
# 2             T139N-R47W-S5  223000.00000 5198000.00000  46.87777  -96.63539
# 3             T139N-R47W-S5  223000.00000 5198000.00000  46.87777  -96.63539
# 4             T139N-R47W-S5  223000.00000 5198000.00000  46.87777  -96.63539
#
#   county_name watershed_major                watershed_name resource_type  \
# 0        Clay        57.00000  Upper Red River of the North  Stream/River
# 1        Lake         2.00000         Lake Superior - South          Lake
# 2        Clay        58.00000                 Buffalo River   Groundwater
# 3        Clay        58.00000                 Buffalo River   Groundwater
# 4        Clay        58.00000                 Buffalo River   Groundwater
#
#   resource_category           resource_name resource_number  well_number  \
# 0     Surface Water  RED RIVER OF THE NORTH
# 1     Surface Water                Superior  16000100.00000
# 2       Groundwater                    QBAA                 222051.00000
# 3       Groundwater                    QBAA                 222049.00000
# 4       Groundwater                    QBUA                 222050.00000
#
#   well_depth_ft                       aquifer use_2022_mg use_2021_mg  \
# 0
# 1                                             15080.40000 15664.80000
# 2     124.00000    Quaternary Buried Artesian     0.00197    15.11960
# 3     122.00000    Quaternary Buried Artesian    43.75936   177.65471
# 4     114.00000  Quaternary Buried Unconfined    89.39540    41.09104
#
#   use_2020_mg use_2019_mg use_2018_mg use_2017_mg use_2016_mg use_2015_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 15811.20000 27024.00000 44671.00000 36464.00000 36849.00000 44169.00000
# 2     9.94974     0.00000    36.10323     2.59150     7.64653     0.00000
# 3   101.81552    94.83861    90.70029    66.43305    45.53407    51.25836
# 4    98.08311   116.75849   145.53145   247.56611   124.52859    86.51413
#
#   use_2014_mg use_2013_mg use_2012_mg use_2011_mg use_2010_mg use_2009_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 45146.00000 46551.00000 45813.00000 45362.00000 44067.00000 47035.00000
# 2    18.22546     0.00000    18.03000     2.81000     0.00000     0.54000
# 3    67.91247   101.29814   133.09000   100.39000    96.21000    27.32000
# 4    24.67334    51.96678   134.57000    49.13000    32.47000    18.51000
#
#   use_2008_mg use_2007_mg use_2006_mg use_2005_mg use_2004_mg use_2003_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 46505.00000 46792.00000 45191.20000 45861.60000 46998.90000 47304.00000
# 2     0.00000     0.00000     0.00000     8.50100    10.59300    32.31000
# 3    34.24200    36.84000    30.52800    10.78400    35.39150    33.47000
# 4    57.85800    86.11000    45.68200    43.79500    26.67550     7.45000
#
#   use_2002_mg use_2001_mg use_2000_mg use_1999_mg use_1998_mg use_1997_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 45878.40000 46008.00000 47433.60000 46677.82000 47299.80000 47304.00000
# 2     0.34600     1.86000     2.90100    10.31200    16.42800    22.13000
# 3    89.02100    32.58000    31.72200    54.46900    75.96500   119.03000
# 4     0.21300    52.51000    82.78600    43.19900    57.23700    33.41000
#
#   use_1996_mg use_1995_mg use_1994_mg use_1993_mg use_1992_mg use_1991_mg  \
# 0     0.00000     6.30000     0.00000     0.00000     7.99200     0.00000
# 1 44452.80000 46641.00000  1543.70000  1548.00000 39775.00000 44145.60000
# 2    21.22300     3.88407    96.70300    92.57100    33.77800     0.00000
# 3   100.03400    93.11032    74.87000   124.75900   146.61500   272.70000
# 4    57.81300    67.06561   128.32700    65.20000   115.06900     0.00000
#
#   use_1990_mg use_1989_mg use_1988_mg WaDEUUID
# 0    29.50000    24.00000     0.00000       d0
# 1 31536.00000  1123.00000     0.00000       d1
# 2                                           d2
# 3   293.33000   355.20700   611.63000       d3
# 4                                           d4

# %%
# convert MGY to CFS for WaDE
# / 365 to get MGD * 1.8581441079018 to get CFS

def ConvertMGYToCFSFunc(valA):
    if str(valA).strip() == "":
        outVal = "";
    else:
        outVal = valA / 365 * 1.8581441079018
    return outVal

dfinPOD['in_AllocationFlow_CFS'] = dfinPOD.apply(lambda row: ConvertMGYToCFSFunc(row['permit_total_volume_mgy']), axis=1)
dfinPOD.head()
# Out:
#    Ã¯Â»Â¿OID_ permit_number general_permit_number permit_status  \
# 0           1     1945-0008                            Inactive
# 1           2     1947-0012                              Active
# 2           3     1947-0014                              Active
# 3           4     1947-0014                              Active
# 4           5     1947-0014                              Active
#
#         permit_class                                use_type  \
# 0  Individual Permit            Agricultural/Food Processing
# 1  Individual Permit  Mine Processing (excludes sand/gravel)
# 2  Individual Permit           Municipal/Public Water Supply
# 3  Individual Permit           Municipal/Public Water Supply
# 4  Individual Permit           Municipal/Public Water Supply
#
#             use_category permit_total_volume_mgy permit_total_acres  \
# 0  Industrial Processing              1769.70000
# 1  Industrial Processing             50000.00000
# 2           Water Supply               730.00000
# 3           Water Supply               730.00000
# 4           Water Supply               730.00000
#
#   permit_effective_date permit_expiration_date   project_name  \
# 0     10/8/1984 0:00:00                              Moorhead
# 1      5/9/2003 0:00:00                         LAKE SUPERIOR
# 2     2/24/1989 0:00:00
# 3     2/24/1989 0:00:00
# 4     2/24/1989 0:00:00
#
#                                  landowner agent  installation_name  \
# 0           American Crystal Sugar Company                        1
# 1  Cleveland Cliffs - Northshore Mining Co                        1
# 2                  Moorhead Public Service        Well #10 - 222051
# 3                  Moorhead Public Service         Well #8 - 222049
# 4                  Moorhead Public Service         Well #9 - 222050
#
#   installation_status installation_pumping_rate_gpm  \
# 0            Inactive                    3363.00000
# 1              Active                   95000.00000
# 2              Active                       0.00000
# 3              Active                       0.00000
# 4              Active                       0.00000
#
#   location_legal_description        utm_x         utm_y  latitude  longitude  \
# 0             T140N-R48W-S32 212733.00000 5199908.00000  46.89055  -96.77104
# 1                T55N-R7W-S6 630929.00000 5237380.00000  47.27682  -91.26885
# 2             T139N-R47W-S5  223000.00000 5198000.00000  46.87777  -96.63539
# 3             T139N-R47W-S5  223000.00000 5198000.00000  46.87777  -96.63539
# 4             T139N-R47W-S5  223000.00000 5198000.00000  46.87777  -96.63539
#
#   county_name watershed_major                watershed_name resource_type  \
# 0        Clay        57.00000  Upper Red River of the North  Stream/River
# 1        Lake         2.00000         Lake Superior - South          Lake
# 2        Clay        58.00000                 Buffalo River   Groundwater
# 3        Clay        58.00000                 Buffalo River   Groundwater
# 4        Clay        58.00000                 Buffalo River   Groundwater
#
#   resource_category           resource_name resource_number  well_number  \
# 0     Surface Water  RED RIVER OF THE NORTH
# 1     Surface Water                Superior  16000100.00000
# 2       Groundwater                    QBAA                 222051.00000
# 3       Groundwater                    QBAA                 222049.00000
# 4       Groundwater                    QBUA                 222050.00000
#
#   well_depth_ft                       aquifer use_2022_mg use_2021_mg  \
# 0
# 1                                             15080.40000 15664.80000
# 2     124.00000    Quaternary Buried Artesian     0.00197    15.11960
# 3     122.00000    Quaternary Buried Artesian    43.75936   177.65471
# 4     114.00000  Quaternary Buried Unconfined    89.39540    41.09104
#
#   use_2020_mg use_2019_mg use_2018_mg use_2017_mg use_2016_mg use_2015_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 15811.20000 27024.00000 44671.00000 36464.00000 36849.00000 44169.00000
# 2     9.94974     0.00000    36.10323     2.59150     7.64653     0.00000
# 3   101.81552    94.83861    90.70029    66.43305    45.53407    51.25836
# 4    98.08311   116.75849   145.53145   247.56611   124.52859    86.51413
#
#   use_2014_mg use_2013_mg use_2012_mg use_2011_mg use_2010_mg use_2009_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 45146.00000 46551.00000 45813.00000 45362.00000 44067.00000 47035.00000
# 2    18.22546     0.00000    18.03000     2.81000     0.00000     0.54000
# 3    67.91247   101.29814   133.09000   100.39000    96.21000    27.32000
# 4    24.67334    51.96678   134.57000    49.13000    32.47000    18.51000
#
#   use_2008_mg use_2007_mg use_2006_mg use_2005_mg use_2004_mg use_2003_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 46505.00000 46792.00000 45191.20000 45861.60000 46998.90000 47304.00000
# 2     0.00000     0.00000     0.00000     8.50100    10.59300    32.31000
# 3    34.24200    36.84000    30.52800    10.78400    35.39150    33.47000
# 4    57.85800    86.11000    45.68200    43.79500    26.67550     7.45000
#
#   use_2002_mg use_2001_mg use_2000_mg use_1999_mg use_1998_mg use_1997_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 45878.40000 46008.00000 47433.60000 46677.82000 47299.80000 47304.00000
# 2     0.34600     1.86000     2.90100    10.31200    16.42800    22.13000
# 3    89.02100    32.58000    31.72200    54.46900    75.96500   119.03000
# 4     0.21300    52.51000    82.78600    43.19900    57.23700    33.41000
#
#   use_1996_mg use_1995_mg use_1994_mg use_1993_mg use_1992_mg use_1991_mg  \
# 0     0.00000     6.30000     0.00000     0.00000     7.99200     0.00000
# 1 44452.80000 46641.00000  1543.70000  1548.00000 39775.00000 44145.60000
# 2    21.22300     3.88407    96.70300    92.57100    33.77800     0.00000
# 3   100.03400    93.11032    74.87000   124.75900   146.61500   272.70000
# 4    57.81300    67.06561   128.32700    65.20000   115.06900     0.00000
#
#   use_1990_mg use_1989_mg use_1988_mg WaDEUUID in_AllocationFlow_CFS
# 0    29.50000    24.00000     0.00000       d0               9.00920
# 1 31536.00000  1123.00000     0.00000       d1             254.54029
# 2                                           d2               3.71629
# 3   293.33000   355.20700   611.63000       d3               3.71629
# 4                                           d4               3.71629

# %%
# create single in_WaterSourceNativeID to work with

def CreateSingleWsIDFunc(valA, valB):
    valA = str(valA).split('.')[0]
    valB = str(valB).split('.')[0]
    
    if valA != "" and valB == "":
        outString = valA
    elif valA == "" and valB != "":
        outString = valB
    else:
        outString = ""
    
    return outString

dfinPOD['in_WaterSourceNativeID'] = dfinPOD.apply(lambda row: CreateSingleWsIDFunc(row['resource_number'], row['well_number']), axis=1)
dfinPOD.head()
# Out:
#    Ã¯Â»Â¿OID_ permit_number general_permit_number permit_status  \
# 0           1     1945-0008                            Inactive
# 1           2     1947-0012                              Active
# 2           3     1947-0014                              Active
# 3           4     1947-0014                              Active
# 4           5     1947-0014                              Active
#
#         permit_class                                use_type  \
# 0  Individual Permit            Agricultural/Food Processing
# 1  Individual Permit  Mine Processing (excludes sand/gravel)
# 2  Individual Permit           Municipal/Public Water Supply
# 3  Individual Permit           Municipal/Public Water Supply
# 4  Individual Permit           Municipal/Public Water Supply
#
#             use_category permit_total_volume_mgy permit_total_acres  \
# 0  Industrial Processing              1769.70000
# 1  Industrial Processing             50000.00000
# 2           Water Supply               730.00000
# 3           Water Supply               730.00000
# 4           Water Supply               730.00000
#
#   permit_effective_date permit_expiration_date   project_name  \
# 0     10/8/1984 0:00:00                              Moorhead
# 1      5/9/2003 0:00:00                         LAKE SUPERIOR
# 2     2/24/1989 0:00:00
# 3     2/24/1989 0:00:00
# 4     2/24/1989 0:00:00
#
#                                  landowner agent  installation_name  \
# 0           American Crystal Sugar Company                        1
# 1  Cleveland Cliffs - Northshore Mining Co                        1
# 2                  Moorhead Public Service        Well #10 - 222051
# 3                  Moorhead Public Service         Well #8 - 222049
# 4                  Moorhead Public Service         Well #9 - 222050
#
#   installation_status installation_pumping_rate_gpm  \
# 0            Inactive                    3363.00000
# 1              Active                   95000.00000
# 2              Active                       0.00000
# 3              Active                       0.00000
# 4              Active                       0.00000
#
#   location_legal_description        utm_x         utm_y  latitude  longitude  \
# 0             T140N-R48W-S32 212733.00000 5199908.00000  46.89055  -96.77104
# 1                T55N-R7W-S6 630929.00000 5237380.00000  47.27682  -91.26885
# 2             T139N-R47W-S5  223000.00000 5198000.00000  46.87777  -96.63539
# 3             T139N-R47W-S5  223000.00000 5198000.00000  46.87777  -96.63539
# 4             T139N-R47W-S5  223000.00000 5198000.00000  46.87777  -96.63539
#
#   county_name watershed_major                watershed_name resource_type  \
# 0        Clay        57.00000  Upper Red River of the North  Stream/River
# 1        Lake         2.00000         Lake Superior - South          Lake
# 2        Clay        58.00000                 Buffalo River   Groundwater
# 3        Clay        58.00000                 Buffalo River   Groundwater
# 4        Clay        58.00000                 Buffalo River   Groundwater
#
#   resource_category           resource_name resource_number  well_number  \
# 0     Surface Water  RED RIVER OF THE NORTH
# 1     Surface Water                Superior  16000100.00000
# 2       Groundwater                    QBAA                 222051.00000
# 3       Groundwater                    QBAA                 222049.00000
# 4       Groundwater                    QBUA                 222050.00000
#
#   well_depth_ft                       aquifer use_2022_mg use_2021_mg  \
# 0
# 1                                             15080.40000 15664.80000
# 2     124.00000    Quaternary Buried Artesian     0.00197    15.11960
# 3     122.00000    Quaternary Buried Artesian    43.75936   177.65471
# 4     114.00000  Quaternary Buried Unconfined    89.39540    41.09104
#
#   use_2020_mg use_2019_mg use_2018_mg use_2017_mg use_2016_mg use_2015_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 15811.20000 27024.00000 44671.00000 36464.00000 36849.00000 44169.00000
# 2     9.94974     0.00000    36.10323     2.59150     7.64653     0.00000
# 3   101.81552    94.83861    90.70029    66.43305    45.53407    51.25836
# 4    98.08311   116.75849   145.53145   247.56611   124.52859    86.51413
#
#   use_2014_mg use_2013_mg use_2012_mg use_2011_mg use_2010_mg use_2009_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 45146.00000 46551.00000 45813.00000 45362.00000 44067.00000 47035.00000
# 2    18.22546     0.00000    18.03000     2.81000     0.00000     0.54000
# 3    67.91247   101.29814   133.09000   100.39000    96.21000    27.32000
# 4    24.67334    51.96678   134.57000    49.13000    32.47000    18.51000
#
#   use_2008_mg use_2007_mg use_2006_mg use_2005_mg use_2004_mg use_2003_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 46505.00000 46792.00000 45191.20000 45861.60000 46998.90000 47304.00000
# 2     0.00000     0.00000     0.00000     8.50100    10.59300    32.31000
# 3    34.24200    36.84000    30.52800    10.78400    35.39150    33.47000
# 4    57.85800    86.11000    45.68200    43.79500    26.67550     7.45000
#
#   use_2002_mg use_2001_mg use_2000_mg use_1999_mg use_1998_mg use_1997_mg  \
# 0     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 1 45878.40000 46008.00000 47433.60000 46677.82000 47299.80000 47304.00000
# 2     0.34600     1.86000     2.90100    10.31200    16.42800    22.13000
# 3    89.02100    32.58000    31.72200    54.46900    75.96500   119.03000
# 4     0.21300    52.51000    82.78600    43.19900    57.23700    33.41000
#
#   use_1996_mg use_1995_mg use_1994_mg use_1993_mg use_1992_mg use_1991_mg  \
# 0     0.00000     6.30000     0.00000     0.00000     7.99200     0.00000
# 1 44452.80000 46641.00000  1543.70000  1548.00000 39775.00000 44145.60000
# 2    21.22300     3.88407    96.70300    92.57100    33.77800     0.00000
# 3   100.03400    93.11032    74.87000   124.75900   146.61500   272.70000
# 4    57.81300    67.06561   128.32700    65.20000   115.06900     0.00000
#
#   use_1990_mg use_1989_mg use_1988_mg WaDEUUID in_AllocationFlow_CFS  \
# 0    29.50000    24.00000     0.00000       d0               9.00920
# 1 31536.00000  1123.00000     0.00000       d1             254.54029
# 2                                           d2               3.71629
# 3   293.33000   355.20700   611.63000       d3               3.71629
# 4                                           d4               3.71629
#
#   in_WaterSourceNativeID
# 0
# 1               16000100
# 2                 222051
# 3                 222049
# 4                 222050

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfinPOD['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "MNwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "MNwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "MNwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfinPOD['resource_name']
df['in_WaterSourceNativeID'] = dfinPOD['in_WaterSourceNativeID'] # will supllment empty Ids below
df['in_WaterSourceTypeCV'] = dfinPOD['resource_category']

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = dfinPOD['county_name']
df['in_EPSGCodeCV'] = "4326"
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfinPOD['latitude']
df['in_Longitude'] = dfinPOD['longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"  # "Point of Diversion"
df['in_SiteName'] = dfinPOD['installation_name']
df['in_SiteNativeID'] = "" # not available, will create custom Id below
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = ""
df['in_StateCV'] = "MN"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = dfinPOD['permit_expiration_date']
df['in_AllocationFlow_CFS'] = dfinPOD['in_AllocationFlow_CFS']
df['in_AllocationLegalStatusCV'] = dfinPOD['permit_status']
df['in_AllocationNativeID'] =  dfinPOD['permit_number']
df['in_AllocationOwner'] = dfinPOD['landowner']
df['in_AllocationPriorityDate'] = dfinPOD['permit_effective_date']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = dfinPOD['permit_class']
df['in_AllocationVolume_AF'] = ""
df['in_BeneficialUseCategory'] = dfinPOD['use_category']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = "0" # either a 1 for excempt or 0 for not-excempt
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = dfinPOD['permit_total_acres']
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = ""

outPOD = df.copy()
outPOD = outPOD.drop_duplicates().reset_index(drop=True)
print(len(outPOD))
outPOD.head()
# Out:
# 30818
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0       d0       MNwr_M1                 MNwr_V1             MNwr_O1
# 1       d1       MNwr_M1                 MNwr_V1             MNwr_O1
# 2       d2       MNwr_M1                 MNwr_V1             MNwr_O1
# 3       d3       MNwr_M1                 MNwr_V1             MNwr_O1
# 4       d4       MNwr_M1                 MNwr_V1             MNwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#        in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0  RED RIVER OF THE NORTH                               Surface Water
# 1                Superior               16000100        Surface Water
# 2                    QBAA                 222051          Groundwater
# 3                    QBAA                 222049          Groundwater
# 4                    QBUA                 222050          Groundwater
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County in_EPSGCodeCV  \
# 0                                                  Clay          4326
# 1                                                  Lake          4326
# 2                                                  Clay          4326
# 3                                                  Clay          4326
# 4                                                  Clay          4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    46.89055     -96.77104
# 1                                    47.27682     -91.26885
# 2                                    46.87777     -96.63539
# 3                                    46.87777     -96.63539
# 4                                    46.87777     -96.63539
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite        in_SiteName  \
# 0                                                   POD                  1
# 1                                                   POD                  1
# 2                                                   POD  Well #10 - 222051
# 3                                                   POD   Well #8 - 222049
# 4                                                   POD   Well #9 - 222050
#
#   in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                                                    MN
# 1                                                    MN
# 2                                                    MN
# 3                                                    MN
# 4                                                    MN
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0                                           9.00920
# 1                                         254.54029
# 2                                           3.71629
# 3                                           3.71629
# 4                                           3.71629
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                   Inactive             1945-0008
# 1                     Active             1947-0012
# 2                     Active             1947-0014
# 3                     Active             1947-0014
# 4                     Active             1947-0014
#
#                         in_AllocationOwner in_AllocationPriorityDate  \
# 0           American Crystal Sugar Company         10/8/1984 0:00:00
# 1  Cleveland Cliffs - Northshore Mining Co          5/9/2003 0:00:00
# 2                  Moorhead Public Service         2/24/1989 0:00:00
# 3                  Moorhead Public Service         2/24/1989 0:00:00
# 4                  Moorhead Public Service         2/24/1989 0:00:00
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0                               Individual Permit
# 1                               Individual Permit
# 2                               Individual Permit
# 3                               Individual Permit
# 4                               Individual Permit
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0    Industrial Processing
# 1    Industrial Processing
# 2             Water Supply
# 3             Water Supply
# 4             Water Supply
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#   in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterAllocationNativeURL
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Place of Use Data

# %%
# N/A

# %% [markdown]
# ## Concatenate POD and POU Data.  Make needed changes

# %%
# Concatenate dataframes
frames = [outPOD]  # list all out dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 30818

# %% [markdown]
# ## Clean Data / data types

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\),(-]", "", Val).title().replace("  ", " ").strip()
    return Val

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Red River Of The North', 'Superior', 'Qbaa', ..., 'South Lida',
#        'St Louis River Estuary St Louis Bay', 'East Sunburg'],
#       dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['Clay', 'Lake', 'Otter Tail', 'St Louis', 'Blue Earth',
#        'Sherburne', 'Martin', 'Scott', 'Cottonwood', 'Isanti', 'Itasca',
#        'Polk', 'Anoka', 'Hennepin', 'Mcleod', 'Nobles', 'Cook', 'Grant',
#        'Dakota', 'Marshall', 'Crow Wing', 'Jackson', 'Redwood',
#        'Mille Lacs', 'Freeborn', 'Rock', 'Lincoln', 'Big Stone', 'Ramsey',
#        'Mower', 'Carver', 'Nicollet', 'Becker', 'Kandiyohi', 'Wadena',
#        'Norman', 'Le Sueur', 'Pope', 'Hubbard', 'Meeker', 'Beltrami',
#        'Olmsted', 'Traverse', 'Washington', 'Stearns', 'Lac Qui Parle',
#        'Benton', 'Clearwater', 'Faribault', 'Todd', 'Swift', 'Rice',
#        'Aitkin', 'Renville', 'Goodhue', 'Wright', 'Fillmore', 'Red Lake',
#        'Douglas', 'Sibley', 'Cass', 'Stevens', 'Pipestone', 'Winona',
#        'Morrison', 'Houston', 'Chisago', 'Kittson', 'Lyon', 'Carlton',
#        'Roseau', 'Watonwan', 'Dodge', 'Lake Of The Woods', 'Brown',
#        'Kanabec', 'Yellow Medicine', 'Pine', 'Chippewa', 'Koochiching',
#        'Wabasha', 'Pennington', 'Steele', 'Wilkin', 'Waseca', 'Mahnomen',
#        'Murray'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['1', 'Well #10 222051', 'Well #8 222049', ...,
#        '23034 Unnamed Pond', '23025 Elk Lake', '23027 Sunburg Lake'],
#       dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['American Crystal Sugar Company',
#        'Cleveland Cliffs Northshore Mining Co', 'Moorhead Public Service',
#        ..., 'Ep Gts Housing Phase I Llc', 'Leatherman Eric',
#        'Erichson Mark'], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Red River Of The North', 'Superior', 'Qbaa', ..., 'South Lida',
#        'St Louis River Estuary St Louis Bay', 'East Sunburg'],
#       dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater', ''], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['1', 'Well #10 222051', 'Well #8 222049', ...,
#        '23034 Unnamed Pond', '23025 Elk Lake', '23027 Sunburg Lake'],
#       dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['American Crystal Sugar Company',
#        'Cleveland Cliffs Northshore Mining Co', 'Moorhead Public Service',
#        ..., 'Ep Gts Housing Phase I Llc', 'Leatherman Eric',
#        'Erichson Mark'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
uniqueList = list(set([i.strip() for i in ','.join(outdf['in_BeneficialUseCategory'].astype(str)).split(',')]))
uniqueList.sort()
uniqueList
# Out:
# ['Agricultural Irrigation',
#  'Heating/Cooling',
#  'Industrial Processing',
#  'Non-Crop Irrigation',
#  'Power Generation',
#  'Special Categories',
#  'Water Level Maintenance',
#  'Water Supply']

# %%
# Ensure Latitude entry is either numireic or a 0
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([46.8905514 , 47.27681851, 46.87777341, ..., 45.92172337,
#        45.06732735, 45.32635259])

# %%
# Ensure Longitude entry is either numireic or a 0
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-96.7710413 , -91.26884763, -96.63538667, ..., -95.53038881,
#        -95.71501657, -95.23501413])

# %%
# Changing datatype of Expiration Date to date fields entry
outdf['in_AllocationExpirationDate'] = pd.to_datetime(outdf['in_AllocationExpirationDate'], errors = 'coerce')
outdf['in_AllocationExpirationDate'] = pd.to_datetime(outdf["in_AllocationExpirationDate"].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationExpirationDate'] = outdf['in_AllocationExpirationDate'].astype(str).str.replace("NaT", "")
outdf['in_AllocationExpirationDate'].unique()
# Out:
# array(['', '2017-05-26', '2024-12-31', ..., '2024-08-31', '2024-10-02',
#        '2024-09-12'], dtype=object)

# %%
# Changing datatype of Priority Date to date fields entry
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'], errors = 'coerce')
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# array(['1984-10-08T00:00:00.000000000', '2003-05-09T00:00:00.000000000',
#        '1989-02-24T00:00:00.000000000', ...,
#        '2023-09-21T00:00:00.000000000', '2023-09-12T00:00:00.000000000',
#        '2023-09-27T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# Ensure Flow entry is either numireic
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([9.00919898014744, 254.54028875367123, 3.7162882158036, ...,
#        18.734165252270202, 1.5944403687529964, 2.708308672339062],
#       dtype=object)

# %%
# Ensure Volume entry is either numireic
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array([''], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], 
                                                                              row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1', '16000100', '222051', ..., '21014200', '12006700',
#        '34033600'], dtype=object)

# %%
# Creating WaDE Custom site native ID for easy site identification
# use Unique Latitude, Longitude, SiteName and SiteTypeCV values
# ----------------------------------------------------------------------------------------------------

# Create temp in_SiteNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_Latitude'] = outdf['in_Latitude'].astype(str).str.strip()
dfTempID['in_Longitude'] = outdf['in_Longitude'].astype(str).str.strip()
dfTempID['in_SiteName'] = outdf['in_SiteName'].astype(str).str.strip()
dfTempID['in_SiteTypeCV'] = outdf['in_SiteTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_SiteNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_Latitude'].astype(str) + dfTempID['in_Longitude'].astype(str) + dfTempID['in_SiteName'].astype(str)+ dfTempID['in_SiteTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_SiteNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB, valC, valD):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip() + str(valC).strip() + str(valD).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_SiteNativeID'], 
                                                                       row['in_Latitude'], row['in_Longitude'],
                                                                       row['in_SiteName'], row['in_SiteTypeCV']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', ..., 'wadeId29225', 'wadeId29226',
#        'wadeId29227'], dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For this {state name / organization}, we don't want water rights that are considered: {enter string entries here}

# %%
# drop non-active AllocationLegalStatusCV values specific to that state.

# drop the list
dropLegalStatusList = ["Inactive"] # enter string entries here

# drop rows from above list
outdf = outdf[outdf.in_AllocationLegalStatusCV.isin(dropLegalStatusList) == False].reset_index(drop=True)

print(len(outdf))
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# 17733
# array(['Active'], dtype=object)

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to POU csv inputs.

# %%
# N/A

# %% [markdown]
# ## Export Data

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17733 entries, 0 to 17732
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   WaDEUUID                                      17733 non-null  object
#  1   in_MethodUUID                                 17733 non-null  object
#  2   in_VariableSpecificUUID                       17733 non-null  object
#  3   in_OrganizationUUID                           17733 non-null  object
#  4   in_Geometry                                   17733 non-null  object
#  5   in_GNISFeatureNameCV                          17733 non-null  object
#  6   in_WaterQualityIndicatorCV                    17733 non-null  object
#  7   in_WaterSourceName                            17733 non-null  object
#  8   in_WaterSourceNativeID                        17733 non-null  object
#  9   in_WaterSourceTypeCV                          17733 non-null  object
#  10  in_CoordinateAccuracy                         17733 non-null  object
#  11  in_CoordinateMethodCV                         17733 non-null  object
#  12  in_County                                     17733 non-null  object
#  13  in_EPSGCodeCV                                 17733 non-null  object
#  14  in_GNISCodeCV                                 17733 non-null  object
#  15  in_HUC12                                      17733 non-null  object
#  16  in_HUC8                                       17733 non-null  object
#  17  in_Latitude                                   17733 non-null  float64
#  18  in_Longitude                                  17733 non-null  float64
#  19  in_NHDNetworkStatusCV                         17733 non-null  object
#  20  in_NHDProductCV                               17733 non-null  object
#  21  in_PODorPOUSite                               17733 non-null  object
#  22  in_SiteName                                   17733 non-null  object
#  23  in_SiteNativeID                               17733 non-null  object
#  24  in_SitePoint                                  17733 non-null  object
#  25  in_SiteTypeCV                                 17733 non-null  object
#  26  in_StateCV                                    17733 non-null  object
#  27  in_USGSSiteID                                 17733 non-null  object
#  28  in_AllocationApplicationDate                  17733 non-null  object
#  29  in_AllocationAssociatedConsumptiveUseSiteIDs  17733 non-null  object
#  30  in_AllocationAssociatedWithdrawalSiteIDs      17733 non-null  object
#  31  in_AllocationBasisCV                          17733 non-null  object
#  32  in_AllocationChangeApplicationIndicator       17733 non-null  object
#  33  in_AllocationCommunityWaterSupplySystem       17733 non-null  object
#  34  in_AllocationCropDutyAmount                   17733 non-null  object
#  35  in_AllocationExpirationDate                   17733 non-null  object
#  36  in_AllocationFlow_CFS                         17733 non-null  object
#  37  in_AllocationLegalStatusCV                    17733 non-null  object
#  38  in_AllocationNativeID                         17733 non-null  object
#  39  in_AllocationOwner                            17733 non-null  object
#  40  in_AllocationPriorityDate                     17733 non-null  datetime64[ns]
#  41  in_AllocationSDWISIdentifierCV                17733 non-null  object
#  42  in_AllocationTimeframeEnd                     17733 non-null  object
#  43  in_AllocationTimeframeStart                   17733 non-null  object
#  44  in_AllocationTypeCV                           17733 non-null  object
#  45  in_AllocationVolume_AF                        17733 non-null  object
#  46  in_BeneficialUseCategory                      17733 non-null  object
#  47  in_CommunityWaterSupplySystem                 17733 non-null  object
#  48  in_CropTypeCV                                 17733 non-null  object
#  49  in_CustomerTypeCV                             17733 non-null  object
#  50  in_DataPublicationDate                        17733 non-null  object
#  51  in_DataPublicationDOI                         17733 non-null  object
#  52  in_ExemptOfVolumeFlowPriority                 17733 non-null  object
#  53  in_GeneratedPowerCapacityMW                   17733 non-null  object
#  54  in_IrrigatedAcreage                           17733 non-null  object
#  55  in_IrrigationMethodCV                         17733 non-null  object
#  56  in_LegacyAllocationIDs                        17733 non-null  object
#  57  in_OwnerClassificationCV                      17733 non-null  object
#  58  in_PopulationServed                           17733 non-null  object
#  59  in_PowerType                                  17733 non-null  object
#  60  in_PrimaryBeneficialUseCategory               17733 non-null  object
#  61  in_SDWISIdentifierCV                          17733 non-null  object
#  62  in_WaterAllocationNativeURL                   17733 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(60)
# memory usage: 8.5+ MB

# %%
outdf
# Out:
#       WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0           d1       MNwr_M1                 MNwr_V1             MNwr_O1
# 1           d2       MNwr_M1                 MNwr_V1             MNwr_O1
# 2           d3       MNwr_M1                 MNwr_V1             MNwr_O1
# 3           d4       MNwr_M1                 MNwr_V1             MNwr_O1
# 4           d6       MNwr_M1                 MNwr_V1             MNwr_O1
# ...        ...           ...                     ...                 ...
# 17728   d30813       MNwr_M1                 MNwr_V1             MNwr_O1
# 17729   d30814       MNwr_M1                 MNwr_V1             MNwr_O1
# 17730   d30815       MNwr_M1                 MNwr_V1             MNwr_O1
# 17731   d30816       MNwr_M1                 MNwr_V1             MNwr_O1
# 17732   d30817       MNwr_M1                 MNwr_V1             MNwr_O1
#
#       in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...           ...                  ...                        ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#       in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0               Superior               16000100        Surface Water
# 1                   Qbaa                 222051          Groundwater
# 2                   Qbaa                 222049          Groundwater
# 3                   Qbua                 222050          Groundwater
# 4                  Colby               69024900        Surface Water
# ...                  ...                    ...                  ...
# 17728                                  wadeId14          Groundwater
# 17729                                  wadeId51        Surface Water
# 17730                Elk               21014200        Surface Water
# 17731            Unnamed               12006700        Surface Water
# 17732       East Sunburg               34033600        Surface Water
#
#       in_CoordinateAccuracy in_CoordinateMethodCV   in_County in_EPSGCodeCV  \
# 0                                                        Lake          4326
# 1                                                        Clay          4326
# 2                                                        Clay          4326
# 3                                                        Clay          4326
# 4                                                    St Louis          4326
# ...                     ...                   ...         ...           ...
# 17728                                                 Chisago          4326
# 17729                                              Otter Tail          4326
# 17730                                                 Douglas          4326
# 17731                                                Chippewa          4326
# 17732                                               Kandiyohi          4326
#
#       in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                        47.27682     -91.26885
# 1                                        46.87777     -96.63539
# 2                                        46.87777     -96.63539
# 3                                        46.87777     -96.63539
# 4                                        47.53334     -92.15899
# ...             ...      ...     ...          ...           ...
# 17728                                    45.32641     -92.99987
# 17729                                    46.55716     -95.96962
# 17730                                    45.92172     -95.53039
# 17731                                    45.06733     -95.71502
# 17732                                    45.32635     -95.23501
#
#       in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0                                                       POD
# 1                                                       POD
# 2                                                       POD
# 3                                                       POD
# 4                                                       POD
# ...                     ...             ...             ...
# 17728                                                   POD
# 17729                                                   POD
# 17730                                                   POD
# 17731                                                   POD
# 17732                                                   POD
#
#               in_SiteName in_SiteNativeID in_SitePoint in_SiteTypeCV  \
# 0                       1         wadeId2
# 1         Well #10 222051         wadeId3
# 2          Well #8 222049         wadeId4
# 3          Well #9 222050         wadeId5
# 4                       1         wadeId7
# ...                   ...             ...          ...           ...
# 17728     Installation #1     wadeId29223
# 17729  23034 Unnamed Pond     wadeId29224
# 17730      23025 Elk Lake     wadeId29225
# 17731     Installation #1     wadeId29226
# 17732  23027 Sunburg Lake     wadeId29227
#
#       in_StateCV in_USGSSiteID in_AllocationApplicationDate  \
# 0             MN
# 1             MN
# 2             MN
# 3             MN
# 4             MN
# ...          ...           ...                          ...
# 17728         MN
# 17729         MN
# 17730         MN
# 17731         MN
# 17732         MN
#
#       in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                            ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#       in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                  ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#       in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#       in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...                         ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#       in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0                                             254.54029
# 1                                               3.71629
# 2                                               3.71629
# 3                                               3.71629
# 4                                              22.94528
# ...                           ...                   ...
# 17728                  2023-10-31               0.01527
# 17729                  2023-12-31               0.01018
# 17730                  2023-12-31               0.25454
# 17731                  2023-12-31               0.00967
# 17732                  2023-12-31               0.01018
#
#       in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                         Active             1947-0012
# 1                         Active             1947-0014
# 2                         Active             1947-0014
# 3                         Active             1947-0014
# 4                         Active             1949-0135
# ...                          ...                   ...
# 17728                     Active             2023-2878
# 17729                     Active             2023-2892
# 17730                     Active             2023-2894
# 17731                     Active             2023-2913
# 17732                     Active             2023-2952
#
#                                       in_AllocationOwner  \
# 0                  Cleveland Cliffs Northshore Mining Co
# 1                                Moorhead Public Service
# 2                                Moorhead Public Service
# 3                                Moorhead Public Service
# 4      Cliffs Erie Llc Minnesota Power A Division Of ...
# ...                                                  ...
# 17728                                      Erichson Mark
# 17729                            Central Specialties Inc
# 17730                            Central Specialties Inc
# 17731                       Chippewa County Highway Dept
# 17732                            Central Specialties Inc
#
#       in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0                    2003-05-09
# 1                    1989-02-24
# 2                    1989-02-24
# 3                    1989-02-24
# 4                    2018-11-01
# ...                         ...                            ...
# 17728                2023-09-25
# 17729                2023-09-20
# 17730                2023-09-21
# 17731                2023-10-05
# 17732                2023-10-05
#
#       in_AllocationTimeframeEnd in_AllocationTimeframeStart  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                         ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#                 in_AllocationTypeCV in_AllocationVolume_AF  \
# 0                 Individual Permit
# 1                 Individual Permit
# 2                 Individual Permit
# 3                 Individual Permit
# 4                 Individual Permit
# ...                             ...                    ...
# 17728  General Permit Authorization
# 17729  General Permit Authorization
# 17730  General Permit Authorization
# 17731  General Permit Authorization
# 17732  General Permit Authorization
#
#       in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0        Industrial Processing
# 1                 Water Supply
# 2                 Water Supply
# 3                 Water Supply
# 4        Industrial Processing
# ...                        ...                           ...           ...
# 17728  Water Level Maintenance
# 17729       Special Categories
# 17730       Special Categories
# 17731       Special Categories
# 17732       Special Categories
#
#       in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                 ...                    ...                   ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#       in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...                         ...
# 17728                             0
# 17729                             0
# 17730                             0
# 17731                             0
# 17732                             0
#
#       in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                   ...                    ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#       in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                 ...          ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#       in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                  ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
#       in_WaterAllocationNativeURL
# 0
# 1
# 2
# 3
# 4
# ...                           ...
# 17728
# 17729
# 17730
# 17731
# 17732
#
# [17733 rows x 63 columns]

# %%
# Export the output dataframe
# change output name / abbreviation to match native state provdier and wade data type 
outdf.to_csv('RawInputData/Pwr_Main.zip', compression=dict(method='zip', archive_name='Pwr_Main.csv'), index=False)  # The output, save as a zip
#dfPoUshape.to_csv('P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
