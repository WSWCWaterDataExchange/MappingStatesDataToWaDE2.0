# %% [markdown]
# # Assign RegulatoryOverlayUUIDs Values to Water Right sites.csv
# Purpose:  To assign RegulatoryOverlayUUIDs values to state water right sites.csv File.
#
# Notes:
# - requires the completed pre-processed sites.csv & watersource.csv files from the state "WaterAllocation/ProcessedInputData" folder to be copied over to the "Regulatory/ProcessedInputData" folder.  Rename to wr_sites.csv & wr_watersource.csv to preserve inputs.
# - requires awareness of unique WaterSourceTypeCV of each water right site match up to corresponding WaterSourceTypeCV of regulatoryoverlays per reportingunits

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library
import geoplot as gplt # for plotting maps
import geoplot.crs as gcrs #used to pull in webdata

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Oregon/Regulatory" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Oregon/Regulatory

# %% [markdown]
# ## Input Data

# %%
# Regulatory Input Data
dfro = pd.read_csv("ProcessedInputData/regulatoryoverlays.csv")
dfru = pd.read_csv("ProcessedInputData/reportingunits.csv")
dfrru = pd.read_csv("ProcessedInputData/regulatoryreportingunits.csv")

# Water right Input Data
dfws = pd.read_csv('ProcessedInputData/wr_watersources.csv')
dfs = pd.read_csv('ProcessedInputData/wr_sites.csv', error_bad_lines=False)
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_19840\3423606318.py:8: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   dfs = pd.read_csv('ProcessedInputData/wr_sites.csv', error_bad_lines=False)
# C:\Users\rjame\AppData\Local\Temp\ipykernel_19840\3423606318.py:8: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = pd.read_csv('ProcessedInputData/wr_sites.csv', error_bad_lines=False)

# %%
#### regulatory watersource info with reporting unit info

# merge regulatoryoverlays -to- regulatoryreportingunits -to- reportingunits
dfro = pd.merge(dfro[['RegulatoryOverlayUUID', 'WaterSourceTypeCV']], dfrru[['RegulatoryOverlayUUID', 'ReportingUnitUUID']], left_on='RegulatoryOverlayUUID', right_on='RegulatoryOverlayUUID', how='left')
dfru = pd.merge(dfru, dfro, left_on='ReportingUnitUUID', right_on='ReportingUnitUUID', how='left')

print(dfru['ReportingUnitTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(dfru['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfru))
dfru.head(1)
# Out:
# ['Administrative Basins']
# ['Surface and Ground Water']
# 18
#   ReportingUnitUUID  EPSGCodeCV ReportingUnitName ReportingUnitNativeID  \
# 0        ORre_RUor1        4326       North Coast                   or1
#
#    ReportingUnitProductVersion    ReportingUnitTypeCV ReportingUnitUpdateDate  \
# 0                      9.60000  Administrative Basins               9/22/2021
#
#   StateCV                                           Geometry  \
# 0      OR  POLYGON ((-123.50593382709745 46.2351311106205...
#
#   RegulatoryOverlayUUID         WaterSourceTypeCV
# 0            ORre_ROor1  Surface and Ground Water

# %%
#### water right watersource info with site info

# explode site.csv on WaterSourceUUIDs
dfs = dfs.assign(WaterSourceUUIDs=dfs['WaterSourceUUIDs'].str.split(',')).explode('WaterSourceUUIDs').reset_index(drop=True)

# merge watersources to dfs via WaterSourceUUIDs -to -WaterSourceUUID
dfs = pd.merge(dfs, dfws[['WaterSourceUUID', 'WaterSourceTypeCV']], left_on='WaterSourceUUIDs', right_on='WaterSourceUUID', how='left')
print(dfs['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfs))
dfs.head(1)
# Out:
# ['Groundwater' 'Surface Water' 'Storage' 'WaDE Blank']
# 193681
#          SiteUUID  RegulatoryOverlayUUIDs  WaterSourceUUIDs  \
# 0  ORwr_SPOD10000                     NaN  ORwr_WSwadeID315
#
#   CoordinateAccuracy CoordinateMethodCV      County  EPSGCodeCV Geometry  \
# 0         WaDE Blank         WaDE Blank  WaDE Blank        4326      NaN
#
#    GNISCodeCV  HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  \
# 0         NaN    NaN   NaN  45.20715 -123.05841                 NaN
#
#    NHDProductCV PODorPOUSite    SiteName SiteNativeID  SitePoint SiteTypeCV  \
# 0           NaN          POD  WaDE Blank     POD10000        NaN       well
#
#   StateCV  USGSSiteID   WaterSourceUUID WaterSourceTypeCV
# 0      OR         NaN  ORwr_WSwadeID315       Groundwater

# %% [markdown]
# ## Extract RegulatoryOverlay from Reporting Units and assing to WR Sites
# - repeat scripts based on the number of ReportingUnitTypeCV types.
# - merge all geo-dataframes into one output

# %% [markdown]
# #### Regulatory Area Data #1

# %%
# Create copy of reportingunits dataframe
# Extract out ReportingUnitTypeCV from reportingunits dataframe
# note unique WaterSourceTypeCV

dfru1 = dfru.copy()
nameOfReportingUnitTypeVar = "Administrative Basins" # change here for ReportingUnitTypeCV of interest
dfru1 = dfru1[dfru1['ReportingUnitTypeCV'] == nameOfReportingUnitTypeVar]
print(len(dfru1))
print(dfru1['WaterSourceTypeCV'].unique())
dfru1.head(1)
# Out:
# 18
# ['Surface and Ground Water']
#   ReportingUnitUUID  EPSGCodeCV ReportingUnitName ReportingUnitNativeID  \
# 0        ORre_RUor1        4326       North Coast                   or1
#
#    ReportingUnitProductVersion    ReportingUnitTypeCV ReportingUnitUpdateDate  \
# 0                      9.60000  Administrative Basins               9/22/2021
#
#   StateCV                                           Geometry  \
# 0      OR  POLYGON ((-123.50593382709745 46.2351311106205...
#
#   RegulatoryOverlayUUID         WaterSourceTypeCV
# 0            ORre_ROor1  Surface and Ground Water

# %%
# Convert dataframe -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

dfru1 = dfru1[dfru1['Geometry'] != ""].reset_index(drop=True)
dfru1['Geometry'] = gpd.GeoSeries.from_wkt(dfru1['Geometry'], crs="EPSG:4326")
gdfru1 = gpd.GeoDataFrame(dfru1, geometry=dfru1['Geometry'], crs="EPSG:4326") # covert to geodataframe
gplt.polyplot(gdfru1, ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Create copy of water right sites dataframe
# Extract out WaterSourceTypeCV and match to that of above reportingunits dataframe

dfs1 = dfs.copy()
nameOfWaterSourceTypeCV= "WaDE Blank" # change here for WaterSourceTypeCV of interest
dfs1 = dfs1[dfs1['WaterSourceTypeCV'] != nameOfWaterSourceTypeCV]
dfs1 = dfs1[dfs1['PODorPOUSite'] == 'POD']
print(len(dfs1))
print(dfs1['WaterSourceTypeCV'].unique())
dfs1.head(1)
# Out:
# 81957
# ['Groundwater' 'Surface Water' 'Storage']
#          SiteUUID  RegulatoryOverlayUUIDs  WaterSourceUUIDs  \
# 0  ORwr_SPOD10000                     NaN  ORwr_WSwadeID315
#
#   CoordinateAccuracy CoordinateMethodCV      County  EPSGCodeCV Geometry  \
# 0         WaDE Blank         WaDE Blank  WaDE Blank        4326      NaN
#
#    GNISCodeCV  HUC12  HUC8  Latitude  Longitude  NHDNetworkStatusCV  \
# 0         NaN    NaN   NaN  45.20715 -123.05841                 NaN
#
#    NHDProductCV PODorPOUSite    SiteName SiteNativeID  SitePoint SiteTypeCV  \
# 0           NaN          POD  WaDE Blank     POD10000        NaN       well
#
#   StateCV  USGSSiteID   WaterSourceUUID WaterSourceTypeCV
# 0      OR         NaN  ORwr_WSwadeID315       Groundwater

# %%
# Convert extracted water right sites -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gdfs1 = gpd.GeoDataFrame(dfs1, geometry=gpd.points_from_xy(dfs1.Longitude.astype(float), dfs1.Latitude.astype(float)), crs="EPSG:4326")
gplt.pointplot(gdfs1, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Select sites within polygon.
gdfs1_ru1 = gpd.sjoin(left_df=gdfs1, right_df=gdfru1[['ReportingUnitUUID', 'RegulatoryOverlayUUID', 'geometry']], op='within').replace(np.nan, "")
print(len(gdfs1_ru1))
gdfs1_ru1.head()
# Out:
# C:\Users\rjame\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# 78952
#            SiteUUID RegulatoryOverlayUUIDs    WaterSourceUUIDs  \
# 0    ORwr_SPOD10000                           ORwr_WSwadeID315
# 17  ORwr_SPOD100039                            ORwr_WSwadeID70
# 18  ORwr_SPOD100040                            ORwr_WSwadeID15
# 19  ORwr_SPOD100041                         ORwr_WSwadeID11650
# 20  ORwr_SPOD100042                            ORwr_WSwadeID70
#
#    CoordinateAccuracy CoordinateMethodCV      County  EPSGCodeCV Geometry  \
# 0          WaDE Blank         WaDE Blank  WaDE Blank        4326
# 17         WaDE Blank         WaDE Blank  WaDE Blank        4326
# 18         WaDE Blank         WaDE Blank  WaDE Blank        4326
# 19         WaDE Blank         WaDE Blank  WaDE Blank        4326
# 20         WaDE Blank         WaDE Blank  WaDE Blank        4326
#
#    GNISCodeCV HUC12 HUC8  Latitude  Longitude NHDNetworkStatusCV NHDProductCV  \
# 0                         45.20715 -123.05841
# 17                        45.07585 -123.10284
# 18                        45.07585 -123.10284
# 19                        45.07723 -123.10461
# 20                        45.07585 -123.10284
#
#    PODorPOUSite    SiteName SiteNativeID SitePoint SiteTypeCV StateCV  \
# 0           POD  WaDE Blank     POD10000                 well      OR
# 17          POD  WaDE Blank    POD100039               stream      OR
# 18          POD  WaDE Blank    POD100040               stream      OR
# 19          POD  WaDE Blank    POD100041            reservoir      OR
# 20          POD  WaDE Blank    POD100042               stream      OR
#
#    USGSSiteID     WaterSourceUUID WaterSourceTypeCV  \
# 0                ORwr_WSwadeID315       Groundwater
# 17                ORwr_WSwadeID70           Storage
# 18                ORwr_WSwadeID15     Surface Water
# 19             ORwr_WSwadeID11650     Surface Water
# 20                ORwr_WSwadeID70           Storage
#
#                        geometry  index_right ReportingUnitUUID  \
# 0   POINT (-123.05841 45.20715)           10        ORre_RUor2
# 17  POINT (-123.10284 45.07585)           10        ORre_RUor2
# 18  POINT (-123.10284 45.07585)           10        ORre_RUor2
# 19  POINT (-123.10461 45.07723)           10        ORre_RUor2
# 20  POINT (-123.10284 45.07585)           10        ORre_RUor2
#
#    RegulatoryOverlayUUID
# 0             ORre_ROor2
# 17            ORre_ROor2
# 18            ORre_ROor2
# 19            ORre_ROor2
# 20            ORre_ROor2

# %%
# plot the selected points
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gplt.pointplot(gdfs1_ru1, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# set RegulatoryOverlayUUIDs
gdfs1_ru1['RegulatoryOverlayUUIDs'] = gdfs1_ru1['RegulatoryOverlayUUID']
gdfs1_ru1 = gdfs1_ru1.drop(['RegulatoryOverlayUUID', 'geometry', 'index_right', 'ReportingUnitUUID', 'WaterSourceUUID', 'WaterSourceTypeCV'], axis=1)
gdfs1_ru1.head(1)
# Out:
#          SiteUUID RegulatoryOverlayUUIDs  WaterSourceUUIDs CoordinateAccuracy  \
# 0  ORwr_SPOD10000             ORre_ROor2  ORwr_WSwadeID315         WaDE Blank
#
#   CoordinateMethodCV      County  EPSGCodeCV Geometry GNISCodeCV HUC12 HUC8  \
# 0         WaDE Blank  WaDE Blank        4326
#
#    Latitude  Longitude NHDNetworkStatusCV NHDProductCV PODorPOUSite  \
# 0  45.20715 -123.05841                                          POD
#
#      SiteName SiteNativeID SitePoint SiteTypeCV StateCV USGSSiteID
# 0  WaDE Blank     POD10000                 well      OR

# %% [markdown]
# #### Regulatory Area Data #2

# %%
# dfru2 = dfru.copy()
# etc etc

# %% [markdown]
# ## Concatenate all Regulatory Area Data Types together
# - drop geometry from the wade wr sites.csv geodataframe

# %%
# Concatenate dataframes into single output
frames = [dfs, gdfs1_ru1] # list all out dataframes here
outdfs = pd.concat(frames)
outdfs = outdfs.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
outdfs = outdfs.groupby('SiteUUID').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem != ""])).replace(np.nan, "").reset_index()
print(len(outdfs))
outdfs.head(1)
# Out:
# 193681
#          SiteUUID RegulatoryOverlayUUIDs  WaterSourceUUIDs CoordinateAccuracy  \
# 0  ORwr_SPOD10000             ORre_ROor2  ORwr_WSwadeID315         WaDE Blank
#
#   CoordinateMethodCV      County EPSGCodeCV Geometry GNISCodeCV HUC12 HUC8  \
# 0         WaDE Blank  WaDE Blank       4326
#
#             Latitude            Longitude NHDNetworkStatusCV NHDProductCV  \
# 0  45.20715210600008  -123.05841099299992
#
#   PODorPOUSite    SiteName SiteNativeID SitePoint SiteTypeCV StateCV  \
# 0          POD  WaDE Blank     POD10000                 well      OR
#
#   USGSSiteID   WaterSourceUUID WaterSourceTypeCV
# 0             ORwr_WSwadeID315       Groundwater

# %% [markdown]
# # Inspect Output Data & Export

# %%
outdfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193681 entries, 0 to 193680
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   SiteUUID                193681 non-null  object
#  1   RegulatoryOverlayUUIDs  193681 non-null  object
#  2   WaterSourceUUIDs        193681 non-null  object
#  3   CoordinateAccuracy      193681 non-null  object
#  4   CoordinateMethodCV      193681 non-null  object
#  5   County                  193681 non-null  object
#  6   EPSGCodeCV              193681 non-null  object
#  7   Geometry                193681 non-null  object
#  8   GNISCodeCV              193681 non-null  object
#  9   HUC12                   193681 non-null  object
#  10  HUC8                    193681 non-null  object
#  11  Latitude                193681 non-null  object
#  12  Longitude               193681 non-null  object
#  13  NHDNetworkStatusCV      193681 non-null  object
#  14  NHDProductCV            193681 non-null  object
#  15  PODorPOUSite            193681 non-null  object
#  16  SiteName                193681 non-null  object
#  17  SiteNativeID            193681 non-null  object
#  18  SitePoint               193681 non-null  object
#  19  SiteTypeCV              193681 non-null  object
#  20  StateCV                 193681 non-null  object
#  21  USGSSiteID              193681 non-null  object
#  22  WaterSourceUUID         193681 non-null  object
#  23  WaterSourceTypeCV       193681 non-null  object
# dtypes: object(24)
# memory usage: 35.5+ MB

# %%
outdfs
# Out:
#                 SiteUUID RegulatoryOverlayUUIDs   WaterSourceUUIDs  \
# 0         ORwr_SPOD10000             ORre_ROor2   ORwr_WSwadeID315
# 1        ORwr_SPOD100000             ORre_ROor8   ORwr_WSwadeID865
# 2        ORwr_SPOD100001             ORre_ROor8   ORwr_WSwadeID865
# 3        ORwr_SPOD100002             ORre_ROor8   ORwr_WSwadeID865
# 4        ORwr_SPOD100011             ORre_ROor4   ORwr_WSwadeID315
# ...                  ...                    ...                ...
# 193676    ORwr_SPOU99997                         ORwr_WSwadeID6054
# 193677  ORwr_SPOU99998_1                           ORwr_WSwadeID48
# 193678  ORwr_SPOU99998_2                           ORwr_WSwadeID15
# 193679  ORwr_SPOU99999_1                           ORwr_WSwadeID48
# 193680  ORwr_SPOU99999_2                           ORwr_WSwadeID15
#
#        CoordinateAccuracy CoordinateMethodCV      County EPSGCodeCV  \
# 0              WaDE Blank         WaDE Blank  WaDE Blank       4326
# 1              WaDE Blank         WaDE Blank  WaDE Blank       4326
# 2              WaDE Blank         WaDE Blank  WaDE Blank       4326
# 3              WaDE Blank         WaDE Blank  WaDE Blank       4326
# 4              WaDE Blank         WaDE Blank  WaDE Blank       4326
# ...                   ...                ...         ...        ...
# 193676         WaDE Blank         WaDE Blank  WaDE Blank       4326
# 193677         WaDE Blank         WaDE Blank  WaDE Blank       4326
# 193678         WaDE Blank         WaDE Blank  WaDE Blank       4326
# 193679         WaDE Blank         WaDE Blank  WaDE Blank       4326
# 193680         WaDE Blank         WaDE Blank  WaDE Blank       4326
#
#                                                  Geometry GNISCodeCV HUC12  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...        ...   ...
# 193676  POLYGON ((-123.9044735440188 44.73248046789933...
# 193677
# 193678
# 193679
# 193680
#
#        HUC8           Latitude            Longitude NHDNetworkStatusCV  \
# 0            45.20715210600008  -123.05841099299992
# 1            45.49223444200004  -117.87363050099998
# 2            45.52683366200006  -117.88435207199996
# 3            45.52122747100003  -117.88161490799996
# 4            45.61262332100006  -121.26713276899994
# ...     ...                ...                  ...                ...
# 193676           44.7323816676       -123.904561295
# 193677           44.5887199454        -123.61761569
# 193678           44.5887199454        -123.61761569
# 193679           44.5886308513       -123.617347815
# 193680           44.5886308513       -123.617347815
#
#        NHDProductCV PODorPOUSite    SiteName SiteNativeID SitePoint  \
# 0                            POD  WaDE Blank     POD10000
# 1                            POD  WaDE Blank    POD100000
# 2                            POD  WaDE Blank    POD100001
# 3                            POD  WaDE Blank    POD100002
# 4                            POD  WaDE Blank    POD100011
# ...             ...          ...         ...          ...       ...
# 193676                       POU  WaDE Blank     POU99997
# 193677                       POU  WaDE Blank   POU99998_1
# 193678                       POU  WaDE Blank   POU99998_2
# 193679                       POU  WaDE Blank   POU99999_1
# 193680                       POU  WaDE Blank   POU99999_2
#
#         SiteTypeCV StateCV USGSSiteID    WaterSourceUUID WaterSourceTypeCV
# 0             well      OR              ORwr_WSwadeID315       Groundwater
# 1           stream      OR              ORwr_WSwadeID865     Surface Water
# 2           stream      OR              ORwr_WSwadeID865     Surface Water
# 3           stream      OR              ORwr_WSwadeID865     Surface Water
# 4             well      OR              ORwr_WSwadeID315       Groundwater
# ...            ...     ...        ...                ...               ...
# 193676  WaDE Blank      OR             ORwr_WSwadeID6054     Surface Water
# 193677  WaDE Blank      OR               ORwr_WSwadeID48     Surface Water
# 193678  WaDE Blank      OR               ORwr_WSwadeID15     Surface Water
# 193679  WaDE Blank      OR               ORwr_WSwadeID48     Surface Water
# 193680  WaDE Blank      OR               ORwr_WSwadeID15     Surface Water
#
# [193681 rows x 24 columns]

# %%
# Export out to CSV.
outdfs.to_csv('ProcessedInputData/sites.csv', index=False) # this is in the Regulatory data folder
