# %% [markdown]
# # Pre-processing Oregon Allocation data for WaDEQA upload.
# Date Updated: 11/03/2020
# Purpose:  To pre-process the Oregon data into one master file for simple DataFrame creation and extraction
#
# Useful Links to Data:
#
# 1) Data Avalaible (use 'Statewide Water Right Spatial Data with Metadata'): https://www.oregon.gov/OWRD/access_Data/Pages/Data.aspx
#
# 2) POD metadata: https://arcgis.wrd.state.or.us/data/wr_pod_metadata.pdf
#
# 3) PoU metadata: https://arcgis.wrd.state.or.us/data/wr_pou_metadata.pdf

# %%
# Needed Libararies
import os
import numpy as np
import pandas as pd
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
# Working Directory and Input File
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Oregon/WaterAllocation/RawInputData"
os.chdir(workingDir)
PoDFile = "ORwr_v_pod_public_input.csv"  # contains PoD info

# %%
# Dataframe creation
df = pd.read_csv(PoDFile, encoding = "ISO-8859-1") #Input
# Out:
# C:\Users\rjame\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,12,21,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         OBJECTID              pod_display pod_display_short  \
# 0              1  Permit: G  10961 * MI            G  10961
# 1              2  Permit: G  10961 * MI            G  10961
# 2              3  Permit: G  12684 * MI            G  12684
# 3              4  Permit: G  12750 * MI            G  12750
# 4              5  Permit: G  12750 * MI            G  12750
# ...          ...                      ...               ...
# 189817    189818  Permit: R  15430 * WI            R  15430
# 189818    189819  Permit: R  15430 * WI            R  15430
# 189819    189820  Permit: R  15430 * WI            R  15430
# 189820    189821  Permit: R  13003 * WI            R  13003
# 189821    189822  Permit: R  13003 * WI            R  13003
#
#                                                 wris_link  snp_id  \
# 0       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   21755
# 1       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   21755
# 2       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   23327
# 3       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   23390
# 4       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   23390
# ...                                                   ...     ...
# 189817  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...  202390
# 189818  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...  202390
# 189819  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...  202390
# 189820  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   33683
# 189821  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   33683
#
#         pod_location_id  pod_use_id app_char  app_nbr permit_char  permit_nbr  \
# 0                  6909       26859       G   11987.0          G      10961.0
# 1                  6910       26860       G   11987.0          G      10961.0
# 2                  9355       29682       G   13684.0          G      12684.0
# 3                  9480       29835       G   13944.0          G      12750.0
# 4                  9480       29836       G   13944.0          G      12750.0
# ...                 ...         ...      ...      ...         ...         ...
# 189817           344799      786691       R   88456.0          R      15430.0
# 189818           344799      786692       R   88456.0          R      15430.0
# 189819           344799      786699       R   88456.0          R      15430.0
# 189820            34240      787503       R   84451.0          R      13003.0
# 189821            34239      787506       R   84451.0          R      13003.0
#
#         cert_nbr claim_char  claim_nbr decree_title transfer_nbr wr_type  \
# 0            NaN        NaN        NaN          NaN          NaN     GW
# 1            NaN        NaN        NaN          NaN          NaN     GW
# 2            NaN        NaN        NaN          NaN          NaN     GW
# 3            NaN        NaN        NaN          NaN          NaN     GW
# 4            NaN        NaN        NaN          NaN          NaN     GW
# ...          ...        ...        ...          ...          ...     ...
# 189817       NaN        NaN        NaN          NaN          NaN     ST
# 189818       NaN        NaN        NaN          NaN          NaN     ST
# 189819       NaN        NaN        NaN          NaN          NaN     ST
# 189820       NaN        NaN        NaN          NaN          NaN     ST
# 189821       NaN        NaN        NaN          NaN          NaN     ST
#
#        name_last    name_first              name_company  pod_nbr pod_char  \
# 0            NaN           NaN  FORMOSA EXPLORATION INC.        1      NaN
# 1            NaN           NaN  FORMOSA EXPLORATION INC.        2      NaN
# 2            NaN           NaN          DUTCH MINING LLC        1      NaN
# 3       STEYAERT          JEFF         KNIFE RIVER CORP.        1      NaN
# 4       STEYAERT          JEFF         KNIFE RIVER CORP.        1      NaN
# ...          ...           ...                       ...      ...      ...
# 189817   URSTADT  ERIC ANTHONY                       NaN        1      NaN
# 189818   URSTADT  ERIC ANTHONY                       NaN        1      NaN
# 189819   URSTADT  ERIC ANTHONY                       NaN        1      NaN
# 189820    MADDOX         ALTON                       NaN        2      NaN
# 189821    MADDOX         ALTON                       NaN        1      NaN
#
#        source_type use_code use_category use_code_description  \
# 0              WE      MI              0               MINING
# 1              WE      MI              0               MINING
# 2              WE      MI              0               MINING
# 3              WE      MI              0               MINING
# 4              WE      MI              0               MINING
# ...            ...      ...          ...                  ...
# 189817         WR      WI              W             WILDLIFE
# 189818         WR      WI              W             WILDLIFE
# 189819         WR      WI              W             WILDLIFE
# 189820         WE      WI              W             WILDLIFE
# 189821         WR      WI              W             WILDLIFE
#
#              priority_date  duty  rate_cfs  rate_cfs_est  max_rate_cfs  \
# 0       11/21/1989 0:00:00   NaN     0.040             0         0.040
# 1       11/21/1989 0:00:00   NaN     0.005             0         0.005
# 2         5/6/1994 0:00:00   NaN     0.110             1         0.220
# 3        1/18/1995 0:00:00   NaN     0.670             0         0.670
# 4        1/18/1995 0:00:00   NaN     0.110             0         0.110
# ...                    ...   ...       ...           ...           ...
# 189817    9/5/2017 0:00:00   NaN       NaN             0           NaN
# 189818    9/5/2017 0:00:00   NaN       NaN             0           NaN
# 189819    9/5/2017 0:00:00   NaN       NaN             0           NaN
# 189820   6/10/2000 0:00:00   NaN       NaN             0           NaN
# 189821   6/10/2000 0:00:00   NaN       NaN             0           NaN
#
#         acre_feet  acre_feet_est  max_rate_acre_feet  \
# 0             NaN              0                 NaN
# 1             NaN              0                 NaN
# 2             NaN              0                 NaN
# 3             NaN              0                 NaN
# 4             NaN              0                 NaN
# ...           ...            ...                 ...
# 189817     1.5375              1                12.3
# 189818     1.5375              1                12.3
# 189819     4.1000              1                12.3
# 189820     0.2187              1                 3.5
# 189821     0.2187              1                 3.5
#
#                                                    source  \
# 0       FORMOSA 1 ADIT                                ...
# 1       SILVER BUTTE 1 ADIT                           ...
# 2       A WELL                                        ...
# 3                                                  A WELL
# 4                                                  A WELL
# ...                                                   ...
# 189817                                             RUNOFF
# 189818                                             RUNOFF
# 189819                                             RUNOFF
# 189820                                             A WELL
# 189821                                             RUNOFF
#
#                           tributary_to            streamcode  \
# 0       CANYON CREEK                    16125009000400430220
# 1       CANYON CREEK                    16125009000400430220
# 2       ROGUE RIVER                           15168010500040
# 3                    TROUT CREEK BASIN     05198012200060050
# 4                    TROUT CREEK BASIN     05198012200060050
# ...                                ...                   ...
# 189817           EAST FORK DAIRY CREEK     02114003000480080
# 189818           EAST FORK DAIRY CREEK     02114003000480080
# 189819           EAST FORK DAIRY CREEK     02114003000480080
# 189820                 ABERNATHY CREEK        02114002500150
# 189821                 ABERNATHY CREEK        02114002500150
#
#                       stream_name  supplemental  begin_month  begin_day  \
# 0             UNN STR > MIDDLE CR             0          1.0        1.0
# 1             UNN STR > MIDDLE CR             0          1.0        1.0
# 2            DRAIN CR > WHISKY CR             0          1.0        1.0
# 3       TROUT CR > INDIAN FORD CR             0          1.0        1.0
# 4       TROUT CR > INDIAN FORD CR             0          1.0        1.0
# ...                           ...           ...          ...        ...
# 189817   E FK DAIRY CR > DAIRY CR             0         12.0        1.0
# 189818   E FK DAIRY CR > DAIRY CR             0          1.0        1.0
# 189819   E FK DAIRY CR > DAIRY CR             0          5.0        1.0
# 189820     UNN STR > ABERNETHY CR             0          1.0        1.0
# 189821     UNN STR > ABERNETHY CR             0          1.0        1.0
#
#         end_month  end_day technician_initials agency  rec_creation_date  \
# 0            12.0     31.0               MIGRT   OWRD   6/1/1996 0:00:00
# 1            12.0     31.0               MIGRT   OWRD   6/1/1996 0:00:00
# 2            12.0     31.0               MIGRT   OWRD   6/1/2001 0:00:00
# 3            12.0     31.0               MIGRT   OWRD   5/1/2001 0:00:00
# 4            12.0     31.0               MIGRT   OWRD   5/1/2001 0:00:00
# ...           ...      ...                 ...    ...                ...
# 189817       12.0     31.0                 SLB   OWRD  2/19/2020 0:00:00
# 189818        4.0     30.0                 SLB   OWRD  2/19/2020 0:00:00
# 189819       11.0     30.0                 SLB   OWRD  2/19/2020 0:00:00
# 189820        6.0     30.0                 SLB   OWRD  3/11/2020 0:00:00
# 189821        6.0     30.0                 SLB   OWRD  3/11/2020 0:00:00
#
#             last_updt_date  feature_quality_code  \
# 0         6/1/1996 0:00:00                   NaN
# 1         6/1/1996 0:00:00                   NaN
# 2         6/1/2001 0:00:00                   NaN
# 3         5/1/2001 0:00:00                   NaN
# 4         5/1/2001 0:00:00                   NaN
# ...                    ...                   ...
# 189817  2/20/2020 15:10:24                  30.0
# 189818  2/20/2020 15:10:24                  30.0
# 189819  2/20/2020 15:10:24                  30.0
# 189820  3/11/2020 14:04:21                  30.0
# 189821  3/11/2020 14:04:21                  30.0
#
#                                          remarks       POINT_X       POINT_Y
# 0                                 0 G   10961  1  5.394125e+05  4.167058e+05
# 1                                 0 G   10961  2  5.392329e+05  4.162520e+05
# 2                                 0 G   12684  1  4.709328e+05  3.559155e+05
# 3                                 0 G   12750  1  1.010124e+06  9.319935e+05
# 4                                 0 G   12750  1  1.010124e+06  9.319935e+05
# ...                                          ...           ...           ...
# 189817  MEASURED DISTANCE; MOVED RELATIVE TO POU  6.532996e+05  1.447329e+06
# 189818  MEASURED DISTANCE; MOVED RELATIVE TO POU  6.532996e+05  1.447329e+06
# 189819  MEASURED DISTANCE; MOVED RELATIVE TO POU  6.532996e+05  1.447329e+06
# 189820                 PLACED USING 2018 IMAGERY  8.075046e+05  1.302937e+06
# 189821                    PLACED RELATIVE TO POU  8.076530e+05  1.302536e+06
#
# [189822 rows x 51 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.dtypes)
# Out:
# OBJECTID                  int64
# pod_display              object
# pod_display_short        object
# wris_link                object
# snp_id                    int64
# pod_location_id           int64
# pod_use_id                int64
# app_char                 object
# app_nbr                 float64
# permit_char              object
# permit_nbr              float64
# cert_nbr                float64
# claim_char               object
# claim_nbr               float64
# decree_title             object
# transfer_nbr             object
# wr_type                  object
# name_last                object
# name_first               object
# name_company             object
# pod_nbr                   int64
# pod_char                 object
# source_type              object
# use_code                 object
# use_category             object
# use_code_description     object
# priority_date            object
# duty                    float64
# rate_cfs                float64
# rate_cfs_est              int64
# max_rate_cfs            float64
# acre_feet               float64
# acre_feet_est             int64
# max_rate_acre_feet      float64
# source                   object
# tributary_to             object
# streamcode               object
# stream_name              object
# supplemental              int64
# begin_month             float64
# begin_day               float64
# end_month               float64
# end_day                 float64
# technician_initials      object
# agency                   object
# rec_creation_date        object
# last_updt_date           object
# feature_quality_code    float64
# remarks                  object
# POINT_X                 float64
# POINT_Y                 float64
# dtype: object

# %%
# Create Purge dataframe to note data that was removed for WaDE purposes.
columnslist = df.columns.tolist()
dfpurge = pd.DataFrame(columns=columnslist)  # purge DataFrame
dfpurge = dfpurge.assign(ReasonRemoved='')
dfpurge
# Out:
# Empty DataFrame
# Columns: [OBJECTID, pod_display, pod_display_short, wris_link, snp_id, pod_location_id, pod_use_id, app_char, app_nbr, permit_char, permit_nbr, cert_nbr, claim_char, claim_nbr, decree_title, transfer_nbr, wr_type, name_last, name_first, name_company, pod_nbr, pod_char, source_type, use_code, use_category, use_code_description, priority_date, duty, rate_cfs, rate_cfs_est, max_rate_cfs, acre_feet, acre_feet_est, max_rate_acre_feet, source, tributary_to, streamcode, stream_name, supplemental, begin_month, begin_day, end_month, end_day, technician_initials, agency, rec_creation_date, last_updt_date, feature_quality_code, remarks, POINT_X, POINT_Y, ReasonRemoved]
# Index: []

# %%
# Changing datatype of used date fields. 
df['priority_date'] = pd.to_datetime(df['priority_date'], errors = 'coerce')
df['priority_date'] = pd.to_datetime(df["priority_date"].dt.strftime('%m/%d/%Y'))

# %%
# Removing NaN, and missing (999) values from max_rate_acre_feet.  Need an amount value for WaDE.
mask = df.loc[ (df['max_rate_acre_feet'] == 999) | (df['max_rate_acre_feet'].isnull()) ].assign(ReasonRemoved='Null max_rate_acre_feet').reset_index()
if len(mask.index) > 0:
    dfpurge = dfpurge.append(mask)  # Append to purge DataFrame
    dropIndex = df.loc[ (df['max_rate_acre_feet'] == 999) | (df['max_rate_acre_feet'].isnull()) ].index
    df = df.drop(dropIndex)
    df = df.reset_index(drop=True)
df.head(3)
# Out:
#    OBJECTID              pod_display pod_display_short  \
# 0        42  Permit: S  53648 * MI            S  53648
# 1        94      Cert:3592 OR * MI                3592
# 2       385     Cert:12006 OR * MI               12006
#
#                                            wris_link  snp_id  pod_location_id  \
# 0  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   51887            47388
# 1  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   55967            52723
# 2  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   64395            64098
#
#    pod_use_id app_char  app_nbr permit_char  permit_nbr  cert_nbr claim_char  \
# 0       56626       S   84101.0          S      53648.0       NaN        NaN
# 1       61998       R    7012.0          R        467.0    3592.0        NaN
# 2       74743       R   15462.0          R        675.0   12006.0        NaN
#
#    claim_nbr decree_title transfer_nbr wr_type name_last name_first  \
# 0        NaN          NaN          NaN     SW        NaN        NaN
# 1        NaN          NaN          NaN     ST     LEHMAN      DAVID
# 2        NaN          NaN          NaN     ST    MAGERLE   CARLOS A
#
#                       name_company  pod_nbr pod_char source_type use_code  \
# 0  KNAPP RANCHES INC.; KNAPP, JEFF        1      NaN         RS      MI
# 1                              NaN        1      NaN         ST      MI
# 2                              NaN        1      NaN         ST      MI
#
#   use_category use_code_description priority_date  duty  rate_cfs  \
# 0            0               MINING    1999-03-24   2.5       0.0
# 1            0               MINING    1920-01-22   NaN       0.0
# 2            0               MINING    1934-08-07   NaN       0.0
#
#    rate_cfs_est  max_rate_cfs  acre_feet  acre_feet_est  max_rate_acre_feet  \
# 0             0           0.0       40.0              0                40.0
# 1             0           0.0        3.0              0                 3.0
# 2             0           0.0        5.7              0                 5.7
#
#                                               source  \
# 0  A RESERVOIR                                   ...
# 1  WOLF CREEK                                    ...
# 2  WARD CREEK                                    ...
#
#                      tributary_to      streamcode            stream_name  \
# 0  ELK RIVER                               171590  ELK R > PACIFIC OCEAN
# 1  GRAVE CREEK                     15168011100150     WOLF CR > GRAVE CR
# 2  ROGUE RIVER                         1516801750      WARD CR > ROGUE R
#
#    supplemental  begin_month  begin_day  end_month  end_day  \
# 0             0          1.0        1.0       12.0     31.0
# 1             0          1.0        1.0       12.0     31.0
# 2             0          1.0        1.0       12.0     31.0
#
#   technician_initials agency    rec_creation_date    last_updt_date  \
# 0                 KLS   OWRD  10/26/2007 12:42:34               NaN
# 1               MIGRT   OWRD     6/1/2001 0:00:00  6/1/2001 0:00:00
# 2               MIGRT   OWRD     6/1/2001 0:00:00  6/1/2001 0:00:00
#
#    feature_quality_code                                            remarks  \
# 0                  10.0  Automapped as center of the envelope for the T...
# 1                   NaN                                  3592 R     467  1
# 2                   NaN                                 12006 R     675  1
#
#          POINT_X        POINT_Y
# 0  236258.299869  403105.375000
# 1  566863.041667  365284.141732
# 2  608290.608268  281559.799869

# %%
# Removing NaN, and missing (999) values from rate_cfs.  Need an amount value for WaDE.
mask = df.loc[ (df['rate_cfs'] == 999) | (df['rate_cfs'].isnull()) ].assign(ReasonRemoved='Null rate_cfs').reset_index()
if len(mask.index) > 0:
    dfpurge = dfpurge.append(mask)  # Append to purge DataFrame
    dropIndex = df.loc[ (df['rate_cfs'] == 999) | (df['rate_cfs'].isnull()) ].index
    df = df.drop(dropIndex)
    df = df.reset_index(drop=True)
df.head(3)
# Out:
#    OBJECTID              pod_display pod_display_short  \
# 0        42  Permit: S  53648 * MI            S  53648
# 1        94      Cert:3592 OR * MI                3592
# 2       385     Cert:12006 OR * MI               12006
#
#                                            wris_link  snp_id  pod_location_id  \
# 0  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   51887            47388
# 1  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   55967            52723
# 2  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   64395            64098
#
#    pod_use_id app_char  app_nbr permit_char  permit_nbr  cert_nbr claim_char  \
# 0       56626       S   84101.0          S      53648.0       NaN        NaN
# 1       61998       R    7012.0          R        467.0    3592.0        NaN
# 2       74743       R   15462.0          R        675.0   12006.0        NaN
#
#    claim_nbr decree_title transfer_nbr wr_type name_last name_first  \
# 0        NaN          NaN          NaN     SW        NaN        NaN
# 1        NaN          NaN          NaN     ST     LEHMAN      DAVID
# 2        NaN          NaN          NaN     ST    MAGERLE   CARLOS A
#
#                       name_company  pod_nbr pod_char source_type use_code  \
# 0  KNAPP RANCHES INC.; KNAPP, JEFF        1      NaN         RS      MI
# 1                              NaN        1      NaN         ST      MI
# 2                              NaN        1      NaN         ST      MI
#
#   use_category use_code_description priority_date  duty  rate_cfs  \
# 0            0               MINING    1999-03-24   2.5       0.0
# 1            0               MINING    1920-01-22   NaN       0.0
# 2            0               MINING    1934-08-07   NaN       0.0
#
#    rate_cfs_est  max_rate_cfs  acre_feet  acre_feet_est  max_rate_acre_feet  \
# 0             0           0.0       40.0              0                40.0
# 1             0           0.0        3.0              0                 3.0
# 2             0           0.0        5.7              0                 5.7
#
#                                               source  \
# 0  A RESERVOIR                                   ...
# 1  WOLF CREEK                                    ...
# 2  WARD CREEK                                    ...
#
#                      tributary_to      streamcode            stream_name  \
# 0  ELK RIVER                               171590  ELK R > PACIFIC OCEAN
# 1  GRAVE CREEK                     15168011100150     WOLF CR > GRAVE CR
# 2  ROGUE RIVER                         1516801750      WARD CR > ROGUE R
#
#    supplemental  begin_month  begin_day  end_month  end_day  \
# 0             0          1.0        1.0       12.0     31.0
# 1             0          1.0        1.0       12.0     31.0
# 2             0          1.0        1.0       12.0     31.0
#
#   technician_initials agency    rec_creation_date    last_updt_date  \
# 0                 KLS   OWRD  10/26/2007 12:42:34               NaN
# 1               MIGRT   OWRD     6/1/2001 0:00:00  6/1/2001 0:00:00
# 2               MIGRT   OWRD     6/1/2001 0:00:00  6/1/2001 0:00:00
#
#    feature_quality_code                                            remarks  \
# 0                  10.0  Automapped as center of the envelope for the T...
# 1                   NaN                                  3592 R     467  1
# 2                   NaN                                 12006 R     675  1
#
#          POINT_X        POINT_Y
# 0  236258.299869  403105.375000
# 1  566863.041667  365284.141732
# 2  608290.608268  281559.799869

# %%
#Determining Company vs Individual. Concatenating name of individual.
def assignownerName(colrowValue1, colrowValue2):
    if colrowValue1 == '' or pd.isnull(colrowValue1):
        outList1 = ''
    else:
        outList1 = colrowValue1.strip()  # remove whitespace chars
    if colrowValue2 == '' or pd.isnull(colrowValue2):
        outList2 = ''
    else:
        outList2 = colrowValue2.strip()  # remove whitespace chars

    if outList1 == '' and outList2 == '':
        outList = ''
    elif outList1 == '':
        outList = outList2
    elif outList2 == '':
        outList = outList1
    else:
        outList = ", ".join(map(str, [colrowValue1, colrowValue2]))
    return outList


def assignownerNameORCompany(colrowValue1, colrowValue2, colrowValue3):
    if colrowValue1 == '' or pd.isnull(colrowValue1):
        outList = assignownerName(colrowValue2, colrowValue3)
    else:
        outList = colrowValue1
    return outList

df['Owner'] = df.apply(lambda row: assignownerNameORCompany(row['name_company'], row['name_last'], row['name_first']), axis=1)

# %%
#Determining AllocationTimeframe Start & End time for each site.

def formatDateString(inString1, inString2):
    #print(inString)
    try:
        valndf = str(int(inString1)).strip() + '/' + str(int(inString2)).strip()
    except:
        valndf = ''

    return valndf;

df['AllocationTimeframeStart'] = df.apply(lambda row: formatDateString(row['begin_month'], row['begin_day']), axis=1)
df['AllocationTimeframeEnd'] = df.apply(lambda row: formatDateString(row['end_month'], row['end_day']), axis=1)

# %%
#Fixing Beneficial Uses PRIMARY_PURPOSE
def fixBenUse(colrowValue):
    if colrowValue == 'IRRIGATION, LIVESTOCK AND DOMESTIC':
        outList = 'IRRIGATION LIVESTOCK AND DOMESTIC'
    else:
        outList = colrowValue
    return outList

df['use_code_description'] = df.apply(lambda row: fixBenUse(row['use_code_description']), axis=1)

# %%
#Exporting to Finished File
df.to_csv('P_OregonMaster.csv', index=False)  # The output
dfpurge.to_csv('inputOregonDataRemoved.csv', index=False)  # Error check for states to see why we removed certaind data.
