# %% [markdown]
# # Pre-processing Oregon Allocation data for WaDEQA upload.
# Date Updated: 11/03/2020
# Purpose:  To pre-process the Oregon data into one master file for simple DataFrame creation and extraction
#
# Useful Links to Data:
#
# - Data Avalaible (use 'Statewide Water Right Spatial Data with Metadata'): https://www.oregon.gov/OWRD/access_Data/Pages/Data.aspx
#
# - POD metadata: https://arcgis.wrd.state.or.us/data/wr_pod_metadata.pdfPOD
#
# - POU metadata: https://arcgis.wrd.state.or.us/data/wr_pou_metadata.pdfPOD

# %%
# Needed Libararies
import os
import numpy as np
import pandas as pd
import geopandas as gpd # the library that lets us read in shapefiles
from datetime import datetime
from pyproj import Transformer, transform
transformer = Transformer.from_proj(2992, 4326)
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
# Working Directory
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Oregon/WaterAllocation/RawInputData"
os.chdir(workingDir)

# %%
columnsList = [
    "in_WaterSourceName",
    "in_WaterSourceTypeCV",
    "in_Latitude",
    "in_Longitude",
    "in_PODorPOUSite",
    "in_SiteName",
    "in_SiteNativeID",
    "in_SiteTypeCV",
    "in_AllocationFlow_CFS",
    "in_AllocationVolume_AF",
    "in_AllocationOwner",
    "in_AllocationTimeframeEnd",
    "in_AllocationTimeframeStart",
    "in_IrrigatedAcreage",
    "snp_id",
    "priority_date",
    "claim_char",
    "use_code_description",
    "wris_link"]

# %% [markdown]
# ## Point of Diversoin Data

# %%
# Dataframe creation
Podfile = "ORwr_v_pod_public_input.csv"  # contains PoD info
df = pd.read_csv(Podfile, encoding = "ISO-8859-1")
print(len(df))
df.head(3)
# Out:
# 189822
# C:\Users\rjame\AppData\Local\Temp\ipykernel_14912\2459566426.py:3: DtypeWarning: Columns (12,26,27,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(Podfile, encoding = "ISO-8859-1")
#    OBJECTID  snp_id  app_nbr              pod_display  permit_nbr  acre_feet  \
# 0         1   21755  11987.0  Permit: G  10961 * MI       10961.0        NaN
# 1         2   21755  11987.0  Permit: G  10961 * MI       10961.0        NaN
# 2         3   23327  13684.0  Permit: G  12684 * MI       12684.0        NaN
#
#    acre_feet_est agency app_char  begin_day  begin_month  cert_nbr claim_char  \
# 0              0   OWRD       G         1.0          1.0       NaN        NaN
# 1              0   OWRD       G         1.0          1.0       NaN        NaN
# 2              0   OWRD       G         1.0          1.0       NaN        NaN
#
#    claim_nbr decree_title  duty  end_day  end_month  feature_quality_code  \
# 0        NaN          NaN   NaN     31.0       12.0                   NaN
# 1        NaN          NaN   NaN     31.0       12.0                   NaN
# 2        NaN          NaN   NaN     31.0       12.0                   NaN
#
#   last_updt_date  max_rate_acre_feet  max_rate_cfs              name_company  \
# 0  6/1/1996 0:00                 NaN         0.040  FORMOSA EXPLORATION INC.
# 1  6/1/1996 0:00                 NaN         0.005  FORMOSA EXPLORATION INC.
# 2  6/1/2001 0:00                 NaN         0.220          DUTCH MINING LLC
#
#   name_first name_last permit_char pod_char pod_display_short  \
# 0        NaN       NaN          G       NaN          G  10961
# 1        NaN       NaN          G       NaN          G  10961
# 2        NaN       NaN          G       NaN          G  12684
#
#    pod_location_id  pod_nbr  pod_use_id      POINT_X      POINT_Y  \
# 0             6909        1       26859  539412.5499  416705.7999
# 1             6910        2       26860  539232.9167  416251.9918
# 2             9355        1       29682  470932.7999  355915.4583
#
#      priority_date  rate_cfs  rate_cfs_est rec_creation_date  \
# 0  11/21/1989 0:00     0.040             0     6/1/1996 0:00
# 1  11/21/1989 0:00     0.005             0     6/1/1996 0:00
# 2    5/6/1994 0:00     0.110             1     6/1/2001 0:00
#
#                 remarks  snp_id.1  \
# 0        0 G   10961  1     21755
# 1        0 G   10961  2     21755
# 2        0 G   12684  1     23327
#
#                                               source source_type  \
# 0  FORMOSA 1 ADIT                                ...         WE
# 1  SILVER BUTTE 1 ADIT                           ...         WE
# 2  A WELL                                        ...         WE
#
#             stream_name    streamcode  supplemental technician_initials  \
# 0   UNN STR > MIDDLE CR  1.612500e+19             0               MIGRT
# 1   UNN STR > MIDDLE CR  1.612500e+19             0               MIGRT
# 2  DRAIN CR > WHISKY CR  1.516800e+13             0               MIGRT
#
#   transfer_nbr                    tributary_to use_category use_code  \
# 0          NaN  CANYON CREEK                              0     MI
# 1          NaN  CANYON CREEK                              0     MI
# 2          NaN  ROGUE RIVER                               0     MI
#
#   use_code_description  Unnamed: 50 wr_type  \
# 0               MINING          NaN     GW
# 1               MINING          NaN     GW
# 2               MINING          NaN     GW
#
#                                            wris_link
# 0  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 1  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 2  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...

# %%
# For creating WaterSourceName
def assignWaterSourceName(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = "Unspecified"
    else:
        outList = colrowValue.strip()
    return outList

df['in_WaterSourceName'] = df.apply(lambda row: assignWaterSourceName(row['source']), axis=1)

# %%
# For creating WaterSourceTypeCV
WSTypeDict = {
    "ST": "Storage",
    "GW": "Groundwater",
    "SW": "Surface Water"}
def assignWaterSourceTypeCV(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = "Unspecified"
    else:
        String1 = colrowValue.strip()
        try:
            outList = WSTypeDict[String1]
        except:
            outList = "Unspecified"

    return outList

df['in_WaterSourceTypeCV'] = df.apply(lambda row: assignWaterSourceTypeCV(row['wr_type']), axis=1)

# %%
# For converting projection latitude.
def assignLat(colrowValueLat, colrowValueLong):
    lat, long = transformer.transform(colrowValueLat, colrowValueLong)
    return lat

# For converting projection longitude.
def assignLong(colrowValueLat, colrowValueLong):
    lat, long = transformer.transform(colrowValueLat, colrowValueLong)
    return long

df['in_Latitude'] = df.apply(lambda row: assignLat(row['POINT_X'], row['POINT_Y']), axis=1)
df['in_Longitude'] = df.apply(lambda row: assignLong(row['POINT_X'], row['POINT_Y']), axis=1)

# %%
# For creating Site Name
def assignSiteName(colrowValueA, colrowValueB):
    if (colrowValueA == '' and colrowValueB == '') or (pd.isnull(colrowValueA) and pd.isnull(colrowValueB)):
        outList = "Unspecified"
    else:
        A = str(colrowValueA).strip()
        B = str(colrowValueB).strip()
        outList = A + "_" + B
    return outList

df['in_SiteName'] = df.apply(lambda row: assignSiteName(row['snp_id'], row['pod_nbr']), axis=1)

# %%
# For creating SiteTypeCV
STCVDict = {
"LK" : "lake",
"DR" : "drain",
"SP" : "spring",
"ST" : "stream",
"SL" : "slough",
"WW" : "waste water",
"WE" : "well",
"WR" : "winter runoff",
"SM" : "sump",
"PD" : "pond",
"RS" : "reservoir",
"DT" : "ditch",
"SE" : "sewage effluent",
"CN" : "canal"}
def assignSiteTypeCV(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = "Unspecified"
    else:
        String1 = colrowValue.strip()
        try:
            outList = STCVDict[String1]
        except:
            outList = "Unspecified"
    return outList

df['in_SiteTypeCV'] = df.apply(lambda row: assignSiteTypeCV(row['source_type']), axis=1)

# %%
# Changing datatype of used date fields. 
df['priority_date'] = pd.to_datetime(df['priority_date'], errors = 'coerce')
df['priority_date'] = pd.to_datetime(df["priority_date"].dt.strftime('%m/%d/%Y'))

# %%
# Creating Ownername.
# Concatenating first and last name of individual.
# Determining if company is available, split string.
# combine together for output.

# first & last name funciton
def assignownerName(colrowValue1, colrowValue2):
    if colrowValue1 == '' or pd.isnull(colrowValue1):
        outList1 = ''
    else:
        outList1 = colrowValue1.strip()  # remove whitespace chars
    if colrowValue2 == '' or pd.isnull(colrowValue2):
        outList2 = ''
    else:
        outList2 = colrowValue2.strip()  # remove whitespace chars

    if outList1 == '' and outList2 == '':
        outList = ''
    elif outList1 == '':
        outList = outList2
    elif outList2 == '':
        outList = outList1
    else:
        outList = " ".join(map(str, [colrowValue1, colrowValue2]))
    return outList


# Business name and Concatenate
def assignownerNameORCompany(buisName, fName, lName):
    
    # Concatenating First and Last name together.
    frilasName = assignownerName(fName, lName)
    
    # Clearn Company Name Entry
    if buisName == "" or pd.isnull(buisName):
        outBuisString = ""
    else:
        buisName = str(buisName).strip()
        if ";" in buisName:
            xList = buisName.split(";")
            for index, item in enumerate(xList):
                if "," in item:
                    list1 = item.split(",")
                    list1.reverse()
                    xList[index] = "".join(list1)
                else:
                    xList[index] = item
            outBuisString = ",".join(xList)
        elif "," in buisName:
            xList = buisName.split(",")
            outBuisString = str(xList[0]).strip() + "," + str(xList[1]).strip()
        else:
            outBuisString = buisName
    
    #Concatenating together, create outString
    if frilasName == ""  or pd.isnull(frilasName):
        if outBuisString == ""  or pd.isnull(outBuisString):
            outString = "Unspecified"
        else:
            outString = outBuisString
    else:
        if outBuisString == ""  or pd.isnull(outBuisString):
            outString = frilasName
        else:
            outString = frilasName + ", " + outBuisString
        
    outString = outString.strip()
    return outString

df['in_AllocationOwner'] = df.apply(lambda row: assignownerNameORCompany(row['name_company'], row['name_first'], row['name_last']), axis=1)

# %%
#Determining AllocationTimeframe Start & End time for each site.

def formatDateString(inString1, inString2):
    #print(inString)
    try:
        valndf = str(int(inString1)).strip() + '/' + str(int(inString2)).strip()
    except:
        valndf = ''

    return valndf;

df['in_AllocationTimeframeStart'] = df.apply(lambda row: formatDateString(row['begin_month'], row['begin_day']), axis=1)
df['in_AllocationTimeframeEnd'] = df.apply(lambda row: formatDateString(row['end_month'], row['end_day']), axis=1)

# %%
#Fixing Beneficial Uses PRIMARY_PURPOSE

def fixBenUse(val):
    val = str(val).strip()
    if val == "IRRIGATION, LIVESTOCK AND DOMESTIC":
        outString = "IRRIGATION, LIVESTOCK, DOMESTIC"
    elif val == "IRRIGATION AND LIVESTOCK":
        outString = "IRRIGATION, LIVESTOCK"
    elif val == "LIVESTOCK AND WILDLIFE":
        outString = "LIVESTOCK, WILDLIFE"
    else:
        outString = val
    return outString

df['use_code_description'] = df.apply(lambda row: fixBenUse(row['use_code_description']), axis=1)

# %%
# Creating the output Dataframe for PODs.

dfPOD = pd.DataFrame(columns=columnsList, index=df.index)

# Water Source
dfPOD["in_WaterSourceName"] = df['in_WaterSourceName']
dfPOD['in_WaterSourceTypeCV'] = df['in_WaterSourceTypeCV']

# Site
dfPOD["in_Latitude"] = df['in_Latitude']
dfPOD["in_Longitude"] = df['in_Longitude']
dfPOD["in_PODorPOUSite"] = "POD"
dfPOD["in_SiteName"] = df['in_SiteName']
dfPOD["in_SiteNativeID"] = "POD" + df['pod_location_id'].astype(str)
dfPOD["in_SiteTypeCV"] = df['in_SiteTypeCV']

# Allocation
dfPOD["in_AllocationFlow_CFS"] = df['rate_cfs'].astype(float)
dfPOD["in_AllocationCropDutyAmount "] = df['duty'].astype(float)
dfPOD['in_AllocationOwner'] = df['in_AllocationOwner']
dfPOD["in_AllocationTimeframeEnd"] = df['in_AllocationTimeframeEnd']
dfPOD["in_AllocationTimeframeStart"] = df['in_AllocationTimeframeStart'] 
dfPOD["in_AllocationVolume_AF"] = df['acre_feet'].astype(float)
dfPOD["in_IrrigatedAcreage"] = ""

# Shared Elements
dfPOD['snp_id'] = df['snp_id']  #for AllocationNativeID
dfPOD['priority_date'] = df['priority_date']  #for AllocationPriorityDate
dfPOD['claim_char'] = df['claim_char']  #for AllocationTypeCV
dfPOD['use_code_description'] = df['use_code_description']  #for BeneficialUseCategory
dfPOD['wris_link'] = df['wris_link']  #for WaterAllocationNativeURL

print(len(dfPOD))
dfPOD
# Out:
# 189822
#          in_WaterSourceName in_WaterSourceTypeCV  in_Latitude  in_Longitude  \
# 0            FORMOSA 1 ADIT          Groundwater    42.855813   -123.382877
# 1       SILVER BUTTE 1 ADIT          Groundwater    42.854551   -123.383487
# 2                    A WELL          Groundwater    42.682269   -123.629420
# 3                    A WELL          Groundwater    44.301041   -121.654631
# 4                    A WELL          Groundwater    44.301041   -121.654631
# ...                     ...                  ...          ...           ...
# 189817               RUNOFF              Storage    45.692059   -123.079106
# 189818               RUNOFF              Storage    45.692059   -123.079106
# 189819               RUNOFF              Storage    45.692059   -123.079106
# 189820               A WELL              Storage    45.307916   -122.462393
# 189821               RUNOFF              Storage    45.306827   -122.461779
#
#        in_PODorPOUSite in_SiteName in_SiteNativeID  in_SiteTypeCV  \
# 0                  POD     21755_1         POD6909           well
# 1                  POD     21755_2         POD6910           well
# 2                  POD     23327_1         POD9355           well
# 3                  POD     23390_1         POD9480           well
# 4                  POD     23390_1         POD9480           well
# ...                ...         ...             ...            ...
# 189817             POD    202390_1       POD344799  winter runoff
# 189818             POD    202390_1       POD344799  winter runoff
# 189819             POD    202390_1       POD344799  winter runoff
# 189820             POD     33683_2        POD34240           well
# 189821             POD     33683_1        POD34239  winter runoff
#
#         in_AllocationFlow_CFS  in_AllocationVolume_AF  \
# 0                       0.040                     NaN
# 1                       0.005                     NaN
# 2                       0.110                     NaN
# 3                       0.670                     NaN
# 4                       0.110                     NaN
# ...                       ...                     ...
# 189817                    NaN                  1.5375
# 189818                    NaN                  1.5375
# 189819                    NaN                  4.1000
# 189820                    NaN                  0.2187
# 189821                    NaN                  0.2187
#
#                       in_AllocationOwner in_AllocationTimeframeEnd  \
# 0               FORMOSA EXPLORATION INC.                     12/31
# 1               FORMOSA EXPLORATION INC.                     12/31
# 2                       DUTCH MINING LLC                     12/31
# 3       JEFF STEYAERT, KNIFE RIVER CORP.                     12/31
# 4       JEFF STEYAERT, KNIFE RIVER CORP.                     12/31
# ...                                  ...                       ...
# 189817              ERIC ANTHONY URSTADT                     12/31
# 189818              ERIC ANTHONY URSTADT                      4/30
# 189819              ERIC ANTHONY URSTADT                     11/30
# 189820                      ALTON MADDOX                      6/30
# 189821                      ALTON MADDOX                      6/30
#
#        in_AllocationTimeframeStart in_IrrigatedAcreage  snp_id priority_date  \
# 0                              1/1                       21755    1989-11-21
# 1                              1/1                       21755    1989-11-21
# 2                              1/1                       23327    1994-05-06
# 3                              1/1                       23390    1995-01-18
# 4                              1/1                       23390    1995-01-18
# ...                            ...                 ...     ...           ...
# 189817                        12/1                      202390    2017-09-05
# 189818                         1/1                      202390    2017-09-05
# 189819                         5/1                      202390    2017-09-05
# 189820                         1/1                       33683    2000-06-10
# 189821                         1/1                       33683    2000-06-10
#
#        claim_char use_code_description  \
# 0             NaN               MINING
# 1             NaN               MINING
# 2             NaN               MINING
# 3             NaN               MINING
# 4             NaN               MINING
# ...           ...                  ...
# 189817        NaN             WILDLIFE
# 189818        NaN             WILDLIFE
# 189819        NaN             WILDLIFE
# 189820        NaN             WILDLIFE
# 189821        NaN             WILDLIFE
#
#                                                 wris_link  \
# 0       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 1       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 2       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 3       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 4       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# ...                                                   ...
# 189817  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 189818  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 189819  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 189820  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 189821  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
#
#         in_AllocationCropDutyAmount
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 189817                           NaN
# 189818                           NaN
# 189819                           NaN
# 189820                           NaN
# 189821                           NaN
#
# [189822 rows x 20 columns]

# %% [markdown]
# ## Place of Use Data

# %%
# Dataframe creation
dfPOUfile = "ORwr_v_pou_public_input.csv"  # contains POU info
df = pd.read_csv(dfPOUfile, encoding = "ISO-8859-1")
print(len(df))
df.head(3)
# Out:
# 109576
# C:\Users\rjame\AppData\Local\Temp\ipykernel_14912\4101147554.py:3: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(dfPOUfile, encoding = "ISO-8859-1")
#    OID_  snp_id agency app_char  app_nbr  cert_nbr claim_char  claim_nbr  \
# 0     1    5135   OWRD       P   81441.0       NaN        NaN        NaN
# 1     2    6333   OWRD       P   82980.0       NaN        NaN        NaN
# 2     3   17008   OWRD      NaN      NaN       NaN        NaN        NaN
#
#      decree_title  delta_size  feature_quality_code   last_updt_date  \
# 0             NaN         NaN                  30.0   7/22/2005 8:02
# 1             NaN         NaN                  30.0  4/11/2016 10:48
# 2  East Mud Creek         NaN                   NaN   12/1/1997 0:00
#
#     Latitude   Longitude      name_company name_first name_last permit_char  \
# 0  43.736859 -118.364476  DASH W BAR RANCH      TERRY  WILLIAMS         NaN
# 1  42.441488 -123.041443               NaN      SOFIA    PARKER         NaN
# 2  45.992923 -118.440767               NaN     DONALD   RENCKEN         NaN
#
#    permit_nbr                      pou_display pou_display_short  pou_use_id  \
# 0         NaN               App: P  81441 * LV          P  81441        4124
# 1         NaN               App: P  82980 * ST          P  82980        5886
# 2         NaN  Inchoate: T  4213 CF (REG) * IR           T  4213        7696
#
#         priority_date rec_creation_date                    remarks  \
# 0       8/7/1996 0:00    6/30/2005 0:00           PLACED USING DRG
# 1       1/7/1997 0:00    4/11/2016 0:00  PLACED USING 2014 IMAGERY
# 2  12/31/1892 0:00:00    12/1/1997 0:00                0 CD     31
#
#      Shape_Area  Shape_Length  supplemental technician_initials transfer_nbr  \
# 0  2.919850e-06      0.008945             0                  MW          NaN
# 1  3.585900e-07      0.004559             0                 BRW          NaN
# 2  4.093100e-06      0.008191             0               MIGRT      T  4213
#
#   use_category use_code use_code_description wr_type  wris_acres  \
# 0            8       LV            LIVESTOCK     ST          NaN
# 1            M       ST              STORAGE     ST          NaN
# 2            3       IR           IRRIGATION     SW         10.0
#
#                                            wris_link
# 0  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 1  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 2  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...

# %%
# For creating WaterSourceTypeCV
WSTypeDict = {
    "ST": "Storage",
    "GW": "Groundwater",
    "SW": "Surface Water"}
def assignWaterSourceTypeCV(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = "Unspecified"
    else:
        String1 = colrowValue.strip()
        try:
            outList = WSTypeDict[String1]
        except:
            outList = "Unspecified"

    return outList

df['in_WaterSourceTypeCV'] = df.apply(lambda row: assignWaterSourceTypeCV(row['wr_type']), axis=1)

# %%
# Changing datatype of used date fields. 
df['priority_date'] = pd.to_datetime(df['priority_date'], errors = 'coerce')
df['priority_date'] = pd.to_datetime(df["priority_date"].dt.strftime('%m/%d/%Y'))

# %%
# Creating Ownername.
# Concatenating first and last name of individual.
# Determining if company is available, split string.
# combine together for output.

# first & last name funciton
def assignownerName(colrowValue1, colrowValue2):
    if colrowValue1 == '' or pd.isnull(colrowValue1):
        outList1 = ''
    else:
        outList1 = colrowValue1.strip()  # remove whitespace chars
    if colrowValue2 == '' or pd.isnull(colrowValue2):
        outList2 = ''
    else:
        outList2 = colrowValue2.strip()  # remove whitespace chars

    if outList1 == '' and outList2 == '':
        outList = ''
    elif outList1 == '':
        outList = outList2
    elif outList2 == '':
        outList = outList1
    else:
        outList = " ".join(map(str, [colrowValue1, colrowValue2]))
    return outList


# Business name and Concatenate
def assignownerNameORCompany(buisName, fName, lName):
    
    # Concatenating First and Last name together.
    frilasName = assignownerName(fName, lName)
    
    # Clearn Company Name Entry
    if buisName == "" or pd.isnull(buisName):
        outBuisString = ""
    else:
        buisName = str(buisName).strip()
        if ";" in buisName:
            xList = buisName.split(";")
            for index, item in enumerate(xList):
                if "," in item:
                    list1 = item.split(",")
                    list1.reverse()
                    xList[index] = "".join(list1)
                else:
                    xList[index] = item
            outBuisString = ",".join(xList)
        elif "," in buisName:
            xList = buisName.split(",")
            outBuisString = str(xList[0]).strip() + "," + str(xList[1]).strip()
        else:
            outBuisString = buisName
    
    #Concatenating together, create outString
    if frilasName == ""  or pd.isnull(frilasName):
        if outBuisString == ""  or pd.isnull(outBuisString):
            outString = "Unspecified"
        else:
            outString = outBuisString
    else:
        if outBuisString == ""  or pd.isnull(outBuisString):
            outString = frilasName
        else:
            outString = frilasName + ", " + outBuisString
        
    outString = outString.strip()
    return outString

df['in_AllocationOwner'] = df.apply(lambda row: assignownerNameORCompany(row['name_company'], row['name_first'], row['name_last']), axis=1)

# %%
#Fixing Beneficial Uses PRIMARY_PURPOSE

def fixBenUse(val):
    val = str(val).strip()
    if val == "IRRIGATION, LIVESTOCK AND DOMESTIC":
        outString = "IRRIGATION, LIVESTOCK, DOMESTIC"
    elif val == "IRRIGATION AND LIVESTOCK":
        outString = "IRRIGATION, LIVESTOCK"
    elif val == "LIVESTOCK AND WILDLIFE":
        outString = "LIVESTOCK, WILDLIFE"
    else:
        outString = val
    return outString

df['use_code_description'] = df.apply(lambda row: fixBenUse(row['use_code_description']), axis=1)

# %%
# Creating the output Dataframe for PODs.

dfPOU = pd.DataFrame(columns=columnsList, index=df.index)

# Water Source
dfPOU["in_WaterSourceName"] = "Unspecified"
dfPOU['in_WaterSourceTypeCV'] = df['in_WaterSourceTypeCV']

# Site
dfPOU["in_Latitude"] = df['Latitude']
dfPOU["in_Longitude"] = df['Longitude']
dfPOU["in_PODorPOUSite"] = "POU"
dfPOU["in_SiteName"] = "Unspecified"
dfPOU["in_SiteNativeID"] = "POU" + df['pou_use_id'].astype(str)
dfPOU["in_SiteTypeCV"] = "Unspecified"

# Allocation
dfPOU["in_AllocationFlow_CFS"] = ""
dfPOD["in_AllocationCropDutyAmount "] = ""
dfPOU['in_AllocationOwner'] =  df['in_AllocationOwner']
dfPOU["in_AllocationTimeframeEnd"] = ""
dfPOU["in_AllocationTimeframeStart"] = ""
dfPOU["in_AllocationVolume_AF"] = ""
dfPOU["in_IrrigatedAcreage"] = df['wris_acres'].astype(float)

# Shared Elements
dfPOU['snp_id'] = df['snp_id']  #for AllocationNativeID
dfPOU['priority_date'] = df['priority_date']  #for AllocationPriorityDate
dfPOU['claim_char'] = df['claim_char']  #for AllocationTypeCV
dfPOU['use_code_description'] = df['use_code_description']  #for BeneficialUseCategory
dfPOU['wris_link'] = df['wris_link']  #for WaterAllocationNativeURL

print(len(dfPOU))
dfPOU
# Out:
# 109576
#        in_WaterSourceName in_WaterSourceTypeCV  in_Latitude  in_Longitude  \
# 0             Unspecified              Storage    43.736859   -118.364476
# 1             Unspecified              Storage    42.441488   -123.041443
# 2             Unspecified        Surface Water    45.992923   -118.440767
# 3             Unspecified        Surface Water    45.993822   -118.439625
# 4             Unspecified        Surface Water    44.235307   -121.551262
# ...                   ...                  ...          ...           ...
# 109571        Unspecified          Groundwater    42.000615   -121.519010
# 109572        Unspecified          Groundwater    42.098688   -121.705149
# 109573        Unspecified          Groundwater    42.054974   -121.656443
# 109574        Unspecified          Groundwater    42.192755   -121.927985
# 109575        Unspecified          Groundwater    42.136499   -121.811614
#
#        in_PODorPOUSite  in_SiteName in_SiteNativeID in_SiteTypeCV  \
# 0                  POU  Unspecified         POU4124   Unspecified
# 1                  POU  Unspecified         POU5886   Unspecified
# 2                  POU  Unspecified         POU7696   Unspecified
# 3                  POU  Unspecified         POU7697   Unspecified
# 4                  POU  Unspecified         POU7713   Unspecified
# ...                ...          ...             ...           ...
# 109571             POU  Unspecified       POU269184   Unspecified
# 109572             POU  Unspecified       POU269187   Unspecified
# 109573             POU  Unspecified       POU269188   Unspecified
# 109574             POU  Unspecified       POU269194   Unspecified
# 109575             POU  Unspecified       POU269221   Unspecified
#
#        in_AllocationFlow_CFS in_AllocationVolume_AF  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...                    ...
# 109571
# 109572
# 109573
# 109574
# 109575
#
#                       in_AllocationOwner in_AllocationTimeframeEnd  \
# 0       TERRY WILLIAMS, DASH W BAR RANCH
# 1                           SOFIA PARKER
# 2                         DONALD RENCKEN
# 3                         DONALD RENCKEN
# 4                            ROY M RUNCO
# ...                                  ...                       ...
# 109571                  MLM PROPERTY LLC
# 109572                KUCERA ENTERPRISES
# 109573                       DAVID HAMEL
# 109574                     HUNTER MOYLES
# 109575                      JUSTIN GRANT
#
#        in_AllocationTimeframeStart  in_IrrigatedAcreage  snp_id priority_date  \
# 0                                                   NaN    5135    1996-08-07
# 1                                                   NaN    6333    1997-01-07
# 2                                                 10.00   17008    1892-12-31
# 3                                                   NaN   17008    1892-12-31
# 4                                                 38.50   17022    1900-12-31
# ...                            ...                  ...     ...           ...
# 109571                                            28.50  208328    2021-04-05
# 109572                                            26.00  208330    2021-04-05
# 109573                                           362.20  208331    2021-04-05
# 109574                                           144.07  208337    2021-04-12
# 109575                                           116.50  208349    2021-04-12
#
#        claim_char     use_code_description  \
# 0             NaN                LIVESTOCK
# 1             NaN                  STORAGE
# 2             NaN               IRRIGATION
# 3             NaN                LIVESTOCK
# 4             NaN               IRRIGATION
# ...           ...                      ...
# 109571        NaN  SUPPLEMENTAL IRRIGATION
# 109572        NaN  SUPPLEMENTAL IRRIGATION
# 109573        NaN  SUPPLEMENTAL IRRIGATION
# 109574        NaN  SUPPLEMENTAL IRRIGATION
# 109575        NaN  SUPPLEMENTAL IRRIGATION
#
#                                                 wris_link
# 0       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 1       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 2       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 3       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 4       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# ...                                                   ...
# 109571  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109572  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109573  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109574  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109575  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
#
# [109576 rows x 19 columns]

# %% [markdown]
# ## Concatenate POD and POU data

# %%
# Concatenate
frames = [dfPOD, dfPOU]
dfout = pd.concat(frames)
print(len(dfout))
dfout.head(3)
# Out:
# 299398
#     in_WaterSourceName in_WaterSourceTypeCV  in_Latitude  in_Longitude  \
# 0       FORMOSA 1 ADIT          Groundwater    42.855813   -123.382877
# 1  SILVER BUTTE 1 ADIT          Groundwater    42.854551   -123.383487
# 2               A WELL          Groundwater    42.682269   -123.629420
#
#   in_PODorPOUSite in_SiteName in_SiteNativeID in_SiteTypeCV  \
# 0             POD     21755_1         POD6909          well
# 1             POD     21755_2         POD6910          well
# 2             POD     23327_1         POD9355          well
#
#   in_AllocationFlow_CFS in_AllocationVolume_AF        in_AllocationOwner  \
# 0                  0.04                    NaN  FORMOSA EXPLORATION INC.
# 1                 0.005                    NaN  FORMOSA EXPLORATION INC.
# 2                  0.11                    NaN          DUTCH MINING LLC
#
#   in_AllocationTimeframeEnd in_AllocationTimeframeStart in_IrrigatedAcreage  \
# 0                     12/31                         1/1
# 1                     12/31                         1/1
# 2                     12/31                         1/1
#
#    snp_id priority_date claim_char use_code_description  \
# 0   21755    1989-11-21        NaN               MINING
# 1   21755    1989-11-21        NaN               MINING
# 2   23327    1994-05-06        NaN               MINING
#
#                                            wris_link  \
# 0  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 1  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 2  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
#
#   in_AllocationCropDutyAmount
# 0
# 1
# 2

# %% [markdown]
# ## Custom WaDE Elements due to missing info

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDEOR_WS" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = dfout['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = dfout['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceName'] == A) & 
                                       (dfWaterSourceNativeID['in_WaterSourceTypeCV'] == B), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfout['in_WaterSourceNativeID'] = dfout.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
dfout
# Out:
#          in_WaterSourceName in_WaterSourceTypeCV  in_Latitude  in_Longitude  \
# 0            FORMOSA 1 ADIT          Groundwater    42.855813   -123.382877
# 1       SILVER BUTTE 1 ADIT          Groundwater    42.854551   -123.383487
# 2                    A WELL          Groundwater    42.682269   -123.629420
# 3                    A WELL          Groundwater    44.301041   -121.654631
# 4                    A WELL          Groundwater    44.301041   -121.654631
# ...                     ...                  ...          ...           ...
# 109571          Unspecified          Groundwater    42.000615   -121.519010
# 109572          Unspecified          Groundwater    42.098688   -121.705149
# 109573          Unspecified          Groundwater    42.054974   -121.656443
# 109574          Unspecified          Groundwater    42.192755   -121.927985
# 109575          Unspecified          Groundwater    42.136499   -121.811614
#
#        in_PODorPOUSite  in_SiteName in_SiteNativeID in_SiteTypeCV  \
# 0                  POD      21755_1         POD6909          well
# 1                  POD      21755_2         POD6910          well
# 2                  POD      23327_1         POD9355          well
# 3                  POD      23390_1         POD9480          well
# 4                  POD      23390_1         POD9480          well
# ...                ...          ...             ...           ...
# 109571             POU  Unspecified       POU269184   Unspecified
# 109572             POU  Unspecified       POU269187   Unspecified
# 109573             POU  Unspecified       POU269188   Unspecified
# 109574             POU  Unspecified       POU269194   Unspecified
# 109575             POU  Unspecified       POU269221   Unspecified
#
#        in_AllocationFlow_CFS in_AllocationVolume_AF  \
# 0                       0.04                    NaN
# 1                      0.005                    NaN
# 2                       0.11                    NaN
# 3                       0.67                    NaN
# 4                       0.11                    NaN
# ...                      ...                    ...
# 109571
# 109572
# 109573
# 109574
# 109575
#
#                       in_AllocationOwner in_AllocationTimeframeEnd  \
# 0               FORMOSA EXPLORATION INC.                     12/31
# 1               FORMOSA EXPLORATION INC.                     12/31
# 2                       DUTCH MINING LLC                     12/31
# 3       JEFF STEYAERT, KNIFE RIVER CORP.                     12/31
# 4       JEFF STEYAERT, KNIFE RIVER CORP.                     12/31
# ...                                  ...                       ...
# 109571                  MLM PROPERTY LLC
# 109572                KUCERA ENTERPRISES
# 109573                       DAVID HAMEL
# 109574                     HUNTER MOYLES
# 109575                      JUSTIN GRANT
#
#        in_AllocationTimeframeStart in_IrrigatedAcreage  snp_id priority_date  \
# 0                              1/1                       21755    1989-11-21
# 1                              1/1                       21755    1989-11-21
# 2                              1/1                       23327    1994-05-06
# 3                              1/1                       23390    1995-01-18
# 4                              1/1                       23390    1995-01-18
# ...                            ...                 ...     ...           ...
# 109571                                            28.5  208328    2021-04-05
# 109572                                            26.0  208330    2021-04-05
# 109573                                           362.2  208331    2021-04-05
# 109574                                          144.07  208337    2021-04-12
# 109575                                           116.5  208349    2021-04-12
#
#        claim_char     use_code_description  \
# 0             NaN                   MINING
# 1             NaN                   MINING
# 2             NaN                   MINING
# 3             NaN                   MINING
# 4             NaN                   MINING
# ...           ...                      ...
# 109571        NaN  SUPPLEMENTAL IRRIGATION
# 109572        NaN  SUPPLEMENTAL IRRIGATION
# 109573        NaN  SUPPLEMENTAL IRRIGATION
# 109574        NaN  SUPPLEMENTAL IRRIGATION
# 109575        NaN  SUPPLEMENTAL IRRIGATION
#
#                                                 wris_link  \
# 0       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 1       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 2       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 3       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 4       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# ...                                                   ...
# 109571  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109572  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109573  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109574  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109575  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
#
#        in_AllocationCropDutyAmount  in_WaterSourceNativeID
# 0                                               WaDEOR_WS1
# 1                                               WaDEOR_WS2
# 2                                               WaDEOR_WS3
# 3                                               WaDEOR_WS3
# 4                                               WaDEOR_WS3
# ...                             ...                    ...
# 109571                          NaN         WaDEOR_WS16875
# 109572                          NaN         WaDEOR_WS16875
# 109573                          NaN         WaDEOR_WS16875
# 109574                          NaN         WaDEOR_WS16875
# 109575                          NaN         WaDEOR_WS16875
#
# [299398 rows x 21 columns]

# %% [markdown]
# ## Shapefile Data
# - For attaching gemetry to csv inputs.

# %%
# PoU Shapefile Data
# Shapefile input
ShapeFileInput = gpd.read_file('shapefile/OR_PoU.shp')
dfPoUshapetemp = pd.DataFrame(ShapeFileInput)
dfPoUshapetemp.head(3)
# Out:
#                         pou_displa pou_disp_1  \
# 0               App: P  81441 * LV   P  81441
# 1               App: P  82980 * ST   P  82980
# 2  Inchoate: T  4213 CF (REG) * IR    T  4213
#
#                                            wris_link  snp_id  pou_use_id  \
# 0  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...    5135        4124
# 1  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...    6333        5886
# 2  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...   17008        7696
#
#   app_char  app_nbr permit_cha  permit_nbr  cert_nbr claim_char  claim_nbr  \
# 0        P    81441       None           0         0       None          0
# 1        P    82980       None           0         0       None          0
# 2     None        0       None           0         0       None          0
#
#        decree_tit transfer_n wr_type name_last name_first        name_compa  \
# 0            None       None      ST  WILLIAMS      TERRY  DASH W BAR RANCH
# 1            None       None      ST    PARKER      SOFIA              None
# 2  East Mud Creek    T  4213      SW   RENCKEN     DONALD              None
#
#   use_code use_catego  use_code_d  priority_d  supplement  wris_acres  \
# 0       LV          8   LIVESTOCK  1996-08-07           0         0.0
# 1       ST          M     STORAGE  1997-01-07           0         0.0
# 2       IR          3  IRRIGATION  1892-12-31           0        10.0
#
#   technician agency  rec_creati  last_updt_  feature_qu  delta_size  \
# 0         MW   OWRD  2005-06-30  2005-07-22          30         0.0
# 1        BRW   OWRD  2016-04-11  2016-04-11          30         0.0
# 2      MIGRT   OWRD  1997-12-01  1997-12-01           0         0.0
#
#                      remarks   Shape_Leng     Shape_Area  \
# 0           PLACED USING DRG  2654.809276  281203.130830
# 1  PLACED USING 2014 IMAGERY  1437.654166   35294.340067
# 2                0 CD     31  2426.484770  379563.116664
#
#                                             geometry
# 0  POLYGON ((-118.36564 43.73765, -118.36567 43.7...
# 1  POLYGON ((-123.04147 42.44192, -123.04144 42.4...
# 2  POLYGON ((-118.43940 45.99213, -118.44205 45.9...

# %%
columnsList = ['in_SiteNativeID', 'geometry']
dfPoUshape = pd.DataFrame(columns=columnsList)
dfPoUshape['in_SiteNativeID'] = "POU" + dfPoUshapetemp['pou_use_id'].astype(str)
dfPoUshape['geometry'] = dfPoUshapetemp['geometry']
dfPoUshape = dfPoUshape.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
dfPoUshape.head(3)
# Out:
#   in_SiteNativeID                                           geometry
# 0         POU4124  POLYGON ((-118.36564 43.73765, -118.36567 43.7...
# 1         POU5886  POLYGON ((-123.04147 42.44192, -123.04144 42.4...
# 2         POU7696  POLYGON ((-118.43940 45.99213, -118.44205 45.9...

# %% [markdown]
# ## The Output

# %%
print(len(dfout))
dfout
# Out:
# 299398
#          in_WaterSourceName in_WaterSourceTypeCV  in_Latitude  in_Longitude  \
# 0            FORMOSA 1 ADIT          Groundwater    42.855813   -123.382877
# 1       SILVER BUTTE 1 ADIT          Groundwater    42.854551   -123.383487
# 2                    A WELL          Groundwater    42.682269   -123.629420
# 3                    A WELL          Groundwater    44.301041   -121.654631
# 4                    A WELL          Groundwater    44.301041   -121.654631
# ...                     ...                  ...          ...           ...
# 109571          Unspecified          Groundwater    42.000615   -121.519010
# 109572          Unspecified          Groundwater    42.098688   -121.705149
# 109573          Unspecified          Groundwater    42.054974   -121.656443
# 109574          Unspecified          Groundwater    42.192755   -121.927985
# 109575          Unspecified          Groundwater    42.136499   -121.811614
#
#        in_PODorPOUSite  in_SiteName in_SiteNativeID in_SiteTypeCV  \
# 0                  POD      21755_1         POD6909          well
# 1                  POD      21755_2         POD6910          well
# 2                  POD      23327_1         POD9355          well
# 3                  POD      23390_1         POD9480          well
# 4                  POD      23390_1         POD9480          well
# ...                ...          ...             ...           ...
# 109571             POU  Unspecified       POU269184   Unspecified
# 109572             POU  Unspecified       POU269187   Unspecified
# 109573             POU  Unspecified       POU269188   Unspecified
# 109574             POU  Unspecified       POU269194   Unspecified
# 109575             POU  Unspecified       POU269221   Unspecified
#
#        in_AllocationFlow_CFS in_AllocationVolume_AF  \
# 0                       0.04                    NaN
# 1                      0.005                    NaN
# 2                       0.11                    NaN
# 3                       0.67                    NaN
# 4                       0.11                    NaN
# ...                      ...                    ...
# 109571
# 109572
# 109573
# 109574
# 109575
#
#                       in_AllocationOwner in_AllocationTimeframeEnd  \
# 0               FORMOSA EXPLORATION INC.                     12/31
# 1               FORMOSA EXPLORATION INC.                     12/31
# 2                       DUTCH MINING LLC                     12/31
# 3       JEFF STEYAERT, KNIFE RIVER CORP.                     12/31
# 4       JEFF STEYAERT, KNIFE RIVER CORP.                     12/31
# ...                                  ...                       ...
# 109571                  MLM PROPERTY LLC
# 109572                KUCERA ENTERPRISES
# 109573                       DAVID HAMEL
# 109574                     HUNTER MOYLES
# 109575                      JUSTIN GRANT
#
#        in_AllocationTimeframeStart in_IrrigatedAcreage  snp_id priority_date  \
# 0                              1/1                       21755    1989-11-21
# 1                              1/1                       21755    1989-11-21
# 2                              1/1                       23327    1994-05-06
# 3                              1/1                       23390    1995-01-18
# 4                              1/1                       23390    1995-01-18
# ...                            ...                 ...     ...           ...
# 109571                                            28.5  208328    2021-04-05
# 109572                                            26.0  208330    2021-04-05
# 109573                                           362.2  208331    2021-04-05
# 109574                                          144.07  208337    2021-04-12
# 109575                                           116.5  208349    2021-04-12
#
#        claim_char     use_code_description  \
# 0             NaN                   MINING
# 1             NaN                   MINING
# 2             NaN                   MINING
# 3             NaN                   MINING
# 4             NaN                   MINING
# ...           ...                      ...
# 109571        NaN  SUPPLEMENTAL IRRIGATION
# 109572        NaN  SUPPLEMENTAL IRRIGATION
# 109573        NaN  SUPPLEMENTAL IRRIGATION
# 109574        NaN  SUPPLEMENTAL IRRIGATION
# 109575        NaN  SUPPLEMENTAL IRRIGATION
#
#                                                 wris_link  \
# 0       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 1       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 2       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 3       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 4       http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# ...                                                   ...
# 109571  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109572  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109573  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109574  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
# 109575  http://apps.wrd.state.or.us/apps/wr/wrinfo/wr_...
#
#        in_AllocationCropDutyAmount  in_WaterSourceNativeID
# 0                                               WaDEOR_WS1
# 1                                               WaDEOR_WS2
# 2                                               WaDEOR_WS3
# 3                                               WaDEOR_WS3
# 4                                               WaDEOR_WS3
# ...                             ...                    ...
# 109571                          NaN         WaDEOR_WS16875
# 109572                          NaN         WaDEOR_WS16875
# 109573                          NaN         WaDEOR_WS16875
# 109574                          NaN         WaDEOR_WS16875
# 109575                          NaN         WaDEOR_WS16875
#
# [299398 rows x 21 columns]

# %%
#Exporting to Finished File
dfout.to_csv('P_OregonMaster.csv', index=False)
dfPoUshape.to_csv('P_OregonGeometry.csv', index=False) # The output geometry.
