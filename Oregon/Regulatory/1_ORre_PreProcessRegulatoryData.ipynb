# %% [markdown]
# # Pre-processing (state / organization Name) Regulatory data for WaDE upload.
# - Purpose:  To preprocess the data into one master file for simple DataFrame creation and extraction.

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Oregon/Regulatory" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Oregon/Regulatory

# %% [markdown]
# ## Regulatory Area Data #1

# %%
# Input File
inputFile = "RawInputData/shapefiles/oregon-water-resources-department-owrd-administrative-basins.zip"
dfin1 = gpd.read_file(inputFile).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin1:
    dfin1['WaDEUUID'] = "re" + dfin1.index.astype(str)
    dfin1.to_csv('RawInputData/oregon-water-resources-department-owrd-administrative-basins.zip', compression=dict(method='zip', archive_name='oregon-water-resources-department-owrd-administrative-basins.csv'), index=False)

# Realign Geometry Projection
dfin1['geometry'] = dfin1['geometry'].to_crs(epsg=4326)

print(len(dfin1))
dfin1.head()
# Out:
# 19
#    BASIN_24  BASIN_24_I  BASIN_NUM    BASIN_NAME       SQ_MI SHORTNAME  \
# 0   2.00000     1.00000          1   North Coast  2556.24000     norco
# 1   3.00000     2.00000          8  Grande Ronde  4919.97000      gron
# 2   4.00000     3.00000          7      Umatilla  4501.74000       uma
# 3   5.00000     4.00000          2    Willamette 11468.98000      will
# 4   6.00000     5.00000          6      John Day  8072.88000      jday
#
#                                             geometry WaDEUUID
# 0  POLYGON ((-123.50593 46.23513, -123.50129 46.2...      re0
# 1  POLYGON ((-117.91886 46.00038, -117.91537 46.0...      re1
# 2  POLYGON ((-119.35597 45.91852, -119.35590 45.9...      re2
# 3  POLYGON ((-122.39995 45.56544, -122.39845 45.5...      re3
# 4  POLYGON ((-120.03311 45.75861, -120.03385 45.7...      re4

# %%
# create output for Regulatory Area #1 dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfin1['WaDEUUID']

# Date Info
df['in_Date'] = "8/31/2023"
df['in_Year'] = "2023"

# Organization Info
df['in_OrganizationUUID'] = "ORre_O1"

# ReportingUnit Info
df['in_EPSGCodeCV'] = "4326"
df['in_ReportingUnitName'] = dfin1["BASIN_NAME"]
df['in_ReportingUnitNativeID'] = "or" + dfin1["BASIN_NUM"].astype(str)
df['in_ReportingUnitProductVersion'] = "9.6"
df['in_ReportingUnitTypeCV'] = "Administrative Basins"
df['in_ReportingUnitUpdateDate'] = "9/22/2021"
df['in_StateCV'] = "OR"
df['in_Geometry'] = ""

# RegulatoryOverlay Info
df['in_OversightAgency'] = "Oregon Water Resources Department"
df['in_RegulatoryDescription'] = "Administrative rules which establish water management policies and objectives and which govern the appropriation and use of the surface and ground water"
df['in_RegulatoryName'] = dfin1["BASIN_NAME"]
df['in_RegulatoryOverlayNativeID'] = "or" + dfin1["BASIN_NUM"].astype(str)
df['in_RegulatoryStatusCV'] = "Active"
df['in_RegulatoryStatute'] = ""
df['in_RegulatoryStatuteLink'] =""
df['in_StatutoryEffectiveDate'] = "10/7/1993"
df['in_StatutoryEndDate'] = ""
df['in_RegulatoryOverlayTypeCV'] = "Administrative Basins"
df['in_WaterSourceTypeCV'] = "Surface and Ground Water"

df = df.drop_duplicates().reset_index(drop=True)
outdf1 = df.copy()
print(len(outdf1))
outdf1.head()
# Out:
# 19
#   WaDEUUID    in_Date in_Year in_OrganizationUUID in_EPSGCodeCV  \
# 0      re0  8/31/2023    2023             ORre_O1          4326
# 1      re1  8/31/2023    2023             ORre_O1          4326
# 2      re2  8/31/2023    2023             ORre_O1          4326
# 3      re3  8/31/2023    2023             ORre_O1          4326
# 4      re4  8/31/2023    2023             ORre_O1          4326
#
#   in_ReportingUnitName in_ReportingUnitNativeID  \
# 0          North Coast                      or1
# 1         Grande Ronde                      or8
# 2             Umatilla                      or7
# 3           Willamette                      or2
# 4             John Day                      or6
#
#   in_ReportingUnitProductVersion in_ReportingUnitTypeCV  \
# 0                            9.6  Administrative Basins
# 1                            9.6  Administrative Basins
# 2                            9.6  Administrative Basins
# 3                            9.6  Administrative Basins
# 4                            9.6  Administrative Basins
#
#   in_ReportingUnitUpdateDate in_StateCV in_Geometry  \
# 0                  9/22/2021         OR
# 1                  9/22/2021         OR
# 2                  9/22/2021         OR
# 3                  9/22/2021         OR
# 4                  9/22/2021         OR
#
#                   in_OversightAgency  \
# 0  Oregon Water Resources Department
# 1  Oregon Water Resources Department
# 2  Oregon Water Resources Department
# 3  Oregon Water Resources Department
# 4  Oregon Water Resources Department
#
#                             in_RegulatoryDescription in_RegulatoryName  \
# 0  Administrative rules which establish water man...       North Coast
# 1  Administrative rules which establish water man...      Grande Ronde
# 2  Administrative rules which establish water man...          Umatilla
# 3  Administrative rules which establish water man...        Willamette
# 4  Administrative rules which establish water man...          John Day
#
#   in_RegulatoryOverlayNativeID in_RegulatoryStatusCV in_RegulatoryStatute  \
# 0                          or1                Active
# 1                          or8                Active
# 2                          or7                Active
# 3                          or2                Active
# 4                          or6                Active
#
#   in_RegulatoryStatuteLink in_StatutoryEffectiveDate in_StatutoryEndDate  \
# 0                                          10/7/1993
# 1                                          10/7/1993
# 2                                          10/7/1993
# 3                                          10/7/1993
# 4                                          10/7/1993
#
#   in_RegulatoryOverlayTypeCV      in_WaterSourceTypeCV
# 0      Administrative Basins  Surface and Ground Water
# 1      Administrative Basins  Surface and Ground Water
# 2      Administrative Basins  Surface and Ground Water
# 3      Administrative Basins  Surface and Ground Water
# 4      Administrative Basins  Surface and Ground Water

# %% [markdown]
# ## Regulatory Area #2

# %%
# etc etc,

# %% [markdown]
# ## Concatenate DataFrames together

# %%
# Concatenate dataframes
frames = [outdf1] # list all out dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 19

# %% [markdown]
# ## Clean Data / data types

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_ReportingUnitName'] = df.apply(lambda row: ensureEmptyString(row['in_ReportingUnitName']), axis=1)
outdf['in_ReportingUnitName'].unique()
# Out:
# array(['North Coast', 'Grande Ronde', 'Umatilla', 'Willamette',
#        'John Day', 'Deschutes', 'Hood', 'Sandy', 'Powder', 'Mid Coast',
#        'Malheur', 'Malheur Lake', 'Umpqua', 'Owyhee',
#        'Goose & Summer Lakes', 'South Coast', 'Klamath', 'Rogue'],
#       dtype=object)

# %%
outdf['in_RegulatoryDescription'] = df.apply(lambda row: ensureEmptyString(row['in_RegulatoryDescription']), axis=1)
outdf['in_RegulatoryDescription'].unique()
# Out:
# array(['Administrative rules which establish water management policies and objectives and which govern the appropriation and use of the surface and ground water'],
#       dtype=object)

# %%
outdf['in_RegulatoryName'] = df.apply(lambda row: ensureEmptyString(row['in_RegulatoryName']), axis=1)
outdf['in_RegulatoryName'].unique()
# Out:
# array(['North Coast', 'Grande Ronde', 'Umatilla', 'Willamette',
#        'John Day', 'Deschutes', 'Hood', 'Sandy', 'Powder', 'Mid Coast',
#        'Malheur', 'Malheur Lake', 'Umpqua', 'Owyhee',
#        'Goose & Summer Lakes', 'South Coast', 'Klamath', 'Rogue'],
#       dtype=object)

# %%
#Update datatype of StatutoryEffectiveDate to fit WaDE 2.0 structure
outdf['in_StatutoryEffectiveDate'] = pd.to_datetime(outdf['in_StatutoryEffectiveDate'], errors = 'coerce')
outdf['in_StatutoryEffectiveDate'] = pd.to_datetime(outdf['in_StatutoryEffectiveDate'].dt.strftime('%m/%d/%Y'))
outdf['in_StatutoryEffectiveDate'].unique()
# Out:
# array(['1993-10-07T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# # Shapefile Data
# - For attaching geometry to reporting unit info.

# %% [markdown]
# #### Regulatory Area #1 shapefile info

# %%
# Input File
# shapeInputFile = "RawInputData/shapefiles/oregon-water-resources-department-owrd-administrative-basins-SHP.zip"
# gdfin1 = gpd.read_file(shapeInputFile)
gdfin1 = dfin1.copy()

# Realign Geometry Projection
gdfin1['geometry'] = dfin1['geometry'].to_crs(epsg=4326)

print(len(gdfin1))
gdfin1.head()
# Out:
# 19
#    BASIN_24  BASIN_24_I  BASIN_NUM    BASIN_NAME       SQ_MI SHORTNAME  \
# 0   2.00000     1.00000          1   North Coast  2556.24000     norco
# 1   3.00000     2.00000          8  Grande Ronde  4919.97000      gron
# 2   4.00000     3.00000          7      Umatilla  4501.74000       uma
# 3   5.00000     4.00000          2    Willamette 11468.98000      will
# 4   6.00000     5.00000          6      John Day  8072.88000      jday
#
#                                             geometry WaDEUUID
# 0  POLYGON ((-123.50593 46.23513, -123.50129 46.2...      re0
# 1  POLYGON ((-117.91886 46.00038, -117.91537 46.0...      re1
# 2  POLYGON ((-119.35597 45.91852, -119.35590 45.9...      re2
# 3  POLYGON ((-122.39995 45.56544, -122.39845 45.5...      re3
# 4  POLYGON ((-120.03311 45.75861, -120.03385 45.7...      re4

# %%
# plot shape info to map
gdfin1.plot()
# Out:
# <AxesSubplot: >

# %%
# create output for Regulatory Area #1 dataframe
df = pd.DataFrame()

columnsList = ['in_ReportingUnitNativeID', 'geometry']
goutdf1 = pd.DataFrame(columns=columnsList, index=gdfin1.index)

goutdf1['in_ReportingUnitNativeID'] = "or" + gdfin1["BASIN_NUM"].astype(str)  # in_ReportingUnitNativeID needs to match source from above equivlaent datframe
goutdf1['geometry'] = gdfin1['geometry']
goutdf1 = goutdf1.drop_duplicates().reset_index(drop=True)
print(len(goutdf1))
goutdf1.head()
# Out:
# 19
#   in_ReportingUnitNativeID                                           geometry
# 0                      or1  POLYGON ((-123.50593 46.23513, -123.50129 46.2...
# 1                      or8  POLYGON ((-117.91886 46.00038, -117.91537 46.0...
# 2                      or7  POLYGON ((-119.35597 45.91852, -119.35590 45.9...
# 3                      or2  POLYGON ((-122.39995 45.56544, -122.39845 45.5...
# 4                      or6  POLYGON ((-120.03311 45.75861, -120.03385 45.7...

# %% [markdown]
# #### Regulatory Area #2 shapefile info

# %%
# etc etc...

# %% [markdown]
# #### Concatenate goutdf shapefile info into single output

# %%
# Concatenate Basin & Subbasin DataFrames
frames = [goutdf1] # add geoutdf dataframes here
goutdf = pd.concat(frames).reset_index(drop=True)

print(len(goutdf))
goutdf.head()
# Out:
# 19
#   in_ReportingUnitNativeID                                           geometry
# 0                      or1  POLYGON ((-123.50593 46.23513, -123.50129 46.2...
# 1                      or8  POLYGON ((-117.91886 46.00038, -117.91537 46.0...
# 2                      or7  POLYGON ((-119.35597 45.91852, -119.35590 45.9...
# 3                      or2  POLYGON ((-122.39995 45.56544, -122.39845 45.5...
# 4                      or6  POLYGON ((-120.03311 45.75861, -120.03385 45.7...

# %% [markdown]
# ## Export Data

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(outdf.dtypes)
# Out:
# WaDEUUID                                  object
# in_Date                                   object
# in_Year                                   object
# in_OrganizationUUID                       object
# in_EPSGCodeCV                             object
# in_ReportingUnitName                      object
# in_ReportingUnitNativeID                  object
# in_ReportingUnitProductVersion            object
# in_ReportingUnitTypeCV                    object
# in_ReportingUnitUpdateDate                object
# in_StateCV                                object
# in_Geometry                               object
# in_OversightAgency                        object
# in_RegulatoryDescription                  object
# in_RegulatoryName                         object
# in_RegulatoryOverlayNativeID              object
# in_RegulatoryStatusCV                     object
# in_RegulatoryStatute                      object
# in_RegulatoryStatuteLink                  object
# in_StatutoryEffectiveDate         datetime64[ns]
# in_StatutoryEndDate                       object
# in_RegulatoryOverlayTypeCV                object
# in_WaterSourceTypeCV                      object
# dtype: object

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(goutdf.dtypes)
# Out:
# in_ReportingUnitNativeID      object
# geometry                    geometry
# dtype: object

# %%
outdf
# Out:
#    WaDEUUID    in_Date in_Year in_OrganizationUUID in_EPSGCodeCV  \
# 0       re0  8/31/2023    2023             ORre_O1          4326
# 1       re1  8/31/2023    2023             ORre_O1          4326
# 2       re2  8/31/2023    2023             ORre_O1          4326
# 3       re3  8/31/2023    2023             ORre_O1          4326
# 4       re4  8/31/2023    2023             ORre_O1          4326
# 5       re5  8/31/2023    2023             ORre_O1          4326
# 6       re6  8/31/2023    2023             ORre_O1          4326
# 7       re7  8/31/2023    2023             ORre_O1          4326
# 8       re8  8/31/2023    2023             ORre_O1          4326
# 9       re9  8/31/2023    2023             ORre_O1          4326
# 10     re10  8/31/2023    2023             ORre_O1          4326
# 11     re11  8/31/2023    2023             ORre_O1          4326
# 12     re12  8/31/2023    2023             ORre_O1          4326
# 13     re13  8/31/2023    2023             ORre_O1          4326
# 14     re14  8/31/2023    2023             ORre_O1          4326
# 15     re15  8/31/2023    2023             ORre_O1          4326
# 16     re16  8/31/2023    2023             ORre_O1          4326
# 17     re17  8/31/2023    2023             ORre_O1          4326
# 18     re18  8/31/2023    2023             ORre_O1          4326
#
#     in_ReportingUnitName in_ReportingUnitNativeID  \
# 0            North Coast                      or1
# 1           Grande Ronde                      or8
# 2               Umatilla                      or7
# 3             Willamette                      or2
# 4               John Day                      or6
# 5              Deschutes                      or5
# 6                   Hood                      or4
# 7                  Sandy                      or3
# 8                 Powder                      or9
# 9              Mid Coast                     or18
# 10               Malheur                     or10
# 11          Malheur Lake                     or12
# 12                Umpqua                     or16
# 13                Owyhee                     or11
# 14  Goose & Summer Lakes                     or13
# 15           South Coast                     or17
# 16               Klamath                     or14
# 17                 Rogue                     or15
# 18           South Coast                     or17
#
#    in_ReportingUnitProductVersion in_ReportingUnitTypeCV  \
# 0                             9.6  Administrative Basins
# 1                             9.6  Administrative Basins
# 2                             9.6  Administrative Basins
# 3                             9.6  Administrative Basins
# 4                             9.6  Administrative Basins
# 5                             9.6  Administrative Basins
# 6                             9.6  Administrative Basins
# 7                             9.6  Administrative Basins
# 8                             9.6  Administrative Basins
# 9                             9.6  Administrative Basins
# 10                            9.6  Administrative Basins
# 11                            9.6  Administrative Basins
# 12                            9.6  Administrative Basins
# 13                            9.6  Administrative Basins
# 14                            9.6  Administrative Basins
# 15                            9.6  Administrative Basins
# 16                            9.6  Administrative Basins
# 17                            9.6  Administrative Basins
# 18                            9.6  Administrative Basins
#
#    in_ReportingUnitUpdateDate in_StateCV in_Geometry  \
# 0                   9/22/2021         OR
# 1                   9/22/2021         OR
# 2                   9/22/2021         OR
# 3                   9/22/2021         OR
# 4                   9/22/2021         OR
# 5                   9/22/2021         OR
# 6                   9/22/2021         OR
# 7                   9/22/2021         OR
# 8                   9/22/2021         OR
# 9                   9/22/2021         OR
# 10                  9/22/2021         OR
# 11                  9/22/2021         OR
# 12                  9/22/2021         OR
# 13                  9/22/2021         OR
# 14                  9/22/2021         OR
# 15                  9/22/2021         OR
# 16                  9/22/2021         OR
# 17                  9/22/2021         OR
# 18                  9/22/2021         OR
#
#                    in_OversightAgency  \
# 0   Oregon Water Resources Department
# 1   Oregon Water Resources Department
# 2   Oregon Water Resources Department
# 3   Oregon Water Resources Department
# 4   Oregon Water Resources Department
# 5   Oregon Water Resources Department
# 6   Oregon Water Resources Department
# 7   Oregon Water Resources Department
# 8   Oregon Water Resources Department
# 9   Oregon Water Resources Department
# 10  Oregon Water Resources Department
# 11  Oregon Water Resources Department
# 12  Oregon Water Resources Department
# 13  Oregon Water Resources Department
# 14  Oregon Water Resources Department
# 15  Oregon Water Resources Department
# 16  Oregon Water Resources Department
# 17  Oregon Water Resources Department
# 18  Oregon Water Resources Department
#
#                              in_RegulatoryDescription     in_RegulatoryName  \
# 0   Administrative rules which establish water man...           North Coast
# 1   Administrative rules which establish water man...          Grande Ronde
# 2   Administrative rules which establish water man...              Umatilla
# 3   Administrative rules which establish water man...            Willamette
# 4   Administrative rules which establish water man...              John Day
# 5   Administrative rules which establish water man...             Deschutes
# 6   Administrative rules which establish water man...                  Hood
# 7   Administrative rules which establish water man...                 Sandy
# 8   Administrative rules which establish water man...                Powder
# 9   Administrative rules which establish water man...             Mid Coast
# 10  Administrative rules which establish water man...               Malheur
# 11  Administrative rules which establish water man...          Malheur Lake
# 12  Administrative rules which establish water man...                Umpqua
# 13  Administrative rules which establish water man...                Owyhee
# 14  Administrative rules which establish water man...  Goose & Summer Lakes
# 15  Administrative rules which establish water man...           South Coast
# 16  Administrative rules which establish water man...               Klamath
# 17  Administrative rules which establish water man...                 Rogue
# 18  Administrative rules which establish water man...           South Coast
#
#    in_RegulatoryOverlayNativeID in_RegulatoryStatusCV in_RegulatoryStatute  \
# 0                           or1                Active
# 1                           or8                Active
# 2                           or7                Active
# 3                           or2                Active
# 4                           or6                Active
# 5                           or5                Active
# 6                           or4                Active
# 7                           or3                Active
# 8                           or9                Active
# 9                          or18                Active
# 10                         or10                Active
# 11                         or12                Active
# 12                         or16                Active
# 13                         or11                Active
# 14                         or13                Active
# 15                         or17                Active
# 16                         or14                Active
# 17                         or15                Active
# 18                         or17                Active
#
#    in_RegulatoryStatuteLink in_StatutoryEffectiveDate in_StatutoryEndDate  \
# 0                                          1993-10-07
# 1                                          1993-10-07
# 2                                          1993-10-07
# 3                                          1993-10-07
# 4                                          1993-10-07
# 5                                          1993-10-07
# 6                                          1993-10-07
# 7                                          1993-10-07
# 8                                          1993-10-07
# 9                                          1993-10-07
# 10                                         1993-10-07
# 11                                         1993-10-07
# 12                                         1993-10-07
# 13                                         1993-10-07
# 14                                         1993-10-07
# 15                                         1993-10-07
# 16                                         1993-10-07
# 17                                         1993-10-07
# 18                                         1993-10-07
#
#    in_RegulatoryOverlayTypeCV      in_WaterSourceTypeCV
# 0       Administrative Basins  Surface and Ground Water
# 1       Administrative Basins  Surface and Ground Water
# 2       Administrative Basins  Surface and Ground Water
# 3       Administrative Basins  Surface and Ground Water
# 4       Administrative Basins  Surface and Ground Water
# 5       Administrative Basins  Surface and Ground Water
# 6       Administrative Basins  Surface and Ground Water
# 7       Administrative Basins  Surface and Ground Water
# 8       Administrative Basins  Surface and Ground Water
# 9       Administrative Basins  Surface and Ground Water
# 10      Administrative Basins  Surface and Ground Water
# 11      Administrative Basins  Surface and Ground Water
# 12      Administrative Basins  Surface and Ground Water
# 13      Administrative Basins  Surface and Ground Water
# 14      Administrative Basins  Surface and Ground Water
# 15      Administrative Basins  Surface and Ground Water
# 16      Administrative Basins  Surface and Ground Water
# 17      Administrative Basins  Surface and Ground Water
# 18      Administrative Basins  Surface and Ground Water

# %%
# Export out to CSV.
outdf.to_csv('RawInputData/Pre_orMain.zip', compression=dict(method='zip', archive_name='Pre_Main.csv'), index=False)  # The output, save as a zip
goutdf.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
