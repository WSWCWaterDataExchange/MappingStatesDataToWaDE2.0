# %% [markdown]
# # Pre-processing South Dakota Allocation data for WaDE upload.
# Purpose: To pre-process the South Dakota data into one master file for simple DataFrame creation and extraction
#
# Notes: N/A

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
import re
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x) # suppress scientific notation in Pandas

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/SouthDakota/WaterAllocation/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## Data: waterights

# %%
# Input File
fileInput = "waterights_input.csv"
dfinPOD = pd.read_csv(fileInput).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "sdwr" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('waterights_input.zip', compression=dict(method='zip', archive_name='waterights_input.csv'), index=False)

print(len(dfinPOD))
dfinPOD.head(1)
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_10552\3599601352.py:3: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfinPOD = pd.read_csv(fileInput).replace(np.nan, "")
# 19238
#   ReasonRemoved IncompleteField  OID_ PERMIT_NO  LATITUDE  LONGITUDE  \
# 0                                   1    FC10-3  43.71384  -97.60780
#
#        LAST_NAME FIRST_NAME ADDRESS2   CITY STATE    ZIP PLUS4 COUNTY_1 BASIN  \
# 0  MCCOOK COUNTY             BOX 550  SALEM    SD  57058   550       MC    JR
#
#   HYDROUNIT1       PRIORDATE STATUS SOURCE AQUIFER MNG_UNIT  DIVERSION1  \
# 0   10160010  12/8/1988 0:00     PE      S                   WOLF CREEK
#
#   USE_TYPE1 USE_TYPE2 USE_TYPE4 USE_TYPE5 USE_TYPE6  PER_CFS  LIC_CFS  \
# 0       FCP                                          0.00000  0.00000
#
#    PER_ACRES  LIC_ACRES     CMPLTN_DTE LIC_DTE INSPT_DATE INSPECTOR  \
# 0    0.00000    0.00000  3/1/1994 0:00
#
#   METHODCODE        REFERENCE  ACCURACY  \
# 0  TRSOTH100  DIVERSION POINT       140
#
#                                            LINK WaDEUUID
# 0  R:\work\wr\imaging\wrinfo\wr_div3\FC10-3.pdf    sdwr0

# %%
# first & last name funciton
def assignownerName(fName, lName):
    
    # Cleaning Text
    fName = str(fName)
    lName = str(lName)
    fName = fName.replace("*", "")
    lName = lName.replace("*", "")      
    
    # Check if first or last name are empty
    if fName == "" or pd.isnull(fName):
        outList1 = ""
    else:
        outList1 = fName.strip()
        
    if lName == "" or pd.isnull(lName):
        outList2 = ""
    else:
        outList2 = lName.strip()

    # ouput
    if outList1 == "" and outList2 == "":
        outList = ""
    elif outList1 == "":
        outList = outList2
    elif outList2 == "":
        outList = outList1
    else:
        outList = " ".join(map(str, [fName, lName]))
    return outList

dfinPOD['in_AllocationOwner'] = dfinPOD.apply(lambda row: assignownerName(row['FIRST_NAME'], row['LAST_NAME']), axis=1)


import re
def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

dfinPOD['in_AllocationOwner'] = dfinPOD.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
dfinPOD['in_AllocationOwner'].unique()
# Out:
# array(['Mccook County', 'Harold Dykstra', 'Meridian Minerals Co', ...,
#        'Ambrose Heimer', 'Ray Mason', 'Charles Capp'], dtype=object)

# %%
#Creating Beneficial Use.
#Need to translate SD abbreviatoins to a workable format.

BenUseDict = {
"COM" : "Commercial",
"DOM" : "Domestic",
"FCP" : "Flood Control Permit",
"FWP" : "Fish And Wildlife Propagation",
"GEO" : "Geothermal",
"GWR" : "Ground Water Remediation",
"IND" : "Industrial",
"INS" : "Institutional",
"IRR" : "Irrigation",
"MUN" : "Municipal",
"REC" : "Recreation",
"RWS" : "Rural Water System",
"SHD" : "Suburban Housing Development"}

def retrieveBenUse(A, B, C, D):
    A = str(A).strip()
    B = str(B).strip()
    C = str(C).strip()
    D = str(D).strip()

    if A == "":
        outA = ""
    else:
        try:
            outA = BenUseDict[A]
        except:
            outA = ""

    if B == "":
        outB = ""
    else:
        try:
            outB = ", " + BenUseDict[B]
        except:
            outB = ", " + ""

    if C == "":
        outC = ""
    else:
        try:
            outC = ", " + BenUseDict[C]
        except:
            outC = ", " + ""

    if D == "":
        outD = ""
    else:
        try:
            outD = ", " + BenUseDict[D]
        except:
            outD = ", " + ""

    outList = outA + outB + outC + outD
    outList = outList.strip()

    return outList

dfinPOD['in_BeneficialUseCategory'] = dfinPOD.apply(lambda row: retrieveBenUse(row['USE_TYPE1'], 
                                                          row['USE_TYPE2'], 
                                                          row['USE_TYPE4'], 
                                                          row['USE_TYPE5']), axis=1)
dfinPOD['in_BeneficialUseCategory'].unique()
# Out:
# array(['Flood Control Permit', 'Irrigation', 'Commercial, Industrial',
#        'Industrial', 'Municipal', 'Rural Water System',
#        'Irrigation, Rural Water System, Fish And Wildlife Propagation, Domestic',
#        'Commercial', 'Commercial, Domestic',
#        'Fish And Wildlife Propagation, Domestic',
#        'Commercial, Recreation', 'Ground Water Remediation',
#        'Fish And Wildlife Propagation', 'Recreation',
#        'Suburban Housing Development, Commercial', 'Irrigation, Domestic',
#        'Domestic', 'Suburban Housing Development',
#        'Municipal, Industrial, Rural Water System, Suburban Housing Development',
#        'Recreation, Domestic', 'Domestic, Commercial',
#        'Fish And Wildlife Propagation, Recreation',
#        'Fish And Wildlife Propagation, Irrigation',
#        'Recreation, Municipal', 'Industrial, Domestic',
#        'Municipal, Industrial, Suburban Housing Development, Commercial',
#        'Commercial, Irrigation', 'Geothermal', 'Institutional',
#        'Domestic, Recreation', 'Domestic, Suburban Housing Development',
#        'Suburban Housing Development, Recreation',
#        'Municipal, Industrial, Commercial',
#        'Domestic, Irrigation, Recreation',
#        'Domestic, Fish And Wildlife Propagation, Recreation',
#        'Domestic, Recreation, Fish And Wildlife Propagation',
#        'Recreation, Domestic, Fish And Wildlife Propagation',
#        'Irrigation, Fish And Wildlife Propagation, Recreation',
#        'Domestic, Fish And Wildlife Propagation',
#        'Commercial, Fish And Wildlife Propagation',
#        'Domestic, Fish And Wildlife Propagation, Irrigation',
#        'Fish And Wildlife Propagation, Domestic, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Recreation',
#        'Fish And Wildlife Propagation, Commercial',
#        'Fish And Wildlife Propagation, Domestic, Recreation',
#        'Domestic, Recreation, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Irrigation, Recreation, Irrigation',
#        'Domestic, Irrigation', 'Irrigation, Municipal',
#        'Irrigation, Commercial',
#        'Suburban Housing Development, Rural Water System',
#        'Domestic, Irrigation, Fish And Wildlife Propagation',
#        'Commercial, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Municipal, Irrigation, Recreation',
#        'Municipal, Industrial',
#        'Recreation, Fish And Wildlife Propagation',
#        'Commercial, Suburban Housing Development',
#        'Recreation, Irrigation',
#        'Irrigation, Fish And Wildlife Propagation, Domestic',
#        'Recreation, Municipal, Industrial, Domestic',
#        'Domestic, Municipal, Fish And Wildlife Propagation',
#        'Irrigation, Suburban Housing Development, Domestic',
#        'Municipal, Geothermal', 'Irrigation, Institutional',
#        'Suburban Housing Development, Domestic', 'Irrigation, Industrial',
#        'Industrial, Commercial',
#        'Rural Water System, Suburban Housing Development',
#        'Industrial, Municipal',
#        'Irrigation, Commercial, Domestic, Industrial',
#        'Rural Water System, Municipal',
#        'Suburban Housing Development, Municipal',
#        'Irrigation, Rural Water System',
#        'Suburban Housing Development, Geothermal',
#        'Irrigation, Municipal, Recreation', '', 'Institutional, Domestic',
#        'Commercial, Geothermal',
#        'Geothermal, Fish And Wildlife Propagation',
#        'Rural Water System, Domestic', 'Municipal, Recreation',
#        'Irrigation, Suburban Housing Development',
#        'Institutional, Industrial', 'Irrigation,',
#        'Municipal, Rural Water System, Suburban Housing Development, Commercial',
#        'Municipal, Industrial, Suburban Housing Development, Rural Water System',
#        'Municipal, Irrigation, Recreation, Domestic',
#        'Irrigation, Municipal, Recreation, Domestic',
#        'Domestic, Geothermal', 'Recreation, Commercial',
#        'Geothermal, Domestic', 'Domestic, Rural Water System',
#        'Domestic, Recreation, Municipal, Industrial',
#        'Rural Water System, Irrigation',
#        'Commercial, Suburban Housing Development, Domestic',
#        'Municipal, Commercial, Rural Water System, Suburban Housing Development',
#        'Irrigation, Recreation, Domestic',
#        'Irrigation, Domestic, Fish And Wildlife Propagation',
#        'Municipal, Rural Water System', 'Domestic, Municipal',
#        'Commercial, Domestic, Rural Water System',
#        'Commercial, Municipal',
#        'Municipal, Industrial, Rural Water System, Domestic',
#        'Industrial, Irrigation', 'Recreation, Institutional',
#        'Irrigation, Recreation', 'Geothermal, Irrigation',
#        'Municipal, Domestic', 'Geothermal, Institutional',
#        'Institutional, Municipal', 'Institutional, Recreation',
#        'Irrigation, Fish And Wildlife Propagation',
#        'Institutional, Irrigation', 'Domestic, Municipal, Industrial',
#        'Municipal, Irrigation',
#        'Irrigation, Domestic, Industrial, Recreation',
#        'Irrigation, Domestic, Fish And Wildlife Propagation, Recreation',
#        'Irrigation, Recreation, Fish And Wildlife Propagation, Domestic',
#        'Industrial, Commercial, Recreation', 'Municipal, Commercial'],
#       dtype=object)

# %%
#Creating WaterSourceTypeCV field

WSTypeDict = {
    "S" : "Surface Water",
    "G" : "Groundwater",
    "B" : "Surface Water and Groundwater"}

def retrieveWSType(colrowValue):
    colrowValue = str(colrowValue).strip()
    if colrowValue == "" or pd.isnull(colrowValue):
        outString = ""
    else:
        try:
            outString = WSTypeDict[colrowValue]
        except:
            outString = ""
    return outString

dfinPOD['in_WaterSourceTypeCV'] = dfinPOD.apply(lambda row: retrieveWSType(row['SOURCE']), axis=1)
dfinPOD['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater', 'Surface Water and Groundwater',
#        ''], dtype=object)

# %%
#Creating allocation status

AlloStatusDict = {
"CA" : "Cancelled",
"DF" : "Deferred",
"DN" : "Denied",
"FU" : "Future Use",
"HD" : "Hold",
"IP" : "Incorporated",
"LC" : "License",
"OC" : "Owner Change",
"PE" : "Permit",
"WI" : "Withdrawn"}

def retrieveStatus(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = ""
    else:
        String1 = str(colrowValue).strip()
        try:
            outList = AlloStatusDict[String1]
        except:
            outList = ""
    return outList

dfinPOD['in_AllocationLegalStatusCV'] = dfinPOD.apply(lambda row: retrieveStatus(row['STATUS']), axis=1)
dfinPOD['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Permit', 'License', 'Cancelled', 'Deferred', 'Denied',
#        'Withdrawn', '', 'Future Use', 'Incorporated', 'Owner Change'],
#       dtype=object)

# %%
dfinPOD.head(1)
# Out:
#   ReasonRemoved IncompleteField  OID_ PERMIT_NO  LATITUDE  LONGITUDE  \
# 0                                   1    FC10-3  43.71384  -97.60780
#
#        LAST_NAME FIRST_NAME ADDRESS2   CITY STATE    ZIP PLUS4 COUNTY_1 BASIN  \
# 0  MCCOOK COUNTY             BOX 550  SALEM    SD  57058   550       MC    JR
#
#   HYDROUNIT1       PRIORDATE STATUS SOURCE AQUIFER MNG_UNIT  DIVERSION1  \
# 0   10160010  12/8/1988 0:00     PE      S                   WOLF CREEK
#
#   USE_TYPE1 USE_TYPE2 USE_TYPE4 USE_TYPE5 USE_TYPE6  PER_CFS  LIC_CFS  \
# 0       FCP                                          0.00000  0.00000
#
#    PER_ACRES  LIC_ACRES     CMPLTN_DTE LIC_DTE INSPT_DATE INSPECTOR  \
# 0    0.00000    0.00000  3/1/1994 0:00
#
#   METHODCODE        REFERENCE  ACCURACY  \
# 0  TRSOTH100  DIVERSION POINT       140
#
#                                            LINK WaDEUUID in_AllocationOwner  \
# 0  R:\work\wr\imaging\wrinfo\wr_div3\FC10-3.pdf    sdwr0      Mccook County
#
#   in_BeneficialUseCategory in_WaterSourceTypeCV in_AllocationLegalStatusCV
# 0     Flood Control Permit        Surface Water                     Permit

# %%
# creating a usable native url
dfinPOD['new_LINK'] = dfinPOD['LINK'].str.replace('\\', "/").str.replace('R:/work/wr/imaging/wrinfo/', "/")
dfinPOD['new_LINK']
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_10552\3910285124.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dfinPOD['new_LINK'] = dfinPOD['LINK'].str.replace('\\', "/").str.replace('R:/work/wr/imaging/wrinfo/', "/")
# 0        /wr_div3/FC10-3.pdf
# 1        /wr_div3/FC11-3.pdf
# 2         /wr_div3/FC7-3.pdf
# 3        /wr_div3/1017-3.pdf
# 4        /wr_div2/1422-2.pdf
#                 ...
# 19233     /wr_div1/697-1.pdf
# 19234     /wr_div1/707-1.pdf
# 19235     /wr_div1/717-1.pdf
# 19236     /wr_div1/753-1.pdf
# 19237     /wr_div1/837-1.pdf
# Name: new_LINK, Length: 19238, dtype: object

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfinPOD['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "SDwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "SDwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "SDwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfinPOD['DIVERSION1'].str.title()
df['in_WaterSourceNativeID'] = "" # auto fill in below
df['in_WaterSourceTypeCV'] = dfinPOD['in_WaterSourceTypeCV']

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = ""
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = dfinPOD['HYDROUNIT1']
df['in_Latitude'] = dfinPOD['LATITUDE']
df['in_Longitude'] = dfinPOD['LONGITUDE']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"
df['in_SiteName'] = ""
df['in_SiteNativeID'] = "" # auto fill in below
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = ""
df['in_StateCV'] = "SD"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = dfinPOD['PER_CFS'].astype(float)
df['in_AllocationLegalStatusCV'] = dfinPOD['in_AllocationLegalStatusCV']
df['in_AllocationNativeID'] =  dfinPOD['PERMIT_NO'].replace("", 0).fillna(0).astype(str)
df['in_AllocationOwner'] = dfinPOD['in_AllocationOwner']
df['in_AllocationPriorityDate'] = dfinPOD['PRIORDATE']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = dfinPOD['PER_ACRES'].astype(float)
df['in_BeneficialUseCategory'] = dfinPOD['in_BeneficialUseCategory']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = "https://danr.sd.gov/wrimage/wrinfo" + dfinPOD['new_LINK'].astype(str)

df = df.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(df))
df.head()
# Out:
# 19238
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0    sdwr0       SDwr_M1                 SDwr_V1             SDwr_O1
# 1    sdwr1       SDwr_M1                 SDwr_V1             SDwr_O1
# 2    sdwr2       SDwr_M1                 SDwr_V1             SDwr_O1
# 3    sdwr3       SDwr_M1                 SDwr_V1             SDwr_O1
# 4    sdwr4       SDwr_M1                 SDwr_V1             SDwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#      in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0            Wolf Creek                               Surface Water
# 1          Beaver Creek                               Surface Water
# 2              Dry Draw                               Surface Water
# 3           Groundwater                                 Groundwater
# 4  Bull Creek Tributary                               Surface Water
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                                                 4326
# 1                                                                 4326
# 2                                                                 4326
# 3                                                                 4326
# 4                                                                 4326
#
#   in_GNISCodeCV in_HUC12   in_HUC8  in_Latitude  in_Longitude  \
# 0                         10160010     43.71384     -97.60780
# 1                         10170203     43.31191     -96.60393
# 2                         10170203     43.63269     -96.56461
# 3                         10170202     44.42416     -96.90175
# 4                         10140101     43.26114     -99.58091
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                   POD
# 1                                                   POD
# 2                                                   POD
# 3                                                   POD
# 4                                                   POD
#
#   in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                                                    SD
# 1                                                    SD
# 2                                                    SD
# 3                                                    SD
# 4                                                    SD
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.00000
# 3                                            1.79700
# 4                                            4.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID    in_AllocationOwner  \
# 0                     Permit                FC10-3         Mccook County
# 1                    License                FC11-3        Harold Dykstra
# 2                  Cancelled                 FC7-3  Meridian Minerals Co
# 3                    License                1017-3         Natasha Swier
# 4                    License                1422-2       Gerald E Gergen
#
#   in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0            12/8/1988 0:00
# 1            7/21/1989 0:00
# 2           12/29/1986 0:00
# 3            2/11/1963 0:00
# 4            8/20/1976 0:00
#
#   in_AllocationTimeframeEnd in_AllocationTimeframeStart in_AllocationTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#    in_AllocationVolume_AF in_BeneficialUseCategory  \
# 0                 0.00000     Flood Control Permit
# 1                 0.00000     Flood Control Permit
# 2                 0.00000     Flood Control Permit
# 3               125.00000               Irrigation
# 4               279.90000               Irrigation
#
#   in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDate in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                                           0
# 1                                                                           0
# 2                                                                           0
# 3                                                                           0
# 4                                                                           0
#
#   in_GeneratedPowerCapacityMW in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 1  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 2  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC7...
# 3  https://danr.sd.gov/wrimage/wrinfo/wr_div3/101...
# 4  https://danr.sd.gov/wrimage/wrinfo/wr_div2/142...

# %% [markdown]
# ## Clean Output

# %%
# Concatenate dataframes
frames = [df] # just POD for now
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 19238

# %%
# Ensure Empty String

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Wolf Creek', 'Beaver Creek', 'Dry Draw', ..., 'Lake',
#        'W Branch Bull Creek', 'Unnamed Dry Creek'], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater', 'Surface Water and Groundwater',
#        ''], dtype=object)

# %%
outdf['in_AllocationLegalStatusCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationLegalStatusCV']), axis=1)
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Permit', 'License', 'Cancelled', 'Deferred', 'Denied',
#        'Withdrawn', '', 'Future Use', 'Incorporated', 'Owner Change'],
#       dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Mccook County', 'Harold Dykstra', 'Meridian Minerals Co', ...,
#        'Ambrose Heimer', 'Ray Mason', 'Charles Capp'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['Flood Control Permit', 'Irrigation', 'Commercial, Industrial',
#        'Industrial', 'Municipal', 'Rural Water System',
#        'Irrigation, Rural Water System, Fish And Wildlife Propagation, Domestic',
#        'Commercial', 'Commercial, Domestic',
#        'Fish And Wildlife Propagation, Domestic',
#        'Commercial, Recreation', 'Ground Water Remediation',
#        'Fish And Wildlife Propagation', 'Recreation',
#        'Suburban Housing Development, Commercial', 'Irrigation, Domestic',
#        'Domestic', 'Suburban Housing Development',
#        'Municipal, Industrial, Rural Water System, Suburban Housing Development',
#        'Recreation, Domestic', 'Domestic, Commercial',
#        'Fish And Wildlife Propagation, Recreation',
#        'Fish And Wildlife Propagation, Irrigation',
#        'Recreation, Municipal', 'Industrial, Domestic',
#        'Municipal, Industrial, Suburban Housing Development, Commercial',
#        'Commercial, Irrigation', 'Geothermal', 'Institutional',
#        'Domestic, Recreation', 'Domestic, Suburban Housing Development',
#        'Suburban Housing Development, Recreation',
#        'Municipal, Industrial, Commercial',
#        'Domestic, Irrigation, Recreation',
#        'Domestic, Fish And Wildlife Propagation, Recreation',
#        'Domestic, Recreation, Fish And Wildlife Propagation',
#        'Recreation, Domestic, Fish And Wildlife Propagation',
#        'Irrigation, Fish And Wildlife Propagation, Recreation',
#        'Domestic, Fish And Wildlife Propagation',
#        'Commercial, Fish And Wildlife Propagation',
#        'Domestic, Fish And Wildlife Propagation, Irrigation',
#        'Fish And Wildlife Propagation, Domestic, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Recreation',
#        'Fish And Wildlife Propagation, Commercial',
#        'Fish And Wildlife Propagation, Domestic, Recreation',
#        'Domestic, Recreation, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Irrigation, Recreation, Irrigation',
#        'Domestic, Irrigation', 'Irrigation, Municipal',
#        'Irrigation, Commercial',
#        'Suburban Housing Development, Rural Water System',
#        'Domestic, Irrigation, Fish And Wildlife Propagation',
#        'Commercial, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Municipal, Irrigation, Recreation',
#        'Municipal, Industrial',
#        'Recreation, Fish And Wildlife Propagation',
#        'Commercial, Suburban Housing Development',
#        'Recreation, Irrigation',
#        'Irrigation, Fish And Wildlife Propagation, Domestic',
#        'Recreation, Municipal, Industrial, Domestic',
#        'Domestic, Municipal, Fish And Wildlife Propagation',
#        'Irrigation, Suburban Housing Development, Domestic',
#        'Municipal, Geothermal', 'Irrigation, Institutional',
#        'Suburban Housing Development, Domestic', 'Irrigation, Industrial',
#        'Industrial, Commercial',
#        'Rural Water System, Suburban Housing Development',
#        'Industrial, Municipal',
#        'Irrigation, Commercial, Domestic, Industrial',
#        'Rural Water System, Municipal',
#        'Suburban Housing Development, Municipal',
#        'Irrigation, Rural Water System',
#        'Suburban Housing Development, Geothermal',
#        'Irrigation, Municipal, Recreation', '', 'Institutional, Domestic',
#        'Commercial, Geothermal',
#        'Geothermal, Fish And Wildlife Propagation',
#        'Rural Water System, Domestic', 'Municipal, Recreation',
#        'Irrigation, Suburban Housing Development',
#        'Institutional, Industrial', 'Irrigation,',
#        'Municipal, Rural Water System, Suburban Housing Development, Commercial',
#        'Municipal, Industrial, Suburban Housing Development, Rural Water System',
#        'Municipal, Irrigation, Recreation, Domestic',
#        'Irrigation, Municipal, Recreation, Domestic',
#        'Domestic, Geothermal', 'Recreation, Commercial',
#        'Geothermal, Domestic', 'Domestic, Rural Water System',
#        'Domestic, Recreation, Municipal, Industrial',
#        'Rural Water System, Irrigation',
#        'Commercial, Suburban Housing Development, Domestic',
#        'Municipal, Commercial, Rural Water System, Suburban Housing Development',
#        'Irrigation, Recreation, Domestic',
#        'Irrigation, Domestic, Fish And Wildlife Propagation',
#        'Municipal, Rural Water System', 'Domestic, Municipal',
#        'Commercial, Domestic, Rural Water System',
#        'Commercial, Municipal',
#        'Municipal, Industrial, Rural Water System, Domestic',
#        'Industrial, Irrigation', 'Recreation, Institutional',
#        'Irrigation, Recreation', 'Geothermal, Irrigation',
#        'Municipal, Domestic', 'Geothermal, Institutional',
#        'Institutional, Municipal', 'Institutional, Recreation',
#        'Irrigation, Fish And Wildlife Propagation',
#        'Institutional, Irrigation', 'Domestic, Municipal, Industrial',
#        'Municipal, Irrigation',
#        'Irrigation, Domestic, Industrial, Recreation',
#        'Irrigation, Domestic, Fish And Wildlife Propagation, Recreation',
#        'Irrigation, Recreation, Fish And Wildlife Propagation, Domestic',
#        'Industrial, Commercial, Recreation', 'Municipal, Commercial'],
#       dtype=object)

# %%
# in_Latitude
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([43.71384, 43.31191, 43.63269, ..., 44.98889, 44.83907, 45.15978])

# %%
# in_Longitude
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([ -97.6078 ,  -96.60393,  -96.56461, ..., -101.9765 , -101.76175,
#        -101.93783])

# %%
#Update datatype of Priority Date to fit WaDE 2.0 structure
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'])
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# array(['1988-12-08T00:00:00.000000000', '1989-07-21T00:00:00.000000000',
#        '1986-12-29T00:00:00.000000000', ...,
#        '1997-02-06T00:00:00.000000000', '1961-05-23T00:00:00.000000000',
#        '1963-05-13T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# Fixing in_AllocationFlow_CFS datatype
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array(['', 1.797, 4.0, 0.55, 2.05, 0.6, 1.57, 2.0, 2.4, 2.1, 2.24, 2.28,
#        5.05, 4.57, 4.4, 0.3, 0.86, 2.5, 0.33, 7.06, 0.62, 0.9, 2.04, 3.94,
#        2.56, 1.72, 0.06, 0.85, 17.7, 3.43, 6.75, 2.66, 2.2, 1.18, 1.21,
#        3.0, 0.56, 3.71, 0.03, 0.09, 4.3, 1.0, 0.73, 8.0, 3.5, 0.055, 4.6,
#        0.006, 1.94, 0.44, 0.044, 1.85, 0.035, 0.1, 0.25, 0.222, 0.166,
#        0.022, 0.05, 0.93, 0.355, 0.045, 0.033, 0.47, 0.71, 0.155, 1.1,
#        0.333, 0.18, 1.77, 2.8, 0.57, 1.66, 1.81, 0.4, 0.07, 1.9, 2.11,
#        2.12, 0.11, 2.23, 0.59, 0.27, 0.22, 1.67, 1.89, 1.78, 0.15, 0.085,
#        2.89, 1.4, 2.9, 1.14, 3.44, 0.37, 7.33, 0.311, 5.52, 2.44, 0.666,
#        0.75, 0.456, 1.79, 1.43, 1.33, 2.55, 1.84, 2.22, 10.0, 0.071,
#        0.891, 0.58, 5.7, 1.86, 1.11, 3.34, 1.56, 2.67, 3.9, 0.67, 2.87,
#        1.45, 0.46, 0.167, 1.28, 0.156, 0.04, 0.51, 2.14, 8.08, 0.66,
#        0.266, 0.444, 0.28, 0.098, 0.031, 1.64, 0.111, 0.144, 0.08, 0.067,
#        0.011, 1.06, 0.45, 1.47, 0.133, 0.077, 16.5, 0.089, 0.165, 3.27,
#        1.73, 0.013, 4.9, 0.29, 0.83, 1.83, 5.0, 0.35, 3.96, 0.2, 8.95,
#        0.16, 4.58, 1.35, 1.2, 3.4, 6.67, 6.0, 0.009, 2.25, 0.5, 2.85,
#        0.34, 1.41, 13.0, 3.66, 6.85, 0.066, 4.5, 8.2, 1.88, 4.36, 0.178,
#        1.5, 0.078, 0.8, 0.267, 1.22, 0.056, 1.59, 1.74, 0.23, 21.4, 0.034,
#        10.2, 1.327, 4.54, 2.03, 0.016, 0.143, 0.017, 0.36, 0.02, 3.56,
#        0.78, 5.65, 25.0, 1.3, 9.6, 3.57, 55.8, 0.74, 0.13, 0.17, 0.667,
#        3.1, 1.82, 1.022, 0.89, 0.39, 0.43, 1.93, 3.37, 0.134, 0.54, 4.05,
#        1.71, 3.12, 7.7, 0.12, 12.0, 4.74, 0.557, 4.46, 0.314, 3.14, 4.28,
#        3.2, 1.34, 9.14, 8.44, 0.21, 0.7, 3.3, 0.98, 0.122, 2.18, 3.77,
#        3.82, 1.937, 4.16, 3.336, 1.668, 3.84, 3.42, 2.52, 0.324, 0.042,
#        15.0, 0.95, 4.56, 5.35, 1.91, 1.97, 0.334, 0.31, 4.08, 7.77, 4.33,
#        0.49, 0.96, 0.64, 6.86, 0.61, 5.56, 2.06, 0.42, 8.86, 1.8, 3.705,
#        1.035, 1.44, 35.14, 12.5, 0.018, 1.29, 2.34, 14.1, 3.36, 0.194,
#        3.89, 0.84, 5.78, 4.26, 0.14, 3.33, 0.093, 13.2, 13.85, 1.7, 1.55,
#        1.95, 1.42, 4.37, 2.96, 2.86, 2.17, 7.87, 2.57, 1.23, 0.53, 2.7,
#        1.58, 3.08, 2.78, 0.244, 0.32, 0.38, 0.24, 4.67, 3.78, 0.123, 2.29,
#        1.15, 2.83, 2.38, 1.16, 5.2, 5.71, 1.69, 3.81, 1.37, 0.69, 6.68,
#        1.6, 1.07, 0.027, 0.184, 6.8, 300.0, 150.0, 17.0, 3.55, 121.0, 6.4,
#        18.6, 10.5, 40.38, 3.47, 60.0, 20.0, 40.0, 5.5, 30.0, 200.0, 80.0,
#        160.0, 17.6, 7.0, 16.0, 24.0, 500.0, 2.45, 3.46, 5.42, 100.0, 2.42,
#        1.39, 4.1, 0.79, 0.48, 4.18, 14.0, 0.77, 3.93, 120.0, 3.8, 1.49,
#        7.27, 0.026, 0.26, 0.63, 9.0, 0.81, 2.63, 2.6, 4.01, 4.89, 0.52,
#        5.55, 14.2, 1.17, 5.82, 75.0, 0.92, 1.76, 0.19, 0.724, 0.038,
#        27.85, 0.833, 4.34, 1.08, 0.94, 0.72, 4.22, 7.78, 2.71, 2.88,
#        0.185, 10.4, 3.7, 1.25, 0.714, 11.14, 13.81, 5.79, 1.05, 0.256,
#        4.44, 5.68, 35.65, 7.29, 8.34, 1.61, 2.77, 8.62, 0.563, 0.057,
#        3.11, 5.33, 5.13, 0.154, 1.53, 0.062, 0.195, 0.01, 7.8, 1.46, 8.85,
#        6.62, 0.024, 1.48, 2.01, 4.04, 7.95, 4.487, 0.467, 8.5, 3.29, 4.29,
#        3.21, 7.47, 1.92, 5.14, 8.36, 7.4, 14.4, 2.94, 3.86, 0.68, 2.27,
#        22.85, 3.73, 0.075, 8.18, 6.46, 0.036, 1.31, 3.18, 1.87, 1.02,
#        10.57, 1.12, 1.38, 3.06, 6.6, 0.91, 2.21, 25.81, 6.34, 16.94,
#        15.52, 3.68, 4.27, 8.55, 9.19, 1.68, 2.51, 7.85, 5.12, 3.04, 6.7,
#        6.66, 11.09, 3.91, 2.97, 4.14, 2.64, 4.35, 5.87, 4.23, 4.47, 4.17,
#        5.17, 3.79, 2.48, 1.63, 1.04, 3.31, 1.96, 2.13, 2.49, 1.03, 0.058,
#        1.113, 9.5, 0.236, 0.446, 0.162, 0.87, 1.75, 0.088, 0.054, 20.12,
#        1.01, 0.074, 0.082, 14.57, 4.11, 2.79, 3.64, 5.34, 2.41, 7.46, 9.4,
#        12.92, 7.12, 0.069, 7.13, 2.43, 10.7, 2.09, 0.047, 28.9, 13.37,
#        2.37, 1.36, 14.26, 1.65, 2.39, 4.55, 2.32, 19.23, 3.48, 6.14, 4.2,
#        2.02, 6.42, 4.45, 5.59, 5.93, 360.0, 21.82, 6.49, 7.97, 0.88, 4.88,
#        1.13, 16.77, 2.08, 13.5, 6.1, 1.27, 5.61, 7.9, 17.3, 6.84, 3.75,
#        15.2, 2.31, 25.57, 8.1, 1.26, 7.07, 19.7, 9.95, 5.64, 0.76, 4.02,
#        2.59, 6.63, 1.62, 1.51, 12.8, 6.5, 5.74, 4.31, 17.16, 4.66, 16.59,
#        11.1, 1.19, 2.46, 4.95, 4.75, 5.89, 14.6, 2.16, 4.48, 15.67, 13.9,
#        3.35, 19.4, 5.23, 11.43, 6.24, 7.28, 2.07, 416.0, 2.3, 3.45, 5.58,
#        0.097, 2.76, 7.6, 5.07, 17.9, 28.0, 0.014, 12.02, 9.66, 4.19, 8.01,
#        5.69, 13.7, 4.65, 9.15, 5.4, 4.85, 3.53, 6.3, 3.87, 7.5, 8.74,
#        6.47, 4.86, 9.26, 5.75, 5.84, 9.9, 5.3, 3.6, 3.95, 12.54, 2.75,
#        4.12, 5.53, 38.0, 18.41, 4.8, 1.54, 9.3, 3.83, 22.3, 10.09, 6.52,
#        2.15, 14.9, 9.08, 4.69, 6.76, 3.97, 16.61, 9.1, 6.2, 3.85, 5.45,
#        3.19, 2.74, 4.99, 164.2, 4.78, 4.61, 7.2, 11.4, 8.37, 4.94, 8.57,
#        3.72, 12.3, 7.82, 4.15, 2.47, 5.46, 0.82, 37.6, 6.69, 5.1, 0.99,
#        5.6, 10.47, 6.45, 3.67, 40.4, 27.21, 22.0, 3.61, 14.8, 4.7, 4.25,
#        9.05, 3.59, 34.3, 3.32, 7.14, 10.3, 4.06, 11.0, 36.4, 2.58, 3.05,
#        23.1, 8.7, 6.9, 2.26, 2.53, 2.69, 13.8, 0.223, 3.02, 18.1, 10.52,
#        5.9, 5.8, 0.97, 6.05, 16.49, 3.17, 5.16, 10.53, 3.13, 8.4, 3.07,
#        3.62, 2.95, 9.53, 1.99, 7.37, 7.71, 0.65, 5.97, 5.94, 6.41, 10.96,
#        5.11, 11.6, 2.19, 5.39, 8.25, 5.95, 24.9, 8.48, 520.0, 8.3, 9.36,
#        23.0, 4.09, 6.38, 10.26, 6.02, 4.83, 2.36, 14.72, 11.3, 7.3, 12.6,
#        8.91, 13.07, 7.31, 3.24, 8.28, 111.0, 6.95, 9.74, 13.4, 13.06,
#        77.8, 3.52, 6.28, 1.32, 7.75, 25.3, 0.068, 0.352, 19.92, 11.42,
#        15.9, 20.5, 6.71, 4.92, 9.75, 110.0, 6.56, 3.16, 65.0, 19.0, 11.63,
#        38.8, 9.12, 9.7, 4.82, 4.72, 3.28, 2.92, 26.42, 341.0, 7.94, 0.533,
#        0.177, 8.42, 1.24, 4.59, 2.68, 431.71, 5.32, 14.25, 16.95, 23.4,
#        0.007, 18.56, 0.784, 12.38, 37.0, 3.74, 3.25, 0.015, 240.0, 10.9,
#        0.004, 4.39, 38.9, 17.2, 2.65, 1.09, 6.44, 2.33, 13.52, 27.0, 3.26,
#        2.35, 34.0, 2.72, 400.0, 10.85, 5.28, 13.71, 32.0, 3.88, 10.8,
#        2500.0, 9.07, 1.98, 14.88, 3.58, 5.25, 12.49, 5.09, 8.32, 25.9,
#        5.57, 16.9, 22.98, 7.53, 8.92, 4.32, 22.08, 6.18, 0.41, 6.54, 6.81,
#        18.29, 11.68, 14.5, 19.5, 6.17, 5.54, 4.64, 1.951, 4.13, 1500.0,
#        23.26, 2.54, 2.98, 1.52, 6.21, 1800.0, 12.25, 17.8, 6.53, 7.88,
#        2.91, 2.62, 12.7, 44.6, 3.22, 30.8, 18.5, 6.55, 14.44, 2.84, 37.1,
#        3.15, 13.66, 7.58, 8.35, 4.91, 0.197, 0.142, 4.42, 117.0, 0.028,
#        8.71, 8.14, 23.25, 17.4, 1040.0, 3.76, 6.26, 0.002, 3.03, 6.82,
#        135.0, 35.0, 58.0, 2.444, 0.224, 4.07, 0.785, 0.048, 9.8, 368.0,
#        6.13, 0.037, 5.96, 16.4, 0.892, 21.42, 54.85, 32.85, 29.71, 8.6,
#        8.78, 3.38, 343.0, 0.096, 19.75, 23.2, 50.0, 6.73, 7.1, 7.68,
#        0.132, 0.692, 700.0, 2000.0, 1000.0, 175.0, 260.0, 206.0, 5.85,
#        0.459, 0.153, 9.37, 21.6, 5.19, 10.86, 4.43, 5.36, 27.14, 19.54,
#        31.48, 8.93, 8.47, 7.04, 237.13, 55.14, 35.73, 12.28, 8.8, 11.85,
#        15.37, 114.0, 178.25, 0.146, 6.57, 324.0, 0.023], dtype=object)

# %%
# Fixing in_AllocationVolume_AF datatype
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array(['', 125.0, 279.9, ..., 111.7, 159.4, 89.95], dtype=object)

# %%
# %%time
# Creating WaDE Custom site native ID for easy site identificaiion
# ----------------------------------------------------------------------------------------------------

# Create temp SiteNativeID dataframe of unique site.
def assignSiteUUID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfSiteNativeID = pd.DataFrame()
dfSiteNativeID['in_Latitude'] = outdf['in_Latitude']
dfSiteNativeID['in_Longitude'] = outdf['in_Longitude']
dfSiteNativeID = dfSiteNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfSiteNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfSiteNativeID['in_SiteNativeID'] = dftemp.apply(lambda row: assignSiteUUID(row['Count']), axis=1)
dfSiteNativeID['linkKey'] = dfSiteNativeID['in_Latitude'].astype(str) + dfSiteNativeID['in_Longitude'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
SiteNativeIDdict = pd.Series(dfSiteNativeID.in_SiteNativeID.values, index=dfSiteNativeID.linkKey.astype(str)).to_dict()
def retrieveSiteNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        colrowValue = str(A).strip() + str(B).strip()
        try:
            outList = SiteNativeIDdict[colrowValue]
        except:
            outList = ''
    return outList

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveSiteNativeID( row['in_Latitude'], row['in_Longitude']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# Wall time: 335 ms
# array(['wadeID1', 'wadeID2', 'wadeID3', ..., 'wadeID16521', 'wadeID16522',
#        'wadeID16523'], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)
dfWaterSourceNativeID['linkKey'] = dfWaterSourceNativeID['in_WaterSourceName'].astype(str) + dfWaterSourceNativeID['in_WaterSourceTypeCV'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
WaterSourceNativeIDdict = pd.Series(dfWaterSourceNativeID.in_WaterSourceNativeID.values, index=dfWaterSourceNativeID.linkKey.astype(str)).to_dict()
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        colrowValue = str(A).strip() + str(B).strip()
        try:
            outList = WaterSourceNativeIDdict[colrowValue]
        except:
            outList = ''
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeID1', 'wadeID2', 'wadeID3', ..., 'wadeID1338', 'wadeID1339',
#        'wadeID1340'], dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For SD, we don't want water rights that are considered: Cancelled, Denied, Withdrawn

# %%
# drop non-active AllocationLegalStatusCV values specific to that state.

# drop the list
dropLegalStatusList = ["Cancelled", "Denied", "Withdrawn"]

# drop rows from above list
outdf = outdf[outdf.in_AllocationLegalStatusCV.isin(dropLegalStatusList) == False].reset_index(drop=True)

print(len(outdf))
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# 13313
# array(['Permit', 'License', 'Deferred', '', 'Future Use', 'Incorporated',
#        'Owner Change'], dtype=object)

# %% [markdown]
# ## Export Outputs

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(outdf.dtypes)
# Out:
# WaDEUUID                                                object
# in_MethodUUID                                           object
# in_VariableSpecificUUID                                 object
# in_OrganizationUUID                                     object
# in_Geometry                                             object
# in_GNISFeatureNameCV                                    object
# in_WaterQualityIndicatorCV                              object
# in_WaterSourceName                                      object
# in_WaterSourceNativeID                                  object
# in_WaterSourceTypeCV                                    object
# in_CoordinateAccuracy                                   object
# in_CoordinateMethodCV                                   object
# in_County                                               object
# in_EPSGCodeCV                                            int64
# in_GNISCodeCV                                           object
# in_HUC12                                                object
# in_HUC8                                                 object
# in_Latitude                                            float64
# in_Longitude                                           float64
# in_NHDNetworkStatusCV                                   object
# in_NHDProductCV                                         object
# in_PODorPOUSite                                         object
# in_SiteName                                             object
# in_SiteNativeID                                         object
# in_SitePoint                                            object
# in_SiteTypeCV                                           object
# in_StateCV                                              object
# in_USGSSiteID                                           object
# in_AllocationApplicationDate                            object
# in_AllocationAssociatedConsumptiveUseSiteIDs            object
# in_AllocationAssociatedWithdrawalSiteIDs                object
# in_AllocationBasisCV                                    object
# in_AllocationChangeApplicationIndicator                 object
# in_AllocationCommunityWaterSupplySystem                 object
# in_AllocationCropDutyAmount                             object
# in_AllocationExpirationDate                             object
# in_AllocationFlow_CFS                                   object
# in_AllocationLegalStatusCV                              object
# in_AllocationNativeID                                   object
# in_AllocationOwner                                      object
# in_AllocationPriorityDate                       datetime64[ns]
# in_AllocationSDWISIdentifierCV                          object
# in_AllocationTimeframeEnd                               object
# in_AllocationTimeframeStart                             object
# in_AllocationTypeCV                                     object
# in_AllocationVolume_AF                                  object
# in_BeneficialUseCategory                                object
# in_CommunityWaterSupplySystem                           object
# in_CropTypeCV                                           object
# in_CustomerTypeCV                                       object
# in_DataPublicationDate                                  object
# in_DataPublicationDOI                                   object
# in_ExemptOfVolumeFlowPriority                            int64
# in_GeneratedPowerCapacityMW                             object
# in_IrrigatedAcreage                                     object
# in_IrrigationMethodCV                                   object
# in_LegacyAllocationIDs                                  object
# in_OwnerClassificationCV                                object
# in_PopulationServed                                     object
# in_PowerType                                            object
# in_PrimaryBeneficialUseCategory                         object
# in_SDWISIdentifierCV                                    object
# in_WaterAllocationNativeURL                             object
# dtype: object

# %%
outdf
# Out:
#         WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0          sdwr0       SDwr_M1                 SDwr_V1             SDwr_O1
# 1          sdwr1       SDwr_M1                 SDwr_V1             SDwr_O1
# 2          sdwr3       SDwr_M1                 SDwr_V1             SDwr_O1
# 3          sdwr4       SDwr_M1                 SDwr_V1             SDwr_O1
# 4         sdwr20       SDwr_M1                 SDwr_V1             SDwr_O1
# ...          ...           ...                     ...                 ...
# 13308  sdwr19224       SDwr_M1                 SDwr_V1             SDwr_O1
# 13309  sdwr19225       SDwr_M1                 SDwr_V1             SDwr_O1
# 13310  sdwr19226       SDwr_M1                 SDwr_V1             SDwr_O1
# 13311  sdwr19227       SDwr_M1                 SDwr_V1             SDwr_O1
# 13312  sdwr19228       SDwr_M1                 SDwr_V1             SDwr_O1
#
#       in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...           ...                  ...                        ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#          in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                Wolf Creek                wadeID1        Surface Water
# 1              Beaver Creek                wadeID2        Surface Water
# 2               Groundwater                wadeID4          Groundwater
# 3      Bull Creek Tributary                wadeID5        Surface Water
# 4               James River               wadeID11        Surface Water
# ...                     ...                    ...                  ...
# 13308                Runoff               wadeID25        Surface Water
# 13309           Groundwater                wadeID4          Groundwater
# 13310           Groundwater                wadeID4          Groundwater
# 13311              Dry Draw                wadeID3        Surface Water
# 13312          French Creek              wadeID130        Surface Water
#
#       in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                                                     4326
# 1                                                                     4326
# 2                                                                     4326
# 3                                                                     4326
# 4                                                                     4326
# ...                     ...                   ...       ...            ...
# 13308                                                                 4326
# 13309                                                                 4326
# 13310                                                                 4326
# 13311                                                                 4326
# 13312                                                                 4326
#
#       in_GNISCodeCV in_HUC12   in_HUC8  in_Latitude  in_Longitude  \
# 0                             10160010     43.71384     -97.60780
# 1                             10170203     43.31191     -96.60393
# 2                             10170202     44.42416     -96.90175
# 3                             10140101     43.26114     -99.58091
# 4                             10160003     45.53910     -98.10536
# ...             ...      ...       ...          ...           ...
# 13308                         10170203     43.51808     -96.57607
# 13309                         10120202     44.60921    -103.63923
# 13310                         10120111     44.19641    -103.35057
# 13311                         10120203     44.40136    -103.84815
# 13312                         10120109     43.75653    -103.64014
#
#       in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                       POD
# 1                                                       POD
# 2                                                       POD
# 3                                                       POD
# 4                                                       POD
# ...                     ...             ...             ...         ...
# 13308                                                   POD
# 13309                                                   POD
# 13310                                                   POD
# 13311                                                   POD
# 13312                                                   POD
#
#       in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0             wadeID1                                    SD
# 1             wadeID2                                    SD
# 2             wadeID4                                    SD
# 3             wadeID5                                    SD
# 4            wadeID21                                    SD
# ...               ...          ...           ...        ...           ...
# 13308     wadeID16511                                    SD
# 13309     wadeID16512                                    SD
# 13310     wadeID16513                                    SD
# 13311     wadeID16514                                    SD
# 13312     wadeID16515                                    SD
#
#       in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                            ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                  ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...                         ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2                                               1.79700
# 3                                               4.00000
# 4
# ...                           ...                   ...
# 13308                                           0.56000
# 13309                                           0.89000
# 13310                                           0.02200
# 13311
# 13312                                           0.02200
#
#       in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                         Permit                FC10-3
# 1                        License                FC11-3
# 2                        License                1017-3
# 3                        License                1422-2
# 4                       Deferred                FC15-3
# ...                          ...                   ...
# 13308                    License                5996-3
# 13309                    License                1650-1
# 13310                    License                1651-1
# 13311                    License                1422-1
# 13312                    License                2380-2
#
#                  in_AllocationOwner in_AllocationPriorityDate  \
# 0                     Mccook County                1988-12-08
# 1                    Harold Dykstra                1989-07-21
# 2                     Natasha Swier                1963-02-11
# 3                   Gerald E Gergen                1976-08-20
# 4      Lower Crow Creek Improvement                       NaT
# ...                             ...                       ...
# 13308               L G Everist Inc                1997-04-21
# 13309      Foothill Land Cattle Llc                1997-04-03
# 13310      Stagebarn Housing Center                1997-05-16
# 13311          Lac Minerals Usa Llc                1987-10-01
# 13312              C Patrick Dillon                1997-02-06
#
#       in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...                       ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0
# 1
# 2                                                                  125.00000
# 3                                                                  279.90000
# 4
# ...                           ...                 ...                    ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0         Flood Control Permit
# 1         Flood Control Permit
# 2                   Irrigation
# 3                   Irrigation
# 4         Flood Control Permit
# ...                        ...                           ...           ...
# 13308               Commercial
# 13309   Commercial, Irrigation
# 13310               Commercial
# 13311               Industrial
# 13312               Industrial
#
#       in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                 ...                    ...                   ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#        in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...                         ...
# 13308                              0
# 13309                              0
# 13310                              0
# 13311                              0
# 13312                              0
#
#       in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                   ...                    ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                 ...          ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                  ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#                              in_WaterAllocationNativeURL
# 0      https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 1      https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 2      https://danr.sd.gov/wrimage/wrinfo/wr_div3/101...
# 3      https://danr.sd.gov/wrimage/wrinfo/wr_div2/142...
# 4      https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# ...                                                  ...
# 13308  https://danr.sd.gov/wrimage/wrinfo/wr_div3/599...
# 13309  https://danr.sd.gov/wrimage/wrinfo/wr_div1/165...
# 13310  https://danr.sd.gov/wrimage/wrinfo/wr_div1/165...
# 13311  https://danr.sd.gov/wrimage/wrinfo/wr_div1/142...
# 13312  https://danr.sd.gov/wrimage/wrinfo/wr_div2/238...
#
# [13313 rows x 63 columns]

# %%
# Export the output dataframe
outdf.to_csv('Pwr_sdMain.zip', compression=dict(method='zip', archive_name='Pwr_sdMain.csv'), index=False)  # The output, save as a zip
#dfPoUshape.to_csv('P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
