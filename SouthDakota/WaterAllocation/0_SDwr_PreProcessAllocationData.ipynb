# %% [markdown]
# # Pre-processing South Dakota Allocation data for WaDEQA upload.
# Purpose: To pre-process the South Dakota data into one master file for simple DataFrame creation and extraction
#
# Notes: N/A

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x) # suppress scientific notation in Pandas

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/SouthDakota/WaterAllocation/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## Data: waterights

# %%
# Input File
fileInput = "waterights_input.csv"
df = pd.read_csv(fileInput).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in df:
    df['WaDEUUID'] = "sdwr" + df.index.astype(str)
    df.to_csv('waterights_input.csv', index=False)

print(len(df))
df.head(1)
# Out:
# 19238
# C:\Users\rjame\AppData\Local\Temp\ipykernel_17744\788753031.py:3: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fileInput).replace(np.nan, "")
#   WaDEUUID ReasonRemoved IncompleteField  OID_ PERMIT_NO  LATITUDE  LONGITUDE  \
# 0    sdwr0                                   1    FC10-3  43.71384  -97.60780
#
#        LAST_NAME FIRST_NAME ADDRESS2   CITY STATE    ZIP PLUS4 COUNTY_1 BASIN  \
# 0  MCCOOK COUNTY             BOX 550  SALEM    SD  57058   550       MC    JR
#
#   HYDROUNIT1       PRIORDATE STATUS SOURCE AQUIFER MNG_UNIT  DIVERSION1  \
# 0   10160010  12/8/1988 0:00     PE      S                   WOLF CREEK
#
#   USE_TYPE1 USE_TYPE2 USE_TYPE4 USE_TYPE5 USE_TYPE6  PER_CFS  LIC_CFS  \
# 0       FCP                                          0.00000  0.00000
#
#    PER_ACRES  LIC_ACRES     CMPLTN_DTE LIC_DTE INSPT_DATE INSPECTOR  \
# 0    0.00000    0.00000  3/1/1994 0:00
#
#   METHODCODE        REFERENCE  ACCURACY  \
# 0  TRSOTH100  DIVERSION POINT       140
#
#                                            LINK
# 0  R:\work\wr\imaging\wrinfo\wr_div3\FC10-3.pdf

# %%
# first & last name funciton
def assignownerName(fName, lName):
    
    # Cleaning Text
    fName = str(fName)
    lName = str(lName)
    fName = fName.replace("*", "")
    lName = lName.replace("*", "")      
    
    # Check if first or last name are empty
    if fName == "" or pd.isnull(fName):
        outList1 = ""
    else:
        outList1 = fName.strip()
        
    if lName == "" or pd.isnull(lName):
        outList2 = ""
    else:
        outList2 = lName.strip()

    # ouput
    if outList1 == "" and outList2 == "":
        outList = ""
    elif outList1 == "":
        outList = outList2
    elif outList2 == "":
        outList = outList1
    else:
        outList = " ".join(map(str, [fName, lName]))
    return outList

df['in_AllocationOwner'] = df.apply(lambda row: assignownerName(row['FIRST_NAME'], row['LAST_NAME']), axis=1)


import re
def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).strip()
    return Val

df['in_AllocationOwner'] = df.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
df['in_AllocationOwner'].unique()
# Out:
# array(['MCCOOK COUNTY', 'HAROLD DYKSTRA', 'MERIDIAN MINERALS CO', ...,
#        'AMBROSE HEIMER', 'RAY MASON', 'CHARLES CAPP'], dtype=object)

# %%
#Creating Beneficial Use.
#Need to translate SD abbreviatoins to a workable format.

BenUseDict = {
"COM" : "Commercial",
"DOM" : "Domestic",
"FCP" : "Flood Control Permit",
"FWP" : "Fish And Wildlife Propagation",
"GEO" : "Geothermal",
"GWR" : "Ground Water Remediation",
"IND" : "Industrial",
"INS" : "Institutional",
"IRR" : "Irrigation",
"MUN" : "Municipal",
"REC" : "Recreation",
"RWS" : "Rural Water System",
"SHD" : "Suburban Housing Development"}

def retrieveBenUse(A, B, C, D):
    A = str(A).strip()
    B = str(B).strip()
    C = str(C).strip()
    D = str(D).strip()

    if A == "":
        outA = ""
    else:
        try:
            outA = BenUseDict[A]
        except:
            outA = "WaDE Unspecified"

    if B == "":
        outB = ""
    else:
        try:
            outB = ", " + BenUseDict[B]
        except:
            outB = ", " + "WaDE Unspecified"

    if C == "":
        outC = ""
    else:
        try:
            outC = ", " + BenUseDict[C]
        except:
            outC = ", " + "WaDE Unspecified"

    if D == "":
        outD = ""
    else:
        try:
            outD = ", " + BenUseDict[D]
        except:
            outD = ", " + "WaDE Unspecified"

    outList = outA + outB + outC + outD
    outList = outList.strip()

    return outList

df['in_BeneficialUseCategory'] = df.apply(lambda row: retrieveBenUse(row['USE_TYPE1'], 
                                                          row['USE_TYPE2'], 
                                                          row['USE_TYPE4'], 
                                                          row['USE_TYPE5']), axis=1)
df['in_BeneficialUseCategory'].unique()
# Out:
# array(['Flood Control Permit', 'Irrigation', 'Commercial, Industrial',
#        'Industrial', 'Municipal', 'Rural Water System',
#        'Irrigation, Rural Water System, Fish And Wildlife Propagation, Domestic',
#        'Commercial', 'Commercial, Domestic',
#        'Fish And Wildlife Propagation, Domestic',
#        'Commercial, Recreation', 'Ground Water Remediation',
#        'Fish And Wildlife Propagation', 'Recreation',
#        'Suburban Housing Development, Commercial', 'Irrigation, Domestic',
#        'Domestic', 'Suburban Housing Development',
#        'Municipal, Industrial, Rural Water System, Suburban Housing Development',
#        'Recreation, Domestic', 'Domestic, Commercial',
#        'Fish And Wildlife Propagation, Recreation',
#        'Fish And Wildlife Propagation, Irrigation',
#        'Recreation, Municipal', 'Industrial, Domestic',
#        'Municipal, Industrial, Suburban Housing Development, Commercial',
#        'Commercial, Irrigation', 'Geothermal', 'Institutional',
#        'Domestic, Recreation', 'Domestic, Suburban Housing Development',
#        'Suburban Housing Development, Recreation',
#        'Municipal, Industrial, Commercial',
#        'Domestic, Irrigation, Recreation',
#        'Domestic, Fish And Wildlife Propagation, Recreation',
#        'Domestic, Recreation, Fish And Wildlife Propagation',
#        'Recreation, Domestic, Fish And Wildlife Propagation',
#        'Irrigation, Fish And Wildlife Propagation, Recreation',
#        'Domestic, Fish And Wildlife Propagation',
#        'Commercial, Fish And Wildlife Propagation',
#        'Domestic, Fish And Wildlife Propagation, Irrigation',
#        'Fish And Wildlife Propagation, Domestic, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Recreation',
#        'Fish And Wildlife Propagation, Commercial',
#        'Fish And Wildlife Propagation, Domestic, Recreation',
#        'Domestic, Recreation, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Irrigation, Recreation, Irrigation',
#        'Domestic, Irrigation', 'Irrigation, Municipal',
#        'Irrigation, Commercial',
#        'Suburban Housing Development, Rural Water System',
#        'Domestic, Irrigation, Fish And Wildlife Propagation',
#        'Commercial, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Municipal, Irrigation, Recreation',
#        'Municipal, Industrial',
#        'Recreation, Fish And Wildlife Propagation',
#        'Commercial, Suburban Housing Development',
#        'Recreation, Irrigation',
#        'Irrigation, Fish And Wildlife Propagation, Domestic',
#        'Recreation, Municipal, Industrial, Domestic',
#        'Domestic, Municipal, Fish And Wildlife Propagation',
#        'Irrigation, Suburban Housing Development, Domestic',
#        'Municipal, Geothermal', 'Irrigation, Institutional',
#        'Suburban Housing Development, Domestic', 'Irrigation, Industrial',
#        'Industrial, Commercial',
#        'Rural Water System, Suburban Housing Development',
#        'Industrial, Municipal',
#        'Irrigation, Commercial, Domestic, Industrial',
#        'Rural Water System, Municipal',
#        'Suburban Housing Development, Municipal',
#        'Irrigation, Rural Water System',
#        'Suburban Housing Development, Geothermal',
#        'Irrigation, Municipal, Recreation', '', 'Institutional, Domestic',
#        'Commercial, Geothermal',
#        'Geothermal, Fish And Wildlife Propagation',
#        'Rural Water System, Domestic', 'Municipal, Recreation',
#        'Irrigation, Suburban Housing Development',
#        'Institutional, Industrial', 'Irrigation, WaDE Unspecified',
#        'Municipal, Rural Water System, Suburban Housing Development, Commercial',
#        'Municipal, Industrial, Suburban Housing Development, Rural Water System',
#        'Municipal, Irrigation, Recreation, Domestic',
#        'Irrigation, Municipal, Recreation, Domestic',
#        'Domestic, Geothermal', 'Recreation, Commercial',
#        'Geothermal, Domestic', 'Domestic, Rural Water System',
#        'Domestic, Recreation, Municipal, Industrial',
#        'Rural Water System, Irrigation',
#        'Commercial, Suburban Housing Development, Domestic',
#        'Municipal, Commercial, Rural Water System, Suburban Housing Development',
#        'Irrigation, Recreation, Domestic',
#        'Irrigation, Domestic, Fish And Wildlife Propagation',
#        'Municipal, Rural Water System', 'Domestic, Municipal',
#        'Commercial, Domestic, Rural Water System',
#        'Commercial, Municipal',
#        'Municipal, Industrial, Rural Water System, Domestic',
#        'Industrial, Irrigation', 'Recreation, Institutional',
#        'Irrigation, Recreation', 'Geothermal, Irrigation',
#        'Municipal, Domestic', 'Geothermal, Institutional',
#        'Institutional, Municipal', 'Institutional, Recreation',
#        'Irrigation, Fish And Wildlife Propagation',
#        'Institutional, Irrigation', 'Domestic, Municipal, Industrial',
#        'Municipal, Irrigation',
#        'Irrigation, Domestic, Industrial, Recreation',
#        'Irrigation, Domestic, Fish And Wildlife Propagation, Recreation',
#        'Irrigation, Recreation, Fish And Wildlife Propagation, Domestic',
#        'Industrial, Commercial, Recreation', 'Municipal, Commercial'],
#       dtype=object)

# %%
#Creating WaterSourceTypeCV field

WSTypeDict = {
    "S" : "Surface Water",
    "G" : "Groundwater",
    "B" : "Surface Water and Groundwater"}

def retrieveWSType(colrowValue):
    colrowValue = str(colrowValue).strip()
    if colrowValue == "" or pd.isnull(colrowValue):
        outString = "WaDE Unspecified"
    else:
        try:
            outString = WSTypeDict[colrowValue]
        except:
            outString = "WaDE Unspecified"
    return outString

df['in_WaterSourceTypeCV'] = df.apply(lambda row: retrieveWSType(row['SOURCE']), axis=1)
df['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater', 'Surface Water and Groundwater',
#        'WaDE Unspecified'], dtype=object)

# %%
#Creating allocation status

AlloStatusDict = {
"CA" : "Cancelled",
"DF" : "Deferred",
"DN" : "Denied",
"FU" : "Future Use",
"HD" : "Hold",
"IP" : "Incorporated",
"LC" : "License",
"OC" : "Owner Change",
"PE" : "Permit",
"WI" : "Withdrawn"}

def retrieveStatus(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = "WaDE Unspecified"
    else:
        String1 = str(colrowValue).strip()
        try:
            outList = AlloStatusDict[String1]
        except:
            outList = "WaDE Unspecified"
    return outList

df['in_AllocationLegalStatusCV'] = df.apply(lambda row: retrieveStatus(row['STATUS']), axis=1)
df['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Permit', 'License', 'Cancelled', 'Deferred', 'Denied',
#        'Withdrawn', 'WaDE Unspecified', 'Future Use', 'Incorporated',
#        'Owner Change'], dtype=object)

# %%
# Creating the output Dataframe for PODs.

dfPOD = pd.DataFrame(index=df.index)

# Data Assessment UUID
dfPOD['WaDEUUID'] = df['WaDEUUID']

# Water Source
dfPOD["in_WaterSourceName"] = df['DIVERSION1']
dfPOD["in_WaterSourceTypeCV"] = df['in_WaterSourceTypeCV']

# Site
dfPOD["in_CoordinateAccuracy"] = "WaDE Unspecified"
dfPOD["in_CoordinateMethodCV"] = "WaDE Unspecified"
dfPOD['in_HUC12'] = ""
dfPOD['in_HUC8'] = df['HYDROUNIT1']
dfPOD['in_County'] = "WaDE Unspecified"
dfPOD["in_Latitude"] = df['LATITUDE']
dfPOD["in_Longitude"] = df['LONGITUDE']
dfPOD["in_PODorPOUSite"] = "POD"
dfPOD["in_SiteName"] = "WaDE Unspecified"
dfPOD["in_SiteNativeID"] = ""  #make custom id below
dfPOD["in_SiteTypeCV"] = "WaDE Unspecified"
dfPOD["in_StateCV"] = "SD"

# Allocation
dfPOD["in_AllocationApplicationDate"] = ""
dfPOD["in_AllocationExpirationDate"] = ""
dfPOD["in_AllocationFlow_CFS"] = df['PER_CFS'].astype(float)
dfPOD["in_AllocationVolume_AF"] = df['PER_ACRES'].astype(float)
dfPOD['in_AllocationLegalStatusCV'] = df['in_AllocationLegalStatusCV']
dfPOD["in_AllocationNativeID"] = df['PERMIT_NO']
dfPOD['in_AllocationOwner'] = df['in_AllocationOwner']
dfPOD['in_AllocationPriorityDate'] = df['PRIORDATE']
dfPOD['in_AllocationTimeframeEnd'] = ""
dfPOD['in_AllocationTimeframeStart'] = ""
dfPOD['in_AllocationTypeCV'] = "WaDE Unspecified"
dfPOD["in_BeneficialUseCategory"] = df['in_BeneficialUseCategory']
dfPOD['in_CommunityWaterSupplySystem'] = ""
dfPOD['in_ExemptOfVolumeFlowPriority'] = "0"
dfPOD["in_IrrigatedAcreage"] = ""
dfPOD["in_IrrigationMethodCV"] = ""
dfPOD["in_WaterAllocationNativeURL"] = "https://danr.sd.gov/wrimage/wrinfo/wr_div3/" + df['PERMIT_NO'] + ".pdf"

dfPOD = dfPOD.drop_duplicates().reset_index(drop=True)
print(len(dfPOD))
dfPOD.head(1)
# Out:
# 19238
#   WaDEUUID in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0    sdwr0         WOLF CREEK        Surface Water      WaDE Unspecified
#
#   in_CoordinateMethodCV in_HUC12   in_HUC8         in_County  in_Latitude  \
# 0      WaDE Unspecified           10160010  WaDE Unspecified     43.71384
#
#    in_Longitude in_PODorPOUSite       in_SiteName in_SiteNativeID  \
# 0     -97.60780             POD  WaDE Unspecified
#
#       in_SiteTypeCV in_StateCV in_AllocationApplicationDate  \
# 0  WaDE Unspecified         SD
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  in_AllocationVolume_AF  \
# 0                                            0.00000                 0.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 0                     Permit                FC10-3      MCCOOK COUNTY
#
#   in_AllocationPriorityDate in_AllocationTimeframeEnd  \
# 0            12/8/1988 0:00
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_BeneficialUseCategory  \
# 0                                WaDE Unspecified     Flood Control Permit
#
#   in_CommunityWaterSupplySystem in_ExemptOfVolumeFlowPriority  \
# 0                                                           0
#
#   in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
#
#                          in_WaterAllocationNativeURL
# 0  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...

# %% [markdown]
# ## WaDE Custom Elements (due to missing sate info)

# %%
# Fixing empty string names

def fixEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or pd.isnull(val):
        outString = "WaDE Unspecified"
    else:
        outString = val
    return outString

# %%
dfPOD['in_WaterSourceName'] = dfPOD.apply(lambda row: fixEmptyString(row['in_WaterSourceName']), axis=1)
dfPOD['in_WaterSourceName'].unique()
# Out:
# array(['WOLF CREEK', 'BEAVER CREEK', 'DRY DRAW', ..., 'LAKE',
#        'W BRANCH BULL CREEK', 'UNNAMED DRY CREEK'], dtype=object)

# %%
dfPOD['in_AllocationLegalStatusCV'] = dfPOD.apply(lambda row: fixEmptyString(row['in_AllocationLegalStatusCV']), axis=1)
dfPOD['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Permit', 'License', 'Cancelled', 'Deferred', 'Denied',
#        'Withdrawn', 'WaDE Unspecified', 'Future Use', 'Incorporated',
#        'Owner Change'], dtype=object)

# %%
dfPOD['in_BeneficialUseCategory'] = dfPOD.apply(lambda row: fixEmptyString(row['in_BeneficialUseCategory']), axis=1)
dfPOD['in_BeneficialUseCategory'].unique()
# Out:
# array(['Flood Control Permit', 'Irrigation', 'Commercial, Industrial',
#        'Industrial', 'Municipal', 'Rural Water System',
#        'Irrigation, Rural Water System, Fish And Wildlife Propagation, Domestic',
#        'Commercial', 'Commercial, Domestic',
#        'Fish And Wildlife Propagation, Domestic',
#        'Commercial, Recreation', 'Ground Water Remediation',
#        'Fish And Wildlife Propagation', 'Recreation',
#        'Suburban Housing Development, Commercial', 'Irrigation, Domestic',
#        'Domestic', 'Suburban Housing Development',
#        'Municipal, Industrial, Rural Water System, Suburban Housing Development',
#        'Recreation, Domestic', 'Domestic, Commercial',
#        'Fish And Wildlife Propagation, Recreation',
#        'Fish And Wildlife Propagation, Irrigation',
#        'Recreation, Municipal', 'Industrial, Domestic',
#        'Municipal, Industrial, Suburban Housing Development, Commercial',
#        'Commercial, Irrigation', 'Geothermal', 'Institutional',
#        'Domestic, Recreation', 'Domestic, Suburban Housing Development',
#        'Suburban Housing Development, Recreation',
#        'Municipal, Industrial, Commercial',
#        'Domestic, Irrigation, Recreation',
#        'Domestic, Fish And Wildlife Propagation, Recreation',
#        'Domestic, Recreation, Fish And Wildlife Propagation',
#        'Recreation, Domestic, Fish And Wildlife Propagation',
#        'Irrigation, Fish And Wildlife Propagation, Recreation',
#        'Domestic, Fish And Wildlife Propagation',
#        'Commercial, Fish And Wildlife Propagation',
#        'Domestic, Fish And Wildlife Propagation, Irrigation',
#        'Fish And Wildlife Propagation, Domestic, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Recreation',
#        'Fish And Wildlife Propagation, Commercial',
#        'Fish And Wildlife Propagation, Domestic, Recreation',
#        'Domestic, Recreation, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Irrigation, Recreation, Irrigation',
#        'Domestic, Irrigation', 'Irrigation, Municipal',
#        'Irrigation, Commercial',
#        'Suburban Housing Development, Rural Water System',
#        'Domestic, Irrigation, Fish And Wildlife Propagation',
#        'Commercial, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Municipal, Irrigation, Recreation',
#        'Municipal, Industrial',
#        'Recreation, Fish And Wildlife Propagation',
#        'Commercial, Suburban Housing Development',
#        'Recreation, Irrigation',
#        'Irrigation, Fish And Wildlife Propagation, Domestic',
#        'Recreation, Municipal, Industrial, Domestic',
#        'Domestic, Municipal, Fish And Wildlife Propagation',
#        'Irrigation, Suburban Housing Development, Domestic',
#        'Municipal, Geothermal', 'Irrigation, Institutional',
#        'Suburban Housing Development, Domestic', 'Irrigation, Industrial',
#        'Industrial, Commercial',
#        'Rural Water System, Suburban Housing Development',
#        'Industrial, Municipal',
#        'Irrigation, Commercial, Domestic, Industrial',
#        'Rural Water System, Municipal',
#        'Suburban Housing Development, Municipal',
#        'Irrigation, Rural Water System',
#        'Suburban Housing Development, Geothermal',
#        'Irrigation, Municipal, Recreation', 'WaDE Unspecified',
#        'Institutional, Domestic', 'Commercial, Geothermal',
#        'Geothermal, Fish And Wildlife Propagation',
#        'Rural Water System, Domestic', 'Municipal, Recreation',
#        'Irrigation, Suburban Housing Development',
#        'Institutional, Industrial', 'Irrigation, WaDE Unspecified',
#        'Municipal, Rural Water System, Suburban Housing Development, Commercial',
#        'Municipal, Industrial, Suburban Housing Development, Rural Water System',
#        'Municipal, Irrigation, Recreation, Domestic',
#        'Irrigation, Municipal, Recreation, Domestic',
#        'Domestic, Geothermal', 'Recreation, Commercial',
#        'Geothermal, Domestic', 'Domestic, Rural Water System',
#        'Domestic, Recreation, Municipal, Industrial',
#        'Rural Water System, Irrigation',
#        'Commercial, Suburban Housing Development, Domestic',
#        'Municipal, Commercial, Rural Water System, Suburban Housing Development',
#        'Irrigation, Recreation, Domestic',
#        'Irrigation, Domestic, Fish And Wildlife Propagation',
#        'Municipal, Rural Water System', 'Domestic, Municipal',
#        'Commercial, Domestic, Rural Water System',
#        'Commercial, Municipal',
#        'Municipal, Industrial, Rural Water System, Domestic',
#        'Industrial, Irrigation', 'Recreation, Institutional',
#        'Irrigation, Recreation', 'Geothermal, Irrigation',
#        'Municipal, Domestic', 'Geothermal, Institutional',
#        'Institutional, Municipal', 'Institutional, Recreation',
#        'Irrigation, Fish And Wildlife Propagation',
#        'Institutional, Irrigation', 'Domestic, Municipal, Industrial',
#        'Municipal, Irrigation',
#        'Irrigation, Domestic, Industrial, Recreation',
#        'Irrigation, Domestic, Fish And Wildlife Propagation, Recreation',
#        'Irrigation, Recreation, Fish And Wildlife Propagation, Domestic',
#        'Industrial, Commercial, Recreation', 'Municipal, Commercial'],
#       dtype=object)

# %%
# Changing datatype of date fields to fit WaDE.
dfPOD['in_AllocationPriorityDate'] = pd.to_datetime(dfPOD['in_AllocationPriorityDate'], errors = 'coerce')
dfPOD['in_AllocationPriorityDate'] = pd.to_datetime(dfPOD["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
dfPOD.head()
# Out:
#    WaDEUUID    in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0     sdwr0            WOLF CREEK        Surface Water      WaDE Unspecified
# 1     sdwr1          BEAVER CREEK        Surface Water      WaDE Unspecified
# 2    sdwr10              DRY DRAW        Surface Water      WaDE Unspecified
# 3   sdwr100           GROUNDWATER          Groundwater      WaDE Unspecified
# 4  sdwr1000  BULL CREEK TRIBUTARY        Surface Water      WaDE Unspecified
#
#   in_CoordinateMethodCV in_HUC12   in_HUC8         in_County  in_Latitude  \
# 0      WaDE Unspecified           10160010  WaDE Unspecified     43.71384
# 1      WaDE Unspecified           10170203  WaDE Unspecified     43.31191
# 2      WaDE Unspecified           10170203  WaDE Unspecified     43.63269
# 3      WaDE Unspecified           10170202  WaDE Unspecified     44.42416
# 4      WaDE Unspecified           10140101  WaDE Unspecified     43.26114
#
#    in_Longitude in_PODorPOUSite       in_SiteName in_SiteNativeID  \
# 0     -97.60780             POD  WaDE Unspecified
# 1     -96.60393             POD  WaDE Unspecified
# 2     -96.56461             POD  WaDE Unspecified
# 3     -96.90175             POD  WaDE Unspecified
# 4     -99.58091             POD  WaDE Unspecified
#
#       in_SiteTypeCV in_StateCV in_AllocationApplicationDate  \
# 0  WaDE Unspecified         SD
# 1  WaDE Unspecified         SD
# 2  WaDE Unspecified         SD
# 3  WaDE Unspecified         SD
# 4  WaDE Unspecified         SD
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  in_AllocationVolume_AF  \
# 0                                            0.00000                 0.00000
# 1                                            0.00000                 0.00000
# 2                                            0.00000                 0.00000
# 3                                            1.79700               125.00000
# 4                                            4.00000               279.90000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID    in_AllocationOwner  \
# 0                     Permit                FC10-3         MCCOOK COUNTY
# 1                    License                FC11-3        HAROLD DYKSTRA
# 2                  Cancelled                 FC7-3  MERIDIAN MINERALS CO
# 3                    License                1017-3         NATASHA SWIER
# 4                    License                1422-2       GERALD E GERGEN
#
#   in_AllocationPriorityDate in_AllocationTimeframeEnd  \
# 0                1988-12-08
# 1                1989-07-21
# 2                1986-12-29
# 3                1963-02-11
# 4                1976-08-20
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_BeneficialUseCategory  \
# 0                                WaDE Unspecified     Flood Control Permit
# 1                                WaDE Unspecified     Flood Control Permit
# 2                                WaDE Unspecified     Flood Control Permit
# 3                                WaDE Unspecified               Irrigation
# 4                                WaDE Unspecified               Irrigation
#
#   in_CommunityWaterSupplySystem in_ExemptOfVolumeFlowPriority  \
# 0                                                           0
# 1                                                           0
# 2                                                           0
# 3                                                           0
# 4                                                           0
#
#   in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 1  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 2  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC7...
# 3  https://danr.sd.gov/wrimage/wrinfo/wr_div3/101...
# 4  https://danr.sd.gov/wrimage/wrinfo/wr_div3/142...

# %%
# Fixing in_AllocationFlow_CFS datatype
dfPOD['in_AllocationFlow_CFS'] = pd.to_numeric(dfPOD['in_AllocationFlow_CFS'], errors='coerce').fillna(0)
dfPOD['in_AllocationFlow_CFS'].unique()
# Out:
# array([0.0000e+00, 1.7970e+00, 4.0000e+00, 5.5000e-01, 2.0500e+00,
#        6.0000e-01, 1.5700e+00, 2.0000e+00, 2.4000e+00, 2.1000e+00,
#        2.2400e+00, 2.2800e+00, 5.0500e+00, 4.5700e+00, 4.4000e+00,
#        3.0000e-01, 8.6000e-01, 2.5000e+00, 3.3000e-01, 7.0600e+00,
#        1.0850e+01, 5.2800e+00, 1.3710e+01, 3.2000e+01, 3.8800e+00,
#        1.0800e+01, 2.5000e+03, 9.0700e+00, 1.9800e+00, 1.4880e+01,
#        3.5800e+00, 5.2500e+00, 1.2490e+01, 5.0900e+00, 8.3200e+00,
#        2.5900e+01, 5.5700e+00, 1.6900e+01, 2.2980e+01, 7.5300e+00,
#        8.9200e+00, 4.3200e+00, 2.2080e+01, 6.1800e+00, 4.1000e-01,
#        6.5400e+00, 6.8100e+00, 1.8290e+01, 1.1680e+01, 1.4500e+01,
#        1.9500e+01, 6.1700e+00, 5.5400e+00, 4.6400e+00, 1.9510e+00,
#        4.1300e+00, 1.5000e+03, 2.3260e+01, 2.5400e+00, 2.9800e+00,
#        1.5200e+00, 6.2100e+00, 1.8000e+03, 1.2250e+01, 1.7800e+01,
#        6.5300e+00, 7.8800e+00, 2.9100e+00, 2.6200e+00, 1.2700e+01,
#        4.4600e+01, 3.2200e+00, 3.0800e+01, 1.8500e+01, 6.5500e+00,
#        1.4440e+01, 2.8400e+00, 3.7100e+01, 3.1500e+00, 1.3660e+01,
#        7.5800e+00, 8.3500e+00, 4.9100e+00, 1.9700e-01, 1.4200e-01,
#        4.4200e+00, 1.1700e+02, 2.8000e-02, 8.7100e+00, 8.1400e+00,
#        2.3250e+01, 1.7400e+01, 1.0400e+03, 3.7600e+00, 6.2600e+00,
#        2.0000e-03, 3.0300e+00, 6.8200e+00, 1.3500e+02, 3.5000e+01,
#        5.8000e+01, 2.4440e+00, 2.2400e-01, 4.0700e+00, 7.8500e-01,
#        4.8000e-02, 9.8000e+00, 3.6800e+02, 6.1300e+00, 3.7000e-02,
#        5.9600e+00, 1.6400e+01, 8.9200e-01, 2.1420e+01, 5.4850e+01,
#        3.2850e+01, 2.9710e+01, 8.6000e+00, 8.7800e+00, 3.3800e+00,
#        3.4300e+02, 9.6000e-02, 1.9750e+01, 2.3200e+01, 5.0000e+01,
#        6.7300e+00, 7.1000e+00, 7.6800e+00, 1.3200e-01, 6.9200e-01,
#        7.0000e+02, 2.0000e+03, 1.0000e+03, 1.7500e+02, 2.6000e+02,
#        2.0600e+02, 5.8500e+00, 4.5900e-01, 1.5300e-01, 9.3700e+00,
#        2.1600e+01, 5.1900e+00, 1.0860e+01, 4.4300e+00, 5.3600e+00,
#        2.7140e+01, 1.9540e+01, 3.1480e+01, 8.9300e+00, 8.4700e+00,
#        7.0400e+00, 2.3713e+02, 5.5140e+01, 3.5730e+01, 1.2280e+01,
#        8.8000e+00, 1.1850e+01, 1.5370e+01, 1.1400e+02, 1.7825e+02,
#        1.4600e-01, 6.5700e+00, 3.2400e+02, 2.3000e-02])

# %%
# Fixing in_AllocationVolume_AF datatype
dfPOD['in_AllocationVolume_AF'] = pd.to_numeric(dfPOD['in_AllocationVolume_AF'], errors='coerce').fillna(0)
dfPOD['in_AllocationVolume_AF'].unique()
# Out:
# array([  0.  , 125.  , 279.9 , ..., 111.7 , 159.4 ,  89.95])

# %%
# Creating WaDE Custom site native ID for easy site identificaiion
# ----------------------------------------------------------------------------------------------------

# Create temp SiteNativeID dataframe of unique site.
def assignSiteUUID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDESD_S" + string1
    return outstring

dfSiteNativeID = pd.DataFrame()
dfSiteNativeID['in_Latitude'] = dfPOD['in_Latitude']
dfSiteNativeID['in_Longitude'] = dfPOD['in_Longitude']
dfSiteNativeID = dfSiteNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfSiteNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfSiteNativeID['in_SiteNativeID'] = dftemp.apply(lambda row: assignSiteUUID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveSiteNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfSiteNativeID.loc[(dfSiteNativeID['in_Latitude'] == A) & 
                                (dfSiteNativeID['in_Longitude'] == B), 'in_SiteNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfPOD['in_SiteNativeID'] = dfPOD.apply(lambda row: retrieveSiteNativeID( row['in_Latitude'], row['in_Longitude']), axis=1)
dfPOD.head(3)
# Out:
#   WaDEUUID in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0    sdwr0         WOLF CREEK        Surface Water      WaDE Unspecified
# 1    sdwr1       BEAVER CREEK        Surface Water      WaDE Unspecified
# 2   sdwr10           DRY DRAW        Surface Water      WaDE Unspecified
#
#   in_CoordinateMethodCV in_HUC12   in_HUC8         in_County  in_Latitude  \
# 0      WaDE Unspecified           10160010  WaDE Unspecified     43.71384
# 1      WaDE Unspecified           10170203  WaDE Unspecified     43.31191
# 2      WaDE Unspecified           10170203  WaDE Unspecified     43.63269
#
#    in_Longitude in_PODorPOUSite       in_SiteName in_SiteNativeID  \
# 0     -97.60780             POD  WaDE Unspecified       WaDESD_S1
# 1     -96.60393             POD  WaDE Unspecified       WaDESD_S2
# 2     -96.56461             POD  WaDE Unspecified       WaDESD_S3
#
#       in_SiteTypeCV in_StateCV in_AllocationApplicationDate  \
# 0  WaDE Unspecified         SD
# 1  WaDE Unspecified         SD
# 2  WaDE Unspecified         SD
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  in_AllocationVolume_AF  \
# 0                                            0.00000                 0.00000
# 1                                            0.00000                 0.00000
# 2                                            0.00000                 0.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID    in_AllocationOwner  \
# 0                     Permit                FC10-3         MCCOOK COUNTY
# 1                    License                FC11-3        HAROLD DYKSTRA
# 2                  Cancelled                 FC7-3  MERIDIAN MINERALS CO
#
#   in_AllocationPriorityDate in_AllocationTimeframeEnd  \
# 0                1988-12-08
# 1                1989-07-21
# 2                1986-12-29
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_BeneficialUseCategory  \
# 0                                WaDE Unspecified     Flood Control Permit
# 1                                WaDE Unspecified     Flood Control Permit
# 2                                WaDE Unspecified     Flood Control Permit
#
#   in_CommunityWaterSupplySystem in_ExemptOfVolumeFlowPriority  \
# 0                                                           0
# 1                                                           0
# 2                                                           0
#
#   in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
#
#                          in_WaterAllocationNativeURL
# 0  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 1  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 2  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC7...

# %%
# Creating WaDE Custom water source native ID for easy watersource identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDESD_WS" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = dfPOD['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = dfPOD['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceName'] == A) &
                                       (dfWaterSourceNativeID['in_WaterSourceTypeCV'] == B), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfPOD['in_WaterSourceNativeID'] = dfPOD.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
dfPOD.head(3)
# Out:
#   WaDEUUID in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0    sdwr0         WOLF CREEK        Surface Water      WaDE Unspecified
# 1    sdwr1       BEAVER CREEK        Surface Water      WaDE Unspecified
# 2   sdwr10           DRY DRAW        Surface Water      WaDE Unspecified
#
#   in_CoordinateMethodCV in_HUC12   in_HUC8         in_County  in_Latitude  \
# 0      WaDE Unspecified           10160010  WaDE Unspecified     43.71384
# 1      WaDE Unspecified           10170203  WaDE Unspecified     43.31191
# 2      WaDE Unspecified           10170203  WaDE Unspecified     43.63269
#
#    in_Longitude in_PODorPOUSite       in_SiteName in_SiteNativeID  \
# 0     -97.60780             POD  WaDE Unspecified       WaDESD_S1
# 1     -96.60393             POD  WaDE Unspecified       WaDESD_S2
# 2     -96.56461             POD  WaDE Unspecified       WaDESD_S3
#
#       in_SiteTypeCV in_StateCV in_AllocationApplicationDate  \
# 0  WaDE Unspecified         SD
# 1  WaDE Unspecified         SD
# 2  WaDE Unspecified         SD
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  in_AllocationVolume_AF  \
# 0                                            0.00000                 0.00000
# 1                                            0.00000                 0.00000
# 2                                            0.00000                 0.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID    in_AllocationOwner  \
# 0                     Permit                FC10-3         MCCOOK COUNTY
# 1                    License                FC11-3        HAROLD DYKSTRA
# 2                  Cancelled                 FC7-3  MERIDIAN MINERALS CO
#
#   in_AllocationPriorityDate in_AllocationTimeframeEnd  \
# 0                1988-12-08
# 1                1989-07-21
# 2                1986-12-29
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_BeneficialUseCategory  \
# 0                                WaDE Unspecified     Flood Control Permit
# 1                                WaDE Unspecified     Flood Control Permit
# 2                                WaDE Unspecified     Flood Control Permit
#
#   in_CommunityWaterSupplySystem in_ExemptOfVolumeFlowPriority  \
# 0                                                           0
# 1                                                           0
# 2                                                           0
#
#   in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
#
#                          in_WaterAllocationNativeURL in_WaterSourceNativeID
# 0  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...             WaDESD_WS1
# 1  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...             WaDESD_WS2
# 2  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC7...             WaDESD_WS3

# %% [markdown]
# ## Export Outputs

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.dtypes)
# Out:
# WaDEUUID                       object
# ReasonRemoved                  object
# IncompleteField                object
# OID_                            int64
# PERMIT_NO                      object
# LATITUDE                      float64
# LONGITUDE                     float64
# LAST_NAME                      object
# FIRST_NAME                     object
# ADDRESS2                       object
# CITY                           object
# STATE                          object
# ZIP                            object
# PLUS4                          object
# COUNTY_1                       object
# BASIN                          object
# HYDROUNIT1                     object
# PRIORDATE                      object
# STATUS                         object
# SOURCE                         object
# AQUIFER                        object
# MNG_UNIT                       object
# DIVERSION1                     object
# USE_TYPE1                      object
# USE_TYPE2                      object
# USE_TYPE4                      object
# USE_TYPE5                      object
# USE_TYPE6                      object
# PER_CFS                       float64
# LIC_CFS                       float64
# PER_ACRES                     float64
# LIC_ACRES                     float64
# CMPLTN_DTE                     object
# LIC_DTE                        object
# INSPT_DATE                     object
# INSPECTOR                      object
# METHODCODE                     object
# REFERENCE                      object
# ACCURACY                        int64
# LINK                           object
# in_AllocationOwner             object
# in_BeneficialUseCategory       object
# in_WaterSourceTypeCV           object
# in_AllocationLegalStatusCV     object
# dtype: object

# %%
# Export the output dataframe
dfPOD.to_csv('Pwr_SouthDakotaMain.zip', index=False, compression="zip")  # The output, save as a zip
