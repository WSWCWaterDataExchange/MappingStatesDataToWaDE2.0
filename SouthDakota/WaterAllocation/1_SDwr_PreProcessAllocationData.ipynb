# %% [markdown]
# # Pre-processing Allocation data for WaDE upload.
# - Purpose:  To pre-process the data into one main file for simple DataFrame creation and extraction

# %%
import os
import sys
print(os.environ['CONDA_DEFAULT_ENV'])
print(sys.version)
# Out:
# base
# 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:20:11) [MSC v.1938 64 bit (AMD64)]

# %%
# Needed Libraries / Modules

# ---- working with data ----
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/WaDE Data Folder/SouthDakota/WaterAllocation" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/WaDE Data Folder/SouthDakota/WaterAllocation

# %% [markdown]
# ## Data: waterights

# %%
# Input File
fileInput = "RawInputData/waterights_input.zip"
dfinPOD = pd.read_csv(fileInput).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "sdwr" + dfinPOD.index.astype(str)
    dfinPOD.to_csv('waterights_input.zip', compression=dict(method='zip', archive_name='waterights_input.csv'), index=False)

print(len(dfinPOD))
dfinPOD.head(1)
# Out:
# 19238
# C:\Users\rjame\AppData\Local\Temp\ipykernel_18336\1833934405.py:3: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfinPOD = pd.read_csv(fileInput).replace(np.nan, "")
#   WaDEUUID ReasonRemoved IncompleteField  OID_ PERMIT_NO  LATITUDE  LONGITUDE  \
# 0    sdwr0                                   1    FC10-3  43.71384  -97.60780
#
#        LAST_NAME FIRST_NAME ADDRESS2   CITY STATE    ZIP PLUS4 COUNTY_1 BASIN  \
# 0  MCCOOK COUNTY             BOX 550  SALEM    SD  57058   550       MC    JR
#
#   HYDROUNIT1       PRIORDATE STATUS SOURCE AQUIFER MNG_UNIT  DIVERSION1  \
# 0   10160010  12/8/1988 0:00     PE      S                   WOLF CREEK
#
#   USE_TYPE1 USE_TYPE2 USE_TYPE4 USE_TYPE5 USE_TYPE6  PER_CFS  LIC_CFS  \
# 0       FCP                                          0.00000  0.00000
#
#    PER_ACRES  LIC_ACRES     CMPLTN_DTE LIC_DTE INSPT_DATE INSPECTOR  \
# 0    0.00000    0.00000  3/1/1994 0:00
#
#   METHODCODE        REFERENCE  ACCURACY  \
# 0  TRSOTH100  DIVERSION POINT       140
#
#                                            LINK
# 0  R:\work\wr\imaging\wrinfo\wr_div3\FC10-3.pdf

# %%
# first & last name funciton
def assignownerName(fName, lName):
    
    # Cleaning Text
    fName = str(fName)
    lName = str(lName)
    fName = fName.replace("*", "")
    lName = lName.replace("*", "")      
    
    # Check if first or last name are empty
    if fName == "" or pd.isnull(fName):
        outList1 = ""
    else:
        outList1 = fName.strip()
        
    if lName == "" or pd.isnull(lName):
        outList2 = ""
    else:
        outList2 = lName.strip()

    # ouput
    if outList1 == "" and outList2 == "":
        outList = ""
    elif outList1 == "":
        outList = outList2
    elif outList2 == "":
        outList = outList1
    else:
        outList = " ".join(map(str, [fName, lName]))
    return outList

dfinPOD['in_AllocationOwner'] = dfinPOD.apply(lambda row: assignownerName(row['FIRST_NAME'], row['LAST_NAME']), axis=1)


import re
def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

dfinPOD['in_AllocationOwner'] = dfinPOD.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
dfinPOD['in_AllocationOwner'].unique()
# Out:
# array(['Mccook County', 'Harold Dykstra', 'Eltor Brenner', ...,
#        'Robert F Richards', 'Tinisu Springs Llc', 'Mary G Madsen'],
#       dtype=object)

# %%
#Creating Beneficial Use.
#Need to translate SD abbreviatoins to a workable format.

BenUseDict = {
"COM" : "Commercial",
"DOM" : "Domestic",
"FCP" : "Flood Control Permit",
"FWP" : "Fish And Wildlife Propagation",
"GEO" : "Geothermal",
"GWR" : "Ground Water Remediation",
"IND" : "Industrial",
"INS" : "Institutional",
"IRR" : "Irrigation",
"MUN" : "Municipal",
"REC" : "Recreation",
"RWS" : "Rural Water System",
"SHD" : "Suburban Housing Development"}

def retrieveBenUse(A, B, C, D):
    A = str(A).strip()
    B = str(B).strip()
    C = str(C).strip()
    D = str(D).strip()

    if A == "":
        outA = ""
    else:
        try:
            outA = BenUseDict[A]
        except:
            outA = ""

    if B == "":
        outB = ""
    else:
        try:
            outB = ", " + BenUseDict[B]
        except:
            outB = ", " + ""

    if C == "":
        outC = ""
    else:
        try:
            outC = ", " + BenUseDict[C]
        except:
            outC = ", " + ""

    if D == "":
        outD = ""
    else:
        try:
            outD = ", " + BenUseDict[D]
        except:
            outD = ", " + ""

    outList = outA + outB + outC + outD
    outList = outList.strip()

    return outList

dfinPOD['in_BeneficialUseCategory'] = dfinPOD.apply(lambda row: retrieveBenUse(row['USE_TYPE1'], 
                                                          row['USE_TYPE2'], 
                                                          row['USE_TYPE4'], 
                                                          row['USE_TYPE5']), axis=1)
dfinPOD['in_BeneficialUseCategory'].unique()
# Out:
# array(['Flood Control Permit', 'Irrigation', 'Municipal',
#        'Municipal, Industrial, Rural Water System, Suburban Housing Development',
#        'Industrial', 'Fish And Wildlife Propagation', 'Commercial',
#        'Geothermal', 'Rural Water System', 'Suburban Housing Development',
#        'Domestic, Municipal, Fish And Wildlife Propagation',
#        'Commercial, Domestic', 'Irrigation, Commercial', 'Recreation',
#        'Institutional', 'Irrigation, Industrial',
#        'Suburban Housing Development, Commercial', 'Irrigation, Domestic',
#        'Domestic', 'Recreation, Commercial',
#        'Fish And Wildlife Propagation, Domestic',
#        'Domestic, Recreation, Municipal, Industrial',
#        'Recreation, Fish And Wildlife Propagation',
#        'Municipal, Industrial',
#        'Fish And Wildlife Propagation, Recreation',
#        'Domestic, Fish And Wildlife Propagation',
#        'Commercial, Recreation', 'Recreation, Domestic',
#        'Municipal, Recreation', 'Ground Water Remediation',
#        'Suburban Housing Development, Rural Water System',
#        'Suburban Housing Development, Domestic', 'Industrial, Commercial',
#        'Domestic, Commercial',
#        'Commercial, Suburban Housing Development, Domestic',
#        'Domestic, Recreation', 'Domestic, Irrigation',
#        'Municipal, Commercial, Rural Water System, Suburban Housing Development',
#        'Municipal, Industrial, Suburban Housing Development, Rural Water System',
#        'Recreation, Institutional', 'Rural Water System, Irrigation',
#        'Rural Water System, Suburban Housing Development',
#        'Recreation, Municipal',
#        'Commercial, Suburban Housing Development',
#        'Rural Water System, Domestic', 'Irrigation, Recreation, Domestic',
#        'Irrigation, Domestic, Fish And Wildlife Propagation',
#        'Municipal, Rural Water System', 'Domestic, Rural Water System',
#        'Irrigation, Suburban Housing Development, Domestic',
#        'Commercial, Municipal', 'Commercial, Irrigation',
#        'Irrigation, Suburban Housing Development',
#        'Commercial, Industrial', 'Irrigation, Recreation',
#        'Rural Water System, Municipal', 'Municipal, Geothermal',
#        'Geothermal, Irrigation', 'Municipal, Domestic',
#        'Geothermal, Institutional', 'Domestic, Municipal',
#        'Irrigation, Institutional', 'Institutional, Municipal',
#        'Institutional, Domestic', 'Industrial, Domestic',
#        'Commercial, Domestic, Rural Water System',
#        'Institutional, Recreation', 'Industrial, Municipal',
#        'Irrigation, Fish And Wildlife Propagation',
#        'Institutional, Irrigation',
#        'Fish And Wildlife Propagation, Irrigation',
#        'Irrigation, Commercial, Domestic, Industrial',
#        'Municipal, Industrial, Rural Water System, Domestic',
#        'Municipal, Industrial, Suburban Housing Development, Commercial',
#        'Domestic, Irrigation, Fish And Wildlife Propagation',
#        'Domestic, Recreation, Fish And Wildlife Propagation',
#        'Domestic, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Irrigation, Recreation',
#        'Domestic, Municipal, Industrial', 'Municipal, Irrigation',
#        'Irrigation, Domestic, Industrial, Recreation',
#        'Irrigation, Domestic, Fish And Wildlife Propagation, Recreation',
#        'Irrigation, Recreation, Fish And Wildlife Propagation, Domestic',
#        'Irrigation, Municipal', 'Industrial, Commercial, Recreation',
#        'Industrial, Irrigation', 'Municipal, Commercial',
#        'Commercial, Fish And Wildlife Propagation',
#        'Domestic, Suburban Housing Development',
#        'Suburban Housing Development, Municipal',
#        'Irrigation, Rural Water System',
#        'Suburban Housing Development, Geothermal',
#        'Irrigation, Municipal, Recreation', '', 'Commercial, Geothermal',
#        'Geothermal, Fish And Wildlife Propagation',
#        'Institutional, Industrial', 'Irrigation,',
#        'Municipal, Rural Water System, Suburban Housing Development, Commercial',
#        'Suburban Housing Development, Recreation',
#        'Municipal, Industrial, Commercial',
#        'Municipal, Irrigation, Recreation, Domestic',
#        'Irrigation, Municipal, Recreation, Domestic',
#        'Domestic, Fish And Wildlife Propagation, Recreation',
#        'Domestic, Geothermal',
#        'Recreation, Domestic, Fish And Wildlife Propagation',
#        'Irrigation, Fish And Wildlife Propagation, Recreation',
#        'Irrigation, Rural Water System, Fish And Wildlife Propagation, Domestic',
#        'Geothermal, Domestic',
#        'Fish And Wildlife Propagation, Domestic, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Recreation',
#        'Fish And Wildlife Propagation, Commercial',
#        'Fish And Wildlife Propagation, Domestic, Recreation',
#        'Domestic, Recreation, Irrigation',
#        'Recreation, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Irrigation, Recreation, Irrigation',
#        'Commercial, Fish And Wildlife Propagation, Irrigation',
#        'Domestic, Municipal, Irrigation, Recreation',
#        'Recreation, Irrigation',
#        'Irrigation, Fish And Wildlife Propagation, Domestic',
#        'Recreation, Municipal, Industrial, Domestic'], dtype=object)

# %%
#Creating WaterSourceTypeCV field

WSTypeDict = {
    "S" : "Surface Water",
    "G" : "Groundwater",
    "B" : "Surface Water and Groundwater"}

def retrieveWSType(colrowValue):
    colrowValue = str(colrowValue).strip()
    if colrowValue == "" or pd.isnull(colrowValue):
        outString = ""
    else:
        try:
            outString = WSTypeDict[colrowValue]
        except:
            outString = ""
    return outString

dfinPOD['in_WaterSourceTypeCV'] = dfinPOD.apply(lambda row: retrieveWSType(row['SOURCE']), axis=1)
dfinPOD['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater', 'Surface Water and Groundwater',
#        ''], dtype=object)

# %%
#Creating allocation status

AlloStatusDict = {
"CA" : "Cancelled",
"DF" : "Deferred",
"DN" : "Denied",
"FU" : "Future Use",
"HD" : "Hold",
"IP" : "Incorporated",
"LC" : "License",
"OC" : "Owner Change",
"PE" : "Permit",
"WI" : "Withdrawn"}

def retrieveStatus(colrowValue):
    if colrowValue == "" or pd.isnull(colrowValue):
        outList = ""
    else:
        String1 = str(colrowValue).strip()
        try:
            outList = AlloStatusDict[String1]
        except:
            outList = ""
    return outList

dfinPOD['in_AllocationLegalStatusCV'] = dfinPOD.apply(lambda row: retrieveStatus(row['STATUS']), axis=1)
dfinPOD['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Permit', 'License', 'Cancelled', '', 'Owner Change', 'Future Use',
#        'Withdrawn', 'Denied', 'Incorporated', 'Deferred'], dtype=object)

# %%
dfinPOD.head(1)
# Out:
#   WaDEUUID ReasonRemoved IncompleteField  OID_ PERMIT_NO  LATITUDE  LONGITUDE  \
# 0    sdwr0                                   1    FC10-3  43.71384  -97.60780
#
#        LAST_NAME FIRST_NAME ADDRESS2   CITY STATE    ZIP PLUS4 COUNTY_1 BASIN  \
# 0  MCCOOK COUNTY             BOX 550  SALEM    SD  57058   550       MC    JR
#
#   HYDROUNIT1       PRIORDATE STATUS SOURCE AQUIFER MNG_UNIT  DIVERSION1  \
# 0   10160010  12/8/1988 0:00     PE      S                   WOLF CREEK
#
#   USE_TYPE1 USE_TYPE2 USE_TYPE4 USE_TYPE5 USE_TYPE6  PER_CFS  LIC_CFS  \
# 0       FCP                                          0.00000  0.00000
#
#    PER_ACRES  LIC_ACRES     CMPLTN_DTE LIC_DTE INSPT_DATE INSPECTOR  \
# 0    0.00000    0.00000  3/1/1994 0:00
#
#   METHODCODE        REFERENCE  ACCURACY  \
# 0  TRSOTH100  DIVERSION POINT       140
#
#                                            LINK in_AllocationOwner  \
# 0  R:\work\wr\imaging\wrinfo\wr_div3\FC10-3.pdf      Mccook County
#
#   in_BeneficialUseCategory in_WaterSourceTypeCV in_AllocationLegalStatusCV
# 0     Flood Control Permit        Surface Water                     Permit

# %%
# creating a usable native url
dfinPOD['new_LINK'] = dfinPOD['LINK'].str.replace('\\', "/").str.replace('R:/work/wr/imaging/wrinfo/', "/")
dfinPOD['new_LINK']
# Out:
# 0         /wr_div3/FC10-3.pdf
# 1         /wr_div3/FC11-3.pdf
# 2         /wr_div3/4059-3.pdf
# 3        /wr_div3/4054A-3.pdf
# 4        /wr_div3/US516-3.pdf
#                  ...
# 19233     /wr_div3/7226-3.pdf
# 19234     /wr_div2/2655-2.pdf
# 19235     /wr_div2/2655-2.pdf
# 19236     /wr_div2/2655-2.pdf
# 19237     /wr_div3/1931-3.pdf
# Name: new_LINK, Length: 19238, dtype: object

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfinPOD['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "SDwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "SDwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "SDwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfinPOD['DIVERSION1'].str.title()
df['in_WaterSourceNativeID'] = "" # auto fill in below
df['in_WaterSourceTypeCV'] = dfinPOD['in_WaterSourceTypeCV']

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = ""
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = dfinPOD['HYDROUNIT1']
df['in_Latitude'] = dfinPOD['LATITUDE']
df['in_Longitude'] = dfinPOD['LONGITUDE']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"
df['in_SiteName'] = ""
df['in_SiteNativeID'] = "POD" + dfinPOD['OID_'].replace("", 0).fillna(0).astype(int).astype(str)
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = ""
df['in_StateCV'] = "SD"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = dfinPOD['PER_CFS'].astype(float)
df['in_AllocationLegalStatusCV'] = dfinPOD['in_AllocationLegalStatusCV']
df['in_AllocationNativeID'] =  dfinPOD['PERMIT_NO'].replace("", 0).fillna(0).astype(str)
df['in_AllocationOwner'] = dfinPOD['in_AllocationOwner']
df['in_AllocationPriorityDate'] = dfinPOD['PRIORDATE']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = dfinPOD['PER_ACRES'].astype(float)
df['in_BeneficialUseCategory'] = dfinPOD['in_BeneficialUseCategory']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = "https://danr.sd.gov/wrimage/wrinfo" + dfinPOD['new_LINK'].astype(str)

outPOD = df.copy()
outPOD = outPOD.drop_duplicates().reset_index(drop=True)
print(len(outPOD))
outPOD.head()
# Out:
# 19238
#    WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     sdwr0       SDwr_M1                 SDwr_V1             SDwr_O1
# 1     sdwr1       SDwr_M1                 SDwr_V1             SDwr_O1
# 2    sdwr10       SDwr_M1                 SDwr_V1             SDwr_O1
# 3   sdwr100       SDwr_M1                 SDwr_V1             SDwr_O1
# 4  sdwr1000       SDwr_M1                 SDwr_V1             SDwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0         Wolf Creek                               Surface Water
# 1       Beaver Creek                               Surface Water
# 2        Groundwater                                 Groundwater
# 3        Groundwater                                 Groundwater
# 4    Big Sioux River                               Surface Water
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                                                 4326
# 1                                                                 4326
# 2                                                                 4326
# 3                                                                 4326
# 4                                                                 4326
#
#   in_GNISCodeCV in_HUC12   in_HUC8  in_Latitude  in_Longitude  \
# 0                         10160010     43.71384     -97.60780
# 1                         10170203     43.31191     -96.60393
# 2                         10170101     43.31710     -98.19177
# 3                         10170201     45.08462     -97.48097
# 4                         10170203     44.10029     -96.60642
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                   POD
# 1                                                   POD
# 2                                                   POD
# 3                                                   POD
# 4                                                   POD
#
#   in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0            POD1                                    SD
# 1            POD2                                    SD
# 2        POD10006                                    SD
# 3        POD10088                                    SD
# 4        POD10899                                    SD
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                                            0.00000
# 1                                            0.00000
# 2                                            2.40000
# 3                                            1.00000
# 4                                            0.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 0                     Permit                FC10-3      Mccook County
# 1                    License                FC11-3     Harold Dykstra
# 2                  Cancelled                4059-3      Eltor Brenner
# 3                    License               4054A-3    Town Of Wallace
# 4                    License               US516-3                Bia
#
#   in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0            12/8/1988 0:00
# 1            7/21/1989 0:00
# 2            5/18/1977 0:00
# 3           10/20/1976 0:00
# 4            4/30/1940 0:00
#
#   in_AllocationTimeframeEnd in_AllocationTimeframeStart in_AllocationTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#    in_AllocationVolume_AF in_BeneficialUseCategory  \
# 0                 0.00000     Flood Control Permit
# 1                 0.00000     Flood Control Permit
# 2               235.00000               Irrigation
# 3                 0.00000                Municipal
# 4                 0.00000               Irrigation
#
#   in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDate in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                                           0
# 1                                                                           0
# 2                                                                           0
# 3                                                                           0
# 4                                                                           0
#
#   in_GeneratedPowerCapacityMW in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 1  https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 2  https://danr.sd.gov/wrimage/wrinfo/wr_div3/405...
# 3  https://danr.sd.gov/wrimage/wrinfo/wr_div3/405...
# 4  https://danr.sd.gov/wrimage/wrinfo/wr_div3/US5...

# %% [markdown]
# ## Clean Output

# %%
# Concatenate dataframes
frames = [outPOD] # just POD for now
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 19238

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip().rstrip(',')
    return Val

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Mccook County', 'Harold Dykstra', 'Eltor Brenner', ...,
#        'Robert F Richards', 'Tinisu Springs Llc', 'Mary G Madsen'],
#       dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Wolf Creek', 'Beaver Creek', 'Groundwater', ...,
#        'Mt Rushmore Spring', 'Cliff Gulch', 'Quinn Dam'], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['Wolf Creek', 'Beaver Creek', 'Groundwater', ...,
#        'Mt Rushmore Spring', 'Cliff Gulch', 'Quinn Dam'], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater', 'Surface Water and Groundwater',
#        ''], dtype=object)

# %%
outdf['in_AllocationLegalStatusCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationLegalStatusCV']), axis=1)
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Permit', 'License', 'Cancelled', '', 'Owner Change', 'Future Use',
#        'Withdrawn', 'Denied', 'Incorporated', 'Deferred'], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Mccook County', 'Harold Dykstra', 'Eltor Brenner', ...,
#        'Robert F Richards', 'Tinisu Springs Llc', 'Mary G Madsen'],
#       dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
uniqueList = list(set([i.strip() for i in ','.join(outdf['in_BeneficialUseCategory'].astype(str)).split(',')]))
uniqueList.sort()
uniqueList
# Out:
# ['',
#  'Commercial',
#  'Domestic',
#  'Fish And Wildlife Propagation',
#  'Flood Control Permit',
#  'Geothermal',
#  'Ground Water Remediation',
#  'Industrial',
#  'Institutional',
#  'Irrigation',
#  'Municipal',
#  'Recreation',
#  'Rural Water System',
#  'Suburban Housing Development']

# %%
# Ensure Latitude entry is either numireic or a 0
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([43.71384, 43.31191, 43.3171 , ..., 42.72809, 44.05716, 43.34562])

# %%
# Ensure Longitude entry is either numireic or a 0
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([ -97.6078 ,  -96.60393,  -98.19177, ...,  -96.94936, -103.30181,
#         -97.04509])

# %%
# Changing datatype of Priority Date to date fields entry
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'], errors = 'coerce')
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# <DatetimeArray>
# ['1988-12-08 00:00:00', '1989-07-21 00:00:00', '1977-05-18 00:00:00',
#  '1976-10-20 00:00:00', '1940-04-30 00:00:00',                 'NaT',
#  '2010-05-04 00:00:00', '2011-02-18 00:00:00', '2011-03-15 00:00:00',
#  '2011-04-29 00:00:00',
#  ...
#  '1972-02-16 00:00:00', '1972-02-22 00:00:00', '1985-05-06 00:00:00',
#  '1972-02-25 00:00:00', '1938-02-07 00:00:00', '1985-01-05 00:00:00',
#  '1985-04-08 00:00:00', '1939-09-01 00:00:00', '1972-03-23 00:00:00',
#  '1972-03-24 00:00:00']
# Length: 6844, dtype: datetime64[ns]

# %%
# Ensure Flow entry is either numireic or a 0
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array(['', 2.4, 1.0, 0.83, 2.0, 0.47, 1.89, 1.1, 0.13, 4.36, 1.7, 3.0,
#        4.29, 7.47, 1.66, 1.67, 1.14, 0.1, 6.67, 4.0, 0.06, 1.57, 0.02,
#        3.56, 1.78, 1.97, 7.4, 3.12, 1.56, 14.4, 3.37, 5.33, 3.86, 2.22,
#        0.07, 4.57, 6.86, 1.64, 3.14, 2.67, 1.77, 3.11, 3.33, 0.89, 1.23,
#        0.18, 6.46, 4.33, 3.89, 7.87, 0.27, 0.45, 4.44, 3.18, 1.5, 3.34,
#        1.33, 3.06, 0.05, 6.6, 3.81, 2.28, 1.42, 1.44, 3.42, 0.17, 2.44,
#        0.08, 1.28, 0.67, 3.78, 0.92, 1.24, 3.68, 6.85, 9.19, 0.44, 2.2,
#        7.85, 1.11, 3.04, 6.7, 0.04, 1.91, 0.57, 0.09, 1.39, 4.37, 8.85,
#        3.55, 2.25, 3.36, 3.82, 7.77, 0.22, 1.48, 14.0, 0.11, 0.8, 3.79,
#        4.28, 1.34, 1.94, 1.68, 2.14, 2.79, 1.22, 1.73, 0.12, 0.33, 0.29,
#        0.03, 3.8, 1.53, 1.71, 4.4, 0.28, 4.05, 40.0, 3.5, 4.59, 416.0,
#        0.5, 5.1, 0.71, 0.88, 0.86, 0.25, 0.37, 0.38, 0.95, 1.2, 2.68, 2.3,
#        1.55, 0.55, 1.9, 0.91, 0.34, 3.45, 0.3, 0.4, 0.7, 15.0, 4.3, 5.58,
#        25.0, 6.84, 431.71, 1.93, 2.9, 7.0, 1.01, 0.94, 2.76, 0.93, 0.48,
#        0.74, 0.01, 7.6, 0.9, 12.0, 1.59, 5.07, 1.74, 1.31, 2.7, 1.92,
#        1.06, 3.1, 0.23, 5.32, 14.25, 17.9, 0.16, 3.43, 0.64, 4.45, 0.75,
#        28.0, 16.95, 23.4, 3.48, 0.21, 1.27, 0.56, 6.76, 3.95, 4.5, 1.29,
#        9.6, 13.2, 2.6, 2.18, 12.02, 5.59, 21.4, 5.93, 4.11, 3.46, 10.2,
#        12.6, 1.43, 3.3, 1.88, 3.77, 9.66, 2.64, 4.19, 8.01, 1.17, 0.15,
#        1.6, 2.16, 5.69, 18.56, 0.2, 11.0, 13.7, 2.5, 2.48, 3.66, 0.78,
#        4.65, 4.54, 11.1, 9.15, 0.65, 1.95, 5.4, 2.1, 2.03, 2.23, 0.43,
#        0.54, 1.75, 12.38, 1.04, 0.35, 0.14, 3.2, 2.55, 37.0, 1.8, 3.74,
#        4.85, 2.57, 3.85, 3.25, 1.4, 4.34, 4.15, 5.7, 0.26, 2.27, 11.4,
#        5.64, 0.63, 6.3, 4.1, 0.66, 240.0, 10.9, 2.66, 4.2, 5.97, 2.85,
#        3.6, 2.8, 0.36, 1.19, 7.5, 8.74, 3.7, 360.0, 6.47, 5.0, 4.39, 4.6,
#        2.71, 1.13, 1.3, 4.86, 16.5, 3.84, 10.0, 20.5, 9.26, 38.9, 4.46,
#        17.2, 5.75, 6.28, 5.84, 9.9, 8.34, 3.17, 5.65, 9.1, 4.23, 0.42,
#        2.65, 21.82, 1.85, 5.34, 1.09, 2.11, 2.83, 8.0, 6.0, 9.5, 1.07,
#        5.3, 6.49, 2.96, 2.43, 6.44, 12.54, 2.33, 1.46, 16.0, 0.31, 13.52,
#        4.7, 8.1, 27.0, 4.14, 4.25, 5.9, 0.85, 3.26, 2.35, 1.45, 34.0,
#        1.81, 2.72, 3.57, 2.39, 8.57, 55.8, 400.0, 5.5, 3.9, 10.85, 1.25,
#        2.75, 2.26, 2.17, 3.13, 0.72, 4.12, 2.24, 2.07, 4.67, 5.53, 1.65,
#        1.82, 2.09, 1.02, 38.0, 5.28, 13.71, 7.14, 18.41, 0.6, 32.0, 4.8,
#        0.46, 1.54, 3.4, 2.06, 3.88, 7.97, 10.8, 6.4, 9.3, 0.39, 4.88,
#        3.27, 1.05, 0.49, 2500.0, 3.83, 2.47, 6.8, 22.3, 5.6, 9.07, 2.15,
#        6.5, 10.09, 1.98, 4.01, 14.88, 2.42, 6.52, 0.59, 0.77, 3.58, 5.25,
#        14.9, 14.2, 3.21, 12.49, 5.09, 8.32, 25.9, 17.0, 2.13, 2.51, 1.21,
#        9.08, 4.69, 5.57, 1.86, 3.97, 16.61, 16.77, 16.9, 6.2, 0.19, 1.08,
#        13.8, 9.0, 22.98, 2.41, 0.87, 2.08, 5.45, 2.88, 7.53, 1.87, 0.79,
#        3.19, 2.74, 0.68, 2.01, 4.99, 0.53, 1.38, 164.2, 13.5, 8.92, 4.78,
#        4.32, 1.63, 2.77, 10.4, 1.61, 4.9, 1.12, 1.58, 4.61, 1.62, 0.97,
#        10.7, 7.2, 8.37, 1.84, 1.16, 9.14, 6.1, 4.94, 5.2, 3.72, 0.58,
#        12.3, 7.82, 0.32, 2.58, 1.15, 3.75, 8.5, 5.78, 22.08, 3.71, 5.46,
#        7.7, 0.82, 4.95, 1.35, 6.18, 37.6, 0.41, 3.08, 6.69, 4.74, 0.99,
#        2.86, 6.54, 10.47, 6.81, 5.35, 1.96, 6.45, 5.71, 18.29, 3.67, 4.56,
#        11.68, 40.4, 27.21, 6.75, 14.5, 22.0, 2.97, 0.96, 0.98, 19.5, 0.24,
#        2.87, 6.14, 30.0, 3.61, 100.0, 6.17, 14.8, 1.18, 7.75, 5.54, 0.84,
#        1.49, 3.28, 4.64, 5.55, 5.8, 9.05, 2.19, 7.9, 3.53, 3.31, 3.59,
#        3.64, 0.69, 0.52, 34.3, 1.47, 6.66, 4.13, 1500.0, 5.14, 2.92,
#        23.26, 3.35, 8.44, 2.78, 2.54, 2.12, 0.76, 3.44, 10.3, 4.06, 2.05,
#        36.4, 0.81, 20.0, 1.72, 0.73, 17.3, 3.05, 4.55, 23.1, 2.98, 8.7,
#        0.61, 2.21, 6.9, 2.29, 4.17, 1.52, 7.13, 2.37, 1.32, 15.2, 6.21,
#        2.69, 1.51, 2.49, 4.16, 0.62, 1800.0, 9.53, 1.03, 1.36, 3.02,
#        12.25, 1.79, 2.52, 17.8, 2.31, 4.31, 4.89, 6.53, 7.88, 25.57, 2.91,
#        2.62, 1.37, 18.1, 2.46, 12.7, 10.52, 1.26, 6.34, 2.89, 44.6, 3.22,
#        7.07, 5.87, 2.02, 6.05, 16.49, 4.48, 8.2, 5.05, 1.76, 2.38, 3.16,
#        5.16, 10.53, 4.08, 2.95, 19.7, 30.8, 8.4, 18.5, 6.56, 3.07, 3.62,
#        7.33, 8.18, 2.04, 6.55, 1.99, 7.37, 7.71, 9.95, 5.94, 14.44, 6.41,
#        2.84, 37.1, 10.96, 3.15, 11.14, 9.74, 5.56, 5.11, 2.59, 11.6, 5.39,
#        8.25, 5.95, 24.9, 3.96, 9.4, 8.48, 13.66, 520.0, 3.24, 8.3, 9.36,
#        4.02, 8.86, 23.0, 7.58, 2.94, 1.83, 4.09, 6.38, 8.35, 10.26, 6.02,
#        4.83, 2.36, 14.72, 11.3, 35.14, 7.3, 6.63, 3.73, 8.91, 12.5, 13.07,
#        7.31, 14.6, 4.91, 0.51, 6.95, 3.94, 4.42, 117.0, 4.27, 2.34, 7.46,
#        8.28, 8.71, 111.0, 8.14, 150.0, 12.8, 14.1, 23.25, 2.56, 13.4,
#        17.4, 1040.0, 13.06, 3.76, 4.04, 6.26, 77.8, 3.03, 6.82, 135.0,
#        35.0, 58.0, 5.52, 3.52, 4.07, 4.26, 5.74, 1.41, 9.8, 368.0, 17.16,
#        7.06, 6.13, 5.96, 16.4, 4.18, 13.85, 19.92, 11.42, 21.42, 13.0,
#        54.85, 32.85, 6.24, 29.71, 8.6, 8.78, 15.9, 2.32, 6.71, 3.38,
#        343.0, 2.45, 4.66, 4.22, 65.0, 75.0, 60.0, 4.92, 19.75, 7.8, 9.75,
#        24.0, 23.2, 50.0, 110.0, 6.73, 16.59, 6.68, 7.1, 7.68, 500.0,
#        700.0, 18.6, 200.0, 120.0, 2000.0, 1000.0, 175.0, 260.0, 206.0,
#        5.85, 9.37, 21.6, 5.19, 19.0, 10.86, 4.43, 5.36, 27.14, 19.54,
#        11.63, 31.48, 38.8, 4.82, 9.12, 8.93, 9.7, 19.23, 4.72, 8.47, 7.04,
#        26.42, 237.13, 55.14, 35.73, 12.28, 8.8, 11.85, 15.37, 341.0,
#        114.0, 178.25, 7.94, 3.32, 6.42, 5.23, 6.57, 17.7, 324.0, 1.69,
#        4.58, 300.0, 121.0, 10.5, 40.38, 3.47, 80.0, 160.0, 17.6, 5.42,
#        8.08, 3.93, 7.27, 2.63, 5.82, 27.85, 7.78, 13.81, 5.79, 5.68,
#        35.65, 7.29, 8.62, 5.13, 6.62, 7.95, 4.49, 3.29, 8.36, 22.85,
#        10.57, 25.81, 16.94, 15.52, 8.55, 5.12, 11.09, 3.91, 4.35, 4.47,
#        5.17, 20.12, 14.57, 12.92, 7.12, 28.9, 13.37, 14.26, 8.95, 5.61,
#        4.75, 5.89, 15.67, 13.9, 19.4, 11.43, 7.28, 3.87, 2.53, 25.3, 8.42],
#       dtype=object)

# %%
# Ensure Volume entry is either numireic or a 0
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array(['', 235.0, 165.0, ..., 2.25, 0.82, 90.2], dtype=object)

# %%
# Ensure Irrigated Acreage entry is either numireic or a 0
outdf['in_IrrigatedAcreage'] = pd.to_numeric(outdf['in_IrrigatedAcreage'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_IrrigatedAcreage'].unique()
# Out:
# array([''], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], 
                                                                              row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', ..., 'wadeId1338', 'wadeId1339',
#        'wadeId1340'], dtype=object)

# %%
# Creating WaDE Custom site native ID for easy site identification
# use Unique Latitude, Longitude, SiteName and SiteTypeCV values
# ----------------------------------------------------------------------------------------------------

# Create temp in_SiteNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_Latitude'] = outdf['in_Latitude'].astype(str).str.strip()
dfTempID['in_Longitude'] = outdf['in_Longitude'].astype(str).str.strip()
dfTempID['in_SiteName'] = outdf['in_SiteName'].astype(str).str.strip()
dfTempID['in_SiteTypeCV'] = outdf['in_SiteTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_SiteNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_Latitude'].astype(str) + dfTempID['in_Longitude'].astype(str) + dfTempID['in_SiteName'].astype(str)+ dfTempID['in_SiteTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_SiteNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB, valC, valD):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip() + str(valC).strip() + str(valD).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_SiteNativeID'], 
                                                                       row['in_Latitude'], row['in_Longitude'],
                                                                       row['in_SiteName'], row['in_SiteTypeCV']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# array(['POD1', 'POD2', 'POD10006', ..., 'POD19529', 'POD19530', 'POD1954'],
#       dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For SD, we don't want water rights that are considered: Cancelled, Denied, Withdrawn

# %%
# drop non-active AllocationLegalStatusCV values specific to that state.

# drop the list
dropLegalStatusList = ["Cancelled", "Denied", "Withdrawn"]

# drop rows from above list
outdf = outdf[outdf.in_AllocationLegalStatusCV.isin(dropLegalStatusList) == False].reset_index(drop=True)

print(len(outdf))
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# 13313
# array(['Permit', 'License', '', 'Owner Change', 'Future Use',
#        'Incorporated', 'Deferred'], dtype=object)

# %% [markdown]
# ## Export Outputs

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13313 entries, 0 to 13312
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   WaDEUUID                                      13313 non-null  object
#  1   in_MethodUUID                                 13313 non-null  object
#  2   in_VariableSpecificUUID                       13313 non-null  object
#  3   in_OrganizationUUID                           13313 non-null  object
#  4   in_Geometry                                   13313 non-null  object
#  5   in_GNISFeatureNameCV                          13313 non-null  object
#  6   in_WaterQualityIndicatorCV                    13313 non-null  object
#  7   in_WaterSourceName                            13313 non-null  object
#  8   in_WaterSourceNativeID                        13313 non-null  object
#  9   in_WaterSourceTypeCV                          13313 non-null  object
#  10  in_CoordinateAccuracy                         13313 non-null  object
#  11  in_CoordinateMethodCV                         13313 non-null  object
#  12  in_County                                     13313 non-null  object
#  13  in_EPSGCodeCV                                 13313 non-null  int64
#  14  in_GNISCodeCV                                 13313 non-null  object
#  15  in_HUC12                                      13313 non-null  object
#  16  in_HUC8                                       13313 non-null  object
#  17  in_Latitude                                   13313 non-null  float64
#  18  in_Longitude                                  13313 non-null  float64
#  19  in_NHDNetworkStatusCV                         13313 non-null  object
#  20  in_NHDProductCV                               13313 non-null  object
#  21  in_PODorPOUSite                               13313 non-null  object
#  22  in_SiteName                                   13313 non-null  object
#  23  in_SiteNativeID                               13313 non-null  object
#  24  in_SitePoint                                  13313 non-null  object
#  25  in_SiteTypeCV                                 13313 non-null  object
#  26  in_StateCV                                    13313 non-null  object
#  27  in_USGSSiteID                                 13313 non-null  object
#  28  in_AllocationApplicationDate                  13313 non-null  object
#  29  in_AllocationAssociatedConsumptiveUseSiteIDs  13313 non-null  object
#  30  in_AllocationAssociatedWithdrawalSiteIDs      13313 non-null  object
#  31  in_AllocationBasisCV                          13313 non-null  object
#  32  in_AllocationChangeApplicationIndicator       13313 non-null  object
#  33  in_AllocationCommunityWaterSupplySystem       13313 non-null  object
#  34  in_AllocationCropDutyAmount                   13313 non-null  object
#  35  in_AllocationExpirationDate                   13313 non-null  object
#  36  in_AllocationFlow_CFS                         13313 non-null  object
#  37  in_AllocationLegalStatusCV                    13313 non-null  object
#  38  in_AllocationNativeID                         13313 non-null  object
#  39  in_AllocationOwner                            13313 non-null  object
#  40  in_AllocationPriorityDate                     12570 non-null  datetime64[ns]
#  41  in_AllocationSDWISIdentifierCV                13313 non-null  object
#  42  in_AllocationTimeframeEnd                     13313 non-null  object
#  43  in_AllocationTimeframeStart                   13313 non-null  object
#  44  in_AllocationTypeCV                           13313 non-null  object
#  45  in_AllocationVolume_AF                        13313 non-null  object
#  46  in_BeneficialUseCategory                      13313 non-null  object
#  47  in_CommunityWaterSupplySystem                 13313 non-null  object
#  48  in_CropTypeCV                                 13313 non-null  object
#  49  in_CustomerTypeCV                             13313 non-null  object
#  50  in_DataPublicationDate                        13313 non-null  object
#  51  in_DataPublicationDOI                         13313 non-null  object
#  52  in_ExemptOfVolumeFlowPriority                 13313 non-null  int64
#  53  in_GeneratedPowerCapacityMW                   13313 non-null  object
#  54  in_IrrigatedAcreage                           13313 non-null  object
#  55  in_IrrigationMethodCV                         13313 non-null  object
#  56  in_LegacyAllocationIDs                        13313 non-null  object
#  57  in_OwnerClassificationCV                      13313 non-null  object
#  58  in_PopulationServed                           13313 non-null  object
#  59  in_PowerType                                  13313 non-null  object
#  60  in_PrimaryBeneficialUseCategory               13313 non-null  object
#  61  in_SDWISIdentifierCV                          13313 non-null  object
#  62  in_WaterAllocationNativeURL                   13313 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(58)
# memory usage: 6.4+ MB

# %%
outdf
# Out:
#         WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0          sdwr0       SDwr_M1                 SDwr_V1             SDwr_O1
# 1          sdwr1       SDwr_M1                 SDwr_V1             SDwr_O1
# 2        sdwr100       SDwr_M1                 SDwr_V1             SDwr_O1
# 3       sdwr1000       SDwr_M1                 SDwr_V1             SDwr_O1
# 4      sdwr10000       SDwr_M1                 SDwr_V1             SDwr_O1
# ...          ...           ...                     ...                 ...
# 13308   sdwr9995       SDwr_M1                 SDwr_V1             SDwr_O1
# 13309   sdwr9996       SDwr_M1                 SDwr_V1             SDwr_O1
# 13310   sdwr9997       SDwr_M1                 SDwr_V1             SDwr_O1
# 13311   sdwr9998       SDwr_M1                 SDwr_V1             SDwr_O1
# 13312   sdwr9999       SDwr_M1                 SDwr_V1             SDwr_O1
#
#       in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...           ...                  ...                        ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0             Wolf Creek                wadeId1        Surface Water
# 1           Beaver Creek                wadeId2        Surface Water
# 2            Groundwater                wadeId3          Groundwater
# 3        Big Sioux River                wadeId4        Surface Water
# 4            Rapid Creek                wadeId5        Surface Water
# ...                  ...                    ...                  ...
# 13308        Groundwater                wadeId3          Groundwater
# 13309        Rapid Creek                wadeId5        Surface Water
# 13310        Rapid Creek                wadeId5        Surface Water
# 13311        Rapid Creek                wadeId5        Surface Water
# 13312        Groundwater                wadeId3          Groundwater
#
#       in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                                                     4326
# 1                                                                     4326
# 2                                                                     4326
# 3                                                                     4326
# 4                                                                     4326
# ...                     ...                   ...       ...            ...
# 13308                                                                 4326
# 13309                                                                 4326
# 13310                                                                 4326
# 13311                                                                 4326
# 13312                                                                 4326
#
#       in_GNISCodeCV in_HUC12   in_HUC8  in_Latitude  in_Longitude  \
# 0                             10160010     43.71384     -97.60780
# 1                             10170203     43.31191     -96.60393
# 2                             10170201     45.08462     -97.48097
# 3                             10170203     44.10029     -96.60642
# 4                             10120110     44.07250    -103.49129
# ...             ...      ...       ...          ...           ...
# 13308                           702001     45.30609     -97.03371
# 13309                         10120110     44.06983    -103.26905
# 13310                         10120110     44.05716    -103.30181
# 13311                         10120110     44.05707    -103.30246
# 13312                         10170102     43.34562     -97.04509
#
#       in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                       POD
# 1                                                       POD
# 2                                                       POD
# 3                                                       POD
# 4                                                       POD
# ...                     ...             ...             ...         ...
# 13308                                                   POD
# 13309                                                   POD
# 13310                                                   POD
# 13311                                                   POD
# 13312                                                   POD
#
#       in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                POD1                                    SD
# 1                POD2                                    SD
# 2            POD10088                                    SD
# 3            POD10899                                    SD
# 4            POD19531                                    SD
# ...               ...          ...           ...        ...           ...
# 13308        POD19527                                    SD
# 13309        POD19528                                    SD
# 13310        POD19529                                    SD
# 13311        POD19530                                    SD
# 13312         POD1954                                    SD
#
#       in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                            ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                  ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...                         ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2                                               1.00000
# 3
# 4                                               0.83000
# ...                           ...                   ...
# 13308                                           0.44000
# 13309                                           0.83000
# 13310                                           0.83000
# 13311                                           0.83000
# 13312                                           2.28000
#
#       in_AllocationLegalStatusCV in_AllocationNativeID  in_AllocationOwner  \
# 0                         Permit                FC10-3       Mccook County
# 1                        License                FC11-3      Harold Dykstra
# 2                        License               4054A-3     Town Of Wallace
# 3                        License               US516-3                 Bia
# 4                        License                2655-2  City Of Rapid City
# ...                          ...                   ...                 ...
# 13308                     Permit                7226-3      Town Of Summit
# 13309                    License                2655-2  City Of Rapid City
# 13310                    License                2655-2  City Of Rapid City
# 13311                    License                2655-2  City Of Rapid City
# 13312                    License                1931-3       Roger R Ihnen
#
#       in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0                    1988-12-08
# 1                    1989-07-21
# 2                    1976-10-20
# 3                    1940-04-30
# 4                           NaT
# ...                         ...                            ...
# 13308                2010-11-05
# 13309                       NaT
# 13310                       NaT
# 13311                       NaT
# 13312                1972-03-24
#
#       in_AllocationTimeframeEnd in_AllocationTimeframeStart  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                         ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_AllocationTypeCV in_AllocationVolume_AF  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                    ...
# 13308
# 13309
# 13310
# 13311
# 13312                                  160.00000
#
#                                 in_BeneficialUseCategory  \
# 0                                   Flood Control Permit
# 1                                   Flood Control Permit
# 2                                              Municipal
# 3                                             Irrigation
# 4      Municipal, Industrial, Rural Water System, Sub...
# ...                                                  ...
# 13308                                          Municipal
# 13309  Municipal, Industrial, Rural Water System, Sub...
# 13310  Municipal, Industrial, Rural Water System, Sub...
# 13311  Municipal, Industrial, Rural Water System, Sub...
# 13312                                         Irrigation
#
#       in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...           ...               ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...                   ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#        in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...                         ...
# 13308                              0
# 13309                              0
# 13310                              0
# 13311                              0
# 13312                              0
#
#       in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                   ...                    ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                 ...          ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#       in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                  ...
# 13308
# 13309
# 13310
# 13311
# 13312
#
#                              in_WaterAllocationNativeURL
# 0      https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 1      https://danr.sd.gov/wrimage/wrinfo/wr_div3/FC1...
# 2      https://danr.sd.gov/wrimage/wrinfo/wr_div3/405...
# 3      https://danr.sd.gov/wrimage/wrinfo/wr_div3/US5...
# 4      https://danr.sd.gov/wrimage/wrinfo/wr_div2/265...
# ...                                                  ...
# 13308  https://danr.sd.gov/wrimage/wrinfo/wr_div3/722...
# 13309  https://danr.sd.gov/wrimage/wrinfo/wr_div2/265...
# 13310  https://danr.sd.gov/wrimage/wrinfo/wr_div2/265...
# 13311  https://danr.sd.gov/wrimage/wrinfo/wr_div2/265...
# 13312  https://danr.sd.gov/wrimage/wrinfo/wr_div3/193...
#
# [13313 rows x 63 columns]

# %%
# Export the output dataframe
# change output name / abbreviation to match native state provdier and wade data type 
outdf.to_csv('RawInputData/Pwr_Main.zip', compression=dict(method='zip', archive_name='Pwr_Main.csv'), index=False)  # The output, save as a zip
#goutdf1.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
