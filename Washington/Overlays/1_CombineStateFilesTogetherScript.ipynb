# %% [markdown]
# # Combine & Upload All State files into single upload Project.
# Purpose:  To combine each individual organizations by state ProcessedInputData csv files into a single WaDE 2.0 upload project.
#
# Notes:
# - asdf

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library
import geoplot as gplt # for plotting maps
import geoplot.crs as gcrs #used to pull in webdata

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Washington/Regulatory" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Washington/Regulatory

# %% [markdown]
# ## Input Data

# %%
# organizations #1 - Regulatory_WDNR
# ----------------------------------------------
dfd1 = pd.read_csv("Regulatory_WDNR/ProcessedInputData/date.csv")
dfo1 = pd.read_csv("Regulatory_WDNR/ProcessedInputData/organizations.csv")
dfro1 = pd.read_csv("Regulatory_WDNR/ProcessedInputData/regulatoryoverlays.csv")
dfru1 = pd.read_csv("Regulatory_WDNR/ProcessedInputData/reportingunits.csv")
dfrru1 = pd.read_csv("Regulatory_WDNR/ProcessedInputData/regulatoryreportingunits.csv")
dfs1 = pd.read_csv("Regulatory_WDNR/ProcessedInputData/sites.csv")
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_21052\3856427309.py:8: DtypeWarning: Columns (1,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs1 = pd.read_csv("Regulatory_WDNR/ProcessedInputData/sites.csv")

# %%
# organizations #1 - Regulatory_WDOE
# ----------------------------------------------
dfd2 = pd.read_csv("Regulatory_WDOE/ProcessedInputData/date.csv")
dfo2 = pd.read_csv("Regulatory_WDOE/ProcessedInputData/organizations.csv")
dfro2 = pd.read_csv("Regulatory_WDOE/ProcessedInputData/regulatoryoverlays.csv")
dfru2 = pd.read_csv("Regulatory_WDOE/ProcessedInputData/reportingunits.csv")
dfrru2 = pd.read_csv("Regulatory_WDOE/ProcessedInputData/regulatoryreportingunits.csv")
dfs2 = pd.read_csv("Regulatory_WDOE/ProcessedInputData/sites.csv")
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_21052\4101448741.py:8: DtypeWarning: Columns (1,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs2 = pd.read_csv("Regulatory_WDOE/ProcessedInputData/sites.csv")

# %% [markdown]
# ## Concatenate Like Files Together

# %%
# Concatenate data.csv files
frames = [dfd1, dfd2]  # list all out dataframes here
dfd = pd.concat(frames)
dfd = dfd.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(dfd))
dfd.head()
# Out:
# 2
#         Date  Year
# 0  7/28/2023  2023

# %%
# Concatenate organizations.csv files
frames = [dfo1, dfo2]  # list all out dataframes here
dfo = pd.concat(frames)
dfo = dfo.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(dfo))
dfo.head()
# Out:
# 2
#   OrganizationUUID OrganizationContactEmail   OrganizationContactName  \
# 0        WDNRre_O1             Olivia Hughs  olivia.hughes@dnr.wa.gov
# 1        WDOEre_O1             Jimmy Norris   jimmy.norris@ecy.wa.gov
#
#                              OrganizationName OrganizationPhoneNumber  \
# 0  Washington Department of Natural Resources         (360) 902-1000​
# 1            Washington Department of Ecology            360-407-6872
#
#               OrganizationPurview      OrganizationWebsite State
# 0              Watershed Analysis  https://www.dnr.wa.gov/    WA
# 1  Water Resource Inventory Areas  https://ecology.wa.gov/    WA

# %%
# Concatenate regulatoryoverlays.csv files
frames = [dfro1, dfro2]  # list all out dataframes here
dfro = pd.concat(frames)
dfro = dfro.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(dfro))
dfro.head()
# Out:
# 908
#   RegulatoryOverlayUUID                             OversightAgency  \
# 0          WDNRre_RO369  Washington Department of Natural Resources
# 1           WDNRre_RO18  Washington Department of Natural Resources
# 2          WDNRre_RO434  Washington Department of Natural Resources
# 3          WDNRre_RO393  Washington Department of Natural Resources
# 4          WDNRre_RO717  Washington Department of Natural Resources
#
#                                RegulatoryDescription       RegulatoryName  \
# 0  a structured approach to developing a forest p...            Abernathy
# 1  a structured approach to developing a forest p...                 Acme
# 2  a structured approach to developing a forest p...                Adams
# 3  a structured approach to developing a forest p...          Adams Creek
# 4  a structured approach to developing a forest p...  Aeneas-Cape Labelle
#
#    RegulatoryOverlayNativeID RegulatoryStatusCV RegulatoryStatute  \
# 0                        369             Active
# 1                         18             Active
# 2                        434             Active
# 3                        393             Active
# 4                        717             Active
#
#   RegulatoryStatuteLink StatutoryEffectiveDate StatutoryEndDate  \
# 0                                   1992-08-02
# 1                                   1992-08-02
# 2                                   1992-08-02
# 3                                   1992-08-02
# 4                                   1992-08-02
#
#           RegulatoryOverlayTypeCV WaterSourceTypeCV
# 0  Watershed Administrative Units     Surface Water
# 1  Watershed Administrative Units     Surface Water
# 2  Watershed Administrative Units     Surface Water
# 3  Watershed Administrative Units     Surface Water
# 4  Watershed Administrative Units     Surface Water

# %%
# Concatenate reportingunits.csv files
frames = [dfru1, dfru2]  # list all out dataframes here
dfru = pd.concat(frames)
dfru = dfru.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(dfru))
dfru.head()
# Out:
# 908
#   ReportingUnitUUID  EPSGCodeCV ReportingUnitName ReportingUnitNativeID  \
# 0      WDNRre_RUwa1        4326        Chilliwack                   wa1
# 1     WDNRre_RUwa10        4326           Warnick                  wa10
# 2    WDNRre_RUwa100        4326            Grandy                 wa100
# 3    WDNRre_RUwa101        4326      Canyon Creek                 wa101
# 4    WDNRre_RUwa102        4326         Silverton                 wa102
#
#   ReportingUnitProductVersion             ReportingUnitTypeCV  \
# 0                              Watershed Administrative Units
# 1                              Watershed Administrative Units
# 2                              Watershed Administrative Units
# 3                              Watershed Administrative Units
# 4                              Watershed Administrative Units
#
#   ReportingUnitUpdateDate StateCV  \
# 0                1/7/2021      WA
# 1                1/7/2021      WA
# 2                1/7/2021      WA
# 3                1/7/2021      WA
# 4                1/7/2021      WA
#
#                                             Geometry
# 0  POLYGON ((-121.23768728399995 49.0007234840000...
# 1  POLYGON ((-122.07900302699994 48.9112357280000...
# 2  POLYGON ((-121.81563656099996 48.6144879190000...
# 3  POLYGON ((-121.68343741799998 48.1617546940000...
# 4  POLYGON ((-121.66734139699997 48.1083808740000...

# %%
# Concatenate regulatoryreportingunits.csv files
frames = [dfrru1, dfrru2]  # list all out dataframes here
dfrru = pd.concat(frames)
dfrru = dfrru.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(dfrru))
dfrru.head()
# Out:
# 908
#   DataPublicationDate OrganizationUUID RegulatoryOverlayUUID ReportingUnitUUID
# 0          08/31/2023        WDNRre_O1          WDNRre_RO843    WDNRre_RUwa843
# 1          08/31/2023        WDNRre_O1          WDNRre_RO842    WDNRre_RUwa842
# 2          08/31/2023        WDNRre_O1          WDNRre_RO819    WDNRre_RUwa819
# 3          08/31/2023        WDNRre_O1          WDNRre_RO821    WDNRre_RUwa821
# 4          08/31/2023        WDNRre_O1           WDNRre_RO26     WDNRre_RUwa26

# %%
# Concatenate sites.csv files
# this will require performing a groupby() method
frames = [dfs1, dfs2]  # list all out dataframes here
dfs = pd.concat(frames)
dfs = dfs.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
dfs = dfs.groupby('SiteUUID').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem != ""])).replace(np.nan, "").reset_index()
print(len(dfs))
dfs.head()
# Out:
# 127740
#           SiteUUID    RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 0  WAwr_SPOD100002  WDNRre_RO157,WDOEre_RO60   WAwr_WSwadeID3
# 1  WAwr_SPOD100004    WDNRre_RO39,WDOEre_RO8   WAwr_WSwadeID3
# 2  WAwr_SPOD100006  WDNRre_RO157,WDOEre_RO60   WAwr_WSwadeID3
# 3  WAwr_SPOD100008  WDNRre_RO157,WDOEre_RO60   WAwr_WSwadeID3
# 4  WAwr_SPOD100009  WDNRre_RO157,WDOEre_RO60   WAwr_WSwadeID3
#
#                                   CoordinateAccuracy CoordinateMethodCV  \
# 0                        field checked (without GPS)   WaDE Unspecified
# 1                              unchecked and Dubious   WaDE Unspecified
# 2  proposed and All-right (does not exist in real...   WaDE Unspecified
# 3            proposed (does not exist in real world)   WaDE Unspecified
# 4            proposed (does not exist in real world)   WaDE Unspecified
#
#              County EPSGCodeCV Geometry GNISCodeCV HUC12 HUC8  \
# 0  WaDE Unspecified       4326
# 1  WaDE Unspecified       4326
# 2  WaDE Unspecified       4326
# 3  WaDE Unspecified       4326
# 4  WaDE Unspecified       4326
#
#              Latitude            Longitude NHDNetworkStatusCV NHDProductCV  \
# 0   47.65069874800008       -122.219626147
# 1   48.53634364700008  -122.88346013399996
# 2  47.652644743000046       -122.217763301
# 3   47.65286443600007  -122.21706725099996
# 4   47.65170126000004  -122.21327070299996
#
#   PODorPOUSite          SiteName SiteNativeID SitePoint  \
# 0          POD  WaDE Unspecified    POD100002
# 1          POD  WaDE Unspecified    POD100004
# 2          POD  WaDE Unspecified    POD100006
# 3          POD  WaDE Unspecified    POD100008
# 4          POD  WaDE Unspecified    POD100009
#
#                                           SiteTypeCV StateCV USGSSiteID  \
# 0                                 Surface Water Pump      WA
# 1  Headworks Gravity Flow (or surface water devic...      WA
# 2                                 Surface Water Pump      WA
# 3                                 Surface Water Pump      WA
# 4                                 Surface Water Pump      WA
#
#   WaterSourceUUID WaterSourceTypeCV
# 0  WAwr_WSwadeID3     Surface Water
# 1  WAwr_WSwadeID3     Surface Water
# 2  WAwr_WSwadeID3     Surface Water
# 3  WAwr_WSwadeID3     Surface Water
# 4  WAwr_WSwadeID3     Surface Water

# %% [markdown]
# # Inspect Output Data & Export

# %%
# Export out to CSV
dfd.to_csv('ProcessedInputData/date.csv', index=False)
dfo.to_csv('ProcessedInputData/organizations.csv', index=False)
dfro.to_csv('ProcessedInputData/regulatoryoverlays.csv', index=False)
dfru.to_csv('ProcessedInputData/reportingunits.csv', index=False)
dfrru.to_csv('ProcessedInputData/regulatoryreportingunits.csv', index=False)
dfs.to_csv('ProcessedInputData/sites.csv', index=False)
