# %% [markdown]
# # Assign RegulatoryOverlayUUIDs Values to Water Right sites.csv
# Purpose:  To assign RegulatoryOverlayUUIDs values to state water right sites.csv File.
#
# Notes:
# - requires the completed pre-processed sites.csv & watersource.csv files from the state "WaterAllocation/ProcessedInputData" folder to be copied over to the "Regulatory/ProcessedInputData" folder.  Rename to wr_sites.csv & wr_watersource.csv to preserve inputs.
# - requires awareness of unique WaterSourceTypeCV of each water right site match up to corresponding WaterSourceTypeCV of regulatoryoverlays per reportingunits

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library
import geoplot as gplt # for plotting maps
import geoplot.crs as gcrs #used to pull in webdata

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

#---- Import Large Data Sets ----
import sys
import csv

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Washington/Regulatory_WDOE" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Washington/Regulatory_WDOE

# %% [markdown]
# ## Input Data

# %%
# Regulatory Input Data
dfro = pd.read_csv("ProcessedInputData/regulatoryoverlays.csv")
dfru = pd.read_csv("ProcessedInputData/reportingunits.csv")
dfrru = pd.read_csv("ProcessedInputData/regulatoryreportingunits.csv")

# Water right Input Data
dfws = pd.read_csv('ProcessedInputData/wr_watersources.csv')
dfs = pd.read_csv('ProcessedInputData/wr_sites.csv', engine = "python", error_bad_lines=False)
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_2804\447271929.py:8: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   dfs = pd.read_csv('ProcessedInputData/wr_sites.csv', engine = "python", error_bad_lines=False)
# Skipping line 72641: field larger than field limit (131072)
# Skipping line 79095: field larger than field limit (131072)
# Skipping line 82677: field larger than field limit (131072)
# Skipping line 83717: field larger than field limit (131072)
# Skipping line 83718: field larger than field limit (131072)
# Skipping line 83719: field larger than field limit (131072)
# Skipping line 83720: field larger than field limit (131072)
# Skipping line 83721: field larger than field limit (131072)
# Skipping line 83722: field larger than field limit (131072)
# Skipping line 83723: field larger than field limit (131072)
# Skipping line 83724: field larger than field limit (131072)
# Skipping line 83725: field larger than field limit (131072)
# Skipping line 83726: field larger than field limit (131072)
# Skipping line 83728: field larger than field limit (131072)
# Skipping line 83729: field larger than field limit (131072)
# Skipping line 83730: field larger than field limit (131072)
# Skipping line 83800: field larger than field limit (131072)
# Skipping line 85673: field larger than field limit (131072)
# Skipping line 85939: field larger than field limit (131072)
# Skipping line 87342: field larger than field limit (131072)
# Skipping line 89623: field larger than field limit (131072)
# Skipping line 89627: field larger than field limit (131072)
# Skipping line 89640: field larger than field limit (131072)
# Skipping line 89644: field larger than field limit (131072)
# Skipping line 89646: field larger than field limit (131072)
# Skipping line 91007: field larger than field limit (131072)
# Skipping line 91009: field larger than field limit (131072)
# Skipping line 91011: field larger than field limit (131072)
# Skipping line 94729: field larger than field limit (131072)
# Skipping line 94796: field larger than field limit (131072)
# Skipping line 94809: field larger than field limit (131072)
# Skipping line 94810: field larger than field limit (131072)
# Skipping line 94811: field larger than field limit (131072)
# Skipping line 94812: field larger than field limit (131072)
# Skipping line 95104: field larger than field limit (131072)
# Skipping line 96465: field larger than field limit (131072)
# Skipping line 96468: field larger than field limit (131072)
# Skipping line 101445: field larger than field limit (131072)
# Skipping line 104882: field larger than field limit (131072)
# Skipping line 109057: field larger than field limit (131072)
# Skipping line 109720: field larger than field limit (131072)
# Skipping line 115114: field larger than field limit (131072)
# Skipping line 116412: field larger than field limit (131072)
# Skipping line 116759: field larger than field limit (131072)
# Skipping line 117978: field larger than field limit (131072)
# Skipping line 118224: field larger than field limit (131072)
# Skipping line 118744: field larger than field limit (131072)
# Skipping line 118746: field larger than field limit (131072)
# Skipping line 118748: field larger than field limit (131072)
# Skipping line 118751: field larger than field limit (131072)
# Skipping line 118752: field larger than field limit (131072)
# Skipping line 118753: field larger than field limit (131072)
# Skipping line 118754: field larger than field limit (131072)
# Skipping line 118758: field larger than field limit (131072)
# Skipping line 118759: field larger than field limit (131072)
# Skipping line 118760: field larger than field limit (131072)
# Skipping line 118762: field larger than field limit (131072)
# Skipping line 118765: field larger than field limit (131072)
# Skipping line 118766: field larger than field limit (131072)
# Skipping line 118768: field larger than field limit (131072)
# Skipping line 118769: field larger than field limit (131072)
# Skipping line 118772: field larger than field limit (131072)
# Skipping line 119958: field larger than field limit (131072)
# Skipping line 120039: field larger than field limit (131072)
# Skipping line 120624: field larger than field limit (131072)
# Skipping line 120679: field larger than field limit (131072)
# Skipping line 120756: field larger than field limit (131072)
# Skipping line 120759: field larger than field limit (131072)
# Skipping line 120763: field larger than field limit (131072)
# Skipping line 121442: field larger than field limit (131072)
# Skipping line 123090: field larger than field limit (131072)
# Skipping line 123210: field larger than field limit (131072)
# Skipping line 123211: field larger than field limit (131072)
# Skipping line 123212: field larger than field limit (131072)
# Skipping line 123214: field larger than field limit (131072)
# Skipping line 123372: field larger than field limit (131072)
# Skipping line 123379: field larger than field limit (131072)
# Skipping line 123406: field larger than field limit (131072)
# Skipping line 123411: field larger than field limit (131072)
# Skipping line 123417: field larger than field limit (131072)
# Skipping line 123427: field larger than field limit (131072)
# Skipping line 123561: field larger than field limit (131072)
# Skipping line 125699: field larger than field limit (131072)
# Skipping line 125711: field larger than field limit (131072)
# Skipping line 125717: field larger than field limit (131072)
# Skipping line 125722: field larger than field limit (131072)
# Skipping line 125728: field larger than field limit (131072)
# Skipping line 125733: field larger than field limit (131072)
# Skipping line 125865: field larger than field limit (131072)
# Skipping line 125868: field larger than field limit (131072)
# Skipping line 125874: field larger than field limit (131072)
# Skipping line 125886: field larger than field limit (131072)
# Skipping line 125888: field larger than field limit (131072)
# Skipping line 125926: field larger than field limit (131072)
# Skipping line 126049: field larger than field limit (131072)
# Skipping line 126122: field larger than field limit (131072)
# Skipping line 126135: field larger than field limit (131072)
# Skipping line 126217: field larger than field limit (131072)
# Skipping line 126222: field larger than field limit (131072)
# Skipping line 126236: field larger than field limit (131072)
# Skipping line 126240: field larger than field limit (131072)
# Skipping line 126241: field larger than field limit (131072)
# Skipping line 126246: field larger than field limit (131072)
# Skipping line 126252: field larger than field limit (131072)
# Skipping line 126266: field larger than field limit (131072)
# Skipping line 126306: field larger than field limit (131072)
# Skipping line 126331: field larger than field limit (131072)
# Skipping line 126347: field larger than field limit (131072)
# Skipping line 126362: field larger than field limit (131072)
# Skipping line 126378: field larger than field limit (131072)
# Skipping line 126381: field larger than field limit (131072)
# Skipping line 126384: field larger than field limit (131072)
# Skipping line 126388: field larger than field limit (131072)
# Skipping line 126391: field larger than field limit (131072)
# Skipping line 126394: field larger than field limit (131072)
# Skipping line 126397: field larger than field limit (131072)
# Skipping line 126402: field larger than field limit (131072)
# Skipping line 126405: field larger than field limit (131072)
# Skipping line 126408: field larger than field limit (131072)
# Skipping line 126412: field larger than field limit (131072)
# Skipping line 126424: field larger than field limit (131072)
# Skipping line 126587: field larger than field limit (131072)
# Skipping line 126598: field larger than field limit (131072)
# Skipping line 126804: field larger than field limit (131072)
# Skipping line 126849: field larger than field limit (131072)
# Skipping line 127240: field larger than field limit (131072)
# Skipping line 127274: field larger than field limit (131072)
# Skipping line 127280: field larger than field limit (131072)
# Skipping line 127363: field larger than field limit (131072)
# Skipping line 127364: field larger than field limit (131072)
# Skipping line 127370: field larger than field limit (131072)
# Skipping line 127873: unexpected end of data

# %%
#### regulatory watersource info with reporting unit info

# merge regulatoryoverlays -to- regulatoryreportingunits -to- reportingunits
dfro = pd.merge(dfro[['RegulatoryOverlayUUID', 'WaterSourceTypeCV']], dfrru[['RegulatoryOverlayUUID', 'ReportingUnitUUID']], left_on='RegulatoryOverlayUUID', right_on='RegulatoryOverlayUUID', how='left')
dfru = pd.merge(dfru, dfro, left_on='ReportingUnitUUID', right_on='ReportingUnitUUID', how='left')

print(dfru['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfru))
dfru.head(1)
# Out:
# ['Surface Water']
# 62
#   ReportingUnitUUID  EPSGCodeCV ReportingUnitName ReportingUnitNativeID  \
# 0      WDOEre_RUwa1        4326      Pend Oreille                   wa1
#
#    ReportingUnitProductVersion             ReportingUnitTypeCV  \
# 0                          NaN  Water Resource Inventory Areas
#
#   ReportingUnitUpdateDate StateCV  \
# 0              2023-08-01      WA
#
#                                             Geometry RegulatoryOverlayUUID  \
# 0  POLYGON ((-117.42954545606052 49.0004744482409...            WDOEre_RO1
#
#   WaterSourceTypeCV
# 0     Surface Water

# %%
#### water right watersource info with site info

# explode site.csv on WaterSourceUUIDs
dfs = dfs.assign(WaterSourceUUIDs=dfs['WaterSourceUUIDs'].str.split(',')).explode('WaterSourceUUIDs').reset_index(drop=True)

# merge watersources to dfs via WaterSourceUUIDs -to -WaterSourceUUID
dfs = pd.merge(dfs, dfws[['WaterSourceUUID', 'WaterSourceTypeCV']], left_on='WaterSourceUUIDs', right_on='WaterSourceUUID', how='left')
print(dfs['WaterSourceTypeCV'].unique()) # check WaterSourceTypeCV for unique values for
print(len(dfs))
dfs.head(1)
# Out:
# ['Surface Water' 'WaDE Unspecified' 'Reservoir' 'Groundwater']
# 129925
#           SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 0  WAwr_SPOD100002                     NaN   WAwr_WSwadeID3
#
#             CoordinateAccuracy CoordinateMethodCV            County  \
# 0  field checked (without GPS)   WaDE Unspecified  WaDE Unspecified
#
#    EPSGCodeCV Geometry  GNISCodeCV  HUC12  HUC8  Latitude  Longitude  \
# 0        4326      NaN         NaN    NaN   NaN  47.65070 -122.21963
#
#    NHDNetworkStatusCV  NHDProductCV PODorPOUSite          SiteName  \
# 0                 NaN           NaN          POD  WaDE Unspecified
#
#   SiteNativeID  SitePoint          SiteTypeCV StateCV  USGSSiteID  \
# 0    POD100002        NaN  Surface Water Pump      WA         NaN
#
#   WaterSourceUUID WaterSourceTypeCV
# 0  WAwr_WSwadeID3     Surface Water

# %% [markdown]
# ## Extract RegulatoryOverlay from Reporting Units and assing to WR Sites
# - repeat scripts based on the number of ReportingUnitTypeCV types.
# - merge all geo-dataframes into one output

# %% [markdown]
# #### Regulatory Area Data #1

# %%
# Create copy of reportingunits dataframe
# Extract out ReportingUnitTypeCV from reportingunits dataframe
# note unique WaterSourceTypeCV

dfru1 = dfru.copy()
nameOfReportingUnitTypeVar = "Water Resource Inventory Areas" # change here for ReportingUnitTypeCV of interest
dfru1 = dfru1[dfru1['ReportingUnitTypeCV'] == nameOfReportingUnitTypeVar]
print(len(dfru1))
print(dfru1['WaterSourceTypeCV'].unique())
dfru1.head(1)
# Out:
# 62
# ['Surface Water']
#   ReportingUnitUUID  EPSGCodeCV ReportingUnitName ReportingUnitNativeID  \
# 0      WDOEre_RUwa1        4326      Pend Oreille                   wa1
#
#    ReportingUnitProductVersion             ReportingUnitTypeCV  \
# 0                          NaN  Water Resource Inventory Areas
#
#   ReportingUnitUpdateDate StateCV  \
# 0              2023-08-01      WA
#
#                                             Geometry RegulatoryOverlayUUID  \
# 0  POLYGON ((-117.42954545606052 49.0004744482409...            WDOEre_RO1
#
#   WaterSourceTypeCV
# 0     Surface Water

# %%
# Convert dataframe -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

dfru1 = dfru1[dfru1['Geometry'] != ""].reset_index(drop=True)
dfru1['Geometry'] = gpd.GeoSeries.from_wkt(dfru1['Geometry'], crs="EPSG:4326")
gdfru1 = gpd.GeoDataFrame(dfru1, geometry=dfru1['Geometry'], crs="EPSG:4326") # covert to geodataframe
gplt.polyplot(gdfru1, ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Create copy of water right sites dataframe
# Extract out WaterSourceTypeCV and match to that of above reportingunits dataframe

dfs1 = dfs.copy()
dfs1 = dfs1[dfs1['PODorPOUSite'] == 'POD']
nameOfWaterSourceTypeCV = "Surface Water" # change here for WaterSourceTypeCV of interest
dfs1 = dfs1[dfs1['WaterSourceTypeCV'] == nameOfWaterSourceTypeCV]
print(len(dfs1))
print(dfs1['WaterSourceTypeCV'].unique())
dfs1.head(1)
# Out:
# 26623
# ['Surface Water']
#           SiteUUID  RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 0  WAwr_SPOD100002                     NaN   WAwr_WSwadeID3
#
#             CoordinateAccuracy CoordinateMethodCV            County  \
# 0  field checked (without GPS)   WaDE Unspecified  WaDE Unspecified
#
#    EPSGCodeCV Geometry  GNISCodeCV  HUC12  HUC8  Latitude  Longitude  \
# 0        4326      NaN         NaN    NaN   NaN  47.65070 -122.21963
#
#    NHDNetworkStatusCV  NHDProductCV PODorPOUSite          SiteName  \
# 0                 NaN           NaN          POD  WaDE Unspecified
#
#   SiteNativeID  SitePoint          SiteTypeCV StateCV  USGSSiteID  \
# 0    POD100002        NaN  Surface Water Pump      WA         NaN
#
#   WaterSourceUUID WaterSourceTypeCV
# 0  WAwr_WSwadeID3     Surface Water

# %%
# Convert extracted water right sites -to- geodataframe & plot
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gdfs1 = gpd.GeoDataFrame(dfs1, geometry=gpd.points_from_xy(dfs1.Longitude.astype(float), dfs1.Latitude.astype(float)), crs="EPSG:4326")
gplt.pointplot(gdfs1, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# Select sites within polygon.
gdfs1_ru1 = gpd.sjoin(left_df=gdfs1, right_df=gdfru1[['ReportingUnitUUID', 'RegulatoryOverlayUUID', 'geometry']], op='within').replace(np.nan, "")
print(len(gdfs1_ru1))
gdfs1_ru1.head()
# Out:
# C:\Users\rjame\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3377: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
# 26604
#             SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 0    WAwr_SPOD100002                          WAwr_WSwadeID3
# 2    WAwr_SPOD100006                          WAwr_WSwadeID3
# 3    WAwr_SPOD100008                          WAwr_WSwadeID3
# 4    WAwr_SPOD100009                          WAwr_WSwadeID3
# 220  WAwr_SPOD100469                          WAwr_WSwadeID3
#
#                                     CoordinateAccuracy CoordinateMethodCV  \
# 0                          field checked (without GPS)   WaDE Unspecified
# 2    proposed and All-right (does not exist in real...   WaDE Unspecified
# 3              proposed (does not exist in real world)   WaDE Unspecified
# 4              proposed (does not exist in real world)   WaDE Unspecified
# 220                             field checked with GPS   WaDE Unspecified
#
#                County  EPSGCodeCV Geometry GNISCodeCV HUC12 HUC8  Latitude  \
# 0    WaDE Unspecified        4326                                 47.65070
# 2    WaDE Unspecified        4326                                 47.65264
# 3    WaDE Unspecified        4326                                 47.65286
# 4    WaDE Unspecified        4326                                 47.65170
# 220  WaDE Unspecified        4326                                 47.65003
#
#      Longitude NHDNetworkStatusCV NHDProductCV PODorPOUSite          SiteName  \
# 0   -122.21963                                          POD  WaDE Unspecified
# 2   -122.21776                                          POD  WaDE Unspecified
# 3   -122.21707                                          POD  WaDE Unspecified
# 4   -122.21327                                          POD  WaDE Unspecified
# 220 -122.22024                                          POD  WaDE Unspecified
#
#     SiteNativeID SitePoint                                         SiteTypeCV  \
# 0      POD100002                                           Surface Water Pump
# 2      POD100006                                           Surface Water Pump
# 3      POD100008                                           Surface Water Pump
# 4      POD100009                                           Surface Water Pump
# 220    POD100469            Headworks Gravity Flow (or surface water devic...
#
#     StateCV USGSSiteID WaterSourceUUID WaterSourceTypeCV  \
# 0        WA             WAwr_WSwadeID3     Surface Water
# 2        WA             WAwr_WSwadeID3     Surface Water
# 3        WA             WAwr_WSwadeID3     Surface Water
# 4        WA             WAwr_WSwadeID3     Surface Water
# 220      WA             WAwr_WSwadeID3     Surface Water
#
#                         geometry  index_right ReportingUnitUUID  \
# 0    POINT (-122.21963 47.65070)           56     WDOEre_RUwa60
# 2    POINT (-122.21776 47.65264)           56     WDOEre_RUwa60
# 3    POINT (-122.21707 47.65286)           56     WDOEre_RUwa60
# 4    POINT (-122.21327 47.65170)           56     WDOEre_RUwa60
# 220  POINT (-122.22024 47.65003)           56     WDOEre_RUwa60
#
#     RegulatoryOverlayUUID
# 0             WDOEre_RO60
# 2             WDOEre_RO60
# 3             WDOEre_RO60
# 4             WDOEre_RO60
# 220           WDOEre_RO60

# %%
# plot the selected points
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')) # use for background map in subplot
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator()) # set subplot

gplt.pointplot(gdfs1_ru1, hue='WaterSourceTypeCV', legend=True, legend_var='hue', ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
# set RegulatoryOverlayUUIDs
gdfs1_ru1['RegulatoryOverlayUUIDs'] = gdfs1_ru1['RegulatoryOverlayUUID']
gdfs1_ru1 = gdfs1_ru1.drop(['RegulatoryOverlayUUID', 'geometry', 'index_right', 'ReportingUnitUUID', 'WaterSourceUUID', 'WaterSourceTypeCV'], axis=1)
gdfs1_ru1.head(1)
# Out:
#           SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 0  WAwr_SPOD100002            WDOEre_RO60   WAwr_WSwadeID3
#
#             CoordinateAccuracy CoordinateMethodCV            County  \
# 0  field checked (without GPS)   WaDE Unspecified  WaDE Unspecified
#
#    EPSGCodeCV Geometry GNISCodeCV HUC12 HUC8  Latitude  Longitude  \
# 0        4326                                 47.65070 -122.21963
#
#   NHDNetworkStatusCV NHDProductCV PODorPOUSite          SiteName SiteNativeID  \
# 0                                          POD  WaDE Unspecified    POD100002
#
#   SitePoint          SiteTypeCV StateCV USGSSiteID
# 0            Surface Water Pump      WA

# %% [markdown]
# #### Regulatory Area Data #2

# %%
# dfru2 = dfru.copy()
# etc etc

# %% [markdown]
# ## Concatenate all Regulatory Area Data Types together
# - drop geometry from the wade wr sites.csv geodataframe

# %%
# Concatenate dataframes into single output
frames = [dfs, gdfs1_ru1] # list all out dataframes here
outdfs = pd.concat(frames)
outdfs = outdfs.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
outdfs = outdfs.groupby('SiteUUID').agg(lambda x: ','.join([str(elem) for elem in (list(set(x))) if elem != ""])).replace(np.nan, "").reset_index()
print(len(outdfs))
outdfs.head(1)
# Out:
# 127740
#           SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 0  WAwr_SPOD100002            WDOEre_RO60   WAwr_WSwadeID3
#
#             CoordinateAccuracy CoordinateMethodCV            County  \
# 0  field checked (without GPS)   WaDE Unspecified  WaDE Unspecified
#
#   EPSGCodeCV Geometry GNISCodeCV HUC12 HUC8           Latitude  \
# 0       4326                                 47.65069874800008
#
#         Longitude NHDNetworkStatusCV NHDProductCV PODorPOUSite  \
# 0  -122.219626147                                          POD
#
#            SiteName SiteNativeID SitePoint          SiteTypeCV StateCV  \
# 0  WaDE Unspecified    POD100002            Surface Water Pump      WA
#
#   USGSSiteID WaterSourceUUID WaterSourceTypeCV
# 0             WAwr_WSwadeID3     Surface Water

# %% [markdown]
# # Inspect Output Data & Export

# %%
outdfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127740 entries, 0 to 127739
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   SiteUUID                127740 non-null  object
#  1   RegulatoryOverlayUUIDs  127740 non-null  object
#  2   WaterSourceUUIDs        127740 non-null  object
#  3   CoordinateAccuracy      127740 non-null  object
#  4   CoordinateMethodCV      127740 non-null  object
#  5   County                  127740 non-null  object
#  6   EPSGCodeCV              127740 non-null  object
#  7   Geometry                127740 non-null  object
#  8   GNISCodeCV              127740 non-null  object
#  9   HUC12                   127740 non-null  object
#  10  HUC8                    127740 non-null  object
#  11  Latitude                127740 non-null  object
#  12  Longitude               127740 non-null  object
#  13  NHDNetworkStatusCV      127740 non-null  object
#  14  NHDProductCV            127740 non-null  object
#  15  PODorPOUSite            127740 non-null  object
#  16  SiteName                127740 non-null  object
#  17  SiteNativeID            127740 non-null  object
#  18  SitePoint               127740 non-null  object
#  19  SiteTypeCV              127740 non-null  object
#  20  StateCV                 127740 non-null  object
#  21  USGSSiteID              127740 non-null  object
#  22  WaterSourceUUID         127740 non-null  object
#  23  WaterSourceTypeCV       127740 non-null  object
# dtypes: object(24)
# memory usage: 23.4+ MB

# %%
outdfs
# Out:
#                    SiteUUID RegulatoryOverlayUUIDs WaterSourceUUIDs  \
# 0           WAwr_SPOD100002            WDOEre_RO60   WAwr_WSwadeID3
# 1           WAwr_SPOD100004             WDOEre_RO8   WAwr_WSwadeID3
# 2           WAwr_SPOD100006            WDOEre_RO60   WAwr_WSwadeID3
# 3           WAwr_SPOD100008            WDOEre_RO60   WAwr_WSwadeID3
# 4           WAwr_SPOD100009            WDOEre_RO60   WAwr_WSwadeID3
# ...                     ...                    ...              ...
# 127735  WAwr_SPOUwade197345                          WAwr_WSwadeID3
# 127736  WAwr_SPOUwade197346                          WAwr_WSwadeID3
# 127737  WAwr_SPOUwade197347                          WAwr_WSwadeID2
# 127738  WAwr_SPOUwade197348                          WAwr_WSwadeID2
# 127739   WAwr_SPOUwade19735                          WAwr_WSwadeID2
#
#                                        CoordinateAccuracy CoordinateMethodCV  \
# 0                             field checked (without GPS)   WaDE Unspecified
# 1                                   unchecked and Dubious   WaDE Unspecified
# 2       proposed and All-right (does not exist in real...   WaDE Unspecified
# 3                 proposed (does not exist in real world)   WaDE Unspecified
# 4                 proposed (does not exist in real world)   WaDE Unspecified
# ...                                                   ...                ...
# 127735                                   WaDE Unspecified   WaDE Unspecified
# 127736                                   WaDE Unspecified   WaDE Unspecified
# 127737                                   WaDE Unspecified   WaDE Unspecified
# 127738                                   WaDE Unspecified   WaDE Unspecified
# 127739                                   WaDE Unspecified   WaDE Unspecified
#
#                   County EPSGCodeCV  \
# 0       WaDE Unspecified       4326
# 1       WaDE Unspecified       4326
# 2       WaDE Unspecified       4326
# 3       WaDE Unspecified       4326
# 4       WaDE Unspecified       4326
# ...                  ...        ...
# 127735  WaDE Unspecified       4326
# 127736  WaDE Unspecified       4326
# 127737  WaDE Unspecified       4326
# 127738  WaDE Unspecified       4326
# 127739  WaDE Unspecified       4326
#
#                                                  Geometry GNISCodeCV HUC12  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...        ...   ...
# 127735  POLYGON ((-119.49631283926607 46.8303052419933...
# 127736  POLYGON ((-119.53824714169218 46.8391017483470...
# 127737  POLYGON ((-118.97255834738979 46.3802638677833...
# 127738  POLYGON ((-118.95208922363872 46.3579778607896...
# 127739  POLYGON ((-117.2603327078881 47.55266299729953...
#
#        HUC8            Latitude            Longitude NHDNetworkStatusCV  \
# 0             47.65069874800008       -122.219626147
# 1             48.53634364700008  -122.88346013399996
# 2            47.652644743000046       -122.217763301
# 3             47.65286443600007  -122.21706725099996
# 4             47.65170126000004  -122.21327070299996
# ...     ...                 ...                  ...                ...
# 127735            46.8332754851       -119.495280493
# 127736            46.8356288945        -119.52737127
# 127737            46.3835247155       -118.961894802
# 127738             46.361692718       -118.957282568
# 127739            47.5522319159       -117.262964811
#
#        NHDProductCV PODorPOUSite          SiteName   SiteNativeID SitePoint  \
# 0                            POD  WaDE Unspecified      POD100002
# 1                            POD  WaDE Unspecified      POD100004
# 2                            POD  WaDE Unspecified      POD100006
# 3                            POD  WaDE Unspecified      POD100008
# 4                            POD  WaDE Unspecified      POD100009
# ...             ...          ...               ...            ...       ...
# 127735                       POU  WaDE Unspecified  POUwade197345
# 127736                       POU  WaDE Unspecified  POUwade197346
# 127737                       POU  WaDE Unspecified  POUwade197347
# 127738                       POU  WaDE Unspecified  POUwade197348
# 127739                       POU  WaDE Unspecified   POUwade19735
#
#                                                SiteTypeCV StateCV USGSSiteID  \
# 0                                      Surface Water Pump      WA
# 1       Headworks Gravity Flow (or surface water devic...      WA
# 2                                      Surface Water Pump      WA
# 3                                      Surface Water Pump      WA
# 4                                      Surface Water Pump      WA
# ...                                                   ...     ...        ...
# 127735                                   WaDE Unspecified      WA
# 127736                                   WaDE Unspecified      WA
# 127737                                   WaDE Unspecified      WA
# 127738                                   WaDE Unspecified      WA
# 127739                                   WaDE Unspecified      WA
#
#        WaterSourceUUID WaterSourceTypeCV
# 0       WAwr_WSwadeID3     Surface Water
# 1       WAwr_WSwadeID3     Surface Water
# 2       WAwr_WSwadeID3     Surface Water
# 3       WAwr_WSwadeID3     Surface Water
# 4       WAwr_WSwadeID3     Surface Water
# ...                ...               ...
# 127735  WAwr_WSwadeID3     Surface Water
# 127736  WAwr_WSwadeID3     Surface Water
# 127737  WAwr_WSwadeID2       Groundwater
# 127738  WAwr_WSwadeID2       Groundwater
# 127739  WAwr_WSwadeID2       Groundwater
#
# [127740 rows x 24 columns]

# %%
# Export out to CSV.
outdfs.to_csv('ProcessedInputData/sites.csv', index=False) # this is in the Regulatory data folder
