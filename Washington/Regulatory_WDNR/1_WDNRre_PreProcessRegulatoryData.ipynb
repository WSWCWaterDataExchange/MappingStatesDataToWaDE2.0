# %% [markdown]
# # Pre-processing (state / organization Name) Regulatory data for WaDE upload.
# - Purpose:  To preprocess the data into one master file for simple DataFrame creation and extraction.

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Washington/Regulatory_WDNR" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Washington/Regulatory_WADNR

# %% [markdown]
# ## Regulatory Area Data #1

# %%
# Input File
inputFile = "RawInputData/shapefiles/WatershedAdministrativeUnits_ForestPracticesRegulation.zip"
dfin1 = gpd.read_file(inputFile).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin1:
    dfin1['WaDEUUID'] = "re" + dfin1.index.astype(str)
    dfin1.to_csv('RawInputData/WatershedAdministrativeUnits_ForestPracticesRegulation.zip', compression=dict(method='zip', archive_name='WatershedAdministrativeUnits_ForestPracticesRegulation.csv'), index=False)

print(len(dfin1))
dfin1.head()
# Out:
# 846
#    OBJECTID  WAU_ID  WAU_CD                           WAU_NM  WSA_NO  \
# 0         1     843  620402                          S SALMO       0
# 1         2     842  620401         PEND OREILLE/SLATE CREEK       0
# 2         3     819  610101           CEDAR CREEK/FISH CREEK       0
# 3         4     821  610103  UPPER LAKE ROOSEVELT/DEEP CREEK       0
# 4         5      26   10519                        BIRCH BAY       0
#
#                         WAU_LABEL_              WAU_ALIAS_  \
# 0                          S Salmo   SOUTH SALMO, SALMO, S
# 1         Pend Oreille/Slate Creek             SLATE CREEK
# 2           Cedar Creek/Fish Creek             CEDAR CREEK
# 3  Upper Lake Roosevelt/Deep Creek  NORTHPORT, CEDAR CREEK
# 4                        Birch Bay
#
#                         HYDRO_REF_    WAU_ACRES  WAU_UPLAND BASIN_CD  \
# 0                SOUTH SALMO RIVER  15971.00000 15971.00000     6204
# 1   PEND OREILLE RIVER/SLATE CREEK  61059.80000 61059.80000     6204
# 2           CEDAR CREEK/FISH CREEK  21718.10000 21718.10000     6101
# 3  UPPER LAKE ROOSEVELT/DEEP CREEK  32578.10000 32578.10000     6101
# 4                        BIRCH BAY 179897.30000 23469.60000     0105
#
#                BASIN_NM        SHAPEAREA     SHAPELEN  Shape_Leng  Shape_Area  \
# 0              METALINE  695697638.00000 145636.56371     0.52318     0.00793
# 1              METALINE 2659765934.50000 243762.40452     0.86843     0.03028
# 2  SOUTHEAST-DEEP CREEK  946039126.50000 150232.64596     0.54401     0.01078
# 3  SOUTHEAST-DEEP CREEK 1419099958.50000 221595.75738     0.72851     0.01614
# 4                 DELTA 7836309438.00000 422079.80803     1.59273     0.08917
#
#                                             geometry WaDEUUID
# 0  POLYGON ((-117.03202 48.94642, -117.03767 48.9...      re0
# 1  POLYGON ((-117.15247 48.93326, -117.15341 48.9...      re1
# 2  POLYGON ((-117.61222 49.00072, -117.58276 49.0...      re2
# 3  POLYGON ((-117.61222 49.00072, -117.61196 48.9...      re3
# 4  POLYGON ((-122.63647 48.87744, -122.63717 48.8...      re4

# %%
# create output for Regulatory Area #1 dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfin1['WaDEUUID']

# Date Info
df['in_Date'] = "8/2/2023"
df['in_Year'] = "2023"

# Organization Info
df['in_OrganizationUUID'] = "WDNRre_O1"

# ReportingUnit Info
df['in_EPSGCodeCV'] = "4326"
df['in_ReportingUnitName'] = dfin1["WAU_LABEL_"]
df['in_ReportingUnitNativeID'] = "wa" + dfin1["WAU_ID"].astype(int).astype(str).str.strip()
df['in_ReportingUnitProductVersion'] = ""
df['in_ReportingUnitTypeCV'] = "Watershed Administrative Units"
df['in_ReportingUnitUpdateDate'] = "1/7/2021"
df['in_StateCV'] = "WA"
df['in_Geometry'] = ""

# RegulatoryOverlay Info
df['in_OversightAgency'] = "Washington Department of Natural Resources"
df['in_RegulatoryDescription'] = "a structured approach to developing a forest practices plan for a WAU based on a biological and physical inventory"
df['in_RegulatoryName'] = dfin1["WAU_LABEL_"]
df['in_RegulatoryOverlayNativeID'] = dfin1["WAU_ID"].astype(int).astype(str).str.strip()
df['in_RegulatoryStatusCV'] = "Active"
df['in_RegulatoryStatute'] = ""
df['in_RegulatoryStatuteLink'] =""
df['in_StatutoryEffectiveDate'] = "8/2/1992"
df['in_StatutoryEndDate'] = ""
df['in_RegulatoryOverlayTypeCV'] = "Watershed Administrative Units"
df['in_WaterSourceTypeCV'] = "Surface Water"

df = df.drop_duplicates().reset_index(drop=True)
outdf1 = df.copy()
print(len(outdf1))
outdf1.head()
# Out:
# 846
#   WaDEUUID   in_Date in_Year in_OrganizationUUID in_EPSGCodeCV  \
# 0      re0  8/2/2023    2023           WDNRre_O1          4326
# 1      re1  8/2/2023    2023           WDNRre_O1          4326
# 2      re2  8/2/2023    2023           WDNRre_O1          4326
# 3      re3  8/2/2023    2023           WDNRre_O1          4326
# 4      re4  8/2/2023    2023           WDNRre_O1          4326
#
#               in_ReportingUnitName in_ReportingUnitNativeID  \
# 0                          S Salmo                    wa843
# 1         Pend Oreille/Slate Creek                    wa842
# 2           Cedar Creek/Fish Creek                    wa819
# 3  Upper Lake Roosevelt/Deep Creek                    wa821
# 4                        Birch Bay                     wa26
#
#   in_ReportingUnitProductVersion          in_ReportingUnitTypeCV  \
# 0                                 Watershed Administrative Units
# 1                                 Watershed Administrative Units
# 2                                 Watershed Administrative Units
# 3                                 Watershed Administrative Units
# 4                                 Watershed Administrative Units
#
#   in_ReportingUnitUpdateDate in_StateCV in_Geometry  \
# 0                   1/7/2021         WA
# 1                   1/7/2021         WA
# 2                   1/7/2021         WA
# 3                   1/7/2021         WA
# 4                   1/7/2021         WA
#
#                            in_OversightAgency  \
# 0  Washington Department of Natural Resources
# 1  Washington Department of Natural Resources
# 2  Washington Department of Natural Resources
# 3  Washington Department of Natural Resources
# 4  Washington Department of Natural Resources
#
#                             in_RegulatoryDescription  \
# 0  a structured approach to developing a forest p...
# 1  a structured approach to developing a forest p...
# 2  a structured approach to developing a forest p...
# 3  a structured approach to developing a forest p...
# 4  a structured approach to developing a forest p...
#
#                  in_RegulatoryName in_RegulatoryOverlayNativeID  \
# 0                          S Salmo                          843
# 1         Pend Oreille/Slate Creek                          842
# 2           Cedar Creek/Fish Creek                          819
# 3  Upper Lake Roosevelt/Deep Creek                          821
# 4                        Birch Bay                           26
#
#   in_RegulatoryStatusCV in_RegulatoryStatute in_RegulatoryStatuteLink  \
# 0                Active
# 1                Active
# 2                Active
# 3                Active
# 4                Active
#
#   in_StatutoryEffectiveDate in_StatutoryEndDate  \
# 0                  8/2/1992
# 1                  8/2/1992
# 2                  8/2/1992
# 3                  8/2/1992
# 4                  8/2/1992
#
#        in_RegulatoryOverlayTypeCV in_WaterSourceTypeCV
# 0  Watershed Administrative Units        Surface Water
# 1  Watershed Administrative Units        Surface Water
# 2  Watershed Administrative Units        Surface Water
# 3  Watershed Administrative Units        Surface Water
# 4  Watershed Administrative Units        Surface Water

# %% [markdown]
# ## Regulatory Area #2

# %%
# etc etc,

# %% [markdown]
# ## Concatenate DataFrames together

# %%
# Concatenate dataframes
frames = [outdf1] # list all out dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 846

# %% [markdown]
# ## Clean Data / data types

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_ReportingUnitName'] = df.apply(lambda row: ensureEmptyString(row['in_ReportingUnitName']), axis=1)
outdf['in_ReportingUnitName'].unique()
# Out:
# array(['S Salmo', 'Pend Oreille/Slate Creek', 'Cedar Creek/Fish Creek',
#        'Upper Lake Roosevelt/Deep Creek', 'Birch Bay', 'Big Sheep Creek',
#        'Kettle River/Deep Creek', 'Drayton', 'Independent Creek',
#        'Lynden', 'W Deer Creek', 'Sumas River', 'Sullivan', 'Vedder',
#        'Tonata Creek', 'Myers Creek', 'Silesia Creek', 'Tonasket Creek',
#        'Similkameen River', 'Chilliwack', 'Boulder Creek', 'Silver Creek',
#        'Lone Ranch', 'Hozomeen', 'Lightning Creek', 'Ashnola River',
#        'Pasayten River', 'Upper Chewuch River', 'NF Toats Coulee',
#        'Canyon/Whistler', 'Gold Creek', 'Toulou Creek', 'Lower Toroda',
#        'Flat Creek', 'NF Deep Creek', 'Little Boulder Creek',
#        'Little Beaver Creek', 'Deming', 'Onion Creek', 'SF Toats Coulee',
#        'Three Fools Creek', 'Shuksan', 'Emanuel Creek', 'Tenmile Creek',
#        'Wannacut-Spectacle-Whitestone', 'Ferndale',
#        'Upper Okanogan River', 'Mazama', 'Chopaka', 'Warnick',
#        'Lost River', 'Pend Oreille/Cedar Creek', 'Racehorse Creek',
#        'Arctic Creek', 'Glacier Creek', 'Long Alec Creek',
#        'Antoine Creek', 'Anderson Creek', 'Curlew Creek', 'NF Boulder',
#        'Big Beaver Creek', 'Harvey Creek', 'Upper Baker River',
#        'Slate Creek', 'China Creek', 'Wauconda Summit', 'Porter Canyon',
#        'Lower Kettle River', 'Nooksack/Silver', 'Aladdin', 'Mt Baker',
#        'Granite Creek', 'Patos Island', 'Clearwater Creek',
#        'Squalicum Creek', 'Cecile Creek', 'Mt Bonaparte', 'Acme',
#        'St Peter-Lambert', 'SF Boulder', 'Devils Creek', 'Curlew Lake',
#        'Muddy Creek', 'Goodell Creek', 'W Aeneas', 'Lummi Island',
#        'Marmot Ridge', 'Gorge Lake', 'Siwash Creek', 'Waldron Island',
#        'Leclerc Creek', 'Hutchinson Creek', 'Whitestone Coulee',
#        'Lake Shannon', 'Orcas Island', 'Ruby Creek/Panther Creek',
#        'Sinlahekin Creek', 'Deadman Creek', 'Mill Creek/Clugston Creek',
#        'Thunder Creek', 'Portage Island', 'Upper Methow',
#        'NF Granite Creek', 'Bacon Creek', 'Pine Creek', 'Stuart Island',
#        'Upper Mill Creek', 'Wolf Creek', 'Ruby Creek', 'Skookum Creek',
#        'Bracken Creek', 'Clallam River', 'Lake Cavanaugh',
#        'Big Creek/Grade Creek', 'Fir Island', 'Colville River/Dry Creek',
#        'Buck Creek', 'Lynx Creek', 'Lower Suiattle', 'Nanamkin Creeks',
#        'Protection Island', 'Stensgar Creek', 'Chiliwist Creek',
#        'Bell Creek', 'Omak Lake', 'Downey-Sulphur', 'NF Calispell Creek',
#        'W Stranger Creek', 'Ozette Lake', 'Benson Creek', 'Twin Lakes',
#        'Cottonwood Creek', 'Dungeness Valley', 'Middle Sauk', 'Hazel',
#        'Pend Oreille/Deer Creek', 'Bridge Creek', 'Lower Pilchuck Creek',
#        'Twin Rivers-Deep Creek', 'Upper Lake Chelan', 'Little Nespelem',
#        'Lower NF Stillaguamish', 'Middle Lake Roosevelt/Harvey Creek',
#        'Many Lakes', 'Siebert McDonald', 'Soap Lake', 'Libby Creek',
#        'Nason Creek', 'Lake Crescent', 'Camano Island',
#        'Stillaguamish Flats', 'Huckleberry Creek', 'Swamp Creek',
#        'Church Creek', 'Salt Creek', 'Middle Suiattle', 'Morse Creek',
#        'Port Angeles', 'French-Boulder', 'Coyote Creek',
#        'Nez Perce Creek', 'Dan Creek', 'Frosty Meadow', 'Wilmont Creek',
#        'Milk Creek', 'Lower Okanogan River', 'Sutherland-Aldwell',
#        'Grouse Creek', 'Big Goose Lake', 'Lower Stillaguamish River',
#        'Otter Creek', 'French Creek', 'Chocolate Glacier', 'Jim Creek',
#        'Texas Creek', 'Methow Gold Creek', 'Upper Sauk/Clear Creek',
#        'West Branch', 'Deer Lake', 'Jordan', 'WF Dickey',
#        'North-Middle Forks Deer Creek', 'Pateros Lake Agricultural Lands',
#        'Canyon Creek', 'White Chuck', 'Many Creeks', 'Discovery Bay',
#        'Hunters Creek', 'Sol Duc Valley', 'Coyote Agricultural Lands',
#        'Blanchard Creek', 'Quilceda Creek', 'EF Dickey', 'Trinity',
#        'Monte Cristo', 'Tulalip Creek', 'Chimakum', 'Upper Entiat',
#        'Indian Dan Canyon', 'Beaver Creek', 'Camas Valley',
#        'Lower Pilchuck River', 'Upper Sol Duc', 'Verlot',
#        'Or-A-Pak-En Creek', 'Watson Draw', 'Ninemile Flat', 'Silverton',
#        'Buffalo Lake', 'Manila Creek', 'Sequim Bay', 'Mission',
#        'Nespelem River', 'Twentythree Mile Creek', 'Wanlick Creek',
#        'Lower Bonaparte', 'Lower Sherman Creek', 'Aeneas-Cape Labelle',
#        'Kalispell Creek', 'Upper Little Pend Oreille River',
#        'Granite Creek/Swamp Creek', 'Lakes', 'Sherman Pass',
#        'Sanpoil/Scatter Creek', 'Damfino', 'Pingston Creek',
#        'Howard Creek', 'NF Salmon Creek', 'Spieden Island', 'Fish Lake',
#        'Haller Creek', 'Edwards Creek', 'Upper WF Sanpoil',
#        'Newhalem Creek', 'Diobsud Creek', 'San Juan Island',
#        'O Brien Creek', 'Sinclair Island', 'Chewiliken Creek',
#        'Guemes Island', 'Lower Chewuch River', 'Cypress Island', 'Grandy',
#        'Blakely Island', 'Middle Creek', 'Shaw Island', 'Jackman Creek',
#        'Lower Little Pend Oreille', 'Lopez Island', 'Stahley Mtn',
#        'Hansen Creek', 'Tunk', 'Quillisascut Creek', 'Alder',
#        'Ninemile Creek', 'Corkindale', 'West Fork Sanpoil/Gold Creek',
#        'Wanacut', 'Middle Cascade River', 'Upper Hall Creek',
#        'Jordan-Boulder', 'Tacoma Creek', 'Neah Bay',
#        'Beaver Creek/Lightning Creek', 'Cee Cee Ah Creek',
#        'Johnson Creek', 'Barnaby Creek', 'Stehekin River',
#        'Fidalgo Island', 'Lost Creek', 'Lower Salmon Creek',
#        'Padilla Bay', 'Day Creek', 'Finney', 'Cascade Pass', 'Bear Creek',
#        'Middle Methow River', 'Gilligan', 'Lower Skagit Flats',
#        'Lower Hall Creek', 'Twisp', 'Seventeenmile Creek', 'Nookachamps',
#        'Loup Loup Creek', 'Moran Creek', 'Magee Creek', 'Sekiu',
#        'Illabot Creek', 'Chewelah Creek', 'Lower Sauk', 'Skookum',
#        'Priest River', 'Frazer Creek', 'Tsoo-Yess', 'Deer Creek',
#        'Disautel', 'E Stranger Creek', 'Upper NF Stilly',
#        'Calispell Creek', 'Hoko', 'Carpenter', 'Spring Coulee',
#        'Whidbey Island', 'Grade Creek', 'Middle Lake Chelan/Coyote Creek',
#        'Lower Dickey', 'Sloan Creek', 'SF Ninemile', 'Alta Lake',
#        'Hunter Mountain', 'Napeequa', 'Sol Duc Lowlands', 'NF Calawah',
#        'NF Sol Duc', 'Chiwawa', 'Pilchuck Mtn', 'Chamokane Creek',
#        'White River', 'Spada Lake', 'Little Spokane/Deer Creek',
#        'Sand Creek', 'Everett', 'SF Calawah', 'Gedney Island',
#        'Mt Carrie', 'Dragoon Creek', 'Lower Calawah', 'Sixmile Creek',
#        'Woods Creek', 'Little Chamokane',
#        'Grand Coulee Agricultural Lands', 'Coulee Dam', 'Brody',
#        'Lower Chiwawa', 'Middle Entiat', 'Howard Flats', 'Orazada Creek',
#        'Bogachiel', 'Quillayute River', 'Gray Wolf', 'Upper Dungeness',
#        'Upper Bogachiel', 'Twentyfive Mile Creek', 'Sultan River',
#        'First Creek', 'Blue Creek', 'Liberty-Miller-Appletree',
#        'Wenatchee Ridge', 'Excelsior Mtn', 'Lower Long Lake',
#        'Bangor-Port Gamble', 'Toandos Peninsula', 'Goodman-Mosquito',
#        'Olney Creek', 'Deadman Creek/Peone Creek', 'Chelan River',
#        'Little Deep Creek', 'Possession Sound-N Elliot Bay',
#        'Upper Hoh River', 'Little Quil', 'Upper Wallace River',
#        'Mad River', 'Upper Long Lake', 'Thompson Creek',
#        'Sammamish River', 'Lower NF Skykomish', 'Middle Hoh',
#        'Harker Canyon', 'E Lake Roosevelt', 'Mt Wilder',
#        'Upper Crab-Wilson Agricultural Lands', 'Stormy',
#        'Plateau Agricultural Lands', 'Big Quil', 'LF Hauser Creek',
#        'Nason Ridge', 'Dartford Creek', 'Beckler River',
#        'Matheson Road Creek', 'Skykomish River', 'Lower Hoh River',
#        'Navarre Coulee', 'Youngs Creek', 'Spring Creek', 'Mt Anderson',
#        'Lake Wenatchee', 'Rain Forest', 'Tumwater Canyon',
#        'Moses Coulee Agricultural Lands',
#        'Lower Snoqualmie River/Cherry Creek', 'Mt Queets',
#        'N Lake Washington', 'Upper Clearwater', 'Mill Canyon',
#        'Upper Nason', 'SF Skykomish River', 'Coulee Creek', 'Cedar',
#        'Deep Creek', 'Lower Nason', 'Spokane Urban', 'Lower Dosewallips',
#        'Nine Mile Reservoir', 'Lower Clearwater', 'Tolt', 'Byrd Canyon',
#        'Deception', 'Liberty Creek', 'Mt Lawson', 'Chumstick',
#        'Enchanted Valley', 'Lower Entiat', 'Kalaloch Ridge', 'Chiwaukum',
#        'Harris Creek', 'Bainbridge Island', 'Dyes Inlet', 'Duckabush',
#        'Tshletshy Ridge', 'N-S Forks Deep Creek', 'French Ridge',
#        'Miller River', 'Derby', 'Foss River', 'W Kitsap', 'Tokul Creek',
#        'Lower Queets River', 'Marshall Creek', 'NF Snoqualmie River',
#        'Patterson Creek', 'Griffin Creek', 'Hamma Hamma',
#        'Waketickeh Creek', 'S Lake Washington', 'Cushman',
#        'Lake Sammamish', 'Lower Latah', 'Palouse Agricultural Lands',
#        'Quinault Lake', 'Swakane Creek', 'Chico Creek', 'Matheny Creek',
#        'Enchantment', 'California-Lower Rock', 'Lower Wenatchee',
#        'S Elliott Bay/E Passage', 'Lower Green-Duwamish', 'Salmon River',
#        'Upper Middle Snoqualmie', 'Great Bend',
#        'Colvos Passage/Carr Inlet', 'S Sinclair Inlet', 'Alps',
#        'Raft River', 'Lynch Cove', 'Tiger', 'Raging River',
#        'Upper Wynoochee', 'SF Skokomish', 'Cooper Lake',
#        'Lower Quinault River', 'Lilliwaup', 'Tate', 'Mt Stuart',
#        'Vashon Island', 'Latah/Spangle', 'Lower Middle Snoqualmie',
#        'Upper Rock Creek/Rose Creek', 'WF Humptulips',
#        'SF Snoqualmie River', 'Lower Mission Creek', 'Lower Cedar River',
#        'Key Peninsula', 'EF Humptulips', 'Lower Wynoochee', 'WF Satsop',
#        'Tekoa', 'Lower NF Skokomish', 'Stafford Creek', 'Blewett',
#        'Mason', 'Cook-Elk', 'MF Satsop', 'Cedar River/Taylor Creek',
#        'Chester Morse', 'Lower Crab Agricultural Lands', 'Stevens Creek',
#        'Upper Mission Creek', 'Lower Skokomish', 'Stemilt Creek',
#        'Moclips', 'Lower Puyallup', 'Wishkah Headwaters', 'Liberty',
#        'NF Green', 'Satsop', 'NF Teanaway', 'Copalis River', 'Cumberland',
#        'EF Satsop', 'Tarpiscan', 'Howard Hanson', 'Chambers-Clover',
#        'Naneum', 'Harstine Island', 'Lower White', 'Newaukum',
#        'Raney Creek', 'Smay Creek', 'Lower Wishkah', 'Middle Humptulips',
#        'Teanaway-Mason Creek', 'Mc Neil Island', 'Lester', 'EF Hoquiam',
#        'Squaxin Island', 'Wynoochee River S', 'Mud Mtn',
#        'Lower Swauk Creek', 'Coleman', 'Lower Humptulips River',
#        'Woodland Creek', 'Young Cove', 'Anderson Island', 'Middle White',
#        'Currier', 'Cloquallum', 'Stray Gulch', 'Yakima River/Dry Creek',
#        'WF-MF Hoquiam', 'Greenwater', 'Lower Deschutes', 'McLane Creek',
#        'South Prairie', 'Clearwater', 'Wilkeson', 'Carbon', 'Electron',
#        'McAllister', 'Taneum Canyon', 'Kennedy Creek', 'Upper White',
#        'WF White', 'Yakima River/Naneum Creek', 'Parke Creek',
#        'Muck Creek', 'Alkali Canyon Agricultural Lands',
#        'Naches/Quartz Creek', 'Delezene Creek', 'Mox Chehalis',
#        'Huckleberry', 'Robinson Canyon', 'SF Manastash',
#        'Ocean Shores Coastal', 'Porter Creek', 'NF Manastash',
#        'Lower Chehalis/Elizabeth Creek', 'Chehalis Sloughs',
#        'Waddell Creek', 'Black River', 'Crow Creek', 'Johns River',
#        'Cliffdell', 'Yelm Creek', 'Fryingpan',
#        'Upper Chehalis/Cedar Creek', 'Vesta-Little North',
#        'N-S Forks Wenas', 'Norse Peak', 'Bumping', 'Tanwax Creek',
#        'Elk River', 'Gibson Creek', 'Ohop Creek', 'Mowich-Puyallup',
#        'Esquatzel Coulee Agricultural Lands', 'Lower North River',
#        'Ellensburg Pass', 'Upper Chehalis/Rock Creek',
#        'Umtanum-Selah Agricultural Lands', 'Scatter Creek', 'Wenas Creek',
#        'North Headwaters', 'Nile Creek', 'Mashel', 'Powell Creek',
#        'Middle Deschutes', 'Middle Snake Agricultural Lands',
#        'Lower Skookumchuck', 'Ohanapecosh', 'Rattlesnake',
#        'Garrard Creek', 'Smith Creek', 'Wenas Creek Agricultural Lands',
#        'Kautz', 'Muddy Fork Cowlitz', 'Cedar River',
#        'Little Nisqually River', 'Independence Creek',
#        'Upper Skookumchuck', 'Naches River', 'Upper Deschutes',
#        'N Elochoman', 'Upper Green', 'Toutle River', 'Piscoe Creek',
#        'Mount Adams Lake', 'Tumalun Creek', 'Patit Creek', 'Pataha Creek',
#        'Skamokawa', 'Chinook', 'Adams Creek', 'Delameter',
#        'McGreedy Creek', 'NF Toutle', 'Tucannon', 'Agency Creek',
#        'Lincoln Plateau', 'Germany', 'Abernathy', 'Silver Lake',
#        'Lower Cowlitz', 'Lower Elochoman', 'E Canyon Creek', 'SF Toutle',
#        'Spirit Lake', 'NF Asotin Creek', 'Muddy River', 'NF Touchet',
#        'Klickitat/Swamp Creek', 'SF Asotin', 'Coal Creek', 'Clear Creek',
#        'Wolf Fork', 'SF Touchet', 'Adams', 'Upper SF Toutle', 'Ostrander',
#        'Dry Creek', 'Surveyors Creek', 'Big Bend Agricultural Lands',
#        'Tepee Creek', 'Springs', 'Upper Coweeman',
#        'Rock-Glade North Agricultural Lands', 'Panjab Creek',
#        'George Creek', 'Lower Coweeman', 'Coppei Creek', 'Longview',
#        'Hellroaring Creek', 'Cascade Creek', 'Goat Mtn',
#        'Swift Reservoir', 'Cougar', 'Trout Creek/Bear Creek',
#        'Crofton Creek', 'Halsey Butte', 'Bird Creek', 'Grande Ronde',
#        'Gotchen Creek', 'Kusshi Creek', 'Trout Lake Creek',
#        'Klickitat/Bacon Creek', 'Middle Kalama', 'Butte Creek',
#        'Satus Pass', 'Lower Kalama', 'Kooskooskie', 'Trout Lake',
#        'Table Rock', 'Bull Creek', 'Summit Creek',
#        'Rock-Glade Central Agricultural Lands', 'Little Goose Creek',
#        'Lake Merwin', 'Conboy', 'Siouxon', 'Pine Creek/Juniper Canyon',
#        'Big Lava Beds', 'Cave Creek', 'Indian Heaven', 'Elmer Canyon',
#        'Cathlapotl', 'Little Klickitat/Canyon Creek', 'Holmes Creek',
#        'Dead Canyon', 'Butler Creek', 'Brooks',
#        'Mill Creek/Devils Canyon', 'Wood Gulch', 'Harrison Creek',
#        'Upper Rock Creek', 'Quartz Creek', 'Cedar Creek/Chelatchie Creek',
#        'Canyon Creek/Fly Creek', 'W Prong', 'Blockhouse Creek',
#        'Panakanic', 'Panther Creek', 'Yacolt',
#        'Little White Salmon River', 'Gilmer Creek', 'Snyder Canyon',
#        'Middle Rock Creek', 'Nelson Butte', 'East Creek', 'Hanaford',
#        'Fall River', 'Little Rattlesnake', 'Lincoln Creek', 'Goat Lake',
#        'Reese Creek', 'Lower Willapa', 'Wilson Creek',
#        'Cowiche Agricultural Lands', 'Carlton', 'Oak Creek',
#        'Mineral Creek', 'Skate', 'Bunker Creek', 'Palix',
#        'Roundtop Creek', 'Teeley Creek', 'NF Newaukum',
#        'NF Mineral Creek', 'NF Tieton-Tumac Plateau', 'Chehalis', 'Catt',
#        'Salzer Creek', 'Elk Creek', 'Berry Creek',
#        'Lower Snake Agricultural Lands', 'SF Willapa', 'Long Beach',
#        'Hope Creek', 'Tieton River', 'SF Newaukum', 'NF Cowiche',
#        'Cowlitz', 'NF Tilton', 'Mill Creek', 'WF Tilton',
#        'Lower Newaukum', 'Packwood Lake', 'Silver', 'Nineteen Creek',
#        'Bremer', 'Rimrock', 'Rock-Jones', 'Cowlitz River/Mill Creek',
#        'Willame Creek', 'Willapa Headwaters',
#        'Yakima/Toppenish Agricultural Lands', 'SF Cowiche',
#        'Cold Creek Agricultural Lands', 'EF Tilton', 'Connelly',
#        'Lower Yakima West Side Agricultural Lands', 'Lake Creek',
#        'Morton', 'SF Chehalis', 'Stillman Creek', 'Davis Creek', 'Kiona',
#        'Foundation Creek', 'Chehalis Headwaters', 'Nemah', 'Harmony',
#        'Kosmos', 'Lacamas', 'SF Ahtanum', 'Olequa', 'Smith Point',
#        'Naselle Headwaters', 'Angry Mtn', 'Lower Riffe Lake',
#        'Long Island', 'Darland Mtn', 'Upper Riffe Lake', 'Lower Naselle',
#        'SF Tieton River', 'Winston', 'Mitchell Creek',
#        'Walla Walla Agricultural Lands', 'Cispus', 'Klickitat Meadows',
#        'WF Grays River', 'Cedar Creek', 'Stillwater', 'Iron',
#        'Burley Mtn', 'Salmon Creek', 'Gilbert Peak', 'NF Cispus',
#        'Yakima/Satus Agricultural Lands', 'Goat Creek', 'Grays Bay',
#        'Bear River', 'Lost Horse', 'Green River', 'Blue Lake Creek',
#        'SF Grays River', 'Horseshoe Falls', 'Trout Creek', 'Copper Creek',
#        'White Salmon/Buck Creek', 'Vancouver', 'Lower Wind',
#        'Major Creek', 'Swale', 'Rock Creek', 'Klickitat', 'Silvas Creek',
#        'Columbia River/Rock Creek', 'Chapman Creek', 'Upper Washougal',
#        'The Burn', 'Lacamas Lake', 'Hamilton Creek', 'Celilo',
#        'Little Washougal', 'Mt Zion', 'WF Salmon Creek', 'Pysht River',
#        'WF Washougal', 'Lake Whatcom', 'Bellingham Bay', 'Friday Creek',
#        'Samish River', 'Samish Bay', 'Keechelus', 'Kachess',
#        'MF Teanaway', 'Cle Elum', 'WF Teanaway', 'Mosquito Creek',
#        'Upper Yakima River/Silver Creek', 'Sunday Creek', 'Cabin Creek',
#        'Lannigan Spring', 'Upper Green River', 'Big Creek', 'Quartz Mtn',
#        'Naches Pass'], dtype=object)

# %%
outdf['in_RegulatoryDescription'] = df.apply(lambda row: ensureEmptyString(row['in_RegulatoryDescription']), axis=1)
outdf['in_RegulatoryDescription'].unique()
# Out:
# array(['a structured approach to developing a forest practices plan for a WAU based on a biological and physical inventory'],
#       dtype=object)

# %%
outdf['in_RegulatoryName'] = df.apply(lambda row: ensureEmptyString(row['in_RegulatoryName']), axis=1)
outdf['in_RegulatoryName'].unique()
# Out:
# array(['S Salmo', 'Pend Oreille/Slate Creek', 'Cedar Creek/Fish Creek',
#        'Upper Lake Roosevelt/Deep Creek', 'Birch Bay', 'Big Sheep Creek',
#        'Kettle River/Deep Creek', 'Drayton', 'Independent Creek',
#        'Lynden', 'W Deer Creek', 'Sumas River', 'Sullivan', 'Vedder',
#        'Tonata Creek', 'Myers Creek', 'Silesia Creek', 'Tonasket Creek',
#        'Similkameen River', 'Chilliwack', 'Boulder Creek', 'Silver Creek',
#        'Lone Ranch', 'Hozomeen', 'Lightning Creek', 'Ashnola River',
#        'Pasayten River', 'Upper Chewuch River', 'NF Toats Coulee',
#        'Canyon/Whistler', 'Gold Creek', 'Toulou Creek', 'Lower Toroda',
#        'Flat Creek', 'NF Deep Creek', 'Little Boulder Creek',
#        'Little Beaver Creek', 'Deming', 'Onion Creek', 'SF Toats Coulee',
#        'Three Fools Creek', 'Shuksan', 'Emanuel Creek', 'Tenmile Creek',
#        'Wannacut-Spectacle-Whitestone', 'Ferndale',
#        'Upper Okanogan River', 'Mazama', 'Chopaka', 'Warnick',
#        'Lost River', 'Pend Oreille/Cedar Creek', 'Racehorse Creek',
#        'Arctic Creek', 'Glacier Creek', 'Long Alec Creek',
#        'Antoine Creek', 'Anderson Creek', 'Curlew Creek', 'NF Boulder',
#        'Big Beaver Creek', 'Harvey Creek', 'Upper Baker River',
#        'Slate Creek', 'China Creek', 'Wauconda Summit', 'Porter Canyon',
#        'Lower Kettle River', 'Nooksack/Silver', 'Aladdin', 'Mt Baker',
#        'Granite Creek', 'Patos Island', 'Clearwater Creek',
#        'Squalicum Creek', 'Cecile Creek', 'Mt Bonaparte', 'Acme',
#        'St Peter-Lambert', 'SF Boulder', 'Devils Creek', 'Curlew Lake',
#        'Muddy Creek', 'Goodell Creek', 'W Aeneas', 'Lummi Island',
#        'Marmot Ridge', 'Gorge Lake', 'Siwash Creek', 'Waldron Island',
#        'Leclerc Creek', 'Hutchinson Creek', 'Whitestone Coulee',
#        'Lake Shannon', 'Orcas Island', 'Ruby Creek/Panther Creek',
#        'Sinlahekin Creek', 'Deadman Creek', 'Mill Creek/Clugston Creek',
#        'Thunder Creek', 'Portage Island', 'Upper Methow',
#        'NF Granite Creek', 'Bacon Creek', 'Pine Creek', 'Stuart Island',
#        'Upper Mill Creek', 'Wolf Creek', 'Ruby Creek', 'Skookum Creek',
#        'Bracken Creek', 'Clallam River', 'Lake Cavanaugh',
#        'Big Creek/Grade Creek', 'Fir Island', 'Colville River/Dry Creek',
#        'Buck Creek', 'Lynx Creek', 'Lower Suiattle', 'Nanamkin Creeks',
#        'Protection Island', 'Stensgar Creek', 'Chiliwist Creek',
#        'Bell Creek', 'Omak Lake', 'Downey-Sulphur', 'NF Calispell Creek',
#        'W Stranger Creek', 'Ozette Lake', 'Benson Creek', 'Twin Lakes',
#        'Cottonwood Creek', 'Dungeness Valley', 'Middle Sauk', 'Hazel',
#        'Pend Oreille/Deer Creek', 'Bridge Creek', 'Lower Pilchuck Creek',
#        'Twin Rivers-Deep Creek', 'Upper Lake Chelan', 'Little Nespelem',
#        'Lower NF Stillaguamish', 'Middle Lake Roosevelt/Harvey Creek',
#        'Many Lakes', 'Siebert McDonald', 'Soap Lake', 'Libby Creek',
#        'Nason Creek', 'Lake Crescent', 'Camano Island',
#        'Stillaguamish Flats', 'Huckleberry Creek', 'Swamp Creek',
#        'Church Creek', 'Salt Creek', 'Middle Suiattle', 'Morse Creek',
#        'Port Angeles', 'French-Boulder', 'Coyote Creek',
#        'Nez Perce Creek', 'Dan Creek', 'Frosty Meadow', 'Wilmont Creek',
#        'Milk Creek', 'Lower Okanogan River', 'Sutherland-Aldwell',
#        'Grouse Creek', 'Big Goose Lake', 'Lower Stillaguamish River',
#        'Otter Creek', 'French Creek', 'Chocolate Glacier', 'Jim Creek',
#        'Texas Creek', 'Methow Gold Creek', 'Upper Sauk/Clear Creek',
#        'West Branch', 'Deer Lake', 'Jordan', 'WF Dickey',
#        'North-Middle Forks Deer Creek', 'Pateros Lake Agricultural Lands',
#        'Canyon Creek', 'White Chuck', 'Many Creeks', 'Discovery Bay',
#        'Hunters Creek', 'Sol Duc Valley', 'Coyote Agricultural Lands',
#        'Blanchard Creek', 'Quilceda Creek', 'EF Dickey', 'Trinity',
#        'Monte Cristo', 'Tulalip Creek', 'Chimakum', 'Upper Entiat',
#        'Indian Dan Canyon', 'Beaver Creek', 'Camas Valley',
#        'Lower Pilchuck River', 'Upper Sol Duc', 'Verlot',
#        'Or-A-Pak-En Creek', 'Watson Draw', 'Ninemile Flat', 'Silverton',
#        'Buffalo Lake', 'Manila Creek', 'Sequim Bay', 'Mission',
#        'Nespelem River', 'Twentythree Mile Creek', 'Wanlick Creek',
#        'Lower Bonaparte', 'Lower Sherman Creek', 'Aeneas-Cape Labelle',
#        'Kalispell Creek', 'Upper Little Pend Oreille River',
#        'Granite Creek/Swamp Creek', 'Lakes', 'Sherman Pass',
#        'Sanpoil/Scatter Creek', 'Damfino', 'Pingston Creek',
#        'Howard Creek', 'NF Salmon Creek', 'Spieden Island', 'Fish Lake',
#        'Haller Creek', 'Edwards Creek', 'Upper WF Sanpoil',
#        'Newhalem Creek', 'Diobsud Creek', 'San Juan Island',
#        'O Brien Creek', 'Sinclair Island', 'Chewiliken Creek',
#        'Guemes Island', 'Lower Chewuch River', 'Cypress Island', 'Grandy',
#        'Blakely Island', 'Middle Creek', 'Shaw Island', 'Jackman Creek',
#        'Lower Little Pend Oreille', 'Lopez Island', 'Stahley Mtn',
#        'Hansen Creek', 'Tunk', 'Quillisascut Creek', 'Alder',
#        'Ninemile Creek', 'Corkindale', 'West Fork Sanpoil/Gold Creek',
#        'Wanacut', 'Middle Cascade River', 'Upper Hall Creek',
#        'Jordan-Boulder', 'Tacoma Creek', 'Neah Bay',
#        'Beaver Creek/Lightning Creek', 'Cee Cee Ah Creek',
#        'Johnson Creek', 'Barnaby Creek', 'Stehekin River',
#        'Fidalgo Island', 'Lost Creek', 'Lower Salmon Creek',
#        'Padilla Bay', 'Day Creek', 'Finney', 'Cascade Pass', 'Bear Creek',
#        'Middle Methow River', 'Gilligan', 'Lower Skagit Flats',
#        'Lower Hall Creek', 'Twisp', 'Seventeenmile Creek', 'Nookachamps',
#        'Loup Loup Creek', 'Moran Creek', 'Magee Creek', 'Sekiu',
#        'Illabot Creek', 'Chewelah Creek', 'Lower Sauk', 'Skookum',
#        'Priest River', 'Frazer Creek', 'Tsoo-Yess', 'Deer Creek',
#        'Disautel', 'E Stranger Creek', 'Upper NF Stilly',
#        'Calispell Creek', 'Hoko', 'Carpenter', 'Spring Coulee',
#        'Whidbey Island', 'Grade Creek', 'Middle Lake Chelan/Coyote Creek',
#        'Lower Dickey', 'Sloan Creek', 'SF Ninemile', 'Alta Lake',
#        'Hunter Mountain', 'Napeequa', 'Sol Duc Lowlands', 'NF Calawah',
#        'NF Sol Duc', 'Chiwawa', 'Pilchuck Mtn', 'Chamokane Creek',
#        'White River', 'Spada Lake', 'Little Spokane/Deer Creek',
#        'Sand Creek', 'Everett', 'SF Calawah', 'Gedney Island',
#        'Mt Carrie', 'Dragoon Creek', 'Lower Calawah', 'Sixmile Creek',
#        'Woods Creek', 'Little Chamokane',
#        'Grand Coulee Agricultural Lands', 'Coulee Dam', 'Brody',
#        'Lower Chiwawa', 'Middle Entiat', 'Howard Flats', 'Orazada Creek',
#        'Bogachiel', 'Quillayute River', 'Gray Wolf', 'Upper Dungeness',
#        'Upper Bogachiel', 'Twentyfive Mile Creek', 'Sultan River',
#        'First Creek', 'Blue Creek', 'Liberty-Miller-Appletree',
#        'Wenatchee Ridge', 'Excelsior Mtn', 'Lower Long Lake',
#        'Bangor-Port Gamble', 'Toandos Peninsula', 'Goodman-Mosquito',
#        'Olney Creek', 'Deadman Creek/Peone Creek', 'Chelan River',
#        'Little Deep Creek', 'Possession Sound-N Elliot Bay',
#        'Upper Hoh River', 'Little Quil', 'Upper Wallace River',
#        'Mad River', 'Upper Long Lake', 'Thompson Creek',
#        'Sammamish River', 'Lower NF Skykomish', 'Middle Hoh',
#        'Harker Canyon', 'E Lake Roosevelt', 'Mt Wilder',
#        'Upper Crab-Wilson Agricultural Lands', 'Stormy',
#        'Plateau Agricultural Lands', 'Big Quil', 'LF Hauser Creek',
#        'Nason Ridge', 'Dartford Creek', 'Beckler River',
#        'Matheson Road Creek', 'Skykomish River', 'Lower Hoh River',
#        'Navarre Coulee', 'Youngs Creek', 'Spring Creek', 'Mt Anderson',
#        'Lake Wenatchee', 'Rain Forest', 'Tumwater Canyon',
#        'Moses Coulee Agricultural Lands',
#        'Lower Snoqualmie River/Cherry Creek', 'Mt Queets',
#        'N Lake Washington', 'Upper Clearwater', 'Mill Canyon',
#        'Upper Nason', 'SF Skykomish River', 'Coulee Creek', 'Cedar',
#        'Deep Creek', 'Lower Nason', 'Spokane Urban', 'Lower Dosewallips',
#        'Nine Mile Reservoir', 'Lower Clearwater', 'Tolt', 'Byrd Canyon',
#        'Deception', 'Liberty Creek', 'Mt Lawson', 'Chumstick',
#        'Enchanted Valley', 'Lower Entiat', 'Kalaloch Ridge', 'Chiwaukum',
#        'Harris Creek', 'Bainbridge Island', 'Dyes Inlet', 'Duckabush',
#        'Tshletshy Ridge', 'N-S Forks Deep Creek', 'French Ridge',
#        'Miller River', 'Derby', 'Foss River', 'W Kitsap', 'Tokul Creek',
#        'Lower Queets River', 'Marshall Creek', 'NF Snoqualmie River',
#        'Patterson Creek', 'Griffin Creek', 'Hamma Hamma',
#        'Waketickeh Creek', 'S Lake Washington', 'Cushman',
#        'Lake Sammamish', 'Lower Latah', 'Palouse Agricultural Lands',
#        'Quinault Lake', 'Swakane Creek', 'Chico Creek', 'Matheny Creek',
#        'Enchantment', 'California-Lower Rock', 'Lower Wenatchee',
#        'S Elliott Bay/E Passage', 'Lower Green-Duwamish', 'Salmon River',
#        'Upper Middle Snoqualmie', 'Great Bend',
#        'Colvos Passage/Carr Inlet', 'S Sinclair Inlet', 'Alps',
#        'Raft River', 'Lynch Cove', 'Tiger', 'Raging River',
#        'Upper Wynoochee', 'SF Skokomish', 'Cooper Lake',
#        'Lower Quinault River', 'Lilliwaup', 'Tate', 'Mt Stuart',
#        'Vashon Island', 'Latah/Spangle', 'Lower Middle Snoqualmie',
#        'Upper Rock Creek/Rose Creek', 'WF Humptulips',
#        'SF Snoqualmie River', 'Lower Mission Creek', 'Lower Cedar River',
#        'Key Peninsula', 'EF Humptulips', 'Lower Wynoochee', 'WF Satsop',
#        'Tekoa', 'Lower NF Skokomish', 'Stafford Creek', 'Blewett',
#        'Mason', 'Cook-Elk', 'MF Satsop', 'Cedar River/Taylor Creek',
#        'Chester Morse', 'Lower Crab Agricultural Lands', 'Stevens Creek',
#        'Upper Mission Creek', 'Lower Skokomish', 'Stemilt Creek',
#        'Moclips', 'Lower Puyallup', 'Wishkah Headwaters', 'Liberty',
#        'NF Green', 'Satsop', 'NF Teanaway', 'Copalis River', 'Cumberland',
#        'EF Satsop', 'Tarpiscan', 'Howard Hanson', 'Chambers-Clover',
#        'Naneum', 'Harstine Island', 'Lower White', 'Newaukum',
#        'Raney Creek', 'Smay Creek', 'Lower Wishkah', 'Middle Humptulips',
#        'Teanaway-Mason Creek', 'Mc Neil Island', 'Lester', 'EF Hoquiam',
#        'Squaxin Island', 'Wynoochee River S', 'Mud Mtn',
#        'Lower Swauk Creek', 'Coleman', 'Lower Humptulips River',
#        'Woodland Creek', 'Young Cove', 'Anderson Island', 'Middle White',
#        'Currier', 'Cloquallum', 'Stray Gulch', 'Yakima River/Dry Creek',
#        'WF-MF Hoquiam', 'Greenwater', 'Lower Deschutes', 'McLane Creek',
#        'South Prairie', 'Clearwater', 'Wilkeson', 'Carbon', 'Electron',
#        'McAllister', 'Taneum Canyon', 'Kennedy Creek', 'Upper White',
#        'WF White', 'Yakima River/Naneum Creek', 'Parke Creek',
#        'Muck Creek', 'Alkali Canyon Agricultural Lands',
#        'Naches/Quartz Creek', 'Delezene Creek', 'Mox Chehalis',
#        'Huckleberry', 'Robinson Canyon', 'SF Manastash',
#        'Ocean Shores Coastal', 'Porter Creek', 'NF Manastash',
#        'Lower Chehalis/Elizabeth Creek', 'Chehalis Sloughs',
#        'Waddell Creek', 'Black River', 'Crow Creek', 'Johns River',
#        'Cliffdell', 'Yelm Creek', 'Fryingpan',
#        'Upper Chehalis/Cedar Creek', 'Vesta-Little North',
#        'N-S Forks Wenas', 'Norse Peak', 'Bumping', 'Tanwax Creek',
#        'Elk River', 'Gibson Creek', 'Ohop Creek', 'Mowich-Puyallup',
#        'Esquatzel Coulee Agricultural Lands', 'Lower North River',
#        'Ellensburg Pass', 'Upper Chehalis/Rock Creek',
#        'Umtanum-Selah Agricultural Lands', 'Scatter Creek', 'Wenas Creek',
#        'North Headwaters', 'Nile Creek', 'Mashel', 'Powell Creek',
#        'Middle Deschutes', 'Middle Snake Agricultural Lands',
#        'Lower Skookumchuck', 'Ohanapecosh', 'Rattlesnake',
#        'Garrard Creek', 'Smith Creek', 'Wenas Creek Agricultural Lands',
#        'Kautz', 'Muddy Fork Cowlitz', 'Cedar River',
#        'Little Nisqually River', 'Independence Creek',
#        'Upper Skookumchuck', 'Naches River', 'Upper Deschutes',
#        'N Elochoman', 'Upper Green', 'Toutle River', 'Piscoe Creek',
#        'Mount Adams Lake', 'Tumalun Creek', 'Patit Creek', 'Pataha Creek',
#        'Skamokawa', 'Chinook', 'Adams Creek', 'Delameter',
#        'McGreedy Creek', 'NF Toutle', 'Tucannon', 'Agency Creek',
#        'Lincoln Plateau', 'Germany', 'Abernathy', 'Silver Lake',
#        'Lower Cowlitz', 'Lower Elochoman', 'E Canyon Creek', 'SF Toutle',
#        'Spirit Lake', 'NF Asotin Creek', 'Muddy River', 'NF Touchet',
#        'Klickitat/Swamp Creek', 'SF Asotin', 'Coal Creek', 'Clear Creek',
#        'Wolf Fork', 'SF Touchet', 'Adams', 'Upper SF Toutle', 'Ostrander',
#        'Dry Creek', 'Surveyors Creek', 'Big Bend Agricultural Lands',
#        'Tepee Creek', 'Springs', 'Upper Coweeman',
#        'Rock-Glade North Agricultural Lands', 'Panjab Creek',
#        'George Creek', 'Lower Coweeman', 'Coppei Creek', 'Longview',
#        'Hellroaring Creek', 'Cascade Creek', 'Goat Mtn',
#        'Swift Reservoir', 'Cougar', 'Trout Creek/Bear Creek',
#        'Crofton Creek', 'Halsey Butte', 'Bird Creek', 'Grande Ronde',
#        'Gotchen Creek', 'Kusshi Creek', 'Trout Lake Creek',
#        'Klickitat/Bacon Creek', 'Middle Kalama', 'Butte Creek',
#        'Satus Pass', 'Lower Kalama', 'Kooskooskie', 'Trout Lake',
#        'Table Rock', 'Bull Creek', 'Summit Creek',
#        'Rock-Glade Central Agricultural Lands', 'Little Goose Creek',
#        'Lake Merwin', 'Conboy', 'Siouxon', 'Pine Creek/Juniper Canyon',
#        'Big Lava Beds', 'Cave Creek', 'Indian Heaven', 'Elmer Canyon',
#        'Cathlapotl', 'Little Klickitat/Canyon Creek', 'Holmes Creek',
#        'Dead Canyon', 'Butler Creek', 'Brooks',
#        'Mill Creek/Devils Canyon', 'Wood Gulch', 'Harrison Creek',
#        'Upper Rock Creek', 'Quartz Creek', 'Cedar Creek/Chelatchie Creek',
#        'Canyon Creek/Fly Creek', 'W Prong', 'Blockhouse Creek',
#        'Panakanic', 'Panther Creek', 'Yacolt',
#        'Little White Salmon River', 'Gilmer Creek', 'Snyder Canyon',
#        'Middle Rock Creek', 'Nelson Butte', 'East Creek', 'Hanaford',
#        'Fall River', 'Little Rattlesnake', 'Lincoln Creek', 'Goat Lake',
#        'Reese Creek', 'Lower Willapa', 'Wilson Creek',
#        'Cowiche Agricultural Lands', 'Carlton', 'Oak Creek',
#        'Mineral Creek', 'Skate', 'Bunker Creek', 'Palix',
#        'Roundtop Creek', 'Teeley Creek', 'NF Newaukum',
#        'NF Mineral Creek', 'NF Tieton-Tumac Plateau', 'Chehalis', 'Catt',
#        'Salzer Creek', 'Elk Creek', 'Berry Creek',
#        'Lower Snake Agricultural Lands', 'SF Willapa', 'Long Beach',
#        'Hope Creek', 'Tieton River', 'SF Newaukum', 'NF Cowiche',
#        'Cowlitz', 'NF Tilton', 'Mill Creek', 'WF Tilton',
#        'Lower Newaukum', 'Packwood Lake', 'Silver', 'Nineteen Creek',
#        'Bremer', 'Rimrock', 'Rock-Jones', 'Cowlitz River/Mill Creek',
#        'Willame Creek', 'Willapa Headwaters',
#        'Yakima/Toppenish Agricultural Lands', 'SF Cowiche',
#        'Cold Creek Agricultural Lands', 'EF Tilton', 'Connelly',
#        'Lower Yakima West Side Agricultural Lands', 'Lake Creek',
#        'Morton', 'SF Chehalis', 'Stillman Creek', 'Davis Creek', 'Kiona',
#        'Foundation Creek', 'Chehalis Headwaters', 'Nemah', 'Harmony',
#        'Kosmos', 'Lacamas', 'SF Ahtanum', 'Olequa', 'Smith Point',
#        'Naselle Headwaters', 'Angry Mtn', 'Lower Riffe Lake',
#        'Long Island', 'Darland Mtn', 'Upper Riffe Lake', 'Lower Naselle',
#        'SF Tieton River', 'Winston', 'Mitchell Creek',
#        'Walla Walla Agricultural Lands', 'Cispus', 'Klickitat Meadows',
#        'WF Grays River', 'Cedar Creek', 'Stillwater', 'Iron',
#        'Burley Mtn', 'Salmon Creek', 'Gilbert Peak', 'NF Cispus',
#        'Yakima/Satus Agricultural Lands', 'Goat Creek', 'Grays Bay',
#        'Bear River', 'Lost Horse', 'Green River', 'Blue Lake Creek',
#        'SF Grays River', 'Horseshoe Falls', 'Trout Creek', 'Copper Creek',
#        'White Salmon/Buck Creek', 'Vancouver', 'Lower Wind',
#        'Major Creek', 'Swale', 'Rock Creek', 'Klickitat', 'Silvas Creek',
#        'Columbia River/Rock Creek', 'Chapman Creek', 'Upper Washougal',
#        'The Burn', 'Lacamas Lake', 'Hamilton Creek', 'Celilo',
#        'Little Washougal', 'Mt Zion', 'WF Salmon Creek', 'Pysht River',
#        'WF Washougal', 'Lake Whatcom', 'Bellingham Bay', 'Friday Creek',
#        'Samish River', 'Samish Bay', 'Keechelus', 'Kachess',
#        'MF Teanaway', 'Cle Elum', 'WF Teanaway', 'Mosquito Creek',
#        'Upper Yakima River/Silver Creek', 'Sunday Creek', 'Cabin Creek',
#        'Lannigan Spring', 'Upper Green River', 'Big Creek', 'Quartz Mtn',
#        'Naches Pass'], dtype=object)

# %%
#Update datatype of StatutoryEffectiveDate to fit WaDE 2.0 structure
outdf['in_StatutoryEffectiveDate'] = pd.to_datetime(outdf['in_StatutoryEffectiveDate'], errors = 'coerce')
outdf['in_StatutoryEffectiveDate'] = pd.to_datetime(outdf['in_StatutoryEffectiveDate'].dt.strftime('%m/%d/%Y'))
outdf['in_StatutoryEffectiveDate'].unique()
# Out:
# array(['1992-08-02T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# # Shapefile Data
# - For attaching geometry to reporting unit info.

# %% [markdown]
# #### Regulatory Area #1 shapefile info

# %%
# Input File
shapeInputFile = "RawInputData/shapefiles/WatershedAdministrativeUnits_ForestPracticesRegulation.zip"
gdfin1 = gpd.read_file(shapeInputFile)
print(len(gdfin1))
gdfin1.head()
# Out:
# 846
#    OBJECTID  WAU_ID  WAU_CD                           WAU_NM  WSA_NO  \
# 0         1     843  620402                          S SALMO       0
# 1         2     842  620401         PEND OREILLE/SLATE CREEK       0
# 2         3     819  610101           CEDAR CREEK/FISH CREEK       0
# 3         4     821  610103  UPPER LAKE ROOSEVELT/DEEP CREEK       0
# 4         5      26   10519                        BIRCH BAY       0
#
#                         WAU_LABEL_              WAU_ALIAS_  \
# 0                          S Salmo   SOUTH SALMO, SALMO, S
# 1         Pend Oreille/Slate Creek             SLATE CREEK
# 2           Cedar Creek/Fish Creek             CEDAR CREEK
# 3  Upper Lake Roosevelt/Deep Creek  NORTHPORT, CEDAR CREEK
# 4                        Birch Bay                    None
#
#                         HYDRO_REF_    WAU_ACRES  WAU_UPLAND BASIN_CD  \
# 0                SOUTH SALMO RIVER  15971.00000 15971.00000     6204
# 1   PEND OREILLE RIVER/SLATE CREEK  61059.80000 61059.80000     6204
# 2           CEDAR CREEK/FISH CREEK  21718.10000 21718.10000     6101
# 3  UPPER LAKE ROOSEVELT/DEEP CREEK  32578.10000 32578.10000     6101
# 4                        BIRCH BAY 179897.30000 23469.60000     0105
#
#                BASIN_NM        SHAPEAREA     SHAPELEN  Shape_Leng  Shape_Area  \
# 0              METALINE  695697638.00000 145636.56371     0.52318     0.00793
# 1              METALINE 2659765934.50000 243762.40452     0.86843     0.03028
# 2  SOUTHEAST-DEEP CREEK  946039126.50000 150232.64596     0.54401     0.01078
# 3  SOUTHEAST-DEEP CREEK 1419099958.50000 221595.75738     0.72851     0.01614
# 4                 DELTA 7836309438.00000 422079.80803     1.59273     0.08917
#
#                                             geometry
# 0  POLYGON ((-117.03202 48.94642, -117.03767 48.9...
# 1  POLYGON ((-117.15247 48.93326, -117.15341 48.9...
# 2  POLYGON ((-117.61222 49.00072, -117.58276 49.0...
# 3  POLYGON ((-117.61222 49.00072, -117.61196 48.9...
# 4  POLYGON ((-122.63647 48.87744, -122.63717 48.8...

# %%
# plot shape info to map
gdfin1.plot()
# Out:
# <AxesSubplot: >

# %%
# create output for Regulatory Area #1 dataframe
columnsList = ['in_ReportingUnitNativeID', 'geometry']
goutdf1 = pd.DataFrame(columns=columnsList, index=gdfin1.index)

goutdf1['in_ReportingUnitNativeID'] = "wa" + gdfin1["WAU_ID"].astype(int).astype(str).str.strip() # in_ReportingUnitNativeID needs to match source from above equivlaent datframe
goutdf1['geometry'] = gdfin1['geometry']
goutdf1 = goutdf1.drop_duplicates().reset_index(drop=True)
print(len(goutdf1))
goutdf1.head()
# Out:
# 846
#   in_ReportingUnitNativeID                                           geometry
# 0                    wa843  POLYGON ((-117.03202 48.94642, -117.03767 48.9...
# 1                    wa842  POLYGON ((-117.15247 48.93326, -117.15341 48.9...
# 2                    wa819  POLYGON ((-117.61222 49.00072, -117.58276 49.0...
# 3                    wa821  POLYGON ((-117.61222 49.00072, -117.61196 48.9...
# 4                     wa26  POLYGON ((-122.63647 48.87744, -122.63717 48.8...

# %% [markdown]
# #### Regulatory Area #2 shapefile info

# %%
# etc etc...

# %% [markdown]
# #### Concatenate goutdf shapefile info into single output

# %%
# Concatenate Basin & Subbasin DataFrames
frames = [goutdf1] # add geoutdf dataframes here
goutdf = pd.concat(frames).reset_index(drop=True)

print(len(goutdf))
goutdf.head()
# Out:
# 846
#   in_ReportingUnitNativeID                                           geometry
# 0                    wa843  POLYGON ((-117.03202 48.94642, -117.03767 48.9...
# 1                    wa842  POLYGON ((-117.15247 48.93326, -117.15341 48.9...
# 2                    wa819  POLYGON ((-117.61222 49.00072, -117.58276 49.0...
# 3                    wa821  POLYGON ((-117.61222 49.00072, -117.61196 48.9...
# 4                     wa26  POLYGON ((-122.63647 48.87744, -122.63717 48.8...

# %% [markdown]
# ## Export Data

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(outdf.dtypes)
# Out:
# WaDEUUID                                  object
# in_Date                                   object
# in_Year                                   object
# in_OrganizationUUID                       object
# in_EPSGCodeCV                             object
# in_ReportingUnitName                      object
# in_ReportingUnitNativeID                  object
# in_ReportingUnitProductVersion            object
# in_ReportingUnitTypeCV                    object
# in_ReportingUnitUpdateDate                object
# in_StateCV                                object
# in_Geometry                               object
# in_OversightAgency                        object
# in_RegulatoryDescription                  object
# in_RegulatoryName                         object
# in_RegulatoryOverlayNativeID              object
# in_RegulatoryStatusCV                     object
# in_RegulatoryStatute                      object
# in_RegulatoryStatuteLink                  object
# in_StatutoryEffectiveDate         datetime64[ns]
# in_StatutoryEndDate                       object
# in_RegulatoryOverlayTypeCV                object
# in_WaterSourceTypeCV                      object
# dtype: object

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(goutdf.dtypes)
# Out:
# in_ReportingUnitNativeID      object
# geometry                    geometry
# dtype: object

# %%
outdf
# Out:
#     WaDEUUID   in_Date in_Year in_OrganizationUUID in_EPSGCodeCV  \
# 0        re0  8/2/2023    2023           WDNRre_O1          4326
# 1        re1  8/2/2023    2023           WDNRre_O1          4326
# 2        re2  8/2/2023    2023           WDNRre_O1          4326
# 3        re3  8/2/2023    2023           WDNRre_O1          4326
# 4        re4  8/2/2023    2023           WDNRre_O1          4326
# ..       ...       ...     ...                 ...           ...
# 841    re841  8/2/2023    2023           WDNRre_O1          4326
# 842    re842  8/2/2023    2023           WDNRre_O1          4326
# 843    re843  8/2/2023    2023           WDNRre_O1          4326
# 844    re844  8/2/2023    2023           WDNRre_O1          4326
# 845    re845  8/2/2023    2023           WDNRre_O1          4326
#
#                 in_ReportingUnitName in_ReportingUnitNativeID  \
# 0                            S Salmo                    wa843
# 1           Pend Oreille/Slate Creek                    wa842
# 2             Cedar Creek/Fish Creek                    wa819
# 3    Upper Lake Roosevelt/Deep Creek                    wa821
# 4                          Birch Bay                     wa26
# ..                               ...                      ...
# 841                  Lannigan Spring                    wa573
# 842                Upper Green River                    wa164
# 843                        Big Creek                    wa576
# 844                       Quartz Mtn                    wa587
# 845                      Naches Pass                    wa549
#
#     in_ReportingUnitProductVersion          in_ReportingUnitTypeCV  \
# 0                                   Watershed Administrative Units
# 1                                   Watershed Administrative Units
# 2                                   Watershed Administrative Units
# 3                                   Watershed Administrative Units
# 4                                   Watershed Administrative Units
# ..                             ...                             ...
# 841                                 Watershed Administrative Units
# 842                                 Watershed Administrative Units
# 843                                 Watershed Administrative Units
# 844                                 Watershed Administrative Units
# 845                                 Watershed Administrative Units
#
#     in_ReportingUnitUpdateDate in_StateCV in_Geometry  \
# 0                     1/7/2021         WA
# 1                     1/7/2021         WA
# 2                     1/7/2021         WA
# 3                     1/7/2021         WA
# 4                     1/7/2021         WA
# ..                         ...        ...         ...
# 841                   1/7/2021         WA
# 842                   1/7/2021         WA
# 843                   1/7/2021         WA
# 844                   1/7/2021         WA
# 845                   1/7/2021         WA
#
#                              in_OversightAgency  \
# 0    Washington Department of Natural Resources
# 1    Washington Department of Natural Resources
# 2    Washington Department of Natural Resources
# 3    Washington Department of Natural Resources
# 4    Washington Department of Natural Resources
# ..                                          ...
# 841  Washington Department of Natural Resources
# 842  Washington Department of Natural Resources
# 843  Washington Department of Natural Resources
# 844  Washington Department of Natural Resources
# 845  Washington Department of Natural Resources
#
#                               in_RegulatoryDescription  \
# 0    a structured approach to developing a forest p...
# 1    a structured approach to developing a forest p...
# 2    a structured approach to developing a forest p...
# 3    a structured approach to developing a forest p...
# 4    a structured approach to developing a forest p...
# ..                                                 ...
# 841  a structured approach to developing a forest p...
# 842  a structured approach to developing a forest p...
# 843  a structured approach to developing a forest p...
# 844  a structured approach to developing a forest p...
# 845  a structured approach to developing a forest p...
#
#                    in_RegulatoryName in_RegulatoryOverlayNativeID  \
# 0                            S Salmo                          843
# 1           Pend Oreille/Slate Creek                          842
# 2             Cedar Creek/Fish Creek                          819
# 3    Upper Lake Roosevelt/Deep Creek                          821
# 4                          Birch Bay                           26
# ..                               ...                          ...
# 841                  Lannigan Spring                          573
# 842                Upper Green River                          164
# 843                        Big Creek                          576
# 844                       Quartz Mtn                          587
# 845                      Naches Pass                          549
#
#     in_RegulatoryStatusCV in_RegulatoryStatute in_RegulatoryStatuteLink  \
# 0                  Active
# 1                  Active
# 2                  Active
# 3                  Active
# 4                  Active
# ..                    ...                  ...                      ...
# 841                Active
# 842                Active
# 843                Active
# 844                Active
# 845                Active
#
#     in_StatutoryEffectiveDate in_StatutoryEndDate  \
# 0                  1992-08-02
# 1                  1992-08-02
# 2                  1992-08-02
# 3                  1992-08-02
# 4                  1992-08-02
# ..                        ...                 ...
# 841                1992-08-02
# 842                1992-08-02
# 843                1992-08-02
# 844                1992-08-02
# 845                1992-08-02
#
#          in_RegulatoryOverlayTypeCV in_WaterSourceTypeCV
# 0    Watershed Administrative Units        Surface Water
# 1    Watershed Administrative Units        Surface Water
# 2    Watershed Administrative Units        Surface Water
# 3    Watershed Administrative Units        Surface Water
# 4    Watershed Administrative Units        Surface Water
# ..                              ...                  ...
# 841  Watershed Administrative Units        Surface Water
# 842  Watershed Administrative Units        Surface Water
# 843  Watershed Administrative Units        Surface Water
# 844  Watershed Administrative Units        Surface Water
# 845  Watershed Administrative Units        Surface Water
#
# [846 rows x 23 columns]

# %%
# Export out to CSV.
outdf.to_csv('RawInputData/Pre_wdnrMain.zip', compression=dict(method='zip', archive_name='Pre_Main.csv'), index=False)  # The output, save as a zip
goutdf.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
