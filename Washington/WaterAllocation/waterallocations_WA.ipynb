# %%
#!/usr/bin/env python
import pandas as pd
import numpy as np
import os
from datetime import datetime
from dateutil.parser import parse

# %%
# working directory
working_dir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Washington/WaterAllocation"
os.chdir(working_dir)

# %%
# Input files
fileInput1 = "RawInputData/Person_Plus_EXTRACT_FromWRTSnotGWIS.csv" 
fileInput2 = "RawInputData/D_Point_WR_Doc.csv"

# water sources look up
inp_wtrsrs="ProcessedInputData/watersources.csv"

# sites look up
inp_sitdim = 'ProcessedInputData/sites.csv'

#output: water allocation
out_alloc = "ProcessedInputData/waterallocations.csv"

# %%
######## WaDE columns
columns = [
    "MethodUUID",
    "OrganizationUUID",
    "SiteUUID",
    "VariableSpecificUUID",
    "WaterSourceUUID",
    "AllocationAmount",
    "AllocationApplicationDate",
    "AllocationAssociatedConsumptiveUseSiteIDs",
    "AllocationAssociatedWithdrawalSiteIDs",
    "AllocationBasisCV",
    "AllocationChangeApplicationIndicator",
    "AllocationCommunityWaterSupplySystem",
    "AllocationCropDutyAmount",
    "AllocationExpirationDate",
    "AllocationLegalStatusCV",
    "AllocationMaximum",
    "AllocationNativeID",
    "AllocationOwner",
    "AllocationPriorityDate",
    "AllocationSDWISIdentifierCV",
    "AllocationTimeframeEnd",
    "AllocationTimeframeStart",
    "AllocationTypeCV",
    "BeneficialUseCategory",
    "CommunityWaterSupplySystem",
    "CropTypeCV",
    "CustomerTypeCV",
    "DataPublicationDate",
    "DataPublicationDOI",
    "GeneratedPowerCapacityMW",
    "IrrigatedAcreage",
    "IrrigationMethodCV",
    "LegacyAllocationIDs",
    "PopulationServed",
    "PowerType",
    "PrimaryUseCategory",
    "WaterAllocationNativeURL"]

# %%
### target dataFrame

outdf100=pd.DataFrame(columns=columns)

# %%
# Read Inputs and merge tables
print("Reading inputs...")
 
df100 = pd.read_csv(fileInput1, encoding = "ISO-8859-1") #, or alternatively encoding = "utf-8"
print (len(df100.index))

# sites look up
df500 = pd.read_csv(inp_sitdim, encoding = "ISO-8859-1")

# water sources look up
df400 = pd.read_csv(inp_wtrsrs, encoding = "ISO-8859-1")
#drop duplicate rows ---this one is not necessary once the water sources table is refined to remove duplicates
df400 = df400.drop_duplicates(subset=['WaterSourceName', 'WaterSourceTypeCV'])
df400
# Out:
# Reading inputs...
# 489112
#   WaterSourceUUID  WaterSourceNativeID WaterSourceName WaterSourceTypeCV  \
# 0            WA_1                    1     Unspecified      surfaceWater
# 1            WA_2                    2     Unspecified       groundwater
# 2            WA_3                    3     Unspecified         reservoir
# 3            WA_4                    4     Unspecified           Unknown
#
#   WaterQualityIndicatorCV  GNISFeatureNameCV  Geometry
# 0                   Fresh                NaN       NaN
# 1                   Fresh                NaN       NaN
# 2                   Fresh                NaN       NaN
# 3                   Fresh                NaN       NaN

# %%
print("Join to Sites native ID source...")

# DPoint_WR
input_cols = ['D_Point_ID', 'WR_Doc_ID']
df200 = pd.read_csv(fileInput2,encoding = "ISO-8859-1", usecols = input_cols)  
df200.drop_duplicates(inplace=True)

df100=pd.merge(df100, df200, left_on='WR_Doc_ID', right_on='WR_Doc_ID', how='left') #

df100
# Out:
# Join to Sites native ID source...
#         X  Y  OBJECTID  OBJECTID_1  WaRecID  WaRecId_1  WR_Doc_ID  \
# 0       0  0         1     6666660  2132706    2132706    2132706
# 1       0  0         2     6809900  2132706    2132706    2132706
# 2       0  0         3     6811534  2132706    2132706    2132706
# 3       0  0         4     6813072  2132706    2132706    2132706
# 4       0  0         5     6814107  2132706    2132706    2132706
# ...    .. ..       ...         ...      ...        ...        ...
# 562442  0  0    489108     6987142  2283068    2283068    2283068
# 562443  0  0    489109     6991296  2283068    2283068    2283068
# 562444  0  0    489110     6994728  2283068    2283068    2283068
# 562445  0  0    489111     6998881  2283068    2283068    2283068
# 562446  0  0    489112     7002409  2283068    2283068    2283068
#
#         WaRecPhaseId WaRecPhasePartyRoleTypeCode  \
# 0               9971                     Primary
# 1               9971                     Primary
# 2               9971                     Primary
# 3               9971                     Primary
# 4               9971                     Primary
# ...              ...                         ...
# 562442        130323              Former Primary
# 562443        130323                     Primary
# 562444        130323              Former Primary
# 562445        130323                     Primary
# 562446        130323              Former Primary
#
#                   PersonLastOrOrganizationNM  ... WaRecProcessStatusTypeCode  \
# 0              WA Fish & Wildlife Dept - CRO  ...                     Active
# 1              WA Fish & Wildlife Dept - CRO  ...                     Active
# 2              WA Fish & Wildlife Dept - CRO  ...                     Active
# 3              WA Fish & Wildlife Dept - CRO  ...                     Active
# 4              WA Fish & Wildlife Dept - CRO  ...                     Active
# ...                                      ...  ...                        ...
# 562442  Northwest Farm Credit Services FLCA*  ...                   Inactive
# 562443                         CBO Selah LLC  ...                   Inactive
# 562444  Northwest Farm Credit Services FLCA*  ...                   Inactive
# 562445                         CBO Selah LLC  ...                   Inactive
# 562446  Northwest Farm Credit Services FLCA*  ...                   Inactive
#
#        WaRecClaimTypeCode WaRecPhaseTypeCode WaRecPhaseStageTypeCode  \
# 0                     NaN        Certificate                     NaN
# 1                     NaN        Certificate                     NaN
# 2                     NaN        Certificate                     NaN
# 3                     NaN        Certificate                     NaN
# 4                     NaN        Certificate                     NaN
# ...                   ...                ...                     ...
# 562442                NaN             Permit              Superseded
# 562443                NaN             Permit              Superseded
# 562444                NaN             Permit              Superseded
# 562445                NaN             Permit              Superseded
# 562446                NaN             Permit              Superseded
#
#        InstantaneousQuantity AnnualVolumeQuantity IrrigatedAreaQuantity  \
# 0                       12.0                  NaN                   NaN
# 1                       12.0                  NaN                   NaN
# 2                       12.0                  NaN                   NaN
# 3                       12.0                  NaN                   NaN
# 4                       12.0                  NaN                   NaN
# ...                      ...                  ...                   ...
# 562442                1324.0               1041.0                 257.0
# 562443                1324.0               1041.0                 257.0
# 562444                1324.0               1041.0                 257.0
# 562445                1324.0               1041.0                 257.0
# 562446                1324.0               1041.0                 257.0
#
#        InstantaneousUnitCode PurposeOfUseTypeCodes D_Point_ID
# 0                        CFS            FS                NaN
# 1                        CFS            FS                NaN
# 2                        CFS            FS                NaN
# 3                        CFS            FS                NaN
# 4                        CFS            FS                NaN
# ...                      ...                   ...        ...
# 562442                   GPM            IR                NaN
# 562443                   GPM            IR                NaN
# 562444                   GPM            IR                NaN
# 562445                   GPM            IR                NaN
# 562446                   GPM            IR                NaN
#
# [562447 rows x 31 columns]

# %%
# use only unique water rights that may have multiple sites/pds
print("Dropping duplicates...")

df100.drop_duplicates(subset = ['D_Point_ID'], inplace=True)   #
df100 = df100.reset_index(drop=True)

print (len(df100.index))

df100
# Out:
# Dropping duplicates...
# 124637
#         X  Y  OBJECTID  OBJECTID_1  WaRecID  WaRecId_1  WR_Doc_ID  \
# 0       0  0         1     6666660  2132706    2132706    2132706
# 1       0  0       103     2553418  2066186    2066186    2066186
# 2       0  0       105     2499326  2065649    2065649    2065649
# 3       0  0       116     2570635  2141830    2141830    2141830
# 4       0  0       117     2358664  2138520    2138520    2138520
# ...    .. ..       ...         ...      ...        ...        ...
# 124632  0  0    488950     2594706  2256313    2256313    2256313
# 124633  0  0    488951     2388775  2162208    2162208    2162208
# 124634  0  0    488953     2362296  2164480    2164480    2164480
# 124635  0  0    488980     2365722  2186470    2186470    2186470
# 124636  0  0    489071     2534203  2284455    2284455    2284455
#
#         WaRecPhaseId WaRecPhasePartyRoleTypeCode  \
# 0               9971                     Primary
# 1              77477                     Primary
# 2              78847                     Primary
# 3               1040                     Primary
# 4               6084                     Primary
# ...              ...                         ...
# 124632        158582                     Primary
# 124633        252338                     Primary
# 124634        252540                     Primary
# 124635        227904                     Primary
# 124636        128602                     Primary
#
#            PersonLastOrOrganizationNM  ... WaRecProcessStatusTypeCode  \
# 0       WA Fish & Wildlife Dept - CRO  ...                     Active
# 1                              LARSON  ...                     Active
# 2                 W. MARD & S. MILLER  ...                     Active
# 3                           HODIN G M  ...                     Active
# 4                               Leone  ...                     Active
# ...                               ...  ...                        ...
# 124632                         SCHEEL  ...                     Active
# 124633                      BERNHARDT  ...                     Active
# 124634                        MAC KAY  ...                     Active
# 124635                       CAMPBELL  ...                     Active
# 124636                      SUNDSTROM  ...                     Active
#
#        WaRecClaimTypeCode WaRecPhaseTypeCode WaRecPhaseStageTypeCode  \
# 0                     NaN        Certificate                     NaN
# 1                LongForm              Claim                     NaN
# 2               ShortForm              Claim                     NaN
# 3                     NaN        Certificate                     NaN
# 4                     NaN        Certificate                     NaN
# ...                   ...                ...                     ...
# 124632          ShortForm              Claim                     NaN
# 124633          ShortForm              Claim                     NaN
# 124634          ShortForm              Claim                     NaN
# 124635           LongForm              Claim                     NaN
# 124636                NaN        Certificate                     NaN
#
#        InstantaneousQuantity AnnualVolumeQuantity IrrigatedAreaQuantity  \
# 0                       12.0                  NaN                   NaN
# 1                       20.0                  6.0                   0.5
# 2                        NaN                  NaN                   NaN
# 3                      300.0                 36.0                   NaN
# 4                      125.0                 18.0                   NaN
# ...                      ...                  ...                   ...
# 124632                   NaN                  NaN                   NaN
# 124633                   NaN                  NaN                   NaN
# 124634                   NaN                  NaN                   NaN
# 124635                   NaN                  NaN                   NaN
# 124636                   0.0                 51.2                   NaN
#
#        InstantaneousUnitCode PurposeOfUseTypeCodes D_Point_ID
# 0                        CFS            FS                NaN
# 1                        GPM          IR DG          209971.0
# 2                        NaN            DG           630570.0
# 3                        GPM            DM           644800.0
# 4                        GPM            DM           384055.0
# ...                      ...                   ...        ...
# 124632                   NaN            DG           515280.0
# 124633                   NaN        ST DG IR         284603.0
# 124634                   NaN        DG IR ST         275424.0
# 124635                   NaN            ST           292917.0
# 124636                   CFS      ST FR IR WL        100162.0
#
# [124637 rows x 31 columns]

# %%
print("Adding SiteUUID...")

def assignSiteID(colrowValue, df500):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        sitl = df500.loc[df500['SiteNativeID'] == colrowValue, 'SiteUUID']
        #print(sitl)
        #print(sitl.empty)
        if not(sitl.empty):            # check if the series is empty
            outList = ','.join(str(inx) for inx in sitl) #sil.iloc[0]
        else:
            outList = ''
    return outList

df100 = df100.assign(SiteUUID='')  #add new column and make is nan

#Permit Number
df100['SiteUUID'] = df100.apply(lambda row: assignSiteID(row['D_Point_ID'], df500), axis=1)

df100
# Out:
# Adding SiteUUID...
#         X  Y  OBJECTID  OBJECTID_1  WaRecID  WaRecId_1  WR_Doc_ID  \
# 0       0  0         1     6666660  2132706    2132706    2132706
# 1       0  0       103     2553418  2066186    2066186    2066186
# 2       0  0       105     2499326  2065649    2065649    2065649
# 3       0  0       116     2570635  2141830    2141830    2141830
# 4       0  0       117     2358664  2138520    2138520    2138520
# ...    .. ..       ...         ...      ...        ...        ...
# 124632  0  0    488950     2594706  2256313    2256313    2256313
# 124633  0  0    488951     2388775  2162208    2162208    2162208
# 124634  0  0    488953     2362296  2164480    2164480    2164480
# 124635  0  0    488980     2365722  2186470    2186470    2186470
# 124636  0  0    489071     2534203  2284455    2284455    2284455
#
#         WaRecPhaseId WaRecPhasePartyRoleTypeCode  \
# 0               9971                     Primary
# 1              77477                     Primary
# 2              78847                     Primary
# 3               1040                     Primary
# 4               6084                     Primary
# ...              ...                         ...
# 124632        158582                     Primary
# 124633        252338                     Primary
# 124634        252540                     Primary
# 124635        227904                     Primary
# 124636        128602                     Primary
#
#            PersonLastOrOrganizationNM  ... WaRecClaimTypeCode  \
# 0       WA Fish & Wildlife Dept - CRO  ...                NaN
# 1                              LARSON  ...           LongForm
# 2                 W. MARD & S. MILLER  ...          ShortForm
# 3                           HODIN G M  ...                NaN
# 4                               Leone  ...                NaN
# ...                               ...  ...                ...
# 124632                         SCHEEL  ...          ShortForm
# 124633                      BERNHARDT  ...          ShortForm
# 124634                        MAC KAY  ...          ShortForm
# 124635                       CAMPBELL  ...           LongForm
# 124636                      SUNDSTROM  ...                NaN
#
#        WaRecPhaseTypeCode WaRecPhaseStageTypeCode InstantaneousQuantity  \
# 0             Certificate                     NaN                  12.0
# 1                   Claim                     NaN                  20.0
# 2                   Claim                     NaN                   NaN
# 3             Certificate                     NaN                 300.0
# 4             Certificate                     NaN                 125.0
# ...                   ...                     ...                   ...
# 124632              Claim                     NaN                   NaN
# 124633              Claim                     NaN                   NaN
# 124634              Claim                     NaN                   NaN
# 124635              Claim                     NaN                   NaN
# 124636        Certificate                     NaN                   0.0
#
#        AnnualVolumeQuantity IrrigatedAreaQuantity InstantaneousUnitCode  \
# 0                       NaN                   NaN                   CFS
# 1                       6.0                   0.5                   GPM
# 2                       NaN                   NaN                   NaN
# 3                      36.0                   NaN                   GPM
# 4                      18.0                   NaN                   GPM
# ...                     ...                   ...                   ...
# 124632                  NaN                   NaN                   NaN
# 124633                  NaN                   NaN                   NaN
# 124634                  NaN                   NaN                   NaN
# 124635                  NaN                   NaN                   NaN
# 124636                 51.2                   NaN                   CFS
#
#        PurposeOfUseTypeCodes D_Point_ID   SiteUUID
# 0                 FS                NaN
# 1               IR DG          209971.0    WA_2195
# 2                 DG           630570.0   WA_20397
# 3                 DM           644800.0   WA_46066
# 4                 DM           384055.0  WA_108331
# ...                      ...        ...        ...
# 124632            DG           515280.0   WA_75638
# 124633        ST DG IR         284603.0  WA_120360
# 124634        DG IR ST         275424.0   WA_61651
# 124635            ST           292917.0  WA_141606
# 124636      ST FR IR WL        100162.0   WA_47981
#
# [124637 rows x 32 columns]

# %%
print("Water sources...")

# water source name is "unspecified" as it is not known
def assignWaterSourceID(colrowValue, df400):
    if colrowValue == '' or pd.isnull(colrowValue):
        colrowValue = 'Unknown'
    ml = df400.loc[df400['WaterSourceTypeCV'] == colrowValue, 'WaterSourceUUID']
    #print(ml.empty)
    if not(ml.empty):            # check if the series is empty
        outList = ml.iloc[0]   # watersourceSer.append(ml.iloc[0])
    else:
        outList = ''
    return outList

df100 = df100.assign(WaterSourceUUID='')

df100 = df100.replace(np.nan, '')

df100['WaterSourceUUID'] = df100.apply(lambda row: 
                        assignWaterSourceID(row['WaRecRCWClassTypeCode'], df400), axis=1)

df100
# Out:
# Water sources...
#         X  Y  OBJECTID  OBJECTID_1  WaRecID  WaRecId_1  WR_Doc_ID  \
# 0       0  0         1     6666660  2132706    2132706    2132706
# 1       0  0       103     2553418  2066186    2066186    2066186
# 2       0  0       105     2499326  2065649    2065649    2065649
# 3       0  0       116     2570635  2141830    2141830    2141830
# 4       0  0       117     2358664  2138520    2138520    2138520
# ...    .. ..       ...         ...      ...        ...        ...
# 124632  0  0    488950     2594706  2256313    2256313    2256313
# 124633  0  0    488951     2388775  2162208    2162208    2162208
# 124634  0  0    488953     2362296  2164480    2164480    2164480
# 124635  0  0    488980     2365722  2186470    2186470    2186470
# 124636  0  0    489071     2534203  2284455    2284455    2284455
#
#         WaRecPhaseId WaRecPhasePartyRoleTypeCode  \
# 0               9971                     Primary
# 1              77477                     Primary
# 2              78847                     Primary
# 3               1040                     Primary
# 4               6084                     Primary
# ...              ...                         ...
# 124632        158582                     Primary
# 124633        252338                     Primary
# 124634        252540                     Primary
# 124635        227904                     Primary
# 124636        128602                     Primary
#
#            PersonLastOrOrganizationNM  ... WaRecPhaseTypeCode  \
# 0       WA Fish & Wildlife Dept - CRO  ...        Certificate
# 1                              LARSON  ...              Claim
# 2                 W. MARD & S. MILLER  ...              Claim
# 3                           HODIN G M  ...        Certificate
# 4                               Leone  ...        Certificate
# ...                               ...  ...                ...
# 124632                         SCHEEL  ...              Claim
# 124633                      BERNHARDT  ...              Claim
# 124634                        MAC KAY  ...              Claim
# 124635                       CAMPBELL  ...              Claim
# 124636                      SUNDSTROM  ...        Certificate
#
#        WaRecPhaseStageTypeCode InstantaneousQuantity AnnualVolumeQuantity  \
# 0                                                 12
# 1                                                 20                    6
# 2
# 3                                                300                   36
# 4                                                125                   18
# ...                        ...                   ...                  ...
# 124632
# 124633
# 124634
# 124635
# 124636                                             0                 51.2
#
#        IrrigatedAreaQuantity InstantaneousUnitCode PurposeOfUseTypeCodes  \
# 0                                              CFS            FS
# 1                        0.5                   GPM          IR DG
# 2                                                             DG
# 3                                              GPM            DM
# 4                                              GPM            DM
# ...                      ...                   ...                   ...
# 124632                                                        DG
# 124633                                                    ST DG IR
# 124634                                                    DG IR ST
# 124635                                                        ST
# 124636                                         CFS      ST FR IR WL
#
#        D_Point_ID   SiteUUID WaterSourceUUID
# 0                                       WA_1
# 1          209971    WA_2195            WA_2
# 2          630570   WA_20397            WA_2
# 3          644800   WA_46066            WA_2
# 4          384055  WA_108331            WA_2
# ...           ...        ...             ...
# 124632     515280   WA_75638            WA_2
# 124633     284603  WA_120360            WA_2
# 124634     275424   WA_61651            WA_2
# 124635     292917  WA_141606            WA_1
# 124636     100162   WA_47981            WA_3
#
# [124637 rows x 33 columns]

# %%
print("Beneficial use categories dictionary and function...")

BenUseDictWA = {
    "508-14":"508-14",
    "AI":"Agricultural Irrigation",
    "CI":"Commercial & indust",
    "CM":"Commercial",
    "CO":"Cooling for indust proces",
    "DC":"Dust Control",
    "DG":"Domestic general",
    "DM":"Domestic multiple",
    "DS":"Domestic single",
    "DY":"Dairy",
    "EN":"Environmental quality",
    "FP":"Frost protection",
    "FR":"Fire protection",
    "FS":"Fish propagation",
    "GP":"Groundwater Preservation",
    "HE":"Heat Exchange",
    "HP":"Heat protection for crops",
    "HW":"Highway",
    "IFlow":"Instream Flow",
    "II":"Individual Irrigation",
    "IR":"Irrigation",
    "IT":"Municipal inter-tie system",
    "IU":"Irrigation Unknown",
    "MI":"Mining",
    "MT":"Mitigation",
    "MU":"Municipal",
    "NR":"No Purpose Identified",
    "OT":"Other",
    "PO":"Power",
    "PR":"Parks and Recreation",
    "RE":"Recreation - beautification",
    "RW":"Railway",
    "SA":"Stream augmentation",
    "SR":"Storage",
    "ST":"Stock water",
    "TS":"Test Well",
    "TW-P":"Trust water, Permanent",
    "TW-T":"Trust water, Temporary",
    "WL":"Wildlife refuge"
}

# Get BenUse based on the field "PurposeOfUseTypeCodes" 
def assignBenUseDictWA(colrowValue):
    # may need to modify capitalization in beneficialUseDictionary
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        keyStr = colrowValue.strip()  # remove whitespace chars
        try:
            benUseListStr = keyStr.split()
            outList = ", ".join(BenUseDictWA[inx] for inx in benUseListStr)
        except:
            outList = ''

    return outList
# Out:
# Beneficial use categories dictionary and function...

# %%
print("Beneficial uses...")

df100 = df100.assign(BeneficialUseCategory='')
df100['BeneficialUseCategory'] = df100.apply(lambda row: 
                                             assignBenUseDictWA(row['PurposeOfUseTypeCodes']),
                                             axis=1)
df100
# Out:
# Beneficial uses...
#         X  Y  OBJECTID  OBJECTID_1  WaRecID  WaRecId_1  WR_Doc_ID  \
# 0       0  0         1     6666660  2132706    2132706    2132706
# 1       0  0       103     2553418  2066186    2066186    2066186
# 2       0  0       105     2499326  2065649    2065649    2065649
# 3       0  0       116     2570635  2141830    2141830    2141830
# 4       0  0       117     2358664  2138520    2138520    2138520
# ...    .. ..       ...         ...      ...        ...        ...
# 124632  0  0    488950     2594706  2256313    2256313    2256313
# 124633  0  0    488951     2388775  2162208    2162208    2162208
# 124634  0  0    488953     2362296  2164480    2164480    2164480
# 124635  0  0    488980     2365722  2186470    2186470    2186470
# 124636  0  0    489071     2534203  2284455    2284455    2284455
#
#         WaRecPhaseId WaRecPhasePartyRoleTypeCode  \
# 0               9971                     Primary
# 1              77477                     Primary
# 2              78847                     Primary
# 3               1040                     Primary
# 4               6084                     Primary
# ...              ...                         ...
# 124632        158582                     Primary
# 124633        252338                     Primary
# 124634        252540                     Primary
# 124635        227904                     Primary
# 124636        128602                     Primary
#
#            PersonLastOrOrganizationNM  ... WaRecPhaseStageTypeCode  \
# 0       WA Fish & Wildlife Dept - CRO  ...
# 1                              LARSON  ...
# 2                 W. MARD & S. MILLER  ...
# 3                           HODIN G M  ...
# 4                               Leone  ...
# ...                               ...  ...                     ...
# 124632                         SCHEEL  ...
# 124633                      BERNHARDT  ...
# 124634                        MAC KAY  ...
# 124635                       CAMPBELL  ...
# 124636                      SUNDSTROM  ...
#
#        InstantaneousQuantity AnnualVolumeQuantity IrrigatedAreaQuantity  \
# 0                         12
# 1                         20                    6                   0.5
# 2
# 3                        300                   36
# 4                        125                   18
# ...                      ...                  ...                   ...
# 124632
# 124633
# 124634
# 124635
# 124636                     0                 51.2
#
#        InstantaneousUnitCode PurposeOfUseTypeCodes D_Point_ID   SiteUUID  \
# 0                        CFS            FS
# 1                        GPM          IR DG            209971    WA_2195
# 2                                       DG             630570   WA_20397
# 3                        GPM            DM             644800   WA_46066
# 4                        GPM            DM             384055  WA_108331
# ...                      ...                   ...        ...        ...
# 124632                                  DG             515280   WA_75638
# 124633                              ST DG IR           284603  WA_120360
# 124634                              DG IR ST           275424   WA_61651
# 124635                                  ST             292917  WA_141606
# 124636                   CFS      ST FR IR WL          100162   WA_47981
#
#        WaterSourceUUID                              BeneficialUseCategory
# 0                 WA_1                                   Fish propagation
# 1                 WA_2                       Irrigation, Domestic general
# 2                 WA_2                                   Domestic general
# 3                 WA_2                                  Domestic multiple
# 4                 WA_2                                  Domestic multiple
# ...                ...                                                ...
# 124632            WA_2                                   Domestic general
# 124633            WA_2          Stock water, Domestic general, Irrigation
# 124634            WA_2          Domestic general, Irrigation, Stock water
# 124635            WA_1                                        Stock water
# 124636            WA_3  Stock water, Fire protection, Irrigation, Wild...
#
# [124637 rows x 34 columns]

# %%
print("AllocationOwner...")

def assignownerName(colrowValue1, colrowValue2):
    if colrowValue1 == '' or pd.isnull(colrowValue1):
        outList1 = ''
    else:
        outList1 = colrowValue1.strip()  # remove whitespace chars
    if colrowValue2 == '' or pd.isnull(colrowValue2):
        outList2 = ''
    else:
        outList2 = colrowValue2.strip()  # remove whitespace chars

    if outList1 == '' and outList2 == '':
        outList = ''
    elif outList1 == '':
        outList = outList2
    elif outList2 == '':
        outList = outList1
    else:
        outList = ", ".join(map(str, [colrowValue1, colrowValue2]))
    return outList

df100 = df100.assign(AllocationOwner='')
df100['AllocationOwner'] = df100.apply(lambda row: 
                                       assignownerName(row['PersonLastOrOrganizationNM'], 
                                                       row['PersonFirstNM']), axis=1)
df100
# Out:
# AllocationOwner...
#         X  Y  OBJECTID  OBJECTID_1  WaRecID  WaRecId_1  WR_Doc_ID  \
# 0       0  0         1     6666660  2132706    2132706    2132706
# 1       0  0       103     2553418  2066186    2066186    2066186
# 2       0  0       105     2499326  2065649    2065649    2065649
# 3       0  0       116     2570635  2141830    2141830    2141830
# 4       0  0       117     2358664  2138520    2138520    2138520
# ...    .. ..       ...         ...      ...        ...        ...
# 124632  0  0    488950     2594706  2256313    2256313    2256313
# 124633  0  0    488951     2388775  2162208    2162208    2162208
# 124634  0  0    488953     2362296  2164480    2164480    2164480
# 124635  0  0    488980     2365722  2186470    2186470    2186470
# 124636  0  0    489071     2534203  2284455    2284455    2284455
#
#         WaRecPhaseId WaRecPhasePartyRoleTypeCode  \
# 0               9971                     Primary
# 1              77477                     Primary
# 2              78847                     Primary
# 3               1040                     Primary
# 4               6084                     Primary
# ...              ...                         ...
# 124632        158582                     Primary
# 124633        252338                     Primary
# 124634        252540                     Primary
# 124635        227904                     Primary
# 124636        128602                     Primary
#
#            PersonLastOrOrganizationNM  ... InstantaneousQuantity  \
# 0       WA Fish & Wildlife Dept - CRO  ...                    12
# 1                              LARSON  ...                    20
# 2                 W. MARD & S. MILLER  ...
# 3                           HODIN G M  ...                   300
# 4                               Leone  ...                   125
# ...                               ...  ...                   ...
# 124632                         SCHEEL  ...
# 124633                      BERNHARDT  ...
# 124634                        MAC KAY  ...
# 124635                       CAMPBELL  ...
# 124636                      SUNDSTROM  ...                     0
#
#        AnnualVolumeQuantity IrrigatedAreaQuantity InstantaneousUnitCode  \
# 0                                                                   CFS
# 1                         6                   0.5                   GPM
# 2
# 3                        36                                         GPM
# 4                        18                                         GPM
# ...                     ...                   ...                   ...
# 124632
# 124633
# 124634
# 124635
# 124636                 51.2                                         CFS
#
#        PurposeOfUseTypeCodes D_Point_ID   SiteUUID WaterSourceUUID  \
# 0                 FS                                          WA_1
# 1               IR DG            209971    WA_2195            WA_2
# 2                 DG             630570   WA_20397            WA_2
# 3                 DM             644800   WA_46066            WA_2
# 4                 DM             384055  WA_108331            WA_2
# ...                      ...        ...        ...             ...
# 124632            DG             515280   WA_75638            WA_2
# 124633        ST DG IR           284603  WA_120360            WA_2
# 124634        DG IR ST           275424   WA_61651            WA_2
# 124635            ST             292917  WA_141606            WA_1
# 124636      ST FR IR WL          100162   WA_47981            WA_3
#
#                                     BeneficialUseCategory  \
# 0                                        Fish propagation
# 1                            Irrigation, Domestic general
# 2                                        Domestic general
# 3                                       Domestic multiple
# 4                                       Domestic multiple
# ...                                                   ...
# 124632                                   Domestic general
# 124633          Stock water, Domestic general, Irrigation
# 124634          Domestic general, Irrigation, Stock water
# 124635                                        Stock water
# 124636  Stock water, Fire protection, Irrigation, Wild...
#
#                       AllocationOwner
# 0       WA Fish & Wildlife Dept - CRO
# 1                   LARSON, ARNOLD V.
# 2                 W. MARD & S. MILLER
# 3                           HODIN G M
# 4                      Leone, Chester
# ...                               ...
# 124632              SCHEEL, NORMAN W.
# 124633            BERNHARDT, RONALD W
# 124634              MAC KAY, DONALD G
# 124635            CAMPBELL, ROBERT H.
# 124636                  SUNDSTROM, AL
#
# [124637 rows x 35 columns]

# %%
print("Allocation priority date...")

# input format 1973-12-07T00:00:00.000
def formatDateString(inString):
    #print(inString)
    try:
        if inString == '' or pd.isnull(inString):
            valndf = ''
        else:
            valD = datetime.strptime(inString, '%Y-%m-%dT00:00:00.000')
            #print(valD)
            valnDd = valD.date()
            #print(valnDd)
            valndf = valnDd.strftime('%m/%d/%Y')
            #print('date:', valndf)
    except:
        valndf = ''

    return valndf

df100 = df100.assign(AllocationPriorityDate='')

df100['AllocationPriorityDate'] = df100.apply(lambda row: formatDateString(row['PriorityDate']), axis=1)

df100
# Out:
# Allocation priority date...
#         X  Y  OBJECTID  OBJECTID_1  WaRecID  WaRecId_1  WR_Doc_ID  \
# 0       0  0         1     6666660  2132706    2132706    2132706
# 1       0  0       103     2553418  2066186    2066186    2066186
# 2       0  0       105     2499326  2065649    2065649    2065649
# 3       0  0       116     2570635  2141830    2141830    2141830
# 4       0  0       117     2358664  2138520    2138520    2138520
# ...    .. ..       ...         ...      ...        ...        ...
# 124632  0  0    488950     2594706  2256313    2256313    2256313
# 124633  0  0    488951     2388775  2162208    2162208    2162208
# 124634  0  0    488953     2362296  2164480    2164480    2164480
# 124635  0  0    488980     2365722  2186470    2186470    2186470
# 124636  0  0    489071     2534203  2284455    2284455    2284455
#
#         WaRecPhaseId WaRecPhasePartyRoleTypeCode  \
# 0               9971                     Primary
# 1              77477                     Primary
# 2              78847                     Primary
# 3               1040                     Primary
# 4               6084                     Primary
# ...              ...                         ...
# 124632        158582                     Primary
# 124633        252338                     Primary
# 124634        252540                     Primary
# 124635        227904                     Primary
# 124636        128602                     Primary
#
#            PersonLastOrOrganizationNM  ... AnnualVolumeQuantity  \
# 0       WA Fish & Wildlife Dept - CRO  ...
# 1                              LARSON  ...                    6
# 2                 W. MARD & S. MILLER  ...
# 3                           HODIN G M  ...                   36
# 4                               Leone  ...                   18
# ...                               ...  ...                  ...
# 124632                         SCHEEL  ...
# 124633                      BERNHARDT  ...
# 124634                        MAC KAY  ...
# 124635                       CAMPBELL  ...
# 124636                      SUNDSTROM  ...                 51.2
#
#        IrrigatedAreaQuantity InstantaneousUnitCode PurposeOfUseTypeCodes  \
# 0                                              CFS            FS
# 1                        0.5                   GPM          IR DG
# 2                                                             DG
# 3                                              GPM            DM
# 4                                              GPM            DM
# ...                      ...                   ...                   ...
# 124632                                                        DG
# 124633                                                    ST DG IR
# 124634                                                    DG IR ST
# 124635                                                        ST
# 124636                                         CFS      ST FR IR WL
#
#        D_Point_ID   SiteUUID WaterSourceUUID  \
# 0                                       WA_1
# 1          209971    WA_2195            WA_2
# 2          630570   WA_20397            WA_2
# 3          644800   WA_46066            WA_2
# 4          384055  WA_108331            WA_2
# ...           ...        ...             ...
# 124632     515280   WA_75638            WA_2
# 124633     284603  WA_120360            WA_2
# 124634     275424   WA_61651            WA_2
# 124635     292917  WA_141606            WA_1
# 124636     100162   WA_47981            WA_3
#
#                                     BeneficialUseCategory  \
# 0                                        Fish propagation
# 1                            Irrigation, Domestic general
# 2                                        Domestic general
# 3                                       Domestic multiple
# 4                                       Domestic multiple
# ...                                                   ...
# 124632                                   Domestic general
# 124633          Stock water, Domestic general, Irrigation
# 124634          Domestic general, Irrigation, Stock water
# 124635                                        Stock water
# 124636  Stock water, Fire protection, Irrigation, Wild...
#
#                       AllocationOwner AllocationPriorityDate
# 0       WA Fish & Wildlife Dept - CRO             12/07/1973
# 1                   LARSON, ARNOLD V.             07/01/1937
# 2                 W. MARD & S. MILLER
# 3                           HODIN G M             07/06/1954
# 4                      Leone, Chester             12/05/1974
# ...                               ...                    ...
# 124632              SCHEEL, NORMAN W.
# 124633            BERNHARDT, RONALD W
# 124634              MAC KAY, DONALD G
# 124635            CAMPBELL, ROBERT H.
# 124636                  SUNDSTROM, AL             05/09/1977
#
# [124637 rows x 36 columns]

# %%
print("AllocationAmount...")

# Check unit from “InstantaneousUnitCode” 
# and leave CFS as is, 
# and convert GPM to CFS for uniformity
def allocAmountUnits(colrowValue1, colrowValue2):
    
    MultiFactor = 1.0
    gpmcfsUnit = colrowValue2.strip()
    
    if gpmcfsUnit == 'GPM':
        MultiFactor = 0.00222800926
    elif gpmcfsUnit == 'GPD':
        MultiFactor = 1.0 / 646317.0
    try:
        outVal = MultiFactor * colrowValue1
    except:
        outVal = colrowValue1
        
    return outVal


df100 = df100.assign(AllocationAmount='')
#make sure it is read as float 
df100[['InstantaneousQuantity']] = df100[['InstantaneousQuantity']].apply(pd.to_numeric)
df100['AllocationAmount'] = df100.apply(lambda row: 
                                        allocAmountUnits(row['InstantaneousQuantity'], 
                                                         row['InstantaneousUnitCode']),
                                        axis=1)

df100
# Out:
# AllocationAmount...
#         X  Y  OBJECTID  OBJECTID_1  WaRecID  WaRecId_1  WR_Doc_ID  \
# 0       0  0         1     6666660  2132706    2132706    2132706
# 1       0  0       103     2553418  2066186    2066186    2066186
# 2       0  0       105     2499326  2065649    2065649    2065649
# 3       0  0       116     2570635  2141830    2141830    2141830
# 4       0  0       117     2358664  2138520    2138520    2138520
# ...    .. ..       ...         ...      ...        ...        ...
# 124632  0  0    488950     2594706  2256313    2256313    2256313
# 124633  0  0    488951     2388775  2162208    2162208    2162208
# 124634  0  0    488953     2362296  2164480    2164480    2164480
# 124635  0  0    488980     2365722  2186470    2186470    2186470
# 124636  0  0    489071     2534203  2284455    2284455    2284455
#
#         WaRecPhaseId WaRecPhasePartyRoleTypeCode  \
# 0               9971                     Primary
# 1              77477                     Primary
# 2              78847                     Primary
# 3               1040                     Primary
# 4               6084                     Primary
# ...              ...                         ...
# 124632        158582                     Primary
# 124633        252338                     Primary
# 124634        252540                     Primary
# 124635        227904                     Primary
# 124636        128602                     Primary
#
#            PersonLastOrOrganizationNM  ... IrrigatedAreaQuantity  \
# 0       WA Fish & Wildlife Dept - CRO  ...
# 1                              LARSON  ...                   0.5
# 2                 W. MARD & S. MILLER  ...
# 3                           HODIN G M  ...
# 4                               Leone  ...
# ...                               ...  ...                   ...
# 124632                         SCHEEL  ...
# 124633                      BERNHARDT  ...
# 124634                        MAC KAY  ...
# 124635                       CAMPBELL  ...
# 124636                      SUNDSTROM  ...
#
#        InstantaneousUnitCode PurposeOfUseTypeCodes D_Point_ID   SiteUUID  \
# 0                        CFS            FS
# 1                        GPM          IR DG            209971    WA_2195
# 2                                       DG             630570   WA_20397
# 3                        GPM            DM             644800   WA_46066
# 4                        GPM            DM             384055  WA_108331
# ...                      ...                   ...        ...        ...
# 124632                                  DG             515280   WA_75638
# 124633                              ST DG IR           284603  WA_120360
# 124634                              DG IR ST           275424   WA_61651
# 124635                                  ST             292917  WA_141606
# 124636                   CFS      ST FR IR WL          100162   WA_47981
#
#        WaterSourceUUID                              BeneficialUseCategory  \
# 0                 WA_1                                   Fish propagation
# 1                 WA_2                       Irrigation, Domestic general
# 2                 WA_2                                   Domestic general
# 3                 WA_2                                  Domestic multiple
# 4                 WA_2                                  Domestic multiple
# ...                ...                                                ...
# 124632            WA_2                                   Domestic general
# 124633            WA_2          Stock water, Domestic general, Irrigation
# 124634            WA_2          Domestic general, Irrigation, Stock water
# 124635            WA_1                                        Stock water
# 124636            WA_3  Stock water, Fire protection, Irrigation, Wild...
#
#                       AllocationOwner AllocationPriorityDate AllocationAmount
# 0       WA Fish & Wildlife Dept - CRO             12/07/1973        12.000000
# 1                   LARSON, ARNOLD V.             07/01/1937         0.044560
# 2                 W. MARD & S. MILLER                                     NaN
# 3                           HODIN G M             07/06/1954         0.668403
# 4                      Leone, Chester             12/05/1974         0.278501
# ...                               ...                    ...              ...
# 124632              SCHEEL, NORMAN W.                                     NaN
# 124633            BERNHARDT, RONALD W                                     NaN
# 124634              MAC KAY, DONALD G                                     NaN
# 124635            CAMPBELL, ROBERT H.                                     NaN
# 124636                  SUNDSTROM, AL             05/09/1977         0.000000
#
# [124637 rows x 37 columns]

# %%
print("Copying all columns...")
#
destCols=["SiteUUID", "WaterSourceUUID", 
          "AllocationNativeID", "AllocationLegalStatusCV", 
          "BeneficialUseCategory", 
          "AllocationOwner", 
          "AllocationTypeCV", 
          "AllocationPriorityDate",
          "AllocationAmount", 
          "AllocationMaximum", 
          "IrrigatedAcreage"]

srsCols=["SiteUUID", "WaterSourceUUID", 
          "WR_Doc_ID", "WaRecProcessStatusTypeCode",
          "BeneficialUseCategory", 
          "AllocationOwner",
          "WaRecPhaseTypeCode", 
          "AllocationPriorityDate", 
          "AllocationAmount",
          "AnnualVolumeQuantity",
          "IrrigatedAreaQuantity"]

outdf100[destCols] = df100[srsCols]

outdf100
# Out:
# Copying all columns...
#        MethodUUID OrganizationUUID   SiteUUID VariableSpecificUUID  \
# 0             NaN              NaN                             NaN
# 1             NaN              NaN    WA_2195                  NaN
# 2             NaN              NaN   WA_20397                  NaN
# 3             NaN              NaN   WA_46066                  NaN
# 4             NaN              NaN  WA_108331                  NaN
# ...           ...              ...        ...                  ...
# 124632        NaN              NaN   WA_75638                  NaN
# 124633        NaN              NaN  WA_120360                  NaN
# 124634        NaN              NaN   WA_61651                  NaN
# 124635        NaN              NaN  WA_141606                  NaN
# 124636        NaN              NaN   WA_47981                  NaN
#
#        WaterSourceUUID  AllocationAmount AllocationApplicationDate  \
# 0                 WA_1         12.000000                       NaN
# 1                 WA_2          0.044560                       NaN
# 2                 WA_2               NaN                       NaN
# 3                 WA_2          0.668403                       NaN
# 4                 WA_2          0.278501                       NaN
# ...                ...               ...                       ...
# 124632            WA_2               NaN                       NaN
# 124633            WA_2               NaN                       NaN
# 124634            WA_2               NaN                       NaN
# 124635            WA_1               NaN                       NaN
# 124636            WA_3          0.000000                       NaN
#
#        AllocationAssociatedConsumptiveUseSiteIDs  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 124632                                       NaN
# 124633                                       NaN
# 124634                                       NaN
# 124635                                       NaN
# 124636                                       NaN
#
#        AllocationAssociatedWithdrawalSiteIDs AllocationBasisCV  ...  \
# 0                                        NaN               NaN  ...
# 1                                        NaN               NaN  ...
# 2                                        NaN               NaN  ...
# 3                                        NaN               NaN  ...
# 4                                        NaN               NaN  ...
# ...                                      ...               ...  ...
# 124632                                   NaN               NaN  ...
# 124633                                   NaN               NaN  ...
# 124634                                   NaN               NaN  ...
# 124635                                   NaN               NaN  ...
# 124636                                   NaN               NaN  ...
#
#        DataPublicationDate DataPublicationDOI GeneratedPowerCapacityMW  \
# 0                      NaN                NaN                      NaN
# 1                      NaN                NaN                      NaN
# 2                      NaN                NaN                      NaN
# 3                      NaN                NaN                      NaN
# 4                      NaN                NaN                      NaN
# ...                    ...                ...                      ...
# 124632                 NaN                NaN                      NaN
# 124633                 NaN                NaN                      NaN
# 124634                 NaN                NaN                      NaN
# 124635                 NaN                NaN                      NaN
# 124636                 NaN                NaN                      NaN
#
#        IrrigatedAcreage IrrigationMethodCV LegacyAllocationIDs  \
# 0                                      NaN                 NaN
# 1                   0.5                NaN                 NaN
# 2                                      NaN                 NaN
# 3                                      NaN                 NaN
# 4                                      NaN                 NaN
# ...                 ...                ...                 ...
# 124632                                 NaN                 NaN
# 124633                                 NaN                 NaN
# 124634                                 NaN                 NaN
# 124635                                 NaN                 NaN
# 124636                                 NaN                 NaN
#
#         PopulationServed PowerType PrimaryUseCategory WaterAllocationNativeURL
# 0                    NaN       NaN                NaN                      NaN
# 1                    NaN       NaN                NaN                      NaN
# 2                    NaN       NaN                NaN                      NaN
# 3                    NaN       NaN                NaN                      NaN
# 4                    NaN       NaN                NaN                      NaN
# ...                  ...       ...                ...                      ...
# 124632               NaN       NaN                NaN                      NaN
# 124633               NaN       NaN                NaN                      NaN
# 124634               NaN       NaN                NaN                      NaN
# 124635               NaN       NaN                NaN                      NaN
# 124636               NaN       NaN                NaN                      NaN
#
# [124637 rows x 37 columns]

# %%
# hard coded
print("Hard coded...")

outdf100.OrganizationUUID = "WSDE"
outdf100.VariableSpecificUUID = "WSDE_Allocation All"
outdf100.MethodUUID = "WSDE_Water Rights"
outdf100.AllocationBasisCV = "Unknown"
outdf100.PrimaryUseCategory = "Irrigation"
outdf100.AllocationTimeframeStart = "01/01"
outdf100.AllocationTimeframeEnd = "12/31"

outdf100.DataPublicationDate = datetime.now().strftime('%m/%d/%Y')    #"10/31/2019" # edit this to the code run date

outdf100
# Out:
# Hard coded...
#                MethodUUID OrganizationUUID   SiteUUID VariableSpecificUUID  \
# 0       WSDE_Water Rights             WSDE             WSDE_Allocation All
# 1       WSDE_Water Rights             WSDE    WA_2195  WSDE_Allocation All
# 2       WSDE_Water Rights             WSDE   WA_20397  WSDE_Allocation All
# 3       WSDE_Water Rights             WSDE   WA_46066  WSDE_Allocation All
# 4       WSDE_Water Rights             WSDE  WA_108331  WSDE_Allocation All
# ...                   ...              ...        ...                  ...
# 124632  WSDE_Water Rights             WSDE   WA_75638  WSDE_Allocation All
# 124633  WSDE_Water Rights             WSDE  WA_120360  WSDE_Allocation All
# 124634  WSDE_Water Rights             WSDE   WA_61651  WSDE_Allocation All
# 124635  WSDE_Water Rights             WSDE  WA_141606  WSDE_Allocation All
# 124636  WSDE_Water Rights             WSDE   WA_47981  WSDE_Allocation All
#
#        WaterSourceUUID  AllocationAmount AllocationApplicationDate  \
# 0                 WA_1         12.000000                       NaN
# 1                 WA_2          0.044560                       NaN
# 2                 WA_2               NaN                       NaN
# 3                 WA_2          0.668403                       NaN
# 4                 WA_2          0.278501                       NaN
# ...                ...               ...                       ...
# 124632            WA_2               NaN                       NaN
# 124633            WA_2               NaN                       NaN
# 124634            WA_2               NaN                       NaN
# 124635            WA_1               NaN                       NaN
# 124636            WA_3          0.000000                       NaN
#
#        AllocationAssociatedConsumptiveUseSiteIDs  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 124632                                       NaN
# 124633                                       NaN
# 124634                                       NaN
# 124635                                       NaN
# 124636                                       NaN
#
#        AllocationAssociatedWithdrawalSiteIDs AllocationBasisCV  ...  \
# 0                                        NaN           Unknown  ...
# 1                                        NaN           Unknown  ...
# 2                                        NaN           Unknown  ...
# 3                                        NaN           Unknown  ...
# 4                                        NaN           Unknown  ...
# ...                                      ...               ...  ...
# 124632                                   NaN           Unknown  ...
# 124633                                   NaN           Unknown  ...
# 124634                                   NaN           Unknown  ...
# 124635                                   NaN           Unknown  ...
# 124636                                   NaN           Unknown  ...
#
#        DataPublicationDate DataPublicationDOI GeneratedPowerCapacityMW  \
# 0               03/09/2020                NaN                      NaN
# 1               03/09/2020                NaN                      NaN
# 2               03/09/2020                NaN                      NaN
# 3               03/09/2020                NaN                      NaN
# 4               03/09/2020                NaN                      NaN
# ...                    ...                ...                      ...
# 124632          03/09/2020                NaN                      NaN
# 124633          03/09/2020                NaN                      NaN
# 124634          03/09/2020                NaN                      NaN
# 124635          03/09/2020                NaN                      NaN
# 124636          03/09/2020                NaN                      NaN
#
#        IrrigatedAcreage IrrigationMethodCV LegacyAllocationIDs  \
# 0                                      NaN                 NaN
# 1                   0.5                NaN                 NaN
# 2                                      NaN                 NaN
# 3                                      NaN                 NaN
# 4                                      NaN                 NaN
# ...                 ...                ...                 ...
# 124632                                 NaN                 NaN
# 124633                                 NaN                 NaN
# 124634                                 NaN                 NaN
# 124635                                 NaN                 NaN
# 124636                                 NaN                 NaN
#
#         PopulationServed PowerType PrimaryUseCategory WaterAllocationNativeURL
# 0                    NaN       NaN         Irrigation                      NaN
# 1                    NaN       NaN         Irrigation                      NaN
# 2                    NaN       NaN         Irrigation                      NaN
# 3                    NaN       NaN         Irrigation                      NaN
# 4                    NaN       NaN         Irrigation                      NaN
# ...                  ...       ...                ...                      ...
# 124632               NaN       NaN         Irrigation                      NaN
# 124633               NaN       NaN         Irrigation                      NaN
# 124634               NaN       NaN         Irrigation                      NaN
# 124635               NaN       NaN         Irrigation                      NaN
# 124636               NaN       NaN         Irrigation                      NaN
#
# [124637 rows x 37 columns]

# %%
print("Droping null allocations...")
# if both Allocation amount and Allocation maximum are empty drop row and save it to a Allocations_missing.csv

outdf100 = outdf100.replace(np.nan, '') #replace blank strings by NaN,
outdf100purge = outdf100.loc[(outdf100["AllocationAmount"] == '') & (outdf100["AllocationMaximum"] == '')]
if len(outdf100purge.index) > 0:
    outdf100purge.to_csv('waterallocations_missing.csv')    #index=False,
    dropIndex = outdf100.loc[(outdf100["AllocationAmount"] == '') & (outdf100["AllocationMaximum"] == '')].index
    outdf100 = outdf100.drop(dropIndex)
    outdf100 = outdf100.reset_index(drop=True)

outdf100
# Out:
# Droping null allocations...
#               MethodUUID OrganizationUUID   SiteUUID VariableSpecificUUID  \
# 0      WSDE_Water Rights             WSDE             WSDE_Allocation All
# 1      WSDE_Water Rights             WSDE    WA_2195  WSDE_Allocation All
# 2      WSDE_Water Rights             WSDE   WA_46066  WSDE_Allocation All
# 3      WSDE_Water Rights             WSDE  WA_108331  WSDE_Allocation All
# 4      WSDE_Water Rights             WSDE   WA_30223  WSDE_Allocation All
# ...                  ...              ...        ...                  ...
# 61550  WSDE_Water Rights             WSDE   WA_56095  WSDE_Allocation All
# 61551  WSDE_Water Rights             WSDE   WA_78680  WSDE_Allocation All
# 61552  WSDE_Water Rights             WSDE   WA_98563  WSDE_Allocation All
# 61553  WSDE_Water Rights             WSDE   WA_63019  WSDE_Allocation All
# 61554  WSDE_Water Rights             WSDE   WA_47981  WSDE_Allocation All
#
#       WaterSourceUUID AllocationAmount AllocationApplicationDate  \
# 0                WA_1               12
# 1                WA_2        0.0445602
# 2                WA_2         0.668403
# 3                WA_2         0.278501
# 4                WA_2          4.45602
# ...               ...              ...                       ...
# 61550            WA_1             0.25
# 61551            WA_1             0.01
# 61552            WA_2         0.891204
# 61553            WA_1            0.075
# 61554            WA_3                0
#
#       AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 61550
# 61551
# 61552
# 61553
# 61554
#
#       AllocationAssociatedWithdrawalSiteIDs AllocationBasisCV  ...  \
# 0                                                     Unknown  ...
# 1                                                     Unknown  ...
# 2                                                     Unknown  ...
# 3                                                     Unknown  ...
# 4                                                     Unknown  ...
# ...                                     ...               ...  ...
# 61550                                                 Unknown  ...
# 61551                                                 Unknown  ...
# 61552                                                 Unknown  ...
# 61553                                                 Unknown  ...
# 61554                                                 Unknown  ...
#
#       DataPublicationDate DataPublicationDOI GeneratedPowerCapacityMW  \
# 0              03/09/2020
# 1              03/09/2020
# 2              03/09/2020
# 3              03/09/2020
# 4              03/09/2020
# ...                   ...                ...                      ...
# 61550          03/09/2020
# 61551          03/09/2020
# 61552          03/09/2020
# 61553          03/09/2020
# 61554          03/09/2020
#
#       IrrigatedAcreage IrrigationMethodCV LegacyAllocationIDs  \
# 0
# 1                  0.5
# 2
# 3
# 4                  250
# ...                ...                ...                 ...
# 61550               25
# 61551
# 61552
# 61553
# 61554
#
#        PopulationServed PowerType PrimaryUseCategory WaterAllocationNativeURL
# 0                                         Irrigation
# 1                                         Irrigation
# 2                                         Irrigation
# 3                                         Irrigation
# 4                                         Irrigation
# ...                 ...       ...                ...                      ...
# 61550                                     Irrigation
# 61551                                     Irrigation
# 61552                                     Irrigation
# 61553                                     Irrigation
# 61554                                     Irrigation
#
# [61555 rows x 37 columns]

# %%
print("Droping null SiteUUIDs...")

outdf100nullID = outdf100.loc[outdf100["SiteUUID"] == '']
if len(outdf100nullID.index) > 0:
    dropIndex = outdf100.loc[outdf100["SiteUUID"] == ''].index
    outdf100 = outdf100.drop(dropIndex)
    outdf100 = outdf100.reset_index(drop=True)

outdf100
# Out:
# Droping null SiteUUIDs...
#               MethodUUID OrganizationUUID   SiteUUID VariableSpecificUUID  \
# 0      WSDE_Water Rights             WSDE    WA_2195  WSDE_Allocation All
# 1      WSDE_Water Rights             WSDE   WA_46066  WSDE_Allocation All
# 2      WSDE_Water Rights             WSDE  WA_108331  WSDE_Allocation All
# 3      WSDE_Water Rights             WSDE   WA_30223  WSDE_Allocation All
# 4      WSDE_Water Rights             WSDE   WA_97966  WSDE_Allocation All
# ...                  ...              ...        ...                  ...
# 61381  WSDE_Water Rights             WSDE   WA_56095  WSDE_Allocation All
# 61382  WSDE_Water Rights             WSDE   WA_78680  WSDE_Allocation All
# 61383  WSDE_Water Rights             WSDE   WA_98563  WSDE_Allocation All
# 61384  WSDE_Water Rights             WSDE   WA_63019  WSDE_Allocation All
# 61385  WSDE_Water Rights             WSDE   WA_47981  WSDE_Allocation All
#
#       WaterSourceUUID AllocationAmount AllocationApplicationDate  \
# 0                WA_2        0.0445602
# 1                WA_2         0.668403
# 2                WA_2         0.278501
# 3                WA_2          4.45602
# 4                WA_2         0.133681
# ...               ...              ...                       ...
# 61381            WA_1             0.25
# 61382            WA_1             0.01
# 61383            WA_2         0.891204
# 61384            WA_1            0.075
# 61385            WA_3                0
#
#       AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 61381
# 61382
# 61383
# 61384
# 61385
#
#       AllocationAssociatedWithdrawalSiteIDs AllocationBasisCV  ...  \
# 0                                                     Unknown  ...
# 1                                                     Unknown  ...
# 2                                                     Unknown  ...
# 3                                                     Unknown  ...
# 4                                                     Unknown  ...
# ...                                     ...               ...  ...
# 61381                                                 Unknown  ...
# 61382                                                 Unknown  ...
# 61383                                                 Unknown  ...
# 61384                                                 Unknown  ...
# 61385                                                 Unknown  ...
#
#       DataPublicationDate DataPublicationDOI GeneratedPowerCapacityMW  \
# 0              03/09/2020
# 1              03/09/2020
# 2              03/09/2020
# 3              03/09/2020
# 4              03/09/2020
# ...                   ...                ...                      ...
# 61381          03/09/2020
# 61382          03/09/2020
# 61383          03/09/2020
# 61384          03/09/2020
# 61385          03/09/2020
#
#       IrrigatedAcreage IrrigationMethodCV LegacyAllocationIDs  \
# 0                  0.5
# 1
# 2
# 3                  250
# 4                   11
# ...                ...                ...                 ...
# 61381               25
# 61382
# 61383
# 61384
# 61385
#
#        PopulationServed PowerType PrimaryUseCategory WaterAllocationNativeURL
# 0                                         Irrigation
# 1                                         Irrigation
# 2                                         Irrigation
# 3                                         Irrigation
# 4                                         Irrigation
# ...                 ...       ...                ...                      ...
# 61381                                     Irrigation
# 61382                                     Irrigation
# 61383                                     Irrigation
# 61384                                     Irrigation
# 61385                                     Irrigation
#
# [61386 rows x 37 columns]

# %%
print("Droping null Priority date...")
outdf100nullPR = outdf100.loc[outdf100["AllocationPriorityDate"] == '']
if len(outdf100nullPR.index) > 0:
    dropIndex = outdf100.loc[outdf100["AllocationPriorityDate"] == ''].index
    outdf100 = outdf100.drop(dropIndex)
    outdf100 = outdf100.reset_index(drop=True)

outdf100
#outdf100nullPR
# Out:
# Droping null Priority date...
#               MethodUUID OrganizationUUID   SiteUUID VariableSpecificUUID  \
# 0      WSDE_Water Rights             WSDE    WA_2195  WSDE_Allocation All
# 1      WSDE_Water Rights             WSDE   WA_46066  WSDE_Allocation All
# 2      WSDE_Water Rights             WSDE  WA_108331  WSDE_Allocation All
# 3      WSDE_Water Rights             WSDE   WA_30223  WSDE_Allocation All
# 4      WSDE_Water Rights             WSDE   WA_97966  WSDE_Allocation All
# ...                  ...              ...        ...                  ...
# 58226  WSDE_Water Rights             WSDE   WA_56095  WSDE_Allocation All
# 58227  WSDE_Water Rights             WSDE   WA_78680  WSDE_Allocation All
# 58228  WSDE_Water Rights             WSDE   WA_98563  WSDE_Allocation All
# 58229  WSDE_Water Rights             WSDE   WA_63019  WSDE_Allocation All
# 58230  WSDE_Water Rights             WSDE   WA_47981  WSDE_Allocation All
#
#       WaterSourceUUID AllocationAmount AllocationApplicationDate  \
# 0                WA_2        0.0445602
# 1                WA_2         0.668403
# 2                WA_2         0.278501
# 3                WA_2          4.45602
# 4                WA_2         0.133681
# ...               ...              ...                       ...
# 58226            WA_1             0.25
# 58227            WA_1             0.01
# 58228            WA_2         0.891204
# 58229            WA_1            0.075
# 58230            WA_3                0
#
#       AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 58226
# 58227
# 58228
# 58229
# 58230
#
#       AllocationAssociatedWithdrawalSiteIDs AllocationBasisCV  ...  \
# 0                                                     Unknown  ...
# 1                                                     Unknown  ...
# 2                                                     Unknown  ...
# 3                                                     Unknown  ...
# 4                                                     Unknown  ...
# ...                                     ...               ...  ...
# 58226                                                 Unknown  ...
# 58227                                                 Unknown  ...
# 58228                                                 Unknown  ...
# 58229                                                 Unknown  ...
# 58230                                                 Unknown  ...
#
#       DataPublicationDate DataPublicationDOI GeneratedPowerCapacityMW  \
# 0              03/09/2020
# 1              03/09/2020
# 2              03/09/2020
# 3              03/09/2020
# 4              03/09/2020
# ...                   ...                ...                      ...
# 58226          03/09/2020
# 58227          03/09/2020
# 58228          03/09/2020
# 58229          03/09/2020
# 58230          03/09/2020
#
#       IrrigatedAcreage IrrigationMethodCV LegacyAllocationIDs  \
# 0                  0.5
# 1
# 2
# 3                  250
# 4                   11
# ...                ...                ...                 ...
# 58226               25
# 58227
# 58228
# 58229
# 58230
#
#        PopulationServed PowerType PrimaryUseCategory WaterAllocationNativeURL
# 0                                         Irrigation
# 1                                         Irrigation
# 2                                         Irrigation
# 3                                         Irrigation
# 4                                         Irrigation
# ...                 ...       ...                ...                      ...
# 58226                                     Irrigation
# 58227                                     Irrigation
# 58228                                     Irrigation
# 58229                                     Irrigation
# 58230                                     Irrigation
#
# [58231 rows x 37 columns]

# %%
print("Droping null WaterSourceUUID ...")

outdf100nullPR = outdf100.loc[outdf100["WaterSourceUUID"] == '']
if len(outdf100nullPR.index) > 0:
    dropIndex = outdf100.loc[outdf100["WaterSourceUUID"] == ''].index
    outdf100 = outdf100.drop(dropIndex)
    outdf100 = outdf100.reset_index(drop=True)
outdf100
# Out:
# Droping null WaterSourceUUID ...
#               MethodUUID OrganizationUUID   SiteUUID VariableSpecificUUID  \
# 0      WSDE_Water Rights             WSDE    WA_2195  WSDE_Allocation All
# 1      WSDE_Water Rights             WSDE   WA_46066  WSDE_Allocation All
# 2      WSDE_Water Rights             WSDE  WA_108331  WSDE_Allocation All
# 3      WSDE_Water Rights             WSDE   WA_30223  WSDE_Allocation All
# 4      WSDE_Water Rights             WSDE   WA_97966  WSDE_Allocation All
# ...                  ...              ...        ...                  ...
# 58226  WSDE_Water Rights             WSDE   WA_56095  WSDE_Allocation All
# 58227  WSDE_Water Rights             WSDE   WA_78680  WSDE_Allocation All
# 58228  WSDE_Water Rights             WSDE   WA_98563  WSDE_Allocation All
# 58229  WSDE_Water Rights             WSDE   WA_63019  WSDE_Allocation All
# 58230  WSDE_Water Rights             WSDE   WA_47981  WSDE_Allocation All
#
#       WaterSourceUUID AllocationAmount AllocationApplicationDate  \
# 0                WA_2        0.0445602
# 1                WA_2         0.668403
# 2                WA_2         0.278501
# 3                WA_2          4.45602
# 4                WA_2         0.133681
# ...               ...              ...                       ...
# 58226            WA_1             0.25
# 58227            WA_1             0.01
# 58228            WA_2         0.891204
# 58229            WA_1            0.075
# 58230            WA_3                0
#
#       AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 58226
# 58227
# 58228
# 58229
# 58230
#
#       AllocationAssociatedWithdrawalSiteIDs AllocationBasisCV  ...  \
# 0                                                     Unknown  ...
# 1                                                     Unknown  ...
# 2                                                     Unknown  ...
# 3                                                     Unknown  ...
# 4                                                     Unknown  ...
# ...                                     ...               ...  ...
# 58226                                                 Unknown  ...
# 58227                                                 Unknown  ...
# 58228                                                 Unknown  ...
# 58229                                                 Unknown  ...
# 58230                                                 Unknown  ...
#
#       DataPublicationDate DataPublicationDOI GeneratedPowerCapacityMW  \
# 0              03/09/2020
# 1              03/09/2020
# 2              03/09/2020
# 3              03/09/2020
# 4              03/09/2020
# ...                   ...                ...                      ...
# 58226          03/09/2020
# 58227          03/09/2020
# 58228          03/09/2020
# 58229          03/09/2020
# 58230          03/09/2020
#
#       IrrigatedAcreage IrrigationMethodCV LegacyAllocationIDs  \
# 0                  0.5
# 1
# 2
# 3                  250
# 4                   11
# ...                ...                ...                 ...
# 58226               25
# 58227
# 58228
# 58229
# 58230
#
#        PopulationServed PowerType PrimaryUseCategory WaterAllocationNativeURL
# 0                                         Irrigation
# 1                                         Irrigation
# 2                                         Irrigation
# 3                                         Irrigation
# 4                                         Irrigation
# ...                 ...       ...                ...                      ...
# 58226                                     Irrigation
# 58227                                     Irrigation
# 58228                                     Irrigation
# 58229                                     Irrigation
# 58230                                     Irrigation
#
# [58231 rows x 37 columns]

# %%
print("Droping duplicates...")
#drop duplicate rows; just make sure

outdf100Duplicated=outdf100.loc[outdf100.duplicated()]
if len(outdf100Duplicated.index) > 0:
    outdf100Duplicated.to_csv("waterallocations_duplicaterows.csv")  # index=False,
    outdf100.drop_duplicates(inplace=True)   #
    outdf100 = outdf100.reset_index(drop=True)

outdf100
# Out:
# Droping duplicates...
#               MethodUUID OrganizationUUID   SiteUUID VariableSpecificUUID  \
# 0      WSDE_Water Rights             WSDE    WA_2195  WSDE_Allocation All
# 1      WSDE_Water Rights             WSDE   WA_46066  WSDE_Allocation All
# 2      WSDE_Water Rights             WSDE  WA_108331  WSDE_Allocation All
# 3      WSDE_Water Rights             WSDE   WA_30223  WSDE_Allocation All
# 4      WSDE_Water Rights             WSDE   WA_97966  WSDE_Allocation All
# ...                  ...              ...        ...                  ...
# 58226  WSDE_Water Rights             WSDE   WA_56095  WSDE_Allocation All
# 58227  WSDE_Water Rights             WSDE   WA_78680  WSDE_Allocation All
# 58228  WSDE_Water Rights             WSDE   WA_98563  WSDE_Allocation All
# 58229  WSDE_Water Rights             WSDE   WA_63019  WSDE_Allocation All
# 58230  WSDE_Water Rights             WSDE   WA_47981  WSDE_Allocation All
#
#       WaterSourceUUID AllocationAmount AllocationApplicationDate  \
# 0                WA_2        0.0445602
# 1                WA_2         0.668403
# 2                WA_2         0.278501
# 3                WA_2          4.45602
# 4                WA_2         0.133681
# ...               ...              ...                       ...
# 58226            WA_1             0.25
# 58227            WA_1             0.01
# 58228            WA_2         0.891204
# 58229            WA_1            0.075
# 58230            WA_3                0
#
#       AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 58226
# 58227
# 58228
# 58229
# 58230
#
#       AllocationAssociatedWithdrawalSiteIDs AllocationBasisCV  ...  \
# 0                                                     Unknown  ...
# 1                                                     Unknown  ...
# 2                                                     Unknown  ...
# 3                                                     Unknown  ...
# 4                                                     Unknown  ...
# ...                                     ...               ...  ...
# 58226                                                 Unknown  ...
# 58227                                                 Unknown  ...
# 58228                                                 Unknown  ...
# 58229                                                 Unknown  ...
# 58230                                                 Unknown  ...
#
#       DataPublicationDate DataPublicationDOI GeneratedPowerCapacityMW  \
# 0              03/09/2020
# 1              03/09/2020
# 2              03/09/2020
# 3              03/09/2020
# 4              03/09/2020
# ...                   ...                ...                      ...
# 58226          03/09/2020
# 58227          03/09/2020
# 58228          03/09/2020
# 58229          03/09/2020
# 58230          03/09/2020
#
#       IrrigatedAcreage IrrigationMethodCV LegacyAllocationIDs  \
# 0                  0.5
# 1
# 2
# 3                  250
# 4                   11
# ...                ...                ...                 ...
# 58226               25
# 58227
# 58228
# 58229
# 58230
#
#        PopulationServed PowerType PrimaryUseCategory WaterAllocationNativeURL
# 0                                         Irrigation
# 1                                         Irrigation
# 2                                         Irrigation
# 3                                         Irrigation
# 4                                         Irrigation
# ...                 ...       ...                ...                      ...
# 58226                                     Irrigation
# 58227                                     Irrigation
# 58228                                     Irrigation
# 58229                                     Irrigation
# 58230                                     Irrigation
#
# [58231 rows x 37 columns]

# %%
print("Checking required is not null...")
# check if any cell of these columns is null

requiredCols = ["OrganizationUUID", "VariableSpecificUUID", "WaterSourceUUID", 
                "MethodUUID", "AllocationPriorityDate"]

outdf100_nullMand = outdf100.loc[(outdf100["OrganizationUUID"] == '') |
                                (outdf100["VariableSpecificUUID"] == '') |
                                (outdf100["WaterSourceUUID"] == '') |
                                (outdf100["MethodUUID"] == '') |
                                (outdf100["AllocationPriorityDate"] == '')]

if(len(outdf100_nullMand.index) > 0):
    outdf100_nullMand.to_csv('ProcessedInputData/waterallocations_mandatoryFieldMissing.csv')  # index=False,
# Out:
# Checking required is not null...

# %%
outdf100.columns
# Out:
# Index(['MethodUUID', 'OrganizationUUID', 'SiteUUID', 'VariableSpecificUUID',
#        'WaterSourceUUID', 'AllocationAmount', 'AllocationApplicationDate',
#        'AllocationAssociatedConsumptiveUseSiteIDs',
#        'AllocationAssociatedWithdrawalSiteIDs', 'AllocationBasisCV',
#        'AllocationChangeApplicationIndicator',
#        'AllocationCommunityWaterSupplySystem', 'AllocationCropDutyAmount',
#        'AllocationExpirationDate', 'AllocationLegalStatusCV',
#        'AllocationMaximum', 'AllocationNativeID', 'AllocationOwner',
#        'AllocationPriorityDate', 'AllocationSDWISIdentifierCV',
#        'AllocationTimeframeEnd', 'AllocationTimeframeStart',
#        'AllocationTypeCV', 'BeneficialUseCategory',
#        'CommunityWaterSupplySystem', 'CropTypeCV', 'CustomerTypeCV',
#        'DataPublicationDate', 'DataPublicationDOI', 'GeneratedPowerCapacityMW',
#        'IrrigatedAcreage', 'IrrigationMethodCV', 'LegacyAllocationIDs',
#        'PopulationServed', 'PowerType', 'PrimaryUseCategory',
#        'WaterAllocationNativeURL'],
#       dtype='object')

# %%
# Solving WaDE 2.0 Upload Issues
############################################################################
#Date Noted: 03/09/2020
#Note: Missing a few columns.
outdf100.DataPublicationDate = "03/09/2020"
outdf100.GeneratedPowerCapacityMW = ''
outdf100.PowerType = ''
outdf100.PrimaryUseCategory = ''

# Date Noted: 03/03/2020
# Note: Insure single 'AllocationNativeID' entry.
print("Joining outdf duplicates based on AllocationNativeID...")
outdf100 = outdf100.groupby('AllocationNativeID', sort=False).agg(lambda x: ','.join([str(elem) for elem in (list(set(x)))])).reset_index()
# Out:
# Joining outdf duplicates based on AllocationNativeID...

# %%
print("Writing outputs...")
#write out
outdf100.to_csv(out_alloc, index=False, encoding = "utf-8")

print("Done Water Allocation")
# Out:
# Writing outputs...
# Done Water Allocation

# %%
outdf100.columns
# Out:
# Index(['AllocationNativeID', 'MethodUUID', 'OrganizationUUID', 'SiteUUID',
#        'VariableSpecificUUID', 'WaterSourceUUID', 'AllocationAmount',
#        'AllocationApplicationDate',
#        'AllocationAssociatedConsumptiveUseSiteIDs',
#        'AllocationAssociatedWithdrawalSiteIDs', 'AllocationBasisCV',
#        'AllocationChangeApplicationIndicator',
#        'AllocationCommunityWaterSupplySystem', 'AllocationCropDutyAmount',
#        'AllocationExpirationDate', 'AllocationLegalStatusCV',
#        'AllocationMaximum', 'AllocationOwner', 'AllocationPriorityDate',
#        'AllocationSDWISIdentifierCV', 'AllocationTimeframeEnd',
#        'AllocationTimeframeStart', 'AllocationTypeCV', 'BeneficialUseCategory',
#        'CommunityWaterSupplySystem', 'CropTypeCV', 'CustomerTypeCV',
#        'DataPublicationDate', 'DataPublicationDOI', 'GeneratedPowerCapacityMW',
#        'IrrigatedAcreage', 'IrrigationMethodCV', 'LegacyAllocationIDs',
#        'PopulationServed', 'PowerType', 'PrimaryUseCategory',
#        'WaterAllocationNativeURL'],
#       dtype='object')
