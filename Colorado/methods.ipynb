# %% [markdown]
# # Methods_dim
# Python code to generate the 'methods.csv' input file to WaDE db

# %%
import numpy as np
import pandas as pd
import os
#from sodapy import *

# %%
# working dir
working_dir = "C:/tsega/jupyterWaDE/csvFiles/"
os.chdir(working_dir)
# input csv
input_csv = 'DWR_Water_Right_-_Net_Amounts.csv'
#output csv
methods_csv = 'methods.csv'

# %%
#read input file
df = pd.read_csv(input_csv)
dfhead=df.head(10)
dfhead
# Out:
#      WDID   Structure Name Structure Type        Water Source   GNIS ID  \
# 0  100501     EMPIRE DITCH          Ditch  SOUTH PLATTE RIVER  201759.0
# 1  100501     EMPIRE DITCH          Ditch  SOUTH PLATTE RIVER  201759.0
# 2  100501     EMPIRE DITCH          Ditch  SOUTH PLATTE RIVER  201759.0
# 3  100503  RIVERSIDE CANAL          Ditch  SOUTH PLATTE RIVER  201759.0
# 4  100503  RIVERSIDE CANAL          Ditch  SOUTH PLATTE RIVER  201759.0
# 5  100503  RIVERSIDE CANAL          Ditch  SOUTH PLATTE RIVER  201759.0
# 6  100503  RIVERSIDE CANAL          Ditch  SOUTH PLATTE RIVER  201759.0
# 7  100503  RIVERSIDE CANAL          Ditch  SOUTH PLATTE RIVER  201759.0
# 8  100503  RIVERSIDE CANAL          Ditch  SOUTH PLATTE RIVER  201759.0
# 9  100503  RIVERSIDE CANAL          Ditch  SOUTH PLATTE RIVER  201759.0
#
#    Stream Mile  DIV  WD County  Q10  ... Net Absolute Net Conditional  \
# 0       162.81    1   1   WELD  NaN  ...       612.48             0.0
# 1       162.81    1   1   WELD  NaN  ...       612.48             0.0
# 2       162.81    1   1   WELD  NaN  ...       612.48             0.0
# 3       161.96    1   1   WELD   SW  ...        22.00             0.0
# 4       161.96    1   1   WELD   SW  ...       500.00             0.0
# 5       161.96    1   1   WELD   SW  ...       417.00             0.0
# 6       161.96    1   1   WELD   SW  ...       740.00             0.0
# 7       161.96    1   1   WELD   SW  ...      1000.00             0.0
# 8       161.96    1   1   WELD   SW  ...      1000.00             0.0
# 9       161.96    1   1   WELD   SW  ...         0.00          1000.0
#
#    Net APEX Absolute Net APEX Conditional Decreed Units Seasonal Limits  \
# 0                0.0                  0.0             C              No
# 1                0.0                  0.0             C              No
# 2                0.0                  0.0             C              No
# 3                0.0                  0.0             C              No
# 4                0.0                  0.0             C              No
# 5                0.0                  0.0             C              No
# 6                0.0                  0.0             C              No
# 7                0.0                  0.0             C              No
# 8                0.0                  0.0             C              No
# 9                0.0                  0.0             C              No
#
#                                             Comments                Modified  \
# 0  1409, 889,1142,1490,1648,1774,1886 ABS 11/30/1...  01/03/2013 05:25:00 PM
# 1                     STORAGE IN EMPIRE RES TO GH 30  01/03/2013 05:25:00 PM
# 2                         1885 STORAGE IN EMPIRE RES  01/03/2013 05:25:00 PM
# 3     TR  6-23-1917 SEE PG 47 TFR BK W-8429/90CW189A  11/21/2017 03:13:00 PM
# 4        STORAGE IN RIVERSIDE AND WILDCAT RES W-8429  11/21/2017 03:13:00 PM
# 5  921 ASP 1420,1658,1783 W-8429/90CW189 INTERCEP...  11/21/2017 03:13:00 PM
# 6        STORAGE IN RIVERSIDE AND WILDCAT RES W-8429  11/21/2017 03:13:00 PM
# 7        STORAGE IN RIVERSIDE AND WILDCAT RES W-8429  11/21/2017 03:13:00 PM
# 8                           STORAGE IN RIVERSIDE RES  11/21/2017 03:13:00 PM
# 9                             STORAGE IN WILDCAT RES  11/21/2017 03:13:00 PM
#
#                                     More Information                  Location
# 0  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.378525, -104.483983)
# 1  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.378525, -104.483983)
# 2  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.378525, -104.483983)
# 3  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.379142, -104.468875)
# 4  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.379142, -104.468875)
# 5  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.379142, -104.468875)
# 6  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.379142, -104.468875)
# 7  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.379142, -104.468875)
# 8  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.379142, -104.468875)
# 9  https://dnrweb.state.co.us/cdss/WaterRights/Ne...  (40.379142, -104.468875)
#
# [10 rows x 43 columns]

# %%
#WaDE target column headers
columns=['MethodUUID', 'MethodName', 'MethodDescription', 'MethodNEMILink', 'ApplicableResourceTypeCV',
         'MethodTypeCV', 'DataCoverageValue', 'DataQualityValueCV',	'DataConfidenceValue']

# %%
#output/target data frame
dfout = pd.DataFrame(columns=columns)

# %% [markdown]
# # Target mapping
#
# The following column mapping are required based on the mapping document at
# https://docs.google.com/document/d/182bibGX8LSYzsOX6sPrxyWtJndu7UGOWjd6KcnFTh7A/edit
#
# outdf.MethodName = 'DiversionTracking'
#
# outdf.MethodDescription = 'Methodology used for tracking diversions in the state of Colorado'
#
# outdf.MethodNEMILink = ''     # leave it blank
#
# outdf.ApplicableResourceTypeCV = 'Allocation'
#
# outdf.MethodTypeCV = 'Water withdrawals'
#
# outdf.DataCoverageValue = ''       # leave it blank
#
# outdf.DataQualityValueCV = ''      # leave it blank
#
# outdf.DataConfidenceValue = ''     # leave it blank

# %%
# the mapping code for Colorado
inpVals = ['CODWR_DiversionTracking','DiversionTracking', 
           'Methodology used for tracking diversions in the state of Colorado', np.nan,
           'Allocation', 'Water withdrawals',
           np.nan, np.nan, np.nan]

outdf100 = pd.DataFrame([inpVals], columns=columns)

# %%
# mapping code for Utah

# %%
#replace blank strings by NaN, if there are any
outdf100 = outdf100.replace('', np.nan)

# %%
# make sure that 'mandatory' fields are not null

# The following fields can not be empty
requiredCols=['MethodUUID', 'MethodName', 'MethodDescription','ApplicableResourceTypeCV','MethodTypeCV']

# find rows where any of these fields is empty
outdf100_nullMand = outdf100.loc[(outdf100["MethodUUID"].isnull()) | (outdf100["MethodName"].isnull()) |
                                (outdf100["MethodDescription"].isnull()) | (outdf100["ApplicableResourceTypeCV"].isnull()) |
                                (outdf100["MethodTypeCV"].isnull())]
#outdf100_nullMand = outdf100.loc[[False | (outdf100[varName].isnull()) for varName in requiredCols]]

# save the rows with a missing mandatory fields
if(len(outdf100_nullMand.index) > 0):
    outdf100_nullMand.to_csv('methods_mandatoryFieldMissing.csv')  # index=False,

#ToDO: purge these cells if there is any missing? 
#For now left to be inspected

# %%
#write output dataframe to csv
outdf100.to_csv(methods_csv, index=False)

print("Done methods")
# Out:
# Done methods
