# %% [markdown]
# # Pre-processing Colorado Site Specific Reservoir and Gage data for WaDE upload.
#
# Notes:
# - Using two different API Colorado CDSS REST web service. 1) [**Division Data**](https://dwr.state.co.us/Rest/GET/Help/Api/GET-api-v2-structures-divrec-waterclasses) api for Division 1-7 site specific information. 2) [**Annual WDID Time Series Data**](https://dwr.state.co.us/Rest/GET/Help/Api/GET-api-v2-structures-divrec-divrecyear) api using sites of interest wdid list produced from Division 1-7.

# %%
# Needed Libararies

# Working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# Visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# Working with API
import requests
import io
import json

# Cleanup
import re
import time
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/Colorado/SS_ReservoirsObservationSites/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## Load Site Data

# %%
# done already

# Query by Division (1-7) to get a full list of WDIDs per division.
# Plug in "division=1" etc into API request.
# Save results as Division1.csv, etc.
# Rinse and Repeat to retreive all data for Divisions 1-7.

# url = "https://dwr.state.co.us/Rest/GET/api/v2/structures/divrec/waterclasses/?division=7&apiKey=wAC6ZmzcPJ30dyy6nYu6jQmG7BBedcem"
# responseD = json.loads(requests.get(url).text)
# LD = responseD['ResultList']

# df_ts = pd.DataFrame()
# for n in range(len(LD)):
#     row = pd.DataFrame([LD[n]])
#     df_ts = df_ts.append(row)
# df_ts

# #Exporting to Finished File
# df_ts.to_csv('Division7.csv', index=False)  # The output

# %%
# Division 1
fileInput = "Success/Division1.csv"
dfs1 = pd.read_csv(fileInput)
print(len(dfs1))
dfs1.head(1)
# Out:
# 50000
# C:\Users\rjame\AppData\Local\Temp\ipykernel_19820\1456464493.py:3: DtypeWarning: Columns (40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs1 = pd.read_csv(fileInput)
#    divrectype availableTimesteps  waterclassNum        wcIdentifier    wdid  \
# 0  DivComment               Year       30100500  0100500 DivComment  100500
#
#    wdidAcctId structureName  wdidAcctName sourceCode sourceDescr  fromWdid  \
# 0         NaN  HOOVER DITCH           NaN        NaN         NaN       NaN
#
#    fromWdidAcctId fromStructureName  fromWdidAcctName useCode useDescr  \
# 0             NaN               NaN               NaN     NaN      NaN
#
#   typeCode typeDescr  groupWdid groupStructureName  toWdid  toWdidAcctId  \
# 0      NaN       NaN        NaN                NaN     NaN           NaN
#
#   toStructureName  toWdidAcctName wcDescr             porStart  \
# 0             NaN             NaN     NaN  1950-10-31T00:00:00
#
#                 porEnd         porLastModified  division  waterDistrict  \
# 0  2019-10-31T00:00:00  2020-09-30T16:00:45.72         1              1
#
#   county             modified availableTimesteps.1         waterSource  \
# 0   WELD  1950-10-31T00:00:00                 Year  SOUTH PLATTE RIVER
#
#    streamMile structureType    gnisId ciuCode  \
# 0      166.09         DITCH  201759.0       A
#
#                                          ciuCodeLong  subdistrict  \
# 0  Active Structure with contemporary diversion r...          NaN
#
#   designatedBasinName managementDistrictName pm township   range  section  \
# 0                 NaN                    NaN  S    5.0 N  64.0 W     15.0
#
#    q10 q40 q160  coordsew coordsewDir  coordsns coordsnsDir      utmX  \
# 0  NaN  SE   NE       NaN         NaN       NaN         NaN  539867.0
#
#         utmY  latdecdeg  longdecdeg
# 0  4472548.0  40.402594 -104.530193

# %%
# Division 2
fileInput = "Success/Division2.csv"
dfs2 = pd.read_csv(fileInput)
print(len(dfs2))
dfs2.head(1)
# Out:
# 50000
# C:\Users\rjame\AppData\Local\Temp\ipykernel_19820\4168285205.py:3: DtypeWarning: Columns (39,40,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs2 = pd.read_csv(fileInput)
#    divrectype availableTimesteps  waterclassNum        wcIdentifier     wdid  \
# 0  DivComment               Year       31000500  1000500 DivComment  1000500
#
#    wdidAcctId       structureName  wdidAcctName sourceCode sourceDescr  \
# 0         NaN  SEVENTY FOUR DITCH           NaN        NaN         NaN
#
#    fromWdid  fromWdidAcctId fromStructureName  fromWdidAcctName useCode  \
# 0       NaN             NaN               NaN               NaN     NaN
#
#   useDescr typeCode typeDescr  groupWdid groupStructureName  toWdid  \
# 0      NaN      NaN       NaN        NaN                NaN     NaN
#
#    toWdidAcctId toStructureName  toWdidAcctName wcDescr             porStart  \
# 0           NaN             NaN             NaN     NaN  1971-10-31T00:00:00
#
#                 porEnd          porLastModified  division  waterDistrict  \
# 0  1978-10-31T00:00:00  2004-06-09T17:09:50.573         2             10
#
#     county             modified     waterSource  streamMile structureType  \
# 0  EL PASO  1971-10-31T00:00:00  MONUMENT CREEK       25.61         DITCH
#
#      gnisId ciuCode                                        ciuCodeLong  \
# 0  193535.0       H  Historical structure only - no longer exists o...
#
#    subdistrict designatedBasinName managementDistrictName pm township   range  \
# 0          NaN                 NaN                    NaN  S   11.0 S  67.0 W
#
#    section  q10 q40 q160  coordsew coordsewDir  coordsns coordsnsDir  \
# 0     15.0  NaN  SE   NW       NaN         NaN       NaN         NaN
#
#        utmX       utmY  latdecdeg  longdecdeg
# 0  510398.2  4327298.6  39.094762 -104.879767

# %%
# Division 3
fileInput = "Success/Division3.csv"
dfs3 = pd.read_csv(fileInput)
print(len(dfs3))
dfs3.head(1)
# Out:
# 21282
#    divrectype  waterclassNum        wcIdentifier     wdid  wdidAcctId  \
# 0  DivComment       32000500  2000500 DivComment  2000500         NaN
#
#   structureName  wdidAcctName sourceCode sourceDescr  fromWdid  \
# 0     ADAMS D 1           NaN        NaN         NaN       NaN
#
#    fromWdidAcctId fromStructureName  fromWdidAcctName useCode useDescr  \
# 0             NaN               NaN               NaN     NaN      NaN
#
#   typeCode typeDescr  groupWdid groupStructureName  toWdid  toWdidAcctId  \
# 0      NaN       NaN        NaN                NaN     NaN           NaN
#
#   toStructureName  toWdidAcctName wcDescr             porStart  \
# 0             NaN             NaN     NaN  1970-10-31T00:00:00
#
#                 porEnd         porLastModified  division  waterDistrict  \
# 0  2013-10-31T00:00:00  2014-04-04T13:51:40.89         3             20
#
#        county             modified availableTimesteps waterSource  streamMile  \
# 0  RIO GRANDE  1970-10-31T00:00:00               Year  RIO GRANDE         NaN
#
#   structureType     gnisId ciuCode  \
# 0         DITCH  1385432.0       U
#
#                                          ciuCodeLong  subdistrict  \
# 0  Active structure but diversion records are not...          NaN
#
#    designatedBasinName  managementDistrictName pm township  range  section  \
# 0                  NaN                     NaN  N   40.0 N  5.0 E     27.0
#
#    q10 q40 q160  coordsew coordsewDir  coordsns coordsnsDir      utmX  \
# 0  NaN  SE   SW       NaN         NaN       NaN         NaN  375104.8
#
#         utmY  latdecdeg  longdecdeg
# 0  4171056.9  37.678221 -106.416346

# %%
# Division 4
fileInput = "Success/Division4.csv"
dfs4 = pd.read_csv(fileInput)
print(len(dfs4))
dfs4.head(1)
# Out:
# 24273
#    divrectype  waterclassNum        wcIdentifier     wdid  wdidAcctId  \
# 0  DivComment       32800500  2800500 DivComment  2800500         NaN
#
#       structureName  wdidAcctName sourceCode sourceDescr  fromWdid  \
# 0  ADAMS NO 1 DITCH           NaN        NaN         NaN       NaN
#
#    fromWdidAcctId fromStructureName  fromWdidAcctName useCode useDescr  \
# 0             NaN               NaN               NaN     NaN      NaN
#
#   typeCode typeDescr  groupWdid groupStructureName  toWdid  toWdidAcctId  \
# 0      NaN       NaN        NaN                NaN     NaN           NaN
#
#   toStructureName  toWdidAcctName wcDescr             porStart  \
# 0             NaN             NaN     NaN  1991-10-31T00:00:00
#
#                 porEnd         porLastModified  division  waterDistrict  \
# 0  1993-10-31T00:00:00  2001-09-26T19:02:08.89         4             28
#
#      county             modified availableTimesteps    waterSource  \
# 0  GUNNISON  1991-10-31T00:00:00               Year  TOMICHI CREEK
#
#    streamMile structureType    gnisId ciuCode  \
# 0        5.62         DITCH  189371.0       A
#
#                                          ciuCodeLong  subdistrict  \
# 0  Active Structure with contemporary diversion r...          NaN
#
#    designatedBasinName  managementDistrictName pm township  range  section  \
# 0                  NaN                     NaN  N   49.0 N  1.0 E      6.0
#
#   q10 q40 q160  coordsew coordsewDir  coordsns coordsnsDir      utmX  \
# 0  SE  SE   NW       NaN         NaN       NaN         NaN  333922.0
#
#         utmY  latdecdeg  longdecdeg
# 0  4267277.0  38.538421 -106.905554

# %%
# Division 5
fileInput = "Success/Division5.csv"
dfs5 = pd.read_csv(fileInput)
print(len(dfs5))
dfs5.head(1)
# Out:
# 50000
# C:\Users\rjame\AppData\Local\Temp\ipykernel_19820\2356719949.py:3: DtypeWarning: Columns (7,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs5 = pd.read_csv(fileInput)
#    divrectype  waterclassNum        wcIdentifier     wdid  wdidAcctId  \
# 0  DivComment       33600501  3600501 DivComment  3600501         NaN
#
#               structureName  wdidAcctName sourceCode sourceDescr  fromWdid  \
# 0  ABBETT AND BENNETT DITCH           NaN        NaN         NaN       NaN
#
#    fromWdidAcctId fromStructureName  fromWdidAcctName useCode useDescr  \
# 0             NaN               NaN               NaN     NaN      NaN
#
#   typeCode typeDescr  groupWdid groupStructureName  toWdid  toWdidAcctId  \
# 0      NaN       NaN        NaN                NaN     NaN           NaN
#
#   toStructureName  toWdidAcctName wcDescr             porStart  \
# 0             NaN             NaN     NaN  1967-10-31T00:00:00
#
#                 porEnd          porLastModified  division  waterDistrict  \
# 0  2019-10-31T00:00:00  2020-02-04T18:15:49.233         5             36
#
#    county             modified availableTimesteps   waterSource  streamMile  \
# 0  SUMMIT  1967-10-31T00:00:00               Year  SPRUCE CREEK        4.04
#
#   structureType    gnisId ciuCode  \
# 0         DITCH  175604.0       A
#
#                                          ciuCodeLong  subdistrict  \
# 0  Active Structure with contemporary diversion r...          NaN
#
#    designatedBasinName  managementDistrictName pm township   range  section  \
# 0                  NaN                     NaN  S    2.0 S  81.0 W      2.0
#
#    q10 q40 q160  coordsew coordsewDir  coordsns coordsnsDir      utmX  \
# 0  NaN  NW   SE       NaN         NaN       NaN         NaN  378567.0
#
#         utmY  latdecdeg  longdecdeg
# 0  4419574.0   39.91757 -106.420881

# %%
# Division 6
fileInput = "Success/Division6.csv"
dfs6 = pd.read_csv(fileInput)
print(len(dfs6))
dfs6.head(1)
# Out:
# 20835
# C:\Users\rjame\AppData\Local\Temp\ipykernel_19820\3786110251.py:3: DtypeWarning: Columns (45) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs6 = pd.read_csv(fileInput)
#    divrectype  waterclassNum        wcIdentifier     wdid  wdidAcctId  \
# 0  DivComment       34300500  4300500 DivComment  4300500         NaN
#
#          structureName  wdidAcctName sourceCode sourceDescr  fromWdid  \
# 0  ADAMS & OWENS DITCH           NaN        NaN         NaN       NaN
#
#    fromWdidAcctId fromStructureName  fromWdidAcctName useCode useDescr  \
# 0             NaN               NaN               NaN     NaN      NaN
#
#   typeCode typeDescr  groupWdid groupStructureName  toWdid  toWdidAcctId  \
# 0      NaN       NaN        NaN                NaN     NaN           NaN
#
#   toStructureName  toWdidAcctName wcDescr             porStart  \
# 0             NaN             NaN     NaN  1977-10-31T00:00:00
#
#                 porEnd         porLastModified  division  waterDistrict  \
# 0  2019-10-31T00:00:00  2020-02-06T12:30:34.11         6             43
#
#        county             modified availableTimesteps waterSource  streamMile  \
# 0  RIO BLANCO  1977-10-31T00:00:00               Year  WEST CREEK        7.66
#
#   structureType    gnisId ciuCode  \
# 0         DITCH  172009.0       A
#
#                                          ciuCodeLong  subdistrict  \
# 0  Active Structure with contemporary diversion r...          NaN
#
#    designatedBasinName  managementDistrictName pm township    range  section  \
# 0                  NaN                     NaN  S    4.0 S  102.0 W     33.0
#
#    q10 q40 q160  coordsew coordsewDir  coordsns coordsnsDir      utmX  \
# 0  NaN  NW   NW       NaN         NaN       NaN         NaN  169228.0
#
#         utmY  latdecdeg  longdecdeg
# 0  4397443.0  39.662817 -108.855604

# %%
# Division 7
fileInput = "Success/Division7.csv"
dfs7 = pd.read_csv(fileInput)
print(len(dfs7))
dfs7.head(1)
# Out:
# 29123
#    divrectype  waterclassNum        wcIdentifier     wdid  wdidAcctId  \
# 0  DivComment       32900500  2900500 DivComment  2900500         NaN
#
#          structureName  wdidAcctName sourceCode sourceDescr  fromWdid  \
# 0  A D ARCHULETA DITCH           NaN        NaN         NaN       NaN
#
#    fromWdidAcctId fromStructureName  fromWdidAcctName useCode useDescr  \
# 0             NaN               NaN               NaN     NaN      NaN
#
#   typeCode typeDescr  groupWdid groupStructureName  toWdid  toWdidAcctId  \
# 0      NaN       NaN        NaN                NaN     NaN           NaN
#
#   toStructureName  toWdidAcctName wcDescr             porStart  \
# 0             NaN             NaN     NaN  1965-10-31T00:00:00
#
#                 porEnd         porLastModified  division  waterDistrict  \
# 0  1979-10-31T00:00:00  2009-06-15T15:20:23.87         7             29
#
#       county             modified availableTimesteps     waterSource  \
# 0  ARCHULETA  1965-10-31T00:00:00               Year  SAN JUAN RIVER
#
#    streamMile structureType     gnisId ciuCode  \
# 0      174.73         DITCH  1454998.0       H
#
#                                          ciuCodeLong  subdistrict  \
# 0  Historical structure only - no longer exists o...          NaN
#
#    designatedBasinName  managementDistrictName pm township  range section  \
# 0                  NaN                     NaN  N   34.0 N  2.0 W      26
#
#    q10 q40 q160  coordsew coordsewDir  coordsns coordsnsDir      utmX  \
# 0  NaN  SE   NW       NaN         NaN       NaN         NaN  318843.9
#
#         utmY  latdecdeg  longdecdeg
# 0  4114927.6  37.163225  -107.04027

# %%
# Concatenate
frames = [dfs1, dfs2, dfs3, dfs4, dfs5, dfs6, dfs7]
dfs = pd.concat(frames)
print(len(dfs))
# Out:
# 245513

# %%
# want DivTotal, Year, and Active Records
dfs = dfs[dfs["divrectype"] == 'DivTotal']
dfs = dfs[dfs["availableTimesteps"] == 'Year']
dfs = dfs[dfs["ciuCode"] == 'A']
print(len(dfs))
# Out:
# 8950

# %%
# fix wdid values that are less then 7 chars long.
def formatWDIDValue(colVal):
    n = str(colVal)
    if len(n) < 7:
        outString = "0" + n
    else:
        outString = n

    return int(outString)
dfs['wdid'] = dfs.apply(lambda row: formatWDIDValue(row['wdid']), axis=1)
dfs['wdid'].unique()
# Out:
# array([ 100539,  100565,  100568, ..., 7807002, 7807003, 7817003],
#       dtype=int64)

# %%
# drop duplicates
dfs = dfs.drop_duplicates(subset='wdid', keep="first").reset_index(drop=True)
print(len(dfs))
dfs.head(1)
# Out:
# 8950
#   divrectype availableTimesteps  waterclassNum                wcIdentifier  \
# 0   DivTotal               Year       10100539  0100539 Total (Diversions)
#
#      wdid  wdidAcctId       structureName  wdidAcctName sourceCode  \
# 0  100539         NaN  MIDDLEMIST DITCH 2           NaN        NaN
#
#   sourceDescr  fromWdid  fromWdidAcctId fromStructureName  fromWdidAcctName  \
# 0         NaN       NaN             NaN               NaN               NaN
#
#   useCode useDescr typeCode typeDescr  groupWdid groupStructureName  toWdid  \
# 0     NaN      NaN      NaN       NaN        NaN                NaN     NaN
#
#    toWdidAcctId toStructureName  toWdidAcctName wcDescr             porStart  \
# 0           NaN             NaN             NaN     NaN  2007-10-31T00:00:00
#
#                 porEnd      porLastModified  division  waterDistrict  county  \
# 0  2007-10-31T00:00:00  2008-04-07T13:22:00         1              1  ELBERT
#
#                  modified availableTimesteps.1       waterSource  streamMile  \
# 0  2011-06-02T08:52:50.99                 Year  MIDDLEMIST CREEK       32.97
#
#   structureType    gnisId ciuCode  \
# 0         DITCH  195017.0       A
#
#                                          ciuCodeLong  subdistrict  \
# 0  Active Structure with contemporary diversion r...          NaN
#
#   designatedBasinName managementDistrictName pm township   range section q10  \
# 0                 NaN                    NaN  S    6.0 S  57.0 W    25.0  SW
#
#   q40 q160  coordsew coordsewDir  coordsns coordsnsDir      utmX       utmY  \
# 0  SW   SW       NaN         NaN       NaN         NaN  609064.0  4372109.0
#
#    latdecdeg  longdecdeg
# 0  39.491687 -103.731685

# %% [markdown]
# ## Retrieve Timeseries info

# %%
# done already

# %%time

# # create wdid list for API
# wdidList = dfs['wdid'].tolist()
# # Split list into catagories that are 100 long. Issue with CO API timing out after too long.
# wdidListB = [wdidList[i:i + 100] for i in range(0, len(wdidList), 100)]

# # Use list of WDIDs (from Division data) as inputs, retreive time series data.

# # Time Series Dataframe
# dfts = pd.DataFrame()

# str2 = "https://dwr.state.co.us/Rest/GET/api/v2/structures/divrec/divrecyear/?wdid="
# str3 = "%2C&apiKey=wAC6ZmzcPJ30dyy6nYu6jQmG7BBedcem"

# for i in range(len(wdidListB)):
#     lstC = wdidListB[i]
#     lstCa = '%2C'.join([str(n) for n in lstC]) 
    
#     url = str2 + lstCa + str3
#     responseD = json.loads(requests.get(url).text)
#     LD = responseD['ResultList']
    
#     for n in range(len(LD)):
#         row = pd.DataFrame([LD[n]])
#         dfts = dfts.append(row)

# print(len(dfts))
# dfts.head()

# %%
# done already

# # Exporting finished time series file for records sake.
# dfts.to_excel('P_TimeSeries.xlsx', index=False)  # The output

# %%
# timeseris data
fileInput = "P_TimeSeries.xlsx"
dfts = pd.read_excel(fileInput)
print(len(dfts))
dfts.head(1)
# Out:
# 232982
#      wdid  waterClassNum                  wcIdentifier measInterval  \
# 0  100539          54342  0100539 S:1 F: U:3 T: G: To:       Annual
#
#    measCount  dataMeasDate  dataValue measUnits obsCode approvalStatus  \
# 0          1          2007       0.92      ACFT       U       Approved
#
#               modified
# 0  2008-04-07T13:22:00

# %%
# use measInterval = 'Annual' data
dfts = dfts[dfts['measInterval'] == "Annual"].reset_index(drop=True)
print(len(dfts))
dfts.head(1)
# Out:
# 231430
#      wdid  waterClassNum                  wcIdentifier measInterval  \
# 0  100539          54342  0100539 S:1 F: U:3 T: G: To:       Annual
#
#    measCount  dataMeasDate  dataValue measUnits obsCode approvalStatus  \
# 0          1          2007       0.92      ACFT       U       Approved
#
#               modified
# 0  2008-04-07T13:22:00

# %% [markdown]
# ## Output DataFrame

# %%
# Merging division & wdid dataframes into one, using left-join.
# need to create a unique join key, use wdid & waterclassNum value.

dfs['key'] = dfs['wdid'].astype(str) + dfs['waterclassNum'].astype(str)
dfts['key'] = dfts['wdid'].astype(str) + dfts['waterClassNum'].astype(str) 

df = pd.merge(dfs, dfts, on='key', how='left')
print(len(df))
df.head()
# Out:
# 105514
#   divrectype availableTimesteps  waterclassNum              wcIdentifier_x  \
# 0   DivTotal               Year       10100539  0100539 Total (Diversions)
# 1   DivTotal               Year       10100565  0100565 Total (Diversions)
# 2   DivTotal               Year       10100565  0100565 Total (Diversions)
# 3   DivTotal               Year       10100565  0100565 Total (Diversions)
# 4   DivTotal               Year       10100565  0100565 Total (Diversions)
#
#    wdid_x  wdidAcctId       structureName  wdidAcctName sourceCode  \
# 0  100539         NaN  MIDDLEMIST DITCH 2           NaN        NaN
# 1  100565         NaN       MAGUIRE DITCH           NaN        NaN
# 2  100565         NaN       MAGUIRE DITCH           NaN        NaN
# 3  100565         NaN       MAGUIRE DITCH           NaN        NaN
# 4  100565         NaN       MAGUIRE DITCH           NaN        NaN
#
#   sourceDescr  fromWdid  fromWdidAcctId fromStructureName  fromWdidAcctName  \
# 0         NaN       NaN             NaN               NaN               NaN
# 1         NaN       NaN             NaN               NaN               NaN
# 2         NaN       NaN             NaN               NaN               NaN
# 3         NaN       NaN             NaN               NaN               NaN
# 4         NaN       NaN             NaN               NaN               NaN
#
#   useCode useDescr typeCode typeDescr  groupWdid groupStructureName  toWdid  \
# 0     NaN      NaN      NaN       NaN        NaN                NaN     NaN
# 1     NaN      NaN      NaN       NaN        NaN                NaN     NaN
# 2     NaN      NaN      NaN       NaN        NaN                NaN     NaN
# 3     NaN      NaN      NaN       NaN        NaN                NaN     NaN
# 4     NaN      NaN      NaN       NaN        NaN                NaN     NaN
#
#    toWdidAcctId toStructureName  toWdidAcctName wcDescr             porStart  \
# 0           NaN             NaN             NaN     NaN  2007-10-31T00:00:00
# 1           NaN             NaN             NaN     NaN  1980-10-31T00:00:00
# 2           NaN             NaN             NaN     NaN  1980-10-31T00:00:00
# 3           NaN             NaN             NaN     NaN  1980-10-31T00:00:00
# 4           NaN             NaN             NaN     NaN  1980-10-31T00:00:00
#
#                 porEnd      porLastModified  division  waterDistrict  county  \
# 0  2007-10-31T00:00:00  2008-04-07T13:22:00         1              1  ELBERT
# 1  2010-10-31T00:00:00  2011-03-30T10:41:00         1              1  ELBERT
# 2  2010-10-31T00:00:00  2011-03-30T10:41:00         1              1  ELBERT
# 3  2010-10-31T00:00:00  2011-03-30T10:41:00         1              1  ELBERT
# 4  2010-10-31T00:00:00  2011-03-30T10:41:00         1              1  ELBERT
#
#                modified_x availableTimesteps.1       waterSource  streamMile  \
# 0  2011-06-02T08:52:50.99                 Year  MIDDLEMIST CREEK       32.97
# 1  2011-06-02T08:52:50.99                 Year  WEST BIJOU CREEK       58.16
# 2  2011-06-02T08:52:50.99                 Year  WEST BIJOU CREEK       58.16
# 3  2011-06-02T08:52:50.99                 Year  WEST BIJOU CREEK       58.16
# 4  2011-06-02T08:52:50.99                 Year  WEST BIJOU CREEK       58.16
#
#   structureType    gnisId ciuCode  \
# 0         DITCH  195017.0       A
# 1         DITCH  184779.0       A
# 2         DITCH  184779.0       A
# 3         DITCH  184779.0       A
# 4         DITCH  184779.0       A
#
#                                          ciuCodeLong  subdistrict  \
# 0  Active Structure with contemporary diversion r...          NaN
# 1  Active Structure with contemporary diversion r...          NaN
# 2  Active Structure with contemporary diversion r...          NaN
# 3  Active Structure with contemporary diversion r...          NaN
# 4  Active Structure with contemporary diversion r...          NaN
#
#   designatedBasinName managementDistrictName pm township   range section q10  \
# 0                 NaN                    NaN  S    6.0 S  57.0 W    25.0  SW
# 1         KIOWA-BIJOU                    NaN  S    9.0 S  62.0 W    16.0  SW
# 2         KIOWA-BIJOU                    NaN  S    9.0 S  62.0 W    16.0  SW
# 3         KIOWA-BIJOU                    NaN  S    9.0 S  62.0 W    16.0  SW
# 4         KIOWA-BIJOU                    NaN  S    9.0 S  62.0 W    16.0  SW
#
#   q40 q160  coordsew coordsewDir  coordsns coordsnsDir      utmX       utmY  \
# 0  SW   SW       NaN         NaN       NaN         NaN  609064.0  4372109.0
# 1  NE   NE    1304.0           E     951.0           N  557541.0  4347071.0
# 2  NE   NE    1304.0           E     951.0           N  557541.0  4347071.0
# 3  NE   NE    1304.0           E     951.0           N  557541.0  4347071.0
# 4  NE   NE    1304.0           E     951.0           N  557541.0  4347071.0
#
#    latdecdeg  longdecdeg             key    wdid_y  waterClassNum  \
# 0  39.491687 -103.731685  10053910100539  100539.0     10100539.0
# 1  39.271083 -104.332951  10056510100565  100565.0     10100565.0
# 2  39.271083 -104.332951  10056510100565  100565.0     10100565.0
# 3  39.271083 -104.332951  10056510100565  100565.0     10100565.0
# 4  39.271083 -104.332951  10056510100565  100565.0     10100565.0
#
#               wcIdentifier_y measInterval  measCount  dataMeasDate  dataValue  \
# 0  0100539 Total (Diversion)       Annual        1.0        2007.0       0.92
# 1  0100565 Total (Diversion)       Annual        1.0        1980.0     226.00
# 2  0100565 Total (Diversion)       Annual        1.0        1983.0     800.00
# 3  0100565 Total (Diversion)       Annual        1.0        1984.0     900.00
# 4  0100565 Total (Diversion)       Annual        1.0        1985.0     950.00
#
#   measUnits obsCode approvalStatus           modified_y
# 0      ACFT       U       Approved  2008-04-07T13:22:00
# 1      ACFT       *       Approved  2001-08-16T17:46:00
# 2      ACFT       *       Approved  2001-08-16T17:46:00
# 3      ACFT       *       Approved  2001-08-16T17:46:00
# 4      ACFT       U       Approved  2011-02-21T15:30:00

# %%
dfout = pd.DataFrame(index=df.index)

# Water Source Info
dfout['in_WaterSourceName'] = df['waterSource']
dfout['in_WaterSourceTypeCV'] = df['waterSource']

# Site Info
dfout['in_County'] = df['county']
dfout['in_GNISCodeCV'] = df['gnisId']
dfout['in_Latitude'] = df['latdecdeg'].astype(float)
dfout['in_Longitude'] = df['longdecdeg'].astype(float)
dfout['in_PODorPOUSite'] = "Observation Site"
dfout['in_SiteName'] = df['structureName']
dfout['in_SiteNativeID'] = df['wdid_x']
dfout['in_SiteTypeCV'] = df['structureType']

# Site VariableAmounts Info
dfout['in_Amount'] = df['dataValue'].astype(float)
dfout['in_BeneficialUseCategory'] = "DivTotal"
dfout['in_ReportYearCV'] = df['dataMeasDate']
dfout['in_TimeframeEnd'] = "" # will fill in below with dataMeasDate value
dfout['in_TimeframeStart'] = "" # will fill in below with dataMeasDate value

print(len(dfout))
dfout.head(1)
# Out:
# 105514
#   in_WaterSourceName in_WaterSourceTypeCV in_County  in_GNISCodeCV  \
# 0   MIDDLEMIST CREEK     MIDDLEMIST CREEK    ELBERT       195017.0
#
#    in_Latitude  in_Longitude   in_PODorPOUSite         in_SiteName  \
# 0    39.491687   -103.731685  Observation Site  MIDDLEMIST DITCH 2
#
#    in_SiteNativeID in_SiteTypeCV  in_Amount in_BeneficialUseCategory  \
# 0           100539         DITCH       0.92                 DivTotal
#
#    in_ReportYearCV in_TimeframeEnd in_TimeframeStart
# 0           2007.0

# %% [markdown]
# ## WaDE Custom Elements (due to missing sate info)

# %%
# Create WaterSourceTypeCV
    
def createWaterSourceTypeCV(valA):
    if "GROUNDWATER:" in valA:
        outString = "Groundwater"
    else:
        outString = "Surface Water"
        
    return outString

dfout['in_WaterSourceTypeCV'] = dfout.apply(lambda row: createWaterSourceTypeCV( row['in_WaterSourceTypeCV']), axis=1)
dfout['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater'], dtype=object)

# %%
# %%time
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDECO_WS" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = dfout['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = dfout['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceName'] == A)& 
                                       (dfWaterSourceNativeID['in_WaterSourceTypeCV'] == B), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfout['in_WaterSourceNativeID'] = dfout.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
dfout.head(3)
# Out:
# Wall time: 41 s
#   in_WaterSourceName in_WaterSourceTypeCV in_County  in_GNISCodeCV  \
# 0   MIDDLEMIST CREEK        Surface Water    ELBERT       195017.0
# 1   WEST BIJOU CREEK        Surface Water    ELBERT       184779.0
# 2   WEST BIJOU CREEK        Surface Water    ELBERT       184779.0
#
#    in_Latitude  in_Longitude   in_PODorPOUSite         in_SiteName  \
# 0    39.491687   -103.731685  Observation Site  MIDDLEMIST DITCH 2
# 1    39.271083   -104.332951  Observation Site       MAGUIRE DITCH
# 2    39.271083   -104.332951  Observation Site       MAGUIRE DITCH
#
#    in_SiteNativeID in_SiteTypeCV  in_Amount in_BeneficialUseCategory  \
# 0           100539         DITCH       0.92                 DivTotal
# 1           100565         DITCH     226.00                 DivTotal
# 2           100565         DITCH     800.00                 DivTotal
#
#    in_ReportYearCV in_TimeframeEnd in_TimeframeStart in_WaterSourceNativeID
# 0           2007.0                                               WaDECO_WS1
# 1           1980.0                                               WaDECO_WS2
# 2           1983.0                                               WaDECO_WS2

# %%
def creatVarspec(WST):
    WST = WST.strip()
    outString = "Discharge Flow_Annual_DivTotal_" + WST
    return outString

dfout['in_VariableSpecificCV'] = dfout.apply(lambda row: creatVarspec(row['in_WaterSourceTypeCV']), axis=1)
dfout['in_VariableSpecificCV'].unique()
# Out:
# array(['Discharge Flow_Annual_DivTotal_Surface Water',
#        'Discharge Flow_Annual_DivTotal_Groundwater'], dtype=object)

# %%
# Drop null values of ReportYearCV. Convert to int

dfout = dfout.dropna(subset=['in_ReportYearCV']).reset_index(drop=True)
dfout['in_ReportYearCV'] = dfout['in_ReportYearCV'].astype(int)
print(len(dfout))
dfout.head(1)
# Out:
# 105513
#   in_WaterSourceName in_WaterSourceTypeCV in_County  in_GNISCodeCV  \
# 0   MIDDLEMIST CREEK        Surface Water    ELBERT       195017.0
#
#    in_Latitude  in_Longitude   in_PODorPOUSite         in_SiteName  \
# 0    39.491687   -103.731685  Observation Site  MIDDLEMIST DITCH 2
#
#    in_SiteNativeID in_SiteTypeCV  in_Amount in_BeneficialUseCategory  \
# 0           100539         DITCH       0.92                 DivTotal
#
#    in_ReportYearCV in_TimeframeEnd in_TimeframeStart in_WaterSourceNativeID  \
# 0             2007                                               WaDECO_WS1
#
#                           in_VariableSpecificCV
# 0  Discharge Flow_Annual_DivTotal_Surface Water

# %%
# TimeframeStart & TimeframeEnd

dfout['in_TimeframeStart'] = '01/01/' + dfout['in_ReportYearCV'].astype(str)
dfout['in_TimeframeEnd'] = '12/31/' + dfout['in_ReportYearCV'].astype(str)
dfout.head(1)
# Out:
#   in_WaterSourceName in_WaterSourceTypeCV in_County  in_GNISCodeCV  \
# 0   MIDDLEMIST CREEK        Surface Water    ELBERT       195017.0
#
#    in_Latitude  in_Longitude   in_PODorPOUSite         in_SiteName  \
# 0    39.491687   -103.731685  Observation Site  MIDDLEMIST DITCH 2
#
#    in_SiteNativeID in_SiteTypeCV  in_Amount in_BeneficialUseCategory  \
# 0           100539         DITCH       0.92                 DivTotal
#
#    in_ReportYearCV in_TimeframeEnd in_TimeframeStart in_WaterSourceNativeID  \
# 0             2007      12/31/2007        01/01/2007             WaDECO_WS1
#
#                           in_VariableSpecificCV
# 0  Discharge Flow_Annual_DivTotal_Surface Water

# %%
# in_Latitude & in_Longitude
dfout['in_Latitude'] = pd.to_numeric(dfout['in_Latitude'], errors='coerce').fillna(0)
dfout['in_Longitude'] = pd.to_numeric(dfout['in_Longitude'], errors='coerce').fillna(0)
dfout.head(1)
# Out:
#   in_WaterSourceName in_WaterSourceTypeCV in_County  in_GNISCodeCV  \
# 0   MIDDLEMIST CREEK        Surface Water    ELBERT       195017.0
#
#    in_Latitude  in_Longitude   in_PODorPOUSite         in_SiteName  \
# 0    39.491687   -103.731685  Observation Site  MIDDLEMIST DITCH 2
#
#    in_SiteNativeID in_SiteTypeCV  in_Amount in_BeneficialUseCategory  \
# 0           100539         DITCH       0.92                 DivTotal
#
#    in_ReportYearCV in_TimeframeEnd in_TimeframeStart in_WaterSourceNativeID  \
# 0             2007      12/31/2007        01/01/2007             WaDECO_WS1
#
#                           in_VariableSpecificCV
# 0  Discharge Flow_Annual_DivTotal_Surface Water

# %% [markdown]
# ## Review & Export Output

# %%
dfout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105513 entries, 0 to 105512
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   in_WaterSourceName        105513 non-null  object
#  1   in_WaterSourceTypeCV      105513 non-null  object
#  2   in_County                 105257 non-null  object
#  3   in_GNISCodeCV             58772 non-null   float64
#  4   in_Latitude               105513 non-null  float64
#  5   in_Longitude              105513 non-null  float64
#  6   in_PODorPOUSite           105513 non-null  object
#  7   in_SiteName               105513 non-null  object
#  8   in_SiteNativeID           105513 non-null  int64
#  9   in_SiteTypeCV             105513 non-null  object
#  10  in_Amount                 105513 non-null  float64
#  11  in_BeneficialUseCategory  105513 non-null  object
#  12  in_ReportYearCV           105513 non-null  int32
#  13  in_TimeframeEnd           105513 non-null  object
#  14  in_TimeframeStart         105513 non-null  object
#  15  in_WaterSourceNativeID    105513 non-null  object
#  16  in_VariableSpecificCV     105513 non-null  object
# dtypes: float64(4), int32(1), int64(1), object(11)
# memory usage: 13.3+ MB

# %%
dfout
# Out:
#        in_WaterSourceName in_WaterSourceTypeCV  in_County  in_GNISCodeCV  \
# 0        MIDDLEMIST CREEK        Surface Water     ELBERT       195017.0
# 1        WEST BIJOU CREEK        Surface Water     ELBERT       184779.0
# 2        WEST BIJOU CREEK        Surface Water     ELBERT       184779.0
# 3        WEST BIJOU CREEK        Surface Water     ELBERT       184779.0
# 4        WEST BIJOU CREEK        Surface Water     ELBERT       184779.0
# ...                   ...                  ...        ...            ...
# 105508        DEVIL CREEK        Surface Water  ARCHULETA       184283.0
# 105509        DEVIL CREEK        Surface Water  ARCHULETA       184283.0
# 105510        DEVIL CREEK        Surface Water  ARCHULETA       184283.0
# 105511        DEVIL CREEK        Surface Water  ARCHULETA       184283.0
# 105512        DEVIL CREEK        Surface Water  ARCHULETA       184283.0
#
#         in_Latitude  in_Longitude   in_PODorPOUSite  \
# 0         39.491687   -103.731685  Observation Site
# 1         39.271083   -104.332951  Observation Site
# 2         39.271083   -104.332951  Observation Site
# 3         39.271083   -104.332951  Observation Site
# 4         39.271083   -104.332951  Observation Site
# ...             ...           ...               ...
# 105508    37.238734   -107.233864  Observation Site
# 105509    37.238734   -107.233864  Observation Site
# 105510    37.238734   -107.233864  Observation Site
# 105511    37.238734   -107.233864  Observation Site
# 105512    37.238734   -107.233864  Observation Site
#
#                         in_SiteName  in_SiteNativeID in_SiteTypeCV  in_Amount  \
# 0                MIDDLEMIST DITCH 2           100539         DITCH       0.92
# 1                     MAGUIRE DITCH           100565         DITCH     226.00
# 2                     MAGUIRE DITCH           100565         DITCH     800.00
# 3                     MAGUIRE DITCH           100565         DITCH     900.00
# 4                     MAGUIRE DITCH           100565         DITCH     950.00
# ...                             ...              ...           ...        ...
# 105508  KEYAH GRANDE AUG PLAN REACH          7817003         REACH       3.10
# 105509  KEYAH GRANDE AUG PLAN REACH          7817003         REACH       3.61
# 105510  KEYAH GRANDE AUG PLAN REACH          7817003         REACH       1.92
# 105511  KEYAH GRANDE AUG PLAN REACH          7817003         REACH       3.84
# 105512  KEYAH GRANDE AUG PLAN REACH          7817003         REACH       3.65
#
#        in_BeneficialUseCategory  in_ReportYearCV in_TimeframeEnd  \
# 0                      DivTotal             2007      12/31/2007
# 1                      DivTotal             1980      12/31/1980
# 2                      DivTotal             1983      12/31/1983
# 3                      DivTotal             1984      12/31/1984
# 4                      DivTotal             1985      12/31/1985
# ...                         ...              ...             ...
# 105508                 DivTotal             2017      12/31/2017
# 105509                 DivTotal             2018      12/31/2018
# 105510                 DivTotal             2019      12/31/2019
# 105511                 DivTotal             2020      12/31/2020
# 105512                 DivTotal             2021      12/31/2021
#
#        in_TimeframeStart in_WaterSourceNativeID  \
# 0             01/01/2007             WaDECO_WS1
# 1             01/01/1980             WaDECO_WS2
# 2             01/01/1983             WaDECO_WS2
# 3             01/01/1984             WaDECO_WS2
# 4             01/01/1985             WaDECO_WS2
# ...                  ...                    ...
# 105508        01/01/2017           WaDECO_WS654
# 105509        01/01/2018           WaDECO_WS654
# 105510        01/01/2019           WaDECO_WS654
# 105511        01/01/2020           WaDECO_WS654
# 105512        01/01/2021           WaDECO_WS654
#
#                                in_VariableSpecificCV
# 0       Discharge Flow_Annual_DivTotal_Surface Water
# 1       Discharge Flow_Annual_DivTotal_Surface Water
# 2       Discharge Flow_Annual_DivTotal_Surface Water
# 3       Discharge Flow_Annual_DivTotal_Surface Water
# 4       Discharge Flow_Annual_DivTotal_Surface Water
# ...                                              ...
# 105508  Discharge Flow_Annual_DivTotal_Surface Water
# 105509  Discharge Flow_Annual_DivTotal_Surface Water
# 105510  Discharge Flow_Annual_DivTotal_Surface Water
# 105511  Discharge Flow_Annual_DivTotal_Surface Water
# 105512  Discharge Flow_Annual_DivTotal_Surface Water
#
# [105513 rows x 17 columns]

# %%
# Exporting to Finished File.
dfout.to_csv('P_coSSRGMain.csv', index=False)  # The output
