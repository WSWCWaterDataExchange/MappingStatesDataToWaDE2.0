# %% [markdown]
# # Pre-processing Overlay data for WaDE upload.
# - Purpose: To preprocess state overlay data into one main file for simple DataFrame creation and extraction.

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/WaDE Data Folder/Nebraska/Overlays" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/WaDE Data Folder/Nebraska/Overlays

# %% [markdown]
# ## Overlay Area Data #1

# %%
# Input File
inputFile = "RawInputData/shapefiles/Natural_Resource_District_NRD_Boundaries_20250129.zip"
dfin1 = gpd.read_file(inputFile).replace(np.nan, "")
dfin1['geometry'] = dfin1['geometry'].to_crs(epsg=4326) # Realign Geometry Projection

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin1:
    dfin1['WaDEUUID'] = "ov" + dfin1.index.astype(str)
    dfin1.to_csv('RawInputData/Natural_Resource_District_NRD_Boundaries_20250129.zip', compression=dict(method='zip', archive_name='Natural_Resource_District_NRD_Boundaries_20250129.csv'), index=False)

print(len(dfin1))
dfin1.head()
# Out:
# 23
#    OBJECTID          NRD_Name        NRD_Name_A  NRD_Num   Shape_Leng  \
# 0         1  Lower Republican  LOWER REPUBLICAN       23 605099.76849
# 1         2         Tri-Basin         TRI-BASIN       24 413768.86546
# 2         3       Little Blue       LITTLE BLUE        5 606780.75182
# 3         4    Lower Big Blue    LOWER BIG BLUE        2 438586.07860
# 4         5            Nemaha            NEMAHA       11 606872.26451
#
#    Shape_Le_1  Shape_Area                                           geometry  \
# 0     5.22031     0.67953  POLYGON ((-97.9346 40.0021, -98.17728 40.0024,...
# 1     3.45080     0.41809  POLYGON ((-98.72437 40.68977, -98.72389 40.451...
# 2     5.01537     0.65961  POLYGON ((-97.36873 40.43739, -97.36879 40.350...
# 3     3.49527     0.45064  POLYGON ((-96.74194 40.52312, -96.68493 40.523...
# 4     4.88719     0.67026  POLYGON ((-95.88707 40.72605, -95.88319 40.717...
#
#   WaDEUUID
# 0      ov0
# 1      ov1
# 2      ov2
# 3      ov3
# 4      ov4

# %%
# Create URL
# URL link info was found here: https://www.nrdnet.org/

URLdict = {
"1" : "https://www.lrnrd.org/",
"2" : "https://www.tribasinnrd.org/",
"3" : "http://www.littlebluenrd.org/",
"4" : "http://www.lbbnrd.net",
"5" : "https://www.nemahanrd.org/",
"6" : "http://www.mrnrd.org",
"7" : "http://www.urnrd.org",
"8" : "https://www.lpsnrd.org/",
"9" : "http://www.upperbigblue.org",
"10" : "www.cpnrd.org",
"11" : "http://www.spnrd.org",
"12" : "http://www.tpnrd.org",
"13" : "http://www.lpnnrd.org",
"14" : "http://www.llnrd.org",
"15" : "http://www.npnrd.org",
"16" : "http://www.upperloupnrd.org",
"17" : "http://www.papionrd.org",
"18" : "http://www.lenrd.org",
"19" : "http://www.uenrd.org",
"20" : "https://lcnrd.nebraska.gov/",
"21" : "http://www.lnnrd.org",
"22" : "http://www.mnnrd.org",
"23" : "http://www.unwnrd.org"}

def retrieveURL(valA):
    valA = str(valA).strip()
    if valA == '' or pd.isnull(valA):
        outString = ''
    else:
        String1 = valA
        try:
            outString = URLdict[String1]
        except:
            outString = ''
    return outString


dfin1['in_StatuteLink'] = dfin1.apply(lambda row: retrieveURL(row['OBJECTID']), axis=1)
dfin1.head()
# Out:
#    OBJECTID          NRD_Name        NRD_Name_A  NRD_Num   Shape_Leng  \
# 0         1  Lower Republican  LOWER REPUBLICAN       23 605099.76849
# 1         2         Tri-Basin         TRI-BASIN       24 413768.86546
# 2         3       Little Blue       LITTLE BLUE        5 606780.75182
# 3         4    Lower Big Blue    LOWER BIG BLUE        2 438586.07860
# 4         5            Nemaha            NEMAHA       11 606872.26451
#
#    Shape_Le_1  Shape_Area                                           geometry  \
# 0     5.22031     0.67953  POLYGON ((-97.9346 40.0021, -98.17728 40.0024,...
# 1     3.45080     0.41809  POLYGON ((-98.72437 40.68977, -98.72389 40.451...
# 2     5.01537     0.65961  POLYGON ((-97.36873 40.43739, -97.36879 40.350...
# 3     3.49527     0.45064  POLYGON ((-96.74194 40.52312, -96.68493 40.523...
# 4     4.88719     0.67026  POLYGON ((-95.88707 40.72605, -95.88319 40.717...
#
#   WaDEUUID                 in_StatuteLink
# 0      ov0         https://www.lrnrd.org/
# 1      ov1   https://www.tribasinnrd.org/
# 2      ov2  http://www.littlebluenrd.org/
# 3      ov3          http://www.lbbnrd.net
# 4      ov4     https://www.nemahanrd.org/

# %%
# create output for Overlay Area #1 dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfin1['WaDEUUID']

# Date Info
df['in_Date'] = "01/25/2025"
df['in_Year'] = "2025"

# Organization Info
df['in_OrganizationUUID'] = "NEov_O1"

# ReportingUnit Info
df['in_EPSGCodeCV'] = "4326"
df['in_ReportingUnitName'] = dfin1['NRD_Name_A']
df['in_ReportingUnitNativeID'] = "ne" + dfin1['NRD_Num'].astype(str)
df['in_ReportingUnitProductVersion'] = ""
df['in_ReportingUnitTypeCV'] = "Natural Resources Districts"
df['in_ReportingUnitUpdateDate'] = ""
df['in_StateCV'] = "NE"
df['in_Geometry'] = dfin1['geometry']

# Overlay Info
df['in_OversightAgency'] = dfin1['NRD_Name_A'] + "NRD"
df['in_OverlayDescription'] = "Natural Resources Districts were created to solve flood control, soil erosion, irrigation run-off, and groundwater quantity and quality issues. Nebraska's NRDs are involved in a wide variety of projects and programs to conserve and protect the state's natural resources. NRDs are charged under state law with 12 areas of responsibility including flood control, soil erosion, groundwater management and many others."
df['in_OverlayName'] = dfin1['NRD_Name_A']
df['in_OverlayNativeID'] = dfin1['NRD_Num']
df['in_OverlayStatusCV'] = "Active"
df['in_Statute'] = ""
df['in_StatuteLink'] = dfin1['in_StatuteLink']
df['in_StatutoryEffectiveDate'] = "01/01/1972"
df['in_StatutoryEndDate'] = ""
df['in_OverlayTypeCV'] = "Natural Resources Districts"
df['in_WaterSourceTypeCV'] = "Groundwater"

df = df.drop_duplicates().reset_index(drop=True)
outdf1 = df.copy()
print(len(outdf1))
outdf1.head()
# Out:
# 23
#   WaDEUUID     in_Date in_Year in_OrganizationUUID in_EPSGCodeCV  \
# 0      ov0  01/25/2025    2025             NEov_O1          4326
# 1      ov1  01/25/2025    2025             NEov_O1          4326
# 2      ov2  01/25/2025    2025             NEov_O1          4326
# 3      ov3  01/25/2025    2025             NEov_O1          4326
# 4      ov4  01/25/2025    2025             NEov_O1          4326
#
#   in_ReportingUnitName in_ReportingUnitNativeID  \
# 0     LOWER REPUBLICAN                     ne23
# 1            TRI-BASIN                     ne24
# 2          LITTLE BLUE                      ne5
# 3       LOWER BIG BLUE                      ne2
# 4               NEMAHA                     ne11
#
#   in_ReportingUnitProductVersion       in_ReportingUnitTypeCV  \
# 0                                 Natural Resources Districts
# 1                                 Natural Resources Districts
# 2                                 Natural Resources Districts
# 3                                 Natural Resources Districts
# 4                                 Natural Resources Districts
#
#   in_ReportingUnitUpdateDate in_StateCV  \
# 0                                    NE
# 1                                    NE
# 2                                    NE
# 3                                    NE
# 4                                    NE
#
#                                          in_Geometry   in_OversightAgency  \
# 0  POLYGON ((-97.9346 40.0021, -98.17728 40.0024,...  LOWER REPUBLICANNRD
# 1  POLYGON ((-98.72437 40.68977, -98.72389 40.451...         TRI-BASINNRD
# 2  POLYGON ((-97.36873 40.43739, -97.36879 40.350...       LITTLE BLUENRD
# 3  POLYGON ((-96.74194 40.52312, -96.68493 40.523...    LOWER BIG BLUENRD
# 4  POLYGON ((-95.88707 40.72605, -95.88319 40.717...            NEMAHANRD
#
#                                in_OverlayDescription    in_OverlayName  \
# 0  Natural Resources Districts were created to so...  LOWER REPUBLICAN
# 1  Natural Resources Districts were created to so...         TRI-BASIN
# 2  Natural Resources Districts were created to so...       LITTLE BLUE
# 3  Natural Resources Districts were created to so...    LOWER BIG BLUE
# 4  Natural Resources Districts were created to so...            NEMAHA
#
#    in_OverlayNativeID in_OverlayStatusCV in_Statute  \
# 0                  23             Active
# 1                  24             Active
# 2                   5             Active
# 3                   2             Active
# 4                  11             Active
#
#                   in_StatuteLink in_StatutoryEffectiveDate  \
# 0         https://www.lrnrd.org/                01/01/1972
# 1   https://www.tribasinnrd.org/                01/01/1972
# 2  http://www.littlebluenrd.org/                01/01/1972
# 3          http://www.lbbnrd.net                01/01/1972
# 4     https://www.nemahanrd.org/                01/01/1972
#
#   in_StatutoryEndDate             in_OverlayTypeCV in_WaterSourceTypeCV
# 0                      Natural Resources Districts          Groundwater
# 1                      Natural Resources Districts          Groundwater
# 2                      Natural Resources Districts          Groundwater
# 3                      Natural Resources Districts          Groundwater
# 4                      Natural Resources Districts          Groundwater

# %% [markdown]
# ## Overlay Area #2

# %%
# etc etc,

# %% [markdown]
# ## Concatenate DataFrames together

# %%
# Concatenate dataframes
frames = [outdf1] # list all out dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 23

# %% [markdown]
# ## Clean Data / data types

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_ReportingUnitName'] = outdf.apply(lambda row: ensureEmptyString(row['in_ReportingUnitName']), axis=1)
outdf['in_ReportingUnitName'].unique()
# Out:
# array(['LOWER REPUBLICAN', 'TRI-BASIN', 'LITTLE BLUE', 'LOWER BIG BLUE',
#        'NEMAHA', 'MIDDLE REPUBLICAN', 'UPPER REPUBLICAN',
#        'LOWER PLATTE SOUTH', 'UPPER BIG BLUE', 'CENTRAL PLATTE',
#        'SOUTH PLATTE', 'TWIN PLATTE', 'LOWER PLATTE NORTH', 'LOWER LOUP',
#        'NORTH PLATTE', 'UPPER LOUP', 'PAPIO-MISSOURI RIVER',
#        'LOWER ELKHORN', 'UPPER ELKHORN', 'LEWIS & CLARK',
#        'LOWER NIOBRARA', 'MIDDLE NIOBRARA', 'UPPER NIOBRARA-WHITE'],
#       dtype=object)

# %%
outdf['in_OverlayDescription'] = outdf.apply(lambda row: ensureEmptyString(row['in_OverlayDescription']), axis=1)
outdf['in_OverlayDescription'].unique()
# Out:
# array(["Natural Resources Districts were created to solve flood control, soil erosion, irrigation run-off, and groundwater quantity and quality issues. Nebraska's NRDs are involved in a wide variety of projects and programs to conserve and protect the state's natural resources. NRDs are charged under state law with 12 areas of responsibility including flood control, soil erosion, groundwater management and many others."],
#       dtype=object)

# %%
outdf['in_OverlayName'] = outdf.apply(lambda row: ensureEmptyString(row['in_OverlayName']), axis=1)
outdf['in_OverlayName'].unique()
# Out:
# array(['LOWER REPUBLICAN', 'TRI-BASIN', 'LITTLE BLUE', 'LOWER BIG BLUE',
#        'NEMAHA', 'MIDDLE REPUBLICAN', 'UPPER REPUBLICAN',
#        'LOWER PLATTE SOUTH', 'UPPER BIG BLUE', 'CENTRAL PLATTE',
#        'SOUTH PLATTE', 'TWIN PLATTE', 'LOWER PLATTE NORTH', 'LOWER LOUP',
#        'NORTH PLATTE', 'UPPER LOUP', 'PAPIO-MISSOURI RIVER',
#        'LOWER ELKHORN', 'UPPER ELKHORN', 'LEWIS & CLARK',
#        'LOWER NIOBRARA', 'MIDDLE NIOBRARA', 'UPPER NIOBRARA-WHITE'],
#       dtype=object)

# %%
#Update datatype of StatutoryEffectiveDate to fit WaDE 2.0 structure
outdf['in_StatutoryEffectiveDate'] = pd.to_datetime(outdf['in_StatutoryEffectiveDate'], errors = 'coerce')
outdf['in_StatutoryEffectiveDate'] = pd.to_datetime(outdf['in_StatutoryEffectiveDate'].dt.strftime('%m/%d/%Y'))
outdf['in_StatutoryEffectiveDate'].unique()
# Out:
# <DatetimeArray>
# ['1972-01-01 00:00:00']
# Length: 1, dtype: datetime64[ns]

# %% [markdown]
# # Geometry Data
# - For attaching geometry to overlay reporting unit area info.

# %% [markdown]
# #### Overlay Area #1 shapefile info

# %%
# # Input File / or use same input as above

gdfin1 = outdf.copy()
gdfin1 = gpd.GeoDataFrame(gdfin1, geometry=gdfin1['in_Geometry'], crs="EPSG:4326") # covert to geodataframe
print(len(gdfin1))
gdfin1.head()
# Out:
# 23
#   WaDEUUID     in_Date in_Year in_OrganizationUUID in_EPSGCodeCV  \
# 0      ov0  01/25/2025    2025             NEov_O1          4326
# 1      ov1  01/25/2025    2025             NEov_O1          4326
# 2      ov2  01/25/2025    2025             NEov_O1          4326
# 3      ov3  01/25/2025    2025             NEov_O1          4326
# 4      ov4  01/25/2025    2025             NEov_O1          4326
#
#   in_ReportingUnitName in_ReportingUnitNativeID  \
# 0     LOWER REPUBLICAN                     ne23
# 1            TRI-BASIN                     ne24
# 2          LITTLE BLUE                      ne5
# 3       LOWER BIG BLUE                      ne2
# 4               NEMAHA                     ne11
#
#   in_ReportingUnitProductVersion       in_ReportingUnitTypeCV  \
# 0                                 Natural Resources Districts
# 1                                 Natural Resources Districts
# 2                                 Natural Resources Districts
# 3                                 Natural Resources Districts
# 4                                 Natural Resources Districts
#
#   in_ReportingUnitUpdateDate in_StateCV  \
# 0                                    NE
# 1                                    NE
# 2                                    NE
# 3                                    NE
# 4                                    NE
#
#                                          in_Geometry   in_OversightAgency  \
# 0  POLYGON ((-97.9346 40.0021, -98.17728 40.0024,...  LOWER REPUBLICANNRD
# 1  POLYGON ((-98.72437 40.68977, -98.72389 40.451...         TRI-BASINNRD
# 2  POLYGON ((-97.36873 40.43739, -97.36879 40.350...       LITTLE BLUENRD
# 3  POLYGON ((-96.74194 40.52312, -96.68493 40.523...    LOWER BIG BLUENRD
# 4  POLYGON ((-95.88707 40.72605, -95.88319 40.717...            NEMAHANRD
#
#                                in_OverlayDescription    in_OverlayName  \
# 0  Natural Resources Districts were created to so...  LOWER REPUBLICAN
# 1  Natural Resources Districts were created to so...         TRI-BASIN
# 2  Natural Resources Districts were created to so...       LITTLE BLUE
# 3  Natural Resources Districts were created to so...    LOWER BIG BLUE
# 4  Natural Resources Districts were created to so...            NEMAHA
#
#    in_OverlayNativeID in_OverlayStatusCV in_Statute  \
# 0                  23             Active
# 1                  24             Active
# 2                   5             Active
# 3                   2             Active
# 4                  11             Active
#
#                   in_StatuteLink in_StatutoryEffectiveDate  \
# 0         https://www.lrnrd.org/                1972-01-01
# 1   https://www.tribasinnrd.org/                1972-01-01
# 2  http://www.littlebluenrd.org/                1972-01-01
# 3          http://www.lbbnrd.net                1972-01-01
# 4     https://www.nemahanrd.org/                1972-01-01
#
#   in_StatutoryEndDate             in_OverlayTypeCV in_WaterSourceTypeCV  \
# 0                      Natural Resources Districts          Groundwater
# 1                      Natural Resources Districts          Groundwater
# 2                      Natural Resources Districts          Groundwater
# 3                      Natural Resources Districts          Groundwater
# 4                      Natural Resources Districts          Groundwater
#
#                                             geometry
# 0  POLYGON ((-97.9346 40.0021, -98.17728 40.0024,...
# 1  POLYGON ((-98.72437 40.68977, -98.72389 40.451...
# 2  POLYGON ((-97.36873 40.43739, -97.36879 40.350...
# 3  POLYGON ((-96.74194 40.52312, -96.68493 40.523...
# 4  POLYGON ((-95.88707 40.72605, -95.88319 40.717...

# %%
# plot shape info to map
gdfin1.plot()
# Out:
# <Axes: >

# %%
# create output for Regulatory Area #1 dataframe
df = pd.DataFrame()

columnsList = ['in_ReportingUnitNativeID', 'geometry']
goutdf1 = pd.DataFrame(columns=columnsList, index=gdfin1.index)

goutdf1['in_ReportingUnitNativeID'] =  gdfin1["in_ReportingUnitNativeID"].astype(str)  #in_ReportingUnitNativeID needs to match source from above equivalent dataframe
goutdf1['geometry'] = gdfin1['in_Geometry']
goutdf1 = goutdf1.drop_duplicates().reset_index(drop=True)

# drop geometery from outdf
outdf = outdf.drop(['in_Geometry'], axis=1)


print(len(goutdf1))
goutdf1.head()
# Out:
# 23
#   in_ReportingUnitNativeID                                           geometry
# 0                     ne23  POLYGON ((-97.9346 40.0021, -98.17728 40.0024,...
# 1                     ne24  POLYGON ((-98.72437 40.68977, -98.72389 40.451...
# 2                      ne5  POLYGON ((-97.36873 40.43739, -97.36879 40.350...
# 3                      ne2  POLYGON ((-96.74194 40.52312, -96.68493 40.523...
# 4                     ne11  POLYGON ((-95.88707 40.72605, -95.88319 40.717...

# %% [markdown]
# #### Overlay Area #2 shapefile info

# %%
# etc etc...

# %% [markdown]
# #### Concatenate goutdf shapefile info into single output

# %%
# Concatenate Geometry DataFrames
frames = [goutdf1] # add geoutdf dataframes here
goutdf = pd.concat(frames).reset_index(drop=True)

print(len(goutdf))
goutdf.head()
# Out:
# 23
#   in_ReportingUnitNativeID                                           geometry
# 0                     ne23  POLYGON ((-97.9346 40.0021, -98.17728 40.0024,...
# 1                     ne24  POLYGON ((-98.72437 40.68977, -98.72389 40.451...
# 2                      ne5  POLYGON ((-97.36873 40.43739, -97.36879 40.350...
# 3                      ne2  POLYGON ((-96.74194 40.52312, -96.68493 40.523...
# 4                     ne11  POLYGON ((-95.88707 40.72605, -95.88319 40.717...

# %% [markdown]
# ## Export Data

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   WaDEUUID                        23 non-null     object
#  1   in_Date                         23 non-null     object
#  2   in_Year                         23 non-null     object
#  3   in_OrganizationUUID             23 non-null     object
#  4   in_EPSGCodeCV                   23 non-null     object
#  5   in_ReportingUnitName            23 non-null     object
#  6   in_ReportingUnitNativeID        23 non-null     object
#  7   in_ReportingUnitProductVersion  23 non-null     object
#  8   in_ReportingUnitTypeCV          23 non-null     object
#  9   in_ReportingUnitUpdateDate      23 non-null     object
#  10  in_StateCV                      23 non-null     object
#  11  in_OversightAgency              23 non-null     object
#  12  in_OverlayDescription           23 non-null     object
#  13  in_OverlayName                  23 non-null     object
#  14  in_OverlayNativeID              23 non-null     int32
#  15  in_OverlayStatusCV              23 non-null     object
#  16  in_Statute                      23 non-null     object
#  17  in_StatuteLink                  23 non-null     object
#  18  in_StatutoryEffectiveDate       23 non-null     datetime64[ns]
#  19  in_StatutoryEndDate             23 non-null     object
#  20  in_OverlayTypeCV                23 non-null     object
#  21  in_WaterSourceTypeCV            23 non-null     object
# dtypes: datetime64[ns](1), int32(1), object(20)
# memory usage: 4.0+ KB

# %%
outdf
# Out:
#    WaDEUUID     in_Date in_Year in_OrganizationUUID in_EPSGCodeCV  \
# 0       ov0  01/25/2025    2025             NEov_O1          4326
# 1       ov1  01/25/2025    2025             NEov_O1          4326
# 2       ov2  01/25/2025    2025             NEov_O1          4326
# 3       ov3  01/25/2025    2025             NEov_O1          4326
# 4       ov4  01/25/2025    2025             NEov_O1          4326
# 5       ov5  01/25/2025    2025             NEov_O1          4326
# 6       ov6  01/25/2025    2025             NEov_O1          4326
# 7       ov7  01/25/2025    2025             NEov_O1          4326
# 8       ov8  01/25/2025    2025             NEov_O1          4326
# 9       ov9  01/25/2025    2025             NEov_O1          4326
# 10     ov10  01/25/2025    2025             NEov_O1          4326
# 11     ov11  01/25/2025    2025             NEov_O1          4326
# 12     ov12  01/25/2025    2025             NEov_O1          4326
# 13     ov13  01/25/2025    2025             NEov_O1          4326
# 14     ov14  01/25/2025    2025             NEov_O1          4326
# 15     ov15  01/25/2025    2025             NEov_O1          4326
# 16     ov16  01/25/2025    2025             NEov_O1          4326
# 17     ov17  01/25/2025    2025             NEov_O1          4326
# 18     ov18  01/25/2025    2025             NEov_O1          4326
# 19     ov19  01/25/2025    2025             NEov_O1          4326
# 20     ov20  01/25/2025    2025             NEov_O1          4326
# 21     ov21  01/25/2025    2025             NEov_O1          4326
# 22     ov22  01/25/2025    2025             NEov_O1          4326
#
#     in_ReportingUnitName in_ReportingUnitNativeID  \
# 0       LOWER REPUBLICAN                     ne23
# 1              TRI-BASIN                     ne24
# 2            LITTLE BLUE                      ne5
# 3         LOWER BIG BLUE                      ne2
# 4                 NEMAHA                     ne11
# 5      MIDDLE REPUBLICAN                     ne22
# 6       UPPER REPUBLICAN                     ne21
# 7     LOWER PLATTE SOUTH                     ne20
# 8         UPPER BIG BLUE                      ne1
# 9         CENTRAL PLATTE                     ne18
# 10          SOUTH PLATTE                     ne16
# 11           TWIN PLATTE                     ne17
# 12    LOWER PLATTE NORTH                     ne19
# 13            LOWER LOUP                      ne7
# 14          NORTH PLATTE                     ne15
# 15            UPPER LOUP                      ne6
# 16  PAPIO-MISSOURI RIVER                     ne10
# 17         LOWER ELKHORN                      ne4
# 18         UPPER ELKHORN                      ne3
# 19         LEWIS & CLARK                      ne8
# 20        LOWER NIOBRARA                     ne14
# 21       MIDDLE NIOBRARA                     ne13
# 22  UPPER NIOBRARA-WHITE                     ne12
#
#    in_ReportingUnitProductVersion       in_ReportingUnitTypeCV  \
# 0                                  Natural Resources Districts
# 1                                  Natural Resources Districts
# 2                                  Natural Resources Districts
# 3                                  Natural Resources Districts
# 4                                  Natural Resources Districts
# 5                                  Natural Resources Districts
# 6                                  Natural Resources Districts
# 7                                  Natural Resources Districts
# 8                                  Natural Resources Districts
# 9                                  Natural Resources Districts
# 10                                 Natural Resources Districts
# 11                                 Natural Resources Districts
# 12                                 Natural Resources Districts
# 13                                 Natural Resources Districts
# 14                                 Natural Resources Districts
# 15                                 Natural Resources Districts
# 16                                 Natural Resources Districts
# 17                                 Natural Resources Districts
# 18                                 Natural Resources Districts
# 19                                 Natural Resources Districts
# 20                                 Natural Resources Districts
# 21                                 Natural Resources Districts
# 22                                 Natural Resources Districts
#
#    in_ReportingUnitUpdateDate in_StateCV       in_OversightAgency  \
# 0                                     NE      LOWER REPUBLICANNRD
# 1                                     NE             TRI-BASINNRD
# 2                                     NE           LITTLE BLUENRD
# 3                                     NE        LOWER BIG BLUENRD
# 4                                     NE                NEMAHANRD
# 5                                     NE     MIDDLE REPUBLICANNRD
# 6                                     NE      UPPER REPUBLICANNRD
# 7                                     NE    LOWER PLATTE SOUTHNRD
# 8                                     NE        UPPER BIG BLUENRD
# 9                                     NE        CENTRAL PLATTENRD
# 10                                    NE          SOUTH PLATTENRD
# 11                                    NE           TWIN PLATTENRD
# 12                                    NE    LOWER PLATTE NORTHNRD
# 13                                    NE            LOWER LOUPNRD
# 14                                    NE          NORTH PLATTENRD
# 15                                    NE            UPPER LOUPNRD
# 16                                    NE  PAPIO-MISSOURI RIVERNRD
# 17                                    NE         LOWER ELKHORNNRD
# 18                                    NE         UPPER ELKHORNNRD
# 19                                    NE         LEWIS & CLARKNRD
# 20                                    NE        LOWER NIOBRARANRD
# 21                                    NE       MIDDLE NIOBRARANRD
# 22                                    NE  UPPER NIOBRARA-WHITENRD
#
#                                 in_OverlayDescription        in_OverlayName  \
# 0   Natural Resources Districts were created to so...      LOWER REPUBLICAN
# 1   Natural Resources Districts were created to so...             TRI-BASIN
# 2   Natural Resources Districts were created to so...           LITTLE BLUE
# 3   Natural Resources Districts were created to so...        LOWER BIG BLUE
# 4   Natural Resources Districts were created to so...                NEMAHA
# 5   Natural Resources Districts were created to so...     MIDDLE REPUBLICAN
# 6   Natural Resources Districts were created to so...      UPPER REPUBLICAN
# 7   Natural Resources Districts were created to so...    LOWER PLATTE SOUTH
# 8   Natural Resources Districts were created to so...        UPPER BIG BLUE
# 9   Natural Resources Districts were created to so...        CENTRAL PLATTE
# 10  Natural Resources Districts were created to so...          SOUTH PLATTE
# 11  Natural Resources Districts were created to so...           TWIN PLATTE
# 12  Natural Resources Districts were created to so...    LOWER PLATTE NORTH
# 13  Natural Resources Districts were created to so...            LOWER LOUP
# 14  Natural Resources Districts were created to so...          NORTH PLATTE
# 15  Natural Resources Districts were created to so...            UPPER LOUP
# 16  Natural Resources Districts were created to so...  PAPIO-MISSOURI RIVER
# 17  Natural Resources Districts were created to so...         LOWER ELKHORN
# 18  Natural Resources Districts were created to so...         UPPER ELKHORN
# 19  Natural Resources Districts were created to so...         LEWIS & CLARK
# 20  Natural Resources Districts were created to so...        LOWER NIOBRARA
# 21  Natural Resources Districts were created to so...       MIDDLE NIOBRARA
# 22  Natural Resources Districts were created to so...  UPPER NIOBRARA-WHITE
#
#     in_OverlayNativeID in_OverlayStatusCV in_Statute  \
# 0                   23             Active
# 1                   24             Active
# 2                    5             Active
# 3                    2             Active
# 4                   11             Active
# 5                   22             Active
# 6                   21             Active
# 7                   20             Active
# 8                    1             Active
# 9                   18             Active
# 10                  16             Active
# 11                  17             Active
# 12                  19             Active
# 13                   7             Active
# 14                  15             Active
# 15                   6             Active
# 16                  10             Active
# 17                   4             Active
# 18                   3             Active
# 19                   8             Active
# 20                  14             Active
# 21                  13             Active
# 22                  12             Active
#
#                    in_StatuteLink in_StatutoryEffectiveDate  \
# 0          https://www.lrnrd.org/                1972-01-01
# 1    https://www.tribasinnrd.org/                1972-01-01
# 2   http://www.littlebluenrd.org/                1972-01-01
# 3           http://www.lbbnrd.net                1972-01-01
# 4      https://www.nemahanrd.org/                1972-01-01
# 5            http://www.mrnrd.org                1972-01-01
# 6            http://www.urnrd.org                1972-01-01
# 7         https://www.lpsnrd.org/                1972-01-01
# 8     http://www.upperbigblue.org                1972-01-01
# 9                   www.cpnrd.org                1972-01-01
# 10           http://www.spnrd.org                1972-01-01
# 11           http://www.tpnrd.org                1972-01-01
# 12          http://www.lpnnrd.org                1972-01-01
# 13           http://www.llnrd.org                1972-01-01
# 14           http://www.npnrd.org                1972-01-01
# 15    http://www.upperloupnrd.org                1972-01-01
# 16        http://www.papionrd.org                1972-01-01
# 17           http://www.lenrd.org                1972-01-01
# 18           http://www.uenrd.org                1972-01-01
# 19    https://lcnrd.nebraska.gov/                1972-01-01
# 20           http://www.lnnrd.org                1972-01-01
# 21           http://www.mnnrd.org                1972-01-01
# 22          http://www.unwnrd.org                1972-01-01
#
#    in_StatutoryEndDate             in_OverlayTypeCV in_WaterSourceTypeCV
# 0                       Natural Resources Districts          Groundwater
# 1                       Natural Resources Districts          Groundwater
# 2                       Natural Resources Districts          Groundwater
# 3                       Natural Resources Districts          Groundwater
# 4                       Natural Resources Districts          Groundwater
# 5                       Natural Resources Districts          Groundwater
# 6                       Natural Resources Districts          Groundwater
# 7                       Natural Resources Districts          Groundwater
# 8                       Natural Resources Districts          Groundwater
# 9                       Natural Resources Districts          Groundwater
# 10                      Natural Resources Districts          Groundwater
# 11                      Natural Resources Districts          Groundwater
# 12                      Natural Resources Districts          Groundwater
# 13                      Natural Resources Districts          Groundwater
# 14                      Natural Resources Districts          Groundwater
# 15                      Natural Resources Districts          Groundwater
# 16                      Natural Resources Districts          Groundwater
# 17                      Natural Resources Districts          Groundwater
# 18                      Natural Resources Districts          Groundwater
# 19                      Natural Resources Districts          Groundwater
# 20                      Natural Resources Districts          Groundwater
# 21                      Natural Resources Districts          Groundwater
# 22                      Natural Resources Districts          Groundwater

# %%
goutdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   in_ReportingUnitNativeID  23 non-null     object
#  1   geometry                  23 non-null     geometry
# dtypes: geometry(1), object(1)
# memory usage: 500.0+ bytes

# %%
goutdf
# Out:
#    in_ReportingUnitNativeID                                           geometry
# 0                      ne23  POLYGON ((-97.9346 40.0021, -98.17728 40.0024,...
# 1                      ne24  POLYGON ((-98.72437 40.68977, -98.72389 40.451...
# 2                       ne5  POLYGON ((-97.36873 40.43739, -97.36879 40.350...
# 3                       ne2  POLYGON ((-96.74194 40.52312, -96.68493 40.523...
# 4                      ne11  POLYGON ((-95.88707 40.72605, -95.88319 40.717...
# 5                      ne22  POLYGON ((-100.22341 40.74359, -100.22339 40.7...
# 6                      ne21  POLYGON ((-101.24861 40.91565, -101.24842 40.8...
# 7                      ne20  POLYGON ((-96.32542 41.05987, -96.3192 41.0450...
# 8                       ne1  POLYGON ((-97.00431 41.22004, -97.0047 41.1916...
# 9                      ne18  POLYGON ((-97.36806 41.26462, -97.42623 41.264...
# 10                     ne16  POLYGON ((-102.05581 41.22155, -102.05586 41.0...
# 11                     ne17  POLYGON ((-100.25122 41.39332, -100.23609 41.3...
# 12                     ne19  POLYGON ((-96.43485 41.4949, -96.4252 41.49491...
# 13                      ne7  POLYGON ((-98.02694 41.91553, -98.02644 41.857...
# 14                     ne15  POLYGON ((-102.06656 42.00905, -102.06749 41.9...
# 15                      ne6  POLYGON ((-99.66358 42.43427, -99.66387 42.368...
# 16                     ne10  POLYGON ((-95.87949 41.05331, -95.88922 41.058...
# 17                      ne4  POLYGON ((-96.7263 42.32208, -96.72658 42.2929...
# 18                      ne3  POLYGON ((-97.95543 42.43736, -97.83441 42.437...
# 19                      ne8  POLYGON ((-96.6315 42.52433, -96.72213 42.5246...
# 20                     ne14  POLYGON ((-97.95352 42.76898, -97.95473 42.597...
# 21                     ne13  POLYGON ((-99.84724 42.998, -99.84601 42.9686,...
# 22                     ne12  POLYGON ((-102.08256 42.99937, -102.08396 42.9...

# %%
# Export out to CSV.
outdf.to_csv('RawInputData/Pov_Main.zip', compression=dict(method='zip', archive_name='Pov_Main.csv'), index=False)  # The output, save as a zip
goutdf.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.

# %%
tempdf = goutdf.copy()
tempdf = tempdf[tempdf['geometry'] == " " ]
tempdf
# Out:
# Empty DataFrame
# Columns: [in_ReportingUnitNativeID, geometry]
# Index: []
