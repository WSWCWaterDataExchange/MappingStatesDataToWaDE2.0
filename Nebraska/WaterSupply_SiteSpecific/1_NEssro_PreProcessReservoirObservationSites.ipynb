# %% [markdown]
# # Preprocessing Nebraska Reservoir and Observation Site data for WaDE

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/Nebraska/SS_ReservoirsObservationSites/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## NEDNR API Data Retreival
# - get site data, save to local copy for future use
# - get timeseries data, save to local copy for future use

# %%
# already done

# %%time
# # Retrieve list of only NeDNRstream gage stations
# #############################################################################

# # API retrieval
# url = "https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/GetStationList"
# responseD = json.loads(requests.get(url).text)
# DtL = responseD['Results']
# length = len(DtL)

# # create dataframe and store
# dfsg = pd.DataFrame()
# for i in range(length):
#     row = pd.DataFrame([DtL[i]])
#     dfsg = pd.concat([dfsg, row])

# # Use only NeNDR Active provided sites
# dfsg = dfsg[dfsg['SourceName'] == 'NeDNR']


# # Update StationNumber values must have 8 digits, with leading 0s
# def updateStationNumber(x):
#     x = str(x).strip()
#     if len(x) == 4:
#         x = "0000" + x
#     if len(x) == 5:
#         x = "000" + x
#     if len(x) == 6:
#         x = "00" + x
#     if len(x) == 7:
#         x = "0" + x
#     return x

# dfsg['StationNumber'] = dfsg.apply(lambda row: updateStationNumber(row['StationNumber']), axis=1)

# # Exporting output files.
# dfsg.to_csv('api_StreamGageGetStationList.zip', compression=dict(method='zip', archive_name='api_StreamGageGetStationList.csv'), index=False)

# print(len(dfsg))
# dfsg

# %%
# # Get list of StationNumber, use for timeseries api
# streamgageIdList = dfsg['StationNumber'].tolist()   
# print(len(streamgageIdList))
# streamgageIdList

# %%
# # Year list
# yearList = ["2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009",
#             "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019",
#             "2020", "2021", "2022"]

# %%
# already done

# %%time
# # get timeseries results
# # use StationNumber in url
# # use yearList

# # create empty dataframe
# dfts = pd.DataFrame()

# sgLength = len(streamgageIdList)
# ylLength = len(yearList)

# for i in range(sgLength):
#     serviceStr = "DailyMeanByYear" # change here
#     for j in range(ylLength):
#         url = "https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/" + serviceStr + "?StationNumber=" + str(streamgageIdList[i]) + "&MeanYear=" + str(yearList[j])
#         print(url)
#         try:
#             responseD = json.loads(requests.get(url).text)
#             DtL = responseD['Results']

#             # store in dataframe
#             dftemp = pd.DataFrame()
#             length = len(DtL)
#             for x in range(length):
#                 row = pd.DataFrame([DtL[x]])
#                 row['url'] = url
#                 row['service'] = serviceStr
#                 dftemp = pd.concat([dftemp, row])

#             dfts = pd.concat([dfts, dftemp])
#         except:
#             dftemp = pd.DataFrame()
#             dftemp['url'] = url
#             dfts = pd.concat([dfts, dftemp])
#             print("Error, issue with API return.")

# # Update StationNumber values must have 8 digits, with leading 0s  
# def updateStationNumber(x):
#     x = str(x).strip()
#     if len(x) == 4:
#         x = "0000" + x
#     if len(x) == 5:
#         x = "000" + x
#     if len(x) == 6:
#         x = "00" + x
#     if len(x) == 7:
#         x = "0" + x
#     return x
# dfts['StationNumber'] = dfts.apply(lambda row: updateStationNumber(row['StationNumber']), axis=1)

# # Exporting output files.
# dfts.to_csv('api_BDailyMeanByYear.zip', compression=dict(method='zip', archive_name='api_BDailyMeanByYear.csv'), index=False)

# print(len(dfts))
# dfts

# %% [markdown]
# ## NEDNR Local Data
# - site info
# - timeseries info

# %%
# Input File - gage stations
fileInput = "NEDNR SW Data/api_StreamGageGetStationList.zip"
dfsg = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfsg:
    dfsg['WaDEUUID'] = "sgNE" + dfsg.index.astype(str)
    dfsg.to_csv('NEDNR SW Data/api_StreamGageGetStationList.zip', compression=dict(method='zip', archive_name='api_StreamGageGetStationList.csv'), index=False)

print(len(dfsg))
dfsg.head()
# Out:
# 209
#                                 StationName SourceName  StationNumber  \
# 0                     Hat Creek at Montrose      NeDNR          62500
# 1                   White River at Crawford      NeDNR        6444000
# 2        Whitney Reservoir from White River      NeDNR         410000
# 3  Niobrara River at Wyoming-Nebraska State      NeDNR        6454000
# 4         Johnson Canal from Niobrara River      NeDNR          72000
#
#        RiverBasin FieldOffice StationTypeDescription  Downstream TimeZone  \
# 0     White River  Bridgeport                 Stream        1500      MST
# 1     White River  Bridgeport                 Stream        2300      MST
# 2     White River  Bridgeport              Reservoir        2350      MST
# 3  Niobrara River  Bridgeport                 Stream        4005      MST
# 4  Niobrara River  Bridgeport             Canal/Pump        4010      MST
#
#    Elevation ElevationUnits  Longitude  Latitude  IsActive WaDEUUID
# 0 3635.12000             ft -103.74280  42.92226      True    sgNE0
# 1 3658.29000             ft -103.41770  42.68664      True    sgNE1
# 2    0.00000             ft -103.30940  42.79211      True    sgNE2
# 3 4685.99000             ft -104.05160  42.65252      True    sgNE3
# 4    0.00000             ft -103.96480  42.61062      True    sgNE4

# %%
# Input File - timeseries
fileInput = "NEDNR SW Data/api_BDailyMeanByYear.zip"
dfts = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfts:
    dfts['WaDEUUID'] = "tsNE" + dfts.index.astype(str)
    dfts.to_csv('NEDNR SW Data/api_BDailyMeanByYear.zip', compression=dict(method='zip', archive_name='api_BDailyMeanByYear.csv'), index=False)

print(len(dfts))
dfts.head()
# Out:
# 1271609
#    StationNumber                       Date   Value    Status Qualifier  \
# 0          62500  2012-05-18T00:00:00-05:00 3.40000  Approved
# 1          62500  2012-05-19T00:00:00-05:00 2.60000  Approved
# 2          62500  2012-05-20T00:00:00-05:00 1.90000  Approved
# 3          62500  2012-05-21T00:00:00-05:00 1.30000  Approved
# 4          62500  2012-05-22T00:00:00-05:00 0.81000  Approved
#
#      Unit                                                url          service  \
# 0  ft^3/s  https://nednr.nebraska.gov/IwipApi/api/v1/Stre...  DailyMeanByYear
# 1  ft^3/s  https://nednr.nebraska.gov/IwipApi/api/v1/Stre...  DailyMeanByYear
# 2  ft^3/s  https://nednr.nebraska.gov/IwipApi/api/v1/Stre...  DailyMeanByYear
# 3  ft^3/s  https://nednr.nebraska.gov/IwipApi/api/v1/Stre...  DailyMeanByYear
# 4  ft^3/s  https://nednr.nebraska.gov/IwipApi/api/v1/Stre...  DailyMeanByYear
#
#   WaDEUUID
# 0    tsNE0
# 1    tsNE1
# 2    tsNE2
# 3    tsNE3
# 4    tsNE4

# %%
 #Merging dataframes into one, using left-join.
dfin1 = pd.merge(dfts, dfsg, on='StationNumber', how='left')
print(len(dfin1))
dfin1.head(1)
# Out:
# 1271609
#    StationNumber                       Date   Value    Status Qualifier  \
# 0          62500  2012-05-18T00:00:00-05:00 3.40000  Approved
#
#      Unit                                                url          service  \
# 0  ft^3/s  https://nednr.nebraska.gov/IwipApi/api/v1/Stre...  DailyMeanByYear
#
#   WaDEUUID_x            StationName SourceName   RiverBasin FieldOffice  \
# 0      tsNE0  Hat Creek at Montrose      NeDNR  White River  Bridgeport
#
#   StationTypeDescription  Downstream TimeZone  Elevation ElevationUnits  \
# 0                 Stream        1500      MST 3635.12000             ft
#
#    Longitude  Latitude  IsActive WaDEUUID_y
# 0 -103.74280  42.92226      True      sgNE0

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfin1['WaDEUUID_x']

# Method Info
df['in_MethodUUID'] = "NEssro_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "NEssro_V1" # for flow

# Organization Info
df['in_OrganizationUUID'] = "NEssro_O1" # NEDNR

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = "Fresh"
df['in_WaterSourceName'] = ""
df['in_WaterSourceNativeID'] = "" # auto fill in below if not provdied
df['in_WaterSourceTypeCV'] = "Surface Water"

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = ""
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfin1['Latitude']
df['in_Longitude'] = dfin1['Longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "Gage" 
df['in_SiteName'] = dfin1['StationName']
df['in_SiteNativeID'] = dfin1['StationNumber']
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = dfin1['StationTypeDescription']
df['in_StateCV'] = "NE"
df['in_USGSSiteID'] = ""

# Site VariableAmounts Info
df['in_Amount'] = dfin1['Value']
df['in_AllocationCropDutyAmount'] = ""
df['in_AssociatedNativeAllocationIDs'] = ""
df['in_BeneficialUseCategory'] = "WaDE Blank"
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_Geometry'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerGeneratedGWh'] = ""
df['in_PowerType'] = ""
df['in_PrimaryUseCategory'] = ""
df['in_ReportYearCV'] = dfin1['Date']
df['in_SDWISIdentifier'] = ""
df['in_TimeframeEnd'] = dfin1['Date']
df['in_TimeframeStart'] = dfin1['Date']

outdf1 = df.copy()
outdf1 = outdf1.drop_duplicates().reset_index(drop=True)
print(len(outdf1))
outdf1.head()
# Out:
# 1271609
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0    tsNE0     NEssro_M1               NEssro_V1           NEssro_O1
# 1    tsNE1     NEssro_M1               NEssro_V1           NEssro_O1
# 2    tsNE2     NEssro_M1               NEssro_V1           NEssro_O1
# 3    tsNE3     NEssro_M1               NEssro_V1           NEssro_O1
# 4    tsNE4     NEssro_M1               NEssro_V1           NEssro_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0                                                       Fresh
# 1                                                       Fresh
# 2                                                       Fresh
# 3                                                       Fresh
# 4                                                       Fresh
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                                  Surface Water
# 1                                                  Surface Water
# 2                                                  Surface Water
# 3                                                  Surface Water
# 4                                                  Surface Water
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                                                 4326
# 1                                                                 4326
# 2                                                                 4326
# 3                                                                 4326
# 4                                                                 4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    42.92226    -103.74280
# 1                                    42.92226    -103.74280
# 2                                    42.92226    -103.74280
# 3                                    42.92226    -103.74280
# 4                                    42.92226    -103.74280
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0                                                  Gage
# 1                                                  Gage
# 2                                                  Gage
# 3                                                  Gage
# 4                                                  Gage
#
#              in_SiteName  in_SiteNativeID in_SitePoint in_SiteTypeCV  \
# 0  Hat Creek at Montrose            62500                     Stream
# 1  Hat Creek at Montrose            62500                     Stream
# 2  Hat Creek at Montrose            62500                     Stream
# 3  Hat Creek at Montrose            62500                     Stream
# 4  Hat Creek at Montrose            62500                     Stream
#
#   in_StateCV in_USGSSiteID  in_Amount in_AllocationCropDutyAmount  \
# 0         NE                  3.40000
# 1         NE                  2.60000
# 2         NE                  1.90000
# 3         NE                  1.30000
# 4         NE                  0.81000
#
#   in_AssociatedNativeAllocationIDs in_BeneficialUseCategory  \
# 0                                                WaDE Blank
# 1                                                WaDE Blank
# 2                                                WaDE Blank
# 3                                                WaDE Blank
# 4                                                WaDE Blank
#
#   in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDate in_DataPublicationDOI in_IrrigatedAcreage  \
# 0
# 1
# 2
# 3
# 4
#
#   in_IrrigationMethodCV in_PopulationServed in_PowerGeneratedGWh in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryUseCategory            in_ReportYearCV in_SDWISIdentifier  \
# 0                        2012-05-18T00:00:00-05:00
# 1                        2012-05-19T00:00:00-05:00
# 2                        2012-05-20T00:00:00-05:00
# 3                        2012-05-21T00:00:00-05:00
# 4                        2012-05-22T00:00:00-05:00
#
#              in_TimeframeEnd          in_TimeframeStart
# 0  2012-05-18T00:00:00-05:00  2012-05-18T00:00:00-05:00
# 1  2012-05-19T00:00:00-05:00  2012-05-19T00:00:00-05:00
# 2  2012-05-20T00:00:00-05:00  2012-05-20T00:00:00-05:00
# 3  2012-05-21T00:00:00-05:00  2012-05-21T00:00:00-05:00
# 4  2012-05-22T00:00:00-05:00  2012-05-22T00:00:00-05:00

# %% [markdown]
# ## University of Nebraska-Lincoln GW Data Local Data
# - site info
# - timeseries info

# %%
# Input File - well location info
fileInput = "University of NebraskaLincoln GW Data/Well_Info.zip"
dfwl = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfwl:
    dfwl['WaDEUUID'] = "wlNE" + dfwl.index.astype(str)
    dfwl.to_csv('University of NebraskaLincoln GW Data/Well_Info.zip', compression=dict(method='zip', archive_name='Well_Info.csv'), index=False)

print(len(dfwl))
dfwl.head()
# Out:
# 23990
# C:\Users\rjame\AppData\Local\Temp\ipykernel_16612\3105779009.py:3: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfwl = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")
#            CSD_ID DNR_Well_ID REGNUM         Legal   County             NRD  \
# 0  08N 12W 04 CCA                      8N 12W 4CCA    ADAMS     LITTLE BLUE
# 1  08N 14W 03 CBB                      8N 14W 3CBB  BUFFALO  CENTRAL PLATTE
# 2  08N 14W 04 CBC                      8N 14W 4CBC  BUFFALO  CENTRAL PLATTE
# 3  08N 14W 17 ADD                     8N 14W 17ADD  KEARNEY       TRI-BASIN
# 4  08N 14W 17 DAD                     8N 14W 17DAD  KEARNEY       TRI-BASIN
#
#    TWN  RNG RLTR  SEC  QTR    LatDD    LongDD LLCoordMeth Agency  \
# 0    8   12    W    4  CCA 40.68450 -98.68160              LBNRD
# 1    8   14    W    3  CBB 40.69077 -98.89306              CPNRD
# 2    8   14    W    4  CBC 40.68934 -98.91206              CPNRD
# 3    8   14    W   17  ADD 40.64878 -98.91551              CPNRD
# 4    8   14    W   17  DAD 40.64591 -98.91551              CPNRD
#
#   Predevelopment Surf_Elev            Surf_Elev_Method Constr_Date WellType  \
# 0                  2005.36  Interpolated from 1m LiDAR
# 1                   2067.2  Interpolated from 1m LiDAR
# 2                  2075.86  Interpolated from 1m LiDAR
# 3                  2084.75  Interpolated from 1m LiDAR
# 4                  2084.63  Interpolated from 1m LiDAR
#
#   Well_Dpth Casing_Dia Scrn_Top Scrn_Bot Scrn_Lngth Slot_Size Scrn_Top2  \
# 0 100.00000
# 1
# 2
# 3
# 4
#
#   Scrn_Bot2 Scrn_Lngth2 Scrn_Top3 Scrn_Bot3 Scrn_Lngth3 WaDEUUID
# 0                                                          wlNE0
# 1                                                          wlNE1
# 2                                                          wlNE2
# 3                                                          wlNE3
# 4                                                          wlNE4

# %%
# Input File - water level timeseries
fileInput = "University of NebraskaLincoln GW Data/Water_Level_Data.zip"
dfwld = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfwld:
    dfwld['WaDEUUID'] = "wldNE" + dfwld.index.astype(str)
    dfwld.to_csv('University of NebraskaLincoln GW Data/Water_Level_Data.zip', compression=dict(method='zip', archive_name='Water_Level_Data.csv'), index=False)

print(len(dfwld))
dfwld.head()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_16612\62422825.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfwld = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")
# 777343
#             CSD_ID  YearMsr    DateMsr  Season  WatLevel WaDEUUID
# 0  403956101531901     1995  4/15/1995  Spring 113.17000   wldNE0
# 1         G-056892     1995  4/15/1995  Spring 127.32000   wldNE1
# 2  404001099463601     1995   4/7/1995  Spring 132.26000   wldNE2
# 3  404002098053101     1995  5/13/1995  Spring  83.42000   wldNE3
# 4  404007099294001     1995  3/15/1995  Spring   8.12000   wldNE4

# %%
 #Merging dataframes into one, using left-join.
dfin2 = pd.merge(dfwl, dfwld, on='CSD_ID', how='left')
print(len(dfin2))
dfin2.head(1)
# Out:
# 654488
#            CSD_ID DNR_Well_ID REGNUM        Legal County          NRD  TWN  \
# 0  08N 12W 04 CCA                     8N 12W 4CCA  ADAMS  LITTLE BLUE    8
#
#    RNG RLTR  SEC  QTR    LatDD    LongDD LLCoordMeth Agency Predevelopment  \
# 0   12    W    4  CCA 40.68450 -98.68160              LBNRD
#
#   Surf_Elev            Surf_Elev_Method Constr_Date WellType Well_Dpth  \
# 0   2005.36  Interpolated from 1m LiDAR                      100.00000
#
#   Casing_Dia Scrn_Top Scrn_Bot Scrn_Lngth Slot_Size Scrn_Top2 Scrn_Bot2  \
# 0
#
#   Scrn_Lngth2 Scrn_Top3 Scrn_Bot3 Scrn_Lngth3 WaDEUUID_x    YearMsr  \
# 0                                                  wlNE0 2002.00000
#
#      DateMsr  Season WatLevel  WaDEUUID_y
# 0  4/15/2002  Spring 12.33000  wldNE27133

# %%
dfin2
# Out:
#                 CSD_ID DNR_Well_ID REGNUM        Legal      County  \
# 0       08N 12W 04 CCA                     8N 12W 4CCA       ADAMS
# 1       08N 12W 04 CCA                     8N 12W 4CCA       ADAMS
# 2       08N 12W 04 CCA                     8N 12W 4CCA       ADAMS
# 3       08N 12W 04 CCA                     8N 12W 4CCA       ADAMS
# 4       08N 12W 04 CCA                     8N 12W 4CCA       ADAMS
# ...                ...         ...    ...          ...         ...
# 654483            W-4S                     24N 10W 33C     WHEELER
# 654484            W-4S                     24N 10W 33C     WHEELER
# 654485            W-4S                     24N 10W 33C     WHEELER
# 654486            W-4S                     24N 10W 33C     WHEELER
# 654487        West Dam                      3N 29W 19A  RED WILLOW
#
#                       NRD  TWN  RNG RLTR  SEC  QTR    LatDD     LongDD  \
# 0             LITTLE BLUE    8   12    W    4  CCA 40.68450  -98.68160
# 1             LITTLE BLUE    8   12    W    4  CCA 40.68450  -98.68160
# 2             LITTLE BLUE    8   12    W    4  CCA 40.68450  -98.68160
# 3             LITTLE BLUE    8   12    W    4  CCA 40.68450  -98.68160
# 4             LITTLE BLUE    8   12    W    4  CCA 40.68450  -98.68160
# ...                   ...  ...  ...  ...  ...  ...      ...        ...
# 654483      UPPER ELKHORN   24   10    W   33    C 42.00850  -98.48952
# 654484      UPPER ELKHORN   24   10    W   33    C 42.00850  -98.48952
# 654485      UPPER ELKHORN   24   10    W   33    C 42.00850  -98.48952
# 654486      UPPER ELKHORN   24   10    W   33    C 42.00850  -98.48952
# 654487  MIDDLE REPUBLICAN    3   29    W   19    A 40.22045 -100.63083
#
#        LLCoordMeth Agency Predevelopment  Surf_Elev  \
# 0                   LBNRD                   2005.36
# 1                   LBNRD                   2005.36
# 2                   LBNRD                   2005.36
# 3                   LBNRD                   2005.36
# 4                   LBNRD                   2005.36
# ...            ...    ...            ...        ...
# 654483              LLNRD                2054.24000
# 654484              LLNRD                2054.24000
# 654485              LLNRD                2054.24000
# 654486              LLNRD                2054.24000
# 654487              MRNRD                2517.03000
#
#                   Surf_Elev_Method Constr_Date WellType Well_Dpth Casing_Dia  \
# 0       Interpolated from 1m LiDAR                      100.00000
# 1       Interpolated from 1m LiDAR                      100.00000
# 2       Interpolated from 1m LiDAR                      100.00000
# 3       Interpolated from 1m LiDAR                      100.00000
# 4       Interpolated from 1m LiDAR                      100.00000
# ...                            ...         ...      ...       ...        ...
# 654483  Interpolated from 1m LiDAR
# 654484  Interpolated from 1m LiDAR
# 654485  Interpolated from 1m LiDAR
# 654486  Interpolated from 1m LiDAR
# 654487  Interpolated from 1m LiDAR
#
#        Scrn_Top Scrn_Bot Scrn_Lngth Slot_Size Scrn_Top2 Scrn_Bot2 Scrn_Lngth2  \
# 0
# 1
# 2
# 3
# 4
# ...         ...      ...        ...       ...       ...       ...         ...
# 654483
# 654484
# 654485
# 654486
# 654487
#
#        Scrn_Top3 Scrn_Bot3 Scrn_Lngth3 WaDEUUID_x    YearMsr     DateMsr  \
# 0                                           wlNE0 2002.00000   4/15/2002
# 1                                           wlNE0 2003.00000   4/15/2003
# 2                                           wlNE0 2013.00000   4/23/2013
# 3                                           wlNE0 2004.00000   4/15/2004
# 4                                           wlNE0 2008.00000   4/15/2008
# ...          ...       ...         ...        ...        ...         ...
# 654483                                  wlNE23988 2006.00000  10/24/2006
# 654484                                  wlNE23988 2020.00000   3/23/2020
# 654485                                  wlNE23988 2021.00000   3/22/2021
# 654486                                  wlNE23988 2022.00000   3/17/2022
# 654487                                  wlNE23989        NaN         NaN
#
#         Season WatLevel   WaDEUUID_y
# 0       Spring 12.33000   wldNE27133
# 1       Spring 14.63000   wldNE32619
# 2       Spring 15.10000   wldNE49974
# 3       Spring 15.89000  wldNE113897
# 4       Spring 13.20000  wldNE136068
# ...        ...      ...          ...
# 654483    Fall 17.57000   wldNE89838
# 654484  Spring 13.15000   wldNE96923
# 654485  Spring 14.85000  wldNE100121
# 654486  Spring 16.70000  wldNE108404
# 654487     NaN      NaN          NaN
#
# [654488 rows x 38 columns]

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfin2['WaDEUUID_x']

# Method Info
df['in_MethodUUID'] = "NEssro_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "NEssro_V2" # for water level depth

# Organization Info
df['in_OrganizationUUID'] = "NEssro_O2" # University of Nebraska-Lincoln

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = "Fresh"
df['in_WaterSourceName'] = ""
df['in_WaterSourceNativeID'] = "" # auto fill in below if not provdied
df['in_WaterSourceTypeCV'] = "Groundwater"

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = dfin2['County']
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfin2['LatDD']
df['in_Longitude'] = dfin2['LongDD']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "Gage" 
df['in_SiteName'] = ""
df['in_SiteNativeID'] = dfin2['CSD_ID']
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = ""
df['in_StateCV'] = "NE"
df['in_USGSSiteID'] = ""

# Site VariableAmounts Info
df['in_Amount'] = dfin2['WatLevel']
df['in_AllocationCropDutyAmount'] = ""
df['in_AssociatedNativeAllocationIDs'] = ""
df['in_BeneficialUseCategory'] = "WaDE Blank"
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_Geometry'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerGeneratedGWh'] = ""
df['in_PowerType'] = ""
df['in_PrimaryUseCategory'] = ""
df['in_ReportYearCV'] = dfin2['YearMsr']
df['in_SDWISIdentifier'] = ""
df['in_TimeframeEnd'] = dfin2['DateMsr']
df['in_TimeframeStart'] = dfin2['DateMsr']

outdf2 = df.copy()
outdf2 = outdf2.drop_duplicates().reset_index(drop=True)
print(len(outdf2))
outdf2.head()
# Out:
# 654034
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0    wlNE0     NEssro_M1               NEssro_V2           NEssro_O2
# 1    wlNE0     NEssro_M1               NEssro_V2           NEssro_O2
# 2    wlNE0     NEssro_M1               NEssro_V2           NEssro_O2
# 3    wlNE0     NEssro_M1               NEssro_V2           NEssro_O2
# 4    wlNE0     NEssro_M1               NEssro_V2           NEssro_O2
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0                                                       Fresh
# 1                                                       Fresh
# 2                                                       Fresh
# 3                                                       Fresh
# 4                                                       Fresh
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                                    Groundwater
# 1                                                    Groundwater
# 2                                                    Groundwater
# 3                                                    Groundwater
# 4                                                    Groundwater
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                                 ADAMS           4326
# 1                                                 ADAMS           4326
# 2                                                 ADAMS           4326
# 3                                                 ADAMS           4326
# 4                                                 ADAMS           4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    40.68450     -98.68160
# 1                                    40.68450     -98.68160
# 2                                    40.68450     -98.68160
# 3                                    40.68450     -98.68160
# 4                                    40.68450     -98.68160
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                  Gage
# 1                                                  Gage
# 2                                                  Gage
# 3                                                  Gage
# 4                                                  Gage
#
#   in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0  08N 12W 04 CCA                                    NE
# 1  08N 12W 04 CCA                                    NE
# 2  08N 12W 04 CCA                                    NE
# 3  08N 12W 04 CCA                                    NE
# 4  08N 12W 04 CCA                                    NE
#
#   in_Amount in_AllocationCropDutyAmount in_AssociatedNativeAllocationIDs  \
# 0  12.33000
# 1  14.63000
# 2  15.10000
# 3  15.89000
# 4  13.20000
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0               WaDE Blank
# 1               WaDE Blank
# 2               WaDE Blank
# 3               WaDE Blank
# 4               WaDE Blank
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerGeneratedGWh in_PowerType in_PrimaryUseCategory  in_ReportYearCV  \
# 0                                                               2002.00000
# 1                                                               2003.00000
# 2                                                               2013.00000
# 3                                                               2004.00000
# 4                                                               2008.00000
#
#   in_SDWISIdentifier in_TimeframeEnd in_TimeframeStart
# 0                          4/15/2002         4/15/2002
# 1                          4/15/2003         4/15/2003
# 2                          4/23/2013         4/23/2013
# 3                          4/15/2004         4/15/2004
# 4                          4/15/2008         4/15/2008

# %%
# Concatenate dataframes
frames = [outdf1, outdf2]
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 1925643

# %% [markdown]
# ## Clean Data / data types

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['Hat Creek At Montrose', 'White River At Crawford',
#        'Niobrara River At Wyomingnebraska State',
#        'Johnson Canal From Niobrara River',
#        'Lakotah Canal From Niobrara River', 'Niobrara River At 33 Ranch',
#        'Earnest Canal South From Niobrara River',
#        'Earnest Canal North From Niobrara River',
#        'Mcginleystover Canal From Niobrara River',
#        'Cook Canal No 1 From Niobrara River',
#        'Harrisneece Canal From Niobrara River', 'Niobrara River At Agate',
#        'Labelle Canal From Niobrara River',
#        'Mettlen Canal From Niobrara River',
#        'Bennettkay Canal From Niobrara River',
#        'Moorekay Canal From Niobrara River',
#        'Geo Hitshew Canal From Niobrara River',
#        'Mclaughlin Canal From Niobrara River',
#        'Excelsior Canal From Niobrara River',
#        'Hughes Canal From Niobrara River',
#        'Pioneer Canal From Niobrara River',
#        'Niobrara River Above Box Butte Reservoir',
#        'Niobrara River Below Box Butte Reservoir',
#        'Lichte Canal From Niobrara River',
#        'Mirage Flats Canal From Niobrara River',
#        'Niobrara River Near Hay Springs', 'Niobrara River Near Gordon',
#        'Niobrara River Near Nenzel', 'Snake River At Doughboy',
#        'Ainsworth Canal From Merritt Reservoir', 'Snake River Near Burge',
#        'Keya Paha River Near Naper', 'Niobrara River Near Butte',
#        'Verdigre Creek Near Verdigre',
#        'Mitchell Gering Canal From North Platte River',
#        'Gering Canal From North Platte River Via Mitchell Canal',
#        'Gering Canal From North Platte River Ramp Flume',
#        'Tristate Canal From North Platte',
#        'Northport Canal From North Platte River And Spills',
#        'Northport Canal Spill Into Upper Dugout Creek',
#        'North Platte Passing Tristate Canal', 'Horse Creek Near Lyman',
#        'Sheep Creek Near Morrill', 'North Platte River At Morrill',
#        'Enterprise Canal From North Platte River',
#        'Dry Spotted Tail Creek At Mitchell',
#        'North Platte River At Mitchell', 'Tub Springs Near Scottsbluff',
#        'Winters Creek Canal From North Platte River',
#        'Winters Creek Canal From Winters Creek',
#        'Central Canal From North Platte River',
#        'Winters Creek Near Scottsbluff',
#        'Minatare Canal From North Platte River',
#        'Gering Creek At Lockwood Road',
#        'Castle Rocksteamboat Canal From North Platte River',
#        'Tristate Canal From Alliance Creek',
#        'North Platte River Near Minatare Combined',
#        'North Platte River Near Minataremain Channel',
#        'North Platte River Near Minatareninemile Channel',
#        'Ninemile Canal From North Platte River',
#        'Ninemile Canal From Ninemile Creek', 'Ninemile Creek Near Mcgrew',
#        'Short Line Canal From North Platte River',
#        'Chimney Rock Canal From North Platte River',
#        'Alliance Canal From Bayard Creek',
#        'Alliance Canal From Red Willow Creek', 'Bayard Creek Near Bayard',
#        'Red Willow Creek Near Bayard',
#        'Belmont Canal From North Platte River',
#        'North Platte River At Bridgeport Combined',
#        'North Platte River At Bridgeport Main Channel',
#        "North Platte River At Bridgeport Brown'S Creek",
#        'Pumpkin Creek Near Bridgeport', 'Belmont Canal From Cedar Creek',
#        'Empire Canal From North Platte River',
#        'Browns Creek Canal From North Platte River',
#        'Courthouse Rock Canal From Pumpkin Creek',
#        'Last Chance Canal From Pumpkin Creek',
#        'Trinnier Canal From Greenwood Creek',
#        'Nelson Canal From Greenwood Creek',
#        'Meredithammer Canal From Pumpkin Creek',
#        'Beerline Canal From North Platte River',
#        'Lisco Canal From North Platte River',
#        'North Platte River At Lisco',
#        'Midlandoverland Canal From North Platte River',
#        'Paisley Canal From Blue Creek',
#        'Blue Creek Hooper Canal From Blue Creek',
#        'Hooper Canal From Blue Creek Via Blue Creek',
#        'Union Canal From Blue Creek', 'Blue Creek Near Lewellen',
#        'North Platte River At Lewellen',
#        'Sutherland Canal From North Platte River',
#        'North Platte River Near Keystone',
#        'Keithlincoln County Canal From North Platte River',
#        'North Platte Canal From North Platte River',
#        'Paxtonhershey Canal From North Platte River',
#        'North Platte River Near Sutherland',
#        'Birdwood Canal From Birdwood Creek',
#        'Suburban Canal From North Platte River',
#        'Birdwood Creek Near Hershey',
#        'Codydillon Canal From North Platte River',
#        'Lincoln County Drain No 1 At North Platte',
#        'North Platte River At North Platte',
#        'Lodgepole Creek Above Oliver Reservoir',
#        'Lodgepole Creek At Ralton',
#        'Western Canal From South Platte River',
#        'Western Canal Spill To South Platte River',
#        'South Platte Supply Canal Korty From South Platte River',
#        'South Platte River At North Platte', 'Sutherland Power Return',
#        'Sutherland Power Return Open Channel',
#        'Tricounty Canal From Platte Open Channel',
#        'Johnson Power Return To Platte River', 'Platte River At Maxwell',
#        'Platte River At Bradychannel 1', 'Platte River At Bradychannel 4',
#        'Platte River At Brady Combined',
#        'Jeffrey Power Return To Platte River',
#        'Thirty Mile Canal From Platte River',
#        'Gothenburg Canal From Platte River',
#        'Buffalo Creek B1 Reservoir Supply Canal',
#        'Cozad Canal From Platte River',
#        'Orchardalfalfa Canal From Platte River',
#        'Dawson County Canal From Platte River',
#        'Platte River Near Cozad South Channel',
#        'Platte River Near Cozad North Channel',
#        'Platte River Near Cozad Combined', 'Platte River Near Darr',
#        'Phelps County Canal From Platte River',
#        'Plum Creek Near Smithfield', 'Kearney Canal From Platte River',
#        'Kearney Power Return To Platte River', 'Platte River Near Odessa',
#        'Turkey Creek Near Kearney', 'North Dry Creek Near Kearney',
#        'Fort Kearney Slough Near Newark', 'Platte River Near Shelton',
#        'Wood River Near Alda', 'Sargent Canal From Middle Loup River',
#        'Middle Loup Canal No 1 From Middle Loup',
#        'Middle Loup Canal No 1 Pump From Middle',
#        'Middle Loup Canal No 2 From Middle Loup',
#        'Middle Loup Canal No 3 From Middle Loup',
#        'Middle Loup Canal No 4 From Middle Loup',
#        'Farwell Sherman Feeder Canal From Midd',
#        'Middle Loup Canal No 4 From Sherman Feeder Canal',
#        'Farwell Main Canal From Sherman Reservoir',
#        'Farwell South Canal From Sherman Reservoir',
#        'Middle Loup River At Rockville', 'Mud Creek Near Sweetwater',
#        'Turkey Creek Near Dannebrog',
#        'Taylorord Canal From North Loup River',
#        'Taylorord Canal Inlet To Mirdan Canal',
#        'Taylorord Canal Outlet From Mirdan Canal',
#        'Kent Canal From North Loup River',
#        'Calamus Fish Hatchery Inlet From Calamus',
#        'Calamus River Near Harrop', 'Mirdan Canal From Calamus Reservoir',
#        'Inlet Canal To Davis Creek Reservoir From Mirdan Canal',
#        'Fullerton Canal From Davis Creek Reservoir',
#        'Calamus River Near Burwell',
#        'Burwellsumter Canal From North Loup River',
#        'North Loup River At Ord',
#        'Ordnorth Loup Canal From North Loup River',
#        'Mira Creek Near North Loup', 'Cedar River Near Spalding',
#        'Cedar River Near Fullerton',
#        'Loup River Power Canal Return At Columbus',
#        'Beaver Creek At Loretto', 'Loup River At Columbus',
#        'Elkhorn River Near Atkinson',
#        'South Fork Elkhorn River Near Ewing', 'Elkhorn River At Neligh',
#        'Elkhorn River Near Tilden', 'Willow Creek Near Foster',
#        'Willow Creek Reservoir Near Pierce', 'Willow Creek Near Pierce',
#        'Union Creek At Madison', 'Pebble Creek At Scribner',
#        'Logan Creek At Pender', 'Elkhorn River Near Winslow',
#        'Haigler Canal Spillback To Arikaree River',
#        'Parks Canal From Republican River',
#        'Frenchman Creek Near Imperial',
#        'Stinking Water Creek Near Palisade',
#        'Riverside Canal From Frenchman Creek',
#        'Red Willow Creek Near Mccook',
#        'Republican River At Highway 47 Bridge At Cambridge',
#        'Medicine Creek Near Somerset', 'Medicine Creek Near Curtis',
#        'Fox Creek At Curtis', 'Medicine Creek Above Harry Strunk Lake',
#        'Medicine Creek Below Harry Strunk Lake',
#        'Muddy Creek At Furnasgosper County Line',
#        'Muddy Creek At Arapahoe',
#        'Turkey Creek At Furnasgosper County Line',
#        'Turkey Creek At Edison', 'Turkey Creek At Naponee',
#        'Republican River At Riverton', 'Thompson Creek At Riverton',
#        'Big Blue River At Surprise', 'Lincoln Creek Near Seward',
#        'Big Blue River At Seward', 'Turkey Creek Near Wilber',
#        'Big Blue River At Beatrice', 'Little Blue River At Hebron',
#        'Big Sandy Creek At Alexandria',
#        'Rose Creek At Highway 15 Near Fairbury', ''], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['', 'Adams', 'Buffalo', 'Kearney', 'Dawson', 'Phelps', 'Frontier',
#        'Hall', 'Perkins', 'Merrick', 'Keith', 'Howard', 'Custer',
#        'Lincoln', 'Nance', 'Webster', 'Dundy', 'Thayer', 'Hooker',
#        'Harlan', 'Brown', 'Cherry', 'Franklin', 'Furnas', 'Richardson',
#        'Nuckolls', 'Hitchcock', 'Red Willow', 'Jefferson', 'Pawnee',
#        'Gage', 'Chase', 'Johnson', 'Saline', 'Hayes', 'Fillmore',
#        'Gosper', 'Clay', 'Nemaha', 'Hamilton', 'Lancaster', 'Otoe',
#        'Seward', 'York', 'Cass', 'Greeley', 'Deuel', 'Cheyenne', 'Duel',
#        'Kimball', 'Sarpy', 'Polk', 'Saunders', 'Sherman', 'Butler',
#        'Madison', 'Douglas', 'Garden', 'Platte', 'Banner', 'Logan',
#        'Valley', 'Arthur', 'Colfax', 'Dodge', 'Mcpherson', 'Washington',
#        'Morrill', 'Boone', 'Burt', 'Scotts Bluff', 'Loup', 'Cuming',
#        'Wheeler', 'Garfield', 'Blaine', 'Grant', 'Stanton', 'Thomas',
#        'Keya Paha', 'Scottsbluff', 'Antelope', 'Sioux', 'Box Butte',
#        'Thurston', 'Sheridan', 'Wayne', 'Pierce', 'Holt', 'Rock', 'Dixon',
#        'Dakota', 'Cedar', 'Knox', 'Dawes', 'Boyd'], dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['Stream', 'Canal/Pump', 'Return', 'Reservoir', ''], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['Hat Creek At Montrose', 'White River At Crawford',
#        'Niobrara River At Wyomingnebraska State',
#        'Johnson Canal From Niobrara River',
#        'Lakotah Canal From Niobrara River', 'Niobrara River At 33 Ranch',
#        'Earnest Canal South From Niobrara River',
#        'Earnest Canal North From Niobrara River',
#        'Mcginleystover Canal From Niobrara River',
#        'Cook Canal No 1 From Niobrara River',
#        'Harrisneece Canal From Niobrara River', 'Niobrara River At Agate',
#        'Labelle Canal From Niobrara River',
#        'Mettlen Canal From Niobrara River',
#        'Bennettkay Canal From Niobrara River',
#        'Moorekay Canal From Niobrara River',
#        'Geo Hitshew Canal From Niobrara River',
#        'Mclaughlin Canal From Niobrara River',
#        'Excelsior Canal From Niobrara River',
#        'Hughes Canal From Niobrara River',
#        'Pioneer Canal From Niobrara River',
#        'Niobrara River Above Box Butte Reservoir',
#        'Niobrara River Below Box Butte Reservoir',
#        'Lichte Canal From Niobrara River',
#        'Mirage Flats Canal From Niobrara River',
#        'Niobrara River Near Hay Springs', 'Niobrara River Near Gordon',
#        'Niobrara River Near Nenzel', 'Snake River At Doughboy',
#        'Ainsworth Canal From Merritt Reservoir', 'Snake River Near Burge',
#        'Keya Paha River Near Naper', 'Niobrara River Near Butte',
#        'Verdigre Creek Near Verdigre',
#        'Mitchell Gering Canal From North Platte River',
#        'Gering Canal From North Platte River Via Mitchell Canal',
#        'Gering Canal From North Platte River Ramp Flume',
#        'Tristate Canal From North Platte',
#        'Northport Canal From North Platte River And Spills',
#        'Northport Canal Spill Into Upper Dugout Creek',
#        'North Platte Passing Tristate Canal', 'Horse Creek Near Lyman',
#        'Sheep Creek Near Morrill', 'North Platte River At Morrill',
#        'Enterprise Canal From North Platte River',
#        'Dry Spotted Tail Creek At Mitchell',
#        'North Platte River At Mitchell', 'Tub Springs Near Scottsbluff',
#        'Winters Creek Canal From North Platte River',
#        'Winters Creek Canal From Winters Creek',
#        'Central Canal From North Platte River',
#        'Winters Creek Near Scottsbluff',
#        'Minatare Canal From North Platte River',
#        'Gering Creek At Lockwood Road',
#        'Castle Rocksteamboat Canal From North Platte River',
#        'Tristate Canal From Alliance Creek',
#        'North Platte River Near Minatare Combined',
#        'North Platte River Near Minataremain Channel',
#        'North Platte River Near Minatareninemile Channel',
#        'Ninemile Canal From North Platte River',
#        'Ninemile Canal From Ninemile Creek', 'Ninemile Creek Near Mcgrew',
#        'Short Line Canal From North Platte River',
#        'Chimney Rock Canal From North Platte River',
#        'Alliance Canal From Bayard Creek',
#        'Alliance Canal From Red Willow Creek', 'Bayard Creek Near Bayard',
#        'Red Willow Creek Near Bayard',
#        'Belmont Canal From North Platte River',
#        'North Platte River At Bridgeport Combined',
#        'North Platte River At Bridgeport Main Channel',
#        "North Platte River At Bridgeport Brown'S Creek",
#        'Pumpkin Creek Near Bridgeport', 'Belmont Canal From Cedar Creek',
#        'Empire Canal From North Platte River',
#        'Browns Creek Canal From North Platte River',
#        'Courthouse Rock Canal From Pumpkin Creek',
#        'Last Chance Canal From Pumpkin Creek',
#        'Trinnier Canal From Greenwood Creek',
#        'Nelson Canal From Greenwood Creek',
#        'Meredithammer Canal From Pumpkin Creek',
#        'Beerline Canal From North Platte River',
#        'Lisco Canal From North Platte River',
#        'North Platte River At Lisco',
#        'Midlandoverland Canal From North Platte River',
#        'Paisley Canal From Blue Creek',
#        'Blue Creek Hooper Canal From Blue Creek',
#        'Hooper Canal From Blue Creek Via Blue Creek',
#        'Union Canal From Blue Creek', 'Blue Creek Near Lewellen',
#        'North Platte River At Lewellen',
#        'Sutherland Canal From North Platte River',
#        'North Platte River Near Keystone',
#        'Keithlincoln County Canal From North Platte River',
#        'North Platte Canal From North Platte River',
#        'Paxtonhershey Canal From North Platte River',
#        'North Platte River Near Sutherland',
#        'Birdwood Canal From Birdwood Creek',
#        'Suburban Canal From North Platte River',
#        'Birdwood Creek Near Hershey',
#        'Codydillon Canal From North Platte River',
#        'Lincoln County Drain No 1 At North Platte',
#        'North Platte River At North Platte',
#        'Lodgepole Creek Above Oliver Reservoir',
#        'Lodgepole Creek At Ralton',
#        'Western Canal From South Platte River',
#        'Western Canal Spill To South Platte River',
#        'South Platte Supply Canal Korty From South Platte River',
#        'South Platte River At North Platte', 'Sutherland Power Return',
#        'Sutherland Power Return Open Channel',
#        'Tricounty Canal From Platte Open Channel',
#        'Johnson Power Return To Platte River', 'Platte River At Maxwell',
#        'Platte River At Bradychannel 1', 'Platte River At Bradychannel 4',
#        'Platte River At Brady Combined',
#        'Jeffrey Power Return To Platte River',
#        'Thirty Mile Canal From Platte River',
#        'Gothenburg Canal From Platte River',
#        'Buffalo Creek B1 Reservoir Supply Canal',
#        'Cozad Canal From Platte River',
#        'Orchardalfalfa Canal From Platte River',
#        'Dawson County Canal From Platte River',
#        'Platte River Near Cozad South Channel',
#        'Platte River Near Cozad North Channel',
#        'Platte River Near Cozad Combined', 'Platte River Near Darr',
#        'Phelps County Canal From Platte River',
#        'Plum Creek Near Smithfield', 'Kearney Canal From Platte River',
#        'Kearney Power Return To Platte River', 'Platte River Near Odessa',
#        'Turkey Creek Near Kearney', 'North Dry Creek Near Kearney',
#        'Fort Kearney Slough Near Newark', 'Platte River Near Shelton',
#        'Wood River Near Alda', 'Sargent Canal From Middle Loup River',
#        'Middle Loup Canal No 1 From Middle Loup',
#        'Middle Loup Canal No 1 Pump From Middle',
#        'Middle Loup Canal No 2 From Middle Loup',
#        'Middle Loup Canal No 3 From Middle Loup',
#        'Middle Loup Canal No 4 From Middle Loup',
#        'Farwell Sherman Feeder Canal From Midd',
#        'Middle Loup Canal No 4 From Sherman Feeder Canal',
#        'Farwell Main Canal From Sherman Reservoir',
#        'Farwell South Canal From Sherman Reservoir',
#        'Middle Loup River At Rockville', 'Mud Creek Near Sweetwater',
#        'Turkey Creek Near Dannebrog',
#        'Taylorord Canal From North Loup River',
#        'Taylorord Canal Inlet To Mirdan Canal',
#        'Taylorord Canal Outlet From Mirdan Canal',
#        'Kent Canal From North Loup River',
#        'Calamus Fish Hatchery Inlet From Calamus',
#        'Calamus River Near Harrop', 'Mirdan Canal From Calamus Reservoir',
#        'Inlet Canal To Davis Creek Reservoir From Mirdan Canal',
#        'Fullerton Canal From Davis Creek Reservoir',
#        'Calamus River Near Burwell',
#        'Burwellsumter Canal From North Loup River',
#        'North Loup River At Ord',
#        'Ordnorth Loup Canal From North Loup River',
#        'Mira Creek Near North Loup', 'Cedar River Near Spalding',
#        'Cedar River Near Fullerton',
#        'Loup River Power Canal Return At Columbus',
#        'Beaver Creek At Loretto', 'Loup River At Columbus',
#        'Elkhorn River Near Atkinson',
#        'South Fork Elkhorn River Near Ewing', 'Elkhorn River At Neligh',
#        'Elkhorn River Near Tilden', 'Willow Creek Near Foster',
#        'Willow Creek Reservoir Near Pierce', 'Willow Creek Near Pierce',
#        'Union Creek At Madison', 'Pebble Creek At Scribner',
#        'Logan Creek At Pender', 'Elkhorn River Near Winslow',
#        'Haigler Canal Spillback To Arikaree River',
#        'Parks Canal From Republican River',
#        'Frenchman Creek Near Imperial',
#        'Stinking Water Creek Near Palisade',
#        'Riverside Canal From Frenchman Creek',
#        'Red Willow Creek Near Mccook',
#        'Republican River At Highway 47 Bridge At Cambridge',
#        'Medicine Creek Near Somerset', 'Medicine Creek Near Curtis',
#        'Fox Creek At Curtis', 'Medicine Creek Above Harry Strunk Lake',
#        'Medicine Creek Below Harry Strunk Lake',
#        'Muddy Creek At Furnasgosper County Line',
#        'Muddy Creek At Arapahoe',
#        'Turkey Creek At Furnasgosper County Line',
#        'Turkey Creek At Edison', 'Turkey Creek At Naponee',
#        'Republican River At Riverton', 'Thompson Creek At Riverton',
#        'Big Blue River At Surprise', 'Lincoln Creek Near Seward',
#        'Big Blue River At Seward', 'Turkey Creek Near Wilber',
#        'Big Blue River At Beatrice', 'Little Blue River At Hebron',
#        'Big Sandy Creek At Alexandria',
#        'Rose Creek At Highway 15 Near Fairbury', ''], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: ensureEmptyString(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['', 'Adams', 'Buffalo', 'Kearney', 'Dawson', 'Phelps', 'Frontier',
#        'Hall', 'Perkins', 'Merrick', 'Keith', 'Howard', 'Custer',
#        'Lincoln', 'Nance', 'Webster', 'Dundy', 'Thayer', 'Hooker',
#        'Harlan', 'Brown', 'Cherry', 'Franklin', 'Furnas', 'Richardson',
#        'Nuckolls', 'Hitchcock', 'Red Willow', 'Jefferson', 'Pawnee',
#        'Gage', 'Chase', 'Johnson', 'Saline', 'Hayes', 'Fillmore',
#        'Gosper', 'Clay', 'Nemaha', 'Hamilton', 'Lancaster', 'Otoe',
#        'Seward', 'York', 'Cass', 'Greeley', 'Deuel', 'Cheyenne', 'Duel',
#        'Kimball', 'Sarpy', 'Polk', 'Saunders', 'Sherman', 'Butler',
#        'Madison', 'Douglas', 'Garden', 'Platte', 'Banner', 'Logan',
#        'Valley', 'Arthur', 'Colfax', 'Dodge', 'Mcpherson', 'Washington',
#        'Morrill', 'Boone', 'Burt', 'Scotts Bluff', 'Loup', 'Cuming',
#        'Wheeler', 'Garfield', 'Blaine', 'Grant', 'Stanton', 'Thomas',
#        'Keya Paha', 'Scottsbluff', 'Antelope', 'Sioux', 'Box Butte',
#        'Thurston', 'Sheridan', 'Wayne', 'Pierce', 'Holt', 'Rock', 'Dixon',
#        'Dakota', 'Cedar', 'Knox', 'Dawes', 'Boyd'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['WaDE Blank'], dtype=object)

# %%
# Ensure Latitude entry is either numireic or blank, no 0 entries
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("").replace(" ", "")
outdf['in_Latitude'].unique()
# Out:
# array([42.92226 , 42.68664 , 42.65252 , ..., 42.008545, 42.0085  ,
#        40.22045 ])

# %%
# Ensure Longitude entry is either numireic or blank, no 0 entries
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("").replace(" ", "")
outdf['in_Longitude'].unique()
# Out:
# array([-103.7428  , -103.4177  , -104.0516  , ...,  -98.489546,
#         -98.489522, -100.63083 ])

# %%
# Ensure Amount entry is either numireic or blank, no 0 entries
outdf['in_Amount'] = pd.to_numeric(outdf['in_Amount'], errors='coerce').replace(0,"").fillna("")
outdf['in_Amount'].unique()
# Out:
# array([3.4, 2.6, 1.9, ..., 55.57000006, 55.54000006, 234.04], dtype=object)

# %%
# Convert TimeframeEnd to YYYY-MM-DD format.
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf['in_TimeframeEnd'], utc=True, errors = 'coerce').fillna("")
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf["in_TimeframeEnd"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeEnd'].unique()
# Out:
# array(['2012-05-18T00:00:00.000000000', '2012-05-19T00:00:00.000000000',
#        '2012-05-20T00:00:00.000000000', ...,
#        '1934-12-12T00:00:00.000000000', '1942-03-26T00:00:00.000000000',
#        '1968-09-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# Convert TimeframeStart to YYYY-MM-DD format.
outdf['in_TimeframeStart'] = pd.to_datetime(outdf['in_TimeframeStart'], utc=True, errors = 'coerce').fillna("")
outdf['in_TimeframeStart'] = pd.to_datetime(outdf["in_TimeframeStart"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeStart'].unique()
# Out:
# array(['2012-05-18T00:00:00.000000000', '2012-05-19T00:00:00.000000000',
#        '2012-05-20T00:00:00.000000000', ...,
#        '1934-12-12T00:00:00.000000000', '1942-03-26T00:00:00.000000000',
#        '1968-09-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# extract year out
# outdf['in_ReportYearCV'] = pd.to_datetime(outdf['in_ReportYearCV'], utc=True)
# outdf['in_ReportYearCV'] = pd.to_datetime(outdf["in_ReportYearCV"].dt.strftime('%m/%d/%Y'))
# outdf['in_ReportYearCV'] = outdf['in_ReportYearCV'].dt.year
outdf['in_ReportYearCV'].unique()
# Out:
# array(['2012-05-18T00:00:00-05:00', '2012-05-19T00:00:00-05:00',
#        '2012-05-20T00:00:00-05:00', ..., 1885.0, 1924.0, 1900.0],
#       dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)
dfWaterSourceNativeID['linkKey'] = dfWaterSourceNativeID['in_WaterSourceName'].astype(str) + dfWaterSourceNativeID['in_WaterSourceTypeCV'].astype(str)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
WaterSourceNativeIDdict = pd.Series(dfWaterSourceNativeID.in_WaterSourceNativeID.values, index=dfWaterSourceNativeID.linkKey.astype(str)).to_dict()
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        colrowValue = str(A).strip() + str(B).strip()
        try:
            outList = WaterSourceNativeIDdict[colrowValue]
        except:
            outList = ''
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID( row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeID1', 'wadeID2'], dtype=object)

# %% [markdown]
# ## Export Outputs

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1925643 entries, 0 to 1925642
# Data columns (total 47 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   WaDEUUID                          object
#  1   in_MethodUUID                     object
#  2   in_VariableSpecificUUID           object
#  3   in_OrganizationUUID               object
#  4   in_Geometry                       object
#  5   in_GNISFeatureNameCV              object
#  6   in_WaterQualityIndicatorCV        object
#  7   in_WaterSourceName                object
#  8   in_WaterSourceNativeID            object
#  9   in_WaterSourceTypeCV              object
#  10  in_CoordinateAccuracy             object
#  11  in_CoordinateMethodCV             object
#  12  in_County                         object
#  13  in_EPSGCodeCV                     int64
#  14  in_GNISCodeCV                     object
#  15  in_HUC12                          object
#  16  in_HUC8                           object
#  17  in_Latitude                       float64
#  18  in_Longitude                      float64
#  19  in_NHDNetworkStatusCV             object
#  20  in_NHDProductCV                   object
#  21  in_PODorPOUSite                   object
#  22  in_SiteName                       object
#  23  in_SiteNativeID                   object
#  24  in_SitePoint                      object
#  25  in_SiteTypeCV                     object
#  26  in_StateCV                        object
#  27  in_USGSSiteID                     object
#  28  in_Amount                         object
#  29  in_AllocationCropDutyAmount       object
#  30  in_AssociatedNativeAllocationIDs  object
#  31  in_BeneficialUseCategory          object
#  32  in_CommunityWaterSupplySystem     object
#  33  in_CropTypeCV                     object
#  34  in_CustomerTypeCV                 object
#  35  in_DataPublicationDate            object
#  36  in_DataPublicationDOI             object
#  37  in_IrrigatedAcreage               object
#  38  in_IrrigationMethodCV             object
#  39  in_PopulationServed               object
#  40  in_PowerGeneratedGWh              object
#  41  in_PowerType                      object
#  42  in_PrimaryUseCategory             object
#  43  in_ReportYearCV                   object
#  44  in_SDWISIdentifier                object
#  45  in_TimeframeEnd                   datetime64[ns]
#  46  in_TimeframeStart                 datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(1), object(42)
# memory usage: 690.5+ MB

# %%
outdf
# Out:
#           WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0            tsNE0     NEssro_M1               NEssro_V1           NEssro_O1
# 1            tsNE1     NEssro_M1               NEssro_V1           NEssro_O1
# 2            tsNE2     NEssro_M1               NEssro_V1           NEssro_O1
# 3            tsNE3     NEssro_M1               NEssro_V1           NEssro_O1
# 4            tsNE4     NEssro_M1               NEssro_V1           NEssro_O1
# ...            ...           ...                     ...                 ...
# 1925638  wlNE23988     NEssro_M1               NEssro_V2           NEssro_O2
# 1925639  wlNE23988     NEssro_M1               NEssro_V2           NEssro_O2
# 1925640  wlNE23988     NEssro_M1               NEssro_V2           NEssro_O2
# 1925641  wlNE23988     NEssro_M1               NEssro_V2           NEssro_O2
# 1925642  wlNE23989     NEssro_M1               NEssro_V2           NEssro_O2
#
#         in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0                                                             Fresh
# 1                                                             Fresh
# 2                                                             Fresh
# 3                                                             Fresh
# 4                                                             Fresh
# ...             ...                  ...                        ...
# 1925638                                                       Fresh
# 1925639                                                       Fresh
# 1925640                                                       Fresh
# 1925641                                                       Fresh
# 1925642                                                       Fresh
#
#         in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                         wadeID1        Surface Water
# 1                                         wadeID1        Surface Water
# 2                                         wadeID1        Surface Water
# 3                                         wadeID1        Surface Water
# 4                                         wadeID1        Surface Water
# ...                    ...                    ...                  ...
# 1925638                                   wadeID2          Groundwater
# 1925639                                   wadeID2          Groundwater
# 1925640                                   wadeID2          Groundwater
# 1925641                                   wadeID2          Groundwater
# 1925642                                   wadeID2          Groundwater
#
#         in_CoordinateAccuracy in_CoordinateMethodCV   in_County  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                   ...         ...
# 1925638                                                 Wheeler
# 1925639                                                 Wheeler
# 1925640                                                 Wheeler
# 1925641                                                 Wheeler
# 1925642                                              Red Willow
#
#          in_EPSGCodeCV in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  \
# 0                 4326                                    42.92226
# 1                 4326                                    42.92226
# 2                 4326                                    42.92226
# 3                 4326                                    42.92226
# 4                 4326                                    42.92226
# ...                ...           ...      ...     ...          ...
# 1925638           4326                                    42.00850
# 1925639           4326                                    42.00850
# 1925640           4326                                    42.00850
# 1925641           4326                                    42.00850
# 1925642           4326                                    40.22045
#
#          in_Longitude in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0          -103.74280                                                  Gage
# 1          -103.74280                                                  Gage
# 2          -103.74280                                                  Gage
# 3          -103.74280                                                  Gage
# 4          -103.74280                                                  Gage
# ...               ...                   ...             ...             ...
# 1925638     -98.48952                                                  Gage
# 1925639     -98.48952                                                  Gage
# 1925640     -98.48952                                                  Gage
# 1925641     -98.48952                                                  Gage
# 1925642    -100.63083                                                  Gage
#
#                    in_SiteName in_SiteNativeID in_SitePoint in_SiteTypeCV  \
# 0        Hat Creek At Montrose           62500                     Stream
# 1        Hat Creek At Montrose           62500                     Stream
# 2        Hat Creek At Montrose           62500                     Stream
# 3        Hat Creek At Montrose           62500                     Stream
# 4        Hat Creek At Montrose           62500                     Stream
# ...                        ...             ...          ...           ...
# 1925638                                   W-4S
# 1925639                                   W-4S
# 1925640                                   W-4S
# 1925641                                   W-4S
# 1925642                               West Dam
#
#         in_StateCV in_USGSSiteID in_Amount in_AllocationCropDutyAmount  \
# 0               NE                 3.40000
# 1               NE                 2.60000
# 2               NE                 1.90000
# 3               NE                 1.30000
# 4               NE                 0.81000
# ...            ...           ...       ...                         ...
# 1925638         NE                17.57000
# 1925639         NE                13.15000
# 1925640         NE                14.85000
# 1925641         NE                16.70000
# 1925642         NE
#
#         in_AssociatedNativeAllocationIDs in_BeneficialUseCategory  \
# 0                                                      WaDE Blank
# 1                                                      WaDE Blank
# 2                                                      WaDE Blank
# 3                                                      WaDE Blank
# 4                                                      WaDE Blank
# ...                                  ...                      ...
# 1925638                                                WaDE Blank
# 1925639                                                WaDE Blank
# 1925640                                                WaDE Blank
# 1925641                                                WaDE Blank
# 1925642                                                WaDE Blank
#
#         in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...           ...               ...
# 1925638
# 1925639
# 1925640
# 1925641
# 1925642
#
#         in_DataPublicationDate in_DataPublicationDOI in_IrrigatedAcreage  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                   ...                 ...
# 1925638
# 1925639
# 1925640
# 1925641
# 1925642
#
#         in_IrrigationMethodCV in_PopulationServed in_PowerGeneratedGWh  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                 ...                  ...
# 1925638
# 1925639
# 1925640
# 1925641
# 1925642
#
#         in_PowerType in_PrimaryUseCategory            in_ReportYearCV  \
# 0                                           2012-05-18T00:00:00-05:00
# 1                                           2012-05-19T00:00:00-05:00
# 2                                           2012-05-20T00:00:00-05:00
# 3                                           2012-05-21T00:00:00-05:00
# 4                                           2012-05-22T00:00:00-05:00
# ...              ...                   ...                        ...
# 1925638                                                    2006.00000
# 1925639                                                    2020.00000
# 1925640                                                    2021.00000
# 1925641                                                    2022.00000
# 1925642
#
#         in_SDWISIdentifier in_TimeframeEnd in_TimeframeStart
# 0                               2012-05-18        2012-05-18
# 1                               2012-05-19        2012-05-19
# 2                               2012-05-20        2012-05-20
# 3                               2012-05-21        2012-05-21
# 4                               2012-05-22        2012-05-22
# ...                    ...             ...               ...
# 1925638                         2006-10-24        2006-10-24
# 1925639                         2020-03-23        2020-03-23
# 1925640                         2021-03-22        2021-03-22
# 1925641                         2022-03-17        2022-03-17
# 1925642                                NaT               NaT
#
# [1925643 rows x 47 columns]

# %%
# Export the output dataframe
outdf.to_csv('Pssro_neMain.zip', compression=dict(method='zip', archive_name='Pssro_neMain.csv'), index=False)  # The output, save as a zip
