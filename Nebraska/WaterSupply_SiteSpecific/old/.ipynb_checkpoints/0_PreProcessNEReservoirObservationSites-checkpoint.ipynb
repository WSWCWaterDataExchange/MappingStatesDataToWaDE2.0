# %% [markdown]
# # Preprocessing Nebraska Reservoir and Observation Site data for WaDE

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/Nebraska/SS_ReservoirsObservationSites/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## API Site Data

# %%
# done already

# %%time
# # Retrieve list of only NeDNRstream gage stations
# #######################################

# # API retrieval
# url = "https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/GetStationList"
# responseD = json.loads(requests.get(url).text)
# DtL = responseD['Results']
# length = len(DtL)

# # create dataframe and store
# df = pd.DataFrame()
# for i in range(length):
#     row = pd.DataFrame([DtL[i]])
#     df = pd.concat([df, row])

# # Use only NeNDR Active provided sites
# df = df[df['SourceName'] == 'NeDNR']

# # Exporting output files.
# df.to_csv('StreamGageGetStationList.csv', index=False)  # The output.

# %%
# Input File - StreamGageGetStationList.csv
sgInput = "StreamGageGetStationList.csv"
dfsg = pd.read_csv(sgInput)

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfsg:
    dfsg['WaDEUUID'] = "nebRG" + dfsg.index.astype(str)
    dfsg.to_csv('StreamGageGetStationList.csv', index=False)

dfsg.head(1)
# Out:
#                          StationName SourceName  StationNumber  \
# 0  Parks Canal from Republican River      NeDNR         120500
#
#          RiverBasin FieldOffice StationTypeDescription  Downstream TimeZone  \
# 0  Republican River         NaN             Canal/Pump           0      MST
#
#    Elevation ElevationUnits   Longitude   Latitude  IsActive WaDEUUID
# 0        0.0             ft -101.733703  40.030071      True   nebRG0

# %%
# # Input File - Stream_Gages_NDNR.csv
# sgInput = "Stream_Gages_NDNR.xlsx"
# dfsg = pd.read_excel(sgInput)

# # WaDE UUID tracker for data assessment
# if 'WaDEUUID' not in dfsg:
#     dfsg['WaDEUUID'] = "nebRG" + dfsg.index.astype(str)
#     dfsg.to_excel('Stream_Gages_NDNR.xlsx', index=False)

# dfsg.head(1)

# %%
# Update StationNumber values must have 8 digits, with leading 0s

def updateStationNumber(x):
    x = str(x).strip()
    if len(x) == 4:
        x = "0000" + x
    if len(x) == 5:
        x = "000" + x
    if len(x) == 6:
        x = "00" + x
    if len(x) == 7:
        x = "0" + x
    return x

dfsg['StationNumber'] = dfsg.apply(lambda row: updateStationNumber(row['StationNumber']), axis=1)
dfsg.head()
# Out:
#                                 StationName SourceName StationNumber  \
# 0         Parks Canal from Republican River      NeDNR      00120500
# 1                     Hat Creek at Montrose      NeDNR      00062500
# 2                   White River at Crawford      NeDNR      06444000
# 3        Whitney Reservoir from White River      NeDNR      00410000
# 4  Niobrara River at Wyoming-Nebraska State      NeDNR      06454000
#
#          RiverBasin FieldOffice StationTypeDescription  Downstream TimeZone  \
# 0  Republican River         NaN             Canal/Pump           0      MST
# 1       White River  Bridgeport                 Stream        1500      MST
# 2       White River  Bridgeport                 Stream        2300      MST
# 3       White River  Bridgeport              Reservoir        2350      MST
# 4    Niobrara River  Bridgeport                 Stream        4005      MST
#
#    Elevation ElevationUnits   Longitude   Latitude  IsActive WaDEUUID
# 0      0.000             ft -101.733703  40.030071      True   nebRG0
# 1   3635.126             ft -103.742800  42.922260      True   nebRG1
# 2   3658.297             ft -103.417700  42.686640      True   nebRG2
# 3      0.000             ft -103.309400  42.792110      True   nebRG3
# 4   4685.993             ft -104.051600  42.652520      True   nebRG4

# %%
# Get list of StationNumber
streamgageIdList = dfsg['StationNumber'].tolist()   
print(len(streamgageIdList))
streamgageIdList
# Out:
# 210
# ['00120500',
#  '00062500',
#  '06444000',
#  '00410000',
#  '06454000',
#  '00072000',
#  '00079000',
#  '06454050',
#  '00038100',
#  '00038200',
#  '00084000',
#  '00029000',
#  '00062000',
#  '06454100',
#  '00078000',
#  '00089000',
#  '00013000',
#  '00104000',
#  '00063000',
#  '00086000',
#  '00046000',
#  '00069000',
#  '00123000',
#  '06454500',
#  '06455500',
#  '00081000',
#  '00100000',
#  '06456500',
#  '06457500',
#  '06459025',
#  '06459175',
#  '00001000',
#  '06459500',
#  '06464900',
#  '06464930',
#  '06465700',
#  '00225000',
#  '06678500',
#  '00101100',
#  '00056000',
#  '00145100',
#  '00002692',
#  '06677500',
#  '06678000',
#  '00040000',
#  '06679000',
#  '06679500',
#  '06680000',
#  '00148000',
#  '00149000',
#  '00022000',
#  '06681000',
#  '00099000',
#  '06680970',
#  '00021000',
#  '00144400',
#  '06682000',
#  '06681999',
#  '06681998',
#  '00106000',
#  '00106100',
#  '06682500',
#  '00133000',
#  '00024000',
#  '00002000',
#  '00003000',
#  '00115100',
#  '00002696',
#  '06683000',
#  '06684000',
#  '00009000',
#  '06684500',
#  '06684498',
#  '06684499',
#  '06685000',
#  '00010000',
#  '00039000',
#  '00019000',
#  '00030000',
#  '00080000',
#  '00144200',
#  '00105500',
#  '00088000',
#  '00007000',
#  '00082000',
#  '06686000',
#  '00098000',
#  '00120000',
#  '00017200',
#  '00067000',
#  '00146000',
#  '06687000',
#  '06687500',
#  '00138000',
#  '06690500',
#  '00076000',
#  '00114000',
#  '00121000',
#  '06691000',
#  '00016000',
#  '00136000',
#  '06692000',
#  '00027000',
#  '06692500',
#  '06693000',
#  '00219500',
#  '06763500',
#  '00147000',
#  '00147001',
#  '06764900',
#  '00140000',
#  '06765500',
#  '00140003',
#  '00142001',
#  '00144000',
#  '00228500',
#  '06765980',
#  '06765990',
#  '06766000',
#  '00143000',
#  '00141000',
#  '00057000',
#  '00019500',
#  '00033000',
#  '00117000',
#  '00037000',
#  '06766498',
#  '06766499',
#  '06766500',
#  '06766650',
#  '00122000',
#  '06767500',
#  '00073000',
#  '00075000',
#  '06770000',
#  '00145700',
#  '06770195',
#  '06770240',
#  '00229300',
#  '06772000',
#  '00130000',
#  '00090000',
#  '00090200',
#  '00091000',
#  '00092000',
#  '00093000',
#  '00047000',
#  '00093200',
#  '00048000',
#  '00049000',
#  '06780000',
#  '06783500',
#  '06784800',
#  '00107000',
#  '00107100',
#  '00107200',
#  '00076500',
#  '00019800',
#  '06787000',
#  '00100500',
#  '00088500',
#  '00054700',
#  '06787500',
#  '00108000',
#  '06788500',
#  '00109000',
#  '06788988',
#  '06791500',
#  '06792000',
#  '00082100',
#  '06793500',
#  '06794500',
#  '06796973',
#  '06798000',
#  '06798500',
#  '06798780',
#  '06799080',
#  '00410300',
#  '00232500',
#  '06799230',
#  '06799385',
#  '06799450',
#  '06799510',
#  '00061500',
#  '06831500',
#  '06835000',
#  '00127000',
#  '06837300',
#  '06837500',
#  '06843400',
#  '06838500',
#  '06839970',
#  '06840000',
#  '06841000',
#  '06842500',
#  '00224600',
#  '06844000',
#  '00231700',
#  '06844210',
#  '06850000',
#  '06851090',
#  '06851500',
#  '06879900',
#  '06880000',
#  '06880500',
#  '06881200',
#  '06881500',
#  '06883555',
#  '06883940',
#  '06884005']

# %% [markdown]
# ## Timeseries Data

# %% [markdown]
# ### DailyMeanByYear

# %%
# %%time
# # get timeseries results
# # use StationNumber in url

# # create empty dataframe
# dfts = pd.DataFrame()

# sglength = len(streamgageIdList)
# for i in range(sglength):
#     serviceStr = "DailyMeanByYear" # change here
#     url = "https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/" + serviceStr + "?StationNumber=" + str(streamgageIdList[i])
#     try:
#         responseD = json.loads(requests.get(url).text)
#         DtL = responseD['Results']

#         # store in dataframe
#         dftemp = pd.DataFrame()
#         length = len(DtL)
#         for x in range(length):
#             row = pd.DataFrame([DtL[x]])
#             row['url'] = url
#             row['service'] = serviceStr
#             dftemp = pd.concat([dftemp, row])

#         dfts = pd.concat([dfts, dftemp])
    
#     except:
#         dftemp = pd.DataFrame()
#         dftemp['url'] = url
#         dfts = pd.concat([dfts, dftemp])
#         print("Error, issue with API return.")

# dfts.to_csv('DailyMeanByYear.csv', index=False)  # The output.
# print(len(dfts))
# dfts.head()

# %%
# # Input File - DailyMeanByYear.csv
# fileInput = "DailyMeanByYear.csv"
# dfts = pd.read_csv(fileInput)

# # WaDE UUID tracker for data assessment
# if 'WaDEUUID' not in dfts:
#     dfts['WaDEUUID'] = "neRG" + dfts.index.astype(str)
#     dfts.to_csv('DailyMeanByYear.csv', index=False)

# dfts.head(1)

# %%
# Year list
yearList = ["2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009",
            "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019",
            "2020", "2021", "2022"]

# %%
# %%time
# get timeseries results
# use StationNumber in url

# create empty dataframe
dfts = pd.DataFrame()

sgLength = len(streamgageIdList)
ylLength = len(yearList)

for i in range(sgLength):
    serviceStr = "DailyMeanByYear" # change here
    for j in range(ylLength):
        url = "https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/" + serviceStr + "?StationNumber=" + str(streamgageIdList[i]) + "&MeanYear=" + str(yearList[j])
        print(url)
        try:
            responseD = json.loads(requests.get(url).text)
            DtL = responseD['Results']

            # store in dataframe
            dftemp = pd.DataFrame()
            length = len(DtL)
            for x in range(length):
                row = pd.DataFrame([DtL[x]])
                row['url'] = url
                row['service'] = serviceStr
                dftemp = pd.concat([dftemp, row])

            dfts = pd.concat([dfts, dftemp])
        except:
            dftemp = pd.DataFrame()
            dftemp['url'] = url
            dfts = pd.concat([dfts, dftemp])
            print("Error, issue with API return.")

print(len(dfts))
dfts.head()
# Out:
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2000
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2001
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2002
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2003
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2004
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2005
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2006
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2007
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2008
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2009
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2010
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2011
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2012
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2013
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2014
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2015
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2016
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2017
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2018
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2019
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2020
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2021
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00120500&MeanYear=2022
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2000
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2001
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2002
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2003
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2004
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2005
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2006
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2007
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2008
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2009
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2010
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2011
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2012
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2013
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2014
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2015
# Error, issue with API return.
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2016
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2017
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2018
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2019
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2020
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2021
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=00062500&MeanYear=2022
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=06444000&MeanYear=2000
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=06444000&MeanYear=2001
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=06444000&MeanYear=2002
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=06444000&MeanYear=2003
# https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/DailyMeanByYear?StationNumber=06444000&MeanYear=2004

# %%
# Update StationNumber values must have 8 digits, with leading 0s

def updateStationNumber(x):
    x = str(x).strip()
    if len(x) == 4:
        x = "0000" + x
    if len(x) == 5:
        x = "000" + x
    if len(x) == 6:
        x = "00" + x
    if len(x) == 7:
        x = "0" + x
    return x

dfts['StationNumber'] = dfts.apply(lambda row: updateStationNumber(row['StationNumber']), axis=1)
dfts.head()

# %% [markdown]
# ## Output Dataframe

# %%
 #Merging dataframes into one, using left-join.
df = pd.merge(dfts, dfsg, on='StationNumber', how='left')
print(len(df))
df.head(1)

# %%
# # output dataframe
# dfout = pd.DataFrame(index=df.index)

# # Site Info
# dfout['in_Latitude'] = df['Latitude']
# dfout['in_Longitude'] = df['Longitude']
# dfout['in_PODorPOUSite'] = "Gage"
# dfout['in_SiteName'] = df['StationName']
# dfout['in_SiteNativeID'] = df['StationNumber']
# dfout['in_SiteTypeCV'] = df['StationTypeDescription']

# # Site VariableAmounts Info
# dfout['in_Amount'] = df['Value']
# dfout['in_BeneficialUseCategory'] = "Unspecified"
# dfout['in_ReportYearCV'] = df['Date']
# dfout['in_TimeframeEnd'] = df['Date']
# dfout['in_TimeframeStart'] = df['Date']

# print(len(dfout))
# dfout.head(1)

# %%
# output dataframe
dfout = pd.DataFrame(index=df.index)

# Site Info
dfout['in_Latitude'] = df['Latitude']
dfout['in_Longitude'] = df['Longitude']
dfout['in_PODorPOUSite'] = "Observation Site"
dfout['in_SiteName'] = df['StationName']
dfout['in_SiteNativeID'] = df['StationNumber']
dfout['in_SiteTypeCV'] = "Unspecified"

# Site VariableAmounts Info
dfout['in_Amount'] = df['Value']
dfout['in_BeneficialUseCategory'] = "Unspecified"
dfout['in_ReportYearCV'] = df['Date']
dfout['in_TimeframeEnd'] = df['Date']
dfout['in_TimeframeStart'] = df['Date']

print(len(dfout))
dfout.head(1)

# %% [markdown]
# ## Cleaning Output

# %%
dfout.info()
dfout.head(1)

# %%
# Convert History Year to YYYY-MM-DD format.
dfout['in_TimeframeEnd'] = pd.to_datetime(dfout['in_TimeframeEnd'], utc=True)
dfout['in_TimeframeEnd'] = pd.to_datetime(dfout["in_TimeframeEnd"].dt.strftime('%m/%d/%Y'))

dfout['in_TimeframeStart'] = pd.to_datetime(dfout['in_TimeframeStart'], utc=True)
dfout['in_TimeframeStart'] = pd.to_datetime(dfout["in_TimeframeStart"].dt.strftime('%m/%d/%Y'))

dfout.head(1)

# %%
# extract year out
dfout['in_ReportYearCV'] = pd.to_datetime(dfout['in_ReportYearCV'], utc=True)
dfout['in_ReportYearCV'] = pd.to_datetime(dfout["in_ReportYearCV"].dt.strftime('%m/%d/%Y'))
dfout['in_ReportYearCV'] = dfout['in_ReportYearCV'].dt.year
dfout.head(1)

# %%
# in_Latitude & in_Longitude
dfout['in_Latitude'] = pd.to_numeric(dfout['in_Latitude'], errors='coerce').fillna(0)
dfout['in_Longitude'] = pd.to_numeric(dfout['in_Longitude'], errors='coerce').fillna(0)
dfout.head(1)

# %% [markdown]
# ## Export Outputs

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(dfout.dtypes)

# %%
# #Exporting to Finished File
# dfout.to_csv('P_neSSRGMain.csv', index=False)  # The output

#Exporting to Finished File
dfout.to_csv('P_StreamGageGetList_neSSRGMain.csv', index=False)  # The output

# %%
dfout['in_ReportYearCV'].unique()
