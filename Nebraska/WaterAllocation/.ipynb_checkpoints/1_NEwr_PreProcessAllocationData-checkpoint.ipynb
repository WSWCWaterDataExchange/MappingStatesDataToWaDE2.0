# %% [markdown]
# # Pre-processing Nebraska Allocation data for WaDEQA upload.
# Date Updated: 10/04/2023
# Purpose:  To pre-process the Nebraska data into one master file for simple DataFrame creation and extraction
#
# ### Notes:
# - asfd

# %%
# Needed Libraries / Modules

# ---- working with data ----
import os  # native operating system interaction
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/Nebraska/WaterAllocation" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/Nebraska/WaterAllocation

# %% [markdown]
# # POD Surface Water Data
# - data already pulled from api, used saved csv instead

# %%
# # already done, skip ahead

# %%time
# # API retrieval
# # shoot for 30 pages, that seemed to be all that AllSurfaceWaterPoints offered.
# df = pd.DataFrame()
# countPage = 1
# while countPage < 30:
#     url = "https://nednr.nebraska.gov/IwipApi/api/v1/WaterRights/AllSurfaceWaterPoints?page=" + str(countPage)
#     print(url)

#     # store in dataframe
#     try:
#         responseD = json.loads(requests.get(url).text)
#         DtL = responseD['Results']
#         length = len(DtL)
#         for i in range(length):
#             row = pd.DataFrame([DtL[i]])
#             df = pd.concat([df, row])
#     except:
#         print("Error, issue with API return.")
    
#     countPage = countPage + 1

# # # Use only NeNDR Active provided sites
# # df = df[df['SourceName'] == 'NeDNR']

# print(len(df))
# df.head()

# %%
# # already done, skip ahead

# # explode these list....
# dftemp = df.copy()
# dftemp = dftemp.explode('NoticeExemptions')
# dftemp = dftemp.explode('Notices')
# dftemp = dftemp.explode('PointOfDiversions')
# dftemp = dftemp.explode('Contacts')

# print(len(dftemp))
# dftemp.head(1)

# %%
# # already done, skip ahead

# # To unpack column's dictionary value new into separate columns -> contact to existing dataframe -> drop unpacked column
# dftemp = pd.concat([dftemp, dftemp["RightUse"].apply(pd.Series)], axis=1).drop(columns="RightUse")
# dftemp = pd.concat([dftemp, dftemp["NoticeExemptions"].apply(pd.Series)], axis=1).drop(columns="NoticeExemptions")
# dftemp = pd.concat([dftemp, dftemp["Notices"].apply(pd.Series)], axis=1).drop(columns="Notices")
# dftemp = pd.concat([dftemp, dftemp["PointOfDiversions"].apply(pd.Series)], axis=1).drop(columns="PointOfDiversions")
# dftemp = pd.concat([dftemp, dftemp["Contacts"].apply(pd.Series)], axis=1).drop(columns="Contacts")

# print(len(dftemp))
# dftemp.head(1)

# %%
# # already done, skip ahead

# # Clean Data
# # we don't really need the 'NoticeExemptions' at this time
# dropList = ['PumpSheets', 'SpecialConditions', 'NoticeID', 'NoticeType', 'NoticeDate', 'EffectiveDate', 'ReasonForAdminAction', 'Notes', 'DeleteNotice']
# dftemp = dftemp.drop(dropList, axis=1).drop_duplicates().reset_index(drop=True)
# #dftemp = dftemp.drop(dropList, axis=1)
# print(len(dftemp))
# dftemp.head()

# %%
# # already done, skip ahead

# # export api data
# dftemp.to_csv('RawInputData/AllSurfaceWaterPoints.zip', compression=dict(method='zip', archive_name='AllSurfaceWaterPoints.csv'), index=False)  # The output, save as a zip

# %%
# POD Data
# read in the above API data that was saved to hard file
PoDAAInput = "RawInputData/AllSurfaceWaterPoints.zip"
dfPoD = pd.read_csv(PoDAAInput).replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfPoD:
    dfPoD['WaDEUUID'] = "neD" + dfPoD.index.astype(str)
    dfPoD.to_csv('RawInputData/AllSurfaceWaterPoints.zip', compression=dict(method='zip', archive_name='AllSurfaceWaterPoints.csv'), index=False)
    
print(len(dfPoD))
dfPoD.head(1)
# Out:
# 28711
# C:\Users\rjame\AppData\Local\Temp\ipykernel_15180\1163056749.py:4: DtypeWarning: Columns (63,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfPoD = pd.read_csv(PoDAAInput).replace(np.nan, "")
#    RightID RightStatus ApplicationName StartDownStream WaterDivision  \
# 0        1      Active          A-365R      8955.00000            1A
#
#   FieldOffice        CarrierA          SourceName ProGrant Units  \
# 0  Bridgeport  Central Canal   North Platte River  0.04000   CFS
#
#   InstantaneousGrant VolumetricGrant ReservoirCapacityGrant      GPM  \
# 0                                                           17.00000
#
#   GrantCounted AcresCounted Rate CurrentTotalAcres AnnualReportRequired  \
# 0          Yes           No                0.00000                   No
#
#   Annotation         PriorityDate BeneficialDate         ApprovalDate  \
# 0  U-29       1897-03-15T00:00:00                 1996-03-05T00:00:00
#
#          LastOrderDate           IrrigationDistrict IrrigationProject  \
# 0  2011-04-26T00:00:00  Central Irrigation District     Central Canal
#
#   PermitGroup  IsDeleted LatitudeDecimalDegrees LongitudeDecimalDegrees  \
# 0      Public      False               41.85584              -103.70574
#
#   UseCode                  UseDescription SendNotices UseTypeDescription 0  \
# 0      US  Incidental Underground Storage         Yes       Natural Flow
#
#   ExemptionDescription 0.1  Section SubSection Township    Range  \
# 0                          28.00000      NE NW 22.00000 55.00000
#
#   RangeDirection    CountyName       NrdName              HUC12 Upstream  \
# 0           West  Scotts Bluff  North Platte 101800090810.00000      Yes
#
#   PrimaryIndicator PODStatus     LegalDescription LatitudeDecimalDegrees.1  \
# 0          Primary    Active  NE NW S28 T22N-R55W                 41.85584
#
#   LongitudeDecimalDegrees.1 0.2 ContactId FirstName  \
# 0                -103.70574     754.00000
#
#                       LastName ContactType  SeqNum BeginDate EndDate  \
# 0  Central Irrigation District       Owner 1.00000
#
#            Address1 Address2    City     State    Zip           Phone1 Phone2  \
# 0  230450 Crow Road           Gering  Nebraska  69341 3086413425.00000
#
#   Phone3 LicenseNumber IsDeleted.1 0.3 WaDEUUID
# 0                               No         neD0

# %%
# Drop non-Active AllocationLegalStatusCV Water Rights
# We only want Active water rights
# We only want active POD sites
dfPoD = dfPoD[dfPoD['RightStatus'] == 'Active'].reset_index(drop=True)
dfPoD = dfPoD[dfPoD['PODStatus'] == 'Active'].reset_index(drop=True)
print(len(dfPoD))
dfPoD.head(1)
# Out:
# 21948
#    RightID RightStatus ApplicationName StartDownStream WaterDivision  \
# 0        1      Active          A-365R      8955.00000            1A
#
#   FieldOffice        CarrierA          SourceName ProGrant Units  \
# 0  Bridgeport  Central Canal   North Platte River  0.04000   CFS
#
#   InstantaneousGrant VolumetricGrant ReservoirCapacityGrant      GPM  \
# 0                                                           17.00000
#
#   GrantCounted AcresCounted Rate CurrentTotalAcres AnnualReportRequired  \
# 0          Yes           No                0.00000                   No
#
#   Annotation         PriorityDate BeneficialDate         ApprovalDate  \
# 0  U-29       1897-03-15T00:00:00                 1996-03-05T00:00:00
#
#          LastOrderDate           IrrigationDistrict IrrigationProject  \
# 0  2011-04-26T00:00:00  Central Irrigation District     Central Canal
#
#   PermitGroup  IsDeleted LatitudeDecimalDegrees LongitudeDecimalDegrees  \
# 0      Public      False               41.85584              -103.70574
#
#   UseCode                  UseDescription SendNotices UseTypeDescription 0  \
# 0      US  Incidental Underground Storage         Yes       Natural Flow
#
#   ExemptionDescription 0.1  Section SubSection Township    Range  \
# 0                          28.00000      NE NW 22.00000 55.00000
#
#   RangeDirection    CountyName       NrdName              HUC12 Upstream  \
# 0           West  Scotts Bluff  North Platte 101800090810.00000      Yes
#
#   PrimaryIndicator PODStatus     LegalDescription LatitudeDecimalDegrees.1  \
# 0          Primary    Active  NE NW S28 T22N-R55W                 41.85584
#
#   LongitudeDecimalDegrees.1 0.2 ContactId FirstName  \
# 0                -103.70574     754.00000
#
#                       LastName ContactType  SeqNum BeginDate EndDate  \
# 0  Central Irrigation District       Owner 1.00000
#
#            Address1 Address2    City     State    Zip           Phone1 Phone2  \
# 0  230450 Crow Road           Gering  Nebraska  69341 3086413425.00000
#
#   Phone3 LicenseNumber IsDeleted.1 0.3 WaDEUUID
# 0                               No         neD0

# %%
# assign VariableSpecificUUID

def assignVariableSpecificUUID(colvA):
    outList = ''
    colvA = str(colvA).strip()
    if colvA == "CFS":
        outList = "NEwr_V1"
    if colvA == "AF":
        outList = "NEwr_V2"

    return outList

dfPoD['in_VariableSpecificUUID'] = dfPoD.apply(lambda row: assignVariableSpecificUUID(row['Units']), axis=1)
dfPoD['in_VariableSpecificUUID'].unique()
# Out:
# array(['NEwr_V1', 'NEwr_V2', ''], dtype=object)

# %%
# AllocationFlow_CFS - based on reporeted Unit

def assignAllocationFlow_CFS(colvA, colvB):
    if colvA == '' or pd.isnull(colvA):
        outList = ''
    else:
        colvB = colvB.strip()
        if colvB == "CFS":
            outList = colvA
        else:
            outList = ''
    return outList

dfPoD['AllocationFlow_CFS'] = dfPoD.apply(lambda row: assignAllocationFlow_CFS(row['ProGrant'], row['Units']), axis=1)
dfPoD['AllocationFlow_CFS'].unique()
# Out:
# array([0.04, 0.16, 0.01, 0.02, 0.38, 0.06, 1.01, 0.33, 0.23, 1.43, 0.5,
#        1.63, 0.12, 0.61, 0.86, 0.11, 2.22, 13.0, 0.21, 0.15, 1.28, '',
#        0.48, 0.19, 1572.0, 780.59, 191.86, 15.63, 192.56, 0.14, 861.0,
#        45.0, 230.07, 0.0, 0.27, 0.74, 3.07, 2.0, 0.3, 0.79, 1.14, 0.57,
#        0.43, 5.14, 0.46, 111.51, 10.0, 3.0, 1.0, 15.0, 1.59, 2.28, 18.19,
#        4.0, 14.38, 24.38, 0.17, 2.24, 5.68, 95.94, 82.48, 3.05, 0.4, 2.26,
#        66.18, 1.02, 37.76, 42.5, 60.0, 0.09, 20.06, 2.92, 0.67, 30.99,
#        1.07, 2.71, 4.91, 0.22, 90.4, 28.57, 0.31, 42.71, 1.11, 59.88, 0.8,
def assignAllocationVolume_AF(colvA, colvB):
    if colvA == '' or pd.isnull(colvA):
        outList = ''
    else:
        colvB = colvB.strip()
        if colvB == "AF":
            outList = colvA
        else:
            outList = ''
    return outList

dfPoD['AllocationVolume_AF'] = dfPoD.apply(lambda row: assignAllocationVolume_AF(row['ProGrant'], row['Units']), axis=1)
dfPoD['AllocationVolume_AF'].unique()
# Out:
# array(['', 10.0, 1.7, ..., 17.99, 34.09, 63.69], dtype=object)

# %%
dfPoD['WaterAllocationNativeURL'] = 'https://nednr.nebraska.gov/dynamic/WaterRights/WaterRights/SWRDetailPage?RightId=' + dfPoD['RightID'].astype(str)
dfPoD.head(1)
# Out:
#    RightID RightStatus ApplicationName StartDownStream WaterDivision  \
# 0        1      Active          A-365R      8955.00000            1A
#
#   FieldOffice        CarrierA          SourceName ProGrant Units  \
# 0  Bridgeport  Central Canal   North Platte River  0.04000   CFS
#
#   InstantaneousGrant VolumetricGrant ReservoirCapacityGrant      GPM  \
# 0                                                           17.00000
#
#   GrantCounted AcresCounted Rate CurrentTotalAcres AnnualReportRequired  \
# 0          Yes           No                0.00000                   No
#
#   Annotation         PriorityDate BeneficialDate         ApprovalDate  \
# 0  U-29       1897-03-15T00:00:00                 1996-03-05T00:00:00
#
#          LastOrderDate           IrrigationDistrict IrrigationProject  \
# 0  2011-04-26T00:00:00  Central Irrigation District     Central Canal
#
#   PermitGroup  IsDeleted LatitudeDecimalDegrees LongitudeDecimalDegrees  \
# 0      Public      False               41.85584              -103.70574
#
#   UseCode                  UseDescription SendNotices UseTypeDescription 0  \
# 0      US  Incidental Underground Storage         Yes       Natural Flow
#
#   ExemptionDescription 0.1  Section SubSection Township    Range  \
# 0                          28.00000      NE NW 22.00000 55.00000
#
#   RangeDirection    CountyName       NrdName              HUC12 Upstream  \
# 0           West  Scotts Bluff  North Platte 101800090810.00000      Yes
#
#   PrimaryIndicator PODStatus     LegalDescription LatitudeDecimalDegrees.1  \
# 0          Primary    Active  NE NW S28 T22N-R55W                 41.85584
#
#   LongitudeDecimalDegrees.1 0.2 ContactId FirstName  \
# 0                -103.70574     754.00000
#
#                       LastName ContactType  SeqNum BeginDate EndDate  \
# 0  Central Irrigation District       Owner 1.00000
#
#            Address1 Address2    City     State    Zip           Phone1 Phone2  \
# 0  230450 Crow Road           Gering  Nebraska  69341 3086413425.00000
#
#   Phone3 LicenseNumber IsDeleted.1 0.3 WaDEUUID in_VariableSpecificUUID  \
# 0                               No         neD0                 NEwr_V1
#
#   AllocationFlow_CFS AllocationVolume_AF  \
# 0            0.04000
#
#                             WaterAllocationNativeURL
# 0  https://nednr.nebraska.gov/dynamic/WaterRights...

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfPoD['WaDEUUID']

# # Method Info
df['in_MethodUUID'] = "NEwr_M1" # for surface water

# Variable Info
df['in_VariableSpecificUUID'] = dfPoD['in_VariableSpecificUUID']

# Organization Info
df['in_OrganizationUUID'] = "NEwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfPoD['SourceName']
df['in_WaterSourceNativeID'] = "" # auto fill in below
df['in_WaterSourceTypeCV'] = "Surface Water"

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = ""
df['in_EPSGCodeCV'] = "4326"
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = dfPoD['HUC12']
df['in_HUC8'] = ""
df['in_Latitude'] = dfPoD['LatitudeDecimalDegrees']
df['in_Longitude'] = dfPoD['LongitudeDecimalDegrees']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"
df['in_SiteName'] = ""
#df['in_SiteNativeID'] = "POD" + dfPoD['PointOfDiversionID'].replace("", 0).fillna(0).astype(int).astype(str)
df['in_SiteNativeID'] = ""
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = ""
df['in_StateCV'] = "NE"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = dfPoD['AllocationFlow_CFS']
df['in_AllocationLegalStatusCV'] = dfPoD['RightStatus']
df['in_AllocationNativeID'] =  dfPoD['RightID'].replace("", 0).fillna(0).astype(str).str.lower().str.strip()
df['in_AllocationOwner'] = dfPoD['FirstName'] + " " + dfPoD['LastName']
df['in_AllocationPriorityDate'] = dfPoD['PriorityDate']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = dfPoD['AllocationVolume_AF']
df['in_BeneficialUseCategory'] = dfPoD['UseDescription']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = dfPoD['WaterAllocationNativeURL']

outdfPoD = df.copy()
outdfPoD = outdfPoD.drop_duplicates().reset_index(drop=True)
print(len(outdfPoD))
outdfPoD.head()
# Out:
# 21948
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     neD0       NEwr_M1                 NEwr_V1             NEwr_O1
# 1     neD1       NEwr_M1                 NEwr_V1             NEwr_O1
# 2     neD2       NEwr_M1                 NEwr_V1             NEwr_O1
# 3     neD3       NEwr_M1                 NEwr_V1             NEwr_O1
# 4     neD4       NEwr_M1                 NEwr_V1             NEwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#    in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0  North Platte River                               Surface Water
# 1       Glenn Springs                               Surface Water
# 2       Glenn Springs                               Surface Water
# 3       Glenn Springs                               Surface Water
# 4       Glenn Springs                               Surface Water
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County in_EPSGCodeCV  \
# 0                                                                4326
# 1                                                                4326
# 2                                                                4326
# 3                                                                4326
# 4                                                                4326
#
#   in_GNISCodeCV           in_HUC12 in_HUC8 in_Latitude in_Longitude  \
# 0               101800090810.00000            41.85584   -103.70574
# 1               101800090402.00000            42.00158   -104.04618
# 2               101800090402.00000            42.00158   -104.04618
# 3               101800090402.00000            42.00158   -104.04618
# 4               101800090402.00000            42.00158   -104.04618
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                   POD
# 1                                                   POD
# 2                                                   POD
# 3                                                   POD
# 4                                                   POD
#
#   in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                                                    NE
# 1                                                    NE
# 2                                                    NE
# 3                                                    NE
# 4                                                    NE
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0                                           0.04000
# 1                                           0.16000
# 2                                           0.16000
# 3                                           0.16000
# 4                                           0.16000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                     Active                     1
# 1                     Active                     2
# 2                     Active                     2
# 3                     Active                     2
# 4                     Active                     2
#
#              in_AllocationOwner in_AllocationPriorityDate  \
# 0   Central Irrigation District       1897-03-15T00:00:00
# 1            Steve & Pam Dickey       1933-05-29T00:00:00
# 2            Steve & Pam Dickey       1933-05-29T00:00:00
# 3            Steve & Pam Dickey       1933-05-29T00:00:00
# 4            Steve & Pam Dickey       1933-05-29T00:00:00
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0
# 1
# 2
# 3
# 4
#
#          in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0  Incidental Underground Storage
# 1  Irrigation from Natural Stream
# 2  Irrigation from Natural Stream
# 3  Irrigation from Natural Stream
# 4  Irrigation from Natural Stream
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#    in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://nednr.nebraska.gov/dynamic/WaterRights...
# 1  https://nednr.nebraska.gov/dynamic/WaterRights...
# 2  https://nednr.nebraska.gov/dynamic/WaterRights...
# 3  https://nednr.nebraska.gov/dynamic/WaterRights...
# 4  https://nednr.nebraska.gov/dynamic/WaterRights...

# %% [markdown]
# # POU Surface Water Data
# - will extract and share some elements from above POD surface water data via RightID

# %%
# Input File - PoU Shapefile Data
# export dataframe as zipped csv
pouInput = 'RawInputData/shapefile/BND_SurfaceWaterRights_DNR.zip'
dfPOU = gpd.read_file(pouInput).replace(np.nan, "").replace("nan,nan", "") #geodataframe read
dfPOU = dfPOU.drop(['geometry'], axis=1)

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfPOU:
    dfPOU['WaDEUUID'] = "waU" + dfPOU.index.astype(str)
    dfPOU.to_csv('RawInputData/BND_SurfaceWaterRights_DNR.zip', compression=dict(method='zip', archive_name='BND_SurfaceWaterRights_DNR.csv'), index=False)

print(len(dfPOU))
dfPOU.head(1)
# Out:
# 7344
#    OBJECTID  RightID                        RightUse Applicatio  Acres_Orde  \
# 0         1     4035  Irrigation from Natural Stream    A-15164    72.00000
#
#   WaterDivis FieldOffic CarrierA CarrierB         SourceName  ProGrant Units  \
# 0         1D    Lincoln     Pump           Indian Creek, Big   1.03000   CFS
#
#    GPM  Rate  CurrentTot              HUC12  PriorityDa Beneficial  \
# 0  462    70    72.00000 102702020505.00000  1978-01-17
#
#    ApprovalDa Irrigation Notice_Sta  Notice_Eff Notice_Typ  \
# 0  1978-11-15                  Open  2022-09-06       Open
#
#            Reason_Adm                                GlobalID  ProjectID  \
# 0  Blue River Compact  {18D626A8-1BCF-43DA-9655-0003FBD63F15}          0
#
#   wadeID  Longitude  Latitude                              GlobalID_1  \
# 0  wade1  -96.81605  40.04782  {FA10E0EF-71A5-4169-9CC2-33D006254082}
#
#    Shape_Leng  Shape_Le_1  Shape_Area WaDEUUID
# 0  4419.99441     0.03462     0.00003     waU0

# %%
# assign VariableSpecificUUID

def assignVariableSpecificUUID(colvA):
    outList = ''
    colvA = str(colvA).strip()
    if colvA == "CFS":
        outList = "NEwr_V1"
    if colvA == "AF":
        outList = "NEwr_V2"

    return outList

dfPOU['in_VariableSpecificUUID'] = dfPOU.apply(lambda row: assignVariableSpecificUUID(row['Units']), axis=1)
dfPOU['in_VariableSpecificUUID'].unique()
# Out:
# array(['NEwr_V1', 'NEwr_V2', ''], dtype=object)

# %%
# AllocationFlow_CFS - based on reporeted Unit

def assignAllocationFlow_CFS(colvA, colvB):
    if colvA == '' or pd.isnull(colvA):
        outList = ''
    else:
        colvB = colvB.strip()
        if colvB == "CFS":
            outList = colvA
        else:
            outList = ''
    return outList

dfPOU['AllocationFlow_CFS'] = dfPOU.apply(lambda row: assignAllocationFlow_CFS(row['ProGrant'], row['Units']), axis=1)
dfPOU['AllocationFlow_CFS'].unique()
# Out:
# array([1.03, 0.67, 0.0, 0.14, 0.57, '', 2.14, 1.15, 1.37, 0.24, 2.84,
#        1.13, 1.09, 1.14, 1.26, 0.21, 0.9, 0.54, 0.28, 0.6, 3.07, 2.19,
#        0.69, 58.08, 0.71, 0.91, 0.35, 0.66, 1.46, 0.17, 1.0, 4.65, 0.41,
#        0.16, 1.93, 2.92, 3.29, 1.51, 2.75, 1.22, 0.1, 0.39, 0.52, 0.43,
#        0.76, 0.23, 230.07, 0.77, 0.7, 0.53, 0.2, 1.59, 2.33, 0.31, 0.11,
#        111.51, 4.24, 2.16, 8.69, 2.06, 3.09, 4.47, 135.78, 3.41, 3.34,
#        2.32, 1.68, 2.79, 1.92, 1806.0, 9.52, 3.04, 2.64, 2.6, 1.86, 1.27,
#        1700.0, 2.97, 4.86, 1.62, 0.001, 32.55, 5.36, 5.06, 3.47, 24.56,
#        2400.0, 1.12, 3.37, 2.74, 2.26, 42.71, 3.71, 3.2, 619.94, 2.88,
#        3.58, 9.71, 11.8, 2.41, 21.61, 2.95, 4.01, 6.9, 5.13, 82.48, 2.81,
#        3.22, 5.68, 2.98, 2.5, 6.18, 11.95, 3.96, 6.77, 1424.0, 28.3, 2.51,
#        2270.0, 50.0, 18.67, 3.8, 12.91, 1969.0, 2.17, 10.33, 1.42, 3.98,
#        25.78, 9.43, 4.91, 2.61, 23.67, 5.76, 3.44, 495.14, 3.13, 18.27,
#        32.72, 7.81, 61.79, 3.1, 31.88, 58.16, 4.17, 3.48, 28.57, 6.76,
#        3.16, 7.23, 10.5, 2.89, 5.4, 4.9, 2.7, 29.07, 7.56, 9.48, 3.56,
#        3.53, 173.52, 2.42, 44.71, 5.17, 15.75, 4.03, 1572.0, 2.69, 2.47,
#        20.06, 22.3, 4.7, 136.8, 1.88, 1.95, 3.19, 2100.0, 4.07, 45.0,
#        4.28, 2.34, 219.0, 2.78, 2.63, 11.13, 87.03, 12.44, 226.56, 2.08,
#        30.99, 9.76, 61.94, 1.18, 3.69, 8.09, 95.94, 25.07, 1818.0, 4.58,
#        5.61, 2.67, 2.12, 2.04, 4.09, 15.23, 15.76, 14.12, 3.91, 3.05,
#        3.94, 2.05, 9.17, 3.87, 2.85, 7.3, 2.9, 13.2, 5.16, 5.23, 4.4,
#        0.026, 11.17, 25.8, 3.03, 5.21, 4.57, 1.94, 193.44, 65.44, 3.62,
#        4.8, 15.96, 4.76, 1800.0, 3.78, 8.5, 3.01, 31.23, 6.67, 5.14, 10.0,
#        6.04, 15.63, 130.86, 7.14, 6.2, 256.43, 861.0, 8.93, 3.15, 2.65,
#        9.15, 4.44, 3.3, 12.89, 7.0, 15.43, 2.73, 3.55, 75.53, 9.59, 35.87,
#        1300.0, 192.56, 13.7, 7.62, 1765.0, 101.11, 140.0, 7.79, 3.9,
#        15.24, 3.5, 6.12, 10.39, 2.25, 151.06, 39.25, 4.13, 2084.0, 8.77,
#        5.71, 18.57, 22.2, 80.56, 1000.0, 6.38, 4.21, 100.25, 14.19, 66.18,
#        736.37, 42.5, 4.33, 14.38, 36.09, 25.0, 2.83, 4.38, 44.06, 2.38,
#        5.56], dtype=object)

# %%
# AllocationVolume_AF - based on reporeted Unit

def assignAllocationVolume_AF(colvA, colvB):
    if colvA == '' or pd.isnull(colvA):
        outList = ''
    else:
        colvB = colvB.strip()
        if colvB == "AF":
            outList = colvA
        else:
            outList = ''
    return outList

dfPOU['AllocationVolume_AF'] = dfPOU.apply(lambda row: assignAllocationVolume_AF(row['ProGrant'], row['Units']), axis=1)
#        15.4, 861.56, 0.05, 60.5, 8.44, 56.3, 17.8, 44.3, 2300.0, 184.0,
#        581.1, 36907.71, 3.03, 13.28, 27.0, 3.84, 74.54, 95.0, 109.2, 21.3,
#        15.1, 29.4, 75.0, 61.4, 20.2, 32.19, 272.7, 13.89, 51.3, 0.41,
#        23.2, 31.6, 443.2, 8.6, 210.0, 137.0, 51.0, 18.1, 389.2, 16.8,
#        15968.54, 90.3, 2.3, 11.4, 49.3, 17.0, 2.9, 120.0, 136.06, 21.6,
#        12013.2, 16.5, 0.26, 0.92, 100.2, 284.0, 33.2, 2049.0, 84.8, 32.0,
#        51.7, 76.0, 91.1, 32.2, 76.6, 31.4, 438.0, 49.0, 35.1, 20.9,
#        14556.6, 6.74, 67.4, 6.9, 377.4, 161.9, 68.0, 11.23, 37076.01,
#        110.6, 60.0, 298.65, 19.1, 16.67, 43.6, 34.9, 93.19, 115.2, 116.0,
#        22.72, 273.0, 74.8, 11013.49, 81.2, 43.51, 0.57, 26500.2, 53.3,
#        237.0, 7.82, 5.6, 9.85, 1293.6, 86.4, 39.5, 7.19, 399.0, 168.0,
#        11.8, 1.76, 38.36, 0.8, 58.16, 34.1, 193.0, 63.0, 38.75, 2.52,
#        26.7, 22.8, 237.1, 130.0, 24.6, 36.55, 82.7, 1552.0, 435.0, 7.3,
#        25.47, 3.1, 81.0, 1.42, 16.92, 0.2, 45.7, 63.7, 8.3, 268.6, 37.0,
#        123.2, 429.3, 58.7, 124.75, 46.2, 78.3, 3482.44, 92.9, 8.1, 5.0,
#        209.4, 66.0, 33.5, 44.7, 4.44, 4.5, 37.1, 273.6, 93.15, 35.2, 7.9,
#        18.42, 238.92, 131.31, 97.74, 93.7, 7.29, 99.6, 23.7, 1.24, 19.0,
#        188.5, 17.99], dtype=object)

# %%
dfPOU['WaterAllocationNativeURL'] = 'https://nednr.nebraska.gov/dynamic/WaterRights/WaterRights/SWRDetailPage?RightId=' + dfPOU['RightID'].astype(str)
dfPOU.head(1)
# Out:
#    OBJECTID  RightID                        RightUse Applicatio  Acres_Orde  \
# 0         1     4035  Irrigation from Natural Stream    A-15164    72.00000
#
#   WaterDivis FieldOffic CarrierA CarrierB         SourceName  ProGrant Units  \
# 0         1D    Lincoln     Pump           Indian Creek, Big   1.03000   CFS
#
#    GPM  Rate  CurrentTot              HUC12  PriorityDa Beneficial  \
# 0  462    70    72.00000 102702020505.00000  1978-01-17
#
#    ApprovalDa Irrigation Notice_Sta  Notice_Eff Notice_Typ  \
# 0  1978-11-15                  Open  2022-09-06       Open
#
#            Reason_Adm                                GlobalID  ProjectID  \
# 0  Blue River Compact  {18D626A8-1BCF-43DA-9655-0003FBD63F15}          0
#
#   wadeID  Longitude  Latitude                              GlobalID_1  \
# 0  wade1  -96.81605  40.04782  {FA10E0EF-71A5-4169-9CC2-33D006254082}
#
#    Shape_Leng  Shape_Le_1  Shape_Area WaDEUUID in_VariableSpecificUUID  \
# 0  4419.99441     0.03462     0.00003     waU0                 NEwr_V1
#
#   AllocationFlow_CFS AllocationVolume_AF  \
# 0            1.03000
#
#                             WaterAllocationNativeURL
# 0  https://nednr.nebraska.gov/dynamic/WaterRights...

# %%
dfPOU['RightUse'].unique()
# Out:
# array(['Irrigation from Natural Stream',
#        'Stor-only (irrigation from a reservoir on lands not covered by a natural flow appropriation)',
#        'Supplemental Irrigation (irrig. from reservoir on lands also covered by a natural flow appropriation)',
#        'Transfer to Instream',
#        'Stor-only and Incidental Underground Storage', 'Recharge',
#        'Supplemental Irrigation and Incidental Underground Storage',
#        'Conducting Surface Water for Irrigation (Uses Water from an Existing Appropriation)',
#        'Incidental Underground Storage', 'Domestic',
#        'Conducting Groundwater for Irrigation (Source is a Registered Groundwater Well)',
#        'Storage', 'Instream Flow',
#        'Irrigation and Incidental Underground Storage',
#        'Fish and wildlife',
#        'Supplemental Storage (an appropriation that has a prior appropriation for storage)',
#        'Domestic Storage Use',
#        'Irrigation and Storage (an appropriation which was approved for both uses)',
#        'Wetlands', 'Cooling', 'Manufacturing', 'Power',
#        'Intentional Underground Storage', 'Irrigation from Natural Lake',
#        'Fish Culture', 'Power and Incidental Underground Storage',
#        'Induced Ground Water Recharge'], dtype=object)

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfPOU['WaDEUUID']

# # Method Info
df['in_MethodUUID'] = "NEwr_M1" # for surface water

# Variable Info
df['in_VariableSpecificUUID'] = dfPOU['in_VariableSpecificUUID']

# Organization Info
df['in_OrganizationUUID'] = "NEwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfPOU['SourceName']
df['in_WaterSourceNativeID'] = "" # auto fill in below
df['in_WaterSourceTypeCV'] = "Surface Water"

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = ""
df['in_EPSGCodeCV'] = "4326"
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = dfPOU['HUC12']
df['in_HUC8'] = ""
df['in_Latitude'] = dfPOU['Latitude']
df['in_Longitude'] = dfPOU['Longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POU"
df['in_SiteName'] = ""
df['in_SiteNativeID'] = "POU" + dfPOU['wadeID'].replace("", 0).fillna(0).astype(str)
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = ""
df['in_StateCV'] = "NE"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = ""
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = dfPOU['AllocationFlow_CFS']
df['in_AllocationLegalStatusCV'] = ""
df['in_AllocationNativeID'] =  dfPOU['RightID'].replace("", 0).fillna(0).astype(str).str.lower().str.strip()
df['in_AllocationOwner'] = ""
df['in_AllocationPriorityDate'] = dfPOU['PriorityDa']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = dfPOU['AllocationVolume_AF']
df['in_BeneficialUseCategory'] = dfPOU['RightUse']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = ""
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = dfPOU['WaterAllocationNativeURL']

outdfPoU = df.copy()
outdfPoU = outdfPoU.drop_duplicates().reset_index(drop=True)
print(len(outdfPoU))
outdfPoU.head()
# Out:
# 7344
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     waU0       NEwr_M1                 NEwr_V1             NEwr_O1
# 1     waU1       NEwr_M1                 NEwr_V1             NEwr_O1
# 2     waU2       NEwr_M1                 NEwr_V1             NEwr_O1
# 3     waU3       NEwr_M1                 NEwr_V1             NEwr_O1
# 4     waU4       NEwr_M1                 NEwr_V1             NEwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#        in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0       Indian Creek, Big                               Surface Water
# 1            Turkey Creek                               Surface Water
# 2       Loup River, South                               Surface Water
# 3        Sandy Creek, Big                               Surface Water
# 4  School Creek, Trib. To                               Surface Water
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County in_EPSGCodeCV  \
# 0                                                                4326
# 1                                                                4326
# 2                                                                4326
# 3                                                                4326
# 4                                                                4326
#
#   in_GNISCodeCV           in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0               102702020505.00000             40.04782     -96.81605
# 1               102702040308.00000             40.51107     -97.01462
# 2               102100040508.00000             41.03143     -98.82382
# 3               102702060807.00000             40.23899     -97.38548
# 4               102702030203.00000             40.64949     -97.91262
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                   POU
# 1                                                   POU
# 2                                                   POU
# 3                                                   POU
# 4                                                   POU
#
#   in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0        POUwade1                                    NE
# 1        POUwade3                                    NE
# 2        POUwade5                                    NE
# 3        POUwade6                                    NE
# 4        POUwade7                                    NE
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0                                           1.03000
# 1                                           0.67000
# 2                                           0.00000
# 3                                           0.14000
# 4                                           0.57000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID in_AllocationOwner  \
# 0                                             4035
# 1                                            10330
# 2                                             5486
# 3                                            10117
# 4                                             3116
#
#   in_AllocationPriorityDate in_AllocationSDWISIdentifierCV  \
# 0                1978-01-17
# 1                1970-01-07
# 2                1970-07-08
# 3                1945-10-29
# 4                1974-12-19
#
#   in_AllocationTimeframeEnd in_AllocationTimeframeStart in_AllocationTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationVolume_AF        in_BeneficialUseCategory  \
# 0                         Irrigation from Natural Stream
# 1                         Irrigation from Natural Stream
# 2                         Irrigation from Natural Stream
# 3                         Irrigation from Natural Stream
# 4                         Irrigation from Natural Stream
#
#   in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_DataPublicationDate in_DataPublicationDOI  in_ExemptOfVolumeFlowPriority  \
# 0                                                                           0
# 1                                                                           0
# 2                                                                           0
# 3                                                                           0
# 4                                                                           0
#
#   in_GeneratedPowerCapacityMW in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_LegacyAllocationIDs in_OwnerClassificationCV in_PopulationServed  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PowerType in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://nednr.nebraska.gov/dynamic/WaterRights...
# 1  https://nednr.nebraska.gov/dynamic/WaterRights...
# 2  https://nednr.nebraska.gov/dynamic/WaterRights...
# 3  https://nednr.nebraska.gov/dynamic/WaterRights...
# 4  https://nednr.nebraska.gov/dynamic/WaterRights...

# %% [markdown]
# # POD Groundwater Data
# - data already pulled from api, used saved csv instead

# %%
# %%time
# # API retrieval
# # Checked api website and would allow up to 270 input as page. 

# columns_to_keep = ['WellID','RegistrationNumber','Status','WellUseDescription','NRDName','CountyName','Location','SurfaceWaterAppropriation','Acres','SeriesType','Pump','OwnerContact','RegistrationDate','CompletionDate','LastChangeDate','Latitude','Longitude']

# df = pd.DataFrame(columns=columns_to_keep)

# countPage = 1
# while countPage <= 260:
#    url = "https://nednr.nebraska.gov/IwipApi/api/v1/Wells/AllWells?page=" + str(countPage)
#    print(url)

#    # Store data in DataFrame
#    try:
#        response = requests.get(url)
#        response.raise_for_status()  # Raise an exception for bad status codes (e.g., 404)
#        responseD = json.loads(response.text)
#        DtL = responseD['Results']
#        length = len(DtL)
#        for i in range(length):
#            row = pd.DataFrame([DtL[i]])
           
#            # Check if the 'Status' is 'Active Registered Well' before adding it to the DataFrame
#            if row['Status'].iloc[0] == 'Active Registered Well':
#                # Select only the desired columns
#                row = row[columns_to_keep]
#                df = pd.concat([df, row])
#    except requests.exceptions.RequestException as e:
#        print(f"Request error: {e}")
#    except json.JSONDecodeError as e:
#        print(f"JSON decoding error: {e}")
#    except KeyError as e:
#        print(f"KeyError: {e}")
    
#    countPage = countPage + 1

# # Reset the DataFrame index
# df.reset_index(drop=True, inplace=True)

# print(len(df))
# df.head()

# %%
# # already done, skip ahead

# # To unpack column's dictionary value new into separate columns -> contact to existing dataframe -> drop unpacked column
# dftemp = df.copy()
# dftemp = pd.concat([dftemp, dftemp["Pump"].apply(pd.Series)], axis=1).drop(columns=["Pump","PumpColumn_Diameter","PumpDepth","PumpInstallationDate","PumpInstallerContact"])
# dftemp = pd.concat([dftemp, dftemp["OwnerContact"].apply(pd.Series)], axis=1).drop(columns=["OwnerContact","ContactId","ContactType","SeqNum","BeginDate","EndDate","Address1","Address2","City","State","Zip","Phone1","Phone2","Phone3","LicenseNumber","IsDeleted"])

# print(len(dftemp))
# dftemp.head(5)

# %%
# # already done, skip ahead

# # export api data
# dftemp.to_csv('RawInputData/AllWells.zip', compression=dict(method='zip', archive_name='AllWells.csv'), index=False)  # The output, save as a zip"

# %%
# Input File
FIgw_PoD = "RawInputData/AllWells.zip"
dfgwinPOD = pd.read_csv(FIgw_PoD, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfgwinPOD:
    dfgwinPOD['WaDEUUID'] = "d" + dfgwinPOD.index.astype(str)
    dfgwinPOD.to_csv('RawInputData/AllWells.zip', compression=dict(method='zip', archive_name='AllWells.csv'), index=False)

print(len(dfgwinPOD))
dfgwinPOD.head()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_15180\522426156.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfgwinPOD = pd.read_csv(FIgw_PoD, encoding = "ISO-8859-1").replace(np.nan, "")
# 188893
#    WellID RegistrationNumber                  Status WellUseDescription  \
# 0       3          A-002200A  Active Registered Well         Irrigation
# 1       4          A-002200B  Active Registered Well         Irrigation
# 2       5          A-002200C  Active Registered Well         Irrigation
# 3       7           A-002513  Active Registered Well         Irrigation
# 4       8           A-002770  Active Registered Well         Irrigation
#
#           NRDName CountyName              Location SurfaceWaterAppropriation  \
# 0    South Platte   Cheyenne     NW S8-T13-R46West
# 1    South Platte   Cheyenne     NW S8-T13-R46West
# 2    South Platte   Cheyenne     NW S8-T13-R46West
# 3  Central Platte     Dawson   SWSE S19-T9-R20West
# 4    South Platte    Kimball  SWNW S28-T15-R54West
#
#       Acres                               SeriesType     RegistrationDate  \
# 0  46.00000  Connected to pump into a common carrier  1931-04-29T00:00:00
# 1  46.00000  Connected to pump into a common carrier  1931-04-29T00:00:00
# 2  46.00000  Connected to pump into a common carrier  1931-04-29T00:00:00
# 3 120.00000                           Single Project  1935-02-15T00:00:00
# 4 113.00000                           Single Project  1937-08-07T00:00:00
#
#         CompletionDate          LastChangeDate  Latitude  Longitude  \
# 0  1931-10-01T00:00:00     2002-10-28T00:00:00  41.11699 -102.62495
# 1  1931-10-01T00:00:00  2011-01-24T11:42:23.48  41.11699 -102.62495
# 2  1931-10-01T00:00:00     2002-10-28T00:00:00  41.11699 -102.62495
# 3  1935-02-15T00:00:00     2006-11-08T00:00:00  40.73164  -99.64524
# 4  1937-08-10T00:00:00  2011-06-15T10:39:43.44  41.24492 -103.52575
#
#     PumpRate         FirstName                   LastName WaDEUUID
# 0  300.00000   Henry & Richard                      Bruns       d0
# 1              Henry & Richard                      Bruns       d1
# 2              Henry & Richard                      Bruns       d2
# 3  488.00000                    Ourada Cattle Company Inc       d3
# 4 1346.00000  Gene R & Chari L                       Mohr       d4

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfgwinPOD['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "NEwr_M2" # for groundwater

# Variable Info
df['in_VariableSpecificUUID'] = "NEwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "NEwr_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = "Fresh"
df['in_WaterSourceName'] = ""
df['in_WaterSourceNativeID'] = "" # auto fill in below if not provdied
df['in_WaterSourceTypeCV'] = "Groundwater"

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = ""
df['in_County'] = dfgwinPOD['CountyName']
df['in_EPSGCodeCV'] = "4326"
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfgwinPOD['Latitude']
df['in_Longitude'] = dfgwinPOD['Longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"  # "Point of Diversion"
df['in_SiteName'] = dfgwinPOD['Location']
df['in_SiteNativeID'] = "PODgw" + dfgwinPOD['WellID'].astype(str).str.strip()
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = dfgwinPOD['SeriesType']
df['in_StateCV'] = "NE"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = dfgwinPOD['RegistrationDate']
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = ""
df['in_AllocationFlow_CFS'] = ""
df['in_AllocationLegalStatusCV'] = dfgwinPOD['Status']
df['in_AllocationNativeID'] = dfgwinPOD['RegistrationNumber']
df['in_AllocationOwner'] = dfgwinPOD['FirstName'] + " " + dfPoD['LastName']
df['in_AllocationPriorityDate'] = ""
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = ""
df['in_AllocationTimeframeStart'] = ""
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = dfgwinPOD['PumpRate']
df['in_BeneficialUseCategory'] = dfgwinPOD['WellUseDescription']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = "10/04/2023"
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = "1"
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = dfgwinPOD['Acres']
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = "https://nednr.nebraska.gov/Dynamic/Wells/Wells/WellDetails?WellId=" + dfgwinPOD['WellID'].astype(str).str.strip()

outgwPOD = df.copy()
outgwPOD = outgwPOD.drop_duplicates().reset_index(drop=True)
print(len(outgwPOD))
outgwPOD.head()
# Out:
# 188893
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0       d0       NEwr_M2                 NEwr_V1             NEwr_O1
# 1       d1       NEwr_M2                 NEwr_V1             NEwr_O1
# 2       d2       NEwr_M2                 NEwr_V1             NEwr_O1
# 3       d3       NEwr_M2                 NEwr_V1             NEwr_O1
# 4       d4       NEwr_M2                 NEwr_V1             NEwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0                                                       Fresh
# 1                                                       Fresh
# 2                                                       Fresh
# 3                                                       Fresh
# 4                                                       Fresh
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                                    Groundwater
# 1                                                    Groundwater
# 2                                                    Groundwater
# 3                                                    Groundwater
# 4                                                    Groundwater
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County in_EPSGCodeCV  \
# 0                                              Cheyenne          4326
# 1                                              Cheyenne          4326
# 2                                              Cheyenne          4326
# 3                                                Dawson          4326
# 4                                               Kimball          4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    41.11699    -102.62495
# 1                                    41.11699    -102.62495
# 2                                    41.11699    -102.62495
# 3                                    40.73164     -99.64524
# 4                                    41.24492    -103.52575
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite           in_SiteName  \
# 0                                                   POD     NW S8-T13-R46West
# 1                                                   POD     NW S8-T13-R46West
# 2                                                   POD     NW S8-T13-R46West
# 3                                                   POD   SWSE S19-T9-R20West
# 4                                                   POD  SWNW S28-T15-R54West
#
#   in_SiteNativeID in_SitePoint                            in_SiteTypeCV  \
# 0          PODgw3               Connected to pump into a common carrier
# 1          PODgw4               Connected to pump into a common carrier
# 2          PODgw5               Connected to pump into a common carrier
# 3          PODgw7                                        Single Project
# 4          PODgw8                                        Single Project
#
#   in_StateCV in_USGSSiteID in_AllocationApplicationDate  \
# 0         NE                        1931-04-29T00:00:00
# 1         NE                        1931-04-29T00:00:00
# 2         NE                        1931-04-29T00:00:00
# 3         NE                        1935-02-15T00:00:00
# 4         NE                        1937-08-07T00:00:00
#
#   in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0     Active Registered Well             A-002200A
# 1     Active Registered Well             A-002200B
# 2     Active Registered Well             A-002200C
# 3     Active Registered Well              A-002513
# 4     Active Registered Well              A-002770
#
#                             in_AllocationOwner in_AllocationPriorityDate  \
# 0  Henry & Richard Central Irrigation District
# 1                       Henry & Richard Dickey
# 2                       Henry & Richard Dickey
# 3                                       Dickey
# 4                      Gene R & Chari L Dickey
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0                                                              300.00000
# 1
# 2
# 3                                                              488.00000
# 4                                                             1346.00000
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0               Irrigation
# 1               Irrigation
# 2               Irrigation
# 3               Irrigation
# 4               Irrigation
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0                               10/04/2023
# 1                               10/04/2023
# 2                               10/04/2023
# 3                               10/04/2023
# 4                               10/04/2023
#
#   in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
#
#   in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0            46.00000
# 1            46.00000
# 2            46.00000
# 3           120.00000
# 4           113.00000
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://nednr.nebraska.gov/Dynamic/Wells/Wells...
# 1  https://nednr.nebraska.gov/Dynamic/Wells/Wells...
# 2  https://nednr.nebraska.gov/Dynamic/Wells/Wells...
# 3  https://nednr.nebraska.gov/Dynamic/Wells/Wells...
# 4  https://nednr.nebraska.gov/Dynamic/Wells/Wells...

# %% [markdown]
# ## Concatenate Data

# %%
# Concatenate dataframes
frames = [outdfPoD, outdfPoU, outgwPOD]
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 218185

# %% [markdown]
# ## Clean Data & WaDE Custom Elements

# %%
# Making Sure datatype of HUC12 is int.

def assignHUC12(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        outList = int(colrowValue)
    return outList

outdf['in_HUC12'] = outdf.apply(lambda row: assignHUC12(row['in_HUC12']), axis=1)
outdf['in_HUC12'].unique()
# Out:
# array([101800090810, 101800090402, 101800130102, ..., 102100060704,
#        101500031701, 102100060805], dtype=object)

# %%
# solving a long benefical use
def longBenUseTempFix(val):
    if val == "Supplemental Cooling (an app. for water for cooling through a system that has a prior app. for cooling)":
        outList = "Supplemental Cooling (app for water for cooling through a system that has a prior app for cooling)"
    elif val == "Supplemental Irrigation (irrig. from reservoir on lands also covered by a natural flow appropriation)":
        outList = "Supplemental Irrigation (irrig. from reservoir on lands covered by a natural flow appropriation)"
    else:
        outList = val
    return outList
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: longBenUseTempFix(row['in_BeneficialUseCategory']), axis=1)

for x in outdf['in_BeneficialUseCategory'].sort_values().unique():
    print(f'"' + str(x) + '",')
# Out:
# "Aquaculture",
# "Commercial/Industrial",
# "Conducting Groundwater for Irrigation (Source is a Registered Groundwater Well)",
# "Conducting Surface Water for Irrigation (Uses Water from an Existing Appropriation)",
# "Cooling",
# "Dewatering (Over 90 Days)",
# "Domestic",
# "Domestic Storage Use",
# "Fish Culture",
# "Fish and wildlife",
# "Flood Control",
# "Ground Heat Exchanger well - Closed Loop Heat Pump well",
# "Heat Pump well - Open Loop Heat Pump Well",
# "Incidental Underground Storage",
# "Induced Ground Water Recharge",
# "Injection",
# "Instream Basin-Management",
# "Instream Flow",
# "Intentional Underground Storage",
# "Irrigation",
# "Irrigation and Incidental Underground Storage",
# "Irrigation and Storage (an appropriation which was approved for both uses)",
# "Irrigation from Natural Lake",
# "Irrigation from Natural Stream",
# "Livestock",
# "Maintain Level of a Lake",
# "Manufacturing",
# "Monitoring (Ground Water Quality)",
# "Observation (Ground Water Levels)",
# "Other",
# "Pit (excavation)",
# "Power",
# "Power and Incidental Underground Storage",
# "Raise Dam",
# "Recharge",
# "Recovery",
# "Stor-only (irrigation from a reservoir on lands not covered by a natural flow appropriation)",
# "Stor-only and Incidental Underground Storage",
# "Storage",
# "Storage and Incidental Underground Storage",
# "Supplemental Cooling (app for water for cooling through a system that has a prior app for cooling)",
# "Supplemental Fish Culture",
# "Supplemental Irrigation (irrig. from reservoir on lands covered by a natural flow appropriation)",
# "Supplemental Irrigation and Incidental Underground Storage",
# "Supplemental Power (an app. for water for power through a system that has a prior app. for power)",
# "Supplemental Power and Incidental Underground Storage",
# "Supplemental Storage (an appropriation that has a prior appropriation for storage)",
# "Transfer to Instream",
# "Waste Storage",
# "Wetlands",

# %%
# Clean owner name up
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Central Irrigation District', 'Steve Pam Dickey',
#        'Charlene I Fitzgerald', ..., 'Eric Kate Livingston',
#        'Susan Livingston',
#        'James L Ella Lower Big Blue Natural Resources District'],
#       dtype=object)

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['North Platte River', 'Glenn Springs', 'Schuppe Creek, West', ...,
#        'Prairie Pond', 'Vieselmeyer Reservoir', 'Toohey Drain'],
#       dtype=object)

# %%
# Ensure Empty String

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Surface Water', 'Groundwater'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: ensureEmptyString(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['', 'Cheyenne', 'Dawson', 'Kimball', 'Hayes', 'Hitchcock',
#        'Scotts Bluff', 'Hall', 'Keith', 'Sioux', 'Banner', 'Lincoln',
#        'Merrick', 'Dodge', 'Hamilton', 'Buffalo', 'Colfax', 'Custer',
#        'Harlan', 'Franklin', 'Webster', 'Butler', 'Chase', 'Boone',
#        'Platte', 'Polk', 'Box Butte', 'York', 'Saline', 'Seward', 'Adams',
#        'Sherman', 'Clay', 'Nuckolls', 'Thayer', 'Gage', 'Valley',
#        'Howard', 'Phelps', 'Fillmore', 'Kearney', 'Garden', 'Red Willow',
#        'Morrill', 'Greeley', 'Cass', 'Furnas', 'Dawes', 'Holt', 'Grant',
#        'Dundy', 'Deuel', 'Frontier', 'Brown', 'Knox', 'Sheridan',
#        'Gosper', 'Lancaster', 'Sarpy', 'Antelope', 'Washington', 'Nance',
#        'Loup', 'Madison', 'Garfield', 'Perkins', 'Rock', 'Logan',
#        'Blaine', 'Saunders', 'Stanton', 'Cherry', 'Arthur', 'Douglas',
#        'Wheeler', 'Otoe', 'Jefferson', 'Thomas', 'Pierce', 'Nemaha',
#        'Thurston', 'Dixon', 'Cedar', 'Cuming', 'Dakota', 'Burt',
#        'Johnson', 'Wayne', 'Hooker', 'Pawnee', 'Keya Paha', 'McPherson',
#        'Boyd', 'Richardson'], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array(['', 'NW S8-T13-R46West', 'SWSE S19-T9-R20West', ...,
#        'NWSW S10-T33-R22West', 'NWNE S4-T29-R20West',
#        'SWSW S34-T34-R32West'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['', 'Connected to pump into a common carrier', 'Single Project',
#        'Part of a DEQ site plan for spill or underground storage',
#        'Monitoring Wells Part of a single site'], dtype=object)

# %%
outdf['in_AllocationLegalStatusCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationLegalStatusCV']), axis=1)
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Active', '', 'Active Registered Well'], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Central Irrigation District', 'Steve Pam Dickey',
#        'Charlene I Fitzgerald', ..., 'Eric Kate Livingston',
#        'Susan Livingston',
#        'James L Ella Lower Big Blue Natural Resources District'],
#       dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
uniqueList = list(set([i.strip() for i in ','.join(outdf['in_BeneficialUseCategory'].astype(str)).split(',')]))
uniqueList.sort()
uniqueList
# Out:
# ['Aquaculture',
#  'Commercial/Industrial',
#  'Conducting Groundwater for Irrigation (Source is a Registered Groundwater Well)',
#  'Conducting Surface Water for Irrigation (Uses Water from an Existing Appropriation)',
#  'Cooling',
#  'Dewatering (Over 90 Days)',
#  'Domestic',
#  'Domestic Storage Use',
#  'Fish Culture',
#  'Fish and wildlife',
#  'Flood Control',
#  'Ground Heat Exchanger well - Closed Loop Heat Pump well',
#  'Heat Pump well - Open Loop Heat Pump Well',
#  'Incidental Underground Storage',
#  'Induced Ground Water Recharge',
#  'Injection',
#  'Instream Basin-Management',
#  'Instream Flow',
#  'Intentional Underground Storage',
#  'Irrigation',
#  'Irrigation and Incidental Underground Storage',
#  'Irrigation and Storage (an appropriation which was approved for both uses)',
#  'Irrigation from Natural Lake',
#  'Irrigation from Natural Stream',
#  'Livestock',
#  'Maintain Level of a Lake',
#  'Manufacturing',
#  'Monitoring (Ground Water Quality)',
#  'Observation (Ground Water Levels)',
#  'Other',
#  'Pit (excavation)',
#  'Power',
#  'Power and Incidental Underground Storage',
#  'Raise Dam',
#  'Recharge',
#  'Recovery',
#  'Stor-only (irrigation from a reservoir on lands not covered by a natural flow appropriation)',
#  'Stor-only and Incidental Underground Storage',
#  'Storage',
#  'Storage and Incidental Underground Storage',
#  'Supplemental Cooling (app for water for cooling through a system that has a prior app for cooling)',
#  'Supplemental Fish Culture',
#  'Supplemental Irrigation (irrig. from reservoir on lands covered by a natural flow appropriation)',
#  'Supplemental Irrigation and Incidental Underground Storage',
#  'Supplemental Power (an app. for water for power through a system that has a prior app. for power)',
#  'Supplemental Power and Incidental Underground Storage',
#  'Supplemental Storage (an appropriation that has a prior appropriation for storage)',
#  'Transfer to Instream',
#  'Waste Storage',
#  'Wetlands']

# %%
# Ensure Latitude entry is either numireic or a 0
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([41.85584158, 42.00158085, 41.99952353, ..., 42.84489444, 42.51755,
#        42.87223055], dtype=object)

# %%
# Ensure Longitude entry is either numireic or a 0
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([-103.70574234, -104.04617675, -104.04244188, ..., -99.90423888,
#        -99.66146944, -101.08125555], dtype=object)

# %%
# Changing datatype of Priority Date to date fields entry
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'], errors = 'coerce')
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# <DatetimeArray>
# ['1897-03-15 00:00:00', '1933-05-29 00:00:00', '1946-06-17 00:00:00',
#  '1934-08-03 00:00:00', '1933-03-27 00:00:00', '1959-12-01 00:00:00',
#  '1962-08-30 00:00:00', '1960-09-28 00:00:00', '1904-12-23 00:00:00',
#  '1960-09-22 00:00:00',
#  ...
#  '2023-07-24 00:00:00', '2023-08-02 00:00:00', '2023-09-07 00:00:00',
#  '2023-08-31 00:00:00', '2023-09-11 00:00:00', '2023-08-08 00:00:00',
#  '2023-09-13 00:00:00', '2023-09-27 00:00:00', '2023-10-02 00:00:00',
#  '2023-11-01 00:00:00']
# Length: 5423, dtype: datetime64[ns]

# %%
# Ensure Flow entry is either numireic or a 0
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([0.04, 0.16, 0.01, 0.02, 0.38, 0.06, 1.01, 0.33, 0.23, 1.43, 0.5,
#        1.63, 0.12, 0.61, 0.86, 0.11, 2.22, 13.0, 0.21, 0.15, 1.28, '',
#        0.48, 0.19, 1572.0, 780.59, 191.86, 15.63, 192.56, 0.14, 861.0,
#        45.0, 230.07, 0.27, 0.74, 3.07, 2.0, 0.3, 0.79, 1.14, 0.57, 0.43,
#        5.14, 0.46, 111.51, 10.0, 3.0, 1.0, 15.0, 1.59, 2.28, 18.19, 4.0,
#        14.38, 24.38, 0.17, 2.24, 5.68, 95.94, 82.48, 3.05, 0.4, 2.26,
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array(['', 10.0, 1.7, ..., 278.0, 1108.0, 648.0], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], 
                                                                              row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', ..., 'wadeId1533', 'wadeId1534',
#        'wadeId1535'], dtype=object)

# %%
# Creating WaDE Custom site native ID for easy site identification
# use Unique Latitude, Longitude, SiteName and SiteTypeCV values
# ----------------------------------------------------------------------------------------------------

# Create temp in_SiteNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_Latitude'] = outdf['in_Latitude'].astype(str).str.strip()
dfTempID['in_Longitude'] = outdf['in_Longitude'].astype(str).str.strip()
dfTempID['in_SiteName'] = outdf['in_SiteName'].astype(str).str.strip()
dfTempID['in_SiteTypeCV'] = outdf['in_SiteTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_SiteNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_Latitude'].astype(str) + dfTempID['in_Longitude'].astype(str) + dfTempID['in_SiteName'].astype(str)+ dfTempID['in_SiteTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_SiteNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB, valC, valD):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip() + str(valC).strip() + str(valD).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_SiteNativeID'], 
                                                                       row['in_Latitude'], row['in_Longitude'],
                                                                       row['in_SiteName'], row['in_SiteTypeCV']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', ..., 'PODgw276203', 'PODgw276204',
#        'PODgw276205'], dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For this {state name / organization}, we don't want water rights that are considered: Cancelled

# %%
# drop non-active AllocationLegalStatusCV values specific to that state.

# drop the list
dropLegalStatusList = ["Cancelled"] # enter string entries here

# drop rows from above list
outdf = outdf[outdf.in_AllocationLegalStatusCV.isin(dropLegalStatusList) == False].reset_index(drop=True)

print(len(outdf))
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# 218185
# array(['Active', '', 'Active Registered Well'], dtype=object)

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to csv inputs.

# %%
# PoU Shapefile Data
# Shapefile input
dfPoUshapetemp = gpd.read_file('RawInputData/shapefile/BND_SurfaceWaterRights_DNR.zip')
print(len(dfPoUshapetemp))
dfPoUshapetemp.head()
# Out:
# 7344
#    OBJECTID  RightID                        RightUse Applicatio  Acres_Orde  \
# 0         1     4035  Irrigation from Natural Stream    A-15164    72.00000
# 1         3    10330  Irrigation from Natural Stream   A-11847B    46.70000
# 2         5     5486  Irrigation from Natural Stream    A-11994     0.00000
# 3         6    10117  Irrigation from Natural Stream    A-3857A    16.60000
# 4         7     3116  Irrigation from Natural Stream    A-13323    40.00000
#
#   WaterDivis FieldOffic CarrierA CarrierB              SourceName  ProGrant  \
# 0         1D    Lincoln     Pump      NaN       Indian Creek, Big   1.03000
# 1         1D    Lincoln     Pump      NaN            Turkey Creek   0.67000
# 2         2A        Ord     Pump      NaN       Loup River, South   0.00000
# 3         1C    Lincoln     Pump      NaN        Sandy Creek, Big   0.14000
# 4         1D    Lincoln     Pump      NaN  School Creek, Trib. To   0.57000
#
#   Units  GPM  Rate  CurrentTot              HUC12  PriorityDa Beneficial  \
# 0   CFS  462    70    72.00000 102702020505.00000  1978-01-17        NaN
# 1   CFS  300    70    46.70000 102702040308.00000  1970-01-07        NaN
# 2   CFS  318    70     0.00000 102100040508.00000  1970-07-08        NaN
# 3   CFS   62   140    16.60000 102702060807.00000  1945-10-29        NaN
# 4   CFS  255    70    40.00000 102702030203.00000  1974-12-19        NaN
#
#    ApprovalDa Irrigation Notice_Sta  Notice_Eff Notice_Typ  \
# 0  1978-11-15        NaN       Open  2022-09-06       Open
# 1  1970-06-05        NaN       Open  2022-09-06       Open
# 2         NaN        NaN        NaN         NaN        NaN
# 3  1945-11-19        NaN       Open  2019-04-23       Open
# 4  1976-09-28        NaN       Open  2016-04-17       Open
#
#                 Reason_Adm                                GlobalID  ProjectID  \
# 0       Blue River Compact  {18D626A8-1BCF-43DA-9655-0003FBD63F15}          0
# 1       Blue River Compact  {CFA8A10C-25B7-48C8-95BA-000F18E3A9D3}          0
# 2                      NaN  {BFB820E1-081D-4418-BE5F-0028547A4F6F}          0
# 3  Natural Flow (Reminder)  {8972DBF2-9D48-4791-AE74-00290D3ACE30}          0
# 4  Natural Flow (Reminder)  {6E3A3D1E-5509-4459-9D4C-002B533F49C6}          0
#
#   wadeID  Longitude  Latitude                              GlobalID_1  \
# 0  wade1  -96.81605  40.04782  {FA10E0EF-71A5-4169-9CC2-33D006254082}
# 1  wade3  -97.01462  40.51107  {549984F2-6647-4625-9F6A-12F7A5C4134D}
# 2  wade5  -98.82382  41.03143  {3394FD90-5715-4315-BD55-8A60CB727D69}
# 3  wade6  -97.38548  40.23899  {0C0D8DBF-F3D5-49AB-963F-B51263666B79}
# 4  wade7  -97.91262  40.64949  {70C8CA7B-973D-4FA9-B37F-E05563AEEED0}
#
#    Shape_Leng  Shape_Le_1  Shape_Area  \
# 0  4419.99441     0.03462     0.00003
# 1  2318.35156     0.01856     0.00002
# 2  5900.61664     0.05139     0.00002
# 3  1746.90699     0.01436     0.00001
# 4  3281.57362     0.02684     0.00002
#
#                                             geometry
# 0  MULTIPOLYGON (((-96.81954 40.04925, -96.81951 ...
# 1  POLYGON ((-97.01224 40.51280, -97.01224 40.512...
# 2  MULTIPOLYGON (((-98.82727 41.03020, -98.82950 ...
# 3  POLYGON ((-97.38431 40.24029, -97.38408 40.240...
# 4  MULTIPOLYGON (((-97.91352 40.65004, -97.91335 ...

# %%
columnsList = ['in_SiteNativeID', 'geometry']
dfPoUshape = pd.DataFrame(columns=columnsList)
dfPoUshape['in_SiteNativeID'] = "POU" + dfPoUshapetemp['wadeID'].replace("", 0).fillna(0).astype(str)
dfPoUshape['geometry'] = dfPoUshapetemp['geometry']
dfPoUshape = dfPoUshape.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
dfPoUshape.head()
# Out:
#   in_SiteNativeID                                           geometry
# 0        POUwade1  MULTIPOLYGON (((-96.81954 40.04925, -96.81951 ...
# 1        POUwade3  POLYGON ((-97.01224 40.51280, -97.01224 40.512...
# 2        POUwade5  MULTIPOLYGON (((-98.82727 41.03020, -98.82950 ...
# 3        POUwade6  POLYGON ((-97.38431 40.24029, -97.38408 40.240...
# 4        POUwade7  MULTIPOLYGON (((-97.91352 40.65004, -97.91335 ...

# %% [markdown]
# ### Exporting to Finished File

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218185 entries, 0 to 218184
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   WaDEUUID                                      218185 non-null  object
#  1   in_MethodUUID                                 218185 non-null  object
#  2   in_VariableSpecificUUID                       218185 non-null  object
#  3   in_OrganizationUUID                           218185 non-null  object
#  4   in_Geometry                                   218185 non-null  object
#  5   in_GNISFeatureNameCV                          218185 non-null  object
#  6   in_WaterQualityIndicatorCV                    218185 non-null  object
#  7   in_WaterSourceName                            218185 non-null  object
#  8   in_WaterSourceNativeID                        218185 non-null  object
#  9   in_WaterSourceTypeCV                          218185 non-null  object
#  10  in_CoordinateAccuracy                         218185 non-null  object
#  11  in_CoordinateMethodCV                         218185 non-null  object
#  12  in_County                                     218185 non-null  object
#  13  in_EPSGCodeCV                                 218185 non-null  object
#  14  in_GNISCodeCV                                 218185 non-null  object
#  15  in_HUC12                                      218185 non-null  object
#  16  in_HUC8                                       218185 non-null  object
#  17  in_Latitude                                   218185 non-null  object
#  18  in_Longitude                                  218185 non-null  object
#  19  in_NHDNetworkStatusCV                         218185 non-null  object
#  20  in_NHDProductCV                               218185 non-null  object
#  21  in_PODorPOUSite                               218185 non-null  object
#  22  in_SiteName                                   218185 non-null  object
#  23  in_SiteNativeID                               218185 non-null  object
#  24  in_SitePoint                                  218185 non-null  object
#  25  in_SiteTypeCV                                 218185 non-null  object
#  26  in_StateCV                                    218185 non-null  object
#  27  in_USGSSiteID                                 218185 non-null  object
#  28  in_AllocationApplicationDate                  218185 non-null  object
#  29  in_AllocationAssociatedConsumptiveUseSiteIDs  218185 non-null  object
#  30  in_AllocationAssociatedWithdrawalSiteIDs      218185 non-null  object
#  31  in_AllocationBasisCV                          218185 non-null  object
#  32  in_AllocationChangeApplicationIndicator       218185 non-null  object
#  33  in_AllocationCommunityWaterSupplySystem       218185 non-null  object
#  34  in_AllocationCropDutyAmount                   218185 non-null  object
#  35  in_AllocationExpirationDate                   218185 non-null  object
#  36  in_AllocationFlow_CFS                         218185 non-null  object
#  37  in_AllocationLegalStatusCV                    218185 non-null  object
#  38  in_AllocationNativeID                         218185 non-null  object
#  39  in_AllocationOwner                            218185 non-null  object
#  40  in_AllocationPriorityDate                     21688 non-null   datetime64[ns]
#  41  in_AllocationSDWISIdentifierCV                218185 non-null  object
#  42  in_AllocationTimeframeEnd                     218185 non-null  object
#  43  in_AllocationTimeframeStart                   218185 non-null  object
#  44  in_AllocationTypeCV                           218185 non-null  object
#  45  in_AllocationVolume_AF                        218185 non-null  object
#  46  in_BeneficialUseCategory                      218185 non-null  object
#  47  in_CommunityWaterSupplySystem                 218185 non-null  object
#  48  in_CropTypeCV                                 218185 non-null  object
#  49  in_CustomerTypeCV                             218185 non-null  object
#  50  in_DataPublicationDate                        218185 non-null  object
#  51  in_DataPublicationDOI                         218185 non-null  object
#  52  in_ExemptOfVolumeFlowPriority                 218185 non-null  object
#  53  in_GeneratedPowerCapacityMW                   218185 non-null  object
#  54  in_IrrigatedAcreage                           218185 non-null  object
#  55  in_IrrigationMethodCV                         218185 non-null  object
#  56  in_LegacyAllocationIDs                        218185 non-null  object
#  57  in_OwnerClassificationCV                      218185 non-null  object
#  58  in_PopulationServed                           218185 non-null  object
#  59  in_PowerType                                  218185 non-null  object
#  60  in_PrimaryBeneficialUseCategory               218185 non-null  object
#  61  in_SDWISIdentifierCV                          218185 non-null  object
#  62  in_WaterAllocationNativeURL                   218185 non-null  object
# dtypes: datetime64[ns](1), object(62)
# memory usage: 104.9+ MB

# %%
outdf
# Out:
#        WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0          neD0       NEwr_M1                 NEwr_V1             NEwr_O1
# 1          neD1       NEwr_M1                 NEwr_V1             NEwr_O1
# 2          neD2       NEwr_M1                 NEwr_V1             NEwr_O1
# 3          neD3       NEwr_M1                 NEwr_V1             NEwr_O1
# 4          neD4       NEwr_M1                 NEwr_V1             NEwr_O1
# ...         ...           ...                     ...                 ...
# 218180  d188888       NEwr_M2                 NEwr_V1             NEwr_O1
# 218181  d188889       NEwr_M2                 NEwr_V1             NEwr_O1
# 218182  d188890       NEwr_M2                 NEwr_V1             NEwr_O1
# 218183  d188891       NEwr_M2                 NEwr_V1             NEwr_O1
# 218184  d188892       NEwr_M2                 NEwr_V1             NEwr_O1
#
#        in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...            ...                  ...                        ...
# 218180                                                       Fresh
# 218181                                                       Fresh
# 218182                                                       Fresh
# 218183                                                       Fresh
# 218184                                                       Fresh
#
#         in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0       North Platte River                wadeId1        Surface Water
# 1            Glenn Springs                wadeId2        Surface Water
# 2            Glenn Springs                wadeId2        Surface Water
# 3            Glenn Springs                wadeId2        Surface Water
# 4            Glenn Springs                wadeId2        Surface Water
# ...                    ...                    ...                  ...
# 218180                                 wadeId1535          Groundwater
# 218181                                 wadeId1535          Groundwater
# 218182                                 wadeId1535          Groundwater
# 218183                                 wadeId1535          Groundwater
# 218184                                 wadeId1535          Groundwater
#
#        in_CoordinateAccuracy in_CoordinateMethodCV   in_County in_EPSGCodeCV  \
# 0                                                                       4326
# 1                                                                       4326
# 2                                                                       4326
# 3                                                                       4326
# 4                                                                       4326
# ...                      ...                   ...         ...           ...
# 218180                                              Washington          4326
# 218181                                               Lancaster          4326
# 218182                                               Keya Paha          4326
# 218183                                                    Rock          4326
# 218184                                                  Cherry          4326
#
#        in_GNISCodeCV      in_HUC12 in_HUC8 in_Latitude in_Longitude  \
# 0                     101800090810            41.85584   -103.70574
# 1                     101800090402            42.00158   -104.04618
# 2                     101800090402            42.00158   -104.04618
# 3                     101800090402            42.00158   -104.04618
# 4                     101800090402            42.00158   -104.04618
# ...              ...           ...     ...         ...          ...
# 218180                                        41.54450    -96.19074
# 218181                                        40.87147    -96.68617
# 218182                                        42.84489    -99.90424
# 218183                                        42.51755    -99.66147
# 218184                                        42.87223   -101.08126
#
#        in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite  \
# 0                                                        POD
# 1                                                        POD
# 2                                                        POD
# 3                                                        POD
# 4                                                        POD
# ...                      ...             ...             ...
# 218180                                                   POD
# 218181                                                   POD
# 218182                                                   POD
# 218183                                                   POD
# 218184                                                   POD
#
#                  in_SiteName in_SiteNativeID in_SitePoint  \
# 0                                    wadeId1
# 1                                    wadeId2
# 2                                    wadeId2
# 3                                    wadeId2
# 4                                    wadeId2
# ...                      ...             ...          ...
# 218180   NWSW S9-T18-R11East     PODgw276201
# 218181    NENE S1-T10-R6East     PODgw276202
# 218182  NWSW S10-T33-R22West     PODgw276203
# 218183   NWNE S4-T29-R20West     PODgw276204
# 218184  SWSW S34-T34-R32West     PODgw276205
#
#                                   in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0                                                       NE
# 1                                                       NE
# 2                                                       NE
# 3                                                       NE
# 4                                                       NE
# ...                                         ...        ...           ...
# 218180  Connected to pump into a common carrier         NE
# 218181  Connected to pump into a common carrier         NE
# 218182                           Single Project         NE
# 218183                           Single Project         NE
# 218184  Connected to pump into a common carrier         NE
#
#        in_AllocationApplicationDate  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...
# 218180          2024-01-04T00:00:00
# 218181          2024-01-05T00:00:00
# 218182          2024-01-05T00:00:00
# 218183          2024-01-05T00:00:00
# 218184          2024-01-05T00:00:00
#
#        in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                             ...
# 218180
# 218181
# 218182
# 218183
# 218184
#
#        in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...                  ...
# 218180
# 218181
# 218182
# 218183
# 218184
#
#        in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 218180
# 218181
# 218182
# 218183
# 218184
#
#        in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                         ...
# 218180
# 218181
# 218182
# 218183
# 218184
#
#        in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0                                                0.04000
# 1                                                0.16000
# 2                                                0.16000
# 3                                                0.16000
# 4                                                0.16000
# ...                            ...                   ...
# 218180
# 218181
# 218182
# 218183
# 218184
#
#        in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                          Active                     1
# 1                          Active                     2
# 2                          Active                     2
# 3                          Active                     2
# 4                          Active                     2
# ...                           ...                   ...
# 218180     Active Registered Well              G-199137
# 218181     Active Registered Well              G-199138
# 218182     Active Registered Well              G-199139
# 218183     Active Registered Well              G-199141
# 218184     Active Registered Well              G-199143
#
#                  in_AllocationOwner in_AllocationPriorityDate  \
# 0       Central Irrigation District                1897-03-15
# 1                  Steve Pam Dickey                1933-05-29
# 2                  Steve Pam Dickey                1933-05-29
# 3                  Steve Pam Dickey                1933-05-29
# 4                  Steve Pam Dickey                1933-05-29
# ...                             ...                       ...
# 218180                                                    NaT
# 218181                                                    NaT
# 218182                                                    NaT
# 218183                                                    NaT
# 218184                                                    NaT
#
#        in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                       ...
# 218180
# 218181
# 218182
# 218183
# 218184
#
#        in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...                 ...                    ...
# 218180
# 218181
# 218182                                                               15.00000
# 218183                                                              850.00000
# 218184                                                              350.00000
#
#                                  in_BeneficialUseCategory  \
# 0                          Incidental Underground Storage
# 1                          Irrigation from Natural Stream
# 2                          Irrigation from Natural Stream
# 3                          Irrigation from Natural Stream
# 4                          Irrigation from Natural Stream
# ...                                                   ...
# 218180  Ground Heat Exchanger well - Closed Loop Heat ...
# 218181  Ground Heat Exchanger well - Closed Loop Heat ...
# 218182                                           Domestic
# 218183                                         Irrigation
# 218184                                         Irrigation
#
#        in_CommunityWaterSupplySystem in_CropTypeCV in_CustomerTypeCV  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...           ...               ...
# 218180
# 218181
# 218182
# 218183
# 218184
#
#        in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                   ...
# 218180             10/04/2023
# 218181             10/04/2023
# 218182             10/04/2023
# 218183             10/04/2023
# 218184             10/04/2023
#
#        in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...                         ...
# 218180                             1
# 218181                             1
# 218182                             1
# 218183                             1
# 218184                             1
#
#        in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...                   ...                    ...
# 218180
# 218181
# 218182
# 218183            67.00000
# 218184           132.00000
#
#        in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                 ...          ...
# 218180
# 218181
# 218182
# 218183
# 218184
#
#        in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                ...                  ...
# 218180
# 218181
# 218182
# 218183
# 218184
#
#                               in_WaterAllocationNativeURL
# 0       https://nednr.nebraska.gov/dynamic/WaterRights...
# 1       https://nednr.nebraska.gov/dynamic/WaterRights...
# 2       https://nednr.nebraska.gov/dynamic/WaterRights...
# 3       https://nednr.nebraska.gov/dynamic/WaterRights...
# 4       https://nednr.nebraska.gov/dynamic/WaterRights...
# ...                                                   ...
# 218180  https://nednr.nebraska.gov/Dynamic/Wells/Wells...
# 218181  https://nednr.nebraska.gov/Dynamic/Wells/Wells...
# 218182  https://nednr.nebraska.gov/Dynamic/Wells/Wells...
# 218183  https://nednr.nebraska.gov/Dynamic/Wells/Wells...
# 218184  https://nednr.nebraska.gov/Dynamic/Wells/Wells...
#
# [218185 rows x 63 columns]

# %%
# Export the output dataframe
outdf.to_csv('RawInputData/Pwr_neMain.zip', compression=dict(method='zip', archive_name='Pwr_neMain.csv'), index=False)  # The output, save as a zip
dfPoUshape.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.

# %%
https://gis.ne.gov/Enterprise/rest/services/SurfaceWaterRightsDiversionsExternal_DNR/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json

# %%
# already done, skip ahead

# %%time
# API retrieval
# shoot for 30 pages, that seemed to be all that AllSurfaceWaterPoints offered.
df = pd.DataFrame()
countPage = 1
while countPage < 30:
    url = "https://nednr.nebraska.gov/IwipApi/api/v1/WaterRights/AllSurfaceWaterPoints?page=" + str(countPage)
    print(url)

    # store in dataframe
    try:
        responseD = json.loads(requests.get(url).text)
        DtL = responseD['Results']
        length = len(DtL)
        for i in range(length):
            row = pd.DataFrame([DtL[i]])
            df = pd.concat([df, row])
    except:
        print("Error, issue with API return.")
    
    countPage = countPage + 1

# # Use only NeNDR Active provided sites
# df = df[df['SourceName'] == 'NeDNR']

print(len(df))
df.head()

# %%
    url = "https://nednr.nebraska.gov/IwipApi/api/v1/WaterRights/AllSurfaceWaterPoints?page=" + str(countPage)
    print(url)

    # store in dataframe
    try:
        responseD = json.loads(requests.get(url).text)
        DtL = responseD['Results']
        length = len(DtL)
        for i in range(length):
            row = pd.DataFrame([DtL[i]])
            df = pd.concat([df, row])
