# %% [markdown]
# # Working with NE Regulatory data.
#
# Pre-processing input data for a smoother upload experience of the state data to the WaDE 2.0 database.
#
# Using geopandas to read in shp file, and coverting to WKT for ReportingUnit geometry.

# %%
#Needed Libararies
import os
import numpy as np
import pandas as pd
from datetime import datetime
import geopandas as gpd # the library that lets us read in shapefiles
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/Nebraska/Regulatory"
os.chdir(workingDir)

#Shapefile input
AZ_AMA = gpd.read_file('RawInputData/Natural_Resource_District__NRD__Boundaries-shp/BND_NaturalResourceDistricts_DNR.shp')
dfshape = pd.DataFrame(AZ_AMA)

# %%
#check shp input
dfshape
# Out:
#     OBJECTID              NRD_Name            NRD_Name_A  NRD_Num  \
# 0          1      Lower Republican      LOWER REPUBLICAN       23
# 1          2             Tri-Basin             TRI-BASIN       24
# 2          3           Little Blue           LITTLE BLUE        5
# 3          4        Lower Big Blue        LOWER BIG BLUE        2
# 4          5                Nemaha                NEMAHA       11
# 5          6     Middle Republican     MIDDLE REPUBLICAN       22
# 6          7      Upper Republican      UPPER REPUBLICAN       21
# 7          8    Lower Platte South    LOWER PLATTE SOUTH       20
# 8          9        Upper Big Blue        UPPER BIG BLUE        1
# 9         10        Central Platte        CENTRAL PLATTE       18
# 10        11          South Platte          SOUTH PLATTE       16
# 11        12           Twin Platte           TWIN PLATTE       17
# 12        13    Lower Platte North    LOWER PLATTE NORTH       19
# ...

# %%
#Export to CSV

#Printing file to xlsx
dfshape.to_excel('RawInputData/P_NEReg.xlsx', index=False)
