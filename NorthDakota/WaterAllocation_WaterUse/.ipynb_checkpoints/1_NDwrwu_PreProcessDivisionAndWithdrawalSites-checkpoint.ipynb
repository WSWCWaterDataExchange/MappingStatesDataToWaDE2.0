# %% [markdown]
# # Pre-processing Water Right and Time Series Water Use data for WaDE Upload
# - Purpose:  To pre-process the data into one main file for simple DataFrame creation and extraction

# %%
import os
import sys
print(os.environ['CONDA_DEFAULT_ENV'])
print(sys.version)
# Out:
# base
# 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:20:11) [MSC v.1938 64 bit (AMD64)]

# %%
# Needed Libraries / Modules

# ---- working with data ----
import numpy as np  # mathematical array manipulation
import pandas as pd  # data structure and data analysis
import geopandas as gpd  # geo-data structure and data analysis

# ---- visualization ----
import matplotlib.pyplot as plt  # plotting library
import seaborn as sns  # plotting library

# ---- API data retrieval ----
import requests  # http requests
import json  # JSON parse

# ---- Cleanup ----
import re  # string regular expression manipulation
from datetime import datetime  # date and time manipulation
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation in Pandas

# %%
# ---- working directory ----
workingDirString = "G:/Shared drives/WaDE Data/WaDE Data Folder/NorthDakota/WaterAllocation_WaterUse" # set working directory folder string here
os.chdir(workingDirString)
print(f'The working Directory is:', workingDirString)
# Out:
# The working Directory is: G:/Shared drives/WaDE Data/WaDE Data Folder/NorthDakota/WaterAllocation_WaterUse

# %% [markdown]
# ## Data Input 1 - Permits.shp file
# - Permits water right data, in a shp file

# %%
# Input File - asdf
shapefileInput = "RawInputData/water_right/Permits.zip"
dfin1 = gpd.read_file(shapefileInput).replace(np.nan, "")

dfin1['permit_ind'] = dfin1['permit_ind'].replace("", 0).astype('Int64').astype('str')
dfin1['pod_index'] = dfin1['pod_index'].replace("", 0).astype('Int64').astype('str')
dfin1['linkKey'] = dfin1['permit_ind'] + "_" + dfin1['pod_index']

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin1:
    dfin1['WaDEUUID'] = "in1" + dfin1.index.astype(str)
    dfin1.to_csv("RawInputData/Permits.zip", compression=dict(method='zip', archive_name="Permits.csv"), index=False)

print(len(dfin1))
dfin1.head(1)
# Out:
# 12889
#   permit_ind permit_num pod_index        pod                     permit_hol  \
# 0          1       4407         1  13007302B  KETTERLING, ROLAND & LORRAINE
#
#    priority_d    use_type  status date_issue date_cance  beneficial    county  \
# 0  1991-03-04  Irrigation  Denied                        1111-11-11  McIntosh
#
#   hu_sub_bas aquifer subaquifer  req_acft  req_acre   req_rate  req_storag  \
# 0     Beaver                    204.00000 135.20000 1000.00000     0.00000
#
#    app_acft  app_acre  app_rate  app_storag pod_status        source  \
# 0   0.00000   0.00000   0.00000     0.00000     Denied  Ground Water
#
#   irrigation source_nam  mainstem impound_lo impound_na return_des discharge_  \
# 0  Sprinkler                    0
#
#   period_sta period_end  return_qua  held_acft  held_acre  held_rate  \
# 0                           0.00000    0.00000    0.00000    0.00000
#
#    held_stora  longitude  latitude  \
# 0     0.00000  -99.78988  46.11130
#
#                                             geometry linkKey WaDEUUID
# 0  POLYGON ((-99.79502 46.11495, -99.79374 46.114...     1_1     in10

# %%
# issue of similar 'pod' values not sharing same lat and long inputs.
# dissolve geometry into single geometry value by 'pod' value
# re-caculate lat and long of centroid
dfin1_s = dfin1[['pod', 'geometry']].sort_values(by=['pod'])
dfin1_s = dfin1_s.dissolve(by= 'pod', as_index=False)
dfin1_s['wade_lon'] = dfin1_s.centroid.x  
dfin1_s['wade_lat'] = dfin1_s.centroid.y
print(len(dfin1_s))
dfin1_s.head(1)
# Out:
# 10746
# C:\Users\rjame\AppData\Local\Temp\ipykernel_7580\4078292785.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   dfin1_s['wade_lon'] = dfin1_s.centroid.x
# C:\Users\rjame\AppData\Local\Temp\ipykernel_7580\4078292785.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   dfin1_s['wade_lat'] = dfin1_s.centroid.y
#           pod                                           geometry   wade_lon  \
# 0  02305925DB  POLYGON ((-104.03320 47.75433, -104.03826 47.7... -104.03573
#
#    wade_lat
# 0  47.75794

# %%
#left merge new geometry back into sites data

dfin1 = dfin1.merge(dfin1_s, left_on='pod', right_on='pod', how='left').replace(np.nan, "")
print(len(dfin1))
dfin1.head(1)
# Out:
# 12889
#   permit_ind permit_num pod_index        pod                     permit_hol  \
# 0          1       4407         1  13007302B  KETTERLING, ROLAND & LORRAINE
#
#    priority_d    use_type  status date_issue date_cance  beneficial    county  \
# 0  1991-03-04  Irrigation  Denied                        1111-11-11  McIntosh
#
#   hu_sub_bas aquifer subaquifer  req_acft  req_acre   req_rate  req_storag  \
# 0     Beaver                    204.00000 135.20000 1000.00000     0.00000
#
#    app_acft  app_acre  app_rate  app_storag pod_status        source  \
# 0   0.00000   0.00000   0.00000     0.00000     Denied  Ground Water
#
#   irrigation source_nam  mainstem impound_lo impound_na return_des discharge_  \
# 0  Sprinkler                    0
#
#   period_sta period_end  return_qua  held_acft  held_acre  held_rate  \
# 0                           0.00000    0.00000    0.00000    0.00000
#
#    held_stora  longitude  latitude  \
# 0     0.00000  -99.78988  46.11130
#
#                                           geometry_x linkKey WaDEUUID  \
# 0  POLYGON ((-99.79502 46.11495, -99.79374 46.114...     1_1     in10
#
#                                           geometry_y  wade_lon  wade_lat
# 0  POLYGON ((-99.79502 46.11495, -99.79374 46.114... -99.78987  46.11130

# %%
# swapping order owner name
import re

def createOwnerName(val):
    if val == "" or pd.isnull(val):
        outString = ""
    else:
        val = str(val)
        val = val.strip()
        if "," in val:
            x = val.split(",")
            outString = str(x[0]).strip() + " " + str(x[1]).strip()
        else:
            outString = val     
    return outString
dfin1['in_AllocationOwner'] = dfin1.apply(lambda row: createOwnerName(row['permit_hol']), axis=1)

def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

dfin1['in_AllocationOwner'] = dfin1.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
dfin1['in_AllocationOwner'].unique()
# Out:
# array(['Ketterling Roland Lorraine', 'Hyde George H', 'Slater A L', ...,
#        'Sneva Craig Mary And Smith', 'Schmit Layne', 'Treeby Hollis'],
#       dtype=object)

# %%
dfin1['in_WaterAllocationNativeURL'] = "https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=" + dfin1['permit_ind'].astype(str)
dfin1['in_WaterAllocationNativeURL'].unique()
# Out:
# array(['https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=1',
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=2',
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=3',
#        ...,
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=45239',
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=45240',
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=45241'],
#       dtype=object)

# %% [markdown]
# ## Data Input 2 - Time Series Use Data
# - Water_Use timeseries data
# - POD site data
# - Permit header data (to bridge timeseries and pod site)

# %%
# Input File - Timeseries water use data
fileInput = "RawInputData/water_use/Water_Use.zip"
dfin2 = pd.read_csv(fileInput).replace(np.nan, "")

dfin2['Permit_Index'] = dfin2['Permit_Index'].replace("", 0).astype('Int64').astype('str')
dfin2['POD_Index'] = dfin2['POD_Index'].replace("", 0).astype('Int64').astype('str')
dfin2['Use_Year'] = dfin2['Use_Year'].replace("", 0).astype('Int64').astype('str')
dfin2['linkKey'] = dfin2['Permit_Index'] + "_" + dfin2['POD_Index']

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfin2:
    dfin2['WaDEUUID'] = "in2" + dfin2.index.astype(str)
    dfin2.to_csv('RawInputData/Water_Use.zip', compression=dict(method='zip', archive_name='Water_Use.csv'), index=False)

print(len(dfin2))
dfin2.head(1)
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_7580\2132715426.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfin2 = pd.read_csv(fileInput).replace(np.nan, "")
# C:\Users\rjame\AppData\Local\Temp\ipykernel_7580\2132715426.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfin2['Permit_Index'] = dfin2['Permit_Index'].replace("", 0).astype('Int64').astype('str')
# C:\Users\rjame\AppData\Local\Temp\ipykernel_7580\2132715426.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfin2['POD_Index'] = dfin2['POD_Index'].replace("", 0).astype('Int64').astype('str')
# 206166
# C:\Users\rjame\AppData\Local\Temp\ipykernel_7580\2132715426.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfin2['Use_Year'] = dfin2['Use_Year'].replace("", 0).astype('Int64').astype('str')
#   Permit_Index POD_Index Use_Year Nature_Of_Data Reported_AcFt Reported_Acres  \
# 0          344       484     1991                     51.90000        0.00000
#
#   Reported_Rate   KWHrs KWH_Demand  Pump_HP Begin_Meter End_Meter Meter_Units  \
# 0     900.00000 0.00000    0.00000 70.00000     0.00000   0.00000       Hours
#
#                                      Comments NonConsumptive_Use Crop_type1  \
# 0  16,902,000 gallons of water reported used.            0.00000       Corn
#
#   Crop_Type2 Reported_Inches Water_Use_Index    Use_Type WaDEUUID  linkKey
# 0                                    0.00000  Irrigation    ndWU0  344_484

# %% [markdown]
# ### merge site info with time series info

# %%
#left merge sites to water use
dfin1 = dfin1.merge(dfin2, left_on='linkKey', right_on='linkKey', how='left').replace(np.nan, "")
print(len(dfin1))
dfin1.head(1)
# Out:
# 202860
#   permit_ind permit_num pod_index        pod                     permit_hol  \
# 0          1       4407         1  13007302B  KETTERLING, ROLAND & LORRAINE
#
#    priority_d    use_type  status date_issue date_cance  beneficial    county  \
# 0  1991-03-04  Irrigation  Denied                        1111-11-11  McIntosh
#
#   hu_sub_bas aquifer subaquifer  req_acft  req_acre   req_rate  req_storag  \
# 0     Beaver                    204.00000 135.20000 1000.00000     0.00000
#
#    app_acft  app_acre  app_rate  app_storag pod_status        source  \
# 0   0.00000   0.00000   0.00000     0.00000     Denied  Ground Water
#
#   irrigation source_nam  mainstem impound_lo impound_na return_des discharge_  \
# 0  Sprinkler                    0
#
#   period_sta period_end  return_qua  held_acft  held_acre  held_rate  \
# 0                           0.00000    0.00000    0.00000    0.00000
#
#    held_stora  longitude  latitude  \
# 0     0.00000  -99.78988  46.11130
#
#                                           geometry_x linkKey WaDEUUID_x  \
# 0  POLYGON ((-99.79502 46.11495, -99.79374 46.114...     1_1       in10
#
#                                           geometry_y  wade_lon  wade_lat  \
# 0  POLYGON ((-99.79502 46.11495, -99.79374 46.114... -99.78987  46.11130
#
#            in_AllocationOwner  \
# 0  Ketterling Roland Lorraine
#
#                          in_WaterAllocationNativeURL Permit_Index POD_Index  \
# 0  https://www.swc.nd.gov/info_edu/map_data_resou...
#
#   Use_Year Nature_Of_Data Reported_AcFt Reported_Acres Reported_Rate KWHrs  \
# 0
#
#   KWH_Demand Pump_HP Begin_Meter End_Meter Meter_Units Comments  \
# 0
#
#   NonConsumptive_Use Crop_type1 Crop_Type2 Reported_Inches Water_Use_Index  \
# 0
#
#   Use_Type WaDEUUID_y
# 0

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfin1['WaDEUUID_x']

# Method Info
df['in_MethodUUID'] = "NDwrwu_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "NDwrwu_V1" # for wr records portion only, will create sa portion below
df['in_AggregationIntervalUnitCV'] = "Annual"
df['in_VariableCV'] = "Water Right Use"

# Organization Info
df['in_OrganizationUUID'] = "NDwrwu_O1"

# WaterSource Info
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df['in_WaterSourceName'] = dfin1['source_nam'] # need this for auto fill below
df['in_WaterSourceNativeID'] = "" # auto fill in below
df['in_WaterSourceTypeCV'] = dfin1['source'] # need this for auto fill below

# Site Info
df['in_CoordinateAccuracy'] = ""
df['in_CoordinateMethodCV'] = "Centroid of Area"
df['in_County'] = ""
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df['in_Latitude'] = dfin1['wade_lat']
df['in_Longitude'] = dfin1['wade_lon']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df['in_PODorPOUSite'] = "POD"
df['in_SiteName'] = ""
df['in_SiteNativeID'] = "nd" + dfin1['pod'].replace("", 0).fillna(0).astype(str)
df['in_SitePoint'] = ""
df['in_SiteTypeCV'] = ""
df['in_StateCV'] = "ND"
df['in_USGSSiteID'] = ""

# AllocationAmount Info
df['in_AllocationApplicationDate'] = dfin1['date_issue']
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df['in_AllocationExpirationDate'] = dfin1['date_cance']
df['in_AllocationFlow_CFS'] = dfin1['app_rate'].astype(float)
df['in_AllocationLegalStatusCV'] = dfin1['pod_status'].astype(str)
df['in_AllocationNativeID'] = dfin1['permit_num'].astype(str).str.strip() + "_" + dfin1['pod_index'].astype(str).str.strip() 
df['in_AllocationOwner'] = dfin1['in_AllocationOwner']
df['in_AllocationPriorityDate'] = dfin1['priority_d']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = dfin1['period_end']
df['in_AllocationTimeframeStart'] = dfin1['period_sta']
df['in_AllocationTypeCV'] = ""
df['in_AllocationVolume_AF'] = dfin1['app_acft'].astype(float)
df['in_BeneficialUseCategory'] = dfin1['use_type']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0 # 1 or 0, if we want this data excempt
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = dfin1['app_acre'].astype(float)
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = dfin1['in_WaterAllocationNativeURL']

# Site VariableAmounts Info
df['in_Amount'] = dfin1['Reported_AcFt']
df['in_AssociatedNativeAllocationIDs'] = dfin1['permit_num'].astype(str).str.strip() + "_" + dfin1['pod_index'].astype(str).str.strip() 
df['in_PowerGeneratedGWh'] = ""
df['in_PrimaryUseCategory'] = ""
df['in_ReportYearCV'] = dfin1['Use_Year']
df['in_SDWISIdentifier'] = ""
df['in_TimeframeEnd'] = dfin1['Use_Year']  + "/12/31"
df['in_TimeframeStart'] = dfin1['Use_Year'] + "/01/01"  
# df['in_AllocationCropDutyAmount'] = "" see above AllocationAmount Info
# df['in_BeneficialUseCategory'] = "" see above AllocationAmount Info
# df['in_CommunityWaterSupplySystem'] = "" see above AllocationAmount Info
# df['in_CropTypeCV'] = "" see above AllocationAmount Info
# df['in_CustomerTypeCV'] = "" see above AllocationAmount Info
# df['in_DataPublicationDate'] = "" see above AllocationAmount Info
# df['in_DataPublicationDOI'] = "" see above AllocationAmount Info
# df['in_Geometry'] = "" see above Site Info
# df['in_IrrigatedAcreage'] = "" see above AllocationAmount Info
# df['in_IrrigationMethodCV'] = "" see above AllocationAmount Info
# df['in_PopulationServed'] = "" see above AllocationAmount Info
# df['in_PowerType'] = "" see above AllocationAmount Info
# df['in_SDWISIdentifier'] = "" see above AllocationAmount Info

outdf1 = df.copy()
outdf1 = outdf1.drop_duplicates().reset_index(drop=True)
print(len(outdf1))
outdf1.head()
# Out:
# 202781
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_AggregationIntervalUnitCV  \
# 0     in10     NDwrwu_M1               NDwrwu_V1                       Annual
# 1     in11     NDwrwu_M1               NDwrwu_V1                       Annual
# 2     in12     NDwrwu_M1               NDwrwu_V1                       Annual
# 3     in13     NDwrwu_M1               NDwrwu_V1                       Annual
# 4     in13     NDwrwu_M1               NDwrwu_V1                       Annual
#
#   in_VariableCV in_OrganizationUUID in_Geometry in_GNISFeatureNameCV  \
# 0   Water Right           NDwrwu_O1
# 1   Water Right           NDwrwu_O1
# 2   Water Right           NDwrwu_O1
# 3   Water Right           NDwrwu_O1
# 4   Water Right           NDwrwu_O1
#
#   in_WaterQualityIndicatorCV in_WaterSourceName in_WaterSourceNativeID  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceTypeCV in_CoordinateAccuracy in_CoordinateMethodCV in_County  \
# 0         Ground Water                            Centroid of Area
# 1        Surface Water                            Centroid of Area
# 2        Surface Water                            Centroid of Area
# 3        Surface Water                            Centroid of Area
# 4        Surface Water                            Centroid of Area
#
#    in_EPSGCodeCV in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0           4326                                    46.11130     -99.78987
# 1           4326                                    48.02622    -103.75216
# 2           4326                                    48.03706    -103.74690
# 3           4326                                    47.70175    -103.44125
# 4           4326                                    47.70175    -103.44125
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                   POD
# 1                                                   POD
# 2                                                   POD
# 3                                                   POD
# 4                                                   POD
#
#   in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0     nd13007302B                                    ND
# 1    nd15310236CC                                    ND
# 2    nd15310236BA                                    ND
# 3    nd14910026AB                                    ND
# 4    nd14910026AB                                    ND
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3                   1937-04-30
# 4                   1937-04-30
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.00000
# 3                                         1615.60000
# 4                                         1615.60000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                     Denied                4407_1
# 1                  Cancelled                  1E_2
# 2                  Cancelled                  2B_3
# 3                     Active                  2D_4
# 4                     Active                  2D_4
#
#               in_AllocationOwner in_AllocationPriorityDate  \
# 0     Ketterling Roland Lorraine                1991-03-04
# 1                  Hyde George H                1901-08-15
# 2                     Slater A L                1901-09-02
# 3  Gudmunsen Robert And Lowraine                1906-01-26
# 4  Gudmunsen Robert And Lowraine                1906-01-26
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeStart in_AllocationTypeCV  in_AllocationVolume_AF  \
# 0                                                                 0.00000
# 1                                                                 0.00000
# 2                                                                 0.00000
# 3                                                               291.00000
# 4                                                               291.00000
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0               Irrigation
# 1               Irrigation
# 2               Irrigation
# 3               Irrigation
# 4               Irrigation
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#    in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
#
#    in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0              0.00000
# 1              0.00000
# 2              0.00000
# 3            291.00000
# 4            291.00000
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL in_Amount  \
# 0  https://www.swc.nd.gov/info_edu/map_data_resou...
# 1  https://www.swc.nd.gov/info_edu/map_data_resou...   0.00000
# 2  https://www.swc.nd.gov/info_edu/map_data_resou...   0.00000
# 3  https://www.swc.nd.gov/info_edu/map_data_resou... 291.00000
# 4  https://www.swc.nd.gov/info_edu/map_data_resou... 291.00000
#
#   in_AssociatedNativeAllocationIDs in_PowerGeneratedGWh in_PrimaryUseCategory  \
# 0                           4407_1
# 1                             1E_2
# 2                             2B_3
# 3                             2D_4
# 4                             2D_4
#
#   in_ReportYearCV in_SDWISIdentifier in_TimeframeEnd in_TimeframeStart
# 0                                             /12/31            /01/01
# 1            1976                         1976/12/31        1976/01/01
# 2            1976                         1976/12/31        1976/01/01
# 3            1977                         1977/12/31        1977/01/01
# 4            1978                         1978/12/31        1978/01/01

# %% [markdown]
# ## Concatenate POD and POU Data.  Make needed changes

# %%
# etc etc,
# outdf2

# %% [markdown]
# ## Concatenate DataFrames together

# %%
# Concatenate dataframes
frames = [outdf1]  # list all out dataframes here
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 202781

# %% [markdown]
# ## Clean Data / data types

# %%
# updating in_WaterSourceTypeCV to be more machine readable / WaDE specific
# ----------------------------------------------------------------------------------------------------

def createWaterSourceTypeCV(inWST):
    inWST = str(inWST).strip()
    
    if inWST == "":
        outString = "WaDE Blank"
    elif inWST == "Ground Water":
        outString = "Groundwater"
    else:
        outString =  inWST
      
    return outString

outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: createWaterSourceTypeCV(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater', 'Surface Water', 'WaDE Blank'], dtype=object)

# %%
# Clean name entries of spcial characters
def removeSpecialCharsFunc(Val):
    Val = str(Val)
    Val = re.sub("[$@&.;/\)(-]", "", Val).title().replace("  ", " ").strip()
    return Val

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['', 'Mouse River', 'Charbonneau Creek', 'Beaver Creek',
#        'Nelson Creek', 'Little Creek, Paulson Creek', 'Green River',
#        'North Fork Cannonball River', 'Little Muddy River',
#        'Des Lacs River', 'Unnamed Coulee Dry Fork Coulee',
#        'Intermittent Draws, Trib To Little Miss', 'Heart River',
#        'Apple Creek', 'Little Missouri River', 'Buford Coulee',
#        'Unnamed Tributary', 'Burnt Creek', 'Souris River', 'Cedar Creek',
#        'Missouri River', 'Tobacco Garden Creek', 'Sheyenne River',
#        'Cherry Creek', 'Cannonball River', 'Knife River', 'Duck Creek',
#        'Lake Sakakawea', 'Yellowstone River', 'Knife River Tributary',
#        'Pembina River', 'Painted Woods Creek',
#        'North Branch Cannonball River', 'Red River', 'Gibb Springs',
#        'Sweetwater Lake', 'Mulberry Creek',
#        "Big Mary'S Coulee, Trib To Mouse River", 'Rush River',
#        'Sheep Creek', 'West Hay Draw Creek',
#        'Tributary To West Hay Draw Creek', 'North Fork Grand River',
#        'Maple River', 'Box Elder Creek, Trib To Little Missour',
#        'Spring Creek', 'James River', 'Chanta Peta Creek',
#        'Beaver Creek, Trib To Little Misouri Ri', 'Antelope Creek',
#        'Unnamed Creek', 'Square Butte Creek',
#        'Oxbow, Trib To Apple Creek', 'Silver Lake', 'Danners Coulee',
#        'Park River', 'South Branch Of The Goose River', 'Goose River',
#        'Unnamed Channel', 'Antler Creek',
#        'Unnamed Trib To Missouri River',
#        'Pats Coulee, Trib To Little Muddy', 'Tongue River', 'Cannonball',
#        '\x7fRed River', 'Scorio Creek',
#        'Horse Creek, Trib To Little Missouri Ri', 'Lake Oahe',
#        'North Branch Of Garner Creek', 'Crooked Creek Tributaries',
#        'Dry Run Creek', 'Dry Run', 'Elm River',
#        'Unnamed Waterway Round Lake', 'Square Butte Creel',
#        'Unnamed Tributary Of Knife River',
#        'Unnamed Tributary Of Deep Creek', 'Crooked Creek',
#        'Unnamed Tributary To The Knife River', 'White Earth River',
#        'Sweetbriar Creek', 'Pipestem Creek Lake Hiawatha',
#        'Unnamed Trib To Spring Creek',
#        'Unnamed Tributary To Crooked Creek Cro',
#        'Trib To Sqaure Butte Creek', 'North Branch Forest River',
#        'Red River Of The North', 'Unnamed Tributary To Spring Creek',
#        'Tributary To Shirk Creek', 'Unnamed Stream, Trib Of Little Muddy',
#        'Spring Creek Unnamed Trib', 'Unnamed Tributary To Slough',
#        'Middle Branch Forest River', 'Intermittent Draws', 'Tepee Creek',
#        'Beicegel Creek', 'Trib To Otter Creek', 'Bear Creek',
#        'South Branch Of Elm River', 'Clear Creek', 'Big Muddy Creek',
#        'Terminal Channel, Trib To Souris River',
#        'Lay Creek, Trib Of Tobacco Garden Creek',
#        'North Fork Grand River And Spring Creek', 'Trib To Turtle Creek',
#        'Trib To Burnt Creek', 'Unnamed Dry Wash', 'Three Mile Creek',
#        'Unnamed Intermittent Draw', 'Wild Rice River',
#        'Unnamed Creek Wild Rice River',
#        'Unamed Creek And Wild Rice River', 'Deep Creek',
#        'Unnamed Trib To Boundary Creek',
#        'Unnamed Channel, Tributary To Cedar Cree', 'Pipestem Creek',
#        'Unnamed Coulee', 'Unnamed Creek, Trib To Otter Creek',
#        'Nelson Lakesquare Butte Creek', 'Cart Creek',
#        'Unnamed Trib To Sweet Briar Creek',
#        'Unnamed Stream Kulmedgeley Reservoir',
#        'Apple Creek, Missouri River Backwater',
#        'Tributary To Pipestem Creek', 'Crooked Creek Tributary',
#        'Trib To Square Butte Creek', 'South Branch Goose River',
#        'Unnamed Tributary, Trib To Heart River', 'Willow Creek',
#        'Unnamed Trib To Crooked Creek', 'Wakopa Creek',
#        'Charbonneau Creek Trib', 'Unnamed Creek Trib To Willow Creek',
#        'Intermittent Creek', 'Trib To Wild Rice River', 'English Coulee',
#        'Unnamed Intermittent Trib', 'Big Coulee', 'Dry Draw',
#        'Unnamed Trib To Tongue River',
#        'Int Draw, Trib To Little Missouri River',
#        'Unnamed Inter Trib To Spring Creek', 'Horse Creek',
#        'Unnamed Coulee, Trib To Souris River',
#        'Unnamed Coulee To Burnt Creek', 'Unnamed Stream',
#        'Spring Creek And Beaver Creek', 'Buffalo Coulee',
#        'Tobacco Garden Cr Missouri R Backwater', 'Andrews Creek',
#        'South Unit', 'Unnamed Intermittent Stream', 'Salt Water Coulee',
#        'Beaver Creek And Missouri River',
#        'Unnamed Creek, Trib To North Fork Grand',
#        'Tongue River Renwick Dam', 'Mt Carmel Dam', 'Little Knife River',
#        'Unnamed Tributary Of Little Missouri R',
#        'Un Named Trib To Andrews Creek',
#        'Unnamed Stream, Trib To Little Missour',
#        'Unnamed Coulee, Tributary To Sakakawea', 'Timber Creek',
#        'Unnamed Intermittent Draws', 'Bullion Creek',
#        'Unnamed Stream, Trib To Cedar Creek',
#        'Unnamed Coulee, Trib To Painted Woods C', 'Franks Creek',
#        'Unnamed Intermittent Creek', 'Mc Gillis Creek', 'Unnamed Draw',
#        'Unnamed Stream, Tributary To Cedar Creek', 'Buffalo Creek',
#        'Big Muddy Creek And Intermittent Stream', 'Cottonwood Creek',
#        'Unnamed Creek, Tributary To Beaver Creek', 'Sand Creek',
#        'Unnamed Intermittent Streams', 'South Branch Of Turtle River',
#        'Apple Creek Tributary', 'Fourmile Creek', 'West Fork Deep Creek',
#        'Garner Creek', 'Unnamed Watershed, Tributary To Souris R',
#        'Unnamed Coulee, Trib To Sheyeene River',
#        'Unnamed Intermittant Draw', 'Oxbow, Trib To Knife River',
#        'Nelson Lake', 'Annie Creek',
#        'Beaver Creek, Trib To Little Missouri R',
#        'Unnamed Trib To Deep Creek', 'Unnamed Trib To Souris River',
#        'Unnamed Dry Channel', 'Long Lake Creek',
#        'Unnamed Draw, Trib To Northfork Cr',
#        'Runoff Unnamed Trib To Knife River', 'Hintz Bros Coulee',
#        'Oahe Reservoir', 'Unnamed Lakes', 'Unnamed Lake', 'Stony Creek',
#        'Sweet Briar Creek', 'Willow Lake', 'Middle Fork Of Deep Creek',
#        'Williams Creek', 'South Branch Turtle River', 'Goose Lake',
#        'Lonesome Creek', 'Iron Springs', 'Twin Lakes',
#        'Unnamed Draw, Tributary To Missouri Riv',
#        'Long Lake Creek Slough', 'Gibbs Springs',
#        'Unnamed Trib To North Fork Of The Grand', 'Unnamed Trib',
#        'Cottonwood Lake', 'Un Named Creek Trib To Missouri River',
#        'Little Beaver Creek', 'Little Knife River Tributary', 'Sloughs',
#        'Pond', 'Unnamed Trib To Cannonball River',
#        'Unnamed Stream, Trib Of Crooked Creek', 'Starkweather Çoulee',
#        'Unnamed Trib And Crooked Creek', 'Unnamed Water Course',
#        '101 Creek, Bennie Pierre Creek', 'Badlands Creek',
#        'Bennie Pierre Creek', 'Unnamed Drain',
#        'Branch Knife River Unnamed Trib', 'Lake Sakakwea',
#        'Dickinson City Sewage Lagoons # 3 4',
#        'Dickinson City Sewage Lagoons #3 4',
#        'Dickinson City Lagoon 4Th Cell',
#        'Unnamed Trib Of Square Butte Creek',
#        'Unnamed Trib To Charbonneau Creek', 'Kane Drain',
#        'Unnamed Stream Trib Of Missouri River',
#        'Third Cell Of Laggon System',
#        'Unnamed Stream Trib To Little Missouri', 'North Creek',
#        'Black Tail Creek', 'Blacktail Creek',
#        'Unnamed Tributary To Lake Sakakawea', 'Middle Fork Deep Creek',
#        'Unnamed Trib To Little Goose River',
#        'City Of Dickinson Lagoon Cell 4',
#        'Unnamed Stream, Trib To Missouri River',
#        'Unnamed Trib To Short Creek', 'Unnamed Trib Of Charbonneau Creek',
#        'Unnamed Drainage', 'Dogtooth Creek', 'Smishek Lake', 'Rice Creek',
#        'Unnamed Trib To Upper Lostwood Lake',
#        'Kanetacoma Drain, Trib Of Souris River',
#        'Unnamed Stream, Trib To Spring Creek',
#        'Tributary To South Branch Turtle River',
#        'Mcclusky Canal, Sta 433+448', 'Turtle Creek',
#        'Little Heart River', 'Fresh Water Coulee',
#        'Unnamed Trib Of Lake Sakakawea', 'Patterson Lake',
#        'Mcclusky Canal', 'Cole Creek', 'Forest River', 'Northfork Creek',
#        'Unnamed Trib To Little Missouri',
#        'Random Creek Trib To Long Lake Creek', 'Culvert Coulee',
#        'Unnamed Stream, Trib To Cannonball Riv', 'Acsc Condenser Pond',
#        "Trib To Kelly'S Slough, Trib To Turtle R",
#        'Skunk Coulee Flood Detention Dam #1', 'Trib To Turtle River',
#        'Unnamed Draw Trib To Laporte Coulee',
#        'Unnamed Draw Trib To Russell Drain',
#        'Unnamed Trib To Turtle River', 'Mud Creek',
#        'Unnamed Trib To Long Lake',
#        'Unnamed Drainage Trib To Harriet Lake', 'Lake Audubon',
#        'Waste Ground Water From Malting Process',
#        'Unnamed Trib To West Stump Lake', 'Otter Creek',
#        'Starkweather Coulee', 'Unnamed Trib To Willow Lake', 'Slough',
#        'Bone Hill Creek', 'Grand Forks County Wrd Flood Detention D',
#        'Mauvais Coulee', 'Heart River Missouri River Backwater',
#        'Plum Creek', 'Heart River Tributary', 'Lightning Creek',
#        'Unnamed Tributary Of Spring Creek',
#        'Unnamed Trib West Branch Of Short Creek',
#        'Unnamed Trib Of Thirty Mile Creek', 'Coal Creek',
#        'Unnamed Trib Of Plum Creek', 'Laporte Coulee', 'Kelly Slough',
#        'Unnamed Wetland A Trib Of Lake Audubon', 'Flat Creek',
#        'Lake Alice', 'Unnamed Trib To Bennie Pierre Creek',
#        'Unnamed Trib To Bennnie Pierre Creek',
#        'Kanetacomaovergaard Drain', 'Alkali Creek',
#        'Unnamed Trib To Slow Cr, Spring Cr Trib', 'Dry Lake',
#        'Unnamed Trib To Cedar Creek', 'Unnamed Trib Of Spring Creek Trib',
#        'Unnamed Trib To Indian Creek',
#        'Unnamed Stream, Trib To Buffalo Creek',
#        'Unnamed Trib To Hans Crspring Cr Trib',
#        'Lagoons For Residual Ground Water',
#        'Unnamed Trib Of Spring Creek', 'Unnamed Trib Of Edmore Coulee',
#        'Unnamed Trib To Edmore Coulee',
#        'Unnamed Stream Trib To Little Knife R', 'Lake Irvine',
#        'Renwick Dam', 'Ranch Lake', 'Unnamed Tributary To Lake George',
#        'Grand Harbor Drainage Trib Six Mile Bay',
#        'Unnamed Tribhaymarsh Cr Trib Big Muddy',
#        'Unnamed Trib Of White Earth River', 'Valley City Sewage Lagoons',
#        'Valley City Municipal Lagoons',
#        'Dickinson City Sewage Lagoon Cells 3 4',
#        'Dickinson City Sewage Lagoon Cell #2',
#        'Dickinson Sewage Lagoons #2, 3, 4',
#        'Big Coulee Waterway Trib Mauvais Coulee',
#        'Big Coulee Waterwau Trib Mauvais Coulee',
#        'Unnamed Trib Of South Branch Park River',
#        'Unnamed Trib Of Beaver Holes Creek',
#        'Muskrat Cr Trib Sims Cr Trib Hailstone C',
#        'Unnamed Trib To Battle Creek', 'Unnamed Trib To Coyote Creek',
#        'Little South Pembina River',
#        'Unnamed Waterway Trib To Roger Creek',
#        'Unnamed Waterway Trib To Deep Creek',
#        'Unnamed Waterway Trib To Heart Butte Ck', 'Goose Creek',
#        'Unnamed Stream Trib To Goose Creek',
#        'Unnamed Trib To Little Heart River', 'Pembina County Drain #20',
#        'Murphy Creek Trib To Spring Creek', 'Groundwater',
#        'Unnamed Tributary To Starkweather Coulee',
#        'Unnamed Drain Trib Starkweather Coulee', 'Unnamed',
#        'Unnamed, Crooked Creek', 'Branch Knife River',
#        'Unnamed Trib To Heart River',
#        'Unnamed Trib To Square Butte Creek', 'Mount Carmel Dam',
#        'Ground Water', 'Unnamed Trib To Maple River',
#        'Middle Branch Park River', 'Unnamed Trib To Dead Buffalo Lake',
#        'West Cut Bank Creek', 'Unnamed Creek Trib To Porcupine Creek',
#        'Unnamed Tributary To Porcupine Creek', 'Indian Creek',
#        'Spring Creek Trib To Lower Coyote Creek',
#        'Unnamed Trib To East Antelope Creek', 'Scab Creek', 'Twin Lake',
#        'Stack Slough', 'Chain Lake', 'Unnamed Tributary Of Beaver Creek',
#        'Central Dakota', 'Oak Creek', 'Random Creek', 'Stoney Creek',
#        'Morrison Lake', 'Long Creek', 'Kenner Marsh', 'Shell Creek',
#        'Island Lake', 'Unnamed Trib Of Coyote Creek',
#        'Drake Sewage Lagoon', 'Dayton Creek', 'Unknown Tributary',
#        'Esmond Aquifer', 'Trappers Coulee Aquifer',
#        'Middle Branch Of Park River', 'Middle Brannch Park',
#        'East Antelope Creek', 'Edmore Coulee',
#        'Unnamed Tributary Of Cedar Creek', 'Skunk Coulee',
#        'Unnamed Tributary Of Wannagan Creek',
#        'Unnamed Creektrib Of Cedar Creek',
#        'Unnamed Stream, Tributary Of Ash Creek',
#        'Unnamed Creek, Trib Of Antelope Creek', 'Wolf Lake',
#        'Coal Bank Creektrib Of Cannonball River',
#        'Unnamed Tributary To Little Knife River',
#        'Unnamed Creek Trib Of Morris Creek',
#        'Unnamed Creek, Trib Of Cold Turkey Creek',
#        'Unnamed Creek Tribe Of Turkey Creek',
#        'Skunk Coulee, Tributary To Turtle River', 'Horne Pond',
#        'Unnamed, Tributary Of Squaw Creek', 'Hiddenwood Lake',
#        'Unnamed Creek A Trib Of Whitmore Creek',
#        'Unnamed Creek Trib Of Whitmore Creek',
#        'Unnamed Creek A Trib Of Crooked Creek',
#        'Sweet Briar Creek A Trib Of The Heart',
#        'Natural Runoff, Trib Of Mclaughlin Lake', 'Drain No 29',
#        'Mclaughlin Lake A Trib Of Pembina River',
#        'Unnamed Source A Trib Of James River',
#        'Unnamed Tributary Of Antelope Creek',
#        'Unnamed Tributary Of The Cannonbal River',
#        'Unnamed Creek Trib Of Lightning Creek', 'Little Muddy Creek',
#        'Unnamed Source Trib Of Pipestem River',
#        'Unnamed Tributary Of Rock Lake', 'Unnamed Tributary To Rock Lake',
#        'Unnamed Trib Of Burnt Creek', 'Knife River Elm Creek',
#        'Calio Coulee', 'Antelpoe Creek',
#        'Unnamed Creek, Tribto Cannonball River', 'Drainage Ditch',
#        'Unnamed Creek A Tributary Of Cedar Creek',
#        'Des Lacs River A Trib Of Souris River',
#        'Unnamed Stream A Trib Of Cedar Creek',
#        'Unnamed Creek Trib Of Timber Creek',
#        'Unnamed Creek, Trib To Leaf On The Hill', 'Souris River Dam 83',
#        'Souris River Pond C', 'Souris River Dam 87', 'Souris Riverdam 41',
#        'Souris Riverdam 96', 'Souris Riverdam 320', 'Souris Riverdam 326',
#        'Souris River Dam 320', 'Souris Riverdam 332',
#        'Souris River Dam 326', 'Souris Riverdam 341',
#        'Souris Riverdam 357', 'Lake Ordway',
#        'Tongue River A Trib Of The Red River', 'Wieler Dam',
#        'Oak Creek A Trib Of Willow Creek',
#        'Unnamed Stream On The Forest River',
#        'Goschke Dam On Tongue River', 'Weiler Dam A Trib Of Tongue River',
#        'Valley City Lagoon', 'Unnamed Creek Trib Of Painted Woods Crk',
#        'North Branch Of The Goose River',
#        'Unnamed Stream Trib Of Forest River',
#        'Unnamed Creek Trib Of The Green River', 'Lake Hoskins',
#        'Jensen Dam', 'Unnamed Creek Trib Of Frank Creek',
#        'Starkwater Coulee Trib Of Devils Lake',
#        'Unnamed Creek, Trib Of Dutton Slough',
#        'Unnamed Creek Trib Of Turtle Creek', 'Morris Creek',
#        'Unnamed Creek Trib Of Knife River',
#        'Unnamed Creek Trib Of Porcupine Creek',
#        'Unnamed Creek, Trib To Heart River',
#        'Unnamed Creek Trib Of Baher Creek',
#        'Unnamed Creek Trib Of Bahr Creek',
#        'Unnamed Creek, Trib Of Painted Woods Cr',
#        'Unnamed Creek Trib Of S Fork Green Riv',
#        'Unnamed Creek Trib Of Big Meadow Marsh',
#        'Russian Slough Creek Trib Of Cedar Creek',
#        'Unnamed Creek Trib Of Leaf On The Hill',
#        'Unnamed Creek Trib Of Missouri River',
#        'Lake Ashtabula Trib Of The Red River',
#        'Cherry Creek Trib Of Little Misouri',
#        'Square Butte Creek Trib Of The Missouri',
#        'Skunk Coulee Flood Detention #1',
#        'Unnamed Creek A Trib Of Sheyenne River',
#        'Jim Creek, Trib Of Little Missouri',
#        'Unnamed Tributary To Kinneman Creek',
#        'Unnamed Creek Trib Of Beaver Creek',
#        'Unnamed Creek Trib Of Lone Tree Creek', 'Five Mile Creek',
#        'Unnamed Trib Of The Missouri River',
#        'Apple Creek East Trib Of Missouri River',
#        'Cow Creek A Trib Of The Heart River',
#        'Unnamed Creek Trib Of Thirty Mile Creek', 'Lake Ibsen',
#        'Unnamed Creek Trib Of Spring Creek',
#        'Unnamed Creek Trib Of Whitetail Creek', 'Adm Ethanol Plant Ponds',
#        'Horse Tied Creek Trib Of Missouri River',
#        'Unnamed Creek Trib Of Sfork Smith Crk',
#        'Unnamed Creek, Trib Of Bahr Creek',
#        'Whitmore Creek Trib Of Cedar Creek',
#        'Unnamed Creek Trib Of East Fork Shell',
#        'Unnamed Creek Trib Of Shell Creek',
#        'Unnamed Stream Trib Of S Fork Maple R',
#        'Unnamed Creek Trib Of Nelson Creek',
#        'Unnamed Creek Trib Of Willow Coulee',
#        'Burnt Creek, Trib Of Missouri River', 'Frying Pan Lake',
#        'Willow Coulee Creek', 'Battle Creek Trib Of The Missouri River',
#        'Cannon Ball River Trib Of Missouri',
#        'Cannon Ball River Trib Of Misssouri',
#        'Unnamed Stream, Trib Of Plum Creek',
#        'Unnamed Stream Trib Of Lightning Creek',
#        'Nelson Creek,Trib Of The Missouri River',
#        'Unnamed Creek Trib Of Powers Lake',
#        'Unnamed Tributary To Ash Creek',
#        'Unnamed Creek, Trib To Branch Knife Rive',
#        'Unnamed Stream Trib Of Apple Creek',
#        'Unnamed Stream Trib Of Thirty Mile Ck', 'Unnamed Wetland',
#        'Cottonwood Creek, Trib Of James River',
#        'Unnamed Streamtrib Of The James River',
#        'Unnamed Stream Trib Of Little Muddy Riv', 'Spiritwood Aquifer',
#        'Unnamed Stream Trib Of Little Muddy',
#        'Goshke Dam On Busse Coulee', 'Goschke Dam On Busse Coulee',
#        'Unamed Coulee Trib Of Lower Des Lacs',
#        'Flat Creek Trib Of N Fork Grand River', 'Chimney Butte Creek',
#        'Unnamed Coulee A Trib Of T Heart River',
#        'Unnamed Coulee Trib Of The Heart River',
#        'Unnamed Creek, Trib Of Wolf Creek',
#        "Gibb'S Spring, Trib Of Little Knife", 'Little Bull Creek',
#        'Unnamed Tributary Of North Branch Park',
#        'Unnamed Creek, Tribof Stony Slough',
#        'Unnamed Waterway, Trib Of Des Lacs River', 'Goschke Dam',
#        'Unnamed Creek, Trib Of The Tongue River',
#        'Bussee Coulee, Trib Of The Tongue River',
#        'Unnamed Stream Trib Of Heart River',
#        'Tongue River Renwick Dam M4', 'Treated City Wastewater',
#        'James River, Fesenden Dam', 'Sheyenne River At Harvey Dam',
#        'Coal Mine Creek', 'Unnamed Creek, A Trib To Knife River',
#        'Scab Creek, Trib To Big Muddy Creek',
#        'Unnamed Creek Trib Of The Heart River',
#        'Unnamed Creek, Trib To Dogtooth Creek',
#        'Unnamed Creek, Trib Of The Heart River',
#        'Tributary To Crooked Creek', 'Trenton Lake',
#        'Cedar Creek Tributary', 'Trib Of Painted Woods Creek',
#        'Muddy Creek Tributary To Heart River', 'Lake Margaret',
#        'Rats Coulee', 'Unnamed Creek, Trib Of Edmore Coulee',
#        'Desmoines Lake', 'Unnamed Creek, Trib Of Square Butte Ck',
#        'Unnamed Tributary To Scab Creek', 'Eightmile Creek',
#        'Unnamed Slough', 'Pitt Creek Tributary',
#        'Alkaline Lake, Aka Northwest Slough', 'Burnt Creek Diversion',
#        'Trib Of Crosby Creek', 'Hazen Brook',
#        'Southwest Pipeline Project', 'Spring Trib Of White Earth River',
#        'Unnamed Tributary To Coal Creek',
#        'Tributary To Painted Woods Creek', 'The Pembina River',
#        'First Larson Coulee', 'Waste Water Logoons',
#        'Waste Water Lagoons', '4 Cell Lagoon System',
#        'Shallow Saturated Alluvium', 'Des Lac Lake',
#        'Tributary To The Wild Rice River', 'Hartel Dam',
#        'Puppy Dog Coulee', 'Oakes Pilot Drain', 'Fort Union',
#        'Sletten Lake', 'Jackson Township Improvement Project',
#        'Dakota Group', 'Tongue River At Goschke Dam',
#        'Schmidt North Pond', 'Schmidt West Pond', 'Schmidt East Pond',
#        'North Branch Turtle River', 'Strommen Stock Pond', 'Popple Lake',
#        'Antelope Crreek', 'Stone Creek',
#        'Unnamed Trib Of East Fork Shell Creek',
#        'Sentinel Buttetongue River', 'Canonball River', 'Demicks Lake',
#        'Ephemeral Drainages', 'South Egg Creek', 'Camp Creek',
#        'Spring Creek Tributary', 'Bennett Creek', 'Unnamed Stock Pond',
#        'Natural Runoff To Coal Lake', 'Unnamed Pond',
#        'Hagel Creek Tributary', 'Strommen Pond Spring Creek Trib',
#        "Pat'S Coulee, Trib To Little Muddy",
#        'Strawberry, Crooked Brekken Lakes',
#        'Strawberr, Crooked Brekken Lakes', 'Strawberry, Crooked Brekken',
#        'Cheyenne River', 'Horseshoe Lake', 'Holding Pond',
#        'Halfbreed Creek', 'Lake Upsilon', 'Lake Trenton', 'Little Stoney',
#        'Unnamed Trib To Knife River', 'Tributary Of Crooked Creek',
#        'Cedar River', 'Muskrat Lake', 'Drain 11', 'East Buehner Pond',
#        'Jim Creek', 'Derudder Reservoir', 'Abbey Lake',
#        'Oxbow Of Stoney Creek', 'Lake Sakakaweabackwater',
#        'Matejcek Reservoir', 'Lake Zahl', 'Frank Creek', 'Murphy Slough',
#        'Mcville', 'Unnamed Reservoir', 'Dry Creek', 'Truchan Pond',
#        'Unnamed Dam', 'Natural Runoff To Lake Nettie', 'Roth Lake',
#        'Unnamed Stock Dam On Bear Den Creek',
#        'Unnamed Tributary Of Norred Creek', 'Cass County Drain 27',
#        'Russian Spring Creek', 'Tributary To Forest River',
#        'Lower Sheyenne River Watershed',
#        'Unnamed Tributary To The James River', 'Dickey Sargent Drain',
#        'Unnamed Tributary To West Antelope Creek',
#        'Unnamed Tributary To Forest River', 'Sorenson Gravel Pit',
#        'Matejcek Dam', 'Unknown', 'Alkaline Lake North',
#        'Unnamed Wetlands', 'Unnamed Sloughs', 'Warneke Dam', 'West Dam',
#        'Camp Dam', 'Unnamed Creek, Tributary To Apple Creek',
#        'Gravel Pit', 'Dakota Lake James River Watershed'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: removeSpecialCharsFunc(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Ketterling Roland Lorraine', 'Hyde George H', 'Slater A L', ...,
#        'Sneva Craig Mary And Smith', 'Schmit Layne', 'Treeby Hollis'],
#       dtype=object)

# %%
# Ensure Empty String / remove string value of "nan"

def ensureEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = ""
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['', 'Mouse River', 'Charbonneau Creek', 'Beaver Creek',
#        'Nelson Creek', 'Little Creek, Paulson Creek', 'Green River',
#        'North Fork Cannonball River', 'Little Muddy River',
#        'Des Lacs River', 'Unnamed Coulee Dry Fork Coulee',
#        'Intermittent Draws, Trib To Little Miss', 'Heart River',
#        'Apple Creek', 'Little Missouri River', 'Buford Coulee',
#        'Unnamed Tributary', 'Burnt Creek', 'Souris River', 'Cedar Creek',
#        'Missouri River', 'Tobacco Garden Creek', 'Sheyenne River',
#        'Cherry Creek', 'Cannonball River', 'Knife River', 'Duck Creek',
#        'Lake Sakakawea', 'Yellowstone River', 'Knife River Tributary',
#        'Pembina River', 'Painted Woods Creek',
#        'North Branch Cannonball River', 'Red River', 'Gibb Springs',
#        'Sweetwater Lake', 'Mulberry Creek',
#        "Big Mary'S Coulee, Trib To Mouse River", 'Rush River',
#        'Sheep Creek', 'West Hay Draw Creek',
#        'Tributary To West Hay Draw Creek', 'North Fork Grand River',
#        'Maple River', 'Box Elder Creek, Trib To Little Missour',
#        'Spring Creek', 'James River', 'Chanta Peta Creek',
#        'Beaver Creek, Trib To Little Misouri Ri', 'Antelope Creek',
#        'Unnamed Creek', 'Square Butte Creek',
#        'Oxbow, Trib To Apple Creek', 'Silver Lake', 'Danners Coulee',
#        'Park River', 'South Branch Of The Goose River', 'Goose River',
#        'Unnamed Channel', 'Antler Creek',
#        'Unnamed Trib To Missouri River',
#        'Pats Coulee, Trib To Little Muddy', 'Tongue River', 'Cannonball',
#        '\x7fRed River', 'Scorio Creek',
#        'Horse Creek, Trib To Little Missouri Ri', 'Lake Oahe',
#        'North Branch Of Garner Creek', 'Crooked Creek Tributaries',
#        'Dry Run Creek', 'Dry Run', 'Elm River',
#        'Unnamed Waterway Round Lake', 'Square Butte Creel',
#        'Unnamed Tributary Of Knife River',
#        'Unnamed Tributary Of Deep Creek', 'Crooked Creek',
#        'Unnamed Tributary To The Knife River', 'White Earth River',
#        'Sweetbriar Creek', 'Pipestem Creek Lake Hiawatha',
#        'Unnamed Trib To Spring Creek',
#        'Unnamed Tributary To Crooked Creek Cro',
#        'Trib To Sqaure Butte Creek', 'North Branch Forest River',
#        'Red River Of The North', 'Unnamed Tributary To Spring Creek',
#        'Tributary To Shirk Creek', 'Unnamed Stream, Trib Of Little Muddy',
#        'Spring Creek Unnamed Trib', 'Unnamed Tributary To Slough',
#        'Middle Branch Forest River', 'Intermittent Draws', 'Tepee Creek',
#        'Beicegel Creek', 'Trib To Otter Creek', 'Bear Creek',
#        'South Branch Of Elm River', 'Clear Creek', 'Big Muddy Creek',
#        'Terminal Channel, Trib To Souris River',
#        'Lay Creek, Trib Of Tobacco Garden Creek',
#        'North Fork Grand River And Spring Creek', 'Trib To Turtle Creek',
#        'Trib To Burnt Creek', 'Unnamed Dry Wash', 'Three Mile Creek',
#        'Unnamed Intermittent Draw', 'Wild Rice River',
#        'Unnamed Creek Wild Rice River',
#        'Unamed Creek And Wild Rice River', 'Deep Creek',
#        'Unnamed Trib To Boundary Creek',
#        'Unnamed Channel, Tributary To Cedar Cree', 'Pipestem Creek',
#        'Unnamed Coulee', 'Unnamed Creek, Trib To Otter Creek',
#        'Nelson Lakesquare Butte Creek', 'Cart Creek',
#        'Unnamed Trib To Sweet Briar Creek',
#        'Unnamed Stream Kulmedgeley Reservoir',
#        'Apple Creek, Missouri River Backwater',
#        'Tributary To Pipestem Creek', 'Crooked Creek Tributary',
#        'Trib To Square Butte Creek', 'South Branch Goose River',
#        'Unnamed Tributary, Trib To Heart River', 'Willow Creek',
#        'Unnamed Trib To Crooked Creek', 'Wakopa Creek',
#        'Charbonneau Creek Trib', 'Unnamed Creek Trib To Willow Creek',
#        'Intermittent Creek', 'Trib To Wild Rice River', 'English Coulee',
#        'Unnamed Intermittent Trib', 'Big Coulee', 'Dry Draw',
#        'Unnamed Trib To Tongue River',
#        'Int Draw, Trib To Little Missouri River',
#        'Unnamed Inter Trib To Spring Creek', 'Horse Creek',
#        'Unnamed Coulee, Trib To Souris River',
#        'Unnamed Coulee To Burnt Creek', 'Unnamed Stream',
#        'Spring Creek And Beaver Creek', 'Buffalo Coulee',
#        'Tobacco Garden Cr Missouri R Backwater', 'Andrews Creek',
#        'South Unit', 'Unnamed Intermittent Stream', 'Salt Water Coulee',
#        'Beaver Creek And Missouri River',
#        'Unnamed Creek, Trib To North Fork Grand',
#        'Tongue River Renwick Dam', 'Mt Carmel Dam', 'Little Knife River',
#        'Unnamed Tributary Of Little Missouri R',
#        'Un Named Trib To Andrews Creek',
#        'Unnamed Stream, Trib To Little Missour',
#        'Unnamed Coulee, Tributary To Sakakawea', 'Timber Creek',
#        'Unnamed Intermittent Draws', 'Bullion Creek',
#        'Unnamed Stream, Trib To Cedar Creek',
#        'Unnamed Coulee, Trib To Painted Woods C', 'Franks Creek',
#        'Unnamed Intermittent Creek', 'Mc Gillis Creek', 'Unnamed Draw',
#        'Unnamed Stream, Tributary To Cedar Creek', 'Buffalo Creek',
#        'Big Muddy Creek And Intermittent Stream', 'Cottonwood Creek',
#        'Unnamed Creek, Tributary To Beaver Creek', 'Sand Creek',
#        'Unnamed Intermittent Streams', 'South Branch Of Turtle River',
#        'Apple Creek Tributary', 'Fourmile Creek', 'West Fork Deep Creek',
#        'Garner Creek', 'Unnamed Watershed, Tributary To Souris R',
#        'Unnamed Coulee, Trib To Sheyeene River',
#        'Unnamed Intermittant Draw', 'Oxbow, Trib To Knife River',
#        'Nelson Lake', 'Annie Creek',
#        'Beaver Creek, Trib To Little Missouri R',
#        'Unnamed Trib To Deep Creek', 'Unnamed Trib To Souris River',
#        'Unnamed Dry Channel', 'Long Lake Creek',
#        'Unnamed Draw, Trib To Northfork Cr',
#        'Runoff Unnamed Trib To Knife River', 'Hintz Bros Coulee',
#        'Oahe Reservoir', 'Unnamed Lakes', 'Unnamed Lake', 'Stony Creek',
#        'Sweet Briar Creek', 'Willow Lake', 'Middle Fork Of Deep Creek',
#        'Williams Creek', 'South Branch Turtle River', 'Goose Lake',
#        'Lonesome Creek', 'Iron Springs', 'Twin Lakes',
#        'Unnamed Draw, Tributary To Missouri Riv',
#        'Long Lake Creek Slough', 'Gibbs Springs',
#        'Unnamed Trib To North Fork Of The Grand', 'Unnamed Trib',
#        'Cottonwood Lake', 'Un Named Creek Trib To Missouri River',
#        'Little Beaver Creek', 'Little Knife River Tributary', 'Sloughs',
#        'Pond', 'Unnamed Trib To Cannonball River',
#        'Unnamed Stream, Trib Of Crooked Creek', 'Starkweather Çoulee',
#        'Unnamed Trib And Crooked Creek', 'Unnamed Water Course',
#        '101 Creek, Bennie Pierre Creek', 'Badlands Creek',
#        'Bennie Pierre Creek', 'Unnamed Drain',
#        'Branch Knife River Unnamed Trib', 'Lake Sakakwea',
#        'Dickinson City Sewage Lagoons # 3 4',
#        'Dickinson City Sewage Lagoons #3 4',
#        'Dickinson City Lagoon 4Th Cell',
#        'Unnamed Trib Of Square Butte Creek',
#        'Unnamed Trib To Charbonneau Creek', 'Kane Drain',
#        'Unnamed Stream Trib Of Missouri River',
#        'Third Cell Of Laggon System',
#        'Unnamed Stream Trib To Little Missouri', 'North Creek',
#        'Black Tail Creek', 'Blacktail Creek',
#        'Unnamed Tributary To Lake Sakakawea', 'Middle Fork Deep Creek',
#        'Unnamed Trib To Little Goose River',
#        'City Of Dickinson Lagoon Cell 4',
#        'Unnamed Stream, Trib To Missouri River',
#        'Unnamed Trib To Short Creek', 'Unnamed Trib Of Charbonneau Creek',
#        'Unnamed Drainage', 'Dogtooth Creek', 'Smishek Lake', 'Rice Creek',
#        'Unnamed Trib To Upper Lostwood Lake',
#        'Kanetacoma Drain, Trib Of Souris River',
#        'Unnamed Stream, Trib To Spring Creek',
#        'Tributary To South Branch Turtle River',
#        'Mcclusky Canal, Sta 433+448', 'Turtle Creek',
#        'Little Heart River', 'Fresh Water Coulee',
#        'Unnamed Trib Of Lake Sakakawea', 'Patterson Lake',
#        'Mcclusky Canal', 'Cole Creek', 'Forest River', 'Northfork Creek',
#        'Unnamed Trib To Little Missouri',
#        'Random Creek Trib To Long Lake Creek', 'Culvert Coulee',
#        'Unnamed Stream, Trib To Cannonball Riv', 'Acsc Condenser Pond',
#        "Trib To Kelly'S Slough, Trib To Turtle R",
#        'Skunk Coulee Flood Detention Dam #1', 'Trib To Turtle River',
#        'Unnamed Draw Trib To Laporte Coulee',
#        'Unnamed Draw Trib To Russell Drain',
#        'Unnamed Trib To Turtle River', 'Mud Creek',
#        'Unnamed Trib To Long Lake',
#        'Unnamed Drainage Trib To Harriet Lake', 'Lake Audubon',
#        'Waste Ground Water From Malting Process',
#        'Unnamed Trib To West Stump Lake', 'Otter Creek',
#        'Starkweather Coulee', 'Unnamed Trib To Willow Lake', 'Slough',
#        'Bone Hill Creek', 'Grand Forks County Wrd Flood Detention D',
#        'Mauvais Coulee', 'Heart River Missouri River Backwater',
#        'Plum Creek', 'Heart River Tributary', 'Lightning Creek',
#        'Unnamed Tributary Of Spring Creek',
#        'Unnamed Trib West Branch Of Short Creek',
#        'Unnamed Trib Of Thirty Mile Creek', 'Coal Creek',
#        'Unnamed Trib Of Plum Creek', 'Laporte Coulee', 'Kelly Slough',
#        'Unnamed Wetland A Trib Of Lake Audubon', 'Flat Creek',
#        'Lake Alice', 'Unnamed Trib To Bennie Pierre Creek',
#        'Unnamed Trib To Bennnie Pierre Creek',
#        'Kanetacomaovergaard Drain', 'Alkali Creek',
#        'Unnamed Trib To Slow Cr, Spring Cr Trib', 'Dry Lake',
#        'Unnamed Trib To Cedar Creek', 'Unnamed Trib Of Spring Creek Trib',
#        'Unnamed Trib To Indian Creek',
#        'Unnamed Stream, Trib To Buffalo Creek',
#        'Unnamed Trib To Hans Crspring Cr Trib',
#        'Lagoons For Residual Ground Water',
#        'Unnamed Trib Of Spring Creek', 'Unnamed Trib Of Edmore Coulee',
#        'Unnamed Trib To Edmore Coulee',
#        'Unnamed Stream Trib To Little Knife R', 'Lake Irvine',
#        'Renwick Dam', 'Ranch Lake', 'Unnamed Tributary To Lake George',
#        'Grand Harbor Drainage Trib Six Mile Bay',
#        'Unnamed Tribhaymarsh Cr Trib Big Muddy',
#        'Unnamed Trib Of White Earth River', 'Valley City Sewage Lagoons',
#        'Valley City Municipal Lagoons',
#        'Dickinson City Sewage Lagoon Cells 3 4',
#        'Dickinson City Sewage Lagoon Cell #2',
#        'Dickinson Sewage Lagoons #2, 3, 4',
#        'Big Coulee Waterway Trib Mauvais Coulee',
#        'Big Coulee Waterwau Trib Mauvais Coulee',
#        'Unnamed Trib Of South Branch Park River',
#        'Unnamed Trib Of Beaver Holes Creek',
#        'Muskrat Cr Trib Sims Cr Trib Hailstone C',
#        'Unnamed Trib To Battle Creek', 'Unnamed Trib To Coyote Creek',
#        'Little South Pembina River',
#        'Unnamed Waterway Trib To Roger Creek',
#        'Unnamed Waterway Trib To Deep Creek',
#        'Unnamed Waterway Trib To Heart Butte Ck', 'Goose Creek',
#        'Unnamed Stream Trib To Goose Creek',
#        'Unnamed Trib To Little Heart River', 'Pembina County Drain #20',
#        'Murphy Creek Trib To Spring Creek', 'Groundwater',
#        'Unnamed Tributary To Starkweather Coulee',
#        'Unnamed Drain Trib Starkweather Coulee', 'Unnamed',
#        'Unnamed, Crooked Creek', 'Branch Knife River',
#        'Unnamed Trib To Heart River',
#        'Unnamed Trib To Square Butte Creek', 'Mount Carmel Dam',
#        'Ground Water', 'Unnamed Trib To Maple River',
#        'Middle Branch Park River', 'Unnamed Trib To Dead Buffalo Lake',
#        'West Cut Bank Creek', 'Unnamed Creek Trib To Porcupine Creek',
#        'Unnamed Tributary To Porcupine Creek', 'Indian Creek',
#        'Spring Creek Trib To Lower Coyote Creek',
#        'Unnamed Trib To East Antelope Creek', 'Scab Creek', 'Twin Lake',
#        'Stack Slough', 'Chain Lake', 'Unnamed Tributary Of Beaver Creek',
#        'Central Dakota', 'Oak Creek', 'Random Creek', 'Stoney Creek',
#        'Morrison Lake', 'Long Creek', 'Kenner Marsh', 'Shell Creek',
#        'Island Lake', 'Unnamed Trib Of Coyote Creek',
#        'Drake Sewage Lagoon', 'Dayton Creek', 'Unknown Tributary',
#        'Esmond Aquifer', 'Trappers Coulee Aquifer',
#        'Middle Branch Of Park River', 'Middle Brannch Park',
#        'East Antelope Creek', 'Edmore Coulee',
#        'Unnamed Tributary Of Cedar Creek', 'Skunk Coulee',
#        'Unnamed Tributary Of Wannagan Creek',
#        'Unnamed Creektrib Of Cedar Creek',
#        'Unnamed Stream, Tributary Of Ash Creek',
#        'Unnamed Creek, Trib Of Antelope Creek', 'Wolf Lake',
#        'Coal Bank Creektrib Of Cannonball River',
#        'Unnamed Tributary To Little Knife River',
#        'Unnamed Creek Trib Of Morris Creek',
#        'Unnamed Creek, Trib Of Cold Turkey Creek',
#        'Unnamed Creek Tribe Of Turkey Creek',
#        'Skunk Coulee, Tributary To Turtle River', 'Horne Pond',
#        'Unnamed, Tributary Of Squaw Creek', 'Hiddenwood Lake',
#        'Unnamed Creek A Trib Of Whitmore Creek',
#        'Unnamed Creek Trib Of Whitmore Creek',
#        'Unnamed Creek A Trib Of Crooked Creek',
#        'Sweet Briar Creek A Trib Of The Heart',
#        'Natural Runoff, Trib Of Mclaughlin Lake', 'Drain No 29',
#        'Mclaughlin Lake A Trib Of Pembina River',
#        'Unnamed Source A Trib Of James River',
#        'Unnamed Tributary Of Antelope Creek',
#        'Unnamed Tributary Of The Cannonbal River',
#        'Unnamed Creek Trib Of Lightning Creek', 'Little Muddy Creek',
#        'Unnamed Source Trib Of Pipestem River',
#        'Unnamed Tributary Of Rock Lake', 'Unnamed Tributary To Rock Lake',
#        'Unnamed Trib Of Burnt Creek', 'Knife River Elm Creek',
#        'Calio Coulee', 'Antelpoe Creek',
#        'Unnamed Creek, Tribto Cannonball River', 'Drainage Ditch',
#        'Unnamed Creek A Tributary Of Cedar Creek',
#        'Des Lacs River A Trib Of Souris River',
#        'Unnamed Stream A Trib Of Cedar Creek',
#        'Unnamed Creek Trib Of Timber Creek',
#        'Unnamed Creek, Trib To Leaf On The Hill', 'Souris River Dam 83',
#        'Souris River Pond C', 'Souris River Dam 87', 'Souris Riverdam 41',
#        'Souris Riverdam 96', 'Souris Riverdam 320', 'Souris Riverdam 326',
#        'Souris River Dam 320', 'Souris Riverdam 332',
#        'Souris River Dam 326', 'Souris Riverdam 341',
#        'Souris Riverdam 357', 'Lake Ordway',
#        'Tongue River A Trib Of The Red River', 'Wieler Dam',
#        'Oak Creek A Trib Of Willow Creek',
#        'Unnamed Stream On The Forest River',
#        'Goschke Dam On Tongue River', 'Weiler Dam A Trib Of Tongue River',
#        'Valley City Lagoon', 'Unnamed Creek Trib Of Painted Woods Crk',
#        'North Branch Of The Goose River',
#        'Unnamed Stream Trib Of Forest River',
#        'Unnamed Creek Trib Of The Green River', 'Lake Hoskins',
#        'Jensen Dam', 'Unnamed Creek Trib Of Frank Creek',
#        'Starkwater Coulee Trib Of Devils Lake',
#        'Unnamed Creek, Trib Of Dutton Slough',
#        'Unnamed Creek Trib Of Turtle Creek', 'Morris Creek',
#        'Unnamed Creek Trib Of Knife River',
#        'Unnamed Creek Trib Of Porcupine Creek',
#        'Unnamed Creek, Trib To Heart River',
#        'Unnamed Creek Trib Of Baher Creek',
#        'Unnamed Creek Trib Of Bahr Creek',
#        'Unnamed Creek, Trib Of Painted Woods Cr',
#        'Unnamed Creek Trib Of S Fork Green Riv',
#        'Unnamed Creek Trib Of Big Meadow Marsh',
#        'Russian Slough Creek Trib Of Cedar Creek',
#        'Unnamed Creek Trib Of Leaf On The Hill',
#        'Unnamed Creek Trib Of Missouri River',
#        'Lake Ashtabula Trib Of The Red River',
#        'Cherry Creek Trib Of Little Misouri',
#        'Square Butte Creek Trib Of The Missouri',
#        'Skunk Coulee Flood Detention #1',
#        'Unnamed Creek A Trib Of Sheyenne River',
#        'Jim Creek, Trib Of Little Missouri',
#        'Unnamed Tributary To Kinneman Creek',
#        'Unnamed Creek Trib Of Beaver Creek',
#        'Unnamed Creek Trib Of Lone Tree Creek', 'Five Mile Creek',
#        'Unnamed Trib Of The Missouri River',
#        'Apple Creek East Trib Of Missouri River',
#        'Cow Creek A Trib Of The Heart River',
#        'Unnamed Creek Trib Of Thirty Mile Creek', 'Lake Ibsen',
#        'Unnamed Creek Trib Of Spring Creek',
#        'Unnamed Creek Trib Of Whitetail Creek', 'Adm Ethanol Plant Ponds',
#        'Horse Tied Creek Trib Of Missouri River',
#        'Unnamed Creek Trib Of Sfork Smith Crk',
#        'Unnamed Creek, Trib Of Bahr Creek',
#        'Whitmore Creek Trib Of Cedar Creek',
#        'Unnamed Creek Trib Of East Fork Shell',
#        'Unnamed Creek Trib Of Shell Creek',
#        'Unnamed Stream Trib Of S Fork Maple R',
#        'Unnamed Creek Trib Of Nelson Creek',
#        'Unnamed Creek Trib Of Willow Coulee',
#        'Burnt Creek, Trib Of Missouri River', 'Frying Pan Lake',
#        'Willow Coulee Creek', 'Battle Creek Trib Of The Missouri River',
#        'Cannon Ball River Trib Of Missouri',
#        'Cannon Ball River Trib Of Misssouri',
#        'Unnamed Stream, Trib Of Plum Creek',
#        'Unnamed Stream Trib Of Lightning Creek',
#        'Nelson Creek,Trib Of The Missouri River',
#        'Unnamed Creek Trib Of Powers Lake',
#        'Unnamed Tributary To Ash Creek',
#        'Unnamed Creek, Trib To Branch Knife Rive',
#        'Unnamed Stream Trib Of Apple Creek',
#        'Unnamed Stream Trib Of Thirty Mile Ck', 'Unnamed Wetland',
#        'Cottonwood Creek, Trib Of James River',
#        'Unnamed Streamtrib Of The James River',
#        'Unnamed Stream Trib Of Little Muddy Riv', 'Spiritwood Aquifer',
#        'Unnamed Stream Trib Of Little Muddy',
#        'Goshke Dam On Busse Coulee', 'Goschke Dam On Busse Coulee',
#        'Unamed Coulee Trib Of Lower Des Lacs',
#        'Flat Creek Trib Of N Fork Grand River', 'Chimney Butte Creek',
#        'Unnamed Coulee A Trib Of T Heart River',
#        'Unnamed Coulee Trib Of The Heart River',
#        'Unnamed Creek, Trib Of Wolf Creek',
#        "Gibb'S Spring, Trib Of Little Knife", 'Little Bull Creek',
#        'Unnamed Tributary Of North Branch Park',
#        'Unnamed Creek, Tribof Stony Slough',
#        'Unnamed Waterway, Trib Of Des Lacs River', 'Goschke Dam',
#        'Unnamed Creek, Trib Of The Tongue River',
#        'Bussee Coulee, Trib Of The Tongue River',
#        'Unnamed Stream Trib Of Heart River',
#        'Tongue River Renwick Dam M4', 'Treated City Wastewater',
#        'James River, Fesenden Dam', 'Sheyenne River At Harvey Dam',
#        'Coal Mine Creek', 'Unnamed Creek, A Trib To Knife River',
#        'Scab Creek, Trib To Big Muddy Creek',
#        'Unnamed Creek Trib Of The Heart River',
#        'Unnamed Creek, Trib To Dogtooth Creek',
#        'Unnamed Creek, Trib Of The Heart River',
#        'Tributary To Crooked Creek', 'Trenton Lake',
#        'Cedar Creek Tributary', 'Trib Of Painted Woods Creek',
#        'Muddy Creek Tributary To Heart River', 'Lake Margaret',
#        'Rats Coulee', 'Unnamed Creek, Trib Of Edmore Coulee',
#        'Desmoines Lake', 'Unnamed Creek, Trib Of Square Butte Ck',
#        'Unnamed Tributary To Scab Creek', 'Eightmile Creek',
#        'Unnamed Slough', 'Pitt Creek Tributary',
#        'Alkaline Lake, Aka Northwest Slough', 'Burnt Creek Diversion',
#        'Trib Of Crosby Creek', 'Hazen Brook',
#        'Southwest Pipeline Project', 'Spring Trib Of White Earth River',
#        'Unnamed Tributary To Coal Creek',
#        'Tributary To Painted Woods Creek', 'The Pembina River',
#        'First Larson Coulee', 'Waste Water Logoons',
#        'Waste Water Lagoons', '4 Cell Lagoon System',
#        'Shallow Saturated Alluvium', 'Des Lac Lake',
#        'Tributary To The Wild Rice River', 'Hartel Dam',
#        'Puppy Dog Coulee', 'Oakes Pilot Drain', 'Fort Union',
#        'Sletten Lake', 'Jackson Township Improvement Project',
#        'Dakota Group', 'Tongue River At Goschke Dam',
#        'Schmidt North Pond', 'Schmidt West Pond', 'Schmidt East Pond',
#        'North Branch Turtle River', 'Strommen Stock Pond', 'Popple Lake',
#        'Antelope Crreek', 'Stone Creek',
#        'Unnamed Trib Of East Fork Shell Creek',
#        'Sentinel Buttetongue River', 'Canonball River', 'Demicks Lake',
#        'Ephemeral Drainages', 'South Egg Creek', 'Camp Creek',
#        'Spring Creek Tributary', 'Bennett Creek', 'Unnamed Stock Pond',
#        'Natural Runoff To Coal Lake', 'Unnamed Pond',
#        'Hagel Creek Tributary', 'Strommen Pond Spring Creek Trib',
#        "Pat'S Coulee, Trib To Little Muddy",
#        'Strawberry, Crooked Brekken Lakes',
#        'Strawberr, Crooked Brekken Lakes', 'Strawberry, Crooked Brekken',
#        'Cheyenne River', 'Horseshoe Lake', 'Holding Pond',
#        'Halfbreed Creek', 'Lake Upsilon', 'Lake Trenton', 'Little Stoney',
#        'Unnamed Trib To Knife River', 'Tributary Of Crooked Creek',
#        'Cedar River', 'Muskrat Lake', 'Drain 11', 'East Buehner Pond',
#        'Jim Creek', 'Derudder Reservoir', 'Abbey Lake',
#        'Oxbow Of Stoney Creek', 'Lake Sakakaweabackwater',
#        'Matejcek Reservoir', 'Lake Zahl', 'Frank Creek', 'Murphy Slough',
#        'Mcville', 'Unnamed Reservoir', 'Dry Creek', 'Truchan Pond',
#        'Unnamed Dam', 'Natural Runoff To Lake Nettie', 'Roth Lake',
#        'Unnamed Stock Dam On Bear Den Creek',
#        'Unnamed Tributary Of Norred Creek', 'Cass County Drain 27',
#        'Russian Spring Creek', 'Tributary To Forest River',
#        'Lower Sheyenne River Watershed',
#        'Unnamed Tributary To The James River', 'Dickey Sargent Drain',
#        'Unnamed Tributary To West Antelope Creek',
#        'Unnamed Tributary To Forest River', 'Sorenson Gravel Pit',
#        'Matejcek Dam', 'Unknown', 'Alkaline Lake North',
#        'Unnamed Wetlands', 'Unnamed Sloughs', 'Warneke Dam', 'West Dam',
#        'Camp Dam', 'Unnamed Creek, Tributary To Apple Creek',
#        'Gravel Pit', 'Dakota Lake James River Watershed'], dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Groundwater', 'Surface Water', 'WaDE Blank'], dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_SiteName'] = outdf.apply(lambda row: ensureEmptyString(row['in_SiteName']), axis=1)
outdf['in_SiteName'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: ensureEmptyString(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array([''], dtype=object)

# %%
outdf['in_AllocationOwner'] = outdf.apply(lambda row: ensureEmptyString(row['in_AllocationOwner']), axis=1)
outdf['in_AllocationOwner'].unique()
# Out:
# array(['Ketterling Roland Lorraine', 'Hyde George H', 'Slater A L', ...,
#        'Sneva Craig Mary And Smith', 'Schmit Layne', 'Treeby Hollis'],
#       dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: ensureEmptyString(row['in_BeneficialUseCategory']), axis=1)
uniqueList = list(set([i.strip() for i in ','.join(outdf['in_BeneficialUseCategory'].astype(str)).split(',')]))
uniqueList.sort()
uniqueList
# Out:
# ['Domestic',
#  'Fish and Wildlife',
#  'Flood Control',
#  'Industrial',
#  'Irrigation',
#  'Multiple Use',
#  'Municipal',
#  'Power Generation',
#  'Recreation',
#  'Rural Water',
#  'Stock',
#  'Undefined']

# %%
# Ensure Latitude entry is numireic, replace '0' values for removal
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Latitude'].unique()
# Out:
# array([46.11129501, 48.02621568, 48.03706116, ..., 48.62286839,
#        46.062472  , 46.05526451])

# %%
# Ensure Longitude entry is numireic, replace '0' values for removal
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').replace(0,"").fillna("")
outdf['in_Longitude'].unique()
# Out:
# array([ -99.78987083, -103.75215903, -103.74690401, ..., -103.99897674,
#         -97.97146753,  -97.97149018])

# %%
# Fixing in_AllocationFlow_CFS datatype
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array(['', 1615.6, 1350.0, 1840.0, 600.0, 530.0, 2000.0, 864.0, 1650.0,
#        500.0, 924.0, 450.0, 366.7, 366.6, 448.0, 1062.5, 1450.0, 827.0,
#        448.8, 900.0, 675.0, 134.6, 4488.0, 4398.2, 435.7, 46.0, 46.1,
#        2692.8, 709.104, 519.4, 785.4, 171.0, 314.0, 225.0, 977.7, 977.8,
#        337.5, 897.6, 269.2, 3666.7, 3666.6, 175.0, 949.5, 673.2, 108000.0,
#        198.0, 99.0, 45.0, 700.0, 350.0, 140.0, 2244.0, 99999.9, 3455.7,
#        13.9, 347.2, 10.4, 52.1, 224.4, 300.0, 710.0, 150.0, 1900.0,
#        4151.4, 2500.0, 330.0, 200.0, 550.0, 280.5, 28.0, 240.1, 86.3,
#        86.2, 105.0, 254.0, 718.0, 807.8, 10417.0, 223.3, 223.4, 60.0,
#        1750.0, 410.0, 1122.0, 284.0, 17952.0, 506.3, 1346.4, 55000.0,
#        403.9, 990.0, 2108.0, 10416.0, 1709.1, 7.3, 10.0, 538.5, 3013.0,
#        3012.0, 1305.0, 435.0, 267.0, 267.1, 46.8, 46.9, 602.0, 738.0,
#        187.5, 948.0, 800.0, 517.5, 270.0, 149.6, 299.2, 34692.2, 33600.0,
#        4128.9, 72.0, 987.3, 250.0, 3000.0, 1000.0, 11.3, 56.1, 2100.0,
#        462.2, 1054.1, 1054.2, 16667.0, 78.4, 44.5, 25132.8, 141.7, 141.6,
#        1485.0, 1003.5, 75.0, 320.0, 67320.0, 5385.6, 1200.0, 583.4,
#        3590.4, 845.0, 4039.2, 1041.5, 893.8, 1468.7, 1817.6, 13464.0,
#        89.7, 815.0, 945.1, 107.1, 107.2, 106.2, 5000.0, 8976.0, 6000.0,
#        1575.0, 9000.0, 33660.0, 100.0, 6283.2, 340.0, 22440.0, 35.0,
#        1211.8, 2019.6, 400.0, 2250.0, 447.5, 3155.0, 4000.0, 2513.2,
#        1165.85, 1243.8, 3700.0, 20.0, 463.0, 8010.0, 1500.0, 1211.7,
#        10501.9, 4937.13, 6732.0, 11220.0, 4500.0, 2700.0, 14362.0, 1100.0,
#        5834.4, 2200.0, 134.0, 180.0, 208.0, 49816.8, 5400.0, 1551.0,
#        104.7, 3006.9, 1502.0, 12117.6, 13500.0, 112.0, 3864.7, 3141.6,
#        625000.0, 1150.0, 3591.0, 0.9, 1.0, 3600.0, 1600.0, 112.5, 11.0,
#        6600.0, 18000.0, 1125.0, 6866.6, 484.7, 1391.2, 9873.6, 493.6,
#        2400.0, 2800.0, 50.0, 750.0, 1188.2, 1800.0, 36.0, 17.0, 22.0,
#        29.0, 31.0, 146.4, 360.0, 70.0, 385.0, 499918.0, 36.6, 2.5, 0.5,
#        13.0, 4.0, 33.0, 65.0, 125.0, 162.5, 4488.3, 170.0, 80.0, 155.0,
#        233.4, 233.3, 110.0, 15.0, 30.0, 120.0, 235.0, 7200.0, 130.0, 83.3,
#        90.0, 930.0, 506.0, 500000.0, 524.0, 524.5, 45000.0, 3150.0,
#        1400.0, 59040.0, 224400.0, 348.3, 850.0, 30745.0, 3972156.0,
#        8645.0, 280.0, 760.0, 2962.0, 34640.0, 12.5, 12730.0, 880.0,
#        1120.0, 215.0, 192.34, 40.0, 920.0, 5850.0, 580.0, 625.0, 762.0,
#        411.0, 382.5, 2240.0, 950.0, 485.0, 590.3, 3500.0, 5175.0, 695.2,
#        854.8, 266.0, 1975.0, 694.5, 438.0, 666.7, 666.6, 3121.0, 370.0,
#        160.0, 146.0, 820.0, 720.0, 55.0, 547.2, 25.0, 480.0, 2450.0,
#        3240.4, 603.0, 910.0, 1530.0, 95.0, 1629.7, 1629.6, 347.0, 22.2,
#        22.3, 6750.0, 1160.0, 1462.5, 24750.0, 33.4, 33.3, 375.0, 296.7,
#        296.6, 610.0, 15500.0, 805.0, 812.5, 1560.0, 6300.0, 1524.0,
#        1700.0, 192.5, 2300.0, 780.0, 3200.0, 440.0, 475.0, 1360.0, 111.0,
#        342.0, 447.0, 3.0, 1300.0, 311.5, 449.2, 449.0, 633.3, 775.0,
#        5834.0, 650.0, 860.0, 14800.0, 3300.0, 338.0, 1050.0, 642.8, 810.0,
#        300.4, 504.3, 504.4, 833.0, 834.0, 405.0, 380.0, 1620.0, 223.5,
#        888.9, 222.2, 444.0, 444.4, 888.5, 1795.2, 690.0, 870.0, 166.0,
#        1153.8, 20197.4, 1250.0, 832.0, 540.0, 770.0, 925.0, 857.5, 875.5,
#        494.4, 224.0, 660.0, 840.0, 575.0, 1850.0, 2600.0, 792.0, 490.0,
#        936.0, 222.0, 56.0, 2510.0, 960.0, 566.0, 568.0, 12.0, 305.0,
#        520.0, 874.0, 876.0, 1178.0, 466.7, 466.6, 872.4, 642.5, 921.0,
#        1639.2, 1639.1, 560.0, 1280.0, 266.7, 266.6, 655.0, 630.0, 346.2,
#        346.1, 825.0, 1820.0, 455.0, 590.0, 3078.0, 991.0, 443.8, 443.7,
#        1385.0, 556.0, 220.0, 166.7, 166.6, 289.0, 272.0, 831.0, 425.0,
#        620.0, 790.0, 835.0, 41.6, 145.0, 133.3, 725.0, 283.0, 31.3, 31.2,
#        52.5, 285.2, 954.8, 275.0, 74.1, 74.2, 74.5, 1080.0, 8000.0,
#        2750.0, 382.0, 735.0, 1730.0, 42.0, 940.0, 882.0, 2410.0, 685.0,
#        1047.0, 264.0, 265.0, 4635.0, 172.0, 320.8, 16.0, 523.0, 10000.0,
#        7100.0, 5.0, 1.5, 2.2, 2.9, 621.0, 7.0, 117.0, 4.5, 753.0, 635.0,
#        2.0, 37.5, 1.8, 6.0, 3750.0, 17300.0, 670.0, 1240.0, 0.4, 6283.0,
#        4.1, 5625.0, 812.0, 7.1, 2.3, 46.7, 46.6, 4040.0, 5.9, 393.8, 12.6,
#        3800.0, 135.0, 3141.8, 740.0, 51.6, 103.4, 258.0, 1028.0, 985.0,
#        205.0, 2323.0, 888.0, 1032.0, 1920.0, 325.0, 7000.0, 1110.0, 119.0,
#        132.0, 975.0, 248.0, 62.0, 928.0, 2900.0, 1092.0, 2915.0, 333.3,
#        333.4, 1021.0, 14.0, 420.0, 59.0, 335.0, 390.0, 126.0, 415.0, 87.5,
#        226.0, 683.2, 12000.0, 758.0, 17.5, 315.0, 4400.0, 349.0, 174.0,
#        1.3, 4640.0, 533.4, 533.3, 18.5, 680.0, 2679.6, 1774.1, 905.5,
#        2394.0, 10771.2, 1138.0, 1249.0, 219.0, 6400.0, 2503.0, 4290.0,
#        1389.0, 470.0, 730.0, 11250.0, 24.0, 952.0, 1019.0, 185.0, 1077.0,
#        1630.0, 3.1, 15000.0, 16000.0, 193.3, 193.4, 1680.0, 816.0, 570.0,
#        2836.0, 1880.0, 43.8, 539.0, 565.0, 240.0, 29.2, 757.0, 36.5,
#        634.0, 633.0, 695.0, 68.0, 85.0, 755.0, 830.0, 292.0, 40000.0,
#        3631.3, 1120.7, 592.0, 973.0, 3400.0, 667.0, 2520.0, 478.0, 909.6,
#        1365.0, 2690.0, 53.9, 1377.0, 795.0, 457.5, 915.0, 428.6, 865.0,
#        785.0, 4235.3, 1569.0, 253.6, 945.0, 3425.0, 1890.0, 2625.0, 823.0,
#        467.0, 855.0, 4200.0, 175.4, 185.2, 719.7, 291.0, 1230.0, 216.0,
#        2550.0, 885.0, 87.0, 935.0, 115.0, 1760.0, 1275.0, 886.0, 33000.0,
#        2150.0, 19.6, 223.0, 11.25, 211.0, 2875.0, 32000.0, 326.0, 5.8,
#        78.0, 18.0, 866.0, 2566.0, 431.0, 1032.6, 212.0, 2650.0, 14.5,
#        733.0, 244.0, 51.0, 583.0, 1267.0, 2125.0, 2175.0, 1458.0, 15.5,
#        1.86, 1234.0, 47.0, 912.5, 1380.0, 18056.0, 116.0, 239.2, 266.8,
#        2435.0, 528.0, 1879.0, 177.0, 53.0, 460.0, 1167.0, 722.0, 1134.0,
#        32.0, 1105.0, 124.0, 905.0, 4650.0, 2782.6, 6500.0, 1174.0, 2445.0,
#        476.0, 189.0, 519.0, 875.0, 73.0, 58.3, 4450.0, 3100.0, 1347.0,
#        1346.0, 1962.0, 285.0, 12600.0, 831.7, 772.9, 4970.0, 595.0, 491.0,
#        3050.0, 4306.0, 803.0, 2815.0, 3062.0, 12399.0, 230.0, 6250.0,
#        4.34, 44.0, 27.0, 1865.0, 2245.0, 1375.0, 496.0, 4165.0, 7287.0,
#        744.0, 4075.0, 19.0, 2470.0, 576.0, 1260.0, 3688.0, 826.0, 2322.0,
#        1982.0, 430.0, 912.0, 968.0, 1580.0, 107.0, 153.0, 1943.0, 1950.0,
#        1539.0, 983.0, 6200.0, 295.0, 74057.0, 640.0, 956.0, 13480.0,
#        487.0, 276.0, 1274.0, 6.2, 252.0, 980.0, 1867.0, 794.0, 1645.0,
#        618.0], dtype=object)

# %%
# Fixing in_AllocationVolume_AF datatype
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').replace(0,"").fillna("")
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array(['', 291.0, 132.0, ..., 352.5, 162.4, 1692.0], dtype=object)

# %%
# Ensure Amount entry is either numireic or blank, no 0 entries
outdf['in_Amount'] = pd.to_numeric(outdf['in_Amount'], errors='coerce').round(2).replace(0,"").fillna("")
outdf['in_Amount'].unique()
# Out:
# array(['', 291.0, 145.5, ..., 77.92, 124.19, 145.92], dtype=object)

# %%
# Ensure PopulationServed entry is numireic WITH 0 entries (no blank strings)
outdf['in_PopulationServed'] = pd.to_numeric(outdf['in_PopulationServed'], errors='coerce').round().replace("",0).fillna(0).astype(int).replace(0,"").fillna("")
outdf['in_PopulationServed'].unique()
# Out:
# array([''], dtype=object)

# %%
#Update datatype of Priority Date to fit WaDE 2.0 structure
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'])
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'].dt.strftime('%m/%d/%Y'))
outdf['in_AllocationPriorityDate'].unique()
# Out:
# <DatetimeArray>
# ['1991-03-04 00:00:00', '1901-08-15 00:00:00', '1901-09-02 00:00:00',
#  '1906-01-26 00:00:00', '1906-02-03 00:00:00', '1902-04-18 00:00:00',
#  '1932-03-16 00:00:00', '1937-09-21 00:00:00', '1901-06-18 00:00:00',
#  '1932-04-16 00:00:00',
#  ...
#  '2023-10-23 00:00:00', '2023-11-02 00:00:00', '2023-10-30 00:00:00',
#  '2023-11-03 00:00:00', '2023-11-09 00:00:00', '2023-11-21 00:00:00',
#  '2023-12-01 00:00:00', '2024-01-04 00:00:00', '2024-01-11 00:00:00',
#  '2024-01-16 00:00:00']
# Length: 5021, dtype: datetime64[ns]

# %%
# Convert TimeframeEnd to YYYY-MM-DD format.
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf['in_TimeframeEnd'], utc=True, errors = 'coerce').fillna("").replace('NaT', "")
outdf['in_TimeframeEnd'] = pd.to_datetime(outdf["in_TimeframeEnd"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeEnd'].unique()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_7580\519214423.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   outdf['in_TimeframeEnd'] = pd.to_datetime(outdf['in_TimeframeEnd'], utc=True, errors = 'coerce').fillna("").replace('NaT', "")
# <DatetimeArray>
# [                'NaT', '1976-12-31 00:00:00', '1977-12-31 00:00:00',
#  '1978-12-31 00:00:00', '1979-12-31 00:00:00', '1980-12-31 00:00:00',
#  '1981-12-31 00:00:00', '1982-12-31 00:00:00', '1983-12-31 00:00:00',
#  '1984-12-31 00:00:00', '1985-12-31 00:00:00', '1986-12-31 00:00:00',
#  '1987-12-31 00:00:00', '1988-12-31 00:00:00', '1989-12-31 00:00:00',
#  '1990-12-31 00:00:00', '1991-12-31 00:00:00', '1992-12-31 00:00:00',
#  '1993-12-31 00:00:00', '1994-12-31 00:00:00', '1995-12-31 00:00:00',
#  '1996-12-31 00:00:00', '1997-12-31 00:00:00', '1999-12-31 00:00:00',
#  '1998-12-31 00:00:00', '2000-12-31 00:00:00', '2001-12-31 00:00:00',
#  '2002-12-31 00:00:00', '2003-12-31 00:00:00', '2004-12-31 00:00:00',
#  '2005-12-31 00:00:00', '2006-12-31 00:00:00', '2007-12-31 00:00:00',
#  '2008-12-31 00:00:00', '2009-12-31 00:00:00', '2011-12-31 00:00:00',
#  '2012-12-31 00:00:00', '2010-12-31 00:00:00', '2013-12-31 00:00:00',
#  '2014-12-31 00:00:00', '2015-12-31 00:00:00', '2016-12-31 00:00:00',
#  '2017-12-31 00:00:00', '2018-12-31 00:00:00', '2019-12-31 00:00:00',
#  '2020-12-31 00:00:00', '2021-12-31 00:00:00', '1967-12-31 00:00:00',
#  '1968-12-31 00:00:00', '1969-12-31 00:00:00', '1970-12-31 00:00:00',
#  '1971-12-31 00:00:00', '1974-12-31 00:00:00', '1975-12-31 00:00:00',
#  '1966-12-31 00:00:00', '1972-12-31 00:00:00', '1973-12-31 00:00:00',
#  '1965-12-31 00:00:00']
# Length: 58, dtype: datetime64[ns]

# %%
# Convert TimeframeStart to YYYY-MM-DD format.
outdf['in_TimeframeStart'] = pd.to_datetime(outdf['in_TimeframeStart'], utc=True, errors = 'coerce').fillna("").replace('NaT', "")
outdf['in_TimeframeStart'] = pd.to_datetime(outdf["in_TimeframeStart"].dt.strftime('%m/%d/%Y'))
outdf['in_TimeframeStart'].unique()
# Out:
# C:\Users\rjame\AppData\Local\Temp\ipykernel_7580\1989387064.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   outdf['in_TimeframeStart'] = pd.to_datetime(outdf['in_TimeframeStart'], utc=True, errors = 'coerce').fillna("").replace('NaT', "")
# <DatetimeArray>
# [                'NaT', '1976-01-01 00:00:00', '1977-01-01 00:00:00',
#  '1978-01-01 00:00:00', '1979-01-01 00:00:00', '1980-01-01 00:00:00',
#  '1981-01-01 00:00:00', '1982-01-01 00:00:00', '1983-01-01 00:00:00',
#  '1984-01-01 00:00:00', '1985-01-01 00:00:00', '1986-01-01 00:00:00',
#  '1987-01-01 00:00:00', '1988-01-01 00:00:00', '1989-01-01 00:00:00',
#  '1990-01-01 00:00:00', '1991-01-01 00:00:00', '1992-01-01 00:00:00',
#  '1993-01-01 00:00:00', '1994-01-01 00:00:00', '1995-01-01 00:00:00',
#  '1996-01-01 00:00:00', '1997-01-01 00:00:00', '1999-01-01 00:00:00',
#  '1998-01-01 00:00:00', '2000-01-01 00:00:00', '2001-01-01 00:00:00',
#  '2002-01-01 00:00:00', '2003-01-01 00:00:00', '2004-01-01 00:00:00',
#  '2005-01-01 00:00:00', '2006-01-01 00:00:00', '2007-01-01 00:00:00',
#  '2008-01-01 00:00:00', '2009-01-01 00:00:00', '2011-01-01 00:00:00',
#  '2012-01-01 00:00:00', '2010-01-01 00:00:00', '2013-01-01 00:00:00',
#  '2014-01-01 00:00:00', '2015-01-01 00:00:00', '2016-01-01 00:00:00',
#  '2017-01-01 00:00:00', '2018-01-01 00:00:00', '2019-01-01 00:00:00',
#  '2020-01-01 00:00:00', '2021-01-01 00:00:00', '1967-01-01 00:00:00',
#  '1968-01-01 00:00:00', '1969-01-01 00:00:00', '1970-01-01 00:00:00',
#  '1971-01-01 00:00:00', '1974-01-01 00:00:00', '1975-01-01 00:00:00',
#  '1966-01-01 00:00:00', '1972-01-01 00:00:00', '1973-01-01 00:00:00',
#  '1965-01-01 00:00:00']
# Length: 58, dtype: datetime64[ns]

# %%
# extract year out
outdf['in_ReportYearCV'] = outdf['in_ReportYearCV'].replace("", 0).fillna(0).astype(int).astype(str)
outdf['in_ReportYearCV'].unique()
# Out:
# array(['0', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1999',
#        '1998', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2011', '2012', '2010', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021', '1967',
#        '1968', '1969', '1970', '1971', '1974', '1975', '1966', '1972',
#        '1973', '1965'], dtype=object)

# %%
# Assign Primary Use Category

import sys
sys.path.append("C:/Users/rjame/Documents/WSWC Documents/MappingStatesDataToWaDE2.0/5_CustomFunctions/AssignPrimaryUseCategory")
import AssignPrimaryUseCategoryFile # Use Custom import file

outdf['in_PrimaryUseCategory'] = outdf.apply(lambda row: AssignPrimaryUseCategoryFile.retrievePrimaryUseCategory(row['in_BeneficialUseCategory']), axis=1)
outdf['in_PrimaryUseCategory'].unique()
# Out:
# array(['Agriculture Irrigation', 'Commercial/Industrial', 'Hydroelectric',
#        'In-stream Flow', 'Livestock', 'Public Supply', 'Recreation',
#        'Domestic', 'Other', 'Unspecified'], dtype=object)

# %%
# Creating WaDE Custom VariableSpecificCV
# ----------------------------------------------------------------------------------------------------
def createVariableSpecificCV(inV, inAIU, inPU, inWST):
    inV = str(inV).strip()
    inAIU = str(inAIU).strip()
    inPU = str(inPU).strip().title()
    inWST = str(inWST).strip()
    outString = inV + "_" + inAIU + "_" + inPU + "_" + inWST
    return outString

outdf['in_VariableSpecificCV'] = outdf.apply(lambda row: createVariableSpecificCV(row['in_VariableCV'], 
                                                                                  row['in_AggregationIntervalUnitCV'],
                                                                                  row['in_PrimaryUseCategory'],
                                                                                  row['in_WaterSourceTypeCV']), axis=1)
outdf['in_VariableSpecificCV'].unique()
# Out:
# array(['Water Right_Annual_Agriculture Irrigation_Groundwater',
#        'Water Right_Annual_Agriculture Irrigation_Surface Water',
#        'Water Right_Annual_Commercial/Industrial_Surface Water',
#        'Water Right_Annual_Hydroelectric_Surface Water',
#        'Water Right_Annual_In-Stream Flow_Surface Water',
#        'Water Right_Annual_Livestock_Surface Water',
#        'Water Right_Annual_Public Supply_Surface Water',
#        'Water Right_Annual_Recreation_Surface Water',
#        'Water Right_Annual_Domestic_Surface Water',
#        'Water Right_Annual_Hydroelectric_Groundwater',
#        'Water Right_Annual_Commercial/Industrial_Groundwater',
#        'Water Right_Annual_Public Supply_Groundwater',
#        'Water Right_Annual_Other_Surface Water',
#        'Water Right_Annual_In-Stream Flow_Groundwater',
#        'Water Right_Annual_Domestic_Groundwater',
#        'Water Right_Annual_Recreation_Groundwater',
#        'Water Right_Annual_Agriculture Irrigation_WaDE Blank',
#        'Water Right_Annual_Unspecified_Groundwater',
#        'Water Right_Annual_Livestock_Groundwater',
#        'Water Right_Annual_Other_WaDE Blank',
#        'Water Right_Annual_Recreation_WaDE Blank',
#        'Water Right_Annual_Unspecified_Surface Water',
#        'Water Right_Annual_In-Stream Flow_WaDE Blank'], dtype=object)

# %%
# Creating WaDE Custom water source native ID for easy water source identification
# use unique WaterSourceName and WaterSourceType values
# ----------------------------------------------------------------------------------------------------

# Create temp in_WaterSourceNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_WaterSourceName'] = outdf['in_WaterSourceName'].astype(str).str.strip()
dfTempID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_WaterSourceNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_WaterSourceName'].astype(str) + dfTempID['in_WaterSourceTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_WaterSourceNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_WaterSourceNativeID'], 
                                                                              row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# array(['wadeId1', 'wadeId2', 'wadeId3', 'wadeId4', 'wadeId5', 'wadeId6',
#        'wadeId7', 'wadeId8', 'wadeId9', 'wadeId10', 'wadeId11',
#        'wadeId12', 'wadeId13', 'wadeId14', 'wadeId15', 'wadeId16',
#        'wadeId17', 'wadeId18', 'wadeId19', 'wadeId20', 'wadeId21',
#        'wadeId22', 'wadeId23', 'wadeId24', 'wadeId25', 'wadeId26',
#        'wadeId27', 'wadeId28', 'wadeId29', 'wadeId30', 'wadeId31',
#        'wadeId32', 'wadeId33', 'wadeId34', 'wadeId35', 'wadeId36',
#        'wadeId37', 'wadeId38', 'wadeId39', 'wadeId40', 'wadeId41',
#        'wadeId42', 'wadeId43', 'wadeId44', 'wadeId45', 'wadeId46',
#        'wadeId47', 'wadeId48', 'wadeId49', 'wadeId50', 'wadeId51',
#        'wadeId52', 'wadeId53', 'wadeId54', 'wadeId55', 'wadeId56',
#        'wadeId57', 'wadeId58', 'wadeId59', 'wadeId60', 'wadeId61',
#        'wadeId62', 'wadeId63', 'wadeId64', 'wadeId65', 'wadeId66',
#        'wadeId67', 'wadeId68', 'wadeId69', 'wadeId70', 'wadeId71',
#        'wadeId72', 'wadeId73', 'wadeId74', 'wadeId75', 'wadeId76',
#        'wadeId77', 'wadeId78', 'wadeId79', 'wadeId80', 'wadeId81',
#        'wadeId82', 'wadeId83', 'wadeId84', 'wadeId85', 'wadeId86',
#        'wadeId87', 'wadeId88', 'wadeId89', 'wadeId90', 'wadeId91',
#        'wadeId92', 'wadeId93', 'wadeId94', 'wadeId95', 'wadeId96',
#        'wadeId97', 'wadeId98', 'wadeId99', 'wadeId100', 'wadeId101',
#        'wadeId102', 'wadeId103', 'wadeId104', 'wadeId105', 'wadeId106',
#        'wadeId107', 'wadeId108', 'wadeId109', 'wadeId110', 'wadeId111',
#        'wadeId112', 'wadeId113', 'wadeId114', 'wadeId115', 'wadeId116',
#        'wadeId117', 'wadeId118', 'wadeId119', 'wadeId120', 'wadeId121',
#        'wadeId122', 'wadeId123', 'wadeId124', 'wadeId125', 'wadeId126',
#        'wadeId127', 'wadeId128', 'wadeId129', 'wadeId130', 'wadeId131',
#        'wadeId132', 'wadeId133', 'wadeId134', 'wadeId135', 'wadeId136',
#        'wadeId137', 'wadeId138', 'wadeId139', 'wadeId140', 'wadeId141',
#        'wadeId142', 'wadeId143', 'wadeId144', 'wadeId145', 'wadeId146',
#        'wadeId147', 'wadeId148', 'wadeId149', 'wadeId150', 'wadeId151',
#        'wadeId152', 'wadeId153', 'wadeId154', 'wadeId155', 'wadeId156',
#        'wadeId157', 'wadeId158', 'wadeId159', 'wadeId160', 'wadeId161',
#        'wadeId162', 'wadeId163', 'wadeId164', 'wadeId165', 'wadeId166',
#        'wadeId167', 'wadeId168', 'wadeId169', 'wadeId170', 'wadeId171',
#        'wadeId172', 'wadeId173', 'wadeId174', 'wadeId175', 'wadeId176',
#        'wadeId177', 'wadeId178', 'wadeId179', 'wadeId180', 'wadeId181',
#        'wadeId182', 'wadeId183', 'wadeId184', 'wadeId185', 'wadeId186',
#        'wadeId187', 'wadeId188', 'wadeId189', 'wadeId190', 'wadeId191',
#        'wadeId192', 'wadeId193', 'wadeId194', 'wadeId195', 'wadeId196',
#        'wadeId197', 'wadeId198', 'wadeId199', 'wadeId200', 'wadeId201',
#        'wadeId202', 'wadeId203', 'wadeId204', 'wadeId205', 'wadeId206',
#        'wadeId207', 'wadeId208', 'wadeId209', 'wadeId210', 'wadeId211',
#        'wadeId212', 'wadeId213', 'wadeId214', 'wadeId215', 'wadeId216',
#        'wadeId217', 'wadeId218', 'wadeId219', 'wadeId220', 'wadeId221',
#        'wadeId222', 'wadeId223', 'wadeId224', 'wadeId225', 'wadeId226',
#        'wadeId227', 'wadeId228', 'wadeId229', 'wadeId230', 'wadeId231',
#        'wadeId232', 'wadeId233', 'wadeId234', 'wadeId235', 'wadeId236',
#        'wadeId237', 'wadeId238', 'wadeId239', 'wadeId240', 'wadeId241',
#        'wadeId242', 'wadeId243', 'wadeId244', 'wadeId245', 'wadeId246',
#        'wadeId247', 'wadeId248', 'wadeId249', 'wadeId250', 'wadeId251',
#        'wadeId252', 'wadeId253', 'wadeId254', 'wadeId255', 'wadeId256',
#        'wadeId257', 'wadeId258', 'wadeId259', 'wadeId260', 'wadeId261',
#        'wadeId262', 'wadeId263', 'wadeId264', 'wadeId265', 'wadeId266',
#        'wadeId267', 'wadeId268', 'wadeId269', 'wadeId270', 'wadeId271',
#        'wadeId272', 'wadeId273', 'wadeId274', 'wadeId275', 'wadeId276',
#        'wadeId277', 'wadeId278', 'wadeId279', 'wadeId280', 'wadeId281',
#        'wadeId282', 'wadeId283', 'wadeId284', 'wadeId285', 'wadeId286',
#        'wadeId287', 'wadeId288', 'wadeId289', 'wadeId290', 'wadeId291',
#        'wadeId292', 'wadeId293', 'wadeId294', 'wadeId295', 'wadeId296',
#        'wadeId297', 'wadeId298', 'wadeId299', 'wadeId300', 'wadeId301',
#        'wadeId302', 'wadeId303', 'wadeId304', 'wadeId305', 'wadeId306',
#        'wadeId307', 'wadeId308', 'wadeId309', 'wadeId310', 'wadeId311',
#        'wadeId312', 'wadeId313', 'wadeId314', 'wadeId315', 'wadeId316',
#        'wadeId317', 'wadeId318', 'wadeId319', 'wadeId320', 'wadeId321',
#        'wadeId322', 'wadeId323', 'wadeId324', 'wadeId325', 'wadeId326',
#        'wadeId327', 'wadeId328', 'wadeId329', 'wadeId330', 'wadeId331',
#        'wadeId332', 'wadeId333', 'wadeId334', 'wadeId335', 'wadeId336',
#        'wadeId337', 'wadeId338', 'wadeId339', 'wadeId340', 'wadeId341',
#        'wadeId342', 'wadeId343', 'wadeId344', 'wadeId345', 'wadeId346',
#        'wadeId347', 'wadeId348', 'wadeId349', 'wadeId350', 'wadeId351',
#        'wadeId352', 'wadeId353', 'wadeId354', 'wadeId355', 'wadeId356',
#        'wadeId357', 'wadeId358', 'wadeId359', 'wadeId360', 'wadeId361',
#        'wadeId362', 'wadeId363', 'wadeId364', 'wadeId365', 'wadeId366',
#        'wadeId367', 'wadeId368', 'wadeId369', 'wadeId370', 'wadeId371',
#        'wadeId372', 'wadeId373', 'wadeId374', 'wadeId375', 'wadeId376',
#        'wadeId377', 'wadeId378', 'wadeId379', 'wadeId380', 'wadeId381',
#        'wadeId382', 'wadeId383', 'wadeId384', 'wadeId385', 'wadeId386',
#        'wadeId387', 'wadeId388', 'wadeId389', 'wadeId390', 'wadeId391',
#        'wadeId392', 'wadeId393', 'wadeId394', 'wadeId395', 'wadeId396',
#        'wadeId397', 'wadeId398', 'wadeId399', 'wadeId400', 'wadeId401',
#        'wadeId402', 'wadeId403', 'wadeId404', 'wadeId405', 'wadeId406',
#        'wadeId407', 'wadeId408', 'wadeId409', 'wadeId410', 'wadeId411',
#        'wadeId412', 'wadeId413', 'wadeId414', 'wadeId415', 'wadeId416',
#        'wadeId417', 'wadeId418', 'wadeId419', 'wadeId420', 'wadeId421',
#        'wadeId422', 'wadeId423', 'wadeId424', 'wadeId425', 'wadeId426',
#        'wadeId427', 'wadeId428', 'wadeId429', 'wadeId430', 'wadeId431',
#        'wadeId432', 'wadeId433', 'wadeId434', 'wadeId435', 'wadeId436',
#        'wadeId437', 'wadeId438', 'wadeId439', 'wadeId440', 'wadeId441',
#        'wadeId442', 'wadeId443', 'wadeId444', 'wadeId445', 'wadeId446',
#        'wadeId447', 'wadeId448', 'wadeId449', 'wadeId450', 'wadeId451',
#        'wadeId452', 'wadeId453', 'wadeId454', 'wadeId455', 'wadeId456',
#        'wadeId457', 'wadeId458', 'wadeId459', 'wadeId460', 'wadeId461',
#        'wadeId462', 'wadeId463', 'wadeId464', 'wadeId465', 'wadeId466',
#        'wadeId467', 'wadeId468', 'wadeId469', 'wadeId470', 'wadeId471',
#        'wadeId472', 'wadeId473', 'wadeId474', 'wadeId475', 'wadeId476',
#        'wadeId477', 'wadeId478', 'wadeId479', 'wadeId480', 'wadeId481',
#        'wadeId482', 'wadeId483', 'wadeId484', 'wadeId485', 'wadeId486',
#        'wadeId487', 'wadeId488', 'wadeId489', 'wadeId490', 'wadeId491',
#        'wadeId492', 'wadeId493', 'wadeId494', 'wadeId495', 'wadeId496',
#        'wadeId497', 'wadeId498', 'wadeId499', 'wadeId500', 'wadeId501',
#        'wadeId502', 'wadeId503', 'wadeId504', 'wadeId505', 'wadeId506',
#        'wadeId507', 'wadeId508', 'wadeId509', 'wadeId510', 'wadeId511',
#        'wadeId512', 'wadeId513', 'wadeId514', 'wadeId515', 'wadeId516',
#        'wadeId517', 'wadeId518', 'wadeId519', 'wadeId520', 'wadeId521',
#        'wadeId522', 'wadeId523', 'wadeId524', 'wadeId525', 'wadeId526',
#        'wadeId527', 'wadeId528', 'wadeId529', 'wadeId530', 'wadeId531',
#        'wadeId532', 'wadeId533', 'wadeId534', 'wadeId535', 'wadeId536',
#        'wadeId537', 'wadeId538', 'wadeId539', 'wadeId540', 'wadeId541',
#        'wadeId542', 'wadeId543', 'wadeId544', 'wadeId545', 'wadeId546',
#        'wadeId547', 'wadeId548', 'wadeId549', 'wadeId550', 'wadeId551',
#        'wadeId552', 'wadeId553', 'wadeId554', 'wadeId555', 'wadeId556',
#        'wadeId557', 'wadeId558', 'wadeId559', 'wadeId560', 'wadeId561',
#        'wadeId562', 'wadeId563', 'wadeId564', 'wadeId565', 'wadeId566',
#        'wadeId567', 'wadeId568', 'wadeId569', 'wadeId570', 'wadeId571',
#        'wadeId572', 'wadeId573', 'wadeId574', 'wadeId575', 'wadeId576',
#        'wadeId577', 'wadeId578', 'wadeId579', 'wadeId580', 'wadeId581',
#        'wadeId582', 'wadeId583', 'wadeId584', 'wadeId585', 'wadeId586',
#        'wadeId587', 'wadeId588', 'wadeId589', 'wadeId590', 'wadeId591',
#        'wadeId592', 'wadeId593', 'wadeId594', 'wadeId595', 'wadeId596',
#        'wadeId597', 'wadeId598', 'wadeId599', 'wadeId600', 'wadeId601',
#        'wadeId602', 'wadeId603', 'wadeId604', 'wadeId605', 'wadeId606',
#        'wadeId607', 'wadeId608', 'wadeId609', 'wadeId610', 'wadeId611',
#        'wadeId612', 'wadeId613', 'wadeId614', 'wadeId615', 'wadeId616',
#        'wadeId617', 'wadeId618', 'wadeId619', 'wadeId620', 'wadeId621',
#        'wadeId622', 'wadeId623', 'wadeId624', 'wadeId625', 'wadeId626',
#        'wadeId627', 'wadeId628', 'wadeId629', 'wadeId630', 'wadeId631',
#        'wadeId632', 'wadeId633', 'wadeId634', 'wadeId635', 'wadeId636',
#        'wadeId637', 'wadeId638', 'wadeId639', 'wadeId640', 'wadeId641',
#        'wadeId642', 'wadeId643', 'wadeId644', 'wadeId645', 'wadeId646',
#        'wadeId647', 'wadeId648', 'wadeId649', 'wadeId650', 'wadeId651',
#        'wadeId652', 'wadeId653', 'wadeId654', 'wadeId655', 'wadeId656',
#        'wadeId657', 'wadeId658', 'wadeId659', 'wadeId660', 'wadeId661',
#        'wadeId662', 'wadeId663', 'wadeId664', 'wadeId665', 'wadeId666',
#        'wadeId667', 'wadeId668', 'wadeId669'], dtype=object)

# %%
# Creating WaDE Custom site native ID for easy site identification
# use Unique Latitude, Longitude, SiteName and SiteTypeCV values
# ----------------------------------------------------------------------------------------------------

# Create temp in_SiteNativeID dataframe of unique water source.
def assignIdValueFunc(colRowValue):
    string1 = str(colRowValue)
    outstring = "wadeId" + string1
    return outstring

dfTempID = pd.DataFrame()
dfTempID['in_Latitude'] = outdf['in_Latitude'].astype(str).str.strip()
dfTempID['in_Longitude'] = outdf['in_Longitude'].astype(str).str.strip()
dfTempID['in_SiteName'] = outdf['in_SiteName'].astype(str).str.strip()
dfTempID['in_SiteTypeCV'] = outdf['in_SiteTypeCV'].astype(str).str.strip()
dfTempID = dfTempID.drop_duplicates()

dfTempCount = pd.DataFrame(index=dfTempID.index)
dfTempCount["Count"] = range(1, len(dfTempCount.index) + 1)
dfTempID['in_SiteNativeID'] = dfTempCount.apply(lambda row: assignIdValueFunc(row['Count']), axis=1)
dfTempID['linkKey'] = dfTempID['in_Latitude'].astype(str) + dfTempID['in_Longitude'].astype(str) + dfTempID['in_SiteName'].astype(str)+ dfTempID['in_SiteTypeCV'].astype(str)
IdDict = pd.Series(dfTempID.in_SiteNativeID.values, index=dfTempID.linkKey.astype(str)).to_dict()
# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom site native ID
def retrieveIdValueFunc(checkVal, valA, valB, valC, valD):
    checkVal = str(checkVal).strip()
    if checkVal == "":
        linkKeyVal = str(valA).strip() + str(valB).strip() + str(valC).strip() + str(valD).strip()
        outString = IdDict[linkKeyVal]
    else:
        outString = checkVal
    return outString

outdf['in_SiteNativeID'] = outdf.apply(lambda row: retrieveIdValueFunc(row['in_SiteNativeID'], 
                                                                       row['in_Latitude'], row['in_Longitude'],
                                                                       row['in_SiteName'], row['in_SiteTypeCV']), axis=1)
outdf['in_SiteNativeID'].unique()
# Out:
# array(['nd13007302B', 'nd15310236CC', 'nd15310236BA', ..., 'nd15910304D',
#        'nd13005820A', 'nd13005820D'], dtype=object)

# %% [markdown]
# ## Drop non-Active AllocationLegalStatusCV Water Rights
# - For ND, we don't want water rights that are considered: Application In Processing, Cancelled, Deferred, Denied, Held In Abeyance, InActive, Pending Review, Under Review, Void

# %%
# drop non-active AllocationLegalStatusCV values specific to that state.

# drop the list
dropLegalStatusList = ["Application In Processing", "Cancelled", "Deferred", "Denied", "Held In Abeyance", "InActive", "Pending Review", "Under Review", "Void"]

# drop rows from above list
outdf = outdf[outdf.in_AllocationLegalStatusCV.isin(dropLegalStatusList) == False].reset_index(drop=True)

print(len(outdf))
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# 135241
# array(['Active', 'POD In Processing', ''], dtype=object)

# %% [markdown]
# ## Shapefile Data
# - For attaching geometry to POU csv inputs.

# %%
# # PoU Shapefile Data
# shapefileInput = "RawInputData/shapefiles/{enter file name here}.zip" # ziped folder of the shp file

# dfPoUshapetemp = gpd.read_file(shapefileInput)
# dfPoUshapetemp['geometry'] = dfPoUshapetemp['geometry'].to_crs(epsg=4326) # Realign Geometry Projection
# print(len(dfPoUshapetemp))
# dfPoUshapetemp.head()

# %%
# # create temp dataframe to hold native ID and geometry from shapefile input
# columnsList = ['in_SiteNativeID', 'geometry']
# dfPoUshape = pd.DataFrame(columns=columnsList)

# # assing values to temp dataframe based on shapefile input
# # for in_SiteNativeID assure ID value is the same as that listed above for POU info.
# dfPoUshape['in_SiteNativeID'] = "POU" + ""
# dfPoUshape['geometry'] = dfPoUshapetemp['geometry']
# dfPoUshape = dfPoUshape.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# print(len(dfPoUshape))
# dfPoUshape.head()

# %% [markdown]
# ## Export Outputs

# %%
outdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135241 entries, 0 to 135240
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   WaDEUUID                                      135241 non-null  object
#  1   in_MethodUUID                                 135241 non-null  object
#  2   in_VariableSpecificUUID                       135241 non-null  object
#  3   in_AggregationIntervalUnitCV                  135241 non-null  object
#  4   in_VariableCV                                 135241 non-null  object
#  5   in_OrganizationUUID                           135241 non-null  object
#  6   in_Geometry                                   135241 non-null  object
#  7   in_GNISFeatureNameCV                          135241 non-null  object
#  8   in_WaterQualityIndicatorCV                    135241 non-null  object
#  9   in_WaterSourceName                            135241 non-null  object
#  10  in_WaterSourceNativeID                        135241 non-null  object
#  11  in_WaterSourceTypeCV                          135241 non-null  object
#  12  in_CoordinateAccuracy                         135241 non-null  object
#  13  in_CoordinateMethodCV                         135241 non-null  object
#  14  in_County                                     135241 non-null  object
#  15  in_EPSGCodeCV                                 135241 non-null  int64
#  16  in_GNISCodeCV                                 135241 non-null  object
#  17  in_HUC12                                      135241 non-null  object
#  18  in_HUC8                                       135241 non-null  object
#  19  in_Latitude                                   135241 non-null  float64
#  20  in_Longitude                                  135241 non-null  float64
#  21  in_NHDNetworkStatusCV                         135241 non-null  object
#  22  in_NHDProductCV                               135241 non-null  object
#  23  in_PODorPOUSite                               135241 non-null  object
#  24  in_SiteName                                   135241 non-null  object
#  25  in_SiteNativeID                               135241 non-null  object
#  26  in_SitePoint                                  135241 non-null  object
#  27  in_SiteTypeCV                                 135241 non-null  object
#  28  in_StateCV                                    135241 non-null  object
#  29  in_USGSSiteID                                 135241 non-null  object
#  30  in_AllocationApplicationDate                  135241 non-null  object
#  31  in_AllocationAssociatedConsumptiveUseSiteIDs  135241 non-null  object
#  32  in_AllocationAssociatedWithdrawalSiteIDs      135241 non-null  object
#  33  in_AllocationBasisCV                          135241 non-null  object
#  34  in_AllocationChangeApplicationIndicator       135241 non-null  object
#  35  in_AllocationCommunityWaterSupplySystem       135241 non-null  object
#  36  in_AllocationCropDutyAmount                   135241 non-null  object
#  37  in_AllocationExpirationDate                   135241 non-null  object
#  38  in_AllocationFlow_CFS                         135241 non-null  object
#  39  in_AllocationLegalStatusCV                    135241 non-null  object
#  40  in_AllocationNativeID                         135241 non-null  object
#  41  in_AllocationOwner                            135241 non-null  object
#  42  in_AllocationPriorityDate                     135240 non-null  datetime64[ns]
#  43  in_AllocationSDWISIdentifierCV                135241 non-null  object
#  44  in_AllocationTimeframeEnd                     135241 non-null  object
#  45  in_AllocationTimeframeStart                   135241 non-null  object
#  46  in_AllocationTypeCV                           135241 non-null  object
#  47  in_AllocationVolume_AF                        135241 non-null  object
#  48  in_BeneficialUseCategory                      135241 non-null  object
#  49  in_CommunityWaterSupplySystem                 135241 non-null  object
#  50  in_CropTypeCV                                 135241 non-null  object
#  51  in_CustomerTypeCV                             135241 non-null  object
#  52  in_DataPublicationDate                        135241 non-null  object
#  53  in_DataPublicationDOI                         135241 non-null  object
#  54  in_ExemptOfVolumeFlowPriority                 135241 non-null  int64
#  55  in_GeneratedPowerCapacityMW                   135241 non-null  object
#  56  in_IrrigatedAcreage                           135241 non-null  float64
#  57  in_IrrigationMethodCV                         135241 non-null  object
#  58  in_LegacyAllocationIDs                        135241 non-null  object
#  59  in_OwnerClassificationCV                      135241 non-null  object
#  60  in_PopulationServed                           135241 non-null  object
#  61  in_PowerType                                  135241 non-null  object
#  62  in_PrimaryBeneficialUseCategory               135241 non-null  object
#  63  in_SDWISIdentifierCV                          135241 non-null  object
#  64  in_WaterAllocationNativeURL                   135241 non-null  object
#  65  in_Amount                                     135241 non-null  object
#  66  in_AssociatedNativeAllocationIDs              135241 non-null  object
#  67  in_PowerGeneratedGWh                          135241 non-null  object
#  68  in_PrimaryUseCategory                         135241 non-null  object
#  69  in_ReportYearCV                               135241 non-null  object
#  70  in_SDWISIdentifier                            135241 non-null  object
#  71  in_TimeframeEnd                               134448 non-null  datetime64[ns]
#  72  in_TimeframeStart                             134448 non-null  datetime64[ns]
#  73  in_VariableSpecificCV                         135241 non-null  object
# dtypes: datetime64[ns](3), float64(3), int64(2), object(66)
# memory usage: 76.4+ MB

# %%
outdf
# Out:
#         WaDEUUID in_MethodUUID in_VariableSpecificUUID  \
# 0           in13     NDwrwu_M1               NDwrwu_V1
# 1           in13     NDwrwu_M1               NDwrwu_V1
# 2           in13     NDwrwu_M1               NDwrwu_V1
# 3           in13     NDwrwu_M1               NDwrwu_V1
# 4           in13     NDwrwu_M1               NDwrwu_V1
# ...          ...           ...                     ...
# 135236  in112884     NDwrwu_M1               NDwrwu_V1
# 135237  in112885     NDwrwu_M1               NDwrwu_V1
# 135238  in112886     NDwrwu_M1               NDwrwu_V1
# 135239  in112887     NDwrwu_M1               NDwrwu_V1
# 135240  in112888     NDwrwu_M1               NDwrwu_V1
#
#        in_AggregationIntervalUnitCV in_VariableCV in_OrganizationUUID  \
# 0                            Annual   Water Right           NDwrwu_O1
# 1                            Annual   Water Right           NDwrwu_O1
# 2                            Annual   Water Right           NDwrwu_O1
# 3                            Annual   Water Right           NDwrwu_O1
# 4                            Annual   Water Right           NDwrwu_O1
# ...                             ...           ...                 ...
# 135236                       Annual   Water Right           NDwrwu_O1
# 135237                       Annual   Water Right           NDwrwu_O1
# 135238                       Annual   Water Right           NDwrwu_O1
# 135239                       Annual   Water Right           NDwrwu_O1
# 135240                       Annual   Water Right           NDwrwu_O1
#
#        in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
# ...            ...                  ...                        ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#        in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                        wadeId2        Surface Water
# 1                                        wadeId2        Surface Water
# 2                                        wadeId2        Surface Water
# 3                                        wadeId2        Surface Water
# 4                                        wadeId2        Surface Water
# ...                   ...                    ...                  ...
# 135236                                   wadeId1          Groundwater
# 135237                                   wadeId1          Groundwater
# 135238                                   wadeId1          Groundwater
# 135239                                   wadeId1          Groundwater
# 135240                                   wadeId1          Groundwater
#
#        in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0                                 Centroid of Area                     4326
# 1                                 Centroid of Area                     4326
# 2                                 Centroid of Area                     4326
# 3                                 Centroid of Area                     4326
# 4                                 Centroid of Area                     4326
# ...                      ...                   ...       ...            ...
# 135236                            Centroid of Area                     4326
# 135237                            Centroid of Area                     4326
# 135238                            Centroid of Area                     4326
# 135239                            Centroid of Area                     4326
# 135240                            Centroid of Area                     4326
#
#        in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                         47.70175    -103.44125
# 1                                         47.70175    -103.44125
# 2                                         47.70175    -103.44125
# 3                                         47.70175    -103.44125
# 4                                         47.70175    -103.44125
# ...              ...      ...     ...          ...           ...
# 135236                                    48.62298    -104.02091
# 135237                                    48.62287    -103.99898
# 135238                                    46.06247     -97.97147
# 135239                                    46.05526     -97.97149
# 135240                                    45.93949     -98.00279
#
#        in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite in_SiteName  \
# 0                                                        POD
# 1                                                        POD
# 2                                                        POD
# 3                                                        POD
# 4                                                        POD
# ...                      ...             ...             ...         ...
# 135236                                                   POD
# 135237                                                   POD
# 135238                                                   POD
# 135239                                                   POD
# 135240                                                   POD
#
#        in_SiteNativeID in_SitePoint in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0         nd14910026AB                                    ND
# 1         nd14910026AB                                    ND
# 2         nd14910026AB                                    ND
# 3         nd14910026AB                                    ND
# 4         nd14910026AB                                    ND
# ...                ...          ...           ...        ...           ...
# 135236     nd15910305D                                    ND
# 135237     nd15910304D                                    ND
# 135238     nd13005820A                                    ND
# 135239     nd13005820D                                    ND
# 135240     nd12905831C                                    ND
#
#        in_AllocationApplicationDate  \
# 0                        1937-04-30
# 1                        1937-04-30
# 2                        1937-04-30
# 3                        1937-04-30
# 4                        1937-04-30
# ...                             ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#        in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3
# 4
# ...                                             ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#        in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...                  ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#        in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#        in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...                         ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#        in_AllocationExpirationDate in_AllocationFlow_CFS  \
# 0                                             1615.60000
# 1                                             1615.60000
# 2                                             1615.60000
# 3                                             1615.60000
# 4                                             1615.60000
# ...                            ...                   ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#        in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                          Active                  2D_4
# 1                          Active                  2D_4
# 2                          Active                  2D_4
# 3                          Active                  2D_4
# 4                          Active                  2D_4
# ...                           ...                   ...
# 135236          POD In Processing            7354_93375
# 135237          POD In Processing            7354_93376
# 135238          POD In Processing            7355_93377
# 135239          POD In Processing            7355_93378
# 135240          POD In Processing            7356_93379
#
#                    in_AllocationOwner in_AllocationPriorityDate  \
# 0       Gudmunsen Robert And Lowraine                1906-01-26
# 1       Gudmunsen Robert And Lowraine                1906-01-26
# 2       Gudmunsen Robert And Lowraine                1906-01-26
# 3       Gudmunsen Robert And Lowraine                1906-01-26
# 4       Gudmunsen Robert And Lowraine                1906-01-26
# ...                               ...                       ...
# 135236       Ibsen Duane And Rosemary                2024-01-04
# 135237       Ibsen Duane And Rosemary                2024-01-04
# 135238                   Schmit Layne                2024-01-11
# 135239                   Schmit Layne                2024-01-11
# 135240                  Treeby Hollis                2024-01-16
#
#        in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                       ...
# 135236                                              December 31
# 135237                                              December 31
# 135238                                               October 31
# 135239                                               October 31
# 135240                                               October 31
#
#        in_AllocationTimeframeStart in_AllocationTypeCV in_AllocationVolume_AF  \
# 0                                                                   291.00000
# 1                                                                   291.00000
# 2                                                                   291.00000
# 3                                                                   291.00000
# 4                                                                   291.00000
# ...                            ...                 ...                    ...
# 135236                   January 1
# 135237                   January 1
# 135238                     April 1
# 135239                     April 1
# 135240                     April 1
#
#        in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0                    Irrigation
# 1                    Irrigation
# 2                    Irrigation
# 3                    Irrigation
# 4                    Irrigation
# ...                         ...                           ...           ...
# 135236               Industrial
# 135237               Industrial
# 135238               Irrigation
# 135239               Irrigation
# 135240               Irrigation
#
#        in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                    ...                   ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#         in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
# ...                               ...                         ...
# 135236                              0
# 135237                              0
# 135238                              0
# 135239                              0
# 135240                              0
#
#         in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0                 291.00000
# 1                 291.00000
# 2                 291.00000
# 3                 291.00000
# 4                 291.00000
# ...                     ...                   ...                    ...
# 135236              0.00000
# 135237              0.00000
# 135238              0.00000
# 135239              0.00000
# 135240              0.00000
#
#        in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                 ...          ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#        in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
# ...                                ...                  ...
# 135236
# 135237
# 135238
# 135239
# 135240
#
#                               in_WaterAllocationNativeURL in_Amount  \
# 0       https://www.swc.nd.gov/info_edu/map_data_resou... 291.00000
# 1       https://www.swc.nd.gov/info_edu/map_data_resou... 291.00000
# 2       https://www.swc.nd.gov/info_edu/map_data_resou... 291.00000
# 3       https://www.swc.nd.gov/info_edu/map_data_resou... 291.00000
# 4       https://www.swc.nd.gov/info_edu/map_data_resou... 291.00000
# ...                                                   ...       ...
# 135236  https://www.swc.nd.gov/info_edu/map_data_resou...
# 135237  https://www.swc.nd.gov/info_edu/map_data_resou...
# 135238  https://www.swc.nd.gov/info_edu/map_data_resou...
# 135239  https://www.swc.nd.gov/info_edu/map_data_resou...
# 135240  https://www.swc.nd.gov/info_edu/map_data_resou...
#
#        in_AssociatedNativeAllocationIDs in_PowerGeneratedGWh  \
# 0                                  2D_4
# 1                                  2D_4
# 2                                  2D_4
# 3                                  2D_4
# 4                                  2D_4
# ...                                 ...                  ...
# 135236                       7354_93375
# 135237                       7354_93376
# 135238                       7355_93377
# 135239                       7355_93378
# 135240                       7356_93379
#
#          in_PrimaryUseCategory in_ReportYearCV in_SDWISIdentifier  \
# 0       Agriculture Irrigation            1977
# 1       Agriculture Irrigation            1978
# 2       Agriculture Irrigation            1979
# 3       Agriculture Irrigation            1980
# 4       Agriculture Irrigation            1981
# ...                        ...             ...                ...
# 135236   Commercial/Industrial               0
# 135237   Commercial/Industrial               0
# 135238  Agriculture Irrigation               0
# 135239  Agriculture Irrigation               0
# 135240  Agriculture Irrigation               0
#
#        in_TimeframeEnd in_TimeframeStart  \
# 0           1977-12-31        1977-01-01
# 1           1978-12-31        1978-01-01
# 2           1979-12-31        1979-01-01
# 3           1980-12-31        1980-01-01
# 4           1981-12-31        1981-01-01
# ...                ...               ...
# 135236             NaT               NaT
# 135237             NaT               NaT
# 135238             NaT               NaT
# 135239             NaT               NaT
# 135240             NaT               NaT
#
#                                     in_VariableSpecificCV
# 0       Water Right_Annual_Agriculture Irrigation_Surf...
# 1       Water Right_Annual_Agriculture Irrigation_Surf...
# 2       Water Right_Annual_Agriculture Irrigation_Surf...
# 3       Water Right_Annual_Agriculture Irrigation_Surf...
# 4       Water Right_Annual_Agriculture Irrigation_Surf...
# ...                                                   ...
# 135236  Water Right_Annual_Commercial/Industrial_Groun...
# 135237  Water Right_Annual_Commercial/Industrial_Groun...
# 135238  Water Right_Annual_Agriculture Irrigation_Grou...
# 135239  Water Right_Annual_Agriculture Irrigation_Grou...
# 135240  Water Right_Annual_Agriculture Irrigation_Grou...
#
# [135241 rows x 74 columns]

# %%
# Export the output dataframe
outdf.to_csv('RawInputData/Pwrwu_Main.zip', compression=dict(method='zip', archive_name='Pwrwu_Main.csv'), index=False)  # The output, save as a zip
#dfPoUshape.to_csv('RawInputData/P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
