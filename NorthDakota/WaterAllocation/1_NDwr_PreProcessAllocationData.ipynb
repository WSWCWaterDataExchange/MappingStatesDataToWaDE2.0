# %% [markdown]
# # Pre-processing North Dakaota Allocation data for WaDEQA upload.
# Date Updated: 03/28/2023
# Purpose:  To pre-process the ND data into one master file for simple DataFrame creation and extraction

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
import re
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x) # suppress scientific notation in Pandas

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/NorthDakota/WaterAllocation/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## POD Data: Permit

# %%
# Input File
dfinPOD = pd.read_csv("Permits_input.zip", encoding = "ISO-8859-1", compression='zip').replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in dfinPOD:
    dfinPOD['WaDEUUID'] = "ndwr" + df.index.astype(str)
    dfinPOD.to_csv('Permits_input.csv', index=False)

print(len(dfinPOD))
dfinPOD.head(1)
# Out:
# 12181
#   WaDEUUID ReasonRemoved IncompleteField  permit_ind permit_num  pod_index  \
# 0    ndwr0                                         1       4407          1
#
#          pod                     permit_hol priority_d    use_type  status  \
# 0  13007302B  KETTERLING, ROLAND & LORRAINE   3/4/1991  Irrigation  Denied
#
#   date_issue date_cance  beneficial    county hu_sub_bas aquifer subaquifer  \
# 0                        1111-11-11  McIntosh     Beaver
#
#    req_acft  req_acre   req_rate  req_storag  app_acft  app_acre  app_rate  \
# 0 204.00000 135.20000 1000.00000     0.00000   0.00000   0.00000   0.00000
#
#    app_storag pod_status        source irrigation source_nam  mainstem  \
# 0     0.00000     Denied  Ground Water  Sprinkler                    0
#
#   impound_lo impound_na return_des discharge_ period_sta period_end  \
# 0
#
#    return_qua  held_acft  held_acre  held_rate  held_stora  longitude  \
# 0           0    0.00000    0.00000    0.00000     0.00000  -99.78988
#
#    latitude
# 0  46.11130

# %%
# swapping order owner name
import re

def createOwnerName(val):
    if val == "" or pd.isnull(val):
        outString = ""
    else:
        val = str(val)
        val = val.strip()
        if "," in val:
            x = val.split(",")
            outString = str(x[0]).strip() + " " + str(x[1]).strip()
        else:
            outString = val     
    return outString
dfinPOD['in_AllocationOwner'] = dfinPOD.apply(lambda row: createOwnerName(row['permit_hol']), axis=1)

def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).strip()
    return Val
dfinPOD['in_AllocationOwner'] = dfinPOD.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
dfinPOD['in_AllocationOwner'].unique()
# Out:
# array(['KETTERLING ROLAND  LORRAINE', 'HYDE GEORGE H', 'SENERIUS FRED',
#        ..., 'IGLEHART DOUG', 'BROTEN ERIC', 'NEW ROCKFORD CITY OF'],
#       dtype=object)

# %%
dfinPOD['in_WaterAllocationNativeURL'] = "https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=" + dfinPOD['permit_ind'].astype(str)
dfinPOD['in_WaterAllocationNativeURL'].unique()
# Out:
# array(['https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=1',
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=2',
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=11',
#        ...,
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=5909',
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=5910',
#        'https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=5911'],
#       dtype=object)

# %%
# create output POD dataframe
df = pd.DataFrame()

# Data Assessment UUID
df['WaDEUUID'] = dfinPOD['WaDEUUID']

# Method Info
df['in_MethodUUID'] = "NDwr_M1"

# Variable Info
df['in_VariableSpecificUUID'] = "NDwr_V1"

# Organization Info
df['in_OrganizationUUID'] = "NDwr_O1"

# Data Assessment UUID
df['WaDEUUID'] = dfinPOD['WaDEUUID']

# Water Source
df['in_Geometry'] = ""
df['in_GNISFeatureNameCV'] = ""
df['in_WaterQualityIndicatorCV'] = ""
df["in_WaterSourceName"] = dfinPOD['source_nam']
df['in_WaterSourceNativeID'] = ""
df["in_WaterSourceTypeCV"] = dfinPOD['source']

# Site
df["in_CoordinateAccuracy"] = "WaDE Unspecified"
df["in_CoordinateMethodCV"] = "Centroid of Area"
df['in_County'] = dfinPOD['county']
df['in_EPSGCodeCV'] = 4326
df['in_Geometry'] = ""
df['in_GNISCodeCV'] = ""
df['in_HUC12'] = ""
df['in_HUC8'] = ""
df["in_Latitude"] = dfinPOD['latitude']
df["in_Longitude"] = dfinPOD['longitude']
df['in_NHDNetworkStatusCV'] = ""
df['in_NHDProductCV'] = ""
df["in_PODorPOUSite"] = "POD"
df["in_SiteName"] = "WaDE Unspecified"
df["in_SiteNativeID"] = "POD" + dfinPOD['pod'].replace("", 0).fillna(0).astype(str)
df['in_SitePoint'] = ""
df["in_SiteTypeCV"] = "WaDE Unspecified"
df["in_StateCV"] = "ND"
df['in_USGSSiteID'] = ""

# Allocation
df["in_AllocationApplicationDate"] = dfinPOD['date_issue']
df['in_AllocationAssociatedConsumptiveUseSiteIDs'] = ""
df['in_AllocationAssociatedWithdrawalSiteIDs'] = ""
df['in_AllocationBasisCV'] = ""
df['in_AllocationChangeApplicationIndicator'] = ""
df['in_AllocationCommunityWaterSupplySystem'] = ""
df['in_AllocationCropDutyAmount'] = ""
df["in_AllocationExpirationDate"] = dfinPOD['date_cance']
df["in_AllocationFlow_CFS"] = dfinPOD['app_rate'].astype(float)
df['in_AllocationLegalStatusCV'] = dfinPOD['pod_status'].astype(str)
df["in_AllocationNativeID"] = dfinPOD['permit_num'].astype(str)
df['in_AllocationOwner'] = dfinPOD['in_AllocationOwner']
df['in_AllocationPriorityDate'] = dfinPOD['priority_d']
df['in_AllocationSDWISIdentifierCV'] = ""
df['in_AllocationTimeframeEnd'] = dfinPOD['period_end']
df['in_AllocationTimeframeStart'] = dfinPOD['period_sta']
df['in_AllocationTypeCV'] = ""
df["in_AllocationVolume_AF"] = dfinPOD['app_acft'].astype(float)
df["in_BeneficialUseCategory"] = dfinPOD['use_type']
df['in_CommunityWaterSupplySystem'] = ""
df['in_CropTypeCV'] = ""
df['in_CustomerTypeCV'] = ""
df['in_DataPublicationDate'] = ""
df['in_DataPublicationDOI'] = ""
df['in_ExemptOfVolumeFlowPriority'] = 0
df['in_GeneratedPowerCapacityMW'] = ""
df['in_IrrigatedAcreage'] = dfinPOD['app_acre'].astype(float)
df['in_IrrigationMethodCV'] = ""
df['in_LegacyAllocationIDs'] = ""
df['in_OwnerClassificationCV'] = ""
df['in_PopulationServed'] = ""
df['in_PowerType'] = ""
df['in_PrimaryBeneficialUseCategory'] = ""
df['in_SDWISIdentifierCV'] = ""
df['in_WaterAllocationNativeURL'] = "https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=" + dfinPOD['in_WaterAllocationNativeURL']

outPOD = df.copy()
outPOD = outPOD.drop_duplicates().reset_index(drop=True)
print(len(outPOD))
outPOD.head()
# Out:
# 12181
#    WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     ndwr0       NDwr_M1                 NDwr_V1             NDwr_O1
# 1     ndwr1       NDwr_M1                 NDwr_V1             NDwr_O1
# 2    ndwr10       NDwr_M1                 NDwr_V1             NDwr_O1
# 3   ndwr100       NDwr_M1                 NDwr_V1             NDwr_O1
# 4  ndwr1000       NDwr_M1                 NDwr_V1             NDwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0                                                   Ground Water
# 1                                                  Surface Water
# 2                                                  Surface Water
# 3                                                  Surface Water
# 4                                                  Surface Water
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0      WaDE Unspecified      Centroid of Area  McIntosh           4326
# 1      WaDE Unspecified      Centroid of Area  McKenzie           4326
# 2      WaDE Unspecified      Centroid of Area    Mercer           4326
# 3      WaDE Unspecified      Centroid of Area      Ward           4326
# 4      WaDE Unspecified      Centroid of Area  Williams           4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    46.11130     -99.78988
# 1                                    48.02622    -103.75216
# 2                                    47.28288    -101.86756
# 3                                    48.33611    -101.46082
# 4                                    48.52694    -103.71934
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite       in_SiteName  \
# 0                                                   POD  WaDE Unspecified
# 1                                                   POD  WaDE Unspecified
# 2                                                   POD  WaDE Unspecified
# 3                                                   POD  WaDE Unspecified
# 4                                                   POD  WaDE Unspecified
#
#   in_SiteNativeID in_SitePoint     in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0    POD13007302B               WaDE Unspecified         ND
# 1   POD15310236CC               WaDE Unspecified         ND
# 2   POD14408820BB               WaDE Unspecified         ND
# 3   POD15608415BD               WaDE Unspecified         ND
# 4   POD15810110AC               WaDE Unspecified         ND
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
# 1
# 2
# 3                     6/9/1915
# 4
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.00000
# 3                                           46.10000
# 4                    2/9/1994                0.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                     Denied                  4407
# 1                  Cancelled                    1E
# 2                  Cancelled                    8E
# 3                   InActive                   91C
# 4                  Cancelled                   902
#
#             in_AllocationOwner in_AllocationPriorityDate  \
# 0  KETTERLING ROLAND  LORRAINE                  3/4/1991
# 1                HYDE GEORGE H                 8/15/1901
# 2                SENERIUS FRED                12/22/1937
# 3   KUDA ALAN P and HUGHESKUDA                  6/9/1915
# 4                   GREV HENRY                 4/10/1961
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeStart in_AllocationTypeCV  in_AllocationVolume_AF  \
# 0                                                                 0.00000
# 1                                                                 0.00000
# 2                                                                 0.00000
# 3                                                                17.00000
# 4                                                                 0.00000
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0               Irrigation
# 1               Irrigation
# 2               Irrigation
# 3               Irrigation
# 4               Irrigation
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#    in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
#
#    in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0              0.00000
# 1              0.00000
# 2              0.00000
# 3              8.50000
# 4              0.00000
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://www.swc.nd.gov/info_edu/map_data_resou...
# 1  https://www.swc.nd.gov/info_edu/map_data_resou...
# 2  https://www.swc.nd.gov/info_edu/map_data_resou...
# 3  https://www.swc.nd.gov/info_edu/map_data_resou...
# 4  https://www.swc.nd.gov/info_edu/map_data_resou...

# %% [markdown]
# ## Concatenate and Clean Data

# %%
# Concatenate dataframes
frames = [outPOD]
outdf = pd.concat(frames)
outdf = outdf.drop_duplicates().reset_index(drop=True).replace(np.nan, "")
print(len(outdf))
# Out:
# 12181

# %% [markdown]
# ## WaDE Custom Elements (due to missing sate info)

# %%
# Fixing empty string names

def fixEmptyString(val):
    if val == "" or val == " " or val == "nan" or pd.isnull(val):
        outString = "WaDE Unspecified"
    else:
        outString = val
    return outString

# %%
outdf['in_WaterSourceName'] = outdf.apply(lambda row: fixEmptyString(row['in_WaterSourceName']), axis=1)
outdf['in_WaterSourceName'].unique()
# Out:
# array(['WaDE Unspecified', 'Unnamed stream trib. of Little Muddy',
#        'Missouri River', 'Goschke Dam on Tongue River',
#        'Goshke Dam on Busse Coulee', 'Goschke Dam on Busse Coulee',
#        'Unnamed Tributary', 'Unamed Coulee trib. of Lower Des Lacs',
#        'Souris River', 'Flat Creek trib. of N. Fork Grand River',
#        'Cannonball River', 'Chimney Butte Creek',
#        'Unnamed coulee trib. of the Heart River',
#        'Unnamed coulee a trib. of t Heart River',
#        'Unnamed creek, trib of Wolf Creek', 'Lake Sakakawea',
#        'Forest River', "Gibb's Spring, Trib. of Little Knife",
#        'White Earth Creek', 'Spring Creek, Trib. of Knife River',
#        'Willow Creek', 'Little Bull Creek',
#        'Unnamed tributary of North Branch Park',
#        'Unnamed creek, trib.of Stony Slough', 'Sheyene River',
#        'unnamed waterway, trib of Des Lacs River', 'Goschke Dam',
#        'Unnamed creek, trib. of the Tongue River',
#        'Bussee Coulee, trib. of the Tongue River',
#        'Warwick Dam on Sheynne River',
#        'Unnamed stream trib. of Heart River',
#        'Tongue River (Renwick Dam M-4)', 'Unnamed creek', 'Apple Creek',
#        'Sheyenne Delta Aquifer', 'Heart River', 'treated city wastewater',
#        'James River, Fesenden Dam', 'un-named trib to Square Butte Creek',
#        'Sheyenne River the Harvey Dam',
#        'Coal Mine Creek, trib. of Heart River', 'Park River',
#        'Unnamed tributary to Knife River', 'Sheyenne River',
#        'Scab Creek, trib to Big Muddy Creek',
#        'unnamed creek trib. of the Heart River', 'Beaver Creek',
#        'Lake Oahe', 'Unnamed creek.',
#        'Unnamed creek, trib. of the Heart River',
#        'Crooked Creek tributary', 'Trenton Lake', 'Cedar Creek tributary',
#        'Trib. of Painted Woods Creek', 'Ranch Lake', 'unnamed creek.',
#        'Lake Margaret', 'Rats Coulee', 'Little South Pembina River',
#        'unnamed creek, trib. of Edmore Coulee',
#        'North Branch of Garner Creek', 'DesMoines Lake',
#        'Unnamed creek, trib. of Square Butte Ck.',
#        'Little Missouri River', 'Unnamed creek trib. of Big Muddy Creek',
#        'Little Muddy River', 'Yellowstone River', 'Spring Creek',
#        'Goose River', 'Eightmile Creek', 'Unnamed slough',
#        'Unnamed stream trib. of Cannonball River', 'Unnamed slough.',
#        'Green River', 'Red River of the North', 'Pitt Creek tributary',
#        'Square Butte Creel', 'Ground water', 'Square Butte Creek',
#        'Burnt Creek Diversion', 'Trib. of Crosby Creek', 'Crooked Creek',
#        'Tobacco Garden Creek', 'Hazen Brook',
#        'Southwest Pipeline Project',
#        'Spring - trib. of White Earth River', 'James River', 'Red River',
#        'The Pembina River', 'Painted Woods Creek', 'Sheynne River',
#        'Knife River', 'First Larson Coulee', 'Waste water Logoons',
#        'Waste water lagoons', '4 cell lagoon system',
#        'Shallow saturated alluvium', 'Mauvais Coulee', 'Groundwater',
#        'Des Lac Lake', 'Trib. to the Wild Rice River',
#        'tobacco Garden Creek', 'Hartel Dam', 'Puppy Dog Coulee',
#        'White Earth River', 'Oakes Pilot Drain', 'Jensen Dam',
#        'Unnamed creek trib of Frank Creek', 'Fort Union', 'Sletten Lake',
#        'Sweet Briar Lake', 'Green River tributary', 'Clear Creek',
#        'Unnamed Creek', 'Cherry Creek', 'Dakota Group', 'Pembina River',
#        'Tongue River at Goschke Dam', 'Little Knife River tributary',
#        'North Branch Turtle River', 'Strommen stock pond', 'Unnamed Lake',
#        'Antelope Creek', 'Unnamed Stream', 'Stone Creek',
#        'Trib. of East Fork Shell Creek', 'Little Knife River',
#        'Little Antelope Creek', 'Canonball River', 'Dimmick Lake',
#        'Ephemeral Drainages', 'South Egg Creek', 'Camp Creek',
#        'Spring Creek tributary', 'Bennett Creek', 'un-named stock pond',
#        'Un-named trib to Spring Creek', 'Unnamed pond',
#        'Hagel Creek tributary', 'Little Missouri river',
#        'Strommen Pond - Spring Creek trib.',
#        "Pat's Coulee, trib. to Little Muddy",
#        'Strawberry, Crooked & Brekken Lakes',
#        'Strawberr, Crooked & Brekken Lakes',
#        'Strawberry, Crooked & Brekken', 'Unnamed', 'Cheyenne River',
#        'Horseshoe Lake', 'Holding Pond', 'Halfbreed Creek',
#        'Lake Upsilon', 'Lake Trenton', 'Little Stoney',
#        'Trib to Sqaure Butte Creek', 'North Branch Forest River',
#        'Unnamed trib to Knife River', 'Tributary of Crooked Creek',
#        'Shell Creek', 'Edmore Coulee', 'Cedar River', 'Muskrat Lake',
#        'Stoney Creek', 'Un-named creek, tributary to Spring Cree',
#        'Otte Creek', 'Drain 11', 'East Buehner Pond', 'Jim Creek',
#        'trib to Shirk Creek', 'Derudder Dam', 'Abbey Lake',
#        'Oxbow of Stoney Creek', 'Lake Sakakawea-backwater',
#        'Matejcek Reservoir', 'Lake Zahl', 'Frank Creek', 'Murphy Slough',
#        'McVille', 'runoff & un-named trib to Knife River',
#        'Little Muddy river', 'Dry Creek',
#        'Unnamed Stream, trib of Little Muddy',
#        'Spring Creek & Un-named trib', 'Sweetbriar Creek',
#        'Middle Branch Forest River', 'Intermittent draws', 'Tepee Creek',
#        'Trib to Otter Creek', 'South Branch of Elm River',
#        'Big Muddy Creek', 'lay Creek, Trib of Tobacco Garden Creek',
#        'North Fork Grand River', 'Trib to Turtle Creek',
#        'trib to Burnt Creek', 'Unnamed Channel',
#        'Unnamed intermittent draw', 'Wild Rice River',
#        'Unnamed Creek & Wild Rice River',
#        'Unamed creek and Wild Rice River', 'Nelson Creek',
#        'Unnamed Coulee', 'Nelson Lake-Square Butte Creek', 'Cart Creek',
#        'Un-named trib to Sweet Briar Creek', 'Branch Knife River',
#        'trib to Square Butte Creek', 'South Branch Goose River',
#        'Duck Creek', 'Wakopa Creek', 'Charbonneau Creek & Trib.',
#        'Unnamed Creek Trib to Willow Creek', 'Intermittent creek',
#        'unnamed coulee', 'Unnamed tributary', 'Elm River',
#        'Trib to Wild Rice River', 'English Coulee, Trib to Red River',
#        'Unnamed Intermittent Trib.', 'Big Coulee', 'Dry Draw',
#        'Tongue River', 'Int. draw, trib to Little Missouri River',
#        'un-named inter trib to Spring Creek', 'Horse Creek',
#        'Burnt Creek', 'Unnamed Coulee to Burnt Creek', 'Rush River',
#        'Buffalo Coulee', 'Tobacco Garden Cr & Missouri R Backwater',
#        'Andrews Creek', 'South unit', 'Unnamed Intermittent Stream',
#        'Salt Water Coulee', 'Beaver Creek and Missouri River',
#        'knife River', 'Knifer River', 'Mt. Carmel Dam',
#        'un-named intermittent stream', 'Mouse River',
#        'un named trib to Andrews Creek',
#        'Un-named stream, trib. to Little Missour', 'Deep Creek',
#        'Un-named coulee, tributary to Garrison R', 'Timber Creek',
#        'Unnamed intermittent draws', 'Charbonneau Creek', 'Bullion Creek',
#        'Unnamed stream', 'Little Creek', 'Mc Gillis Creek',
#        'unnamed draw', 'Intermittent draws, trib. to Little Miss',
#        'Big Muddy Creek and Intermittent Stream', 'Cottonwood Creek',
#        'Unnamed creek, tributary to Beaver Creek', 'Sand Creek',
#        'Unnamed Intermittent Streams', 'South Branch of Turtle River',
#        'Apple Creek tributary', 'Fourmile Creek', 'Gibb Springs',
#        'Sweetwater Lake', 'Mulberry Creek',
#        "Big Mary's Coulee, trib to Mouse River",
#        'Unnamed coulee, trib to Sheyeene River', 'Oxbow - Knife River',
#        'unnamed intermittant draw',
#        'Spring Creek, a trib of the Knife River',
#        'Spring Creek, a trib of Knife River',
#        'Spring Creek, a trib of the Knife Rriver', 'Nelson Lake',
#        'Beaver Creek, trib. to Little Missouri R', 'Annie Creek',
#        'Unnamed Trib. to Deep Creek', 'Tributary to West Hay Draw Creek',
#        'West Hay Draw Creek', 'Sheep Creek',
#        'Unnamed trib to Souris River', 'Long Lake Creek',
#        'unnamed draw, trib to Northfork Cr.', 'Unnamed Intermittent Draw',
#        'Unnamed Intermittent Draws',
#        'Box Elder Creek, trib. to Little Missour', 'Stony Creek',
#        'Sweet Briar Creek', 'Willow Lake',
#        'Un-named coulee & Dry Fork Coulee', 'Sout Branch Turtle river',
#        'Goose Lake', 'Chanta Peta Creek', 'Pipestem Creek',
#        'Lonesome Creek', 'Iron Springs',
#        'Beaver Creek, trib. to Little Misouri Ri',
#        'Un-named draw, tributary to Missouri Riv',
#        'Knife River tributary', 'Long Lake Creek & Slough',
#        'Gibbs Springs', 'Unnamed Trib. to North Fork of the Grand',
#        'Unnamed Trib.', 'Cottonwood Lake',
#        'Un named creek - trib to Missouri River', 'Little Beaver Creek',
#        'Maple River', 'Un-named trib to Cannonball River',
#        'Unnamed Stream, trib. of Crooked Creek',
#        'Starkweather Ã¯Â¿Â½oulee', 'Old Oxbow of Apple Creek',
#        'Buford Coulee', 'Bennie Pierre Creek',
#        '101 Creek, Bennie Pierre Creek', 'Badlands Creek', 'Silver Lake',
#        'Lake Sakakwea', 'Danners Coulee',
#        'Dickinson City Sewage Lagoons # 3 & 4',
#        'Dickinson City Sewage Lagoons #3 & 4',
#        'Unnamed Trib. of Square Butte Creek',
#        'Unnamed Trib. to Charbonneau Creek',
#        'Unnamed stream trib. of Missouri River',
#        'Third cell of laggon system',
#        'Unnamed Stream Trib. to Little Missouri', 'North Creek',
#        'Blacktail Creek', 'Black Tail Creek',
#        'Unnamed Trib to Little Goose River',
#        'unnamed stream, trib. to Missouri River',
#        'Unnamed Trib. to Short Creek',
#        'Un-named trib of Charbonneau Creek', 'Buffalo Creek',
#        'Dogtooth Creek', 'Smishek Lake', 'Rice Creek', 'Park Rver',
#        'Unnamed Trib. to Upper Lostwood Lake',
#        'un-named creek, tributary to Spring Cree',
#        'Tributary to South Branch Turtle River',
#        'McClusky Canal, Sta. 433+44.8', 'Turtle Creek',
#        'Little Heart River', 'Fresh Water Coulee',
#        'Unnamed Trib. of Lake Sakakawea',
#        'South Branch of the Goose River', 'Northfork Creek',
#        'un-named trib to Little Missouri',
#        'Random Creek trib to Long Lake Creek', 'Culvert Coulee',
#        'ACSC Condenser Pond', "Trib to Kelly's Slough, Trib to Turtle R",
#        'Skunk Coulee & Flood Detention Dam #1', 'Trib to Turtle River',
#        'Unnamed Draw trib. to LaPorte Coulee',
#        'Unnamed Draw trib to Russell Drain', 'Mud Creek',
#        'Unnamed Drainage', 'Unnamed Trib. to Long Lake',
#        'Unnamed drainage trib to Harriet Lake', 'Lake Audubon',
#        'waste ground water from malting process', 'Unnamed drainage',
#        'Unnamed Trib to West Stump Lake', 'Otter Creek',
#        'Starkweather Coulee', 'Unnamed trib. to Willow Lake',
#        'Grand Forks County WRD Flood Detention D', 'PLUM CREEK',
#        'Unnamed Trib', 'Lightning Creek',
#        'Unnamed Tributary of Spring Creek',
#        'Unnamed Trib. West Branch of Short Creek',
#        'Unnamed Trib. of Thirty Mile Creek', 'Coal Creek',
#        'Unnamed Trib. of Plum Creek.', 'LaPorte Coulee', 'Kelly Slough',
#        'Unnamed wetland a trib. of Lake Audubon.', 'Flat Creek',
#        'Lake Alice', 'Unnamed Trib. to Bennie Pierre Creek',
#        'Unnamed Trib. to Bennnie Pierre Creek',
#        'Unnamed Trib to Bennie Pierre Creek',
#        'Kane/Tacoma/Overgaard Drain', 'Alkali Creek',
#        'Unnamed Trib to Slow Cr, Spring Cr Trib.', 'Dry Lake',
#        'Unnamed Trib. to Cedar Creek',
#        'Unnamed Trib. of Spring Creek Trib.',
#        'Unnamed Trib. to Indian Creek',
#        'Unnamed Stream Trib. to Buffalo Creek',
#        'Unnamed Trib. to Hans Cr-Spring Cr Trib.',
#        'Lagoons for residual ground  water',
#        'Unnamed Trib. to Spring Creek', 'Unnamed Trib. of Spring Creek',
#        'Unnamed Trib. of Edmore Coulee', 'Unnamed Trib. to Edmore Coulee',
#        'Unnamed Stream Trib. to Little Knife R.', 'Antler Creek',
#        'Lake Irvine', 'Unnaned trib to Missouri river',
#        'Unnamed Trib. of the Red River', 'Unnamed Trib. of Red River',
#        'Renwick Dam', 'Unnamed Tributary to Lake George',
#        'Grand Harbor Drainage trib Six Mile Bay',
#        'Unnamed Trib-Haymarsh Cr trib Big Muddy',
#        'Unnamed Trib. of White Earth River',
#        'Unnamed Tributary to the Red River', 'Valley City Sewage Lagoons',
#        'Valley City Municipal Lagoons',
#        'Dickinson City Sewage Lagoon Cells 3 & 4',
#        'Dickinson City Sewage Lagoon Cell #2',
#        'Dickinson Sewage Lagoons #2, 3, & 4',
#        'Big Coulee Waterway trib Mauvais Coulee',
#        'Big Coulee Waterwau trib Mauvais Coulee',
#        'Unnamed Trib. of South Branch Park River',
#        'Unnamed Trib. of Beaver Holes Creek',
#        'Muskrat Cr trib Sims Cr trib Hailstone C',
#        'Unnamed Trib. to Battle Creek', 'Unnamed Drain',
#        'Unnamed Trib. to Coyote Creek',
#        'Unnamed waterway trib. to Roger Creek',
#        'Unnamed Waterway trib. to Deep Creek',
#        'Unnamed waterway trib. to Deep Creek',
#        'Unnamed Waterway trib to Heart Butte Ck', 'Goose Creek',
#        'Unnamed stream trib. to Goose Creek',
#        'Unnamed trib. to Little Heart River', 'Pembina County Drain #20',
#        'Murphy Creek Trib. to Spring Creek', 'groundwater',
#        'Unnamed trib to Charbonneau Creek',
#        'Unnamed Tributary to Starkweather Coulee',
#        'Unnamed Drain trib Starkweather Coulee', 'Unnamed, Crooked Creek',
#        'Unnamed trib to Heart River',
#        'Unnamed trib to Square Butte Creek', 'Mount Carmel Dam',
#        'Unnamed trib. to Maple River', 'Middle Branch Park River',
#        'Unnamed Trib. to Dead Buffalo Lake',
#        'Pats Coulee, Trib to Little Muddy', 'West Cut Bank Creek',
#        'Unnamed creek trib to Porcupine Creek', 'Indian Creek',
#        'Spring Creek trib to Lower Coyote Creek',
#        'Unnamed Trib to East Antelope Creek', 'Scab Creek', 'Twin Lake',
#        'Stack Slough', 'Chain Lake', 'Unnamed/ Tributary of Beaver Creek',
#        'Oak Creek', 'Random Creek', 'Morrison Lake', 'Long Creek',
#        'Kenner Marsh', 'unnamed tributary', 'Island Lake', 'UNNAMED',
#        'Unnamed trib of Coyote Creek', 'Drake sewage lagoon',
#        'Dayton Creek', 'unnamed creek', 'unnamed stream',
#        'Unknown Tributary', 'Esmond aquifer', 'Trappers Coulee aquifer',
#        'Middle Branch of Park River', '\x7f', 'Middle Brannch Park',
#        'East Antelope Creek', 'MISSOURI RIVER', 'unnamed',
#        'Des Lacs River', 'Skunk Coulee',
#        'unnamed tributary of Wannagan Creek',
#        'unnamed creek/trib. of Cedar Creek',
#        'unnamed stream, trib of Ash Creek',
#        'unnamed creek, trib of Antelope Creek', 'Wolf Lake',
#        'unnamed drainage', 'Coal Bank Creek/Trib of Cannonball River',
#        'unnamed tributary to Little Knife River',
#        'unnamed creek/ trib of Morris Creek',
#        'unnamed creek/ trib of Cold Turkey Creek',
#        'unnamed creek/ trib. of the Cannonball R',
#        'unnamed creek - tribe. of Turkey Creek',
#        'Middle Branch park River',
#        'Skunk Coulee, Tributary to Turtle River', 'Horne Pond',
#        'unnamed, tributary of Squaw Creek', 'Hiddenwood Lake',
#        'unnamed creek a trib. of Whitmore Creek',
#        'unnamed creek trib. of Whitmore Creek',
#        'unnamed creek a trib. of Crooked Creek',
#        'Sweet Briar Creek a trib. of the Heart',
#        'natural runoff, trib of McLaughlin Lake', 'Drain No. 29',
#        'McLaughlin Lake a trib of Pembina River',
#        'Unnamed source a trib of James River',
#        'unnamed tributary of Antelope Creek',
#        'unnamed tributary of the Cannonbal River',
#        'unnamed creek trib. of Lightning Creek.',
#        'unnamed creek trib. of Lightning Creek', 'Little Muddy Creek',
#        'unnamed source trib. of Pipestem River',
#        'Unnamed tributary of Rock Lake', 'Unnamed tributary to Rock lake',
#        'Unnamed tributary to Rock Lake', 'unnamed trib. of Burnt Creek',
#        'Little Missouri  River', 'Knife River & Elm Creek',
#        'Calio Coulee', 'Antelpoe Creek', 'unnamed intermittent streams',
#        'Unnamed intermittent streams.', 'Unnamed intermittent streams',
#        'Unnamed creek a Trib. of the Cannonball', 'Drainage Ditch',
#        'Cole Creek trib of the Red River',
#        'Unnamed creek a tributary of Cedar Creek',
#        'Des Lacs River a trib. of Souris River',
#        'Unnamed stream a trib of Cedar Creek',
#        'Unnamed Creek trib. of Timber Creek', 'Souris River/ Dam 83',
#        'Souris River/ Pond C', 'Souris River/ Dam 87',
#        'Souris River/Dam 96', 'Souris River/Dam 41',
#        'Souris River/Dam 320', 'Souris River/Dam 326',
#        'Souris River/ Dam 320', 'Souris River/Dam 332',
#        'Souris River/ Dam 326', 'Souris River/Dam 341',
#        'Souris River/Dam 357', 'Wild Rice River trib. of Red River',
#        'Wild Rice trib. of Red River', 'Lake Ordway',
#        'Tongue River a trib. of the Red River', 'Scorio Creek',
#        'Wieler Dam', 'Oak Ã¯Â¿Â½reek a trib. of Willow Creek',
#        'unnamed stream on the Forest River.',
#        'Weiler Dam a trib. of Tongue River',
#        'Elm River a trib. of the Red River', 'Valley City Lagoon',
#        'unnamed creek trib. of Painted Woods Ck.',
#        'North Branch of the Goose River',
#        'unnamed stream trib. of Forest River',
#        'unnamed creek trib. of the Green River', 'Lake Hoskins',
#        'unnamed creek trib of Frank Creek',
#        'Starkwater Coulee trib. of Devils Lake',
#        'unnamed creek trib. of Dutton Slough',
#        'unnamed creek trib. of Turtle Creek', 'Morris Creek',
#        'unnamed creek trib. of Knife River',
#        'Horse Creek, trib. to Little Missouri Ri',
#        'unnamed creek trib. of Porcupine Creek',
#        'unnamed creek trib. of the Heart river',
#        'unnamed creek trib. of Baher Creek',
#        'unnamed creek trib. of Bahr Creek', 'Un-named creek',
#        'unnamed creek trib. of S. Fork Green Riv',
#        'unnamed creek trib. of Big Meadow Marsh',
#        'Russian Slough Creek trib of Cedar Creek',
#        'unnamed creek trib. of Leaf on the Hill', 'Missouri river',
#        'Unnamed creek trib. of Missouri River',
#        'Lake Ashtabula trib. of the Red river',
#        'Cherry Creek trib. of Little Misouri',
#        'Square Butte Creek trib. of the Missouri',
#        'Skunk Coulee & flood detention dam #1',
#        'Skunk Coulee & flood detention #1',
#        'Unnamed creek a trib. of Sheyenne River',
#        'Jim Creek, trib. of Little Missouri',
#        'Heart River trib. of Missouri River',
#        'unnamed creek trib. of Kinneman Creek',
#        'Cottonwood Creek trib. of James River',
#        'unnamed creek trib. of Beaver Creek',
#        'unnamed creek trib. of Lone Tree Creek',
#        'Unnamed creek trib. of Lightning Creek', 'Five Mile Creek',
#        'Unnamed trib. of the Missouri River',
#        'Apple Creek East trib. of Missouri River',
#        'Cow Creek a trib. of the Heart River',
#        'Unnamed Creek trib. of Thirty Mile Creek', 'Lake Ibsen',
#        'unnamed creek trib. of Spring Creek',
#        'Unnamed Creek trib. of Whitetail Creek',
#        'ADM Ethanol Plant Ponds',
#        'Horse Tied Creek trib. of Missouri River',
#        'Unnamed creek trib. of S.Fork Smith Crk.',
#        'Little Knife River, trib. of Knife River',
#        'unnamed creek, trib of Bahr Creek',
#        'Unnamed creek trib. of Whitmore Creek',
#        'Whitmore Creek trib. of Cedar Creek',
#        'Unnamed creek trib. of East Fork Shell',
#        'Unnamed creek trib of Shell Creek',
#        'Unnamed stream trib. of S. Fork Maple R.',
#        'Unnamed creek trib. of Nelson Creek',
#        'Unnamed creek trib. of Willow Coulee',
#        'Burnt Creek, trib. of Missouri River', 'Frying Pan Lake',
#        'Goose River a trib. of the Red River',
#        'Willow Coulee (Creek) trib. of Red River',
#        'Maple River trib. of the Sheyenne River',
#        'Battle Creek trib. of the Missouri River',
#        'Cannon Ball River trib. of Missouri',
#        'Cannon Ball River trib. of Misssouri',
#        'Unnamed stream, trib. of Plum Creek',
#        'Unnamed stream trib. of Lightning Creek',
#        'Nelson Creek,trib. of the Missouri River',
#        'unnamed creek trib. of Cherry Creek',
#        'unnamed creek trib. of Powers Lake',
#        'Unnamed stream trib. of Ash Creek',
#        'Unnamed creek, trib toBranch Knife River',
#        'Unnamed stream trib. of Apple Creek',
#        'Unnamed stream trib. of Thirty Mile Ck.', 'Un-named wetland',
#        'Cottonwood Creek, Trib. of James River',
#        'Unnamed stream-trib. of the James River',
#        'Unnamed stream trib of Little Muddy Riv.', 'Spiritwood aquifer'],
#       dtype=object)

# %%
outdf['in_WaterSourceTypeCV'] = outdf.apply(lambda row: fixEmptyString(row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Ground Water', 'Surface Water', 'WaDE Unspecified'], dtype=object)

# %%
outdf['in_County'] = outdf.apply(lambda row: fixEmptyString(row['in_County']), axis=1)
outdf['in_County'].unique()
# Out:
# array(['McIntosh', 'McKenzie', 'Mercer', 'Ward', 'Williams', 'Oliver',
#        'Renville', 'Dickey', 'Sargent', 'Dunn', 'Grand Forks', 'McHenry',
#        'Logan', 'Grant', 'Pembina', 'McLean', 'Kidder', 'Bowman',
#        'Stutsman', 'Adams', 'LaMoure', 'Sioux', 'Morton', 'Mountrail',
#        'Griggs', 'Burleigh', 'Ransom', 'Bottineau', 'Steele', 'Billings',
#        'Divide', 'Burke', 'Benson', 'Cavalier', 'Wells', 'Emmons',
#        'Stark', 'Nelson', 'Cass', 'Eddy', 'Barnes', 'Towner', 'Walsh',
#        'Foster', 'Richland', 'Slope', 'Golden Valley', 'Traill',
#        'Hettinger', 'Rolette', 'Ramsey', 'Sheridan', 'Pierce'],
#       dtype=object)

# %%
outdf['in_SiteTypeCV'] = outdf.apply(lambda row: fixEmptyString(row['in_SiteTypeCV']), axis=1)
outdf['in_SiteTypeCV'].unique()
# Out:
# array(['WaDE Unspecified'], dtype=object)

# %%
outdf['in_AllocationLegalStatusCV'] = outdf.apply(lambda row: fixEmptyString(row['in_AllocationLegalStatusCV']), axis=1)
outdf['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Denied', 'Cancelled', 'InActive', 'Active', 'Deferred', 'Void',
#        'Held In Abeyance', 'WaDE Unspecified'], dtype=object)

# %%
outdf['in_BeneficialUseCategory'] = outdf.apply(lambda row: fixEmptyString(row['in_BeneficialUseCategory']), axis=1)
outdf['in_BeneficialUseCategory'].unique()
# Out:
# array(['Irrigation', 'Industrial', 'Rural Water', 'Fish and Wildlife',
#        'Recreation', 'Stock', 'Municipal', 'Multiple Use',
#        'Flood Control', 'Undefined', 'Power Generation', 'Domestic'],
#       dtype=object)

# %%
# in_Latitude & in_Longitude
outdf['in_Latitude'] = pd.to_numeric(outdf['in_Latitude'], errors='coerce').fillna(0)
outdf['in_Longitude'] = pd.to_numeric(outdf['in_Longitude'], errors='coerce').fillna(0)
outdf.head(1)
# Out:
#   WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0    ndwr0       NDwr_M1                 NDwr_V1             NDwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0   WaDE Unspecified                                Ground Water
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0      WaDE Unspecified      Centroid of Area  McIntosh           4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    46.11130     -99.78988
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite       in_SiteName  \
# 0                                                   POD  WaDE Unspecified
#
#   in_SiteNativeID in_SitePoint     in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0    POD13007302B               WaDE Unspecified         ND
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
#
#   in_AllocationChangeApplicationIndicator  \
# 0
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                                            0.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                     Denied                  4407
#
#             in_AllocationOwner in_AllocationPriorityDate  \
# 0  KETTERLING ROLAND  LORRAINE                  3/4/1991
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
#
#   in_AllocationTimeframeStart in_AllocationTypeCV  in_AllocationVolume_AF  \
# 0                                                                 0.00000
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0               Irrigation
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
#
#    in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                              0
#
#    in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0              0.00000
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
#
#                          in_WaterAllocationNativeURL
# 0  https://www.swc.nd.gov/info_edu/map_data_resou...

# %%
# Changing datatype of date fields to fit WaDE.
outdf['in_AllocationApplicationDate'] = pd.to_datetime(outdf['in_AllocationApplicationDate'], errors = 'coerce')
outdf['in_AllocationApplicationDate'] = pd.to_datetime(outdf["in_AllocationApplicationDate"].dt.strftime('%m/%d/%Y'))

outdf['in_AllocationExpirationDate'] = pd.to_datetime(outdf['in_AllocationExpirationDate'], errors = 'coerce')
outdf['in_AllocationExpirationDate'] = pd.to_datetime(outdf["in_AllocationExpirationDate"].dt.strftime('%m/%d/%Y'))

outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf['in_AllocationPriorityDate'], errors = 'coerce')
outdf['in_AllocationPriorityDate'] = pd.to_datetime(outdf["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
outdf.head()
# Out:
#    WaDEUUID in_MethodUUID in_VariableSpecificUUID in_OrganizationUUID  \
# 0     ndwr0       NDwr_M1                 NDwr_V1             NDwr_O1
# 1     ndwr1       NDwr_M1                 NDwr_V1             NDwr_O1
# 2    ndwr10       NDwr_M1                 NDwr_V1             NDwr_O1
# 3   ndwr100       NDwr_M1                 NDwr_V1             NDwr_O1
# 4  ndwr1000       NDwr_M1                 NDwr_V1             NDwr_O1
#
#   in_Geometry in_GNISFeatureNameCV in_WaterQualityIndicatorCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_WaterSourceName in_WaterSourceNativeID in_WaterSourceTypeCV  \
# 0   WaDE Unspecified                                Ground Water
# 1   WaDE Unspecified                               Surface Water
# 2   WaDE Unspecified                               Surface Water
# 3   WaDE Unspecified                               Surface Water
# 4   WaDE Unspecified                               Surface Water
#
#   in_CoordinateAccuracy in_CoordinateMethodCV in_County  in_EPSGCodeCV  \
# 0      WaDE Unspecified      Centroid of Area  McIntosh           4326
# 1      WaDE Unspecified      Centroid of Area  McKenzie           4326
# 2      WaDE Unspecified      Centroid of Area    Mercer           4326
# 3      WaDE Unspecified      Centroid of Area      Ward           4326
# 4      WaDE Unspecified      Centroid of Area  Williams           4326
#
#   in_GNISCodeCV in_HUC12 in_HUC8  in_Latitude  in_Longitude  \
# 0                                    46.11130     -99.78988
# 1                                    48.02622    -103.75216
# 2                                    47.28288    -101.86756
# 3                                    48.33611    -101.46082
# 4                                    48.52694    -103.71934
#
#   in_NHDNetworkStatusCV in_NHDProductCV in_PODorPOUSite       in_SiteName  \
# 0                                                   POD  WaDE Unspecified
# 1                                                   POD  WaDE Unspecified
# 2                                                   POD  WaDE Unspecified
# 3                                                   POD  WaDE Unspecified
# 4                                                   POD  WaDE Unspecified
#
#   in_SiteNativeID in_SitePoint     in_SiteTypeCV in_StateCV in_USGSSiteID  \
# 0    POD13007302B               WaDE Unspecified         ND
# 1   POD15310236CC               WaDE Unspecified         ND
# 2   POD14408820BB               WaDE Unspecified         ND
# 3   POD15608415BD               WaDE Unspecified         ND
# 4   POD15810110AC               WaDE Unspecified         ND
#
#   in_AllocationApplicationDate in_AllocationAssociatedConsumptiveUseSiteIDs  \
# 0                          NaT
# 1                          NaT
# 2                          NaT
# 3                   1915-06-09
# 4                          NaT
#
#   in_AllocationAssociatedWithdrawalSiteIDs in_AllocationBasisCV  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationChangeApplicationIndicator  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationCommunityWaterSupplySystem in_AllocationCropDutyAmount  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationExpirationDate  in_AllocationFlow_CFS  \
# 0                         NaT                0.00000
# 1                         NaT                0.00000
# 2                         NaT                0.00000
# 3                         NaT               46.10000
# 4                  1994-02-09                0.00000
#
#   in_AllocationLegalStatusCV in_AllocationNativeID  \
# 0                     Denied                  4407
# 1                  Cancelled                    1E
# 2                  Cancelled                    8E
# 3                   InActive                   91C
# 4                  Cancelled                   902
#
#             in_AllocationOwner in_AllocationPriorityDate  \
# 0  KETTERLING ROLAND  LORRAINE                1991-03-04
# 1                HYDE GEORGE H                1901-08-15
# 2                SENERIUS FRED                1937-12-22
# 3   KUDA ALAN P and HUGHESKUDA                1915-06-09
# 4                   GREV HENRY                1961-04-10
#
#   in_AllocationSDWISIdentifierCV in_AllocationTimeframeEnd  \
# 0
# 1
# 2
# 3
# 4
#
#   in_AllocationTimeframeStart in_AllocationTypeCV  in_AllocationVolume_AF  \
# 0                                                                 0.00000
# 1                                                                 0.00000
# 2                                                                 0.00000
# 3                                                                17.00000
# 4                                                                 0.00000
#
#   in_BeneficialUseCategory in_CommunityWaterSupplySystem in_CropTypeCV  \
# 0               Irrigation
# 1               Irrigation
# 2               Irrigation
# 3               Irrigation
# 4               Irrigation
#
#   in_CustomerTypeCV in_DataPublicationDate in_DataPublicationDOI  \
# 0
# 1
# 2
# 3
# 4
#
#    in_ExemptOfVolumeFlowPriority in_GeneratedPowerCapacityMW  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
#
#    in_IrrigatedAcreage in_IrrigationMethodCV in_LegacyAllocationIDs  \
# 0              0.00000
# 1              0.00000
# 2              0.00000
# 3              8.50000
# 4              0.00000
#
#   in_OwnerClassificationCV in_PopulationServed in_PowerType  \
# 0
# 1
# 2
# 3
# 4
#
#   in_PrimaryBeneficialUseCategory in_SDWISIdentifierCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://www.swc.nd.gov/info_edu/map_data_resou...
# 1  https://www.swc.nd.gov/info_edu/map_data_resou...
# 2  https://www.swc.nd.gov/info_edu/map_data_resou...
# 3  https://www.swc.nd.gov/info_edu/map_data_resou...
# 4  https://www.swc.nd.gov/info_edu/map_data_resou...

# %%
outdf['in_AllocationTimeframeEnd'] = pd.to_datetime(outdf['in_AllocationTimeframeEnd'], errors = 'coerce')
outdf['in_AllocationTimeframeEnd'] = outdf["in_AllocationTimeframeEnd"].dt.strftime('%m/%d')
outdf['in_AllocationTimeframeEnd'].unique()
# Out:
# array([nan, '10/15', '06/15', '04/01', '05/15', '05/01'], dtype=object)

# %%
outdf['in_AllocationTimeframeStart'] = pd.to_datetime(outdf['in_AllocationTimeframeStart'], errors = 'coerce')
outdf['in_AllocationTimeframeStart'] = outdf["in_AllocationTimeframeStart"].dt.strftime('%m/%d')
outdf['in_AllocationTimeframeStart'].unique()
# Out:
# array([nan, '04/01'], dtype=object)

# %%
# Fixing in_AllocationFlow_CFS datatype
outdf['in_AllocationFlow_CFS'] = pd.to_numeric(outdf['in_AllocationFlow_CFS'], errors='coerce').fillna(0)
outdf['in_AllocationFlow_CFS'].unique()
# Out:
# array([0.000000e+00, 4.610000e+01, 6.500000e+03, 1.750000e+02,
#        3.000000e+02, 8.750000e+01, 8.000000e+02, 1.174000e+03,
#        1.671000e+03, 2.000000e+01, 2.445000e+03, 8.500000e+02,
#        4.000000e+02, 4.500000e+01, 7.000000e+02, 1.600000e+03,
#        1.050000e+03, 3.500000e+02, 2.450000e+03, 9.000000e+02,
#        1.000000e+03, 8.010000e+03, 2.000000e+02, 4.760000e+02,
#        9.000000e+01, 3.750000e+02, 1.500000e+01, 6.000000e+00,
#        5.000000e+03, 1.346400e+04, 4.250000e+02, 3.500000e+03,
#        9.500000e+02, 4.380000e+02, 2.500000e+02, 3.600000e+02,
#        1.850000e+03, 1.500000e+03, 5.000000e+02, 1.211700e+03,
#        1.240000e+03, 1.890000e+02, 2.500000e+03, 5.190000e+02,
#        5.000000e+01, 8.750000e+02, 7.300000e+01, 1.000000e+02,
#        7.500000e+02, 5.830000e+01, 1.200000e+03, 8.250000e+02,
#        1.200000e+01, 4.450000e+03, 1.950000e+03, 1.585000e+03,
#        6.500000e+02, 4.500000e+02, 2.250000e+03, 1.347000e+03,
#        1.346000e+03, 1.346000e+04, 9.520000e+02, 2.150000e+02,
#        3.500000e+01, 6.000000e+01, 2.000000e+03, 1.050190e+04,
#        3.000000e+00, 6.550000e+02, 4.937130e+03, 1.962000e+03,
#        6.850000e+02, 6.000000e+02, 6.732000e+03, 9.300000e+02,
#        1.900000e+03, 1.122000e+04, 1.500000e+02, 2.850000e+02,
#        8.976000e+03, 4.000000e+01, 1.260000e+04, 3.600000e+03,
#        6.230000e+02, 1.300000e+03, 8.317000e+02, 7.729000e+02,
#        4.500000e+03, 3.000000e+03, 3.200000e+02, 4.970000e+03,
#        1.330000e+02, 4.488000e+02, 5.950000e+02, 1.800000e+02,
#        2.400000e+03, 4.910000e+02, 1.800000e+03, 2.900000e+03,
#        7.800000e+01, 1.680000e+03, 2.700000e+03, 6.750000e+02,
#        1.350000e+03, 1.750000e+03, 1.100000e+03, 4.306000e+03,
#        8.100000e+02, 8.030000e+02, 4.000000e+03, 5.830000e+02,
#        5.834400e+03, 1.250000e+02, 5.800000e+02, 2.815000e+03,
#        3.062000e+03, 2.692800e+03, 2.600000e+03, 2.200000e+03,
#        1.239900e+04, 6.700000e+02, 1.200000e+02, 1.250000e+03,
#        7.000000e+03, 1.700000e+03, 1.340000e+02, 1.050000e+02,
#        4.490000e+02, 1.450000e+03, 2.300000e+02, 6.250000e+03,
#        4.340000e+00, 2.100000e+03, 9.450000e+02, 2.080000e+02,
#        4.400000e+01, 7.200000e+02, 3.590400e+03, 9.250000e+02,
#        7.000000e+01, 2.700000e+01, 8.700000e+02, 2.245000e+03,
#        9.600000e+02, 2.250000e+02, 9.350000e+02, 8.850000e+02,
#        1.170000e+02, 4.488000e+03, 4.981680e+04, 3.250000e+02,
#        1.400000e+03, 1.920000e+03, 5.500000e+01, 4.475000e+02,
#        6.960000e+02, 4.960000e+02, 4.165000e+03, 7.287000e+03,
#        1.000000e+01, 7.440000e+02, 2.266700e+03, 3.571000e+03,
#        1.900000e+01, 3.700000e+03, 6.460000e+02, 1.480000e+03,
#        1.820000e+03, 1.167000e+03, 8.200000e+02, 5.400000e+03,
#        1.551000e+03, 1.300000e+02, 5.760000e+02, 1.047000e+02,
#        1.260000e+03, 3.006900e+03, 1.550000e+02, 3.688000e+03,
#        8.260000e+02, 4.700000e+02, 4.000000e+00, 7.180000e+02,
#        2.322000e+03, 7.900000e+02, 1.502000e+03, 1.300000e+01,
#        4.300000e+02, 1.211760e+04, 5.385000e+02, 1.350000e+04,
#        5.194000e+02, 8.700000e+01, 1.964000e+03, 1.600000e+02,
#        9.120000e+02, 9.680000e+02, 1.120000e+02, 1.070000e+02,
#        8.500000e+01, 9.100000e+02, 1.530000e+02, 3.864700e+03,
#        1.666000e+02, 1.667000e+02, 3.141600e+03, 1.875000e+02,
#        6.250000e+05, 1.000000e+00, 1.266000e+03, 8.400000e+02,
#        1.539000e+03, 9.900000e+01, 1.150000e+03, 8.976000e+02,
#        9.830000e+02, 5.400000e+02, 7.405700e+04, 5.834000e+03,
#        9.560000e+02, 9.000000e-01, 1.125000e+02, 1.100000e+01,
#        6.600000e+03, 1.800000e+04, 1.125000e+03, 6.866600e+03,
#        4.847000e+02, 1.391200e+03, 9.873600e+03, 4.936000e+02,
#        5.300000e+02, 2.800000e+03, 1.188200e+03, 1.400000e+02,
#        3.600000e+01, 1.700000e+01, 2.200000e+01, 2.900000e+01,
#        3.100000e+01, 1.464000e+02, 2.050000e+02, 3.850000e+02,
#        4.999180e+05, 3.660000e+01, 7.500000e+01, 2.500000e+00,
#        5.000000e-01, 3.300000e+01, 6.500000e+01, 1.625000e+02,
#        4.488300e+03, 1.710000e+02, 1.700000e+02, 8.000000e+01,
#        2.334000e+02, 2.333000e+02, 1.100000e+02, 3.000000e+01,
#        2.350000e+02, 7.200000e+03, 8.330000e+01, 4.937180e+05,
#        5.240000e+02, 5.245000e+02, 3.366000e+04, 4.500000e+04,
#        2.240000e+02, 2.244000e+04, 3.150000e+03, 1.040000e+02,
#        2.019600e+03, 2.244000e+03, 5.904000e+04, 2.244000e+05,
#        6.732000e+02, 3.483000e+02, 8.078000e+02, 3.074500e+04,
#        3.972156e+06, 8.645000e+03, 9.778000e+02, 9.777000e+02,
#        2.800000e+02, 7.600000e+02, 2.962000e+03, 3.464000e+04,
#        1.250000e+01, 3.375000e+02, 1.273000e+04, 6.000000e+03,
#        1.346000e+02, 1.120000e+03, 8.800000e+02, 2.813000e+02,
#        3.666700e+03, 3.666600e+03, 1.928000e+02, 9.829000e+02,
#        9.495000e+02, 9.200000e+02, 5.850000e+03, 6.250000e+02,
#        7.620000e+02, 3.825000e+02, 4.110000e+02, 2.240000e+03,
#        1.080000e+05, 1.575000e+03, 4.850000e+02, 1.980000e+02,
#        5.903000e+02, 5.175000e+03, 6.952000e+02, 8.548000e+02,
#        2.670000e+02, 2.660000e+02, 1.975000e+03, 8.334000e+02,
#        3.084000e+02, 3.083000e+02, 6.667000e+02, 6.666000e+02,
#        3.121000e+03, 3.700000e+02, 1.460000e+02, 5.472000e+02,
#        2.500000e+01, 9.999990e+04, 4.800000e+02, 3.455700e+03,
#        3.240400e+03, 6.030000e+02, 1.390000e+01, 1.530000e+03,
#        7.100000e+02, 9.500000e+01, 1.629600e+03, 1.629700e+03,
#        3.472000e+02, 9.000000e+03, 1.040000e+01, 3.470000e+02,
#        4.630000e+02, 2.220000e+01, 2.230000e+01, 6.750000e+03,
#        5.210000e+01, 1.160000e+03, 1.462500e+03, 2.667000e+02,
#        2.666000e+02, 5.000000e+05, 2.475000e+04, 3.330000e+01,
#        3.340000e+01, 2.967000e+02, 2.966000e+02, 6.100000e+02,
#        1.550000e+04, 8.050000e+02, 8.125000e+02, 2.244000e+02,
#        1.560000e+03, 1.524000e+03, 1.925000e+02, 2.300000e+03,
#        7.800000e+02, 1.615600e+03, 3.200000e+03, 1.952000e+02,
#        4.744000e+02, 4.750000e+02, 1.360000e+03, 1.110000e+02,
#        3.420000e+02, 4.470000e+02, 2.692000e+02, 5.667000e+02,
#        5.666000e+02, 3.115000e+02, 4.492000e+02, 6.333000e+02,
#        7.750000e+02, 4.128900e+03, 8.600000e+02, 1.480000e+04,
#        3.380000e+02, 6.428000e+02, 3.004000e+02, 5.043000e+02,
#        5.044000e+02, 8.330000e+02, 8.340000e+02, 4.050000e+02,
#        3.800000e+02, 3.300000e+02, 1.163000e+03, 9.240000e+02,
#        2.235000e+02, 8.889000e+02, 8.885000e+02, 2.222000e+02,
#        4.440000e+02, 4.444000e+02, 1.795200e+03, 6.900000e+02,
#        1.660000e+02, 5.500000e+02, 1.153800e+03, 2.019740e+04,
#        8.320000e+02, 2.805000e+02, 7.700000e+02, 8.575000e+02,
#        8.755000e+02, 2.800000e+01, 4.944000e+02, 6.600000e+02,
#        3.667000e+02, 2.401000e+02, 8.630000e+01, 8.620000e+01,
#        2.750000e+02, 5.750000e+02, 7.920000e+02, 4.900000e+02,
#        2.540000e+02, 9.360000e+02, 2.220000e+02, 5.600000e+01,
#        3.666000e+02, 5.660000e+02, 5.680000e+02, 3.050000e+02,
#        1.041700e+04, 2.233000e+02, 2.234000e+02, 5.200000e+02,
#        8.760000e+02, 1.178000e+03, 4.667000e+02, 4.666000e+02,
#        8.724000e+02, 6.425000e+02, 6.580000e+02, 4.039000e+02,
#        1.122000e+03, 9.210000e+02, 1.430000e+02, 1.420000e+02,
#        1.639200e+03, 1.639100e+03, 2.840000e+02, 5.600000e+02,
#        1.280000e+03, 2.710000e+02, 2.590000e+02, 2.700000e+02,
#        6.300000e+02, 1.795200e+04, 3.462000e+02, 3.461000e+02,
#        4.550000e+02, 5.900000e+02, 3.078000e+03, 9.910000e+02,
#        4.438000e+02, 4.437000e+02, 1.385000e+03, 5.560000e+02,
#        2.200000e+02, 5.063000e+02, 1.346400e+03, 4.480000e+02,
#        2.890000e+02, 5.500000e+04, 2.720000e+02, 1.062500e+03,
#        2.108000e+03, 8.310000e+02, 1.041600e+04, 1.709100e+03,
#        7.300000e+00, 8.350000e+02, 4.160000e+01, 1.450000e+02,
#        1.333000e+02, 7.250000e+02, 2.830000e+02, 3.013000e+03,
#        3.012000e+03, 3.130000e+01, 3.120000e+01, 5.250000e+01,
#        2.852000e+02, 9.548000e+02, 6.525000e+02, 7.410000e+01,
#        7.420000e+01, 2.950000e+02, 7.450000e+01, 1.080000e+03,
#        2.671000e+02, 3.820000e+02, 7.350000e+02, 4.680000e+01,
#        4.690000e+01, 3.010000e+02, 1.730000e+03, 4.200000e+01,
#        9.400000e+02, 2.400000e+02, 7.380000e+02, 1.047000e+03,
#        2.640000e+02, 2.650000e+02, 4.635000e+03, 1.720000e+02,
#        3.208000e+02, 1.600000e+01, 5.230000e+02, 1.000000e+04,
#        9.480000e+02, 7.100000e+03, 4.290000e+02, 6.710000e+02,
#        5.175000e+02, 5.000000e+00, 1.500000e+00, 2.200000e+00,
#        2.900000e+00, 6.210000e+02, 1.840000e+03, 2.992000e+02,
#        7.000000e+00, 1.496000e+02, 4.500000e+00, 7.530000e+02,
#        6.350000e+02, 2.000000e+00, 3.750000e+01, 1.333300e+03,
#        1.333400e+03, 1.800000e+00, 3.750000e+03, 3.360000e+04,
#        3.469220e+04, 1.730000e+04, 8.270000e+02, 7.200000e+01,
#        4.000000e-01, 6.283000e+03, 4.100000e+00, 5.625000e+03,
#        8.120000e+02, 7.100000e+00, 2.300000e+00, 4.670000e+01,
#        4.660000e+01, 9.873000e+02, 4.040000e+03, 5.900000e+00,
#        3.938000e+02, 1.130000e+01, 4.480000e+01, 1.260000e+01,
#        3.800000e+03, 1.350000e+02, 7.400000e+02, 5.160000e+01,
#        1.034000e+02, 2.580000e+02, 1.028000e+03, 9.850000e+02,
#        2.323000e+03, 8.880000e+02, 1.032000e+03, 1.110000e+03,
#        1.190000e+02, 4.622000e+02, 1.320000e+02, 9.750000e+02,
#        1.054200e+03, 9.900000e+02, 1.054100e+03, 2.480000e+02,
#        6.200000e+01, 1.666700e+04, 9.280000e+02, 1.092000e+03,
#        2.915000e+03, 3.334000e+02, 3.333000e+02, 1.021000e+03,
#        7.840000e+01, 4.450000e+01, 1.400000e+01, 4.200000e+02,
#        5.900000e+01, 3.350000e+02, 3.900000e+02, 2.513280e+04,
#        1.260000e+02, 4.150000e+02, 1.417000e+02, 2.260000e+02,
#        6.832000e+02, 1.200000e+04, 1.416000e+02, 7.580000e+02,
#        1.750000e+01, 1.485000e+03, 3.150000e+02, 4.400000e+03,
#        3.490000e+02, 1.740000e+02, 1.003500e+03, 1.300000e+00,
#        4.640000e+03, 5.334000e+02, 5.333000e+02, 1.850000e+01,
#        2.679600e+03, 1.774100e+03, 9.055000e+02, 9.470000e+02,
#        2.394000e+03, 4.350000e+02, 1.077120e+04, 1.138000e+03,
#        1.249000e+03, 2.190000e+02, 6.400000e+03, 6.732000e+04,
#        2.503000e+03, 4.290000e+03, 6.050000e+02, 5.385600e+03,
#        5.834000e+02, 7.300000e+02, 1.125000e+04, 2.400000e+01,
#        1.019000e+03, 1.850000e+02, 1.077000e+03, 1.630000e+03,
#        8.450000e+02, 3.100000e+00, 1.500000e+04, 4.039200e+03,
#        1.041500e+03, 1.600000e+04, 1.933000e+02, 1.934000e+02,
#        8.938000e+02, 1.468700e+03, 8.160000e+02, 5.700000e+02,
#        2.836000e+03, 1.817600e+03, 1.880000e+03, 8.820000e+02,
#        4.380000e+01, 5.390000e+02, 5.650000e+02, 2.920000e+01,
#        7.570000e+02, 3.650000e+01, 6.340000e+02, 6.330000e+02,
#        8.970000e+01, 6.950000e+02, 6.800000e+01, 8.150000e+02,
#        9.451000e+02, 1.071000e+02, 1.072000e+02, 1.062000e+02,
#        7.550000e+02, 8.300000e+02, 2.920000e+02, 1.960000e+03,
#        1.170000e+03, 4.000000e+04, 3.631300e+03, 1.120700e+03,
#        5.920000e+02, 9.730000e+02, 3.400000e+03, 6.670000e+02,
#        4.780000e+02, 9.096000e+02, 1.365000e+03, 2.690000e+03,
#        5.390000e+01, 1.377000e+03, 7.950000e+02, 4.575000e+02,
#        9.150000e+02, 4.286000e+02, 8.650000e+02, 1.655000e+03,
#        7.850000e+02, 4.235300e+03, 1.569000e+03, 2.536000e+02,
#        5.610000e+01, 6.730000e+02, 3.425000e+03, 1.890000e+03,
#        2.625000e+03, 8.230000e+02, 4.670000e+02, 8.550000e+02,
#        4.200000e+03, 1.754000e+02, 7.197000e+02, 1.852000e+02,
#        2.910000e+02, 1.230000e+03, 2.160000e+02, 1.760000e+03,
#        1.620000e+03, 1.275000e+03, 8.860000e+02, 3.300000e+04,
#        6.283200e+03, 2.150000e+03, 1.960000e+01, 2.230000e+02,
#        1.125000e+01, 2.110000e+02, 3.400000e+02, 3.200000e+04,
#        9.700000e+02, 5.800000e+00, 1.800000e+01, 8.660000e+02,
#        2.566000e+03, 4.310000e+02, 1.032600e+03, 4.600000e+01,
#        2.120000e+02, 1.450000e+01, 7.330000e+02, 2.440000e+02,
#        5.100000e+01, 4.398200e+03, 1.211800e+03, 1.267000e+03,
#        2.125000e+03, 2.175000e+03, 1.458000e+03, 1.550000e+01,
#        1.860000e+00, 2.470000e+03, 1.234000e+03, 4.700000e+01,
#        9.125000e+02, 8.900000e+02, 1.380000e+03, 1.805600e+04,
#        1.160000e+02, 2.392000e+02, 3.155000e+03, 2.668000e+02,
#        2.435000e+03, 4.357000e+02, 8.000000e+03, 2.513200e+03,
#        5.280000e+02, 1.879000e+03, 5.300000e+01, 1.770000e+02,
#        4.600000e+02, 1.165850e+03, 1.243800e+03, 7.220000e+02,
#        1.134000e+03, 3.200000e+01, 1.105000e+03, 1.240000e+02,
#        9.050000e+02, 9.310000e+02, 2.782600e+03])

# %%
# Fixing in_AllocationVolume_AF datatype
outdf['in_AllocationVolume_AF'] = pd.to_numeric(outdf['in_AllocationVolume_AF'], errors='coerce').fillna(0)
outdf['in_AllocationVolume_AF'].unique()
# Out:
# array([   0.  ,   17.  , 1858.  , ..., 4480.  ,  193.05,  871.  ])

# %%
# Fixing in_IrrigatedAcreage datatype
outdf['in_IrrigatedAcreage'] = pd.to_numeric(outdf['in_IrrigatedAcreage'], errors='coerce').fillna(0)
outdf['in_IrrigatedAcreage'].unique()
# Out:
# array([  0. ,   8.5, 929. , ..., 142.2, 258.3, 350.1])

# %%
# %%time

# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "wadeID" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = outdf['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = outdf['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceName'] == A) & 
                                       (dfWaterSourceNativeID['in_WaterSourceTypeCV'] == B), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

outdf['in_WaterSourceNativeID'] = outdf.apply(lambda row: retrieveWaterSourceNativeID(row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
outdf['in_WaterSourceNativeID'].unique()
# Out:
# Wall time: 4.79 s
# array(['wadeID1', 'wadeID2', 'wadeID3', 'wadeID4', 'wadeID5', 'wadeID6',
#        'wadeID7', 'wadeID8', 'wadeID9', 'wadeID10', 'wadeID11',
#        'wadeID12', 'wadeID13', 'wadeID14', 'wadeID15', 'wadeID16',
#        'wadeID17', 'wadeID18', 'wadeID19', 'wadeID20', 'wadeID21',
#        'wadeID22', 'wadeID23', 'wadeID24', 'wadeID25', 'wadeID26',
#        'wadeID27', 'wadeID28', 'wadeID29', 'wadeID30', 'wadeID31',
#        'wadeID32', 'wadeID33', 'wadeID34', 'wadeID35', 'wadeID36',
#        'wadeID37', 'wadeID38', 'wadeID39', 'wadeID40', 'wadeID41',
#        'wadeID42', 'wadeID43', 'wadeID44', 'wadeID45', 'wadeID46',
#        'wadeID47', 'wadeID48', 'wadeID49', 'wadeID50', 'wadeID51',
#        'wadeID52', 'wadeID53', 'wadeID54', 'wadeID55', 'wadeID56',
#        'wadeID57', 'wadeID58', 'wadeID59', 'wadeID60', 'wadeID61',
#        'wadeID62', 'wadeID63', 'wadeID64', 'wadeID65', 'wadeID66',
#        'wadeID67', 'wadeID68', 'wadeID69', 'wadeID70', 'wadeID71',
#        'wadeID72', 'wadeID73', 'wadeID74', 'wadeID75', 'wadeID76',
#        'wadeID77', 'wadeID78', 'wadeID79', 'wadeID80', 'wadeID81',
#        'wadeID82', 'wadeID83', 'wadeID84', 'wadeID85', 'wadeID86',
#        'wadeID87', 'wadeID88', 'wadeID89', 'wadeID90', 'wadeID91',
#        'wadeID92', 'wadeID93', 'wadeID94', 'wadeID95', 'wadeID96',
#        'wadeID97', 'wadeID98', 'wadeID99', 'wadeID100', 'wadeID101',
#        'wadeID102', 'wadeID103', 'wadeID104', 'wadeID105', 'wadeID106',
#        'wadeID107', 'wadeID108', 'wadeID109', 'wadeID110', 'wadeID111',
#        'wadeID112', 'wadeID113', 'wadeID114', 'wadeID115', 'wadeID116',
#        'wadeID117', 'wadeID118', 'wadeID119', 'wadeID120', 'wadeID121',
#        'wadeID122', 'wadeID123', 'wadeID124', 'wadeID125', 'wadeID126',
#        'wadeID127', 'wadeID128', 'wadeID129', 'wadeID130', 'wadeID131',
#        'wadeID132', 'wadeID133', 'wadeID134', 'wadeID135', 'wadeID136',
#        'wadeID137', 'wadeID138', 'wadeID139', 'wadeID140', 'wadeID141',
#        'wadeID142', 'wadeID143', 'wadeID144', 'wadeID145', 'wadeID146',
#        'wadeID147', 'wadeID148', 'wadeID149', 'wadeID150', 'wadeID151',
#        'wadeID152', 'wadeID153', 'wadeID154', 'wadeID155', 'wadeID156',
#        'wadeID157', 'wadeID158', 'wadeID159', 'wadeID160', 'wadeID161',
#        'wadeID162', 'wadeID163', 'wadeID164', 'wadeID165', 'wadeID166',
#        'wadeID167', 'wadeID168', 'wadeID169', 'wadeID170', 'wadeID171',
#        'wadeID172', 'wadeID173', 'wadeID174', 'wadeID175', 'wadeID176',
#        'wadeID177', 'wadeID178', 'wadeID179', 'wadeID180', 'wadeID181',
#        'wadeID182', 'wadeID183', 'wadeID184', 'wadeID185', 'wadeID186',
#        'wadeID187', 'wadeID188', 'wadeID189', 'wadeID190', 'wadeID191',
#        'wadeID192', 'wadeID193', 'wadeID194', 'wadeID195', 'wadeID196',
#        'wadeID197', 'wadeID198', 'wadeID199', 'wadeID200', 'wadeID201',
#        'wadeID202', 'wadeID203', 'wadeID204', 'wadeID205', 'wadeID206',
#        'wadeID207', 'wadeID208', 'wadeID209', 'wadeID210', 'wadeID211',
#        'wadeID212', 'wadeID213', 'wadeID214', 'wadeID215', 'wadeID216',
#        'wadeID217', 'wadeID218', 'wadeID219', 'wadeID220', 'wadeID221',
#        'wadeID222', 'wadeID223', 'wadeID224', 'wadeID225', 'wadeID226',
#        'wadeID227', 'wadeID228', 'wadeID229', 'wadeID230', 'wadeID231',
#        'wadeID232', 'wadeID233', 'wadeID234', 'wadeID235', 'wadeID236',
#        'wadeID237', 'wadeID238', 'wadeID239', 'wadeID240', 'wadeID241',
#        'wadeID242', 'wadeID243', 'wadeID244', 'wadeID245', 'wadeID246',
#        'wadeID247', 'wadeID248', 'wadeID249', 'wadeID250', 'wadeID251',
#        'wadeID252', 'wadeID253', 'wadeID254', 'wadeID255', 'wadeID256',
#        'wadeID257', 'wadeID258', 'wadeID259', 'wadeID260', 'wadeID261',
#        'wadeID262', 'wadeID263', 'wadeID264', 'wadeID265', 'wadeID266',
#        'wadeID267', 'wadeID268', 'wadeID269', 'wadeID270', 'wadeID271',
#        'wadeID272', 'wadeID273', 'wadeID274', 'wadeID275', 'wadeID276',
#        'wadeID277', 'wadeID278', 'wadeID279', 'wadeID280', 'wadeID281',
#        'wadeID282', 'wadeID283', 'wadeID284', 'wadeID285', 'wadeID286',
#        'wadeID287', 'wadeID288', 'wadeID289', 'wadeID290', 'wadeID291',
#        'wadeID292', 'wadeID293', 'wadeID294', 'wadeID295', 'wadeID296',
#        'wadeID297', 'wadeID298', 'wadeID299', 'wadeID300', 'wadeID301',
#        'wadeID302', 'wadeID303', 'wadeID304', 'wadeID305', 'wadeID306',
#        'wadeID307', 'wadeID308', 'wadeID309', 'wadeID310', 'wadeID311',
#        'wadeID312', 'wadeID313', 'wadeID314', 'wadeID315', 'wadeID316',
#        'wadeID317', 'wadeID318', 'wadeID319', 'wadeID320', 'wadeID321',
#        'wadeID322', 'wadeID323', 'wadeID324', 'wadeID325', 'wadeID326',
#        'wadeID327', 'wadeID328', 'wadeID329', 'wadeID330', 'wadeID331',
#        'wadeID332', 'wadeID333', 'wadeID334', 'wadeID335', 'wadeID336',
#        'wadeID337', 'wadeID338', 'wadeID339', 'wadeID340', 'wadeID341',
#        'wadeID342', 'wadeID343', 'wadeID344', 'wadeID345', 'wadeID346',
#        'wadeID347', 'wadeID348', 'wadeID349', 'wadeID350', 'wadeID351',
#        'wadeID352', 'wadeID353', 'wadeID354', 'wadeID355', 'wadeID356',
#        'wadeID357', 'wadeID358', 'wadeID359', 'wadeID360', 'wadeID361',
#        'wadeID362', 'wadeID363', 'wadeID364', 'wadeID365', 'wadeID366',
#        'wadeID367', 'wadeID368', 'wadeID369', 'wadeID370', 'wadeID371',
#        'wadeID372', 'wadeID373', 'wadeID374', 'wadeID375', 'wadeID376',
#        'wadeID377', 'wadeID378', 'wadeID379', 'wadeID380', 'wadeID381',
#        'wadeID382', 'wadeID383', 'wadeID384', 'wadeID385', 'wadeID386',
#        'wadeID387', 'wadeID388', 'wadeID389', 'wadeID390', 'wadeID391',
#        'wadeID392', 'wadeID393', 'wadeID394', 'wadeID395', 'wadeID396',
#        'wadeID397', 'wadeID398', 'wadeID399', 'wadeID400', 'wadeID401',
#        'wadeID402', 'wadeID403', 'wadeID404', 'wadeID405', 'wadeID406',
#        'wadeID407', 'wadeID408', 'wadeID409', 'wadeID410', 'wadeID411',
#        'wadeID412', 'wadeID413', 'wadeID414', 'wadeID415', 'wadeID416',
#        'wadeID417', 'wadeID418', 'wadeID419', 'wadeID420', 'wadeID421',
#        'wadeID422', 'wadeID423', 'wadeID424', 'wadeID425', 'wadeID426',
#        'wadeID427', 'wadeID428', 'wadeID429', 'wadeID430', 'wadeID431',
#        'wadeID432', 'wadeID433', 'wadeID434', 'wadeID435', 'wadeID436',
#        'wadeID437', 'wadeID438', 'wadeID439', 'wadeID440', 'wadeID441',
#        'wadeID442', 'wadeID443', 'wadeID444', 'wadeID445', 'wadeID446',
#        'wadeID447', 'wadeID448', 'wadeID449', 'wadeID450', 'wadeID451',
#        'wadeID452', 'wadeID453', 'wadeID454', 'wadeID455', 'wadeID456',
#        'wadeID457', 'wadeID458', 'wadeID459', 'wadeID460', 'wadeID461',
#        'wadeID462', 'wadeID463', 'wadeID464', 'wadeID465', 'wadeID466',
#        'wadeID467', 'wadeID468', 'wadeID469', 'wadeID470', 'wadeID471',
#        'wadeID472', 'wadeID473', 'wadeID474', 'wadeID475', 'wadeID476',
#        'wadeID477', 'wadeID478', 'wadeID479', 'wadeID480', 'wadeID481',
#        'wadeID482', 'wadeID483', 'wadeID484', 'wadeID485', 'wadeID486',
#        'wadeID487', 'wadeID488', 'wadeID489', 'wadeID490', 'wadeID491',
#        'wadeID492', 'wadeID493', 'wadeID494', 'wadeID495', 'wadeID496',
#        'wadeID497', 'wadeID498', 'wadeID499', 'wadeID500', 'wadeID501',
#        'wadeID502', 'wadeID503', 'wadeID504', 'wadeID505', 'wadeID506',
#        'wadeID507', 'wadeID508', 'wadeID509', 'wadeID510', 'wadeID511',
#        'wadeID512', 'wadeID513', 'wadeID514', 'wadeID515', 'wadeID516',
#        'wadeID517', 'wadeID518', 'wadeID519', 'wadeID520', 'wadeID521',
#        'wadeID522', 'wadeID523', 'wadeID524', 'wadeID525', 'wadeID526',
#        'wadeID527', 'wadeID528', 'wadeID529', 'wadeID530', 'wadeID531',
#        'wadeID532', 'wadeID533', 'wadeID534', 'wadeID535', 'wadeID536',
#        'wadeID537', 'wadeID538', 'wadeID539', 'wadeID540', 'wadeID541',
#        'wadeID542', 'wadeID543', 'wadeID544', 'wadeID545', 'wadeID546',
#        'wadeID547', 'wadeID548', 'wadeID549', 'wadeID550', 'wadeID551',
#        'wadeID552', 'wadeID553', 'wadeID554', 'wadeID555', 'wadeID556',
#        'wadeID557', 'wadeID558', 'wadeID559', 'wadeID560', 'wadeID561',
#        'wadeID562', 'wadeID563', 'wadeID564', 'wadeID565', 'wadeID566',
#        'wadeID567', 'wadeID568', 'wadeID569', 'wadeID570', 'wadeID571',
#        'wadeID572', 'wadeID573', 'wadeID574', 'wadeID575', 'wadeID576',
#        'wadeID577', 'wadeID578', 'wadeID579', 'wadeID580', 'wadeID581',
#        'wadeID582', 'wadeID583', 'wadeID584', 'wadeID585', 'wadeID586',
#        'wadeID587', 'wadeID588', 'wadeID589', 'wadeID590', 'wadeID591',
#        'wadeID592', 'wadeID593', 'wadeID594', 'wadeID595', 'wadeID596',
#        'wadeID597', 'wadeID598', 'wadeID599', 'wadeID600', 'wadeID601',
#        'wadeID602', 'wadeID603', 'wadeID604', 'wadeID605', 'wadeID606',
#        'wadeID607', 'wadeID608', 'wadeID609', 'wadeID610', 'wadeID611',
#        'wadeID612', 'wadeID613', 'wadeID614', 'wadeID615', 'wadeID616',
#        'wadeID617', 'wadeID618', 'wadeID619', 'wadeID620', 'wadeID621',
#        'wadeID622', 'wadeID623', 'wadeID624', 'wadeID625', 'wadeID626'],
#       dtype=object)

# %% [markdown]
# # Export the Output

# %%
#technique to check datatype of long dataframes.
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(outdf.dtypes)
# Out:
# WaDEUUID                                                object
# in_MethodUUID                                           object
# in_VariableSpecificUUID                                 object
# in_OrganizationUUID                                     object
# in_Geometry                                             object
# in_GNISFeatureNameCV                                    object
# in_WaterQualityIndicatorCV                              object
# in_WaterSourceName                                      object
# in_WaterSourceNativeID                                  object
# in_WaterSourceTypeCV                                    object
# in_CoordinateAccuracy                                   object
# in_CoordinateMethodCV                                   object
# in_County                                               object
# in_EPSGCodeCV                                            int64
# in_GNISCodeCV                                           object
# in_HUC12                                                object
# in_HUC8                                                 object
# in_Latitude                                            float64
# in_Longitude                                           float64
# in_NHDNetworkStatusCV                                   object
# in_NHDProductCV                                         object
# in_PODorPOUSite                                         object
# in_SiteName                                             object
# in_SiteNativeID                                         object
# in_SitePoint                                            object
# in_SiteTypeCV                                           object
# in_StateCV                                              object
# in_USGSSiteID                                           object
# in_AllocationApplicationDate                    datetime64[ns]
# in_AllocationAssociatedConsumptiveUseSiteIDs            object
# in_AllocationAssociatedWithdrawalSiteIDs                object
# in_AllocationBasisCV                                    object
# in_AllocationChangeApplicationIndicator                 object
# in_AllocationCommunityWaterSupplySystem                 object
# in_AllocationCropDutyAmount                             object
# in_AllocationExpirationDate                     datetime64[ns]
# in_AllocationFlow_CFS                                  float64
# in_AllocationLegalStatusCV                              object
# in_AllocationNativeID                                   object
# in_AllocationOwner                                      object
# in_AllocationPriorityDate                       datetime64[ns]
# in_AllocationSDWISIdentifierCV                          object
# in_AllocationTimeframeEnd                               object
# in_AllocationTimeframeStart                             object
# in_AllocationTypeCV                                     object
# in_AllocationVolume_AF                                 float64
# in_BeneficialUseCategory                                object
# in_CommunityWaterSupplySystem                           object
# in_CropTypeCV                                           object
# in_CustomerTypeCV                                       object
# in_DataPublicationDate                                  object
# in_DataPublicationDOI                                   object
# in_ExemptOfVolumeFlowPriority                            int64
# in_GeneratedPowerCapacityMW                             object
# in_IrrigatedAcreage                                    float64
# in_IrrigationMethodCV                                   object
# in_LegacyAllocationIDs                                  object
# in_OwnerClassificationCV                                object
# in_PopulationServed                                     object
# in_PowerType                                            object
# in_PrimaryBeneficialUseCategory                         object
# in_SDWISIdentifierCV                                    object
# in_WaterAllocationNativeURL                             object
# dtype: object

# %%
# Export the output dataframe
outdf.to_csv('Pwr_ndMain.zip', index=False, compression="zip")  # The output, save as a zip
#dfPoUshape.to_csv('P_Geometry.zip', compression=dict(method='zip', archive_name='P_Geometry.csv'), index=False)  # The output geometry.
