# %% [markdown]
# # Pre-processing North Dakaota Allocation data for WaDEQA upload.
# Date Updated: 03/28/2023
# Purpose:  To pre-process the ND data into one master file for simple DataFrame creation and extraction

# %%
#Needed Libararies

# working with data
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# visulizaiton
import matplotlib.pyplot as plt
import seaborn as sns

# API retrieval
import requests
import json

# Cleanup
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.set_option('display.float_format', lambda x: '%.5f' % x) # suppress scientific notation in Pandas

# %%
# Working Directory
workingDir = "G:/Shared drives/WaDE Data/NorthDakota/WaterAllocation/RawInputData"
os.chdir(workingDir)

# %% [markdown]
# ## Data: Permit

# %%
# Input File
fileInput = "Permits_input.csv"
df = pd.read_csv(fileInput, encoding = "ISO-8859-1").replace(np.nan, "")

# WaDE UUID tracker for data assessment
if 'WaDEUUID' not in df:
    df['WaDEUUID'] = "ndwr" + df.index.astype(str)
    df.to_csv('Permits_input.csv', index=False)

print(len(df))
df.head(1)
# Out:
# 12181
#   WaDEUUID ReasonRemoved IncompleteField  permit_ind permit_num  pod_index  \
# 0    ndwr0                                         1       4407          1
#
#          pod                     permit_hol priority_d    use_type  status  \
# 0  13007302B  KETTERLING, ROLAND & LORRAINE   3/4/1991  Irrigation  Denied
#
#   date_issue date_cance  beneficial    county hu_sub_bas aquifer subaquifer  \
# 0                        1111-11-11  McIntosh     Beaver
#
#    req_acft  req_acre   req_rate  req_storag  app_acft  app_acre  app_rate  \
# 0 204.00000 135.20000 1000.00000     0.00000   0.00000   0.00000   0.00000
#
#    app_storag pod_status        source irrigation source_nam  mainstem  \
# 0     0.00000     Denied  Ground Water  Sprinkler                    0
#
#   impound_lo impound_na return_des discharge_ period_sta period_end  \
# 0
#
#    return_qua  held_acft  held_acre  held_rate  held_stora  longitude  \
# 0           0    0.00000    0.00000    0.00000     0.00000  -99.78988
#
#    latitude
# 0  46.11130

# %%
# swapping order owner name
import re

def createOwnerName(val):
    if val == "" or pd.isnull(val):
        outString = ""
    else:
        val = str(val)
        val = val.strip()
        if "," in val:
            x = val.split(",")
            outString = str(x[0]).strip() + " " + str(x[1]).strip()
        else:
            outString = val     
    return outString
df['in_AllocationOwner'] = df.apply(lambda row: createOwnerName(row['permit_hol']), axis=1)


def cleanOwnerDataFunc(Val):
    Val = re.sub("[$@&.;,/\)(-]", "", Val).strip()
    return Val
df['in_AllocationOwner'] = df.apply(lambda row: cleanOwnerDataFunc(row['in_AllocationOwner']), axis=1)
df['in_AllocationOwner'].unique()
# Out:
# array(['KETTERLING ROLAND  LORRAINE', 'HYDE GEORGE H', 'SENERIUS FRED',
#        ..., 'IGLEHART DOUG', 'BROTEN ERIC', 'NEW ROCKFORD CITY OF'],
#       dtype=object)

# %%
# Changing format to Title to clean up text.
df['source_nam'] = df['source_nam'].str.title()
df['source'] = df['source'].str.title()
df['permit_hol'] = df['permit_hol'].str.title()

# Removing white space from certain text fields to help clean up text.
df['source_nam'] = df['source_nam'].str.strip()
df['source'] = df['source'].str.strip()
df['permit_hol'] = df['permit_hol'].str.strip()

df['county'] = df['county'].str.strip()
df['aquifer'] = df['aquifer'].str.strip()
df['pod'] = df['pod'].str.strip()
df['status'] = df['status'].str.strip()
df['use_type'] = df['use_type'].str.strip()
df['permit_num'] = df['permit_num'].str.strip()
df.head()
# Out:
#    WaDEUUID ReasonRemoved IncompleteField  permit_ind permit_num  pod_index  \
# 0     ndwr0                                         1       4407          1
# 1     ndwr1                                         2         1E          2
# 2    ndwr10                                        11         8E         11
# 3   ndwr100                                        72        91C        102
# 4  ndwr1000                                       679        902       1047
#
#           pod                                  permit_hol  priority_d  \
# 0   13007302B               Ketterling, Roland & Lorraine    3/4/1991
# 1  15310236CC                             Hyde, George H.   8/15/1901
# 2  14408820BB                              Senerius, Fred  12/22/1937
# 3  15608415BD  Kuda, Alan P. And Hughes/Kuda, Kathleen A.    6/9/1915
# 4  15810110AC                                 Grev, Henry   4/10/1961
#
#      use_type     status date_issue date_cance  beneficial    county  \
# 0  Irrigation     Denied                        1111-11-11  McIntosh
# 1  Irrigation  Cancelled                                    McKenzie
# 2  Irrigation  Cancelled                         6/12/1938    Mercer
# 3  Irrigation  Perfected   6/9/1915               6/9/1919      Ward
# 4  Irrigation  Cancelled              2/9/1994    7/1/1967  Williams
#
#                           hu_sub_bas aquifer subaquifer  req_acft  req_acre  \
# 0                             Beaver                    204.00000 135.20000
# 1                     Lake Sakakawea                     80.00000  80.00000
# 2                              Knife                      0.00000   0.00000
# 3  Moose Mountain Creek-Souris River                     17.00000   8.50000
# 4                       Little Muddy                     50.00000  31.00000
#
#     req_rate  req_storag  app_acft  app_acre  app_rate  app_storag pod_status  \
# 0 1000.00000     0.00000   0.00000   0.00000   0.00000     0.00000     Denied
# 1  448.80000     0.00000   0.00000   0.00000   0.00000     0.00000  Cancelled
# 2    0.00000     0.00000   0.00000   0.00000   0.00000     0.00000  Cancelled
# 3   46.00000     0.00000  17.00000   8.50000  46.10000     0.00000   InActive
# 4 4488.00000     0.00000   0.00000   0.00000   0.00000     0.00000  Cancelled
#
#           source   irrigation source_nam  mainstem impound_lo impound_na  \
# 0   Ground Water    Sprinkler                    0
# 1  Surface Water  Combination                    1
# 2  Surface Water     Flooding                    0
# 3  Surface Water     Flooding                    1
# 4  Surface Water     Flooding                    0
#
#   return_des discharge_ period_sta period_end  return_qua  held_acft  \
# 0                                                       0    0.00000
# 1                                                       0    0.00000
# 2                                                       0    0.00000
# 3                                                       0    0.00000
# 4                                                       0    0.00000
#
#    held_acre  held_rate  held_stora  longitude  latitude  \
# 0    0.00000    0.00000     0.00000  -99.78988  46.11130
# 1    0.00000    0.00000     0.00000 -103.75216  48.02622
# 2    0.00000    0.00000     0.00000 -101.86756  47.28288
# 3    0.00000    0.00000     0.00000 -101.46082  48.33611
# 4    0.00000    0.00000     0.00000 -103.71934  48.52694
#
#             in_AllocationOwner
# 0  KETTERLING ROLAND  LORRAINE
# 1                HYDE GEORGE H
# 2                SENERIUS FRED
# 3   KUDA ALAN P and HUGHESKUDA
# 4                   GREV HENRY

# %%
df['in_WaterAllocationNativeURL'] = "https://www.swc.nd.gov/info_edu/map_data_resources/waterpermits/single.php?id=" + df['permit_ind'].astype(str)
df.head(1)
# Out:
#   WaDEUUID ReasonRemoved IncompleteField  permit_ind permit_num  pod_index  \
# 0    ndwr0                                         1       4407          1
#
#          pod                     permit_hol priority_d    use_type  status  \
# 0  13007302B  Ketterling, Roland & Lorraine   3/4/1991  Irrigation  Denied
#
#   date_issue date_cance  beneficial    county hu_sub_bas aquifer subaquifer  \
# 0                        1111-11-11  McIntosh     Beaver
#
#    req_acft  req_acre   req_rate  req_storag  app_acft  app_acre  app_rate  \
# 0 204.00000 135.20000 1000.00000     0.00000   0.00000   0.00000   0.00000
#
#    app_storag pod_status        source irrigation source_nam  mainstem  \
# 0     0.00000     Denied  Ground Water  Sprinkler                    0
#
#   impound_lo impound_na return_des discharge_ period_sta period_end  \
# 0
#
#    return_qua  held_acft  held_acre  held_rate  held_stora  longitude  \
# 0           0    0.00000    0.00000    0.00000     0.00000  -99.78988
#
#    latitude           in_AllocationOwner  \
# 0  46.11130  KETTERLING ROLAND  LORRAINE
#
#                          in_WaterAllocationNativeURL
# 0  https://www.swc.nd.gov/info_edu/map_data_resou...

# %%
# Creating the output Dataframe for PODs.

dfPOD = pd.DataFrame(index=df.index)

# Data Assessment UUID
dfPOD['WaDEUUID'] = df['WaDEUUID']

# Water Source
dfPOD["in_WaterSourceName"] = df['source_nam']
dfPOD["in_WaterSourceTypeCV"] = df['source']

# Site
dfPOD["in_CoordinateAccuracy"] = "WaDE Unspecified"
dfPOD["in_CoordinateMethodCV"] = "Centroid of Area"
dfPOD['in_HUC12'] = ""
dfPOD['in_HUC8'] = ""
dfPOD['in_County'] = df['county']
dfPOD["in_Latitude"] = df['latitude']
dfPOD["in_Longitude"] = df['longitude']
dfPOD["in_PODorPOUSite"] = "POD"
dfPOD["in_SiteName"] = "WaDE Unspecified"
dfPOD["in_SiteNativeID"] = "POD" + df['pod'].astype(str)
dfPOD["in_SiteTypeCV"] = "WaDE Unspecified"
dfPOD["in_StateCV"] = "ND"

# Allocation
dfPOD["in_AllocationApplicationDate"] = df['date_issue']
dfPOD["in_AllocationExpirationDate"] = df['date_cance']
dfPOD["in_AllocationFlow_CFS"] = df['req_rate'].astype(float)
dfPOD["in_AllocationVolume_AF"] = df['req_acft'].astype(float)
dfPOD['in_AllocationLegalStatusCV'] = df['pod_status'].astype(str)
dfPOD["in_AllocationNativeID"] = df['permit_num'].astype(str)
dfPOD['in_AllocationOwner'] = df['in_AllocationOwner']
dfPOD['in_AllocationPriorityDate'] = df['priority_d']
dfPOD['in_AllocationTimeframeEnd'] = df['period_end']
dfPOD['in_AllocationTimeframeStart'] = df['period_sta']
dfPOD['in_AllocationTypeCV'] = ""
dfPOD["in_BeneficialUseCategory"] = df['use_type']
dfPOD['in_CommunityWaterSupplySystem'] = ""
dfPOD['in_ExemptOfVolumeFlowPriority'] = "0"
dfPOD["in_IrrigatedAcreage"] = ""
dfPOD["in_IrrigationMethodCV"] = ""
dfPOD["in_WaterAllocationNativeURL"] = df['in_WaterAllocationNativeURL']

dfPOD = dfPOD.drop_duplicates().reset_index(drop=True)
print(len(dfPOD))
dfPOD.head(1)
# Out:
# 12181
#   WaDEUUID in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0    ndwr0                            Ground Water      WaDE Unspecified
#
#   in_CoordinateMethodCV in_HUC12 in_HUC8 in_County  in_Latitude  in_Longitude  \
# 0      Centroid of Area                   McIntosh     46.11130     -99.78988
#
#   in_PODorPOUSite       in_SiteName in_SiteNativeID     in_SiteTypeCV  \
# 0             POD  WaDE Unspecified    POD13007302B  WaDE Unspecified
#
#   in_StateCV in_AllocationApplicationDate in_AllocationExpirationDate  \
# 0         ND
#
#    in_AllocationFlow_CFS  in_AllocationVolume_AF in_AllocationLegalStatusCV  \
# 0             1000.00000               204.00000                     Denied
#
#   in_AllocationNativeID           in_AllocationOwner  \
# 0                  4407  KETTERLING ROLAND  LORRAINE
#
#   in_AllocationPriorityDate in_AllocationTimeframeEnd  \
# 0                  3/4/1991
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_BeneficialUseCategory  \
# 0                                                               Irrigation
#
#   in_CommunityWaterSupplySystem in_ExemptOfVolumeFlowPriority  \
# 0                                                           0
#
#   in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
#
#                          in_WaterAllocationNativeURL
# 0  https://www.swc.nd.gov/info_edu/map_data_resou...

# %% [markdown]
# ## WaDE Custom Elements (due to missing sate info)

# %%
# Fixing empty string names

def fixEmptyString(val):
    val = str(val).strip()
    if val == "" or val == " " or pd.isnull(val):
        outString = "WaDE Unspecified"
    else:
        outString = val
    return outString

# %%
dfPOD['in_WaterSourceName'] = dfPOD.apply(lambda row: fixEmptyString(row['in_WaterSourceName']), axis=1)
dfPOD['in_WaterSourceName'].unique()
# Out:
# array(['WaDE Unspecified', 'Unnamed Stream Trib. Of Little Muddy',
#        'Missouri River', 'Goschke Dam On Tongue River',
#        'Goshke Dam On Busse Coulee', 'Goschke Dam On Busse Coulee',
#        'Unnamed Tributary', 'Unamed Coulee Trib. Of Lower Des Lacs',
#        'Souris River', 'Flat Creek Trib. Of N. Fork Grand River',
#        'Cannonball River', 'Chimney Butte Creek',
#        'Unnamed Coulee Trib. Of The Heart River',
#        'Unnamed Coulee A Trib. Of T Heart River',
#        'Unnamed Creek, Trib Of Wolf Creek', 'Lake Sakakawea',
#        'Forest River', "Gibb'S Spring, Trib. Of Little Knife",
#        'White Earth Creek', 'Spring Creek, Trib. Of Knife River',
#        'Willow Creek', 'Little Bull Creek',
#        'Unnamed Tributary Of North Branch Park',
#        'Unnamed Creek, Trib.Of Stony Slough', 'Sheyene River',
#        'Unnamed Waterway, Trib Of Des Lacs River', 'Goschke Dam',
#        'Unnamed Creek, Trib. Of The Tongue River',
#        'Bussee Coulee, Trib. Of The Tongue River',
#        'Warwick Dam On Sheynne River',
#        'Unnamed Stream Trib. Of Heart River',
#        'Tongue River (Renwick Dam M-4)', 'Unnamed Creek', 'Apple Creek',
#        'Sheyenne Delta Aquifer', 'Heart River', 'Treated City Wastewater',
#        'James River, Fesenden Dam', 'Un-Named Trib To Square Butte Creek',
#        'Sheyenne River The Harvey Dam',
#        'Coal Mine Creek, Trib. Of Heart River', 'Park River',
#        'Unnamed Tributary To Knife River', 'Sheyenne River',
#        'Scab Creek, Trib To Big Muddy Creek',
#        'Unnamed Creek Trib. Of The Heart River', 'Beaver Creek',
#        'Lake Oahe', 'Unnamed Creek.',
#        'Unnamed Creek, Trib. Of The Heart River',
#        'Crooked Creek Tributary', 'Trenton Lake', 'Cedar Creek Tributary',
#        'Trib. Of Painted Woods Creek', 'Ranch Lake', 'Lake Margaret',
#        'Rats Coulee', 'Little South Pembina River',
#        'Unnamed Creek, Trib. Of Edmore Coulee',
#        'North Branch Of Garner Creek', 'Desmoines Lake',
#        'Unnamed Creek, Trib. Of Square Butte Ck.',
#        'Little Missouri River', 'Unnamed Creek Trib. Of Big Muddy Creek',
#        'Little Muddy River', 'Yellowstone River', 'Spring Creek',
#        'Goose River', 'Eightmile Creek', 'Unnamed Slough',
#        'Unnamed Stream Trib. Of Cannonball River', 'Unnamed Slough.',
#        'Green River', 'Red River Of The North', 'Pitt Creek Tributary',
#        'Square Butte Creel', 'Ground Water', 'Square Butte Creek',
#        'Burnt Creek Diversion', 'Trib. Of Crosby Creek', 'Crooked Creek',
#        'Tobacco Garden Creek', 'Hazen Brook',
#        'Southwest Pipeline Project',
#        'Spring - Trib. Of White Earth River', 'James River', 'Red River',
#        'The Pembina River', 'Painted Woods Creek', 'Sheynne River',
#        'Knife River', 'First Larson Coulee', 'Waste Water Logoons',
#        'Waste Water Lagoons', '4 Cell Lagoon System',
#        'Shallow Saturated Alluvium', 'Mauvais Coulee', 'Groundwater',
#        'Des Lac Lake', 'Trib. To The Wild Rice River', 'Hartel Dam',
#        'Puppy Dog Coulee', 'White Earth River', 'Oakes Pilot Drain',
#        'Jensen Dam', 'Unnamed Creek Trib Of Frank Creek', 'Fort Union',
#        'Sletten Lake', 'Sweet Briar Lake', 'Green River Tributary',
#        'Clear Creek', 'Cherry Creek', 'Dakota Group', 'Pembina River',
#        'Tongue River At Goschke Dam', 'Little Knife River Tributary',
#        'North Branch Turtle River', 'Strommen Stock Pond', 'Unnamed Lake',
#        'Antelope Creek', 'Unnamed Stream', 'Stone Creek',
#        'Trib. Of East Fork Shell Creek', 'Little Knife River',
#        'Little Antelope Creek', 'Canonball River', 'Dimmick Lake',
#        'Ephemeral Drainages', 'South Egg Creek', 'Camp Creek',
#        'Spring Creek Tributary', 'Bennett Creek', 'Un-Named Stock Pond',
#        'Un-Named Trib To Spring Creek', 'Unnamed Pond',
#        'Hagel Creek Tributary', 'Strommen Pond - Spring Creek Trib.',
#        "Pat'S Coulee, Trib. To Little Muddy",
#        'Strawberry, Crooked & Brekken Lakes',
#        'Strawberr, Crooked & Brekken Lakes',
#        'Strawberry, Crooked & Brekken', 'Unnamed', 'Cheyenne River',
#        'Horseshoe Lake', 'Holding Pond', 'Halfbreed Creek',
#        'Lake Upsilon', 'Lake Trenton', 'Little Stoney',
#        'Trib To Sqaure Butte Creek', 'North Branch Forest River',
#        'Unnamed Trib To Knife River', 'Tributary Of Crooked Creek',
#        'Shell Creek', 'Edmore Coulee', 'Cedar River', 'Muskrat Lake',
#        'Stoney Creek', 'Un-Named Creek, Tributary To Spring Cree',
#        'Otte Creek', 'Drain 11', 'East Buehner Pond', 'Jim Creek',
#        'Trib To Shirk Creek', 'Derudder Dam', 'Abbey Lake',
#        'Oxbow Of Stoney Creek', 'Lake Sakakawea-Backwater',
#        'Matejcek Reservoir', 'Lake Zahl', 'Frank Creek', 'Murphy Slough',
#        'Mcville', 'Runoff & Un-Named Trib To Knife River', 'Dry Creek',
#        'Unnamed Stream, Trib Of Little Muddy',
#        'Spring Creek & Un-Named Trib', 'Sweetbriar Creek',
#        'Middle Branch Forest River', 'Intermittent Draws', 'Tepee Creek',
#        'Trib To Otter Creek', 'South Branch Of Elm River',
#        'Big Muddy Creek', 'Lay Creek, Trib Of Tobacco Garden Creek',
#        'North Fork Grand River', 'Trib To Turtle Creek',
#        'Trib To Burnt Creek', 'Unnamed Channel',
#        'Unnamed Intermittent Draw', 'Wild Rice River',
#        'Unnamed Creek & Wild Rice River',
#        'Unamed Creek And Wild Rice River', 'Nelson Creek',
#        'Unnamed Coulee', 'Nelson Lake-Square Butte Creek', 'Cart Creek',
#        'Un-Named Trib To Sweet Briar Creek', 'Branch Knife River',
#        'Trib To Square Butte Creek', 'South Branch Goose River',
#        'Duck Creek', 'Wakopa Creek', 'Charbonneau Creek & Trib.',
#        'Unnamed Creek Trib To Willow Creek', 'Intermittent Creek',
#        'Elm River', 'Trib To Wild Rice River',
#        'English Coulee, Trib To Red River', 'Unnamed Intermittent Trib.',
#        'Big Coulee', 'Dry Draw', 'Tongue River',
#        'Int. Draw, Trib To Little Missouri River',
#        'Un-Named Inter Trib To Spring Creek', 'Horse Creek',
#        'Burnt Creek', 'Unnamed Coulee To Burnt Creek', 'Rush River',
#        'Buffalo Coulee', 'Tobacco Garden Cr & Missouri R Backwater',
#        'Andrews Creek', 'South Unit', 'Unnamed Intermittent Stream',
#        'Salt Water Coulee', 'Beaver Creek And Missouri River',
#        'Knifer River', 'Mt. Carmel Dam', 'Un-Named Intermittent Stream',
#        'Mouse River', 'Un Named Trib To Andrews Creek',
#        'Un-Named Stream, Trib. To Little Missour', 'Deep Creek',
#        'Un-Named Coulee, Tributary To Garrison R', 'Timber Creek',
#        'Unnamed Intermittent Draws', 'Charbonneau Creek', 'Bullion Creek',
#        'Little Creek', 'Mc Gillis Creek', 'Unnamed Draw',
#        'Intermittent Draws, Trib. To Little Miss',
#        'Big Muddy Creek And Intermittent Stream', 'Cottonwood Creek',
#        'Unnamed Creek, Tributary To Beaver Creek', 'Sand Creek',
#        'Unnamed Intermittent Streams', 'South Branch Of Turtle River',
#        'Apple Creek Tributary', 'Fourmile Creek', 'Gibb Springs',
#        'Sweetwater Lake', 'Mulberry Creek',
#        "Big Mary'S Coulee, Trib To Mouse River",
#        'Unnamed Coulee, Trib To Sheyeene River', 'Oxbow - Knife River',
#        'Unnamed Intermittant Draw',
#        'Spring Creek, A Trib Of The Knife River',
#        'Spring Creek, A Trib Of Knife River',
#        'Spring Creek, A Trib Of The Knife Rriver', 'Nelson Lake',
#        'Beaver Creek, Trib. To Little Missouri R', 'Annie Creek',
#        'Unnamed Trib. To Deep Creek', 'Tributary To West Hay Draw Creek',
#        'West Hay Draw Creek', 'Sheep Creek',
#        'Unnamed Trib To Souris River', 'Long Lake Creek',
#        'Unnamed Draw, Trib To Northfork Cr.',
#        'Box Elder Creek, Trib. To Little Missour', 'Stony Creek',
#        'Sweet Briar Creek', 'Willow Lake',
#        'Un-Named Coulee & Dry Fork Coulee', 'Sout Branch Turtle River',
#        'Goose Lake', 'Chanta Peta Creek', 'Pipestem Creek',
#        'Lonesome Creek', 'Iron Springs',
#        'Beaver Creek, Trib. To Little Misouri Ri',
#        'Un-Named Draw, Tributary To Missouri Riv',
#        'Knife River Tributary', 'Long Lake Creek & Slough',
#        'Gibbs Springs', 'Unnamed Trib. To North Fork Of The Grand',
#        'Unnamed Trib.', 'Cottonwood Lake',
#        'Un Named Creek - Trib To Missouri River', 'Little Beaver Creek',
#        'Maple River', 'Un-Named Trib To Cannonball River',
#        'Unnamed Stream, Trib. Of Crooked Creek',
#        'Starkweather Ã¯Â¿Â½Oulee', 'Old Oxbow Of Apple Creek',
#        'Buford Coulee', 'Bennie Pierre Creek',
#        '101 Creek, Bennie Pierre Creek', 'Badlands Creek', 'Silver Lake',
#        'Lake Sakakwea', 'Danners Coulee',
#        'Dickinson City Sewage Lagoons # 3 & 4',
#        'Dickinson City Sewage Lagoons #3 & 4',
#        'Unnamed Trib. Of Square Butte Creek',
#        'Unnamed Trib. To Charbonneau Creek',
#        'Unnamed Stream Trib. Of Missouri River',
#        'Third Cell Of Laggon System',
#        'Unnamed Stream Trib. To Little Missouri', 'North Creek',
#        'Blacktail Creek', 'Black Tail Creek',
#        'Unnamed Trib To Little Goose River',
#        'Unnamed Stream, Trib. To Missouri River',
#        'Unnamed Trib. To Short Creek',
#        'Un-Named Trib Of Charbonneau Creek', 'Buffalo Creek',
#        'Dogtooth Creek', 'Smishek Lake', 'Rice Creek', 'Park Rver',
#        'Unnamed Trib. To Upper Lostwood Lake',
#        'Tributary To South Branch Turtle River',
#        'Mcclusky Canal, Sta. 433+44.8', 'Turtle Creek',
#        'Little Heart River', 'Fresh Water Coulee',
#        'Unnamed Trib. Of Lake Sakakawea',
#        'South Branch Of The Goose River', 'Northfork Creek',
#        'Un-Named Trib To Little Missouri',
#        'Random Creek Trib To Long Lake Creek', 'Culvert Coulee',
#        'Acsc Condenser Pond', "Trib To Kelly'S Slough, Trib To Turtle R",
#        'Skunk Coulee & Flood Detention Dam #1', 'Trib To Turtle River',
#        'Unnamed Draw Trib. To Laporte Coulee',
#        'Unnamed Draw Trib To Russell Drain', 'Mud Creek',
#        'Unnamed Drainage', 'Unnamed Trib. To Long Lake',
#        'Unnamed Drainage Trib To Harriet Lake', 'Lake Audubon',
#        'Waste Ground Water From Malting Process',
#        'Unnamed Trib To West Stump Lake', 'Otter Creek',
#        'Starkweather Coulee', 'Unnamed Trib. To Willow Lake',
#        'Grand Forks County Wrd Flood Detention D', 'Plum Creek',
#        'Unnamed Trib', 'Lightning Creek',
#        'Unnamed Tributary Of Spring Creek',
#        'Unnamed Trib. West Branch Of Short Creek',
#        'Unnamed Trib. Of Thirty Mile Creek', 'Coal Creek',
#        'Unnamed Trib. Of Plum Creek.', 'Laporte Coulee', 'Kelly Slough',
#        'Unnamed Wetland A Trib. Of Lake Audubon.', 'Flat Creek',
#        'Lake Alice', 'Unnamed Trib. To Bennie Pierre Creek',
#        'Unnamed Trib. To Bennnie Pierre Creek',
#        'Unnamed Trib To Bennie Pierre Creek',
#        'Kane/Tacoma/Overgaard Drain', 'Alkali Creek',
#        'Unnamed Trib To Slow Cr, Spring Cr Trib.', 'Dry Lake',
#        'Unnamed Trib. To Cedar Creek',
#        'Unnamed Trib. Of Spring Creek Trib.',
#        'Unnamed Trib. To Indian Creek',
#        'Unnamed Stream Trib. To Buffalo Creek',
#        'Unnamed Trib. To Hans Cr-Spring Cr Trib.',
#        'Lagoons For Residual Ground  Water',
#        'Unnamed Trib. To Spring Creek', 'Unnamed Trib. Of Spring Creek',
#        'Unnamed Trib. Of Edmore Coulee', 'Unnamed Trib. To Edmore Coulee',
#        'Unnamed Stream Trib. To Little Knife R.', 'Antler Creek',
#        'Lake Irvine', 'Unnaned Trib To Missouri River',
#        'Unnamed Trib. Of The Red River', 'Unnamed Trib. Of Red River',
#        'Renwick Dam', 'Unnamed Tributary To Lake George',
#        'Grand Harbor Drainage Trib Six Mile Bay',
#        'Unnamed Trib-Haymarsh Cr Trib Big Muddy',
#        'Unnamed Trib. Of White Earth River',
#        'Unnamed Tributary To The Red River', 'Valley City Sewage Lagoons',
#        'Valley City Municipal Lagoons',
#        'Dickinson City Sewage Lagoon Cells 3 & 4',
#        'Dickinson City Sewage Lagoon Cell #2',
#        'Dickinson Sewage Lagoons #2, 3, & 4',
#        'Big Coulee Waterway Trib Mauvais Coulee',
#        'Big Coulee Waterwau Trib Mauvais Coulee',
#        'Unnamed Trib. Of South Branch Park River',
#        'Unnamed Trib. Of Beaver Holes Creek',
#        'Muskrat Cr Trib Sims Cr Trib Hailstone C',
#        'Unnamed Trib. To Battle Creek', 'Unnamed Drain',
#        'Unnamed Trib. To Coyote Creek',
#        'Unnamed Waterway Trib. To Roger Creek',
#        'Unnamed Waterway Trib. To Deep Creek',
#        'Unnamed Waterway Trib To Heart Butte Ck', 'Goose Creek',
#        'Unnamed Stream Trib. To Goose Creek',
#        'Unnamed Trib. To Little Heart River', 'Pembina County Drain #20',
#        'Murphy Creek Trib. To Spring Creek',
#        'Unnamed Trib To Charbonneau Creek',
#        'Unnamed Tributary To Starkweather Coulee',
#        'Unnamed Drain Trib Starkweather Coulee', 'Unnamed, Crooked Creek',
#        'Unnamed Trib To Heart River',
#        'Unnamed Trib To Square Butte Creek', 'Mount Carmel Dam',
#        'Unnamed Trib. To Maple River', 'Middle Branch Park River',
#        'Unnamed Trib. To Dead Buffalo Lake',
#        'Pats Coulee, Trib To Little Muddy', 'West Cut Bank Creek',
#        'Unnamed Creek Trib To Porcupine Creek', 'Indian Creek',
#        'Spring Creek Trib To Lower Coyote Creek',
#        'Unnamed Trib To East Antelope Creek', 'Scab Creek', 'Twin Lake',
#        'Stack Slough', 'Chain Lake', 'Unnamed/ Tributary Of Beaver Creek',
#        'Oak Creek', 'Random Creek', 'Morrison Lake', 'Long Creek',
#        'Kenner Marsh', 'Island Lake', 'Unnamed Trib Of Coyote Creek',
#        'Unnamed Stream Trib Of Little Muddy Riv.', 'Spiritwood Aquifer'],
#       dtype=object)

# %%
dfPOD['in_WaterSourceTypeCV'] = dfPOD.apply(lambda row: fixEmptyString(row['in_WaterSourceTypeCV']), axis=1)
dfPOD['in_WaterSourceTypeCV'].unique()
# Out:
# array(['Ground Water', 'Surface Water', 'WaDE Unspecified'], dtype=object)

# %%
dfPOD['in_County'] = dfPOD.apply(lambda row: fixEmptyString(row['in_County']), axis=1)
dfPOD['in_County'].unique()
# Out:
# array(['McIntosh', 'McKenzie', 'Mercer', 'Ward', 'Williams', 'Oliver',
#        'Renville', 'Dickey', 'Sargent', 'Dunn', 'Grand Forks', 'McHenry',
#        'Logan', 'Grant', 'Pembina', 'McLean', 'Kidder', 'Bowman',
#        'Stutsman', 'Adams', 'LaMoure', 'Sioux', 'Morton', 'Mountrail',
#        'Griggs', 'Burleigh', 'Ransom', 'Bottineau', 'Steele', 'Billings',
#        'Divide', 'Burke', 'Benson', 'Cavalier', 'Wells', 'Emmons',
#        'Stark', 'Nelson', 'Cass', 'Eddy', 'Barnes', 'Towner', 'Walsh',
#        'Foster', 'Richland', 'Slope', 'Golden Valley', 'Traill',
#        'Hettinger', 'Rolette', 'Ramsey', 'Sheridan', 'Pierce'],
#       dtype=object)

# %%
dfPOD['in_SiteTypeCV'] = dfPOD.apply(lambda row: fixEmptyString(row['in_SiteTypeCV']), axis=1)
dfPOD['in_SiteTypeCV'].unique()
# Out:
# array(['WaDE Unspecified'], dtype=object)

# %%
dfPOD['in_AllocationLegalStatusCV'] = dfPOD.apply(lambda row: fixEmptyString(row['in_AllocationLegalStatusCV']), axis=1)
dfPOD['in_AllocationLegalStatusCV'].unique()
# Out:
# array(['Denied', 'Cancelled', 'InActive', 'Active', 'Deferred', 'Void',
#        'Held In Abeyance', 'WaDE Unspecified'], dtype=object)

# %%
dfPOD['in_BeneficialUseCategory'] = dfPOD.apply(lambda row: fixEmptyString(row['in_BeneficialUseCategory']), axis=1)
dfPOD['in_BeneficialUseCategory'].unique()
# Out:
# array(['Irrigation', 'Industrial', 'Rural Water', 'Fish and Wildlife',
#        'Recreation', 'Stock', 'Municipal', 'Multiple Use',
#        'Flood Control', 'Undefined', 'Power Generation', 'Domestic'],
#       dtype=object)

# %%
# Changing datatype of date fields to fit WaDE.
dfPOD['in_AllocationApplicationDate'] = pd.to_datetime(dfPOD['in_AllocationApplicationDate'], errors = 'coerce')
dfPOD['in_AllocationApplicationDate'] = pd.to_datetime(dfPOD["in_AllocationApplicationDate"].dt.strftime('%m/%d/%Y'))

dfPOD['in_AllocationExpirationDate'] = pd.to_datetime(dfPOD['in_AllocationExpirationDate'], errors = 'coerce')
dfPOD['in_AllocationExpirationDate'] = pd.to_datetime(dfPOD["in_AllocationExpirationDate"].dt.strftime('%m/%d/%Y'))

dfPOD['in_AllocationPriorityDate'] = pd.to_datetime(dfPOD['in_AllocationPriorityDate'], errors = 'coerce')
dfPOD['in_AllocationPriorityDate'] = pd.to_datetime(dfPOD["in_AllocationPriorityDate"].dt.strftime('%m/%d/%Y'))
dfPOD.head()
# Out:
#    WaDEUUID in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0     ndwr0   WaDE Unspecified         Ground Water      WaDE Unspecified
# 1     ndwr1   WaDE Unspecified        Surface Water      WaDE Unspecified
# 2    ndwr10   WaDE Unspecified        Surface Water      WaDE Unspecified
# 3   ndwr100   WaDE Unspecified        Surface Water      WaDE Unspecified
# 4  ndwr1000   WaDE Unspecified        Surface Water      WaDE Unspecified
#
#   in_CoordinateMethodCV in_HUC12 in_HUC8 in_County  in_Latitude  in_Longitude  \
# 0      Centroid of Area                   McIntosh     46.11130     -99.78988
# 1      Centroid of Area                   McKenzie     48.02622    -103.75216
# 2      Centroid of Area                     Mercer     47.28288    -101.86756
# 3      Centroid of Area                       Ward     48.33611    -101.46082
# 4      Centroid of Area                   Williams     48.52694    -103.71934
#
#   in_PODorPOUSite       in_SiteName in_SiteNativeID     in_SiteTypeCV  \
# 0             POD  WaDE Unspecified    POD13007302B  WaDE Unspecified
# 1             POD  WaDE Unspecified   POD15310236CC  WaDE Unspecified
# 2             POD  WaDE Unspecified   POD14408820BB  WaDE Unspecified
# 3             POD  WaDE Unspecified   POD15608415BD  WaDE Unspecified
# 4             POD  WaDE Unspecified   POD15810110AC  WaDE Unspecified
#
#   in_StateCV in_AllocationApplicationDate in_AllocationExpirationDate  \
# 0         ND                          NaT                         NaT
# 1         ND                          NaT                         NaT
# 2         ND                          NaT                         NaT
# 3         ND                   1915-06-09                         NaT
# 4         ND                          NaT                  1994-02-09
#
#    in_AllocationFlow_CFS  in_AllocationVolume_AF in_AllocationLegalStatusCV  \
# 0             1000.00000               204.00000                     Denied
# 1              448.80000                80.00000                  Cancelled
# 2                0.00000                 0.00000                  Cancelled
# 3               46.00000                17.00000                   InActive
# 4             4488.00000                50.00000                  Cancelled
#
#   in_AllocationNativeID           in_AllocationOwner  \
# 0                  4407  KETTERLING ROLAND  LORRAINE
# 1                    1E                HYDE GEORGE H
# 2                    8E                SENERIUS FRED
# 3                   91C   KUDA ALAN P and HUGHESKUDA
# 4                   902                   GREV HENRY
#
#   in_AllocationPriorityDate in_AllocationTimeframeEnd  \
# 0                1991-03-04
# 1                1901-08-15
# 2                1937-12-22
# 3                1915-06-09
# 4                1961-04-10
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_BeneficialUseCategory  \
# 0                                                               Irrigation
# 1                                                               Irrigation
# 2                                                               Irrigation
# 3                                                               Irrigation
# 4                                                               Irrigation
#
#   in_CommunityWaterSupplySystem in_ExemptOfVolumeFlowPriority  \
# 0                                                           0
# 1                                                           0
# 2                                                           0
# 3                                                           0
# 4                                                           0
#
#   in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
# 3
# 4
#
#                          in_WaterAllocationNativeURL
# 0  https://www.swc.nd.gov/info_edu/map_data_resou...
# 1  https://www.swc.nd.gov/info_edu/map_data_resou...
# 2  https://www.swc.nd.gov/info_edu/map_data_resou...
# 3  https://www.swc.nd.gov/info_edu/map_data_resou...
# 4  https://www.swc.nd.gov/info_edu/map_data_resou...

# %%
dfPOD['in_AllocationTimeframeEnd'] = pd.to_datetime(dfPOD['in_AllocationTimeframeEnd'], errors = 'coerce')
dfPOD['in_AllocationTimeframeEnd'] = dfPOD["in_AllocationTimeframeEnd"].dt.strftime('%m/%d')
dfPOD['in_AllocationTimeframeEnd'].unique()
# Out:
# array([nan, '10/15', '06/15', '04/01', '05/15', '05/01'], dtype=object)

# %%
dfPOD['in_AllocationTimeframeStart'] = pd.to_datetime(dfPOD['in_AllocationTimeframeStart'], errors = 'coerce')
dfPOD['in_AllocationTimeframeStart'] = dfPOD["in_AllocationTimeframeStart"].dt.strftime('%m/%d')
dfPOD['in_AllocationTimeframeStart'].unique()
# Out:
# array([nan, '04/01'], dtype=object)

# %%
# Fixing in_AllocationFlow_CFS datatype
dfPOD['in_AllocationFlow_CFS'] = pd.to_numeric(dfPOD['in_AllocationFlow_CFS'], errors='coerce').fillna(0)
dfPOD['in_AllocationFlow_CFS'].unique()
# Out:
# array([1.000000e+03, 4.488000e+02, 0.000000e+00, 4.600000e+01,
#        4.488000e+03, 5.000000e+02, 6.500000e+03, 1.750000e+02,
#        1.500000e+03, 2.000000e+03, 3.000000e+02, 8.750000e+01,
#        9.000000e+02, 2.000000e+02, 1.175000e+03, 1.174000e+03,
#        1.671000e+03, 1.500000e+01, 2.000000e+01, 2.445000e+03,
#        8.500000e+02, 4.000000e+02, 2.730000e+02, 4.500000e+01,
#        9.500000e+02, 7.000000e+02, 1.600000e+03, 4.178400e+04,
#        7.500000e+01, 1.050000e+03, 3.500000e+02, 7.500000e+03,
#        2.400000e+03, 2.450000e+03, 6.000000e+02, 1.250000e+02,
#        8.010000e+03, 4.000000e+01, 3.750000e+02, 1.800000e+03,
#        6.000000e+00, 5.000000e+01, 5.000000e+03, 1.346400e+04,
#        4.250000e+02, 3.500000e+03, 8.000000e+02, 4.380000e+02,
#        2.301000e+03, 2.500000e+02, 3.600000e+02, 1.850000e+03,
#        2.240000e+03, 1.890000e+03, 1.211700e+03, 1.240000e+03,
#        2.500000e+03, 1.550000e+03, 1.300000e+03, 8.750000e+02,
#        2.550000e+03, 4.500000e+03, 7.300000e+01, 4.480000e+01,
#        1.000000e+02, 5.833000e+01, 3.400000e+03, 5.830000e+01,
#        8.250000e+02, 1.200000e+01, 5.700000e+03, 1.950000e+03,
#        6.500000e+02, 4.500000e+02, 2.250000e+03, 1.808000e+03,
#        1.347000e+03, 1.346000e+03, 9.520000e+02, 9.300000e+02,
#        2.150000e+02, 3.500000e+01, 6.000000e+01, 1.050000e+02,
#        3.000000e+03, 2.244000e+02, 1.050190e+04, 3.000000e+00,
#        6.550000e+02, 4.937130e+03, 1.962000e+03, 6.850000e+02,
#        7.500000e+02, 6.732000e+03, 1.900000e+03, 1.122000e+04,
#        2.500000e+01, 1.500000e+02, 1.200000e+03, 8.976000e+03,
#        1.400000e+03, 1.795200e+03, 1.260000e+04, 8.000000e+01,
#        3.600000e+03, 6.230000e+02, 8.317000e+02, 7.729000e+02,
#        4.200000e+03, 3.200000e+02, 3.476000e+02, 1.085000e+03,
#        3.300000e+04, 5.800000e+03, 1.960000e+01, 2.230000e+02,
#        2.875000e+03, 6.900000e+02, 3.635200e+03, 3.200000e+04,
#        1.340000e+03, 1.800000e+01, 2.566000e+03, 4.310000e+02,
#        1.032600e+03, 1.720000e+02, 2.120000e+02, 3.590000e+03,
#        9.300000e+00, 7.330000e+02, 3.650000e+01, 4.398200e+03,
#        1.211800e+03, 1.267000e+03, 6.188000e+02, 6.187000e+02,
#        2.175000e+03, 1.458000e+03, 1.550000e+01, 1.860000e+00,
#        1.100000e+04, 1.234000e+03, 4.700000e+01, 1.805600e+04,
#        1.160000e+02, 8.950000e+02, 2.392000e+02, 3.155000e+03,
#        5.336000e+02, 2.435000e+03, 4.776000e+03, 4.357000e+02,
#        4.020000e+02, 1.470000e+03, 1.022000e+03, 2.722500e+04,
#        1.165850e+03, 1.297210e+03, 2.632000e+03, 5.369400e+02,
#        7.220000e+02, 1.134000e+03, 1.860000e+03, 3.200000e+01,
#        1.105000e+03, 9.050000e+02, 1.420000e+02, 2.296000e+03,
#        2.440000e+04, 2.782000e+03])

# %%
# Fixing in_AllocationVolume_AF datatype
dfPOD['in_AllocationVolume_AF'] = pd.to_numeric(dfPOD['in_AllocationVolume_AF'], errors='coerce').fillna(0)
dfPOD['in_AllocationVolume_AF'].unique()
# Out:
# array([ 204.  ,   80.  ,    0.  , ..., 4480.  ,  391.65, 2420.  ])

# %%
# %%time

# Creating WaDE Custom water source native ID for easy water source identification
# ----------------------------------------------------------------------------------------------------

# Create temp WaterSourceNativeID dataframe of unique water source.
def assignWaterSourceNativeID(colrowValue):
    string1 = str(colrowValue)
    outstring = "WaDEND_WS" + string1
    return outstring

dfWaterSourceNativeID = pd.DataFrame()
dfWaterSourceNativeID['in_WaterSourceName'] = dfPOD['in_WaterSourceName']
dfWaterSourceNativeID['in_WaterSourceTypeCV'] = dfPOD['in_WaterSourceTypeCV']
dfWaterSourceNativeID = dfWaterSourceNativeID.drop_duplicates()

dftemp = pd.DataFrame(index=dfWaterSourceNativeID.index)
dftemp["Count"] = range(1, len(dftemp.index) + 1)
dfWaterSourceNativeID['in_WaterSourceNativeID'] = dftemp.apply(lambda row: assignWaterSourceNativeID(row['Count']), axis=1)

# ----------------------------------------------------------------------------------------------------

# Retreive WaDE Custom water source native ID
def retrieveWaterSourceNativeID(A, B):
    if (A == '' and B == '') or (pd.isnull(A) and pd.isnull(B)):
        outList = ''
    else:
        ml = dfWaterSourceNativeID.loc[(dfWaterSourceNativeID['in_WaterSourceName'] == A) & 
                                       (dfWaterSourceNativeID['in_WaterSourceTypeCV'] == B), 'in_WaterSourceNativeID']
        if not (ml.empty):  # check if the series is empty
            outList = ml.iloc[0]
        else:
            outList = ''
    return outList

dfPOD['in_WaterSourceNativeID'] = dfPOD.apply(lambda row: retrieveWaterSourceNativeID(row['in_WaterSourceName'], row['in_WaterSourceTypeCV']), axis=1)
dfPOD.head(3)
# Out:
# Wall time: 4.89 s
#   WaDEUUID in_WaterSourceName in_WaterSourceTypeCV in_CoordinateAccuracy  \
# 0    ndwr0   WaDE Unspecified         Ground Water      WaDE Unspecified
# 1    ndwr1   WaDE Unspecified        Surface Water      WaDE Unspecified
# 2   ndwr10   WaDE Unspecified        Surface Water      WaDE Unspecified
#
#   in_CoordinateMethodCV in_HUC12 in_HUC8 in_County  in_Latitude  in_Longitude  \
# 0      Centroid of Area                   McIntosh     46.11130     -99.78988
# 1      Centroid of Area                   McKenzie     48.02622    -103.75216
# 2      Centroid of Area                     Mercer     47.28288    -101.86756
#
#   in_PODorPOUSite       in_SiteName in_SiteNativeID     in_SiteTypeCV  \
# 0             POD  WaDE Unspecified    POD13007302B  WaDE Unspecified
# 1             POD  WaDE Unspecified   POD15310236CC  WaDE Unspecified
# 2             POD  WaDE Unspecified   POD14408820BB  WaDE Unspecified
#
#   in_StateCV in_AllocationApplicationDate in_AllocationExpirationDate  \
# 0         ND                          NaT                         NaT
# 1         ND                          NaT                         NaT
# 2         ND                          NaT                         NaT
#
#    in_AllocationFlow_CFS  in_AllocationVolume_AF in_AllocationLegalStatusCV  \
# 0             1000.00000               204.00000                     Denied
# 1              448.80000                80.00000                  Cancelled
# 2                0.00000                 0.00000                  Cancelled
#
#   in_AllocationNativeID           in_AllocationOwner  \
# 0                  4407  KETTERLING ROLAND  LORRAINE
# 1                    1E                HYDE GEORGE H
# 2                    8E                SENERIUS FRED
#
#   in_AllocationPriorityDate in_AllocationTimeframeEnd  \
# 0                1991-03-04                       NaN
# 1                1901-08-15                       NaN
# 2                1937-12-22                       NaN
#
#   in_AllocationTimeframeStart in_AllocationTypeCV in_BeneficialUseCategory  \
# 0                         NaN                                   Irrigation
# 1                         NaN                                   Irrigation
# 2                         NaN                                   Irrigation
#
#   in_CommunityWaterSupplySystem in_ExemptOfVolumeFlowPriority  \
# 0                                                           0
# 1                                                           0
# 2                                                           0
#
#   in_IrrigatedAcreage in_IrrigationMethodCV  \
# 0
# 1
# 2
#
#                          in_WaterAllocationNativeURL in_WaterSourceNativeID
# 0  https://www.swc.nd.gov/info_edu/map_data_resou...             WaDEND_WS1
# 1  https://www.swc.nd.gov/info_edu/map_data_resou...             WaDEND_WS2
# 2  https://www.swc.nd.gov/info_edu/map_data_resou...             WaDEND_WS2

# %% [markdown]
# # Export the Output

# %%
#technique to check datatype of long dataframes.
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.dtypes)
# Out:
# WaDEUUID                        object
# ReasonRemoved                   object
# IncompleteField                 object
# permit_ind                       int64
# permit_num                      object
# pod_index                        int64
# pod                             object
# permit_hol                      object
# priority_d                      object
# use_type                        object
# status                          object
# date_issue                      object
# date_cance                      object
# beneficial                      object
# county                          object
# hu_sub_bas                      object
# aquifer                         object
# subaquifer                      object
# req_acft                       float64
# req_acre                       float64
# req_rate                       float64
# req_storag                     float64
# app_acft                       float64
# app_acre                       float64
# app_rate                       float64
# app_storag                     float64
# pod_status                      object
# source                          object
# irrigation                      object
# source_nam                      object
# mainstem                         int64
# impound_lo                      object
# impound_na                      object
# return_des                      object
# discharge_                      object
# period_sta                      object
# period_end                      object
# return_qua                       int64
# held_acft                      float64
# held_acre                      float64
# held_rate                      float64
# held_stora                     float64
# longitude                      float64
# latitude                       float64
# in_AllocationOwner              object
# in_WaterAllocationNativeURL     object
# dtype: object

# %%
# Export the output dataframe
dfPOD.to_csv('P_NorthDakotaMaster.zip', index=False, compression="zip")  # The output, save as a zip
